# %% [markdown]
# # Various illustrations on IHT-logistic fitting
#
# In this notebook we illustrate the functionalities and behaviors of IHT used for high-dimensional logistic regressions. Specifically, we investigate:
# + How large of an effect size is needed for IHT logistic to recover?
# + Is initializing $\beta$ good in terms of speed and model selection?
# + Is debiasing good in terms of speed and model selection?
# + How does IHT compare to LASSO?

# %%
using Revise
using MendelIHT
using SnpArrays
using DataFrames
using Distributions
using BenchmarkTools
using Random
using LinearAlgebra
using StatsFuns: logistic
# Out:
# ┌ Info: Loading DataFrames support into Gadfly.jl
# └ @ Gadfly /Users/biona001/.julia/packages/Gadfly/09PWZ/src/mapping.jl:228

# %% [markdown]
# # How large of an effect size is needed for IHT logistic to recover?
#
# First we simulate 50 different SNP matrices, with 50 different $\beta \sim N(0, 1)$, to examine reconstruction behavior. Overall, IHT struggles to find effect sizes $< 0.3$. For values in $(0.3, 0.5)$, IHT tends to overestimate the effect size, a consequence of the [MLE estimator for logistic regression is biased in high dimensions](https://arxiv.org/abs/1803.06964).

# %%
#some function that runs poisson regression on different SNP matrices
function run_logistic(n :: Int64, p :: Int64, k :: Int64)    
    #set random seed
    Random.seed!(1111)

    #construct snpmatrix, covariate files, and true model b
    x, maf = simulate_random_snparray(n, p)
    xbm = SnpBitMatrix{Float64}(x, model=ADDITIVE_MODEL, center=true, scale=true); 
    z = ones(n, 1) # non-genetic covariates, just the intercept
    true_b = zeros(p)
    true_b[1:k] = randn(k)
    shuffle!(true_b)
    correct_position = findall(x -> x != 0, true_b)

    #simulate bernoulli data
    y_temp = xbm * true_b
    prob = logistic.(y_temp) #inverse logit link
    y = [rand(Bernoulli(x)) for x in prob]
    y = Float64.(y)

    #compute logistic IHT result
    result = L0_logistic_reg(x, z, y, 1, k, glm = "logistic", debias=false, show_info=false)

    #check result
    estimated_models = result.beta[correct_position]
    true_model = true_b[correct_position]
    compare_model = DataFrame(
        true_β      = true_model, 
        estimated_β = estimated_models)
    
    
    #display results
    @show sort(compare_model, rev=true, by=abs)
    println("Total iteration number was " * string(result.iter))
    println("Total time was " * string(result.time) * "\n\n")
end
# Out:
# run_logistic (generic function with 1 method)

# %%
k = 10
for i = 1:50
    println("running the $i th model")
    n = rand(500:2000) 
    p = rand(1:10)n
    println("n, p = " * string(n) * ", " * string(p))
    run_logistic(n, p, k)
end
# Out:
# running the 1 th model
# n, p = 1624, 6496
# sort(compare_model, rev=true, by=abs) = 10×2 DataFrame
# │ Row │ true_β    │ estimated_β │
# │     │ Float64   │ Float64     │
# ├─────┼───────────┼─────────────┤
# │ 1   │ -2.05135  │ -2.10342    │
# │ 2   │ -1.6632   │ -1.84877    │
# │ 3   │ 1.04428   │ 1.07126     │
# │ 4   │ -0.88058  │ -0.974179   │
# │ 5   │ -0.716923 │ -0.913469   │
# │ 6   │ -0.36553  │ -0.466592   │
# │ 7   │ -0.2244   │ 0.0         │
# │ 8   │ -0.133693 │ 0.0         │
# │ 9   │ -0.132844 │ -0.294623   │
# │ 10  │ 0.125008  │ 0.0         │
# Total iteration number was 37
# Total time was 2.4596590995788574
#
#
# running the 2 th model
# n, p = 901, 8109
# sort(compare_model, rev=true, by=abs) = 10×2 DataFrame
# │ Row │ true_β    │ estimated_β │
# │     │ Float64   │ Float64     │
# ├─────┼───────────┼─────────────┤
# │ 1   │ 1.35335   │ 1.54232     │
# │ 2   │ 1.05911   │ 1.25674     │
# │ 3   │ 1.00805   │ 1.11736     │
# │ 4   │ 0.666356  │ 0.85089     │
# │ 5   │ 0.624684  │ 0.768927    │
# │ 6   │ 0.598996  │ 0.510321    │
# │ 7   │ -0.389762 │ -0.575788   │
# │ 8   │ 0.28084   │ 0.42344     │
# │ 9   │ 0.154611  │ 0.0         │
# │ 10  │ 0.0323682 │ 0.0         │
# Total iteration number was 27
# Total time was 1.222823143005371
#
#
# running the 3 th model
# n, p = 1574, 12592
# sort(compare_model, rev=true, by=abs) = 10×2 DataFrame
# │ Row │ true_β    │ estimated_β │
# │     │ Float64   │ Float64     │
# ├─────┼───────────┼─────────────┤
# │ 1   │ 2.11661   │ 2.2278      │
# │ 2   │ -1.79828  │ -1.81895    │
# │ 3   │ -1.62308  │ -1.6754     │
# │ 4   │ -1.3941   │ -1.38429    │
# │ 5   │ -1.3325   │ -1.29166    │
# │ 6   │ -1.10034  │ -1.04667    │
# │ 7   │ -0.846053 │ -0.870174   │
# │ 8   │ 0.418186  │ 0.0         │
# │ 9   │ -0.400689 │ 0.0         │
# │ 10  │ -0.343114 │ -0.448495   │
# Total iteration number was 43
# Total time was 5.420742988586426
#
#
# running the 4 th model
# n, p = 1871, 3742
# sort(compare_model, rev=true, by=abs) = 10×2 DataFrame
# │ Row │ true_β    │ estimated_β │
# │     │ Float64   │ Float64     │
# ├─────┼───────────┼─────────────┤
# │ 1   │ -1.66266  │ -1.46035    │
# │ 2   │ -1.51798  │ -1.46389    │
# │ 3   │ -1.15514  │ -1.07511    │
# │ 4   │ 0.985101  │ 0.881421    │
# │ 5   │ 0.927609  │ 0.920194    │
# │ 6   │ -0.926257 │ -0.94773    │
# │ 7   │ -0.79122  │ -0.73775    │
# │ 8   │ -0.438507 │ -0.433843   │
# │ 9   │ 0.366289  │ 0.365151    │
# │ 10  │ 0.0940222 │ 0.0         │
# Total iteration number was 21
# Total time was 0.9028940200805664
#
#
# running the 5 th model
# n, p = 922, 7376
# sort(compare_model, rev=true, by=abs) = 10×2 DataFrame
# │ Row │ true_β    │ estimated_β │
# │     │ Float64   │ Float64     │
# ├─────┼───────────┼─────────────┤
# │ 1   │ -1.62323  │ -1.54402    │
# │ 2   │ -1.6006   │ -1.61345    │
# │ 3   │ -1.08959  │ -1.12335    │
# │ 4   │ 0.703922  │ 0.641687    │
# │ 5   │ 0.602497  │ 0.699001    │
# │ 6   │ -0.548307 │ -0.493228   │
# │ 7   │ -0.333132 │ 0.0         │
# │ 8   │ 0.170163  │ 0.0         │
# │ 9   │ 0.0132153 │ 0.0         │
# │ 10  │ 0.0125217 │ 0.0         │
# Total iteration number was 49
# Total time was 2.1572628021240234
#
#
# running the 6 th model
# n, p = 1171, 1171
# sort(compare_model, rev=true, by=abs) = 10×2 DataFrame
# │ Row │ true_β    │ estimated_β │
# │     │ Float64   │ Float64     │
# ├─────┼───────────┼─────────────┤
# │ 1   │ -1.11458  │ -1.11362    │
# │ 2   │ 1.03792   │ 1.0923      │
# │ 3   │ -1.00806  │ -1.18837    │
# │ 4   │ 0.843987  │ 1.01593     │
# │ 5   │ 0.740459  │ 0.829279    │
# │ 6   │ 0.683206  │ 0.708658    │
# │ 7   │ -0.662899 │ -0.750907   │
# │ 8   │ 0.478273  │ 0.453665    │
# │ 9   │ -0.187589 │ 0.0         │
# │ 10  │ 0.0567366 │ 0.0         │
# Total iteration number was 19
# Total time was 0.17290782928466797
#
#
# running the 7 th model
# n, p = 1359, 4077
# sort(compare_model, rev=true, by=abs) = 10×2 DataFrame
# │ Row │ true_β     │ estimated_β │
# │     │ Float64    │ Float64     │
# ├─────┼────────────┼─────────────┤
# │ 1   │ -2.47702   │ -2.42576    │
# │ 2   │ -1.26343   │ -1.36427    │
# │ 3   │ 0.961635   │ 0.985817    │
# │ 4   │ -0.843266  │ -0.82655    │
# │ 5   │ -0.538715  │ -0.507917   │
# │ 6   │ -0.478846  │ -0.412386   │
# │ 7   │ 0.393059   │ 0.435039    │
# │ 8   │ 0.267928   │ 0.0         │
# │ 9   │ 0.262722   │ 0.0         │
# │ 10  │ -0.0408085 │ 0.0         │
# Total iteration number was 29
# Total time was 0.9936721324920654
#
#
# running the 8 th model
# n, p = 1776, 5328
# sort(compare_model, rev=true, by=abs) = 10×2 DataFrame
# │ Row │ true_β     │ estimated_β │
# │     │ Float64    │ Float64     │
# ├─────┼────────────┼─────────────┤
# │ 1   │ 1.81188    │ 1.78784     │
# │ 2   │ 1.25573    │ 1.33944     │
# │ 3   │ 1.04375    │ 1.14448     │
# │ 4   │ 0.828774   │ 0.844355    │
# │ 5   │ -0.580875  │ -0.634866   │
# │ 6   │ 0.455756   │ 0.418893    │
# │ 7   │ -0.299732  │ -0.419761   │
# │ 8   │ 0.223652   │ 0.0         │
# │ 9   │ -0.0585662 │ 0.0         │
# │ 10  │ 0.0539903  │ 0.0         │
# Total iteration number was 728
# Total time was 46.657747983932495
#
#
# running the 9 th model
# n, p = 1661, 9966
# sort(compare_model, rev=true, by=abs) = 10×2 DataFrame
# │ Row │ true_β     │ estimated_β │
# │     │ Float64    │ Float64     │
# ├─────┼────────────┼─────────────┤
# │ 1   │ 1.96145    │ 1.99584     │
# │ 2   │ 1.56006    │ 1.33835     │
# │ 3   │ 1.2575     │ 1.03143     │
# │ 4   │ 1.051      │ 1.08113     │
# │ 5   │ -0.749481  │ -0.786154   │
# │ 6   │ 0.727172   │ 0.499398    │
# │ 7   │ 0.555776   │ 0.549483    │
# │ 8   │ 0.254487   │ 0.0         │
# │ 9   │ 0.208819   │ 0.0         │
# │ 10  │ -0.0457759 │ 0.0         │
# Total iteration number was 31
# Total time was 3.298194169998169
#
#
# running the 10 th model
# n, p = 726, 4356
# sort(compare_model, rev=true, by=abs) = 10×2 DataFrame
# │ Row │ true_β     │ estimated_β │
# │     │ Float64    │ Float64     │
# ├─────┼────────────┼─────────────┤
# │ 1   │ -1.30525   │ -1.46408    │
# │ 2   │ -1.0048    │ -1.18984    │
# │ 3   │ -0.754359  │ -0.720898   │
# │ 4   │ -0.633065  │ -0.610236   │
# │ 5   │ 0.58441    │ 0.499857    │
# │ 6   │ -0.527213  │ -0.617986   │
# │ 7   │ -0.505547  │ -0.474694   │
# │ 8   │ 0.229392   │ 0.0         │
# │ 9   │ -0.21075   │ 0.0         │
# │ 10  │ -0.0362724 │ 0.0         │
# Total iteration number was 19
# Total time was 0.36975693702697754
#
#
# running the 11 th model
# n, p = 1609, 4827
# sort(compare_model, rev=true, by=abs) = 10×2 DataFrame
# │ Row │ true_β     │ estimated_β │
# │     │ Float64    │ Float64     │
# ├─────┼────────────┼─────────────┤
# │ 1   │ -1.48723   │ -1.67029    │
# │ 2   │ -1.35154   │ -1.38906    │
# │ 3   │ 0.757046   │ 0.756692    │
# │ 4   │ -0.712502  │ -0.689254   │
# │ 5   │ 0.476761   │ 0.56896     │
# │ 6   │ -0.370971  │ -0.431844   │
# │ 7   │ 0.365547   │ 0.434201    │
# │ 8   │ 0.207004   │ 0.0         │
# │ 9   │ -0.0642414 │ 0.0         │
# │ 10  │ -0.0543685 │ 0.0         │
# Total iteration number was 37
# Total time was 1.810302972793579
#
#
# running the 12 th model
# n, p = 1266, 8862
# sort(compare_model, rev=true, by=abs) = 10×2 DataFrame
# │ Row │ true_β    │ estimated_β │
# │     │ Float64   │ Float64     │
# ├─────┼───────────┼─────────────┤
# │ 1   │ -1.56158  │ -1.77945    │
# │ 2   │ 1.13199   │ 1.27689     │
# │ 3   │ 0.728572  │ 0.766215    │
# │ 4   │ 0.523206  │ 0.627024    │
# │ 5   │ -0.439814 │ -0.388679   │
# │ 6   │ -0.417062 │ -0.463374   │
# │ 7   │ 0.373848  │ 0.334578    │
# │ 8   │ -0.199641 │ 0.0         │
# │ 9   │ -0.196801 │ -0.319216   │
# │ 10  │ -0.102105 │ 0.0         │
# Total iteration number was 21
# Total time was 1.5022969245910645
#
#
# running the 13 th model
# n, p = 1670, 5010
# sort(compare_model, rev=true, by=abs) = 10×2 DataFrame
# │ Row │ true_β    │ estimated_β │
# │     │ Float64   │ Float64     │
# ├─────┼───────────┼─────────────┤
# │ 1   │ -1.42023  │ -1.40666    │
# │ 2   │ 1.08292   │ 1.10767     │
# │ 3   │ 0.943179  │ 1.02893     │
# │ 4   │ -0.941928 │ -0.935258   │
# │ 5   │ 0.929139  │ 1.00563     │
# │ 6   │ -0.908711 │ -0.916975   │
# │ 7   │ 0.871858  │ 0.978055    │
# │ 8   │ -0.388467 │ -0.30527    │
# │ 9   │ 0.365602  │ 0.302088    │
# │ 10  │ -0.158464 │ 0.0         │
# Total iteration number was 26
# Total time was 1.3953750133514404
#
#
# running the 14 th model
# n, p = 1839, 11034
# sort(compare_model, rev=true, by=abs) = 10×2 DataFrame
# │ Row │ true_β     │ estimated_β │
# │     │ Float64    │ Float64     │
# ├─────┼────────────┼─────────────┤
# │ 1   │ -3.24897   │ -3.15097    │
# │ 2   │ 1.22765    │ 1.17281     │
# │ 3   │ 1.01643    │ 0.996745    │
# │ 4   │ -0.587157  │ -0.698938   │
# │ 5   │ 0.541711   │ 0.65992     │
# │ 6   │ 0.337842   │ 0.0         │
# │ 7   │ -0.294184  │ -0.345693   │
# │ 8   │ -0.25261   │ 0.0         │
# │ 9   │ 0.168232   │ 0.0         │
# │ 10  │ -0.0157443 │ 0.0         │
# Total iteration number was 40
# Total time was 5.054905891418457
#
#
# running the 15 th model
# n, p = 851, 7659
# sort(compare_model, rev=true, by=abs) = 10×2 DataFrame
# │ Row │ true_β    │ estimated_β │
# │     │ Float64   │ Float64     │
# ├─────┼───────────┼─────────────┤
# │ 1   │ 1.93003   │ 1.91308     │
# │ 2   │ -1.64876  │ -1.81837    │
# │ 3   │ -1.49801  │ -1.69722    │
# │ 4   │ 1.276     │ 1.4148      │
# │ 5   │ -1.16426  │ -1.25565    │
# │ 6   │ -0.908868 │ -1.06535    │
# │ 7   │ -0.620847 │ -0.633558   │
# │ 8   │ 0.434513  │ 0.0         │
# │ 9   │ 0.38938   │ 0.471357    │
# │ 10  │ 0.255813  │ 0.435017    │
# Total iteration number was 41
# Total time was 1.6010818481445312
#
#
# running the 16 th model
# n, p = 1990, 9950
# sort(compare_model, rev=true, by=abs) = 10×2 DataFrame
# │ Row │ true_β    │ estimated_β │
# │     │ Float64   │ Float64     │
# ├─────┼───────────┼─────────────┤
# │ 1   │ -2.32695  │ -2.3101     │
# │ 2   │ 1.64429   │ 1.76038     │
# │ 3   │ 1.56346   │ 1.48188     │
# │ 4   │ -1.28913  │ -1.24603    │
# │ 5   │ -1.21556  │ -1.10538    │
# │ 6   │ -0.791805 │ -0.772768   │
# │ 7   │ -0.692881 │ -0.62829    │
# │ 8   │ -0.407953 │ -0.328686   │
# │ 9   │ -0.394982 │ -0.431616   │
# │ 10  │ -0.345479 │ -0.358986   │
# Total iteration number was 42
# Total time was 4.9223010540008545
#
#
# running the 17 th model
# n, p = 774, 2322
# sort(compare_model, rev=true, by=abs) = 10×2 DataFrame
# │ Row │ true_β    │ estimated_β │
# │     │ Float64   │ Float64     │
# ├─────┼───────────┼─────────────┤
# │ 1   │ -2.05673  │ -2.47768    │
# │ 2   │ -1.40458  │ -1.51247    │
# │ 3   │ 1.34936   │ 1.41505     │
# │ 4   │ -1.26072  │ -1.51246    │
# │ 5   │ -0.916964 │ -0.991403   │
# │ 6   │ 0.765253  │ 0.700647    │
# │ 7   │ 0.593436  │ 0.688878    │
# │ 8   │ -0.287766 │ 0.0         │
# │ 9   │ 0.272691  │ 0.0         │
# │ 10  │ -0.071329 │ 0.0         │
# Total iteration number was 40
# Total time was 0.43256497383117676
#
#
# running the 18 th model
# n, p = 1933, 3866
# sort(compare_model, rev=true, by=abs) = 10×2 DataFrame
# │ Row │ true_β    │ estimated_β │
# │     │ Float64   │ Float64     │
# ├─────┼───────────┼─────────────┤
# │ 1   │ 1.82007   │ 2.18652     │
# │ 2   │ -1.37021  │ -1.46503    │
# │ 3   │ 1.35963   │ 1.34203     │
# │ 4   │ 1.34462   │ 1.49288     │
# │ 5   │ 0.793575  │ 0.987866    │
# │ 6   │ -0.579811 │ -0.593107   │
# │ 7   │ 0.485823  │ 0.494404    │
# │ 8   │ 0.317788  │ 0.353394    │
# │ 9   │ 0.171294  │ 0.0         │
# │ 10  │ 0.0429957 │ 0.0         │
# Total iteration number was 40
# Total time was 1.956315040588379
#
#
# running the 19 th model
# n, p = 1463, 7315
# sort(compare_model, rev=true, by=abs) = 10×2 DataFrame
# │ Row │ true_β     │ estimated_β │
# │     │ Float64    │ Float64     │
# ├─────┼────────────┼─────────────┤
# │ 1   │ -0.94507   │ -1.04689    │
# │ 2   │ -0.919687  │ -0.963457   │
# │ 3   │ 0.637492   │ 0.495125    │
# │ 4   │ -0.63304   │ -0.584152   │
# │ 5   │ 0.594451   │ 0.710688    │
# │ 6   │ -0.553039  │ -0.57379    │
# │ 7   │ 0.487197   │ 0.511039    │
# │ 8   │ -0.285272  │ 0.0         │
# │ 9   │ -0.212742  │ -0.251661   │
# │ 10  │ -0.0479313 │ 0.0         │
# Total iteration number was 16
# Total time was 1.1882190704345703
#
#
# running the 20 th model
# n, p = 1236, 1236
# sort(compare_model, rev=true, by=abs) = 10×2 DataFrame
# │ Row │ true_β    │ estimated_β │
# │     │ Float64   │ Float64     │
# ├─────┼───────────┼─────────────┤
# │ 1   │ 1.42914   │ 1.48398     │
# │ 2   │ 1.11697   │ 1.23699     │
# │ 3   │ -0.785457 │ -0.775103   │
# │ 4   │ -0.778152 │ -0.933891   │
# │ 5   │ -0.734436 │ -0.766645   │
# │ 6   │ 0.728718  │ 0.641934    │
# │ 7   │ -0.467061 │ -0.454851   │
# │ 8   │ 0.437626  │ 0.0         │
# │ 9   │ 0.285009  │ 0.327087    │
# │ 10  │ 0.0326945 │ 0.0         │
# Total iteration number was 35
# Total time was 0.3823671340942383
#
#
# running the 21 th model
# n, p = 817, 817
# sort(compare_model, rev=true, by=abs) = 10×2 DataFrame
# │ Row │ true_β     │ estimated_β │
# │     │ Float64    │ Float64     │
# ├─────┼────────────┼─────────────┤
# │ 1   │ 2.80778    │ 3.34588     │
# │ 2   │ -1.5505    │ -1.80391    │
# │ 3   │ -1.21051   │ -1.26659    │
# │ 4   │ 1.18934    │ 1.62729     │
# │ 5   │ -1.1225    │ -1.48594    │
# │ 6   │ -0.922376  │ -1.25546    │
# │ 7   │ 0.608591   │ 0.701211    │
# │ 8   │ -0.267894  │ 0.0         │
# │ 9   │ 0.10415    │ 0.0         │
# │ 10  │ -0.0932952 │ 0.0         │
# Total iteration number was 73
# Total time was 0.34914398193359375
#
#
# running the 22 th model
# n, p = 1123, 2246
# sort(compare_model, rev=true, by=abs) = 10×2 DataFrame
# │ Row │ true_β     │ estimated_β │
# │     │ Float64    │ Float64     │
# ├─────┼────────────┼─────────────┤
# │ 1   │ 1.75353    │ 1.73899     │
# │ 2   │ -0.923176  │ -0.849299   │
# │ 3   │ -0.757541  │ -0.715205   │
# │ 4   │ 0.746789   │ 0.786379    │
# │ 5   │ -0.457258  │ -0.501073   │
# │ 6   │ 0.444949   │ 0.425047    │
# │ 7   │ 0.143731   │ 0.0         │
# │ 8   │ -0.0413846 │ 0.0         │
# │ 9   │ -0.0345622 │ 0.0         │
# │ 10  │ -0.0266689 │ 0.0         │
# Total iteration number was 21
# Total time was 0.37421107292175293
#
#
# running the 23 th model
# n, p = 1232, 12320
# sort(compare_model, rev=true, by=abs) = 10×2 DataFrame
# │ Row │ true_β     │ estimated_β │
# │     │ Float64    │ Float64     │
# ├─────┼────────────┼─────────────┤
# │ 1   │ -2.27565   │ -2.85272    │
# │ 2   │ 1.9063     │ 1.9684      │
# │ 3   │ 1.87744    │ 1.97301     │
# │ 4   │ 0.903008   │ 0.861059    │
# │ 5   │ 0.880022   │ 0.866776    │
# │ 6   │ -0.683811  │ -0.632245   │
# │ 7   │ 0.302575   │ 0.0         │
# │ 8   │ 0.264723   │ 0.0         │
# │ 9   │ -0.198838  │ 0.0         │
# │ 10  │ -0.0600126 │ 0.0         │
# Total iteration number was 905
# Total time was 107.1111090183258
#
#
# running the 24 th model
# n, p = 1460, 1460
# sort(compare_model, rev=true, by=abs) = 10×2 DataFrame
# │ Row │ true_β    │ estimated_β │
# │     │ Float64   │ Float64     │
# ├─────┼───────────┼─────────────┤
# │ 1   │ 1.92572   │ 2.08802     │
# │ 2   │ 1.85984   │ 1.9232      │
# │ 3   │ -1.67251  │ -1.69157    │
# │ 4   │ -1.27584  │ -1.28888    │
# │ 5   │ 0.778674  │ 0.743095    │
# │ 6   │ -0.629745 │ -0.717545   │
# │ 7   │ 0.441021  │ 0.421481    │
# │ 8   │ 0.248212  │ 0.0         │
# │ 9   │ -0.178754 │ 0.0         │
# │ 10  │ -0.111893 │ 0.0         │
# Total iteration number was 41
# Total time was 0.6273720264434814
#
#
# running the 25 th model
# n, p = 1340, 10720
# sort(compare_model, rev=true, by=abs) = 10×2 DataFrame
# │ Row │ true_β    │ estimated_β │
# │     │ Float64   │ Float64     │
# ├─────┼───────────┼─────────────┤
# │ 1   │ -1.74899  │ -1.87634    │
# │ 2   │ 1.54708   │ 1.46289     │
# │ 3   │ 1.46002   │ 1.39252     │
# │ 4   │ -1.1544   │ -1.02546    │
# │ 5   │ 1.03364   │ 0.92581     │
# │ 6   │ -0.759898 │ -0.608475   │
# │ 7   │ -0.513884 │ -0.433548   │
# │ 8   │ -0.333532 │ 0.0         │
# │ 9   │ -0.330247 │ 0.0         │
# │ 10  │ 0.27279   │ 0.0         │
# Total iteration number was 38
# Total time was 3.925281047821045
#
#
# running the 26 th model
# n, p = 1760, 12320
# sort(compare_model, rev=true, by=abs) = 10×2 DataFrame
# │ Row │ true_β    │ estimated_β │
# │     │ Float64   │ Float64     │
# ├─────┼───────────┼─────────────┤
# │ 1   │ 2.41405   │ 2.82013     │
# │ 2   │ 1.8143    │ 2.07193     │
# │ 3   │ 1.41121   │ 1.68187     │
# │ 4   │ -0.542373 │ -0.80452    │
# │ 5   │ -0.533491 │ -0.639757   │
# │ 6   │ -0.395936 │ 0.0         │
# │ 7   │ -0.370822 │ -0.454617   │
# │ 8   │ 0.262942  │ 0.339431    │
# │ 9   │ -0.105587 │ 0.0         │
# │ 10  │ 0.0860989 │ 0.0         │
# Total iteration number was 43
# Total time was 6.226262092590332
#
#
# running the 27 th model
# n, p = 1027, 5135
# sort(compare_model, rev=true, by=abs) = 10×2 DataFrame
# │ Row │ true_β    │ estimated_β │
# │     │ Float64   │ Float64     │
# ├─────┼───────────┼─────────────┤
# │ 1   │ 1.45543   │ 1.5624      │
# │ 2   │ 1.15496   │ 1.33519     │
# │ 3   │ -1.12237  │ -0.85725    │
# │ 4   │ -1.10444  │ -1.03484    │
# │ 5   │ -0.742725 │ -0.786365   │
# │ 6   │ -0.72998  │ -0.751407   │
# │ 7   │ -0.58933  │ -0.560561   │
# │ 8   │ -0.539981 │ -0.703143   │
# │ 9   │ -0.332738 │ -0.417268   │
# │ 10  │ -0.108421 │ 0.0         │
# Total iteration number was 33
# Total time was 1.075767993927002
#
#
# running the 28 th model
# n, p = 810, 8100
# sort(compare_model, rev=true, by=abs) = 10×2 DataFrame
# │ Row │ true_β     │ estimated_β │
# │     │ Float64    │ Float64     │
# ├─────┼────────────┼─────────────┤
# │ 1   │ 2.23902    │ 2.86166     │
# │ 2   │ -1.47788   │ -1.78342    │
# │ 3   │ 1.18131    │ 1.58503     │
# │ 4   │ -0.905787  │ -0.863516   │
# │ 5   │ 0.7394     │ 0.973423    │
# │ 6   │ 0.64879    │ 0.749674    │
# │ 7   │ -0.574168  │ -0.725626   │
# │ 8   │ -0.168031  │ 0.0         │
# │ 9   │ -0.0804165 │ 0.0         │
# │ 10  │ 0.0364724  │ 0.0         │
# Total iteration number was 55
# Total time was 2.236098051071167
#
#
# running the 29 th model
# n, p = 1486, 2972
# sort(compare_model, rev=true, by=abs) = 10×2 DataFrame
# │ Row │ true_β     │ estimated_β │
# │     │ Float64    │ Float64     │
# ├─────┼────────────┼─────────────┤
# │ 1   │ -2.16289   │ -2.43347    │
# │ 2   │ -1.85326   │ -1.98898    │
# │ 3   │ 1.8025     │ 1.82406     │
# │ 4   │ 1.34115    │ 0.987012    │
# │ 5   │ -1.30403   │ -1.45319    │
# │ 6   │ 0.571003   │ 0.586654    │
# │ 7   │ -0.511641  │ -0.601213   │
# │ 8   │ -0.308149  │ -0.316477   │
# │ 9   │ -0.23626   │ 0.0         │
# │ 10  │ -0.0987839 │ 0.0         │
# Total iteration number was 85
# Total time was 2.452030897140503
#
#
# running the 30 th model
# n, p = 1767, 14136
# sort(compare_model, rev=true, by=abs) = 10×2 DataFrame
# │ Row │ true_β    │ estimated_β │
# │     │ Float64   │ Float64     │
# ├─────┼───────────┼─────────────┤
# │ 1   │ 2.04793   │ 2.23838     │
# │ 2   │ -1.63474  │ -1.87155    │
# │ 3   │ 1.26826   │ 1.44808     │
# │ 4   │ 0.991275  │ 1.10762     │
# │ 5   │ 0.936849  │ 1.14168     │
# │ 6   │ 0.796933  │ 0.88313     │
# │ 7   │ 0.707282  │ 0.809017    │
# │ 8   │ -0.523601 │ -0.483496   │
# │ 9   │ -0.253172 │ 0.0         │
# │ 10  │ -0.142495 │ 0.0         │
# Total iteration number was 42
# Total time was 6.529127836227417
#
#
# running the 31 th model
# n, p = 1156, 6936
# sort(compare_model, rev=true, by=abs) = 10×2 DataFrame
# │ Row │ true_β    │ estimated_β │
# │     │ Float64   │ Float64     │
# ├─────┼───────────┼─────────────┤
# │ 1   │ -1.8115   │ -1.97727    │
# │ 2   │ 0.947826  │ 1.06903     │
# │ 3   │ -0.89642  │ -0.968864   │
# │ 4   │ -0.798595 │ -1.04749    │
# │ 5   │ 0.72987   │ 0.81817     │
# │ 6   │ 0.453536  │ 0.463259    │
# │ 7   │ -0.433791 │ -0.482973   │
# │ 8   │ 0.289975  │ 0.43887     │
# │ 9   │ 0.227891  │ 0.503702    │
# │ 10  │ 0.169853  │ 0.0         │
# Total iteration number was 23
# Total time was 1.263948917388916
#
#
# running the 32 th model
# n, p = 1729, 1729
# sort(compare_model, rev=true, by=abs) = 10×2 DataFrame
# │ Row │ true_β    │ estimated_β │
# │     │ Float64   │ Float64     │
# ├─────┼───────────┼─────────────┤
# │ 1   │ 1.05582   │ 1.07634     │
# │ 2   │ -0.876439 │ -0.872198   │
# │ 3   │ -0.756344 │ -0.764847   │
# │ 4   │ -0.714105 │ -0.70231    │
# │ 5   │ -0.634108 │ -0.493481   │
# │ 6   │ 0.496922  │ 0.500529    │
# │ 7   │ 0.493271  │ 0.402421    │
# │ 8   │ -0.403382 │ -0.351245   │
# │ 9   │ 0.354554  │ 0.465305    │
# │ 10  │ -0.217393 │ -0.323953   │
# Total iteration number was 11
# Total time was 0.23542380332946777
#
#
# running the 33 th model
# n, p = 1328, 13280
# sort(compare_model, rev=true, by=abs) = 10×2 DataFrame
# │ Row │ true_β     │ estimated_β │
# │     │ Float64    │ Float64     │
# ├─────┼────────────┼─────────────┤
# │ 1   │ 1.5523     │ 1.62104     │
# │ 2   │ -1.47872   │ -1.2908     │
# │ 3   │ -1.17313   │ -1.22312    │
# │ 4   │ 0.990601   │ 1.06508     │
# │ 5   │ -0.585388  │ -0.698412   │
# │ 6   │ -0.573331  │ -0.444557   │
# │ 7   │ 0.513728   │ 0.44416     │
# │ 8   │ 0.447639   │ 0.445792    │
# │ 9   │ -0.0965289 │ 0.0         │
# │ 10  │ -0.0648543 │ 0.0         │
# Total iteration number was 40
# Total time was 4.728000164031982
#
#
# running the 34 th model
# n, p = 1253, 12530
# sort(compare_model, rev=true, by=abs) = 10×2 DataFrame
# │ Row │ true_β     │ estimated_β │
# │     │ Float64    │ Float64     │
# ├─────┼────────────┼─────────────┤
# │ 1   │ -1.86609   │ -2.2039     │
# │ 2   │ -1.36153   │ -1.67847    │
# │ 3   │ 0.633528   │ 0.676801    │
# │ 4   │ -0.443816  │ -0.421177   │
# │ 5   │ -0.312523  │ 0.0         │
# │ 6   │ -0.249978  │ 0.0         │
# │ 7   │ -0.233095  │ 0.0         │
# │ 8   │ -0.104702  │ 0.0         │
# │ 9   │ -0.0956895 │ 0.0         │
# │ 10  │ -0.0786692 │ 0.0         │
# Total iteration number was 22
# Total time was 2.2325329780578613
#
#
# running the 35 th model
# n, p = 647, 3235
# sort(compare_model, rev=true, by=abs) = 10×2 DataFrame
# │ Row │ true_β    │ estimated_β │
# │     │ Float64   │ Float64     │
# ├─────┼───────────┼─────────────┤
# │ 1   │ -2.79434  │ -2.86307    │
# │ 2   │ 1.75268   │ 1.88781     │
# │ 3   │ -1.45683  │ -1.65445    │
# │ 4   │ -1.30689  │ -1.24068    │
# │ 5   │ -1.27281  │ -1.07521    │
# │ 6   │ 1.09441   │ 1.25298     │
# │ 7   │ -1.02647  │ -1.05344    │
# │ 8   │ -0.797459 │ -1.00236    │
# │ 9   │ -0.726904 │ -0.820476   │
# │ 10  │ -0.156497 │ 0.0         │
# Total iteration number was 41
# Total time was 0.5322000980377197
#
#
# running the 36 th model
# n, p = 1979, 5937
# sort(compare_model, rev=true, by=abs) = 10×2 DataFrame
# │ Row │ true_β    │ estimated_β │
# │     │ Float64   │ Float64     │
# ├─────┼───────────┼─────────────┤
# │ 1   │ -2.58333  │ -2.54167    │
# │ 2   │ 1.98569   │ 1.96488     │
# │ 3   │ 1.6089    │ 1.51675     │
# │ 4   │ -1.55172  │ -1.47453    │
# │ 5   │ -1.49498  │ -1.36148    │
# │ 6   │ -0.830406 │ -0.778068   │
# │ 7   │ -0.826718 │ -0.805897   │
# │ 8   │ 0.762603  │ 0.774343    │
# │ 9   │ 0.705577  │ 0.627781    │
# │ 10  │ -0.289508 │ 0.0         │
# Total iteration number was 41
# Total time was 3.035362958908081
#
#
# running the 37 th model
# n, p = 1671, 3342
# sort(compare_model, rev=true, by=abs) = 10×2 DataFrame
# │ Row │ true_β   │ estimated_β │
# │     │ Float64  │ Float64     │
# ├─────┼──────────┼─────────────┤
# │ 1   │ -2.27418 │ -2.08353    │
# │ 2   │ 1.34674  │ 1.32621     │
# │ 3   │ 1.2957   │ 1.45365     │
# │ 4   │ -1.0025  │ -1.08914    │
# │ 5   │ 0.725697 │ 0.773763    │
# │ 6   │ 0.477225 │ 0.534929    │
# │ 7   │ 0.458646 │ 0.48075     │
# │ 8   │ 0.315854 │ 0.396669    │
# │ 9   │ 0.2523   │ 0.41508     │
# │ 10  │ 0.203635 │ 0.0         │
# Total iteration number was 42
# Total time was 1.6104609966278076
#
#
# running the 38 th model
# n, p = 1116, 6696
# sort(compare_model, rev=true, by=abs) = 10×2 DataFrame
# │ Row │ true_β     │ estimated_β │
# │     │ Float64    │ Float64     │
# ├─────┼────────────┼─────────────┤
# │ 1   │ -1.23111   │ -1.2855     │
# │ 2   │ -0.861272  │ -0.858593   │
# │ 3   │ 0.706027   │ 0.860695    │
# │ 4   │ -0.681722  │ -0.641049   │
# │ 5   │ 0.665287   │ 0.761316    │
# │ 6   │ -0.408873  │ -0.452095   │
# │ 7   │ -0.265808  │ -0.297064   │
# │ 8   │ 0.129552   │ 0.0         │
# │ 9   │ -0.106946  │ 0.0         │
# │ 10  │ 0.00908638 │ 0.0         │
# Total iteration number was 19
# Total time was 1.011059045791626
#
#
# running the 39 th model
# n, p = 1650, 8250
# sort(compare_model, rev=true, by=abs) = 10×2 DataFrame
# │ Row │ true_β    │ estimated_β │
# │     │ Float64   │ Float64     │
# ├─────┼───────────┼─────────────┤
# │ 1   │ -2.06723  │ -2.12777    │
# │ 2   │ -1.34791  │ -1.02296    │
# │ 3   │ -0.74102  │ -0.715814   │
# │ 4   │ 0.635122  │ 0.64238     │
# │ 5   │ -0.551715 │ -0.481869   │
# │ 6   │ -0.437631 │ -0.40838    │
# │ 7   │ 0.388809  │ 0.424771    │
# │ 8   │ 0.377165  │ 0.288219    │
# │ 9   │ 0.0825302 │ 0.0         │
# │ 10  │ 0.068548  │ 0.0         │
# Total iteration number was 20
# Total time was 1.8140449523925781
#
#
# running the 40 th model
# n, p = 553, 5530
# sort(compare_model, rev=true, by=abs) = 10×2 DataFrame
# │ Row │ true_β     │ estimated_β │
# │     │ Float64    │ Float64     │
# ├─────┼────────────┼─────────────┤
# │ 1   │ -3.00197   │ -3.73322    │
# │ 2   │ -2.40256   │ -2.6582     │
# │ 3   │ -1.94933   │ -2.36199    │
# │ 4   │ -1.0232    │ -1.10616    │
# │ 5   │ -0.928525  │ -0.848033   │
# │ 6   │ 0.817756   │ 0.963207    │
# │ 7   │ 0.631153   │ 1.02698     │
# │ 8   │ -0.289697  │ 0.0         │
# │ 9   │ -0.0597074 │ 0.0         │
# │ 10  │ 0.0512605  │ 0.0         │
# Total iteration number was 76
# Total time was 1.6063199043273926
#
#
# running the 41 th model
# n, p = 1213, 9704
# sort(compare_model, rev=true, by=abs) = 10×2 DataFrame
# │ Row │ true_β     │ estimated_β │
# │     │ Float64    │ Float64     │
# ├─────┼────────────┼─────────────┤
# │ 1   │ 2.3759     │ 2.06704     │
# │ 2   │ -1.78786   │ -1.58065    │
# │ 3   │ -1.7317    │ -1.55013    │
# │ 4   │ 1.27726    │ 1.06909     │
# │ 5   │ 1.20703    │ 1.38374     │
# │ 6   │ -0.500576  │ -0.413011   │
# │ 7   │ 0.46492    │ 0.602777    │
# │ 8   │ 0.306673   │ 0.517282    │
# │ 9   │ -0.254864  │ 0.0         │
# │ 10  │ -0.0250811 │ 0.0         │
# Total iteration number was 41
# Total time was 3.1095468997955322
#
#
# running the 42 th model
# n, p = 742, 2226
# sort(compare_model, rev=true, by=abs) = 10×2 DataFrame
# │ Row │ true_β    │ estimated_β │
# │     │ Float64   │ Float64     │
# ├─────┼───────────┼─────────────┤
# │ 1   │ -1.08468  │ -1.08454    │
# │ 2   │ -0.980643 │ -0.956679   │
# │ 3   │ -0.81542  │ -0.767003   │
# │ 4   │ 0.795792  │ 0.703582    │
# │ 5   │ -0.791436 │ -0.846606   │
# │ 6   │ 0.722377  │ 0.649988    │
# │ 7   │ -0.290129 │ 0.0         │
# │ 8   │ 0.171897  │ 0.0         │
# │ 9   │ 0.128792  │ 0.0         │
# │ 10  │ 0.0224033 │ 0.0         │
# Total iteration number was 20
# Total time was 0.21429014205932617
#
#
# running the 43 th model
# n, p = 1648, 13184
# sort(compare_model, rev=true, by=abs) = 10×2 DataFrame
# │ Row │ true_β    │ estimated_β │
# │     │ Float64   │ Float64     │
# ├─────┼───────────┼─────────────┤
# │ 1   │ -2.00259  │ -2.04114    │
# │ 2   │ 1.70459   │ 1.7924      │
# │ 3   │ -1.10627  │ -1.16194    │
# │ 4   │ -0.705703 │ -0.676075   │
# │ 5   │ 0.511923  │ 0.584529    │
# │ 6   │ 0.479957  │ 0.548169    │
# │ 7   │ 0.368032  │ 0.278075    │
# │ 8   │ -0.313841 │ -0.362203   │
# │ 9   │ 0.192027  │ 0.0         │
# │ 10  │ 0.156551  │ 0.0         │
# Total iteration number was 35
# Total time was 4.789448976516724
#
#
# running the 44 th model
# n, p = 560, 5040
# sort(compare_model, rev=true, by=abs) = 10×2 DataFrame
# │ Row │ true_β    │ estimated_β │
# │     │ Float64   │ Float64     │
# ├─────┼───────────┼─────────────┤
# │ 1   │ 2.64314   │ 3.50386     │
# │ 2   │ 2.35013   │ 3.18511     │
# │ 3   │ -1.51793  │ -1.5071     │
# │ 4   │ -0.999189 │ -1.21736    │
# │ 5   │ -0.650759 │ -1.28485    │
# │ 6   │ 0.590481  │ 0.0         │
# │ 7   │ -0.406826 │ 0.0         │
# │ 8   │ -0.373732 │ 0.0         │
# │ 9   │ 0.370067  │ 0.815187    │
# │ 10  │ 0.143967  │ 0.0         │
# Total iteration number was 72
# Total time was 1.3430888652801514
#
#
# running the 45 th model
# n, p = 642, 6420
# sort(compare_model, rev=true, by=abs) = 10×2 DataFrame
# │ Row │ true_β    │ estimated_β │
# │     │ Float64   │ Float64     │
# ├─────┼───────────┼─────────────┤
# │ 1   │ 0.996838  │ 1.31633     │
# │ 2   │ 0.996319  │ 1.15074     │
# │ 3   │ 0.972837  │ 1.85346     │
# │ 4   │ 0.641787  │ 0.586495    │
# │ 5   │ 0.62325   │ 0.583395    │
# │ 6   │ 0.620015  │ 0.742832    │
# │ 7   │ 0.302947  │ 0.0         │
# │ 8   │ -0.186501 │ 0.0         │
# │ 9   │ -0.173358 │ 0.0         │
# │ 10  │ 0.127606  │ 0.0         │
# Total iteration number was 87
# Total time was 2.3117458820343018
#
#
# running the 46 th model
# n, p = 559, 4472
# sort(compare_model, rev=true, by=abs) = 10×2 DataFrame
# │ Row │ true_β    │ estimated_β │
# │     │ Float64   │ Float64     │
# ├─────┼───────────┼─────────────┤
# │ 1   │ 1.03395   │ 1.0082      │
# │ 2   │ 1.00719   │ 1.06928     │
# │ 3   │ -0.753298 │ -0.784509   │
# │ 4   │ -0.685864 │ -0.4436     │
# │ 5   │ 0.656989  │ 0.66626     │
# │ 6   │ 0.602886  │ 0.47343     │
# │ 7   │ -0.377927 │ 0.0         │
# │ 8   │ 0.212801  │ 0.0         │
# │ 9   │ 0.109875  │ 0.0         │
# │ 10  │ 0.0114035 │ 0.0         │
# Total iteration number was 15
# Total time was 0.24970793724060059
#
#
# running the 47 th model
# n, p = 1341, 13410
# sort(compare_model, rev=true, by=abs) = 10×2 DataFrame
# │ Row │ true_β    │ estimated_β │
# │     │ Float64   │ Float64     │
# ├─────┼───────────┼─────────────┤
# │ 1   │ -2.06092  │ -2.16146    │
# │ 2   │ 1.74597   │ 0.0         │
# │ 3   │ -1.47255  │ -1.46413    │
# │ 4   │ 1.30032   │ 1.51738     │
# │ 5   │ 0.869211  │ 1.05613     │
# │ 6   │ -0.757717 │ -0.913647   │
# │ 7   │ -0.499005 │ -0.582652   │
# │ 8   │ 0.430442  │ 0.465705    │
# │ 9   │ 0.213782  │ 0.0         │
# │ 10  │ 0.111029  │ 0.0         │
# Total iteration number was 38
# Total time was 4.365494966506958
#
#
# running the 48 th model
# n, p = 1965, 7860
# sort(compare_model, rev=true, by=abs) = 10×2 DataFrame
# │ Row │ true_β      │ estimated_β │
# │     │ Float64     │ Float64     │
# ├─────┼─────────────┼─────────────┤
# │ 1   │ 2.43343     │ 2.28004     │
# │ 2   │ -1.65661    │ -0.832736   │
# │ 3   │ 1.22537     │ 1.1066      │
# │ 4   │ -0.665419   │ -0.581942   │
# │ 5   │ -0.560939   │ -0.504986   │
# │ 6   │ 0.502965    │ 0.325991    │
# │ 7   │ 0.441303    │ 0.489012    │
# │ 8   │ 0.342963    │ 0.362219    │
# │ 9   │ -0.136521   │ 0.0         │
# │ 10  │ -0.00623083 │ 0.0         │
# Total iteration number was 140
# Total time was 14.669358968734741
#
#
# running the 49 th model
# n, p = 1926, 13482
# sort(compare_model, rev=true, by=abs) = 10×2 DataFrame
# │ Row │ true_β     │ estimated_β │
# │     │ Float64    │ Float64     │
# ├─────┼────────────┼─────────────┤
# │ 1   │ -2.04514   │ -2.46388    │
# │ 2   │ -1.36905   │ -1.42438    │
# │ 3   │ -1.31051   │ -1.30684    │
# │ 4   │ -1.04578   │ -1.02386    │
# │ 5   │ 0.913988   │ 0.857411    │
# │ 6   │ -0.494928  │ -0.509727   │
# │ 7   │ -0.408768  │ -0.415278   │
# │ 8   │ 0.203675   │ 0.276337    │
# │ 9   │ -0.0447455 │ 0.0         │
# │ 10  │ 0.019599   │ 0.0         │
# Total iteration number was 81
# Total time was 12.805602073669434
#
#
# running the 50 th model
# n, p = 1374, 1374
# sort(compare_model, rev=true, by=abs) = 10×2 DataFrame
# │ Row │ true_β    │ estimated_β │
# │     │ Float64   │ Float64     │
# ├─────┼───────────┼─────────────┤
# │ 1   │ -1.63856  │ -1.61244    │
# │ 2   │ 1.38168   │ 1.36196     │
# │ 3   │ -1.07848  │ -1.06983    │
# │ 4   │ 0.961701  │ 1.07802     │
# │ 5   │ -0.754331 │ -0.729431   │
# │ 6   │ 0.535554  │ 0.523       │
# │ 7   │ -0.45358  │ -0.532943   │
# │ 8   │ -0.448219 │ -0.406673   │
# │ 9   │ 0.431375  │ 0.0         │
# │ 10  │ -0.363829 │ -0.299707   │
# Total iteration number was 194
# Total time was 2.5909628868103027

# %% [markdown]
# # Is initializing $\beta$ good in terms of speed and model selection?
#
# When initilizing the model, we can fit a bunch of univariate regressions to find a good initial approximation to the model before starting the IHT algorithm. Doing so introduces extra computational cost, but could reduce total iteration number and/or improve model selection. This section examines whether this is useful for logistic regression (ans: it is not).

# %%
function test_logistic_init(n :: Int64, p :: Int64, k :: Int64)    
    #set random seed
    Random.seed!(1111)

    #construct snpmatrix, covariate files, and true model b
    x, maf = simulate_random_snparray(n, p)
    xbm = SnpBitMatrix{Float64}(x, model=ADDITIVE_MODEL, center=true, scale=true); 
    z = ones(n, 1) # non-genetic covariates, just the intercept
    true_b = zeros(p)
    true_b[1:k] = randn(k)
    shuffle!(true_b)
    correct_position = findall(x -> x != 0, true_b)

    #simulate bernoulli data
    y_temp = xbm * true_b
    prob = logistic.(y_temp) #inverse logit link
    y = [rand(Bernoulli(x)) for x in prob]
    y = Float64.(y)

    #compute poisson IHT result
    no_init = L0_logistic_reg(x, z, y, 1, k, glm = "logistic", debias=false, convg=false, show_info=false, init=false)
    yes_init = L0_logistic_reg(x, z, y, 1, k, glm = "logistic", debias=false, convg=false, show_info=false, init=true)
    
    #check result
    est_model_init = yes_init.beta[correct_position]
    est_model_no_init = no_init.beta[correct_position]
    true_model = true_b[correct_position]
    compare_model = DataFrame(
        true_β      = true_model, 
        est_β_no_init = est_model_no_init,
        est_β_with_init = est_model_init)
        
    #display results
    @show sort(compare_model, rev=true, by=abs)
    println("No initilialization:")
    println("    Iter =" * string(no_init.iter))
    println("    Time =" * string(no_init.time))
    println("Yes initilialization:")
    println("    Iter = " * string(yes_init.iter))
    println("    Time = " * string(yes_init.time) * "\n\n")
    
    #return summary statistic
    yes_init_found = length(findall(!iszero, est_model_init))
    no_init_found = length(findall(!iszero, est_model_no_init))
    yes_init_time = yes_init.time
    no_init_time = no_init.time
    return yes_init_found, no_init_found, yes_init_time, no_init_time
end
# Out:
# test_logistic_init (generic function with 1 method)

# %%
k = 10
yes_init_total_found = 0
no_init_total_found = 0
yes_init_total_time = 0
no_init_total_time = 0

iter = 50
for i = 1:iter
    println("running the $i th model")
    n = rand(500:2000) 
    p = rand(1:10)n
    println("n, p = " * string(n) * ", " * string(p))
    yif, nif, yit, nit = test_logistic_init(n, p, k)
    yes_init_total_found += yif
    no_init_total_found += nif
    yes_init_total_time += yit
    no_init_total_time += nit
end
println("With initialization, found $yes_init_total_found " * "predictors out of " * string(k*iter))
println("With initialization, average time was " * string(yes_init_total_time/iter))
println("Without initialization, found $no_init_total_found " * "predictors out of " * string(k*iter))
println("Without initialization, average time was " * string(no_init_total_time/iter))
# Out:
# running the 1 th model
# n, p = 744, 5952
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β    │ est_β_no_init │ est_β_with_init │
# │     │ Float64   │ Float64       │ Float64         │
# ├─────┼───────────┼───────────────┼─────────────────┤
# │ 1   │ -1.37566  │ -1.49858      │ -1.52421        │
# │ 2   │ -0.912635 │ -1.16557      │ -1.26168        │
# │ 3   │ -0.879982 │ -1.10409      │ -1.17207        │
# │ 4   │ -0.65125  │ -0.814297     │ -0.8513         │
# │ 5   │ 0.579642  │ 0.0           │ 0.0             │
# │ 6   │ -0.5352   │ -0.719459     │ -0.749592       │
# │ 7   │ 0.30467   │ 0.514603      │ 0.459092        │
# │ 8   │ -0.234034 │ 0.0           │ 0.0             │
# │ 9   │ 0.201716  │ 0.401632      │ 0.41397         │
# │ 10  │ -0.153747 │ 0.0           │ 0.0             │
# No initilialization:
#     Iter =20
#     Time =0.5437190532684326
# Yes initilialization:
#     Iter = 44
#     Time = 2.3536880016326904
#
#
# running the 2 th model
# n, p = 693, 4851
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β     │ est_β_no_init │ est_β_with_init │
# │     │ Float64    │ Float64       │ Float64         │
# ├─────┼────────────┼───────────────┼─────────────────┤
# │ 1   │ -2.78366   │ -3.25241      │ -3.21008        │
# │ 2   │ 2.66146    │ 2.62187       │ 2.55562         │
# │ 3   │ -0.903621  │ -0.885644     │ -0.821204       │
# │ 4   │ -0.649125  │ -0.726851     │ -0.704387       │
# │ 5   │ -0.50423   │ -0.597609     │ -0.596249       │
# │ 6   │ 0.385116   │ 0.634004      │ 0.665796        │
# │ 7   │ 0.29331    │ 0.0           │ 0.0             │
# │ 8   │ -0.223249  │ 0.0           │ 0.0             │
# │ 9   │ -0.0659658 │ 0.0           │ 0.0             │
# │ 10  │ 0.0283566  │ 0.0           │ 0.0             │
# No initilialization:
#     Iter =83
#     Time =1.620635986328125
# Yes initilialization:
#     Iter = 69
#     Time = 2.2812328338623047
#
#
# running the 3 th model
# n, p = 865, 7785
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β    │ est_β_no_init │ est_β_with_init │
# │     │ Float64   │ Float64       │ Float64         │
# ├─────┼───────────┼───────────────┼─────────────────┤
# │ 1   │ 1.95968   │ 1.61438       │ 1.63875         │
# │ 2   │ 1.46327   │ 1.62424       │ 1.64846         │
# │ 3   │ -0.935872 │ -0.996057     │ -1.01627        │
# │ 4   │ 0.817422  │ 0.979604      │ 0.9946          │
# │ 5   │ -0.499005 │ -0.381518     │ -0.396098       │
# │ 6   │ 0.38085   │ 0.552694      │ 0.521342        │
# │ 7   │ 0.337683  │ 0.490983      │ 0.495239        │
# │ 8   │ 0.222634  │ 0.0           │ 0.0             │
# │ 9   │ -0.137192 │ 0.0           │ 0.0             │
# │ 10  │ 0.10569   │ 0.0           │ 0.0             │
# No initilialization:
#     Iter =40
#     Time =1.5273380279541016
# Yes initilialization:
#     Iter = 97
#     Time = 5.586920976638794
#
#
# running the 4 th model
# n, p = 993, 9930
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β     │ est_β_no_init │ est_β_with_init │
# │     │ Float64    │ Float64       │ Float64         │
# ├─────┼────────────┼───────────────┼─────────────────┤
# │ 1   │ 1.87566    │ 2.11788       │ 2.09427         │
# │ 2   │ 1.00364    │ 0.91393       │ 0.897394        │
# │ 3   │ 0.811131   │ 0.968025      │ 0.97315         │
# │ 4   │ 0.79077    │ 1.01479       │ 1.0071          │
# │ 5   │ 0.622412   │ 0.61269       │ 0.635013        │
# │ 6   │ 0.616716   │ 0.801855      │ 0.787202        │
# │ 7   │ 0.237476   │ 0.0           │ 0.0             │
# │ 8   │ 0.22252    │ 0.0           │ 0.0             │
# │ 9   │ 0.165183   │ 0.0           │ 0.0             │
# │ 10  │ 0.00024963 │ 0.0           │ 0.0             │
# No initilialization:
#     Iter =22
#     Time =1.3440649509429932
# Yes initilialization:
#     Iter = 20
#     Time = 3.876159191131592
#
#
# running the 5 th model
# n, p = 1677, 5031
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β    │ est_β_no_init │ est_β_with_init │
# │     │ Float64   │ Float64       │ Float64         │
# ├─────┼───────────┼───────────────┼─────────────────┤
# │ 1   │ -1.92201  │ -1.88665      │ -1.90028        │
# │ 2   │ 1.80413   │ 1.84863       │ 1.86535         │
# │ 3   │ -1.27937  │ -1.24929      │ -1.24652        │
# │ 4   │ -1.12058  │ -1.07656      │ -1.07364        │
# │ 5   │ 1.0218    │ 1.11323       │ 1.11187         │
# │ 6   │ -0.992846 │ -0.888327     │ -0.890212       │
# │ 7   │ 0.926049  │ 0.937671      │ 0.966735        │
# │ 8   │ -0.896021 │ -0.955124     │ -0.955975       │
# │ 9   │ 0.41138   │ 0.370099      │ 0.379222        │
# │ 10  │ -0.224452 │ 0.0           │ 0.0             │
# No initilialization:
#     Iter =48
#     Time =2.311844825744629
# Yes initilialization:
#     Iter = 45
#     Time = 4.503171920776367
#
#
# running the 6 th model
# n, p = 909, 4545
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β    │ est_β_no_init │ est_β_with_init │
# │     │ Float64   │ Float64       │ Float64         │
# ├─────┼───────────┼───────────────┼─────────────────┤
# │ 1   │ 1.38274   │ 1.39981       │ 1.4095          │
# │ 2   │ 1.07199   │ 0.992271      │ 1.01024         │
# │ 3   │ 0.668949  │ 0.703126      │ 0.730274        │
# │ 4   │ 0.408409  │ 0.300602      │ 0.312283        │
# │ 5   │ -0.377218 │ 0.0           │ 0.0             │
# │ 6   │ 0.294961  │ 0.0           │ 0.301031        │
# │ 7   │ 0.147597  │ 0.0           │ 0.0             │
# │ 8   │ -0.141991 │ 0.0           │ 0.0             │
# │ 9   │ -0.133317 │ 0.0           │ 0.0             │
# │ 10  │ 0.114156  │ 0.0           │ 0.0             │
# No initilialization:
#     Iter =20
#     Time =0.49147701263427734
# Yes initilialization:
#     Iter = 20
#     Time = 1.607191801071167
#
#
# running the 7 th model
# n, p = 518, 518
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β    │ est_β_no_init │ est_β_with_init │
# │     │ Float64   │ Float64       │ Float64         │
# ├─────┼───────────┼───────────────┼─────────────────┤
# │ 1   │ -2.35361  │ -2.49721      │ -2.49744        │
# │ 2   │ 1.13457   │ 0.846074      │ 0.84616         │
# │ 3   │ -1.07313  │ -1.08884      │ -1.08895        │
# │ 4   │ -0.929614 │ -0.926472     │ -0.926571       │
# │ 5   │ 0.746757  │ 0.791113      │ 0.7912          │
# │ 6   │ -0.487511 │ 0.0           │ 0.0             │
# │ 7   │ 0.427943  │ 0.500729      │ 0.500774        │
# │ 8   │ -0.31696  │ 0.0           │ 0.0             │
# │ 9   │ -0.282705 │ 0.0           │ 0.0             │
# │ 10  │ 0.17982   │ 0.0           │ 0.0             │
# No initilialization:
#     Iter =37
#     Time =0.07102799415588379
# Yes initilialization:
#     Iter = 34
#     Time = 0.1412198543548584
#
#
# running the 8 th model
# n, p = 1264, 3792
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β    │ est_β_no_init │ est_β_with_init │
# │     │ Float64   │ Float64       │ Float64         │
# ├─────┼───────────┼───────────────┼─────────────────┤
# │ 1   │ -2.12949  │ -2.05932      │ -2.05941        │
# │ 2   │ -2.05614  │ -2.09305      │ -2.09314        │
# │ 3   │ -1.73398  │ -1.69994      │ -1.70001        │
# │ 4   │ -1.56921  │ -1.59923      │ -1.5993         │
# │ 5   │ -0.971285 │ -0.834058     │ -0.834092       │
# │ 6   │ 0.778053  │ 0.784675      │ 0.784715        │
# │ 7   │ -0.688653 │ -0.666095     │ -0.666128       │
# │ 8   │ 0.482829  │ 0.481589      │ 0.481614        │
# │ 9   │ -0.46586  │ -0.614928     │ -0.614954       │
# │ 10  │ -0.43913  │ -0.564841     │ -0.564867       │
# No initilialization:
#     Iter =40
#     Time =1.1671240329742432
# Yes initilialization:
#     Iter = 42
#     Time = 2.5414140224456787
#
#
# running the 9 th model
# n, p = 794, 7146
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β     │ est_β_no_init │ est_β_with_init │
# │     │ Float64    │ Float64       │ Float64         │
# ├─────┼────────────┼───────────────┼─────────────────┤
# │ 1   │ 2.45649    │ 2.55743       │ 2.55741         │
# │ 2   │ -1.65434   │ -1.52593      │ -1.52591        │
# │ 3   │ -1.535     │ -1.65026      │ -1.65026        │
# │ 4   │ 1.3125     │ 1.4256        │ 1.42558         │
# │ 5   │ 0.888371   │ 1.01099       │ 1.01098         │
# │ 6   │ 0.782833   │ 0.739464      │ 0.739456        │
# │ 7   │ -0.749084  │ -0.767621     │ -0.767613       │
# │ 8   │ 0.658579   │ 0.510233      │ 0.510227        │
# │ 9   │ 0.293359   │ 0.0           │ 0.0             │
# │ 10  │ -0.0996405 │ 0.0           │ 0.0             │
# No initilialization:
#     Iter =48
#     Time =1.5600700378417969
# Yes initilialization:
#     Iter = 50
#     Time = 3.157639980316162
#
#
# running the 10 th model
# n, p = 945, 2835
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β    │ est_β_no_init │ est_β_with_init │
# │     │ Float64   │ Float64       │ Float64         │
# ├─────┼───────────┼───────────────┼─────────────────┤
# │ 1   │ 1.55067   │ 0.607554      │ 0.623229        │
# │ 2   │ 1.08688   │ 0.973846      │ 0.974289        │
# │ 3   │ 0.888266  │ 0.973361      │ 0.973606        │
# │ 4   │ 0.863306  │ 0.860877      │ 0.861161        │
# │ 5   │ 0.764743  │ 1.62732       │ 1.62516         │
# │ 6   │ -0.640977 │ -0.753963     │ -0.754291       │
# │ 7   │ -0.596083 │ -0.515081     │ -0.515235       │
# │ 8   │ -0.520128 │ -0.443248     │ -0.443545       │
# │ 9   │ -0.483273 │ -0.60856      │ -0.608594       │
# │ 10  │ 0.290213  │ 0.0           │ 0.0             │
# No initilialization:
#     Iter =77
#     Time =1.2275490760803223
# Yes initilialization:
#     Iter = 71
#     Time = 1.8566210269927979
#
#
# running the 11 th model
# n, p = 1103, 9927
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β     │ est_β_no_init │ est_β_with_init │
# │     │ Float64    │ Float64       │ Float64         │
# ├─────┼────────────┼───────────────┼─────────────────┤
# │ 1   │ -2.61575   │ -2.68762      │ -2.73453        │
# │ 2   │ 1.40421    │ 1.41078       │ 1.39811         │
# │ 3   │ -0.875019  │ -0.81823      │ -0.799842       │
# │ 4   │ -0.829779  │ -0.919651     │ -0.917534       │
# │ 5   │ 0.792006   │ 0.850428      │ 0.815069        │
# │ 6   │ -0.44122   │ -0.399599     │ -0.438879       │
# │ 7   │ -0.407927  │ 0.0           │ 0.0             │
# │ 8   │ 0.229561   │ 0.0           │ 0.0             │
# │ 9   │ 0.0537     │ 0.0           │ 0.0             │
# │ 10  │ -0.0225921 │ 0.0           │ 0.0             │
# No initilialization:
#     Iter =36
#     Time =2.45701003074646
# Yes initilialization:
#     Iter = 39
#     Time = 5.593415975570679
#
#
# running the 12 th model
# n, p = 630, 630
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β     │ est_β_no_init │ est_β_with_init │
# │     │ Float64    │ Float64       │ Float64         │
# ├─────┼────────────┼───────────────┼─────────────────┤
# │ 1   │ -1.76172   │ -1.66417      │ -1.66425        │
# │ 2   │ 1.30603    │ 1.01062       │ 1.01065         │
# │ 3   │ 1.0974     │ 0.870949      │ 0.870963        │
# │ 4   │ -0.766189  │ -0.779352     │ -0.77937        │
# │ 5   │ -0.692048  │ -0.636275     │ -0.63629        │
# │ 6   │ 0.653482   │ 0.955911      │ 0.955935        │
# │ 7   │ -0.648565  │ -0.481965     │ -0.481975       │
# │ 8   │ 0.603348   │ 0.0           │ 0.0             │
# │ 9   │ 0.532539   │ 0.530424      │ 0.530436        │
# │ 10  │ -0.0280464 │ 0.0           │ 0.0             │
# No initilialization:
#     Iter =26
#     Time =0.06780290603637695
# Yes initilialization:
#     Iter = 22
#     Time = 0.16364693641662598
#
#
# running the 13 th model
# n, p = 1529, 12232
# Did not converge!!!!! The run time for IHT was 111.63989615440369seconds and model size was10sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β    │ est_β_no_init │ est_β_with_init │
# │     │ Float64   │ Float64       │ Float64         │
# ├─────┼───────────┼───────────────┼─────────────────┤
# │ 1   │ -3.06339  │ -3.03424      │ -3.31836        │
# │ 2   │ 1.61461   │ 1.63434       │ 1.55268         │
# │ 3   │ 1.2514    │ 1.22823       │ 1.18613         │
# │ 4   │ 1.1117    │ 1.14342       │ 1.09462         │
# │ 5   │ -0.861115 │ -0.841637     │ -0.758849       │
# │ 6   │ -0.755433 │ -0.740841     │ -0.679868       │
# │ 7   │ -0.65548  │ -0.719522     │ -0.671389       │
# │ 8   │ 0.642166  │ 0.824709      │ 0.807214        │
# │ 9   │ -0.544423 │ -0.503431     │ -0.487387       │
# │ 10  │ 0.462963  │ 0.512675      │ 0.0             │
# No initilialization:
#     Iter =47
#     Time =5.274986028671265
# Yes initilialization:
#     Iter = 1000
#     Time = 111.63989615440369
#
#
# running the 14 th model
# n, p = 668, 6012
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β    │ est_β_no_init │ est_β_with_init │
# │     │ Float64   │ Float64       │ Float64         │
# ├─────┼───────────┼───────────────┼─────────────────┤
# │ 1   │ -3.5154   │ -4.51567      │ -4.52564        │
# │ 2   │ 1.48621   │ 2.28932       │ 2.16703         │
# │ 3   │ 1.40585   │ 1.93535       │ 1.9936          │
# │ 4   │ -1.34348  │ -1.77592      │ -1.57493        │
# │ 5   │ -1.15278  │ -1.84758      │ -1.64365        │
# │ 6   │ 0.680926  │ 0.861055      │ 0.644819        │
# │ 7   │ 0.338213  │ 0.0           │ 0.0             │
# │ 8   │ -0.326892 │ 0.0           │ 0.0             │
# │ 9   │ -0.258546 │ 0.0           │ 0.0             │
# │ 10  │ 0.207956  │ 0.0           │ 0.0             │
# No initilialization:
#     Iter =104
#     Time =2.375581979751587
# Yes initilialization:
#     Iter = 47
#     Time = 2.174623966217041
#
#
# running the 15 th model
# n, p = 1370, 10960
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β     │ est_β_no_init │ est_β_with_init │
# │     │ Float64    │ Float64       │ Float64         │
# ├─────┼────────────┼───────────────┼─────────────────┤
# │ 1   │ -2.81803   │ -2.6838       │ -2.68239        │
# │ 2   │ -1.68138   │ -1.63914      │ -1.60351        │
# │ 3   │ 1.60408    │ 1.74458       │ 1.73054         │
# │ 4   │ 0.938062   │ 0.726649      │ 0.727094        │
# │ 5   │ 0.863713   │ 0.987112      │ 0.997842        │
# │ 6   │ 0.754662   │ 0.853189      │ 0.81379         │
# │ 7   │ 0.656647   │ 0.588391      │ 0.56906         │
# │ 8   │ 0.556686   │ 0.451535      │ 0.463314        │
# │ 9   │ -0.487633  │ -0.563243     │ -0.55142        │
# │ 10  │ -0.0499008 │ 0.0           │ 0.0             │
# No initilialization:
#     Iter =45
#     Time =4.052081108093262
# Yes initilialization:
#     Iter = 87
#     Time = 11.601677894592285
#
#
# running the 16 th model
# n, p = 821, 4105
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β   │ est_β_no_init │ est_β_with_init │
# │     │ Float64  │ Float64       │ Float64         │
# ├─────┼──────────┼───────────────┼─────────────────┤
# │ 1   │ -1.56343 │ -1.71033      │ -1.71035        │
# │ 2   │ 1.50068  │ 1.51483       │ 1.51484         │
# │ 3   │ 1.33823  │ 2.44991       │ 2.42825         │
# │ 4   │ -1.25403 │ -1.29621      │ -1.29628        │
# │ 5   │ -1.21334 │ -1.23345      │ -1.21425        │
# │ 6   │ 1.10754  │ 1.10182       │ 1.1018          │
# │ 7   │ 0.975187 │ 1.07984       │ 1.07986         │
# │ 8   │ 0.830006 │ 0.764703      │ 0.764702        │
# │ 9   │ 0.558491 │ 0.578697      │ 0.578709        │
# │ 10  │ 0.342966 │ 0.470458      │ 0.470464        │
# No initilialization:
#     Iter =432
#     Time =8.24242901802063
# Yes initilialization:
#     Iter = 294
#     Time = 6.536272048950195
#
#
# running the 17 th model
# n, p = 631, 1893
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β     │ est_β_no_init │ est_β_with_init │
# │     │ Float64    │ Float64       │ Float64         │
# ├─────┼────────────┼───────────────┼─────────────────┤
# │ 1   │ 1.89784    │ 2.24431       │ 2.27332         │
# │ 2   │ -1.67308   │ -1.64746      │ -1.70626        │
# │ 3   │ -1.38308   │ -1.39818      │ -1.42023        │
# │ 4   │ -0.907986  │ -1.07571      │ -1.07734        │
# │ 5   │ 0.878021   │ 1.01445       │ 1.05788         │
# │ 6   │ 0.672833   │ 0.605175      │ 0.630243        │
# │ 7   │ 0.436635   │ 0.555165      │ 0.596007        │
# │ 8   │ -0.374844  │ 0.0           │ 0.0             │
# │ 9   │ 0.256751   │ 0.0           │ 0.0             │
# │ 10  │ -0.0829466 │ 0.0           │ 0.0             │
# No initilialization:
#     Iter =39
#     Time =0.29322290420532227
# Yes initilialization:
#     Iter = 40
#     Time = 0.6328108310699463
#
#
# running the 18 th model
# n, p = 979, 2937
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β    │ est_β_no_init │ est_β_with_init │
# │     │ Float64   │ Float64       │ Float64         │
# ├─────┼───────────┼───────────────┼─────────────────┤
# │ 1   │ -1.27512  │ -1.23033      │ -1.22614        │
# │ 2   │ -1.19347  │ -1.41346      │ -1.39905        │
# │ 3   │ 1.02565   │ 1.17954       │ 1.18164         │
# │ 4   │ -0.810173 │ -0.783538     │ -0.76891        │
# │ 5   │ -0.677532 │ -0.61442      │ -0.611309       │
# │ 6   │ 0.632032  │ 0.685658      │ 0.668883        │
# │ 7   │ 0.525398  │ 0.431442      │ 0.442754        │
# │ 8   │ 0.356614  │ 0.0           │ 0.0             │
# │ 9   │ 0.343033  │ 0.0           │ 0.0             │
# │ 10  │ 0.0613371 │ 0.0           │ 0.0             │
# No initilialization:
#     Iter =23
#     Time =0.4013638496398926
# Yes initilialization:
#     Iter = 22
#     Time = 1.1671109199523926
#
#
# running the 19 th model
# n, p = 546, 3276
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β     │ est_β_no_init │ est_β_with_init │
# │     │ Float64    │ Float64       │ Float64         │
# ├─────┼────────────┼───────────────┼─────────────────┤
# │ 1   │ -1.54572   │ 0.0           │ -1.4617         │
# │ 2   │ 1.15173    │ 1.16785       │ 1.37432         │
# │ 3   │ 1.08544    │ 1.07457       │ 1.04808         │
# │ 4   │ 0.984208   │ 0.0           │ 0.935923        │
# │ 5   │ 0.607373   │ 0.721052      │ 0.703971        │
# │ 6   │ 0.383051   │ 0.0           │ 0.0             │
# │ 7   │ 0.354342   │ 0.494236      │ 0.494524        │
# │ 8   │ -0.320938  │ 0.0           │ 0.0             │
# │ 9   │ 0.204028   │ 0.0           │ 0.0             │
# │ 10  │ -0.0687743 │ 0.0           │ 0.0             │
# No initilialization:
#     Iter =70
#     Time =0.750985860824585
# Yes initilialization:
#     Iter = 92
#     Time = 1.4568359851837158
#
#
# running the 20 th model
# n, p = 1661, 11627
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β   │ est_β_no_init │ est_β_with_init │
# │     │ Float64  │ Float64       │ Float64         │
# ├─────┼──────────┼───────────────┼─────────────────┤
# │ 1   │ -2.03974 │ -2.00581      │ -2.01075        │
# │ 2   │ 1.91932  │ 1.74117       │ 1.74517         │
# │ 3   │ 1.78182  │ 1.60155       │ 1.60549         │
# │ 4   │ -1.6595  │ -1.40381      │ -1.40719        │
# │ 5   │ 1.33948  │ 1.3008        │ 1.30397         │
# │ 6   │ 1.31183  │ 1.3973        │ 1.4004          │
# │ 7   │ -1.10364 │ -1.15763      │ -1.16034        │
# │ 8   │ 0.888001 │ 0.831428      │ 0.833347        │
# │ 9   │ 0.290884 │ 0.0           │ 0.0             │
# │ 10  │ 0.133611 │ 0.0           │ 0.0             │
# No initilialization:
#     Iter =43
#     Time =5.179327011108398
# Yes initilialization:
#     Iter = 52
#     Time = 11.004418134689331
#
#
# running the 21 th model
# n, p = 1291, 7746
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β    │ est_β_no_init │ est_β_with_init │
# │     │ Float64   │ Float64       │ Float64         │
# ├─────┼───────────┼───────────────┼─────────────────┤
# │ 1   │ -1.33975  │ -1.48428      │ -1.50384        │
# │ 2   │ -1.1206   │ -1.15005      │ -1.15559        │
# │ 3   │ -0.915652 │ -0.971999     │ -1.00609        │
# │ 4   │ -0.854998 │ -0.845284     │ -0.853506       │
# │ 5   │ -0.611784 │ -0.59081      │ -0.593467       │
# │ 6   │ -0.570757 │ -0.394645     │ -0.396418       │
# │ 7   │ 0.310851  │ 0.0           │ 0.0             │
# │ 8   │ -0.238925 │ 0.0           │ 0.0             │
# │ 9   │ 0.220361  │ 0.0           │ 0.0             │
# │ 10  │ 0.202697  │ 0.0           │ 0.0             │
# No initilialization:
#     Iter =20
#     Time =1.269606113433838
# Yes initilialization:
#     Iter = 19
#     Time = 3.8337278366088867
#
#
# running the 22 th model
# n, p = 1671, 15039
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β     │ est_β_no_init │ est_β_with_init │
# │     │ Float64    │ Float64       │ Float64         │
# ├─────┼────────────┼───────────────┼─────────────────┤
# │ 1   │ -1.79522   │ -1.98625      │ -1.99089        │
# │ 2   │ 1.46197    │ 1.60437       │ 1.60815         │
# │ 3   │ 0.90904    │ 1.02589       │ 1.02831         │
# │ 4   │ -0.872772  │ -0.96727      │ -0.969405       │
# │ 5   │ -0.69361   │ -0.788661     │ -0.790525       │
# │ 6   │ -0.670935  │ -0.740309     │ -0.741999       │
# │ 7   │ 0.452121   │ 0.557167      │ 0.558334        │
# │ 8   │ 0.370089   │ 0.341171      │ 0.342011        │
# │ 9   │ -0.365744  │ -0.396283     │ -0.397109       │
# │ 10  │ -0.0328738 │ 0.0           │ 0.0             │
# No initilialization:
#     Iter =35
#     Time =5.017106056213379
# Yes initilialization:
#     Iter = 18
#     Time = 9.36345100402832
#
#
# running the 23 th model
# n, p = 1284, 8988
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β     │ est_β_no_init │ est_β_with_init │
# │     │ Float64    │ Float64       │ Float64         │
# ├─────┼────────────┼───────────────┼─────────────────┤
# │ 1   │ 1.4103     │ 1.47033       │ 1.47004         │
# │ 2   │ -1.06624   │ -0.916813     │ -0.916607       │
# │ 3   │ 0.957631   │ 0.953018      │ 0.952794        │
# │ 4   │ 0.706983   │ 0.746685      │ 0.746543        │
# │ 5   │ 0.590029   │ 0.445134      │ 0.445052        │
# │ 6   │ 0.574855   │ 0.584182      │ 0.584059        │
# │ 7   │ -0.431186  │ -0.430998     │ -0.4309         │
# │ 8   │ 0.12891    │ 0.0           │ 0.0             │
# │ 9   │ -0.0465914 │ 0.0           │ 0.0             │
# │ 10  │ 0.041402   │ 0.0           │ 0.0             │
# No initilialization:
#     Iter =19
#     Time =1.3138248920440674
# Yes initilialization:
#     Iter = 20
#     Time = 4.436539173126221
#
#
# running the 24 th model
# n, p = 1845, 9225
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β    │ est_β_no_init │ est_β_with_init │
# │     │ Float64   │ Float64       │ Float64         │
# ├─────┼───────────┼───────────────┼─────────────────┤
# │ 1   │ 1.82599   │ 1.98218       │ 1.98207         │
# │ 2   │ -1.58395  │ -1.77574      │ -1.77565        │
# │ 3   │ 1.40381   │ 1.61692       │ 1.61683         │
# │ 4   │ 1.19779   │ 1.22391       │ 1.22385         │
# │ 5   │ -1.10588  │ -1.28249      │ -1.28242        │
# │ 6   │ 1.06448   │ 1.05953       │ 1.05947         │
# │ 7   │ 0.733443  │ 0.730963      │ 0.730924        │
# │ 8   │ 0.628653  │ 0.739406      │ 0.739365        │
# │ 9   │ 0.501221  │ 0.461943      │ 0.461914        │
# │ 10  │ -0.214589 │ 0.0           │ 0.0             │
# No initilialization:
#     Iter =42
#     Time =4.113195896148682
# Yes initilialization:
#     Iter = 42
#     Time = 8.745995044708252
#
#
# running the 25 th model
# n, p = 580, 4640
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β    │ est_β_no_init │ est_β_with_init │
# │     │ Float64   │ Float64       │ Float64         │
# ├─────┼───────────┼───────────────┼─────────────────┤
# │ 1   │ -2.48692  │ -3.55523      │ -3.51488        │
# │ 2   │ -1.40854  │ -1.52122      │ -1.52569        │
# │ 3   │ -1.06706  │ -0.877783     │ -0.878037       │
# │ 4   │ -0.997683 │ -1.08189      │ -1.08187        │
# │ 5   │ 0.979952  │ 0.899647      │ 0.900129        │
# │ 6   │ -0.965485 │ -0.951656     │ -0.951698       │
# │ 7   │ -0.89079  │ -0.952399     │ -0.95202        │
# │ 8   │ -0.867944 │ -0.91751      │ -0.917359       │
# │ 9   │ 0.621373  │ 0.961729      │ 0.960957        │
# │ 10  │ 0.263965  │ 0.0           │ 0.0             │
# No initilialization:
#     Iter =152
#     Time =2.4251668453216553
# Yes initilialization:
#     Iter = 81
#     Time = 2.3187448978424072
#
#
# running the 26 th model
# n, p = 1655, 4965
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β    │ est_β_no_init │ est_β_with_init │
# │     │ Float64   │ Float64       │ Float64         │
# ├─────┼───────────┼───────────────┼─────────────────┤
# │ 1   │ -1.69679  │ -1.79393      │ -1.79395        │
# │ 2   │ 1.64368   │ 1.67563       │ 1.67566         │
# │ 3   │ 1.38649   │ 1.41734       │ 1.41736         │
# │ 4   │ -1.38548  │ -1.32932      │ -1.32934        │
# │ 5   │ -1.27302  │ -1.20008      │ -1.2001         │
# │ 6   │ -0.941559 │ -1.09734      │ -1.09735        │
# │ 7   │ -0.892945 │ -0.980046     │ -0.980059       │
# │ 8   │ 0.776453  │ 0.69747       │ 0.69748         │
# │ 9   │ -0.428426 │ -0.490729     │ -0.490734       │
# │ 10  │ 0.21944   │ 0.303993      │ 0.303997        │
# No initilialization:
#     Iter =41
#     Time =1.9591238498687744
# Yes initilialization:
#     Iter = 40
#     Time = 4.1439549922943115
#
#
# running the 27 th model
# n, p = 759, 3795
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β   │ est_β_no_init │ est_β_with_init │
# │     │ Float64  │ Float64       │ Float64         │
# ├─────┼──────────┼───────────────┼─────────────────┤
# │ 1   │ 2.29939  │ 2.23955       │ 2.24752         │
# │ 2   │ 2.16938  │ 2.09674       │ 2.10823         │
# │ 3   │ -2.00502 │ -1.71165      │ -1.71892        │
# │ 4   │ -1.66515 │ -1.356        │ -1.36147        │
# │ 5   │ -1.47161 │ -2.00519      │ -2.0164         │
# │ 6   │ 0.654064 │ 0.561148      │ 0.563731        │
# │ 7   │ 0.590971 │ 0.67885       │ 0.681495        │
# │ 8   │ 0.378969 │ 0.0           │ 0.0             │
# │ 9   │ 0.169428 │ 0.0           │ 0.0             │
# │ 10  │ 0.157848 │ 0.0           │ 0.0             │
# No initilialization:
#     Iter =59
#     Time =1.0522799491882324
# Yes initilialization:
#     Iter = 93
#     Time = 2.362602949142456
#
#
# running the 28 th model
# n, p = 556, 2780
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β     │ est_β_no_init │ est_β_with_init │
# │     │ Float64    │ Float64       │ Float64         │
# ├─────┼────────────┼───────────────┼─────────────────┤
# │ 1   │ 1.86455    │ 2.3534        │ 2.21826         │
# │ 2   │ 1.70737    │ 0.813533      │ 0.874476        │
# │ 3   │ 1.54748    │ 2.2917        │ 2.34255         │
# │ 4   │ 0.953906   │ 1.13077       │ 1.0471          │
# │ 5   │ -0.60125   │ -0.660329     │ -0.672685       │
# │ 6   │ -0.551902  │ 0.0           │ 0.0             │
# │ 7   │ 0.430871   │ 0.0           │ 0.0             │
# │ 8   │ 0.226456   │ 0.0           │ 0.0             │
# │ 9   │ 0.158672   │ 0.0           │ 0.0             │
# │ 10  │ -0.0517065 │ 0.0           │ 0.0             │
# No initilialization:
#     Iter =40
#     Time =0.39814305305480957
# Yes initilialization:
#     Iter = 39
#     Time = 0.8226990699768066
#
#
# running the 29 th model
# n, p = 1660, 1660
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β     │ est_β_no_init │ est_β_with_init │
# │     │ Float64    │ Float64       │ Float64         │
# ├─────┼────────────┼───────────────┼─────────────────┤
# │ 1   │ -1.9456    │ -1.92095      │ -1.92094        │
# │ 2   │ -1.90002   │ -1.89692      │ -1.89691        │
# │ 3   │ -1.49949   │ -1.5314       │ -1.5314         │
# │ 4   │ 0.882264   │ 0.795961      │ 0.795957        │
# │ 5   │ -0.65588   │ -0.637605     │ -0.637602       │
# │ 6   │ 0.340675   │ 0.315176      │ 0.315174        │
# │ 7   │ 0.243499   │ 0.0           │ 0.0             │
# │ 8   │ 0.103726   │ 0.0           │ 0.0             │
# │ 9   │ 0.039693   │ 0.0           │ 0.0             │
# │ 10  │ -0.0319191 │ 0.0           │ 0.0             │
# No initilialization:
#     Iter =35
#     Time =0.5662679672241211
# Yes initilialization:
#     Iter = 34
#     Time = 1.2869799137115479
#
#
# running the 30 th model
# n, p = 1310, 9170
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β    │ est_β_no_init │ est_β_with_init │
# │     │ Float64   │ Float64       │ Float64         │
# ├─────┼───────────┼───────────────┼─────────────────┤
# │ 1   │ 1.22451   │ 1.24073       │ 1.24078         │
# │ 2   │ 1.159     │ 1.38524       │ 1.3853          │
# │ 3   │ -1.13725  │ -1.26888      │ -1.26894        │
# │ 4   │ 1.07328   │ 1.13594       │ 1.13599         │
# │ 5   │ 0.885882  │ 0.878858      │ 0.878888        │
# │ 6   │ -0.708224 │ -0.705531     │ -0.705561       │
# │ 7   │ 0.440588  │ 0.594676      │ 0.594696        │
# │ 8   │ -0.436995 │ -0.472158     │ -0.472175       │
# │ 9   │ -0.21103  │ 0.0           │ 0.0             │
# │ 10  │ 0.103232  │ 0.0           │ 0.0             │
# No initilialization:
#     Iter =35
#     Time =2.4541778564453125
# Yes initilialization:
#     Iter = 34
#     Time = 5.611670970916748
#
#
# running the 31 th model
# n, p = 1256, 7536
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β    │ est_β_no_init │ est_β_with_init │
# │     │ Float64   │ Float64       │ Float64         │
# ├─────┼───────────┼───────────────┼─────────────────┤
# │ 1   │ 2.0755    │ 2.1138        │ 2.11991         │
# │ 2   │ 1.81599   │ 1.80847       │ 1.8136          │
# │ 3   │ 1.71758   │ 1.67841       │ 1.68329         │
# │ 4   │ -1.18555  │ -1.24522      │ -1.24884        │
# │ 5   │ 0.977571  │ 1.12395       │ 1.12719         │
# │ 6   │ 0.810208  │ 0.85424       │ 0.856458        │
# │ 7   │ -0.684291 │ -0.558621     │ -0.560193       │
# │ 8   │ 0.528897  │ 0.44513       │ 0.446335        │
# │ 9   │ -0.517118 │ -0.594103     │ -0.595618       │
# │ 10  │ -0.230619 │ 0.0           │ 0.0             │
# No initilialization:
#     Iter =39
#     Time =2.1349191665649414
# Yes initilialization:
#     Iter = 59
#     Time = 5.732493162155151
#
#
# running the 32 th model
# n, p = 1798, 3596
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β     │ est_β_no_init │ est_β_with_init │
# │     │ Float64    │ Float64       │ Float64         │
# ├─────┼────────────┼───────────────┼─────────────────┤
# │ 1   │ 1.51475    │ 1.64199       │ 1.62782         │
# │ 2   │ 1.15739    │ 1.19096       │ 1.17572         │
# │ 3   │ -1.01331   │ -1.02924      │ -1.0219         │
# │ 4   │ -0.882691  │ -0.896579     │ -0.896995       │
# │ 5   │ 0.789004   │ 0.816656      │ 0.820647        │
# │ 6   │ -0.784542  │ -0.796571     │ -0.781807       │
# │ 7   │ -0.419193  │ -0.344041     │ -0.34647        │
# │ 8   │ -0.351722  │ -0.355473     │ -0.358009       │
# │ 9   │ -0.178027  │ 0.0           │ 0.0             │
# │ 10  │ 0.00621928 │ 0.0           │ 0.0             │
# No initilialization:
#     Iter =22
#     Time =0.8221278190612793
# Yes initilialization:
#     Iter = 43
#     Time = 3.2130930423736572
#
#
# running the 33 th model
# n, p = 1327, 5308
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β     │ est_β_no_init │ est_β_with_init │
# │     │ Float64    │ Float64       │ Float64         │
# ├─────┼────────────┼───────────────┼─────────────────┤
# │ 1   │ 1.61283    │ 1.45611       │ 1.47884         │
# │ 2   │ -1.47036   │ -1.54952      │ -1.57959        │
# │ 3   │ -1.31085   │ -1.32575      │ -1.36583        │
# │ 4   │ 1.28328    │ 1.37383       │ 1.33664         │
# │ 5   │ -1.16672   │ -1.16624      │ -1.15256        │
# │ 6   │ 0.905323   │ 0.801757      │ 0.812059        │
# │ 7   │ 0.492974   │ 0.503635      │ 0.51267         │
# │ 8   │ 0.197467   │ 0.0           │ 0.0             │
# │ 9   │ -0.0462641 │ 0.0           │ 0.0             │
# │ 10  │ -0.0444092 │ 0.0           │ 0.0             │
# No initilialization:
#     Iter =40
#     Time =1.6417219638824463
# Yes initilialization:
#     Iter = 38
#     Time = 3.375396966934204
#
#
# running the 34 th model
# n, p = 831, 8310
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β    │ est_β_no_init │ est_β_with_init │
# │     │ Float64   │ Float64       │ Float64         │
# ├─────┼───────────┼───────────────┼─────────────────┤
# │ 1   │ -2.12601  │ -1.86817      │ -1.86116        │
# │ 2   │ 1.25496   │ 1.06058       │ 1.09165         │
# │ 3   │ -0.950442 │ -1.00548      │ -1.02331        │
# │ 4   │ 0.689832  │ 0.642669      │ 0.669776        │
# │ 5   │ 0.560064  │ 0.0           │ 0.0             │
# │ 6   │ 0.427459  │ 0.418624      │ 0.450716        │
# │ 7   │ -0.400328 │ -0.766915     │ -0.756678       │
# │ 8   │ 0.299294  │ 0.0           │ 0.397672        │
# │ 9   │ -0.220538 │ 0.0           │ 0.0             │
# │ 10  │ -0.130867 │ 0.0           │ 0.0             │
# No initilialization:
#     Iter =33
#     Time =1.3678209781646729
# Yes initilialization:
#     Iter = 45
#     Time = 3.6551928520202637
#
#
# running the 35 th model
# n, p = 1950, 13650
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β    │ est_β_no_init │ est_β_with_init │
# │     │ Float64   │ Float64       │ Float64         │
# ├─────┼───────────┼───────────────┼─────────────────┤
# │ 1   │ -1.46704  │ -1.41937      │ -1.42109        │
# │ 2   │ 1.03565   │ 0.977         │ 0.977753        │
# │ 3   │ -0.955871 │ -0.937664     │ -0.938272       │
# │ 4   │ 0.807736  │ 0.620067      │ 0.622362        │
# │ 5   │ -0.539686 │ -0.54606      │ -0.546487       │
# │ 6   │ 0.472584  │ 0.475988      │ 0.476348        │
# │ 7   │ -0.467375 │ -0.321287     │ -0.321455       │
# │ 8   │ -0.331118 │ -0.383956     │ -0.384265       │
# │ 9   │ -0.307681 │ -0.330501     │ -0.330741       │
# │ 10  │ -0.208931 │ 0.0           │ 0.0             │
# No initilialization:
#     Iter =22
#     Time =3.3981258869171143
# Yes initilialization:
#     Iter = 24
#     Time = 10.784849882125854
#
#
# running the 36 th model
# n, p = 1124, 11240
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β    │ est_β_no_init │ est_β_with_init │
# │     │ Float64   │ Float64       │ Float64         │
# ├─────┼───────────┼───────────────┼─────────────────┤
# │ 1   │ -0.826135 │ -0.967716     │ -0.970535       │
# │ 2   │ -0.776143 │ -0.752662     │ -0.736883       │
# │ 3   │ 0.700736  │ 0.0           │ 0.614552        │
# │ 4   │ -0.660135 │ -0.72776      │ -0.704485       │
# │ 5   │ -0.591415 │ -0.638788     │ -0.608927       │
# │ 6   │ 0.510639  │ 0.52425       │ 0.497051        │
# │ 7   │ -0.402041 │ -0.494792     │ -0.488533       │
# │ 8   │ -0.237885 │ -0.320178     │ -0.362238       │
# │ 9   │ 0.110832  │ 0.0           │ 0.0             │
# │ 10  │ -0.105012 │ 0.0           │ 0.0             │
# No initilialization:
#     Iter =18
#     Time =1.3839290142059326
# Yes initilialization:
#     Iter = 177
#     Time = 15.805124044418335
#
#
# running the 37 th model
# n, p = 510, 510
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β    │ est_β_no_init │ est_β_with_init │
# │     │ Float64   │ Float64       │ Float64         │
# ├─────┼───────────┼───────────────┼─────────────────┤
# │ 1   │ -1.51561  │ -1.39336      │ -1.39321        │
# │ 2   │ -1.02819  │ -1.17923      │ -1.17912        │
# │ 3   │ 1.02408   │ 1.01953       │ 1.01941         │
# │ 4   │ 0.692322  │ 0.794066      │ 0.793981        │
# │ 5   │ 0.671005  │ 0.843148      │ 0.843045        │
# │ 6   │ 0.64106   │ 0.675961      │ 0.675892        │
# │ 7   │ 0.448525  │ 0.0           │ 0.0             │
# │ 8   │ -0.42411  │ 0.0           │ 0.0             │
# │ 9   │ -0.373162 │ -0.48272      │ -0.48268        │
# │ 10  │ -0.263388 │ 0.0           │ 0.0             │
# No initilialization:
#     Iter =21
#     Time =0.0395660400390625
# Yes initilialization:
#     Iter = 20
#     Time = 0.10740804672241211
#
#
# running the 38 th model
# n, p = 1094, 2188
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β     │ est_β_no_init │ est_β_with_init │
# │     │ Float64    │ Float64       │ Float64         │
# ├─────┼────────────┼───────────────┼─────────────────┤
# │ 1   │ -2.67842   │ -2.52868      │ -2.50933        │
# │ 2   │ -1.58114   │ -1.6357       │ -1.64923        │
# │ 3   │ 0.899869   │ 0.768278      │ 0.744604        │
# │ 4   │ 0.884164   │ 0.790192      │ 0.797931        │
# │ 5   │ 0.553499   │ 0.662889      │ 0.613585        │
# │ 6   │ -0.400124  │ -0.635753     │ -0.598569       │
# │ 7   │ -0.259856  │ 0.0           │ 0.0             │
# │ 8   │ -0.0882666 │ 0.0           │ 0.0             │
# │ 9   │ 0.0863141  │ 0.0           │ 0.0             │
# │ 10  │ -0.0246386 │ 0.0           │ 0.0             │
# No initilialization:
#     Iter =37
#     Time =0.5193889141082764
# Yes initilialization:
#     Iter = 35
#     Time = 1.1400270462036133
#
#
# running the 39 th model
# n, p = 1669, 11683
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β    │ est_β_no_init │ est_β_with_init │
# │     │ Float64   │ Float64       │ Float64         │
# ├─────┼───────────┼───────────────┼─────────────────┤
# │ 1   │ 1.6862    │ 1.71062       │ 1.69006         │
# │ 2   │ 1.44454   │ 1.40633       │ 1.40862         │
# │ 3   │ -1.12468  │ -0.968988     │ -0.959515       │
# │ 4   │ -0.835314 │ -0.79579      │ -0.808927       │
# │ 5   │ -0.529533 │ -0.564758     │ -0.540332       │
# │ 6   │ -0.382435 │ 0.0           │ 0.0             │
# │ 7   │ -0.343548 │ -0.340104     │ -0.349694       │
# │ 8   │ -0.319034 │ 0.0           │ 0.0             │
# │ 9   │ -0.216488 │ 0.0           │ 0.0             │
# │ 10  │ 0.18348   │ 0.0           │ 0.0             │
# No initilialization:
#     Iter =21
#     Time =2.471982955932617
# Yes initilialization:
#     Iter = 20
#     Time = 7.717545032501221
#
#
# running the 40 th model
# n, p = 1093, 9837
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β    │ est_β_no_init │ est_β_with_init │
# │     │ Float64   │ Float64       │ Float64         │
# ├─────┼───────────┼───────────────┼─────────────────┤
# │ 1   │ -1.57447  │ -1.56714      │ -1.5698         │
# │ 2   │ -1.43544  │ -1.44632      │ -1.44877        │
# │ 3   │ 0.872985  │ 0.725825      │ 0.727081        │
# │ 4   │ -0.845911 │ -0.910186     │ -0.911859       │
# │ 5   │ -0.482053 │ -0.542765     │ -0.543497       │
# │ 6   │ 0.439961  │ 0.357411      │ 0.35789         │
# │ 7   │ -0.406166 │ -0.413659     │ -0.414385       │
# │ 8   │ -0.326303 │ -0.304416     │ -0.30487        │
# │ 9   │ -0.303679 │ 0.0           │ 0.0             │
# │ 10  │ 0.29132   │ 0.0           │ 0.0             │
# No initilialization:
#     Iter =20
#     Time =1.33477783203125
# Yes initilialization:
#     Iter = 43
#     Time = 5.721403121948242
#
#
# running the 41 th model
# n, p = 551, 3306
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β    │ est_β_no_init │ est_β_with_init │
# │     │ Float64   │ Float64       │ Float64         │
# ├─────┼───────────┼───────────────┼─────────────────┤
# │ 1   │ -1.41065  │ -1.42681      │ -1.35733        │
# │ 2   │ -1.27781  │ -1.22615      │ -1.20487        │
# │ 3   │ 0.887033  │ 0.975492      │ 0.960794        │
# │ 4   │ -0.6651   │ 0.0           │ 0.0             │
# │ 5   │ 0.363614  │ 0.0           │ 0.0             │
# │ 6   │ -0.32842  │ 0.0           │ 0.0             │
# │ 7   │ 0.276983  │ 0.467135      │ 0.488309        │
# │ 8   │ -0.252167 │ 0.0           │ 0.0             │
# │ 9   │ 0.231164  │ 0.0           │ 0.0             │
# │ 10  │ 0.196574  │ 0.0           │ 0.0             │
# No initilialization:
#     Iter =25
#     Time =0.28481006622314453
# Yes initilialization:
#     Iter = 20
#     Time = 0.7327752113342285
#
#
# running the 42 th model
# n, p = 1821, 5463
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β     │ est_β_no_init │ est_β_with_init │
# │     │ Float64    │ Float64       │ Float64         │
# ├─────┼────────────┼───────────────┼─────────────────┤
# │ 1   │ 1.61582    │ 1.44298       │ 1.4431          │
# │ 2   │ 1.56268    │ 1.55047       │ 1.5506          │
# │ 3   │ -1.53548   │ -1.4238       │ -1.42392        │
# │ 4   │ 1.45045    │ 1.44515       │ 1.44525         │
# │ 5   │ 1.00647    │ 1.05901       │ 1.05909         │
# │ 6   │ 0.931566   │ 1.01001       │ 1.01009         │
# │ 7   │ 0.607824   │ 0.461293      │ 0.461325        │
# │ 8   │ -0.275107  │ 0.0           │ 0.0             │
# │ 9   │ -0.0607475 │ 0.0           │ 0.0             │
# │ 10  │ 0.0279037  │ 0.0           │ 0.0             │
# No initilialization:
#     Iter =37
#     Time =2.185581922531128
# Yes initilialization:
#     Iter = 37
#     Time = 4.876309871673584
#
#
# running the 43 th model
# n, p = 1398, 4194
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β     │ est_β_no_init │ est_β_with_init │
# │     │ Float64    │ Float64       │ Float64         │
# ├─────┼────────────┼───────────────┼─────────────────┤
# │ 1   │ -1.08982   │ -1.25388      │ -1.25878        │
# │ 2   │ -0.772237  │ -0.828331     │ -0.850939       │
# │ 3   │ -0.506388  │ -0.697874     │ -0.718914       │
# │ 4   │ 0.360141   │ 0.454689      │ 0.463444        │
# │ 5   │ -0.333992  │ -0.38707      │ -0.386312       │
# │ 6   │ 0.283927   │ 0.0           │ 0.0             │
# │ 7   │ 0.162512   │ 0.0           │ 0.0             │
# │ 8   │ -0.117319  │ 0.0           │ 0.0             │
# │ 9   │ 0.0897303  │ 0.0           │ 0.0             │
# │ 10  │ -0.0134571 │ 0.0           │ 0.0             │
# No initilialization:
#     Iter =12
#     Time =0.45081210136413574
# Yes initilialization:
#     Iter = 10
#     Time = 1.940269947052002
#
#
# running the 44 th model
# n, p = 1555, 1555
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β    │ est_β_no_init │ est_β_with_init │
# │     │ Float64   │ Float64       │ Float64         │
# ├─────┼───────────┼───────────────┼─────────────────┤
# │ 1   │ -1.8673   │ -1.62199      │ -1.6202         │
# │ 2   │ -1.03151  │ -0.841737     │ -0.85612        │
# │ 3   │ 0.98797   │ 0.832761      │ 0.840003        │
# │ 4   │ -0.796484 │ -0.805801     │ -0.796219       │
# │ 5   │ -0.736914 │ -0.704879     │ -0.708794       │
# │ 6   │ 0.243298  │ 0.0           │ 0.0             │
# │ 7   │ 0.237038  │ 0.0           │ 0.0             │
# │ 8   │ 0.127193  │ 0.197467      │ 0.0             │
# │ 9   │ 0.1049    │ 0.0           │ 0.0             │
# │ 10  │ 0.0924616 │ 0.0           │ 0.0             │
# No initilialization:
#     Iter =20
#     Time =0.2971689701080322
# Yes initilialization:
#     Iter = 20
#     Time = 0.9582340717315674
#
#
# running the 45 th model
# n, p = 736, 3680
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β    │ est_β_no_init │ est_β_with_init │
# │     │ Float64   │ Float64       │ Float64         │
# ├─────┼───────────┼───────────────┼─────────────────┤
# │ 1   │ -1.96463  │ -1.91962      │ -1.92141        │
# │ 2   │ 1.82962   │ 1.77416       │ 1.81339         │
# │ 3   │ -1.05158  │ -1.26123      │ -1.23757        │
# │ 4   │ -0.968742 │ -0.881611     │ -0.912427       │
# │ 5   │ -0.75368  │ -0.895235     │ -0.92388        │
# │ 6   │ 0.622276  │ 0.478712      │ 0.488163        │
# │ 7   │ -0.535007 │ 0.0           │ 0.0             │
# │ 8   │ 0.492958  │ 0.560288      │ 0.589611        │
# │ 9   │ -0.205253 │ 0.0           │ 0.0             │
# │ 10  │ 0.0765855 │ 0.0           │ 0.0             │
# No initilialization:
#     Iter =40
#     Time =0.6615378856658936
# Yes initilialization:
#     Iter = 42
#     Time = 1.4209239482879639
#
#
# running the 46 th model
# n, p = 617, 6170
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β    │ est_β_no_init │ est_β_with_init │
# │     │ Float64   │ Float64       │ Float64         │
# ├─────┼───────────┼───────────────┼─────────────────┤
# │ 1   │ 2.52402   │ 2.23205       │ 2.32404         │
# │ 2   │ 1.25932   │ 1.13162       │ 1.21953         │
# │ 3   │ 1.12909   │ 1.21085       │ 1.33515         │
# │ 4   │ 1.00865   │ 0.855743      │ 0.978597        │
# │ 5   │ -0.525557 │ -0.719532     │ -0.732475       │
# │ 6   │ 0.522679  │ 0.0           │ 0.0             │
# │ 7   │ -0.469498 │ 0.0           │ 0.0             │
# │ 8   │ -0.388313 │ 0.0           │ 0.0             │
# │ 9   │ 0.354454  │ 0.0           │ 0.0             │
# │ 10  │ -0.277053 │ 0.0           │ 0.0             │
# No initilialization:
#     Iter =26
#     Time =0.6282899379730225
# Yes initilialization:
#     Iter = 35
#     Time = 1.8625788688659668
#
#
# running the 47 th model
# n, p = 1052, 7364
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β    │ est_β_no_init │ est_β_with_init │
# │     │ Float64   │ Float64       │ Float64         │
# ├─────┼───────────┼───────────────┼─────────────────┤
# │ 1   │ 1.62569   │ 1.77589       │ 1.79701         │
# │ 2   │ 1.44896   │ 1.54412       │ 1.57163         │
# │ 3   │ -1.03942  │ -1.00262      │ -1.00648        │
# │ 4   │ -1.03736  │ -1.06015      │ -1.05102        │
# │ 5   │ 0.869575  │ 0.851231      │ 0.839004        │
# │ 6   │ -0.618111 │ -0.67402      │ -0.671268       │
# │ 7   │ -0.370024 │ -0.46989      │ -0.486759       │
# │ 8   │ 0.358992  │ 0.36422       │ 0.395371        │
# │ 9   │ -0.221594 │ 0.0           │ 0.0             │
# │ 10  │ 0.0603021 │ 0.0           │ 0.0             │
# No initilialization:
#     Iter =34
#     Time =1.6258759498596191
# Yes initilialization:
#     Iter = 36
#     Time = 3.787355899810791
#
#
# running the 48 th model
# n, p = 1347, 9429
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β    │ est_β_no_init │ est_β_with_init │
# │     │ Float64   │ Float64       │ Float64         │
# ├─────┼───────────┼───────────────┼─────────────────┤
# │ 1   │ 1.57546   │ 1.66493       │ 1.70784         │
# │ 2   │ 0.835075  │ 0.884295      │ 0.894399        │
# │ 3   │ 0.627953  │ 0.512406      │ 0.538933        │
# │ 4   │ -0.608406 │ -0.555652     │ -0.549722       │
# │ 5   │ 0.508647  │ 0.502445      │ 0.530509        │
# │ 6   │ -0.50176  │ -0.706841     │ -0.725235       │
# │ 7   │ 0.241219  │ 0.0           │ 0.284499        │
# │ 8   │ 0.238656  │ 0.0           │ 0.0             │
# │ 9   │ 0.0821759 │ 0.0           │ 0.0             │
# │ 10  │ 0.0263825 │ 0.0           │ 0.0             │
# No initilialization:
#     Iter =21
#     Time =1.71356201171875
# Yes initilialization:
#     Iter = 50
#     Time = 7.736037969589233
#
#
# running the 49 th model
# n, p = 1671, 6684
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β    │ est_β_no_init │ est_β_with_init │
# │     │ Float64   │ Float64       │ Float64         │
# ├─────┼───────────┼───────────────┼─────────────────┤
# │ 1   │ 2.72911   │ 2.90461       │ 2.9042          │
# │ 2   │ -1.75184  │ -1.83825      │ -1.83808        │
# │ 3   │ 1.48107   │ 1.45391       │ 1.45378         │
# │ 4   │ -1.46072  │ -1.32921      │ -1.32909        │
# │ 5   │ -1.22515  │ -1.08703      │ -1.08693        │
# │ 6   │ 0.611568  │ 0.703154      │ 0.703065        │
# │ 7   │ 0.588566  │ 0.712709      │ 0.712651        │
# │ 8   │ 0.459546  │ 0.457555      │ 0.457522        │
# │ 9   │ -0.351852 │ -0.366433     │ -0.366399       │
# │ 10  │ -0.230753 │ 0.0           │ 0.0             │
# No initilialization:
#     Iter =47
#     Time =3.867582082748413
# Yes initilialization:
#     Iter = 43
#     Time = 6.168466091156006
#
#
# running the 50 th model
# n, p = 1427, 9989
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β    │ est_β_no_init │ est_β_with_init │
# │     │ Float64   │ Float64       │ Float64         │
# ├─────┼───────────┼───────────────┼─────────────────┤
# │ 1   │ -1.54507  │ -1.58599      │ -1.58606        │
# │ 2   │ 1.38656   │ 1.29791       │ 1.29797         │
# │ 3   │ 0.952717  │ 1.00756       │ 1.00761         │
# │ 4   │ 0.906077  │ 0.946579      │ 0.94662         │
# │ 5   │ 0.904165  │ 0.981965      │ 0.982008        │
# │ 6   │ -0.794114 │ -0.949816     │ -0.949859       │
# │ 7   │ -0.54543  │ -0.41744      │ -0.417459       │
# │ 8   │ 0.503974  │ 0.545503      │ 0.545525        │
# │ 9   │ -0.297532 │ -0.306806     │ -0.30682        │
# │ 10  │ 0.16455   │ 0.0           │ 0.0             │
# No initilialization:
#     Iter =24
#     Time =2.1358988285064697
# Yes initilialization:
#     Iter = 22
#     Time = 5.817259073257446
#
#
# With initialization, found 366 predictors out of 500
# With initialization, average time was 6.30710156917572
# Without initialization, found 362 predictors out of 500
# Without initialization, average time was 1.809880290031433

# %% [markdown]
# # Is debiasing good in terms of speed and model selection?
#
# Within each IHT iteration, we can fit a GLM regression (using scoring algorithm) on just the support set of that iteration. This is known as debiasing. We now investigate whether this is a good idea, both in terms of speed and model selection performance. (ans: yes)

# %%
function test_logistic_debias(n :: Int64, p :: Int64, k :: Int64)    
    #set random seed
    Random.seed!(1111)

    #construct snpmatrix, covariate files, and true model b
    x, maf = simulate_random_snparray(n, p)
    xbm = SnpBitMatrix{Float64}(x, model=ADDITIVE_MODEL, center=true, scale=true); 
    z = ones(n, 1) # non-genetic covariates, just the intercept
    true_b = zeros(p)
    true_b[1:k] = randn(k)
    shuffle!(true_b)
    correct_position = findall(x -> x != 0, true_b)

    #simulate bernoulli data
    y_temp = xbm * true_b
    prob = logistic.(y_temp) #inverse logit link
    y = [rand(Bernoulli(x)) for x in prob]
    y = Float64.(y)

    #compute poisson IHT result
    no_debias = L0_logistic_reg(x, z, y, 1, k, glm = "logistic", debias=false, convg=false, show_info=false, init=false)
    yes_debias = L0_logistic_reg(x, z, y, 1, k, glm = "logistic", debias=true, convg=false, show_info=false, init=false)
    
    #check result
    est_model_yes = yes_debias.beta[correct_position]
    est_model_no = no_debias.beta[correct_position]
    true_model = true_b[correct_position]
    compare_model = DataFrame(
        true_β           = true_model, 
        est_β_no_debias  = est_model_no,
        est_β_yes_debias = est_model_yes)
        
    #display results
    @show sort(compare_model, rev=true, by=abs)
    println("No debiasing:")
    println("    Iter = " * string(no_debias.iter))
    println("    Time = " * string(no_debias.time))
    println("Yes debiasing:")
    println("    Iter = " * string(yes_debias.iter))
    println("    Time = " * string(yes_debias.time) * "\n\n")
    
    #return summary statistic
    yes_debias_found = length(findall(!iszero, est_model_yes))
    no_debias_found = length(findall(!iszero, est_model_no))
    yes_debias_time = yes_debias.time
    no_debias_time = no_debias.time
    return yes_debias_found, no_debias_found, yes_debias_time, no_debias_time
end
# Out:
# test_logistic_debias (generic function with 1 method)

# %%
k = 10
yes_debias_total_found = 0
no_debias_total_found = 0
yes_debias_total_time = 0
no_debias_total_time = 0

iter = 50
for i = 1:iter
    println("running the $i th model")
    n = rand(500:2000) 
    p = rand(1:10)n
    println("n, p = " * string(n) * ", " * string(p))
    ydf, ndf, ydt, ndt = test_logistic_debias(n, p, k)
    yes_debias_total_found += ydf
    no_debias_total_found += ndf
    yes_debias_total_time += ydt
    no_debias_total_time += ndt
end
println("With debiasing, found $yes_debias_total_found " * "predictors out of " * string(k*iter))
println("With debiasing, average time was " * string(yes_debias_total_time/iter))
println("Without debiasing, found $no_debias_total_found " * "predictors out of " * string(k*iter))
println("Without debiasing, average time was " * string(no_debias_total_time/iter))
# Out:
# running the 1 th model
# n, p = 1773, 14184
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β     │ est_β_no_debias │ est_β_yes_debias │
# │     │ Float64    │ Float64         │ Float64          │
# ├─────┼────────────┼─────────────────┼──────────────────┤
# │ 1   │ -1.45114   │ -1.28484        │ -1.28621         │
# │ 2   │ -1.27653   │ -1.39328        │ -1.39483         │
# │ 3   │ 1.2719     │ 1.25807         │ 1.25945          │
# │ 4   │ -1.06845   │ -1.1152         │ -1.11638         │
# │ 5   │ -1.05779   │ -1.20612        │ -1.2075          │
# │ 6   │ -1.04699   │ -1.08232        │ -1.08359         │
# │ 7   │ -0.599334  │ -0.482863       │ -0.483373        │
# │ 8   │ -0.259217  │ -0.268291       │ -0.268572        │
# │ 9   │ -0.0652767 │ 0.0             │ 0.0              │
# │ 10  │ -0.0383971 │ 0.0             │ 0.0              │
# No debiasing:
#     Iter = 35
#     Time = 5.318166971206665
# Yes debiasing:
#     Iter = 12
#     Time = 1.9383821487426758
#
#
# running the 2 th model
# n, p = 1084, 7588
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β    │ est_β_no_debias │ est_β_yes_debias │
# │     │ Float64   │ Float64         │ Float64          │
# ├─────┼───────────┼─────────────────┼──────────────────┤
# │ 1   │ -1.38415  │ -1.52968        │ -1.53099         │
# │ 2   │ -1.05264  │ -1.09924        │ -1.10001         │
# │ 3   │ -0.789241 │ -0.830038       │ -0.830769        │
# │ 4   │ 0.766733  │ 0.872298        │ 0.873101         │
# │ 5   │ 0.64681   │ 0.77572         │ 0.776323         │
# │ 6   │ 0.571508  │ 0.519719        │ 0.520202         │
# │ 7   │ -0.373109 │ -0.408414       │ -0.408682        │
# │ 8   │ -0.372716 │ 0.0             │ 0.0              │
# │ 9   │ 0.366782  │ 0.327216        │ 0.327467         │
# │ 10  │ -0.161275 │ 0.0             │ 0.0              │
# No debiasing:
#     Iter = 20
#     Time = 1.0516347885131836
# Yes debiasing:
#     Iter = 12
#     Time = 0.6787288188934326
#
#
# running the 3 th model
# n, p = 1128, 3384
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β    │ est_β_no_debias │ est_β_yes_debias │
# │     │ Float64   │ Float64         │ Float64          │
# ├─────┼───────────┼─────────────────┼──────────────────┤
# │ 1   │ -1.73827  │ -1.7013         │ -1.70041         │
# │ 2   │ 1.33189   │ 1.46701         │ 1.49124          │
# │ 3   │ 1.11517   │ 1.15202         │ 1.17379          │
# │ 4   │ -0.895059 │ -0.804305       │ -0.814982        │
# │ 5   │ -0.889063 │ -0.998946       │ -1.00269         │
# │ 6   │ 0.692984  │ 0.648176        │ 0.633392         │
# │ 7   │ 0.30618   │ 0.341185        │ 0.320779         │
# │ 8   │ -0.305245 │ 0.0             │ -0.32649         │
# │ 9   │ 0.181507  │ 0.0             │ 0.0              │
# │ 10  │ -0.113109 │ -0.295274       │ -0.309007        │
# No debiasing:
#     Iter = 36
#     Time = 0.8813281059265137
# Yes debiasing:
#     Iter = 16
#     Time = 0.43460583686828613
#
#
# running the 4 th model
# n, p = 1535, 13815
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β    │ est_β_no_debias │ est_β_yes_debias │
# │     │ Float64   │ Float64         │ Float64          │
# ├─────┼───────────┼─────────────────┼──────────────────┤
# │ 1   │ -1.24815  │ -1.38667        │ -1.38741         │
# │ 2   │ -1.0843   │ -1.14939        │ -1.15005         │
# │ 3   │ -1.0732   │ -1.22152        │ -1.22221         │
# │ 4   │ -0.967546 │ -1.19433        │ -1.19527         │
# │ 5   │ 0.48288   │ 0.457898        │ 0.458166         │
# │ 6   │ -0.316924 │ -0.340991       │ -0.341208        │
# │ 7   │ -0.195412 │ 0.0             │ 0.0              │
# │ 8   │ 0.159591  │ 0.0             │ 0.0              │
# │ 9   │ 0.151938  │ 0.0             │ 0.0              │
# │ 10  │ -0.098264 │ 0.0             │ 0.0              │
# No debiasing:
#     Iter = 21
#     Time = 2.817760944366455
# Yes debiasing:
#     Iter = 20
#     Time = 2.6096339225769043
#
#
# running the 5 th model
# n, p = 1390, 1390
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β   │ est_β_no_debias │ est_β_yes_debias │
# │     │ Float64  │ Float64         │ Float64          │
# ├─────┼──────────┼─────────────────┼──────────────────┤
# │ 1   │ 3.19752  │ 3.37103         │ 3.3866           │
# │ 2   │ -1.79805 │ -2.06962        │ -2.04786         │
# │ 3   │ -1.1913  │ -1.23142        │ -1.2236          │
# │ 4   │ 0.744764 │ 0.731034        │ 0.748247         │
# │ 5   │ 0.730828 │ 0.727428        │ 0.747298         │
# │ 6   │ 0.665033 │ 0.717896        │ 0.738985         │
# │ 7   │ 0.640108 │ 0.645527        │ 0.673795         │
# │ 8   │ 0.590184 │ 0.747942        │ 0.768755         │
# │ 9   │ 0.402659 │ 0.444657        │ 0.437073         │
# │ 10  │ 0.010725 │ 0.0             │ 0.0              │
# No debiasing:
#     Iter = 43
#     Time = 0.5290350914001465
# Yes debiasing:
#     Iter = 14
#     Time = 0.2183988094329834
#
#
# running the 6 th model
# n, p = 1389, 4167
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β      │ est_β_no_debias │ est_β_yes_debias │
# │     │ Float64     │ Float64         │ Float64          │
# ├─────┼─────────────┼─────────────────┼──────────────────┤
# │ 1   │ -2.09873    │ -2.37322        │ -2.39038         │
# │ 2   │ -2.01539    │ -2.2573         │ -2.22859         │
# │ 3   │ 1.89726     │ 2.08141         │ 2.09006          │
# │ 4   │ 1.8124      │ 2.19168         │ 2.23225          │
# │ 5   │ 0.571692    │ 0.583127        │ 0.587954         │
# │ 6   │ -0.533855   │ -0.656481       │ -0.629112        │
# │ 7   │ 0.505425    │ 0.45412         │ 0.44701          │
# │ 8   │ -0.281664   │ 0.0             │ -0.352053        │
# │ 9   │ -0.147195   │ 0.0             │ 0.0              │
# │ 10  │ -0.00513477 │ 0.0             │ 0.0              │
# No debiasing:
#     Iter = 46
#     Time = 1.6127769947052002
# Yes debiasing:
#     Iter = 11
#     Time = 0.46266984939575195
#
#
# running the 7 th model
# n, p = 1560, 14040
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β    │ est_β_no_debias │ est_β_yes_debias │
# │     │ Float64   │ Float64         │ Float64          │
# ├─────┼───────────┼─────────────────┼──────────────────┤
# │ 1   │ -1.89787  │ -1.79414        │ -1.79678         │
# │ 2   │ -1.60541  │ -1.64845        │ -1.65851         │
# │ 3   │ -1.24594  │ -1.29873        │ -1.29647         │
# │ 4   │ 1.06169   │ 0.999275        │ 0.997775         │
# │ 5   │ -1.04874  │ -0.913479       │ -0.930126        │
# │ 6   │ -0.954571 │ -1.00058        │ -0.992841        │
# │ 7   │ 0.794195  │ 0.854441        │ 0.874379         │
# │ 8   │ -0.51058  │ -0.33176        │ -0.325987        │
# │ 9   │ 0.466011  │ 0.320495        │ 0.0              │
# │ 10  │ 0.37565   │ 0.433934        │ 0.451806         │
# No debiasing:
#     Iter = 39
#     Time = 5.2673499584198
# Yes debiasing:
#     Iter = 13
#     Time = 1.8634440898895264
#
#
# running the 8 th model
# n, p = 546, 546
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β    │ est_β_no_debias │ est_β_yes_debias │
# │     │ Float64   │ Float64         │ Float64          │
# ├─────┼───────────┼─────────────────┼──────────────────┤
# │ 1   │ -1.6901   │ -1.67063        │ -1.67287         │
# │ 2   │ 1.07565   │ 0.872985        │ 0.873891         │
# │ 3   │ -1.01547  │ -0.820586       │ -0.821622        │
# │ 4   │ -0.905156 │ -0.736369       │ -0.737119        │
# │ 5   │ -0.83042  │ -0.773295       │ -0.77412         │
# │ 6   │ -0.783345 │ -0.677395       │ -0.677958        │
# │ 7   │ 0.632524  │ 0.61204         │ 0.612763         │
# │ 8   │ 0.551765  │ 0.545536        │ 0.546161         │
# │ 9   │ 0.479842  │ 0.468995        │ 0.469543         │
# │ 10  │ 0.0816871 │ 0.0             │ 0.0              │
# No debiasing:
#     Iter = 19
#     Time = 0.03981304168701172
# Yes debiasing:
#     Iter = 15
#     Time = 0.04603910446166992
#
#
# running the 9 th model
# n, p = 1394, 13940
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β      │ est_β_no_debias │ est_β_yes_debias │
# │     │ Float64     │ Float64         │ Float64          │
# ├─────┼─────────────┼─────────────────┼──────────────────┤
# │ 1   │ -1.27347    │ -1.26358        │ -1.26856         │
# │ 2   │ -0.942521   │ -0.954058       │ -0.942046        │
# │ 3   │ 0.606559    │ 0.745389        │ 0.743732         │
# │ 4   │ -0.401995   │ -0.41518        │ -0.389408        │
# │ 5   │ -0.266977   │ -0.357515       │ -0.344541        │
# │ 6   │ -0.190883   │ 0.0             │ 0.0              │
# │ 7   │ 0.103841    │ 0.0             │ 0.0              │
# │ 8   │ 0.0664769   │ 0.0             │ 0.0              │
# │ 9   │ 0.0363198   │ 0.0             │ 0.0              │
# │ 10  │ -0.00299459 │ 0.0             │ 0.0              │
# No debiasing:
#     Iter = 17
#     Time = 2.0746471881866455
# Yes debiasing:
#     Iter = 11
#     Time = 1.4265592098236084
#
#
# running the 10 th model
# n, p = 1133, 1133
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β     │ est_β_no_debias │ est_β_yes_debias │
# │     │ Float64    │ Float64         │ Float64          │
# ├─────┼────────────┼─────────────────┼──────────────────┤
# │ 1   │ -1.49367   │ -1.48088        │ -1.52116         │
# │ 2   │ -1.09043   │ -1.05268        │ -1.05484         │
# │ 3   │ 0.70631    │ 0.908612        │ 0.92289          │
# │ 4   │ -0.61696   │ -0.782213       │ -0.778867        │
# │ 5   │ -0.602165  │ -0.630987       │ -0.620166        │
# │ 6   │ -0.403802  │ -0.327639       │ -0.340515        │
# │ 7   │ -0.402237  │ -0.370844       │ -0.364462        │
# │ 8   │ -0.339709  │ -0.250437       │ -0.262904        │
# │ 9   │ -0.197429  │ 0.0             │ 0.0              │
# │ 10  │ -0.0522495 │ 0.0             │ 0.0              │
# No debiasing:
#     Iter = 17
#     Time = 0.14547491073608398
# Yes debiasing:
#     Iter = 13
#     Time = 0.13833904266357422
#
#
# running the 11 th model
# n, p = 1160, 6960
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β    │ est_β_no_debias │ est_β_yes_debias │
# │     │ Float64   │ Float64         │ Float64          │
# ├─────┼───────────┼─────────────────┼──────────────────┤
# │ 1   │ -1.89029  │ -2.02949        │ -2.03135         │
# │ 2   │ 1.17783   │ 1.37803         │ 1.37825          │
# │ 3   │ -1.05024  │ -1.03262        │ -1.03294         │
# │ 4   │ 0.976595  │ 1.55287         │ 1.56572          │
# │ 5   │ -0.956401 │ -0.860034       │ -0.860381        │
# │ 6   │ 0.802595  │ 0.970622        │ 0.971244         │
# │ 7   │ 0.795196  │ 0.837248        │ 0.837597         │
# │ 8   │ -0.563013 │ -0.498598       │ -0.498652        │
# │ 9   │ 0.421775  │ 0.441901        │ 0.441973         │
# │ 10  │ -0.112037 │ 0.0             │ 0.0              │
# No debiasing:
#     Iter = 85
#     Time = 4.151221036911011
# Yes debiasing:
#     Iter = 11
#     Time = 0.6352770328521729
#
#
# running the 12 th model
# n, p = 1705, 17050
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β    │ est_β_no_debias │ est_β_yes_debias │
# │     │ Float64   │ Float64         │ Float64          │
# ├─────┼───────────┼─────────────────┼──────────────────┤
# │ 1   │ 1.27399   │ 1.16232         │ 1.16315          │
# │ 2   │ 0.919085  │ 0.901621        │ 0.902261         │
# │ 3   │ 0.87314   │ 0.895799        │ 0.896414         │
# │ 4   │ 0.796401  │ 0.720285        │ 0.720799         │
# │ 5   │ 0.775982  │ 0.860075        │ 0.860715         │
# │ 6   │ 0.767836  │ 0.762077        │ 0.762639         │
# │ 7   │ -0.654847 │ -0.652945       │ -0.653435        │
# │ 8   │ 0.59723   │ 0.548536        │ 0.548976         │
# │ 9   │ 0.521746  │ 0.561911        │ 0.562289         │
# │ 10  │ 0.181678  │ 0.0             │ 0.0              │
# No debiasing:
#     Iter = 20
#     Time = 3.558319091796875
# Yes debiasing:
#     Iter = 14
#     Time = 2.5300118923187256
#
#
# running the 13 th model
# n, p = 732, 5124
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β   │ est_β_no_debias │ est_β_yes_debias │
# │     │ Float64  │ Float64         │ Float64          │
# ├─────┼──────────┼─────────────────┼──────────────────┤
# │ 1   │ 2.42235  │ 2.47995         │ 2.52221          │
# │ 2   │ 2.02107  │ 1.86932         │ 1.95398          │
# │ 3   │ -1.92595 │ -1.91885        │ -1.97798         │
# │ 4   │ 1.83947  │ 1.60871         │ 1.68501          │
# │ 5   │ 1.41993  │ 1.3718          │ 1.37646          │
# │ 6   │ 1.32172  │ 1.27192         │ 1.27362          │
# │ 7   │ -1.01454 │ -1.08333        │ -1.08023         │
# │ 8   │ 0.805066 │ 0.564975        │ 0.59716          │
# │ 9   │ 0.674827 │ 0.527896        │ 0.562028         │
# │ 10  │ 0.544614 │ 0.0             │ 0.0              │
# No debiasing:
#     Iter = 43
#     Time = 0.9815211296081543
# Yes debiasing:
#     Iter = 13
#     Time = 0.32705116271972656
#
#
# running the 14 th model
# n, p = 720, 4320
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β    │ est_β_no_debias │ est_β_yes_debias │
# │     │ Float64   │ Float64         │ Float64          │
# ├─────┼───────────┼─────────────────┼──────────────────┤
# │ 1   │ 2.33321   │ 2.65909         │ 2.67091          │
# │ 2   │ -1.90482  │ -2.00881        │ -2.10181         │
# │ 3   │ 1.69295   │ 1.86427         │ 1.84018          │
# │ 4   │ -1.14999  │ -1.40647        │ -1.40129         │
# │ 5   │ -0.86154  │ -0.767225       │ -0.728419        │
# │ 6   │ 0.677714  │ 0.880766        │ 0.822684         │
# │ 7   │ -0.646758 │ -0.837991       │ -0.843833        │
# │ 8   │ 0.50164   │ 0.496583        │ 0.480679         │
# │ 9   │ -0.417907 │ 0.0             │ 0.0              │
# │ 10  │ -0.202827 │ 0.0             │ 0.0              │
# No debiasing:
#     Iter = 53
#     Time = 0.9608359336853027
# Yes debiasing:
#     Iter = 15
#     Time = 0.31099486351013184
#
#
# running the 15 th model
# n, p = 1445, 8670
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β      │ est_β_no_debias │ est_β_yes_debias │
# │     │ Float64     │ Float64         │ Float64          │
# ├─────┼─────────────┼─────────────────┼──────────────────┤
# │ 1   │ 2.98646     │ 3.16234         │ 3.19391          │
# │ 2   │ 2.02289     │ 2.15277         │ 2.17767          │
# │ 3   │ 1.45604     │ 1.43215         │ 1.45414          │
# │ 4   │ -1.17533    │ -1.24095        │ -1.26375         │
# │ 5   │ 1.16786     │ 1.18106         │ 1.18377          │
# │ 6   │ 1.0803      │ 1.10851         │ 1.1114           │
# │ 7   │ 0.58814     │ 0.821511        │ 0.818697         │
# │ 8   │ 0.185924    │ 0.0             │ 0.0              │
# │ 9   │ -0.109511   │ 0.0             │ 0.0              │
# │ 10  │ -0.00560907 │ 0.0             │ 0.0              │
# No debiasing:
#     Iter = 48
#     Time = 3.6227200031280518
# Yes debiasing:
#     Iter = 21
#     Time = 1.7015290260314941
#
#
# running the 16 th model
# n, p = 1259, 11331
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β    │ est_β_no_debias │ est_β_yes_debias │
# │     │ Float64   │ Float64         │ Float64          │
# ├─────┼───────────┼─────────────────┼──────────────────┤
# │ 1   │ -1.53226  │ -1.42446        │ -1.42553         │
# │ 2   │ -1.46167  │ -1.30411        │ -1.31826         │
# │ 3   │ -1.36022  │ -1.44161        │ -1.48972         │
# │ 4   │ 1.19754   │ 1.17568         │ 1.21673          │
# │ 5   │ -0.804039 │ -0.891934       │ -0.864643        │
# │ 6   │ 0.801379  │ 0.861962        │ 0.858108         │
# │ 7   │ -0.542772 │ -0.494816       │ -0.455864        │
# │ 8   │ -0.329399 │ 0.0             │ 0.0              │
# │ 9   │ 0.23736   │ 0.0             │ 0.0              │
# │ 10  │ 0.228609  │ 0.0             │ 0.0              │
# No debiasing:
#     Iter = 37
#     Time = 3.292280912399292
# Yes debiasing:
#     Iter = 12
#     Time = 1.1667919158935547
#
#
# running the 17 th model
# n, p = 1247, 8729
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β    │ est_β_no_debias │ est_β_yes_debias │
# │     │ Float64   │ Float64         │ Float64          │
# ├─────┼───────────┼─────────────────┼──────────────────┤
# │ 1   │ -1.66437  │ -1.7702         │ -1.76303         │
# │ 2   │ -1.16961  │ -1.30264        │ -1.25491         │
# │ 3   │ 0.795939  │ 0.746977        │ 0.741937         │
# │ 4   │ 0.778759  │ 0.741606        │ 0.763613         │
# │ 5   │ -0.762457 │ -0.763799       │ -0.766374        │
# │ 6   │ -0.738182 │ -0.79373        │ -0.797886        │
# │ 7   │ 0.654995  │ 0.557682        │ 0.546705         │
# │ 8   │ -0.577503 │ -0.622465       │ -0.610945        │
# │ 9   │ 0.29587   │ 0.0             │ 0.0              │
# │ 10  │ -0.200601 │ 0.0             │ 0.0              │
# No debiasing:
#     Iter = 21
#     Time = 1.369318962097168
# Yes debiasing:
#     Iter = 14
#     Time = 0.9681439399719238
#
#
# running the 18 th model
# n, p = 923, 6461
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β    │ est_β_no_debias │ est_β_yes_debias │
# │     │ Float64   │ Float64         │ Float64          │
# ├─────┼───────────┼─────────────────┼──────────────────┤
# │ 1   │ -2.04426  │ -1.91702        │ -2.0188          │
# │ 2   │ 1.332     │ 1.42666         │ 1.46429          │
# │ 3   │ -1.18436  │ -1.1822         │ -1.20427         │
# │ 4   │ -1.16792  │ -1.24034        │ -1.26954         │
# │ 5   │ -0.693255 │ -0.762049       │ -0.77788         │
# │ 6   │ 0.662508  │ 0.91955         │ 0.917257         │
# │ 7   │ -0.458847 │ -0.641829       │ -0.645771        │
# │ 8   │ -0.35573  │ 0.0             │ -0.397324        │
# │ 9   │ -0.275403 │ 0.0             │ 0.0              │
# │ 10  │ -0.272916 │ 0.0             │ 0.0              │
# No debiasing:
#     Iter = 35
#     Time = 1.3316848278045654
# Yes debiasing:
#     Iter = 15
#     Time = 0.6157751083374023
#
#
# running the 19 th model
# n, p = 1855, 9275
# Did not converge!!!!! The run time for IHT was 99.36545300483704seconds and model size was10sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β    │ est_β_no_debias │ est_β_yes_debias │
# │     │ Float64   │ Float64         │ Float64          │
# ├─────┼───────────┼─────────────────┼──────────────────┤
# │ 1   │ 2.40089   │ 2.71015         │ 2.51006          │
# │ 2   │ -1.64083  │ -1.90925        │ -1.83532         │
# │ 3   │ 1.19392   │ 1.23451         │ 1.29081          │
# │ 4   │ 1.15375   │ 0.396054        │ 3.47127          │
# │ 5   │ -0.591829 │ -0.447841       │ -0.486178        │
# │ 6   │ -0.574977 │ -0.740093       │ -0.672719        │
# │ 7   │ 0.561704  │ 0.586944        │ 0.58326          │
# │ 8   │ -0.454301 │ -0.571438       │ -0.495491        │
# │ 9   │ 0.315283  │ 0.481003        │ 0.410356         │
# │ 10  │ 0.0667044 │ 0.0             │ 0.0              │
# No debiasing:
#     Iter = 1000
#     Time = 99.36545300483704
# Yes debiasing:
#     Iter = 14
#     Time = 1.5774171352386475
#
#
# running the 20 th model
# n, p = 1033, 10330
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β    │ est_β_no_debias │ est_β_yes_debias │
# │     │ Float64   │ Float64         │ Float64          │
# ├─────┼───────────┼─────────────────┼──────────────────┤
# │ 1   │ 1.25433   │ 1.21109         │ 1.21217          │
# │ 2   │ -1.19048  │ -1.09266        │ -1.09367         │
# │ 3   │ 0.887489  │ 0.928576        │ 0.929466         │
# │ 4   │ 0.804048  │ 0.934163        │ 0.935089         │
# │ 5   │ -0.794026 │ -0.75995        │ -0.760541        │
# │ 6   │ 0.639034  │ 0.566318        │ 0.56684          │
# │ 7   │ -0.627366 │ -0.771726       │ -0.772376        │
# │ 8   │ -0.569678 │ -0.511614       │ -0.512149        │
# │ 9   │ -0.253648 │ -0.449828       │ -0.450204        │
# │ 10  │ -0.194984 │ 0.0             │ 0.0              │
# No debiasing:
#     Iter = 21
#     Time = 1.439906120300293
# Yes debiasing:
#     Iter = 12
#     Time = 0.900644063949585
#
#
# running the 21 th model
# n, p = 1421, 2842
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β     │ est_β_no_debias │ est_β_yes_debias │
# │     │ Float64    │ Float64         │ Float64          │
# ├─────┼────────────┼─────────────────┼──────────────────┤
# │ 1   │ -1.95726   │ -1.43657        │ -1.45466         │
# │ 2   │ 1.91583    │ 1.88508         │ 1.8845           │
# │ 3   │ -1.65571   │ -1.74452        │ -1.7433          │
# │ 4   │ 1.39881    │ 1.42169         │ 1.42106          │
# │ 5   │ -1.19749   │ -1.14318        │ -1.14243         │
# │ 6   │ 0.323236   │ 0.405635        │ 0.405511         │
# │ 7   │ -0.290512  │ 0.0             │ 0.0              │
# │ 8   │ 0.263359   │ 0.0             │ 0.0              │
# │ 9   │ -0.217589  │ 0.0             │ 0.0              │
# │ 10  │ -0.0605532 │ 0.0             │ 0.0              │
# No debiasing:
#     Iter = 144
#     Time = 3.4212560653686523
# Yes debiasing:
#     Iter = 13
#     Time = 0.38834691047668457
#
#
# running the 22 th model
# n, p = 1365, 2730
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β     │ est_β_no_debias │ est_β_yes_debias │
# │     │ Float64    │ Float64         │ Float64          │
# ├─────┼────────────┼─────────────────┼──────────────────┤
# │ 1   │ 1.59208    │ 1.50751         │ 1.51248          │
# │ 2   │ 1.5453     │ 1.50203         │ 1.53247          │
# │ 3   │ -1.19277   │ -1.16058        │ -1.16474         │
# │ 4   │ -1.1726    │ -1.3187         │ -1.33655         │
# │ 5   │ 1.04226    │ 0.987079        │ 1.00403          │
# │ 6   │ -0.962435  │ -1.05115        │ -1.05438         │
# │ 7   │ 0.916447   │ 0.689837        │ 0.681057         │
# │ 8   │ 0.233124   │ 0.0             │ 0.0              │
# │ 9   │ 0.216522   │ 0.0             │ 0.266262         │
# │ 10  │ -0.0310352 │ 0.0             │ 0.0              │
# No debiasing:
#     Iter = 35
#     Time = 0.8243379592895508
# Yes debiasing:
#     Iter = 12
#     Time = 0.333651065826416
#
#
# running the 23 th model
# n, p = 1708, 15372
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β    │ est_β_no_debias │ est_β_yes_debias │
# │     │ Float64   │ Float64         │ Float64          │
# ├─────┼───────────┼─────────────────┼──────────────────┤
# │ 1   │ 2.84544   │ 2.80989         │ 2.72034          │
# │ 2   │ 1.00651   │ 0.975759        │ 0.986261         │
# │ 3   │ 0.643838  │ 0.642045        │ 0.636868         │
# │ 4   │ 0.392656  │ 0.464561        │ 0.453365         │
# │ 5   │ 0.301612  │ 0.262236        │ 0.269325         │
# │ 6   │ -0.224038 │ 0.0             │ 0.0              │
# │ 7   │ 0.207259  │ 0.0             │ 0.0              │
# │ 8   │ -0.181109 │ 0.0             │ 0.0              │
# │ 9   │ 0.0992214 │ 0.0             │ 0.0              │
# │ 10  │ 0.0210077 │ 0.0             │ 0.0              │
# No debiasing:
#     Iter = 111
#     Time = 16.348344087600708
# Yes debiasing:
#     Iter = 17
#     Time = 2.7135391235351562
#
#
# running the 24 th model
# n, p = 1538, 4614
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β     │ est_β_no_debias │ est_β_yes_debias │
# │     │ Float64    │ Float64         │ Float64          │
# ├─────┼────────────┼─────────────────┼──────────────────┤
# │ 1   │ 1.59297    │ 1.61995         │ 1.62596          │
# │ 2   │ 1.3681     │ 1.34959         │ 1.35838          │
# │ 3   │ -1.12466   │ -1.20519        │ -1.21642         │
# │ 4   │ 1.07789    │ 1.06789         │ 1.05959          │
# │ 5   │ 0.956571   │ 0.948923        │ 0.955269         │
# │ 6   │ -0.616601  │ -0.682506       │ -0.700745        │
# │ 7   │ 0.448375   │ 0.337403        │ 0.335911         │
# │ 8   │ 0.14606    │ 0.0             │ 0.0              │
# │ 9   │ -0.130785  │ 0.0             │ 0.0              │
# │ 10  │ -0.0150109 │ 0.0             │ 0.0              │
# No debiasing:
#     Iter = 23
#     Time = 1.1338560581207275
# Yes debiasing:
#     Iter = 7
#     Time = 0.40437889099121094
#
#
# running the 25 th model
# n, p = 819, 1638
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β    │ est_β_no_debias │ est_β_yes_debias │
# │     │ Float64   │ Float64         │ Float64          │
# ├─────┼───────────┼─────────────────┼──────────────────┤
# │ 1   │ 2.92052   │ 3.09278         │ 3.17547          │
# │ 2   │ -2.12535  │ -2.25305        │ -2.2698          │
# │ 3   │ 1.02157   │ 1.13569         │ 1.17032          │
# │ 4   │ -0.613413 │ -0.847681       │ -0.828597        │
# │ 5   │ 0.488893  │ 0.509964        │ 0.583037         │
# │ 6   │ 0.426945  │ 0.0             │ 0.0              │
# │ 7   │ -0.342343 │ 0.0             │ 0.0              │
# │ 8   │ 0.172696  │ 0.0             │ 0.0              │
# │ 9   │ 0.0957559 │ 0.0             │ 0.0              │
# │ 10  │ 0.0130187 │ 0.0             │ 0.0              │
# No debiasing:
#     Iter = 41
#     Time = 0.36626601219177246
# Yes debiasing:
#     Iter = 12
#     Time = 0.12191390991210938
#
#
# running the 26 th model
# n, p = 628, 1884
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β      │ est_β_no_debias │ est_β_yes_debias │
# │     │ Float64     │ Float64         │ Float64          │
# ├─────┼─────────────┼─────────────────┼──────────────────┤
# │ 1   │ 2.92823     │ 3.45607         │ 3.41045          │
# │ 2   │ 2.37629     │ 3.85905         │ 3.93833          │
# │ 3   │ 1.69475     │ 1.78028         │ 1.65112          │
# │ 4   │ 1.01576     │ 1.37706         │ 1.24421          │
# │ 5   │ -0.896313   │ -1.08342        │ -1.13022         │
# │ 6   │ 0.89245     │ 1.13278         │ 1.07957          │
# │ 7   │ 0.745157    │ 1.00089         │ 1.00439          │
# │ 8   │ 0.73079     │ 0.0             │ 0.661215         │
# │ 9   │ 0.510363    │ 0.831265        │ 0.768653         │
# │ 10  │ -0.00587085 │ 0.0             │ 0.0              │
# No debiasing:
#     Iter = 112
#     Time = 0.7423880100250244
# Yes debiasing:
#     Iter = 15
#     Time = 0.13166379928588867
#
#
# running the 27 th model
# n, p = 596, 1192
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β     │ est_β_no_debias │ est_β_yes_debias │
# │     │ Float64    │ Float64         │ Float64          │
# ├─────┼────────────┼─────────────────┼──────────────────┤
# │ 1   │ 2.08229    │ 2.05336         │ 2.05686          │
# │ 2   │ 1.29159    │ 1.34199         │ 1.34454          │
# │ 3   │ -1.15622   │ -0.960644       │ -0.962435        │
# │ 4   │ -1.12793   │ -0.761622       │ -0.762883        │
# │ 5   │ -0.999501  │ -0.963536       │ -0.967191        │
# │ 6   │ 0.511007   │ 0.65316         │ 0.654237         │
# │ 7   │ 0.350923   │ 0.0             │ 0.0              │
# │ 8   │ -0.276996  │ -0.468906       │ -0.469689        │
# │ 9   │ 0.169096   │ 0.0             │ 0.0              │
# │ 10  │ -0.0674873 │ 0.0             │ 0.0              │
# No debiasing:
#     Iter = 35
#     Time = 0.16895389556884766
# Yes debiasing:
#     Iter = 12
#     Time = 0.0654301643371582
#
#
# running the 28 th model
# n, p = 813, 3252
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β     │ est_β_no_debias │ est_β_yes_debias │
# │     │ Float64    │ Float64         │ Float64          │
# ├─────┼────────────┼─────────────────┼──────────────────┤
# │ 1   │ -1.92796   │ -1.97509        │ -1.92987         │
# │ 2   │ -1.59026   │ -1.52926        │ -1.50263         │
# │ 3   │ 1.5867     │ 1.65788         │ 1.57096          │
# │ 4   │ -1.44735   │ -1.25653        │ -1.29266         │
# │ 5   │ 1.2772     │ 1.35298         │ 1.37775          │
# │ 6   │ -1.19647   │ -1.14555        │ -1.12155         │
# │ 7   │ -0.596173  │ -0.646844       │ -0.603326        │
# │ 8   │ -0.403024  │ 0.0             │ 0.0              │
# │ 9   │ 0.383289   │ 0.369367        │ 0.0              │
# │ 10  │ -0.0200048 │ 0.0             │ 0.0              │
# No debiasing:
#     Iter = 38
#     Time = 0.618319034576416
# Yes debiasing:
#     Iter = 11
#     Time = 0.21577906608581543
#
#
# running the 29 th model
# n, p = 1228, 8596
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β     │ est_β_no_debias │ est_β_yes_debias │
# │     │ Float64    │ Float64         │ Float64          │
# ├─────┼────────────┼─────────────────┼──────────────────┤
# │ 1   │ -1.78386   │ -1.78559        │ -1.78774         │
# │ 2   │ -1.1782    │ -1.21616        │ -1.2176          │
# │ 3   │ -1.15899   │ -1.1166         │ -1.11795         │
# │ 4   │ 0.997745   │ 0.973537        │ 0.975779         │
# │ 5   │ -0.919573  │ -0.998339       │ -0.99953         │
# │ 6   │ -0.7724    │ -0.60755        │ -0.608266        │
# │ 7   │ -0.543164  │ -0.553352       │ -0.554025        │
# │ 8   │ -0.406331  │ -0.33816        │ -0.33849         │
# │ 9   │ 0.290219   │ 0.0             │ 0.0              │
# │ 10  │ -0.0891076 │ 0.0             │ 0.0              │
# No debiasing:
#     Iter = 23
#     Time = 1.5220568180084229
# Yes debiasing:
#     Iter = 11
#     Time = 0.7842869758605957
#
#
# running the 30 th model
# n, p = 1754, 8770
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β    │ est_β_no_debias │ est_β_yes_debias │
# │     │ Float64   │ Float64         │ Float64          │
# ├─────┼───────────┼─────────────────┼──────────────────┤
# │ 1   │ 1.92728   │ 2.05947         │ 2.03246          │
# │ 2   │ 1.56619   │ 1.59615         │ 1.57078          │
# │ 3   │ 1.46142   │ 1.68141         │ 1.684            │
# │ 4   │ -0.966722 │ -0.943321       │ -0.957513        │
# │ 5   │ -0.508654 │ -0.502701       │ -0.508095        │
# │ 6   │ 0.431853  │ 0.479082        │ 0.468681         │
# │ 7   │ -0.29403  │ 0.0             │ 0.0              │
# │ 8   │ 0.191473  │ 0.266677        │ 0.0              │
# │ 9   │ -0.111581 │ 0.0             │ 0.0              │
# │ 10  │ -0.109006 │ -0.318512       │ -0.314842        │
# No debiasing:
#     Iter = 39
#     Time = 3.561041831970215
# Yes debiasing:
#     Iter = 12
#     Time = 1.1998698711395264
#
#
# running the 31 th model
# n, p = 562, 2248
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β    │ est_β_no_debias │ est_β_yes_debias │
# │     │ Float64   │ Float64         │ Float64          │
# ├─────┼───────────┼─────────────────┼──────────────────┤
# │ 1   │ 2.71321   │ 3.07073         │ 3.26446          │
# │ 2   │ -1.59096  │ -1.7124         │ -1.66916         │
# │ 3   │ -1.35792  │ -1.33065        │ -1.90343         │
# │ 4   │ -1.19345  │ -1.22508        │ -1.21893         │
# │ 5   │ 0.929352  │ 0.937827        │ 0.971726         │
# │ 6   │ 0.669375  │ 0.642284        │ 0.675183         │
# │ 7   │ -0.663243 │ -0.734684       │ -0.761952        │
# │ 8   │ -0.4417   │ -0.518274       │ -0.498788        │
# │ 9   │ 0.16319   │ 0.512553        │ 0.487566         │
# │ 10  │ 0.0929482 │ 0.0             │ 0.0              │
# No debiasing:
#     Iter = 255
#     Time = 1.8746209144592285
# Yes debiasing:
#     Iter = 10
#     Time = 0.09474802017211914
#
#
# running the 32 th model
# n, p = 774, 3096
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β    │ est_β_no_debias │ est_β_yes_debias │
# │     │ Float64   │ Float64         │ Float64          │
# ├─────┼───────────┼─────────────────┼──────────────────┤
# │ 1   │ -1.04572  │ -1.06443        │ -1.05953         │
# │ 2   │ 0.729268  │ 0.952343        │ 0.924027         │
# │ 3   │ 0.645073  │ 0.857517        │ 0.86037          │
# │ 4   │ 0.586387  │ 0.584337        │ 0.544491         │
# │ 5   │ -0.538833 │ -0.761164       │ -0.735757        │
# │ 6   │ 0.480428  │ 0.495484        │ 0.476717         │
# │ 7   │ -0.460102 │ -0.654736       │ -0.669601        │
# │ 8   │ -0.286859 │ 0.0             │ 0.0              │
# │ 9   │ 0.144698  │ 0.0             │ 0.0              │
# │ 10  │ 0.0254425 │ 0.0             │ 0.0              │
# No debiasing:
#     Iter = 20
#     Time = 0.2930748462677002
# Yes debiasing:
#     Iter = 9
#     Time = 0.16588497161865234
#
#
# running the 33 th model
# n, p = 1268, 12680
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β     │ est_β_no_debias │ est_β_yes_debias │
# │     │ Float64    │ Float64         │ Float64          │
# ├─────┼────────────┼─────────────────┼──────────────────┤
# │ 1   │ 1.96455    │ 2.1165          │ 2.12863          │
# │ 2   │ 1.48116    │ 1.65467         │ 1.65153          │
# │ 3   │ -1.20295   │ 0.0             │ 0.0              │
# │ 4   │ -1.12879   │ -1.25386        │ -1.25948         │
# │ 5   │ 0.798045   │ 0.801253        │ 0.781307         │
# │ 6   │ 0.753133   │ 0.849943        │ 0.848269         │
# │ 7   │ -0.731029  │ -0.833037       │ -0.841432        │
# │ 8   │ -0.696871  │ -0.778158       │ -0.793444        │
# │ 9   │ 0.637752   │ 0.6278          │ 0.631961         │
# │ 10  │ 0.00555743 │ 0.0             │ 0.0              │
# No debiasing:
#     Iter = 34
#     Time = 3.350360155105591
# Yes debiasing:
#     Iter = 13
#     Time = 1.377410888671875
#
#
# running the 34 th model
# n, p = 865, 5190
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β     │ est_β_no_debias │ est_β_yes_debias │
# │     │ Float64    │ Float64         │ Float64          │
# ├─────┼────────────┼─────────────────┼──────────────────┤
# │ 1   │ -1.36638   │ -1.76482        │ -1.76779         │
# │ 2   │ -1.28805   │ -1.5771         │ -1.5794          │
# │ 3   │ 1.20994    │ 1.64998         │ 1.65387          │
# │ 4   │ -0.826115  │ -1.05556        │ -1.05691         │
# │ 5   │ 0.660475   │ 0.784246        │ 0.785281         │
# │ 6   │ -0.539825  │ -0.521786       │ -0.522484        │
# │ 7   │ 0.3733     │ 0.511948        │ 0.512513         │
# │ 8   │ 0.358102   │ 0.0             │ 0.0              │
# │ 9   │ -0.172833  │ 0.0             │ 0.0              │
# │ 10  │ -0.0904992 │ 0.0             │ 0.0              │
# No debiasing:
#     Iter = 40
#     Time = 1.0684330463409424
# Yes debiasing:
#     Iter = 11
#     Time = 0.3302490711212158
#
#
# running the 35 th model
# n, p = 1076, 10760
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β      │ est_β_no_debias │ est_β_yes_debias │
# │     │ Float64     │ Float64         │ Float64          │
# ├─────┼─────────────┼─────────────────┼──────────────────┤
# │ 1   │ 0.697893    │ 0.563826        │ 0.572328         │
# │ 2   │ -0.683696   │ -0.625618       │ -0.635591        │
# │ 3   │ 0.54638     │ 0.468544        │ 0.474081         │
# │ 4   │ -0.537397   │ -0.437949       │ -0.448915        │
# │ 5   │ 0.40769     │ 0.345836        │ 0.334604         │
# │ 6   │ -0.301432   │ -0.307209       │ -0.310973        │
# │ 7   │ 0.213959    │ 0.0             │ 0.0              │
# │ 8   │ -0.0917621  │ 0.0             │ 0.0              │
# │ 9   │ -0.0146049  │ 0.0             │ 0.0              │
# │ 10  │ 0.000304506 │ 0.0             │ 0.0              │
# No debiasing:
#     Iter = 14
#     Time = 1.043382167816162
# Yes debiasing:
#     Iter = 14
#     Time = 1.0608868598937988
#
#
# running the 36 th model
# n, p = 919, 919
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β    │ est_β_no_debias │ est_β_yes_debias │
# │     │ Float64   │ Float64         │ Float64          │
# ├─────┼───────────┼─────────────────┼──────────────────┤
# │ 1   │ 1.47738   │ 1.68759         │ 1.67543          │
# │ 2   │ 1.21121   │ 1.47885         │ 1.49305          │
# │ 3   │ -1.15576  │ -1.52641        │ -1.502           │
# │ 4   │ -1.06341  │ -1.03196        │ -1.0397          │
# │ 5   │ -0.868173 │ -0.838754       │ -0.853881        │
# │ 6   │ -0.74179  │ -0.621054       │ -0.618736        │
# │ 7   │ 0.492842  │ 0.442511        │ 0.456475         │
# │ 8   │ 0.420722  │ 0.411349        │ 0.437386         │
# │ 9   │ -0.238525 │ 0.0             │ 0.0              │
# │ 10  │ 0.0512048 │ 0.0             │ 0.0              │
# No debiasing:
#     Iter = 31
#     Time = 0.16792583465576172
# Yes debiasing:
#     Iter = 17
#     Time = 0.1083669662475586
#
#
# running the 37 th model
# n, p = 1541, 7705
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β     │ est_β_no_debias │ est_β_yes_debias │
# │     │ Float64    │ Float64         │ Float64          │
# ├─────┼────────────┼─────────────────┼──────────────────┤
# │ 1   │ -1.8186    │ -1.89241        │ -1.8913          │
# │ 2   │ -1.74357   │ -1.56176        │ -1.58437         │
# │ 3   │ -1.32913   │ -1.16963        │ -1.17998         │
# │ 4   │ -0.895326  │ -0.906733       │ -0.91837         │
# │ 5   │ -0.55046   │ -0.648162       │ -0.658015        │
# │ 6   │ -0.520356  │ -0.428011       │ -0.42067         │
# │ 7   │ 0.353319   │ 0.425465        │ 0.421165         │
# │ 8   │ 0.233439   │ 0.0             │ 0.0              │
# │ 9   │ -0.1656    │ 0.0             │ 0.0              │
# │ 10  │ -0.0574888 │ 0.0             │ 0.0              │
# No debiasing:
#     Iter = 39
#     Time = 2.9480180740356445
# Yes debiasing:
#     Iter = 14
#     Time = 1.0999269485473633
#
#
# running the 38 th model
# n, p = 996, 7968
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β    │ est_β_no_debias │ est_β_yes_debias │
# │     │ Float64   │ Float64         │ Float64          │
# ├─────┼───────────┼─────────────────┼──────────────────┤
# │ 1   │ -1.64484  │ -1.8678         │ -1.86401         │
# │ 2   │ -0.910135 │ -1.02036        │ -1.03538         │
# │ 3   │ -0.883556 │ -0.932119       │ -0.943038        │
# │ 4   │ 0.845211  │ 0.950329        │ 0.968747         │
# │ 5   │ -0.665853 │ -0.825604       │ -0.819101        │
# │ 6   │ 0.330145  │ 0.0             │ 0.0              │
# │ 7   │ -0.208036 │ 0.0             │ 0.0              │
# │ 8   │ 0.135091  │ 0.0             │ 0.0              │
# │ 9   │ 0.111289  │ 0.0             │ 0.0              │
# │ 10  │ 0.0950582 │ 0.0             │ 0.0              │
# No debiasing:
#     Iter = 25
#     Time = 1.2487719058990479
# Yes debiasing:
#     Iter = 10
#     Time = 0.5634360313415527
#
#
# running the 39 th model
# n, p = 863, 4315
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β    │ est_β_no_debias │ est_β_yes_debias │
# │     │ Float64   │ Float64         │ Float64          │
# ├─────┼───────────┼─────────────────┼──────────────────┤
# │ 1   │ -2.04993  │ -2.23387        │ -2.23689         │
# │ 2   │ 2.03206   │ 1.9991          │ 2.00126          │
# │ 3   │ 1.50638   │ 1.40328         │ 1.40521          │
# │ 4   │ -1.10322  │ -1.18831        │ -1.18977         │
# │ 5   │ 0.551054  │ 0.697622        │ 0.698615         │
# │ 6   │ 0.388669  │ 0.475747        │ 0.476228         │
# │ 7   │ -0.299377 │ 0.0             │ 0.0              │
# │ 8   │ 0.270592  │ 0.0             │ 0.0              │
# │ 9   │ -0.180989 │ 0.0             │ 0.0              │
# │ 10  │ 0.0159316 │ 0.0             │ 0.0              │
# No debiasing:
#     Iter = 54
#     Time = 1.2000670433044434
# Yes debiasing:
#     Iter = 20
#     Time = 0.4947659969329834
#
#
# running the 40 th model
# n, p = 1989, 1989
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β     │ est_β_no_debias │ est_β_yes_debias │
# │     │ Float64    │ Float64         │ Float64          │
# ├─────┼────────────┼─────────────────┼──────────────────┤
# │ 1   │ -1.24413   │ -1.19176        │ -1.19264         │
# │ 2   │ -1.19976   │ -1.22705        │ -1.22799         │
# │ 3   │ -1.1653    │ -1.21681        │ -1.21981         │
# │ 4   │ 1.08421    │ 1.01378         │ 1.01466          │
# │ 5   │ 1.00762    │ 1.06348         │ 1.06435          │
# │ 6   │ -0.966104  │ -0.942851       │ -0.943581        │
# │ 7   │ -0.686028  │ -0.712187       │ -0.712771        │
# │ 8   │ -0.63031   │ -0.662824       │ -0.663341        │
# │ 9   │ -0.167433  │ 0.0             │ 0.0              │
# │ 10  │ -0.0886843 │ 0.0             │ 0.0              │
# No debiasing:
#     Iter = 35
#     Time = 0.8146779537200928
# Yes debiasing:
#     Iter = 10
#     Time = 0.27475500106811523
#
#
# running the 41 th model
# n, p = 1697, 6788
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β     │ est_β_no_debias │ est_β_yes_debias │
# │     │ Float64    │ Float64         │ Float64          │
# ├─────┼────────────┼─────────────────┼──────────────────┤
# │ 1   │ -1.23062   │ -1.36618        │ -1.36716         │
# │ 2   │ 1.21401    │ 1.3312          │ 1.33215          │
# │ 3   │ -0.901029  │ -1.03399        │ -1.03469         │
# │ 4   │ 0.865047   │ 0.935122        │ 0.935892         │
# │ 5   │ -0.863329  │ -0.938137       │ -0.938885        │
# │ 6   │ -0.840027  │ -0.847632       │ -0.84823         │
# │ 7   │ 0.494508   │ 0.503971        │ 0.504336         │
# │ 8   │ 0.424137   │ 0.447592        │ 0.44804          │
# │ 9   │ 0.299613   │ 0.283817        │ 0.284073         │
# │ 10  │ -0.0533707 │ 0.0             │ 0.0              │
# No debiasing:
#     Iter = 21
#     Time = 1.4772839546203613
# Yes debiasing:
#     Iter = 15
#     Time = 1.0988669395446777
#
#
# running the 42 th model
# n, p = 1499, 4497
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β     │ est_β_no_debias │ est_β_yes_debias │
# │     │ Float64    │ Float64         │ Float64          │
# ├─────┼────────────┼─────────────────┼──────────────────┤
# │ 1   │ 1.66538    │ 1.82156         │ 1.82371          │
# │ 2   │ -1.52248   │ -1.81137        │ -1.81346         │
# │ 3   │ 1.50982    │ 1.56098         │ 1.5628           │
# │ 4   │ -1.40243   │ -1.58191        │ -1.58393         │
# │ 5   │ -0.602872  │ -0.514447       │ -0.515064        │
# │ 6   │ 0.435913   │ 0.655955        │ 0.656766         │
# │ 7   │ 0.396424   │ 0.347256        │ 0.347643         │
# │ 8   │ -0.348129  │ -0.391104       │ -0.391595        │
# │ 9   │ 0.0362675  │ 0.0             │ 0.0              │
# │ 10  │ -0.0228135 │ 0.0             │ 0.0              │
# No debiasing:
#     Iter = 42
#     Time = 1.7675361633300781
# Yes debiasing:
#     Iter = 13
#     Time = 0.6446940898895264
#
#
# running the 43 th model
# n, p = 1689, 11823
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β     │ est_β_no_debias │ est_β_yes_debias │
# │     │ Float64    │ Float64         │ Float64          │
# ├─────┼────────────┼─────────────────┼──────────────────┤
# │ 1   │ -1.92764   │ -1.8238         │ -1.82571         │
# │ 2   │ -1.80841   │ -1.808          │ -1.80997         │
# │ 3   │ -1.05786   │ -1.05934        │ -1.06056         │
# │ 4   │ -1.0152    │ -0.952535       │ -0.953638        │
# │ 5   │ -0.467475  │ -0.55992        │ -0.560552        │
# │ 6   │ 0.355475   │ 0.402493        │ 0.403031         │
# │ 7   │ -0.33199   │ 0.0             │ 0.0              │
# │ 8   │ -0.0477749 │ 0.0             │ 0.0              │
# │ 9   │ 0.0271635  │ 0.0             │ 0.0              │
# │ 10  │ 0.00278986 │ 0.0             │ 0.0              │
# No debiasing:
#     Iter = 34
#     Time = 4.3403661251068115
# Yes debiasing:
#     Iter = 15
#     Time = 1.9203381538391113
#
#
# running the 44 th model
# n, p = 1306, 1306
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β    │ est_β_no_debias │ est_β_yes_debias │
# │     │ Float64   │ Float64         │ Float64          │
# ├─────┼───────────┼─────────────────┼──────────────────┤
# │ 1   │ -1.55738  │ -1.61772        │ -1.61885         │
# │ 2   │ 1.30147   │ 1.35414         │ 1.35509          │
# │ 3   │ -1.2387   │ -1.39202        │ -1.39319         │
# │ 4   │ 0.756626  │ 0.77689         │ 0.77747          │
# │ 5   │ -0.459595 │ -0.419564       │ -0.419895        │
# │ 6   │ 0.295772  │ 0.423844        │ 0.424176         │
# │ 7   │ 0.285411  │ 0.0             │ 0.0              │
# │ 8   │ -0.268956 │ 0.0             │ 0.0              │
# │ 9   │ -0.199421 │ -0.292686       │ -0.292902        │
# │ 10  │ 0.127883  │ 0.0             │ 0.0              │
# No debiasing:
#     Iter = 22
#     Time = 0.2475419044494629
# Yes debiasing:
#     Iter = 17
#     Time = 0.22472000122070312
#
#
# running the 45 th model
# n, p = 677, 4739
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β     │ est_β_no_debias │ est_β_yes_debias │
# │     │ Float64    │ Float64         │ Float64          │
# ├─────┼────────────┼─────────────────┼──────────────────┤
# │ 1   │ -1.77862   │ -2.12504        │ -2.13207         │
# │ 2   │ -1.59507   │ -1.64022        │ -1.62531         │
# │ 3   │ 0.836027   │ 0.872409        │ 0.860353         │
# │ 4   │ -0.780163  │ -0.840591       │ -0.738577        │
# │ 5   │ -0.69742   │ -0.910291       │ -0.903169        │
# │ 6   │ -0.640154  │ -0.631308       │ -0.671024        │
# │ 7   │ 0.625169   │ 0.788341        │ 0.773164         │
# │ 8   │ -0.338887  │ 0.0             │ 0.0              │
# │ 9   │ -0.158483  │ 0.0             │ 0.0              │
# │ 10  │ -0.0963733 │ 0.0             │ 0.0              │
# No debiasing:
#     Iter = 35
#     Time = 0.6957590579986572
# Yes debiasing:
#     Iter = 13
#     Time = 0.28333282470703125
#
#
# running the 46 th model
# n, p = 1866, 5598
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β    │ est_β_no_debias │ est_β_yes_debias │
# │     │ Float64   │ Float64         │ Float64          │
# ├─────┼───────────┼─────────────────┼──────────────────┤
# │ 1   │ 1.71395   │ 1.6354          │ 1.63714          │
# │ 2   │ -1.60149  │ -1.58289        │ -1.58456         │
# │ 3   │ -1.43171  │ -1.37288        │ -1.37436         │
# │ 4   │ 1.05589   │ 0.966849        │ 0.967948         │
# │ 5   │ -0.931018 │ -0.686753       │ -0.687465        │
# │ 6   │ 0.871661  │ 0.840494        │ 0.841381         │
# │ 7   │ 0.795234  │ 0.664657        │ 0.665442         │
# │ 8   │ 0.691058  │ 0.600477        │ 0.601125         │
# │ 9   │ 0.545939  │ 0.482093        │ 0.482608         │
# │ 10  │ 0.27279   │ 0.0             │ 0.0              │
# No debiasing:
#     Iter = 38
#     Time = 2.472499132156372
# Yes debiasing:
#     Iter = 12
#     Time = 0.8450989723205566
#
#
# running the 47 th model
# n, p = 1168, 7008
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β    │ est_β_no_debias │ est_β_yes_debias │
# │     │ Float64   │ Float64         │ Float64          │
# ├─────┼───────────┼─────────────────┼──────────────────┤
# │ 1   │ -1.23342  │ -1.3805         │ -1.38317         │
# │ 2   │ 0.581907  │ 0.707439        │ 0.703651         │
# │ 3   │ 0.475995  │ 0.56042         │ 0.566566         │
# │ 4   │ -0.470945 │ -0.428949       │ -0.43456         │
# │ 5   │ 0.450533  │ 0.577706        │ 0.584391         │
# │ 6   │ 0.350398  │ 0.365946        │ 0.385075         │
# │ 7   │ 0.266492  │ 0.414855        │ 0.425311         │
# │ 8   │ 0.175129  │ 0.0             │ 0.0              │
# │ 9   │ 0.0507207 │ 0.0             │ 0.0              │
# │ 10  │ 0.0294983 │ 0.0             │ 0.0              │
# No debiasing:
#     Iter = 15
#     Time = 0.7696528434753418
# Yes debiasing:
#     Iter = 15
#     Time = 0.8013930320739746
#
#
# running the 48 th model
# n, p = 924, 1848
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β     │ est_β_no_debias │ est_β_yes_debias │
# │     │ Float64    │ Float64         │ Float64          │
# ├─────┼────────────┼─────────────────┼──────────────────┤
# │ 1   │ -1.60659   │ -1.94602        │ -1.94508         │
# │ 2   │ 1.60647    │ 1.95507         │ 1.96055          │
# │ 3   │ 1.58164    │ 1.77754         │ 1.76876          │
# │ 4   │ -1.48577   │ -1.72924        │ -1.73498         │
# │ 5   │ -0.785071  │ -0.889986       │ -0.864686        │
# │ 6   │ -0.341992  │ 0.0             │ 0.0              │
# │ 7   │ 0.286507   │ 0.364223        │ 0.371733         │
# │ 8   │ 0.263208   │ 0.0             │ 0.0              │
# │ 9   │ 0.0241175  │ 0.0             │ 0.0              │
# │ 10  │ -0.0121702 │ 0.0             │ 0.0              │
# No debiasing:
#     Iter = 41
#     Time = 0.47640419006347656
# Yes debiasing:
#     Iter = 11
#     Time = 0.15160799026489258
#
#
# running the 49 th model
# n, p = 1806, 9030
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β    │ est_β_no_debias │ est_β_yes_debias │
# │     │ Float64   │ Float64         │ Float64          │
# ├─────┼───────────┼─────────────────┼──────────────────┤
# │ 1   │ -1.69735  │ -1.70972        │ -1.72544         │
# │ 2   │ -1.60693  │ -1.64748        │ -1.65729         │
# │ 3   │ -0.830909 │ -0.77917        │ -0.790768        │
# │ 4   │ 0.817657  │ 0.903069        │ 0.903873         │
# │ 5   │ 0.786708  │ 0.782162        │ 0.782768         │
# │ 6   │ -0.715444 │ -0.833509       │ -0.843441        │
# │ 7   │ 0.449139  │ 0.540396        │ 0.535626         │
# │ 8   │ 0.330361  │ 0.301898        │ 0.326            │
# │ 9   │ 0.240166  │ 0.0             │ 0.0              │
# │ 10  │ -0.176833 │ 0.0             │ 0.0              │
# No debiasing:
#     Iter = 37
#     Time = 3.505635976791382
# Yes debiasing:
#     Iter = 13
#     Time = 1.3928580284118652
#
#
# running the 50 th model
# n, p = 1606, 9636
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β    │ est_β_no_debias │ est_β_yes_debias │
# │     │ Float64   │ Float64         │ Float64          │
# ├─────┼───────────┼─────────────────┼──────────────────┤
# │ 1   │ 2.00329   │ 2.12416         │ 2.12664          │
# │ 2   │ 1.84887   │ 1.97361         │ 1.97588          │
# │ 3   │ -1.74421  │ -1.77049        │ -1.77294         │
# │ 4   │ -1.19396  │ -1.20252        │ -1.20414         │
# │ 5   │ -0.576945 │ -0.668214       │ -0.669206        │
# │ 6   │ -0.466073 │ -0.478464       │ -0.479083        │
# │ 7   │ 0.364745  │ 0.510584        │ 0.511161         │
# │ 8   │ -0.356282 │ -0.433434       │ -0.433942        │
# │ 9   │ 0.230422  │ 0.0             │ 0.0              │
# │ 10  │ 0.099691  │ 0.324869        │ 0.325159         │
# No debiasing:
#     Iter = 42
#     Time = 3.9361939430236816
# Yes debiasing:
#     Iter = 13
#     Time = 1.3259670734405518
#
#
# With debiasing, found 378 predictors out of 500
# With debiasing, average time was 0.8233720922470092
# Without debiasing, found 376 predictors out of 500
# Without debiasing, average time was 4.04432548046112

# %% [markdown]
# # How does IHT compare to LASSO?

# %%
using Revise
using GLMNet #julia wrapper for GLMNet package in R, which calls fortran
using GLM
using MendelIHT
using SnpArrays
using DataFrames
using Distributions
using StatsFuns: logistic
using Random
using LinearAlgebra
using DelimitedFiles

# %%
#verify multiple threads are enabled
Threads.nthreads()
# Out:
# 1

# %%
function iht_lasso_logistic(n :: Int64, p :: Int64, sim :: Int64)
    #define maf and true model size
    k = 10
    
    #set random seed
    Random.seed!(1111)

    #construct snpmatrix, covariate files, and true model b
    x, maf = simulate_random_snparray(n, p)
    xbm = SnpBitMatrix{Float64}(x, model=ADDITIVE_MODEL, center=true, scale=true); 
    z           = ones(n, 1)                   # non-genetic covariates, just the intercept
    true_b      = zeros(p)                     # model vector
    true_b[1:k] = rand(Normal(0, 0.25), k)     # k true response
    shuffle!(true_b)                           # Shuffle the entries
    correct_position = findall(x -> x != 0, true_b) # keep track of what the true entries are

    #simulate bernoulli data
    y_temp = xbm * true_b
    prob = logistic.(y_temp) #inverse logit link
    y = [rand(Bernoulli(x)) for x in prob]
    y = Float64.(y)

    #compute logistic IHT result
    path = collect(1:20)
    num_folds = 5
    folds = rand(1:num_folds, size(x, 1))
    k_est_iht = cv_iht(x, z, y, 1, path, folds, num_folds, use_maf=false, glm="logistic", debias=true)
    iht_result = L0_logistic_reg(x, z, y, 1, k_est_iht, glm = "logistic", debias=true, convg=false, show_info=false, init=false)

    #compute poisson lasso result
    x_float = [convert(Matrix{Float64}, x, center=true, scale=true) z]
    y_glmnet = [1 .- y y]
    cv = glmnetcv(x_float, y_glmnet, Binomial(), pmax=20, nfolds=5, folds=folds)
    best = argmin(cv.meanloss)
    lasso_result = cv.path.betas[:, best]
    k_est_lasso = length(findall(!iszero, lasso_result))
    
    #compute regular poisson regression using only true predictors
    x_true = [x_float[:, correct_position] z]
    regular_result = glm(x_true, y, Poisson(), LogLink())
    regular_result = regular_result.pp.beta0
    
    #check result
    IHT_model = iht_result.beta[correct_position]
    lasso_model = lasso_result[correct_position]
    true_model = true_b[correct_position]
    compare_model = DataFrame(
        true_β  = true_model, 
        iht_β   = IHT_model,
        lasso_β = lasso_model,
        regular_β = regular_result[1:10])
    @show compare_model

    #compute summary statistics
    lasso_num_correct_predictors = length(findall(!iszero, lasso_model))
    lasso_false_positives = k_est_lasso - lasso_num_correct_predictors
    lasso_false_negatives = k - lasso_num_correct_predictors
    iht_num_correct_predictors = length(findall(!iszero, IHT_model))
    iht_false_positives = k_est_iht - iht_num_correct_predictors
    iht_false_negatives = k - iht_num_correct_predictors
    println("IHT cv found $iht_false_positives" * " false positives and $iht_false_negatives" * " false negatives")
    println("lasso cv found $lasso_false_positives" * " false positives and $lasso_false_negatives" * " false negatives\n\n")

    #write y to file to view distribution later
    writedlm("./IHT_poisson_simulations_mean/data_simulation_$sim.txt", y)

    return lasso_num_correct_predictors, lasso_false_positives, lasso_false_negatives, iht_num_correct_predictors, iht_false_positives, iht_false_negatives
end
