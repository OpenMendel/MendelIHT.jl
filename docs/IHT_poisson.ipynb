# %% [markdown]
# # Various illustrations on IHT-poisson fitting

# %%
using Revise
using IHT
using SnpArrays
using DataFrames
using Distributions
using BenchmarkTools
using Random
using LinearAlgebra
using StatsFuns: logistic
# Out:
# ┌ Info: Recompiling stale cache file /Users/biona001/.julia/compiled/v1.0/IHT/eaqWB.ji for IHT [921c7187-1484-5754-b919-5d3ed9ac03c4]
# └ @ Base loading.jl:1190
# ┌ Info: Loading DataFrames support into Gadfly.jl
# └ @ Gadfly /Users/biona001/.julia/packages/Gadfly/09PWZ/src/mapping.jl:228

# %% [markdown]
# # Poisson regression
#
# First we simulate 50 different SNP matrices, with 50 different $\beta \sim N(0, 0.25)$, to examine reconstruction behavior. Overall, IHT struggles to find effect sizes $< 0.1$ but performs well for larger values.

# %%
#some function that runs poisson regression on different SNP matrices
function run_poisson(n :: Int64, p :: Int64, k :: Int64)    
    #set random seed
    Random.seed!(1111)

    #construct snpmatrix, covariate files, and true model b
    x, maf = simulate_random_snparray(n, p)
    xbm = SnpBitMatrix{Float64}(x, model=ADDITIVE_MODEL, center=true, scale=true); 
    z = ones(n, 1) # non-genetic covariates, just the intercept
    true_b = zeros(p)
    true_b[1:k] = rand(Normal(0, 0.25), k)
    shuffle!(true_b)
    correct_position = findall(x -> x != 0, true_b)

    # Simulate poisson data
    y_temp = xbm * true_b
    λ = exp.(y_temp) #inverse log link
    y = [rand(Poisson(x)) for x in λ]
    y = Float64.(y)

    #compute poisson IHT result
    result = L0_poisson_reg(x, z, y, 1, k, glm = "poisson", debias=false, convg=false, show_info=false)

    #check result
    estimated_models = result.beta[correct_position]
    true_model = true_b[correct_position]
    compare_model = DataFrame(
        correct_position = correct_position, 
        true_β           = true_model, 
        estimated_β      = estimated_models)
    
    #display results
    @show compare_model
    println("Total iteration number was " * string(result.iter))
    println("Total time was " * string(result.time))
    println("median of y = " * string(median(y)))
    println("maximum of y = " * string(maximum(y)))
    println("minimum of y = " * string(minimum(y)))
    println("skewness of y = " * string(skewness(y)))
    println("kurtosis of y = " * string(kurtosis(y)))
    println("mean of y = " * string(mean(y)))
    println("variance of y = " * string(var(y)))
    println("var / mean = " * string(var(y) / mean(y)) * "\n\n")
end
# Out:
# run_poisson (generic function with 1 method)

# %%
k = 10
for i = 1:50
    println("running the $i th model")
    n = rand(500:2000) 
    p = rand(1:10)n
    println("n, p = " * string(n) * ", " * string(p))
    run_poisson(n, p, k)
end
# Out:
# running the 1 th model
# n, p = 1828, 7312
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β     │ estimated_β │
# │     │ Int64            │ Float64    │ Float64     │
# ├─────┼──────────────────┼────────────┼─────────────┤
# │ 1   │ 363              │ 0.238954   │ 0.228253    │
# │ 2   │ 437              │ -0.0727749 │ -0.10205    │
# │ 3   │ 516              │ -0.0730439 │ 0.0         │
# │ 4   │ 1832             │ -0.183891  │ -0.141271   │
# │ 5   │ 2004             │ -0.137655  │ -0.106951   │
# │ 6   │ 3746             │ 0.206968   │ 0.194926    │
# │ 7   │ 4181             │ 0.355171   │ 0.354624    │
# │ 8   │ 5979             │ 0.138518   │ 0.147283    │
# │ 9   │ 6338             │ 0.0290228  │ 0.0         │
# │ 10  │ 6599             │ -0.449113  │ -0.485518   │
# Total iteration number was 11
# Total time was 0.9138290882110596
# median of y = 1.0
# maximum of y = 14.0
# minimum of y = 0.0
# skewness of y = 1.9510798615215827
# kurtosis of y = 6.479998361865022
# mean of y = 1.298140043763676
# variance of y = 2.422831787711437
# var / mean = 1.8663870661342212
#
#
# running the 2 th model
# n, p = 1808, 1808
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 408              │ 0.285962  │ 0.275694    │
# │ 2   │ 564              │ -0.455625 │ -0.448346   │
# │ 3   │ 1214             │ -0.12581  │ -0.123426   │
# │ 4   │ 1219             │ 0.481171  │ 0.473692    │
# │ 5   │ 1277             │ -0.217859 │ -0.195452   │
# │ 6   │ 1403             │ 0.0509612 │ 0.0         │
# │ 7   │ 1520             │ -0.170035 │ -0.147856   │
# │ 8   │ 1545             │ 0.094656  │ 0.118273    │
# │ 9   │ 1647             │ 0.154182  │ 0.153633    │
# │ 10  │ 1748             │ 0.130591  │ 0.108906    │
# Total iteration number was 12
# Total time was 0.24337506294250488
# median of y = 1.0
# maximum of y = 14.0
# minimum of y = 0.0
# skewness of y = 2.253994230476876
# kurtosis of y = 7.987275422630468
# mean of y = 1.3473451327433628
# variance of y = 2.8698767330587547
# var / mean = 2.1300234537644616
#
#
# running the 3 th model
# n, p = 1606, 3212
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β     │ estimated_β │
# │     │ Int64            │ Float64    │ Float64     │
# ├─────┼──────────────────┼────────────┼─────────────┤
# │ 1   │ 127              │ -0.0603642 │ 0.0         │
# │ 2   │ 333              │ 0.403012   │ 0.425787    │
# │ 3   │ 428              │ -0.111309  │ -0.119032   │
# │ 4   │ 554              │ -0.246383  │ -0.285335   │
# │ 5   │ 1128             │ -0.1678    │ 0.0         │
# │ 6   │ 1223             │ 0.0638864  │ 0.0         │
# │ 7   │ 1238             │ -0.0346098 │ 0.0         │
# │ 8   │ 1795             │ 0.119081   │ 0.149824    │
# │ 9   │ 2303             │ -0.471065  │ -0.512652   │
# │ 10  │ 2560             │ 0.0792605  │ 0.0         │
# Total iteration number was 28
# Total time was 0.8339648246765137
# median of y = 1.0
# maximum of y = 12.0
# minimum of y = 0.0
# skewness of y = 1.9391916678236558
# kurtosis of y = 5.8795810393189925
# mean of y = 1.3082191780821917
# variance of y = 2.503695642896769
# var / mean = 1.91381970608863
#
#
# running the 4 th model
# n, p = 1687, 3374
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β     │ estimated_β │
# │     │ Int64            │ Float64    │ Float64     │
# ├─────┼──────────────────┼────────────┼─────────────┤
# │ 1   │ 34               │ -0.08426   │ 0.0         │
# │ 2   │ 284              │ -0.106774  │ 0.0         │
# │ 3   │ 1269             │ -0.336869  │ -0.298023   │
# │ 4   │ 1528             │ 0.136357   │ 0.141059    │
# │ 5   │ 1937             │ 0.104092   │ 0.125179    │
# │ 6   │ 1959             │ -0.445335  │ -0.436836   │
# │ 7   │ 2204             │ -0.0219089 │ 0.0         │
# │ 8   │ 2767             │ 0.323524   │ 0.348073    │
# │ 9   │ 3106             │ 0.0965478  │ 0.121082    │
# │ 10  │ 3136             │ -0.545485  │ -0.559637   │
# Total iteration number was 25
# Total time was 0.8160789012908936
# median of y = 1.0
# maximum of y = 15.0
# minimum of y = 0.0
# skewness of y = 2.095031726248828
# kurtosis of y = 7.019949222320333
# mean of y = 1.4309425014819206
# variance of y = 2.990334994912598
# var / mean = 2.0897660051439737
#
#
# running the 5 th model
# n, p = 528, 528
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 14               │ 0.200652  │ 0.193882    │
# │ 2   │ 70               │ -0.492616 │ -0.538185   │
# │ 3   │ 82               │ 0.337792  │ 0.283937    │
# │ 4   │ 124              │ 0.297951  │ 0.305538    │
# │ 5   │ 151              │ 0.151602  │ 0.177416    │
# │ 6   │ 397              │ 0.277876  │ 0.219194    │
# │ 7   │ 417              │ 0.12616   │ 0.0         │
# │ 8   │ 421              │ 0.195564  │ 0.173814    │
# │ 9   │ 424              │ -0.442421 │ -0.405129   │
# │ 10  │ 444              │ 0.153968  │ 0.0         │
# Total iteration number was 14
# Total time was 0.0278170108795166
# median of y = 1.0
# maximum of y = 10.0
# minimum of y = 0.0
# skewness of y = 1.7373954330230215
# kurtosis of y = 3.633945019948933
# mean of y = 1.4715909090909092
# variance of y = 3.141506382611696
# var / mean = 2.134768815983237
#
#
# running the 6 th model
# n, p = 687, 4809
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 417              │ -0.283243 │ -0.257468   │
# │ 2   │ 653              │ -0.909452 │ -0.873994   │
# │ 3   │ 2425             │ 0.122938  │ 0.0         │
# │ 4   │ 2878             │ -0.490447 │ -0.499283   │
# │ 5   │ 2976             │ 0.0871257 │ 0.0         │
# │ 6   │ 2986             │ 0.113492  │ 0.11203     │
# │ 7   │ 3450             │ -0.178168 │ -0.202553   │
# │ 8   │ 3834             │ -0.271441 │ -0.243444   │
# │ 9   │ 3928             │ -0.578791 │ -0.648779   │
# │ 10  │ 4184             │ 0.0834609 │ 0.143079    │
# Total iteration number was 26
# Total time was 0.5200419425964355
# median of y = 1.0
# maximum of y = 15.0
# minimum of y = 0.0
# skewness of y = 1.6563616958855398
# kurtosis of y = 2.8843103845151985
# mean of y = 1.9883551673944686
# variance of y = 6.5479691564710745
# var / mean = 3.293158719250094
#
#
# running the 7 th model
# n, p = 1906, 13342
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β     │ estimated_β │
# │     │ Int64            │ Float64    │ Float64     │
# ├─────┼──────────────────┼────────────┼─────────────┤
# │ 1   │ 10               │ -0.0507271 │ 0.0         │
# │ 2   │ 31               │ 0.00852992 │ 0.0         │
# │ 3   │ 1611             │ 0.0920723  │ 0.0         │
# │ 4   │ 1957             │ 0.00119904 │ 0.0         │
# │ 5   │ 4574             │ -0.437011  │ -0.393495   │
# │ 6   │ 7507             │ -0.0500933 │ 0.0         │
# │ 7   │ 8882             │ -0.13858   │ -0.177315   │
# │ 8   │ 10141            │ -0.225073  │ -0.268604   │
# │ 9   │ 10343            │ -0.221649  │ -0.173745   │
# │ 10  │ 11211            │ 0.189116   │ 0.17608     │
# Total iteration number was 35
# Total time was 4.93449592590332
# median of y = 1.0
# maximum of y = 7.0
# minimum of y = 0.0
# skewness of y = 1.3125331749258249
# kurtosis of y = 1.984517720573992
# mean of y = 1.1290661070304302
# variance of y = 1.482545794052763
# var / mean = 1.3130726224277725
#
#
# running the 8 th model
# n, p = 973, 6811
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β       │ estimated_β │
# │     │ Int64            │ Float64      │ Float64     │
# ├─────┼──────────────────┼──────────────┼─────────────┤
# │ 1   │ 747              │ -0.0894819   │ 0.0         │
# │ 2   │ 1097             │ 0.193205     │ 0.229291    │
# │ 3   │ 1715             │ 0.247686     │ 0.258985    │
# │ 4   │ 2188             │ 0.0944468    │ 0.0         │
# │ 5   │ 2276             │ -0.000403725 │ 0.0         │
# │ 6   │ 2783             │ 0.120496     │ 0.0999247   │
# │ 7   │ 4193             │ 0.255825     │ 0.209512    │
# │ 8   │ 5600             │ -0.633169    │ -0.578618   │
# │ 9   │ 6128             │ -0.335839    │ -0.378501   │
# │ 10  │ 6757             │ 0.359284     │ 0.380644    │
# Total iteration number was 23
# Total time was 0.8829798698425293
# median of y = 1.0
# maximum of y = 10.0
# minimum of y = 0.0
# skewness of y = 1.5314722365330606
# kurtosis of y = 2.489543120523215
# mean of y = 1.4429599177800616
# variance of y = 2.802555838926744
# var / mean = 1.9422270878032208
#
#
# running the 9 th model
# n, p = 933, 933
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β     │ estimated_β │
# │     │ Int64            │ Float64    │ Float64     │
# ├─────┼──────────────────┼────────────┼─────────────┤
# │ 1   │ 11               │ 0.548355   │ 0.573227    │
# │ 2   │ 74               │ -0.093659  │ 0.0         │
# │ 3   │ 79               │ 0.21211    │ 0.244027    │
# │ 4   │ 250              │ -0.192813  │ -0.19294    │
# │ 5   │ 255              │ -0.320763  │ -0.290436   │
# │ 6   │ 304              │ 0.0120831  │ 0.0         │
# │ 7   │ 305              │ 0.422983   │ 0.427009    │
# │ 8   │ 377              │ -0.288375  │ 0.0         │
# │ 9   │ 472              │ -0.0727276 │ -0.096383   │
# │ 10  │ 739              │ 0.168954   │ 0.180748    │
# Total iteration number was 22
# Total time was 0.11111021041870117
# median of y = 1.0
# maximum of y = 19.0
# minimum of y = 0.0
# skewness of y = 2.9514756675154414
# kurtosis of y = 15.114552884322098
# mean of y = 1.4941050375133977
# variance of y = 3.8253407486119344
# var / mean = 2.5602890376290777
#
#
# running the 10 th model
# n, p = 832, 1664
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β     │ estimated_β │
# │     │ Int64            │ Float64    │ Float64     │
# ├─────┼──────────────────┼────────────┼─────────────┤
# │ 1   │ 102              │ -0.323843  │ -0.332114   │
# │ 2   │ 447              │ -0.0113476 │ 0.0         │
# │ 3   │ 471              │ 0.115997   │ 0.175245    │
# │ 4   │ 556              │ -0.0607733 │ 0.0         │
# │ 5   │ 698              │ 0.247981   │ 0.208969    │
# │ 6   │ 986              │ 0.118998   │ 0.12222     │
# │ 7   │ 995              │ 0.117438   │ 0.0         │
# │ 8   │ 999              │ 0.0054471  │ 0.0         │
# │ 9   │ 1274             │ -0.0663594 │ 0.0         │
# │ 10  │ 1561             │ 0.12416    │ 0.0         │
# Total iteration number was 15
# Total time was 0.12252378463745117
# median of y = 1.0
# maximum of y = 7.0
# minimum of y = 0.0
# skewness of y = 1.3892432791023317
# kurtosis of y = 2.5630863211630253
# mean of y = 1.1430288461538463
# variance of y = 1.4512389498287508
# var / mean = 1.2696433293980236
#
#
# running the 11 th model
# n, p = 607, 4249
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β     │ estimated_β │
# │     │ Int64            │ Float64    │ Float64     │
# ├─────┼──────────────────┼────────────┼─────────────┤
# │ 1   │ 293              │ -0.0400236 │ 0.0         │
# │ 2   │ 683              │ -0.194169  │ 0.0         │
# │ 3   │ 698              │ 0.222042   │ 0.271398    │
# │ 4   │ 783              │ 0.354028   │ 0.288002    │
# │ 5   │ 932              │ -0.509097  │ -0.51481    │
# │ 6   │ 994              │ -0.348194  │ 0.0         │
# │ 7   │ 1307             │ -0.302166  │ -0.337068   │
# │ 8   │ 1885             │ -0.390767  │ -0.460632   │
# │ 9   │ 2706             │ -0.222207  │ -0.249717   │
# │ 10  │ 4101             │ 0.00865189 │ 0.0         │
# Total iteration number was 13
# Total time was 0.21111583709716797
# median of y = 1.0
# maximum of y = 15.0
# minimum of y = 0.0
# skewness of y = 2.2545666048573274
# kurtosis of y = 6.768189098013805
# mean of y = 1.5074135090609555
# variance of y = 4.14474692938816
# var / mean = 2.749575285397391
#
#
# running the 12 th model
# n, p = 1368, 4104
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 637              │ 0.204366  │ 0.204494    │
# │ 2   │ 954              │ 0.334643  │ 0.344926    │
# │ 3   │ 1055             │ 0.278224  │ 0.273969    │
# │ 4   │ 2017             │ -0.578932 │ -0.577091   │
# │ 5   │ 2190             │ -0.146205 │ -0.151028   │
# │ 6   │ 2196             │ 0.423239  │ 0.436831    │
# │ 7   │ 2641             │ -0.206835 │ -0.201636   │
# │ 8   │ 3005             │ -0.146147 │ -0.127857   │
# │ 9   │ 3182             │ -0.249168 │ -0.218412   │
# │ 10  │ 3585             │ 0.11266   │ 0.0913891   │
# Total iteration number was 24
# Total time was 0.7652080059051514
# median of y = 1.0
# maximum of y = 25.0
# minimum of y = 0.0
# skewness of y = 3.0712185708625683
# kurtosis of y = 17.379972164591862
# mean of y = 1.5445906432748537
# variance of y = 4.480819290973105
# var / mean = 2.900975291079606
#
#
# running the 13 th model
# n, p = 657, 6570
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β      │ estimated_β │
# │     │ Int64            │ Float64     │ Float64     │
# ├─────┼──────────────────┼─────────────┼─────────────┤
# │ 1   │ 625              │ -0.299284   │ 0.0         │
# │ 2   │ 1451             │ 0.0843916   │ 0.0         │
# │ 3   │ 2108             │ 0.0548761   │ 0.0         │
# │ 4   │ 2334             │ 0.817506    │ 0.865104    │
# │ 5   │ 2350             │ -0.00759142 │ 0.0         │
# │ 6   │ 2640             │ -0.130775   │ 0.0         │
# │ 7   │ 2743             │ 0.137641    │ 0.140045    │
# │ 8   │ 4111             │ 0.201042    │ 0.241302    │
# │ 9   │ 5523             │ -0.132113   │ 0.0         │
# │ 10  │ 6296             │ -0.268747   │ -0.283346   │
# Total iteration number was 52
# Total time was 1.264362096786499
# median of y = 1.0
# maximum of y = 89.0
# minimum of y = 0.0
# skewness of y = 9.745347967263653
# kurtosis of y = 117.83127664420448
# mean of y = 2.024353120243531
# variance of y = 34.874406021457474
# var / mean = 17.227432147441775
#
#
# running the 14 th model
# n, p = 1090, 3270
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β      │ estimated_β │
# │     │ Int64            │ Float64     │ Float64     │
# ├─────┼──────────────────┼─────────────┼─────────────┤
# │ 1   │ 399              │ 0.133261    │ 0.13313     │
# │ 2   │ 684              │ -0.16704    │ -0.195192   │
# │ 3   │ 1187             │ 0.0130527   │ 0.0         │
# │ 4   │ 1227             │ 0.0402059   │ 0.0         │
# │ 5   │ 1231             │ 0.147898    │ 0.0         │
# │ 6   │ 1601             │ 0.579535    │ 0.603093    │
# │ 7   │ 1718             │ -0.178755   │ -0.18404    │
# │ 8   │ 2102             │ -0.00728366 │ 0.0         │
# │ 9   │ 2917             │ 0.0767886   │ 0.0         │
# │ 10  │ 3166             │ 0.175708    │ 0.211242    │
# Total iteration number was 13
# Total time was 0.28482794761657715
# median of y = 1.0
# maximum of y = 10.0
# minimum of y = 0.0
# skewness of y = 1.9354390059178561
# kurtosis of y = 5.093674907662102
# mean of y = 1.3247706422018348
# variance of y = 2.610680617686457
# var / mean = 1.9706661172286968
#
#
# running the 15 th model
# n, p = 1660, 11620
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β      │ estimated_β │
# │     │ Int64            │ Float64     │ Float64     │
# ├─────┼──────────────────┼─────────────┼─────────────┤
# │ 1   │ 34               │ -0.202581   │ -0.204355   │
# │ 2   │ 1712             │ -0.385087   │ -0.406339   │
# │ 3   │ 2385             │ 0.407756    │ 0.402045    │
# │ 4   │ 2778             │ -0.135825   │ -0.146963   │
# │ 5   │ 3421             │ 0.06187     │ 0.0856907   │
# │ 6   │ 3646             │ 0.0142869   │ 0.0         │
# │ 7   │ 5899             │ 0.00397524  │ 0.0         │
# │ 8   │ 5951             │ -0.00386753 │ 0.0         │
# │ 9   │ 6482             │ 0.397788    │ 0.397361    │
# │ 10  │ 7689             │ -0.568051   │ -0.549313   │
# Total iteration number was 24
# Total time was 2.6968460083007812
# median of y = 1.0
# maximum of y = 21.0
# minimum of y = 0.0
# skewness of y = 2.64276568407165
# kurtosis of y = 13.422160771008745
# mean of y = 1.4150602409638555
# variance of y = 3.500315547905908
# var / mean = 2.473615925723204
#
#
# running the 16 th model
# n, p = 640, 640
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β     │ estimated_β │
# │     │ Int64            │ Float64    │ Float64     │
# ├─────┼──────────────────┼────────────┼─────────────┤
# │ 1   │ 3                │ 0.01612    │ 0.0         │
# │ 2   │ 90               │ 0.0253462  │ 0.0         │
# │ 3   │ 127              │ -0.542122  │ -0.56879    │
# │ 4   │ 231              │ -0.210136  │ -0.219341   │
# │ 5   │ 288              │ 0.251245   │ 0.276188    │
# │ 6   │ 329              │ -0.702423  │ -0.668893   │
# │ 7   │ 441              │ -0.0778557 │ 0.0         │
# │ 8   │ 510              │ -0.194336  │ -0.203052   │
# │ 9   │ 557              │ 0.0685632  │ 0.0         │
# │ 10  │ 606              │ 0.0729563  │ 0.0         │
# Total iteration number was 21
# Total time was 0.05348801612854004
# median of y = 1.0
# maximum of y = 14.0
# minimum of y = 0.0
# skewness of y = 2.0736555123591023
# kurtosis of y = 5.541024320464178
# mean of y = 1.503125
# variance of y = 3.9655614241001547
# var / mean = 2.6382113424366933
#
#
# running the 17 th model
# n, p = 1913, 1913
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 23               │ -0.235812 │ -0.239127   │
# │ 2   │ 104              │ 0.166863  │ 0.150008    │
# │ 3   │ 112              │ -0.53457  │ -0.488793   │
# │ 4   │ 691              │ 0.200357  │ 0.167003    │
# │ 5   │ 701              │ -0.247481 │ -0.255226   │
# │ 6   │ 850              │ 0.298297  │ 0.31515     │
# │ 7   │ 927              │ 0.0431467 │ 0.0826257   │
# │ 8   │ 1050             │ 0.129093  │ 0.0772986   │
# │ 9   │ 1497             │ -0.436231 │ -0.446462   │
# │ 10  │ 1909             │ -0.158355 │ -0.16319    │
# Total iteration number was 16
# Total time was 0.3576850891113281
# median of y = 1.0
# maximum of y = 16.0
# minimum of y = 0.0
# skewness of y = 2.499523835136042
# kurtosis of y = 10.272421703558628
# mean of y = 1.442237323575536
# variance of y = 3.407880347413755
# var / mean = 2.362912324973727
#
#
# running the 18 th model
# n, p = 1946, 9730
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β     │ estimated_β │
# │     │ Int64            │ Float64    │ Float64     │
# ├─────┼──────────────────┼────────────┼─────────────┤
# │ 1   │ 1256             │ -0.166296  │ 0.0         │
# │ 2   │ 2399             │ -0.0547001 │ 0.0         │
# │ 3   │ 2965             │ -0.203302  │ -0.205858   │
# │ 4   │ 3098             │ 0.0279615  │ 0.0         │
# │ 5   │ 5307             │ -0.226481  │ -0.249661   │
# │ 6   │ 5890             │ 0.299947   │ 0.296729    │
# │ 7   │ 6314             │ 0.538097   │ 0.515157    │
# │ 8   │ 7303             │ 0.0716462  │ 0.0         │
# │ 9   │ 8644             │ -0.211597  │ -0.1658     │
# │ 10  │ 9215             │ -0.288366  │ -0.287404   │
# Total iteration number was 19
# Total time was 2.1946868896484375
# median of y = 1.0
# maximum of y = 40.0
# minimum of y = 0.0
# skewness of y = 5.247093174067735
# kurtosis of y = 60.309878410211574
# mean of y = 1.4249743062692704
# variance of y = 4.765833546897335
# var / mean = 3.344504898039024
#
#
# running the 19 th model
# n, p = 855, 7695
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 1216             │ -0.199722 │ -0.166213   │
# │ 2   │ 2664             │ -0.11413  │ 0.0         │
# │ 3   │ 3144             │ 0.0116179 │ 0.0         │
# │ 4   │ 3175             │ 0.144812  │ 0.148801    │
# │ 5   │ 4681             │ 0.236297  │ 0.214855    │
# │ 6   │ 5118             │ -0.653919 │ -0.61257    │
# │ 7   │ 5610             │ 0.349247  │ 0.373621    │
# │ 8   │ 5909             │ 0.250633  │ 0.243008    │
# │ 9   │ 6949             │ -0.426622 │ -0.41699    │
# │ 10  │ 7429             │ 0.277377  │ 0.309049    │
# Total iteration number was 26
# Total time was 1.1278681755065918
# median of y = 1.0
# maximum of y = 13.0
# minimum of y = 0.0
# skewness of y = 2.0436678436954545
# kurtosis of y = 5.814906125967221
# mean of y = 1.5263157894736843
# variance of y = 3.7062738814248726
# var / mean = 2.4282484050714683
#
#
# running the 20 th model
# n, p = 1366, 5464
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β     │ estimated_β │
# │     │ Int64            │ Float64    │ Float64     │
# ├─────┼──────────────────┼────────────┼─────────────┤
# │ 1   │ 41               │ -0.0297791 │ 0.0         │
# │ 2   │ 438              │ -0.585388  │ -0.577682   │
# │ 3   │ 674              │ -0.181159  │ -0.17947    │
# │ 4   │ 2787             │ 0.245653   │ 0.260017    │
# │ 5   │ 3903             │ -0.0957931 │ -0.112119   │
# │ 6   │ 3930             │ -0.142     │ -0.14021    │
# │ 7   │ 4576             │ 0.133232   │ 0.13093     │
# │ 8   │ 4927             │ -0.485199  │ -0.455125   │
# │ 9   │ 5298             │ 0.32388    │ 0.321223    │
# │ 10  │ 5302             │ 0.068544   │ 0.112096    │
# Total iteration number was 71
# Total time was 3.157396078109741
# median of y = 1.0
# maximum of y = 12.0
# minimum of y = 0.0
# skewness of y = 2.0409924860728537
# kurtosis of y = 5.823558260308767
# mean of y = 1.4275256222547583
# variance of y = 3.1050000268155484
# var / mean = 2.1750923264769435
#
#
# running the 21 th model
# n, p = 1091, 10910
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β     │ estimated_β │
# │     │ Int64            │ Float64    │ Float64     │
# ├─────┼──────────────────┼────────────┼─────────────┤
# │ 1   │ 758              │ 0.056736   │ 0.0         │
# │ 2   │ 2274             │ -0.250818  │ -0.247709   │
# │ 3   │ 2768             │ -0.0600414 │ 0.0         │
# │ 4   │ 4503             │ -0.179924  │ -0.153829   │
# │ 5   │ 4544             │ 0.30209    │ 0.298766    │
# │ 6   │ 5453             │ -0.190575  │ -0.209024   │
# │ 7   │ 5701             │ -0.0477102 │ 0.0         │
# │ 8   │ 7040             │ 0.105628   │ 0.105463    │
# │ 9   │ 8158             │ 0.0546561  │ 0.0         │
# │ 10  │ 8968             │ -0.208857  │ 0.0         │
# Total iteration number was 9
# Total time was 0.7467150688171387
# median of y = 1.0
# maximum of y = 7.0
# minimum of y = 0.0
# skewness of y = 1.2766174736163625
# kurtosis of y = 1.905985355310774
# mean of y = 1.1466544454628782
# variance of y = 1.4408580630513208
# var / mean = 1.256575656905668
#
#
# running the 22 th model
# n, p = 1175, 3525
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β      │ estimated_β │
# │     │ Int64            │ Float64     │ Float64     │
# ├─────┼──────────────────┼─────────────┼─────────────┤
# │ 1   │ 820              │ -0.541254   │ -0.54787    │
# │ 2   │ 1440             │ 0.219448    │ 0.223786    │
# │ 3   │ 1799             │ -0.0358019  │ 0.0         │
# │ 4   │ 1803             │ -0.129582   │ 0.0         │
# │ 5   │ 2240             │ -0.00919766 │ 0.0         │
# │ 6   │ 2418             │ -0.341037   │ -0.319439   │
# │ 7   │ 2521             │ 0.167584    │ 0.185387    │
# │ 8   │ 2692             │ -0.350716   │ -0.32019    │
# │ 9   │ 2738             │ 0.200082    │ 0.219431    │
# │ 10  │ 2950             │ 0.301633    │ 0.310723    │
# Total iteration number was 17
# Total time was 0.44215989112854004
# median of y = 1.0
# maximum of y = 17.0
# minimum of y = 0.0
# skewness of y = 2.278819401276003
# kurtosis of y = 8.77560376064922
# mean of y = 1.3736170212765957
# variance of y = 3.0672760882960595
# var / mean = 2.2329921956306507
#
#
# running the 23 th model
# n, p = 1924, 9620
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 216              │ 0.148353  │ 0.172586    │
# │ 2   │ 246              │ 0.0933856 │ 0.0756716   │
# │ 3   │ 2190             │ 0.518788  │ 0.508283    │
# │ 4   │ 2429             │ 0.367063  │ 0.346194    │
# │ 5   │ 2630             │ 0.192621  │ 0.212493    │
# │ 6   │ 2689             │ 0.162612  │ 0.174051    │
# │ 7   │ 4347             │ 0.240734  │ 0.217691    │
# │ 8   │ 5281             │ 0.0339783 │ 0.0         │
# │ 9   │ 5769             │ 0.0299877 │ 0.0         │
# │ 10  │ 6734             │ 0.0833236 │ 0.0728425   │
# Total iteration number was 20
# Total time was 2.590610980987549
# median of y = 1.0
# maximum of y = 98.0
# minimum of y = 0.0
# skewness of y = 14.70802607736725
# kurtosis of y = 380.5814460677177
# mean of y = 1.5254677754677755
# variance of y = 10.986870555903318
# var / mean = 7.202296064585344
#
#
# running the 24 th model
# n, p = 1238, 2476
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β     │ estimated_β │
# │     │ Int64            │ Float64    │ Float64     │
# ├─────┼──────────────────┼────────────┼─────────────┤
# │ 1   │ 271              │ -0.114277  │ -0.117976   │
# │ 2   │ 482              │ 0.0384188  │ 0.0         │
# │ 3   │ 524              │ 0.503609   │ 0.500796    │
# │ 4   │ 1401             │ 0.327674   │ 0.354856    │
# │ 5   │ 1717             │ 0.156052   │ 0.139214    │
# │ 6   │ 1837             │ 0.19227    │ 0.211558    │
# │ 7   │ 1875             │ 0.0984431  │ 0.0         │
# │ 8   │ 1901             │ 0.149635   │ 0.131523    │
# │ 9   │ 2028             │ -0.0838197 │ -0.119262   │
# │ 10  │ 2243             │ 0.17367    │ 0.154439    │
# Total iteration number was 13
# Total time was 0.2730710506439209
# median of y = 1.0
# maximum of y = 15.0
# minimum of y = 0.0
# skewness of y = 2.600853507888357
# kurtosis of y = 11.508869551568191
# mean of y = 1.2827140549273022
# variance of y = 2.801172256083625
# var / mean = 2.1837854238233803
#
#
# running the 25 th model
# n, p = 1299, 7794
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β      │ estimated_β │
# │     │ Int64            │ Float64     │ Float64     │
# ├─────┼──────────────────┼─────────────┼─────────────┤
# │ 1   │ 79               │ -0.218956   │ -0.234661   │
# │ 2   │ 474              │ 0.258465    │ 0.299783    │
# │ 3   │ 1186             │ -0.0723539  │ 0.0         │
# │ 4   │ 1668             │ -0.00525507 │ 0.0         │
# │ 5   │ 3930             │ 0.237569    │ 0.231325    │
# │ 6   │ 4665             │ -0.299059   │ -0.266383   │
# │ 7   │ 5022             │ -0.12715    │ 0.0         │
# │ 8   │ 7090             │ -0.128147   │ -0.105349   │
# │ 9   │ 7267             │ -0.0553264  │ 0.0         │
# │ 10  │ 7377             │ 0.0775984   │ 0.0         │
# Total iteration number was 10
# Total time was 0.6719410419464111
# median of y = 1.0
# maximum of y = 9.0
# minimum of y = 0.0
# skewness of y = 1.4725202306766143
# kurtosis of y = 3.0953256339235784
# mean of y = 1.1886066204772903
# variance of y = 1.7340457457496636
# var / mean = 1.4588895231404229
#
#
# running the 26 th model
# n, p = 592, 1184
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β      │ estimated_β │
# │     │ Int64            │ Float64     │ Float64     │
# ├─────┼──────────────────┼─────────────┼─────────────┤
# │ 1   │ 224              │ -0.0921019  │ 0.0         │
# │ 2   │ 499              │ -0.00773403 │ 0.0         │
# │ 3   │ 523              │ -0.225232   │ -0.179513   │
# │ 4   │ 531              │ 0.270839    │ 0.319168    │
# │ 5   │ 596              │ -0.205183   │ -0.162067   │
# │ 6   │ 773              │ -0.134809   │ 0.0         │
# │ 7   │ 788              │ -0.119075   │ 0.0         │
# │ 8   │ 1081             │ 0.101364    │ 0.0         │
# │ 9   │ 1126             │ 0.12192     │ 0.0         │
# │ 10  │ 1160             │ 0.0023285   │ 0.0         │
# Total iteration number was 27
# Total time was 0.1177821159362793
# median of y = 1.0
# maximum of y = 7.0
# minimum of y = 0.0
# skewness of y = 1.1415155611020527
# kurtosis of y = 1.5460302467722578
# mean of y = 1.1199324324324325
# variance of y = 1.3612263913659852
# var / mean = 1.215454032712916
#
#
# running the 27 th model
# n, p = 808, 6464
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β      │ estimated_β │
# │     │ Int64            │ Float64     │ Float64     │
# ├─────┼──────────────────┼─────────────┼─────────────┤
# │ 1   │ 255              │ -0.0328451  │ 0.0         │
# │ 2   │ 502              │ 0.109956    │ 0.0         │
# │ 3   │ 1114             │ 0.312806    │ 0.341389    │
# │ 4   │ 2461             │ -0.0652788  │ 0.0         │
# │ 5   │ 3050             │ -0.00459783 │ 0.0         │
# │ 6   │ 4039             │ -0.061523   │ 0.0         │
# │ 7   │ 4389             │ 0.203422    │ 0.226252    │
# │ 8   │ 5642             │ -0.24244    │ 0.0         │
# │ 9   │ 5833             │ -0.181896   │ -0.237817   │
# │ 10  │ 6455             │ -0.789217   │ -0.792444   │
# Total iteration number was 19
# Total time was 0.6225018501281738
# median of y = 1.0
# maximum of y = 16.0
# minimum of y = 0.0
# skewness of y = 2.2417064229260024
# kurtosis of y = 7.0322390233799545
# mean of y = 1.5792079207920793
# variance of y = 4.330769136393194
# var / mean = 2.7423679170891067
#
#
# running the 28 th model
# n, p = 1635, 4905
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β     │ estimated_β │
# │     │ Int64            │ Float64    │ Float64     │
# ├─────┼──────────────────┼────────────┼─────────────┤
# │ 1   │ 16               │ 0.215755   │ 0.191916    │
# │ 2   │ 152              │ 0.0457712  │ 0.0         │
# │ 3   │ 472              │ -0.224001  │ 0.0         │
# │ 4   │ 891              │ 0.0948544  │ 0.0         │
# │ 5   │ 1141             │ 0.162535   │ 0.180137    │
# │ 6   │ 1659             │ 0.134462   │ 0.151857    │
# │ 7   │ 1689             │ -0.0312663 │ 0.0         │
# │ 8   │ 1845             │ 0.191231   │ 0.184744    │
# │ 9   │ 1863             │ -0.0270534 │ 0.0         │
# │ 10  │ 2280             │ -0.0556611 │ 0.0         │
# Total iteration number was 18
# Total time was 0.8544638156890869
# median of y = 1.0
# maximum of y = 10.0
# minimum of y = 0.0
# skewness of y = 1.7106903505764997
# kurtosis of y = 4.99164320017405
# mean of y = 1.0837920489296635
# variance of y = 1.4819586837800707
# var / mean = 1.3673828713207763
#
#
# running the 29 th model
# n, p = 1477, 10339
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 3                │ 0.234543  │ 0.216725    │
# │ 2   │ 540              │ -0.248704 │ -0.246072   │
# │ 3   │ 1326             │ 0.462125  │ 0.453705    │
# │ 4   │ 1401             │ -0.119449 │ -0.122053   │
# │ 5   │ 1832             │ -0.21856  │ -0.208337   │
# │ 6   │ 7113             │ 0.0739162 │ 0.0         │
# │ 7   │ 9528             │ -0.105511 │ -0.0895071  │
# │ 8   │ 9716             │ 0.163276  │ 0.167427    │
# │ 9   │ 9785             │ -0.34271  │ -0.329599   │
# │ 10  │ 10219            │ 1.03002   │ 1.05652     │
# Total iteration number was 34
# Total time was 2.921865940093994
# median of y = 1.0
# maximum of y = 67.0
# minimum of y = 0.0
# skewness of y = 5.943202869469391
# kurtosis of y = 53.32134015291417
# mean of y = 2.3987813134732567
# variance of y = 25.39167873059909
# var / mean = 10.585241175584208
#
#
# running the 30 th model
# n, p = 1015, 3045
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β     │ estimated_β │
# │     │ Int64            │ Float64    │ Float64     │
# ├─────┼──────────────────┼────────────┼─────────────┤
# │ 1   │ 494              │ -0.141394  │ -0.127421   │
# │ 2   │ 543              │ 0.137303   │ 0.1736      │
# │ 3   │ 1589             │ -0.0991919 │ -0.0994982  │
# │ 4   │ 1738             │ -0.240554  │ -0.239058   │
# │ 5   │ 1835             │ -0.157525  │ -0.174756   │
# │ 6   │ 2160             │ -0.183692  │ -0.173735   │
# │ 7   │ 2266             │ 0.00603055 │ 0.0         │
# │ 8   │ 2512             │ 0.075906   │ 0.0         │
# │ 9   │ 2624             │ -0.255734  │ -0.28647    │
# │ 10  │ 2710             │ -0.0707988 │ 0.0         │
# Total iteration number was 29
# Total time was 0.5193078517913818
# median of y = 1.0
# maximum of y = 7.0
# minimum of y = 0.0
# skewness of y = 1.1755315194720428
# kurtosis of y = 1.389699654638349
# mean of y = 1.1408866995073892
# variance of y = 1.4525179506611872
# var / mean = 1.27314829008731
#
#
# running the 31 th model
# n, p = 1180, 7080
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β     │ estimated_β │
# │     │ Int64            │ Float64    │ Float64     │
# ├─────┼──────────────────┼────────────┼─────────────┤
# │ 1   │ 105              │ 0.241974   │ 0.206136    │
# │ 2   │ 515              │ -0.453626  │ -0.400507   │
# │ 3   │ 795              │ 0.230154   │ 0.183488    │
# │ 4   │ 2281             │ -0.0801457 │ 0.0         │
# │ 5   │ 2491             │ 0.0754463  │ 0.0         │
# │ 6   │ 2865             │ 0.0528208  │ 0.0         │
# │ 7   │ 4544             │ 0.156839   │ 0.15859     │
# │ 8   │ 4843             │ -0.0345444 │ 0.0         │
# │ 9   │ 6366             │ 0.190288   │ 0.194288    │
# │ 10  │ 6591             │ 0.0705469  │ 0.0         │
# Total iteration number was 9
# Total time was 0.4832620620727539
# median of y = 1.0
# maximum of y = 8.0
# minimum of y = 0.0
# skewness of y = 1.4840081132111118
# kurtosis of y = 2.7332698831907107
# mean of y = 1.1694915254237288
# variance of y = 1.7066172136685778
# var / mean = 1.459281385600668
#
#
# running the 32 th model
# n, p = 1225, 11025
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β      │ estimated_β │
# │     │ Int64            │ Float64     │ Float64     │
# ├─────┼──────────────────┼─────────────┼─────────────┤
# │ 1   │ 816              │ -0.385095   │ -0.312977   │
# │ 2   │ 922              │ 0.10913     │ 0.0         │
# │ 3   │ 1595             │ 0.16371     │ 0.155505    │
# │ 4   │ 2924             │ -0.129721   │ -0.101455   │
# │ 5   │ 3815             │ 0.133314    │ 0.139338    │
# │ 6   │ 3900             │ -0.0786941  │ 0.0         │
# │ 7   │ 4965             │ -0.297237   │ -0.283463   │
# │ 8   │ 6274             │ 0.38315     │ 0.393079    │
# │ 9   │ 8107             │ 0.000359345 │ 0.0         │
# │ 10  │ 10190            │ 0.120605    │ 0.0         │
# Total iteration number was 13
# Total time was 1.065669059753418
# median of y = 1.0
# maximum of y = 13.0
# minimum of y = 0.0
# skewness of y = 2.340716640458341
# kurtosis of y = 8.573287269244567
# mean of y = 1.2857142857142858
# variance of y = 2.5833333333333335
# var / mean = 2.009259259259259
#
#
# running the 33 th model
# n, p = 672, 672
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β     │ estimated_β │
# │     │ Int64            │ Float64    │ Float64     │
# ├─────┼──────────────────┼────────────┼─────────────┤
# │ 1   │ 79               │ -0.0849744 │ 0.0         │
# │ 2   │ 123              │ -0.368841  │ -0.353037   │
# │ 3   │ 185              │ 0.0799833  │ 0.0         │
# │ 4   │ 221              │ 0.149493   │ 0.106167    │
# │ 5   │ 324              │ -0.315711  │ -0.273576   │
# │ 6   │ 410              │ 0.0776823  │ 0.0         │
# │ 7   │ 464              │ 0.0784524  │ 0.0         │
# │ 8   │ 478              │ -0.0837112 │ 0.0         │
# │ 9   │ 557              │ -0.0445711 │ 0.0         │
# │ 10  │ 560              │ -0.490358  │ 0.0         │
# Total iteration number was 13
# Total time was 0.03830909729003906
# median of y = 1.0
# maximum of y = 6.0
# minimum of y = 0.0
# skewness of y = 1.135749462787519
# kurtosis of y = 1.1870813211281215
# mean of y = 1.2098214285714286
# variance of y = 1.6414533212688938
# var / mean = 1.3567732249602664
#
#
# running the 34 th model
# n, p = 1553, 12424
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β     │ estimated_β │
# │     │ Int64            │ Float64    │ Float64     │
# ├─────┼──────────────────┼────────────┼─────────────┤
# │ 1   │ 359              │ -0.326707  │ -0.317532   │
# │ 2   │ 437              │ 0.0501328  │ 0.0         │
# │ 3   │ 1378             │ -0.265255  │ -0.261841   │
# │ 4   │ 2222             │ -0.0240644 │ 0.0         │
# │ 5   │ 3359             │ -0.358704  │ -0.350326   │
# │ 6   │ 3990             │ 0.051946   │ 0.11181     │
# │ 7   │ 4992             │ -0.268401  │ -0.246584   │
# │ 8   │ 7899             │ -0.0186747 │ 0.0         │
# │ 9   │ 7964             │ -0.167013  │ -0.16486    │
# │ 10  │ 8442             │ 0.176422   │ 0.165939    │
# Total iteration number was 28
# Total time was 3.1332590579986572
# median of y = 1.0
# maximum of y = 7.0
# minimum of y = 0.0
# skewness of y = 1.2105183986700028
# kurtosis of y = 1.3717624845079692
# mean of y = 1.1777205408886027
# variance of y = 1.6114362955636246
# var / mean = 1.3682671224769323
#
#
# running the 35 th model
# n, p = 585, 2925
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β      │ estimated_β │
# │     │ Int64            │ Float64     │ Float64     │
# ├─────┼──────────────────┼─────────────┼─────────────┤
# │ 1   │ 137              │ 0.225216    │ 0.24283     │
# │ 2   │ 159              │ -0.0554315  │ 0.0         │
# │ 3   │ 720              │ -0.00149611 │ 0.0         │
# │ 4   │ 859              │ -0.110411   │ 0.0         │
# │ 5   │ 1293             │ 0.0244766   │ 0.0         │
# │ 6   │ 1675             │ 0.423319    │ 0.357403    │
# │ 7   │ 2396             │ -0.281728   │ -0.191927   │
# │ 8   │ 2478             │ 0.00130143  │ 0.0         │
# │ 9   │ 2481             │ 0.133491    │ 0.0         │
# │ 10  │ 2799             │ 0.303565    │ 0.346768    │
# Total iteration number was 11
# Total time was 0.12998390197753906
# median of y = 1.0
# maximum of y = 12.0
# minimum of y = 0.0
# skewness of y = 2.215159633169766
# kurtosis of y = 9.333898095530428
# mean of y = 1.2820512820512822
# variance of y = 2.141201264488936
# var / mean = 1.6701369863013702
#
#
# running the 36 th model
# n, p = 1629, 9774
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β     │ estimated_β │
# │     │ Int64            │ Float64    │ Float64     │
# ├─────┼──────────────────┼────────────┼─────────────┤
# │ 1   │ 2151             │ -0.0536315 │ 0.0         │
# │ 2   │ 2673             │ -0.0136477 │ 0.0         │
# │ 3   │ 3942             │ 0.0637389  │ 0.0         │
# │ 4   │ 4353             │ -0.284468  │ -0.252909   │
# │ 5   │ 5644             │ 0.028655   │ 0.0         │
# │ 6   │ 6070             │ -0.39331   │ -0.386391   │
# │ 7   │ 6544             │ -0.18267   │ -0.228429   │
# │ 8   │ 8538             │ -0.261644  │ -0.227166   │
# │ 9   │ 9325             │ 0.508522   │ 0.522269    │
# │ 10  │ 9373             │ 0.0587897  │ 0.0         │
# Total iteration number was 14
# Total time was 1.3139820098876953
# median of y = 1.0
# maximum of y = 12.0
# minimum of y = 0.0
# skewness of y = 1.901095862944012
# kurtosis of y = 4.835627201003677
# mean of y = 1.332719459791283
# variance of y = 2.697583570511747
# var / mean = 2.0241195929818683
#
#
# running the 37 th model
# n, p = 1730, 12110
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 4972             │ 0.148351  │ 0.158423    │
# │ 2   │ 5172             │ 0.0603649 │ 0.0         │
# │ 3   │ 5291             │ 0.28703   │ 0.297917    │
# │ 4   │ 6634             │ -0.104951 │ -0.094599   │
# │ 5   │ 6851             │ -0.306851 │ -0.267862   │
# │ 6   │ 7118             │ 0.30601   │ 0.300041    │
# │ 7   │ 8646             │ 0.179877  │ 0.200693    │
# │ 8   │ 9641             │ 0.31374   │ 0.328234    │
# │ 9   │ 10298            │ 0.205802  │ 0.200482    │
# │ 10  │ 11049            │ -0.101332 │ -0.109044   │
# Total iteration number was 13
# Total time was 1.6263699531555176
# median of y = 1.0
# maximum of y = 22.0
# minimum of y = 0.0
# skewness of y = 3.0657659897255116
# kurtosis of y = 19.180836291617076
# mean of y = 1.3393063583815028
# variance of y = 2.9368578181781717
# var / mean = 2.192820036878825
#
#
# running the 38 th model
# n, p = 582, 5820
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 31               │ -0.475236 │ -0.421703   │
# │ 2   │ 89               │ 0.071242  │ 0.0         │
# │ 3   │ 134              │ 0.121068  │ 0.0         │
# │ 4   │ 1225             │ 0.0383328 │ 0.0         │
# │ 5   │ 2796             │ 0.300549  │ 0.202935    │
# │ 6   │ 2828             │ -0.262749 │ -0.319313   │
# │ 7   │ 3286             │ 0.592543  │ 0.488335    │
# │ 8   │ 4297             │ 0.0513413 │ 0.0         │
# │ 9   │ 4318             │ 0.149346  │ 0.131714    │
# │ 10  │ 5231             │ -0.410863 │ -0.40989    │
# Total iteration number was 23
# Total time was 0.467926025390625
# median of y = 1.0
# maximum of y = 14.0
# minimum of y = 0.0
# skewness of y = 2.6327333612636266
# kurtosis of y = 9.987638717480184
# mean of y = 1.470790378006873
# variance of y = 3.5783191676869475
# var / mean = 2.432922611675004
#
#
# running the 39 th model
# n, p = 1709, 8545
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β     │ estimated_β │
# │     │ Int64            │ Float64    │ Float64     │
# ├─────┼──────────────────┼────────────┼─────────────┤
# │ 1   │ 3525             │ -0.0361085 │ 0.0         │
# │ 2   │ 4082             │ 0.145683   │ 0.148332    │
# │ 3   │ 4258             │ 0.182846   │ 0.199643    │
# │ 4   │ 4611             │ 0.118641   │ 0.0991058   │
# │ 5   │ 4824             │ -0.308928  │ -0.277853   │
# │ 6   │ 4931             │ 0.183158   │ 0.162522    │
# │ 7   │ 6286             │ 0.0289929  │ 0.0         │
# │ 8   │ 6510             │ -0.259701  │ -0.28288    │
# │ 9   │ 7944             │ -0.432253  │ -0.413198   │
# │ 10  │ 7962             │ -0.277418  │ -0.26104    │
# Total iteration number was 20
# Total time was 1.6733438968658447
# median of y = 1.0
# maximum of y = 9.0
# minimum of y = 0.0
# skewness of y = 1.5499435030011397
# kurtosis of y = 3.265222033180388
# mean of y = 1.2832065535400818
# variance of y = 1.9700983770998837
# var / mean = 1.5352932633213412
#
#
# running the 40 th model
# n, p = 780, 3120
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β     │ estimated_β │
# │     │ Int64            │ Float64    │ Float64     │
# ├─────┼──────────────────┼────────────┼─────────────┤
# │ 1   │ 785              │ 0.273254   │ 0.253168    │
# │ 2   │ 996              │ -0.0482388 │ 0.0         │
# │ 3   │ 1235             │ 0.0446605  │ 0.0         │
# │ 4   │ 1422             │ 0.226092   │ 0.219165    │
# │ 5   │ 1462             │ -0.635932  │ -0.682615   │
# │ 6   │ 1539             │ 0.221059   │ 0.249361    │
# │ 7   │ 1654             │ 0.29721    │ 0.346935    │
# │ 8   │ 1723             │ 0.0847635  │ 0.143633    │
# │ 9   │ 2166             │ 0.394932   │ 0.380395    │
# │ 10  │ 2324             │ 0.222697   │ 0.0         │
# Total iteration number was 117
# Total time was 1.6627609729766846
# median of y = 1.0
# maximum of y = 13.0
# minimum of y = 0.0
# skewness of y = 2.0391986948848086
# kurtosis of y = 5.849604267161425
# mean of y = 1.523076923076923
# variance of y = 3.510378196899378
# var / mean = 2.304793765641006
#
#
# running the 41 th model
# n, p = 1134, 9072
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 235              │ 0.39193   │ 0.372695    │
# │ 2   │ 1645             │ -0.287121 │ -0.274286   │
# │ 3   │ 2239             │ -0.19568  │ -0.1823     │
# │ 4   │ 2591             │ -0.642164 │ -0.68597    │
# │ 5   │ 3731             │ 0.192769  │ 0.167504    │
# │ 6   │ 4507             │ -0.19778  │ 0.0         │
# │ 7   │ 4929             │ -0.138789 │ -0.124548   │
# │ 8   │ 6846             │ -0.235588 │ -0.277353   │
# │ 9   │ 7201             │ -0.4296   │ -0.43572    │
# │ 10  │ 7338             │ -0.336385 │ -0.309452   │
# Total iteration number was 39
# Total time was 2.2552571296691895
# median of y = 1.0
# maximum of y = 25.0
# minimum of y = 0.0
# skewness of y = 3.2001771005449404
# kurtosis of y = 15.73719855103436
# mean of y = 1.6807760141093475
# variance of y = 6.019806634693367
# var / mean = 3.5815638634534515
#
#
# running the 42 th model
# n, p = 1431, 1431
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β     │ estimated_β │
# │     │ Int64            │ Float64    │ Float64     │
# ├─────┼──────────────────┼────────────┼─────────────┤
# │ 1   │ 28               │ -0.0617443 │ 0.0         │
# │ 2   │ 138              │ 0.296655   │ 0.274537    │
# │ 3   │ 233              │ -0.343303  │ -0.302336   │
# │ 4   │ 322              │ -0.102183  │ -0.18376    │
# │ 5   │ 501              │ 0.0864408  │ 0.0         │
# │ 6   │ 514              │ 0.0097365  │ 0.0         │
# │ 7   │ 679              │ -0.0739486 │ 0.0         │
# │ 8   │ 1046             │ -0.222706  │ -0.287492   │
# │ 9   │ 1082             │ 0.285209   │ 0.307505    │
# │ 10  │ 1103             │ 0.412225   │ 0.426879    │
# Total iteration number was 33
# Total time was 0.3756988048553467
# median of y = 1.0
# maximum of y = 50.0
# minimum of y = 0.0
# skewness of y = 8.240212258646
# kurtosis of y = 132.43746723078436
# mean of y = 1.4262753319357093
# variance of y = 5.7370433898735795
# var / mean = 4.022395438955949
#
#
# running the 43 th model
# n, p = 748, 3740
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β     │ estimated_β │
# │     │ Int64            │ Float64    │ Float64     │
# ├─────┼──────────────────┼────────────┼─────────────┤
# │ 1   │ 508              │ 0.294177   │ 0.351717    │
# │ 2   │ 705              │ 0.150167   │ 0.117146    │
# │ 3   │ 867              │ 0.236547   │ 0.239623    │
# │ 4   │ 1036             │ 0.141059   │ 0.113746    │
# │ 5   │ 1324             │ -0.141739  │ -0.166455   │
# │ 6   │ 1701             │ 0.126345   │ 0.150202    │
# │ 7   │ 1900             │ -0.354569  │ -0.372182   │
# │ 8   │ 2282             │ -0.0534288 │ 0.0         │
# │ 9   │ 2494             │ 0.427457   │ 0.457688    │
# │ 10  │ 2500             │ 0.0965372  │ 0.109745    │
# Total iteration number was 14
# Total time was 0.23558402061462402
# median of y = 1.0
# maximum of y = 16.0
# minimum of y = 0.0
# skewness of y = 2.739540013490197
# kurtosis of y = 13.130889584217417
# mean of y = 1.3061497326203209
# variance of y = 2.8793731074028748
# var / mean = 2.204473986015712
#
#
# running the 44 th model
# n, p = 873, 3492
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β      │ estimated_β │
# │     │ Int64            │ Float64     │ Float64     │
# ├─────┼──────────────────┼─────────────┼─────────────┤
# │ 1   │ 930              │ -0.303015   │ -0.249102   │
# │ 2   │ 959              │ 0.119338    │ 0.138657    │
# │ 3   │ 1305             │ 0.175252    │ 0.160629    │
# │ 4   │ 1352             │ -0.217875   │ -0.201842   │
# │ 5   │ 1723             │ 0.123131    │ 0.10199     │
# │ 6   │ 1737             │ 0.044004    │ 0.0         │
# │ 7   │ 2412             │ -0.00745323 │ 0.0         │
# │ 8   │ 2747             │ 0.0166657   │ 0.0         │
# │ 9   │ 2961             │ 0.0588968   │ 0.0         │
# │ 10  │ 2994             │ -0.411402   │ -0.408289   │
# Total iteration number was 15
# Total time was 0.27163100242614746
# median of y = 1.0
# maximum of y = 8.0
# minimum of y = 0.0
# skewness of y = 1.308116408131904
# kurtosis of y = 2.4617633584718384
# mean of y = 1.143184421534937
# variance of y = 1.537960948747859
# var / mean = 1.3453305693956723
#
#
# running the 45 th model
# n, p = 1889, 9445
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β     │ estimated_β │
# │     │ Int64            │ Float64    │ Float64     │
# ├─────┼──────────────────┼────────────┼─────────────┤
# │ 1   │ 478              │ -0.082571  │ 0.0         │
# │ 2   │ 1780             │ -0.117576  │ -0.102377   │
# │ 3   │ 1833             │ -0.131754  │ -0.148676   │
# │ 4   │ 3156             │ -0.305146  │ -0.336984   │
# │ 5   │ 3621             │ 0.159235   │ 0.196742    │
# │ 6   │ 3809             │ 0.269679   │ 0.246755    │
# │ 7   │ 4766             │ -0.0248695 │ 0.0         │
# │ 8   │ 6682             │ -0.0138994 │ 0.0         │
# │ 9   │ 7050             │ 0.243532   │ 0.23289     │
# │ 10  │ 9407             │ 0.132421   │ 0.148195    │
# Total iteration number was 21
# Total time was 2.1042070388793945
# median of y = 1.0
# maximum of y = 9.0
# minimum of y = 0.0
# skewness of y = 1.4611191152335077
# kurtosis of y = 3.0223954844849823
# mean of y = 1.1471678136580201
# variance of y = 1.578965756251626
# var / mean = 1.3764034672631849
#
#
# running the 46 th model
# n, p = 1233, 2466
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β     │ estimated_β │
# │     │ Int64            │ Float64    │ Float64     │
# ├─────┼──────────────────┼────────────┼─────────────┤
# │ 1   │ 415              │ 0.0190281  │ 0.0         │
# │ 2   │ 491              │ 0.0762953  │ 0.104208    │
# │ 3   │ 1168             │ 0.144465   │ 0.118189    │
# │ 4   │ 1276             │ -0.0261838 │ 0.0         │
# │ 5   │ 1652             │ 0.405432   │ 0.391017    │
# │ 6   │ 1863             │ 0.0534592  │ 0.0         │
# │ 7   │ 2040             │ -0.451481  │ -0.425325   │
# │ 8   │ 2127             │ 0.142095   │ 0.147259    │
# │ 9   │ 2151             │ 0.331519   │ 0.311989    │
# │ 10  │ 2186             │ -0.0553218 │ -0.108711   │
# Total iteration number was 14
# Total time was 0.25916385650634766
# median of y = 1.0
# maximum of y = 12.0
# minimum of y = 0.0
# skewness of y = 2.0842219510337694
# kurtosis of y = 6.588174972636539
# mean of y = 1.2814274128142742
# variance of y = 2.510831727072602
# var / mean = 1.9594022275193155
#
#
# running the 47 th model
# n, p = 1367, 2734
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β     │ estimated_β │
# │     │ Int64            │ Float64    │ Float64     │
# ├─────┼──────────────────┼────────────┼─────────────┤
# │ 1   │ 112              │ 0.251385   │ 0.275527    │
# │ 2   │ 234              │ 0.0314126  │ 0.0         │
# │ 3   │ 890              │ 0.0784391  │ 0.0817396   │
# │ 4   │ 1383             │ -0.0518416 │ 0.0         │
# │ 5   │ 1402             │ 0.342272   │ 0.333295    │
# │ 6   │ 1447             │ -0.269496  │ -0.250259   │
# │ 7   │ 1529             │ 0.190325   │ 0.169443    │
# │ 8   │ 1938             │ -0.18884   │ -0.145237   │
# │ 9   │ 1978             │ -0.161212  │ 0.0         │
# │ 10  │ 2165             │ 0.157609   │ 0.169234    │
# Total iteration number was 14
# Total time was 0.3290138244628906
# median of y = 1.0
# maximum of y = 11.0
# minimum of y = 0.0
# skewness of y = 1.4277786926949634
# kurtosis of y = 3.2178175487176883
# mean of y = 1.2033650329188004
# variance of y = 1.7258159010604486
# var / mean = 1.4341582594222693
#
#
# running the 48 th model
# n, p = 621, 4968
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β     │ estimated_β │
# │     │ Int64            │ Float64    │ Float64     │
# ├─────┼──────────────────┼────────────┼─────────────┤
# │ 1   │ 295              │ 0.639455   │ 0.579297    │
# │ 2   │ 1261             │ 0.46338    │ 0.470774    │
# │ 3   │ 1657             │ -0.287148  │ -0.336597   │
# │ 4   │ 1810             │ 0.0564219  │ 0.0         │
# │ 5   │ 2290             │ -0.149167  │ -0.159003   │
# │ 6   │ 2377             │ 0.237946   │ 0.247521    │
# │ 7   │ 3457             │ -0.215108  │ -0.283085   │
# │ 8   │ 3618             │ 0.183017   │ 0.166897    │
# │ 9   │ 4452             │ -0.0886803 │ 0.0         │
# │ 10  │ 4552             │ -0.0432063 │ 0.0         │
# Total iteration number was 15
# Total time was 0.3075380325317383
# median of y = 1.0
# maximum of y = 17.0
# minimum of y = 0.0
# skewness of y = 2.4030072718225965
# kurtosis of y = 8.591888655996376
# mean of y = 1.541062801932367
# variance of y = 4.2680691912108495
# var / mean = 2.769562139751241
#
#
# running the 49 th model
# n, p = 1138, 6828
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β     │ estimated_β │
# │     │ Int64            │ Float64    │ Float64     │
# ├─────┼──────────────────┼────────────┼─────────────┤
# │ 1   │ 300              │ 0.127339   │ 0.106744    │
# │ 2   │ 457              │ 0.156695   │ 0.19791     │
# │ 3   │ 532              │ -0.460387  │ -0.466298   │
# │ 4   │ 551              │ 0.100912   │ 0.0         │
# │ 5   │ 1042             │ -0.315793  │ -0.347087   │
# │ 6   │ 1368             │ -0.0832159 │ 0.0         │
# │ 7   │ 2003             │ 0.286756   │ 0.299752    │
# │ 8   │ 2422             │ -0.0996552 │ -0.120345   │
# │ 9   │ 5068             │ -0.250654  │ -0.206641   │
# │ 10  │ 5403             │ -0.0909665 │ 0.0         │
# Total iteration number was 14
# Total time was 0.6560549736022949
# median of y = 1.0
# maximum of y = 8.0
# minimum of y = 0.0
# skewness of y = 1.522051898613945
# kurtosis of y = 2.6891150448060914
# mean of y = 1.3145869947275923
# variance of y = 2.214052643700547
# var / mean = 1.6842191901946675
#
#
# running the 50 th model
# n, p = 721, 2163
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β     │ estimated_β │
# │     │ Int64            │ Float64    │ Float64     │
# ├─────┼──────────────────┼────────────┼─────────────┤
# │ 1   │ 49               │ -0.135581  │ -0.105026   │
# │ 2   │ 305              │ -0.35711   │ -0.361303   │
# │ 3   │ 801              │ 0.136302   │ 0.0         │
# │ 4   │ 1012             │ 0.698256   │ 0.66962     │
# │ 5   │ 1091             │ -0.14329   │ -0.150313   │
# │ 6   │ 1246             │ -0.0147975 │ 0.0         │
# │ 7   │ 1931             │ -0.105854  │ 0.0         │
# │ 8   │ 2029             │ -0.229757  │ -0.238294   │
# │ 9   │ 2039             │ -0.429588  │ -0.372285   │
# │ 10  │ 2093             │ 0.00935661 │ 0.0         │
# Total iteration number was 23
# Total time was 0.22382307052612305
# median of y = 1.0
# maximum of y = 16.0
# minimum of y = 0.0
# skewness of y = 2.808296256863068
# kurtosis of y = 10.603377337158982
# mean of y = 1.6865464632454923
# variance of y = 5.482165973185393
# var / mean = 3.2505276864035104

# %% [markdown]
# # Should I initialize beta?

# %% [markdown]
# ## Examine reconstruction result as k increase
#
# Here we use the same SNP matrix but different sparsity parameter to examine reconstruction results, where $k = \{1,2,...,30\}$.

# %%
function run_poisson_increasing_k()
    n, p = 2000, 20000

    #set random seed
    Random.seed!(1111)

    #simulate data
    bernoulli_rates = 0.5rand(p) #minor allele frequencies are drawn from uniform (0, 0.5)
    x = simulate_random_snparray(n, p, bernoulli_rates)
    xbm = SnpBitMatrix{Float64}(x, model=ADDITIVE_MODEL, center=true, scale=true); 
    z = ones(n, 1)                   # non-genetic covariates, just the intercept

    for k in 1:30
        true_b      = zeros(p)                     # model vector
        true_b[1:k] = rand(Normal(0, 0.25), k)     # Initialize k non-zero entries in the true model
        shuffle!(true_b)                           # Shuffle the entries
        correct_position = findall(x -> x != 0, true_b) # keep track of what the true entries are

        #simulate phenotypes under different noises by: y = Xb + noise
        y_temp = xbm * true_b

        # Simulate poisson data
        λ = exp.(y_temp) #inverse log link
        y = [rand(Poisson(x)) for x in λ]
        y = Float64.(y)

        #compute poisson IHT result
        result = L0_poisson_reg(x, z, y, 1, k, glm = "poisson", debias=false, convg=false, show_info=false)

        #check result
        estimated_models = result.beta[correct_position]
        true_model = true_b[correct_position]
        compare_model = DataFrame(
            correct_position = correct_position, 
            true_β           = true_model, 
            estimated_β      = estimated_models)

        #display results
        @show compare_model
        println("Total iteration number was " * string(result.iter))
        println("Total time was " * string(result.time))
    end
end
# Out:
# run_poisson_increasing_k (generic function with 1 method)

# %%
run_poisson_increasing_k()
# Out:
# compare_model = 1×3 DataFrame
# │ Row │ correct_position │ true_β     │ estimated_β │
# │     │ Int64            │ Float64    │ Float64     │
# ├─────┼──────────────────┼────────────┼─────────────┤
# │ 1   │ 9568             │ -0.0456826 │ 0.0         │
# Total iteration number was 8
# Total time was 13.029578924179077
# compare_model = 2×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 10299            │ 0.218268  │ 0.2111      │
# │ 2   │ 12735            │ 0.0469189 │ 0.0         │
# Total iteration number was 13
# Total time was 11.204272985458374
# compare_model = 3×3 DataFrame
# │ Row │ correct_position │ true_β     │ estimated_β │
# │     │ Int64            │ Float64    │ Float64     │
# ├─────┼──────────────────┼────────────┼─────────────┤
# │ 1   │ 962              │ -0.0913304 │ 0.0         │
# │ 2   │ 14502            │ 0.0597354  │ 0.0         │
# │ 3   │ 18863            │ 0.421816   │ 0.397571    │
# Total iteration number was 9
# Total time was 9.888180017471313
# compare_model = 4×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 4021             │ -0.183905 │ -0.199426   │
# │ 2   │ 6782             │ 0.13128   │ 0.140093    │
# │ 3   │ 7058             │ -0.114921 │ 0.0         │
# │ 4   │ 9688             │ -0.171892 │ -0.155973   │
# Total iteration number was 41
# Total time was 16.54461407661438
# compare_model = 5×3 DataFrame
# │ Row │ correct_position │ true_β   │ estimated_β │
# │     │ Int64            │ Float64  │ Float64     │
# ├─────┼──────────────────┼──────────┼─────────────┤
# │ 1   │ 4903             │ -0.14212 │ 0.0         │
# │ 2   │ 8833             │ 0.356474 │ 0.0         │
# │ 3   │ 9987             │ 0.434339 │ 0.444072    │
# │ 4   │ 14050            │ 0.53447  │ 0.546328    │
# │ 5   │ 18116            │ 0.411711 │ 0.0         │
# Total iteration number was 11
# Total time was 13.088027000427246
# compare_model = 6×3 DataFrame
# │ Row │ correct_position │ true_β     │ estimated_β │
# │     │ Int64            │ Float64    │ Float64     │
# ├─────┼──────────────────┼────────────┼─────────────┤
# │ 1   │ 3142             │ 0.0925245  │ 0.115717    │
# │ 2   │ 3223             │ 0.100644   │ 0.137062    │
# │ 3   │ 3760             │ -0.0444144 │ 0.0         │
# │ 4   │ 5371             │ -0.251812  │ -0.264254   │
# │ 5   │ 5376             │ 0.372268   │ 0.341707    │
# │ 6   │ 13824            │ -0.0290951 │ 0.0         │
# Total iteration number was 46
# Total time was 19.51695418357849
# compare_model = 7×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 5617             │ 0.106973  │ 0.0         │
# │ 2   │ 6268             │ 0.357896  │ 0.350574    │
# │ 3   │ 11566            │ -0.1358   │ 0.0         │
# │ 4   │ 15056            │ -0.376455 │ -0.365423   │
# │ 5   │ 15879            │ 0.246083  │ 0.258632    │
# │ 6   │ 18295            │ 0.054023  │ 0.0         │
# │ 7   │ 19102            │ -0.197035 │ -0.192038   │
# Total iteration number was 11
# Total time was 11.02547001838684
# compare_model = 8×3 DataFrame
# │ Row │ correct_position │ true_β     │ estimated_β │
# │     │ Int64            │ Float64    │ Float64     │
# ├─────┼──────────────────┼────────────┼─────────────┤
# │ 1   │ 4603             │ -0.0631335 │ 0.0         │
# │ 2   │ 7773             │ -0.389874  │ -0.390311   │
# │ 3   │ 12095            │ -0.371609  │ -0.368128   │
# │ 4   │ 12459            │ -0.635677  │ -0.677959   │
# │ 5   │ 18137            │ -0.18601   │ -0.169981   │
# │ 6   │ 18157            │ 0.295663   │ 0.294559    │
# │ 7   │ 18398            │ 0.0451897  │ 0.0         │
# │ 8   │ 19604            │ 0.152154   │ 0.166434    │
# Total iteration number was 227
# Total time was 57.66154909133911
# compare_model = 9×3 DataFrame
# │ Row │ correct_position │ true_β     │ estimated_β │
# │     │ Int64            │ Float64    │ Float64     │
# ├─────┼──────────────────┼────────────┼─────────────┤
# │ 1   │ 2462             │ -0.0780719 │ 0.0         │
# │ 2   │ 4986             │ -0.107277  │ 0.0         │
# │ 3   │ 6813             │ -0.271797  │ -0.245961   │
# │ 4   │ 9414             │ -0.0777801 │ 0.0         │
# │ 5   │ 9892             │ 0.234149   │ 0.219046    │
# │ 6   │ 9926             │ 0.0937795  │ 0.0         │
# │ 7   │ 16321            │ 0.265392   │ 0.254284    │
# │ 8   │ 18704            │ -0.405938  │ -0.411073   │
# │ 9   │ 18964            │ 0.343031   │ 0.323705    │
# Total iteration number was 14
# Total time was 12.612072944641113
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β     │ estimated_β │
# │     │ Int64            │ Float64    │ Float64     │
# ├─────┼──────────────────┼────────────┼─────────────┤
# │ 1   │ 1975             │ -0.335097  │ -0.347302   │
# │ 2   │ 2126             │ -0.135402  │ -0.138379   │
# │ 3   │ 3225             │ -0.214612  │ -0.189161   │
# │ 4   │ 4469             │ 0.0738079  │ 0.0         │
# │ 5   │ 5669             │ -0.0307269 │ 0.0         │
# │ 6   │ 7437             │ -0.504329  │ -0.494942   │
# │ 7   │ 8734             │ 0.217724   │ 0.211177    │
# │ 8   │ 9550             │ 0.199216   │ 0.182169    │
# │ 9   │ 10699            │ -0.200157  │ -0.696921   │
# │ 10  │ 17910            │ 0.130384   │ 0.156012    │
# Total iteration number was 123
# Total time was 34.47650408744812
# compare_model = 11×3 DataFrame
# │ Row │ correct_position │ true_β     │ estimated_β │
# │     │ Int64            │ Float64    │ Float64     │
# ├─────┼──────────────────┼────────────┼─────────────┤
# │ 1   │ 3676             │ -0.149796  │ -0.15499    │
# │ 2   │ 3788             │ 0.131613   │ 0.122537    │
# │ 3   │ 8966             │ 0.0550746  │ 0.0         │
# │ 4   │ 9783             │ -0.109534  │ 0.0         │
# │ 5   │ 10001            │ 0.16556    │ 0.132194    │
# │ 6   │ 10224            │ 0.343136   │ 0.318468    │
# │ 7   │ 10446            │ -0.0503296 │ 0.0         │
# │ 8   │ 13200            │ -0.248111  │ -0.280816   │
# │ 9   │ 16916            │ 0.119628   │ 0.0         │
# │ 10  │ 17740            │ 0.107018   │ 0.0         │
# │ 11  │ 19736            │ -0.0704231 │ 0.0         │
# Total iteration number was 30
# Total time was 15.342043161392212
# compare_model = 12×3 DataFrame
# │ Row │ correct_position │ true_β     │ estimated_β │
# │     │ Int64            │ Float64    │ Float64     │
# ├─────┼──────────────────┼────────────┼─────────────┤
# │ 1   │ 1060             │ -0.447248  │ -0.414389   │
# │ 2   │ 1080             │ -0.128598  │ -0.141729   │
# │ 3   │ 1818             │ 0.297896   │ 0.260299    │
# │ 4   │ 3749             │ -0.466367  │ -0.415418   │
# │ 5   │ 6272             │ 0.0211795  │ 0.0         │
# │ 6   │ 8855             │ 0.107979   │ 0.099074    │
# │ 7   │ 15018            │ 0.261584   │ 0.240539    │
# │ 8   │ 15775            │ -0.25385   │ -0.209067   │
# │ 9   │ 15860            │ -0.117792  │ -0.12913    │
# │ 10  │ 18541            │ -0.455834  │ -0.434951   │
# │ 11  │ 18767            │ 0.00141674 │ 0.0         │
# │ 12  │ 19866            │ 0.133343   │ 0.149795    │
# Total iteration number was 102
# Total time was 32.099008083343506
# compare_model = 13×3 DataFrame
# │ Row │ correct_position │ true_β     │ estimated_β │
# │     │ Int64            │ Float64    │ Float64     │
# ├─────┼──────────────────┼────────────┼─────────────┤
# │ 1   │ 837              │ 0.482301   │ 0.487336    │
# │ 2   │ 1627             │ 0.0696352  │ 0.0         │
# │ 3   │ 1754             │ 0.260422   │ 0.273504    │
# │ 4   │ 2338             │ 0.00876747 │ 0.0         │
# │ 5   │ 2710             │ -0.333467  │ -0.316057   │
# │ 6   │ 4355             │ 0.0361395  │ 0.0         │
# │ 7   │ 5370             │ 0.0843651  │ 0.0         │
# │ 8   │ 5757             │ 0.0891103  │ 0.0         │
# │ 9   │ 8092             │ -0.176401  │ -0.158967   │
# │ 10  │ 8922             │ -0.14565   │ 0.0         │
# │ 11  │ 14425            │ 0.0466751  │ 0.0         │
# │ 12  │ 17171            │ 0.158075   │ 0.137805    │
# │ 13  │ 17401            │ 0.275921   │ 0.291836    │
# Total iteration number was 14
# Total time was 12.349570035934448
# compare_model = 14×3 DataFrame
# │ Row │ correct_position │ true_β     │ estimated_β │
# │     │ Int64            │ Float64    │ Float64     │
# ├─────┼──────────────────┼────────────┼─────────────┤
# │ 1   │ 944              │ -0.0281627 │ 0.0         │
# │ 2   │ 972              │ -0.470759  │ -0.492215   │
# │ 3   │ 4811             │ 0.1451     │ 0.14736     │
# │ 4   │ 6994             │ 0.275992   │ 0.253826    │
# │ 5   │ 7578             │ 0.490997   │ 0.497094    │
# │ 6   │ 10823            │ -0.047239  │ 0.0         │
# │ 7   │ 14030            │ 0.211842   │ 0.210062    │
# │ 8   │ 14186            │ -0.178754  │ -0.156666   │
# │ 9   │ 14332            │ -0.216243  │ -0.203253   │
# │ 10  │ 15531            │ -0.138384  │ -0.124302   │
# │ 11  │ 16551            │ -0.401501  │ -0.410837   │
# │ 12  │ 17593            │ -0.3789    │ -0.342634   │
# │ 13  │ 17700            │ 0.0172266  │ 0.0         │
# │ 14  │ 19480            │ 0.104272   │ 0.0601249   │
# Total iteration number was 48
# Total time was 22.086112022399902
# compare_model = 15×3 DataFrame
# │ Row │ correct_position │ true_β     │ estimated_β │
# │     │ Int64            │ Float64    │ Float64     │
# ├─────┼──────────────────┼────────────┼─────────────┤
# │ 1   │ 724              │ -0.0565231 │ 0.0         │
# │ 2   │ 1275             │ 0.15887    │ 0.139613    │
# │ 3   │ 2022             │ -0.136846  │ 0.0         │
# │ 4   │ 3031             │ -0.183528  │ 0.0         │
# │ 5   │ 4240             │ -0.281765  │ -0.252862   │
# │ 6   │ 7946             │ -0.0605412 │ 0.0         │
# │ 7   │ 8234             │ -0.465959  │ -0.480285   │
# │ 8   │ 14298            │ -0.462556  │ -0.476015   │
# │ 9   │ 14975            │ 0.00929031 │ 0.0         │
# │ 10  │ 15320            │ 0.257953   │ 0.236598    │
# │ 11  │ 15691            │ -0.121347  │ 0.0         │
# │ 12  │ 16055            │ 0.146572   │ 0.0         │
# │ 13  │ 16893            │ -0.0469325 │ 0.0         │
# │ 14  │ 17380            │ -0.0172363 │ 0.0         │
# │ 15  │ 19159            │ -0.367395  │ -0.344208   │
# Total iteration number was 14
# Total time was 14.632152795791626
# compare_model = 16×3 DataFrame
# │ Row │ correct_position │ true_β      │ estimated_β │
# │     │ Int64            │ Float64     │ Float64     │
# ├─────┼──────────────────┼─────────────┼─────────────┤
# │ 1   │ 839              │ 0.252661    │ 0.237347    │
# │ 2   │ 1275             │ -0.0673381  │ 0.0         │
# │ 3   │ 2302             │ 0.0471596   │ 0.0         │
# │ 4   │ 2345             │ -0.255943   │ -0.241975   │
# │ 5   │ 4925             │ 0.0407581   │ 0.0         │
# │ 6   │ 5887             │ 0.0372448   │ 0.0         │
# │ 7   │ 5992             │ -0.252004   │ -0.255103   │
# │ 8   │ 6364             │ 0.207766    │ 0.220228    │
# │ 9   │ 8696             │ -0.00571543 │ 0.0         │
# │ 10  │ 9341             │ -0.0170063  │ 0.0         │
# │ 11  │ 9678             │ 0.248238    │ 0.234788    │
# │ 12  │ 11016            │ 0.139676    │ 0.105019    │
# │ 13  │ 11047            │ 0.0956616   │ 0.0         │
# │ 14  │ 12660            │ 0.278976    │ 0.263985    │
# │ 15  │ 13067            │ -0.208148   │ -0.198983   │
# │ 16  │ 16306            │ 0.274934    │ 0.27253     │
# Total iteration number was 13
# Total time was 12.893104076385498
# compare_model = 17×3 DataFrame
# │ Row │ correct_position │ true_β     │ estimated_β │
# │     │ Int64            │ Float64    │ Float64     │
# ├─────┼──────────────────┼────────────┼─────────────┤
# │ 1   │ 731              │ 0.151062   │ 0.0         │
# │ 2   │ 1015             │ 0.14965    │ 0.141997    │
# │ 3   │ 5097             │ 0.394914   │ 0.387203    │
# │ 4   │ 5289             │ -0.317126  │ -0.315615   │
# │ 5   │ 6605             │ 0.231801   │ 0.229767    │
# │ 6   │ 7886             │ -0.024159  │ 0.0         │
# │ 7   │ 11763            │ -0.396087  │ -0.380209   │
# │ 8   │ 12542            │ -0.128651  │ -0.143865   │
# │ 9   │ 12899            │ -0.403014  │ -0.39109    │
# │ 10  │ 14557            │ 0.458012   │ 0.473785    │
# │ 11  │ 14905            │ -0.191063  │ -0.197274   │
# │ 12  │ 15380            │ 0.082236   │ 0.0         │
# │ 13  │ 15449            │ -0.0955146 │ 0.0         │
# │ 14  │ 17620            │ -0.117384  │ -0.137156   │
# │ 15  │ 18545            │ 0.228318   │ 0.227414    │
# │ 16  │ 18818            │ -0.267718  │ -0.25803    │
# │ 17  │ 19426            │ 0.322496   │ 0.325107    │
# Total iteration number was 15
# Total time was 15.442013025283813
# compare_model = 18×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 577              │ -0.282649 │ -0.30036    │
# │ 2   │ 1450             │ 0.294111  │ 0.306319    │
# │ 3   │ 1698             │ 0.550302  │ 0.553472    │
# │ 4   │ 5026             │ -0.117964 │ 0.0         │
# │ 5   │ 6085             │ -0.20619  │ -0.186986   │
# │ 6   │ 6571             │ 0.307487  │ 0.299779    │
# │ 7   │ 6844             │ -0.359285 │ -0.380181   │
# │ 8   │ 7867             │ -0.46047  │ -0.456586   │
# │ 9   │ 8394             │ -0.164666 │ -0.157286   │
# │ 10  │ 8890             │ 0.290437  │ 0.30401     │
# │ 11  │ 9058             │ 0.209821  │ 0.206857    │
# │ 12  │ 9254             │ -0.407114 │ -0.397446   │
# │ 13  │ 9760             │ 0.341367  │ 0.350395    │
# │ 14  │ 12715            │ 0.0760053 │ 0.0786701   │
# │ 15  │ 13216            │ -0.577941 │ -0.565214   │
# │ 16  │ 14857            │ 0.323995  │ 0.335869    │
# │ 17  │ 15638            │ -0.294954 │ -0.303933   │
# │ 18  │ 16668            │ -0.281422 │ -0.30499    │
# Total iteration number was 37
# Total time was 16.492121934890747
# compare_model = 19×3 DataFrame
# │ Row │ correct_position │ true_β     │ estimated_β │
# │     │ Int64            │ Float64    │ Float64     │
# ├─────┼──────────────────┼────────────┼─────────────┤
# │ 1   │ 1162             │ -0.163277  │ 0.0         │
# │ 2   │ 3416             │ 0.346106   │ 0.323925    │
# │ 3   │ 5178             │ 0.369223   │ 0.340248    │
# │ 4   │ 5566             │ -0.460975  │ -0.458357   │
# │ 5   │ 5798             │ -0.468493  │ -0.468959   │
# │ 6   │ 5908             │ 0.413301   │ 0.426356    │
# │ 7   │ 6897             │ -0.0619296 │ 0.0         │
# │ 8   │ 7068             │ 0.160586   │ 0.169971    │
# │ 9   │ 7970             │ 0.229721   │ 0.235032    │
# │ 10  │ 8006             │ -0.419202  │ -0.417284   │
# │ 11  │ 10025            │ -0.0666965 │ 0.0         │
# │ 12  │ 10075            │ 0.54272    │ 0.534691    │
# │ 13  │ 10520            │ -0.1752    │ 0.0         │
# │ 14  │ 11004            │ 0.464758   │ 0.454704    │
# │ 15  │ 11344            │ -0.261532  │ -0.246142   │
# │ 16  │ 13582            │ 0.343534   │ 0.33683     │
# │ 17  │ 15567            │ 0.364209   │ 0.339174    │
# │ 18  │ 16931            │ -0.0518164 │ 0.0         │
# │ 19  │ 19998            │ -0.305458  │ -0.270245   │
# Total iteration number was 139
# Total time was 38.1286301612854
# compare_model = 20×3 DataFrame
# │ Row │ correct_position │ true_β     │ estimated_β │
# │     │ Int64            │ Float64    │ Float64     │
# ├─────┼──────────────────┼────────────┼─────────────┤
# │ 1   │ 467              │ 0.349058   │ 0.342384    │
# │ 2   │ 3309             │ -0.0702903 │ 0.0         │
# │ 3   │ 3857             │ -0.119845  │ 0.0         │
# │ 4   │ 7094             │ -0.25632   │ -0.252214   │
# │ 5   │ 7514             │ 0.205315   │ 0.225558    │
# │ 6   │ 7797             │ -0.0560814 │ 0.0         │
# │ 7   │ 7963             │ -0.078046  │ 0.0         │
# │ 8   │ 9246             │ -0.475073  │ -0.493516   │
# │ 9   │ 10458            │ 0.322181   │ 0.338377    │
# │ 10  │ 10862            │ -0.107235  │ 0.0         │
# │ 11  │ 13047            │ 0.301636   │ 0.287842    │
# │ 12  │ 13323            │ -0.230498  │ -0.232792   │
# │ 13  │ 14058            │ 0.290856   │ 0.284361    │
# │ 14  │ 14304            │ 0.301004   │ 0.301097    │
# │ 15  │ 16273            │ 0.27036    │ 0.267697    │
# │ 16  │ 16567            │ 0.00306024 │ 0.0         │
# │ 17  │ 17775            │ -0.206685  │ -0.195396   │
# │ 18  │ 18726            │ -0.0300255 │ 0.0         │
# │ 19  │ 19073            │ 0.138785   │ 0.130616    │
# │ 20  │ 19804            │ -0.221658  │ -0.251163   │
# Total iteration number was 18
# Total time was 16.406529903411865
# compare_model = 21×3 DataFrame
# │ Row │ correct_position │ true_β     │ estimated_β │
# │     │ Int64            │ Float64    │ Float64     │
# ├─────┼──────────────────┼────────────┼─────────────┤
# │ 1   │ 1208             │ 0.208714   │ 0.216493    │
# │ 2   │ 4544             │ -0.100257  │ 0.0         │
# │ 3   │ 4977             │ 0.0293109  │ 0.0         │
# │ 4   │ 5180             │ 0.205709   │ 0.185342    │
# │ 5   │ 5683             │ 0.312847   │ 0.330427    │
# │ 6   │ 6418             │ -0.154858  │ -0.168368   │
# │ 7   │ 7206             │ -0.127109  │ -0.124394   │
# │ 8   │ 10178            │ -0.0660716 │ 0.0         │
# │ 9   │ 10642            │ -0.187934  │ -0.19448    │
# │ 10  │ 11108            │ -0.171197  │ -0.148832   │
# │ 11  │ 11778            │ 0.0196232  │ 0.0         │
# │ 12  │ 12415            │ -0.345341  │ -0.333807   │
# │ 13  │ 12942            │ 0.667716   │ 0.657221    │
# │ 14  │ 14216            │ -0.595393  │ -0.583527   │
# │ 15  │ 14640            │ 0.0355746  │ 0.0         │
# │ 16  │ 15281            │ 0.0601718  │ 0.0         │
# │ 17  │ 16752            │ 0.107047   │ 0.108714    │
# │ 18  │ 17120            │ 0.0486042  │ 0.0         │
# │ 19  │ 17283            │ 0.230315   │ 0.204554    │
# │ 20  │ 19273            │ -0.312386  │ -0.306591   │
# │ 21  │ 19470            │ -0.377827  │ -0.376887   │
# Total iteration number was 32
# Total time was 18.31134796142578
# compare_model = 22×3 DataFrame
# │ Row │ correct_position │ true_β      │ estimated_β │
# │     │ Int64            │ Float64     │ Float64     │
# ├─────┼──────────────────┼─────────────┼─────────────┤
# │ 1   │ 783              │ -0.00321413 │ 0.0         │
# │ 2   │ 959              │ 0.0620032   │ 0.0         │
# │ 3   │ 1119             │ -0.299744   │ -0.300392   │
# │ 4   │ 1634             │ 0.0857074   │ 0.10377     │
# │ 5   │ 3864             │ -0.375103   │ -0.37933    │
# │ 6   │ 4023             │ -0.521928   │ -0.513141   │
# │ 7   │ 5497             │ -0.082202   │ -0.0768259  │
# │ 8   │ 6636             │ 0.216758    │ 0.224786    │
# │ 9   │ 6937             │ 0.0538608   │ 0.0         │
# │ 10  │ 9628             │ -0.172755   │ -0.192393   │
# │ 11  │ 11457            │ 0.238467    │ 0.219656    │
# │ 12  │ 12569            │ 0.334664    │ 0.311332    │
# │ 13  │ 13087            │ -0.0582741  │ 0.0         │
# │ 14  │ 13357            │ -0.228979   │ -0.237863   │
# │ 15  │ 13695            │ -0.185466   │ -0.143836   │
# │ 16  │ 14059            │ -0.170571   │ -0.141953   │
# │ 17  │ 14987            │ -0.0216766  │ 0.0         │
# │ 18  │ 16251            │ -0.00278503 │ 0.0         │
# │ 19  │ 17203            │ 0.0105382   │ 0.0         │
# │ 20  │ 19394            │ 0.0598824   │ 0.0         │
# │ 21  │ 19507            │ 0.0060896   │ 0.0         │
# │ 22  │ 19995            │ 0.0637453   │ 0.0         │
# Total iteration number was 210
# Total time was 59.55594515800476
# compare_model = 23×3 DataFrame
# │ Row │ correct_position │ true_β      │ estimated_β │
# │     │ Int64            │ Float64     │ Float64     │
# ├─────┼──────────────────┼─────────────┼─────────────┤
# │ 1   │ 1089             │ -0.195566   │ -0.201588   │
# │ 2   │ 1609             │ 0.674209    │ 0.672229    │
# │ 3   │ 1634             │ 0.352236    │ 0.371517    │
# │ 4   │ 4511             │ 0.066423    │ 0.0         │
# │ 5   │ 5691             │ -0.01037    │ 0.0         │
# │ 6   │ 6394             │ -0.0759238  │ -0.0587957  │
# │ 7   │ 6502             │ 0.0271264   │ 0.0         │
# │ 8   │ 6701             │ 0.145579    │ 0.167272    │
# │ 9   │ 7863             │ -0.225375   │ -0.236814   │
# │ 10  │ 9126             │ -0.0597095  │ 0.0         │
# │ 11  │ 9659             │ -0.00225808 │ 0.0         │
# │ 12  │ 10322            │ 0.248697    │ 0.240911    │
# │ 13  │ 11264            │ -0.0975974  │ -0.12845    │
# │ 14  │ 11794            │ 0.125881    │ 0.162163    │
# │ 15  │ 12000            │ -0.112744   │ -0.112306   │
# │ 16  │ 12343            │ 0.416618    │ 0.428745    │
# │ 17  │ 14501            │ 0.198       │ 0.208235    │
# │ 18  │ 14789            │ -0.0739576  │ -0.0679177  │
# │ 19  │ 15570            │ -0.504864   │ -0.494347   │
# │ 20  │ 17444            │ -0.542459   │ -0.536165   │
# │ 21  │ 18468            │ -0.211994   │ -0.193181   │
# │ 22  │ 18887            │ 0.210053    │ 0.193529    │
# │ 23  │ 19952            │ -0.0815283  │ -0.099653   │
# Total iteration number was 128
# Total time was 36.09219193458557
# compare_model = 24×3 DataFrame
# │ Row │ correct_position │ true_β     │ estimated_β │
# │     │ Int64            │ Float64    │ Float64     │
# ├─────┼──────────────────┼────────────┼─────────────┤
# │ 1   │ 571              │ -0.17214   │ -0.168034   │
# │ 2   │ 1267             │ -0.19297   │ -0.208327   │
# │ 3   │ 2052             │ -0.27387   │ -0.270444   │
# │ 4   │ 2562             │ -0.126769  │ -0.117039   │
# │ 5   │ 2883             │ 0.0263218  │ 0.0         │
# │ 6   │ 2899             │ 0.0652015  │ 0.0         │
# │ 7   │ 3904             │ -0.192662  │ -0.18522    │
# │ 8   │ 3943             │ 0.246813   │ 0.0         │
# │ 9   │ 4654             │ 0.380902   │ 0.360312    │
# │ 10  │ 5257             │ -0.358345  │ -0.397186   │
# │ 11  │ 5875             │ 0.0157358  │ 0.0         │
# │ 12  │ 7474             │ -0.122422  │ -0.118244   │
# │ 13  │ 8811             │ -0.266906  │ -0.271281   │
# │ 14  │ 10615            │ -0.0527952 │ 0.0         │
# │ 15  │ 11352            │ 0.0187955  │ 0.0         │
# │ 16  │ 13926            │ -0.0147123 │ 0.0         │
# │ 17  │ 15590            │ -0.0346897 │ 0.0         │
# │ 18  │ 15807            │ 0.293329   │ 0.281902    │
# │ 19  │ 17279            │ 0.314726   │ 0.30539     │
# │ 20  │ 17874            │ -0.245664  │ -0.265629   │
# │ 21  │ 18372            │ 0.0773752  │ 0.0         │
# │ 22  │ 19530            │ 0.299608   │ 0.304198    │
# │ 23  │ 19691            │ -0.393099  │ -0.417859   │
# │ 24  │ 19809            │ 0.0831796  │ 0.0851145   │
# Total iteration number was 57
# Total time was 23.348795890808105
# compare_model = 25×3 DataFrame
# │ Row │ correct_position │ true_β     │ estimated_β │
# │     │ Int64            │ Float64    │ Float64     │
# ├─────┼──────────────────┼────────────┼─────────────┤
# │ 1   │ 1741             │ 0.135611   │ 0.0         │
# │ 2   │ 2169             │ -0.383838  │ -0.380142   │
# │ 3   │ 3599             │ 0.518621   │ 0.508329    │
# │ 4   │ 3629             │ -0.167301  │ -0.220504   │
# │ 5   │ 4160             │ -0.154663  │ -0.15829    │
# │ 6   │ 5865             │ -0.279115  │ 0.0         │
# │ 7   │ 6630             │ 0.108534   │ 0.0         │
# │ 8   │ 8378             │ 0.0871269  │ 0.115684    │
# │ 9   │ 8713             │ -0.523936  │ -0.533449   │
# │ 10  │ 9057             │ 0.448092   │ 0.408427    │
# │ 11  │ 11200            │ -0.351914  │ -0.38423    │
# │ 12  │ 11758            │ 0.315083   │ 0.299352    │
# │ 13  │ 13211            │ 0.280809   │ 0.288273    │
# │ 14  │ 13639            │ -0.160379  │ -0.15638    │
# │ 15  │ 13723            │ -0.0102694 │ 0.0         │
# │ 16  │ 15417            │ 0.242607   │ 0.236627    │
# │ 17  │ 15508            │ 0.324706   │ 0.343013    │
# │ 18  │ 16109            │ -0.219785  │ -0.239554   │
# │ 19  │ 16183            │ -0.100805  │ 0.0         │
# │ 20  │ 16702            │ -0.189672  │ 0.0         │
# │ 21  │ 16740            │ -0.209994  │ 0.0         │
# │ 22  │ 18369            │ 0.232218   │ 0.225453    │
# │ 23  │ 18408            │ 0.557716   │ 0.558747    │
# │ 24  │ 18598            │ -0.376105  │ -0.378541   │
# │ 25  │ 19154            │ 0.0609496  │ 0.0         │
# Total iteration number was 21
# Total time was 12.788964986801147
# compare_model = 26×3 DataFrame
# │ Row │ correct_position │ true_β     │ estimated_β │
# │     │ Int64            │ Float64    │ Float64     │
# ├─────┼──────────────────┼────────────┼─────────────┤
# │ 1   │ 2                │ 0.0820794  │ 0.0         │
# │ 2   │ 585              │ 0.328218   │ 0.33302     │
# │ 3   │ 1322             │ -0.178809  │ -0.157588   │
# │ 4   │ 3680             │ 0.0303164  │ 0.0         │
# │ 5   │ 3686             │ -0.0214966 │ 0.0         │
# │ 6   │ 3809             │ -0.109891  │ -0.0940382  │
# │ 7   │ 4243             │ 0.111965   │ 0.125205    │
# │ 8   │ 5879             │ 0.22939    │ 0.225956    │
# │ 9   │ 6123             │ -0.15277   │ -0.155309   │
# │ 10  │ 6744             │ 0.435564   │ 0.427002    │
# │ 11  │ 6813             │ -0.250099  │ -0.272061   │
# │ 12  │ 7612             │ -0.523749  │ -0.527195   │
# │ 13  │ 8593             │ 0.0166052  │ 0.0         │
# │ 14  │ 8727             │ -0.0251083 │ 0.0         │
# │ 15  │ 9334             │ -0.357843  │ -0.355559   │
# │ 16  │ 10033            │ 0.0871137  │ 0.0892325   │
# │ 17  │ 10337            │ -0.0523524 │ 0.0         │
# │ 18  │ 10713            │ 0.157415   │ 0.168897    │
# │ 19  │ 12310            │ 0.234196   │ 0.239745    │
# │ 20  │ 12799            │ 0.130604   │ 0.134635    │
# │ 21  │ 13434            │ -0.124941  │ 0.0         │
# │ 22  │ 13786            │ -0.071462  │ 0.0         │
# │ 23  │ 14274            │ 0.0946927  │ 0.0713782   │
# │ 24  │ 15339            │ 0.108227   │ 0.0         │
# │ 25  │ 18395            │ 0.288496   │ 0.297507    │
# │ 26  │ 19454            │ -0.148598  │ -0.161105   │
# Total iteration number was 77
# Total time was 27.685517072677612
# compare_model = 27×3 DataFrame
# │ Row │ correct_position │ true_β      │ estimated_β │
# │     │ Int64            │ Float64     │ Float64     │
# ├─────┼──────────────────┼─────────────┼─────────────┤
# │ 1   │ 1033             │ 0.164225    │ 0.1489      │
# │ 2   │ 1370             │ 0.0917442   │ 0.0         │
# │ 3   │ 2638             │ -0.233358   │ -0.198562   │
# │ 4   │ 2987             │ 0.383148    │ 0.373685    │
# │ 5   │ 4123             │ -0.137451   │ -0.15034    │
# │ 6   │ 4411             │ -0.0440859  │ 0.0         │
# │ 7   │ 4922             │ 0.0318388   │ 0.0         │
# │ 8   │ 6534             │ -0.540415   │ -0.525453   │
# │ 9   │ 8338             │ -0.104897   │ -0.100183   │
# │ 10  │ 9798             │ 0.551365    │ 0.52106     │
# │ 11  │ 10107            │ -0.611002   │ -0.634937   │
# │ 12  │ 10242            │ 0.22044     │ 0.199755    │
# │ 13  │ 10378            │ 0.100119    │ 0.0850566   │
# │ 14  │ 10470            │ 0.000786545 │ 0.0         │
# │ 15  │ 10520            │ -0.759547   │ -0.73902    │
# │ 16  │ 11450            │ -0.215281   │ -0.218898   │
# │ 17  │ 12111            │ -0.245072   │ -0.233791   │
# │ 18  │ 13661            │ -0.0627635  │ 0.0         │
# │ 19  │ 14019            │ 0.321036    │ 0.320025    │
# │ 20  │ 15254            │ 0.0143268   │ 0.0         │
# │ 21  │ 15886            │ 0.122316    │ 0.133516    │
# │ 22  │ 16874            │ 0.136214    │ 0.125754    │
# │ 23  │ 17208            │ 0.198406    │ 0.18519     │
# │ 24  │ 17474            │ 0.195294    │ 0.188793    │
# │ 25  │ 18850            │ -0.0394294  │ 0.0         │
# │ 26  │ 19311            │ 0.0494082   │ 0.0         │
# │ 27  │ 19644            │ -0.0638894  │ 0.0         │
# Total iteration number was 30
# Total time was 18.3036208152771
# compare_model = 28×3 DataFrame
# │ Row │ correct_position │ true_β      │ estimated_β │
# │     │ Int64            │ Float64     │ Float64     │
# ├─────┼──────────────────┼─────────────┼─────────────┤
# │ 1   │ 166              │ -0.035892   │ 0.0         │
# │ 2   │ 437              │ 0.323284    │ 0.327798    │
# │ 3   │ 1946             │ -0.166938   │ -0.156705   │
# │ 4   │ 3335             │ -0.0397684  │ 0.0         │
# │ 5   │ 4228             │ -0.00769037 │ 0.0         │
# │ 6   │ 6071             │ -0.694623   │ -0.634781   │
# │ 7   │ 6322             │ 0.00707797  │ 0.0         │
# │ 8   │ 6332             │ 0.120137    │ 0.143591    │
# │ 9   │ 7243             │ -0.321206   │ -0.313362   │
# │ 10  │ 7409             │ 0.18182     │ 0.168034    │
# │ 11  │ 9891             │ -0.368808   │ -0.528281   │
# │ 12  │ 9954             │ -0.171644   │ -0.170419   │
# │ 13  │ 10196            │ 0.155812    │ 0.129657    │
# │ 14  │ 11080            │ -0.0524415  │ 0.0         │
# │ 15  │ 11823            │ -0.0184926  │ 0.0         │
# │ 16  │ 12145            │ 0.354832    │ 0.364985    │
# │ 17  │ 12465            │ -0.107862   │ 0.0         │
# │ 18  │ 12530            │ -0.313998   │ -0.313579   │
# │ 19  │ 12601            │ 0.0319778   │ 0.0         │
# │ 20  │ 13051            │ 0.270711    │ 0.259474    │
# │ 21  │ 15803            │ -0.169788   │ -0.201577   │
# │ 22  │ 17514            │ 0.254605    │ 0.258248    │
# │ 23  │ 18148            │ 0.170194    │ 0.162339    │
# │ 24  │ 18484            │ 0.190969    │ 0.212325    │
# │ 25  │ 18533            │ -0.546146   │ -0.511046   │
# │ 26  │ 19649            │ 0.0174481   │ 0.0         │
# │ 27  │ 19690            │ 0.0238545   │ 0.0         │
# │ 28  │ 19799            │ -0.279472   │ -0.288128   │
# Total iteration number was 37
# Total time was 19.373018980026245
# compare_model = 29×3 DataFrame
# │ Row │ correct_position │ true_β      │ estimated_β │
# │     │ Int64            │ Float64     │ Float64     │
# ├─────┼──────────────────┼─────────────┼─────────────┤
# │ 1   │ 736              │ 0.244212    │ 0.238821    │
# │ 2   │ 910              │ -0.689839   │ -0.687573   │
# │ 3   │ 1087             │ 0.293749    │ 0.286529    │
# │ 4   │ 2153             │ 0.337159    │ 0.326893    │
# │ 5   │ 3159             │ -0.101239   │ 0.0         │
# │ 6   │ 3351             │ -0.385811   │ -0.385869   │
# │ 7   │ 3510             │ -0.0832147  │ -0.0665126  │
# │ 8   │ 5673             │ 0.0810603   │ 0.088958    │
# │ 9   │ 6397             │ 0.0917574   │ 0.102238    │
# │ 10  │ 6587             │ 0.232192    │ 0.216291    │
# │ 11  │ 6614             │ 0.307864    │ 0.303034    │
# │ 12  │ 9938             │ 0.196219    │ 0.18617     │
# │ 13  │ 10178            │ -0.114101   │ 0.0         │
# │ 14  │ 10414            │ 0.277472    │ 0.2716      │
# │ 15  │ 10912            │ -0.0303595  │ 0.0         │
# │ 16  │ 11909            │ -0.3863     │ -0.363172   │
# │ 17  │ 12407            │ -0.0919432  │ -0.0805809  │
# │ 18  │ 12701            │ -0.164515   │ -0.164646   │
# │ 19  │ 13496            │ -0.10397    │ 0.0         │
# │ 20  │ 13708            │ 0.2373      │ 0.251528    │
# │ 21  │ 14315            │ 0.112247    │ 0.103492    │
# │ 22  │ 14516            │ 0.762633    │ 0.744264    │
# │ 23  │ 14792            │ -0.380408   │ -0.361142   │
# │ 24  │ 17171            │ -0.00456312 │ 0.0         │
# │ 25  │ 17247            │ -0.171624   │ -0.185903   │
# │ 26  │ 17318            │ -0.147472   │ -0.151291   │
# │ 27  │ 17708            │ -0.00831558 │ 0.0         │
# │ 28  │ 19018            │ 0.108407    │ 0.0         │
# │ 29  │ 19462            │ 0.233161    │ 0.259876    │
# Total iteration number was 51
# Total time was 19.255131006240845
# compare_model = 30×3 DataFrame
# │ Row │ correct_position │ true_β     │ estimated_β │
# │     │ Int64            │ Float64    │ Float64     │
# ├─────┼──────────────────┼────────────┼─────────────┤
# │ 1   │ 1573             │ -0.258586  │ -0.280688   │
# │ 2   │ 2293             │ 0.128948   │ 0.125133    │
# │ 3   │ 2772             │ 0.199817   │ 0.197498    │
# │ 4   │ 3072             │ -0.132755  │ 0.0         │
# │ 5   │ 3486             │ 0.128234   │ 0.159097    │
# │ 6   │ 3676             │ -0.302025  │ -0.276099   │
# │ 7   │ 4349             │ -0.203906  │ -0.207243   │
# │ 8   │ 4786             │ -0.279046  │ -0.247477   │
# │ 9   │ 5567             │ 0.125092   │ 0.0         │
# │ 10  │ 8110             │ 0.261097   │ 0.264937    │
# │ 11  │ 8140             │ 0.0762149  │ 0.0         │
# │ 12  │ 8973             │ 0.266975   │ 0.278856    │
# │ 13  │ 9909             │ -0.0710088 │ 0.0         │
# │ 14  │ 10495            │ 0.194104   │ 0.190741    │
# │ 15  │ 11713            │ 0.20794    │ 0.215777    │
# │ 16  │ 11965            │ -0.165547  │ 0.0         │
# │ 17  │ 12809            │ 0.591656   │ 0.588499    │
# │ 18  │ 15222            │ 0.0227158  │ 0.0         │
# │ 19  │ 15387            │ 0.106419   │ 0.0         │
# │ 20  │ 15651            │ -0.398469  │ -0.38528    │
# │ 21  │ 16022            │ 0.0928532  │ 0.0         │
# │ 22  │ 16053            │ 0.256806   │ 0.251161    │
# │ 23  │ 16661            │ -0.406452  │ -0.411445   │
# │ 24  │ 17270            │ -0.354371  │ -0.380499   │
# │ 25  │ 17273            │ -0.122347  │ 0.0         │
# │ 26  │ 17920            │ 0.135373   │ 0.0         │
# │ 27  │ 18420            │ 0.18532    │ 0.204189    │
# │ 28  │ 19845            │ 0.0205379  │ 0.0         │
# │ 29  │ 19922            │ -0.0724886 │ 0.0         │
# │ 30  │ 19932            │ 0.223286   │ 0.234552    │
# Total iteration number was 35
# Total time was 19.199124813079834

# %% [markdown]
# # Comparison with LASSO: cross validation

# %%
using Revise
using GLMNet #julia wrapper for GLMNet package in R, which calls fortran
using GLM
using MendelIHT
using SnpArrays
using DataFrames
using Distributions
using StatsFuns: logistic
using Random
using LinearAlgebra
using DelimitedFiles
# Out:
# ┌ Info: Loading DataFrames support into Gadfly.jl
# └ @ Gadfly /Users/biona001/.julia/packages/Gadfly/09PWZ/src/mapping.jl:228

# %%
Threads.nthreads() #verify multiple threads are enabled
# Out:
# 8

# %%
function iht_lasso_poisson(n :: Int64, p :: Int64, sim :: Int64)
    #define maf and true model size
    k = 10
    
    #set random seed
    Random.seed!(1111)

    #construct snpmatrix, covariate files, and true model b
    x, maf = simulate_random_snparray(n, p)
    xbm = SnpBitMatrix{Float64}(x, model=ADDITIVE_MODEL, center=true, scale=true); 
    z           = ones(n, 1)                   # non-genetic covariates, just the intercept
    true_b      = zeros(p)                     # model vector
    true_b[1:k] = rand(Normal(0, 0.25), k)     # k true response
    shuffle!(true_b)                           # Shuffle the entries
    correct_position = findall(x -> x != 0, true_b) # keep track of what the true entries are

    # Simulate poisson data
    y_temp = xbm * true_b
    λ = exp.(y_temp) #inverse log link
    y = [rand(Poisson(x)) for x in λ]
    y = Float64.(y)

    #compute poisson IHT result
    path = collect(1:15)
    num_folds = 5
    folds = rand(1:num_folds, size(x, 1))
    k_est_iht = cv_iht(x, z, y, 1, path, folds, num_folds, use_maf=false, glm="poisson", debias=false)
    iht_result = L0_poisson_reg(x, z, y, 1, k_est_iht, glm = "poisson", debias=false, convg=false, show_info=false, true_beta=true_b, init=false)

    #compute poisson lasso result
    x_float = [convert(Matrix{Float64}, x, center=true, scale=true) z]
    cv = glmnetcv(x_float, y, Poisson(), dfmax=15, nfolds=5, folds=folds)
    best = argmin(cv.meanloss)
    lasso_result = cv.path.betas[:, best]
    k_est_lasso = length(findall(!iszero, lasso_result))
    
    #compute regular poisson regression using only true predictors
    x_true = [x_float[:, correct_position] z]
    regular_result = glm(x_true, y, Poisson(), LogLink())
    regular_result = regular_result.pp.beta0
    
    #check result
    IHT_model = iht_result.beta[correct_position]
    lasso_model = lasso_result[correct_position]
    true_model = true_b[correct_position]
    compare_model = DataFrame(
        true_β  = true_model, 
        iht_β   = IHT_model,
        lasso_β = lasso_model,
        regular_β = regular_result[1:10])
    @show compare_model

    #compute summary statistics
    lasso_num_correct_predictors = length(findall(!iszero, lasso_model))
    lasso_false_positives = k_est_lasso - lasso_num_correct_predictors
    lasso_false_negatives = k - lasso_num_correct_predictors
    iht_num_correct_predictors = length(findall(!iszero, IHT_model))
    iht_false_positives = k_est_iht - iht_num_correct_predictors
    iht_false_negatives = k - iht_num_correct_predictors
    println("IHT cv found $iht_false_positives" * " false positives and $iht_false_negatives" * " false negatives")
    println("lasso cv found $lasso_false_positives" * " false positives and $lasso_false_negatives" * " false negatives\n\n")

    #write y to file to view distribution later
    writedlm("./IHT_poisson_simulations_mean/data_simulation_$sim.txt", y)

    return lasso_num_correct_predictors, lasso_false_positives, lasso_false_negatives, iht_num_correct_predictors, iht_false_positives, iht_false_negatives
end
# Out:
# iht_lasso_poisson (generic function with 1 method)

# %%
function run_iht_lasso_poisson()
    lasso_total_found = 0
    lasso_false_positives = 0
    lasso_false_negatives = 0
    iht_total_found = 0
    iht_false_positives = 0
    iht_false_negatives = 0
    
    iter = 10
    for i = 1:iter
        n = rand(500:1000) 
        p = rand(1:10)n
        println("Running the $i th model where " * "n, p = " * string(n) * ", " * string(p))
        ltf, lfp, lfn, itf, ifp, ifn = iht_lasso_poisson(n, p, i)

        lasso_total_found += ltf
        lasso_false_positives += lfp
        lasso_false_negatives += lfn
        iht_total_found += itf
        iht_false_positives += ifp
        iht_false_negatives += ifn
    end
    println("IHT  : Found $iht_total_found " * "correct predictors, out of " * string(10iter))
    println("IHT  : False positives = $iht_false_positives")
    println("IHT  : False negatives = $iht_false_negatives")   
    println("Lasso: Found $lasso_total_found " * "correct predictors, out of " * string(10iter))
    println("Lasso: False positives = $lasso_false_positives")
    println("Lasso: False negatives = $lasso_false_negatives")
end
# Out:
# run_iht_lasso_poisson (generic function with 1 method)

# %%
Random.seed!(2019)
run_iht_lasso_poisson()
# Out:
# Running the 1 th model where n, p = 601, 3005
# compare_model = 10×4 DataFrame
# │ Row │ true_β     │ iht_β     │ lasso_β    │ regular_β │
# │     │ Float64    │ Float64   │ Float64    │ Float64   │
# ├─────┼────────────┼───────────┼────────────┼───────────┤
# │ 1   │ -0.19935   │ 0.0       │ -0.0529655 │ -0.171662 │
# │ 2   │ 0.18049    │ 0.0       │ 0.105772   │ 0.167837  │
# │ 3   │ 0.524747   │ 0.591968  │ 0.512252   │ 0.582238  │
# │ 4   │ 0.292468   │ 0.340894  │ 0.252993   │ 0.312079  │
# │ 5   │ 0.429149   │ 0.460376  │ 0.359645   │ 0.451225  │
# │ 6   │ -0.22333   │ 0.0       │ -0.0916251 │ -0.240026 │
# │ 7   │ -0.367907  │ -0.360886 │ -0.240433  │ -0.374834 │
# │ 8   │ -0.0342718 │ 0.0       │ 0.0        │ 0.0374873 │
# │ 9   │ 0.0696975  │ 0.0       │ 0.0        │ 0.076362  │
# │ 10  │ -0.142232  │ 0.0       │ -0.0378819 │ -0.145426 │
# IHT cv   found 4predictors, with 0 false positives and 6 false negatives
# lasso cv found 16predictors, with 8 false positives and 2 false negatives
# Running the 2 th model where n, p = 895, 6265
# compare_model = 10×4 DataFrame
# │ Row │ true_β     │ iht_β    │ lasso_β    │ regular_β  │
# │     │ Float64    │ Float64  │ Float64    │ Float64    │
# ├─────┼────────────┼──────────┼────────────┼────────────┤
# │ 1   │ 0.32077    │ 0.282387 │ 0.176125   │ 0.278268   │
# │ 2   │ -0.314712  │ 0.0      │ -0.12966   │ -0.348582  │
# │ 3   │ -0.128871  │ 0.0      │ 0.0        │ -0.14721   │
# │ 4   │ -0.209794  │ -0.24344 │ -0.125339  │ -0.244717  │
# │ 5   │ 0.103625   │ 0.0      │ 0.0118509  │ 0.129377   │
# │ 6   │ 0.329615   │ 0.378569 │ 0.259376   │ 0.358901   │
# │ 7   │ -0.193473  │ 0.0      │ -0.0702193 │ -0.201657  │
# │ 8   │ 0.116365   │ 0.0      │ 0.0192602  │ 0.117855   │
# │ 9   │ 0.0630766  │ 0.0      │ 0.0        │ 0.0999933  │
# │ 10  │ -0.0314619 │ 0.0      │ 0.0        │ -0.0474841 │
# IHT cv   found 3predictors, with 0 false positives and 7 false negatives
# lasso cv found 20predictors, with 13 false positives and 3 false negatives
# Running the 3 th model where n, p = 502, 1004
# compare_model = 10×4 DataFrame
# │ Row │ true_β     │ iht_β     │ lasso_β   │ regular_β  │
# │     │ Float64    │ Float64   │ Float64   │ Float64    │
# ├─────┼────────────┼───────────┼───────────┼────────────┤
# │ 1   │ 0.0922453  │ 0.0       │ 0.0201051 │ 0.118772   │
# │ 2   │ 0.0842563  │ 0.0       │ 0.0       │ 0.065867   │
# │ 3   │ 0.378245   │ 0.362436  │ 0.237671  │ 0.366176   │
# │ 4   │ -0.292068  │ -0.242346 │ -0.124037 │ -0.254202  │
# │ 5   │ -0.329856  │ -0.396376 │ -0.280383 │ -0.41099   │
# │ 6   │ -0.412172  │ -0.437596 │ -0.236084 │ -0.44776   │
# │ 7   │ -0.0993468 │ 0.0       │ 0.0       │ -0.0923523 │
# │ 8   │ 0.0332345  │ 0.0       │ 0.0       │ 0.0513461  │
# │ 9   │ 0.104396   │ 0.134964  │ 0.0110719 │ 0.125968   │
# │ 10  │ 0.222711   │ 0.288661  │ 0.189699  │ 0.305126   │
# IHT cv   found 6predictors, with 0 false positives and 4 false negatives
# lasso cv found 18predictors, with 11 false positives and 3 false negatives
# Running the 4 th model where n, p = 701, 3505
# compare_model = 10×4 DataFrame
# │ Row │ true_β     │ iht_β     │ lasso_β    │ regular_β  │
# │     │ Float64    │ Float64   │ Float64    │ Float64    │
# ├─────┼────────────┼───────────┼────────────┼────────────┤
# │ 1   │ -0.083415  │ 0.0       │ 0.0        │ -0.070123  │
# │ 2   │ -0.1799    │ 0.0       │ -0.0324837 │ -0.174827  │
# │ 3   │ 0.274451   │ 0.340549  │ 0.245256   │ 0.328857   │
# │ 4   │ -0.256658  │ -0.342253 │ -0.157908  │ -0.334356  │
# │ 5   │ 0.256233   │ 0.231126  │ 0.178616   │ 0.237771   │
# │ 6   │ -0.292176  │ -0.383653 │ -0.248522  │ -0.36383   │
# │ 7   │ -0.0310549 │ 0.0       │ 0.0        │ -0.0610635 │
# │ 8   │ -0.205247  │ 0.0       │ -0.0822405 │ -0.258957  │
# │ 9   │ 0.0586747  │ 0.0       │ 0.0        │ 0.0276079  │
# │ 10  │ -0.17277   │ 0.0       │ -0.0349735 │ -0.166105  │
# IHT cv   found 4predictors, with 0 false positives and 6 false negatives
# lasso cv found 17predictors, with 10 false positives and 3 false negatives
# Running the 5 th model where n, p = 694, 1388
# compare_model = 10×4 DataFrame
# │ Row │ true_β      │ iht_β     │ lasso_β     │ regular_β  │
# │     │ Float64     │ Float64   │ Float64     │ Float64    │
# ├─────┼─────────────┼───────────┼─────────────┼────────────┤
# │ 1   │ 0.238942    │ 0.243121  │ 0.133753    │ 0.251239   │
# │ 2   │ 0.378592    │ 0.356073  │ 0.273342    │ 0.361557   │
# │ 3   │ 0.697868    │ 0.676946  │ 0.602228    │ 0.702117   │
# │ 4   │ -0.260869   │ -0.278714 │ -0.132204   │ -0.286915  │
# │ 5   │ 0.258679    │ 0.220267  │ 0.109249    │ 0.230427   │
# │ 6   │ -0.22479    │ -0.21065  │ -0.0841132  │ -0.226723  │
# │ 7   │ -0.00110442 │ 0.0       │ 0.0         │ -0.0435739 │
# │ 8   │ -0.0188487  │ 0.0       │ 0.0         │ 0.00769947 │
# │ 9   │ -0.292298   │ -0.321408 │ -0.202825   │ -0.33355   │
# │ 10  │ 0.109346    │ 0.0842612 │ 0.000649967 │ 0.0931426  │
# IHT cv   found 9predictors, with 1 false positives and 2 false negatives
# lasso cv found 18predictors, with 10 false positives and 2 false negatives
# Running the 6 th model where n, p = 506, 5060
# compare_model = 10×4 DataFrame
# │ Row │ true_β     │ iht_β    │ lasso_β   │ regular_β   │
# │     │ Float64    │ Float64  │ Float64   │ Float64     │
# ├─────┼────────────┼──────────┼───────────┼─────────────┤
# │ 1   │ 0.10125    │ 0.0      │ 0.0       │ 0.0976463   │
# │ 2   │ 0.0170957  │ 0.0      │ 0.0       │ -0.0150193  │
# │ 3   │ 0.247686   │ 0.318568 │ 0.209989  │ 0.267622    │
# │ 4   │ 0.506443   │ 0.582721 │ 0.468865  │ 0.547112    │
# │ 5   │ 0.364478   │ 0.44885  │ 0.372112  │ 0.411915    │
# │ 6   │ -0.28323   │ 0.0      │ -0.106317 │ -0.257379   │
# │ 7   │ -0.0552525 │ 0.0      │ 0.0       │ -0.0376917  │
# │ 8   │ -0.0855862 │ 0.0      │ 0.0       │ -0.00263972 │
# │ 9   │ 0.0749117  │ 0.0      │ 0.0       │ 0.0846423   │
# │ 10  │ 0.171301   │ 0.0      │ 0.075213  │ 0.119374    │
# IHT cv   found 3predictors, with 0 false positives and 7 false negatives
# lasso cv found 17predictors, with 12 false positives and 5 false negatives
# Running the 7 th model where n, p = 726, 3630
# compare_model = 10×4 DataFrame
# │ Row │ true_β     │ iht_β     │ lasso_β    │ regular_β  │
# │     │ Float64    │ Float64   │ Float64    │ Float64    │
# ├─────┼────────────┼───────────┼────────────┼────────────┤
# │ 1   │ -0.0205577 │ 0.0       │ 0.0        │ -0.0235595 │
# │ 2   │ 0.320257   │ 0.290412  │ 0.239359   │ 0.310406   │
# │ 3   │ -0.0220066 │ 0.0       │ 0.0        │ 0.0144784  │
# │ 4   │ 0.145989   │ 0.0       │ 0.00880438 │ 0.109961   │
# │ 5   │ 0.0641469  │ 0.0       │ 0.0        │ 0.0368637  │
# │ 6   │ 0.108482   │ 0.0       │ 0.0662215  │ 0.134904   │
# │ 7   │ 0.1915     │ 0.196472  │ 0.0982789  │ 0.180275   │
# │ 8   │ 0.128497   │ 0.138493  │ 0.0717538  │ 0.163715   │
# │ 9   │ -0.0144837 │ 0.0       │ 0.0        │ -0.0624628 │
# │ 10  │ -0.55871   │ -0.555644 │ -0.44462   │ -0.589712  │
# IHT cv   found 7predictors, with 3 false positives and 6 false negatives
# lasso cv found 17predictors, with 11 false positives and 4 false negatives
# Running the 8 th model where n, p = 837, 7533
# compare_model = 10×4 DataFrame
# │ Row │ true_β      │ iht_β     │ lasso_β    │ regular_β    │
# │     │ Float64     │ Float64   │ Float64    │ Float64      │
# ├─────┼─────────────┼───────────┼────────────┼──────────────┤
# │ 1   │ 0.0330785   │ 0.0       │ 0.00967589 │ 0.124442     │
# │ 2   │ -0.0230506  │ 0.0       │ 0.0        │ -0.0542897   │
# │ 3   │ -0.0645446  │ 0.0       │ 0.0        │ -0.0262314   │
# │ 4   │ -0.207034   │ -0.195298 │ -0.0798026 │ -0.202142    │
# │ 5   │ -0.280693   │ -0.243222 │ -0.131753  │ -0.249567    │
# │ 6   │ 0.264254    │ 0.296349  │ 0.205163   │ 0.293384     │
# │ 7   │ -0.00415908 │ 0.0       │ 0.0        │ -0.000507169 │
# │ 8   │ 0.0643845   │ 0.0       │ 0.0        │ 0.0626744    │
# │ 9   │ 0.141258    │ 0.140374  │ 0.025821   │ 0.130527     │
# │ 10  │ -0.161842   │ 0.0       │ -0.0376191 │ -0.16206     │
# IHT cv   found 5predictors, with 1 false positives and 6 false negatives
# lasso cv found 17predictors, with 11 false positives and 4 false negatives
# Running the 9 th model where n, p = 722, 4332
# compare_model = 10×4 DataFrame
# │ Row │ true_β    │ iht_β     │ lasso_β    │ regular_β │
# │     │ Float64   │ Float64   │ Float64    │ Float64   │
# ├─────┼───────────┼───────────┼────────────┼───────────┤
# │ 1   │ 0.33493   │ 0.330726  │ 0.335829   │ 0.349799  │
# │ 2   │ -0.416951 │ -0.312977 │ -0.219334  │ -0.35102  │
# │ 3   │ 0.230345  │ 0.212168  │ 0.119306   │ 0.236309  │
# │ 4   │ 0.0446928 │ 0.0       │ 0.0        │ 0.0190675 │
# │ 5   │ -0.140229 │ -0.124341 │ -0.0479367 │ -0.148545 │
# │ 6   │ -0.205987 │ -0.258528 │ -0.164761  │ -0.293439 │
# │ 7   │ 0.456827  │ 0.415338  │ 0.346056   │ 0.436162  │
# │ 8   │ 0.0755214 │ 0.0       │ 0.0        │ 0.086532  │
# │ 9   │ 0.0733232 │ 0.0       │ 0.0        │ 0.0860705 │
# │ 10  │ -0.075088 │ 0.0       │ 0.0        │ -0.055189 │
# IHT cv   found 14predictors, with 8 false positives and 4 false negatives
# lasso cv found 17predictors, with 11 false positives and 4 false negatives
# Running the 10 th model where n, p = 866, 5196
# compare_model = 10×4 DataFrame
# │ Row │ true_β     │ iht_β     │ lasso_β     │ regular_β  │
# │     │ Float64    │ Float64   │ Float64     │ Float64    │
# ├─────┼────────────┼───────────┼─────────────┼────────────┤
# │ 1   │ 0.168736   │ 0.0       │ 0.0         │ 0.111671   │
# │ 2   │ 0.164707   │ 0.0       │ 0.0386583   │ 0.146651   │
# │ 3   │ -0.380463  │ -0.327629 │ -0.201496   │ -0.320875  │
# │ 4   │ 0.167284   │ 0.0       │ 0.103094    │ 0.157707   │
# │ 5   │ 0.16768    │ 0.191911  │ 0.0989761   │ 0.19226    │
# │ 6   │ -0.0721828 │ 0.0       │ -0.00285476 │ -0.0983082 │
# │ 7   │ 0.0210215  │ 0.0       │ 0.0         │ -0.0121754 │
# │ 8   │ 0.160942   │ 0.0       │ 0.0822491   │ 0.189276   │
# │ 9   │ 0.319918   │ 0.264442  │ 0.206738    │ 0.286359   │
# │ 10  │ -0.0300136 │ 0.0       │ 0.0         │ -0.0859119 │
# IHT cv   found 6predictors, with 3 false positives and 7 false negatives
# lasso cv found 19predictors, with 12 false positives and 3 false negatives
# IHT  : Found 45 correct predictors, out of 100
# IHT  : False positives = 16
# IHT  : False negatives = 55
# Lasso: Found 67 correct predictors, out of 100
# Lasso: False positives = 109
# Lasso: False negatives = 33

# %%
#some function that runs poisson regression on different SNP matrices
function run_poisson(n :: Int64, p :: Int64)
    #set random seed
    Random.seed!(1111)

    #simulate data
    k = 10 # number of true predictors
    bernoulli_rates = 0.5rand(p) #minor allele frequencies are drawn from uniform (0, 0.5)
    x = simulate_random_snparray(n, p, bernoulli_rates)
    xbm = SnpBitMatrix{Float64}(x, model=ADDITIVE_MODEL, center=true, scale=true); 

    #construct snpmatrix, covariate files, and true model b
    z           = ones(n, 1)                   # non-genetic covariates, just the intercept
    true_b      = zeros(p)                     # model vector
    true_b[1:k] = 0.2randn(k)                     # Initialize k non-zero entries in the true model
    shuffle!(true_b)                           # Shuffle the entries
    correct_position = findall(x -> x != 0, true_b) # keep track of what the true entries are

    #check maf
    bernoulli_rates[correct_position]

    #simulate phenotypes under different noises by: y = Xb + noise
    y_temp = xbm * true_b

    # Simulate poisson data
    λ = exp.(y_temp) #inverse log link
    y = [rand(Poisson(x)) for x in λ]
    y = Float64.(y)

    #compute poisson IHT result
    result = L0_poisson_reg(x, z, y, 1, k, glm = "poisson", debias=false, convg=false, show_info=false)

    #check result
    estimated_models = result.beta[correct_position]
    true_model = true_b[correct_position]
    compare_model = DataFrame(
        correct_position = correct_position, 
        true_β           = true_model, 
        estimated_β      = estimated_models)
    
    #display results
    @show compare_model
    println("Total iteration number was " * string(result.iter))
    println("Total time was " * string(result.time))
    println("median of y = " * string(median(y)))
    println("maximum of y = " * string(maximum(y)))
    println("minimum of y = " * string(minimum(y)))
    println("skewness of y = " * string(skewness(y)))
    println("kurtosis of y = " * string(kurtosis(y)))
    println("mean of y = " * string(mean(y)))
    println("variance of y = " * string(var(y)))
    println("var / mean = " * string(var(y) / mean(y)) * "\n\n")
end
# Out:
# run_poisson (generic function with 1 method)

# %%
for i = 1:25
    n = rand(2000:5000) 
    p = rand(1:10)n
    println("Running the $i th model where " * "n, p = " * string(n) * ", " * string(p))
    run_poisson(n, p)
end
# Out:
# Running the 1 th model where n, p = 3047, 9141
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 996              │ -0.441003 │ -0.43984    │
# │ 2   │ 1847             │ -0.502956 │ -0.46739    │
# │ 3   │ 2935             │ 0.351857  │ 0.354962    │
# │ 4   │ 3016             │ -0.414902 │ -0.419244   │
# │ 5   │ 3379             │ 0.207074  │ 0.188294    │
# │ 6   │ 3577             │ 0.0125818 │ 0.0         │
# │ 7   │ 3984             │ 0.0480669 │ 0.0         │
# │ 8   │ 8060             │ 0.147444  │ 0.146366    │
# │ 9   │ 8211             │ 0.215924  │ 0.204016    │
# │ 10  │ 8999             │ -0.26669  │ -0.277494   │
# Total iteration number was 84
# Total time was 19.836469888687134
# median of y = 1.0
# maximum of y = 20.0
# minimum of y = 0.0
# skewness of y = 2.9606381620155013
# kurtosis of y = 15.91986963097509
# mean of y = 1.4972103708565803
# variance of y = 3.716259451133382
# var / mean = 2.482122434810043
#
#
# Running the 2 th model where n, p = 3713, 7426
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β      │ estimated_β │
# │     │ Int64            │ Float64     │ Float64     │
# ├─────┼──────────────────┼─────────────┼─────────────┤
# │ 1   │ 688              │ 0.120636    │ 0.10462     │
# │ 2   │ 2601             │ 0.0187394   │ 0.0         │
# │ 3   │ 2614             │ -0.10266    │ -0.111708   │
# │ 4   │ 3709             │ -0.369171   │ -0.34248    │
# │ 5   │ 4454             │ -0.162482   │ -0.167024   │
# │ 6   │ 5669             │ -0.00893067 │ 0.0         │
# │ 7   │ 5676             │ -0.0492203  │ 0.0         │
# │ 8   │ 5793             │ 0.172223    │ 0.189454    │
# │ 9   │ 7269             │ 0.339765    │ 0.360884    │
# │ 10  │ 7390             │ -0.0624767  │ -0.0792489  │
# Total iteration number was 14
# Total time was 7.501152038574219
# median of y = 1.0
# maximum of y = 9.0
# minimum of y = 0.0
# skewness of y = 1.3049589314613894
# kurtosis of y = 1.946416471252924
# mean of y = 1.1626716940479396
# variance of y = 1.6023023428865952
# var / mean = 1.3781210560893975
#
#
# Running the 3 th model where n, p = 3296, 32960
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β     │ estimated_β │
# │     │ Int64            │ Float64    │ Float64     │
# ├─────┼──────────────────┼────────────┼─────────────┤
# │ 1   │ 176              │ -0.354387  │ -0.361571   │
# │ 2   │ 7229             │ -0.362849  │ -0.379867   │
# │ 3   │ 16246            │ 0.00216519 │ 0.0         │
# │ 4   │ 18559            │ -0.265755  │ -0.2551     │
# │ 5   │ 20050            │ 0.0845607  │ 0.102911    │
# │ 6   │ 28053            │ -0.199164  │ -0.193195   │
# │ 7   │ 29184            │ 0.477157   │ 0.484482    │
# │ 8   │ 31709            │ 0.210072   │ 0.205697    │
# │ 9   │ 31950            │ -0.0761894 │ -0.0690298  │
# │ 10  │ 32867            │ -0.207939  │ -0.204883   │
# Total iteration number was 13
# Total time was 36.68658494949341
# median of y = 1.0
# maximum of y = 25.0
# minimum of y = 0.0
# skewness of y = 3.0927521111440757
# kurtosis of y = 19.908870653100482
# mean of y = 1.4192961165048543
# variance of y = 3.495154102273229
# var / mean = 2.462596819387038
#
#
# Running the 4 th model where n, p = 2341, 11705
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β     │ estimated_β │
# │     │ Int64            │ Float64    │ Float64     │
# ├─────┼──────────────────┼────────────┼─────────────┤
# │ 1   │ 662              │ -0.367204  │ -0.345948   │
# │ 2   │ 891              │ -0.286644  │ -0.276084   │
# │ 3   │ 936              │ 0.158829   │ 0.144322    │
# │ 4   │ 3082             │ -0.0881077 │ 0.0         │
# │ 5   │ 3697             │ -0.176099  │ -0.152906   │
# │ 6   │ 5073             │ 0.242477   │ 0.239445    │
# │ 7   │ 7207             │ -0.0403277 │ 0.0         │
# │ 8   │ 9770             │ 0.0787858  │ 0.0         │
# │ 9   │ 9855             │ -0.0330873 │ 0.0         │
# │ 10  │ 11193            │ 0.0223694  │ 0.0         │
# Total iteration number was 75
# Total time was 16.162285804748535
# median of y = 1.0
# maximum of y = 9.0
# minimum of y = 0.0
# skewness of y = 1.479697629506804
# kurtosis of y = 3.0164947941247746
# mean of y = 1.1614694574967963
# variance of y = 1.6636600619941075
# var / mean = 1.43237521336087
#
#
# Running the 5 th model where n, p = 2468, 12340
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β     │ estimated_β │
# │     │ Int64            │ Float64    │ Float64     │
# ├─────┼──────────────────┼────────────┼─────────────┤
# │ 1   │ 430              │ -0.287955  │ -0.311473   │
# │ 2   │ 4104             │ -0.286303  │ -0.316004   │
# │ 3   │ 5150             │ -0.297496  │ -0.285665   │
# │ 4   │ 5930             │ -0.128868  │ 0.0         │
# │ 5   │ 6206             │ -0.30872   │ -0.296303   │
# │ 6   │ 7560             │ -0.106265  │ 0.0         │
# │ 7   │ 7953             │ 0.37265    │ 0.348741    │
# │ 8   │ 8057             │ 0.203803   │ 0.214923    │
# │ 9   │ 9244             │ -0.0201651 │ 0.0         │
# │ 10  │ 10564            │ -0.0514429 │ 0.0         │
# Total iteration number was 11
# Total time was 8.186016082763672
# median of y = 1.0
# maximum of y = 11.0
# minimum of y = 0.0
# skewness of y = 1.7827671081121657
# kurtosis of y = 4.172967697488745
# mean of y = 1.3213128038897892
# variance of y = 2.4848799945340083
# var / mean = 1.8806144822170907
#
#
# Running the 6 th model where n, p = 3705, 3705
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β     │ estimated_β │
# │     │ Int64            │ Float64    │ Float64     │
# ├─────┼──────────────────┼────────────┼─────────────┤
# │ 1   │ 82               │ -0.290717  │ -0.263518   │
# │ 2   │ 600              │ -0.0770018 │ -0.086708   │
# │ 3   │ 1445             │ -0.254053  │ -0.28039    │
# │ 4   │ 1890             │ -0.0928666 │ -0.0676182  │
# │ 5   │ 1952             │ -0.0934076 │ 0.0         │
# │ 6   │ 2260             │ 0.0366963  │ 0.0         │
# │ 7   │ 2404             │ -0.068147  │ 0.0         │
# │ 8   │ 3179             │ -0.155185  │ -0.155295   │
# │ 9   │ 3463             │ -0.247281  │ -0.265907   │
# │ 10  │ 3625             │ -0.210418  │ -0.233467   │
# Total iteration number was 19
# Total time was 4.081143856048584
# median of y = 1.0
# maximum of y = 9.0
# minimum of y = 0.0
# skewness of y = 1.277586520479108
# kurtosis of y = 1.998986820137067
# mean of y = 1.1738191632928474
# variance of y = 1.551312218909126
# var / mean = 1.3215938769966227
#
#
# Running the 7 th model where n, p = 3418, 30762
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β      │ estimated_β │
# │     │ Int64            │ Float64     │ Float64     │
# ├─────┼──────────────────┼─────────────┼─────────────┤
# │ 1   │ 255              │ 0.103729    │ 0.10322     │
# │ 2   │ 1179             │ -0.445587   │ -0.454281   │
# │ 3   │ 2759             │ 0.218697    │ 0.211209    │
# │ 4   │ 7116             │ -0.00295007 │ 0.0         │
# │ 5   │ 10555            │ -0.114633   │ -0.132847   │
# │ 6   │ 17238            │ 0.00317603  │ 0.0         │
# │ 7   │ 20003            │ 0.413299    │ 0.412128    │
# │ 8   │ 20878            │ 0.235612    │ 0.234896    │
# │ 9   │ 21730            │ -0.0525906  │ 0.0         │
# │ 10  │ 23076            │ -0.123224   │ -0.123034   │
# Total iteration number was 15
# Total time was 31.00113797187805
# median of y = 1.0
# maximum of y = 16.0
# minimum of y = 0.0
# skewness of y = 2.190830919173338
# kurtosis of y = 7.55060930596548
# mean of y = 1.2954944411936806
# variance of y = 2.5529852544320697
# var / mean = 1.970664769568386
#
#
# Running the 8 th model where n, p = 4386, 21930
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β     │ estimated_β │
# │     │ Int64            │ Float64    │ Float64     │
# ├─────┼──────────────────┼────────────┼─────────────┤
# │ 1   │ 1699             │ 0.099134   │ 0.118089    │
# │ 2   │ 2081             │ -0.143249  │ -0.125912   │
# │ 3   │ 4493             │ -0.268285  │ -0.26907    │
# │ 4   │ 7071             │ 0.149182   │ 0.144433    │
# │ 5   │ 8139             │ 0.0066974  │ 0.0         │
# │ 6   │ 13362            │ -0.0675163 │ -0.0672543  │
# │ 7   │ 14244            │ 0.344556   │ 0.339627    │
# │ 8   │ 15286            │ 0.3459     │ 0.342229    │
# │ 9   │ 15466            │ 0.0631921  │ 0.0         │
# │ 10  │ 18276            │ 0.0564994  │ 0.0         │
# Total iteration number was 24
# Total time was 30.370573043823242
# median of y = 1.0
# maximum of y = 12.0
# minimum of y = 0.0
# skewness of y = 1.6378794619965418
# kurtosis of y = 4.389807282019603
# mean of y = 1.2165982672138622
# variance of y = 1.8468031120061186
# var / mean = 1.5180057063828405
#
#
# Running the 9 th model where n, p = 4355, 30485
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β     │ estimated_β │
# │     │ Int64            │ Float64    │ Float64     │
# ├─────┼──────────────────┼────────────┼─────────────┤
# │ 1   │ 349              │ 0.210758   │ 0.207041    │
# │ 2   │ 8258             │ -0.225549  │ -0.227572   │
# │ 3   │ 11079            │ -0.0471884 │ 0.0         │
# │ 4   │ 14018            │ -0.261653  │ -0.249101   │
# │ 5   │ 16801            │ -0.354642  │ -0.378518   │
# │ 6   │ 16891            │ 0.0853689  │ 0.0524296   │
# │ 7   │ 19363            │ -0.0406657 │ 0.0         │
# │ 8   │ 24426            │ 0.0148103  │ 0.0         │
# │ 9   │ 26219            │ -0.2064    │ -0.209937   │
# │ 10  │ 27050            │ -0.184024  │ -0.200977   │
# Total iteration number was 38
# Total time was 52.177765130996704
# median of y = 1.0
# maximum of y = 11.0
# minimum of y = 0.0
# skewness of y = 1.4570396485390666
# kurtosis of y = 2.987429477216093
# mean of y = 1.209873708381171
# variance of y = 1.6895212288791024
# var / mean = 1.3964442876766923
#
#
# Running the 10 th model where n, p = 4942, 29652
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β     │ estimated_β │
# │     │ Int64            │ Float64    │ Float64     │
# ├─────┼──────────────────┼────────────┼─────────────┤
# │ 1   │ 1060             │ 0.0991197  │ 0.118609    │
# │ 2   │ 1529             │ -0.2061    │ -0.191074   │
# │ 3   │ 1684             │ 0.0111416  │ 0.0         │
# │ 4   │ 4171             │ -0.0384073 │ 0.0         │
# │ 5   │ 14763            │ 0.291218   │ 0.297164    │
# │ 6   │ 15334            │ 0.00801855 │ 0.0         │
# │ 7   │ 17712            │ 0.306283   │ 0.299491    │
# │ 8   │ 22246            │ -0.337829  │ -0.33528    │
# │ 9   │ 22346            │ -0.139462  │ -0.151654   │
# │ 10  │ 28755            │ 0.157543   │ 0.155501    │
# Total iteration number was 12
# Total time was 41.70933198928833
# median of y = 1.0
# maximum of y = 12.0
# minimum of y = 0.0
# skewness of y = 1.64251970683903
# kurtosis of y = 4.005412254578287
# mean of y = 1.2197490894374747
# variance of y = 1.893007992080733
# var / mean = 1.551965079107993
#
#
# Running the 11 th model where n, p = 2639, 5278
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β     │ estimated_β │
# │     │ Int64            │ Float64    │ Float64     │
# ├─────┼──────────────────┼────────────┼─────────────┤
# │ 1   │ 24               │ -0.215795  │ -0.216133   │
# │ 2   │ 1079             │ 0.0275921  │ 0.0         │
# │ 3   │ 1313             │ 0.150004   │ 0.131187    │
# │ 4   │ 1344             │ 0.145129   │ 0.168321    │
# │ 5   │ 1746             │ 0.109202   │ 0.0801188   │
# │ 6   │ 2032             │ 0.0474999  │ 0.066664    │
# │ 7   │ 2203             │ 0.199461   │ 0.225587    │
# │ 8   │ 2841             │ -0.0267609 │ 0.0         │
# │ 9   │ 3031             │ -0.062017  │ 0.0         │
# │ 10  │ 4671             │ 0.316024   │ 0.312224    │
# Total iteration number was 10
# Total time was 3.5095748901367188
# median of y = 1.0
# maximum of y = 8.0
# minimum of y = 0.0
# skewness of y = 1.4671043136071467
# kurtosis of y = 2.8982263146421676
# mean of y = 1.1231527093596059
# variance of y = 1.4969580627210497
# var / mean = 1.3328179242647944
#
#
# Running the 12 th model where n, p = 4616, 36928
# InterruptException:
#
# Stacktrace:
#  [1] copy at ./array.jl:299 [inlined]
#  [2] regress(::Array{Float64,2}, ::Array{Float64,1}, ::String) at /Users/biona001/.julia/dev/MendelIHT/src/utilities.jl:729
#  [3] initialize_beta!(::MendelIHT.IHTVariable{Float64}, ::Array{Float64,1}, ::SnpArray, ::String) at /Users/biona001/.julia/dev/MendelIHT/src/utilities.jl:806
#  [4] #L0_poisson_reg#15(::Bool, ::String, ::Float64, ::Int64, ::Int64, ::Array{Float64,1}, ::Bool, ::Bool, ::Bool, ::Bool, ::Array{Float64,1}, ::typeof(L0_poisson_reg), ::SnpArray, ::Array{Float64,2}, ::Array{Float64,1}, ::Int64, ::Int64) at /Users/biona001/.julia/dev/MendelIHT/src/gwas_poisson.jl:192
#  [5] (::getfield(MendelIHT, Symbol("#kw##L0_poisson_reg")))(::NamedTuple{(:glm, :debias, :convg, :show_info),Tuple{String,Bool,Bool,Bool}}, ::typeof(L0_poisson_reg), ::SnpArray, ::Array{Float64,2}, ::Array{Float64,1}, ::Int64, ::Int64) at ./none:0
#  [6] run_poisson(::Int64, ::Int64) at ./In[15]:31
#  [7] top-level scope at ./In[17]:5
