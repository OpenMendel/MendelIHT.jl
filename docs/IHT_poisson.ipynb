# %% [markdown]
# # Various illustrations on IHT-poisson fitting
#
# In this notebook we illustrate the functionalities and behaviors of IHT used for high-dimensional poisson regressions. Specifically, we investigate:
# + What is a reasonable distribution for $\beta_{true}$?
# + Is initializing $\beta$ good in terms of speed and model selection?
# + Is debiasing good in terms of speed and model selection?
# + How does IHT compare to LASSO?

# %%
using Revise
using MendelIHT
using SnpArrays
using DataFrames
using Distributions
using BenchmarkTools
using Random
using LinearAlgebra
using StatsFuns: logistic
# Out:
# ┌ Info: Recompiling stale cache file /Users/biona001/.julia/compiled/v1.0/MendelIHT/eaqWB.ji for MendelIHT [921c7187-1484-5754-b919-5d3ed9ac03c4]
# └ @ Base loading.jl:1190
# ┌ Info: Loading DataFrames support into Gadfly.jl
# └ @ Gadfly /Users/biona001/.julia/packages/Gadfly/09PWZ/src/mapping.jl:228

# %% [markdown]
# # What is a reasonable distribution for $\beta_{true}$?
#
# Recall that when $\lambda \geq 20$, Poisson($\lambda)$ can be [approximated by the normal distributions with a continuity correction](http://wiki.stat.ucla.edu/socr/index.php/AP_Statistics_Curriculum_2007_Limits_Norm2Poisson). Thus in our data simulation, it is a good idea to make sure the mean of the generated $\lambda_i$ for each sample does not exceed this value, because otherwise it would be more appropriate to fit a normal, or log-normal distribution. This can be roughly ensured if we let $\beta \sim N(0, s)$ where $s$ is small, but obviously the smaller the $\beta$, the harder it is to find it. This section investigates what distribution we should choose for $\beta$ to approximately ensure that the median of $y$ lies in a reasonable range.

# %% [markdown]
# ## "Bad" poisson reconstruction for extreme $\lambda$ values
#
# To convince the skeptical reader, first we show poisson reconstruction results that are "sometimes bad" as a result of a few extreme $\lambda_i$. These extreme values forces extremely large gradients in the first few iterations. This introduces numerical instability, but also brings the model estimate to disproportionately large values, rendering IHT powerless. For $k = 10$, this happens around $50\%$ of the time (i.e. when mean$(y) \leq 20$), and this probability tend to increase with larger $k$ values because $\lambda_i = \exp(x_i^T\beta)$.

# %%
#some function that runs poisson regression on different SNP matrices
function run_poisson_bad(n :: Int64, p :: Int64, k :: Int64)
    #set random seed
    Random.seed!(1111)

    #construct snpmatrix, covariate files, and true model b. Here we show N(0, 1) is a BAD MODEL 
    x, maf = simulate_random_snparray(n, p)
    xbm = SnpBitMatrix{Float64}(x, model=ADDITIVE_MODEL, center=true, scale=true); 
    z = ones(n, 1) #intercept
    true_b = zeros(p)
    true_b[1:k] = randn(k) #N(0, 1) is a BAD MODEL 
    shuffle!(true_b)
    correct_position = findall(x -> x != 0, true_b)

    # Simulate poisson data
    y_temp = xbm * true_b
    λ = exp.(y_temp)
    y = [rand(Poisson(x)) for x in λ]
    y = Float64.(y)

    #compute poisson IHT result
    result = L0_poisson_reg(x, z, y, 1, k, glm = "poisson", debias=false, convg=true, show_info=false, true_beta=true_b, scale=false, init=false)

    #check result
    estimated_models = result.beta[correct_position]
    true_model = true_b[correct_position]
    compare_model = DataFrame(
        true_β      = true_model, 
        estimated_β = estimated_models)
    
    #display results
    @show sort(compare_model, rev=true, by=abs)
    println("Total iteration number was " * string(result.iter))
    println("Total time was " * string(result.time))
    println("median of y = " * string(median(y)))
    println("maximum of y = " * string(maximum(y)))
    println("minimum of y = " * string(minimum(y)))
    println("skewness of y = " * string(skewness(y)))
    println("kurtosis of y = " * string(kurtosis(y)))
    println("mean of y = " * string(mean(y)))
    println("variance of y = " * string(var(y)))
    println("var / mean = " * string(var(y) / mean(y)) * "\n\n")
end
# Out:
# run_poisson_bad (generic function with 1 method)

# %%
for i = 1:50
    n = rand(2000:5000) 
    p = rand(1:10)n
    k = 10
    println("Running the $i th model where " * "n, p = " * string(n) * ", " * string(p))
    run_poisson_bad(n, p, k)
end
# Out:
# Running the 1 th model where n, p = 2274, 15918
# sort(compare_model, rev=true, by=abs) = 10×2 DataFrame
# │ Row │ true_β    │ estimated_β │
# │     │ Float64   │ Float64     │
# ├─────┼───────────┼─────────────┤
# │ 1   │ 1.29571   │ 1.29473     │
# │ 2   │ 1.25988   │ 1.25969     │
# │ 3   │ -1.22584  │ -1.23833    │
# │ 4   │ 0.745645  │ 0.734241    │
# │ 5   │ -0.376801 │ -0.383461   │
# │ 6   │ -0.305932 │ -0.303664   │
# │ 7   │ 0.275386  │ 0.271365    │
# │ 8   │ 0.186843  │ 0.184365    │
# │ 9   │ 0.173627  │ 0.176104    │
# │ 10  │ -0.145285 │ -0.137414   │
# Total iteration number was 159
# Total time was 31.70826482772827
# median of y = 1.0
# maximum of y = 1166.0
# minimum of y = 0.0
# skewness of y = 10.392052871583946
# kurtosis of y = 142.86550411712287
# mean of y = 14.214160070360599
# variance of y = 4088.5458442788117
# var / mean = 287.6389335733075
#
#
# Running the 2 th model where n, p = 3074, 24592
# sort(compare_model, rev=true, by=abs) = 10×2 DataFrame
# │ Row │ true_β    │ estimated_β │
# │     │ Float64   │ Float64     │
# ├─────┼───────────┼─────────────┤
# │ 1   │ 1.98005   │ 23617.8     │
# │ 2   │ 1.71546   │ 20184.4     │
# │ 3   │ -0.922395 │ 0.0         │
# │ 4   │ -0.716426 │ 0.0         │
# │ 5   │ 0.685908  │ 0.0         │
# │ 6   │ -0.582152 │ 0.0         │
# │ 7   │ 0.565595  │ 0.0         │
# │ 8   │ -0.504705 │ 0.0         │
# │ 9   │ 0.418443  │ 0.0         │
# │ 10  │ 0.246142  │ 0.0         │
# Total iteration number was 2
# Total time was 1.8272368907928467
# median of y = 1.0
# maximum of y = 1.8753294e7
# minimum of y = 0.0
# skewness of y = 31.165814547589807
# kurtosis of y = 1100.7840432135506
# mean of y = 25345.691607026674
# variance of y = 2.212309961751427e11
# var / mean = 8.728544464488396e6
#
#
# Running the 3 th model where n, p = 3007, 21049
# sort(compare_model, rev=true, by=abs) = 10×2 DataFrame
# │ Row │ true_β    │ estimated_β │
# │     │ Float64   │ Float64     │
# ├─────┼───────────┼─────────────┤
# │ 1   │ 1.51224   │ 0.0         │
# │ 2   │ 1.12079   │ 0.0         │
# │ 3   │ 1.0388    │ 2068.02     │
# │ 4   │ 0.955073  │ 0.0         │
# │ 5   │ 0.924786  │ 0.0         │
# │ 6   │ 0.860068  │ 0.0         │
# │ 7   │ -0.651107 │ 0.0         │
# │ 8   │ -0.295142 │ 0.0         │
# │ 9   │ -0.212039 │ 0.0         │
# │ 10  │ 0.0341331 │ 0.0         │
# Total iteration number was 2
# Total time was 1.459028959274292
# median of y = 1.0
# maximum of y = 2.713081e6
# minimum of y = 0.0
# skewness of y = 51.31527469753942
# kurtosis of y = 2714.740865075282
# mean of y = 1226.4825407382773
# variance of y = 2.576709027327624e9
# var / mean = 2.100893361088191e6
#
#
# Running the 4 th model where n, p = 3968, 11904
# sort(compare_model, rev=true, by=abs) = 10×2 DataFrame
# │ Row │ true_β   │ estimated_β │
# │     │ Float64  │ Float64     │
# ├─────┼──────────┼─────────────┤
# │ 1   │ -1.51584 │ -1.48816    │
# │ 2   │ 1.46478  │ 1.47166     │
# │ 3   │ 1.15255  │ 1.15909     │
# │ 4   │ 0.697642 │ 0.7026      │
# │ 5   │ 0.591422 │ 0.587268    │
# │ 6   │ 0.577188 │ 0.573793    │
# │ 7   │ 0.533    │ 0.530137    │
# │ 8   │ 0.394403 │ 0.396892    │
# │ 9   │ 0.301158 │ 0.29975     │
# │ 10  │ 0.114197 │ 0.121098    │
# Total iteration number was 194
# Total time was 51.66505694389343
# median of y = 1.0
# maximum of y = 5937.0
# minimum of y = 0.0
# skewness of y = 27.435576070770477
# kurtosis of y = 1054.8000030958196
# mean of y = 19.069808467741936
# variance of y = 17736.80858660308
# var / mean = 930.0989371029223
#
#
# Running the 5 th model where n, p = 2046, 18414
# sort(compare_model, rev=true, by=abs) = 10×2 DataFrame
# │ Row │ true_β    │ estimated_β │
# │     │ Float64   │ Float64     │
# ├─────┼───────────┼─────────────┤
# │ 1   │ 3.56515   │ 1302.7      │
# │ 2   │ -1.29929  │ -594.005    │
# │ 3   │ -1.2951   │ 0.0         │
# │ 4   │ -1.07244  │ 0.0         │
# │ 5   │ 0.982112  │ 714.206     │
# │ 6   │ -0.87773  │ 0.0         │
# │ 7   │ -0.555334 │ 0.0         │
# │ 8   │ -0.552498 │ 0.0         │
# │ 9   │ -0.294555 │ 0.0         │
# │ 10  │ 0.0962369 │ 0.0         │
# Total iteration number was 2
# Total time was 0.8675148487091064
# median of y = 1.0
# maximum of y = 243973.0
# minimum of y = 0.0
# skewness of y = 15.467697848422508
# kurtosis of y = 289.6700039104255
# mean of y = 1152.7111436950147
# variance of y = 9.617164590820839e7
# var / mean = 83430.82864622115
#
#
# Running the 6 th model where n, p = 4536, 4536
# sort(compare_model, rev=true, by=abs) = 10×2 DataFrame
# │ Row │ true_β    │ estimated_β │
# │     │ Float64   │ Float64     │
# ├─────┼───────────┼─────────────┤
# │ 1   │ -2.27565  │ -111.204    │
# │ 2   │ -1.74658  │ -92.0875    │
# │ 3   │ 1.24806   │ 125.293     │
# │ 4   │ -1.20233  │ 0.0         │
# │ 5   │ 0.974197  │ 171.877     │
# │ 6   │ 0.855283  │ 70.9928     │
# │ 7   │ -0.586311 │ 0.0         │
# │ 8   │ 0.555698  │ 0.0         │
# │ 9   │ -0.49599  │ 0.0         │
# │ 10  │ 0.0167003 │ 0.0         │
# Total iteration number was 1000
# Total time was 125.76453113555908
# median of y = 1.0
# maximum of y = 121679.0
# minimum of y = 0.0
# skewness of y = 34.60710890509606
# kurtosis of y = 1357.3787479431517
# mean of y = 198.3101851851852
# variance of y = 8.3459698051972315e6
# var / mean = 42085.43195803903
#
#
# Running the 7 th model where n, p = 3042, 18252
# sort(compare_model, rev=true, by=abs) = 10×2 DataFrame
# │ Row │ true_β    │ estimated_β │
# │     │ Float64   │ Float64     │
# ├─────┼───────────┼─────────────┤
# │ 1   │ -1.69367  │ -67.6427    │
# │ 2   │ 1.68271   │ 162.936     │
# │ 3   │ 0.975622  │ 84.928      │
# │ 4   │ -0.85116  │ 0.0         │
# │ 5   │ -0.724413 │ 0.0         │
# │ 6   │ -0.547334 │ 0.0         │
# │ 7   │ -0.370104 │ 0.0         │
# │ 8   │ -0.225758 │ 0.0         │
# │ 9   │ -0.220994 │ 0.0         │
# │ 10  │ -0.123277 │ 0.0         │
# Total iteration number was 1000
# Total time was 304.0956552028656
# median of y = 1.0
# maximum of y = 33209.0
# minimum of y = 0.0
# skewness of y = 26.800718131188457
# kurtosis of y = 803.9027373600823
# mean of y = 76.01873767258382
# variance of y = 1.0346351949792678e6
# var / mean = 13610.265398453324
#
#
# Running the 8 th model where n, p = 2571, 15426
# sort(compare_model, rev=true, by=abs) = 10×2 DataFrame
# │ Row │ true_β    │ estimated_β │
# │     │ Float64   │ Float64     │
# ├─────┼───────────┼─────────────┤
# │ 1   │ -1.47581  │ -1.42407    │
# │ 2   │ -1.16198  │ 0.0         │
# │ 3   │ -1.12847  │ -1.12093    │
# │ 4   │ 0.620823  │ 0.624161    │
# │ 5   │ 0.417945  │ 0.430622    │
# │ 6   │ -0.364234 │ -0.363328   │
# │ 7   │ -0.246534 │ -0.25094    │
# │ 8   │ 0.224137  │ 0.22208     │
# │ 9   │ 0.198804  │ 0.210647    │
# │ 10  │ -0.121666 │ -0.133049   │
# Total iteration number was 94
# Total time was 19.2453351020813
# median of y = 1.0
# maximum of y = 261.0
# minimum of y = 0.0
# skewness of y = 7.488354025894708
# kurtosis of y = 84.91179325363436
# mean of y = 5.427071178529755
# variance of y = 191.2704575276165
# var / mean = 35.2437716837599
#
#
# Running the 9 th model where n, p = 4015, 40150
# sort(compare_model, rev=true, by=abs) = 10×2 DataFrame
# │ Row │ true_β    │ estimated_β │
# │     │ Float64   │ Float64     │
# ├─────┼───────────┼─────────────┤
# │ 1   │ -1.55949  │ -1.55532    │
# │ 2   │ 1.32378   │ 1.32416     │
# │ 3   │ -1.13604  │ -1.10767    │
# │ 4   │ -0.815197 │ -0.80339    │
# │ 5   │ -0.442512 │ -0.430385   │
# │ 6   │ -0.401253 │ 0.0         │
# │ 7   │ 0.358259  │ 0.355796    │
# │ 8   │ 0.314403  │ 0.316992    │
# │ 9   │ 0.23746   │ 0.235842    │
# │ 10  │ 0.0511162 │ 0.0487375   │
# Total iteration number was 164
# Total time was 141.58847880363464
# median of y = 1.0
# maximum of y = 941.0
# minimum of y = 0.0
# skewness of y = 9.148324245514832
# kurtosis of y = 119.06004586121253
# mean of y = 12.506351183063511
# variance of y = 2191.4707493883498
# var / mean = 175.22862722391062
#
#
# Running the 10 th model where n, p = 4695, 32865
# sort(compare_model, rev=true, by=abs) = 10×2 DataFrame
# │ Row │ true_β     │ estimated_β │
# │     │ Float64    │ Float64     │
# ├─────┼────────────┼─────────────┤
# │ 1   │ 2.06319    │ 363.586     │
# │ 2   │ -1.84148   │ -172.5      │
# │ 3   │ -1.34823   │ 0.0         │
# │ 4   │ -1.32403   │ -187.503    │
# │ 5   │ 1.20345    │ 244.27      │
# │ 6   │ -0.417776  │ 0.0         │
# │ 7   │ 0.37706    │ 0.0         │
# │ 8   │ 0.354061   │ 0.0         │
# │ 9   │ -0.0329335 │ 0.0         │
# │ 10  │ -0.0299097 │ 0.0         │
# Total iteration number was 1000
# Total time was 797.8297970294952
# median of y = 1.0
# maximum of y = 239942.0
# minimum of y = 0.0
# skewness of y = 31.844048915850905
# kurtosis of y = 1230.728126970275
# mean of y = 369.7269435569755
# variance of y = 2.7926034372803926e7
# var / mean = 75531.51010348392

# %% [markdown]
# ## What's the appropriate variance of our model?
#
# Below we have $s = 0.1, 0.2, ... 1.0$ and let $\beta \sim N(0, s)$. Then we construct 10 different SNP matrices for each model to simulate data. We compute some summary statistics at the end, but overall variance $= 0.3$ works the best for maximizing $\beta$ coefficients (i.e. making the problem easy) but minimizes extreme outliers.

# %%
function compute_y_mean(variance :: Float64)     
    #simulat data
    n = rand(2000:5000)
    p = 10n
    k = 10 # number of true predictors

    #construct snpmatrix, covariate files, and true model b
    x, maf = simulate_random_snparray(n, p)
    xbm = SnpBitMatrix{Float64}(x, model=ADDITIVE_MODEL, center=true, scale=true); 
    z = ones(n, 1) # non-genetic covariates, just the intercept
    true_b = zeros(p)
    true_b[1:k] = rand(Normal(0, variance), k)
    shuffle!(true_b)
    correct_position = findall(x -> x != 0, true_b)

    #simulate data
    y_temp = xbm * true_b
    λ = exp.(y_temp) #inverse log link
    y = [rand(Poisson(x)) for x in λ]
    y = Float64.(y)
    
    return n, p, median(y), maximum(y), mean(y), var(y), skewness(y), kurtosis(y) 
end
# Out:
# compute_y_mean (generic function with 1 method)

# %%
Random.seed!(2019)
s = collect(0.1:0.1:1) #beta ~ N(0, s) for s in {0.1, 0.2,..., 1} 
repeats = 30
for i in 1:length(s)
    df = DataFrame(n = Int64[], p = Int64[], median = Float64[], max = Float64[], mean = Float64[], 
        var = Float64[], skew = Float64[], kur = Float64[])
    for j in 1:repeats
        n, p, med, max, μ, σ, skew, kur = compute_y_mean(s[i])
        push!(df, [n, p, med, max, μ, σ, skew, kur])
    end
    println("for variance = " * string(s[i]) * ", the result is as follows:")
    @show(df)
    println("\n\n")
end
# Out:
# for variance = 0.1, the result is as follows:
# df = 30×8 DataFrame
# │ Row │ n     │ p     │ median  │ max     │ mean    │ var      │ skew     │ kur      │
# │     │ Int64 │ Int64 │ Float64 │ Float64 │ Float64 │ Float64  │ Float64  │ Float64  │
# ├─────┼───────┼───────┼─────────┼─────────┼─────────┼──────────┼──────────┼──────────┤
# │ 1   │ 2101  │ 21010 │ 1.0     │ 9.0     │ 1.04998 │ 1.15512  │ 1.22887  │ 2.47232  │
# │ 2   │ 2421  │ 24210 │ 1.0     │ 6.0     │ 1.0033  │ 1.08346  │ 1.02249  │ 0.936058 │
# │ 3   │ 4679  │ 46790 │ 1.0     │ 6.0     │ 1.06305 │ 1.17495  │ 1.0925   │ 1.18712  │
# │ 4   │ 2024  │ 20240 │ 1.0     │ 7.0     │ 1.03656 │ 1.12372  │ 1.145    │ 1.5472   │
# │ 5   │ 3581  │ 35810 │ 1.0     │ 7.0     │ 1.0081  │ 1.09016  │ 1.10599  │ 1.43206  │
# │ 6   │ 2451  │ 24510 │ 1.0     │ 7.0     │ 1.04366 │ 1.14626  │ 1.10676  │ 1.31603  │
# │ 7   │ 2966  │ 29660 │ 1.0     │ 7.0     │ 1.02326 │ 1.09052  │ 1.20477  │ 2.13775  │
# │ 8   │ 4298  │ 42980 │ 1.0     │ 8.0     │ 1.09981 │ 1.32795  │ 1.21373  │ 1.66191  │
# │ 9   │ 4780  │ 47800 │ 1.0     │ 7.0     │ 1.07259 │ 1.25713  │ 1.18075  │ 1.5363   │
# │ 10  │ 4565  │ 45650 │ 1.0     │ 7.0     │ 1.04535 │ 1.14453  │ 1.1221   │ 1.46682  │
# │ 11  │ 2825  │ 28250 │ 1.0     │ 8.0     │ 1.02796 │ 1.17592  │ 1.26106  │ 2.3529   │
# │ 12  │ 3540  │ 35400 │ 1.0     │ 8.0     │ 1.08672 │ 1.28635  │ 1.30332  │ 2.49742  │
# │ 13  │ 4021  │ 40210 │ 1.0     │ 7.0     │ 1.05024 │ 1.14872  │ 1.14768  │ 1.77378  │
# │ 14  │ 2489  │ 24890 │ 1.0     │ 9.0     │ 1.12455 │ 1.53191  │ 1.50052  │ 3.33973  │
# │ 15  │ 3206  │ 32060 │ 1.0     │ 6.0     │ 1.02308 │ 1.06031  │ 0.998264 │ 0.912885 │
# │ 16  │ 4207  │ 42070 │ 1.0     │ 7.0     │ 1.02258 │ 1.07248  │ 1.04548  │ 1.11154  │
# │ 17  │ 2176  │ 21760 │ 1.0     │ 6.0     │ 1.00827 │ 1.05648  │ 1.0024   │ 0.9063   │
# │ 18  │ 4497  │ 44970 │ 1.0     │ 7.0     │ 1.02958 │ 1.05673  │ 1.02455  │ 1.14747  │
# │ 19  │ 4825  │ 48250 │ 1.0     │ 9.0     │ 1.06964 │ 1.23603  │ 1.27735  │ 2.3561   │
# │ 20  │ 2727  │ 27270 │ 1.0     │ 7.0     │ 1.00073 │ 1.07704  │ 1.1448   │ 1.70664  │
# │ 21  │ 3539  │ 35390 │ 1.0     │ 8.0     │ 1.08138 │ 1.23136  │ 1.18968  │ 1.73595  │
# │ 22  │ 4823  │ 48230 │ 1.0     │ 8.0     │ 1.06241 │ 1.25098  │ 1.24492  │ 1.99395  │
# │ 23  │ 2323  │ 23230 │ 1.0     │ 6.0     │ 1.0043  │ 1.04391  │ 0.977637 │ 0.72674  │
# │ 24  │ 3238  │ 32380 │ 1.0     │ 5.0     │ 0.99197 │ 0.995919 │ 0.984129 │ 0.776253 │
# │ 25  │ 2076  │ 20760 │ 1.0     │ 7.0     │ 1.05732 │ 1.10466  │ 1.02402  │ 1.04773  │
# │ 26  │ 4506  │ 45060 │ 1.0     │ 7.0     │ 1.08211 │ 1.23765  │ 1.19023  │ 1.65154  │
# │ 27  │ 4938  │ 49380 │ 1.0     │ 6.0     │ 1.01701 │ 1.08053  │ 1.03302  │ 0.984216 │
# │ 28  │ 4195  │ 41950 │ 1.0     │ 7.0     │ 1.06913 │ 1.21601  │ 1.25035  │ 2.07949  │
# │ 29  │ 4276  │ 42760 │ 1.0     │ 8.0     │ 1.05122 │ 1.12229  │ 1.09507  │ 1.56404  │
# │ 30  │ 2911  │ 29110 │ 1.0     │ 6.0     │ 1.04431 │ 1.12278  │ 1.0488   │ 1.01807  │
#
#
#
# for variance = 0.2, the result is as follows:
# df = 30×8 DataFrame
# │ Row │ n     │ p     │ median  │ max     │ mean    │ var     │ skew    │ kur     │
# │     │ Int64 │ Int64 │ Float64 │ Float64 │ Float64 │ Float64 │ Float64 │ Float64 │
# ├─────┼───────┼───────┼─────────┼─────────┼─────────┼─────────┼─────────┼─────────┤
# │ 1   │ 3591  │ 35910 │ 1.0     │ 8.0     │ 1.14286 │ 1.51914 │ 1.40177 │ 2.57818 │
# │ 2   │ 2516  │ 25160 │ 1.0     │ 19.0    │ 1.44952 │ 3.60501 │ 2.72495 │ 13.1708 │
# │ 3   │ 2984  │ 29840 │ 1.0     │ 19.0    │ 1.26273 │ 2.60812 │ 2.64677 │ 12.9467 │
# │ 4   │ 2875  │ 28750 │ 1.0     │ 23.0    │ 1.35548 │ 3.0253  │ 2.94096 │ 16.9332 │
# │ 5   │ 4090  │ 40900 │ 1.0     │ 8.0     │ 1.11051 │ 1.41454 │ 1.25158 │ 1.78498 │
# │ 6   │ 2171  │ 21710 │ 1.0     │ 15.0    │ 1.26624 │ 2.31526 │ 2.33997 │ 9.85727 │
# │ 7   │ 4568  │ 45680 │ 1.0     │ 7.0     │ 1.11646 │ 1.32955 │ 1.13551 │ 1.38639 │
# │ 8   │ 4742  │ 47420 │ 1.0     │ 12.0    │ 1.24736 │ 2.18411 │ 1.96248 │ 6.09569 │
# │ 9   │ 2081  │ 20810 │ 1.0     │ 16.0    │ 1.24556 │ 2.16227 │ 2.27576 │ 10.3126 │
# │ 10  │ 3146  │ 31460 │ 1.0     │ 26.0    │ 1.35569 │ 3.26263 │ 3.26564 │ 22.8292 │
# │ 11  │ 2705  │ 27050 │ 1.0     │ 27.0    │ 1.38115 │ 3.12871 │ 2.92415 │ 20.9586 │
# │ 12  │ 2067  │ 20670 │ 1.0     │ 14.0    │ 1.30334 │ 2.57929 │ 2.28937 │ 8.36481 │
# │ 13  │ 2909  │ 29090 │ 1.0     │ 9.0     │ 1.1461  │ 1.54433 │ 1.40998 │ 2.72255 │
# │ 14  │ 2184  │ 21840 │ 1.0     │ 10.0    │ 1.14698 │ 1.62246 │ 1.64029 │ 4.3107  │
# │ 15  │ 4270  │ 42700 │ 1.0     │ 23.0    │ 1.27564 │ 2.24656 │ 2.57291 │ 16.411  │
# │ 16  │ 2264  │ 22640 │ 1.0     │ 13.0    │ 1.23852 │ 2.05886 │ 1.94908 │ 6.63427 │
# │ 17  │ 2268  │ 22680 │ 1.0     │ 18.0    │ 1.40697 │ 3.39099 │ 2.71285 │ 12.6071 │
# │ 18  │ 4749  │ 47490 │ 1.0     │ 26.0    │ 1.44451 │ 3.63324 │ 2.97266 │ 16.9107 │
# │ 19  │ 2043  │ 20430 │ 1.0     │ 8.0     │ 1.18747 │ 1.5383  │ 1.29265 │ 2.15734 │
# │ 20  │ 2825  │ 28250 │ 1.0     │ 13.0    │ 1.24602 │ 1.97947 │ 1.81463 │ 5.64079 │
# │ 21  │ 4361  │ 43610 │ 1.0     │ 26.0    │ 1.15845 │ 2.12007 │ 4.47587 │ 47.055  │
# │ 22  │ 3975  │ 39750 │ 1.0     │ 19.0    │ 1.28503 │ 2.49624 │ 2.57276 │ 12.9403 │
# │ 23  │ 3300  │ 33000 │ 1.0     │ 10.0    │ 1.21121 │ 1.7829  │ 1.48373 │ 2.86341 │
# │ 24  │ 3661  │ 36610 │ 1.0     │ 10.0    │ 1.16963 │ 1.65619 │ 1.55496 │ 3.75256 │
# │ 25  │ 4184  │ 41840 │ 1.0     │ 11.0    │ 1.33246 │ 2.31474 │ 1.64188 │ 3.62465 │
# │ 26  │ 3161  │ 31610 │ 1.0     │ 12.0    │ 1.18444 │ 1.83718 │ 1.75592 │ 5.02046 │
# │ 27  │ 2640  │ 26400 │ 1.0     │ 10.0    │ 1.15    │ 1.49246 │ 1.44068 │ 3.07398 │
# │ 28  │ 2830  │ 28300 │ 1.0     │ 17.0    │ 1.18127 │ 1.79781 │ 1.98765 │ 9.38261 │
# │ 29  │ 3242  │ 32420 │ 1.0     │ 11.0    │ 1.25972 │ 1.99856 │ 1.53135 │ 3.45519 │
# │ 30  │ 4350  │ 43500 │ 1.0     │ 15.0    │ 1.29264 │ 2.54506 │ 2.36368 │ 9.64571 │
#
#
#
# for variance = 0.3, the result is as follows:
# df = 30×8 DataFrame
# │ Row │ n     │ p     │ median  │ max     │ mean    │ var     │ skew    │ kur     │
# │     │ Int64 │ Int64 │ Float64 │ Float64 │ Float64 │ Float64 │ Float64 │ Float64 │
# ├─────┼───────┼───────┼─────────┼─────────┼─────────┼─────────┼─────────┼─────────┤
# │ 1   │ 2859  │ 28590 │ 1.0     │ 248.0   │ 1.95838 │ 42.8111 │ 21.0496 │ 715.082 │
# │ 2   │ 4492  │ 44920 │ 1.0     │ 221.0   │ 2.39203 │ 36.1622 │ 15.1062 │ 433.149 │
# │ 3   │ 2560  │ 25600 │ 1.0     │ 32.0    │ 1.85586 │ 7.98898 │ 3.42734 │ 19.0171 │
# │ 4   │ 2372  │ 23720 │ 1.0     │ 41.0    │ 1.95616 │ 10.7699 │ 4.15024 │ 27.7236 │
# │ 5   │ 2694  │ 26940 │ 1.0     │ 10.0    │ 1.10245 │ 1.46295 │ 1.47057 │ 3.17072 │
# │ 6   │ 3914  │ 39140 │ 1.0     │ 79.0    │ 1.83572 │ 10.399  │ 7.2004  │ 111.076 │
# │ 7   │ 2057  │ 20570 │ 1.0     │ 168.0   │ 1.92319 │ 26.1857 │ 19.0653 │ 558.629 │
# │ 8   │ 3347  │ 33470 │ 1.0     │ 40.0    │ 1.8282  │ 10.5924 │ 4.71786 │ 33.5291 │
# │ 9   │ 3042  │ 30420 │ 1.0     │ 34.0    │ 1.43918 │ 4.00699 │ 4.16715 │ 38.4996 │
# │ 10  │ 2035  │ 20350 │ 1.0     │ 35.0    │ 2.06241 │ 12.9514 │ 3.87803 │ 21.0801 │
# │ 11  │ 3741  │ 37410 │ 1.0     │ 16.0    │ 1.50361 │ 3.31797 │ 1.99339 │ 6.40461 │
# │ 12  │ 4390  │ 43900 │ 1.0     │ 21.0    │ 1.40273 │ 3.25996 │ 2.62264 │ 12.1177 │
# │ 13  │ 4555  │ 45550 │ 1.0     │ 359.0   │ 2.4191  │ 61.8447 │ 23.9888 │ 959.508 │
# │ 14  │ 2256  │ 22560 │ 1.0     │ 15.0    │ 1.47872 │ 3.44168 │ 2.09162 │ 6.07592 │
# │ 15  │ 3384  │ 33840 │ 1.0     │ 16.0    │ 1.39746 │ 3.04121 │ 2.17203 │ 7.49613 │
# │ 16  │ 3239  │ 32390 │ 1.0     │ 11.0    │ 1.29886 │ 2.51967 │ 1.86587 │ 4.60936 │
# │ 17  │ 3045  │ 30450 │ 1.0     │ 3727.0  │ 5.90673 │ 7751.4  │ 29.3134 │ 1099.31 │
# │ 18  │ 2370  │ 23700 │ 1.0     │ 87.0    │ 1.71013 │ 12.8999 │ 10.7484 │ 197.054 │
# │ 19  │ 2916  │ 29160 │ 1.0     │ 36.0    │ 1.59979 │ 5.64321 │ 4.12808 │ 32.9262 │
# │ 20  │ 2377  │ 23770 │ 1.0     │ 41.0    │ 1.50736 │ 6.13557 │ 6.15232 │ 67.7662 │
# │ 21  │ 2602  │ 26020 │ 1.0     │ 22.0    │ 1.68063 │ 5.84914 │ 2.94887 │ 12.7275 │
# │ 22  │ 2211  │ 22110 │ 1.0     │ 20.0    │ 1.58118 │ 4.46071 │ 2.6694  │ 11.1536 │
# │ 23  │ 3753  │ 37530 │ 1.0     │ 30.0    │ 1.49374 │ 4.47711 │ 3.57052 │ 23.8046 │
# │ 24  │ 2419  │ 24190 │ 1.0     │ 1338.0  │ 4.13559 │ 2627.25 │ 19.3293 │ 410.356 │
# │ 25  │ 3889  │ 38890 │ 1.0     │ 631.0   │ 2.08125 │ 128.757 │ 45.1956 │ 2441.09 │
# │ 26  │ 3531  │ 35310 │ 1.0     │ 11.0    │ 1.19824 │ 1.82584 │ 1.67589 │ 4.01173 │
# │ 27  │ 3024  │ 30240 │ 1.0     │ 13.0    │ 1.4256  │ 2.75927 │ 1.85917 │ 5.29647 │
# │ 28  │ 3070  │ 30700 │ 1.0     │ 13.0    │ 1.47785 │ 3.07983 │ 1.71493 │ 3.75244 │
# │ 29  │ 2187  │ 21870 │ 1.0     │ 138.0   │ 2.28212 │ 38.9931 │ 10.5974 │ 178.335 │
# │ 30  │ 2975  │ 29750 │ 1.0     │ 39.0    │ 1.40807 │ 4.97196 │ 5.51025 │ 57.0205 │
#
#
#
# for variance = 0.4, the result is as follows:
# df = 30×8 DataFrame
# │ Row │ n     │ p     │ median  │ max     │ mean    │ var     │ skew    │ kur     │
# │     │ Int64 │ Int64 │ Float64 │ Float64 │ Float64 │ Float64 │ Float64 │ Float64 │
# ├─────┼───────┼───────┼─────────┼─────────┼─────────┼─────────┼─────────┼─────────┤
# │ 1   │ 4144  │ 41440 │ 1.0     │ 14.0    │ 1.48335 │ 3.3094  │ 1.90428 │ 5.26654 │
# │ 2   │ 4637  │ 46370 │ 1.0     │ 64.0    │ 1.79124 │ 9.56685 │ 6.8171  │ 92.9401 │
# │ 3   │ 2038  │ 20380 │ 1.0     │ 73.0    │ 3.18253 │ 37.4159 │ 4.34438 │ 28.3528 │
# │ 4   │ 3312  │ 33120 │ 1.0     │ 88.0    │ 2.14463 │ 19.1543 │ 7.23218 │ 87.2866 │
# │ 5   │ 3371  │ 33710 │ 1.0     │ 48.0    │ 1.78285 │ 8.73503 │ 4.55652 │ 36.6654 │
# │ 6   │ 2697  │ 26970 │ 1.0     │ 380.0   │ 3.01372 │ 128.494 │ 19.5784 │ 539.611 │
# │ 7   │ 4320  │ 43200 │ 1.0     │ 23.0    │ 1.57616 │ 4.33965 │ 2.4803  │ 9.64251 │
# │ 8   │ 3756  │ 37560 │ 1.0     │ 166.0   │ 2.98749 │ 59.5181 │ 9.50512 │ 138.67  │
# │ 9   │ 2860  │ 28600 │ 1.0     │ 10.0    │ 1.20524 │ 1.93862 │ 1.61508 │ 3.66769 │
# │ 10  │ 2334  │ 23340 │ 1.0     │ 181.0   │ 1.88603 │ 27.0963 │ 20.3713 │ 629.678 │
# │ 11  │ 2479  │ 24790 │ 1.0     │ 102.0   │ 2.06333 │ 28.9254 │ 9.57225 │ 125.69  │
# │ 12  │ 4944  │ 49440 │ 1.0     │ 317.0   │ 2.02933 │ 72.5828 │ 23.5591 │ 693.25  │
# │ 13  │ 3910  │ 39100 │ 1.0     │ 27.0    │ 1.86598 │ 5.59882 │ 2.33107 │ 10.1574 │
# │ 14  │ 3141  │ 31410 │ 1.0     │ 20.0    │ 1.4731  │ 3.7328  │ 2.26244 │ 7.65403 │
# │ 15  │ 3650  │ 36500 │ 1.0     │ 91.0    │ 3.45123 │ 63.9188 │ 5.39576 │ 38.2375 │
# │ 16  │ 2716  │ 27160 │ 1.0     │ 55.0    │ 2.49963 │ 15.8486 │ 3.87639 │ 25.949  │
# │ 17  │ 2877  │ 28770 │ 1.0     │ 134.0   │ 2.49287 │ 35.7083 │ 9.77997 │ 155.18  │
# │ 18  │ 2954  │ 29540 │ 1.0     │ 431.0   │ 3.31991 │ 240.01  │ 17.6796 │ 403.305 │
# │ 19  │ 2158  │ 21580 │ 1.0     │ 73.0    │ 2.70853 │ 34.545  │ 4.85149 │ 31.2312 │
# │ 20  │ 4847  │ 48470 │ 1.0     │ 24.0    │ 1.53043 │ 3.7679  │ 2.50285 │ 11.6107 │
# │ 21  │ 2328  │ 23280 │ 1.0     │ 27.0    │ 1.67569 │ 6.30689 │ 3.43242 │ 17.7961 │
# │ 22  │ 3583  │ 35830 │ 1.0     │ 83.0    │ 2.36841 │ 24.2975 │ 5.72373 │ 49.6185 │
# │ 23  │ 4432  │ 44320 │ 1.0     │ 81.0    │ 1.98917 │ 11.8744 │ 6.91804 │ 105.746 │
# │ 24  │ 3267  │ 32670 │ 1.0     │ 27.0    │ 1.85338 │ 8.75406 │ 3.43154 │ 16.7412 │
# │ 25  │ 4593  │ 45930 │ 1.0     │ 70.0    │ 1.86958 │ 12.9475 │ 7.52915 │ 97.1561 │
# │ 26  │ 4835  │ 48350 │ 1.0     │ 28.0    │ 1.69452 │ 5.41535 │ 2.77771 │ 12.8826 │
# │ 27  │ 3466  │ 34660 │ 1.0     │ 57.0    │ 1.89094 │ 11.9789 │ 5.57809 │ 51.6277 │
# │ 28  │ 2579  │ 25790 │ 1.0     │ 24.0    │ 1.69446 │ 6.0478  │ 3.31935 │ 17.763  │
# │ 29  │ 4346  │ 43460 │ 1.0     │ 29.0    │ 1.5902  │ 5.05619 │ 2.97576 │ 15.1921 │
# │ 30  │ 2995  │ 29950 │ 1.0     │ 31.0    │ 1.67179 │ 6.3201  │ 3.85717 │ 25.6969 │
#
#
#
# for variance = 0.5, the result is as follows:
# df = 30×8 DataFrame
# │ Row │ n     │ p     │ median  │ max       │ mean    │ var       │ skew    │ kur     │
# │     │ Int64 │ Int64 │ Float64 │ Float64   │ Float64 │ Float64   │ Float64 │ Float64 │
# ├─────┼───────┼───────┼─────────┼───────────┼─────────┼───────────┼─────────┼─────────┤
# │ 1   │ 2974  │ 29740 │ 1.0     │ 780.0     │ 4.50605 │ 646.644   │ 20.2136 │ 498.69  │
# │ 2   │ 3303  │ 33030 │ 1.0     │ 53.0      │ 1.9894  │ 12.495    │ 5.77997 │ 54.5772 │
# │ 3   │ 2739  │ 27390 │ 1.0     │ 105.0     │ 2.97444 │ 51.1381   │ 7.19735 │ 72.8998 │
# │ 4   │ 2312  │ 23120 │ 1.0     │ 157.0     │ 3.34472 │ 63.9491   │ 8.01903 │ 102.47  │
# │ 5   │ 3606  │ 36060 │ 1.0     │ 241.0     │ 2.43123 │ 49.6201   │ 17.9633 │ 496.436 │
# │ 6   │ 3716  │ 37160 │ 1.0     │ 61.0      │ 2.15662 │ 13.4166   │ 4.3624  │ 33.9525 │
# │ 7   │ 3179  │ 31790 │ 1.0     │ 81.0      │ 2.59736 │ 31.9543   │ 6.37566 │ 58.1003 │
# │ 8   │ 2723  │ 27230 │ 1.0     │ 28.0      │ 2.148   │ 11.6508   │ 2.94245 │ 11.14   │
# │ 9   │ 3315  │ 33150 │ 1.0     │ 1045.0    │ 6.59548 │ 1125.44   │ 16.9739 │ 407.301 │
# │ 10  │ 2532  │ 25320 │ 1.0     │ 59.0      │ 2.30885 │ 19.903    │ 5.38309 │ 43.1612 │
# │ 11  │ 4241  │ 42410 │ 1.0     │ 38.0      │ 1.6456  │ 6.44065   │ 4.26344 │ 32.1952 │
# │ 12  │ 4807  │ 48070 │ 1.0     │ 21.0      │ 1.39401 │ 3.12438   │ 2.44113 │ 11.1755 │
# │ 13  │ 3405  │ 34050 │ 1.0     │ 85.0      │ 2.22496 │ 20.8489   │ 7.31834 │ 91.6598 │
# │ 14  │ 2102  │ 21020 │ 1.0     │ 92.0      │ 1.6746  │ 13.6961   │ 11.5235 │ 217.6   │
# │ 15  │ 2381  │ 23810 │ 1.0     │ 61.0      │ 2.8278  │ 24.7418   │ 4.0565  │ 25.7175 │
# │ 16  │ 3948  │ 39480 │ 1.0     │ 389.0     │ 4.51039 │ 205.215   │ 13.8769 │ 299.235 │
# │ 17  │ 3211  │ 32110 │ 1.0     │ 42.0      │ 1.763   │ 7.50487   │ 3.95356 │ 28.2967 │
# │ 18  │ 4476  │ 44760 │ 1.0     │ 61.0      │ 2.15974 │ 12.4391   │ 4.76483 │ 42.9224 │
# │ 19  │ 3817  │ 38170 │ 1.0     │ 169.0     │ 3.43385 │ 73.0528   │ 8.17572 │ 101.036 │
# │ 20  │ 2958  │ 29580 │ 1.0     │ 33910.0   │ 117.769 │ 1.82417e6 │ 18.3259 │ 398.081 │
# │ 21  │ 4334  │ 43340 │ 1.0     │ 257818.0  │ 160.777 │ 2.26038e7 │ 43.4712 │ 2142.81 │
# │ 22  │ 4018  │ 40180 │ 1.0     │ 2857.0    │ 11.7073 │ 6121.06   │ 22.1494 │ 636.878 │
# │ 23  │ 4180  │ 41800 │ 1.0     │ 12300.0   │ 11.9273 │ 38027.9   │ 60.0481 │ 3771.6  │
# │ 24  │ 3222  │ 32220 │ 1.0     │ 46.0      │ 1.8144  │ 7.6973    │ 3.96454 │ 31.7096 │
# │ 25  │ 2488  │ 24880 │ 1.0     │ 129.0     │ 3.32315 │ 71.7982   │ 6.5862  │ 61.1566 │
# │ 26  │ 4035  │ 40350 │ 1.0     │ 1914.0    │ 4.8969  │ 1056.7    │ 50.6381 │ 2948.64 │
# │ 27  │ 4626  │ 46260 │ 1.0     │ 1024.0    │ 5.06788 │ 697.271   │ 24.493  │ 802.172 │
# │ 28  │ 3522  │ 35220 │ 1.0     │ 1.15116e6 │ 617.693 │ 5.03167e8 │ 45.7276 │ 2182.5  │
# │ 29  │ 4566  │ 45660 │ 1.0     │ 225.0     │ 3.39181 │ 85.5439   │ 11.5059 │ 200.297 │
# │ 30  │ 2378  │ 23780 │ 1.0     │ 21.0      │ 1.4651  │ 4.1151    │ 3.0313  │ 14.3777 │
#
#
#
# for variance = 0.6, the result is as follows:
# df = 30×8 DataFrame
# │ Row │ n     │ p     │ median  │ max     │ mean    │ var      │ skew    │ kur     │
# │     │ Int64 │ Int64 │ Float64 │ Float64 │ Float64 │ Float64  │ Float64 │ Float64 │
# ├─────┼───────┼───────┼─────────┼─────────┼─────────┼──────────┼─────────┼─────────┤
# │ 1   │ 4757  │ 47570 │ 1.0     │ 511.0   │ 5.74522 │ 411.444  │ 11.928  │ 211.763 │
# │ 2   │ 4316  │ 43160 │ 1.0     │ 2959.0  │ 9.05283 │ 4222.19  │ 27.0121 │ 1055.87 │
# │ 3   │ 3516  │ 35160 │ 1.0     │ 1891.0  │ 8.98208 │ 2542.37  │ 22.95   │ 705.49  │
# │ 4   │ 4109  │ 41090 │ 1.0     │ 176.0   │ 3.42322 │ 83.8839  │ 8.81816 │ 114.978 │
# │ 5   │ 2987  │ 29870 │ 1.0     │ 1565.0  │ 9.21794 │ 2945.26  │ 17.7489 │ 404.098 │
# │ 6   │ 4045  │ 40450 │ 1.0     │ 3939.0  │ 20.7713 │ 17201.3  │ 17.1966 │ 381.926 │
# │ 7   │ 4871  │ 48710 │ 1.0     │ 155.0   │ 5.78998 │ 178.382  │ 4.41154 │ 24.8538 │
# │ 8   │ 2839  │ 28390 │ 1.0     │ 1409.0  │ 10.0085 │ 3515.87  │ 14.8422 │ 270.123 │
# │ 9   │ 2140  │ 21400 │ 1.0     │ 12825.0 │ 22.0449 │ 98405.2  │ 34.0474 │ 1321.21 │
# │ 10  │ 3982  │ 39820 │ 1.0     │ 4109.0  │ 14.2082 │ 9912.18  │ 23.2712 │ 790.957 │
# │ 11  │ 4066  │ 40660 │ 1.0     │ 103.0   │ 4.49065 │ 80.9944  │ 3.71238 │ 18.2047 │
# │ 12  │ 3911  │ 39110 │ 1.0     │ 598.0   │ 2.89517 │ 127.198  │ 38.421  │ 1983.76 │
# │ 13  │ 3829  │ 38290 │ 1.0     │ 662.0   │ 3.33037 │ 251.997  │ 24.848  │ 877.105 │
# │ 14  │ 3843  │ 38430 │ 1.0     │ 355.0   │ 2.18215 │ 49.3676  │ 34.2541 │ 1660.73 │
# │ 15  │ 2915  │ 29150 │ 1.0     │ 275.0   │ 3.4765  │ 132.919  │ 11.1691 │ 179.767 │
# │ 16  │ 4083  │ 40830 │ 1.0     │ 3567.0  │ 8.23414 │ 4797.94  │ 36.5752 │ 1745.84 │
# │ 17  │ 2686  │ 26860 │ 1.0     │ 87.0    │ 3.1828  │ 35.8872  │ 4.35761 │ 29.8887 │
# │ 18  │ 3590  │ 35900 │ 1.0     │ 3088.0  │ 13.3401 │ 7984.11  │ 20.3247 │ 558.26  │
# │ 19  │ 4614  │ 46140 │ 1.0     │ 140.0   │ 4.76485 │ 126.77   │ 5.02128 │ 31.872  │
# │ 20  │ 2687  │ 26870 │ 1.0     │ 356.0   │ 3.10495 │ 167.579  │ 16.1655 │ 346.653 │
# │ 21  │ 2331  │ 23310 │ 1.0     │ 361.0   │ 5.59245 │ 331.793  │ 9.76767 │ 138.177 │
# │ 22  │ 3070  │ 30700 │ 1.0     │ 383.0   │ 6.23876 │ 478.278  │ 8.45055 │ 94.0873 │
# │ 23  │ 3589  │ 35890 │ 1.0     │ 154.0   │ 2.87044 │ 46.304   │ 8.46699 │ 121.036 │
# │ 24  │ 2114  │ 21140 │ 1.0     │ 143.0   │ 4.08136 │ 113.095  │ 7.02573 │ 67.3674 │
# │ 25  │ 4523  │ 45230 │ 1.0     │ 1464.0  │ 14.4577 │ 4463.5   │ 12.8226 │ 219.633 │
# │ 26  │ 3435  │ 34350 │ 1.0     │ 2962.0  │ 11.7354 │ 7213.48  │ 21.3323 │ 585.63  │
# │ 27  │ 4948  │ 49480 │ 1.0     │ 31380.0 │ 63.7112 │ 659867.0 │ 30.0842 │ 1051.74 │
# │ 28  │ 2153  │ 21530 │ 1.0     │ 7433.0  │ 14.5834 │ 30003.6  │ 37.7955 │ 1576.75 │
# │ 29  │ 4424  │ 44240 │ 1.0     │ 83.0    │ 3.53526 │ 34.256   │ 3.85194 │ 27.3875 │
# │ 30  │ 3088  │ 30880 │ 1.0     │ 1167.0  │ 7.20369 │ 896.905  │ 21.4377 │ 744.874 │
#
#
#
# for variance = 0.7, the result is as follows:
# df = 30×8 DataFrame
# │ Row │ n     │ p     │ median  │ max       │ mean      │ var        │ skew    │ kur     │
# │     │ Int64 │ Int64 │ Float64 │ Float64   │ Float64   │ Float64    │ Float64 │ Float64 │
# ├─────┼───────┼───────┼─────────┼───────────┼───────────┼────────────┼─────────┼─────────┤
# │ 1   │ 2590  │ 25900 │ 1.0     │ 11200.0   │ 50.8598   │ 1.56047e5  │ 18.2003 │ 405.752 │
# │ 2   │ 4492  │ 44920 │ 1.0     │ 1008.0    │ 30.0138   │ 11548.7    │ 5.82027 │ 36.6328 │
# │ 3   │ 4778  │ 47780 │ 1.0     │ 38596.0   │ 38.6478   │ 4.53491e5  │ 45.3081 │ 2388.14 │
# │ 4   │ 4515  │ 45150 │ 1.0     │ 3.19672e8 │ 1.67544e5 │ 3.48496e13 │ 46.0949 │ 2276.09 │
# │ 5   │ 3972  │ 39720 │ 1.0     │ 8846.0    │ 28.5932   │ 98902.6    │ 18.0102 │ 377.892 │
# │ 6   │ 4614  │ 46140 │ 1.0     │ 55.0      │ 2.14586   │ 14.0188    │ 4.6478  │ 35.7881 │
# │ 7   │ 3772  │ 37720 │ 1.0     │ 31379.0   │ 100.968   │ 7.61981e5  │ 24.8931 │ 774.708 │
# │ 8   │ 3860  │ 38600 │ 1.0     │ 503.0     │ 5.99689   │ 622.342    │ 11.2551 │ 164.49  │
# │ 9   │ 4296  │ 42960 │ 1.0     │ 2.05949e6 │ 786.332   │ 1.0209e9   │ 62.5054 │ 4012.36 │
# │ 10  │ 2141  │ 21410 │ 1.0     │ 64996.0   │ 181.512   │ 4.65259e6  │ 19.5381 │ 466.322 │
# │ 11  │ 4903  │ 49030 │ 1.0     │ 327.0     │ 4.22476   │ 157.246    │ 9.92079 │ 156.584 │
# │ 12  │ 2995  │ 29950 │ 1.0     │ 65135.0   │ 126.457   │ 3.28228e6  │ 25.4582 │ 760.236 │
# │ 13  │ 3462  │ 34620 │ 1.0     │ 1361.0    │ 7.42028   │ 1261.85    │ 21.6512 │ 688.244 │
# │ 14  │ 2525  │ 25250 │ 1.0     │ 6120.0    │ 30.2273   │ 56701.1    │ 19.8431 │ 429.261 │
# │ 15  │ 2703  │ 27030 │ 1.0     │ 598.0     │ 5.36182   │ 434.184    │ 14.6432 │ 314.984 │
# │ 16  │ 2787  │ 27870 │ 1.0     │ 553.0     │ 6.87801   │ 707.012    │ 10.1115 │ 137.132 │
# │ 17  │ 2237  │ 22370 │ 1.0     │ 37695.0   │ 51.878    │ 1.11843e6  │ 30.2312 │ 965.99  │
# │ 18  │ 4994  │ 49940 │ 1.0     │ 816.0     │ 5.29075   │ 814.63     │ 17.9412 │ 409.534 │
# │ 19  │ 3163  │ 31630 │ 1.0     │ 4662.0    │ 11.1948   │ 9688.52    │ 36.7635 │ 1627.82 │
# │ 20  │ 2145  │ 21450 │ 1.0     │ 1921.0    │ 8.92028   │ 2975.11    │ 23.8304 │ 748.606 │
# │ 21  │ 3638  │ 36380 │ 1.0     │ 134.0     │ 3.30044   │ 54.2487    │ 7.39982 │ 87.2436 │
# │ 22  │ 3270  │ 32700 │ 1.0     │ 541.0     │ 4.7208    │ 392.538    │ 14.6912 │ 308.565 │
# │ 23  │ 3826  │ 38260 │ 1.0     │ 789.0     │ 4.04705   │ 255.989    │ 32.7281 │ 1525.27 │
# │ 24  │ 2729  │ 27290 │ 1.0     │ 1853.0    │ 7.29938   │ 2884.42    │ 21.6248 │ 604.853 │
# │ 25  │ 3623  │ 36230 │ 1.0     │ 5478.0    │ 26.8438   │ 34035.2    │ 16.1388 │ 336.886 │
# │ 26  │ 4845  │ 48450 │ 1.0     │ 501.0     │ 6.48132   │ 477.021    │ 11.1903 │ 184.443 │
# │ 27  │ 4194  │ 41940 │ 1.0     │ 1424.0    │ 6.73295   │ 1091.48    │ 24.1815 │ 879.98  │
# │ 28  │ 2426  │ 24260 │ 1.0     │ 1668.0    │ 9.34666   │ 2568.07    │ 18.8806 │ 514.659 │
# │ 29  │ 4141  │ 41410 │ 1.0     │ 4250.0    │ 18.6875   │ 13752.8    │ 19.9463 │ 554.978 │
# │ 30  │ 4552  │ 45520 │ 1.0     │ 160.0     │ 4.37522   │ 117.326    │ 6.19389 │ 53.8106 │
#
#
#
# for variance = 0.8, the result is as follows:
# df = 30×8 DataFrame
# │ Row │ n     │ p     │ median  │ max       │ mean      │ var        │ skew    │ kur     │
# │     │ Int64 │ Int64 │ Float64 │ Float64   │ Float64   │ Float64    │ Float64 │ Float64 │
# ├─────┼───────┼───────┼─────────┼───────────┼───────────┼────────────┼─────────┼─────────┤
# │ 1   │ 3140  │ 31400 │ 1.0     │ 165.0     │ 4.97389   │ 113.376    │ 5.30764 │ 45.12   │
# │ 2   │ 3286  │ 32860 │ 1.0     │ 9.50154e8 │ 5.70738e5 │ 3.06096e14 │ 49.5942 │ 2648.59 │
# │ 3   │ 4303  │ 43030 │ 1.0     │ 204.0     │ 2.85243   │ 46.9487    │ 10.8469 │ 228.209 │
# │ 4   │ 4466  │ 44660 │ 1.0     │ 131.0     │ 3.68854   │ 72.3892    │ 6.66708 │ 66.5155 │
# │ 5   │ 4203  │ 42030 │ 1.0     │ 882.0     │ 8.26029   │ 759.793    │ 12.383  │ 279.162 │
# │ 6   │ 2618  │ 26180 │ 1.0     │ 35080.0   │ 71.3896   │ 1.02795e6  │ 28.6067 │ 896.505 │
# │ 7   │ 2594  │ 25940 │ 1.0     │ 719.0     │ 7.22359   │ 876.331    │ 11.9877 │ 201.779 │
# │ 8   │ 4936  │ 49360 │ 1.0     │ 306.0     │ 4.36994   │ 175.739    │ 10.4755 │ 164.546 │
# │ 9   │ 4888  │ 48880 │ 1.0     │ 259.0     │ 2.7543    │ 78.196     │ 12.6294 │ 240.637 │
# │ 10  │ 3913  │ 39130 │ 1.0     │ 2.42272e9 │ 3.39609e6 │ 4.99281e15 │ 27.4305 │ 829.683 │
# │ 11  │ 2042  │ 20420 │ 1.0     │ 9667.0    │ 33.4971   │ 1.15937e5  │ 19.0858 │ 432.836 │
# │ 12  │ 4002  │ 40020 │ 1.0     │ 27329.0   │ 50.3598   │ 3.66693e5  │ 32.9827 │ 1275.74 │
# │ 13  │ 2450  │ 24500 │ 1.0     │ 1.99079e6 │ 1418.91   │ 1.67409e9  │ 47.1142 │ 2281.0  │
# │ 14  │ 3844  │ 38440 │ 1.0     │ 890830.0  │ 694.458   │ 2.4086e8   │ 50.4907 │ 2829.31 │
# │ 15  │ 3622  │ 36220 │ 1.0     │ 1173.0    │ 11.4415   │ 2472.69    │ 11.7699 │ 194.64  │
# │ 16  │ 2917  │ 29170 │ 1.0     │ 4426.0    │ 24.8159   │ 21028.9    │ 17.9082 │ 427.284 │
# │ 17  │ 4504  │ 45040 │ 1.0     │ 146684.0  │ 261.984   │ 1.20517e7  │ 30.4722 │ 1113.07 │
# │ 18  │ 3824  │ 38240 │ 1.0     │ 10918.0   │ 26.3525   │ 84426.6    │ 25.9221 │ 807.026 │
# │ 19  │ 4814  │ 48140 │ 0.0     │ 3.97661e6 │ 3683.35   │ 7.89124e9  │ 32.0559 │ 1167.46 │
# │ 20  │ 4705  │ 47050 │ 1.0     │ 90.0      │ 4.68034   │ 81.3787    │ 3.36    │ 14.0869 │
# │ 21  │ 3004  │ 30040 │ 1.0     │ 295924.0  │ 263.365   │ 3.23724e7  │ 47.3211 │ 2429.87 │
# │ 22  │ 4677  │ 46770 │ 1.0     │ 3823.0    │ 13.9173   │ 14112.5    │ 22.1744 │ 590.349 │
# │ 23  │ 3689  │ 36890 │ 1.0     │ 2.2853e6  │ 979.335   │ 1.47054e9  │ 57.594  │ 3414.27 │
# │ 24  │ 3056  │ 30560 │ 1.0     │ 27719.0   │ 42.1777   │ 3.00777e5  │ 43.531  │ 2137.63 │
# │ 25  │ 4325  │ 43250 │ 1.0     │ 3071.0    │ 14.2694   │ 8094.93    │ 22.6498 │ 678.095 │
# │ 26  │ 4028  │ 40280 │ 1.0     │ 38221.0   │ 87.5484   │ 1.00614e6  │ 29.9829 │ 1065.8  │
# │ 27  │ 3083  │ 30830 │ 1.0     │ 1498.0    │ 18.5105   │ 6842.55    │ 9.54467 │ 114.46  │
# │ 28  │ 2728  │ 27280 │ 1.0     │ 5555.0    │ 19.4036   │ 21952.3    │ 24.7127 │ 800.872 │
# │ 29  │ 3493  │ 34930 │ 1.0     │ 55621.0   │ 111.917   │ 2.11062e6  │ 28.0161 │ 919.201 │
# │ 30  │ 3706  │ 37060 │ 1.0     │ 363.0     │ 7.72234   │ 585.095    │ 6.96112 │ 64.8478 │
#
#
#
# for variance = 0.9, the result is as follows:
# df = 30×8 DataFrame
# │ Row │ n     │ p     │ median  │ max       │ mean      │ var        │ skew    │ kur     │
# │     │ Int64 │ Int64 │ Float64 │ Float64   │ Float64   │ Float64    │ Float64 │ Float64 │
# ├─────┼───────┼───────┼─────────┼───────────┼───────────┼────────────┼─────────┼─────────┤
# │ 1   │ 2968  │ 29680 │ 1.0     │ 131356.0  │ 165.37    │ 7.84096e6  │ 38.8155 │ 1704.6  │
# │ 2   │ 4251  │ 42510 │ 1.0     │ 2956.0    │ 19.7913   │ 12707.8    │ 14.5521 │ 275.51  │
# │ 3   │ 4164  │ 41640 │ 1.0     │ 45447.0   │ 202.019   │ 2.96926e6  │ 15.1265 │ 272.386 │
# │ 4   │ 4104  │ 41040 │ 1.0     │ 73789.0   │ 55.6518   │ 1.43961e6  │ 57.2913 │ 3482.82 │
# │ 5   │ 3844  │ 38440 │ 1.0     │ 112205.0  │ 105.043   │ 4.29483e6  │ 44.9671 │ 2302.19 │
# │ 6   │ 3435  │ 34350 │ 1.0     │ 377.0     │ 6.34178   │ 319.051    │ 7.66712 │ 91.5325 │
# │ 7   │ 3745  │ 37450 │ 1.0     │ 14595.0   │ 90.1303   │ 4.74852e5  │ 13.0373 │ 198.595 │
# │ 8   │ 4225  │ 42250 │ 1.0     │ 67083.0   │ 123.076   │ 2.93284e6  │ 26.6684 │ 841.869 │
# │ 9   │ 2655  │ 26550 │ 1.0     │ 4628.0    │ 11.7902   │ 15616.9    │ 26.8559 │ 857.603 │
# │ 10  │ 2943  │ 29430 │ 1.0     │ 1788.0    │ 18.9657   │ 5393.04    │ 9.9035  │ 155.402 │
# │ 11  │ 4612  │ 46120 │ 1.0     │ 2924.0    │ 12.5022   │ 4693.1     │ 21.494  │ 755.378 │
# │ 12  │ 2642  │ 26420 │ 1.0     │ 8124.0    │ 15.6113   │ 36257.1    │ 32.5294 │ 1282.97 │
# │ 13  │ 4971  │ 49710 │ 1.0     │ 188999.0  │ 197.469   │ 1.26147e7  │ 39.7806 │ 1865.93 │
# │ 14  │ 4530  │ 45300 │ 1.0     │ 3580.0    │ 33.326    │ 27913.2    │ 11.1782 │ 168.55  │
# │ 15  │ 3286  │ 32860 │ 1.0     │ 20697.0   │ 68.2839   │ 3.61584e5  │ 21.6198 │ 590.569 │
# │ 16  │ 2112  │ 21120 │ 1.0     │ 6953.0    │ 12.08     │ 25236.0    │ 39.9452 │ 1726.65 │
# │ 17  │ 4477  │ 44770 │ 1.0     │ 23645.0   │ 23.4617   │ 1.46613e5  │ 53.8058 │ 3248.43 │
# │ 18  │ 2842  │ 28420 │ 1.0     │ 52393.0   │ 176.345   │ 1.93201e6  │ 22.688  │ 736.488 │
# │ 19  │ 4560  │ 45600 │ 1.0     │ 2.72056e7 │ 7194.88   │ 1.63954e11 │ 66.5419 │ 4463.71 │
# │ 20  │ 3728  │ 37280 │ 1.0     │ 1.76771e6 │ 1063.28   │ 1.26338e9  │ 41.9416 │ 1886.7  │
# │ 21  │ 3457  │ 34570 │ 1.0     │ 3527.0    │ 31.5632   │ 23524.8    │ 11.2493 │ 173.683 │
# │ 22  │ 2621  │ 26210 │ 1.0     │ 52339.0   │ 68.9252   │ 1.57623e6  │ 33.9034 │ 1271.52 │
# │ 23  │ 4941  │ 49410 │ 1.0     │ 37583.0   │ 76.3449   │ 5.13831e5  │ 33.3923 │ 1567.25 │
# │ 24  │ 3074  │ 30740 │ 1.0     │ 1.41514e9 │ 1.01394e6 │ 1.31715e15 │ 38.5699 │ 1497.95 │
# │ 25  │ 4716  │ 47160 │ 1.0     │ 48634.0   │ 130.974   │ 2.02243e6  │ 22.0633 │ 593.97  │
# │ 26  │ 3534  │ 35340 │ 1.0     │ 1498.0    │ 8.92134   │ 2059.14    │ 18.7609 │ 483.129 │
# │ 27  │ 3266  │ 32660 │ 1.0     │ 183204.0  │ 120.111   │ 1.0631e7   │ 54.3684 │ 3043.43 │
# │ 28  │ 4355  │ 43550 │ 1.0     │ 4.37821e6 │ 1891.08   │ 4.7373e9   │ 59.7867 │ 3761.48 │
# │ 29  │ 4074  │ 40740 │ 1.0     │ 11566.0   │ 54.5037   │ 1.81357e5  │ 19.6416 │ 443.326 │
# │ 30  │ 2941  │ 29410 │ 1.0     │ 5717.0    │ 16.7154   │ 23142.4    │ 24.8533 │ 788.222 │
#
#
#
# for variance = 1.0, the result is as follows:
# df = 30×8 DataFrame
# │ Row │ n     │ p     │ median  │ max        │ mean      │ var        │ skew    │ kur     │
# │     │ Int64 │ Int64 │ Float64 │ Float64    │ Float64   │ Float64    │ Float64 │ Float64 │
# ├─────┼───────┼───────┼─────────┼────────────┼───────────┼────────────┼─────────┼─────────┤
# │ 1   │ 2279  │ 22790 │ 1.0     │ 251872.0   │ 539.539   │ 9.02456e7  │ 21.1603 │ 470.51  │
# │ 2   │ 2036  │ 20360 │ 1.0     │ 21632.0    │ 97.9386   │ 565412.0   │ 20.0551 │ 492.187 │
# │ 3   │ 4671  │ 46710 │ 1.0     │ 90503.0    │ 80.4098   │ 2.23155e6  │ 51.0481 │ 2947.85 │
# │ 4   │ 4525  │ 45250 │ 1.0     │ 2382.0     │ 8.82917   │ 2687.41    │ 27.012  │ 1052.09 │
# │ 5   │ 3591  │ 35910 │ 1.0     │ 186651.0   │ 281.39    │ 2.21008e7  │ 28.9725 │ 952.447 │
# │ 6   │ 3622  │ 36220 │ 1.0     │ 5889.0     │ 37.3495   │ 47544.5    │ 15.4819 │ 306.014 │
# │ 7   │ 3662  │ 36620 │ 1.0     │ 11159.0    │ 36.0055   │ 78576.8    │ 24.0033 │ 785.36  │
# │ 8   │ 2902  │ 29020 │ 1.0     │ 62791.0    │ 166.365   │ 3.39627e6  │ 23.5628 │ 659.682 │
# │ 9   │ 3287  │ 32870 │ 2.0     │ 959.0      │ 15.6069   │ 2724.35    │ 9.05206 │ 110.304 │
# │ 10  │ 3658  │ 36580 │ 1.0     │ 111494.0   │ 175.172   │ 7.16227e6  │ 29.4873 │ 1040.23 │
# │ 11  │ 3733  │ 37330 │ 1.0     │ 304617.0   │ 268.027   │ 3.5813e7   │ 40.706  │ 1896.25 │
# │ 12  │ 4052  │ 40520 │ 1.0     │ 17599.0    │ 23.0121   │ 1.15894e5  │ 39.489  │ 1855.23 │
# │ 13  │ 3833  │ 38330 │ 1.0     │ 695.0      │ 9.24341   │ 1128.53    │ 10.1388 │ 143.489 │
# │ 14  │ 3160  │ 31600 │ 1.0     │ 1.43062e7  │ 24205.6   │ 2.00984e11 │ 27.3413 │ 811.527 │
# │ 15  │ 3669  │ 36690 │ 1.0     │ 203075.0   │ 260.126   │ 1.87458e7  │ 37.5255 │ 1595.12 │
# │ 16  │ 4770  │ 47700 │ 1.0     │ 36336.0    │ 57.7914   │ 6.50775e5  │ 33.5664 │ 1290.42 │
# │ 17  │ 2806  │ 28060 │ 1.0     │ 27948.0    │ 78.1287   │ 1.03436e6  │ 21.4669 │ 500.478 │
# │ 18  │ 3094  │ 30940 │ 1.0     │ 132333.0   │ 68.1613   │ 5.86423e6  │ 52.959  │ 2877.49 │
# │ 19  │ 2358  │ 23580 │ 1.0     │ 1.56428e6  │ 1006.28   │ 1.12615e9  │ 43.8125 │ 2007.09 │
# │ 20  │ 3104  │ 31040 │ 1.0     │ 2.14759e10 │ 7.52334e6 │ 1.48842e17 │ 55.542  │ 3088.03 │
# │ 21  │ 2348  │ 23480 │ 1.0     │ 88385.0    │ 123.781   │ 5.9036e6   │ 33.2074 │ 1132.84 │
# │ 22  │ 3878  │ 38780 │ 1.0     │ 13384.0    │ 35.7803   │ 1.03043e5  │ 27.6775 │ 969.129 │
# │ 23  │ 3557  │ 35570 │ 1.0     │ 553.0      │ 5.49452   │ 581.656    │ 14.4916 │ 255.895 │
# │ 24  │ 2705  │ 27050 │ 1.0     │ 800613.0   │ 910.512   │ 2.87664e8  │ 40.443  │ 1844.65 │
# │ 25  │ 2232  │ 22320 │ 1.0     │ 174.0      │ 3.10529   │ 60.3704    │ 9.18583 │ 142.8   │
# │ 26  │ 3147  │ 31470 │ 1.0     │ 3.82093e6  │ 2089.94   │ 4.7972e9   │ 53.4341 │ 2936.25 │
# │ 27  │ 4177  │ 41770 │ 1.0     │ 1.84218e6  │ 1830.63   │ 1.5356e9   │ 34.6526 │ 1392.06 │
# │ 28  │ 3794  │ 37940 │ 1.0     │ 48794.0    │ 60.8548   │ 1.14876e6  │ 38.5171 │ 1607.37 │
# │ 29  │ 4274  │ 42740 │ 1.0     │ 3174.0     │ 22.3849   │ 14117.2    │ 13.6175 │ 259.509 │
# │ 30  │ 2289  │ 22890 │ 1.0     │ 43013.0    │ 132.941   │ 2.18231e6  │ 22.0785 │ 558.524 │

# %% [markdown]
# ## Examine reconstruction for variance = 0.4
#
# From the above, it seems like variance = 0.4 is a reasonable choice for $\beta$. Below simulate 50 different SNP matrices, with 50 different $\beta \sim N(0, 0.4)$, to examine reconstruction behavior. Overall, IHT struggles to find effect sizes $< 0.1$ but performs well for larger values.

# %%
#some function that runs poisson regression on different SNP matrices
function run_poisson(n :: Int64, p :: Int64, k :: Int64)    
    #set random seed
    Random.seed!(1111)

    #construct snpmatrix, covariate files, and true model b
    x, maf = simulate_random_snparray(n, p)
    xbm = SnpBitMatrix{Float64}(x, model=ADDITIVE_MODEL, center=true, scale=true); 
    z = ones(n, 1) # non-genetic covariates, just the intercept
    true_b = zeros(p)
    true_b[1:k] = rand(Normal(0, 0.4), k)
    shuffle!(true_b)
    correct_position = findall(x -> x != 0, true_b)

    # Simulate poisson data
    y_temp = xbm * true_b
    λ = exp.(y_temp) #inverse log link
    y = [rand(Poisson(x)) for x in λ]
    y = Float64.(y)

    #compute poisson IHT result
    result = L0_poisson_reg(x, z, y, 1, k, glm = "poisson", debias=false, convg=false, show_info=false)

    #check result
    estimated_models = result.beta[correct_position]
    true_model = true_b[correct_position]
    compare_model = DataFrame(
        true_β      = true_model, 
        estimated_β = estimated_models)
    
    #display results
    @show sort(compare_model, rev=true, by=abs)
    println("Total iteration number was " * string(result.iter))
    println("Total time was " * string(result.time))
    println("median of y = " * string(median(y)))
    println("maximum of y = " * string(maximum(y)))
    println("minimum of y = " * string(minimum(y)))
    println("skewness of y = " * string(skewness(y)))
    println("kurtosis of y = " * string(kurtosis(y)))
    println("mean of y = " * string(mean(y)))
    println("variance of y = " * string(var(y)))
    println("var / mean = " * string(var(y) / mean(y)) * "\n\n")
end
# Out:
# run_poisson (generic function with 1 method)

# %%
k = 10
for i = 1:50
    println("running the $i th model")
    n = rand(500:2000) 
    p = rand(1:10)n
    println("n, p = " * string(n) * ", " * string(p))
    run_poisson(n, p, k)
end
# Out:
# running the 1 th model
# n, p = 803, 8030
# sort(compare_model, rev=true, by=abs) = 10×2 DataFrame
# │ Row │ true_β     │ estimated_β │
# │     │ Float64    │ Float64     │
# ├─────┼────────────┼─────────────┤
# │ 1   │ 1.09447    │ 1.12531     │
# │ 2   │ 0.556104   │ 0.536675    │
# │ 3   │ 0.429742   │ 0.429157    │
# │ 4   │ -0.397894  │ 0.0         │
# │ 5   │ -0.362368  │ 0.0         │
# │ 6   │ 0.313917   │ 0.3287      │
# │ 7   │ 0.26377    │ 0.237004    │
# │ 8   │ 0.228922   │ 0.222751    │
# │ 9   │ -0.219458  │ -0.24286    │
# │ 10  │ -0.0312748 │ 0.0         │
# Total iteration number was 57
# Total time was 2.2881321907043457
# median of y = 1.0
# maximum of y = 87.0
# minimum of y = 0.0
# skewness of y = 5.516287937432489
# kurtosis of y = 49.98787061852346
# mean of y = 2.955168119551681
# variance of y = 38.68377313254844
# var / mean = 13.090210630188116
#
#
# running the 2 th model
# n, p = 1096, 7672
# sort(compare_model, rev=true, by=abs) = 10×2 DataFrame
# │ Row │ true_β     │ estimated_β │
# │     │ Float64    │ Float64     │
# ├─────┼────────────┼─────────────┤
# │ 1   │ -0.421428  │ 0.0         │
# │ 2   │ -0.243026  │ -0.261018   │
# │ 3   │ 0.222792   │ 0.220576    │
# │ 4   │ 0.219633   │ 0.193754    │
# │ 5   │ 0.19329    │ 0.176161    │
# │ 6   │ 0.191148   │ 0.216279    │
# │ 7   │ -0.144022  │ -0.156244   │
# │ 8   │ -0.120044  │ 0.0         │
# │ 9   │ -0.114698  │ -0.130699   │
# │ 10  │ -0.0925887 │ 0.0         │
# Total iteration number was 9
# Total time was 0.4674549102783203
# median of y = 1.0
# maximum of y = 11.0
# minimum of y = 0.0
# skewness of y = 1.7218125440593044
# kurtosis of y = 4.887380418990293
# mean of y = 1.227189781021898
# variance of y = 1.8798445155484456
# var / mean = 1.5318286907368746
#
#
# running the 3 th model
# n, p = 1429, 1429
# sort(compare_model, rev=true, by=abs) = 10×2 DataFrame
# │ Row │ true_β     │ estimated_β │
# │     │ Float64    │ Float64     │
# ├─────┼────────────┼─────────────┤
# │ 1   │ -0.672938  │ -0.651374   │
# │ 2   │ 0.663165   │ 0.67558     │
# │ 3   │ -0.547261  │ -0.569649   │
# │ 4   │ 0.396616   │ 0.402823    │
# │ 5   │ 0.275042   │ 0.267734    │
# │ 6   │ -0.221236  │ -0.212316   │
# │ 7   │ 0.0925328  │ 0.0759971   │
# │ 8   │ -0.0818771 │ -0.107655   │
# │ 9   │ -0.0783058 │ -0.0734947  │
# │ 10  │ -0.0444548 │ 0.0         │
# Total iteration number was 46
# Total time was 0.5048229694366455
# median of y = 1.0
# maximum of y = 145.0
# minimum of y = 0.0
# skewness of y = 9.774162994591082
# kurtosis of y = 137.3917295101477
# mean of y = 2.639608117564731
# variance of y = 55.951959510186164
# var / mean = 21.19707055674868
#
#
# running the 4 th model
# n, p = 1709, 8545
# sort(compare_model, rev=true, by=abs) = 10×2 DataFrame
# │ Row │ true_β     │ estimated_β │
# │     │ Float64    │ Float64     │
# ├─────┼────────────┼─────────────┤
# │ 1   │ -0.691605  │ -0.659874   │
# │ 2   │ -0.494285  │ -0.466211   │
# │ 3   │ -0.443869  │ -0.445088   │
# │ 4   │ -0.415522  │ -0.435229   │
# │ 5   │ 0.293053   │ 0.303241    │
# │ 6   │ 0.292553   │ 0.314208    │
# │ 7   │ 0.233092   │ 0.229661    │
# │ 8   │ 0.189826   │ 0.206772    │
# │ 9   │ -0.0577736 │ 0.0         │
# │ 10  │ 0.0463887  │ 0.0         │
# Total iteration number was 27
# Total time was 2.170585870742798
# median of y = 1.0
# maximum of y = 35.0
# minimum of y = 0.0
# skewness of y = 3.5670317646247343
# kurtosis of y = 25.706215229167796
# mean of y = 1.7794031597425395
# variance of y = 6.412081376594223
# var / mean = 3.603501174810762
#
#
# running the 5 th model
# n, p = 1270, 2540
# sort(compare_model, rev=true, by=abs) = 10×2 DataFrame
# │ Row │ true_β     │ estimated_β │
# │     │ Float64    │ Float64     │
# ├─────┼────────────┼─────────────┤
# │ 1   │ -0.63286   │ -0.626803   │
# │ 2   │ 0.55026    │ 0.535451    │
# │ 3   │ 0.398311   │ 0.373221    │
# │ 4   │ 0.212651   │ 0.232345    │
# │ 5   │ 0.146906   │ 0.151337    │
# │ 6   │ 0.0823376  │ 0.0         │
# │ 7   │ -0.068387  │ 0.0         │
# │ 8   │ -0.0349153 │ 0.0         │
# │ 9   │ 0.0236399  │ 0.0         │
# │ 10  │ 0.0223236  │ 0.0         │
# Total iteration number was 22
# Total time was 0.39808201789855957
# median of y = 1.0
# maximum of y = 45.0
# minimum of y = 0.0
# skewness of y = 6.744567455112412
# kurtosis of y = 77.80371258117317
# mean of y = 1.674015748031496
# variance of y = 7.838488983203342
# var / mean = 4.682446382252231
#
#
# running the 6 th model
# n, p = 1648, 8240
# sort(compare_model, rev=true, by=abs) = 10×2 DataFrame
# │ Row │ true_β    │ estimated_β │
# │     │ Float64   │ Float64     │
# ├─────┼───────────┼─────────────┤
# │ 1   │ -0.657448 │ -0.657099   │
# │ 2   │ 0.623298  │ 0.653143    │
# │ 3   │ -0.517544 │ -0.47733    │
# │ 4   │ 0.387968  │ 0.381065    │
# │ 5   │ -0.289944 │ -0.332319   │
# │ 6   │ -0.189978 │ -0.178984   │
# │ 7   │ 0.17906   │ 0.170956    │
# │ 8   │ 0.0898609 │ 0.0902518   │
# │ 9   │ 0.0892657 │ 0.067134    │
# │ 10  │ 0.0740675 │ 0.075391    │
# Total iteration number was 35
# Total time was 2.5921499729156494
# median of y = 1.0
# maximum of y = 62.0
# minimum of y = 0.0
# skewness of y = 5.5272825890960595
# kurtosis of y = 52.73085140185642
# mean of y = 2.1074029126213594
# variance of y = 15.279896590446889
# var / mean = 7.250581509086229
#
#
# running the 7 th model
# n, p = 752, 7520
# sort(compare_model, rev=true, by=abs) = 10×2 DataFrame
# │ Row │ true_β    │ estimated_β │
# │     │ Float64   │ Float64     │
# ├─────┼───────────┼─────────────┤
# │ 1   │ 0.655102  │ 0.700711    │
# │ 2   │ 0.597136  │ 0.576069    │
# │ 3   │ 0.563292  │ 0.491151    │
# │ 4   │ 0.490291  │ 0.503518    │
# │ 5   │ -0.464176 │ -0.484315   │
# │ 6   │ 0.451658  │ 0.526641    │
# │ 7   │ -0.368225 │ 0.0         │
# │ 8   │ -0.289853 │ 0.0         │
# │ 9   │ 0.23543   │ 0.198718    │
# │ 10  │ -0.151885 │ -0.111055   │
# Total iteration number was 56
# Total time was 1.7623438835144043
# median of y = 1.0
# maximum of y = 79.0
# minimum of y = 0.0
# skewness of y = 6.300954830768347
# kurtosis of y = 56.546230388378504
# mean of y = 2.7699468085106385
# variance of y = 40.55020079610167
# var / mean = 14.639342774204732
#
#
# running the 8 th model
# n, p = 1023, 1023
# sort(compare_model, rev=true, by=abs) = 10×2 DataFrame
# │ Row │ true_β    │ estimated_β │
# │     │ Float64   │ Float64     │
# ├─────┼───────────┼─────────────┤
# │ 1   │ -0.619902 │ -0.631182   │
# │ 2   │ -0.59816  │ -0.575796   │
# │ 3   │ -0.435113 │ -0.430941   │
# │ 4   │ -0.424027 │ -0.366112   │
# │ 5   │ -0.359678 │ -0.340601   │
# │ 6   │ 0.253024  │ 0.252196    │
# │ 7   │ 0.23273   │ 0.233332    │
# │ 8   │ -0.223457 │ -0.238161   │
# │ 9   │ 0.202302  │ 0.24894     │
# │ 10  │ -0.171162 │ 0.0         │
# Total iteration number was 21
# Total time was 0.13019800186157227
# median of y = 1.0
# maximum of y = 27.0
# minimum of y = 0.0
# skewness of y = 2.838386140496378
# kurtosis of y = 13.902634982824054
# mean of y = 1.7976539589442815
# variance of y = 6.689935782291062
# var / mean = 3.721481405809547
#
#
# running the 9 th model
# n, p = 959, 6713
# sort(compare_model, rev=true, by=abs) = 10×2 DataFrame
# │ Row │ true_β     │ estimated_β │
# │     │ Float64    │ Float64     │
# ├─────┼────────────┼─────────────┤
# │ 1   │ 0.734945   │ 0.736444    │
# │ 2   │ -0.50076   │ -0.48188    │
# │ 3   │ -0.273886  │ 0.0         │
# │ 4   │ 0.233644   │ 0.255918    │
# │ 5   │ 0.22531    │ 0.236353    │
# │ 6   │ -0.195373  │ -0.216129   │
# │ 7   │ 0.121063   │ 0.0         │
# │ 8   │ 0.120382   │ 0.162167    │
# │ 9   │ -0.0591756 │ 0.0         │
# │ 10  │ 0.0236857  │ 0.0         │
# Total iteration number was 33
# Total time was 1.1650488376617432
# median of y = 1.0
# maximum of y = 69.0
# minimum of y = 0.0
# skewness of y = 8.073324579856804
# kurtosis of y = 101.90121418233507
# mean of y = 1.9280500521376434
# variance of y = 16.32571550479905
# var / mean = 8.467474942727035
#
#
# running the 10 th model
# n, p = 1182, 4728
# sort(compare_model, rev=true, by=abs) = 10×2 DataFrame
# │ Row │ true_β     │ estimated_β │
# │     │ Float64    │ Float64     │
# ├─────┼────────────┼─────────────┤
# │ 1   │ 0.55579    │ 0.58504     │
# │ 2   │ 0.437785   │ 0.43144     │
# │ 3   │ -0.257431  │ -0.279348   │
# │ 4   │ 0.202296   │ 0.220102    │
# │ 5   │ 0.197387   │ 0.191191    │
# │ 6   │ -0.0979579 │ 0.0         │
# │ 7   │ 0.0944912  │ 0.0         │
# │ 8   │ 0.0355498  │ 0.0         │
# │ 9   │ 0.0222328  │ 0.0         │
# │ 10  │ 0.011594   │ 0.0         │
# Total iteration number was 23
# Total time was 0.7266218662261963
# median of y = 1.0
# maximum of y = 18.0
# minimum of y = 0.0
# skewness of y = 2.3393651482791773
# kurtosis of y = 9.562859029153023
# mean of y = 1.4602368866328257
# variance of y = 3.3629391479015607
# var / mean = 2.3030093121782413
#
#
# running the 11 th model
# n, p = 1018, 2036
# sort(compare_model, rev=true, by=abs) = 10×2 DataFrame
# │ Row │ true_β    │ estimated_β │
# │     │ Float64   │ Float64     │
# ├─────┼───────────┼─────────────┤
# │ 1   │ 0.52834   │ 0.555489    │
# │ 2   │ 0.506332  │ 0.484085    │
# │ 3   │ -0.489109 │ -0.540414   │
# │ 4   │ 0.334007  │ 0.341309    │
# │ 5   │ 0.300403  │ 0.317697    │
# │ 6   │ 0.223972  │ 0.242141    │
# │ 7   │ 0.215679  │ 0.199287    │
# │ 8   │ 0.178786  │ 0.19816     │
# │ 9   │ 0.125529  │ 0.168703    │
# │ 10  │ 0.0449796 │ 0.0         │
# Total iteration number was 44
# Total time was 0.501000165939331
# median of y = 1.0
# maximum of y = 57.0
# minimum of y = 0.0
# skewness of y = 6.285640778563575
# kurtosis of y = 79.58110932948532
# mean of y = 1.9233791748526523
# variance of y = 10.959708530617997
# var / mean = 5.698152851976057
#
#
# running the 12 th model
# n, p = 877, 3508
# sort(compare_model, rev=true, by=abs) = 10×2 DataFrame
# │ Row │ true_β     │ estimated_β │
# │     │ Float64    │ Float64     │
# ├─────┼────────────┼─────────────┤
# │ 1   │ 0.639781   │ 0.635888    │
# │ 2   │ -0.548769  │ -0.596654   │
# │ 3   │ 0.473359   │ 0.429259    │
# │ 4   │ 0.435602   │ 0.436465    │
# │ 5   │ -0.348129  │ -0.373945   │
# │ 6   │ 0.29436    │ 0.334104    │
# │ 7   │ 0.277273   │ 0.257038    │
# │ 8   │ 0.114072   │ 0.0         │
# │ 9   │ 0.0615428  │ 0.0         │
# │ 10  │ -0.0564808 │ 0.0         │
# Total iteration number was 147
# Total time was 2.443878173828125
# median of y = 1.0
# maximum of y = 427.0
# minimum of y = 0.0
# skewness of y = 21.573580368652905
# kurtosis of y = 552.1039633133731
# mean of y = 3.115165336374002
# variance of y = 258.45818299203927
# var / mean = 82.96772565300822
#
#
# running the 13 th model
# n, p = 1925, 7700
# sort(compare_model, rev=true, by=abs) = 10×2 DataFrame
# │ Row │ true_β    │ estimated_β │
# │     │ Float64   │ Float64     │
# ├─────┼───────────┼─────────────┤
# │ 1   │ 0.775865  │ 0.833506    │
# │ 2   │ 0.510542  │ 0.550274    │
# │ 3   │ 0.42837   │ 0.440256    │
# │ 4   │ -0.408308 │ -0.417351   │
# │ 5   │ -0.407132 │ 0.0         │
# │ 6   │ -0.346397 │ -0.321188   │
# │ 7   │ -0.301558 │ -0.271675   │
# │ 8   │ 0.300762  │ 0.30268     │
# │ 9   │ -0.136967 │ -0.121112   │
# │ 10  │ -0.125687 │ 0.0         │
# Total iteration number was 30
# Total time was 2.486325979232788
# median of y = 1.0
# maximum of y = 115.0
# minimum of y = 0.0
# skewness of y = 10.056041260154942
# kurtosis of y = 193.904378115146
# mean of y = 2.205194805194805
# variance of y = 21.567540567540565
# var / mean = 9.780333472912977
#
#
# running the 14 th model
# n, p = 1824, 1824
# sort(compare_model, rev=true, by=abs) = 10×2 DataFrame
# │ Row │ true_β     │ estimated_β │
# │     │ Float64    │ Float64     │
# ├─────┼────────────┼─────────────┤
# │ 1   │ -0.560129  │ -0.569984   │
# │ 2   │ -0.535179  │ -0.490374   │
# │ 3   │ 0.461466   │ 0.457529    │
# │ 4   │ 0.445444   │ 0.428901    │
# │ 5   │ 0.334547   │ 0.376526    │
# │ 6   │ 0.286356   │ 0.306014    │
# │ 7   │ 0.250049   │ 0.2357      │
# │ 8   │ 0.229895   │ 0.227186    │
# │ 9   │ -0.111633  │ -0.0921746  │
# │ 10  │ -0.0754671 │ 0.0         │
# Total iteration number was 26
# Total time was 0.4796009063720703
# median of y = 1.0
# maximum of y = 33.0
# minimum of y = 0.0
# skewness of y = 3.957737041584973
# kurtosis of y = 22.857936203609157
# mean of y = 1.9396929824561404
# variance of y = 10.879520695595259
# var / mean = 5.608888001347019
#
#
# running the 15 th model
# n, p = 1644, 1644
# sort(compare_model, rev=true, by=abs) = 10×2 DataFrame
# │ Row │ true_β     │ estimated_β │
# │     │ Float64    │ Float64     │
# ├─────┼────────────┼─────────────┤
# │ 1   │ -0.498235  │ -0.516105   │
# │ 2   │ -0.439091  │ -0.452164   │
# │ 3   │ -0.387941  │ -0.336617   │
# │ 4   │ 0.270202   │ 0.270796    │
# │ 5   │ -0.260078  │ -0.269271   │
# │ 6   │ -0.214704  │ -0.223385   │
# │ 7   │ -0.214425  │ -0.235627   │
# │ 8   │ -0.0893121 │ -0.108033   │
# │ 9   │ -0.0384165 │ 0.0         │
# │ 10  │ -0.0179423 │ 0.0         │
# Total iteration number was 31
# Total time was 0.4689300060272217
# median of y = 1.0
# maximum of y = 11.0
# minimum of y = 0.0
# skewness of y = 1.59028440694427
# kurtosis of y = 3.1087608343698916
# mean of y = 1.4190997566909975
# variance of y = 2.6124408202312255
# var / mean = 1.8409141485041298
#
#
# running the 16 th model
# n, p = 913, 9130
# sort(compare_model, rev=true, by=abs) = 10×2 DataFrame
# │ Row │ true_β    │ estimated_β │
# │     │ Float64   │ Float64     │
# ├─────┼───────────┼─────────────┤
# │ 1   │ 0.690459  │ 0.686778    │
# │ 2   │ 0.429032  │ 0.424285    │
# │ 3   │ -0.377099 │ -0.355197   │
# │ 4   │ 0.297677  │ 0.301871    │
# │ 5   │ -0.221706 │ 0.0         │
# │ 6   │ -0.151995 │ -0.173222   │
# │ 7   │ 0.12399   │ 0.115853    │
# │ 8   │ 0.10914   │ 0.0995332   │
# │ 9   │ 0.0861979 │ 0.0         │
# │ 10  │ 0.0459461 │ 0.0         │
# Total iteration number was 15
# Total time was 0.7478580474853516
# median of y = 1.0
# maximum of y = 32.0
# minimum of y = 0.0
# skewness of y = 4.052948279286975
# kurtosis of y = 28.930390608915346
# mean of y = 1.6506024096385543
# variance of y = 6.771427816529279
# var / mean = 4.102397874247665
#
#
# running the 17 th model
# n, p = 1219, 1219
# sort(compare_model, rev=true, by=abs) = 10×2 DataFrame
# │ Row │ true_β    │ estimated_β │
# │     │ Float64   │ Float64     │
# ├─────┼───────────┼─────────────┤
# │ 1   │ -0.688037 │ -0.721583   │
# │ 2   │ 0.497129  │ 0.500005    │
# │ 3   │ -0.40798  │ -0.36953    │
# │ 4   │ -0.400113 │ -0.427256   │
# │ 5   │ -0.397325 │ -0.38238    │
# │ 6   │ 0.393242  │ 0.379369    │
# │ 7   │ -0.328086 │ -0.308734   │
# │ 8   │ -0.231065 │ -0.237085   │
# │ 9   │ 0.209034  │ 0.248832    │
# │ 10  │ 0.0211293 │ 0.0         │
# Total iteration number was 62
# Total time was 0.5232529640197754
# median of y = 1.0
# maximum of y = 27.0
# minimum of y = 0.0
# skewness of y = 2.894535829344184
# kurtosis of y = 12.621635598917685
# mean of y = 1.9351927809680065
# variance of y = 7.812709548190863
# var / mean = 4.037173776703969
#
#
# running the 18 th model
# n, p = 1543, 15430
# sort(compare_model, rev=true, by=abs) = 10×2 DataFrame
# │ Row │ true_β     │ estimated_β │
# │     │ Float64    │ Float64     │
# ├─────┼────────────┼─────────────┤
# │ 1   │ -0.695143  │ -0.665317   │
# │ 2   │ 0.656008   │ 0.673917    │
# │ 3   │ -0.43652   │ -0.438381   │
# │ 4   │ -0.432716  │ 0.0         │
# │ 5   │ -0.224173  │ -0.228353   │
# │ 6   │ 0.192718   │ 0.17025     │
# │ 7   │ -0.172238  │ -0.15837    │
# │ 8   │ 0.117405   │ 0.0         │
# │ 9   │ 0.0643859  │ 0.0         │
# │ 10  │ -0.0555097 │ 0.0         │
# Total iteration number was 62
# Total time was 8.169988870620728
# median of y = 1.0
# maximum of y = 16.0
# minimum of y = 0.0
# skewness of y = 2.0415309496614666
# kurtosis of y = 5.134671942332485
# mean of y = 1.8502916396629943
# variance of y = 5.915964571181682
# var / mean = 3.1973146526561593
#
#
# running the 19 th model
# n, p = 1410, 12690
# sort(compare_model, rev=true, by=abs) = 10×2 DataFrame
# │ Row │ true_β     │ estimated_β │
# │     │ Float64    │ Float64     │
# ├─────┼────────────┼─────────────┤
# │ 1   │ 0.542051   │ 0.504827    │
# │ 2   │ 0.335399   │ 0.373334    │
# │ 3   │ -0.218034  │ -0.246889   │
# │ 4   │ 0.21248    │ 0.163786    │
# │ 5   │ 0.20352    │ 0.212465    │
# │ 6   │ -0.193827  │ -0.193898   │
# │ 7   │ 0.183678   │ 0.199327    │
# │ 8   │ -0.108478  │ 0.0         │
# │ 9   │ 0.0532826  │ 0.0         │
# │ 10  │ -0.0184006 │ 0.0         │
# Total iteration number was 26
# Total time was 2.7412071228027344
# median of y = 1.0
# maximum of y = 13.0
# minimum of y = 0.0
# skewness of y = 2.302505448796771
# kurtosis of y = 7.6700876254570005
# mean of y = 1.3921985815602838
# variance of y = 3.2719050279610813
# var / mean = 2.3501712121370986
#
#
# running the 20 th model
# n, p = 1467, 1467
# sort(compare_model, rev=true, by=abs) = 10×2 DataFrame
# │ Row │ true_β     │ estimated_β │
# │     │ Float64    │ Float64     │
# ├─────┼────────────┼─────────────┤
# │ 1   │ 0.842309   │ 0.822382    │
# │ 2   │ -0.792704  │ -0.781637   │
# │ 3   │ 0.752997   │ 0.757672    │
# │ 4   │ -0.544092  │ -0.538982   │
# │ 5   │ -0.410148  │ -0.390242   │
# │ 6   │ 0.380943   │ 0.384953    │
# │ 7   │ 0.294353   │ 0.282529    │
# │ 8   │ -0.165181  │ -0.207133   │
# │ 9   │ -0.0873729 │ -0.103051   │
# │ 10  │ 0.0313665  │ 0.0         │
# Total iteration number was 78
# Total time was 0.94309401512146
# median of y = 1.0
# maximum of y = 447.0
# minimum of y = 0.0
# skewness of y = 16.527839585561757
# kurtosis of y = 382.0235528940628
# mean of y = 4.213360599863667
# variance of y = 274.6713629824303
# var / mean = 65.19056616975008
#
#
# running the 21 th model
# n, p = 1814, 5442
# sort(compare_model, rev=true, by=abs) = 10×2 DataFrame
# │ Row │ true_β     │ estimated_β │
# │     │ Float64    │ Float64     │
# ├─────┼────────────┼─────────────┤
# │ 1   │ 0.680411   │ 0.658255    │
# │ 2   │ -0.61272   │ -0.603551   │
# │ 3   │ -0.452891  │ -0.474863   │
# │ 4   │ 0.338361   │ 0.342995    │
# │ 5   │ -0.326168  │ -0.331537   │
# │ 6   │ 0.286105   │ 0.277792    │
# │ 7   │ 0.226892   │ 0.240481    │
# │ 8   │ -0.0977464 │ -0.12191    │
# │ 9   │ -0.0225367 │ 0.0         │
# │ 10  │ 0.0198865  │ 0.0         │
# Total iteration number was 116
# Total time was 6.408205986022949
# median of y = 1.0
# maximum of y = 129.0
# minimum of y = 0.0
# skewness of y = 13.896285871902961
# kurtosis of y = 347.2844849892033
# mean of y = 2.065049614112459
# variance of y = 20.497696715683794
# var / mean = 9.926006898625307
#
#
# running the 22 th model
# n, p = 1887, 13209
# sort(compare_model, rev=true, by=abs) = 10×2 DataFrame
# │ Row │ true_β     │ estimated_β │
# │     │ Float64    │ Float64     │
# ├─────┼────────────┼─────────────┤
# │ 1   │ 0.655409   │ 0.631104    │
# │ 2   │ 0.469605   │ 0.498498    │
# │ 3   │ 0.315079   │ 0.298916    │
# │ 4   │ -0.294511  │ -0.318209   │
# │ 5   │ 0.247196   │ 0.282199    │
# │ 6   │ -0.0998982 │ 0.0         │
# │ 7   │ -0.0846695 │ 0.0         │
# │ 8   │ -0.0652092 │ 0.0         │
# │ 9   │ -0.02532   │ 0.0         │
# │ 10  │ 0.0110328  │ 0.0         │
# Total iteration number was 22
# Total time was 3.2102391719818115
# median of y = 1.0
# maximum of y = 59.0
# minimum of y = 0.0
# skewness of y = 6.757469948951246
# kurtosis of y = 72.98369577448175
# mean of y = 1.8235294117647058
# variance of y = 12.154949784791972
# var / mean = 6.665617623918179
#
#
# running the 23 th model
# n, p = 506, 4554
# sort(compare_model, rev=true, by=abs) = 10×2 DataFrame
# │ Row │ true_β    │ estimated_β │
# │     │ Float64   │ Float64     │
# ├─────┼───────────┼─────────────┤
# │ 1   │ 1.20707   │ 1.20472     │
# │ 2   │ -0.71006  │ -0.756123   │
# │ 3   │ -0.546664 │ -0.516361   │
# │ 4   │ 0.44764   │ 0.448724    │
# │ 5   │ 0.339322  │ 0.34457     │
# │ 6   │ -0.236622 │ -0.249834   │
# │ 7   │ -0.212293 │ -0.198483   │
# │ 8   │ -0.197448 │ -0.126957   │
# │ 9   │ -0.168816 │ -0.19072    │
# │ 10  │ 0.0478471 │ 0.0         │
# Total iteration number was 1000
# Total time was 12.018532037734985
# median of y = 1.0
# maximum of y = 9231.0
# minimum of y = 0.0
# skewness of y = 20.975965826466364
# kurtosis of y = 452.3856563287278
# mean of y = 28.1897233201581
# variance of y = 176997.88076546797
# var / mean = 6278.80872597636
#
#
# running the 24 th model
# n, p = 1638, 9828
# sort(compare_model, rev=true, by=abs) = 10×2 DataFrame
# │ Row │ true_β     │ estimated_β │
# │     │ Float64    │ Float64     │
# ├─────┼────────────┼─────────────┤
# │ 1   │ 0.701907   │ 0.689854    │
# │ 2   │ -0.454542  │ -0.485179   │
# │ 3   │ 0.409735   │ 0.392708    │
# │ 4   │ 0.300569   │ 0.290553    │
# │ 5   │ 0.271604   │ 0.275518    │
# │ 6   │ 0.258214   │ 0.26522     │
# │ 7   │ 0.239415   │ 0.207883    │
# │ 8   │ -0.216074  │ -0.188917   │
# │ 9   │ 0.215849   │ 0.210975    │
# │ 10  │ -0.0993059 │ 0.0         │
# Total iteration number was 36
# Total time was 3.1154279708862305
# median of y = 1.0
# maximum of y = 38.0
# minimum of y = 0.0
# skewness of y = 4.838229800688791
# kurtosis of y = 40.04708693113009
# mean of y = 1.7503052503052503
# variance of y = 8.294975471823363
# var / mean = 4.739159338279271
#
#
# running the 25 th model
# n, p = 691, 6219
# sort(compare_model, rev=true, by=abs) = 10×2 DataFrame
# │ Row │ true_β     │ estimated_β │
# │     │ Float64    │ Float64     │
# ├─────┼────────────┼─────────────┤
# │ 1   │ 0.825034   │ 0.802869    │
# │ 2   │ -0.775103  │ -0.80144    │
# │ 3   │ 0.651273   │ 0.631349    │
# │ 4   │ -0.287227  │ -0.3255     │
# │ 5   │ 0.190985   │ 0.179723    │
# │ 6   │ 0.170425   │ 0.208112    │
# │ 7   │ -0.101513  │ 0.0         │
# │ 8   │ 0.0882659  │ 0.0         │
# │ 9   │ 0.0748935  │ 0.0         │
# │ 10  │ -0.0630278 │ 0.0         │
# Total iteration number was 27
# Total time was 0.7056820392608643
# median of y = 1.0
# maximum of y = 39.0
# minimum of y = 0.0
# skewness of y = 4.403415284130933
# kurtosis of y = 26.699729252449597
# mean of y = 2.3111432706222867
# variance of y = 17.20015100987856
# var / mean = 7.442269472652526
#
#
# running the 26 th model
# n, p = 748, 6732
# sort(compare_model, rev=true, by=abs) = 10×2 DataFrame
# │ Row │ true_β      │ estimated_β │
# │     │ Float64     │ Float64     │
# ├─────┼─────────────┼─────────────┤
# │ 1   │ 0.676687    │ 0.690281    │
# │ 2   │ -0.642607   │ -0.645266   │
# │ 3   │ -0.526432   │ -0.561526   │
# │ 4   │ -0.470807   │ -0.407128   │
# │ 5   │ 0.445956    │ 0.425763    │
# │ 6   │ -0.236623   │ -0.231393   │
# │ 7   │ 0.164997    │ 0.197781    │
# │ 8   │ 0.107984    │ 0.145507    │
# │ 9   │ 0.0831514   │ 0.0         │
# │ 10  │ -0.00474566 │ 0.0         │
# Total iteration number was 29
# Total time was 0.8206908702850342
# median of y = 1.0
# maximum of y = 62.0
# minimum of y = 0.0
# skewness of y = 6.094808983644242
# kurtosis of y = 55.316009815077955
# mean of y = 2.3489304812834226
# variance of y = 22.20338573545519
# var / mean = 9.452551240819853
#
#
# running the 27 th model
# n, p = 1661, 1661
# sort(compare_model, rev=true, by=abs) = 10×2 DataFrame
# │ Row │ true_β     │ estimated_β │
# │     │ Float64    │ Float64     │
# ├─────┼────────────┼─────────────┤
# │ 1   │ 0.452027   │ 0.462808    │
# │ 2   │ 0.382812   │ 0.368343    │
# │ 3   │ 0.158363   │ 0.167162    │
# │ 4   │ 0.143185   │ 0.157059    │
# │ 5   │ -0.125709  │ 0.0         │
# │ 6   │ -0.095942  │ -0.0691613  │
# │ 7   │ 0.0829973  │ 0.0         │
# │ 8   │ 0.0784645  │ 0.0832705   │
# │ 9   │ 0.00360884 │ 0.0         │
# │ 10  │ -0.0028054 │ 0.0         │
# Total iteration number was 11
# Total time was 0.1900959014892578
# median of y = 1.0
# maximum of y = 13.0
# minimum of y = 0.0
# skewness of y = 2.590551349637755
# kurtosis of y = 10.572349686678285
# mean of y = 1.283564118001204
# variance of y = 2.698458614711706
# var / mean = 2.102316960148285
#
#
# running the 28 th model
# n, p = 1281, 11529
# sort(compare_model, rev=true, by=abs) = 10×2 DataFrame
# │ Row │ true_β     │ estimated_β │
# │     │ Float64    │ Float64     │
# ├─────┼────────────┼─────────────┤
# │ 1   │ -0.338215  │ 0.0         │
# │ 2   │ -0.335379  │ -0.364675   │
# │ 3   │ 0.266487   │ 0.315939    │
# │ 4   │ 0.240297   │ 0.25825     │
# │ 5   │ -0.195597  │ 0.0         │
# │ 6   │ -0.19459   │ -0.19304    │
# │ 7   │ -0.193019  │ -0.175799   │
# │ 8   │ 0.141527   │ 0.153777    │
# │ 9   │ 0.0348127  │ 0.0         │
# │ 10  │ -0.0284543 │ 0.0         │
# Total iteration number was 12
# Total time was 1.0665898323059082
# median of y = 1.0
# maximum of y = 10.0
# minimum of y = 0.0
# skewness of y = 1.718587057489249
# kurtosis of y = 4.250820578920864
# mean of y = 1.273224043715847
# variance of y = 2.1862278005464484
# var / mean = 1.7170802038626611
#
#
# running the 29 th model
# n, p = 742, 5936
# sort(compare_model, rev=true, by=abs) = 10×2 DataFrame
# │ Row │ true_β    │ estimated_β │
# │     │ Float64   │ Float64     │
# ├─────┼───────────┼─────────────┤
# │ 1   │ -0.697321 │ -0.681112   │
# │ 2   │ -0.680922 │ -0.678278   │
# │ 3   │ -0.649907 │ -0.687648   │
# │ 4   │ 0.431045  │ 0.431381    │
# │ 5   │ -0.407681 │ -0.428294   │
# │ 6   │ -0.301595 │ -0.330529   │
# │ 7   │ 0.249539  │ 0.0         │
# │ 8   │ -0.205908 │ -0.152244   │
# │ 9   │ 0.133835  │ 0.0         │
# │ 10  │ -0.114763 │ 0.0         │
# Total iteration number was 27
# Total time was 0.7723681926727295
# median of y = 1.0
# maximum of y = 37.0
# minimum of y = 0.0
# skewness of y = 3.949956592819965
# kurtosis of y = 19.559673329789664
# mean of y = 2.454177897574124
# variance of y = 20.87981383065792
# var / mean = 8.507864833799108
#
#
# running the 30 th model
# n, p = 1095, 3285
# sort(compare_model, rev=true, by=abs) = 10×2 DataFrame
# │ Row │ true_β     │ estimated_β │
# │     │ Float64    │ Float64     │
# ├─────┼────────────┼─────────────┤
# │ 1   │ -0.635702  │ -0.612461   │
# │ 2   │ -0.47033   │ -0.444484   │
# │ 3   │ 0.313483   │ 0.313122    │
# │ 4   │ 0.29719    │ 0.315415    │
# │ 5   │ -0.1745    │ 0.0         │
# │ 6   │ 0.172557   │ 0.18183     │
# │ 7   │ -0.139317  │ -0.177348   │
# │ 8   │ -0.119183  │ 0.0         │
# │ 9   │ -0.0694036 │ 0.0         │
# │ 10  │ 0.0459534  │ 0.0         │
# Total iteration number was 14
# Total time was 0.2984001636505127
# median of y = 1.0
# maximum of y = 13.0
# minimum of y = 0.0
# skewness of y = 2.1985329038796992
# kurtosis of y = 5.83684855635193
# mean of y = 1.547945205479452
# variance of y = 4.231474293155694
# var / mean = 2.7336072867289
#
#
# running the 31 th model
# n, p = 668, 6680
# sort(compare_model, rev=true, by=abs) = 10×2 DataFrame
# │ Row │ true_β    │ estimated_β │
# │     │ Float64   │ Float64     │
# ├─────┼───────────┼─────────────┤
# │ 1   │ -0.741724 │ -0.719025   │
# │ 2   │ 0.483958  │ 0.508998    │
# │ 3   │ 0.436822  │ 0.492753    │
# │ 4   │ 0.360663  │ 0.344294    │
# │ 5   │ 0.338337  │ 0.350769    │
# │ 6   │ 0.334899  │ 0.368061    │
# │ 7   │ -0.326244 │ -0.292196   │
# │ 8   │ -0.201377 │ -0.208194   │
# │ 9   │ 0.188019  │ 0.198236    │
# │ 10  │ -0.145171 │ 0.0         │
# Total iteration number was 20
# Total time was 0.5790839195251465
# median of y = 1.0
# maximum of y = 39.0
# minimum of y = 0.0
# skewness of y = 4.164410029645532
# kurtosis of y = 24.393301684276793
# mean of y = 2.1392215568862274
# variance of y = 14.428864160734005
# var / mean = 6.74491340753696
#
#
# running the 32 th model
# n, p = 1294, 1294
# sort(compare_model, rev=true, by=abs) = 10×2 DataFrame
# │ Row │ true_β    │ estimated_β │
# │     │ Float64   │ Float64     │
# ├─────┼───────────┼─────────────┤
# │ 1   │ 0.420426  │ 0.420993    │
# │ 2   │ -0.358106 │ -0.29929    │
# │ 3   │ 0.294415  │ 0.312418    │
# │ 4   │ -0.258982 │ -0.308773   │
# │ 5   │ 0.257257  │ 0.27521     │
# │ 6   │ -0.206577 │ -0.190766   │
# │ 7   │ 0.181925  │ 0.187113    │
# │ 8   │ 0.142693  │ 0.11208     │
# │ 9   │ 0.110774  │ 0.134196    │
# │ 10  │ 0.106201  │ 0.127906    │
# Total iteration number was 24
# Total time was 0.2339000701904297
# median of y = 1.0
# maximum of y = 12.0
# minimum of y = 0.0
# skewness of y = 1.7278051900080635
# kurtosis of y = 4.112283051131334
# mean of y = 1.4173106646058733
# variance of y = 2.708934447883085
# var / mean = 1.9113201611563315
#
#
# running the 33 th model
# n, p = 1158, 1158
# sort(compare_model, rev=true, by=abs) = 10×2 DataFrame
# │ Row │ true_β     │ estimated_β │
# │     │ Float64    │ Float64     │
# ├─────┼────────────┼─────────────┤
# │ 1   │ -0.492902  │ -0.515674   │
# │ 2   │ -0.447957  │ -0.441349   │
# │ 3   │ 0.43166    │ 0.374665    │
# │ 4   │ 0.378452   │ 0.386073    │
# │ 5   │ 0.3641     │ 0.305307    │
# │ 6   │ -0.180484  │ -0.221809   │
# │ 7   │ -0.121235  │ -0.107217   │
# │ 8   │ -0.0966335 │ 0.0         │
# │ 9   │ 0.0731874  │ 0.101693    │
# │ 10  │ -0.069165  │ -0.081598   │
# Total iteration number was 18
# Total time was 0.1443309783935547
# median of y = 1.0
# maximum of y = 19.0
# minimum of y = 0.0
# skewness of y = 2.7304796193306853
# kurtosis of y = 11.20166088002258
# mean of y = 1.544041450777202
# variance of y = 4.505837412282078
# var / mean = 2.91821013614242
#
#
# running the 34 th model
# n, p = 1345, 8070
# sort(compare_model, rev=true, by=abs) = 10×2 DataFrame
# │ Row │ true_β      │ estimated_β │
# │     │ Float64     │ Float64     │
# ├─────┼─────────────┼─────────────┤
# │ 1   │ -0.637956   │ -0.570336   │
# │ 2   │ -0.604622   │ -0.600144   │
# │ 3   │ -0.290294   │ -0.316884   │
# │ 4   │ 0.26213     │ 0.26047     │
# │ 5   │ -0.180634   │ -0.202797   │
# │ 6   │ -0.134139   │ -0.135134   │
# │ 7   │ -0.0766096  │ -0.0912058  │
# │ 8   │ -0.0720629  │ 0.0         │
# │ 9   │ 0.0322996   │ 0.0         │
# │ 10  │ -0.00479531 │ 0.0         │
# Total iteration number was 26
# Total time was 1.6015660762786865
# median of y = 1.0
# maximum of y = 18.0
# minimum of y = 0.0
# skewness of y = 2.2025141822024716
# kurtosis of y = 8.989072075919685
# mean of y = 1.5011152416356877
# variance of y = 3.3989942910249584
# var / mean = 2.2643126901577855
#
#
# running the 35 th model
# n, p = 659, 3954
# sort(compare_model, rev=true, by=abs) = 10×2 DataFrame
# │ Row │ true_β    │ estimated_β │
# │     │ Float64   │ Float64     │
# ├─────┼───────────┼─────────────┤
# │ 1   │ 0.818251  │ 0.81268     │
# │ 2   │ 0.658047  │ 0.635546    │
# │ 3   │ -0.560711 │ -0.545595   │
# │ 4   │ 0.422791  │ 0.424392    │
# │ 5   │ -0.41492  │ -0.390988   │
# │ 6   │ -0.404752 │ -0.387179   │
# │ 7   │ -0.272343 │ -0.274226   │
# │ 8   │ 0.192299  │ 0.20948     │
# │ 9   │ 0.138244  │ 0.169847    │
# │ 10  │ 0.137022  │ 0.125744    │
# Total iteration number was 28
# Total time was 0.4701089859008789
# median of y = 1.0
# maximum of y = 63.0
# minimum of y = 0.0
# skewness of y = 4.909591764418386
# kurtosis of y = 34.08801208564694
# mean of y = 2.7192716236722307
# variance of y = 32.7706158820355
# var / mean = 12.051247693226225
#
#
# running the 36 th model
# n, p = 1737, 12159
# sort(compare_model, rev=true, by=abs) = 10×2 DataFrame
# │ Row │ true_β     │ estimated_β │
# │     │ Float64    │ Float64     │
# ├─────┼────────────┼─────────────┤
# │ 1   │ 0.606928   │ 0.618809    │
# │ 2   │ -0.424863  │ -0.415204   │
# │ 3   │ 0.371395   │ 0.394175    │
# │ 4   │ -0.293602  │ -0.278562   │
# │ 5   │ -0.264189  │ -0.251688   │
# │ 6   │ 0.152224   │ 0.157967    │
# │ 7   │ 0.106266   │ 0.104112    │
# │ 8   │ -0.0947234 │ 0.0         │
# │ 9   │ -0.0889954 │ 0.0         │
# │ 10  │ -0.0593459 │ -0.0895566  │
# Total iteration number was 25
# Total time was 3.0035080909729004
# median of y = 1.0
# maximum of y = 18.0
# minimum of y = 0.0
# skewness of y = 2.697014458200091
# kurtosis of y = 11.549582279891556
# mean of y = 1.5060449050086355
# variance of y = 4.141812516415559
# var / mean = 2.750125512619964
#
#
# running the 37 th model
# n, p = 1889, 18890
# sort(compare_model, rev=true, by=abs) = 10×2 DataFrame
# │ Row │ true_β     │ estimated_β │
# │     │ Float64    │ Float64     │
# ├─────┼────────────┼─────────────┤
# │ 1   │ -0.680976  │ -0.675082   │
# │ 2   │ 0.462086   │ 0.463615    │
# │ 3   │ 0.340346   │ 0.345745    │
# │ 4   │ -0.253658  │ -0.230763   │
# │ 5   │ 0.230238   │ 0.2336      │
# │ 6   │ 0.214203   │ 0.18701     │
# │ 7   │ 0.16884    │ 0.167952    │
# │ 8   │ 0.146315   │ 0.151749    │
# │ 9   │ 0.0926604  │ 0.0810414   │
# │ 10  │ -0.0275184 │ 0.0         │
# Total iteration number was 13
# Total time was 2.8743221759796143
# median of y = 1.0
# maximum of y = 17.0
# minimum of y = 0.0
# skewness of y = 2.526786746198236
# kurtosis of y = 9.21494001171996
# mean of y = 1.6151402858655373
# variance of y = 4.753817260500131
# var / mean = 2.943284433000573
#
#
# running the 38 th model
# n, p = 1114, 10026
# sort(compare_model, rev=true, by=abs) = 10×2 DataFrame
# │ Row │ true_β    │ estimated_β │
# │     │ Float64   │ Float64     │
# ├─────┼───────────┼─────────────┤
# │ 1   │ 0.276855  │ 0.302111    │
# │ 2   │ 0.271831  │ 0.25508     │
# │ 3   │ 0.249639  │ 0.281623    │
# │ 4   │ -0.235962 │ -0.25269    │
# │ 5   │ 0.189173  │ 0.161529    │
# │ 6   │ -0.180959 │ -0.172475   │
# │ 7   │ 0.154631  │ 0.173184    │
# │ 8   │ 0.111782  │ 0.0         │
# │ 9   │ 0.104277  │ 0.0         │
# │ 10  │ 0.0689921 │ 0.0         │
# Total iteration number was 14
# Total time was 0.9343218803405762
# median of y = 1.0
# maximum of y = 15.0
# minimum of y = 0.0
# skewness of y = 2.435372202074966
# kurtosis of y = 10.60657767964652
# mean of y = 1.1929982046678635
# variance of y = 2.2888637789725164
# var / mean = 1.9185810758279784
#
#
# running the 39 th model
# n, p = 1796, 14368
# sort(compare_model, rev=true, by=abs) = 10×2 DataFrame
# │ Row │ true_β     │ estimated_β │
# │     │ Float64    │ Float64     │
# ├─────┼────────────┼─────────────┤
# │ 1   │ 0.466894   │ 0.468027    │
# │ 2   │ -0.277228  │ -0.23084    │
# │ 3   │ 0.246313   │ 0.248515    │
# │ 4   │ -0.213842  │ -0.206472   │
# │ 5   │ -0.199098  │ -0.218066   │
# │ 6   │ 0.113264   │ 0.136398    │
# │ 7   │ 0.101737   │ 0.0817026   │
# │ 8   │ -0.0902097 │ 0.0         │
# │ 9   │ -0.0514469 │ 0.0         │
# │ 10  │ -0.0498506 │ 0.0         │
# Total iteration number was 19
# Total time was 2.7384397983551025
# median of y = 1.0
# maximum of y = 8.0
# minimum of y = 0.0
# skewness of y = 1.4683549909085194
# kurtosis of y = 2.3578603627032084
# mean of y = 1.260022271714922
# variance of y = 1.980818718166647
# var / mean = 1.5720505602418462
#
#
# running the 40 th model
# n, p = 1633, 1633
# sort(compare_model, rev=true, by=abs) = 10×2 DataFrame
# │ Row │ true_β     │ estimated_β │
# │     │ Float64    │ Float64     │
# ├─────┼────────────┼─────────────┤
# │ 1   │ 1.01879    │ 0.997949    │
# │ 2   │ -0.736857  │ -0.75512    │
# │ 3   │ -0.496768  │ -0.485102   │
# │ 4   │ 0.460153   │ 0.438826    │
# │ 5   │ -0.396218  │ -0.409893   │
# │ 6   │ 0.368241   │ 0.381985    │
# │ 7   │ 0.187368   │ 0.196436    │
# │ 8   │ -0.163682  │ -0.167801   │
# │ 9   │ -0.0697279 │ -0.0773252  │
# │ 10  │ 0.0239967  │ 0.0         │
# Total iteration number was 261
# Total time was 3.9840989112854004
# median of y = 1.0
# maximum of y = 83.0
# minimum of y = 0.0
# skewness of y = 6.123884295434789
# kurtosis of y = 51.574055865741265
# mean of y = 2.9914268218003675
# variance of y = 44.503602926167424
# var / mean = 14.877048838982887
#
#
# running the 41 th model
# n, p = 765, 5355
# sort(compare_model, rev=true, by=abs) = 10×2 DataFrame
# │ Row │ true_β     │ estimated_β │
# │     │ Float64    │ Float64     │
# ├─────┼────────────┼─────────────┤
# │ 1   │ -0.783141  │ -0.776346   │
# │ 2   │ 0.477758   │ 0.425825    │
# │ 3   │ 0.286116   │ 0.284572    │
# │ 4   │ -0.145555  │ -0.130162   │
# │ 5   │ -0.12309   │ 0.0         │
# │ 6   │ -0.111686  │ 0.0         │
# │ 7   │ -0.0960509 │ 0.0         │
# │ 8   │ 0.0720336  │ 0.0         │
# │ 9   │ 0.026559   │ 0.0         │
# │ 10  │ 0.00564881 │ 0.0         │
# Total iteration number was 16
# Total time was 0.40586280822753906
# median of y = 1.0
# maximum of y = 10.0
# minimum of y = 0.0
# skewness of y = 1.6362862031794996
# kurtosis of y = 2.9916271259650884
# mean of y = 1.4326797385620915
# variance of y = 3.1515484378742777
# var / mean = 2.1997578056330496
#
#
# running the 42 th model
# n, p = 1199, 2398
# sort(compare_model, rev=true, by=abs) = 10×2 DataFrame
# │ Row │ true_β     │ estimated_β │
# │     │ Float64    │ Float64     │
# ├─────┼────────────┼─────────────┤
# │ 1   │ 0.968328   │ 0.963838    │
# │ 2   │ -0.480347  │ -0.487073   │
# │ 3   │ -0.40395   │ -0.426656   │
# │ 4   │ -0.334148  │ -0.310486   │
# │ 5   │ 0.161957   │ 0.141752    │
# │ 6   │ -0.155336  │ -0.150254   │
# │ 7   │ -0.129806  │ -0.127143   │
# │ 8   │ 0.11762    │ 0.144938    │
# │ 9   │ -0.0906596 │ 0.0         │
# │ 10  │ 0.00831469 │ 0.0         │
# Total iteration number was 16
# Total time was 0.2864501476287842
# median of y = 1.0
# maximum of y = 45.0
# minimum of y = 0.0
# skewness of y = 4.462663119367477
# kurtosis of y = 31.529980778867163
# mean of y = 2.085070892410342
# variance of y = 12.76738127627224
# var / mean = 6.123236060100165
#
#
# running the 43 th model
# n, p = 1037, 2074
# sort(compare_model, rev=true, by=abs) = 10×2 DataFrame
# │ Row │ true_β       │ estimated_β │
# │     │ Float64      │ Float64     │
# ├─────┼──────────────┼─────────────┤
# │ 1   │ -0.907804    │ -0.907391   │
# │ 2   │ 0.595802     │ 0.5793      │
# │ 3   │ 0.281452     │ 0.25714     │
# │ 4   │ -0.20584     │ -0.196783   │
# │ 5   │ -0.189452    │ -0.202372   │
# │ 6   │ -0.139057    │ -0.131504   │
# │ 7   │ 0.0489165    │ 0.0754932   │
# │ 8   │ -0.0197783   │ 0.0         │
# │ 9   │ -0.0121306   │ 0.0         │
# │ 10  │ -0.000772901 │ 0.0         │
# Total iteration number was 16
# Total time was 0.20712494850158691
# median of y = 1.0
# maximum of y = 30.0
# minimum of y = 0.0
# skewness of y = 3.616598184718089
# kurtosis of y = 19.244638933647977
# mean of y = 1.8919961427193828
# variance of y = 9.492184911182017
# var / mean = 5.017021280782748
#
#
# running the 44 th model
# n, p = 1814, 3628
# sort(compare_model, rev=true, by=abs) = 10×2 DataFrame
# │ Row │ true_β     │ estimated_β │
# │     │ Float64    │ Float64     │
# ├─────┼────────────┼─────────────┤
# │ 1   │ -0.643876  │ -0.677913   │
# │ 2   │ 0.624875   │ 0.621354    │
# │ 3   │ 0.248678   │ 0.210251    │
# │ 4   │ 0.227223   │ 0.246752    │
# │ 5   │ -0.170521  │ 0.0         │
# │ 6   │ -0.165367  │ -0.19666    │
# │ 7   │ 0.120182   │ 0.0         │
# │ 8   │ -0.101723  │ -0.104413   │
# │ 9   │ 0.0368735  │ 0.0         │
# │ 10  │ 0.00231531 │ 0.0         │
# Total iteration number was 60
# Total time was 2.2105469703674316
# median of y = 1.0
# maximum of y = 13.0
# minimum of y = 0.0
# skewness of y = 2.0385032945598565
# kurtosis of y = 5.614208466592759
# mean of y = 1.509922822491731
# variance of y = 3.5881530001076376
# var / mean = 2.3763817240581435
#
#
# running the 45 th model
# n, p = 1263, 10104
# sort(compare_model, rev=true, by=abs) = 10×2 DataFrame
# │ Row │ true_β    │ estimated_β │
# │     │ Float64   │ Float64     │
# ├─────┼───────────┼─────────────┤
# │ 1   │ 0.737812  │ 0.754493    │
# │ 2   │ -0.594675 │ -0.599408   │
# │ 3   │ -0.503566 │ -0.501792   │
# │ 4   │ -0.230669 │ -0.207672   │
# │ 5   │ 0.210766  │ 0.185669    │
# │ 6   │ 0.199994  │ 0.204371    │
# │ 7   │ -0.162584 │ -0.0903602  │
# │ 8   │ 0.103319  │ 0.0966972   │
# │ 9   │ 0.068004  │ 0.0         │
# │ 10  │ 0.0498411 │ 0.0         │
# Total iteration number was 34
# Total time was 2.391350030899048
# median of y = 1.0
# maximum of y = 65.0
# minimum of y = 0.0
# skewness of y = 7.012331578197605
# kurtosis of y = 75.62548193011352
# mean of y = 2.0665083135391926
# variance of y = 18.3442260710481
# var / mean = 8.876918593001436
#
#
# running the 46 th model
# n, p = 1874, 18740
# sort(compare_model, rev=true, by=abs) = 10×2 DataFrame
# │ Row │ true_β    │ estimated_β │
# │     │ Float64   │ Float64     │
# ├─────┼───────────┼─────────────┤
# │ 1   │ 0.600417  │ 0.585842    │
# │ 2   │ 0.533446  │ 0.527183    │
# │ 3   │ 0.41676   │ 0.419111    │
# │ 4   │ 0.34206   │ 0.357992    │
# │ 5   │ 0.319977  │ 0.32207     │
# │ 6   │ -0.173001 │ -0.185363   │
# │ 7   │ 0.157599  │ 0.155798    │
# │ 8   │ 0.157577  │ 0.175345    │
# │ 9   │ 0.0684693 │ 0.0         │
# │ 10  │ 0.0593057 │ 0.0         │
# Total iteration number was 16
# Total time was 3.3580939769744873
# median of y = 1.0
# maximum of y = 32.0
# minimum of y = 0.0
# skewness of y = 3.852546490129578
# kurtosis of y = 24.341911237230715
# mean of y = 1.7459978655282817
# variance of y = 7.264866515745576
# var / mean = 4.160867924971641
#
#
# running the 47 th model
# n, p = 877, 1754
# sort(compare_model, rev=true, by=abs) = 10×2 DataFrame
# │ Row │ true_β    │ estimated_β │
# │     │ Float64   │ Float64     │
# ├─────┼───────────┼─────────────┤
# │ 1   │ 0.509968  │ 0.507186    │
# │ 2   │ -0.432133 │ -0.381722   │
# │ 3   │ -0.422484 │ -0.425861   │
# │ 4   │ -0.420171 │ -0.445459   │
# │ 5   │ 0.342228  │ 0.324324    │
# │ 6   │ 0.293371  │ 0.284939    │
# │ 7   │ -0.251949 │ -0.225757   │
# │ 8   │ -0.18205  │ -0.18849    │
# │ 9   │ 0.166632  │ 0.176446    │
# │ 10  │ 0.158509  │ 0.148767    │
# Total iteration number was 33
# Total time was 0.28916192054748535
# median of y = 1.0
# maximum of y = 92.0
# minimum of y = 0.0
# skewness of y = 10.305540270626336
# kurtosis of y = 141.22608267903976
# mean of y = 1.9407069555302165
# variance of y = 27.092370732520045
# var / mean = 13.96005236922449
#
#
# running the 48 th model
# n, p = 635, 5080
# sort(compare_model, rev=true, by=abs) = 10×2 DataFrame
# │ Row │ true_β    │ estimated_β │
# │     │ Float64   │ Float64     │
# ├─────┼───────────┼─────────────┤
# │ 1   │ -0.780626 │ 0.0         │
# │ 2   │ 0.697705  │ 0.665635    │
# │ 3   │ 0.67207   │ 0.660314    │
# │ 4   │ -0.516446 │ -0.497432   │
# │ 5   │ -0.250144 │ 0.0         │
# │ 6   │ -0.231984 │ -0.165129   │
# │ 7   │ 0.198547  │ 0.0         │
# │ 8   │ 0.187279  │ 0.168218    │
# │ 9   │ 0.127454  │ 0.150142    │
# │ 10  │ 0.0311708 │ 0.0         │
# Total iteration number was 44
# Total time was 0.8528060913085938
# median of y = 1.0
# maximum of y = 83.0
# minimum of y = 0.0
# skewness of y = 7.539660822670036
# kurtosis of y = 78.84292553362862
# mean of y = 2.5826771653543306
# variance of y = 33.915472316749046
# var / mean = 13.131905439716856
#
#
# running the 49 th model
# n, p = 1967, 7868
# sort(compare_model, rev=true, by=abs) = 10×2 DataFrame
# │ Row │ true_β    │ estimated_β │
# │     │ Float64   │ Float64     │
# ├─────┼───────────┼─────────────┤
# │ 1   │ 0.652309  │ 0.672499    │
# │ 2   │ 0.569616  │ 0.524544    │
# │ 3   │ -0.553919 │ 0.0         │
# │ 4   │ 0.339142  │ 0.341298    │
# │ 5   │ -0.292563 │ -0.270793   │
# │ 6   │ -0.231384 │ -0.24325    │
# │ 7   │ -0.22154  │ -0.241461   │
# │ 8   │ -0.197569 │ -0.187435   │
# │ 9   │ 0.160643  │ 0.164642    │
# │ 10  │ 0.134959  │ 0.146144    │
# Total iteration number was 38
# Total time was 3.247587203979492
# median of y = 1.0
# maximum of y = 173.0
# minimum of y = 0.0
# skewness of y = 16.33646233695257
# kurtosis of y = 355.37277571379076
# mean of y = 2.211997966446365
# variance of y = 45.13255180467537
# var / mean = 20.40352319002447
#
#
# running the 50 th model
# n, p = 1757, 17570
# sort(compare_model, rev=true, by=abs) = 10×2 DataFrame
# │ Row │ true_β     │ estimated_β │
# │     │ Float64    │ Float64     │
# ├─────┼────────────┼─────────────┤
# │ 1   │ -0.689818  │ -0.70538    │
# │ 2   │ -0.635434  │ -0.63619    │
# │ 3   │ -0.485112  │ -0.499967   │
# │ 4   │ 0.46888    │ 0.461521    │
# │ 5   │ 0.425028   │ 0.433934    │
# │ 6   │ -0.313445  │ -0.323078   │
# │ 7   │ -0.185887  │ -0.227861   │
# │ 8   │ -0.117949  │ -0.1005     │
# │ 9   │ -0.0674461 │ 0.0         │
# │ 10  │ -0.0429797 │ 0.0         │
# Total iteration number was 21
# Total time was 3.7549941539764404
# median of y = 1.0
# maximum of y = 44.0
# minimum of y = 0.0
# skewness of y = 3.696968630614838
# kurtosis of y = 21.122489417787534
# mean of y = 2.100170745589072
# variance of y = 12.638023888824785
# var / mean = 6.017617336765623

# %% [markdown]
# # Is initializing $\beta$ good in terms of speed and model selection?
#
# When initilizing the model, we can fit a bunch of univariate regressions to find a good initial approximation to the model before starting the IHT algorithm. Doing so introduces extra computational cost, but could reduce total iteration number and/or improve model selection. This section examines whether this is useful (it's not).

# %%
#some function that runs poisson regression on different SNP matrices
function test_poisson_init(n :: Int64, p :: Int64, k :: Int64)    
    #set random seed
    Random.seed!(1111)

    #construct snpmatrix, covariate files, and true model b
    x, maf = simulate_random_snparray(n, p)
    xbm = SnpBitMatrix{Float64}(x, model=ADDITIVE_MODEL, center=true, scale=true); 
    z = ones(n, 1) # non-genetic covariates, just the intercept
    true_b = zeros(p)
    true_b[1:k] = rand(Normal(0, 0.4), k)
    shuffle!(true_b)
    correct_position = findall(x -> x != 0, true_b)

    # Simulate poisson data
    y_temp = xbm * true_b
    λ = exp.(y_temp) #inverse log link
    y = [rand(Poisson(x)) for x in λ]
    y = Float64.(y)

    #compute poisson IHT result
    yes_init = L0_poisson_reg(x, z, y, 1, k, glm = "poisson", debias=false, convg=false, show_info=false, init=true)
    no_init = L0_poisson_reg(x, z, y, 1, k, glm = "poisson", debias=false, convg=false, show_info=false, init=false)
    
    #check result
    est_model_init = yes_init.beta[correct_position]
    est_model_no_init = no_init.beta[correct_position]
    true_model = true_b[correct_position]
    compare_model = DataFrame(
        true_β      = true_model, 
        est_β_no_init = est_model_no_init,
        est_β_with_init = est_model_init)
        
    #display results
    @show sort(compare_model, rev=true, by=abs)
    println("No initilialization:")
    println("    Iter = " * string(no_init.iter))
    println("    Time = " * string(no_init.time))
    println("Yes initilialization:")
    println("    Iter = " * string(yes_init.iter))
    println("    Time = " * string(yes_init.time) * "\n\n")
    
    #return summary statistic
    yes_init_found = length(findall(!iszero, est_model_init))
    no_init_found = length(findall(!iszero, est_model_no_init))
    yes_init_time = yes_init.time
    no_init_time = no_init.time
    return yes_init_found, no_init_found, yes_init_time, no_init_time
end
# Out:
# test_poisson_init (generic function with 1 method)

# %%
k = 10
yes_init_total_found = 0
no_init_total_found = 0
yes_init_total_time = 0
no_init_total_time = 0

iter = 50
for i = 1:iter
    println("running the $i th model")
    n = rand(500:2000) 
    p = rand(1:10)n
    println("n, p = " * string(n) * ", " * string(p))
    yif, nif, yit, nit = test_poisson_init(n, p, k)
    yes_init_total_found += yif
    no_init_total_found += nif
    yes_init_total_time += yit
    no_init_total_time += nit
end
println("With initialization, found $yes_init_total_found " * "predictors out of " * string(k*iter))
println("With initialization, average time was " * string(yes_init_total_time/iter))
println("Without initialization, found $no_init_total_found " * "predictors out of " * string(k*iter))
println("Without initialization, average time was " * string(no_init_total_time/iter))
# Out:
# running the 1 th model
# n, p = 1350, 13500
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β     │ est_β_no_init │ est_β_with_init │
# │     │ Float64    │ Float64       │ Float64         │
# ├─────┼────────────┼───────────────┼─────────────────┤
# │ 1   │ -0.548454  │ -0.533148     │ -0.526393       │
# │ 2   │ 0.44135    │ 0.402357      │ 0.404395        │
# │ 3   │ 0.439569   │ 0.426857      │ 0.421325        │
# │ 4   │ -0.368719  │ -0.414614     │ -0.417164       │
# │ 5   │ 0.296116   │ 0.297873      │ 0.297031        │
# │ 6   │ 0.208152   │ 0.205636      │ 0.206739        │
# │ 7   │ -0.196641  │ -0.203148     │ -0.19881        │
# │ 8   │ 0.120121   │ 0.137878      │ 0.138934        │
# │ 9   │ -0.0998402 │ 0.0           │ 0.0             │
# │ 10  │ -0.0346985 │ 0.0           │ 0.0             │
# No initilialization:
#     Iter = 23
#     Time = 2.4194629192352295
# Yes initilialization:
#     Iter = 120
#     Time = 16.844393014907837
#
#
# running the 2 th model
# n, p = 870, 5220
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β     │ est_β_no_init │ est_β_with_init │
# │     │ Float64    │ Float64       │ Float64         │
# ├─────┼────────────┼───────────────┼─────────────────┤
# │ 1   │ -0.394409  │ -0.379621     │ -0.370033       │
# │ 2   │ -0.329165  │ 0.0           │ -0.279706       │
# │ 3   │ 0.304044   │ 0.30737       │ 0.314958        │
# │ 4   │ 0.234113   │ 0.217692      │ 0.199719        │
# │ 5   │ -0.218644  │ 0.0           │ -0.184917       │
# │ 6   │ -0.217405  │ -0.243549     │ -0.268849       │
# │ 7   │ 0.167248   │ 0.0           │ 0.169943        │
# │ 8   │ 0.146227   │ 0.182445      │ 0.168072        │
# │ 9   │ -0.124067  │ 0.0           │ 0.0             │
# │ 10  │ -0.0157277 │ 0.0           │ 0.0             │
# No initilialization:
#     Iter = 18
#     Time = 0.48518896102905273
# Yes initilialization:
#     Iter = 62
#     Time = 2.6577539443969727
#
#
# running the 3 th model
# n, p = 1578, 4734
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β     │ est_β_no_init │ est_β_with_init │
# │     │ Float64    │ Float64       │ Float64         │
# ├─────┼────────────┼───────────────┼─────────────────┤
# │ 1   │ 0.753826   │ 0.709553      │ 0.727344        │
# │ 2   │ 0.487954   │ 0.463425      │ 0.470902        │
# │ 3   │ 0.443921   │ 0.441851      │ 0.444716        │
# │ 4   │ 0.431317   │ 0.407083      │ 0.416311        │
# │ 5   │ 0.378484   │ 0.373885      │ 0.38521         │
# │ 6   │ -0.372239  │ 0.0           │ -0.437878       │
# │ 7   │ -0.348697  │ -0.288635     │ -0.299806       │
# │ 8   │ -0.229159  │ -0.2032       │ -0.200324       │
# │ 9   │ -0.208946  │ -0.202834     │ -0.200375       │
# │ 10  │ -0.0775952 │ -0.0953376    │ -0.104968       │
# No initilialization:
#     Iter = 39
#     Time = 1.6172688007354736
# Yes initilialization:
#     Iter = 29
#     Time = 3.3705689907073975
#
#
# running the 4 th model
# n, p = 1398, 9786
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β    │ est_β_no_init │ est_β_with_init │
# │     │ Float64   │ Float64       │ Float64         │
# ├─────┼───────────┼───────────────┼─────────────────┤
# │ 1   │ -0.640633 │ -0.738083     │ -0.640952       │
# │ 2   │ -0.514849 │ 0.0           │ -0.627643       │
# │ 3   │ 0.372438  │ 0.356552      │ 0.353205        │
# │ 4   │ 0.366403  │ 0.361043      │ 0.354741        │
# │ 5   │ 0.324501  │ 0.336955      │ 0.321185        │
# │ 6   │ 0.316712  │ 0.308756      │ 0.29848         │
# │ 7   │ 0.10685   │ 0.109592      │ 0.101423        │
# │ 8   │ 0.0838172 │ 0.0           │ 0.0             │
# │ 9   │ 0.0353976 │ 0.0           │ 0.0             │
# │ 10  │ -0.03074  │ 0.0           │ 0.0             │
# No initilialization:
#     Iter = 88
#     Time = 6.649555921554565
# Yes initilialization:
#     Iter = 216
#     Time = 19.110378980636597
#
#
# running the 5 th model
# n, p = 1475, 7375
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β     │ est_β_no_init │ est_β_with_init │
# │     │ Float64    │ Float64       │ Float64         │
# ├─────┼────────────┼───────────────┼─────────────────┤
# │ 1   │ 0.665417   │ 0.659634      │ 0.659633        │
# │ 2   │ 0.570434   │ 0.592021      │ 0.592013        │
# │ 3   │ -0.410483  │ -0.416819     │ -0.416751       │
# │ 4   │ 0.260607   │ 0.254904      │ 0.254901        │
# │ 5   │ 0.257297   │ 0.255147      │ 0.255156        │
# │ 6   │ 0.211481   │ 0.188942      │ 0.188996        │
# │ 7   │ -0.185438  │ -0.18016      │ -0.180223       │
# │ 8   │ -0.13449   │ 0.0           │ 0.0             │
# │ 9   │ -0.0636782 │ -0.113141     │ -0.113145       │
# │ 10  │ 0.0590136  │ 0.0           │ 0.0             │
# No initilialization:
#     Iter = 39
#     Time = 2.3122098445892334
# Yes initilialization:
#     Iter = 31
#     Time = 5.298655033111572
#
#
# running the 6 th model
# n, p = 1080, 7560
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β    │ est_β_no_init │ est_β_with_init │
# │     │ Float64   │ Float64       │ Float64         │
# ├─────┼───────────┼───────────────┼─────────────────┤
# │ 1   │ -0.890159 │ -0.931519     │ -0.931444       │
# │ 2   │ -0.452395 │ -0.447875     │ -0.447892       │
# │ 3   │ 0.437088  │ 0.424375      │ 0.424388        │
# │ 4   │ 0.403091  │ 0.412937      │ 0.412945        │
# │ 5   │ 0.343178  │ 0.366002      │ 0.36601         │
# │ 6   │ 0.298457  │ 0.300286      │ 0.300293        │
# │ 7   │ -0.249414 │ -0.299622     │ -0.299635       │
# │ 8   │ 0.199797  │ 0.187683      │ 0.187689        │
# │ 9   │ 0.179346  │ 0.190759      │ 0.190763        │
# │ 10  │ 0.161615  │ 0.145389      │ 0.145394        │
# No initilialization:
#     Iter = 31
#     Time = 1.420361042022705
# Yes initilialization:
#     Iter = 21
#     Time = 3.5243029594421387
#
#
# running the 7 th model
# n, p = 1561, 15610
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β     │ est_β_no_init │ est_β_with_init │
# │     │ Float64    │ Float64       │ Float64         │
# ├─────┼────────────┼───────────────┼─────────────────┤
# │ 1   │ -0.803077  │ -0.816572     │ -0.818099       │
# │ 2   │ -0.799615  │ -0.822056     │ -0.830488       │
# │ 3   │ -0.78436   │ -0.80372      │ -0.805025       │
# │ 4   │ -0.76802   │ -0.711428     │ -0.707554       │
# │ 5   │ 0.51606    │ 0.53011       │ 0.528749        │
# │ 6   │ 0.125467   │ 0.121572      │ 0.114361        │
# │ 7   │ -0.122375  │ -0.142352     │ -0.141129       │
# │ 8   │ -0.0287974 │ 0.0           │ 0.0             │
# │ 9   │ 0.019136   │ 0.0           │ 0.0             │
# │ 10  │ -0.0109541 │ 0.0           │ 0.0             │
# No initilialization:
#     Iter = 109
#     Time = 14.349823236465454
# Yes initilialization:
#     Iter = 63
#     Time = 13.36509394645691
#
#
# running the 8 th model
# n, p = 1206, 2412
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β     │ est_β_no_init │ est_β_with_init │
# │     │ Float64    │ Float64       │ Float64         │
# ├─────┼────────────┼───────────────┼─────────────────┤
# │ 1   │ -0.38732   │ -0.335581     │ -0.325913       │
# │ 2   │ -0.307935  │ 0.0           │ -0.305351       │
# │ 3   │ -0.280353  │ 0.0           │ -0.27271        │
# │ 4   │ -0.271841  │ -0.344423     │ -0.32827        │
# │ 5   │ 0.215162   │ 0.170765      │ 0.172853        │
# │ 6   │ 0.141963   │ 0.180698      │ 0.170746        │
# │ 7   │ 0.12027    │ 0.107555      │ 0.108242        │
# │ 8   │ 0.120045   │ 0.135144      │ 0.132102        │
# │ 9   │ 0.116938   │ 0.155246      │ 0.151912        │
# │ 10  │ -0.0910609 │ 0.0           │ 0.0             │
# No initilialization:
#     Iter = 35
#     Time = 0.5621750354766846
# Yes initilialization:
#     Iter = 41
#     Time = 1.1706640720367432
#
#
# running the 9 th model
# n, p = 1919, 5757
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β    │ est_β_no_init │ est_β_with_init │
# │     │ Float64   │ Float64       │ Float64         │
# ├─────┼───────────┼───────────────┼─────────────────┤
# │ 1   │ 0.734217  │ 0.736146      │ 0.736156        │
# │ 2   │ 0.699213  │ 0.692492      │ 0.692478        │
# │ 3   │ 0.674633  │ 0.677764      │ 0.677705        │
# │ 4   │ -0.664348 │ -0.669846     │ -0.669982       │
# │ 5   │ 0.309579  │ 0.329708      │ 0.329703        │
# │ 6   │ 0.259913  │ 0.256793      │ 0.25685         │
# │ 7   │ 0.166012  │ 0.168836      │ 0.168811        │
# │ 8   │ -0.138561 │ -0.161537     │ -0.161517       │
# │ 9   │ 0.110123  │ 0.111236      │ 0.111257        │
# │ 10  │ 0.0884305 │ 0.0835277     │ 0.083661        │
# No initilialization:
#     Iter = 32
#     Time = 2.203484058380127
# Yes initilialization:
#     Iter = 66
#     Time = 7.091842889785767
#
#
# running the 10 th model
# n, p = 1125, 10125
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β     │ est_β_no_init │ est_β_with_init │
# │     │ Float64    │ Float64       │ Float64         │
# ├─────┼────────────┼───────────────┼─────────────────┤
# │ 1   │ -0.86729   │ -0.811135     │ -0.814218       │
# │ 2   │ -0.366293  │ -0.345781     │ -0.345048       │
# │ 3   │ -0.305893  │ -0.316077     │ -0.303575       │
# │ 4   │ 0.193395   │ 0.148321      │ 0.144913        │
# │ 5   │ 0.151924   │ 0.159994      │ 0.160609        │
# │ 6   │ -0.124594  │ 0.0           │ -0.1211         │
# │ 7   │ 0.0947123  │ 0.0           │ 0.0             │
# │ 8   │ -0.0934834 │ 0.0           │ 0.0             │
# │ 9   │ -0.0140278 │ 0.0           │ 0.0             │
# │ 10  │ 0.00768112 │ 0.0           │ 0.0             │
# No initilialization:
#     Iter = 22
#     Time = 1.433506965637207
# Yes initilialization:
#     Iter = 94
#     Time = 8.971442937850952
#
#
# running the 11 th model
# n, p = 1084, 2168
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β      │ est_β_no_init │ est_β_with_init │
# │     │ Float64     │ Float64       │ Float64         │
# ├─────┼─────────────┼───────────────┼─────────────────┤
# │ 1   │ -0.616473   │ -0.568075     │ 0.0             │
# │ 2   │ 0.447349    │ 0.442583      │ 5.22856         │
# │ 3   │ 0.438518    │ 0.43613       │ 0.0             │
# │ 4   │ -0.388097   │ -0.36942      │ 0.0             │
# │ 5   │ 0.318059    │ 0.310648      │ 0.0             │
# │ 6   │ 0.312845    │ 0.247766      │ 0.0             │
# │ 7   │ -0.28485    │ -0.287715     │ 0.0             │
# │ 8   │ -0.0614141  │ 0.0           │ 0.0             │
# │ 9   │ 0.0498711   │ 0.0           │ 0.0             │
# │ 10  │ -0.00899233 │ 0.0           │ 0.0             │
# No initilialization:
#     Iter = 139
#     Time = 1.7113690376281738
# Yes initilialization:
#     Iter = 1000
#     Time = 13.120066165924072
#
#
# running the 12 th model
# n, p = 640, 5120
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β     │ est_β_no_init │ est_β_with_init │
# │     │ Float64    │ Float64       │ Float64         │
# ├─────┼────────────┼───────────────┼─────────────────┤
# │ 1   │ 0.630074   │ 0.639788      │ 0.639796        │
# │ 2   │ -0.553768  │ -0.496379     │ -0.496393       │
# │ 3   │ -0.54043   │ -0.473563     │ -0.473607       │
# │ 4   │ 0.473579   │ 0.492634      │ 0.492575        │
# │ 5   │ 0.299079   │ 0.306216      │ 0.306223        │
# │ 6   │ 0.297139   │ 0.297532      │ 0.297467        │
# │ 7   │ 0.228695   │ 0.213271      │ 0.213237        │
# │ 8   │ -0.205376  │ 0.0           │ 0.0             │
# │ 9   │ -0.142572  │ -0.177298     │ -0.177398       │
# │ 10  │ -0.0833004 │ 0.0           │ 0.0             │
# No initilialization:
#     Iter = 52
#     Time = 0.9248108863830566
# Yes initilialization:
#     Iter = 48
#     Time = 1.8951358795166016
#
#
# running the 13 th model
# n, p = 1484, 14840
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β    │ est_β_no_init │ est_β_with_init │
# │     │ Float64   │ Float64       │ Float64         │
# ├─────┼───────────┼───────────────┼─────────────────┤
# │ 1   │ -0.355983 │ -0.39091      │ -0.385592       │
# │ 2   │ -0.354442 │ -0.359884     │ -0.348902       │
# │ 3   │ 0.336716  │ 0.295863      │ 0.298702        │
# │ 4   │ 0.299994  │ 0.282407      │ 0.291824        │
# │ 5   │ 0.277865  │ 0.279403      │ 0.276409        │
# │ 6   │ -0.275594 │ -0.23126      │ -0.230088       │
# │ 7   │ -0.274824 │ 0.0           │ -0.247329       │
# │ 8   │ 0.274764  │ 0.293922      │ 0.296852        │
# │ 9   │ -0.22672  │ -0.274016     │ -0.259207       │
# │ 10  │ 0.0428934 │ 0.0           │ 0.0             │
# No initilialization:
#     Iter = 50
#     Time = 5.921612977981567
# Yes initilialization:
#     Iter = 22
#     Time = 8.140204906463623
#
#
# running the 14 th model
# n, p = 1861, 5583
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β     │ est_β_no_init │ est_β_with_init │
# │     │ Float64    │ Float64       │ Float64         │
# ├─────┼────────────┼───────────────┼─────────────────┤
# │ 1   │ -0.712045  │ -0.740255     │ -0.741057       │
# │ 2   │ -0.62129   │ -0.621686     │ -0.618025       │
# │ 3   │ -0.575665  │ -0.583063     │ -0.581406       │
# │ 4   │ 0.441509   │ 0.427124      │ 0.426516        │
# │ 5   │ 0.366104   │ 0.36536       │ 0.363388        │
# │ 6   │ -0.356043  │ -0.393291     │ -0.389236       │
# │ 7   │ -0.3459    │ -0.355136     │ -0.353223       │
# │ 8   │ -0.106395  │ -0.103392     │ -0.101742       │
# │ 9   │ -0.0654851 │ -0.0649865    │ -0.0664652      │
# │ 10  │ 0.0338886  │ 0.0           │ 0.0             │
# No initilialization:
#     Iter = 150
#     Time = 8.304455041885376
# Yes initilialization:
#     Iter = 129
#     Time = 10.37218189239502
#
#
# running the 15 th model
# n, p = 862, 862
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β       │ est_β_no_init │ est_β_with_init │
# │     │ Float64      │ Float64       │ Float64         │
# ├─────┼──────────────┼───────────────┼─────────────────┤
# │ 1   │ -0.595225    │ -0.531212     │ -0.543527       │
# │ 2   │ -0.288946    │ -0.300355     │ -0.289257       │
# │ 3   │ -0.19847     │ -0.249504     │ -0.246706       │
# │ 4   │ 0.193403     │ 0.186758      │ 0.177908        │
# │ 5   │ 0.143241     │ 0.174066      │ 0.163608        │
# │ 6   │ 0.101446     │ 0.0           │ 0.0             │
# │ 7   │ 0.0759018    │ 0.0           │ 0.0             │
# │ 8   │ -0.0535861   │ 0.0           │ 0.0             │
# │ 9   │ -0.0335743   │ 0.0           │ 0.0             │
# │ 10  │ -0.000687013 │ 0.0           │ 0.0             │
# No initilialization:
#     Iter = 63
#     Time = 0.29796600341796875
# Yes initilialization:
#     Iter = 35
#     Time = 0.3321988582611084
#
#
# running the 16 th model
# n, p = 1436, 5744
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β     │ est_β_no_init │ est_β_with_init │
# │     │ Float64    │ Float64       │ Float64         │
# ├─────┼────────────┼───────────────┼─────────────────┤
# │ 1   │ -0.59108   │ -0.586891     │ -0.58054        │
# │ 2   │ -0.432556  │ -0.464021     │ -0.4693         │
# │ 3   │ 0.420568   │ 0.416716      │ 0.415425        │
# │ 4   │ -0.298745  │ -0.296891     │ -0.298065       │
# │ 5   │ 0.295856   │ 0.295321      │ 0.287833        │
# │ 6   │ -0.216025  │ -0.199602     │ -0.198528       │
# │ 7   │ -0.171142  │ -0.162866     │ -0.15782        │
# │ 8   │ -0.14955   │ -0.138206     │ -0.134677       │
# │ 9   │ -0.0998998 │ -0.0974563    │ -0.0967191      │
# │ 10  │ 0.0792776  │ 0.0           │ 0.0             │
# No initilialization:
#     Iter = 18
#     Time = 0.8462378978729248
# Yes initilialization:
#     Iter = 37
#     Time = 3.781203031539917
#
#
# running the 17 th model
# n, p = 708, 2832
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β     │ est_β_no_init │ est_β_with_init │
# │     │ Float64    │ Float64       │ Float64         │
# ├─────┼────────────┼───────────────┼─────────────────┤
# │ 1   │ 0.517507   │ 0.48546       │ 0.467872        │
# │ 2   │ -0.49162   │ -0.534157     │ -0.526439       │
# │ 3   │ 0.352902   │ 0.33326       │ 0.333879        │
# │ 4   │ -0.334651  │ -0.273264     │ -0.266224       │
# │ 5   │ 0.329634   │ 0.363855      │ 0.337653        │
# │ 6   │ 0.169104   │ 0.128966      │ 0.115496        │
# │ 7   │ -0.145509  │ 0.0           │ 0.0             │
# │ 8   │ -0.14224   │ -0.13273      │ -0.131354       │
# │ 9   │ 0.0243348  │ 0.0           │ 0.0             │
# │ 10  │ -0.0196864 │ 0.0           │ 0.0             │
# No initilialization:
#     Iter = 17
#     Time = 0.19005799293518066
# Yes initilialization:
#     Iter = 1000
#     Time = 11.91144609451294
#
#
# running the 18 th model
# n, p = 981, 4905
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β     │ est_β_no_init │ est_β_with_init │
# │     │ Float64    │ Float64       │ Float64         │
# ├─────┼────────────┼───────────────┼─────────────────┤
# │ 1   │ 0.728777   │ 0.720843      │ 0.716571        │
# │ 2   │ 0.563872   │ 0.565893      │ 0.5657          │
# │ 3   │ -0.434376  │ 0.0           │ -0.795415       │
# │ 4   │ -0.43265   │ -0.388135     │ -0.395412       │
# │ 5   │ 0.412485   │ 0.418824      │ 0.416199        │
# │ 6   │ -0.277824  │ -0.246353     │ -0.256678       │
# │ 7   │ -0.225787  │ 0.0           │ -0.245873       │
# │ 8   │ 0.208731   │ 0.194916      │ 0.193267        │
# │ 9   │ -0.0443711 │ 0.0           │ 0.0             │
# │ 10  │ 0.0269631  │ 0.0           │ 0.0             │
# No initilialization:
#     Iter = 31
#     Time = 0.8631289005279541
# Yes initilialization:
#     Iter = 225
#     Time = 7.327972888946533
#
#
# running the 19 th model
# n, p = 1585, 7925
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β    │ est_β_no_init │ est_β_with_init │
# │     │ Float64   │ Float64       │ Float64         │
# ├─────┼───────────┼───────────────┼─────────────────┤
# │ 1   │ -0.655104 │ -0.620435     │ -0.620371       │
# │ 2   │ 0.502305  │ 0.494366      │ 0.49436         │
# │ 3   │ 0.441556  │ 0.428938      │ 0.428939        │
# │ 4   │ -0.42273  │ -0.434079     │ -0.434089       │
# │ 5   │ -0.37566  │ -0.372025     │ -0.372026       │
# │ 6   │ 0.364887  │ 0.382013      │ 0.382011        │
# │ 7   │ 0.238113  │ 0.259638      │ 0.259629        │
# │ 8   │ -0.156089 │ -0.143592     │ -0.143593       │
# │ 9   │ -0.125916 │ -0.113696     │ -0.113697       │
# │ 10  │ 0.0884594 │ 0.110875      │ 0.110875        │
# No initilialization:
#     Iter = 92
#     Time = 5.97459602355957
# Yes initilialization:
#     Iter = 61
#     Time = 7.980252981185913
#
#
# running the 20 th model
# n, p = 1946, 5838
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β     │ est_β_no_init │ est_β_with_init │
# │     │ Float64    │ Float64       │ Float64         │
# ├─────┼────────────┼───────────────┼─────────────────┤
# │ 1   │ 0.768077   │ 0.802101      │ 0.774452        │
# │ 2   │ -0.403688  │ 0.0           │ -0.444186       │
# │ 3   │ -0.363402  │ -0.415238     │ -0.396361       │
# │ 4   │ -0.32323   │ -0.343056     │ -0.324344       │
# │ 5   │ -0.272189  │ -0.268006     │ -0.258294       │
# │ 6   │ -0.254625  │ -0.244135     │ -0.240445       │
# │ 7   │ -0.23949   │ -0.24196      │ -0.224671       │
# │ 8   │ -0.147567  │ 0.0           │ -0.136396       │
# │ 9   │ -0.0745125 │ -0.080972     │ -0.0735971      │
# │ 10  │ 0.00900211 │ 0.0           │ 0.0             │
# No initilialization:
#     Iter = 26
#     Time = 1.6294820308685303
# Yes initilialization:
#     Iter = 158
#     Time = 12.271381855010986
#
#
# running the 21 th model
# n, p = 932, 7456
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β      │ est_β_no_init │ est_β_with_init │
# │     │ Float64     │ Float64       │ Float64         │
# ├─────┼─────────────┼───────────────┼─────────────────┤
# │ 1   │ 0.561076    │ 0.549098      │ 0.550442        │
# │ 2   │ -0.49914    │ -0.505487     │ -0.507343       │
# │ 3   │ -0.44227    │ -0.478316     │ -0.484709       │
# │ 4   │ 0.361585    │ 0.369946      │ 0.374152        │
# │ 5   │ 0.276128    │ 0.277822      │ 0.278319        │
# │ 6   │ -0.245796   │ -0.307889     │ -0.304922       │
# │ 7   │ 0.201946    │ 0.144897      │ 0.140937        │
# │ 8   │ -0.191139   │ -0.216069     │ -0.214874       │
# │ 9   │ -0.0987664  │ 0.0           │ 0.0             │
# │ 10  │ -0.00062872 │ 0.0           │ 0.0             │
# No initilialization:
#     Iter = 13
#     Time = 0.5538020133972168
# Yes initilialization:
#     Iter = 283
#     Time = 12.619776964187622
#
#
# running the 22 th model
# n, p = 716, 7160
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β     │ est_β_no_init │ est_β_with_init │
# │     │ Float64    │ Float64       │ Float64         │
# ├─────┼────────────┼───────────────┼─────────────────┤
# │ 1   │ -1.04639   │ -1.07546      │ -1.07206        │
# │ 2   │ -0.974357  │ -0.955928     │ -0.956936       │
# │ 3   │ -0.874591  │ -0.893615     │ -0.892034       │
# │ 4   │ 0.816221   │ 0.810005      │ 0.807157        │
# │ 5   │ -0.67846   │ -0.64129      │ -0.651094       │
# │ 6   │ 0.447856   │ 0.445552      │ 0.437773        │
# │ 7   │ -0.251271  │ -0.263686     │ -0.248669       │
# │ 8   │ -0.133366  │ -0.128799     │ -0.132164       │
# │ 9   │ -0.12887   │ 0.0           │ 0.0             │
# │ 10  │ -0.0529459 │ 0.0           │ 0.0             │
# No initilialization:
#     Iter = 80
#     Time = 2.312530994415283
# Yes initilialization:
#     Iter = 1000
#     Time = 30.295021057128906
#
#
# running the 23 th model
# n, p = 1190, 3570
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β     │ est_β_no_init │ est_β_with_init │
# │     │ Float64    │ Float64       │ Float64         │
# ├─────┼────────────┼───────────────┼─────────────────┤
# │ 1   │ -0.648635  │ -0.672183     │ -0.667127       │
# │ 2   │ 0.505442   │ 0.494588      │ 0.496436        │
# │ 3   │ 0.463557   │ 0.468122      │ 0.464578        │
# │ 4   │ -0.384661  │ -0.395539     │ -0.391798       │
# │ 5   │ -0.220565  │ -0.195914     │ -0.206146       │
# │ 6   │ -0.202194  │ -0.20546      │ -0.1948         │
# │ 7   │ 0.16577    │ 0.158936      │ 0.153341        │
# │ 8   │ -0.123576  │ 0.0           │ -0.123013       │
# │ 9   │ 0.0602807  │ 0.0773511     │ 0.0774333       │
# │ 10  │ -0.0105287 │ 0.0           │ 0.0             │
# No initilialization:
#     Iter = 56
#     Time = 1.341871976852417
# Yes initilialization:
#     Iter = 25
#     Time = 1.6740880012512207
#
#
# running the 24 th model
# n, p = 1347, 13470
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β     │ est_β_no_init │ est_β_with_init │
# │     │ Float64    │ Float64       │ Float64         │
# ├─────┼────────────┼───────────────┼─────────────────┤
# │ 1   │ -1.02407   │ -1.01272      │ -1.02191        │
# │ 2   │ 0.405329   │ 0.405572      │ 0.40293         │
# │ 3   │ 0.272178   │ 0.265628      │ 0.250953        │
# │ 4   │ 0.198437   │ 0.187727      │ 0.189748        │
# │ 5   │ -0.175398  │ -0.237471     │ -0.247436       │
# │ 6   │ -0.115907  │ -0.15001      │ -0.159175       │
# │ 7   │ 0.114599   │ 0.119644      │ 0.0             │
# │ 8   │ 0.098081   │ 0.0           │ 0.0             │
# │ 9   │ 0.045625   │ 0.0           │ 0.0             │
# │ 10  │ -0.0365574 │ 0.0           │ 0.0             │
# No initilialization:
#     Iter = 23
#     Time = 2.3309061527252197
# Yes initilialization:
#     Iter = 51
#     Time = 10.127662897109985
#
#
# running the 25 th model
# n, p = 1990, 11940
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β     │ est_β_no_init │ est_β_with_init │
# │     │ Float64    │ Float64       │ Float64         │
# ├─────┼────────────┼───────────────┼─────────────────┤
# │ 1   │ -0.620594  │ -0.585588     │ -0.573062       │
# │ 2   │ -0.567681  │ -0.581334     │ -0.564774       │
# │ 3   │ -0.411406  │ -0.408429     │ -0.404971       │
# │ 4   │ -0.293746  │ 0.0           │ -0.282291       │
# │ 5   │ 0.288364   │ 0.292502      │ 0.285997        │
# │ 6   │ 0.230549   │ 0.24345       │ 0.246182        │
# │ 7   │ 0.161884   │ 0.206493      │ 0.193479        │
# │ 8   │ -0.0727267 │ 0.0           │ 0.0             │
# │ 9   │ -0.0690117 │ 0.0           │ 0.0             │
# │ 10  │ 0.025367   │ 0.0           │ 0.0             │
# No initilialization:
#     Iter = 52
#     Time = 6.92688512802124
# Yes initilialization:
#     Iter = 91
#     Time = 17.810180187225342
#
#
# running the 26 th model
# n, p = 1296, 12960
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β     │ est_β_no_init │ est_β_with_init │
# │     │ Float64    │ Float64       │ Float64         │
# ├─────┼────────────┼───────────────┼─────────────────┤
# │ 1   │ -0.564285  │ -0.586058     │ -0.580631       │
# │ 2   │ -0.55309   │ 0.0           │ -0.598402       │
# │ 3   │ 0.499066   │ 0.50762       │ 0.510958        │
# │ 4   │ -0.442053  │ -0.413167     │ -0.39265        │
# │ 5   │ 0.285003   │ 0.273764      │ 0.273429        │
# │ 6   │ -0.197369  │ 0.0           │ -0.192776       │
# │ 7   │ 0.0976315  │ 0.0           │ 0.0             │
# │ 8   │ 0.0949779  │ 0.108921      │ 0.0989005       │
# │ 9   │ 0.0319806  │ 0.0           │ 0.0             │
# │ 10  │ -0.0100378 │ 0.0           │ 0.0             │
# No initilialization:
#     Iter = 28
#     Time = 2.7139360904693604
# Yes initilialization:
#     Iter = 70
#     Time = 11.057785034179688
#
#
# running the 27 th model
# n, p = 1964, 15712
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β     │ est_β_no_init │ est_β_with_init │
# │     │ Float64    │ Float64       │ Float64         │
# ├─────┼────────────┼───────────────┼─────────────────┤
# │ 1   │ 0.847449   │ 5520.96       │ 1.05126e5       │
# │ 2   │ 0.754338   │ 0.0           │ 0.0             │
# │ 3   │ -0.625315  │ 0.0           │ 0.0             │
# │ 4   │ 0.209323   │ 0.0           │ 0.0             │
# │ 5   │ -0.203897  │ 0.0           │ 0.0             │
# │ 6   │ -0.178506  │ 0.0           │ 0.0             │
# │ 7   │ -0.0729253 │ 0.0           │ 0.0             │
# │ 8   │ 0.066645   │ 0.0           │ 0.0             │
# │ 9   │ 0.0363747  │ 0.0           │ 0.0             │
# │ 10  │ -0.0222863 │ 0.0           │ 0.0             │
# No initilialization:
#     Iter = 2
#     Time = 0.647589921951294
# Yes initilialization:
#     Iter = 2
#     Time = 6.027261972427368
#
#
# running the 28 th model
# n, p = 745, 5215
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β    │ est_β_no_init │ est_β_with_init │
# │     │ Float64   │ Float64       │ Float64         │
# ├─────┼───────────┼───────────────┼─────────────────┤
# │ 1   │ 1.03232   │ 38.5039       │ 146.153         │
# │ 2   │ 0.616287  │ 0.0           │ 0.0             │
# │ 3   │ -0.563685 │ 0.0           │ 0.0             │
# │ 4   │ 0.518932  │ 0.0           │ 0.0             │
# │ 5   │ -0.419317 │ 0.0           │ 0.0             │
# │ 6   │ -0.407123 │ 0.0           │ 0.0             │
# │ 7   │ -0.382674 │ 0.0           │ 0.0             │
# │ 8   │ -0.161933 │ 0.0           │ 0.0             │
# │ 9   │ -0.090667 │ 0.0           │ 0.0             │
# │ 10  │ 0.0858972 │ 0.0           │ 0.0             │
# No initilialization:
#     Iter = 1000
#     Time = 22.565880060195923
# Yes initilialization:
#     Iter = 1000
#     Time = 23.5912868976593
#
#
# running the 29 th model
# n, p = 1512, 10584
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β    │ est_β_no_init │ est_β_with_init │
# │     │ Float64   │ Float64       │ Float64         │
# ├─────┼───────────┼───────────────┼─────────────────┤
# │ 1   │ -0.85952  │ -0.888378     │ -0.888886       │
# │ 2   │ -0.7666   │ -0.791175     │ -0.79112        │
# │ 3   │ -0.629307 │ -0.65411      │ -0.654057       │
# │ 4   │ -0.601721 │ -0.604211     │ -0.604137       │
# │ 5   │ -0.57271  │ -0.563747     │ -0.5637         │
# │ 6   │ -0.37535  │ -0.340174     │ -0.340146       │
# │ 7   │ -0.337228 │ -0.325908     │ -0.325887       │
# │ 8   │ 0.264678  │ 0.2648        │ 0.26479         │
# │ 9   │ -0.182143 │ -0.167611     │ -0.167598       │
# │ 10  │ -0.153807 │ -0.14223      │ -0.142223       │
# No initilialization:
#     Iter = 70
#     Time = 5.987162113189697
# Yes initilialization:
#     Iter = 53
#     Time = 7.806066989898682
#
#
# running the 30 th model
# n, p = 1994, 9970
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β     │ est_β_no_init │ est_β_with_init │
# │     │ Float64    │ Float64       │ Float64         │
# ├─────┼────────────┼───────────────┼─────────────────┤
# │ 1   │ -0.822412  │ -0.829082     │ -0.828958       │
# │ 2   │ 0.60371    │ 0.605198      │ 0.605246        │
# │ 3   │ 0.450498   │ 0.457235      │ 0.457219        │
# │ 4   │ 0.248604   │ 0.246813      │ 0.246796        │
# │ 5   │ -0.241662  │ -0.232848     │ -0.233165       │
# │ 6   │ 0.238178   │ 0.249338      │ 0.24934         │
# │ 7   │ 0.127033   │ 0.117636      │ 0.11756         │
# │ 8   │ -0.124824  │ -0.150856     │ -0.150871       │
# │ 9   │ 0.116564   │ 0.106456      │ 0.106442        │
# │ 10  │ -0.0985908 │ -0.118542     │ -0.118592       │
# No initilialization:
#     Iter = 22
#     Time = 2.422724962234497
# Yes initilialization:
#     Iter = 15
#     Time = 7.825520992279053
#
#
# running the 31 th model
# n, p = 1409, 2818
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β    │ est_β_no_init │ est_β_with_init │
# │     │ Float64   │ Float64       │ Float64         │
# ├─────┼───────────┼───────────────┼─────────────────┤
# │ 1   │ -0.349637 │ -0.376256     │ -0.365007       │
# │ 2   │ 0.313023  │ 0.300732      │ 0.29664         │
# │ 3   │ 0.277294  │ 0.260258      │ 0.256887        │
# │ 4   │ -0.272742 │ -0.263663     │ -0.257252       │
# │ 5   │ 0.234092  │ 0.243993      │ 0.248236        │
# │ 6   │ 0.216065  │ 0.215089      │ 0.217907        │
# │ 7   │ -0.186315 │ -0.147834     │ -0.146936       │
# │ 8   │ -0.137067 │ -0.178984     │ -0.163344       │
# │ 9   │ 0.131225  │ 0.0           │ 0.140178        │
# │ 10  │ -0.122842 │ -0.126977     │ -0.134848       │
# No initilialization:
#     Iter = 17
#     Time = 0.38387012481689453
# Yes initilialization:
#     Iter = 14
#     Time = 1.0831639766693115
#
#
# running the 32 th model
# n, p = 784, 784
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β    │ est_β_no_init │ est_β_with_init │
# │     │ Float64   │ Float64       │ Float64         │
# ├─────┼───────────┼───────────────┼─────────────────┤
# │ 1   │ 1.01225   │ 1.01551       │ 1.01536         │
# │ 2   │ 0.637738  │ 0.616342      │ 0.616306        │
# │ 3   │ 0.497658  │ 0.517805      │ 0.517773        │
# │ 4   │ -0.48792  │ -0.49117      │ -0.491211       │
# │ 5   │ -0.337885 │ -0.350423     │ -0.351436       │
# │ 6   │ 0.333527  │ 0.391191      │ 0.391158        │
# │ 7   │ -0.29795  │ -0.324043     │ -0.323873       │
# │ 8   │ 0.262965  │ 0.247652      │ 0.247642        │
# │ 9   │ -0.175637 │ -0.203546     │ -0.203662       │
# │ 10  │ 0.13075   │ 0.101651      │ 0.101537        │
# No initilialization:
#     Iter = 39
#     Time = 0.14223909378051758
# Yes initilialization:
#     Iter = 60
#     Time = 0.33306217193603516
#
#
# running the 33 th model
# n, p = 943, 7544
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β    │ est_β_no_init │ est_β_with_init │
# │     │ Float64   │ Float64       │ Float64         │
# ├─────┼───────────┼───────────────┼─────────────────┤
# │ 1   │ -0.896147 │ -0.866469     │ -0.867608       │
# │ 2   │ 0.643575  │ 0.66147       │ 0.660399        │
# │ 3   │ 0.561241  │ 0.572816      │ 0.573982        │
# │ 4   │ -0.471157 │ -0.530919     │ -0.523116       │
# │ 5   │ 0.429675  │ 0.447323      │ 0.448294        │
# │ 6   │ 0.178161  │ 0.184407      │ 0.182191        │
# │ 7   │ 0.16515   │ 0.132546      │ 0.125741        │
# │ 8   │ 0.150644  │ 0.159809      │ 0.167752        │
# │ 9   │ 0.0544522 │ 0.0           │ 0.0             │
# │ 10  │ 0.0477049 │ 0.0           │ 0.0             │
# No initilialization:
#     Iter = 55
#     Time = 2.227008819580078
# Yes initilialization:
#     Iter = 589
#     Time = 25.444180011749268
#
#
# running the 34 th model
# n, p = 1451, 8706
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β     │ est_β_no_init │ est_β_with_init │
# │     │ Float64    │ Float64       │ Float64         │
# ├─────┼────────────┼───────────────┼─────────────────┤
# │ 1   │ 0.649694   │ 0.665255      │ 0.652036        │
# │ 2   │ 0.627548   │ 0.638343      │ 0.628408        │
# │ 3   │ -0.50527   │ -0.479408     │ -0.478447       │
# │ 4   │ -0.42496   │ -0.441398     │ -0.435123       │
# │ 5   │ 0.350854   │ 0.369128      │ 0.358651        │
# │ 6   │ -0.250981  │ -0.254801     │ -0.239518       │
# │ 7   │ -0.233555  │ -0.23317      │ -0.222307       │
# │ 8   │ -0.206389  │ 0.0           │ -0.202844       │
# │ 9   │ -0.0953564 │ -0.0864771    │ -0.0934252      │
# │ 10  │ -0.0176675 │ 0.0           │ 0.0             │
# No initilialization:
#     Iter = 84
#     Time = 5.62648606300354
# Yes initilialization:
#     Iter = 86
#     Time = 8.285826921463013
#
#
# running the 35 th model
# n, p = 1627, 9762
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β      │ est_β_no_init │ est_β_with_init │
# │     │ Float64     │ Float64       │ Float64         │
# ├─────┼─────────────┼───────────────┼─────────────────┤
# │ 1   │ -0.706201   │ 0.0           │ -0.7775         │
# │ 2   │ 0.65632     │ 0.664655      │ 0.666742        │
# │ 3   │ 0.640642    │ 0.608452      │ 0.621332        │
# │ 4   │ 0.537321    │ 0.538344      │ 0.541358        │
# │ 5   │ 0.260765    │ 0.271025      │ 0.270961        │
# │ 6   │ -0.217424   │ -0.218279     │ -0.212967       │
# │ 7   │ -0.203936   │ -0.204897     │ -0.196505       │
# │ 8   │ 0.190594    │ 0.175768      │ 0.164762        │
# │ 9   │ 0.177933    │ 0.164467      │ 0.168858        │
# │ 10  │ 0.000736831 │ 0.0           │ 0.0             │
# No initilialization:
#     Iter = 37
#     Time = 3.2135539054870605
# Yes initilialization:
#     Iter = 304
#     Time = 30.259235858917236
#
#
# running the 36 th model
# n, p = 659, 2636
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β      │ est_β_no_init │ est_β_with_init │
# │     │ Float64     │ Float64       │ Float64         │
# ├─────┼─────────────┼───────────────┼─────────────────┤
# │ 1   │ 0.652064    │ 0.637148      │ 0.637185        │
# │ 2   │ -0.58332    │ -0.645901     │ -0.64523        │
# │ 3   │ 0.53957     │ 0.531255      │ 0.531247        │
# │ 4   │ 0.44902     │ 0.44223       │ 0.442234        │
# │ 5   │ -0.443317   │ -0.430647     │ -0.430651       │
# │ 6   │ 0.385248    │ 0.381365      │ 0.38137         │
# │ 7   │ -0.299465   │ -0.312622     │ -0.313413       │
# │ 8   │ -0.222237   │ -0.230982     │ -0.230939       │
# │ 9   │ -0.130594   │ -0.148592     │ -0.148597       │
# │ 10  │ -0.00666864 │ 0.0           │ 0.0             │
# No initilialization:
#     Iter = 41
#     Time = 0.38953089714050293
# Yes initilialization:
#     Iter = 33
#     Time = 0.9089610576629639
#
#
# running the 37 th model
# n, p = 1013, 8104
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β     │ est_β_no_init │ est_β_with_init │
# │     │ Float64    │ Float64       │ Float64         │
# ├─────┼────────────┼───────────────┼─────────────────┤
# │ 1   │ 0.900782   │ 0.878141      │ 0.88453         │
# │ 2   │ -0.429104  │ -0.471295     │ -0.478799       │
# │ 3   │ 0.426776   │ 0.431622      │ 0.433643        │
# │ 4   │ -0.357891  │ -0.353632     │ -0.35944        │
# │ 5   │ -0.238198  │ -0.282491     │ -0.273795       │
# │ 6   │ 0.101809   │ 0.106927      │ 0.102821        │
# │ 7   │ -0.0898481 │ 0.0           │ 0.0             │
# │ 8   │ 0.0855208  │ 0.0           │ 0.0             │
# │ 9   │ -0.0468547 │ 0.0           │ 0.0             │
# │ 10  │ 0.0115736  │ 0.0           │ 0.0             │
# No initilialization:
#     Iter = 44
#     Time = 1.936460018157959
# Yes initilialization:
#     Iter = 131
#     Time = 8.255981922149658
#
#
# running the 38 th model
# n, p = 1202, 2404
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β     │ est_β_no_init │ est_β_with_init │
# │     │ Float64    │ Float64       │ Float64         │
# ├─────┼────────────┼───────────────┼─────────────────┤
# │ 1   │ -0.913261  │ -0.950095     │ -0.946583       │
# │ 2   │ 0.593164   │ 0.602336      │ 0.591637        │
# │ 3   │ -0.462984  │ -0.415796     │ -0.413356       │
# │ 4   │ -0.398503  │ -0.416771     │ -0.407768       │
# │ 5   │ -0.268345  │ -0.275167     │ -0.281419       │
# │ 6   │ -0.190136  │ 0.0           │ -0.217718       │
# │ 7   │ 0.153217   │ 0.153339      │ 0.162377        │
# │ 8   │ 0.113605   │ 0.0724867     │ 0.0             │
# │ 9   │ -0.110554  │ -0.134045     │ -0.120069       │
# │ 10  │ -0.0906433 │ -0.118288     │ -0.115463       │
# No initilialization:
#     Iter = 54
#     Time = 0.8526039123535156
# Yes initilialization:
#     Iter = 44
#     Time = 1.5443370342254639
#
#
# running the 39 th model
# n, p = 1959, 11754
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β      │ est_β_no_init │ est_β_with_init │
# │     │ Float64     │ Float64       │ Float64         │
# ├─────┼─────────────┼───────────────┼─────────────────┤
# │ 1   │ 0.744937    │ 0.743846      │ 0.74249         │
# │ 2   │ -0.559463   │ -0.569351     │ -0.568644       │
# │ 3   │ -0.435803   │ -0.434681     │ -0.433258       │
# │ 4   │ -0.397307   │ -0.399207     │ -0.399618       │
# │ 5   │ -0.369567   │ -0.355773     │ -0.356847       │
# │ 6   │ 0.363929    │ 0.358205      │ 0.359732        │
# │ 7   │ 0.259458    │ 0.278118      │ 0.277988        │
# │ 8   │ -0.0847302  │ -0.0891579    │ -0.0916381      │
# │ 9   │ -0.0532339  │ 0.0           │ 0.0             │
# │ 10  │ -0.00680403 │ 0.0           │ 0.0             │
# No initilialization:
#     Iter = 21
#     Time = 2.652233839035034
# Yes initilialization:
#     Iter = 107
#     Time = 19.491256952285767
#
#
# running the 40 th model
# n, p = 1807, 3614
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β    │ est_β_no_init │ est_β_with_init │
# │     │ Float64   │ Float64       │ Float64         │
# ├─────┼───────────┼───────────────┼─────────────────┤
# │ 1   │ -1.19282  │ -1.15532      │ -1.18387        │
# │ 2   │ 0.690259  │ 0.670129      │ 0.687493        │
# │ 3   │ 0.574754  │ 0.572809      │ 0.57645         │
# │ 4   │ 0.351289  │ 0.34226       │ 0.346424        │
# │ 5   │ -0.249539 │ -0.242978     │ -0.246385       │
# │ 6   │ -0.156138 │ -0.152063     │ -0.161322       │
# │ 7   │ 0.141546  │ 0.146827      │ 0.151428        │
# │ 8   │ 0.133319  │ 0.0           │ 0.0             │
# │ 9   │ 0.090873  │ 0.102048      │ 0.093578        │
# │ 10  │ -0.041249 │ 0.0           │ 0.0             │
# No initilialization:
#     Iter = 56
#     Time = 1.9297330379486084
# Yes initilialization:
#     Iter = 746
#     Time = 26.37493395805359
#
#
# running the 41 th model
# n, p = 1216, 8512
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β     │ est_β_no_init │ est_β_with_init │
# │     │ Float64    │ Float64       │ Float64         │
# ├─────┼────────────┼───────────────┼─────────────────┤
# │ 1   │ -0.559269  │ -0.615141     │ -0.613713       │
# │ 2   │ -0.474503  │ -0.520331     │ -0.524955       │
# │ 3   │ 0.402867   │ 0.382628      │ 0.387815        │
# │ 4   │ 0.385297   │ 0.380693      │ 0.379552        │
# │ 5   │ -0.328484  │ -0.316778     │ -0.328066       │
# │ 6   │ -0.235323  │ -0.222061     │ -0.226534       │
# │ 7   │ 0.181087   │ 0.169741      │ 0.175522        │
# │ 8   │ 0.143842   │ 0.151306      │ 0.1546          │
# │ 9   │ -0.0784074 │ 0.0           │ 0.0             │
# │ 10  │ 0.03117    │ 0.0           │ 0.0             │
# No initilialization:
#     Iter = 145
#     Time = 7.784866094589233
# Yes initilialization:
#     Iter = 77
#     Time = 7.107006072998047
#
#
# running the 42 th model
# n, p = 539, 1078
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β     │ est_β_no_init │ est_β_with_init │
# │     │ Float64    │ Float64       │ Float64         │
# ├─────┼────────────┼───────────────┼─────────────────┤
# │ 1   │ 0.41107    │ 0.452953      │ 0.454512        │
# │ 2   │ -0.37268   │ -0.449709     │ -0.450749       │
# │ 3   │ -0.336057  │ -0.304546     │ -0.303422       │
# │ 4   │ 0.272988   │ 0.270536      │ 0.271429        │
# │ 5   │ -0.23589   │ -0.195216     │ -0.19371        │
# │ 6   │ 0.15532    │ 0.163497      │ 0.16168         │
# │ 7   │ -0.149928  │ 0.0           │ 0.0             │
# │ 8   │ 0.0939923  │ 0.0           │ 0.0             │
# │ 9   │ -0.076248  │ 0.0           │ 0.0             │
# │ 10  │ -0.0641797 │ 0.0           │ 0.0             │
# No initilialization:
#     Iter = 13
#     Time = 0.04504704475402832
# Yes initilialization:
#     Iter = 91
#     Time = 0.45462679862976074
#
#
# running the 43 th model
# n, p = 1156, 5780
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β     │ est_β_no_init │ est_β_with_init │
# │     │ Float64    │ Float64       │ Float64         │
# ├─────┼────────────┼───────────────┼─────────────────┤
# │ 1   │ -1.10923   │ -1.15796      │ -1.12586        │
# │ 2   │ 0.516276   │ 0.491299      │ 0.479133        │
# │ 3   │ -0.413175  │ -0.416989     │ -0.430324       │
# │ 4   │ -0.382563  │ 0.0           │ -0.428142       │
# │ 5   │ 0.269816   │ 0.258446      │ 0.25062         │
# │ 6   │ 0.249025   │ 0.287481      │ 0.282418        │
# │ 7   │ 0.23396    │ 0.248158      │ 0.241645        │
# │ 8   │ -0.223833  │ -0.249458     │ -0.219216       │
# │ 9   │ 0.0982031  │ 0.100307      │ 0.0974024       │
# │ 10  │ 0.00727278 │ 0.0           │ 0.0             │
# No initilialization:
#     Iter = 24
#     Time = 0.8845548629760742
# Yes initilialization:
#     Iter = 171
#     Time = 8.181287050247192
#
#
# running the 44 th model
# n, p = 1406, 1406
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β     │ est_β_no_init │ est_β_with_init │
# │     │ Float64    │ Float64       │ Float64         │
# ├─────┼────────────┼───────────────┼─────────────────┤
# │ 1   │ -0.683321  │ -0.668213     │ -0.6684         │
# │ 2   │ -0.477763  │ -0.482422     │ -0.482277       │
# │ 3   │ -0.420266  │ -0.45731      │ -0.457281       │
# │ 4   │ -0.363541  │ -0.339604     │ -0.339522       │
# │ 5   │ -0.235187  │ -0.201869     │ -0.201873       │
# │ 6   │ 0.224105   │ 0.222423      │ 0.222429        │
# │ 7   │ 0.162586   │ 0.160605      │ 0.160588        │
# │ 8   │ -0.148251  │ -0.136817     │ -0.136813       │
# │ 9   │ -0.122112  │ -0.166007     │ -0.165989       │
# │ 10  │ -0.0537647 │ -0.0725407    │ -0.0725454      │
# No initilialization:
#     Iter = 13
#     Time = 0.1514420509338379
# Yes initilialization:
#     Iter = 12
#     Time = 0.6201038360595703
#
#
# running the 45 th model
# n, p = 1823, 1823
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β     │ est_β_no_init │ est_β_with_init │
# │     │ Float64    │ Float64       │ Float64         │
# ├─────┼────────────┼───────────────┼─────────────────┤
# │ 1   │ -0.710687  │ -0.694992     │ -0.693735       │
# │ 2   │ 0.34147    │ 0.346625      │ 0.345451        │
# │ 3   │ 0.272825   │ 0.240172      │ 0.236175        │
# │ 4   │ 0.262791   │ 0.262536      │ 0.259826        │
# │ 5   │ 0.262036   │ 0.258437      │ 0.259556        │
# │ 6   │ 0.218339   │ 0.254951      │ 0.256901        │
# │ 7   │ 0.190175   │ 0.208016      │ 0.207377        │
# │ 8   │ -0.0718773 │ -0.0800648    │ -0.0812663      │
# │ 9   │ 0.0446821  │ 0.0           │ 0.0             │
# │ 10  │ 0.0220765  │ 0.0           │ 0.0             │
# No initilialization:
#     Iter = 13
#     Time = 0.2533900737762451
# Yes initilialization:
#     Iter = 13
#     Time = 1.0574359893798828
#
#
# running the 46 th model
# n, p = 1068, 4272
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β     │ est_β_no_init │ est_β_with_init │
# │     │ Float64    │ Float64       │ Float64         │
# ├─────┼────────────┼───────────────┼─────────────────┤
# │ 1   │ -0.692887  │ -0.665805     │ -0.667745       │
# │ 2   │ 0.522998   │ 0.562452      │ 0.564132        │
# │ 3   │ -0.494268  │ -0.483741     │ -0.478066       │
# │ 4   │ -0.405969  │ -0.387608     │ -0.393175       │
# │ 5   │ -0.377198  │ -0.361002     │ -0.359655       │
# │ 6   │ -0.367628  │ -0.381853     │ -0.385984       │
# │ 7   │ 0.173847   │ 0.17377       │ 0.174615        │
# │ 8   │ -0.162184  │ -0.156338     │ -0.152436       │
# │ 9   │ -0.0158029 │ 0.0           │ 0.0             │
# │ 10  │ 0.00466915 │ 0.0           │ 0.0             │
# No initilialization:
#     Iter = 51
#     Time = 1.275913953781128
# Yes initilialization:
#     Iter = 319
#     Time = 9.132272005081177
#
#
# running the 47 th model
# n, p = 1048, 5240
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β    │ est_β_no_init │ est_β_with_init │
# │     │ Float64   │ Float64       │ Float64         │
# ├─────┼───────────┼───────────────┼─────────────────┤
# │ 1   │ 0.937216  │ 0.938548      │ 0.938561        │
# │ 2   │ 0.793993  │ 0.809222      │ 0.809229        │
# │ 3   │ 0.760041  │ 0.774389      │ 0.774388        │
# │ 4   │ 0.714247  │ 0.677908      │ 0.677891        │
# │ 5   │ -0.268024 │ -0.24194      │ -0.241872       │
# │ 6   │ -0.227886 │ -0.211187     │ -0.211192       │
# │ 7   │ 0.133111  │ 0.150075      │ 0.150073        │
# │ 8   │ 0.0940302 │ 0.0           │ 0.0             │
# │ 9   │ 0.091946  │ 0.0770631     │ 0.0770647       │
# │ 10  │ 0.088685  │ 0.0           │ 0.0             │
# No initilialization:
#     Iter = 105
#     Time = 3.023118019104004
# Yes initilialization:
#     Iter = 61
#     Time = 3.09529709815979
#
#
# running the 48 th model
# n, p = 1572, 6288
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β    │ est_β_no_init │ est_β_with_init │
# │     │ Float64   │ Float64       │ Float64         │
# ├─────┼───────────┼───────────────┼─────────────────┤
# │ 1   │ -0.678718 │ -0.710829     │ -0.70892        │
# │ 2   │ -0.658246 │ -0.663465     │ -0.663557       │
# │ 3   │ 0.491728  │ 0.478569      │ 0.478224        │
# │ 4   │ 0.418147  │ 0.415578      │ 0.409222        │
# │ 5   │ 0.329733  │ 0.343346      │ 0.34312         │
# │ 6   │ 0.305161  │ 0.311955      │ 0.314145        │
# │ 7   │ -0.29027  │ -0.271621     │ -0.268783       │
# │ 8   │ -0.126342 │ 0.0           │ 0.0             │
# │ 9   │ 0.104981  │ 0.13382       │ 0.131085        │
# │ 10  │ 0.0911877 │ 0.089482      │ 0.0923196       │
# No initilialization:
#     Iter = 28
#     Time = 1.5010178089141846
# Yes initilialization:
#     Iter = 368
#     Time = 22.387046813964844
#
#
# running the 49 th model
# n, p = 1447, 7235
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β      │ est_β_no_init │ est_β_with_init │
# │     │ Float64     │ Float64       │ Float64         │
# ├─────┼─────────────┼───────────────┼─────────────────┤
# │ 1   │ -0.675875   │ -0.693783     │ -0.692161       │
# │ 2   │ -0.523807   │ -0.53145      │ -0.524271       │
# │ 3   │ 0.267083    │ 0.321736      │ 0.314316        │
# │ 4   │ -0.115423   │ -0.102623     │ -0.102818       │
# │ 5   │ -0.113475   │ -0.134748     │ -0.138945       │
# │ 6   │ 0.0873899   │ 0.0968246     │ 0.0991138       │
# │ 7   │ -0.0835868  │ -0.0944584    │ -0.0844613      │
# │ 8   │ -0.0356323  │ 0.0           │ 0.0             │
# │ 9   │ 0.0274294   │ 0.0           │ 0.0             │
# │ 10  │ -0.00321264 │ 0.0           │ 0.0             │
# No initilialization:
#     Iter = 34
#     Time = 1.9395999908447266
# Yes initilialization:
#     Iter = 225
#     Time = 15.29430890083313
#
#
# running the 50 th model
# n, p = 1731, 5193
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β    │ est_β_no_init │ est_β_with_init │
# │     │ Float64   │ Float64       │ Float64         │
# ├─────┼───────────┼───────────────┼─────────────────┤
# │ 1   │ -1.21699  │ -1.19676      │ -1.19673        │
# │ 2   │ -0.665081 │ -0.651523     │ -0.651534       │
# │ 3   │ -0.316479 │ -0.302668     │ -0.302667       │
# │ 4   │ -0.272598 │ -0.273079     │ -0.273078       │
# │ 5   │ 0.259457  │ 0.262825      │ 0.262821        │
# │ 6   │ 0.238041  │ 0.225773      │ 0.22577         │
# │ 7   │ -0.209906 │ -0.211474     │ -0.211474       │
# │ 8   │ 0.203767  │ 0.189947      │ 0.189946        │
# │ 9   │ -0.176434 │ -0.171638     │ -0.171638       │
# │ 10  │ 0.0957231 │ 0.0970386     │ 0.0970383       │
# No initilialization:
#     Iter = 37
#     Time = 1.7880349159240723
# Yes initilialization:
#     Iter = 30
#     Time = 4.0838329792022705
#
#
# With initialization, found 394 predictors out of 500
# With initialization, average time was 9.615318994522095
# Without initialization, found 380 predictors out of 500
# Without initialization, average time was 2.9184149503707886

# %% [markdown]
# # Is debiasing good in terms of speed and model selection?
#
# Within each IHT iteration, we can fit a GLM regression (using scoring algorithm) on just the support set of that iteration. This is known as debiasing. We now investigate whether this is a good idea, both in terms of speed and model selection performance. (ans: yes)

# %%
function test_poisson_debias(n :: Int64, p :: Int64, k :: Int64)    
    #set random seed
    Random.seed!(1111)

    #construct snpmatrix, covariate files, and true model b
    x, maf = simulate_random_snparray(n, p)
    xbm = SnpBitMatrix{Float64}(x, model=ADDITIVE_MODEL, center=true, scale=true); 
    z = ones(n, 1) # non-genetic covariates, just the intercept
    true_b = zeros(p)
    true_b[1:k] = rand(Normal(0, 0.4), k)
    shuffle!(true_b)
    correct_position = findall(x -> x != 0, true_b)

    # Simulate poisson data
    y_temp = xbm * true_b
    λ = exp.(y_temp) #inverse log link
    y = [rand(Poisson(x)) for x in λ]
    y = Float64.(y)

    #compute poisson IHT result
    no_debias = L0_poisson_reg(x, z, y, 1, k, glm = "poisson", debias=false, convg=false, show_info=false, init=false)
    yes_debias = L0_poisson_reg(x, z, y, 1, k, glm = "poisson", debias=true, convg=false, show_info=false, init=false)
    
    #check result
    est_model_yes = yes_debias.beta[correct_position]
    est_model_no = no_debias.beta[correct_position]
    true_model = true_b[correct_position]
    compare_model = DataFrame(
        true_β           = true_model, 
        est_β_no_debias  = est_model_no,
        est_β_yes_debias = est_model_yes)
        
    #display results
    @show sort(compare_model, rev=true, by=abs)
    println("No debiasing:")
    println("    Iter = " * string(no_debias.iter))
    println("    Time = " * string(no_debias.time))
    println("Yes debiasing:")
    println("    Iter = " * string(yes_debias.iter))
    println("    Time = " * string(yes_debias.time) * "\n\n")
    
    #return summary statistic
    yes_debias_found = length(findall(!iszero, est_model_yes))
    no_debias_found = length(findall(!iszero, est_model_no))
    yes_debias_time = yes_debias.time
    no_debias_time = no_debias.time
    return yes_debias_found, no_debias_found, yes_debias_time, no_debias_time
end
# Out:
# test_poisson_debias (generic function with 1 method)

# %%
k = 10
yes_debias_total_found = 0
no_debias_total_found = 0
yes_debias_total_time = 0
no_debias_total_time = 0

iter = 50
for i = 1:iter
    println("running the $i th model")
    n = rand(500:2000) 
    p = rand(1:10)n
    println("n, p = " * string(n) * ", " * string(p))
    ydf, ndf, ydt, ndt = test_poisson_debias(n, p, k)
    yes_debias_total_found += ydf
    no_debias_total_found += ndf
    yes_debias_total_time += ydt
    no_debias_total_time += ndt
end
println("With debiasing, found $yes_debias_total_found " * "predictors out of " * string(k*iter))
println("With debiasing, average time was " * string(yes_debias_total_time/iter))
println("Without debiasing, found $no_debias_total_found " * "predictors out of " * string(k*iter))
println("Without debiasing, average time was " * string(no_debias_total_time/iter))
# Out:
# running the 1 th model
# n, p = 1695, 10170
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β     │ est_β_no_debias │ est_β_yes_debias │
# │     │ Float64    │ Float64         │ Float64          │
# ├─────┼────────────┼─────────────────┼──────────────────┤
# │ 1   │ -0.942554  │ -0.930659       │ -0.930799        │
# │ 2   │ 0.68117    │ 0.691088        │ 0.69103          │
# │ 3   │ -0.371658  │ -0.372763       │ -0.372735        │
# │ 4   │ -0.341904  │ -0.328759       │ -0.328743        │
# │ 5   │ -0.280735  │ -0.267045       │ -0.267026        │
# │ 6   │ -0.255104  │ -0.24732        │ -0.247274        │
# │ 7   │ -0.185256  │ -0.165724       │ -0.165698        │
# │ 8   │ 0.113998   │ 0.122994        │ 0.122978         │
# │ 9   │ 0.0876498  │ 0.102293        │ 0.10228          │
# │ 10  │ -0.0591206 │ -0.078097       │ -0.0780855       │
# No debiasing:
#     Iter = 22
#     Time = 2.0880799293518066
# Yes debiasing:
#     Iter = 24
#     Time = 2.273534059524536
#
#
# running the 2 th model
# n, p = 920, 920
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β     │ est_β_no_debias │ est_β_yes_debias │
# │     │ Float64    │ Float64         │ Float64          │
# ├─────┼────────────┼─────────────────┼──────────────────┤
# │ 1   │ 0.590952   │ 0.602319        │ 0.607068         │
# │ 2   │ 0.484482   │ 0.502245        │ 0.504967         │
# │ 3   │ -0.462305  │ -0.445918       │ -0.455735        │
# │ 4   │ -0.425366  │ -0.406035       │ -0.407318        │
# │ 5   │ -0.347269  │ -0.353346       │ -0.356172        │
# │ 6   │ -0.306306  │ -0.329828       │ -0.337932        │
# │ 7   │ -0.296716  │ -0.316884       │ -0.316832        │
# │ 8   │ 0.168289   │ 0.162387        │ 0.157138         │
# │ 9   │ -0.0954101 │ 0.0             │ 0.0              │
# │ 10  │ 0.0204819  │ 0.0             │ 0.0              │
# No debiasing:
#     Iter = 38
#     Time = 0.1706409454345703
# Yes debiasing:
#     Iter = 55
#     Time = 0.27397704124450684
#
#
# running the 3 th model
# n, p = 977, 8793
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β     │ est_β_no_debias │ est_β_yes_debias │
# │     │ Float64    │ Float64         │ Float64          │
# ├─────┼────────────┼─────────────────┼──────────────────┤
# │ 1   │ -0.909648  │ -0.917958       │ -0.913817        │
# │ 2   │ 0.644969   │ 0.63492         │ 0.64849          │
# │ 3   │ -0.576734  │ -0.595513       │ -0.589451        │
# │ 4   │ -0.541886  │ -0.508561       │ -0.503362        │
# │ 5   │ 0.50797    │ 0.532237        │ 0.52479          │
# │ 6   │ -0.27119   │ -0.246383       │ -0.253481        │
# │ 7   │ -0.242931  │ -0.261209       │ -0.259039        │
# │ 8   │ 0.155869   │ 0.146446        │ 0.0              │
# │ 9   │ -0.133905  │ -0.141664       │ -0.11971         │
# │ 10  │ -0.0785947 │ -0.132829       │ -0.13703         │
# No debiasing:
#     Iter = 29
#     Time = 1.3415617942810059
# Yes debiasing:
#     Iter = 28
#     Time = 1.3237779140472412
#
#
# running the 4 th model
# n, p = 1308, 2616
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β    │ est_β_no_debias │ est_β_yes_debias │
# │     │ Float64   │ Float64         │ Float64          │
# ├─────┼───────────┼─────────────────┼──────────────────┤
# │ 1   │ 0.483259  │ 0.487596        │ 0.487585         │
# │ 2   │ 0.438643  │ 0.449924        │ 0.449908         │
# │ 3   │ -0.401439 │ -0.407832       │ -0.407834        │
# │ 4   │ 0.393119  │ 0.373617        │ 0.373609         │
# │ 5   │ 0.341285  │ 0.338257        │ 0.33825          │
# │ 6   │ -0.333877 │ -0.30314        │ -0.303303        │
# │ 7   │ 0.263342  │ 0.289028        │ 0.289022         │
# │ 8   │ 0.143059  │ 0.153775        │ 0.153783         │
# │ 9   │ 0.107832  │ 0.124312        │ 0.124291         │
# │ 10  │ 0.0355878 │ 0.0             │ 0.0              │
# No debiasing:
#     Iter = 15
#     Time = 0.2988269329071045
# Yes debiasing:
#     Iter = 18
#     Time = 0.3619418144226074
#
#
# running the 5 th model
# n, p = 990, 2970
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β     │ est_β_no_debias │ est_β_yes_debias │
# │     │ Float64    │ Float64         │ Float64          │
# ├─────┼────────────┼─────────────────┼──────────────────┤
# │ 1   │ -0.753531  │ -0.783494       │ -0.779218        │
# │ 2   │ -0.737666  │ -0.774864       │ -0.783029        │
# │ 3   │ 0.543119   │ 0.571758        │ 0.575512         │
# │ 4   │ -0.520461  │ -0.493517       │ -0.503256        │
# │ 5   │ -0.375613  │ -0.371022       │ -0.377562        │
# │ 6   │ -0.211404  │ -0.203042       │ -0.204012        │
# │ 7   │ -0.154816  │ -0.131016       │ -0.116624        │
# │ 8   │ -0.0997489 │ -0.0971392      │ -0.0919376       │
# │ 9   │ -0.0972013 │ -0.0697609      │ -0.0655338       │
# │ 10  │ 0.026889   │ 0.0             │ 0.0              │
# No debiasing:
#     Iter = 19
#     Time = 0.3153250217437744
# Yes debiasing:
#     Iter = 25
#     Time = 0.4220468997955322
#
#
# running the 6 th model
# n, p = 1846, 11076
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β    │ est_β_no_debias │ est_β_yes_debias │
# │     │ Float64   │ Float64         │ Float64          │
# ├─────┼───────────┼─────────────────┼──────────────────┤
# │ 1   │ -0.684199 │ -0.694716       │ -0.687005        │
# │ 2   │ 0.482994  │ 0.508745        │ 0.506561         │
# │ 3   │ -0.271703 │ -0.259823       │ -0.256882        │
# │ 4   │ -0.220923 │ -0.192407       │ -0.190642        │
# │ 5   │ -0.217326 │ -0.237261       │ -0.239285        │
# │ 6   │ -0.180963 │ -0.17616        │ -0.18178         │
# │ 7   │ 0.131872  │ 0.145678        │ 0.14248          │
# │ 8   │ 0.107948  │ 0.0972943       │ 0.0981396        │
# │ 9   │ 0.0914802 │ 0.0948328       │ 0.0979893        │
# │ 10  │ 0.0217313 │ 0.0             │ 0.0              │
# No debiasing:
#     Iter = 26
#     Time = 2.8850150108337402
# Yes debiasing:
#     Iter = 18
#     Time = 2.0673320293426514
#
#
# running the 7 th model
# n, p = 1653, 9918
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β     │ est_β_no_debias │ est_β_yes_debias │
# │     │ Float64    │ Float64         │ Float64          │
# ├─────┼────────────┼─────────────────┼──────────────────┤
# │ 1   │ 0.762646   │ 0.756968        │ 0.756915         │
# │ 2   │ -0.460307  │ -0.453051       │ -0.453169        │
# │ 3   │ -0.457652  │ -0.461486       │ -0.461425        │
# │ 4   │ -0.439135  │ -0.431369       │ -0.431913        │
# │ 5   │ -0.24675   │ -0.267058       │ -0.267014        │
# │ 6   │ 0.228552   │ 0.242496        │ 0.242468         │
# │ 7   │ 0.174223   │ 0.201166        │ 0.201142         │
# │ 8   │ -0.153352  │ -0.166879       │ -0.166854        │
# │ 9   │ -0.109754  │ -0.0802136      │ -0.0802178       │
# │ 10  │ -0.0982089 │ 0.0             │ 0.0              │
# No debiasing:
#     Iter = 40
#     Time = 3.4852488040924072
# Yes debiasing:
#     Iter = 23
#     Time = 2.079117774963379
#
#
# running the 8 th model
# n, p = 1638, 11466
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β     │ est_β_no_debias │ est_β_yes_debias │
# │     │ Float64    │ Float64         │ Float64          │
# ├─────┼────────────┼─────────────────┼──────────────────┤
# │ 1   │ -0.757122  │ -0.803269       │ -0.812529        │
# │ 2   │ 0.556755   │ 0.52855         │ 0.524692         │
# │ 3   │ -0.527216  │ -0.54513        │ -0.543255        │
# │ 4   │ 0.495463   │ 0.516838        │ 0.51449          │
# │ 5   │ -0.248096  │ -0.242965       │ -0.241058        │
# │ 6   │ 0.230482   │ 0.252739        │ 0.258843         │
# │ 7   │ -0.181637  │ -0.216637       │ -0.212081        │
# │ 8   │ -0.165204  │ -0.140725       │ -0.136354        │
# │ 9   │ -0.0896718 │ 0.0             │ 0.0              │
# │ 10  │ 0.065926   │ 0.0             │ 0.0              │
# No debiasing:
#     Iter = 55
#     Time = 5.549540042877197
# Yes debiasing:
#     Iter = 24
#     Time = 2.475727081298828
#
#
# running the 9 th model
# n, p = 1915, 19150
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β     │ est_β_no_debias │ est_β_yes_debias │
# │     │ Float64    │ Float64         │ Float64          │
# ├─────┼────────────┼─────────────────┼──────────────────┤
# │ 1   │ -0.481773  │ -0.449727       │ -0.451283        │
# │ 2   │ 0.453967   │ 0.465984        │ 0.468109         │
# │ 3   │ -0.440995  │ -0.434156       │ -0.438726        │
# │ 4   │ 0.335234   │ 0.342449        │ 0.341492         │
# │ 5   │ 0.243412   │ 0.213934        │ 0.216592         │
# │ 6   │ 0.237088   │ 0.249385        │ 0.245086         │
# │ 7   │ -0.144553  │ -0.142648       │ -0.141824        │
# │ 8   │ 0.0711592  │ 0.0             │ 0.0              │
# │ 9   │ -0.0408035 │ 0.0             │ 0.0              │
# │ 10  │ 0.0406431  │ 0.0             │ 0.0              │
# No debiasing:
#     Iter = 16
#     Time = 3.3424429893493652
# Yes debiasing:
#     Iter = 18
#     Time = 3.650491952896118
#
#
# running the 10 th model
# n, p = 1517, 4551
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β     │ est_β_no_debias │ est_β_yes_debias │
# │     │ Float64    │ Float64         │ Float64          │
# ├─────┼────────────┼─────────────────┼──────────────────┤
# │ 1   │ 0.48958    │ 0.480883        │ 0.497573         │
# │ 2   │ 0.451233   │ 0.449116        │ 0.46607          │
# │ 3   │ 0.419955   │ 0.398718        │ 0.429487         │
# │ 4   │ -0.31815   │ -0.319981       │ 0.0              │
# │ 5   │ 0.317853   │ 0.28129         │ 0.306272         │
# │ 6   │ -0.246993  │ -0.222401       │ -0.225738        │
# │ 7   │ -0.12808   │ 0.0             │ 0.0              │
# │ 8   │ -0.0778959 │ 0.0             │ 0.0              │
# │ 9   │ -0.0628822 │ 0.0             │ 0.0              │
# │ 10  │ -0.061603  │ 0.0             │ 0.0              │
# No debiasing:
#     Iter = 48
#     Time = 1.7514820098876953
# Yes debiasing:
#     Iter = 1000
#     Time = 37.007335901260376
#
#
# running the 11 th model
# n, p = 997, 7976
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β     │ est_β_no_debias │ est_β_yes_debias │
# │     │ Float64    │ Float64         │ Float64          │
# ├─────┼────────────┼─────────────────┼──────────────────┤
# │ 1   │ 0.755247   │ 0.772455        │ 0.769392         │
# │ 2   │ 0.647156   │ 0.669823        │ 0.67927          │
# │ 3   │ 0.614387   │ 0.618394        │ 0.628444         │
# │ 4   │ 0.446093   │ 0.429754        │ 0.44419          │
# │ 5   │ -0.352303  │ -0.349789       │ -0.34154         │
# │ 6   │ -0.346702  │ -0.348348       │ -0.367021        │
# │ 7   │ 0.285626   │ 0.263987        │ 0.277549         │
# │ 8   │ -0.203211  │ 0.0             │ 0.0              │
# │ 9   │ 0.154406   │ 0.188965        │ 0.191578         │
# │ 10  │ -0.0231256 │ 0.0             │ 0.0              │
# No debiasing:
#     Iter = 52
#     Time = 2.186702013015747
# Yes debiasing:
#     Iter = 65
#     Time = 2.7506730556488037
#
#
# running the 12 th model
# n, p = 731, 5848
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β     │ est_β_no_debias │ est_β_yes_debias │
# │     │ Float64    │ Float64         │ Float64          │
# ├─────┼────────────┼─────────────────┼──────────────────┤
# │ 1   │ 0.497829   │ 0.50699         │ 0.502289         │
# │ 2   │ -0.478424  │ -0.425661       │ -0.425323        │
# │ 3   │ -0.350742  │ -0.340896       │ -0.338741        │
# │ 4   │ -0.234836  │ -0.191585       │ -0.193965        │
# │ 5   │ -0.219709  │ -0.220384       │ -0.215175        │
# │ 6   │ -0.182933  │ -0.208463       │ -0.21428         │
# │ 7   │ -0.178541  │ 0.0             │ 0.0              │
# │ 8   │ -0.130599  │ 0.0             │ 0.0              │
# │ 9   │ -0.117641  │ 0.0             │ -0.130909        │
# │ 10  │ 0.00227033 │ 0.0             │ 0.0              │
# No debiasing:
#     Iter = 14
#     Time = 0.3518521785736084
# Yes debiasing:
#     Iter = 18
#     Time = 0.4557058811187744
#
#
# running the 13 th model
# n, p = 900, 900
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β     │ est_β_no_debias │ est_β_yes_debias │
# │     │ Float64    │ Float64         │ Float64          │
# ├─────┼────────────┼─────────────────┼──────────────────┤
# │ 1   │ -1.07521   │ -1.10677        │ -1.10779         │
# │ 2   │ -0.658179  │ -0.615055       │ -0.614832        │
# │ 3   │ -0.560032  │ -0.560214       │ -0.559993        │
# │ 4   │ -0.451056  │ -0.475263       │ -0.475072        │
# │ 5   │ -0.403148  │ -0.379813       │ -0.379662        │
# │ 6   │ -0.219554  │ -0.183802       │ -0.18373         │
# │ 7   │ -0.15269   │ -0.174534       │ -0.174464        │
# │ 8   │ -0.11204   │ -0.11807        │ -0.118061        │
# │ 9   │ -0.0206368 │ 0.0             │ 0.0              │
# │ 10  │ -0.0164221 │ 0.0             │ 0.0              │
# No debiasing:
#     Iter = 59
#     Time = 0.273845911026001
# Yes debiasing:
#     Iter = 23
#     Time = 0.11350107192993164
#
#
# running the 14 th model
# n, p = 542, 4878
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β     │ est_β_no_debias │ est_β_yes_debias │
# │     │ Float64    │ Float64         │ Float64          │
# ├─────┼────────────┼─────────────────┼──────────────────┤
# │ 1   │ -0.65731   │ -0.652546       │ -0.699997        │
# │ 2   │ -0.644042  │ -0.605099       │ -0.597867        │
# │ 3   │ -0.636558  │ -0.608649       │ -0.627845        │
# │ 4   │ -0.561508  │ -0.539752       │ -0.524332        │
# │ 5   │ -0.510788  │ -0.546284       │ -0.554406        │
# │ 6   │ -0.500863  │ -0.546823       │ -0.530767        │
# │ 7   │ 0.278914   │ 0.0             │ 0.0              │
# │ 8   │ 0.183383   │ 0.0             │ 0.0              │
# │ 9   │ -0.135402  │ 0.0             │ 0.0              │
# │ 10  │ -0.0468825 │ 0.0             │ 0.0              │
# No debiasing:
#     Iter = 55
#     Time = 0.805413007736206
# Yes debiasing:
#     Iter = 43
#     Time = 0.6301059722900391
#
#
# running the 15 th model
# n, p = 1818, 7272
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β      │ est_β_no_debias │ est_β_yes_debias │
# │     │ Float64     │ Float64         │ Float64          │
# ├─────┼─────────────┼─────────────────┼──────────────────┤
# │ 1   │ 0.595447    │ 0.590106        │ 0.593242         │
# │ 2   │ 0.534855    │ 0.525617        │ 0.525928         │
# │ 3   │ -0.501417   │ -0.488207       │ -0.496291        │
# │ 4   │ 0.395521    │ 0.388746        │ 0.392729         │
# │ 5   │ -0.389992   │ -0.394288       │ -0.387242        │
# │ 6   │ -0.306153   │ -0.293558       │ -0.29683         │
# │ 7   │ 0.270308    │ 0.255244        │ 0.263067         │
# │ 8   │ 0.243411    │ 0.248041        │ 0.252598         │
# │ 9   │ -0.0160182  │ 0.0             │ 0.0              │
# │ 10  │ -0.00244607 │ 0.0             │ 0.0              │
# No debiasing:
#     Iter = 63
#     Time = 4.355239152908325
# Yes debiasing:
#     Iter = 42
#     Time = 2.9634029865264893
#
#
# running the 16 th model
# n, p = 1886, 5658
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β    │ est_β_no_debias │ est_β_yes_debias │
# │     │ Float64   │ Float64         │ Float64          │
# ├─────┼───────────┼─────────────────┼──────────────────┤
# │ 1   │ 0.922772  │ 0.921499        │ 0.921475         │
# │ 2   │ 0.726387  │ 0.729343        │ 0.729327         │
# │ 3   │ -0.515729 │ -0.497052       │ -0.497357        │
# │ 4   │ -0.353146 │ -0.383405       │ -0.383371        │
# │ 5   │ 0.348198  │ 0.324455        │ 0.324449         │
# │ 6   │ 0.326237  │ 0.332638        │ 0.332617         │
# │ 7   │ -0.218986 │ -0.211703       │ -0.211644        │
# │ 8   │ -0.197665 │ -0.211612       │ -0.21161         │
# │ 9   │ 0.180255  │ 0.176989        │ 0.176997         │
# │ 10  │ -0.16877  │ -0.172357       │ -0.172339        │
# No debiasing:
#     Iter = 79
#     Time = 4.336810827255249
# Yes debiasing:
#     Iter = 97
#     Time = 5.439774990081787
#
#
# running the 17 th model
# n, p = 1586, 12688
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β    │ est_β_no_debias │ est_β_yes_debias │
# │     │ Float64   │ Float64         │ Float64          │
# ├─────┼───────────┼─────────────────┼──────────────────┤
# │ 1   │ 0.647162  │ 0.67499         │ 0.682            │
# │ 2   │ 0.451251  │ 0.446896        │ 0.455543         │
# │ 3   │ 0.337837  │ 0.332096        │ 0.339682         │
# │ 4   │ -0.328529 │ -0.347133       │ -0.350908        │
# │ 5   │ -0.27717  │ -0.307107       │ 0.0              │
# │ 6   │ 0.270014  │ 0.261243        │ 0.284398         │
# │ 7   │ -0.234113 │ -0.217586       │ -0.227575        │
# │ 8   │ 0.208214  │ 0.208612        │ 0.222303         │
# │ 9   │ -0.159975 │ 0.0             │ 0.0              │
# │ 10  │ 0.0765779 │ 0.0             │ 0.0              │
# No debiasing:
#     Iter = 45
#     Time = 4.859637022018433
# Yes debiasing:
#     Iter = 38
#     Time = 4.091587066650391
#
#
# running the 18 th model
# n, p = 944, 2832
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β     │ est_β_no_debias │ est_β_yes_debias │
# │     │ Float64    │ Float64         │ Float64          │
# ├─────┼────────────┼─────────────────┼──────────────────┤
# │ 1   │ 0.728171   │ 0.731244        │ 0.733616         │
# │ 2   │ 0.461025   │ 0.446403        │ 0.441362         │
# │ 3   │ 0.307072   │ 0.300706        │ 0.267867         │
# │ 4   │ 0.296419   │ 0.296859        │ 0.302693         │
# │ 5   │ -0.266931  │ -0.268297       │ -0.301165        │
# │ 6   │ -0.235954  │ -0.215457       │ 0.0              │
# │ 7   │ -0.202921  │ -0.217865       │ -0.238433        │
# │ 8   │ 0.0968658  │ 0.0913913       │ 0.0              │
# │ 9   │ -0.0485865 │ 0.0             │ 0.0              │
# │ 10  │ -0.0125181 │ 0.0             │ 0.0              │
# No debiasing:
#     Iter = 53
#     Time = 0.7298829555511475
# Yes debiasing:
#     Iter = 122
#     Time = 1.7689640522003174
#
#
# running the 19 th model
# n, p = 712, 2136
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β    │ est_β_no_debias │ est_β_yes_debias │
# │     │ Float64   │ Float64         │ Float64          │
# ├─────┼───────────┼─────────────────┼──────────────────┤
# │ 1   │ -0.856996 │ -0.89653        │ -0.897225        │
# │ 2   │ -0.651603 │ -0.665184       │ -0.664997        │
# │ 3   │ 0.551485  │ 0.559916        │ 0.559892         │
# │ 4   │ 0.4274    │ 0.389229        │ 0.38918          │
# │ 5   │ 0.299158  │ 0.296559        │ 0.296501         │
# │ 6   │ 0.255713  │ 0.27641         │ 0.276406         │
# │ 7   │ -0.204354 │ 0.0             │ 0.0              │
# │ 8   │ -0.159699 │ 0.0             │ 0.0              │
# │ 9   │ -0.148884 │ -0.116935       │ -0.116914        │
# │ 10  │ 0.015553  │ 0.0             │ 0.0              │
# No debiasing:
#     Iter = 31
#     Time = 0.25989484786987305
# Yes debiasing:
#     Iter = 20
#     Time = 0.18271207809448242
#
#
# running the 20 th model
# n, p = 1513, 7565
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β     │ est_β_no_debias │ est_β_yes_debias │
# │     │ Float64    │ Float64         │ Float64          │
# ├─────┼────────────┼─────────────────┼──────────────────┤
# │ 1   │ -0.878945  │ -0.85975        │ -0.854855        │
# │ 2   │ -0.553755  │ -0.542312       │ -0.543986        │
# │ 3   │ 0.498278   │ 0.496207        │ 0.494969         │
# │ 4   │ 0.496185   │ 0.483516        │ 0.487126         │
# │ 5   │ -0.383648  │ -0.385457       │ -0.396384        │
# │ 6   │ 0.310939   │ 0.315462        │ 0.313152         │
# │ 7   │ 0.310521   │ 0.30631         │ 0.309139         │
# │ 8   │ 0.148815   │ 0.128026        │ 0.131013         │
# │ 9   │ 0.0819315  │ 0.0865499       │ 0.0              │
# │ 10  │ 0.00774295 │ 0.0             │ 0.0              │
# No debiasing:
#     Iter = 33
#     Time = 2.0200300216674805
# Yes debiasing:
#     Iter = 33
#     Time = 2.0536000728607178
#
#
# running the 21 th model
# n, p = 703, 2812
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β    │ est_β_no_debias │ est_β_yes_debias │
# │     │ Float64   │ Float64         │ Float64          │
# ├─────┼───────────┼─────────────────┼──────────────────┤
# │ 1   │ 0.725449  │ 0.720563        │ 0.720563         │
# │ 2   │ -0.702869 │ -0.664715       │ -0.664715        │
# │ 3   │ 0.601941  │ 0.582948        │ 0.582948         │
# │ 4   │ 0.447434  │ 0.454354        │ 0.454354         │
# │ 5   │ 0.299092  │ 0.346775        │ 0.346775         │
# │ 6   │ 0.146865  │ 0.0             │ 0.0              │
# │ 7   │ 0.0627483 │ 0.0             │ 0.0              │
# │ 8   │ 0.0406268 │ 0.0             │ 0.0              │
# │ 9   │ 0.0316617 │ 0.0             │ 0.0              │
# │ 10  │ 0.0218377 │ 0.0             │ 0.0              │
# No debiasing:
#     Iter = 355
#     Time = 3.608208179473877
# Yes debiasing:
#     Iter = 355
#     Time = 3.7069740295410156
#
#
# running the 22 th model
# n, p = 1104, 9936
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β     │ est_β_no_debias │ est_β_yes_debias │
# │     │ Float64    │ Float64         │ Float64          │
# ├─────┼────────────┼─────────────────┼──────────────────┤
# │ 1   │ 0.987544   │ 0.979383        │ 0.977555         │
# │ 2   │ 0.678189   │ 0.669208        │ 0.672586         │
# │ 3   │ -0.305246  │ -0.333597       │ -0.328325        │
# │ 4   │ 0.256413   │ 0.236535        │ 0.232776         │
# │ 5   │ -0.160048  │ -0.184932       │ -0.174793        │
# │ 6   │ 0.151931   │ 0.154527        │ 0.159159         │
# │ 7   │ 0.142386   │ 0.147415        │ 0.152881         │
# │ 8   │ 0.123605   │ 0.1184          │ 0.108456         │
# │ 9   │ 0.088064   │ 0.0786027       │ 0.0              │
# │ 10  │ -0.0197149 │ 0.0             │ 0.0              │
# No debiasing:
#     Iter = 25
#     Time = 1.5110960006713867
# Yes debiasing:
#     Iter = 28
#     Time = 1.7124309539794922
#
#
# running the 23 th model
# n, p = 744, 2232
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β    │ est_β_no_debias │ est_β_yes_debias │
# │     │ Float64   │ Float64         │ Float64          │
# ├─────┼───────────┼─────────────────┼──────────────────┤
# │ 1   │ 0.510857  │ 0.450956        │ 0.443304         │
# │ 2   │ 0.474958  │ 0.483664        │ 0.482712         │
# │ 3   │ -0.421889 │ -0.397917       │ -0.404167        │
# │ 4   │ -0.333413 │ -0.331525       │ -0.32831         │
# │ 5   │ -0.197538 │ -0.208731       │ -0.200709        │
# │ 6   │ -0.191459 │ -0.209533       │ -0.209356        │
# │ 7   │ 0.112319  │ 0.0             │ 0.0              │
# │ 8   │ 0.0748705 │ 0.112745        │ 0.120054         │
# │ 9   │ 0.0743943 │ 0.0             │ 0.0              │
# │ 10  │ 0.0437944 │ 0.0             │ 0.0              │
# No debiasing:
#     Iter = 14
#     Time = 0.1319282054901123
# Yes debiasing:
#     Iter = 32
#     Time = 0.30238890647888184
#
#
# running the 24 th model
# n, p = 1088, 9792
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β    │ est_β_no_debias │ est_β_yes_debias │
# │     │ Float64   │ Float64         │ Float64          │
# ├─────┼───────────┼─────────────────┼──────────────────┤
# │ 1   │ -0.836769 │ -0.818037       │ -0.817959        │
# │ 2   │ -0.701615 │ -0.697638       │ -0.697595        │
# │ 3   │ -0.592892 │ -0.591058       │ -0.591214        │
# │ 4   │ -0.59184  │ -0.573502       │ -0.573522        │
# │ 5   │ 0.508885  │ 0.503952        │ 0.503945         │
# │ 6   │ -0.269591 │ -0.25284        │ -0.252823        │
# │ 7   │ 0.177828  │ 0.179328        │ 0.179333         │
# │ 8   │ 0.141927  │ 0.123139        │ 0.12312          │
# │ 9   │ 0.131908  │ 0.148406        │ 0.148391         │
# │ 10  │ 0.0638052 │ 0.0             │ 0.0              │
# No debiasing:
#     Iter = 27
#     Time = 1.5958619117736816
# Yes debiasing:
#     Iter = 29
#     Time = 1.7350502014160156
#
#
# running the 25 th model
# n, p = 701, 1402
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β    │ est_β_no_debias │ est_β_yes_debias │
# │     │ Float64   │ Float64         │ Float64          │
# ├─────┼───────────┼─────────────────┼──────────────────┤
# │ 1   │ -1.02541  │ -1.07517        │ -1.07629         │
# │ 2   │ 0.701906  │ 0.666941        │ 0.656696         │
# │ 3   │ 0.699202  │ 0.734532        │ 0.740987         │
# │ 4   │ 0.366881  │ 0.356046        │ 0.35922          │
# │ 5   │ -0.306206 │ -0.230048       │ -0.23676         │
# │ 6   │ -0.20917  │ -0.210113       │ -0.206878        │
# │ 7   │ -0.207967 │ -0.19176        │ -0.1755          │
# │ 8   │ -0.153034 │ 0.0             │ 0.0              │
# │ 9   │ 0.10595   │ 0.106019        │ 0.102297         │
# │ 10  │ 0.020284  │ 0.0             │ 0.0              │
# No debiasing:
#     Iter = 77
#     Time = 0.430696964263916
# Yes debiasing:
#     Iter = 29
#     Time = 0.17374396324157715
#
#
# running the 26 th model
# n, p = 1638, 4914
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β     │ est_β_no_debias │ est_β_yes_debias │
# │     │ Float64    │ Float64         │ Float64          │
# ├─────┼────────────┼─────────────────┼──────────────────┤
# │ 1   │ 0.603897   │ 0.593289        │ 0.589108         │
# │ 2   │ -0.572936  │ -0.593552       │ -0.593011        │
# │ 3   │ 0.309317   │ 0.313256        │ 0.310984         │
# │ 4   │ 0.251871   │ 0.239132        │ 0.236326         │
# │ 5   │ 0.199882   │ 0.206373        │ 0.200053         │
# │ 6   │ -0.153837  │ -0.15355        │ -0.14961         │
# │ 7   │ 0.115154   │ 0.127162        │ 0.130735         │
# │ 8   │ -0.111196  │ -0.0830155      │ -0.0796332       │
# │ 9   │ 0.0614801  │ 0.0             │ 0.0              │
# │ 10  │ -0.0596896 │ -0.0740701      │ -0.0722831       │
# No debiasing:
#     Iter = 29
#     Time = 1.326840877532959
# Yes debiasing:
#     Iter = 27
#     Time = 1.2535510063171387
#
#
# running the 27 th model
# n, p = 1635, 8175
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β     │ est_β_no_debias │ est_β_yes_debias │
# │     │ Float64    │ Float64         │ Float64          │
# ├─────┼────────────┼─────────────────┼──────────────────┤
# │ 1   │ 0.933033   │ 0.928513        │ 0.935992         │
# │ 2   │ -0.586393  │ -0.554797       │ -0.551968        │
# │ 3   │ 0.58449    │ 0.584266        │ 0.587314         │
# │ 4   │ 0.553496   │ 0.579599        │ 0.584349         │
# │ 5   │ -0.501116  │ -0.49984        │ -0.501804        │
# │ 6   │ 0.377809   │ 0.374097        │ 0.375411         │
# │ 7   │ -0.275793  │ -0.305318       │ -0.311398        │
# │ 8   │ 0.111164   │ 0.113773        │ 0.106172         │
# │ 9   │ -0.0860201 │ 0.0             │ 0.0              │
# │ 10  │ 0.0349796  │ 0.0             │ 0.0              │
# No debiasing:
#     Iter = 98
#     Time = 6.777402877807617
# Yes debiasing:
#     Iter = 97
#     Time = 6.8339948654174805
#
#
# running the 28 th model
# n, p = 598, 2392
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β    │ est_β_no_debias │ est_β_yes_debias │
# │     │ Float64   │ Float64         │ Float64          │
# ├─────┼───────────┼─────────────────┼──────────────────┤
# │ 1   │ 0.530026  │ 0.517423        │ 0.52674          │
# │ 2   │ -0.376029 │ -0.384358       │ -0.364197        │
# │ 3   │ -0.354269 │ 0.0             │ 0.0              │
# │ 4   │ -0.346859 │ -0.37072        │ -0.338736        │
# │ 5   │ 0.275157  │ 0.270064        │ 0.284349         │
# │ 6   │ -0.256904 │ 0.0             │ 0.0              │
# │ 7   │ 0.17024   │ 0.0             │ 0.0              │
# │ 8   │ -0.152749 │ -0.153547       │ -0.151795        │
# │ 9   │ 0.0869181 │ 0.0             │ 0.0              │
# │ 10  │ 0.0430493 │ 0.0             │ 0.0              │
# No debiasing:
#     Iter = 18
#     Time = 0.1511399745941162
# Yes debiasing:
#     Iter = 31
#     Time = 0.2590510845184326
#
#
# running the 29 th model
# n, p = 1747, 5241
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β     │ est_β_no_debias │ est_β_yes_debias │
# │     │ Float64    │ Float64         │ Float64          │
# ├─────┼────────────┼─────────────────┼──────────────────┤
# │ 1   │ 0.690217   │ 0.687728        │ 0.681857         │
# │ 2   │ -0.420253  │ -0.426601       │ -0.426936        │
# │ 3   │ 0.376193   │ 0.380165        │ 0.389843         │
# │ 4   │ -0.373311  │ -0.38528        │ -0.382884        │
# │ 5   │ 0.308767   │ 0.329531        │ 0.331488         │
# │ 6   │ 0.269365   │ 0.276123        │ 0.278253         │
# │ 7   │ 0.238823   │ 0.246857        │ 0.254085         │
# │ 8   │ -0.0866352 │ 0.0             │ 0.0              │
# │ 9   │ -0.0763307 │ -0.0866006      │ 0.0              │
# │ 10  │ 0.0669669  │ 0.0             │ 0.0              │
# No debiasing:
#     Iter = 27
#     Time = 1.3345749378204346
# Yes debiasing:
#     Iter = 27
#     Time = 1.3678770065307617
#
#
# running the 30 th model
# n, p = 818, 5726
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β     │ est_β_no_debias │ est_β_yes_debias │
# │     │ Float64    │ Float64         │ Float64          │
# ├─────┼────────────┼─────────────────┼──────────────────┤
# │ 1   │ 0.941286   │ 1.74515         │ 1.18366          │
# │ 2   │ 0.926242   │ 1.98185         │ 1.61641          │
# │ 3   │ 0.798888   │ 1.9048          │ 1.01759          │
# │ 4   │ 0.621485   │ 0.0             │ 1.1638           │
# │ 5   │ 0.354951   │ 0.0             │ 0.0              │
# │ 6   │ -0.249857  │ 0.0             │ 0.0              │
# │ 7   │ -0.140652  │ 0.0             │ 0.0              │
# │ 8   │ -0.0909141 │ 0.0             │ 0.0              │
# │ 9   │ 0.0567466  │ 0.0             │ 0.0              │
# │ 10  │ 0.0520133  │ 0.0             │ 0.0              │
# No debiasing:
#     Iter = 1000
#     Time = 25.994589805603027
# Yes debiasing:
#     Iter = 1000
#     Time = 26.115280151367188
#
#
# running the 31 th model
# n, p = 1832, 1832
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β     │ est_β_no_debias │ est_β_yes_debias │
# │     │ Float64    │ Float64         │ Float64          │
# ├─────┼────────────┼─────────────────┼──────────────────┤
# │ 1   │ 0.615847   │ 0.61431         │ 0.614293         │
# │ 2   │ 0.597688   │ 0.573027        │ 0.573007         │
# │ 3   │ 0.571205   │ 0.59189         │ 0.591859         │
# │ 4   │ 0.560302   │ 0.568629        │ 0.568612         │
# │ 5   │ -0.403158  │ -0.38977        │ -0.390263        │
# │ 6   │ -0.333891  │ -0.318857       │ -0.318864        │
# │ 7   │ 0.288575   │ 0.293679        │ 0.293661         │
# │ 8   │ -0.271145  │ -0.279231       │ -0.279231        │
# │ 9   │ 0.197279   │ 0.198467        │ 0.198457         │
# │ 10  │ 0.00757013 │ 0.0             │ 0.0              │
# No debiasing:
#     Iter = 50
#     Time = 0.8973660469055176
# Yes debiasing:
#     Iter = 28
#     Time = 0.5417189598083496
#
#
# running the 32 th model
# n, p = 1559, 12472
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β    │ est_β_no_debias │ est_β_yes_debias │
# │     │ Float64   │ Float64         │ Float64          │
# ├─────┼───────────┼─────────────────┼──────────────────┤
# │ 1   │ -0.623778 │ -0.635533       │ -0.63547         │
# │ 2   │ 0.440261  │ 0.426727        │ 0.426697         │
# │ 3   │ -0.399641 │ -0.444305       │ -0.444745        │
# │ 4   │ 0.321587  │ 0.298893        │ 0.298878         │
# │ 5   │ -0.307081 │ -0.287803       │ -0.287788        │
# │ 6   │ 0.291931  │ 0.272013        │ 0.271989         │
# │ 7   │ 0.190513  │ 0.156719        │ 0.15672          │
# │ 8   │ 0.159143  │ 0.162266        │ 0.16225          │
# │ 9   │ 0.0687084 │ 0.0818966       │ 0.0818929        │
# │ 10  │ -0.012236 │ 0.0             │ 0.0              │
# No debiasing:
#     Iter = 30
#     Time = 3.2100868225097656
# Yes debiasing:
#     Iter = 17
#     Time = 1.8844599723815918
#
#
# running the 33 th model
# n, p = 1091, 7637
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β     │ est_β_no_debias │ est_β_yes_debias │
# │     │ Float64    │ Float64         │ Float64          │
# ├─────┼────────────┼─────────────────┼──────────────────┤
# │ 1   │ 0.634213   │ 0.616166        │ 0.653592         │
# │ 2   │ -0.53541   │ -0.515524       │ 0.0              │
# │ 3   │ 0.457618   │ 0.429973        │ 0.451359         │
# │ 4   │ 0.386943   │ 0.433183        │ 0.438753         │
# │ 5   │ 0.315878   │ 0.335541        │ 0.346745         │
# │ 6   │ 0.29434    │ 0.289085        │ 0.298923         │
# │ 7   │ -0.269934  │ -0.258733       │ -0.246044        │
# │ 8   │ 0.169977   │ 0.168009        │ 0.0              │
# │ 9   │ -0.130196  │ 0.0             │ 0.0              │
# │ 10  │ -0.0759931 │ 0.0             │ 0.0              │
# No debiasing:
#     Iter = 74
#     Time = 3.3251328468322754
# Yes debiasing:
#     Iter = 25
#     Time = 1.166693925857544
#
#
# running the 34 th model
# n, p = 651, 3255
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β     │ est_β_no_debias │ est_β_yes_debias │
# │     │ Float64    │ Float64         │ Float64          │
# ├─────┼────────────┼─────────────────┼──────────────────┤
# │ 1   │ 0.770286   │ 0.778662        │ 0.777174         │
# │ 2   │ -0.669004  │ -0.685269       │ -0.68045         │
# │ 3   │ -0.510337  │ -0.451773       │ -0.474127        │
# │ 4   │ -0.33046   │ -0.377364       │ -0.401868        │
# │ 5   │ 0.31147    │ 0.263685        │ 0.0              │
# │ 6   │ -0.240657  │ -0.258657       │ 0.0              │
# │ 7   │ -0.213137  │ -0.207177       │ -0.156794        │
# │ 8   │ -0.0715017 │ -0.110702       │ 0.0              │
# │ 9   │ -0.0548052 │ 0.0             │ 0.0              │
# │ 10  │ 0.0122846  │ 0.0             │ 0.0              │
# No debiasing:
#     Iter = 30
#     Time = 0.3506131172180176
# Yes debiasing:
#     Iter = 26
#     Time = 0.3110389709472656
#
#
# running the 35 th model
# n, p = 697, 4182
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β    │ est_β_no_debias │ est_β_yes_debias │
# │     │ Float64   │ Float64         │ Float64          │
# ├─────┼───────────┼─────────────────┼──────────────────┤
# │ 1   │ 0.591498  │ 0.596215        │ 0.608097         │
# │ 2   │ -0.547498 │ -0.460049       │ -0.485103        │
# │ 3   │ -0.338025 │ -0.380213       │ -0.400289        │
# │ 4   │ 0.271274  │ 0.228046        │ 0.266078         │
# │ 5   │ -0.218623 │ 0.0             │ 0.0              │
# │ 6   │ 0.218086  │ 0.166339        │ 0.0              │
# │ 7   │ 0.154498  │ 0.0             │ 0.0              │
# │ 8   │ -0.109174 │ -0.156489       │ -0.175536        │
# │ 9   │ -0.079791 │ 0.0             │ 0.0              │
# │ 10  │ 0.0525475 │ 0.0             │ 0.0              │
# No debiasing:
#     Iter = 25
#     Time = 0.41406893730163574
# Yes debiasing:
#     Iter = 19
#     Time = 0.33342909812927246
#
#
# running the 36 th model
# n, p = 1768, 3536
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β    │ est_β_no_debias │ est_β_yes_debias │
# │     │ Float64   │ Float64         │ Float64          │
# ├─────┼───────────┼─────────────────┼──────────────────┤
# │ 1   │ 0.617184  │ 0.614436        │ 0.669612         │
# │ 2   │ -0.612769 │ -0.631312       │ -0.675706        │
# │ 3   │ 0.605673  │ 0.627104        │ 0.652769         │
# │ 4   │ -0.384454 │ 0.0             │ 0.0              │
# │ 5   │ -0.360231 │ -0.392501       │ 0.0              │
# │ 6   │ 0.360143  │ 0.373079        │ 0.0              │
# │ 7   │ -0.278784 │ 0.0             │ 0.0              │
# │ 8   │ 0.246547  │ 0.239618        │ 0.0              │
# │ 9   │ 0.136746  │ 0.167986        │ 0.0              │
# │ 10  │ 0.109369  │ 0.0             │ 0.0              │
# No debiasing:
#     Iter = 82
#     Time = 2.671799898147583
# Yes debiasing:
#     Iter = 1000
#     Time = 34.22497320175171
#
#
# running the 37 th model
# n, p = 1746, 3492
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β     │ est_β_no_debias │ est_β_yes_debias │
# │     │ Float64    │ Float64         │ Float64          │
# ├─────┼────────────┼─────────────────┼──────────────────┤
# │ 1   │ 0.797762   │ 0.795082        │ 0.795104         │
# │ 2   │ 0.635599   │ 0.651449        │ 0.651459         │
# │ 3   │ -0.409235  │ -0.404906       │ -0.404895        │
# │ 4   │ 0.273384   │ 0.285345        │ 0.28534          │
# │ 5   │ 0.264603   │ 0.266461        │ 0.26646          │
# │ 6   │ -0.179359  │ -0.180438       │ -0.180568        │
# │ 7   │ 0.118464   │ 0.131582        │ 0.131557         │
# │ 8   │ 0.0899218  │ 0.085419        │ 0.0854089        │
# │ 9   │ -0.0619943 │ 0.0             │ 0.0              │
# │ 10  │ -0.037852  │ 0.0             │ 0.0              │
# No debiasing:
#     Iter = 26
#     Time = 0.8668699264526367
# Yes debiasing:
#     Iter = 43
#     Time = 1.4609119892120361
#
#
# running the 38 th model
# n, p = 1205, 6025
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β      │ est_β_no_debias │ est_β_yes_debias │
# │     │ Float64     │ Float64         │ Float64          │
# ├─────┼─────────────┼─────────────────┼──────────────────┤
# │ 1   │ 0.700065    │ 0.67128         │ 0.676566         │
# │ 2   │ -0.634188   │ -0.651248       │ -0.66486         │
# │ 3   │ 0.441482    │ 0.451175        │ 0.456461         │
# │ 4   │ -0.362874   │ -0.377691       │ -0.376554        │
# │ 5   │ 0.276999    │ 0.28183         │ 0.293449         │
# │ 6   │ -0.228062   │ -0.231995       │ -0.22788         │
# │ 7   │ 0.155559    │ 0.185052        │ 0.0              │
# │ 8   │ 0.0617368   │ 0.0             │ 0.0614125        │
# │ 9   │ -0.0349045  │ 0.0             │ 0.0              │
# │ 10  │ -0.00357584 │ 0.0             │ 0.0              │
# No debiasing:
#     Iter = 39
#     Time = 1.5354650020599365
# Yes debiasing:
#     Iter = 31
#     Time = 1.2752728462219238
#
#
# running the 39 th model
# n, p = 679, 3395
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β    │ est_β_no_debias │ est_β_yes_debias │
# │     │ Float64   │ Float64         │ Float64          │
# ├─────┼───────────┼─────────────────┼──────────────────┤
# │ 1   │ 0.715711  │ 0.702109        │ 0.681816         │
# │ 2   │ 0.5678    │ 0.617449        │ 0.636954         │
# │ 3   │ -0.298692 │ 0.0             │ 0.0              │
# │ 4   │ -0.285496 │ -0.280674       │ -0.23271         │
# │ 5   │ -0.248122 │ -0.232644       │ -0.208829        │
# │ 6   │ 0.244478  │ 0.255304        │ 0.0              │
# │ 7   │ -0.233479 │ -0.245104       │ -0.261313        │
# │ 8   │ 0.20181   │ 0.0             │ 0.0              │
# │ 9   │ -0.166377 │ -0.238822       │ -0.269684        │
# │ 10  │ -0.154686 │ 0.0             │ 0.0              │
# No debiasing:
#     Iter = 29
#     Time = 0.37587594985961914
# Yes debiasing:
#     Iter = 1000
#     Time = 13.155681133270264
#
#
# running the 40 th model
# n, p = 1580, 12640
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β    │ est_β_no_debias │ est_β_yes_debias │
# │     │ Float64   │ Float64         │ Float64          │
# ├─────┼───────────┼─────────────────┼──────────────────┤
# │ 1   │ -0.630688 │ -0.616692       │ -0.618475        │
# │ 2   │ -0.412694 │ -0.379888       │ -0.379572        │
# │ 3   │ 0.404109  │ 0.396295        │ 0.3962           │
# │ 4   │ -0.331651 │ -0.351621       │ -0.351494        │
# │ 5   │ 0.248696  │ 0.225793        │ 0.225745         │
# │ 6   │ 0.155165  │ 0.163378        │ 0.163336         │
# │ 7   │ 0.152668  │ 0.133338        │ 0.133303         │
# │ 8   │ 0.0921064 │ 0.0             │ 0.0              │
# │ 9   │ 0.0711551 │ 0.0             │ 0.0              │
# │ 10  │ 0.0304753 │ 0.0             │ 0.0              │
# No debiasing:
#     Iter = 82
#     Time = 8.822354078292847
# Yes debiasing:
#     Iter = 30
#     Time = 3.288187026977539
#
#
# running the 41 th model
# n, p = 1738, 1738
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β     │ est_β_no_debias │ est_β_yes_debias │
# │     │ Float64    │ Float64         │ Float64          │
# ├─────┼────────────┼─────────────────┼──────────────────┤
# │ 1   │ 0.417933   │ 0.420174        │ 0.415464         │
# │ 2   │ -0.400958  │ -0.404981       │ -0.400041        │
# │ 3   │ 0.383368   │ 0.391695        │ 0.394999         │
# │ 4   │ -0.281711  │ -0.258515       │ -0.255341        │
# │ 5   │ 0.264253   │ 0.280144        │ 0.281371         │
# │ 6   │ 0.190871   │ 0.203938        │ 0.205326         │
# │ 7   │ 0.167206   │ 0.167207        │ 0.164559         │
# │ 8   │ -0.0912994 │ -0.126828       │ -0.128754        │
# │ 9   │ -0.0724522 │ 0.0             │ 0.0              │
# │ 10  │ 0.0367357  │ 0.0             │ 0.0              │
# No debiasing:
#     Iter = 14
#     Time = 0.24608302116394043
# Yes debiasing:
#     Iter = 25
#     Time = 0.4397730827331543
#
#
# running the 42 th model
# n, p = 1551, 3102
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β     │ est_β_no_debias │ est_β_yes_debias │
# │     │ Float64    │ Float64         │ Float64          │
# ├─────┼────────────┼─────────────────┼──────────────────┤
# │ 1   │ -0.683865  │ -0.680751       │ -0.679966        │
# │ 2   │ -0.65305   │ -0.631978       │ -0.630138        │
# │ 3   │ 0.635855   │ 0.65879         │ 0.663727         │
# │ 4   │ -0.566821  │ -0.562283       │ -0.565383        │
# │ 5   │ 0.469928   │ 0.457805        │ 0.458341         │
# │ 6   │ -0.157993  │ -0.12235        │ -0.131519        │
# │ 7   │ 0.126169   │ 0.122393        │ 0.0              │
# │ 8   │ 0.0972484  │ 0.0780703       │ 0.0868568        │
# │ 9   │ -0.0769899 │ -0.0890559      │ -0.0885572       │
# │ 10  │ -0.0321597 │ 0.0             │ 0.0              │
# No debiasing:
#     Iter = 95
#     Time = 2.4603731632232666
# Yes debiasing:
#     Iter = 40
#     Time = 1.061371088027954
#
#
# running the 43 th model
# n, p = 1223, 11007
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β     │ est_β_no_debias │ est_β_yes_debias │
# │     │ Float64    │ Float64         │ Float64          │
# ├─────┼────────────┼─────────────────┼──────────────────┤
# │ 1   │ 0.849241   │ 0.843793        │ 0.813428         │
# │ 2   │ -0.712738  │ -0.727451       │ -0.744256        │
# │ 3   │ -0.56327   │ -0.536294       │ 0.0              │
# │ 4   │ 0.390978   │ 0.397561        │ 0.0              │
# │ 5   │ -0.31266   │ -0.344911       │ 0.0              │
# │ 6   │ 0.283893   │ 0.273081        │ 0.0              │
# │ 7   │ 0.279893   │ 0.294987        │ 0.0              │
# │ 8   │ 0.140117   │ 0.128005        │ 0.0              │
# │ 9   │ -0.087877  │ -0.0892829      │ 0.0              │
# │ 10  │ -0.0138424 │ 0.0             │ 0.0              │
# No debiasing:
#     Iter = 91
#     Time = 6.487660884857178
# Yes debiasing:
#     Iter = 1000
#     Time = 73.61555099487305
#
#
# running the 44 th model
# n, p = 1987, 13909
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β    │ est_β_no_debias │ est_β_yes_debias │
# │     │ Float64   │ Float64         │ Float64          │
# ├─────┼───────────┼─────────────────┼──────────────────┤
# │ 1   │ 0.558588  │ 0.57609         │ 0.58064          │
# │ 2   │ 0.557593  │ 0.553257        │ 0.551096         │
# │ 3   │ 0.489439  │ 0.466618        │ 0.456777         │
# │ 4   │ -0.402775 │ -0.374654       │ 0.0              │
# │ 5   │ -0.399115 │ -0.421562       │ -0.448364        │
# │ 6   │ 0.380055  │ 0.387882        │ 0.382221         │
# │ 7   │ 0.286399  │ 0.260127        │ 0.274836         │
# │ 8   │ -0.261693 │ -0.254699       │ -0.261109        │
# │ 9   │ 0.235452  │ 0.229496        │ 0.229852         │
# │ 10  │ -0.148027 │ -0.149498       │ 0.0              │
# No debiasing:
#     Iter = 65
#     Time = 9.485581159591675
# Yes debiasing:
#     Iter = 115
#     Time = 16.653027057647705
#
#
# running the 45 th model
# n, p = 1827, 7308
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β     │ est_β_no_debias │ est_β_yes_debias │
# │     │ Float64    │ Float64         │ Float64          │
# ├─────┼────────────┼─────────────────┼──────────────────┤
# │ 1   │ -0.710534  │ -0.693505       │ -0.69199         │
# │ 2   │ -0.638226  │ -0.613544       │ -0.611016        │
# │ 3   │ 0.325002   │ 0.298849        │ 0.294862         │
# │ 4   │ -0.282729  │ -0.264074       │ -0.260814        │
# │ 5   │ -0.276752  │ -0.272753       │ -0.266816        │
# │ 6   │ -0.169203  │ -0.173608       │ -0.17336         │
# │ 7   │ 0.129485   │ 0.12321         │ 0.116361         │
# │ 8   │ -0.10754   │ 0.0             │ 0.0              │
# │ 9   │ 0.0514076  │ 0.0             │ 0.0              │
# │ 10  │ -0.0121619 │ 0.0             │ 0.0              │
# No debiasing:
#     Iter = 39
#     Time = 2.790092945098877
# Yes debiasing:
#     Iter = 16
#     Time = 1.238218069076538
#
#
# running the 46 th model
# n, p = 1527, 3054
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β    │ est_β_no_debias │ est_β_yes_debias │
# │     │ Float64   │ Float64         │ Float64          │
# ├─────┼───────────┼─────────────────┼──────────────────┤
# │ 1   │ 0.542499  │ 0.54784         │ 0.553888         │
# │ 2   │ 0.452424  │ 0.456088        │ 0.45157          │
# │ 3   │ 0.350753  │ 0.363691        │ 0.370866         │
# │ 4   │ 0.341711  │ 0.32011         │ 0.320759         │
# │ 5   │ -0.27338  │ -0.276004       │ -0.287357        │
# │ 6   │ -0.157702 │ -0.146668       │ -0.142842        │
# │ 7   │ -0.122468 │ -0.126309       │ -0.118087        │
# │ 8   │ -0.109807 │ 0.0             │ 0.0              │
# │ 9   │ 0.0617877 │ 0.0983987       │ 0.0              │
# │ 10  │ 0.0201398 │ 0.0             │ 0.0              │
# No debiasing:
#     Iter = 19
#     Time = 0.49837398529052734
# Yes debiasing:
#     Iter = 19
#     Time = 0.5132708549499512
#
#
# running the 47 th model
# n, p = 1101, 6606
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β     │ est_β_no_debias │ est_β_yes_debias │
# │     │ Float64    │ Float64         │ Float64          │
# ├─────┼────────────┼─────────────────┼──────────────────┤
# │ 1   │ 1.0144     │ 1.01162         │ 1.01162          │
# │ 2   │ 0.986523   │ 0.984266        │ 0.984266         │
# │ 3   │ 0.664649   │ 0.661515        │ 0.661515         │
# │ 4   │ 0.426839   │ 0.426121        │ 0.426121         │
# │ 5   │ -0.296077  │ -0.301831       │ -0.301831        │
# │ 6   │ -0.172036  │ -0.170077       │ -0.170077        │
# │ 7   │ -0.169046  │ -0.134334       │ -0.134334        │
# │ 8   │ -0.121853  │ -0.115466       │ -0.115466        │
# │ 9   │ -0.0459373 │ 0.0             │ 0.0              │
# │ 10  │ 0.0189062  │ 0.0             │ 0.0              │
# No debiasing:
#     Iter = 336
#     Time = 12.645142078399658
# Yes debiasing:
#     Iter = 336
#     Time = 12.766782999038696
#
#
# running the 48 th model
# n, p = 1240, 12400
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β    │ est_β_no_debias │ est_β_yes_debias │
# │     │ Float64   │ Float64         │ Float64          │
# ├─────┼───────────┼─────────────────┼──────────────────┤
# │ 1   │ 0.911915  │ 0.928317        │ 0.928317         │
# │ 2   │ -0.71957  │ -0.732164       │ -0.732164        │
# │ 3   │ 0.615147  │ 0.620649        │ 0.620649         │
# │ 4   │ 0.514319  │ 0.505704        │ 0.505704         │
# │ 5   │ -0.511572 │ -0.515722       │ -0.515722        │
# │ 6   │ -0.381088 │ -0.393807       │ -0.393807        │
# │ 7   │ -0.351173 │ -0.280877       │ -0.280877        │
# │ 8   │ 0.159011  │ 0.142834        │ 0.142834         │
# │ 9   │ 0.0575867 │ 0.0710375       │ 0.0710375        │
# │ 10  │ 0.050737  │ 0.0             │ 0.0              │
# No debiasing:
#     Iter = 177
#     Time = 14.071757793426514
# Yes debiasing:
#     Iter = 177
#     Time = 14.196047067642212
#
#
# running the 49 th model
# n, p = 1641, 13128
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β     │ est_β_no_debias │ est_β_yes_debias │
# │     │ Float64    │ Float64         │ Float64          │
# ├─────┼────────────┼─────────────────┼──────────────────┤
# │ 1   │ 0.579223   │ 0.609842        │ 0.611118         │
# │ 2   │ 0.407667   │ 0.396133        │ 0.39864          │
# │ 3   │ -0.374732  │ -0.370921       │ -0.368907        │
# │ 4   │ 0.349708   │ 0.317629        │ 0.323138         │
# │ 5   │ -0.324055  │ -0.310128       │ -0.309542        │
# │ 6   │ 0.307211   │ 0.338071        │ 0.338968         │
# │ 7   │ -0.143473  │ 0.0             │ 0.0              │
# │ 8   │ -0.113964  │ 0.0             │ 0.0              │
# │ 9   │ 0.0382618  │ 0.0             │ 0.0              │
# │ 10  │ -0.0241041 │ 0.0             │ 0.0              │
# No debiasing:
#     Iter = 31
#     Time = 3.631492853164673
# Yes debiasing:
#     Iter = 18
#     Time = 2.189423084259033
#
#
# running the 50 th model
# n, p = 774, 774
# sort(compare_model, rev=true, by=abs) = 10×3 DataFrame
# │ Row │ true_β     │ est_β_no_debias │ est_β_yes_debias │
# │     │ Float64    │ Float64         │ Float64          │
# ├─────┼────────────┼─────────────────┼──────────────────┤
# │ 1   │ -0.503193  │ -0.471408       │ -0.471416        │
# │ 2   │ -0.499197  │ -0.472148       │ -0.472527        │
# │ 3   │ 0.461951   │ 0.469822        │ 0.469825         │
# │ 4   │ 0.364542   │ 0.442473        │ 0.442409         │
# │ 5   │ -0.318928  │ -0.315787       │ -0.315507        │
# │ 6   │ -0.221208  │ -0.228603       │ -0.228657        │
# │ 7   │ -0.139778  │ -0.167293       │ -0.167402        │
# │ 8   │ -0.0642468 │ 0.0             │ 0.0              │
# │ 9   │ 0.0334915  │ 0.0             │ 0.0              │
# │ 10  │ 0.0231319  │ 0.0             │ 0.0              │
# No debiasing:
#     Iter = 22
#     Time = 0.08203697204589844
# Yes debiasing:
#     Iter = 17
#     Time = 0.07062697410583496
#
#
# With debiasing, found 363 predictors out of 500
# With debiasing, average time was 5.924642205238342
# Without debiasing, found 391 predictors out of 500
# Without debiasing, average time was 3.182760772705078

# %% [markdown]
# # Comparison with LASSO: cross validation

# %%
using Revise
using GLMNet #julia wrapper for GLMNet package in R, which calls fortran
using GLM
using MendelIHT
using SnpArrays
using DataFrames
using Distributions
using StatsFuns: logistic
using Random
using LinearAlgebra
using DelimitedFiles
# Out:
# ┌ Info: Loading DataFrames support into Gadfly.jl
# └ @ Gadfly /Users/biona001/.julia/packages/Gadfly/09PWZ/src/mapping.jl:228

# %%
Threads.nthreads() #verify multiple threads are enabled
# Out:
# 8

# %%
function iht_lasso_poisson(n :: Int64, p :: Int64, sim :: Int64)
    #define maf and true model size
    k = 10
    
    #set random seed
    Random.seed!(1111)

    #construct snpmatrix, covariate files, and true model b
    x, maf = simulate_random_snparray(n, p)
    xbm = SnpBitMatrix{Float64}(x, model=ADDITIVE_MODEL, center=true, scale=true); 
    z           = ones(n, 1)                   # non-genetic covariates, just the intercept
    true_b      = zeros(p)                     # model vector
    true_b[1:k] = rand(Normal(0, 0.4), k)      # k true response
    shuffle!(true_b)                           # Shuffle the entries
    correct_position = findall(x -> x != 0, true_b) # keep track of what the true entries are

    # Simulate poisson data
    y_temp = xbm * true_b
    λ = exp.(y_temp) #inverse log link
    y = [rand(Poisson(x)) for x in λ]
    y = Float64.(y)

    #compute poisson IHT result
    cur_time = time()
    path = collect(1:20)
    num_folds = 3
    folds = rand(1:num_folds, size(x, 1))
    k_est_iht = cv_iht(x, z, y, 1, path, folds, num_folds, use_maf=false, glm="poisson", debias=true)
    iht_result = L0_poisson_reg(x, z, y, 1, k_est_iht, glm = "poisson", debias=true, convg=false, show_info=false, true_beta=true_b, init=false)
    iht_time = time() - cur_time
    
    #compute poisson lasso result
    x_float = [convert(Matrix{Float64}, x, center=true, scale=true) z]
    cur_time = time()
    cv = glmnetcv(x_float, y, Poisson(), pmax=20, nfolds=3, folds=folds)
    best = argmin(cv.meanloss)
    lasso_result = cv.path.betas[:, best]
    k_est_lasso = length(findall(!iszero, lasso_result))
    lasso_time = time() - cur_time
    
    #compute regular poisson regression using only true predictors
    x_true = [x_float[:, correct_position] z]
    regular_result = glm(x_true, y, Poisson(), LogLink())
    regular_result = regular_result.pp.beta0
    
    #check result
    IHT_model = iht_result.beta[correct_position]
    lasso_model = lasso_result[correct_position]
    true_model = true_b[correct_position]
    compare_model = DataFrame(
        true_β  = true_model, 
        iht_β   = IHT_model,
        lasso_β = lasso_model,
        regular_β = regular_result[1:10])
    @show compare_model

    #compute summary statistics
    lasso_num_correct_predictors = length(findall(!iszero, lasso_model))
    lasso_false_positives = k_est_lasso - lasso_num_correct_predictors
    lasso_false_negatives = k - lasso_num_correct_predictors
    iht_num_correct_predictors = length(findall(!iszero, IHT_model))
    iht_false_positives = k_est_iht - iht_num_correct_predictors
    iht_false_negatives = k - iht_num_correct_predictors
    println("IHT cv found $iht_false_positives" * " false positives and $iht_false_negatives" * " false negatives, and used $iht_time" * " seconds")
    println("lasso cv found $lasso_false_positives" * " false positives and $lasso_false_negatives" * " false negatives, and used $lasso_time" * " seconds \n\n")

    #write y to file to view distribution later
    #writedlm("./IHT_poisson_simulations_mean/data_simulation_$sim.txt", y)

    return lasso_num_correct_predictors, lasso_false_positives, lasso_false_negatives, lasso_time, iht_num_correct_predictors, iht_false_positives, iht_false_negatives, iht_time
end
# Out:
# iht_lasso_poisson (generic function with 1 method)

# %%
function run_iht_lasso_poisson()
    lasso_total_found = 0
    lasso_false_positives = 0
    lasso_false_negatives = 0
    lasso_total_time = 0
    iht_total_found = 0
    iht_false_positives = 0
    iht_false_negatives = 0
    iht_total_time = 0
    
    iter = 10
    for i = 1:iter
        n = rand(1000:3000) 
        p = rand(1:10)n
        println("Running the $i th model where " * "n, p = " * string(n) * ", " * string(p))
        ltf, lfp, lfn, ltt, itf, ifp, ifn, itt = iht_lasso_poisson(n, p, i)

        lasso_total_found += ltf
        lasso_false_positives += lfp
        lasso_false_negatives += lfn
        lasso_total_time += ltt
        iht_total_found += itf
        iht_false_positives += ifp
        iht_false_negatives += ifn
        iht_total_time += itt
    end
    println("IHT  : Found $iht_total_found " * "correct predictors, out of " * string(10iter))
    println("IHT  : False positives = $iht_false_positives")
    println("IHT  : False negatives = $iht_false_negatives")   
    println("IHT  : Average time = " * string(iht_total_time / iter))   
    println("Lasso: Found $lasso_total_found " * "correct predictors, out of " * string(10iter))
    println("Lasso: False positives = $lasso_false_positives")
    println("Lasso: False negatives = $lasso_false_negatives")
    println("Lasso: Average time = " * string(lasso_total_time / iter))   
end
# Out:
# run_iht_lasso_poisson (generic function with 1 method)

# %%
Random.seed!(2019)
run_iht_lasso_poisson()
# Out:
# Running the 1 th model where n, p = 1101, 5505
# ┌ Warning: glmnet: number of non-zero coefficients along path exceeds allowed value at 1010000th lambda value
# └ @ GLMNet /Users/biona001/.julia/dev/GLMNet/src/GLMNet.jl:209
# ┌ Warning: glmnet: number of non-zero coefficients along path exceeds allowed value at 1010000th lambda value
# └ @ GLMNet /Users/biona001/.julia/dev/GLMNet/src/GLMNet.jl:209
# ┌ Warning: glmnet: number of non-zero coefficients along path exceeds allowed value at 1010000th lambda value
# └ @ GLMNet /Users/biona001/.julia/dev/GLMNet/src/GLMNet.jl:209
# ┌ Warning: glmnet: number of non-zero coefficients along path exceeds allowed value at 1010000th lambda value
# └ @ GLMNet /Users/biona001/.julia/dev/GLMNet/src/GLMNet.jl:209
# compare_model = 10×4 DataFrame
# │ Row │ true_β     │ iht_β     │ lasso_β    │ regular_β   │
# │     │ Float64    │ Float64   │ Float64    │ Float64     │
# ├─────┼────────────┼───────────┼────────────┼─────────────┤
# │ 1   │ 0.350726   │ 0.348157  │ 0.232491   │ 0.338618    │
# │ 2   │ -0.0691278 │ 0.0       │ 0.0        │ -0.0423288  │
# │ 3   │ 0.321821   │ 0.33175   │ 0.218928   │ 0.33577     │
# │ 4   │ 0.0206803  │ 0.0       │ 0.0        │ -0.00955842 │
# │ 5   │ -0.364041  │ -0.348065 │ -0.190411  │ -0.345578   │
# │ 6   │ -0.0117973 │ 0.0       │ 0.0        │ -0.0224709  │
# │ 7   │ 0.384137   │ 0.408748  │ 0.286903   │ 0.402484    │
# │ 8   │ -0.0379634 │ 0.0       │ 0.0        │ -0.0453506  │
# │ 9   │ 0.0114505  │ 0.0       │ 0.0        │ 0.0324529   │
# │ 10  │ -0.19394   │ 0.0       │ -0.0653144 │ -0.2002     │
# IHT cv found 0 false positives and 6 false negatives, and used 60.85119676589966 seconds
# lasso cv found 0 false positives and 5 false negatives, and used 2.4331750869750977 seconds
#
#
# Running the 2 th model where n, p = 2195, 21950
# ┌ Warning: glmnet: number of non-zero coefficients along path exceeds allowed value at 1010000th lambda value
# └ @ GLMNet /Users/biona001/.julia/dev/GLMNet/src/GLMNet.jl:209
# ┌ Warning: glmnet: number of non-zero coefficients along path exceeds allowed value at 1010000th lambda value
# └ @ GLMNet /Users/biona001/.julia/dev/GLMNet/src/GLMNet.jl:209
# ┌ Warning: glmnet: number of non-zero coefficients along path exceeds allowed value at 1010000th lambda value
# └ @ GLMNet /Users/biona001/.julia/dev/GLMNet/src/GLMNet.jl:209
# ┌ Warning: glmnet: number of non-zero coefficients along path exceeds allowed value at 1010000th lambda value
# └ @ GLMNet /Users/biona001/.julia/dev/GLMNet/src/GLMNet.jl:209
# compare_model = 10×4 DataFrame
# │ Row │ true_β     │ iht_β     │ lasso_β    │ regular_β │
# │     │ Float64    │ Float64   │ Float64    │ Float64   │
# ├─────┼────────────┼───────────┼────────────┼───────────┤
# │ 1   │ -0.166785  │ 0.0       │ -0.0381534 │ -0.137296 │
# │ 2   │ -0.0966497 │ -0.106139 │ -0.0220758 │ -0.102758 │
# │ 3   │ 0.585055   │ 0.591731  │ 0.543016   │ 0.585122  │
# │ 4   │ -0.11679   │ -0.135514 │ -0.0418787 │ -0.132134 │
# │ 5   │ -0.469501  │ -0.445559 │ -0.314045  │ -0.437911 │
# │ 6   │ 0.179822   │ 0.173472  │ 0.0865679  │ 0.173136  │
# │ 7   │ 0.266917   │ 0.280213  │ 0.195209   │ 0.269821  │
# │ 8   │ -0.271124  │ -0.277599 │ -0.173511  │ -0.265895 │
# │ 9   │ 0.268131   │ 0.281803  │ 0.213427   │ 0.271134  │
# │ 10  │ -0.849929  │ -0.921018 │ -0.511578  │ -0.877314 │
# IHT cv found 0 false positives and 1 false negatives, and used 77.47188878059387 seconds
# lasso cv found 0 false positives and 0 false negatives, and used 10.86150598526001 seconds
#
#
# Running the 3 th model where n, p = 2157, 6471
# ┌ Warning: glmnet: number of non-zero coefficients along path exceeds allowed value at 1010000th lambda value
# └ @ GLMNet /Users/biona001/.julia/dev/GLMNet/src/GLMNet.jl:209
# ┌ Warning: glmnet: number of non-zero coefficients along path exceeds allowed value at 1010000th lambda value
# └ @ GLMNet /Users/biona001/.julia/dev/GLMNet/src/GLMNet.jl:209
# ┌ Warning: glmnet: number of non-zero coefficients along path exceeds allowed value at 1010000th lambda value
# └ @ GLMNet /Users/biona001/.julia/dev/GLMNet/src/GLMNet.jl:209
# ┌ Warning: glmnet: number of non-zero coefficients along path exceeds allowed value at 1010000th lambda value
# └ @ GLMNet /Users/biona001/.julia/dev/GLMNet/src/GLMNet.jl:209
# compare_model = 10×4 DataFrame
# │ Row │ true_β      │ iht_β     │ lasso_β    │ regular_β   │
# │     │ Float64     │ Float64   │ Float64    │ Float64     │
# ├─────┼─────────────┼───────────┼────────────┼─────────────┤
# │ 1   │ 0.185692    │ 0.194874  │ 0.11655    │ 0.196478    │
# │ 2   │ 0.789222    │ 0.781809  │ 0.770326   │ 0.78866     │
# │ 3   │ 0.0306279   │ 0.0       │ 0.0        │ 0.0176097   │
# │ 4   │ -0.125003   │ -0.142287 │ -0.0313078 │ -0.145971   │
# │ 5   │ -0.366029   │ -0.340488 │ -0.207299  │ -0.35054    │
# │ 6   │ 0.116492    │ 0.111686  │ 0.0667364  │ 0.123994    │
# │ 7   │ 0.38709     │ 0.375683  │ 0.349523   │ 0.385362    │
# │ 8   │ -0.18326    │ -0.173212 │ -0.0716869 │ -0.177553   │
# │ 9   │ 0.282194    │ 0.277962  │ 0.193002   │ 0.284255    │
# │ 10  │ 0.000576499 │ 0.0       │ 0.0        │ -0.00663532 │
# IHT cv found 6 false positives and 2 false negatives, and used 109.81043982505798 seconds
# lasso cv found 3 false positives and 2 false negatives, and used 4.152333974838257 seconds
#
#
# Running the 4 th model where n, p = 1309, 10472
# ┌ Warning: glmnet: number of non-zero coefficients along path exceeds allowed value at 1010000th lambda value
# └ @ GLMNet /Users/biona001/.julia/dev/GLMNet/src/GLMNet.jl:209
# ┌ Warning: glmnet: number of non-zero coefficients along path exceeds allowed value at 1010000th lambda value
# └ @ GLMNet /Users/biona001/.julia/dev/GLMNet/src/GLMNet.jl:209
# ┌ Warning: glmnet: number of non-zero coefficients along path exceeds allowed value at 1010000th lambda value
# └ @ GLMNet /Users/biona001/.julia/dev/GLMNet/src/GLMNet.jl:209
# ┌ Warning: glmnet: number of non-zero coefficients along path exceeds allowed value at 1010000th lambda value
# └ @ GLMNet /Users/biona001/.julia/dev/GLMNet/src/GLMNet.jl:209
# compare_model = 10×4 DataFrame
# │ Row │ true_β     │ iht_β      │ lasso_β   │ regular_β  │
# │     │ Float64    │ Float64    │ Float64   │ Float64    │
# ├─────┼────────────┼────────────┼───────────┼────────────┤
# │ 1   │ -0.539167  │ -0.550889  │ -0.304965 │ -0.555071  │
# │ 2   │ -0.0968708 │ 0.0        │ 0.0       │ -0.0960337 │
# │ 3   │ 0.846705   │ 0.821827   │ 0.719073  │ 0.821006   │
# │ 4   │ -0.441297  │ -0.461406  │ -0.254502 │ -0.456925  │
# │ 5   │ -0.128018  │ -0.0882122 │ 0.0       │ -0.122613  │
# │ 6   │ 0.132842   │ 0.0        │ 0.0       │ 0.146273   │
# │ 7   │ -0.158806  │ -0.137324  │ 0.0       │ -0.156672  │
# │ 8   │ -0.987442  │ -1.01963   │ -0.732095 │ -1.0204    │
# │ 9   │ 0.203632   │ 0.190123   │ 0.0770605 │ 0.189536   │
# │ 10  │ -0.615237  │ -0.63718   │ -0.402071 │ -0.623348  │
# IHT cv found 9 false positives and 2 false negatives, and used 32.19886112213135 seconds
# lasso cv found 4 false positives and 4 false negatives, and used 2.7987639904022217 seconds
#
#
# Running the 5 th model where n, p = 1854, 12978
# ┌ Warning: glmnet: number of non-zero coefficients along path exceeds allowed value at 1010000th lambda value
# └ @ GLMNet /Users/biona001/.julia/dev/GLMNet/src/GLMNet.jl:209
# ┌ Warning: glmnet: number of non-zero coefficients along path exceeds allowed value at 1010000th lambda value
# └ @ GLMNet /Users/biona001/.julia/dev/GLMNet/src/GLMNet.jl:209
# ┌ Warning: glmnet: number of non-zero coefficients along path exceeds allowed value at 1010000th lambda value
# └ @ GLMNet /Users/biona001/.julia/dev/GLMNet/src/GLMNet.jl:209
# ┌ Warning: glmnet: number of non-zero coefficients along path exceeds allowed value at 1010000th lambda value
# └ @ GLMNet /Users/biona001/.julia/dev/GLMNet/src/GLMNet.jl:209
# compare_model = 10×4 DataFrame
# │ Row │ true_β    │ iht_β     │ lasso_β    │ regular_β │
# │     │ Float64   │ Float64   │ Float64    │ Float64   │
# ├─────┼───────────┼───────────┼────────────┼───────────┤
# │ 1   │ 0.149501  │ 0.179655  │ 0.0904689  │ 0.17243   │
# │ 2   │ -0.315157 │ -0.360698 │ -0.251767  │ -0.347977 │
# │ 3   │ -0.313771 │ 0.0       │ -0.0559417 │ -0.24464  │
# │ 4   │ 0.596863  │ 0.596541  │ 0.481438   │ 0.566446  │
# │ 5   │ 0.0613366 │ 0.0       │ 0.0        │ 0.011362  │
# │ 6   │ 0.39443   │ 0.386599  │ 0.331247   │ 0.379504  │
# │ 7   │ 0.046383  │ 0.0       │ 0.0        │ 0.0405169 │
# │ 8   │ 0.391428  │ 0.381169  │ 0.283873   │ 0.370438  │
# │ 9   │ 0.0246291 │ 0.0       │ 0.0        │ 0.0586396 │
# │ 10  │ 0.0489828 │ 0.0       │ 0.0        │ 0.069528  │
# IHT cv found 2 false positives and 5 false negatives, and used 38.80105805397034 seconds
# lasso cv found 0 false positives and 4 false negatives, and used 4.259769916534424 seconds
#
#
# Running the 6 th model where n, p = 1893, 15144
# ┌ Warning: glmnet: number of non-zero coefficients along path exceeds allowed value at 1010000th lambda value
# └ @ GLMNet /Users/biona001/.julia/dev/GLMNet/src/GLMNet.jl:209
# ┌ Warning: glmnet: number of non-zero coefficients along path exceeds allowed value at 1010000th lambda value
# └ @ GLMNet /Users/biona001/.julia/dev/GLMNet/src/GLMNet.jl:209
# ┌ Warning: glmnet: number of non-zero coefficients along path exceeds allowed value at 1010000th lambda value
# └ @ GLMNet /Users/biona001/.julia/dev/GLMNet/src/GLMNet.jl:209
# ┌ Warning: glmnet: number of non-zero coefficients along path exceeds allowed value at 1010000th lambda value
# └ @ GLMNet /Users/biona001/.julia/dev/GLMNet/src/GLMNet.jl:209
# compare_model = 10×4 DataFrame
# │ Row │ true_β     │ iht_β     │ lasso_β    │ regular_β   │
# │     │ Float64    │ Float64   │ Float64    │ Float64     │
# ├─────┼────────────┼───────────┼────────────┼─────────────┤
# │ 1   │ 0.0565106  │ 0.0       │ 0.0        │ 0.0664289   │
# │ 2   │ -0.0288542 │ 0.0       │ 0.0        │ -0.0239858  │
# │ 3   │ 0.0157203  │ 0.0       │ 0.0        │ 0.0324769   │
# │ 4   │ -0.0170607 │ 0.0       │ 0.0        │ 0.0118499   │
# │ 5   │ -0.248815  │ -0.266159 │ -0.176822  │ -0.260139   │
# │ 6   │ 0.503222   │ 0.525     │ 0.457777   │ 0.519209    │
# │ 7   │ -0.204717  │ -0.187565 │ -0.0914828 │ -0.181551   │
# │ 8   │ -0.0144074 │ 0.0       │ 0.0        │ -0.00435644 │
# │ 9   │ -0.588691  │ -0.625465 │ -0.490498  │ -0.616987   │
# │ 10  │ -0.0416818 │ 0.0       │ 0.0        │ -0.0470831  │
# IHT cv found 0 false positives and 6 false negatives, and used 25.94583797454834 seconds
# lasso cv found 0 false positives and 6 false negatives, and used 5.142854928970337 seconds
#
#
# Running the 7 th model where n, p = 2131, 14917
# ┌ Warning: glmnet: number of non-zero coefficients along path exceeds allowed value at 1010000th lambda value
# └ @ GLMNet /Users/biona001/.julia/dev/GLMNet/src/GLMNet.jl:209
# ┌ Warning: glmnet: number of non-zero coefficients along path exceeds allowed value at 1010000th lambda value
# └ @ GLMNet /Users/biona001/.julia/dev/GLMNet/src/GLMNet.jl:209
# ┌ Warning: glmnet: number of non-zero coefficients along path exceeds allowed value at 1010000th lambda value
# └ @ GLMNet /Users/biona001/.julia/dev/GLMNet/src/GLMNet.jl:209
# ┌ Warning: glmnet: number of non-zero coefficients along path exceeds allowed value at 1010000th lambda value
# └ @ GLMNet /Users/biona001/.julia/dev/GLMNet/src/GLMNet.jl:209
# compare_model = 10×4 DataFrame
# │ Row │ true_β    │ iht_β     │ lasso_β    │ regular_β │
# │     │ Float64   │ Float64   │ Float64    │ Float64   │
# ├─────┼───────────┼───────────┼────────────┼───────────┤
# │ 1   │ -0.497047 │ -0.484773 │ -0.346357  │ -0.470824 │
# │ 2   │ 0.537552  │ 0.534424  │ 0.418754   │ 0.517245  │
# │ 3   │ -0.311976 │ -0.319035 │ -0.168462  │ -0.299785 │
# │ 4   │ -0.111079 │ -0.10272  │ 0.0        │ -0.103387 │
# │ 5   │ -0.419224 │ -0.41377  │ -0.310428  │ -0.400017 │
# │ 6   │ -0.191882 │ -0.168608 │ -0.0558217 │ -0.169596 │
# │ 7   │ 0.352124  │ 0.333572  │ 0.253353   │ 0.326187  │
# │ 8   │ 0.193935  │ 0.180412  │ 0.0765412  │ 0.177762  │
# │ 9   │ 0.256262  │ 0.262324  │ 0.197361   │ 0.260144  │
# │ 10  │ 0.383622  │ 0.384063  │ 0.263412   │ 0.367638  │
# IHT cv found 5 false positives and 0 false negatives, and used 156.70267391204834 seconds
# lasso cv found 0 false positives and 1 false negatives, and used 5.286602020263672 seconds
#
#
# Running the 8 th model where n, p = 2292, 2292
# ┌ Warning: glmnet: number of non-zero coefficients along path exceeds allowed value at 1010000th lambda value
# └ @ GLMNet /Users/biona001/.julia/dev/GLMNet/src/GLMNet.jl:209
# ┌ Warning: glmnet: number of non-zero coefficients along path exceeds allowed value at 1010000th lambda value
# └ @ GLMNet /Users/biona001/.julia/dev/GLMNet/src/GLMNet.jl:209
# ┌ Warning: glmnet: number of non-zero coefficients along path exceeds allowed value at 1010000th lambda value
# └ @ GLMNet /Users/biona001/.julia/dev/GLMNet/src/GLMNet.jl:209
# ┌ Warning: glmnet: number of non-zero coefficients along path exceeds allowed value at 1010000th lambda value
# └ @ GLMNet /Users/biona001/.julia/dev/GLMNet/src/GLMNet.jl:209
# compare_model = 10×4 DataFrame
# │ Row │ true_β    │ iht_β     │ lasso_β    │ regular_β │
# │     │ Float64   │ Float64   │ Float64    │ Float64   │
# ├─────┼───────────┼───────────┼────────────┼───────────┤
# │ 1   │ 0.0419999 │ 0.0       │ 0.0        │ 0.0275679 │
# │ 2   │ 0.125858  │ 0.107102  │ 0.037222   │ 0.107911  │
# │ 3   │ -0.794255 │ -0.79384  │ -0.675938  │ -0.79406  │
# │ 4   │ 0.457812  │ 0.468226  │ 0.440908   │ 0.46645   │
# │ 5   │ -0.192134 │ -0.195708 │ -0.12773   │ -0.193447 │
# │ 6   │ -0.204108 │ -0.204849 │ -0.133766  │ -0.200409 │
# │ 7   │ 0.26224   │ 0.274216  │ 0.212134   │ 0.274652  │
# │ 8   │ -0.132775 │ -0.112193 │ -0.0367459 │ -0.112336 │
# │ 9   │ 0.0217522 │ 0.0       │ 0.0        │ 0.022861  │
# │ 10  │ 0.548122  │ 0.54901   │ 0.524515   │ 0.550788  │
# IHT cv found 0 false positives and 2 false negatives, and used 9.282888889312744 seconds
# lasso cv found 1 false positives and 2 false negatives, and used 1.6354539394378662 seconds
#
#
# Running the 9 th model where n, p = 2283, 9132
# ┌ Warning: glmnet: number of non-zero coefficients along path exceeds allowed value at 1010000th lambda value
# └ @ GLMNet /Users/biona001/.julia/dev/GLMNet/src/GLMNet.jl:209
# ┌ Warning: glmnet: number of non-zero coefficients along path exceeds allowed value at 1010000th lambda value
# └ @ GLMNet /Users/biona001/.julia/dev/GLMNet/src/GLMNet.jl:209
# ┌ Warning: glmnet: number of non-zero coefficients along path exceeds allowed value at 1010000th lambda value
# └ @ GLMNet /Users/biona001/.julia/dev/GLMNet/src/GLMNet.jl:209
# ┌ Warning: glmnet: number of non-zero coefficients along path exceeds allowed value at 1010000th lambda value
# └ @ GLMNet /Users/biona001/.julia/dev/GLMNet/src/GLMNet.jl:209
# compare_model = 10×4 DataFrame
# │ Row │ true_β     │ iht_β     │ lasso_β   │ regular_β  │
# │     │ Float64    │ Float64   │ Float64   │ Float64    │
# ├─────┼────────────┼───────────┼───────────┼────────────┤
# │ 1   │ -0.35539   │ -0.329295 │ -0.257184 │ -0.328476  │
# │ 2   │ 0.138335   │ 0.0       │ 0.0678976 │ 0.153547   │
# │ 3   │ -0.370387  │ -0.344611 │ -0.251284 │ -0.342879  │
# │ 4   │ 0.0358637  │ 0.0       │ 0.0       │ 0.0254869  │
# │ 5   │ -0.0912084 │ 0.0       │ 0.0       │ -0.0895277 │
# │ 6   │ 0.0378541  │ 0.0       │ 0.0       │ 0.0451899  │
# │ 7   │ 0.417998   │ 0.418837  │ 0.369821  │ 0.421582   │
# │ 8   │ -0.0813847 │ 0.0       │ 0.0       │ -0.0737161 │
# │ 9   │ -0.239892  │ 0.0       │ -0.121925 │ -0.211919  │
# │ 10  │ 0.488211   │ 0.490875  │ 0.481137  │ 0.486368   │
# IHT cv found 1 false positives and 6 false negatives, and used 97.13794088363647 seconds
# lasso cv found 0 false positives and 4 false negatives, and used 5.294406890869141 seconds
#
#
# Running the 10 th model where n, p = 2927, 23416
# ┌ Warning: glmnet: number of non-zero coefficients along path exceeds allowed value at 1010000th lambda value
# └ @ GLMNet /Users/biona001/.julia/dev/GLMNet/src/GLMNet.jl:209
# ┌ Warning: glmnet: number of non-zero coefficients along path exceeds allowed value at 1010000th lambda value
# └ @ GLMNet /Users/biona001/.julia/dev/GLMNet/src/GLMNet.jl:209
# ┌ Warning: glmnet: number of non-zero coefficients along path exceeds allowed value at 1010000th lambda value
# └ @ GLMNet /Users/biona001/.julia/dev/GLMNet/src/GLMNet.jl:209
# ┌ Warning: glmnet: number of non-zero coefficients along path exceeds allowed value at 1010000th lambda value
# └ @ GLMNet /Users/biona001/.julia/dev/GLMNet/src/GLMNet.jl:209
# compare_model = 10×4 DataFrame
# │ Row │ true_β      │ iht_β     │ lasso_β   │ regular_β   │
# │     │ Float64     │ Float64   │ Float64   │ Float64     │
# ├─────┼─────────────┼───────────┼───────────┼─────────────┤
# │ 1   │ 0.163141    │ 0.153406  │ 0.117559  │ 0.15415     │
# │ 2   │ -0.00928313 │ 0.0       │ 0.0       │ -0.00435653 │
# │ 3   │ -0.640022   │ -0.648787 │ -0.529854 │ -0.63863    │
# │ 4   │ 1.18325     │ 1.18939   │ 1.12608   │ 1.1773      │
# │ 5   │ -0.259045   │ -0.272451 │ -0.193102 │ -0.268432   │
# │ 6   │ -0.818365   │ -0.812832 │ -0.64731  │ -0.80088    │
# │ 7   │ 0.01962     │ 0.0       │ 0.0       │ 0.00601566  │
# │ 8   │ 0.026186    │ 0.0       │ 0.0       │ 0.0233668   │
# │ 9   │ -0.216924   │ -0.226072 │ -0.173227 │ -0.228295   │
# │ 10  │ -0.291759   │ 0.0       │ 0.0       │ -0.414913   │
# IHT cv found 0 false positives and 4 false negatives, and used 138.42418003082275 seconds
# lasso cv found 1 false positives and 4 false negatives, and used 17.067068099975586 seconds
#
#
# IHT  : Found 66 correct predictors, out of 100
# IHT  : False positives = 23
# IHT  : False negatives = 34
# IHT  : Average time = 74.66269662380219
# Lasso: Found 68 correct predictors, out of 100
# Lasso: False positives = 9
# Lasso: False negatives = 32
# Lasso: Average time = 5.893193483352661
