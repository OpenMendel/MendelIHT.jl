# %% [markdown]
# # IHT code on fitting generalized linear models

# %%
using Revise
using IHT
using SnpArrays
using DataFrames
using Distributions
using BenchmarkTools
using Random
using LinearAlgebra
using StatsFuns: logistic
# Out:
# ┌ Info: Recompiling stale cache file /Users/biona001/.julia/compiled/v1.0/IHT/eaqWB.ji for IHT [921c7187-1484-5754-b919-5d3ed9ac03c4]
# └ @ Base loading.jl:1190
# ┌ Info: Loading DataFrames support into Gadfly.jl
# └ @ Gadfly /Users/biona001/.julia/packages/Gadfly/09PWZ/src/mapping.jl:228

# %% [markdown]
# ## Logistic Regression:

# %%
#problem size
n = 2000
p = 25000

#set random seed
Random.seed!(1111)

#simulate data using k true predictors
k = 10 
bernoulli_rates = 0.5rand(p) #minor allele frequencies are drawn from uniform (0, 0.5)
x = simulate_random_snparray(n, p, bernoulli_rates)
xbm = SnpBitMatrix{Float64}(x, model=ADDITIVE_MODEL, center=true, scale=true); 

#construct covariates (intercept) and true model b ~ N(0, 1)
z = ones(n, 1)          # non-genetic covariates, just the intercept
true_b = zeros(p)       # model vector
true_b[1:k] = randn(k)  # Initialize k non-zero entries in the true model
shuffle!(true_b)        # Shuffle the entries
correct_position = findall(x -> x != 0, true_b) # keep track of what the true entries are

#simulate phenotypes (e.g. vector y) via: y = Xb
y_temp = xbm * true_b

# Apply inverse logit link and sample from the vector of distributions
prob = logistic.(y_temp) #inverse logit link
y = [rand(Bernoulli(x)) for x in prob]
y = Float64.(y)

#compute logistic IHT result. Debias accelerates convergence
result = L0_logistic_reg(x, z, y, 1, k, glm = "logistic", debias=true, show_info=false)
@show result

#check result
estimated_models = result.beta[correct_position]
true_model = true_b[correct_position]
compare_model = DataFrame(
    correct_position = correct_position, 
    true_β           = true_model, 
    estimated_β      = estimated_models)
# Out:
# result = IHT results:
#
# Compute time (sec):     4.952028036117554
# Final loglikelihood:    -670.8572856298258
# Iterations:             14
# Max number of groups:   1
# Max predictors/group:   10
# IHT estimated 10 nonzero coefficients.
# 10×3 DataFrame
# │ Row │ Group │ Predictor │ Estimated_β │
# │     │ Int64 │ Int64     │ Float64     │
# ├─────┼───────┼───────────┼─────────────┤
# │ 1   │ 1     │ 3281      │ 0.254733    │
# │ 2   │ 1     │ 5036      │ -0.336928   │
# │ 3   │ 1     │ 7955      │ 0.705645    │
# │ 4   │ 1     │ 11125     │ 1.3001      │
# │ 5   │ 1     │ 14778     │ 0.265708    │
# │ 6   │ 1     │ 15259     │ 0.440616    │
# │ 7   │ 1     │ 15611     │ -0.825903   │
# │ 8   │ 1     │ 16824     │ -1.21126    │
# │ 9   │ 1     │ 18529     │ 2.19817     │
# │ 10  │ 1     │ 22323     │ 1.06874     │
#
# Intercept of model = 0.0
# 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 2671             │ 0.14408   │ 0.0         │
# │ 2   │ 5036             │ -0.499722 │ -0.336928   │
# │ 3   │ 7955             │ 0.899909  │ 0.705645    │
# │ 4   │ 11125            │ 1.45065   │ 1.3001      │
# │ 5   │ 15259            │ 0.44709   │ 0.440616    │
# │ 6   │ 15611            │ -0.875885 │ -0.825903   │
# │ 7   │ 16627            │ 0.243581  │ 0.0         │
# │ 8   │ 16824            │ -1.16319  │ -1.21126    │
# │ 9   │ 18529            │ 2.29413   │ 2.19817     │
# │ 10  │ 22323            │ 1.04997   │ 1.06874     │

# %% [markdown]
# ## Poisson regression:

# %%
#problem size
n = 2000
p = 20001

#set random seed
Random.seed!(1111)

#simulate data using k true predictors
k = 10 # number of true predictors
bernoulli_rates = 0.5rand(p) #minor allele frequencies are drawn from uniform (0, 0.5)
x = simulate_random_snparray(n, p, bernoulli_rates)
xbm = SnpBitMatrix{Float64}(x, model=ADDITIVE_MODEL, center=true, scale=true); 

#construct snpmatrix, covariate files, and true model b
z           = ones(n, 1)                   # non-genetic covariates, just the intercept
true_b      = zeros(p)                     # model vector
true_b[1:k] = randn(k)                     # Initialize k non-zero entries in the true model
shuffle!(true_b)                           # Shuffle the entries
correct_position = findall(x -> x != 0, true_b) # keep track of what the true entries are

#check maf
bernoulli_rates[correct_position]

#simulate phenotypes by: y = Xb + noise
y_temp = xbm * true_b

# Simulate poisson data
λ = exp.(y_temp) #inverse log link
y = [rand(Poisson(x)) for x in λ]
y = Float64.(y)

#compute poisson IHT result
result = L0_poisson_reg(x, z, y, 1, k, glm = "poisson", debias=false, convg=false, show_info=false, true_beta=true_b)
@show result

#check result
estimated_models = result.beta[correct_position]
true_model = true_b[correct_position]
compare_model = DataFrame(
    correct_position = correct_position, 
    true_β           = true_model, 
    estimated_β      = estimated_models)
# Out:
# result = IHT results:
#
# Compute time (sec):     35.481719970703125
# Final loglikelihood:    653148.285035393
# Iterations:             127
# Max number of groups:   1
# Max predictors/group:   10
# IHT estimated 10 nonzero coefficients.
# 10×3 DataFrame
# │ Row │ Group │ Predictor │ Estimated_β │
# │     │ Int64 │ Int64     │ Float64     │
# ├─────┼───────┼───────────┼─────────────┤
# │ 1   │ 1     │ 3435      │ -1.65424    │
# │ 2   │ 1     │ 5454      │ -0.583612   │
# │ 3   │ 1     │ 8250      │ 1.20102     │
# │ 4   │ 1     │ 9447      │ -0.270882   │
# │ 5   │ 1     │ 10707     │ 0.155146    │
# │ 6   │ 1     │ 10822     │ -1.38683    │
# │ 7   │ 1     │ 11077     │ 0.674554    │
# │ 8   │ 1     │ 12764     │ 0.361803    │
# │ 9   │ 1     │ 13340     │ 1.65805     │
# │ 10  │ 1     │ 17035     │ 0.911785    │
#
# Intercept of model = 0.0
# 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 3435             │ -1.6435   │ -1.65424    │
# │ 2   │ 5454             │ -0.574795 │ -0.583612   │
# │ 3   │ 8250             │ 1.20082   │ 1.20102     │
# │ 4   │ 9447             │ -0.27556  │ -0.270882   │
# │ 5   │ 10707            │ 0.15172   │ 0.155146    │
# │ 6   │ 10822            │ -1.47364  │ -1.38683    │
# │ 7   │ 11077            │ 0.668192  │ 0.674554    │
# │ 8   │ 12764            │ 0.362815  │ 0.361803    │
# │ 9   │ 13340            │ 1.64449   │ 1.65805     │
# │ 10  │ 17035            │ 0.909084  │ 0.911785    │

# %% [markdown]
# # Often times poisson regression does not work.
#
# The example above is hand-picked. In about 40% of the time, poisson performs poorly.

# %%
#some function that runs poisson regression on different SNP matrices
function run_poisson(n :: Int64, p :: Int64)
    #set random seed
    Random.seed!(1111)

    #simulate data
    k = 10 # number of true predictors
    bernoulli_rates = 0.5rand(p) #minor allele frequencies are drawn from uniform (0, 0.5)
    x = simulate_random_snparray(n, p, bernoulli_rates)
    xbm = SnpBitMatrix{Float64}(x, model=ADDITIVE_MODEL, center=true, scale=true); 

    #construct snpmatrix, covariate files, and true model b
    z           = ones(n, 1)                   # non-genetic covariates, just the intercept
    true_b      = zeros(p)                     # model vector
    true_b[1:k] = randn(k)                     # Initialize k non-zero entries in the true model
    shuffle!(true_b)                           # Shuffle the entries
    correct_position = findall(x -> x != 0, true_b) # keep track of what the true entries are

    #check maf
    bernoulli_rates[correct_position]

    #simulate phenotypes under different noises by: y = Xb + noise
    y_temp = xbm * true_b

    # Simulate poisson data
    λ = exp.(y_temp) #inverse log link
    y = [rand(Poisson(x)) for x in λ]
    y = Float64.(y)

    #compute poisson IHT result
    result = L0_poisson_reg(x, z, y, 1, k, glm = "poisson", debias=false, convg=false, show_info=false)

    #check result
    estimated_models = result.beta[correct_position]
    true_model = true_b[correct_position]
    compare_model = DataFrame(
        correct_position = correct_position, 
        true_β           = true_model, 
        estimated_β      = estimated_models)
    
    #display results
    @show compare_model
    println("Total iteration number was " * string(result.iter))
    println("Total time was " * string(result.time))
end
# Out:
# run_poisson (generic function with 1 method)

# %%
for i = 1:25
    println("running the $i th model")
    n = rand(500:2000) 
    p = rand(1:10)n
    println("n, p = " * string(n) * ", " * string(p))
    run_poisson(n, p)
end
# Out:
# running the 1 th model
# n, p = 1682, 6728
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 192              │ -1.27736  │ 0.0         │
# │ 2   │ 1342             │ 1.33404   │ 0.0         │
# │ 3   │ 1373             │ -2.3186   │ -1.82063    │
# │ 4   │ 1382             │ 0.128027  │ 0.0         │
# │ 5   │ 2345             │ 1.09643   │ 1.02478     │
# │ 6   │ 3293             │ 0.907412  │ 0.0         │
# │ 7   │ 3525             │ -1.78121  │ -1.76787    │
# │ 8   │ 4387             │ -0.920503 │ 0.0         │
# │ 9   │ 4559             │ -1.91075  │ -1.14125    │
# │ 10  │ 6097             │ 0.120748  │ 0.0         │
# Total iteration number was 292
# Total time was 21.481292009353638
# running the 2 th model
# n, p = 1175, 2350
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 145              │ -0.166704 │ 0.0         │
# │ 2   │ 149              │ -1.35817  │ 0.0         │
# │ 3   │ 351              │ -1.51132  │ 0.0         │
# │ 4   │ 440              │ 0.763088  │ 0.0         │
# │ 5   │ 925              │ -1.08894  │ 0.0         │
# │ 6   │ 1150             │ 0.25407   │ 0.0         │
# │ 7   │ 1419             │ -2.02503  │ -1.24726    │
# │ 8   │ 2174             │ 0.497975  │ 0.706381    │
# │ 9   │ 2329             │ 1.09125   │ 0.910756    │
# │ 10  │ 2333             │ 0.981417  │ 0.0         │
# Total iteration number was 231
# Total time was 4.324492931365967
# running the 3 th model
# n, p = 1166, 10494
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 211              │ 1.03636   │ 1.0475      │
# │ 2   │ 692              │ 0.134457  │ 0.128991    │
# │ 3   │ 2849             │ 0.0130759 │ 0.0         │
# │ 4   │ 2858             │ 0.463262  │ 0.464108    │
# │ 5   │ 3249             │ -0.396346 │ -0.389202   │
# │ 6   │ 4384             │ 0.280829  │ 0.274847    │
# │ 7   │ 5667             │ -1.69248  │ -1.51781    │
# │ 8   │ 7613             │ -0.84576  │ -0.848724   │
# │ 9   │ 10146            │ -0.494829 │ -0.486877   │
# │ 10  │ 10491            │ 0.938236  │ 0.933961    │
# Total iteration number was 43
# Total time was 5.078933000564575
# running the 4 th model
# n, p = 1299, 2598
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 323              │ -0.677124 │ -0.655287   │
# │ 2   │ 627              │ 0.477399  │ 0.512344    │
# │ 3   │ 713              │ 0.732579  │ 0.74386     │
# │ 4   │ 981              │ -0.145141 │ 0.0         │
# │ 5   │ 1145             │ -1.7438   │ -1.74563    │
# │ 6   │ 1529             │ 0.303436  │ 0.288468    │
# │ 7   │ 1901             │ 1.51798   │ 1.50966     │
# │ 8   │ 2095             │ -0.463385 │ -0.454751   │
# │ 9   │ 2269             │ 1.59672   │ 1.5939      │
# │ 10  │ 2302             │ -1.64246  │ -1.65998    │
# Total iteration number was 137
# Total time was 3.2418301105499268
# running the 5 th model
# n, p = 1954, 1954
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 49               │ 0.463409  │ 0.465692    │
# │ 2   │ 165              │ -1.63087  │ -1.64577    │
# │ 3   │ 166              │ 0.428629  │ 0.428857    │
# │ 4   │ 664              │ -0.215436 │ 0.0         │
# │ 5   │ 940              │ 0.39492   │ 0.402282    │
# │ 6   │ 960              │ -1.07293  │ -1.07252    │
# │ 7   │ 979              │ -2.01809  │ -1.59416    │
# │ 8   │ 1322             │ -1.62911  │ -1.42428    │
# │ 9   │ 1775             │ 0.29638   │ 0.289801    │
# │ 10  │ 1842             │ 1.40519   │ 1.4142      │
# Total iteration number was 98
# Total time was 2.8872900009155273
# running the 6 th model
# n, p = 986, 2958
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 427              │ 0.227974  │ 0.228394    │
# │ 2   │ 1026             │ -0.152498 │ -0.154929   │
# │ 3   │ 1233             │ -1.56583  │ -1.57111    │
# │ 4   │ 1435             │ 1.63668   │ 1.63358     │
# │ 5   │ 1510             │ -0.793842 │ -0.69612    │
# │ 6   │ 1515             │ -0.370037 │ -0.372636   │
# │ 7   │ 1897             │ 0.434774  │ 0.441363    │
# │ 8   │ 2068             │ 1.03398   │ 1.03606     │
# │ 9   │ 2360             │ 0.276515  │ 0.269022    │
# │ 10  │ 2627             │ -1.38633  │ -1.40406    │
# Total iteration number was 101
# Total time was 2.3469090461730957
# running the 7 th model
# n, p = 1291, 12910
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 1011             │ 0.584803  │ 0.0         │
# │ 2   │ 1525             │ 1.84898   │ 0.0         │
# │ 3   │ 2305             │ -0.588209 │ 0.0         │
# │ 4   │ 2402             │ -0.928701 │ 0.0         │
# │ 5   │ 3644             │ -1.82555  │ 0.0         │
# │ 6   │ 5438             │ 1.36927   │ 0.0         │
# │ 7   │ 7199             │ -2.93903  │ -2.39179    │
# │ 8   │ 7687             │ 0.390627  │ 0.0         │
# │ 9   │ 10908            │ -0.846676 │ 0.0         │
# │ 10  │ 12719            │ -0.54843  │ 0.0         │
# Total iteration number was 406
# Total time was 40.34921479225159
# running the 8 th model
# n, p = 532, 3192
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β      │ estimated_β │
# │     │ Int64            │ Float64     │ Float64     │
# ├─────┼──────────────────┼─────────────┼─────────────┤
# │ 1   │ 593              │ -1.19886    │ -1.21595    │
# │ 2   │ 992              │ -0.253849   │ -0.278046   │
# │ 3   │ 1112             │ 0.360862    │ 0.351584    │
# │ 4   │ 1459             │ -1.07704    │ -1.02439    │
# │ 5   │ 1710             │ -1.54279    │ -1.50668    │
# │ 6   │ 2149             │ -0.960638   │ -0.938946   │
# │ 7   │ 2596             │ -0.0444626  │ 0.0         │
# │ 8   │ 2870             │ -0.965713   │ -0.96073    │
# │ 9   │ 2928             │ -0.00685197 │ 0.0         │
# │ 10  │ 3133             │ -0.473533   │ -0.446828   │
# Total iteration number was 122
# Total time was 1.5383539199829102
# running the 9 th model
# n, p = 792, 7128
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 311              │ -0.466472 │ 0.0         │
# │ 2   │ 653              │ 2.26987   │ 0.0         │
# │ 3   │ 1070             │ -1.28702  │ 0.0         │
# │ 4   │ 1695             │ 0.537899  │ 0.0         │
# │ 5   │ 3220             │ 0.824496  │ 0.0         │
# │ 6   │ 4399             │ 0.691587  │ 0.0         │
# │ 7   │ 4441             │ -0.261211 │ 0.0         │
# │ 8   │ 4508             │ -0.622069 │ 0.0         │
# │ 9   │ 5063             │ 0.602591  │ 0.0         │
# │ 10  │ 6452             │ 1.72373   │ 0.0         │
# Total iteration number was 199
# Total time was 7.608752012252808
# running the 10 th model
# n, p = 1477, 7385
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β      │ estimated_β │
# │     │ Int64            │ Float64     │ Float64     │
# ├─────┼──────────────────┼─────────────┼─────────────┤
# │ 1   │ 1208             │ -0.651067   │ -0.645867   │
# │ 2   │ 1558             │ -0.00935977 │ 0.0         │
# │ 3   │ 3041             │ -0.685231   │ -0.662472   │
# │ 4   │ 3678             │ -2.14567    │ -1.68608    │
# │ 5   │ 3758             │ 0.651002    │ 0.657675    │
# │ 6   │ 4164             │ -1.34134    │ -1.27696    │
# │ 7   │ 5356             │ 0.22178     │ 0.216859    │
# │ 8   │ 6289             │ 1.41211     │ 1.41233     │
# │ 9   │ 6592             │ 0.987541    │ 0.983341    │
# │ 10  │ 6639             │ 0.601637    │ 0.603782    │
# Total iteration number was 88
# Total time was 6.839394807815552
# running the 11 th model
# n, p = 556, 5004
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β     │ estimated_β │
# │     │ Int64            │ Float64    │ Float64     │
# ├─────┼──────────────────┼────────────┼─────────────┤
# │ 1   │ 853              │ 0.960332   │ 0.99613     │
# │ 2   │ 1896             │ -1.83579   │ -1.79671    │
# │ 3   │ 1897             │ 1.12789    │ 1.11129     │
# │ 4   │ 2052             │ -0.0620287 │ 0.0         │
# │ 5   │ 2622             │ 0.114353   │ 0.0         │
# │ 6   │ 3493             │ -0.952088  │ -0.784306   │
# │ 7   │ 4196             │ 0.462485   │ 0.3941      │
# │ 8   │ 4262             │ -1.99042   │ -1.85978    │
# │ 9   │ 4469             │ 0.329497   │ 0.0         │
# │ 10  │ 4916             │ -0.35381   │ -0.338001   │
# Total iteration number was 326
# Total time was 5.713693141937256
# running the 12 th model
# n, p = 961, 961
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 126              │ -0.360702 │ 0.0         │
# │ 2   │ 194              │ -1.08581  │ -1.27748    │
# │ 3   │ 288              │ -0.746891 │ -0.761132   │
# │ 4   │ 300              │ -1.32596  │ -1.3216     │
# │ 5   │ 386              │ -0.392685 │ 0.0         │
# │ 6   │ 532              │ 0.61642   │ 0.684076    │
# │ 7   │ 576              │ -1.18333  │ -1.13154    │
# │ 8   │ 593              │ -0.525093 │ -0.487851   │
# │ 9   │ 643              │ 0.755503  │ 0.736471    │
# │ 10  │ 947              │ 0.800602  │ 0.767535    │
# Total iteration number was 118
# Total time was 0.8338930606842041
# running the 13 th model
# n, p = 679, 2037
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β     │ estimated_β │
# │     │ Int64            │ Float64    │ Float64     │
# ├─────┼──────────────────┼────────────┼─────────────┤
# │ 1   │ 307              │ 1.064      │ 1.05597     │
# │ 2   │ 424              │ -0.044296  │ 0.0         │
# │ 3   │ 433              │ 0.0492218  │ 0.0         │
# │ 4   │ 704              │ -0.508219  │ -0.519641   │
# │ 5   │ 709              │ 0.0904915  │ 0.116238    │
# │ 6   │ 756              │ -0.0334339 │ 0.0         │
# │ 7   │ 801              │ 0.62139    │ 0.619335    │
# │ 8   │ 1139             │ -1.07505   │ -1.01627    │
# │ 9   │ 1170             │ -1.30675   │ -1.23642    │
# │ 10  │ 1476             │ -0.312853  │ -0.326612   │
# Total iteration number was 94
# Total time was 1.0540649890899658
# running the 14 th model
# n, p = 763, 7630
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 300              │ 2.70004   │ 1.99842     │
# │ 2   │ 562              │ 0.25584   │ 0.0         │
# │ 3   │ 2974             │ -1.30223  │ 0.0         │
# │ 4   │ 3623             │ -0.493639 │ 0.0         │
# │ 5   │ 3629             │ 0.687367  │ 0.0         │
# │ 6   │ 3942             │ -0.217069 │ 0.0         │
# │ 7   │ 4187             │ 1.56129   │ 0.0         │
# │ 8   │ 5009             │ 0.712548  │ 0.0         │
# │ 9   │ 5792             │ 1.0093    │ 0.0         │
# │ 10  │ 6184             │ 1.36063   │ 0.0         │
# Total iteration number was 279
# Total time was 10.829925060272217
# running the 15 th model
# n, p = 1784, 16056
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β     │ estimated_β │
# │     │ Int64            │ Float64    │ Float64     │
# ├─────┼──────────────────┼────────────┼─────────────┤
# │ 1   │ 1461             │ 0.557188   │ 0.553492    │
# │ 2   │ 1704             │ 0.49728    │ 0.493316    │
# │ 3   │ 2855             │ 0.367441   │ 0.372723    │
# │ 4   │ 3512             │ -0.0172641 │ 0.0         │
# │ 5   │ 4196             │ 1.01224    │ 1.02118     │
# │ 6   │ 9996             │ 0.41788    │ 0.416103    │
# │ 7   │ 10622            │ -1.17122   │ -1.1466     │
# │ 8   │ 11315            │ 0.115015   │ 0.106598    │
# │ 9   │ 13206            │ -0.545258  │ -0.54098    │
# │ 10  │ 13635            │ -1.01059   │ -1.01602    │
# Total iteration number was 27
# Total time was 9.082090139389038
# running the 16 th model
# n, p = 1991, 13937
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β   │ estimated_β │
# │     │ Int64            │ Float64  │ Float64     │
# ├─────┼──────────────────┼──────────┼─────────────┤
# │ 1   │ 826              │ 0.14522  │ 0.0         │
# │ 2   │ 952              │ 0.105855 │ 0.0         │
# │ 3   │ 5593             │ 1.68411  │ 1.22291     │
# │ 4   │ 7673             │ -1.26026 │ -0.87795    │
# │ 5   │ 7809             │ 0.73679  │ 0.0         │
# │ 6   │ 8041             │ 0.755497 │ 0.0         │
# │ 7   │ 10139            │ 1.93537  │ 0.0         │
# │ 8   │ 11316            │ 1.12735  │ 0.0         │
# │ 9   │ 12667            │ 1.22055  │ 0.0         │
# │ 10  │ 12829            │ -1.01251 │ 0.0         │
# Total iteration number was 174
# Total time was 31.76523995399475
# running the 17 th model
# n, p = 1056, 7392
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 379              │ 1.09818   │ 0.649224    │
# │ 2   │ 3335             │ 1.11026   │ 0.803509    │
# │ 3   │ 3553             │ -0.363299 │ 0.0         │
# │ 4   │ 3655             │ -0.540411 │ 0.0         │
# │ 5   │ 4121             │ 0.96677   │ 0.0         │
# │ 6   │ 4793             │ 1.43558   │ 1.30107     │
# │ 7   │ 5012             │ -0.84844  │ -0.770332   │
# │ 8   │ 5819             │ 0.351185  │ 0.0         │
# │ 9   │ 6786             │ -0.996867 │ 0.0         │
# │ 10  │ 6906             │ 1.5083    │ 1.59185     │
# Total iteration number was 221
# Total time was 11.37800407409668
# running the 18 th model
# n, p = 1049, 8392
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β     │ estimated_β │
# │     │ Int64            │ Float64    │ Float64     │
# ├─────┼──────────────────┼────────────┼─────────────┤
# │ 1   │ 169              │ -1.77053   │ -1.74       │
# │ 2   │ 933              │ -0.0697603 │ 0.0         │
# │ 3   │ 1504             │ 0.881352   │ 0.880374    │
# │ 4   │ 1758             │ -0.209376  │ -0.200855   │
# │ 5   │ 2378             │ -1.62511   │ -1.592      │
# │ 6   │ 3377             │ -0.427696  │ -0.400106   │
# │ 7   │ 5603             │ -0.25049   │ -0.250637   │
# │ 8   │ 6825             │ -1.00578   │ -1.02333    │
# │ 9   │ 7073             │ 0.202856   │ 0.219663    │
# │ 10  │ 8162             │ -0.657364  │ -0.665737   │
# Total iteration number was 159
# Total time was 9.545666933059692
# running the 19 th model
# n, p = 1373, 4119
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β     │ estimated_β │
# │     │ Int64            │ Float64    │ Float64     │
# ├─────┼──────────────────┼────────────┼─────────────┤
# │ 1   │ 40               │ -0.128967  │ -0.115217   │
# │ 2   │ 63               │ -2.16218   │ -2.17412    │
# │ 3   │ 330              │ 0.38277    │ 0.374156    │
# │ 4   │ 516              │ 0.588187   │ 0.58187     │
# │ 5   │ 826              │ -0.891298  │ -0.887763   │
# │ 6   │ 1002             │ -0.233509  │ -0.23549    │
# │ 7   │ 1303             │ 0.459918   │ 0.480062    │
# │ 8   │ 1341             │ 0.854453   │ 0.849127    │
# │ 9   │ 2390             │ 0.665069   │ 0.672664    │
# │ 10  │ 2710             │ -0.0425367 │ -0.040452   │
# Total iteration number was 87
# Total time was 3.461052894592285
# running the 20 th model
# n, p = 1546, 7730
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 980              │ 0.555591  │ 0.567245    │
# │ 2   │ 1362             │ 0.0477888 │ 0.0         │
# │ 3   │ 2554             │ 1.28067   │ 1.26591     │
# │ 4   │ 3663             │ -0.194551 │ -0.199891   │
# │ 5   │ 4582             │ 0.711126  │ 0.702849    │
# │ 6   │ 4886             │ 0.904206  │ 0.902477    │
# │ 7   │ 5288             │ 0.0830302 │ 0.0         │
# │ 8   │ 5606             │ 0.922239  │ 0.89524     │
# │ 9   │ 5715             │ -0.60385  │ -0.586745   │
# │ 10  │ 7374             │ 0.998488  │ 1.00027     │
# Total iteration number was 52
# Total time was 5.467841148376465
# running the 21 th model
# n, p = 1892, 5676
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 794              │ -0.922833 │ 0.0         │
# │ 2   │ 1088             │ -0.937453 │ 0.0         │
# │ 3   │ 1176             │ 0.243105  │ 0.0         │
# │ 4   │ 1668             │ -0.559206 │ 0.0         │
# │ 5   │ 2007             │ 0.616306  │ 0.0         │
# │ 6   │ 2493             │ 1.5142    │ 0.0         │
# │ 7   │ 2510             │ 1.20181   │ 0.0         │
# │ 8   │ 2609             │ -1.07066  │ 0.0         │
# │ 9   │ 4280             │ -0.994643 │ 0.0         │
# │ 10  │ 5001             │ 1.00885   │ 0.0         │
# Total iteration number was 311
# Total time was 20.51149821281433
# running the 22 th model
# n, p = 1620, 12960
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β     │ estimated_β │
# │     │ Int64            │ Float64    │ Float64     │
# ├─────┼──────────────────┼────────────┼─────────────┤
# │ 1   │ 306              │ -1.65476   │ -1.59902    │
# │ 2   │ 2044             │ 0.54923    │ 0.0         │
# │ 3   │ 4041             │ -1.48404   │ -1.21434    │
# │ 4   │ 5149             │ -1.77145   │ 0.0         │
# │ 5   │ 5759             │ -1.16592   │ 0.0         │
# │ 6   │ 6233             │ -1.51365   │ -1.67498    │
# │ 7   │ 7173             │ 1.6669     │ 0.849697    │
# │ 8   │ 7686             │ -0.0284799 │ 0.0         │
# │ 9   │ 7745             │ 0.704853   │ 0.0         │
# │ 10  │ 9847             │ -0.874043  │ -1.25285    │
# Total iteration number was 208
# Total time was 27.524980068206787
# running the 23 th model
# n, p = 550, 4400
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β     │ estimated_β │
# │     │ Int64            │ Float64    │ Float64     │
# ├─────┼──────────────────┼────────────┼─────────────┤
# │ 1   │ 132              │ 0.793984   │ 0.593244    │
# │ 2   │ 476              │ 1.16587    │ 0.866469    │
# │ 3   │ 1860             │ -0.405663  │ 0.0         │
# │ 4   │ 1967             │ 0.882072   │ 0.682764    │
# │ 5   │ 2790             │ -0.521187  │ 0.0         │
# │ 6   │ 2920             │ -0.688048  │ 0.0         │
# │ 7   │ 3535             │ 0.682062   │ 0.0         │
# │ 8   │ 3667             │ -0.0247543 │ 0.0         │
# │ 9   │ 3696             │ 0.900856   │ 0.0         │
# │ 10  │ 4111             │ -1.24194   │ 0.0         │
# Total iteration number was 100
# Total time was 1.9123950004577637
# running the 24 th model
# n, p = 881, 4405
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 682              │ -0.25085  │ -0.359103   │
# │ 2   │ 1282             │ 0.162982  │ 0.0         │
# │ 3   │ 1677             │ 0.380189  │ 0.0         │
# │ 4   │ 1813             │ 1.04718   │ 0.995294    │
# │ 5   │ 1964             │ -0.79014  │ -0.914877   │
# │ 6   │ 2026             │ 0.520714  │ 0.411516    │
# │ 7   │ 2177             │ 2.67023   │ 2.30615     │
# │ 8   │ 2574             │ -0.621328 │ -0.557153   │
# │ 9   │ 4292             │ 0.127233  │ 0.0         │
# │ 10  │ 4310             │ -2.07552  │ -1.5003     │
# Total iteration number was 324
# Total time was 7.866052150726318
# running the 25 th model
# n, p = 930, 6510
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β     │ estimated_β │
# │     │ Int64            │ Float64    │ Float64     │
# ├─────┼──────────────────┼────────────┼─────────────┤
# │ 1   │ 277              │ 0.666387   │ 0.666763    │
# │ 2   │ 570              │ 0.294152   │ 0.291489    │
# │ 3   │ 1990             │ 1.48757    │ 1.47075     │
# │ 4   │ 2292             │ 0.9859     │ 0.978468    │
# │ 5   │ 2773             │ 0.876703   │ 0.872344    │
# │ 6   │ 3133             │ -0.606454  │ -0.601722   │
# │ 7   │ 3676             │ -0.134446  │ -0.142736   │
# │ 8   │ 3851             │ -0.219458  │ -0.220575   │
# │ 9   │ 4110             │ -0.0204971 │ 0.0         │
# │ 10  │ 6299             │ 0.905733   │ 0.897603    │
# Total iteration number was 80
# Total time was 3.706529140472412

# %% [markdown]
# ## Reconstruction becomes harder as k increase

# %%
function run_poisson()
    n, p = 2000, 20000

    #set random seed
    Random.seed!(1111)

    #simulate data
    bernoulli_rates = 0.5rand(p) #minor allele frequencies are drawn from uniform (0, 0.5)
    x = simulate_random_snparray(n, p, bernoulli_rates)
    xbm = SnpBitMatrix{Float64}(x, model=ADDITIVE_MODEL, center=true, scale=true); 
    z           = ones(n, 1)                   # non-genetic covariates, just the intercept

    for k in 1:30
        true_b      = zeros(p)                     # model vector
        true_b[1:k] = randn(k)                     # Initialize k non-zero entries in the true model
        shuffle!(true_b)                           # Shuffle the entries
        correct_position = findall(x -> x != 0, true_b) # keep track of what the true entries are

        #simulate phenotypes under different noises by: y = Xb + noise
        y_temp = xbm * true_b

        # Simulate poisson data
        λ = exp.(y_temp) #inverse log link
        y = [rand(Poisson(x)) for x in λ]
        y = Float64.(y)

        #compute poisson IHT result
        result = L0_poisson_reg(x, z, y, 1, k, glm = "poisson", debias=false, convg=false, show_info=false)

        #check result
        estimated_models = result.beta[correct_position]
        true_model = true_b[correct_position]
        compare_model = DataFrame(
            correct_position = correct_position, 
            true_β           = true_model, 
            estimated_β      = estimated_models)

        #display results
        @show compare_model
        println("Total iteration number was " * string(result.iter))
        println("Total time was " * string(result.time))
    end
end
# Out:
# run_poisson (generic function with 2 methods)

# %%
run_poisson()
# Out:
# compare_model = 1×3 DataFrame
# │ Row │ correct_position │ true_β   │ estimated_β │
# │     │ Int64            │ Float64  │ Float64     │
# ├─────┼──────────────────┼──────────┼─────────────┤
# │ 1   │ 9568             │ -0.18273 │ 0.0         │
# Total iteration number was 11
# Total time was 9.347173929214478
# compare_model = 2×3 DataFrame
# │ Row │ correct_position │ true_β   │ estimated_β │
# │     │ Int64            │ Float64  │ Float64     │
# ├─────┼──────────────────┼──────────┼─────────────┤
# │ 1   │ 10299            │ 0.873072 │ 0.8714      │
# │ 2   │ 12735            │ 0.187676 │ 0.179331    │
# Total iteration number was 18
# Total time was 14.012959003448486
# compare_model = 3×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 1010             │ -0.138243 │ -0.140331   │
# │ 2   │ 14539            │ -0.118317 │ -0.123353   │
# │ 3   │ 18887            │ -0.432062 │ -0.385693   │
# Total iteration number was 12
# Total time was 10.121201992034912
# compare_model = 4×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 4059             │ 1.29005   │ 1.30988     │
# │ 2   │ 6827             │ -0.192455 │ -0.188125   │
# │ 3   │ 7105             │ 0.545564  │ 0.54297     │
# │ 4   │ 9720             │ -1.79911  │ -1.76972    │
# Total iteration number was 48
# Total time was 16.333723783493042
# compare_model = 5×3 DataFrame
# │ Row │ correct_position │ true_β   │ estimated_β │
# │     │ Int64            │ Float64  │ Float64     │
# ├─────┼──────────────────┼──────────┼─────────────┤
# │ 1   │ 5035             │ -0.28988 │ -0.311452   │
# │ 2   │ 8961             │ 0.611105 │ 0.676649    │
# │ 3   │ 10135            │ -1.58512 │ -1.55917    │
# │ 4   │ 14250            │ 0.225668 │ 0.0         │
# │ 5   │ 18240            │ 1.00503  │ 0.997882    │
# Total iteration number was 28
# Total time was 12.487333059310913
# compare_model = 6×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 3369             │ 0.783642  │ 0.789491    │
# │ 2   │ 3458             │ -0.577404 │ -0.576255   │
# │ 3   │ 4034             │ -0.127524 │ -0.135174   │
# │ 4   │ 5569             │ 0.106733  │ 0.10827     │
# │ 5   │ 5574             │ -2.48769  │ -2.47622    │
# │ 6   │ 14088            │ 0.176788  │ 0.185846    │
# Total iteration number was 83
# Total time was 23.9163179397583
# compare_model = 7×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 6030             │ -0.15743  │ 0.0         │
# │ 2   │ 6729             │ 0.297527  │ 0.304241    │
# │ 3   │ 12001            │ 0.309246  │ 0.307606    │
# │ 4   │ 15629            │ -1.17185  │ -1.15239    │
# │ 5   │ 16438            │ -0.405277 │ -0.423401   │
# │ 6   │ 18635            │ 0.62852   │ 0.61824     │
# │ 7   │ 19468            │ 0.790734  │ 0.808297    │
# Total iteration number was 25
# Total time was 12.70618486404419
# compare_model = 8×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 4951             │ -1.15069  │ -1.31402    │
# │ 2   │ 8256             │ -0.924164 │ -0.930367   │
# │ 3   │ 12556            │ 1.32369   │ 1.2835      │
# │ 4   │ 12930            │ -0.417574 │ 0.0         │
# │ 5   │ 18477            │ 0.276919  │ 0.0         │
# │ 6   │ 18497            │ -1.10193  │ -1.16252    │
# │ 7   │ 18742            │ 1.51045   │ 1.50266     │
# │ 8   │ 19979            │ 1.54316   │ 1.55472     │
# Total iteration number was 331
# Total time was 79.68141388893127
# compare_model = 9×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 3019             │ -0.7811   │ 0.0         │
# │ 2   │ 5512             │ 0.266125  │ 0.0         │
# │ 3   │ 7548             │ 0.093598  │ 0.0         │
# │ 4   │ 9875             │ -0.139851 │ 0.0         │
# │ 5   │ 10376            │ 1.25183   │ 1.17337     │
# │ 6   │ 10413            │ -0.348939 │ 0.0         │
# │ 7   │ 16763            │ 0.437089  │ 0.0         │
# │ 8   │ 19178            │ 1.00667   │ 0.878038    │
# │ 9   │ 19446            │ 0.245279  │ 0.0         │
# Total iteration number was 210
# Total time was 54.5252890586853
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 1429             │ 0.326387  │ 0.31143     │
# │ 2   │ 2555             │ 0.591543  │ 0.591439    │
# │ 3   │ 2700             │ 0.643238  │ 0.641376    │
# │ 4   │ 4106             │ 0.0815982 │ 0.0         │
# │ 5   │ 5013             │ -0.542064 │ -0.530784   │
# │ 6   │ 6359             │ -1.88083  │ -1.90284    │
# │ 7   │ 9261             │ -0.969115 │ -0.942309   │
# │ 8   │ 10115            │ 0.388973  │ 0.395741    │
# │ 9   │ 11342            │ -0.888615 │ -0.8844     │
# │ 10  │ 18464            │ 0.255919  │ 0.241679    │
# Total iteration number was 62
# Total time was 19.52348804473877
# compare_model = 11×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 4023             │ -1.85152  │ -1.65501    │
# │ 2   │ 4157             │ 0.535379  │ 0.533627    │
# │ 3   │ 6258             │ -2.00161  │ -1.97408    │
# │ 4   │ 9657             │ -0.849762 │ -0.848946   │
# │ 5   │ 10546            │ 1.30444   │ 1.29981     │
# │ 6   │ 10779            │ 1.66634   │ 1.65191     │
# │ 7   │ 11021            │ -0.377597 │ -0.365174   │
# │ 8   │ 11261            │ -0.275861 │ -0.268743   │
# │ 9   │ 14228            │ -1.29204  │ -1.27075    │
# │ 10  │ 17553            │ 0.0237866 │ 0.0         │
# │ 11  │ 18420            │ 0.492398  │ 0.483926    │
# Total iteration number was 182
# Total time was 47.15670585632324
# compare_model = 12×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 461              │ -1.01172  │ 0.0         │
# │ 2   │ 1391             │ -0.571599 │ 0.0         │
# │ 3   │ 1917             │ 1.13214   │ 0.819856    │
# │ 4   │ 1952             │ 1.43975   │ 0.0         │
# │ 5   │ 7342             │ 0.06547   │ 0.0         │
# │ 6   │ 9589             │ -0.131303 │ 0.0         │
# │ 7   │ 16276            │ -1.61553  │ 0.0         │
# │ 8   │ 16731            │ 0.662625  │ 0.0         │
# │ 9   │ 16771            │ -0.212645 │ 0.0         │
# │ 10  │ 19159            │ 0.807764  │ 0.0         │
# │ 11  │ 19287            │ -0.383231 │ 0.0         │
# │ 12  │ 19523            │ -1.22683  │ -1.29811    │
# Total iteration number was 219
# Total time was 59.129148960113525
# compare_model = 13×3 DataFrame
# │ Row │ correct_position │ true_β     │ estimated_β │
# │     │ Int64            │ Float64    │ Float64     │
# ├─────┼──────────────────┼────────────┼─────────────┤
# │ 1   │ 1668             │ -1.04482   │ -1.03433    │
# │ 2   │ 2623             │ 0.326726   │ 0.328359    │
# │ 3   │ 2723             │ 1.09925    │ 1.09896     │
# │ 4   │ 3332             │ 0.382672   │ 0.378921    │
# │ 5   │ 3354             │ -2.42067   │ -2.13793    │
# │ 6   │ 3861             │ -0.586625  │ -0.578141   │
# │ 7   │ 5246             │ 0.00827184 │ 0.0         │
# │ 8   │ 6466             │ -0.847782  │ -0.778339   │
# │ 9   │ 6933             │ -0.135371  │ -0.128038   │
# │ 10  │ 9781             │ 0.138301   │ 0.14017     │
# │ 11  │ 15813            │ 0.230798   │ 0.228667    │
# │ 12  │ 17971            │ 0.298303   │ 0.301472    │
# │ 13  │ 18216            │ 0.948283   │ 0.943907    │
# Total iteration number was 98
# Total time was 29.149083137512207
# compare_model = 14×3 DataFrame
# │ Row │ correct_position │ true_β     │ estimated_β │
# │     │ Int64            │ Float64    │ Float64     │
# ├─────┼──────────────────┼────────────┼─────────────┤
# │ 1   │ 2079             │ 0.442496   │ 0.445944    │
# │ 2   │ 2093             │ 0.917902   │ 0.91958     │
# │ 3   │ 4883             │ -0.125838  │ -0.137357   │
# │ 4   │ 5878             │ -0.68364   │ -0.659583   │
# │ 5   │ 7138             │ 0.178558   │ 0.193629    │
# │ 6   │ 8709             │ -0.0395192 │ 0.0         │
# │ 7   │ 11942            │ -0.140715  │ -0.146196   │
# │ 8   │ 15473            │ 0.369727   │ 0.373689    │
# │ 9   │ 15645            │ 0.67671    │ 0.674686    │
# │ 10  │ 15809            │ 0.186651   │ 0.18213     │
# │ 11  │ 17405            │ -0.226702  │ -0.218509   │
# │ 12  │ 18409            │ 2.30306    │ 2.27152     │
# │ 13  │ 18497            │ -0.318848  │ -0.32682    │
# │ 14  │ 18610            │ 0.0783846  │ 0.0655768   │
# Total iteration number was 161
# Total time was 43.07953190803528
# compare_model = 15×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 71               │ 0.79995   │ 0.727521    │
# │ 2   │ 836              │ -2.17122  │ -1.9955     │
# │ 3   │ 3046             │ -0.123925 │ 0.0         │
# │ 4   │ 3842             │ -1.02066  │ -0.916994   │
# │ 5   │ 4313             │ 1.19966   │ 1.14318     │
# │ 6   │ 5177             │ -0.44601  │ 0.0         │
# │ 7   │ 8964             │ -0.107237 │ 0.0         │
# │ 8   │ 9161             │ 0.718854  │ 0.746859    │
# │ 9   │ 15951            │ -1.62816  │ -1.53825    │
# │ 10  │ 16527            │ -0.326701 │ -0.402376   │
# │ 11  │ 16735            │ -0.722617 │ -0.76721    │
# │ 12  │ 16931            │ 0.870855  │ 0.8984      │
# │ 13  │ 17130            │ -1.14957  │ -1.01236    │
# │ 14  │ 17845            │ -1.10406  │ -1.08493    │
# │ 15  │ 18362            │ -0.970912 │ -0.909493   │
# Total iteration number was 340
# Total time was 81.79513502120972
# compare_model = 16×3 DataFrame
# │ Row │ correct_position │ true_β     │ estimated_β │
# │     │ Int64            │ Float64    │ Float64     │
# ├─────┼──────────────────┼────────────┼─────────────┤
# │ 1   │ 1662             │ 0.512031   │ 0.0         │
# │ 2   │ 2293             │ -0.327181  │ 0.0         │
# │ 3   │ 3880             │ 0.263797   │ 0.0         │
# │ 4   │ 3957             │ -1.2074    │ 0.0         │
# │ 5   │ 6397             │ 0.827808   │ 0.0         │
# │ 6   │ 7636             │ 0.422174   │ 0.0         │
# │ 7   │ 7771             │ 0.499972   │ 0.0         │
# │ 8   │ 8223             │ 0.377278   │ 0.0         │
# │ 9   │ 9858             │ 0.388456   │ 0.0         │
# │ 10  │ 10580            │ 1.53205    │ 0.0         │
# │ 11  │ 10958            │ 0.394888   │ 0.0         │
# │ 12  │ 12461            │ -1.6343    │ -0.957876   │
# │ 13  │ 12506            │ 1.6059     │ 0.0         │
# │ 14  │ 14337            │ 2.43882    │ 1.04224     │
# │ 15  │ 14796            │ -1.01666   │ 0.0         │
# │ 16  │ 17390            │ -0.0126038 │ 0.0         │
# Total iteration number was 245
# Total time was 60.780760049819946
# compare_model = 17×3 DataFrame
# │ Row │ correct_position │ true_β     │ estimated_β │
# │     │ Int64            │ Float64    │ Float64     │
# ├─────┼──────────────────┼────────────┼─────────────┤
# │ 1   │ 413              │ -0.649549  │ -0.645496   │
# │ 2   │ 2057             │ 0.139303   │ 0.135345    │
# │ 3   │ 6909             │ -2.28898   │ -2.25793    │
# │ 4   │ 7183             │ 0.806363   │ 0.80657     │
# │ 5   │ 7671             │ -0.153402  │ -0.15708    │
# │ 6   │ 8449             │ 1.04714    │ 1.05051     │
# │ 7   │ 9317             │ -0.38117   │ -0.384217   │
# │ 8   │ 13562            │ -0.0772076 │ -0.0806134  │
# │ 9   │ 13639            │ -0.352752  │ -0.350583   │
# │ 10  │ 14543            │ -0.452039  │ -0.451157   │
# │ 11  │ 14964            │ 0.62376    │ 0.630857    │
# │ 12  │ 16632            │ -0.566118  │ -0.569156   │
# │ 13  │ 16826            │ 0.253848   │ 0.260553    │
# │ 14  │ 17106            │ -0.563578  │ -0.56549    │
# │ 15  │ 17153            │ 1.57943    │ 1.58845     │
# │ 16  │ 18986            │ 0.563921   │ 0.566673    │
# │ 17  │ 19973            │ -0.346716  │ -0.352955   │
# Total iteration number was 328
# Total time was 76.34214496612549
# compare_model = 18×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 1658             │ 1.4727    │ 0.0         │
# │ 2   │ 3529             │ 0.389861  │ 0.0         │
# │ 3   │ 3821             │ -1.41783  │ -0.828091   │
# │ 4   │ 5532             │ 1.29362   │ 0.51599     │
# │ 5   │ 6349             │ -1.6278   │ -0.692473   │
# │ 6   │ 6792             │ -0.805765 │ 0.0         │
# │ 7   │ 7243             │ 0.330027  │ 0.0         │
# │ 8   │ 8743             │ -1.33948  │ -0.857384   │
# │ 9   │ 9148             │ 0.992178  │ 0.0         │
# │ 10  │ 10002            │ 0.0589773 │ 0.0         │
# │ 11  │ 10590            │ -1.62474  │ 0.0         │
# │ 12  │ 10789            │ -1.14095  │ 0.0         │
# │ 13  │ 11026            │ -0.394024 │ 0.0         │
# │ 14  │ 11621            │ -0.69159  │ 0.0         │
# │ 15  │ 15129            │ -1.83768  │ -0.800353   │
# │ 16  │ 15722            │ 0.723016  │ 0.0         │
# │ 17  │ 17447            │ 0.477451  │ 0.0         │
# │ 18  │ 18190            │ 0.896145  │ 0.0         │
# Total iteration number was 185
# Total time was 47.11943793296814
# compare_model = 19×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 1904             │ -0.87187  │ 0.0         │
# │ 2   │ 2922             │ 0.853228  │ 0.570842    │
# │ 3   │ 3336             │ -0.371956 │ 0.0         │
# │ 4   │ 3681             │ 1.5734    │ 0.8964      │
# │ 5   │ 6545             │ -0.914173 │ 0.0         │
# │ 6   │ 7535             │ -2.11517  │ -2.21752    │
# │ 7   │ 7619             │ 0.442123  │ 0.0         │
# │ 8   │ 8198             │ 1.3793    │ 0.469706    │
# │ 9   │ 8463             │ -1.33151  │ -0.833867   │
# │ 10  │ 9148             │ -0.560331 │ 0.0         │
# │ 11  │ 12175            │ 0.971478  │ 0.0         │
# │ 12  │ 12239            │ -0.595664 │ 0.0         │
# │ 13  │ 12769            │ -0.918205 │ 0.0         │
# │ 14  │ 13034            │ 0.216643  │ 0.0         │
# │ 15  │ 13356            │ -0.115169 │ 0.0         │
# │ 16  │ 13779            │ -1.55382  │ -1.01446    │
# │ 17  │ 16453            │ -0.733257 │ 0.0         │
# │ 18  │ 17614            │ -0.95834  │ 0.0         │
# │ 19  │ 18651            │ -0.417708 │ 0.0         │
# Total iteration number was 150
# Total time was 39.27016305923462
# compare_model = 20×3 DataFrame
# │ Row │ correct_position │ true_β     │ estimated_β │
# │     │ Int64            │ Float64    │ Float64     │
# ├─────┼──────────────────┼────────────┼─────────────┤
# │ 1   │ 727              │ 0.170101   │ 0.0         │
# │ 2   │ 868              │ -1.81449   │ -1.50087    │
# │ 3   │ 1097             │ 0.574143   │ 0.0         │
# │ 4   │ 1647             │ -0.525686  │ 0.0         │
# │ 5   │ 3000             │ 0.437415   │ 0.0         │
# │ 6   │ 5361             │ -0.0830687 │ 0.0         │
# │ 7   │ 5649             │ 0.875822   │ 0.0         │
# │ 8   │ 6083             │ 0.493144   │ 0.0         │
# │ 9   │ 6687             │ 0.35479    │ 0.0         │
# │ 10  │ 9738             │ -0.693293  │ 0.0         │
# │ 11  │ 11484            │ -0.171119  │ 0.0         │
# │ 12  │ 13007            │ -0.402358  │ 0.0         │
# │ 13  │ 13116            │ -0.0812274 │ 0.0         │
# │ 14  │ 13526            │ 0.0477134  │ 0.0         │
# │ 15  │ 16249            │ -1.27231   │ 0.0         │
# │ 16  │ 16488            │ 0.149651   │ 0.0         │
# │ 17  │ 17098            │ -0.803938  │ 0.0         │
# │ 18  │ 18184            │ 1.29611    │ 0.698263    │
# │ 19  │ 18444            │ -1.19973   │ -0.861094   │
# │ 20  │ 19789            │ 0.44404    │ 0.0         │
# Total iteration number was 240
# Total time was 59.2596480846405
# compare_model = 21×3 DataFrame
# │ Row │ correct_position │ true_β      │ estimated_β │
# │     │ Int64            │ Float64     │ Float64     │
# ├─────┼──────────────────┼─────────────┼─────────────┤
# │ 1   │ 67               │ 0.600963    │ 0.0         │
# │ 2   │ 4056             │ 1.28758     │ 0.665215    │
# │ 3   │ 5335             │ 0.104095    │ 0.0         │
# │ 4   │ 7347             │ -1.05685    │ -0.736948   │
# │ 5   │ 8022             │ -0.115421   │ 0.0         │
# │ 6   │ 8499             │ 0.630776    │ 0.0         │
# │ 7   │ 9675             │ 0.869839    │ 0.0         │
# │ 8   │ 11163            │ -0.410495   │ 0.0         │
# │ 9   │ 12582            │ 0.190576    │ 0.0         │
# │ 10  │ 12660            │ 0.962739    │ 0.0         │
# │ 11  │ 12867            │ 1.67043     │ 0.419421    │
# │ 12  │ 13454            │ -1.43665    │ 0.0         │
# │ 13  │ 14040            │ -0.901095   │ 0.0         │
# │ 14  │ 14902            │ 1.44776     │ 0.0         │
# │ 15  │ 15693            │ 2.44585     │ 1.42913     │
# │ 16  │ 16355            │ -0.00137665 │ 0.0         │
# │ 17  │ 17417            │ 0.534562    │ 0.0         │
# │ 18  │ 17807            │ -1.40506    │ -1.28877    │
# │ 19  │ 18884            │ 0.504029    │ 0.0         │
# │ 20  │ 19297            │ 0.852052    │ 0.0         │
# │ 21  │ 19483            │ 0.714822    │ 0.0         │
# Total iteration number was 267
# Total time was 64.0393271446228
# compare_model = 22×3 DataFrame
# │ Row │ correct_position │ true_β     │ estimated_β │
# │     │ Int64            │ Float64    │ Float64     │
# ├─────┼──────────────────┼────────────┼─────────────┤
# │ 1   │ 402              │ 0.297467   │ 0.0         │
# │ 2   │ 610              │ -0.686067  │ 0.0         │
# │ 3   │ 1697             │ -0.631875  │ 0.0         │
# │ 4   │ 3350             │ 0.0264911  │ 0.0         │
# │ 5   │ 4997             │ -0.142372  │ 0.0         │
# │ 6   │ 6562             │ 0.420004   │ 0.0         │
# │ 7   │ 6694             │ -0.284563  │ 0.0         │
# │ 8   │ 8084             │ -0.801784  │ 0.0         │
# │ 9   │ 8587             │ 0.868753   │ 0.0         │
# │ 10  │ 8928             │ -1.51738   │ -1.6238     │
# │ 11  │ 9414             │ -2.64603   │ -1.55249    │
# │ 12  │ 9638             │ -0.941639  │ 0.0         │
# │ 13  │ 12359            │ 0.441127   │ 0.0         │
# │ 14  │ 14300            │ -0.981706  │ 0.0         │
# │ 15  │ 14715            │ -0.0188519 │ 0.0         │
# │ 16  │ 16138            │ 1.5306     │ 0.809828    │
# │ 17  │ 16575            │ -0.580333  │ 0.0         │
# │ 18  │ 16957            │ 0.683606   │ 0.0         │
# │ 19  │ 17182            │ -0.0949992 │ 0.0         │
# │ 20  │ 17728            │ 0.849795   │ 0.0         │
# │ 21  │ 18507            │ 0.796701   │ 0.419114    │
# │ 22  │ 19519            │ 2.10294    │ 1.02637     │
# Total iteration number was 199
# Total time was 48.20963406562805
# compare_model = 23×3 DataFrame
# │ Row │ correct_position │ true_β     │ estimated_β │
# │     │ Int64            │ Float64    │ Float64     │
# ├─────┼──────────────────┼────────────┼─────────────┤
# │ 1   │ 1262             │ 0.731897   │ 0.689727    │
# │ 2   │ 1531             │ -0.730856  │ -0.671154   │
# │ 3   │ 1691             │ 0.406725   │ 0.410798    │
# │ 4   │ 2111             │ -0.37142   │ 0.0         │
# │ 5   │ 2510             │ 0.65698    │ 0.514341    │
# │ 6   │ 4357             │ -0.829946  │ -0.841527   │
# │ 7   │ 6074             │ -0.285131  │ 0.0         │
# │ 8   │ 6511             │ -0.396821  │ -0.250259   │
# │ 9   │ 6847             │ 1.69585    │ 1.53685     │
# │ 10  │ 7913             │ -0.0285674 │ 0.0         │
# │ 11  │ 8965             │ -1.92062   │ -1.7516     │
# │ 12  │ 9207             │ -0.129598  │ 0.0         │
# │ 13  │ 9563             │ 0.342082   │ 0.312404    │
# │ 14  │ 12055            │ -0.648381  │ 0.0         │
# │ 15  │ 12735            │ 0.394175   │ 0.396948    │
# │ 16  │ 13625            │ 0.777291   │ 0.716424    │
# │ 17  │ 13932            │ -0.324708  │ -0.355434   │
# │ 18  │ 14835            │ -0.355667  │ 0.0         │
# │ 19  │ 15173            │ -0.211494  │ 0.0         │
# │ 20  │ 15537            │ 0.423647   │ 0.486572    │
# │ 21  │ 15826            │ 0.206211   │ 0.227493    │
# │ 22  │ 16270            │ -0.25684   │ 0.0         │
# │ 23  │ 16962            │ -0.614427  │ -0.637859   │
# Total iteration number was 328
# Total time was 74.22974896430969
# compare_model = 24×3 DataFrame
# │ Row │ correct_position │ true_β     │ estimated_β │
# │     │ Int64            │ Float64    │ Float64     │
# ├─────┼──────────────────┼────────────┼─────────────┤
# │ 1   │ 600              │ 0.89884    │ 0.0         │
# │ 2   │ 2147             │ 0.322312   │ 0.0         │
# │ 3   │ 3112             │ 2.24856    │ 0.0         │
# │ 4   │ 3578             │ -0.99944   │ 0.0         │
# │ 5   │ 4766             │ -0.623972  │ 0.0         │
# │ 6   │ 5308             │ 0.55221    │ 0.0         │
# │ 7   │ 5360             │ 0.0544819  │ 0.0         │
# │ 8   │ 6016             │ -1.51286   │ 0.0         │
# │ 9   │ 7074             │ 1.18949    │ 0.0         │
# │ 10  │ 8051             │ 0.15005    │ 0.0         │
# │ 11  │ 8388             │ -0.853524  │ 0.0         │
# │ 12  │ 8910             │ -1.01639   │ 0.0         │
# │ 13  │ 10637            │ -0.0295577 │ 0.0         │
# │ 14  │ 11322            │ 0.337123   │ 0.0         │
# │ 15  │ 11955            │ 0.311612   │ 0.0         │
# │ 16  │ 12018            │ -0.31561   │ 0.0         │
# │ 17  │ 12814            │ -0.172715  │ 0.0         │
# │ 18  │ 14378            │ -2.44428   │ -1.52366    │
# │ 19  │ 15366            │ 0.871102   │ 0.0         │
# │ 20  │ 17577            │ -0.0396521 │ 0.0         │
# │ 21  │ 17959            │ -1.11007   │ 0.0         │
# │ 22  │ 17978            │ -0.137276  │ 0.0         │
# │ 23  │ 18022            │ 2.07491    │ 0.0         │
# │ 24  │ 18311            │ -1.24929   │ 0.0         │
# Total iteration number was 277
# Total time was 77.65311312675476
# compare_model = 25×3 DataFrame
# │ Row │ correct_position │ true_β     │ estimated_β │
# │     │ Int64            │ Float64    │ Float64     │
# ├─────┼──────────────────┼────────────┼─────────────┤
# │ 1   │ 546              │ -0.391323  │ 0.0         │
# │ 2   │ 985              │ 1.00974    │ 0.0         │
# │ 3   │ 2975             │ -0.0642956 │ 0.0         │
# │ 4   │ 3424             │ 1.10941    │ 0.0         │
# │ 5   │ 3935             │ 0.619359   │ 0.0         │
# │ 6   │ 4657             │ -0.626384  │ 0.0         │
# │ 7   │ 5925             │ 0.847415   │ 0.0         │
# │ 8   │ 7520             │ 0.450929   │ 0.0         │
# │ 9   │ 8168             │ -0.104605  │ 0.0         │
# │ 10  │ 9713             │ -0.158334  │ 0.0         │
# │ 11  │ 10111            │ -2.26054   │ -1.19919    │
# │ 12  │ 10322            │ 0.114115   │ 0.0         │
# │ 13  │ 11700            │ -0.84514   │ 0.0         │
# │ 14  │ 12170            │ 1.16019    │ 0.0         │
# │ 15  │ 12645            │ -0.476464  │ 0.0         │
# │ 16  │ 14694            │ 1.15083    │ 0.0         │
# │ 17  │ 15345            │ 0.189165   │ 0.0         │
# │ 18  │ 15568            │ -0.232896  │ 0.0         │
# │ 19  │ 16327            │ 0.0474921  │ 0.0         │
# │ 20  │ 17590            │ 1.40665    │ 0.0         │
# │ 21  │ 17652            │ -0.639601  │ 0.0         │
# │ 22  │ 19137            │ 1.99307    │ 0.0         │
# │ 23  │ 19182            │ -0.0985312 │ 0.0         │
# │ 24  │ 19685            │ 0.778512   │ 0.0         │
# │ 25  │ 19731            │ -0.817664  │ 0.0         │
# Total iteration number was 197
# Total time was 52.03258299827576
# compare_model = 26×3 DataFrame
# │ Row │ correct_position │ true_β     │ estimated_β │
# │     │ Int64            │ Float64    │ Float64     │
# ├─────┼──────────────────┼────────────┼─────────────┤
# │ 1   │ 395              │ 0.378782   │ 0.0         │
# │ 2   │ 459              │ 0.733837   │ 0.0         │
# │ 3   │ 2260             │ 0.873153   │ 0.0         │
# │ 4   │ 4367             │ -0.405392  │ 0.0         │
# │ 5   │ 4636             │ 0.297211   │ 0.0         │
# │ 6   │ 4812             │ 0.273293   │ 0.0         │
# │ 7   │ 6588             │ 2.34086    │ 1.19985     │
# │ 8   │ 7908             │ 0.216333   │ 0.0         │
# │ 9   │ 8037             │ 0.691679   │ 0.0         │
# │ 10  │ 8087             │ -0.11588   │ 0.0         │
# │ 11  │ 10138            │ 0.600582   │ 0.0         │
# │ 12  │ 10635            │ 0.421803   │ 0.0         │
# │ 13  │ 10687            │ -0.280005  │ 0.0         │
# │ 14  │ 10782            │ 0.447587   │ 0.0         │
# │ 15  │ 12218            │ 0.700309   │ 0.0         │
# │ 16  │ 12401            │ 0.86653    │ 0.0         │
# │ 17  │ 13282            │ -0.794662  │ 0.0         │
# │ 18  │ 14267            │ -0.327104  │ 0.0         │
# │ 19  │ 14532            │ 0.58587    │ 0.0         │
# │ 20  │ 14719            │ -0.018963  │ 0.0         │
# │ 21  │ 15213            │ -0.637488  │ 0.0         │
# │ 22  │ 15990            │ -0.993433  │ 0.0         │
# │ 23  │ 17159            │ 1.27428    │ 0.584016    │
# │ 24  │ 17253            │ -0.143982  │ 0.0         │
# │ 25  │ 17676            │ -0.553382  │ 0.0         │
# │ 26  │ 18233            │ -0.0984134 │ 0.0         │
# Total iteration number was 403
# Total time was 100.75294303894043
# compare_model = 27×3 DataFrame
# │ Row │ correct_position │ true_β     │ estimated_β │
# │     │ Int64            │ Float64    │ Float64     │
# ├─────┼──────────────────┼────────────┼─────────────┤
# │ 1   │ 220              │ 0.732156   │ 0.0         │
# │ 2   │ 2466             │ -0.182739  │ 0.0         │
# │ 3   │ 3129             │ 0.687665   │ 0.0         │
# │ 4   │ 3449             │ 0.541315   │ 0.0         │
# │ 5   │ 4038             │ -0.38007   │ 0.0         │
# │ 6   │ 5664             │ -0.732273  │ 0.0         │
# │ 7   │ 6428             │ 0.79682    │ 0.0         │
# │ 8   │ 7142             │ -0.75626   │ 0.0         │
# │ 9   │ 7315             │ -0.251855  │ 0.0         │
# │ 10  │ 8702             │ 1.08156    │ 0.0         │
# │ 11  │ 10722            │ 0.860199   │ 0.0         │
# │ 12  │ 11499            │ -1.02954   │ 0.0         │
# │ 13  │ 11715            │ 0.818918   │ 0.0         │
# │ 14  │ 12221            │ -0.320464  │ 0.0         │
# │ 15  │ 14329            │ 0.264479   │ 0.0         │
# │ 16  │ 14754            │ -0.875071  │ 0.0         │
# │ 17  │ 14939            │ 0.30624    │ 0.0         │
# │ 18  │ 15127            │ 1.0603     │ 0.0         │
# │ 19  │ 15190            │ -0.0956409 │ 0.0         │
# │ 20  │ 15255            │ -0.281615  │ 0.0         │
# │ 21  │ 15327            │ -0.160572  │ 0.0         │
# │ 22  │ 17028            │ -1.01361   │ 0.0         │
# │ 23  │ 18083            │ -1.10443   │ 0.0         │
# │ 24  │ 18296            │ 1.57861    │ 0.439608    │
# │ 25  │ 19292            │ -1.17292   │ 0.0         │
# │ 26  │ 19486            │ 0.0775424  │ 0.0         │
# │ 27  │ 19543            │ -2.52885   │ -1.25442    │
# Total iteration number was 181
# Total time was 47.991442918777466
# compare_model = 28×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 404              │ 0.0106238 │ 0.0         │
# │ 2   │ 1122             │ 0.990652  │ 0.0         │
# │ 3   │ 2175             │ 0.360463  │ 0.0         │
# │ 4   │ 3311             │ 2.17922   │ 0.0         │
# │ 5   │ 3804             │ -1.1686   │ 0.0         │
# │ 6   │ 4761             │ 0.84741   │ 0.0         │
# │ 7   │ 5964             │ -0.568735 │ 0.0         │
# │ 8   │ 6162             │ -0.355551 │ 0.0         │
# │ 9   │ 6228             │ -0.524456 │ 0.0         │
# │ 10  │ 7224             │ -0.140118 │ 0.0         │
# │ 11  │ 8410             │ -0.707435 │ 0.0         │
# │ 12  │ 10333            │ 0.405136  │ 0.0         │
# │ 13  │ 10564            │ -0.102203 │ 0.0         │
# │ 14  │ 11277            │ 0.689591  │ 0.0         │
# │ 15  │ 11414            │ 1.6845    │ 0.0         │
# │ 16  │ 12075            │ 2.35609   │ 0.0         │
# │ 17  │ 14511            │ 2.62114   │ 0.0         │
# │ 18  │ 14604            │ 1.46078   │ 0.0         │
# │ 19  │ 14971            │ 0.722655  │ 0.0         │
# │ 20  │ 15112            │ 1.75866   │ 0.0         │
# │ 21  │ 16279            │ -2.04508  │ 0.0         │
# │ 22  │ 16523            │ 0.595937  │ 0.0         │
# │ 23  │ 16833            │ -0.358908 │ 0.0         │
# │ 24  │ 17127            │ 0.151411  │ 0.0         │
# │ 25  │ 17350            │ 1.08605   │ 0.0         │
# │ 26  │ 17401            │ 0.992419  │ 0.0         │
# │ 27  │ 18605            │ -0.4648   │ -1.34373    │
# │ 28  │ 19587            │ 1.00197   │ 0.0         │
# Total iteration number was 398
# Total time was 96.28231501579285
# compare_model = 29×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 563              │ -0.759976 │ 0.0         │
# │ 2   │ 1155             │ -0.371046 │ 0.0         │
# │ 3   │ 1636             │ -1.1153   │ -0.634491   │
# │ 4   │ 1921             │ 1.10786   │ 0.679411    │
# │ 5   │ 1934             │ 0.264645  │ 0.0         │
# │ 6   │ 3291             │ 1.12966   │ 0.53684     │
# │ 7   │ 5139             │ -0.529844 │ 0.0         │
# │ 8   │ 6539             │ 0.0467999 │ 0.0         │
# │ 9   │ 7033             │ -0.124931 │ 0.0         │
# │ 10  │ 7954             │ -0.998094 │ -0.438933   │
# │ 11  │ 8852             │ -0.41134  │ 0.0         │
# │ 12  │ 9396             │ 0.126207  │ 0.0         │
# │ 13  │ 9595             │ 0.0154544 │ 0.0         │
# │ 14  │ 10080            │ -0.822443 │ 0.0         │
# │ 15  │ 10321            │ 1.36911   │ 0.818791    │
# │ 16  │ 10857            │ 0.273076  │ 0.0         │
# │ 17  │ 11848            │ 1.43309   │ 0.641951    │
# │ 18  │ 14678            │ 0.844604  │ 0.68384     │
# │ 19  │ 15046            │ 1.37239   │ 0.630364    │
# │ 20  │ 15084            │ -0.408247 │ 0.0         │
# │ 21  │ 15284            │ 1.29284   │ 0.752439    │
# │ 22  │ 15418            │ 0.130918  │ 0.0         │
# │ 23  │ 16135            │ 0.990663  │ 0.256869    │
# │ 24  │ 16142            │ -0.28633  │ 0.0         │
# │ 25  │ 16986            │ 0.957744  │ 0.548027    │
# │ 26  │ 17000            │ 0.284806  │ 0.0         │
# │ 27  │ 17559            │ -0.345875 │ 0.0         │
# │ 28  │ 18098            │ 1.06759   │ 0.466331    │
# │ 29  │ 18932            │ 0.504486  │ 0.0         │
# Total iteration number was 474
# Total time was 115.56639099121094
# compare_model = 30×3 DataFrame
# │ Row │ correct_position │ true_β     │ estimated_β │
# │     │ Int64            │ Float64    │ Float64     │
# ├─────┼──────────────────┼────────────┼─────────────┤
# │ 1   │ 297              │ 1.01203    │ 0.0         │
# │ 2   │ 404              │ 0.352998   │ 0.0         │
# │ 3   │ 832              │ 0.276357   │ 0.0         │
# │ 4   │ 3568             │ -1.35031   │ 0.0         │
# │ 5   │ 4878             │ -1.02926   │ 0.0         │
# │ 6   │ 5481             │ 0.632188   │ 0.0         │
# │ 7   │ 5666             │ 0.0603708  │ 0.0         │
# │ 8   │ 5806             │ -0.148095  │ 0.0         │
# │ 9   │ 6441             │ -0.448761  │ 0.0         │
# │ 10  │ 6737             │ -0.0325784 │ 0.0         │
# │ 11  │ 7796             │ -0.310086  │ 0.0         │
# │ 12  │ 8181             │ 2.39744    │ 0.0         │
# │ 13  │ 8389             │ 1.87071    │ 0.0         │
# │ 14  │ 8786             │ 1.03604    │ 0.0         │
# │ 15  │ 9032             │ -2.22996   │ 0.0         │
# │ 16  │ 9512             │ -0.300212  │ 0.0         │
# │ 17  │ 10242            │ 0.501159   │ 0.0         │
# │ 18  │ 12341            │ 1.33592    │ 0.0         │
# │ 19  │ 12363            │ 1.12685    │ 0.0         │
# │ 20  │ 13593            │ 0.711016   │ 0.0         │
# │ 21  │ 15037            │ 1.77731    │ 0.0         │
# │ 22  │ 15923            │ -0.210841  │ 0.0         │
# │ 23  │ 17475            │ -1.0036    │ 0.0         │
# │ 24  │ 17656            │ -1.06366   │ -0.757287   │
# │ 25  │ 17839            │ -0.31111   │ 0.0         │
# │ 26  │ 18315            │ -1.21707   │ 0.0         │
# │ 27  │ 19368            │ -0.406157  │ 0.0         │
# │ 28  │ 19490            │ 2.2662     │ 0.0         │
# │ 29  │ 19635            │ -0.600862  │ 0.0         │
# │ 30  │ 19895            │ 1.6548     │ 0.0         │
# Total iteration number was 229
# Total time was 61.74346995353699

# %% [markdown]
# # Comparison with LASSO

# %%
using Revise
using GLMNet #julia wrapper for GLMNet package in R, which calls fortran
using GLM
using MendelIHT
using SnpArrays
using DataFrames
using Distributions
using StatsFuns: logistic
using Random
using LinearAlgebra

# %%
Threads.nthreads() #verify multiple threads are enabled
# Out:
# 8

# %%
function run_iht_lasso_poisson(n :: Int64, p :: Int64)
    #set random seed
    Random.seed!(1111)

    #define maf and true model size
    bernoulli_rates = 0.5rand(p)
    k = 10

    #construct snpmatrix, covariate files, and true model b
    x = simulate_random_snparray(n, p, bernoulli_rates)
    xbm = SnpBitMatrix{Float64}(x, model=ADDITIVE_MODEL, center=true, scale=true); 
    z           = ones(n, 1)                   # non-genetic covariates, just the intercept
    true_b      = zeros(p)                     # model vector
    true_b[1:k] = randn(k)                     # Initialize k non-zero entries in the true model
    shuffle!(true_b)                           # Shuffle the entries
    correct_position = findall(x -> x != 0, true_b) # keep track of what the true entries are

    # Simulate poisson data
    y_temp = xbm * true_b
    λ = exp.(y_temp) #inverse log link
    y = [rand(Poisson(x)) for x in λ]
    y = Float64.(y)

    #compute poisson IHT result
    path = collect(1:15)
    num_folds = 5
    folds = rand(1:num_folds, size(x, 1))
    k_est_iht = cv_iht(x, z, y, 1, path, folds, num_folds, use_maf=false, glm="poisson", debias=false)
    iht_result = L0_poisson_reg(x, z, y, 1, k_est_iht, glm = "poisson", debias=false, convg=false, show_info=false, true_beta=true_b)

    #compute poisson lasso result
    x_float = [convert(Matrix{Float64}, x, center=true, scale=true) z]
    cv = glmnetcv(x_float, y, Poisson(), dfmax=15, nfolds=5, folds=folds)
    best = argmin(cv.meanloss)
    lasso_result = cv.path.betas[:, best]
    k_est_lasso = length(findall(!iszero, lasso_result))

    #check result
    IHT_model = iht_result.beta[correct_position]
    lasso_model = lasso_result[correct_position]
    true_model = true_b[correct_position]
    compare_model = DataFrame(
        correct_position = correct_position, 
        true_β           = true_model, 
        iht_β            = IHT_model,
        lasso_β          = lasso_model)
    @show compare_model

    #compute summary statistics
    lasso_num_correct_predictors = length(findall(!iszero, lasso_model))
    lasso_false_positives = k_est_lasso - lasso_num_correct_predictors
    lasso_false_negatives = k - lasso_num_correct_predictors
    iht_num_correct_predictors = length(findall(!iszero, IHT_model))
    iht_false_positives = k_est_iht - iht_num_correct_predictors
    iht_false_negatives = k - iht_num_correct_predictors
    println("IHT:   cv found " * "$k_est_iht predictors, " * "$iht_false_positives false positives " * "and $iht_false_negatives false negatives")
    println("lasso: cv found " * "$k_est_lasso predictors, " * "$lasso_false_positives false positives and " * "$lasso_false_negatives false negatives \n\n")

    return lasso_false_positives, lasso_false_negatives, iht_false_positives, iht_false_negatives
end
# Out:
# run_iht_lasso_poisson (generic function with 1 method)

# %%
function run_iht_lasso_poisson()
    lasso_total_found = 0
    lasso_false_positives = 0
    lasso_false_negatives = 0
    iht_total_found = 0
    iht_false_positives = 0
    iht_false_negatives = 0
    
    iter = 50
    for i = 1:iter
        n = rand(100:1000) 
        p = rand(1:10)n
        println("Running the $i th model where " * "n, p = " * string(n) * ", " * string(p))
        ltf, lfp, lfn, itf, ifp, ifn = iht_lasso_poisson(n, p)

        lasso_total_found += ltf
        lasso_false_positives += lfp
        lasso_false_negatives += lfn
        iht_total_found += itf
        iht_false_positives += ifp
        iht_false_negatives += ifn
    end
    println("IHT  : Found $iht_total_found " * "correct predictors, out of " * string(10iter))
    println("IHT  : False positives = $iht_false_positives")
    println("IHT  : False negatives = $iht_false_negatives")   
    println("Lasso: Found $lasso_total_found " * "correct predictors, out of " * string(10iter))
    println("Lasso: False positives = $lasso_false_positives")
    println("Lasso: False negatives = $lasso_false_negatives")
end
# Out:
# run (generic function with 1 method)

# %%
Random.seed!(123)
run_iht_lasso_poisson()
# Out:
# Running the 1 th model where n, p = 360, 1080
# compare_model = 10×4 DataFrame
# │ Row │ correct_position │ true_β    │ iht_β   │ lasso_β   │
# │     │ Int64            │ Float64   │ Float64 │ Float64   │
# ├─────┼──────────────────┼───────────┼─────────┼───────────┤
# │ 1   │ 58               │ -0.420191 │ 0.0     │ 0.0       │
# │ 2   │ 88               │ 1.57568   │ 0.0     │ 0.434664  │
# │ 3   │ 127              │ 1.13548   │ 0.0     │ 0.0212406 │
# │ 4   │ 220              │ 1.92294   │ 0.0     │ 0.0       │
# │ 5   │ 232              │ -0.411312 │ 0.0     │ 0.0       │
# │ 6   │ 268              │ 0.0502952 │ 0.0     │ 0.0       │
# │ 7   │ 341              │ 2.22311   │ 0.0     │ 0.49858   │
# │ 8   │ 472              │ 0.0777493 │ 0.0     │ 0.0       │
# │ 9   │ 551              │ -0.172964 │ 0.0     │ 0.0       │
# │ 10  │ 556              │ 2.87123   │ 0.0     │ 0.621692  │
# IHT:   cv found 1 predictors, 1 false positives and 10 false negatives
# lasso: cv found 17 predictors, 13 false positives and 6 false negatives
#
#
# Running the 2 th model where n, p = 276, 2760
# compare_model = 10×4 DataFrame
# │ Row │ correct_position │ true_β     │ iht_β   │ lasso_β  │
# │     │ Int64            │ Float64    │ Float64 │ Float64  │
# ├─────┼──────────────────┼────────────┼─────────┼──────────┤
# │ 1   │ 37               │ -0.560215  │ 0.0     │ 0.0      │
# │ 2   │ 255              │ 0.569188   │ 0.0     │ 0.0      │
# │ 3   │ 785              │ -0.560505  │ 0.0     │ 0.0      │
# │ 4   │ 938              │ 0.115275   │ 0.0     │ 0.0      │
# │ 5   │ 1424             │ 0.00848683 │ 0.0     │ 0.0      │
# │ 6   │ 1464             │ 1.87342    │ 0.0     │ 0.493909 │
# │ 7   │ 1869             │ 0.383772   │ 0.0     │ 0.0      │
# │ 8   │ 2142             │ 0.630724   │ 0.0     │ 0.0      │
# │ 9   │ 2344             │ 0.185526   │ 0.0     │ 0.0      │
# │ 10  │ 2527             │ 1.15711    │ 0.0     │ 0.55916  │
# IHT:   cv found 12 predictors, 12 false positives and 10 false negatives
# lasso: cv found 6 predictors, 4 false positives and 8 false negatives
#
#
# Running the 3 th model where n, p = 881, 1762
# compare_model = 10×4 DataFrame
# │ Row │ correct_position │ true_β    │ iht_β     │ lasso_β    │
# │     │ Int64            │ Float64   │ Float64   │ Float64    │
# ├─────┼──────────────────┼───────────┼───────────┼────────────┤
# │ 1   │ 217              │ -0.557778 │ -0.579735 │ -0.0379039 │
# │ 2   │ 477              │ -0.100879 │ 0.0       │ 0.0        │
# │ 3   │ 785              │ 0.0482008 │ 0.0       │ 0.0        │
# │ 4   │ 821              │ -0.489098 │ -0.644248 │ 0.0        │
# │ 5   │ 1086             │ 1.50267   │ 1.48306   │ 0.839718   │
# │ 6   │ 1326             │ 0.740253  │ 0.760976  │ 0.12224    │
# │ 7   │ 1408             │ -0.553545 │ 0.0       │ 0.0        │
# │ 8   │ 1529             │ 0.587932  │ 0.630479  │ 0.0        │
# │ 9   │ 1565             │ 0.997683  │ 0.965827  │ 0.56243    │
# │ 10  │ 1701             │ -1.01839  │ -1.12305  │ -0.402204  │
# IHT:   cv found 8 predictors, 1 false positives and 3 false negatives
# lasso: cv found 17 predictors, 12 false positives and 5 false negatives
#
#
# Running the 4 th model where n, p = 488, 2928
# compare_model = 10×4 DataFrame
# │ Row │ correct_position │ true_β     │ iht_β     │ lasso_β   │
# │     │ Int64            │ Float64    │ Float64   │ Float64   │
# ├─────┼──────────────────┼────────────┼───────────┼───────────┤
# │ 1   │ 681              │ 0.22368    │ 0.261016  │ 0.0       │
# │ 2   │ 1120             │ 0.791749   │ 0.776649  │ 0.489698  │
# │ 3   │ 1173             │ -0.544308  │ -0.485949 │ 0.0       │
# │ 4   │ 1501             │ 0.43082    │ 0.409151  │ 0.0543876 │
# │ 5   │ 1551             │ 0.138027   │ 0.0       │ 0.0       │
# │ 6   │ 1604             │ 0.490931   │ 0.486585  │ 0.274499  │
# │ 7   │ 1611             │ -1.61818   │ -1.63599  │ -0.637803 │
# │ 8   │ 2057             │ -0.0750695 │ 0.0       │ 0.0       │
# │ 9   │ 2712             │ -0.915359  │ -0.95056  │ -0.334871 │
# │ 10  │ 2775             │ -0.937709  │ -0.923012 │ -0.322347 │
# IHT:   cv found 9 predictors, 1 false positives and 2 false negatives
# lasso: cv found 16 predictors, 10 false positives and 4 false negatives
#
#
# Running the 5 th model where n, p = 706, 2824
# compare_model = 10×4 DataFrame
# │ Row │ correct_position │ true_β    │ iht_β    │ lasso_β  │
# │     │ Int64            │ Float64   │ Float64  │ Float64  │
# ├─────┼──────────────────┼───────────┼──────────┼──────────┤
# │ 1   │ 649              │ 0.684915  │ 0.0      │ 0.0      │
# │ 2   │ 697              │ -0.350032 │ 0.0      │ 0.0      │
# │ 3   │ 1240             │ 1.12972   │ 1.06155  │ 0.678303 │
# │ 4   │ 1420             │ -0.99747  │ 0.0      │ 0.0      │
# │ 5   │ 1429             │ 0.769791  │ 0.0      │ 0.422276 │
# │ 6   │ 1621             │ 1.12556   │ 0.0      │ 0.747318 │
# │ 7   │ 1708             │ -1.57055  │ -1.76379 │ 0.0      │
# │ 8   │ 1730             │ -0.70236  │ 0.0      │ 0.0      │
# │ 9   │ 1921             │ -0.159916 │ 0.0      │ 0.0      │
# │ 10  │ 1999             │ 0.181859  │ 0.0      │ 0.0      │
# IHT:   cv found 3 predictors, 1 false positives and 8 false negatives
# lasso: cv found 16 predictors, 13 false positives and 7 false negatives
#
#
# Running the 6 th model where n, p = 731, 6579
# compare_model = 10×4 DataFrame
# │ Row │ correct_position │ true_β    │ iht_β     │ lasso_β    │
# │     │ Int64            │ Float64   │ Float64   │ Float64    │
# ├─────┼──────────────────┼───────────┼───────────┼────────────┤
# │ 1   │ 219              │ -0.205163 │ -0.20723  │ 0.0        │
# │ 2   │ 374              │ -1.09028  │ -1.08082  │ -0.0197324 │
# │ 3   │ 582              │ 0.573968  │ 0.577337  │ 0.0485374  │
# │ 4   │ 1099             │ 0.872475  │ 0.892078  │ 0.263148   │
# │ 5   │ 2216             │ -1.20246  │ -1.15335  │ -0.178333  │
# │ 6   │ 2320             │ -0.611188 │ -0.592002 │ 0.0        │
# │ 7   │ 3166             │ -0.750053 │ -0.739102 │ -0.0160305 │
# │ 8   │ 3186             │ -0.265196 │ -0.247487 │ 0.0        │
# │ 9   │ 4711             │ 0.479482  │ 0.499289  │ 0.0738037  │
# │ 10  │ 4805             │ -0.890002 │ -0.900999 │ -0.019851  │
# IHT:   cv found 14 predictors, 4 false positives and 0 false negatives
# lasso: cv found 16 predictors, 9 false positives and 3 false negatives
#
#
# Running the 7 th model where n, p = 632, 3160
# compare_model = 10×4 DataFrame
# │ Row │ correct_position │ true_β    │ iht_β     │ lasso_β   │
# │     │ Int64            │ Float64   │ Float64   │ Float64   │
# ├─────┼──────────────────┼───────────┼───────────┼───────────┤
# │ 1   │ 114              │ -0.778326 │ -0.765866 │ -0.541594 │
# │ 2   │ 1544             │ -0.216119 │ -0.219446 │ -0.034272 │
# │ 3   │ 2101             │ 0.530392  │ 0.541557  │ 0.406321  │
# │ 4   │ 2118             │ 0.666389  │ 0.645169  │ 0.423243  │
# │ 5   │ 2571             │ -0.408685 │ -0.333228 │ -0.144183 │
# │ 6   │ 2602             │ 0.413033  │ 0.40806   │ 0.220414  │
# │ 7   │ 2678             │ 0.65461   │ 0.648434  │ 0.502048  │
# │ 8   │ 2913             │ -0.652285 │ -0.578888 │ -0.365367 │
# │ 9   │ 3027             │ -0.409433 │ -0.469273 │ -0.255224 │
# │ 10  │ 3113             │ -0.337991 │ -0.30837  │ -0.188947 │
# IHT:   cv found 15 predictors, 5 false positives and 0 false negatives
# lasso: cv found 17 predictors, 7 false positives and 0 false negatives
#
#
# Running the 8 th model where n, p = 957, 8613
# compare_model = 10×4 DataFrame
# │ Row │ correct_position │ true_β    │ iht_β     │ lasso_β    │
# │     │ Int64            │ Float64   │ Float64   │ Float64    │
# ├─────┼──────────────────┼───────────┼───────────┼────────────┤
# │ 1   │ 1099             │ 1.01676   │ 1.02602   │ 0.719592   │
# │ 2   │ 2695             │ -0.494367 │ -0.508135 │ -0.199753  │
# │ 3   │ 3406             │ 0.528398  │ 0.538576  │ 0.34245    │
# │ 4   │ 3529             │ -0.60128  │ -0.599395 │ -0.364541  │
# │ 5   │ 6255             │ 0.120246  │ 0.129216  │ 0.0        │
# │ 6   │ 6591             │ -0.605488 │ -0.626933 │ -0.126259  │
# │ 7   │ 7938             │ -0.261243 │ -0.261955 │ -0.002084  │
# │ 8   │ 8110             │ -0.750185 │ -0.721675 │ -0.331106  │
# │ 9   │ 8469             │ -1.19285  │ -1.16262  │ -0.177655  │
# │ 10  │ 8549             │ -0.448234 │ -0.431625 │ -0.0175592 │
# IHT:   cv found 11 predictors, 1 false positives and 0 false negatives
# lasso: cv found 16 predictors, 7 false positives and 1 false negatives
#
#
# Running the 9 th model where n, p = 968, 968
# compare_model = 10×4 DataFrame
# │ Row │ correct_position │ true_β     │ iht_β     │ lasso_β   │
# │     │ Int64            │ Float64    │ Float64   │ Float64   │
# ├─────┼──────────────────┼────────────┼───────────┼───────────┤
# │ 1   │ 15               │ 1.77001    │ 1.75788   │ 1.39162   │
# │ 2   │ 32               │ -0.233966  │ -0.189386 │ 0.0       │
# │ 3   │ 125              │ 0.780281   │ 0.770339  │ 0.623439  │
# │ 4   │ 203              │ -0.875781  │ -0.854647 │ -0.351129 │
# │ 5   │ 216              │ -1.4475    │ -1.62476  │ 0.0       │
# │ 6   │ 386              │ -0.667675  │ -0.625772 │ -0.17131  │
# │ 7   │ 542              │ -0.36381   │ 0.0       │ 0.0       │
# │ 8   │ 748              │ -1.23415   │ -1.20212  │ -0.61128  │
# │ 9   │ 812              │ -0.0779829 │ 0.0       │ 0.0       │
# │ 10  │ 917              │ 0.124807   │ 0.134733  │ 0.0       │
# IHT:   cv found 12 predictors, 4 false positives and 2 false negatives
# lasso: cv found 16 predictors, 11 false positives and 5 false negatives
#
#
# Running the 10 th model where n, p = 874, 6118
# compare_model = 10×4 DataFrame
# │ Row │ correct_position │ true_β    │ iht_β    │ lasso_β    │
# │     │ Int64            │ Float64   │ Float64  │ Float64    │
# ├─────┼──────────────────┼───────────┼──────────┼────────────┤
# │ 1   │ 284              │ 0.593482  │ 0.0      │ 0.0        │
# │ 2   │ 1577             │ -1.55641  │ -1.46442 │ -0.0358452 │
# │ 3   │ 1680             │ 1.51493   │ 1.30081  │ 0.820803   │
# │ 4   │ 1831             │ 0.273814  │ 0.0      │ 0.0        │
# │ 5   │ 2252             │ 0.309814  │ 0.0      │ 0.0        │
# │ 6   │ 2493             │ 0.353902  │ 0.0      │ 0.0        │
# │ 7   │ 2859             │ -0.573053 │ 0.0      │ 0.0        │
# │ 8   │ 3782             │ -1.06168  │ 0.0      │ 0.0        │
# │ 9   │ 5120             │ -1.52515  │ -1.31483 │ -0.0166858 │
# │ 10  │ 5140             │ 0.655857  │ 0.738601 │ 0.406318   │
# IHT:   cv found 6 predictors, 2 false positives and 6 false negatives
# lasso: cv found 17 predictors, 13 false positives and 6 false negatives
#
#
# Running the 11 th model where n, p = 816, 4080
# compare_model = 10×4 DataFrame
# │ Row │ correct_position │ true_β      │ iht_β     │ lasso_β     │
# │     │ Int64            │ Float64     │ Float64   │ Float64     │
# ├─────┼──────────────────┼─────────────┼───────────┼─────────────┤
# │ 1   │ 116              │ -0.00458719 │ 0.0       │ 0.0         │
# │ 2   │ 153              │ 1.0575      │ 1.04649   │ 0.884395    │
# │ 3   │ 494              │ 0.39498     │ 0.399054  │ 0.326196    │
# │ 4   │ 957              │ 0.0858082   │ 0.0787473 │ 0.0         │
# │ 5   │ 1161             │ 0.161705    │ 0.141317  │ 0.0         │
# │ 6   │ 1924             │ 0.734964    │ 0.731465  │ 0.474311    │
# │ 7   │ 2708             │ -0.620304   │ -0.599001 │ -0.333273   │
# │ 8   │ 3428             │ -1.71444    │ -2.15992  │ -0.15068    │
# │ 9   │ 3725             │ -1.53397    │ -1.41953  │ -0.624058   │
# │ 10  │ 3876             │ -0.20842    │ -0.220971 │ -0.00560428 │
# IHT:   cv found 15 predictors, 6 false positives and 1 false negatives
# lasso: cv found 17 predictors, 10 false positives and 3 false negatives
#
#
# Running the 12 th model where n, p = 859, 5154
# compare_model = 10×4 DataFrame
# │ Row │ correct_position │ true_β     │ iht_β   │ lasso_β  │
# │     │ Int64            │ Float64    │ Float64 │ Float64  │
# ├─────┼──────────────────┼────────────┼─────────┼──────────┤
# │ 1   │ 463              │ -1.92187   │ 0.0     │ 0.0      │
# │ 2   │ 578              │ -0.531141  │ 0.0     │ 0.0      │
# │ 3   │ 1967             │ -0.967628  │ 0.0     │ 0.0      │
# │ 4   │ 2851             │ -0.977989  │ 0.0     │ 0.0      │
# │ 5   │ 3209             │ 0.40231    │ 0.0     │ 0.0      │
# │ 6   │ 3500             │ 2.33015    │ 0.0     │ 0.469779 │
# │ 7   │ 3667             │ 1.55831    │ 2.31502 │ 0.576279 │
# │ 8   │ 3701             │ 1.18902    │ 0.0     │ 0.611006 │
# │ 9   │ 4618             │ -0.995377  │ 0.0     │ 0.0      │
# │ 10  │ 4972             │ -0.0282625 │ 0.0     │ 0.0      │
# IHT:   cv found 4 predictors, 3 false positives and 9 false negatives
# lasso: cv found 16 predictors, 13 false positives and 7 false negatives
#
#
# Running the 13 th model where n, p = 126, 1134
# compare_model = 10×4 DataFrame
# │ Row │ correct_position │ true_β    │ iht_β    │ lasso_β    │
# │     │ Int64            │ Float64   │ Float64  │ Float64    │
# ├─────┼──────────────────┼───────────┼──────────┼────────────┤
# │ 1   │ 165              │ -1.75312  │ 0.0      │ -0.0284686 │
# │ 2   │ 224              │ 0.398341  │ 0.0      │ 0.0        │
# │ 3   │ 304              │ -0.434734 │ 0.0      │ 0.0        │
# │ 4   │ 363              │ 1.26325   │ 1.58017  │ 0.249519   │
# │ 5   │ 441              │ -0.444977 │ 0.0      │ 0.0        │
# │ 6   │ 654              │ 1.83346   │ 1.17976  │ 0.0673856  │
# │ 7   │ 880              │ 0.305762  │ 0.0      │ 0.0        │
# │ 8   │ 999              │ 1.02547   │ 0.0      │ 0.0        │
# │ 9   │ 1081             │ 1.24524   │ 0.0      │ 0.0        │
# │ 10  │ 1103             │ -1.18185  │ -2.06718 │ 0.0        │
# IHT:   cv found 10 predictors, 7 false positives and 7 false negatives
# lasso: cv found 17 predictors, 14 false positives and 7 false negatives
#
#
# Running the 14 th model where n, p = 161, 966
# compare_model = 10×4 DataFrame
# │ Row │ correct_position │ true_β    │ iht_β    │ lasso_β    │
# │     │ Int64            │ Float64   │ Float64  │ Float64    │
# ├─────┼──────────────────┼───────────┼──────────┼────────────┤
# │ 1   │ 34               │ -0.292589 │ 0.0      │ 0.0        │
# │ 2   │ 79               │ 0.812658  │ 0.0      │ 0.171441   │
# │ 3   │ 145              │ -1.43433  │ -1.40516 │ -0.518322  │
# │ 4   │ 173              │ -0.251588 │ 0.0      │ 0.0        │
# │ 5   │ 176              │ 1.03735   │ 1.21932  │ 0.49323    │
# │ 6   │ 182              │ -1.09611  │ 0.0      │ -0.0918643 │
# │ 7   │ 230              │ -1.01581  │ 0.0      │ -0.0143846 │
# │ 8   │ 467              │ 0.319654  │ 0.0      │ 0.0        │
# │ 9   │ 595              │ -0.290443 │ 0.0      │ 0.0        │
# │ 10  │ 781              │ 0.169212  │ 0.0      │ 0.0        │
# IHT:   cv found 7 predictors, 5 false positives and 8 false negatives
# lasso: cv found 16 predictors, 11 false positives and 5 false negatives
#
#
# Running the 15 th model where n, p = 105, 945
# compare_model = 10×4 DataFrame
# │ Row │ correct_position │ true_β    │ iht_β    │ lasso_β   │
# │     │ Int64            │ Float64   │ Float64  │ Float64   │
# ├─────┼──────────────────┼───────────┼──────────┼───────────┤
# │ 1   │ 46               │ -1.25194  │ -0.97786 │ 0.0       │
# │ 2   │ 162              │ 0.559563  │ 0.0      │ 0.204291  │
# │ 3   │ 174              │ 1.22867   │ 1.19183  │ 0.929547  │
# │ 4   │ 252              │ 0.433     │ 0.0      │ 0.0       │
# │ 5   │ 473              │ 0.0154465 │ 0.0      │ 0.0       │
# │ 6   │ 494              │ -0.179489 │ 0.0      │ 0.0       │
# │ 7   │ 753              │ 0.112528  │ 0.0      │ 0.0       │
# │ 8   │ 811              │ -0.557847 │ 0.0      │ -0.135501 │
# │ 9   │ 812              │ -1.23478  │ -1.31185 │ 0.0       │
# │ 10  │ 820              │ -0.719194 │ 0.0      │ 0.0       │
# IHT:   cv found 8 predictors, 5 false positives and 7 false negatives
# lasso: cv found 16 predictors, 13 false positives and 7 false negatives
#
#
# Running the 16 th model where n, p = 386, 1158
# compare_model = 10×4 DataFrame
# │ Row │ correct_position │ true_β    │ iht_β   │ lasso_β  │
# │     │ Int64            │ Float64   │ Float64 │ Float64  │
# ├─────┼──────────────────┼───────────┼─────────┼──────────┤
# │ 1   │ 21               │ -0.613432 │ 0.0     │ 0.0      │
# │ 2   │ 66               │ 0.992505  │ 0.0     │ 0.0      │
# │ 3   │ 247              │ -1.62367  │ 0.0     │ 0.0      │
# │ 4   │ 292              │ 1.43943   │ 0.0     │ 0.0      │
# │ 5   │ 433              │ -0.54014  │ 0.0     │ 0.0      │
# │ 6   │ 438              │ -0.98856  │ 0.0     │ 0.0      │
# │ 7   │ 734              │ 2.39683   │ 0.0     │ 0.0      │
# │ 8   │ 822              │ 0.94575   │ 0.0     │ 0.0      │
# │ 9   │ 858              │ 2.5714    │ 0.0     │ 0.624229 │
# │ 10  │ 902              │ 1.46084   │ 0.0     │ 0.0      │
# IHT:   cv found 1 predictors, 1 false positives and 10 false negatives
# lasso: cv found 5 predictors, 4 false positives and 9 false negatives
#
#
# Running the 17 th model where n, p = 974, 6818
# compare_model = 10×4 DataFrame
# │ Row │ correct_position │ true_β     │ iht_β     │ lasso_β   │
# │     │ Int64            │ Float64    │ Float64   │ Float64   │
# ├─────┼──────────────────┼────────────┼───────────┼───────────┤
# │ 1   │ 1308             │ -0.886343  │ -0.854967 │ -0.440977 │
# │ 2   │ 1320             │ -0.0931211 │ 0.0       │ 0.0       │
# │ 3   │ 1381             │ -0.568421  │ -0.557841 │ -0.230847 │
# │ 4   │ 1516             │ 0.363551   │ 0.347051  │ 0.150235  │
# │ 5   │ 1878             │ -1.32963   │ -1.26382  │ -0.816365 │
# │ 6   │ 3393             │ -0.48081   │ -0.495744 │ -0.301613 │
# │ 7   │ 5193             │ -0.793765  │ -0.764328 │ -0.439915 │
# │ 8   │ 5275             │ 0.331257   │ 0.297281  │ 0.11943   │
# │ 9   │ 5472             │ 1.37981    │ 1.36969   │ 1.06889   │
# │ 10  │ 6494             │ 0.052361   │ 0.0       │ 0.0       │
# IHT:   cv found 12 predictors, 4 false positives and 2 false negatives
# lasso: cv found 16 predictors, 8 false positives and 2 false negatives
#
#
# Running the 18 th model where n, p = 447, 1788
# compare_model = 10×4 DataFrame
# │ Row │ correct_position │ true_β    │ iht_β    │ lasso_β      │
# │     │ Int64            │ Float64   │ Float64  │ Float64      │
# ├─────┼──────────────────┼───────────┼──────────┼──────────────┤
# │ 1   │ 118              │ -2.19438  │ -2.36139 │ -0.000143224 │
# │ 2   │ 330              │ 0.470617  │ 0.0      │ 0.422257     │
# │ 3   │ 598              │ 2.13569   │ 2.64898  │ 0.48253      │
# │ 4   │ 664              │ -0.483268 │ 0.0      │ 0.0          │
# │ 5   │ 809              │ -0.022095 │ 0.0      │ 0.0          │
# │ 6   │ 939              │ -0.636111 │ 0.0      │ 0.0          │
# │ 7   │ 1082             │ -0.113165 │ 0.0      │ 0.0          │
# │ 8   │ 1167             │ 1.74326   │ 1.81758  │ 0.40511      │
# │ 9   │ 1190             │ -1.00158  │ -1.1706  │ 0.0          │
# │ 10  │ 1312             │ 0.561314  │ 0.0      │ 0.0          │
# IHT:   cv found 4 predictors, 0 false positives and 6 false negatives
# lasso: cv found 16 predictors, 12 false positives and 6 false negatives
#
#
# Running the 19 th model where n, p = 250, 1250
# compare_model = 10×4 DataFrame
# │ Row │ correct_position │ true_β      │ iht_β   │ lasso_β  │
# │     │ Int64            │ Float64     │ Float64 │ Float64  │
# ├─────┼──────────────────┼─────────────┼─────────┼──────────┤
# │ 1   │ 26               │ 2.56267     │ 0.0     │ 0.0      │
# │ 2   │ 41               │ -0.933721   │ 0.0     │ 0.0      │
# │ 3   │ 167              │ 3.05914     │ 0.0     │ 0.621803 │
# │ 4   │ 500              │ 0.173744    │ 0.0     │ 0.0      │
# │ 5   │ 519              │ -1.08205    │ 0.0     │ 0.0      │
# │ 6   │ 568              │ -0.063975   │ 0.0     │ 0.0      │
# │ 7   │ 707              │ -0.00638469 │ 0.0     │ 0.0      │
# │ 8   │ 712              │ 1.8283      │ 0.0     │ 0.0      │
# │ 9   │ 717              │ -0.895808   │ 0.0     │ 0.0      │
# │ 10  │ 906              │ 0.217009    │ 0.0     │ 0.0      │
# IHT:   cv found 5 predictors, 5 false positives and 10 false negatives
# lasso: cv found 5 predictors, 4 false positives and 9 false negatives
#
#
# Running the 20 th model where n, p = 151, 1359
# compare_model = 10×4 DataFrame
# │ Row │ correct_position │ true_β     │ iht_β    │ lasso_β    │
# │     │ Int64            │ Float64    │ Float64  │ Float64    │
# ├─────┼──────────────────┼────────────┼──────────┼────────────┤
# │ 1   │ 153              │ -2.52644   │ -2.23822 │ -0.0832764 │
# │ 2   │ 182              │ 0.834641   │ 0.0      │ 0.0        │
# │ 3   │ 326              │ -0.0703586 │ 0.0      │ 0.0        │
# │ 4   │ 400              │ -0.829611  │ 0.0      │ 0.0        │
# │ 5   │ 410              │ 1.47648    │ 0.786117 │ 0.0        │
# │ 6   │ 769              │ 1.22437    │ 0.0      │ 0.0        │
# │ 7   │ 1095             │ 0.794      │ 0.0      │ 0.047358   │
# │ 8   │ 1161             │ -1.09184   │ 0.0      │ 0.0        │
# │ 9   │ 1200             │ 0.707841   │ 0.0      │ 0.0        │
# │ 10  │ 1247             │ -3.12959   │ -2.28504 │ 0.0        │
# IHT:   cv found 12 predictors, 9 false positives and 7 false negatives
# lasso: cv found 10 predictors, 8 false positives and 8 false negatives
#
#
# Running the 21 th model where n, p = 398, 796
# compare_model = 10×4 DataFrame
# │ Row │ correct_position │ true_β     │ iht_β     │ lasso_β   │
# │     │ Int64            │ Float64    │ Float64   │ Float64   │
# ├─────┼──────────────────┼────────────┼───────────┼───────────┤
# │ 1   │ 80               │ 1.05468    │ 1.08922   │ 0.79939   │
# │ 2   │ 101              │ 0.995611   │ 0.992722  │ 0.6214    │
# │ 3   │ 178              │ -2.22521   │ -2.16345  │ -0.527674 │
# │ 4   │ 209              │ 0.485483   │ 0.453046  │ 0.0310574 │
# │ 5   │ 297              │ 0.302171   │ 0.274338  │ 0.0733126 │
# │ 6   │ 385              │ 0.072449   │ 0.0871755 │ 0.0       │
# │ 7   │ 439              │ -0.0708416 │ 0.0       │ 0.0       │
# │ 8   │ 484              │ -0.789997  │ -0.790011 │ -0.14272  │
# │ 9   │ 601              │ 0.391105   │ 0.400376  │ 0.353543  │
# │ 10  │ 717              │ 0.383099   │ 0.36819   │ 0.138311  │
# IHT:   cv found 12 predictors, 3 false positives and 1 false negatives
# lasso: cv found 18 predictors, 10 false positives and 2 false negatives
#
#
# Running the 22 th model where n, p = 186, 1860
# compare_model = 10×4 DataFrame
# │ Row │ correct_position │ true_β     │ iht_β   │ lasso_β  │
# │     │ Int64            │ Float64    │ Float64 │ Float64  │
# ├─────┼──────────────────┼────────────┼─────────┼──────────┤
# │ 1   │ 178              │ 0.0148795  │ 0.0     │ 0.0      │
# │ 2   │ 641              │ 1.27642    │ 0.0     │ 0.449098 │
# │ 3   │ 1005             │ -0.491142  │ 0.0     │ 0.0      │
# │ 4   │ 1086             │ 0.294499   │ 0.0     │ 0.0      │
# │ 5   │ 1344             │ 0.247435   │ 0.0     │ 0.0      │
# │ 6   │ 1477             │ 0.130654   │ 0.0     │ 0.0      │
# │ 7   │ 1556             │ -0.0596672 │ 0.0     │ 0.0      │
# │ 8   │ 1612             │ 0.669224   │ 0.0     │ 0.0      │
# │ 9   │ 1741             │ -1.21125   │ 0.0     │ 0.0      │
# │ 10  │ 1841             │ 2.27941    │ 1.31248 │ 0.939314 │
# IHT:   cv found 13 predictors, 12 false positives and 9 false negatives
# lasso: cv found 17 predictors, 15 false positives and 8 false negatives
#
#
# Running the 23 th model where n, p = 358, 2864
# compare_model = 10×4 DataFrame
# │ Row │ correct_position │ true_β    │ iht_β    │ lasso_β  │
# │     │ Int64            │ Float64   │ Float64  │ Float64  │
# ├─────┼──────────────────┼───────────┼──────────┼──────────┤
# │ 1   │ 738              │ -1.80117  │ -1.21416 │ 0.0      │
# │ 2   │ 1320             │ -0.833082 │ 0.0      │ 0.0      │
# │ 3   │ 1644             │ 1.04504   │ 0.0      │ 0.0      │
# │ 4   │ 1779             │ 0.156187  │ 0.0      │ 0.0      │
# │ 5   │ 1822             │ 0.918269  │ 0.0      │ 0.0      │
# │ 6   │ 1835             │ 1.64003   │ 0.0      │ 0.864349 │
# │ 7   │ 1873             │ 1.98437   │ 1.67675  │ 0.610751 │
# │ 8   │ 1925             │ 0.747625  │ 0.0      │ 0.0      │
# │ 9   │ 1950             │ 0.17416   │ 0.0      │ 0.0      │
# │ 10  │ 2131             │ 0.282961  │ 0.0      │ 0.0      │
# IHT:   cv found 11 predictors, 9 false positives and 8 false negatives
# lasso: cv found 10 predictors, 8 false positives and 8 false negatives
#
#
# Running the 24 th model where n, p = 657, 1314
# compare_model = 10×4 DataFrame
# │ Row │ correct_position │ true_β    │ iht_β     │ lasso_β   │
# │     │ Int64            │ Float64   │ Float64   │ Float64   │
# ├─────┼──────────────────┼───────────┼───────────┼───────────┤
# │ 1   │ 229              │ -1.59317  │ -1.56047  │ -0.589085 │
# │ 2   │ 356              │ 0.540876  │ 0.557092  │ 0.468853  │
# │ 3   │ 379              │ 0.340242  │ 0.320115  │ 0.246865  │
# │ 4   │ 407              │ -0.430603 │ -0.400612 │ -0.27149  │
# │ 5   │ 665              │ -0.627782 │ -0.652181 │ -0.499014 │
# │ 6   │ 816              │ -0.263837 │ -0.252505 │ -0.133961 │
# │ 7   │ 998              │ -0.408287 │ -0.394943 │ -0.300942 │
# │ 8   │ 1193             │ -0.704085 │ -0.679274 │ -0.540692 │
# │ 9   │ 1295             │ 0.171276  │ 0.20897   │ 0.132411  │
# │ 10  │ 1302             │ 0.0651556 │ 0.0       │ 0.0       │
# IHT:   cv found 10 predictors, 1 false positives and 1 false negatives
# lasso: cv found 18 predictors, 9 false positives and 1 false negatives
#
#
# Running the 25 th model where n, p = 875, 3500
# compare_model = 10×4 DataFrame
# │ Row │ correct_position │ true_β    │ iht_β   │ lasso_β  │
# │     │ Int64            │ Float64   │ Float64 │ Float64  │
# ├─────┼──────────────────┼───────────┼─────────┼──────────┤
# │ 1   │ 107              │ -0.478321 │ 0.0     │ 0.0      │
# │ 2   │ 865              │ 1.37502   │ 0.0     │ 0.0      │
# │ 3   │ 2281             │ 2.17631   │ 0.0     │ 0.911433 │
# │ 4   │ 2373             │ 0.955981  │ 0.0     │ 0.394594 │
# │ 5   │ 2399             │ -0.356567 │ 0.0     │ 0.0      │
# │ 6   │ 2412             │ 1.63621   │ 0.0     │ 0.470604 │
# │ 7   │ 2526             │ 0.211501  │ 0.0     │ 0.0      │
# │ 8   │ 2934             │ 1.04873   │ 0.0     │ 0.159579 │
# │ 9   │ 3013             │ -2.02116  │ 0.0     │ 0.0      │
# │ 10  │ 3331             │ 0.922451  │ 0.0     │ 0.0      │
# IHT:   cv found 1 predictors, 1 false positives and 10 false negatives
# lasso: cv found 17 predictors, 13 false positives and 6 false negatives
#
#
# Running the 26 th model where n, p = 887, 5322
# compare_model = 10×4 DataFrame
# │ Row │ correct_position │ true_β    │ iht_β   │ lasso_β  │
# │     │ Int64            │ Float64   │ Float64 │ Float64  │
# ├─────┼──────────────────┼───────────┼─────────┼──────────┤
# │ 1   │ 1371             │ 0.432714  │ 0.0     │ 0.0      │
# │ 2   │ 1661             │ -1.62546  │ 0.0     │ 0.0      │
# │ 3   │ 2623             │ -1.74758  │ 0.0     │ 0.0      │
# │ 4   │ 2652             │ 0.409912  │ 0.0     │ 0.0      │
# │ 5   │ 2793             │ 0.823468  │ 0.0     │ 0.0      │
# │ 6   │ 2892             │ -2.18677  │ 0.0     │ 0.0      │
# │ 7   │ 3832             │ -0.887524 │ 0.0     │ 0.0      │
# │ 8   │ 4047             │ 1.81931   │ 0.0     │ 0.0      │
# │ 9   │ 4572             │ 1.3742    │ 0.0     │ 0.741291 │
# │ 10  │ 4895             │ 0.985741  │ 0.0     │ 0.0      │
# IHT:   cv found 5 predictors, 5 false positives and 10 false negatives
# lasso: cv found 6 predictors, 5 false positives and 9 false negatives
#
#
# Running the 27 th model where n, p = 229, 1603
# compare_model = 10×4 DataFrame
# │ Row │ correct_position │ true_β     │ iht_β    │ lasso_β   │
# │     │ Int64            │ Float64    │ Float64  │ Float64   │
# ├─────┼──────────────────┼────────────┼──────────┼───────────┤
# │ 1   │ 11               │ 0.217151   │ 0.0      │ 0.0       │
# │ 2   │ 702              │ 0.954916   │ 0.752975 │ 0.714803  │
# │ 3   │ 744              │ 0.0529258  │ 0.0      │ 0.0       │
# │ 4   │ 779              │ 0.00560793 │ 0.0      │ 0.0       │
# │ 5   │ 809              │ 0.883777   │ 0.0      │ 0.0754123 │
# │ 6   │ 831              │ 0.963168   │ 0.443243 │ 0.354003  │
# │ 7   │ 1187             │ 0.432605   │ 0.0      │ 0.021514  │
# │ 8   │ 1201             │ 0.954701   │ 0.885052 │ 0.539402  │
# │ 9   │ 1475             │ 0.255386   │ 0.0      │ 0.0       │
# │ 10  │ 1484             │ -0.161913  │ 0.0      │ 0.0       │
# IHT:   cv found 7 predictors, 4 false positives and 7 false negatives
# lasso: cv found 16 predictors, 11 false positives and 5 false negatives
#
#
# Running the 28 th model where n, p = 338, 338
# compare_model = 10×4 DataFrame
# │ Row │ correct_position │ true_β     │ iht_β     │ lasso_β    │
# │     │ Int64            │ Float64    │ Float64   │ Float64    │
# ├─────┼──────────────────┼────────────┼───────────┼────────────┤
# │ 1   │ 3                │ -0.0504504 │ 0.0       │ 0.0        │
# │ 2   │ 13               │ 0.159771   │ 0.0       │ 0.0        │
# │ 3   │ 66               │ 0.571432   │ 0.523966  │ 0.0505866  │
# │ 4   │ 82               │ -0.197506  │ -0.223707 │ 0.0        │
# │ 5   │ 128              │ 0.866426   │ 0.840832  │ 0.258925   │
# │ 6   │ 216              │ -1.27822   │ -1.54121  │ 0.0        │
# │ 7   │ 290              │ 1.60283    │ 1.5725    │ 1.14459    │
# │ 8   │ 295              │ -2.05117   │ -2.09139  │ -0.767438  │
# │ 9   │ 299              │ -0.270861  │ -0.295793 │ -0.0563644 │
# │ 10  │ 329              │ 0.966142   │ 0.939465  │ 0.638798   │
# IHT:   cv found 8 predictors, 0 false positives and 2 false negatives
# lasso: cv found 16 predictors, 10 false positives and 4 false negatives
#
#
# Running the 29 th model where n, p = 861, 8610
# compare_model = 10×4 DataFrame
# │ Row │ correct_position │ true_β    │ iht_β   │ lasso_β  │
# │     │ Int64            │ Float64   │ Float64 │ Float64  │
# ├─────┼──────────────────┼───────────┼─────────┼──────────┤
# │ 1   │ 861              │ -0.691805 │ 0.0     │ 0.0      │
# │ 2   │ 2034             │ -0.126351 │ 0.0     │ 0.0      │
# │ 3   │ 2802             │ -1.13476  │ 0.0     │ 0.0      │
# │ 4   │ 3033             │ 0.384407  │ 0.0     │ 0.0      │
# │ 5   │ 3813             │ 0.0283471 │ 0.0     │ 0.0      │
# │ 6   │ 4525             │ 0.152892  │ 0.0     │ 0.0      │
# │ 7   │ 4744             │ -0.108664 │ 0.0     │ 0.0      │
# │ 8   │ 6724             │ 1.78695   │ 0.0     │ 0.220053 │
# │ 9   │ 7655             │ 1.96768   │ 0.0     │ 0.951871 │
# │ 10  │ 8167             │ 1.08607   │ 0.0     │ 0.0      │
# IHT:   cv found 1 predictors, 1 false positives and 10 false negatives
# lasso: cv found 10 predictors, 8 false positives and 8 false negatives
#
#
# Running the 30 th model where n, p = 910, 910
# compare_model = 10×4 DataFrame
# │ Row │ correct_position │ true_β     │ iht_β      │ lasso_β   │
# │     │ Int64            │ Float64    │ Float64    │ Float64   │
# ├─────┼──────────────────┼────────────┼────────────┼───────────┤
# │ 1   │ 6                │ -0.42854   │ -0.427584  │ 0.0       │
# │ 2   │ 363              │ -0.0694814 │ -0.0764315 │ 0.0       │
# │ 3   │ 372              │ -0.604989  │ -0.597409  │ 0.0       │
# │ 4   │ 383              │ -0.0648007 │ -0.0624554 │ 0.0       │
# │ 5   │ 474              │ -0.866878  │ -0.865134  │ 0.0       │
# │ 6   │ 607              │ 1.75804    │ 1.75474    │ 1.19292   │
# │ 7   │ 669              │ -1.19249   │ -1.1849    │ -0.451625 │
# │ 8   │ 817              │ -0.615152  │ -0.609162  │ 0.0       │
# │ 9   │ 848              │ 1.18982    │ 1.19176    │ 0.803366  │
# │ 10  │ 856              │ 0.414725   │ 0.416333   │ 0.0202855 │
# IHT:   cv found 11 predictors, 1 false positives and 0 false negatives
# lasso: cv found 16 predictors, 12 false positives and 6 false negatives
#
#
# Running the 31 th model where n, p = 345, 1380
# compare_model = 10×4 DataFrame
# │ Row │ correct_position │ true_β    │ iht_β   │ lasso_β  │
# │     │ Int64            │ Float64   │ Float64 │ Float64  │
# ├─────┼──────────────────┼───────────┼─────────┼──────────┤
# │ 1   │ 297              │ 1.44595   │ 0.0     │ 0.0      │
# │ 2   │ 344              │ 0.424104  │ 0.0     │ 0.0      │
# │ 3   │ 509              │ 1.11398   │ 0.0     │ 0.0      │
# │ 4   │ 622              │ -0.592925 │ 0.0     │ 0.0      │
# │ 5   │ 646              │ 0.799573  │ 0.0     │ 0.549793 │
# │ 6   │ 838              │ -0.669487 │ 0.0     │ 0.0      │
# │ 7   │ 846              │ 0.617313  │ 0.0     │ 0.0      │
# │ 8   │ 980              │ 0.132316  │ 0.0     │ 0.0      │
# │ 9   │ 1050             │ 0.783542  │ 0.0     │ 0.0      │
# │ 10  │ 1201             │ 1.35652   │ 0.0     │ 0.0      │
# IHT:   cv found 7 predictors, 7 false positives and 10 false negatives
# lasso: cv found 4 predictors, 3 false positives and 9 false negatives
#
#
# Running the 32 th model where n, p = 466, 2796
# compare_model = 10×4 DataFrame
# │ Row │ correct_position │ true_β    │ iht_β   │ lasso_β    │
# │     │ Int64            │ Float64   │ Float64 │ Float64    │
# ├─────┼──────────────────┼───────────┼─────────┼────────────┤
# │ 1   │ 239              │ 0.0285951 │ 0.0     │ 0.0        │
# │ 2   │ 296              │ -0.473781 │ 0.0     │ -0.0265172 │
# │ 3   │ 755              │ 0.45717   │ 0.0     │ 0.0        │
# │ 4   │ 960              │ -0.133841 │ 0.0     │ 0.0        │
# │ 5   │ 1085             │ -0.674342 │ 0.0     │ 0.0        │
# │ 6   │ 1504             │ -0.45596  │ 0.0     │ 0.0        │
# │ 7   │ 1789             │ 1.07359   │ 0.0     │ 0.67518    │
# │ 8   │ 1792             │ 0.874963  │ 0.0     │ 0.305368   │
# │ 9   │ 1808             │ 1.27953   │ 1.05498 │ 0.815821   │
# │ 10  │ 1886             │ -0.267945 │ 0.0     │ 0.0        │
# IHT:   cv found 2 predictors, 1 false positives and 9 false negatives
# lasso: cv found 16 predictors, 12 false positives and 6 false negatives
#
#
# Running the 33 th model where n, p = 878, 7902
# compare_model = 10×4 DataFrame
# │ Row │ correct_position │ true_β    │ iht_β   │ lasso_β  │
# │     │ Int64            │ Float64   │ Float64 │ Float64  │
# ├─────┼──────────────────┼───────────┼─────────┼──────────┤
# │ 1   │ 607              │ 0.326062  │ 0.0     │ 0.0      │
# │ 2   │ 1358             │ -0.399189 │ 0.0     │ 0.0      │
# │ 3   │ 2109             │ -0.058498 │ 0.0     │ 0.0      │
# │ 4   │ 3348             │ 0.714758  │ 0.0     │ 0.0      │
# │ 5   │ 4233             │ 0.573019  │ 0.0     │ 0.0      │
# │ 6   │ 4961             │ -0.174743 │ 0.0     │ 0.0      │
# │ 7   │ 5833             │ 2.1416    │ 1.50572 │ 1.06905  │
# │ 8   │ 6017             │ -0.584722 │ 0.0     │ 0.0      │
# │ 9   │ 7525             │ -0.546209 │ 0.0     │ 0.0      │
# │ 10  │ 7741             │ 2.60438   │ 0.0     │ 0.473678 │
# IHT:   cv found 5 predictors, 4 false positives and 9 false negatives
# lasso: cv found 10 predictors, 8 false positives and 8 false negatives
#
#
# Running the 34 th model where n, p = 522, 3132
# compare_model = 10×4 DataFrame
# │ Row │ correct_position │ true_β     │ iht_β   │ lasso_β   │
# │     │ Int64            │ Float64    │ Float64 │ Float64   │
# ├─────┼──────────────────┼────────────┼─────────┼───────────┤
# │ 1   │ 1036             │ -1.2257    │ -1.1451 │ -0.113735 │
# │ 2   │ 1143             │ 0.592288   │ 0.0     │ 0.0       │
# │ 3   │ 1159             │ -0.0292927 │ 0.0     │ 0.0       │
# │ 4   │ 1240             │ 0.214924   │ 0.0     │ 0.0       │
# │ 5   │ 1458             │ 0.599399   │ 0.0     │ 0.0       │
# │ 6   │ 1482             │ 1.32573    │ 1.32342 │ 0.67767   │
# │ 7   │ 1510             │ 0.00208933 │ 0.0     │ 0.0       │
# │ 8   │ 2111             │ 0.307722   │ 0.0     │ 0.0       │
# │ 9   │ 2588             │ 2.09219    │ 2.20209 │ 1.15185   │
# │ 10  │ 2679             │ -0.198153  │ 0.0     │ 0.0       │
# IHT:   cv found 7 predictors, 4 false positives and 7 false negatives
# lasso: cv found 16 predictors, 13 false positives and 7 false negatives
#
#
# Running the 35 th model where n, p = 591, 5319
# compare_model = 10×4 DataFrame
# │ Row │ correct_position │ true_β    │ iht_β   │ lasso_β   │
# │     │ Int64            │ Float64   │ Float64 │ Float64   │
# ├─────┼──────────────────┼───────────┼─────────┼───────────┤
# │ 1   │ 1186             │ -0.232456 │ 0.0     │ 0.0       │
# │ 2   │ 2216             │ 1.50704   │ 1.07937 │ 0.787635  │
# │ 3   │ 2507             │ 0.857883  │ 0.0     │ 0.0349965 │
# │ 4   │ 2691             │ 0.89792   │ 0.0     │ 0.0       │
# │ 5   │ 3004             │ 1.73486   │ 0.0     │ 0.953538  │
# │ 6   │ 3469             │ -0.407988 │ 0.0     │ 0.0       │
# │ 7   │ 3811             │ 0.838073  │ 0.0     │ 0.0       │
# │ 8   │ 3819             │ 0.454098  │ 0.0     │ 0.0       │
# │ 9   │ 4142             │ 1.18577   │ 0.0     │ 0.0       │
# │ 10  │ 4588             │ -0.928882 │ 0.0     │ 0.0       │
# IHT:   cv found 11 predictors, 10 false positives and 9 false negatives
# lasso: cv found 16 predictors, 13 false positives and 7 false negatives
#
#
# Running the 36 th model where n, p = 545, 3815
# compare_model = 10×4 DataFrame
# │ Row │ correct_position │ true_β     │ iht_β   │ lasso_β    │
# │     │ Int64            │ Float64    │ Float64 │ Float64    │
# ├─────┼──────────────────┼────────────┼─────────┼────────────┤
# │ 1   │ 163              │ 1.81433    │ 0.0     │ 1.09546    │
# │ 2   │ 420              │ 0.06284    │ 0.0     │ 0.0        │
# │ 3   │ 540              │ -0.543143  │ 0.0     │ -0.152101  │
# │ 4   │ 666              │ -0.361431  │ 0.0     │ 0.0        │
# │ 5   │ 956              │ -0.0190017 │ 0.0     │ 0.0        │
# │ 6   │ 1243             │ 0.205855   │ 0.0     │ 0.0        │
# │ 7   │ 1421             │ -0.287277  │ 0.0     │ 0.0        │
# │ 8   │ 1455             │ -1.30933   │ 0.0     │ -0.0200346 │
# │ 9   │ 2497             │ -0.559077  │ 0.0     │ 0.0        │
# │ 10  │ 3062             │ 0.837587   │ 0.0     │ 0.717602   │
# IHT:   cv found 1 predictors, 1 false positives and 10 false negatives
# lasso: cv found 12 predictors, 8 false positives and 6 false negatives
#
#
# Running the 37 th model where n, p = 362, 3620
# compare_model = 10×4 DataFrame
# │ Row │ correct_position │ true_β    │ iht_β    │ lasso_β  │
# │     │ Int64            │ Float64   │ Float64  │ Float64  │
# ├─────┼──────────────────┼───────────┼──────────┼──────────┤
# │ 1   │ 851              │ -1.25333  │ 0.0      │ 0.0      │
# │ 2   │ 879              │ 2.14971   │ 0.0      │ 0.589918 │
# │ 3   │ 964              │ -2.11306  │ -2.08863 │ 0.0      │
# │ 4   │ 1071             │ -0.368088 │ 0.0      │ 0.0      │
# │ 5   │ 1156             │ -0.394403 │ 0.0      │ 0.0      │
# │ 6   │ 1372             │ 1.09002   │ 0.0      │ 0.0      │
# │ 7   │ 1766             │ -0.202934 │ 0.0      │ 0.0      │
# │ 8   │ 1877             │ -0.676817 │ 0.0      │ 0.0      │
# │ 9   │ 2490             │ 1.58491   │ 0.0      │ 0.664193 │
# │ 10  │ 2983             │ -1.49695  │ 0.0      │ 0.0      │
# IHT:   cv found 7 predictors, 6 false positives and 9 false negatives
# lasso: cv found 14 predictors, 12 false positives and 8 false negatives
#
#
# Running the 38 th model where n, p = 926, 1852
# compare_model = 10×4 DataFrame
# │ Row │ correct_position │ true_β    │ iht_β     │ lasso_β    │
# │     │ Int64            │ Float64   │ Float64   │ Float64    │
# ├─────┼──────────────────┼───────────┼───────────┼────────────┤
# │ 1   │ 121              │ -0.673897 │ -0.654835 │ -0.104027  │
# │ 2   │ 238              │ 0.406818  │ 0.378774  │ 0.149883   │
# │ 3   │ 275              │ -0.816513 │ -0.757234 │ -0.0938518 │
# │ 4   │ 487              │ -0.776713 │ -0.76883  │ -0.361326  │
# │ 5   │ 728              │ 0.388687  │ 0.381015  │ 0.270534   │
# │ 6   │ 896              │ 0.701891  │ 0.705904  │ 0.57636    │
# │ 7   │ 909              │ 0.367938  │ 0.364389  │ 0.185813   │
# │ 8   │ 1229             │ 0.251338  │ 0.259826  │ 0.0152199  │
# │ 9   │ 1453             │ -1.088    │ -1.07441  │ -0.638931  │
# │ 10  │ 1641             │ -0.853783 │ -0.876086 │ -0.459439  │
# IHT:   cv found 15 predictors, 5 false positives and 0 false negatives
# lasso: cv found 16 predictors, 6 false positives and 0 false negatives
#
#
# Running the 39 th model where n, p = 575, 2300
# compare_model = 10×4 DataFrame
# │ Row │ correct_position │ true_β    │ iht_β     │ lasso_β   │
# │     │ Int64            │ Float64   │ Float64   │ Float64   │
# ├─────┼──────────────────┼───────────┼───────────┼───────────┤
# │ 1   │ 34               │ -0.293072 │ 0.0       │ 0.0       │
# │ 2   │ 530              │ 0.748774  │ 0.675926  │ 0.258476  │
# │ 3   │ 801              │ 0.122947  │ 0.0       │ 0.0       │
# │ 4   │ 1140             │ 0.871043  │ 0.768461  │ 0.14591   │
# │ 5   │ 1319             │ -0.987682 │ -0.841982 │ 0.0       │
# │ 6   │ 1356             │ -3.32826  │ -2.83283  │ -0.213271 │
# │ 7   │ 1695             │ 0.408356  │ 0.0       │ 0.0       │
# │ 8   │ 1797             │ 0.882994  │ 0.777942  │ 0.0076415 │
# │ 9   │ 1966             │ 0.547504  │ 0.328631  │ 0.0       │
# │ 10  │ 2206             │ 0.156983  │ 0.0       │ 0.0       │
# IHT:   cv found 9 predictors, 3 false positives and 4 false negatives
# lasso: cv found 16 predictors, 12 false positives and 6 false negatives
#
#
# Running the 40 th model where n, p = 670, 3350
# compare_model = 10×4 DataFrame
# │ Row │ correct_position │ true_β     │ iht_β   │ lasso_β     │
# │     │ Int64            │ Float64    │ Float64 │ Float64     │
# ├─────┼──────────────────┼────────────┼─────────┼─────────────┤
# │ 1   │ 1101             │ 0.0195108  │ 0.0     │ 0.0         │
# │ 2   │ 1481             │ 1.43626    │ 0.0     │ 0.388512    │
# │ 3   │ 1547             │ 0.569572   │ 0.0     │ 0.0         │
# │ 4   │ 1777             │ -0.231178  │ 0.0     │ 0.0         │
# │ 5   │ 2253             │ 2.3033     │ 1.51536 │ 1.00811     │
# │ 6   │ 2369             │ -0.299791  │ 0.0     │ 0.0         │
# │ 7   │ 3002             │ -1.8582    │ 0.0     │ -0.00969194 │
# │ 8   │ 3119             │ -0.0505315 │ 0.0     │ 0.0         │
# │ 9   │ 3170             │ -0.512253  │ 0.0     │ 0.0         │
# │ 10  │ 3314             │ -0.530146  │ 0.0     │ 0.0         │
# IHT:   cv found 2 predictors, 1 false positives and 9 false negatives
# lasso: cv found 16 predictors, 13 false positives and 7 false negatives
#
#
# Running the 41 th model where n, p = 527, 4216
# compare_model = 10×4 DataFrame
# │ Row │ correct_position │ true_β     │ iht_β     │ lasso_β   │
# │     │ Int64            │ Float64    │ Float64   │ Float64   │
# ├─────┼──────────────────┼────────────┼───────────┼───────────┤
# │ 1   │ 908              │ 0.405663   │ 0.423932  │ 0.324234  │
# │ 2   │ 1170             │ 0.52465    │ 0.506337  │ 0.416522  │
# │ 3   │ 1599             │ -0.833589  │ -0.869167 │ -0.545882 │
# │ 4   │ 1811             │ 0.203721   │ 0.0       │ 0.0       │
# │ 5   │ 2544             │ 0.16927    │ 0.0       │ 0.0       │
# │ 6   │ 3514             │ 0.082418   │ 0.0       │ 0.0       │
# │ 7   │ 3532             │ 1.06098    │ 1.06148   │ 0.929793  │
# │ 8   │ 3905             │ -0.0895056 │ 0.0       │ 0.0       │
# │ 9   │ 4075             │ -0.56991   │ -0.549189 │ -0.357946 │
# │ 10  │ 4186             │ -0.571129  │ -0.490537 │ -0.176982 │
# IHT:   cv found 10 predictors, 4 false positives and 4 false negatives
# lasso: cv found 16 predictors, 10 false positives and 4 false negatives
#
#
# Running the 42 th model where n, p = 740, 7400
# compare_model = 10×4 DataFrame
# │ Row │ correct_position │ true_β     │ iht_β     │ lasso_β      │
# │     │ Int64            │ Float64    │ Float64   │ Float64      │
# ├─────┼──────────────────┼────────────┼───────────┼──────────────┤
# │ 1   │ 170              │ -0.3213    │ -0.340649 │ -0.066298    │
# │ 2   │ 911              │ -0.602639  │ -0.583392 │ -0.292408    │
# │ 3   │ 1935             │ 0.386995   │ 0.379423  │ 0.344392     │
# │ 4   │ 3077             │ -0.186859  │ -0.190534 │ 0.0          │
# │ 5   │ 4001             │ 0.53965    │ 0.519776  │ 0.387343     │
# │ 6   │ 4470             │ -0.119457  │ -0.127563 │ -0.000488414 │
# │ 7   │ 4522             │ 1.09386    │ 1.07629   │ 0.947964     │
# │ 8   │ 4770             │ -2.03079   │ -1.88651  │ -0.552789    │
# │ 9   │ 5405             │ -0.0134124 │ 0.0       │ 0.0          │
# │ 10  │ 6983             │ 0.151436   │ 0.135105  │ 0.0          │
# IHT:   cv found 14 predictors, 5 false positives and 1 false negatives
# lasso: cv found 16 predictors, 9 false positives and 3 false negatives
#
#
# Running the 43 th model where n, p = 539, 3234
# compare_model = 10×4 DataFrame
# │ Row │ correct_position │ true_β    │ iht_β     │ lasso_β    │
# │     │ Int64            │ Float64   │ Float64   │ Float64    │
# ├─────┼──────────────────┼───────────┼───────────┼────────────┤
# │ 1   │ 53               │ -0.339415 │ 0.0       │ 0.0        │
# │ 2   │ 477              │ 0.275899  │ 0.0       │ 0.0        │
# │ 3   │ 1124             │ 1.02644   │ 1.06075   │ 0.75237    │
# │ 4   │ 1667             │ -0.123224 │ 0.0       │ 0.0        │
# │ 5   │ 2129             │ 0.264478  │ 0.0       │ 0.0        │
# │ 6   │ 2151             │ 1.03611   │ 1.00443   │ 0.65996    │
# │ 7   │ 2447             │ -0.254307 │ 0.0       │ 0.0        │
# │ 8   │ 3007             │ -0.966501 │ -0.950916 │ -0.24013   │
# │ 9   │ 3060             │ -0.617681 │ -0.5442   │ -0.0803444 │
# │ 10  │ 3095             │ -0.877353 │ -0.683053 │ 0.0        │
# IHT:   cv found 8 predictors, 3 false positives and 5 false negatives
# lasso: cv found 16 predictors, 12 false positives and 6 false negatives
#
#
# Running the 44 th model where n, p = 781, 5467
# compare_model = 10×4 DataFrame
# │ Row │ correct_position │ true_β    │ iht_β   │ lasso_β  │
# │     │ Int64            │ Float64   │ Float64 │ Float64  │
# ├─────┼──────────────────┼───────────┼─────────┼──────────┤
# │ 1   │ 827              │ 0.0965717 │ 0.0     │ 0.0      │
# │ 2   │ 1346             │ -1.44502  │ 0.0     │ 0.0      │
# │ 3   │ 2212             │ -0.462039 │ 0.0     │ 0.0      │
# │ 4   │ 3806             │ -0.424686 │ 0.0     │ 0.0      │
# │ 5   │ 3834             │ 0.921385  │ 0.0     │ 0.0      │
# │ 6   │ 3898             │ -1.35757  │ 0.0     │ 0.0      │
# │ 7   │ 4274             │ -1.33548  │ 0.0     │ 0.0      │
# │ 8   │ 4366             │ 1.61596   │ 0.0     │ 0.734682 │
# │ 9   │ 4627             │ 0.378278  │ 0.0     │ 0.0      │
# │ 10  │ 5059             │ -0.902572 │ 0.0     │ 0.0      │
# IHT:   cv found 6 predictors, 6 false positives and 10 false negatives
# lasso: cv found 6 predictors, 5 false positives and 9 false negatives
#
#
# Running the 45 th model where n, p = 783, 783
# compare_model = 10×4 DataFrame
# │ Row │ correct_position │ true_β    │ iht_β     │ lasso_β   │
# │     │ Int64            │ Float64   │ Float64   │ Float64   │
# ├─────┼──────────────────┼───────────┼───────────┼───────────┤
# │ 1   │ 1                │ 1.38839   │ 1.38017   │ 1.08776   │
# │ 2   │ 80               │ 1.31829   │ 1.29161   │ 0.919415  │
# │ 3   │ 156              │ -0.743223 │ -0.758969 │ -0.549023 │
# │ 4   │ 252              │ 0.255015  │ 0.246397  │ 0.0961697 │
# │ 5   │ 289              │ 0.173183  │ 0.0       │ 0.0       │
# │ 6   │ 316              │ -0.175091 │ -0.150587 │ 0.0       │
# │ 7   │ 512              │ 0.980326  │ 0.968243  │ 0.610151  │
# │ 8   │ 591              │ -0.125692 │ -0.146517 │ 0.0       │
# │ 9   │ 665              │ 0.346859  │ 0.343449  │ 0.0822114 │
# │ 10  │ 745              │ -0.562743 │ -0.664549 │ 0.0       │
# IHT:   cv found 9 predictors, 0 false positives and 1 false negatives
# lasso: cv found 16 predictors, 10 false positives and 4 false negatives
#
#
# Running the 46 th model where n, p = 368, 3680
# compare_model = 10×4 DataFrame
# │ Row │ correct_position │ true_β     │ iht_β     │ lasso_β    │
# │     │ Int64            │ Float64    │ Float64   │ Float64    │
# ├─────┼──────────────────┼────────────┼───────────┼────────────┤
# │ 1   │ 111              │ 1.21964    │ 1.07963   │ 0.628931   │
# │ 2   │ 416              │ 0.448205   │ 0.417793  │ 0.144185   │
# │ 3   │ 1017             │ 0.376463   │ 0.316175  │ 0.0        │
# │ 4   │ 1382             │ 0.0138152  │ 0.0       │ 0.0        │
# │ 5   │ 1443             │ -0.0846773 │ 0.0       │ 0.0        │
# │ 6   │ 1565             │ -1.42889   │ -1.32823  │ -0.549238  │
# │ 7   │ 1849             │ 0.416343   │ 0.386899  │ 0.0391516  │
# │ 8   │ 2585             │ 0.0237432  │ 0.0       │ 0.0        │
# │ 9   │ 2657             │ -0.517216  │ -0.493389 │ -0.0218241 │
# │ 10  │ 3465             │ 1.03009    │ 0.908948  │ 0.590713   │
# IHT:   cv found 15 predictors, 8 false positives and 3 false negatives
# lasso: cv found 16 predictors, 10 false positives and 4 false negatives
#
#
# Running the 47 th model where n, p = 498, 1992
# compare_model = 10×4 DataFrame
# │ Row │ correct_position │ true_β   │ iht_β    │ lasso_β   │
# │     │ Int64            │ Float64  │ Float64  │ Float64   │
# ├─────┼──────────────────┼──────────┼──────────┼───────────┤
# │ 1   │ 75               │ 0.526832 │ 0.0      │ 0.0       │
# │ 2   │ 456              │ 1.23644  │ 1.027    │ 0.0501845 │
# │ 3   │ 457              │ 0.342277 │ 0.0      │ 0.0       │
# │ 4   │ 640              │ -1.04351 │ 0.0      │ 0.0       │
# │ 5   │ 1167             │ 1.80262  │ 1.81161  │ 0.521702  │
# │ 6   │ 1392             │ 0.976833 │ 0.646478 │ 0.0       │
# │ 7   │ 1439             │ 0.60096  │ 0.0      │ 0.0       │
# │ 8   │ 1526             │ 0.334336 │ 0.0      │ 0.0       │
# │ 9   │ 1540             │ 1.32481  │ 0.953501 │ 0.0       │
# │ 10  │ 1547             │ -0.59995 │ 0.0      │ 0.0       │
# IHT:   cv found 8 predictors, 4 false positives and 6 false negatives
# lasso: cv found 16 predictors, 14 false positives and 8 false negatives
#
#
# Running the 48 th model where n, p = 653, 3918
# compare_model = 10×4 DataFrame
# │ Row │ correct_position │ true_β    │ iht_β     │ lasso_β   │
# │     │ Int64            │ Float64   │ Float64   │ Float64   │
# ├─────┼──────────────────┼───────────┼───────────┼───────────┤
# │ 1   │ 726              │ -0.489796 │ -0.476252 │ 0.0       │
# │ 2   │ 1145             │ 0.873523  │ 0.81333   │ 0.0868416 │
# │ 3   │ 1147             │ -0.313374 │ 0.0       │ 0.0       │
# │ 4   │ 1306             │ -0.12161  │ 0.0       │ 0.0       │
# │ 5   │ 1739             │ 0.276805  │ 0.0       │ 0.0       │
# │ 6   │ 2161             │ 0.956643  │ 1.02089   │ 0.440386  │
# │ 7   │ 2376             │ 0.886324  │ 0.93232   │ 0.35247   │
# │ 8   │ 2489             │ 2.53387   │ 2.64961   │ 1.18891   │
# │ 9   │ 2780             │ 0.496745  │ 0.0       │ 0.008434  │
# │ 10  │ 3643             │ -0.614667 │ 0.0       │ 0.0       │
# IHT:   cv found 8 predictors, 3 false positives and 5 false negatives
# lasso: cv found 16 predictors, 11 false positives and 5 false negatives
#
#
# Running the 49 th model where n, p = 601, 3005
# compare_model = 10×4 DataFrame
# │ Row │ correct_position │ true_β    │ iht_β     │ lasso_β   │
# │     │ Int64            │ Float64   │ Float64   │ Float64   │
# ├─────┼──────────────────┼───────────┼───────────┼───────────┤
# │ 1   │ 45               │ 0.185024  │ 0.200738  │ 0.0       │
# │ 2   │ 432              │ 0.324008  │ 0.321307  │ 0.0396106 │
# │ 3   │ 1062             │ -0.384758 │ -0.363597 │ 0.0       │
# │ 4   │ 1127             │ 0.0937062 │ 0.0634861 │ 0.0       │
# │ 5   │ 1449             │ -1.26818  │ -1.17656  │ 0.0       │
# │ 6   │ 2393             │ 0.615488  │ 0.617071  │ 0.0       │
# │ 7   │ 2529             │ 0.330147  │ 0.327041  │ 0.0       │
# │ 8   │ 2608             │ 0.667249  │ 0.66436   │ 0.409603  │
# │ 9   │ 2765             │ 0.103207  │ 0.0       │ 0.0       │
# │ 10  │ 2944             │ 1.74739   │ 1.7182    │ 0.895113  │
# IHT:   cv found 14 predictors, 5 false positives and 1 false negatives
# lasso: cv found 16 predictors, 13 false positives and 7 false negatives
#
#
# Running the 50 th model where n, p = 811, 811
# compare_model = 10×4 DataFrame
# │ Row │ correct_position │ true_β    │ iht_β     │ lasso_β     │
# │     │ Int64            │ Float64   │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼───────────┼─────────────┤
# │ 1   │ 5                │ 0.415467  │ 0.408136  │ 0.0102955   │
# │ 2   │ 44               │ -0.919687 │ -0.910718 │ -0.298426   │
# │ 3   │ 80               │ -0.658771 │ -0.655839 │ -0.170918   │
# │ 4   │ 224              │ -1.66026  │ -1.6725   │ -0.436719   │
# │ 5   │ 381              │ -1.27142  │ -1.27121  │ -0.488883   │
# │ 6   │ 417              │ -0.581601 │ -0.588256 │ -0.105671   │
# │ 7   │ 576              │ -1.75364  │ -1.73376  │ -0.287812   │
# │ 8   │ 664              │ -1.81848  │ -1.91509  │ 0.0         │
# │ 9   │ 710              │ 0.966745  │ 0.959375  │ 0.366743    │
# │ 10  │ 747              │ -1.5784   │ -1.46172  │ -0.00291796 │
# IHT:   cv found 15 predictors, 5 false positives and 0 false negatives
# lasso: cv found 19 predictors, 10 false positives and 1 false negatives
#
#
# IHT  : Found 222 correct predictors, out of 500
# IHT  : False positives = 199
# IHT  : False negatives = 278
# Lasso: Found 220 correct predictors, out of 500
# Lasso: False positives = 501
# Lasso: False negatives = 280

# %%
function iht_lasso_poisson(n :: Int64, p :: Int64)
    #set random seed
    Random.seed!(1111)

    #define maf and true model size
    bernoulli_rates = 0.5rand(p)
    k = 10

    #construct snpmatrix, covariate files, and true model b
    x = simulate_random_snparray(n, p, bernoulli_rates)
    xbm = SnpBitMatrix{Float64}(x, model=ADDITIVE_MODEL, center=true, scale=true); 
    z           = ones(n, 1)                   # non-genetic covariates, just the intercept
    true_b      = zeros(p)                     # model vector
    true_b[1:k] = randn(k)                     # Initialize k non-zero entries in the true model
    shuffle!(true_b)                           # Shuffle the entries
    correct_position = findall(x -> x != 0, true_b) # keep track of what the true entries are

    # Simulate poisson data
    y_temp = xbm * true_b
    λ = exp.(y_temp) #inverse log link
    y = [rand(Poisson(x)) for x in λ]
    y = Float64.(y)

    #compute poisson IHT result
    path = collect(1:15)
    num_folds = 5
    folds = rand(1:num_folds, size(x, 1))
    k_est_iht = cv_iht(x, z, y, 1, path, folds, num_folds, use_maf=false, glm="poisson", debias=false)
    iht_result = L0_poisson_reg(x, z, y, 1, k_est_iht, glm = "poisson", debias=false, convg=false, show_info=false, true_beta=true_b)

    #compute poisson lasso result
    x_float = [convert(Matrix{Float64}, x, center=true, scale=true) z]
    cv = glmnetcv(x_float, y, Poisson(), dfmax=15, nfolds=5, folds=folds)
    best = argmin(cv.meanloss)
    lasso_result = cv.path.betas[:, best]
    k_est_lasso = length(findall(!iszero, lasso_result))
    
    #compute regular poisson regression using only true predictors
    x_true = [x_float[:, correct_position] z]
    regular_result = glm(x_true, y, Poisson(), LogLink())
    regular_result = regular_result.pp.beta0
    
    #check result
    IHT_model = iht_result.beta[correct_position]
    lasso_model = lasso_result[correct_position]
    true_model = true_b[correct_position]
    compare_model = DataFrame(
        true_β  = true_model, 
        iht_β   = IHT_model,
        lasso_β = lasso_model,
        regular_β = regular_result[1:10])
    @show compare_model

    #compute summary statistics
    lasso_num_correct_predictors = length(findall(!iszero, lasso_model))
    lasso_false_positives = k_est_lasso - lasso_num_correct_predictors
    lasso_false_negatives = k - lasso_num_correct_predictors
    iht_num_correct_predictors = length(findall(!iszero, IHT_model))
    iht_false_positives = k_est_iht - iht_num_correct_predictors
    iht_false_negatives = k - iht_num_correct_predictors
    println("IHT:   cv found " * "$k_est_iht predictors, " * "$iht_false_positives false positives " * "and $iht_false_negatives false negatives")
    println("lasso: cv found " * "$k_est_lasso predictors, " * "$lasso_false_positives false positives and " * "$lasso_false_negatives false negatives \n\n")

    return lasso_num_correct_predictors, lasso_false_positives, lasso_false_negatives, iht_num_correct_predictors, iht_false_positives, iht_false_negatives
end
# Out:
# iht_lasso_poisson (generic function with 1 method)

# %%
function run_iht_lasso_poisson()
    lasso_total_found = 0
    lasso_false_positives = 0
    lasso_false_negatives = 0
    iht_total_found = 0
    iht_false_positives = 0
    iht_false_negatives = 0
    
    iter = 10
    for i = 1:iter
        n = rand(500:1000) 
        p = rand(1:10)n
        println("Running the $i th model where " * "n, p = " * string(n) * ", " * string(p))
        ltf, lfp, lfn, itf, ifp, ifn = iht_lasso_poisson(n, p)

        lasso_total_found += ltf
        lasso_false_positives += lfp
        lasso_false_negatives += lfn
        iht_total_found += itf
        iht_false_positives += ifp
        iht_false_negatives += ifn
    end
    println("IHT  : Found $iht_total_found " * "correct predictors, out of " * string(10iter))
    println("IHT  : False positives = $iht_false_positives")
    println("IHT  : False negatives = $iht_false_negatives")   
    println("Lasso: Found $lasso_total_found " * "correct predictors, out of " * string(10iter))
    println("Lasso: False positives = $lasso_false_positives")
    println("Lasso: False negatives = $lasso_false_negatives")
end
# Out:
# run_iht_lasso_poisson (generic function with 1 method)

# %%
Random.seed!(2019)
run_iht_lasso_poisson()
