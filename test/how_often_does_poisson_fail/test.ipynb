# %%
using Revise
using IHT
using SnpArrays
using DataFrames
using Distributions
using StatsFuns: logistic
using Random
using LinearAlgebra
# Out:
# ┌ Info: Recompiling stale cache file /Users/biona001/.julia/compiled/v1.0/IHT/eaqWB.ji for IHT [921c7187-1484-5754-b919-5d3ed9ac03c4]
# └ @ Base loading.jl:1190
# ┌ Info: Loading DataFrames support into Gadfly.jl
# └ @ Gadfly /Users/biona001/.julia/packages/Gadfly/09PWZ/src/mapping.jl:228

# %%
function run_poisson(n :: Int64, p :: Int64)
    #set random seed
    Random.seed!(1111)

    #simulate data
    k = 10 # number of true predictors
    bernoulli_rates = 0.5rand(p) #minor allele frequencies are drawn from uniform (0, 0.5)
    x = simulate_random_snparray(n, p, bernoulli_rates)
    xbm = SnpBitMatrix{Float64}(x, model=ADDITIVE_MODEL, center=true, scale=true); 

    #construct snpmatrix, covariate files, and true model b
    z           = ones(n, 1)                   # non-genetic covariates, just the intercept
    true_b      = zeros(p)                     # model vector
    true_b[1:k] = randn(k)                     # Initialize k non-zero entries in the true model
    shuffle!(true_b)                           # Shuffle the entries
    correct_position = findall(x -> x != 0, true_b) # keep track of what the true entries are

    #check maf
    bernoulli_rates[correct_position]

    #simulate phenotypes under different noises by: y = Xb + noise
    y_temp = xbm * true_b

    # Simulate poisson data
    λ = exp.(y_temp) #inverse log link
    y = [rand(Poisson(x)) for x in λ]
    y = Float64.(y)

    #compute poisson IHT result
    result = L0_poisson_reg(x, z, y, 1, k, glm = "poisson", debias=false, convg=false, show_info=false)

    #check result
    estimated_models = zeros(k)
    estimated_models .= result.beta[correct_position]
    true_model = true_b[correct_position]
    compare_model = DataFrame(
        correct_position = correct_position, 
        true_β           = true_model, 
        estimated_β      = estimated_models)
    
    #display results
    @show compare_model
    println("n = " * string(n) * ", and p = " * string(p))
    println("Total iteration number was " * string(result.iter))
    println("Total time was " * string(result.time))
end

function run_logistic(n :: Int64, p :: Int64, debias :: Bool)
    #set random seed
    Random.seed!(1111)

    #simulate data
    k = 10 # number of true predictors
    bernoulli_rates = 0.5rand(p) #minor allele frequencies are drawn from uniform (0, 0.5)
    x = simulate_random_snparray(n, p, bernoulli_rates)
    xbm = SnpBitMatrix{Float64}(x, model=ADDITIVE_MODEL, center=true, scale=true); 

    #construct snpmatrix, covariate files, and true model b
    z           = ones(n, 1)                   # non-genetic covariates, just the intercept
    true_b      = zeros(p)                     # model vector
    true_b[1:k] = randn(k)                     # Initialize k non-zero entries in the true model
    shuffle!(true_b)                           # Shuffle the entries
    correct_position = findall(x -> x != 0, true_b) # keep track of what the true entries are

    #simulate phenotypes under different noises by: y = Xb + noise
    y_temp = xbm * true_b

    # Apply inverse logit link and sample from the vector of distributions
    prob = logistic.(y_temp) #inverse logit link
    y = [rand(Bernoulli(x)) for x in prob]
    y = Float64.(y)

    #compute logistic IHT result
    result = L0_logistic_reg(x, z, y, 1, k, glm = "logistic", debias=debias, show_info=false)

    #check result
    estimated_models = result.beta[correct_position]
    true_model = true_b[correct_position]
    compare_model = DataFrame(
        correct_position = correct_position, 
        true_β           = true_model, 
        estimated_β      = estimated_models)
    println("Total iteration number was " * string(result.iter))
    println("Total time was " * string(result.time))

    #display results
    @show compare_model
    println("n = " * string(n) * ", and p = " * string(p))
    println("Total iteration number was " * string(result.iter))
    println("Total time was " * string(result.time))
end
# Out:
# run_logistic (generic function with 1 method)

# %% [markdown]
# # Poisson sample size = 100~1000 (no debias)

# %%
for i = 1:100
    println("running the $i th model")
    n = rand(100:1000) 
    p = rand(1:10)n
    run_poisson(n, p)
end
# Out:
# running the 1 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β     │ estimated_β │
# │     │ Int64            │ Float64    │ Float64     │
# ├─────┼──────────────────┼────────────┼─────────────┤
# │ 1   │ 2                │ 0.00897563 │ 0.0         │
# │ 2   │ 9                │ 0.0701975  │ 0.0         │
# │ 3   │ 44               │ -0.777736  │ -0.317116   │
# │ 4   │ 130              │ 0.210051   │ 0.0         │
# │ 5   │ 145              │ -0.185546  │ 0.0         │
# │ 6   │ 148              │ 1.21199    │ 1.03397     │
# │ 7   │ 167              │ -1.98988   │ 0.0         │
# │ 8   │ 248              │ 0.284483   │ 0.0         │
# │ 9   │ 258              │ -0.123728  │ 0.0         │
# │ 10  │ 273              │ -0.473523  │ 0.0         │
# n = 278, and p = 278
# Total iteration number was 252
# Total time was 0.5504870414733887
# running the 2 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β     │ estimated_β │
# │     │ Int64            │ Float64    │ Float64     │
# ├─────┼──────────────────┼────────────┼─────────────┤
# │ 1   │ 167              │ 0.23548    │ 0.0         │
# │ 2   │ 220              │ -0.206169  │ -0.276183   │
# │ 3   │ 404              │ -0.0585504 │ 0.0         │
# │ 4   │ 430              │ -0.98851   │ -1.03272    │
# │ 5   │ 469              │ 0.596469   │ 0.599761    │
# │ 6   │ 866              │ -0.608259  │ -0.685592   │
# │ 7   │ 869              │ 0.501085   │ 0.47856     │
# │ 8   │ 1167             │ 1.34238    │ 1.24878     │
# │ 9   │ 2076             │ 0.851028   │ 0.806482    │
# │ 10  │ 2081             │ -1.07134   │ -1.09144    │
# n = 586, and p = 2344
# Total iteration number was 205
# Total time was 1.547712802886963
# running the 3 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 313              │ -0.727468 │ -0.736953   │
# │ 2   │ 440              │ -2.12925  │ 0.0         │
# │ 3   │ 493              │ 0.480927  │ 0.0         │
# │ 4   │ 868              │ 1.217     │ 0.925024    │
# │ 5   │ 1237             │ 0.134026  │ 0.0         │
# │ 6   │ 1298             │ -0.83463  │ 0.0         │
# │ 7   │ 1394             │ 2.47601   │ 2.01437     │
# │ 8   │ 1564             │ -0.75805  │ 0.0         │
# │ 9   │ 1678             │ 0.312379  │ 0.0         │
# │ 10  │ 1816             │ -1.04538  │ 0.0         │
# n = 309, and p = 1854
# Total iteration number was 385
# Total time was 1.2914988994598389
# running the 4 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 588              │ 0.675038  │ 0.674139    │
# │ 2   │ 994              │ 0.498217  │ 0.491078    │
# │ 3   │ 1580             │ 1.14479   │ 1.13775     │
# │ 4   │ 1698             │ -0.549736 │ -0.54657    │
# │ 5   │ 1936             │ -0.24323  │ -0.241257   │
# │ 6   │ 2147             │ -0.321306 │ -0.331548   │
# │ 7   │ 3495             │ 0.716034  │ 0.714443    │
# │ 8   │ 3817             │ 1.14789   │ 1.15079     │
# │ 9   │ 4271             │ 0.880861  │ 0.892084    │
# │ 10  │ 4598             │ -0.697766 │ -0.697365   │
# n = 792, and p = 5544
# Total iteration number was 260
# Total time was 6.179845094680786
# running the 5 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 712              │ -0.916546 │ 0.0         │
# │ 2   │ 770              │ -1.24208  │ 0.0         │
# │ 3   │ 811              │ 1.40254   │ 1.13291     │
# │ 4   │ 874              │ 0.469878  │ 0.0         │
# │ 5   │ 1035             │ -0.433553 │ 0.0         │
# │ 6   │ 1081             │ 0.884609  │ 0.0         │
# │ 7   │ 1440             │ 0.165744  │ 0.0         │
# │ 8   │ 1551             │ -0.544002 │ 0.0         │
# │ 9   │ 1847             │ 0.374477  │ 0.0         │
# │ 10  │ 2078             │ 1.57038   │ 1.26363     │
# n = 271, and p = 2710
# Total iteration number was 370
# Total time was 1.5726690292358398
# running the 6 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 235              │ -1.41651  │ -1.41541    │
# │ 2   │ 737              │ -1.27028  │ -1.27894    │
# │ 3   │ 1080             │ 0.665166  │ 0.66274     │
# │ 4   │ 1103             │ -1.77081  │ -1.75588    │
# │ 5   │ 2974             │ -0.737881 │ -0.734221   │
# │ 6   │ 3850             │ -2.5741   │ -2.59216    │
# │ 7   │ 4939             │ -0.490545 │ -0.491772   │
# │ 8   │ 5859             │ -0.305376 │ -0.301436   │
# │ 9   │ 6610             │ 0.551274  │ 0.554539    │
# │ 10  │ 6822             │ 1.55315   │ 1.54634     │
# n = 823, and p = 8230
# Total iteration number was 243
# Total time was 8.846246004104614
# running the 7 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β     │ estimated_β │
# │     │ Int64            │ Float64    │ Float64     │
# ├─────┼──────────────────┼────────────┼─────────────┤
# │ 1   │ 48               │ -1.25963   │ -1.24459    │
# │ 2   │ 254              │ 1.14178    │ 1.10846     │
# │ 3   │ 295              │ -0.539151  │ -0.535466   │
# │ 4   │ 748              │ -0.149006  │ -0.12028    │
# │ 5   │ 772              │ 0.83864    │ 0.841912    │
# │ 6   │ 1640             │ -0.0887407 │ 0.0         │
# │ 7   │ 1694             │ -0.472854  │ -0.49127    │
# │ 8   │ 1834             │ 0.343333   │ 0.359513    │
# │ 9   │ 2069             │ -0.708985  │ -0.708672   │
# │ 10  │ 2225             │ -0.127798  │ 0.0         │
# n = 381, and p = 2286
# Total iteration number was 148
# Total time was 0.727679967880249
# running the 8 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β     │ estimated_β │
# │     │ Int64            │ Float64    │ Float64     │
# ├─────┼──────────────────┼────────────┼─────────────┤
# │ 1   │ 68               │ -1.48743   │ 0.0         │
# │ 2   │ 703              │ -0.795836  │ 0.0         │
# │ 3   │ 1090             │ 1.66489    │ 0.883119    │
# │ 4   │ 1339             │ -0.578599  │ 0.0         │
# │ 5   │ 1504             │ 2.59152    │ 2.14725     │
# │ 6   │ 1650             │ -0.0298617 │ 0.0         │
# │ 7   │ 2206             │ 0.912098   │ 0.0         │
# │ 8   │ 2341             │ -0.929545  │ 0.0         │
# │ 9   │ 2441             │ -0.208773  │ 0.0         │
# │ 10  │ 3213             │ 0.211867   │ 0.0         │
# n = 415, and p = 3320
# Total iteration number was 230
# Total time was 1.7463629245758057
# running the 9 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 38               │ 1.39259   │ 1.44811     │
# │ 2   │ 82               │ 0.133099  │ 0.0         │
# │ 3   │ 191              │ -0.488614 │ -0.429904   │
# │ 4   │ 330              │ 0.339619  │ 0.340842    │
# │ 5   │ 786              │ 0.17061   │ 0.112631    │
# │ 6   │ 791              │ 0.657659  │ 0.635344    │
# │ 7   │ 916              │ -1.30902  │ -1.32488    │
# │ 8   │ 1494             │ -0.621029 │ -0.625194   │
# │ 9   │ 1564             │ -0.854134 │ -0.798026   │
# │ 10  │ 1613             │ 0.748779  │ 0.790857    │
# n = 349, and p = 1745
# Total iteration number was 139
# Total time was 0.47955799102783203
# running the 10 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 562              │ 0.124931  │ 0.127433    │
# │ 2   │ 619              │ -0.795829 │ -0.893475   │
# │ 3   │ 776              │ 1.53435   │ 1.49094     │
# │ 4   │ 791              │ 1.19478   │ 1.1736      │
# │ 5   │ 872              │ -0.224463 │ 0.0         │
# │ 6   │ 1109             │ 0.955507  │ 0.962639    │
# │ 7   │ 1145             │ 0.0531558 │ 0.0         │
# │ 8   │ 1149             │ 0.805292  │ 0.814062    │
# │ 9   │ 1244             │ -2.0982   │ -2.07848    │
# │ 10  │ 1314             │ -1.71014  │ -1.68015    │
# n = 863, and p = 1726
# Total iteration number was 557
# Total time was 4.475462913513184
# running the 11 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β     │ estimated_β │
# │     │ Int64            │ Float64    │ Float64     │
# ├─────┼──────────────────┼────────────┼─────────────┤
# │ 1   │ 161              │ -1.08971   │ -1.10156    │
# │ 2   │ 564              │ 0.310247   │ 0.313029    │
# │ 3   │ 1160             │ -1.60742   │ -1.58377    │
# │ 4   │ 2492             │ -0.915153  │ -0.917168   │
# │ 5   │ 2868             │ 0.547258   │ 0.544285    │
# │ 6   │ 2879             │ 0.855384   │ 0.849069    │
# │ 7   │ 3019             │ 0.452041   │ 0.457309    │
# │ 8   │ 3623             │ -0.586104  │ -0.584402   │
# │ 9   │ 3628             │ -0.0280865 │ 0.0         │
# │ 10  │ 4053             │ -1.02079   │ -1.06182    │
# n = 705, and p = 4230
# Total iteration number was 802
# Total time was 12.890640020370483
# running the 12 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 44               │ -0.681026 │ -0.681218   │
# │ 2   │ 244              │ 0.253845  │ 0.24282     │
# │ 3   │ 955              │ 0.857279  │ 0.859497    │
# │ 4   │ 958              │ 0.894847  │ 0.901687    │
# │ 5   │ 1047             │ -1.08494  │ -1.08923    │
# │ 6   │ 1878             │ 0.362641  │ 0.364668    │
# │ 7   │ 2394             │ 0.518589  │ 0.519914    │
# │ 8   │ 2450             │ 0.796585  │ 0.786897    │
# │ 9   │ 2784             │ 0.358721  │ 0.350213    │
# │ 10  │ 3329             │ -1.1779   │ -1.17471    │
# n = 880, and p = 3520
# Total iteration number was 240
# Total time was 3.9240150451660156
# running the 13 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 2                │ -1.00869  │ 0.0         │
# │ 2   │ 46               │ 1.42458   │ 1.40494     │
# │ 3   │ 82               │ 1.10529   │ 0.0         │
# │ 4   │ 234              │ -1.34862  │ -0.937894   │
# │ 5   │ 268              │ 1.22262   │ 1.43913     │
# │ 6   │ 419              │ -2.1323   │ 0.0         │
# │ 7   │ 528              │ 1.83133   │ 1.86999     │
# │ 8   │ 539              │ -1.33239  │ 0.0         │
# │ 9   │ 704              │ 0.37109   │ 0.469838    │
# │ 10  │ 715              │ -0.992517 │ 0.0         │
# n = 924, and p = 924
# Total iteration number was 397
# Total time was 1.820214033126831
# running the 14 th model
# Did not converge!!!!! The run time for IHT was 2.1648409366607666seconds and model size was10compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 41               │ 0.757886  │ 0.0         │
# │ 2   │ 92               │ -2.07727  │ 0.0         │
# │ 3   │ 304              │ 0.626288  │ 0.0         │
# │ 4   │ 350              │ -0.178804 │ 0.0         │
# │ 5   │ 365              │ -0.131029 │ 0.0         │
# │ 6   │ 375              │ -2.73526  │ -0.526893   │
# │ 7   │ 440              │ 2.0555    │ 2.27377     │
# │ 8   │ 446              │ -1.48327  │ 0.0         │
# │ 9   │ 461              │ 1.23944   │ 0.0         │
# │ 10  │ 538              │ -0.17593  │ 0.0         │
# n = 621, and p = 621
# Total iteration number was 1000
# Total time was 2.1648409366607666
# running the 15 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 511              │ 0.118112  │ 0.0         │
# │ 2   │ 541              │ 0.699117  │ 0.648462    │
# │ 3   │ 667              │ -1.03564  │ -1.01881    │
# │ 4   │ 1261             │ -0.139732 │ 0.0         │
# │ 5   │ 1718             │ -0.537753 │ -0.487782   │
# │ 6   │ 2393             │ -1.10875  │ -1.05024    │
# │ 7   │ 2479             │ -1.70926  │ -1.73257    │
# │ 8   │ 2583             │ -0.554008 │ -0.488221   │
# │ 9   │ 2747             │ -0.81002  │ 0.0         │
# │ 10  │ 3079             │ -0.428315 │ 0.0         │
# n = 389, and p = 3501
# Total iteration number was 239
# Total time was 1.8447868824005127
# running the 16 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 363              │ -0.140406 │ 0.0         │
# │ 2   │ 511              │ 0.972304  │ 0.825807    │
# │ 3   │ 844              │ -0.264245 │ 0.0         │
# │ 4   │ 872              │ -1.03492  │ 0.0         │
# │ 5   │ 1029             │ -0.621999 │ 0.0         │
# │ 6   │ 1117             │ 1.61299   │ 1.24186     │
# │ 7   │ 1120             │ 0.203114  │ 0.0         │
# │ 8   │ 1143             │ -0.810384 │ 0.0         │
# │ 9   │ 1173             │ -0.250604 │ 0.0         │
# │ 10  │ 1182             │ 1.86997   │ 1.24782     │
# n = 209, and p = 1881
# Total iteration number was 390
# Total time was 0.9233109951019287
# running the 17 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β     │ estimated_β │
# │     │ Int64            │ Float64    │ Float64     │
# ├─────┼──────────────────┼────────────┼─────────────┤
# │ 1   │ 542              │ 0.432155   │ 0.0         │
# │ 2   │ 550              │ 0.776498   │ 0.0         │
# │ 3   │ 1393             │ 0.853735   │ 0.0         │
# │ 4   │ 1454             │ -0.100404  │ 0.0         │
# │ 5   │ 1638             │ 0.314241   │ 0.0         │
# │ 6   │ 1927             │ -0.0563195 │ 0.0         │
# │ 7   │ 2347             │ 1.2173     │ 1.03829     │
# │ 8   │ 2374             │ 0.576761   │ 0.0         │
# │ 9   │ 2411             │ 0.629584   │ 0.822116    │
# │ 10  │ 2559             │ -0.921601  │ -0.814401   │
# n = 322, and p = 2898
# Total iteration number was 163
# Total time was 0.9027149677276611
# running the 18 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β     │ estimated_β │
# │     │ Int64            │ Float64    │ Float64     │
# ├─────┼──────────────────┼────────────┼─────────────┤
# │ 1   │ 3                │ -0.0505672 │ 0.0         │
# │ 2   │ 33               │ 0.75141    │ 0.0         │
# │ 3   │ 34               │ 0.841058   │ 0.0         │
# │ 4   │ 123              │ 0.359916   │ 0.0         │
# │ 5   │ 130              │ 1.67914    │ 0.9573      │
# │ 6   │ 225              │ -0.677769  │ 0.0         │
# │ 7   │ 257              │ 0.331408   │ 0.0         │
# │ 8   │ 286              │ 2.31911    │ 2.11638     │
# │ 9   │ 291              │ 1.62906    │ 1.23784     │
# │ 10  │ 301              │ 0.625798   │ 0.0         │
# n = 112, and p = 336
# Total iteration number was 782
# Total time was 0.20271682739257812
# running the 19 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 11               │ -2.05429  │ -2.16059    │
# │ 2   │ 37               │ -2.92845  │ 0.0         │
# │ 3   │ 39               │ 0.0841235 │ 0.0         │
# │ 4   │ 61               │ -0.194861 │ 0.0         │
# │ 5   │ 80               │ 1.69692   │ 1.5422      │
# │ 6   │ 100              │ -0.741036 │ 0.0         │
# │ 7   │ 131              │ 0.460113  │ 0.42325     │
# │ 8   │ 183              │ -0.970978 │ -1.05866    │
# │ 9   │ 196              │ 0.105389  │ 0.0         │
# │ 10  │ 226              │ 1.87352   │ 1.8351      │
# n = 267, and p = 267
# Total iteration number was 603
# Total time was 0.2774848937988281
# running the 20 th model
# Did not converge!!!!! The run time for IHT was 0.5141520500183105seconds and model size was10compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β     │ estimated_β │
# │     │ Int64            │ Float64    │ Float64     │
# ├─────┼──────────────────┼────────────┼─────────────┤
# │ 1   │ 14               │ -1.95471   │ 0.0         │
# │ 2   │ 46               │ 2.10265    │ 1.49402     │
# │ 3   │ 74               │ 1.49617    │ 0.135003    │
# │ 4   │ 116              │ -1.36898   │ 0.0         │
# │ 5   │ 131              │ -0.0846486 │ 0.0         │
# │ 6   │ 158              │ 2.12975    │ 0.0         │
# │ 7   │ 159              │ 0.508735   │ 0.0         │
# │ 8   │ 200              │ 1.04357    │ 0.0         │
# │ 9   │ 222              │ 0.361687   │ 0.0         │
# │ 10  │ 246              │ 1.58743    │ 1.03881     │
# n = 289, and p = 289
# Total iteration number was 1000
# Total time was 0.5141520500183105
# running the 21 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β      │ estimated_β │
# │     │ Int64            │ Float64     │ Float64     │
# ├─────┼──────────────────┼─────────────┼─────────────┤
# │ 1   │ 216              │ -0.00549474 │ 0.0         │
# │ 2   │ 1723             │ 0.243156    │ 0.0         │
# │ 3   │ 2792             │ 0.853295    │ 0.0         │
# │ 4   │ 3003             │ 0.776168    │ 0.0         │
# │ 5   │ 3188             │ 0.852805    │ 0.0         │
# │ 6   │ 3264             │ 0.0899217   │ 0.0         │
# │ 7   │ 4005             │ 0.0419151   │ 0.0         │
# │ 8   │ 5504             │ -0.0682509  │ 0.0         │
# │ 9   │ 5696             │ -1.20109    │ 0.0         │
# │ 10  │ 7246             │ 1.86168     │ 1.50214     │
# n = 813, and p = 7317
# Total iteration number was 784
# Total time was 24.41868805885315
# running the 22 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 55               │ 0.577724  │ 0.583356    │
# │ 2   │ 492              │ -1.22015  │ -1.19517    │
# │ 3   │ 1547             │ 0.0552035 │ 0.0         │
# │ 4   │ 1665             │ 1.2381    │ 1.25094     │
# │ 5   │ 1811             │ 0.840435  │ 0.857946    │
# │ 6   │ 1993             │ 1.00507   │ 1.02351     │
# │ 7   │ 2118             │ -0.528816 │ -0.545347   │
# │ 8   │ 2709             │ -1.41951  │ -1.45048    │
# │ 9   │ 2988             │ -0.378802 │ 0.0         │
# │ 10  │ 3017             │ 0.718717  │ 0.709347    │
# n = 979, and p = 3916
# Total iteration number was 536
# Total time was 10.930308103561401
# running the 23 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 499              │ 1.25822   │ 1.11061     │
# │ 2   │ 572              │ 0.671173  │ 0.724594    │
# │ 3   │ 833              │ 0.112519  │ 0.0         │
# │ 4   │ 1557             │ -0.6364   │ 0.0         │
# │ 5   │ 1689             │ 0.935555  │ 0.992715    │
# │ 6   │ 1773             │ -0.947858 │ -0.863106   │
# │ 7   │ 1964             │ -0.341796 │ 0.0         │
# │ 8   │ 2107             │ 1.45633   │ 1.31725     │
# │ 9   │ 2124             │ -0.26937  │ 0.0         │
# │ 10  │ 2302             │ -1.00693  │ -0.917849   │
# n = 652, and p = 2608
# Total iteration number was 358
# Total time was 3.2252581119537354
# running the 24 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 46               │ -0.103629 │ 0.0         │
# │ 2   │ 438              │ 0.0477613 │ 0.0         │
# │ 3   │ 498              │ -0.287304 │ -0.263749   │
# │ 4   │ 510              │ 0.276582  │ 0.294803    │
# │ 5   │ 546              │ 0.250121  │ 0.255146    │
# │ 6   │ 1273             │ -0.943794 │ -1.045      │
# │ 7   │ 1845             │ -0.405352 │ -0.375126   │
# │ 8   │ 1894             │ -0.256796 │ -0.2713     │
# │ 9   │ 2349             │ -0.280624 │ -0.217825   │
# │ 10  │ 2366             │ 0.154176  │ 0.108661    │
# n = 868, and p = 2604
# Total iteration number was 109
# Total time was 1.4278638362884521
# running the 25 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 385              │ -1.71685  │ -1.57612    │
# │ 2   │ 1309             │ -0.185086 │ 0.0         │
# │ 3   │ 1372             │ -0.650541 │ 0.0         │
# │ 4   │ 1637             │ 1.49752   │ 1.5362      │
# │ 5   │ 1663             │ 1.78782   │ 1.61963     │
# │ 6   │ 1756             │ -0.625322 │ 0.0         │
# │ 7   │ 1884             │ 1.02716   │ 0.772665    │
# │ 8   │ 2014             │ -0.322396 │ 0.0         │
# │ 9   │ 3009             │ 0.580053  │ 0.0         │
# │ 10  │ 3138             │ -0.509701 │ 0.0         │
# n = 394, and p = 3152
# Total iteration number was 721
# Total time was 4.8630530834198
# running the 26 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 884              │ -0.130509 │ -0.095074   │
# │ 2   │ 1001             │ -0.925577 │ -0.920324   │
# │ 3   │ 1384             │ -0.965563 │ -0.932849   │
# │ 4   │ 2076             │ 2.22436   │ 2.23654     │
# │ 5   │ 2194             │ -0.28869  │ -0.318595   │
# │ 6   │ 2423             │ -0.151669 │ 0.0         │
# │ 7   │ 2459             │ -0.448679 │ -0.437684   │
# │ 8   │ 3239             │ -1.97753  │ -1.99764    │
# │ 9   │ 3344             │ -1.16454  │ -1.17235    │
# │ 10  │ 3459             │ 2.50329   │ 2.46948     │
# n = 873, and p = 3492
# Total iteration number was 447
# Total time was 7.158488988876343
# running the 27 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 116              │ 0.745773  │ 0.75011     │
# │ 2   │ 513              │ -0.940917 │ -0.91967    │
# │ 3   │ 1244             │ 0.480652  │ 0.474269    │
# │ 4   │ 1648             │ -1.20865  │ -1.23985    │
# │ 5   │ 1861             │ -0.123853 │ -0.129462   │
# │ 6   │ 2548             │ 0.705525  │ 0.710505    │
# │ 7   │ 2839             │ -0.654802 │ -0.658973   │
# │ 8   │ 2973             │ 0.141787  │ 0.134334    │
# │ 9   │ 3111             │ 0.713215  │ 0.7045      │
# │ 10  │ 4759             │ -0.893423 │ -0.878645   │
# n = 977, and p = 4885
# Total iteration number was 148
# Total time was 3.689399003982544
# running the 28 th model
# Did not converge!!!!! The run time for IHT was 25.908963203430176seconds and model size was10compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 1192             │ 0.677972  │ 0.0         │
# │ 2   │ 1380             │ -0.353286 │ 0.0         │
# │ 3   │ 1464             │ 1.19229   │ 0.63586     │
# │ 4   │ 1609             │ 0.140739  │ 0.0         │
# │ 5   │ 2878             │ 0.518511  │ 0.0         │
# │ 6   │ 3394             │ 0.942017  │ 0.0         │
# │ 7   │ 3484             │ -1.01236  │ 0.0         │
# │ 8   │ 3988             │ 1.30722   │ 0.0         │
# │ 9   │ 4268             │ -1.41581  │ 0.0         │
# │ 10  │ 4380             │ -0.926679 │ 0.0         │
# n = 946, and p = 4730
# Total iteration number was 1000
# Total time was 25.908963203430176
# running the 29 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 4                │ -0.604686 │ -0.474728   │
# │ 2   │ 83               │ 0.340345  │ 0.0         │
# │ 3   │ 117              │ -0.935976 │ -0.851319   │
# │ 4   │ 185              │ 1.17239   │ 0.882256    │
# │ 5   │ 206              │ -0.50155  │ 0.0         │
# │ 6   │ 210              │ -0.729232 │ 0.0         │
# │ 7   │ 234              │ 1.79241   │ 1.31286     │
# │ 8   │ 284              │ -0.487973 │ 0.0         │
# │ 9   │ 305              │ -0.346742 │ 0.0         │
# │ 10  │ 307              │ 0.642685  │ 0.448133    │
# n = 156, and p = 312
# Total iteration number was 212
# Total time was 0.08552718162536621
# running the 30 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β     │ estimated_β │
# │     │ Int64            │ Float64    │ Float64     │
# ├─────┼──────────────────┼────────────┼─────────────┤
# │ 1   │ 23               │ 1.42554    │ 1.3643      │
# │ 2   │ 243              │ -0.238907  │ 0.0         │
# │ 3   │ 289              │ -1.28713   │ 0.0         │
# │ 4   │ 315              │ -0.533174  │ -0.430395   │
# │ 5   │ 359              │ -0.0260459 │ 0.0         │
# │ 6   │ 538              │ 0.309159   │ 0.0         │
# │ 7   │ 544              │ -0.577136  │ -0.451136   │
# │ 8   │ 619              │ -1.29438   │ -1.2597     │
# │ 9   │ 787              │ -0.491157  │ -0.425818   │
# │ 10  │ 791              │ -1.25691   │ -1.15425    │
# n = 449, and p = 898
# Total iteration number was 227
# Total time was 0.5342850685119629
# running the 31 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 460              │ -0.269799 │ 0.0         │
# │ 2   │ 1375             │ -0.261944 │ 0.0         │
# │ 3   │ 1795             │ -0.786238 │ -0.641464   │
# │ 4   │ 2056             │ -0.263135 │ 0.0         │
# │ 5   │ 2650             │ 0.360541  │ 0.585176    │
# │ 6   │ 2909             │ 0.0568693 │ 0.0         │
# │ 7   │ 2917             │ 1.56935   │ 1.58884     │
# │ 8   │ 3203             │ -0.645285 │ -0.681691   │
# │ 9   │ 3373             │ 0.521789  │ 0.0         │
# │ 10  │ 3930             │ 1.7688    │ 1.63969     │
# n = 724, and p = 4344
# Total iteration number was 660
# Total time was 11.39623212814331
# running the 32 th model
# Did not converge!!!!! The run time for IHT was 9.44737982749939seconds and model size was10compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 224              │ 1.68049   │ 0.0         │
# │ 2   │ 743              │ -0.723356 │ 0.0         │
# │ 3   │ 789              │ 1.98237   │ 1.55869     │
# │ 4   │ 1463             │ 0.377376  │ 0.0         │
# │ 5   │ 1523             │ -0.380155 │ 0.0         │
# │ 6   │ 1596             │ 0.448699  │ 0.0         │
# │ 7   │ 1654             │ -0.218335 │ 0.0         │
# │ 8   │ 1666             │ 1.02595   │ 0.0         │
# │ 9   │ 1991             │ -0.760957 │ 0.0         │
# │ 10  │ 2650             │ 1.13363   │ 0.0         │
# n = 540, and p = 3240
# Total iteration number was 1000
# Total time was 9.44737982749939
# running the 33 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 150              │ -0.37064  │ 0.0         │
# │ 2   │ 210              │ -0.573208 │ 0.0         │
# │ 3   │ 263              │ 0.75701   │ 0.254168    │
# │ 4   │ 274              │ -1.72702  │ 0.0         │
# │ 5   │ 275              │ -1.63346  │ 0.0         │
# │ 6   │ 288              │ 0.548325  │ 0.0         │
# │ 7   │ 465              │ -0.619983 │ 0.0         │
# │ 8   │ 693              │ 0.510067  │ 0.0         │
# │ 9   │ 717              │ 0.546565  │ 0.0         │
# │ 10  │ 751              │ 0.905606  │ 0.333547    │
# n = 152, and p = 760
# Total iteration number was 78
# Total time was 0.0594789981842041
# running the 34 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β     │ estimated_β │
# │     │ Int64            │ Float64    │ Float64     │
# ├─────┼──────────────────┼────────────┼─────────────┤
# │ 1   │ 42               │ 0.285661   │ 0.0         │
# │ 2   │ 155              │ -1.0513    │ 0.0         │
# │ 3   │ 302              │ 0.697329   │ 0.0         │
# │ 4   │ 701              │ -0.808778  │ 0.0         │
# │ 5   │ 879              │ 0.635265   │ 0.0         │
# │ 6   │ 1438             │ -1.73075   │ 0.0         │
# │ 7   │ 1485             │ 1.58495    │ 0.924388    │
# │ 8   │ 1505             │ -0.0734955 │ 0.0         │
# │ 9   │ 1516             │ -0.471331  │ 0.0         │
# │ 10  │ 1536             │ -1.08618   │ 0.0         │
# n = 192, and p = 1536
# Total iteration number was 338
# Total time was 0.5911920070648193
# running the 35 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 7                │ -1.67124  │ -1.63141    │
# │ 2   │ 447              │ -0.420665 │ -0.402573   │
# │ 3   │ 688              │ -0.229041 │ -0.231088   │
# │ 4   │ 939              │ 0.524695  │ 0.525124    │
# │ 5   │ 1026             │ 0.768628  │ 0.748991    │
# │ 6   │ 1054             │ 0.948637  │ 0.928702    │
# │ 7   │ 1301             │ -1.20086  │ 0.0         │
# │ 8   │ 1375             │ 0.0212101 │ 0.0         │
# │ 9   │ 1397             │ -0.777771 │ -0.779928   │
# │ 10  │ 1488             │ 0.187112  │ 0.213411    │
# n = 772, and p = 1544
# Total iteration number was 209
# Total time was 1.3554348945617676
# running the 36 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 10               │ -0.444259 │ 0.0         │
# │ 2   │ 97               │ -0.142126 │ 0.0         │
# │ 3   │ 158              │ -0.968681 │ 0.0         │
# │ 4   │ 294              │ -0.275917 │ 0.0         │
# │ 5   │ 307              │ 0.880513  │ 1.07732     │
# │ 6   │ 388              │ 2.69093   │ 2.72628     │
# │ 7   │ 620              │ -0.693293 │ 0.0         │
# │ 8   │ 727              │ 0.0393477 │ 0.0         │
# │ 9   │ 752              │ -0.548876 │ -0.455581   │
# │ 10  │ 872              │ -0.367998 │ 0.0         │
# n = 347, and p = 1041
# Total iteration number was 637
# Total time was 1.3194961547851562
# running the 37 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β     │ estimated_β │
# │     │ Int64            │ Float64    │ Float64     │
# ├─────┼──────────────────┼────────────┼─────────────┤
# │ 1   │ 1761             │ -1.27731   │ 0.0         │
# │ 2   │ 1882             │ 0.00447914 │ 0.0         │
# │ 3   │ 1933             │ 0.291208   │ 0.0         │
# │ 4   │ 2260             │ -0.398879  │ 0.0         │
# │ 5   │ 2462             │ 0.560748   │ 0.0         │
# │ 6   │ 2468             │ -0.219226  │ 0.0         │
# │ 7   │ 2665             │ -0.402761  │ 0.0         │
# │ 8   │ 2670             │ 1.18859    │ 0.854671    │
# │ 9   │ 2969             │ 0.570119   │ 0.0         │
# │ 10  │ 3079             │ 0.7175     │ 0.593142    │
# n = 506, and p = 3542
# Total iteration number was 128
# Total time was 1.2567288875579834
# running the 38 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β     │ estimated_β │
# │     │ Int64            │ Float64    │ Float64     │
# ├─────┼──────────────────┼────────────┼─────────────┤
# │ 1   │ 14               │ 0.248844   │ 0.292716    │
# │ 2   │ 91               │ 0.88682    │ 0.865402    │
# │ 3   │ 258              │ 0.183982   │ 0.17789     │
# │ 4   │ 307              │ 0.0880354  │ 0.107016    │
# │ 5   │ 476              │ -0.0604917 │ 0.0         │
# │ 6   │ 759              │ 0.493076   │ 0.475282    │
# │ 7   │ 827              │ 0.688102   │ 0.673691    │
# │ 8   │ 830              │ -0.587855  │ -0.572414   │
# │ 9   │ 957              │ 1.14639    │ 1.15164     │
# │ 10  │ 1024             │ 0.031428   │ 0.0         │
# n = 522, and p = 1044
# Total iteration number was 131
# Total time was 0.3998231887817383
# running the 39 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 14               │ 2.20445   │ 1.81031     │
# │ 2   │ 652              │ 0.781649  │ 0.0         │
# │ 3   │ 678              │ -0.76484  │ 0.0         │
# │ 4   │ 691              │ -0.317928 │ 0.0         │
# │ 5   │ 807              │ -0.326294 │ 0.0         │
# │ 6   │ 810              │ -1.54146  │ -1.31658    │
# │ 7   │ 856              │ -0.223274 │ 0.0         │
# │ 8   │ 1074             │ 0.270643  │ 0.0         │
# │ 9   │ 1186             │ 0.284055  │ 0.0         │
# │ 10  │ 1749             │ -0.12734  │ 0.0         │
# n = 201, and p = 2010
# Total iteration number was 375
# Total time was 0.9113130569458008
# running the 40 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β     │ estimated_β │
# │     │ Int64            │ Float64    │ Float64     │
# ├─────┼──────────────────┼────────────┼─────────────┤
# │ 1   │ 7                │ -0.0294044 │ 0.0         │
# │ 2   │ 40               │ -1.06827   │ 0.0         │
# │ 3   │ 354              │ -0.110548  │ 0.0         │
# │ 4   │ 357              │ 1.38117    │ 0.772441    │
# │ 5   │ 379              │ -1.07387   │ 0.0         │
# │ 6   │ 394              │ 0.908613   │ 0.0         │
# │ 7   │ 829              │ 1.20217    │ 0.0         │
# │ 8   │ 848              │ 0.059126   │ 0.0         │
# │ 9   │ 853              │ 0.295695   │ 0.0         │
# │ 10  │ 885              │ -0.558022  │ 0.0         │
# n = 175, and p = 1050
# Total iteration number was 219
# Total time was 0.25116896629333496
# running the 41 th model
# Did not converge!!!!! The run time for IHT was 50.90246105194092seconds and model size was10compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β     │ estimated_β │
# │     │ Int64            │ Float64    │ Float64     │
# ├─────┼──────────────────┼────────────┼─────────────┤
# │ 1   │ 1707             │ -0.925414  │ 0.0         │
# │ 2   │ 1863             │ -0.0554741 │ 0.0         │
# │ 3   │ 1981             │ 1.31658    │ 1.50623     │
# │ 4   │ 2786             │ -0.925834  │ -0.706662   │
# │ 5   │ 3097             │ 0.871542   │ 0.911981    │
# │ 6   │ 3346             │ -0.617891  │ 0.0         │
# │ 7   │ 3625             │ -2.17723   │ -2.40777    │
# │ 8   │ 5941             │ 1.35523    │ 1.69495     │
# │ 9   │ 8722             │ -2.15401   │ 0.0         │
# │ 10  │ 8780             │ 0.0341342  │ 0.0         │
# n = 1000, and p = 9000
# Total iteration number was 1000
# Total time was 50.90246105194092
# running the 42 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 1                │ -1.5583   │ -1.3314     │
# │ 2   │ 13               │ -1.03237  │ 0.0         │
# │ 3   │ 22               │ 0.160932  │ 0.0         │
# │ 4   │ 55               │ -0.208074 │ 0.0         │
# │ 5   │ 133              │ -1.36218  │ -1.02481    │
# │ 6   │ 138              │ -0.973333 │ -0.833787   │
# │ 7   │ 153              │ -1.33654  │ -1.23771    │
# │ 8   │ 177              │ -0.241081 │ 0.0         │
# │ 9   │ 183              │ 0.238239  │ 0.0         │
# │ 10  │ 195              │ -0.65069  │ 0.0         │
# n = 211, and p = 211
# Total iteration number was 209
# Total time was 0.07380199432373047
# running the 43 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β      │ estimated_β │
# │     │ Int64            │ Float64     │ Float64     │
# ├─────┼──────────────────┼─────────────┼─────────────┤
# │ 1   │ 7                │ 0.127928    │ 0.0         │
# │ 2   │ 9                │ -0.261129   │ -0.214616   │
# │ 3   │ 26               │ 0.649406    │ 0.572445    │
# │ 4   │ 62               │ 1.39231     │ 1.30779     │
# │ 5   │ 101              │ 0.525287    │ 0.53336     │
# │ 6   │ 141              │ -1.27387    │ -1.28564    │
# │ 7   │ 143              │ -0.00537211 │ 0.0         │
# │ 8   │ 265              │ -0.42079    │ 0.0         │
# │ 9   │ 326              │ 0.197113    │ 0.0         │
# │ 10  │ 357              │ -1.14754    │ -1.13157    │
# n = 140, and p = 420
# Total iteration number was 204
# Total time was 0.102294921875
# running the 44 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 38               │ 0.551343  │ 0.0         │
# │ 2   │ 187              │ -1.03423  │ 0.0         │
# │ 3   │ 238              │ 1.59702   │ 0.0         │
# │ 4   │ 984              │ 0.566048  │ 0.0         │
# │ 5   │ 1045             │ 2.00309   │ 0.0         │
# │ 6   │ 1500             │ 1.58862   │ 0.644457    │
# │ 7   │ 1960             │ 0.875098  │ 0.0         │
# │ 8   │ 2013             │ 0.202974  │ 0.0         │
# │ 9   │ 2155             │ -0.682445 │ 0.0         │
# │ 10  │ 2169             │ -0.876886 │ 0.0         │
# n = 398, and p = 2388
# Total iteration number was 390
# Total time was 2.129473924636841
# running the 45 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β   │ estimated_β │
# │     │ Int64            │ Float64  │ Float64     │
# ├─────┼──────────────────┼──────────┼─────────────┤
# │ 1   │ 1901             │ 0.912556 │ 0.937449    │
# │ 2   │ 2256             │ 0.757645 │ 0.760935    │
# │ 3   │ 2452             │ -0.70404 │ -0.695198   │
# │ 4   │ 3660             │ 0.313488 │ 0.307099    │
# │ 5   │ 4426             │ 0.217216 │ 0.213303    │
# │ 6   │ 6851             │ 0.687455 │ 0.682454    │
# │ 7   │ 7099             │ -0.46093 │ -0.465595   │
# │ 8   │ 7774             │ 0.920593 │ 0.9087      │
# │ 9   │ 7879             │ 0.399584 │ 0.404831    │
# │ 10  │ 8003             │ -0.73543 │ -0.733356   │
# n = 926, and p = 8334
# Total iteration number was 205
# Total time was 8.629943132400513
# running the 46 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 108              │ -1.13177  │ -1.14426    │
# │ 2   │ 456              │ -0.487575 │ 0.0         │
# │ 3   │ 467              │ 1.86552   │ 1.80834     │
# │ 4   │ 478              │ -0.967509 │ 0.0         │
# │ 5   │ 655              │ 0.490133  │ 0.0         │
# │ 6   │ 1007             │ -0.88405  │ -0.511124   │
# │ 7   │ 1741             │ -0.601674 │ 0.0         │
# │ 8   │ 1797             │ -2.14455  │ -1.8303     │
# │ 9   │ 2153             │ -0.951363 │ 0.0         │
# │ 10  │ 3236             │ 0.485727  │ 0.440842    │
# n = 383, and p = 3830
# Total iteration number was 273
# Total time was 2.2824230194091797
# running the 47 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β     │ estimated_β │
# │     │ Int64            │ Float64    │ Float64     │
# ├─────┼──────────────────┼────────────┼─────────────┤
# │ 1   │ 1                │ -1.2192    │ 0.0         │
# │ 2   │ 105              │ -0.889355  │ 0.0         │
# │ 3   │ 188              │ 1.72594    │ 0.995281    │
# │ 4   │ 229              │ 0.108483   │ 0.0         │
# │ 5   │ 230              │ -0.0621348 │ 0.0         │
# │ 6   │ 329              │ 0.0459511  │ 0.0         │
# │ 7   │ 397              │ -0.6537    │ -0.515845   │
# │ 8   │ 412              │ 0.496588   │ 0.0         │
# │ 9   │ 427              │ -1.54692   │ -1.17756    │
# │ 10  │ 501              │ -2.70399   │ 0.0         │
# n = 167, and p = 501
# Total iteration number was 157
# Total time was 0.08843183517456055
# running the 48 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 29               │ -0.999353 │ -1.0013     │
# │ 2   │ 125              │ 1.43823   │ 1.44663     │
# │ 3   │ 646              │ -0.454303 │ 0.0         │
# │ 4   │ 1216             │ -0.166703 │ -0.186937   │
# │ 5   │ 1252             │ 0.520951  │ 0.528107    │
# │ 6   │ 1646             │ 1.01153   │ 1.01481     │
# │ 7   │ 2005             │ -1.19321  │ -1.22078    │
# │ 8   │ 2074             │ -0.450632 │ -0.445054   │
# │ 9   │ 3053             │ 1.27498   │ 1.28259     │
# │ 10  │ 3126             │ 0.874746  │ 0.890232    │
# n = 642, and p = 3210
# Total iteration number was 535
# Total time was 5.963166952133179
# running the 49 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 16               │ 1.06156   │ 1.11689     │
# │ 2   │ 39               │ -1.27002  │ 0.0         │
# │ 3   │ 180              │ 0.516293  │ 0.0         │
# │ 4   │ 203              │ 0.411396  │ 0.0         │
# │ 5   │ 242              │ 1.01333   │ 0.938057    │
# │ 6   │ 322              │ 0.346051  │ 0.0         │
# │ 7   │ 609              │ -0.126751 │ 0.0         │
# │ 8   │ 890              │ -2.89252  │ 0.0         │
# │ 9   │ 976              │ -0.124032 │ 0.0         │
# │ 10  │ 1133             │ 0.108216  │ 0.0         │
# n = 381, and p = 1143
# Total iteration number was 341
# Total time was 0.8447690010070801
# running the 50 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 15               │ -1.22099  │ -1.16079    │
# │ 2   │ 94               │ 1.31426   │ 1.30272     │
# │ 3   │ 374              │ -0.552073 │ -0.551574   │
# │ 4   │ 504              │ -0.831403 │ -0.529436   │
# │ 5   │ 514              │ -1.02068  │ -0.99417    │
# │ 6   │ 971              │ 1.08155   │ 1.0837      │
# │ 7   │ 1237             │ 0.79984   │ 0.79967     │
# │ 8   │ 1288             │ 0.140363  │ 0.135742    │
# │ 9   │ 1467             │ 0.0392763 │ 0.0         │
# │ 10  │ 1485             │ 0.727792  │ 0.74652     │
# n = 921, and p = 1842
# Total iteration number was 718
# Total time was 6.60131311416626
# running the 51 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β     │ estimated_β │
# │     │ Int64            │ Float64    │ Float64     │
# ├─────┼──────────────────┼────────────┼─────────────┤
# │ 1   │ 883              │ -0.0654802 │ 0.0         │
# │ 2   │ 1356             │ 0.347418   │ 0.0         │
# │ 3   │ 2473             │ 1.14738    │ 0.930932    │
# │ 4   │ 2896             │ 0.0815164  │ 0.0         │
# │ 5   │ 3414             │ -1.0354    │ -0.850227   │
# │ 6   │ 3595             │ 0.419804   │ 0.400676    │
# │ 7   │ 4006             │ 0.517367   │ 0.0         │
# │ 8   │ 4494             │ 0.455376   │ 0.0         │
# │ 9   │ 4709             │ 1.30705    │ 1.14818     │
# │ 10  │ 4956             │ 1.04452    │ 0.961696    │
# n = 928, and p = 5568
# Total iteration number was 930
# Total time was 25.44179606437683
# running the 52 th model
# Did not converge!!!!! The run time for IHT was 23.81335186958313seconds and model size was10compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β     │ estimated_β │
# │     │ Int64            │ Float64    │ Float64     │
# ├─────┼──────────────────┼────────────┼─────────────┤
# │ 1   │ 380              │ -0.26975   │ 0.0         │
# │ 2   │ 932              │ -1.17707   │ 0.0         │
# │ 3   │ 1565             │ -0.591201  │ 0.0         │
# │ 4   │ 1985             │ -1.22238   │ 0.0         │
# │ 5   │ 2454             │ 1.1233     │ 1.03363     │
# │ 6   │ 2566             │ -0.0878101 │ 0.0         │
# │ 7   │ 2589             │ -1.46737   │ 0.0         │
# │ 8   │ 3672             │ 1.04029    │ 0.0         │
# │ 9   │ 5343             │ 1.16667    │ 1.31923     │
# │ 10  │ 5830             │ 0.366024   │ 0.0         │
# n = 665, and p = 6650
# Total iteration number was 1000
# Total time was 23.81335186958313
# running the 53 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 884              │ -1.00701  │ -0.743552   │
# │ 2   │ 2422             │ 0.436847  │ 0.0         │
# │ 3   │ 2579             │ -0.130457 │ 0.0         │
# │ 4   │ 2854             │ 0.190212  │ 0.0         │
# │ 5   │ 2874             │ 1.63697   │ 1.48783     │
# │ 6   │ 3860             │ 0.872044  │ 0.764832    │
# │ 7   │ 4546             │ 0.153013  │ 0.0         │
# │ 8   │ 4631             │ 1.38083   │ 1.11854     │
# │ 9   │ 6900             │ 0.36746   │ 0.0         │
# │ 10  │ 7432             │ -0.859501 │ 0.0         │
# n = 953, and p = 7624
# Total iteration number was 283
# Total time was 11.054199934005737
# running the 54 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 349              │ 0.384318  │ 0.0         │
# │ 2   │ 784              │ 0.747943  │ 0.0         │
# │ 3   │ 1115             │ -2.46277  │ 0.0         │
# │ 4   │ 1329             │ 0.708602  │ 0.0         │
# │ 5   │ 1508             │ 1.76522   │ 1.95005     │
# │ 6   │ 1980             │ -0.952782 │ 0.0         │
# │ 7   │ 2198             │ 0.631387  │ 0.0         │
# │ 8   │ 2928             │ 1.74772   │ 1.32325     │
# │ 9   │ 3318             │ 1.80918   │ 0.0         │
# │ 10  │ 3641             │ 1.95678   │ 0.0         │
# n = 366, and p = 3660
# Total iteration number was 706
# Total time was 5.306982040405273
# running the 55 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β     │ estimated_β │
# │     │ Int64            │ Float64    │ Float64     │
# ├─────┼──────────────────┼────────────┼─────────────┤
# │ 1   │ 2                │ 0.822507   │ 0.0         │
# │ 2   │ 74               │ 0.949516   │ 0.0         │
# │ 3   │ 138              │ 1.40002    │ 1.1836      │
# │ 4   │ 223              │ 0.944922   │ 0.0         │
# │ 5   │ 298              │ -0.195353  │ 0.0         │
# │ 6   │ 301              │ -0.49212   │ 0.0         │
# │ 7   │ 409              │ 0.63503    │ 0.0         │
# │ 8   │ 414              │ -0.520861  │ 0.0         │
# │ 9   │ 471              │ 1.80799    │ 1.52682     │
# │ 10  │ 681              │ -0.0363247 │ 0.0         │
# n = 392, and p = 784
# Total iteration number was 480
# Total time was 0.858942985534668
# running the 56 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β     │ estimated_β │
# │     │ Int64            │ Float64    │ Float64     │
# ├─────┼──────────────────┼────────────┼─────────────┤
# │ 1   │ 480              │ -0.316475  │ -0.419548   │
# │ 2   │ 638              │ -0.529409  │ 0.0         │
# │ 3   │ 716              │ 0.0574962  │ 0.0         │
# │ 4   │ 1121             │ 0.659423   │ 0.618163    │
# │ 5   │ 1501             │ -0.92179   │ -0.800552   │
# │ 6   │ 1502             │ 0.0848251  │ 0.0         │
# │ 7   │ 1537             │ 1.27798    │ 1.36417     │
# │ 8   │ 1539             │ 0.6236     │ 0.68024     │
# │ 9   │ 1621             │ -0.287553  │ 0.0         │
# │ 10  │ 2366             │ -0.0837092 │ 0.0         │
# n = 303, and p = 2424
# Total iteration number was 88
# Total time was 0.3960280418395996
# running the 57 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β     │ estimated_β │
# │     │ Int64            │ Float64    │ Float64     │
# ├─────┼──────────────────┼────────────┼─────────────┤
# │ 1   │ 60               │ 0.262467   │ 0.211392    │
# │ 2   │ 575              │ -0.41473   │ 0.0         │
# │ 3   │ 595              │ -0.0215137 │ 0.0         │
# │ 4   │ 598              │ 0.339165   │ 0.2736      │
# │ 5   │ 645              │ 1.2174     │ 1.18694     │
# │ 6   │ 760              │ -0.484736  │ -0.602928   │
# │ 7   │ 769              │ -0.614949  │ -0.706848   │
# │ 8   │ 1484             │ -0.213662  │ 0.0         │
# ...
# n = 829, and p = 3316
# Total iteration number was 1000
# Total time was 14.3262619972229
# running the 82 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 215              │ 0.235974  │ 0.0         │
# │ 2   │ 465              │ 0.147248  │ 0.0         │
# │ 3   │ 658              │ 0.525844  │ 0.0         │
# │ 4   │ 674              │ -0.681091 │ -0.599194   │
# │ 5   │ 773              │ 1.32876   │ 1.13318     │
# │ 6   │ 1477             │ 1.32084   │ 1.31231     │
# │ 7   │ 1571             │ -0.151228 │ 0.0         │
# │ 8   │ 1886             │ -0.126637 │ 0.0         │
# │ 9   │ 2032             │ 1.65959   │ 1.72234     │
# │ 10  │ 2096             │ -2.80265  │ -3.06075    │
# n = 729, and p = 2187
# Total iteration number was 763
# Total time was 6.453293085098267
# running the 83 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 106              │ 0.990491  │ 1.02758     │
# │ 2   │ 190              │ -1.78994  │ -1.8411     │
# │ 3   │ 469              │ 0.490831  │ 0.508253    │
# │ 4   │ 507              │ -1.69286  │ -1.75597    │
# │ 5   │ 539              │ -0.510188 │ 0.0         │
# │ 6   │ 704              │ 0.861881  │ 0.889743    │
# │ 7   │ 740              │ -1.12795  │ -1.10918    │
# │ 8   │ 832              │ -0.395118 │ -0.411481   │
# │ 9   │ 957              │ 0.450121  │ 0.459549    │
# │ 10  │ 1368             │ -0.523374 │ -0.52304    │
# n = 395, and p = 1580
# Total iteration number was 520
# Total time was 1.8035500049591064
# running the 84 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 77               │ 0.177852  │ 0.0         │
# │ 2   │ 534              │ -0.708056 │ 0.0         │
# │ 3   │ 661              │ -0.295484 │ 0.0         │
# │ 4   │ 1216             │ -0.332977 │ 0.0         │
# │ 5   │ 1379             │ -0.85806  │ 0.0         │
# │ 6   │ 1942             │ 3.04062   │ 0.0         │
# │ 7   │ 1986             │ 0.950186  │ 0.0         │
# │ 8   │ 2170             │ 1.62457   │ 0.0         │
# │ 9   │ 2443             │ -1.09897  │ 0.0         │
# │ 10  │ 2954             │ 1.0601    │ 0.0         │
# n = 608, and p = 3040
# Total iteration number was 362
# Total time was 3.531471014022827
# running the 85 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 4                │ 1.27043   │ 1.2232      │
# │ 2   │ 51               │ -0.216702 │ -0.18969    │
# │ 3   │ 115              │ -0.311705 │ -0.315293   │
# │ 4   │ 212              │ -0.366709 │ -0.386612   │
# │ 5   │ 433              │ 0.269118  │ 0.0         │
# │ 6   │ 934              │ 1.00836   │ 1.02952     │
# │ 7   │ 1367             │ -0.12922  │ -0.215612   │
# │ 8   │ 1388             │ 0.064756  │ 0.0         │
# │ 9   │ 1446             │ -2.51432  │ -2.59902    │
# │ 10  │ 1688             │ 0.657493  │ 0.665069    │
# n = 435, and p = 1740
# Total iteration number was 390
# Total time was 1.6432199478149414
# running the 86 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 457              │ 1.55082   │ 0.0         │
# │ 2   │ 463              │ -1.42612  │ 0.0         │
# │ 3   │ 569              │ 0.850567  │ 0.0         │
# │ 4   │ 637              │ -0.37162  │ 0.732148    │
# │ 5   │ 683              │ 1.35275   │ 0.0         │
# │ 6   │ 1311             │ 0.460742  │ 0.0         │
# │ 7   │ 2063             │ -0.335424 │ 0.0         │
# │ 8   │ 2426             │ -2.08837  │ 0.0         │
# │ 9   │ 2446             │ 0.604088  │ 0.0         │
# │ 10  │ 2593             │ -0.73443  │ 0.0         │
# n = 845, and p = 3380
# Total iteration number was 505
# Total time was 7.444950103759766
# running the 87 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 899              │ 0.0988079 │ 0.0         │
# │ 2   │ 984              │ 0.289989  │ 0.301901    │
# │ 3   │ 2371             │ -0.245807 │ 0.0         │
# │ 4   │ 2581             │ 0.0163787 │ 0.0         │
# │ 5   │ 3004             │ -0.16782  │ 0.0         │
# │ 6   │ 4511             │ -1.50568  │ 0.0         │
# │ 7   │ 4795             │ 0.781236  │ 0.746537    │
# │ 8   │ 5657             │ 0.86857   │ 0.836046    │
# │ 9   │ 7483             │ 0.951565  │ 0.873569    │
# │ 10  │ 7845             │ -0.306925 │ -0.34521    │
# n = 825, and p = 8250
# Total iteration number was 470
# Total time was 17.338560104370117
# running the 88 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 1121             │ 1.13024   │ 0.0         │
# │ 2   │ 1169             │ -0.718651 │ 0.0         │
# │ 3   │ 1793             │ 0.689248  │ 0.951171    │
# │ 4   │ 1935             │ -1.26984  │ 0.0         │
# │ 5   │ 2181             │ 0.627996  │ 0.0         │
# │ 6   │ 2429             │ 0.875291  │ 0.0         │
# │ 7   │ 2488             │ 1.57374   │ 1.37463     │
# │ 8   │ 2667             │ 0.426515  │ 0.0         │
# │ 9   │ 3070             │ -1.16019  │ 0.0         │
# │ 10  │ 3390             │ 2.44937   │ 2.04885     │
# n = 962, and p = 3848
# Total iteration number was 369
# Total time was 7.1131510734558105
# running the 89 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β     │ estimated_β │
# │     │ Int64            │ Float64    │ Float64     │
# ├─────┼──────────────────┼────────────┼─────────────┤
# │ 1   │ 1168             │ 1.75104    │ 1.4065      │
# │ 2   │ 1987             │ 0.588066   │ 0.0         │
# │ 3   │ 2868             │ 1.00725    │ 0.0         │
# │ 4   │ 3441             │ 0.35708    │ 0.0         │
# │ 5   │ 4118             │ 0.623554   │ 0.0         │
# │ 6   │ 4834             │ -0.0307826 │ 0.0         │
# │ 7   │ 5927             │ -2.91336   │ 0.0         │
# │ 8   │ 6066             │ -0.346332  │ 0.0         │
# │ 9   │ 6073             │ 0.00956552 │ 0.0         │
# │ 10  │ 7007             │ 0.747795   │ 0.0         │
# n = 788, and p = 7092
# Total iteration number was 942
# Total time was 27.59195899963379
# running the 90 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 150              │ -1.15174  │ -1.09461    │
# │ 2   │ 225              │ -0.407154 │ -0.391393   │
# │ 3   │ 324              │ -1.12536  │ -1.09808    │
# │ 4   │ 341              │ -0.703228 │ -0.695967   │
# │ 5   │ 353              │ 0.466813  │ 0.455941    │
# │ 6   │ 401              │ -0.814509 │ -0.822851   │
# │ 7   │ 510              │ -0.822648 │ -0.789546   │
# │ 8   │ 581              │ 0.163547  │ 0.184788    │
# │ 9   │ 609              │ -2.08163  │ 0.0         │
# │ 10  │ 615              │ 0.701131  │ 0.709992    │
# n = 677, and p = 677
# Total iteration number was 204
# Total time was 0.5193679332733154
# running the 91 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β     │ estimated_β │
# │     │ Int64            │ Float64    │ Float64     │
# ├─────┼──────────────────┼────────────┼─────────────┤
# │ 1   │ 435              │ -0.328129  │ -0.305051   │
# │ 2   │ 489              │ -0.0131617 │ 0.0         │
# │ 3   │ 1212             │ 1.07141    │ 1.07949     │
# │ 4   │ 1502             │ 0.347911   │ 0.340656    │
# │ 5   │ 1537             │ -0.0968047 │ -0.115783   │
# │ 6   │ 1755             │ -0.444941  │ -0.481      │
# │ 7   │ 1779             │ 0.10157    │ 0.123517    │
# │ 8   │ 1952             │ 0.029928   │ 0.0         │
# │ 9   │ 1982             │ 0.482409   │ 0.458665    │
# │ 10  │ 2360             │ 0.392654   │ 0.375924    │
# n = 661, and p = 2644
# Total iteration number was 457
# Total time was 4.26589298248291
# running the 92 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 104              │ 0.283962  │ 0.0         │
# │ 2   │ 163              │ 0.0246116 │ 0.0         │
# │ 3   │ 214              │ 0.19026   │ 0.0         │
# │ 4   │ 497              │ 1.0885    │ 1.10761     │
# │ 5   │ 514              │ -2.18169  │ 0.0         │
# │ 6   │ 576              │ -1.40343  │ 0.0         │
# │ 7   │ 708              │ 1.86979   │ 1.65425     │
# │ 8   │ 768              │ 0.586623  │ 0.0         │
# │ 9   │ 821              │ -0.702811 │ 0.0         │
# │ 10  │ 861              │ 0.801387  │ 0.280055    │
# n = 217, and p = 1085
# Total iteration number was 813
# Total time was 1.175774097442627
# running the 93 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 23               │ -2.09834  │ -2.12741    │
# │ 2   │ 650              │ 1.05539   │ 1.05609     │
# │ 3   │ 711              │ -0.697413 │ -0.713786   │
# │ 4   │ 781              │ 0.227735  │ 0.221098    │
# │ 5   │ 948              │ -1.21574  │ -1.17935    │
# │ 6   │ 1228             │ 0.888208  │ 0.889029    │
# │ 7   │ 1771             │ 0.173725  │ 0.168067    │
# │ 8   │ 1884             │ -1.09588  │ -1.09367    │
# │ 9   │ 1999             │ 0.355986  │ 0.352567    │
# │ 10  │ 2828             │ 0.246697  │ 0.246444    │
# n = 994, and p = 2982
# Total iteration number was 512
# Total time was 8.575504064559937
# running the 94 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 187              │ -0.412377 │ -0.415742   │
# │ 2   │ 1320             │ 0.909757  │ 0.896703    │
# │ 3   │ 2176             │ -0.615772 │ -0.610926   │
# │ 4   │ 2216             │ 1.07555   │ 1.08494     │
# │ 5   │ 2586             │ -0.708346 │ -0.708448   │
# │ 6   │ 2642             │ 1.06878   │ 1.05074     │
# │ 7   │ 4037             │ -0.117479 │ -0.126641   │
# │ 8   │ 4073             │ -0.809669 │ -0.812152   │
# │ 9   │ 4438             │ -1.06782  │ -1.06414    │
# │ 10  │ 4656             │ 1.29707   │ 1.30663     │
# n = 777, and p = 4662
# Total iteration number was 124
# Total time was 2.5983450412750244
# running the 95 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 112              │ 0.930212  │ 0.940396    │
# │ 2   │ 137              │ 0.336323  │ 0.342649    │
# │ 3   │ 297              │ -1.31741  │ -1.32284    │
# │ 4   │ 310              │ 1.69755   │ 1.69858     │
# │ 5   │ 968              │ 0.677076  │ 0.682624    │
# │ 6   │ 969              │ -0.845031 │ -0.839048   │
# │ 7   │ 1155             │ -0.693021 │ -0.69278    │
# │ 8   │ 1427             │ 0.560896  │ 0.563959    │
# │ 9   │ 1479             │ 0.161578  │ 0.160055    │
# │ 10  │ 1789             │ -1.92071  │ -1.87012    │
# n = 614, and p = 1842
# Total iteration number was 559
# Total time was 3.582943916320801
# running the 96 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 210              │ 0.74578   │ 0.0         │
# │ 2   │ 2126             │ 0.831967  │ 0.42084     │
# │ 3   │ 2322             │ 0.499818  │ 0.431842    │
# │ 4   │ 2708             │ -0.981066 │ 0.0         │
# │ 5   │ 2797             │ 1.72512   │ 1.42473     │
# │ 6   │ 2893             │ 1.30306   │ 0.972231    │
# │ 7   │ 3261             │ 1.46467   │ 1.3969      │
# │ 8   │ 3717             │ 0.0389355 │ 0.0         │
# │ 9   │ 3817             │ 0.679987  │ 0.0         │
# │ 10  │ 5183             │ 0.519988  │ 0.0         │
# n = 801, and p = 6408
# Total iteration number was 372
# Total time was 10.158383131027222
# running the 97 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 469              │ -1.20087  │ 0.0         │
# │ 2   │ 559              │ 1.0203    │ 0.0         │
# │ 3   │ 806              │ -0.174329 │ 0.0         │
# │ 4   │ 1464             │ 1.04108   │ 0.0         │
# │ 5   │ 3468             │ 0.718073  │ 0.0         │
# │ 6   │ 3549             │ 0.611252  │ 0.0         │
# │ 7   │ 3662             │ -1.81676  │ 0.0         │
# │ 8   │ 3973             │ 1.36239   │ 0.0         │
# │ 9   │ 4720             │ -1.2137   │ 0.0         │
# │ 10  │ 5224             │ 0.222824  │ 0.0         │
# n = 780, and p = 5460
# Total iteration number was 156
# Total time was 3.5197560787200928
# running the 98 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β     │ estimated_β │
# │     │ Int64            │ Float64    │ Float64     │
# ├─────┼──────────────────┼────────────┼─────────────┤
# │ 1   │ 251              │ 0.19441    │ 0.0         │
# │ 2   │ 434              │ -0.171638  │ 0.0         │
# │ 3   │ 1693             │ -0.466373  │ -0.471601   │
# │ 4   │ 1939             │ 0.630335   │ 0.666971    │
# │ 5   │ 1964             │ 0.945363   │ 0.889936    │
# │ 6   │ 2332             │ -0.309146  │ -0.283083   │
# │ 7   │ 2679             │ 1.42324    │ 1.39727     │
# │ 8   │ 2770             │ -0.0463634 │ 0.0         │
# │ 9   │ 3661             │ -1.31951   │ -1.32907    │
# │ 10  │ 3798             │ 0.105536   │ 0.0898493   │
# n = 764, and p = 3820
# Total iteration number was 472
# Total time was 7.24800705909729
# running the 99 th model
# Did not converge!!!!! The run time for IHT was 23.27071499824524seconds and model size was10compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 322              │ -1.13336  │ 0.0         │
# │ 2   │ 1643             │ -2.264    │ 0.0         │
# │ 3   │ 2108             │ 0.810653  │ 0.0         │
# │ 4   │ 2217             │ 0.5573    │ 0.0         │
# │ 5   │ 2518             │ -1.27401  │ 0.0         │
# │ 6   │ 3176             │ -1.56583  │ 0.0         │
# │ 7   │ 4479             │ 2.98015   │ 0.911024    │
# │ 8   │ 4696             │ 1.02334   │ 0.0         │
# │ 9   │ 5130             │ 0.484517  │ 0.0         │
# │ 10  │ 5654             │ -0.411055 │ 0.0         │
# n = 661, and p = 6610
# Total iteration number was 1000
# Total time was 23.27071499824524
# running the 100 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 818              │ -0.436337 │ -0.432006   │
# │ 2   │ 980              │ -1.43842  │ -1.38275    │
# │ 3   │ 1050             │ 0.649357  │ 0.651618    │
# │ 4   │ 2232             │ -0.479139 │ -0.494251   │
# │ 5   │ 2883             │ -0.213859 │ -0.227272   │
# │ 6   │ 3130             │ 0.800243  │ 0.788917    │
# │ 7   │ 3551             │ 0.0319829 │ 0.0         │
# │ 8   │ 3827             │ -0.196103 │ -0.192802   │
# │ 9   │ 3828             │ 1.84325   │ 1.86305     │
# │ 10  │ 4080             │ -1.00433  │ -0.993726   │
# n = 851, and p = 4255
# Total iteration number was 468
# Total time was 8.773834943771362

# %% [markdown]
# # Poisson sample size = 100~1000 (with debias)

# %%
for i = 1:100
    println("running the $i th model")
    n = rand(100:1000) 
    p = rand(1:10)n
    run_poisson(n, p)
end
# Out:
# running the 1 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β     │ estimated_β │
# │     │ Int64            │ Float64    │ Float64     │
# ├─────┼──────────────────┼────────────┼─────────────┤
# │ 1   │ 5                │ 0.963311   │ 1.07236     │
# │ 2   │ 25               │ -0.0162929 │ 0.0         │
# │ 3   │ 332              │ -0.833918  │ 0.0         │
# │ 4   │ 661              │ -1.11357   │ -1.32764    │
# │ 5   │ 1279             │ -0.0145944 │ 0.0         │
# │ 6   │ 1751             │ -0.706056  │ 0.0         │
# │ 7   │ 2184             │ 0.958318   │ 1.11266     │
# │ 8   │ 2195             │ 1.07606    │ 0.975752    │
# │ 9   │ 2258             │ -0.607827  │ 0.0         │
# │ 10  │ 2517             │ 0.075377   │ 0.0         │
# n = 381, and p = 2667
# Total iteration number was 152
# Total time was 0.9217848777770996
# running the 2 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 251              │ 0.450709  │ 0.42096     │
# │ 2   │ 1256             │ -2.27996  │ -2.24572    │
# │ 3   │ 1815             │ -0.203438 │ -0.239892   │
# │ 4   │ 2301             │ -1.18762  │ 0.0         │
# │ 5   │ 3102             │ 0.828182  │ 0.701033    │
# │ 6   │ 3166             │ 0.344241  │ 0.281703    │
# │ 7   │ 3202             │ 0.26169   │ 0.0         │
# │ 8   │ 3376             │ 1.44367   │ 1.43145     │
# │ 9   │ 4968             │ -1.4321   │ -1.47613    │
# │ 10  │ 5678             │ -0.283929 │ -0.407311   │
# n = 871, and p = 6097
# Total iteration number was 290
# Total time was 8.617605924606323
# running the 3 th model
# Did not converge!!!!! The run time for IHT was 3.902310848236084seconds and model size was10compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 3                │ -0.793993 │ 0.0         │
# │ 2   │ 11               │ 0.948598  │ 0.8326      │
# │ 3   │ 157              │ -1.41339  │ 0.0         │
# │ 4   │ 313              │ 1.7356    │ 0.13016     │
# │ 5   │ 465              │ 2.76084   │ 2.60044     │
# │ 6   │ 585              │ 1.25304   │ 0.0         │
# │ 7   │ 698              │ -0.106817 │ 0.0         │
# │ 8   │ 918              │ -0.58891  │ 0.0         │
# │ 9   │ 1098             │ -0.422901 │ 0.0         │
# │ 10  │ 1159             │ 0.641799  │ 0.0         │
# n = 439, and p = 1317
# Total iteration number was 1000
# Total time was 3.902310848236084
# running the 4 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 123              │ -0.110988 │ 0.0         │
# │ 2   │ 399              │ 0.982221  │ 0.910346    │
# │ 3   │ 637              │ -0.384675 │ 0.0         │
# │ 4   │ 1217             │ 0.321453  │ 0.0         │
# │ 5   │ 1224             │ -0.408767 │ -0.431358   │
# │ 6   │ 1576             │ 0.405551  │ 0.0         │
# │ 7   │ 1650             │ -1.09158  │ -0.927393   │
# │ 8   │ 1756             │ 0.97091   │ 0.925891    │
# │ 9   │ 1812             │ -0.946009 │ 0.0         │
# │ 10  │ 2391             │ 1.30651   │ 1.24157     │
# n = 283, and p = 2547
# Total iteration number was 175
# Total time was 0.7415781021118164
# running the 5 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 283              │ -0.733445 │ -0.725508   │
# │ 2   │ 469              │ 1.0443    │ 0.0         │
# │ 3   │ 479              │ -0.695335 │ 0.0         │
# │ 4   │ 598              │ 0.677568  │ 0.0         │
# │ 5   │ 819              │ -1.5591   │ 0.0         │
# │ 6   │ 948              │ 0.148248  │ 0.0         │
# │ 7   │ 1109             │ -0.244735 │ 0.0         │
# │ 8   │ 1153             │ -0.980448 │ 0.0         │
# │ 9   │ 1360             │ -1.10115  │ 0.0         │
# │ 10  │ 1444             │ 1.8854    │ 1.39184     │
# n = 264, and p = 1848
# Total iteration number was 296
# Total time was 0.8902969360351562
# running the 6 th model
# Did not converge!!!!! The run time for IHT was 15.448773860931396seconds and model size was10compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 246              │ -0.672195 │ 0.0         │
# │ 2   │ 625              │ 0.104216  │ 0.0         │
# │ 3   │ 941              │ 1.14703   │ 0.962256    │
# │ 4   │ 2451             │ -0.32044  │ 0.0         │
# │ 5   │ 2620             │ 1.17979   │ 1.14032     │
# │ 6   │ 2983             │ -1.2744   │ -1.45212    │
# │ 7   │ 3168             │ -0.364624 │ 0.0         │
# │ 8   │ 3187             │ 1.48277   │ 1.47607     │
# │ 9   │ 3267             │ 0.524624  │ 0.0         │
# │ 10  │ 3905             │ 0.93092   │ 0.766309    │
# n = 635, and p = 4445
# Total iteration number was 1000
# Total time was 15.448773860931396
# running the 7 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 37               │ -1.76205  │ -1.63232    │
# │ 2   │ 329              │ 0.726966  │ 0.72454     │
# │ 3   │ 654              │ -0.928433 │ -0.930116   │
# │ 4   │ 1114             │ 0.315485  │ 0.323737    │
# │ 5   │ 1230             │ 0.451415  │ 0.444647    │
# │ 6   │ 1713             │ 1.23516   │ 1.23378     │
# │ 7   │ 3438             │ -0.366356 │ -0.374126   │
# │ 8   │ 3634             │ -1.59756  │ 0.0         │
# │ 9   │ 3695             │ -0.594471 │ -0.585611   │
# │ 10  │ 4455             │ -2.1102   │ -2.10528    │
# n = 642, and p = 4494
# Total iteration number was 415
# Total time was 6.418133974075317
# running the 8 th model
# Did not converge!!!!! The run time for IHT was 22.992859840393066seconds and model size was10compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 216              │ 0.16447   │ 0.0         │
# │ 2   │ 949              │ 1.7008    │ 1.68108     │
# │ 3   │ 1033             │ 0.0526545 │ 0.0         │
# │ 4   │ 1341             │ -1.4953   │ -1.55774    │
# │ 5   │ 2166             │ -0.131493 │ -0.139614   │
# │ 6   │ 3040             │ 0.0933673 │ 0.10806     │
# │ 7   │ 3594             │ -0.161433 │ 0.0         │
# │ 8   │ 3617             │ 0.596566  │ 0.624891    │
# │ 9   │ 5281             │ 0.560949  │ 0.545436    │
# │ 10  │ 5313             │ -1.94779  │ -1.93025    │
# n = 766, and p = 5362
# Total iteration number was 1000
# Total time was 22.992859840393066
# running the 9 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β     │ estimated_β │
# │     │ Int64            │ Float64    │ Float64     │
# ├─────┼──────────────────┼────────────┼─────────────┤
# │ 1   │ 52               │ 0.560678   │ 0.0         │
# │ 2   │ 113              │ -0.0383714 │ 0.0         │
# │ 3   │ 304              │ -0.78089   │ 0.0         │
# │ 4   │ 388              │ -0.764712  │ -0.275742   │
# │ 5   │ 391              │ 0.147948   │ 0.0         │
# │ 6   │ 460              │ -0.190519  │ 0.0         │
# │ 7   │ 488              │ 0.250157   │ 0.0         │
# │ 8   │ 754              │ 0.0389039  │ 0.0         │
# │ 9   │ 1061             │ -0.395159  │ 0.0         │
# │ 10  │ 1301             │ 1.08956    │ 0.928741    │
# n = 502, and p = 1506
# Total iteration number was 157
# Total time was 0.6971180438995361
# running the 10 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 46               │ -1.30349  │ -1.7533     │
# │ 2   │ 51               │ -1.07228  │ -1.19127    │
# │ 3   │ 120              │ 0.0158377 │ 0.0         │
# │ 4   │ 150              │ 0.496023  │ 0.617341    │
# │ 5   │ 161              │ -0.398408 │ -0.445538   │
# │ 6   │ 208              │ -1.4216   │ 0.0         │
# │ 7   │ 273              │ -0.12487  │ 0.0         │
# │ 8   │ 308              │ -0.172563 │ 0.0         │
# │ 9   │ 318              │ -0.363813 │ -0.409776   │
# │ 10  │ 323              │ -0.854751 │ -0.916859   │
# n = 348, and p = 348
# Total iteration number was 56
# Total time was 0.05029606819152832
# running the 11 th model
# Did not converge!!!!! The run time for IHT was 2.6724140644073486seconds and model size was10compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β     │ estimated_β │
# │     │ Int64            │ Float64    │ Float64     │
# ├─────┼──────────────────┼────────────┼─────────────┤
# │ 1   │ 266              │ -0.709956  │ 0.0         │
# │ 2   │ 704              │ -0.107477  │ 0.0         │
# │ 3   │ 729              │ -0.121896  │ 0.0         │
# │ 4   │ 860              │ 0.770831   │ 0.860764    │
# │ 5   │ 907              │ -0.0516698 │ 0.0         │
# │ 6   │ 1023             │ -1.72893   │ 0.0         │
# │ 7   │ 1026             │ 1.16885    │ 1.27628     │
# │ 8   │ 1047             │ 0.943476   │ 1.04153     │
# │ 9   │ 1075             │ -0.0279899 │ 0.0         │
# │ 10  │ 1083             │ -0.468514  │ 0.0         │
# n = 314, and p = 1256
# Total iteration number was 1000
# Total time was 2.6724140644073486
# running the 12 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β     │ estimated_β │
# │     │ Int64            │ Float64    │ Float64     │
# ├─────┼──────────────────┼────────────┼─────────────┤
# │ 1   │ 238              │ -0.0737206 │ 0.0         │
# │ 2   │ 514              │ 0.784672   │ 0.717102    │
# │ 3   │ 598              │ 0.386199   │ 0.406467    │
# │ 4   │ 910              │ 0.510033   │ 0.568473    │
# │ 5   │ 2421             │ 1.13627    │ 1.01931     │
# │ 6   │ 2823             │ -0.945346  │ -0.921415   │
# │ 7   │ 3037             │ 1.60767    │ 1.4753      │
# │ 8   │ 3514             │ -0.856199  │ -0.694577   │
# │ 9   │ 3544             │ 0.439262   │ 0.48815     │
# │ 10  │ 3593             │ -0.305183  │ 0.0         │
# n = 768, and p = 3840
# Total iteration number was 362
# Total time was 6.028281211853027
# running the 13 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β     │ estimated_β │
# │     │ Int64            │ Float64    │ Float64     │
# ├─────┼──────────────────┼────────────┼─────────────┤
# │ 1   │ 23               │ -0.620625  │ 0.0         │
# │ 2   │ 36               │ -0.0387711 │ 0.0         │
# │ 3   │ 58               │ -1.99747   │ -1.00672    │
# │ 4   │ 142              │ -0.889091  │ 0.0         │
# │ 5   │ 499              │ 0.728083   │ 0.0         │
# │ 6   │ 526              │ 1.65947    │ 1.42188     │
# │ 7   │ 563              │ 0.0611173  │ 0.0         │
# │ 8   │ 583              │ -0.934606  │ -0.735313   │
# │ 9   │ 596              │ 0.673401   │ 0.0         │
# │ 10  │ 694              │ -0.183164  │ 0.0         │
# n = 276, and p = 1380
# Total iteration number was 195
# Total time was 0.4675149917602539
# running the 14 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 2174             │ 0.606715  │ 0.0         │
# │ 2   │ 2794             │ 0.795332  │ 0.0         │
# │ 3   │ 3053             │ 1.34103   │ 1.02088     │
# │ 4   │ 3758             │ -0.162311 │ 0.0         │
# │ 5   │ 4368             │ 1.8313    │ 1.42035     │
# │ 6   │ 5283             │ 0.71513   │ 0.0         │
# │ 7   │ 6035             │ 0.212662  │ 0.0         │
# │ 8   │ 7048             │ 1.64559   │ 1.56434     │
# │ 9   │ 7463             │ 0.457023  │ 0.0         │
# │ 10  │ 9219             │ -1.08401  │ 0.0         │
# n = 992, and p = 9920
# Total iteration number was 364
# Total time was 19.27171802520752
# running the 15 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 61               │ -0.985009 │ -1.01385    │
# │ 2   │ 195              │ -0.134038 │ 0.0         │
# │ 3   │ 339              │ -0.541968 │ -0.562572   │
# │ 4   │ 353              │ -0.24548  │ -0.202822   │
# │ 5   │ 363              │ -1.75137  │ -1.74516    │
# │ 6   │ 403              │ -0.232117 │ -0.21181    │
# │ 7   │ 446              │ -1.22987  │ -1.20381    │
# │ 8   │ 463              │ -0.184661 │ -0.163033   │
# │ 9   │ 578              │ 0.752658  │ 0.765457    │
# │ 10  │ 587              │ -0.933025 │ -0.912729   │
# n = 288, and p = 864
# Total iteration number was 243
# Total time was 0.38704514503479004
# running the 16 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β     │ estimated_β │
# │     │ Int64            │ Float64    │ Float64     │
# ├─────┼──────────────────┼────────────┼─────────────┤
# │ 1   │ 4                │ -0.9262    │ -0.939075   │
# │ 2   │ 50               │ 0.541709   │ 0.544806    │
# │ 3   │ 499              │ 0.7642     │ 0.75936     │
# │ 4   │ 957              │ -0.324672  │ -0.312233   │
# │ 5   │ 1183             │ -0.312027  │ -0.307942   │
# │ 6   │ 1488             │ -0.636542  │ -0.622628   │
# │ 7   │ 1767             │ 0.762048   │ 0.760435    │
# │ 8   │ 2508             │ 0.712022   │ 0.699792    │
# │ 9   │ 3106             │ -0.0943736 │ -0.0936076  │
# │ 10  │ 3330             │ -2.21392   │ -2.21924    │
# n = 373, and p = 3357
# Total iteration number was 522
# Total time was 3.6984078884124756
# running the 17 th model
# Did not converge!!!!! The run time for IHT was 2.4060959815979004seconds and model size was10compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 60               │ 2.47994   │ 1.18598     │
# │ 2   │ 158              │ -1.33615  │ 0.0         │
# │ 3   │ 246              │ 1.57253   │ 0.0         │
# │ 4   │ 385              │ 0.863036  │ 0.0         │
# │ 5   │ 418              │ 0.126956  │ 0.0         │
# │ 6   │ 568              │ 1.15843   │ 0.0         │
# │ 7   │ 746              │ -1.14701  │ 0.0         │
# │ 8   │ 796              │ 1.25819   │ 1.46292     │
# │ 9   │ 979              │ 1.13552   │ 0.0         │
# │ 10  │ 1562             │ -0.157115 │ 0.0         │
# n = 261, and p = 1566
# Total iteration number was 1000
# Total time was 2.4060959815979004
# running the 18 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β     │ estimated_β │
# │     │ Int64            │ Float64    │ Float64     │
# ├─────┼──────────────────┼────────────┼─────────────┤
# │ 1   │ 36               │ 0.0291318  │ 0.0         │
# │ 2   │ 315              │ 0.737451   │ 0.0         │
# │ 3   │ 1662             │ 0.392857   │ 0.0         │
# │ 4   │ 1822             │ -0.537887  │ 0.0         │
# │ 5   │ 1881             │ 2.53924    │ 2.05152     │
# │ 6   │ 2344             │ -0.0428135 │ 0.0         │
# │ 7   │ 2557             │ 0.537986   │ 0.0         │
# │ 8   │ 2714             │ 0.446035   │ 0.0         │
# │ 9   │ 2890             │ -1.13907   │ 0.0         │
# │ 10  │ 3164             │ 1.00863    │ 0.666315    │
# n = 487, and p = 3409
# Total iteration number was 339
# Total time was 3.112036943435669
# running the 19 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 164              │ 0.400348  │ 0.412927    │
# │ 2   │ 1282             │ -1.01169  │ -1.02595    │
# │ 3   │ 1484             │ -0.480944 │ 0.0         │
# │ 4   │ 3424             │ -0.72189  │ -0.701675   │
# │ 5   │ 4212             │ -0.484155 │ -0.48659    │
# │ 6   │ 5025             │ 0.705864  │ 0.691235    │
# │ 7   │ 5324             │ -0.374139 │ -0.357904   │
# │ 8   │ 5657             │ 1.94551   │ 1.94401     │
# │ 9   │ 6171             │ -0.500868 │ -0.495705   │
# │ 10  │ 7860             │ -0.111692 │ -0.0895972  │
# n = 860, and p = 8600
# Total iteration number was 120
# Total time was 5.000982046127319
# running the 20 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 13               │ -0.266127 │ 0.0         │
# │ 2   │ 65               │ -0.384746 │ -0.386641   │
# │ 3   │ 132              │ -0.705902 │ -0.767283   │
# │ 4   │ 135              │ -0.450695 │ 0.0         │
# │ 5   │ 169              │ -1.38495  │ -1.43579    │
# │ 6   │ 195              │ -0.18172  │ 0.0         │
# │ 7   │ 243              │ -0.96746  │ -0.994373   │
# │ 8   │ 291              │ 0.213028  │ 0.0         │
# │ 9   │ 409              │ -1.39059  │ -1.42303    │
# │ 10  │ 423              │ 0.529908  │ 0.493923    │
# n = 437, and p = 437
# Total iteration number was 95
# Total time was 0.14025211334228516
# running the 21 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 13               │ 1.03219   │ 0.0         │
# │ 2   │ 746              │ -2.04395  │ 0.0         │
# │ 3   │ 747              │ -0.244587 │ 0.0         │
# │ 4   │ 748              │ 0.660595  │ 0.0         │
# │ 5   │ 1766             │ 1.36775   │ 0.0         │
# │ 6   │ 2202             │ -1.3243   │ 0.0         │
# │ 7   │ 2373             │ -1.71821  │ 0.0         │
# │ 8   │ 3401             │ 0.0203611 │ 0.0         │
# │ 9   │ 3635             │ -1.65835  │ 0.0         │
# │ 10  │ 4493             │ 1.40398   │ 1.22682     │
# n = 577, and p = 4616
# Total iteration number was 815
# Total time was 12.116050004959106
# running the 22 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 5                │ 0.496098  │ 0.0         │
# │ 2   │ 52               │ 0.537965  │ 0.951733    │
# │ 3   │ 76               │ -1.59677  │ -1.47322    │
# │ 4   │ 87               │ 1.91715   │ 1.7802      │
# │ 5   │ 97               │ 1.41566   │ 1.0909      │
# │ 6   │ 174              │ -1.63307  │ 0.0         │
# │ 7   │ 215              │ 0.246489  │ 0.0         │
# │ 8   │ 216              │ 0.506934  │ 0.0         │
# │ 9   │ 244              │ -0.547957 │ 0.0         │
# │ 10  │ 263              │ 0.757525  │ 0.653452    │
# n = 333, and p = 333
# Total iteration number was 398
# Total time was 0.3060920238494873
# running the 23 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β      │ estimated_β │
# │     │ Int64            │ Float64     │ Float64     │
# ├─────┼──────────────────┼─────────────┼─────────────┤
# │ 1   │ 71               │ -0.101725   │ -0.0923656  │
# │ 2   │ 805              │ 1.60419     │ 1.5811      │
# │ 3   │ 1461             │ 0.731018    │ 0.715909    │
# │ 4   │ 1624             │ -1.84051    │ -1.78509    │
# │ 5   │ 1791             │ 0.403342    │ 0.397159    │
# │ 6   │ 2475             │ 0.436055    │ 0.438767    │
# │ 7   │ 3418             │ -0.00329061 │ 0.0         │
# │ 8   │ 4885             │ 0.588905    │ 0.577267    │
# │ 9   │ 5016             │ 0.609411    │ 0.592488    │
# │ 10  │ 5593             │ 0.0255569   │ 0.0         │
# n = 607, and p = 6070
# Total iteration number was 274
# Total time was 5.703723907470703
# running the 24 th model
# Did not converge!!!!! The run time for IHT was 12.534186124801636seconds and model size was10compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 53               │ 0.0979618 │ 0.0         │
# │ 2   │ 1259             │ -0.748236 │ 0.0         │
# │ 3   │ 1934             │ -1.6156   │ 0.0         │
# │ 4   │ 2149             │ 1.01842   │ 0.0         │
# │ 5   │ 2180             │ -0.115766 │ 0.0         │
# │ 6   │ 2458             │ 1.46053   │ 0.0         │
# │ 7   │ 2537             │ 1.84789   │ 0.0         │
# │ 8   │ 2626             │ -0.585224 │ 0.0         │
# │ 9   │ 3240             │ 0.50107   │ 0.0         │
# │ 10  │ 3257             │ 0.50446   │ 0.0         │
# n = 593, and p = 3558
# Total iteration number was 1000
# Total time was 12.534186124801636
# running the 25 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 8                │ 0.427745  │ 0.0         │
# │ 2   │ 136              │ 1.04905   │ 0.833719    │
# │ 3   │ 259              │ 1.26343   │ 0.0         │
# │ 4   │ 280              │ -0.107693 │ 0.0         │
# │ 5   │ 294              │ -0.995036 │ 0.0         │
# │ 6   │ 475              │ -1.07936  │ 0.0         │
# │ 7   │ 701              │ -0.947605 │ 0.0         │
# │ 8   │ 754              │ -1.89462  │ 0.0         │
# │ 9   │ 878              │ 0.361312  │ 0.0         │
# │ 10  │ 888              │ -0.108662 │ 0.0         │
# n = 117, and p = 936
# Total iteration number was 203
# Total time was 0.1816558837890625
# running the 26 th model
# Did not converge!!!!! The run time for IHT was 6.261883020401001seconds and model size was10compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β     │ estimated_β │
# │     │ Int64            │ Float64    │ Float64     │
# ├─────┼──────────────────┼────────────┼─────────────┤
# │ 1   │ 7                │ 0.851923   │ 0.966997    │
# │ 2   │ 186              │ 0.981656   │ 1.15596     │
# │ 3   │ 215              │ 0.197538   │ 0.0         │
# │ 4   │ 729              │ 0.20467    │ 0.0         │
# │ 5   │ 1115             │ 0.0488647  │ 0.0         │
# │ 6   │ 1187             │ -1.30638   │ 0.0         │
# │ 7   │ 1232             │ 0.212265   │ 0.0         │
# │ 8   │ 1368             │ -0.0625165 │ 0.0         │
# │ 9   │ 1629             │ 0.25107    │ 0.0         │
# │ 10  │ 1650             │ 0.298972   │ 0.0         │
# n = 578, and p = 1734
# Total iteration number was 1000
# Total time was 6.261883020401001
# running the 27 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β     │ estimated_β │
# │     │ Int64            │ Float64    │ Float64     │
# ├─────┼──────────────────┼────────────┼─────────────┤
# │ 1   │ 11               │ 0.0399939  │ 0.0         │
# │ 2   │ 114              │ 1.60059    │ 1.5867      │
# │ 3   │ 151              │ 0.859161   │ 0.862978    │
# │ 4   │ 260              │ 0.477167   │ 0.487357    │
# │ 5   │ 294              │ 0.343758   │ 0.299191    │
# │ 6   │ 310              │ -0.301803  │ -0.300097   │
# │ 7   │ 333              │ -0.0750364 │ 0.0         │
# │ 8   │ 344              │ 0.0848825  │ 0.0734833   │
# │ 9   │ 417              │ -0.178727  │ -0.150352   │
# │ 10  │ 456              │ 0.235095   │ 0.280354    │
# n = 468, and p = 468
# Total iteration number was 98
# Total time was 0.15169215202331543
# running the 28 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 746              │ 1.06155   │ 1.05065     │
# │ 2   │ 778              │ -1.09427  │ -1.11499    │
# │ 3   │ 909              │ -2.14263  │ -2.16169    │
# │ 4   │ 1667             │ -0.181806 │ -0.172617   │
# │ 5   │ 2559             │ -0.648749 │ -0.636193   │
# │ 6   │ 2931             │ 0.115536  │ 0.129907    │
# │ 7   │ 3330             │ 1.92427   │ 1.93452     │
# │ 8   │ 4543             │ -1.04643  │ -1.03565    │
# │ 9   │ 4778             │ -0.272727 │ 0.0         │
# │ 10  │ 4944             │ -0.191222 │ -0.199269   │
# n = 631, and p = 5048
# Total iteration number was 437
# Total time was 7.640549898147583
# running the 29 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 49               │ 0.808103  │ 0.820815    │
# │ 2   │ 889              │ -0.229319 │ 0.0         │
# │ 3   │ 1128             │ -0.502496 │ -0.531493   │
# │ 4   │ 1160             │ -0.290687 │ 0.0         │
# │ 5   │ 1267             │ -0.195091 │ 0.0         │
# │ 6   │ 1448             │ -1.71884  │ -1.51643    │
# │ 7   │ 1608             │ -1.79253  │ -1.74539    │
# │ 8   │ 1629             │ 0.582721  │ 0.500932    │
# │ 9   │ 2095             │ -0.23636  │ 0.0         │
# │ 10  │ 2219             │ 1.51219   │ 1.41481     │
# n = 528, and p = 2640
# Total iteration number was 405
# Total time was 3.286808967590332
# running the 30 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 708              │ -0.296501 │ 0.0         │
# │ 2   │ 889              │ 0.411067  │ 0.0         │
# │ 3   │ 1058             │ 0.341766  │ 0.0         │
# │ 4   │ 1105             │ -0.248857 │ 0.0         │
# │ 5   │ 1994             │ 0.273221  │ 0.0         │
# │ 6   │ 2352             │ 1.45798   │ 1.08758     │
# │ 7   │ 4575             │ -0.130683 │ 0.0         │
# │ 8   │ 5377             │ 1.41368   │ 1.01687     │
# │ 9   │ 5579             │ -1.0485   │ -0.993116   │
# │ 10  │ 5749             │ -0.284948 │ 0.0         │
# n = 583, and p = 5830
# Total iteration number was 101
# Total time was 1.9328830242156982
# running the 31 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 200              │ 0.0670938 │ 0.0         │
# │ 2   │ 223              │ 0.419471  │ 0.0         │
# │ 3   │ 240              │ 0.554151  │ 0.0         │
# │ 4   │ 310              │ 0.856718  │ 0.758545    │
# │ 5   │ 1197             │ -0.704821 │ 0.0         │
# │ 6   │ 1430             │ 1.59766   │ 1.52478     │
# │ 7   │ 2452             │ 0.908967  │ 0.900376    │
# │ 8   │ 2691             │ 0.698282  │ 0.581162    │
# │ 9   │ 2729             │ -0.228871 │ 0.0         │
# │ 10  │ 2938             │ 0.159342  │ 0.0         │
# n = 740, and p = 3700
# Total iteration number was 414
# Total time was 6.142833948135376
# running the 32 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β     │ estimated_β │
# │     │ Int64            │ Float64    │ Float64     │
# ├─────┼──────────────────┼────────────┼─────────────┤
# │ 1   │ 29               │ 1.14855    │ 1.05117     │
# │ 2   │ 216              │ 1.0536     │ 0.977506    │
# │ 3   │ 708              │ -1.00313   │ -0.644105   │
# │ 4   │ 741              │ 0.47091    │ 0.0         │
# │ 5   │ 814              │ -0.0592248 │ 0.0         │
# │ 6   │ 1012             │ -0.834     │ -0.559831   │
# │ 7   │ 1065             │ -1.00272   │ -0.830257   │
# │ 8   │ 1296             │ -0.982696  │ 0.0         │
# │ 9   │ 1352             │ -1.12826   │ 0.0         │
# │ 10  │ 1467             │ -0.982909  │ -0.562666   │
# n = 853, and p = 1706
# Total iteration number was 310
# Total time was 2.5784239768981934
# running the 33 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β     │ estimated_β │
# │     │ Int64            │ Float64    │ Float64     │
# ├─────┼──────────────────┼────────────┼─────────────┤
# │ 1   │ 101              │ 0.967102   │ 0.979073    │
# │ 2   │ 304              │ 0.198052   │ 0.194446    │
# │ 3   │ 361              │ -0.167148  │ -0.165941   │
# │ 4   │ 705              │ 0.406127   │ 0.408914    │
# │ 5   │ 985              │ -2.81551   │ -2.85948    │
# │ 6   │ 1091             │ -0.0547972 │ -0.0683949  │
# │ 7   │ 1247             │ 0.0577849  │ 0.0523279   │
# │ 8   │ 1390             │ 0.51253    │ 0.510938    │
# │ 9   │ 1431             │ 0.971827   │ 0.960099    │
# │ 10  │ 2199             │ -0.598143  │ -0.542921   │
# n = 723, and p = 2892
# Total iteration number was 726
# Total time was 8.411076068878174
# running the 34 th model
# Did not converge!!!!! The run time for IHT was 14.97534704208374seconds and model size was10compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β     │ estimated_β │
# │     │ Int64            │ Float64    │ Float64     │
# ├─────┼──────────────────┼────────────┼─────────────┤
# │ 1   │ 151              │ 0.0201094  │ 0.0         │
# │ 2   │ 238              │ 1.39184    │ 1.09231     │
# │ 3   │ 502              │ 0.624735   │ 0.0         │
# │ 4   │ 760              │ -0.684997  │ 0.0         │
# │ 5   │ 1287             │ 0.699991   │ 0.0         │
# │ 6   │ 2294             │ -0.0234585 │ 0.0         │
# │ 7   │ 3992             │ -0.455679  │ 0.0         │
# │ 8   │ 4086             │ -0.385143  │ 0.0         │
# │ 9   │ 4149             │ 1.52025    │ 1.12482     │
# │ 10  │ 4210             │ 1.66275    │ 0.819059    │
# n = 550, and p = 4950
# Total iteration number was 1000
# Total time was 14.97534704208374
# running the 35 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 945              │ 0.102871  │ 0.0         │
# │ 2   │ 1153             │ 0.580661  │ 0.656556    │
# │ 3   │ 1169             │ 0.313046  │ 0.354176    │
# │ 4   │ 1763             │ -0.141353 │ 0.0         │
# │ 5   │ 1777             │ -0.652556 │ -0.672792   │
# │ 6   │ 2333             │ 0.269112  │ 0.0         │
# │ 7   │ 2585             │ 0.116723  │ 0.0         │
# │ 8   │ 2603             │ 0.443439  │ 0.0         │
# │ 9   │ 2788             │ 0.825486  │ 0.844462    │
# │ 10  │ 3413             │ 0.285003  │ 0.291749    │
# n = 446, and p = 4460
# Total iteration number was 49
# Total time was 0.5569710731506348
# running the 36 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 3                │ 1.3753    │ 1.37211     │
# │ 2   │ 365              │ 0.0338046 │ 0.0         │
# │ 3   │ 899              │ 2.07204   │ 2.06763     │
# │ 4   │ 1064             │ 0.780237  │ 0.787923    │
# │ 5   │ 2127             │ 0.911439  │ 0.916477    │
# │ 6   │ 2167             │ -0.157079 │ 0.0         │
# │ 7   │ 2217             │ 0.292772  │ 0.290882    │
# │ 8   │ 2597             │ -0.614568 │ -0.626982   │
# │ 9   │ 3084             │ 0.0922361 │ 0.0985469   │
# │ 10  │ 3291             │ 0.589744  │ 0.59241     │
# n = 906, and p = 3624
# Total iteration number was 569
# Total time was 10.11382007598877
# running the 37 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 193              │ 0.50423   │ 0.0         │
# │ 2   │ 329              │ -0.881648 │ 0.0         │
# │ 3   │ 526              │ 0.779442  │ 0.0         │
# │ 4   │ 881              │ -2.22087  │ 0.0         │
# │ 5   │ 947              │ -0.794274 │ 0.0         │
# │ 6   │ 959              │ 1.70794   │ 2.30852     │
# │ 7   │ 1005             │ 0.335995  │ 0.0         │
# │ 8   │ 1203             │ -0.49681  │ 0.0         │
# │ 9   │ 1413             │ -1.85204  │ 0.0         │
# │ 10  │ 2422             │ 0.788197  │ 0.0         │
# n = 863, and p = 2589
# Total iteration number was 747
# Total time was 9.491627931594849
# running the 38 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β     │ estimated_β │
# │     │ Int64            │ Float64    │ Float64     │
# ├─────┼──────────────────┼────────────┼─────────────┤
# │ 1   │ 48               │ 0.100814   │ 0.102331    │
# │ 2   │ 358              │ 0.0105777  │ 0.0         │
# │ 3   │ 562              │ -0.51106   │ -0.510964   │
# │ 4   │ 569              │ -0.0565827 │ 0.0         │
# │ 5   │ 577              │ 2.21399    │ 2.19449     │
# │ 6   │ 772              │ -0.0751124 │ 0.0         │
# │ 7   │ 1081             │ -1.79407   │ -1.78087    │
# │ 8   │ 1500             │ 0.164773   │ 0.0         │
# │ 9   │ 1795             │ -1.75323   │ -1.7161     │
# │ 10  │ 2274             │ 0.298242   │ 0.0         │
# n = 494, and p = 2470
# Total iteration number was 710
# Total time was 4.8155341148376465
# running the 39 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 104              │ 0.328088  │ 0.0         │
# │ 2   │ 165              │ -0.460698 │ 0.0         │
# │ 3   │ 226              │ 1.52406   │ 1.25968     │
# │ 4   │ 741              │ 0.926414  │ 0.0         │
# │ 5   │ 1241             │ -0.637886 │ -0.255486   │
# │ 6   │ 1318             │ -0.900829 │ 0.0         │
# │ 7   │ 1861             │ 0.0718752 │ 0.0         │
# │ 8   │ 2140             │ 1.18543   │ 0.0         │
# │ 9   │ 2595             │ -2.6611   │ 0.0         │
# │ 10  │ 2653             │ 0.812042  │ 0.559772    │
# n = 329, and p = 2961
# Total iteration number was 191
# Total time was 1.0698721408843994
# running the 40 th model
# Did not converge!!!!! The run time for IHT was 10.897554159164429seconds and model size was10compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 271              │ -0.908172 │ -0.948326   │
# │ 2   │ 422              │ -1.53985  │ -1.61133    │
# │ 3   │ 905              │ 0.396946  │ 0.406056    │
# │ 4   │ 1721             │ 0.607188  │ 0.595538    │
# │ 5   │ 1941             │ 0.234488  │ 0.23602     │
# │ 6   │ 2000             │ 0.345074  │ 0.391085    │
# │ 7   │ 2077             │ -0.317019 │ -0.305152   │
# │ 8   │ 2527             │ -1.30676  │ 0.0         │
# │ 9   │ 3059             │ 0.0446506 │ 0.0         │
# │ 10  │ 3137             │ 1.40524   │ 1.42188     │
# n = 559, and p = 3354
# Total iteration number was 1000
# Total time was 10.897554159164429
# running the 41 th model
# Did not converge!!!!! The run time for IHT was 5.3838090896606445seconds and model size was10compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 262              │ -0.327832 │ 0.0         │
# │ 2   │ 332              │ -0.119219 │ 0.0         │
# │ 3   │ 408              │ 0.656962  │ 0.837344    │
# │ 4   │ 928              │ -0.588453 │ -0.791401   │
# │ 5   │ 1325             │ 0.394166  │ 0.0         │
# │ 6   │ 1345             │ -2.12272  │ 0.0         │
# │ 7   │ 1386             │ -0.197391 │ -0.325674   │
# │ 8   │ 2267             │ -1.04196  │ -1.3795     │
# │ 9   │ 2565             │ 0.47152   │ 0.543877    │
# │ 10  │ 2754             │ -0.379605 │ 0.0         │
# n = 311, and p = 2799
# Total iteration number was 1000
# Total time was 5.3838090896606445
# running the 42 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 31               │ 0.641461  │ 0.0         │
# │ 2   │ 149              │ 0.5529    │ 0.505355    │
# │ 3   │ 153              │ 1.0857    │ 0.692219    │
# │ 4   │ 1238             │ 0.580168  │ 0.527283    │
# │ 5   │ 1610             │ 0.435787  │ 0.566747    │
# │ 6   │ 2113             │ -1.3254   │ 0.0         │
# │ 7   │ 2780             │ -0.335501 │ 0.0         │
# │ 8   │ 3021             │ 0.146244  │ 0.0         │
# │ 9   │ 3053             │ 1.16056   │ 1.01321     │
# │ 10  │ 3135             │ 0.175199  │ 0.0         │
# n = 322, and p = 3220
# Total iteration number was 257
# Total time was 1.5015151500701904
# running the 43 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 998              │ -0.338142 │ 0.0         │
# │ 2   │ 1064             │ 0.615931  │ 0.0         │
# │ 3   │ 1178             │ -0.056845 │ 0.0         │
# │ 4   │ 1926             │ 0.223451  │ 0.0         │
# │ 5   │ 3443             │ 1.04179   │ 0.0         │
# │ 6   │ 3675             │ -0.770731 │ 0.0         │
# │ 7   │ 3996             │ -1.19295  │ 0.0         │
# │ 8   │ 4223             │ 0.0699161 │ 0.0         │
# │ 9   │ 4289             │ 2.27486   │ 0.0         │
# │ 10  │ 4762             │ 0.522672  │ 0.0         │
# n = 560, and p = 5040
# Total iteration number was 743
# Total time was 12.323181867599487
# running the 44 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 42               │ 0.594738  │ 0.0         │
# │ 2   │ 107              │ -0.320463 │ 0.0         │
# │ 3   │ 111              │ -1.23118  │ -1.08431    │
# │ 4   │ 136              │ 2.19009   │ 2.00686     │
# │ 5   │ 140              │ -2.65637  │ -2.36419    │
# │ 6   │ 162              │ 0.454339  │ 0.449621    │
# │ 7   │ 172              │ 0.518203  │ 0.0         │
# │ 8   │ 247              │ 0.480934  │ 0.0         │
# │ 9   │ 286              │ 0.375618  │ 0.503057    │
# │ 10  │ 321              │ -0.670118 │ -0.643498   │
# n = 323, and p = 323
# Total iteration number was 549
# Total time was 0.43629002571105957
# running the 45 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β     │ estimated_β │
# │     │ Int64            │ Float64    │ Float64     │
# ├─────┼──────────────────┼────────────┼─────────────┤
# │ 1   │ 1442             │ -0.949688  │ -0.840177   │
# │ 2   │ 1464             │ -0.404527  │ 0.0         │
# │ 3   │ 1534             │ -0.0855779 │ 0.0         │
# │ 4   │ 1633             │ -0.457522  │ 0.0         │
# │ 5   │ 1646             │ -0.0443792 │ 0.0         │
# │ 6   │ 1783             │ 1.96274    │ 2.00734     │
# │ 7   │ 2087             │ -0.407423  │ -0.411983   │
# │ 8   │ 2388             │ 0.645731   │ 0.745407    │
# │ 9   │ 2462             │ 0.202232   │ 0.0         │
# │ 10  │ 3121             │ -1.02098   │ -1.15657    │
# n = 405, and p = 3240
# Total iteration number was 247
# Total time was 1.9043419361114502
# running the 46 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 574              │ 0.297149  │ 0.0         │
# │ 2   │ 1507             │ 1.21162   │ 1.07832     │
# │ 3   │ 1808             │ 0.115537  │ 0.0         │
# │ 4   │ 2199             │ -1.44659  │ 0.0         │
# │ 5   │ 2444             │ -1.3039   │ 0.0         │
# │ 6   │ 3558             │ 1.10471   │ 1.0515      │
# │ 7   │ 3773             │ -1.2936   │ -1.4375     │
# │ 8   │ 4033             │ -0.355583 │ 0.0         │
# │ 9   │ 5039             │ 0.587618  │ 0.0         │
# │ 10  │ 5058             │ 0.136803  │ 0.0         │
# n = 742, and p = 5194
# Total iteration number was 315
# Total time was 6.745189905166626
# running the 47 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 467              │ 1.15051   │ 1.18321     │
# │ 2   │ 486              │ 0.198973  │ 0.217969    │
# │ 3   │ 1290             │ -0.879589 │ -0.899588   │
# │ 4   │ 2159             │ -0.745542 │ 0.0         │
# │ 5   │ 2247             │ -1.38915  │ -1.41179    │
# │ 6   │ 2721             │ 0.180043  │ 0.188345    │
# │ 7   │ 2812             │ 0.830594  │ 0.835319    │
# │ 8   │ 2997             │ 0.420223  │ 0.427934    │
# │ 9   │ 3235             │ 0.0272763 │ 0.0         │
# │ 10  │ 3338             │ 0.522658  │ 0.522885    │
# n = 889, and p = 3556
# Total iteration number was 442
# Total time was 7.613205909729004
# running the 48 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 139              │ -1.3064   │ 0.0         │
# │ 2   │ 363              │ -0.616187 │ -0.516979   │
# │ 3   │ 622              │ 0.704905  │ 0.524009    │
# │ 4   │ 1127             │ 0.720575  │ 0.518236    │
# │ 5   │ 1449             │ 1.67268   │ 1.5029      │
# │ 6   │ 1509             │ -0.458372 │ 0.0         │
# │ 7   │ 1548             │ -0.597315 │ -0.639278   │
# │ 8   │ 1611             │ 0.272302  │ 0.0         │
# │ 9   │ 1621             │ 0.298858  │ 0.0         │
# │ 10  │ 1894             │ 0.809706  │ 0.979867    │
# n = 985, and p = 1970
# Total iteration number was 344
# Total time was 3.7473390102386475
# running the 49 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 135              │ -0.583617 │ 0.0         │
# │ 2   │ 246              │ 0.0559589 │ 0.0         │
# │ 3   │ 528              │ -0.674415 │ -0.729501   │
# │ 4   │ 706              │ -0.58651  │ -0.626327   │
# │ 5   │ 969              │ -0.248088 │ -0.142239   │
# │ 6   │ 1189             │ 0.323854  │ 0.263108    │
# │ 7   │ 1471             │ -0.589441 │ -0.603218   │
# │ 8   │ 1687             │ 1.23791   │ 1.2905      │
# │ 9   │ 2073             │ -0.258575 │ 0.0         │
# │ 10  │ 2203             │ -0.293928 │ -0.219388   │
# n = 516, and p = 2580
# Total iteration number was 53
# Total time was 0.44775819778442383
# running the 50 th model
# Did not converge!!!!! The run time for IHT was 5.007835149765015seconds and model size was10compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β     │ estimated_β │
# │     │ Int64            │ Float64    │ Float64     │
# ├─────┼──────────────────┼────────────┼─────────────┤
# │ 1   │ 1                │ -1.39602   │ -0.721334   │
# │ 2   │ 9                │ 0.865832   │ 0.927556    │
# │ 3   │ 36               │ 0.554006   │ 0.0         │
# │ 4   │ 276              │ -0.824963  │ 0.0         │
# │ 5   │ 279              │ -1.51615   │ -1.70933    │
# │ 6   │ 383              │ 0.173161   │ 0.0         │
# │ 7   │ 455              │ -0.0993538 │ 0.0         │
# │ 8   │ 1213             │ 0.316962   │ 0.0         │
# │ 9   │ 1451             │ 1.69256    │ 1.89007     │
# │ 10  │ 1794             │ -1.00332   │ 0.0         │
# n = 395, and p = 1975
# Total iteration number was 1000
# Total time was 5.007835149765015
# running the 51 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 149              │ 0.10597   │ 0.0         │
# │ 2   │ 197              │ 0.975227  │ 0.852891    │
# │ 3   │ 347              │ -0.822166 │ 0.0         │
# │ 4   │ 456              │ 0.576814  │ 0.652892    │
# │ 5   │ 863              │ -0.099226 │ 0.0         │
# │ 6   │ 912              │ 0.101605  │ 0.0         │
# │ 7   │ 1148             │ 0.127927  │ 0.0         │
# │ 8   │ 1248             │ 0.154355  │ 0.0         │
# │ 9   │ 1461             │ -0.582886 │ 0.0         │
# │ 10  │ 1555             │ 2.43496   │ 2.25794     │
# n = 788, and p = 1576
# Total iteration number was 367
# Total time was 2.5845179557800293
# running the 52 th model
# Did not converge!!!!! The run time for IHT was 3.2714431285858154seconds and model size was10compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 80               │ -0.415882 │ 0.0         │
# │ 2   │ 345              │ -0.961484 │ 0.0         │
# │ 3   │ 399              │ 0.911782  │ 0.845686    │
# │ 4   │ 810              │ -0.351533 │ 0.0         │
# │ 5   │ 928              │ -0.519614 │ 0.0         │
# │ 6   │ 951              │ -0.19262  │ 0.0         │
# │ 7   │ 1265             │ -0.681069 │ 0.0         │
# │ 8   │ 1403             │ -0.217831 │ 0.0         │
# │ 9   │ 1523             │ 0.504268  │ 0.578378    │
# │ 10  │ 1794             │ -0.938519 │ 0.0         │
# n = 228, and p = 2052
# Total iteration number was 1000
# Total time was 3.2714431285858154
# running the 53 th model
# Did not converge!!!!! The run time for IHT was 5.966365098953247seconds and model size was10compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β     │ estimated_β │
# │     │ Int64            │ Float64    │ Float64     │
# ├─────┼──────────────────┼────────────┼─────────────┤
# │ 1   │ 188              │ -0.102033  │ 0.0         │
# │ 2   │ 192              │ -0.239866  │ 0.0         │
# │ 3   │ 373              │ -0.769313  │ 0.0         │
# │ 4   │ 619              │ 1.06213    │ 0.0         │
# │ 5   │ 1299             │ 2.21167    │ 2.46008     │
# │ 6   │ 1341             │ -0.0887121 │ 0.0         │
# │ 7   │ 1907             │ 0.0512322  │ 0.0         │
# │ 8   │ 1934             │ 1.59196    │ 1.50889     │
# │ 9   │ 1995             │ -1.27859   │ -1.06688    │
# │ 10  │ 2418             │ -2.30854   │ -2.20498    │
# n = 373, and p = 2611
# Total iteration number was 1000
# Total time was 5.966365098953247
# running the 54 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β     │ estimated_β │
# │     │ Int64            │ Float64    │ Float64     │
# ├─────┼──────────────────┼────────────┼─────────────┤
# │ 1   │ 22               │ 0.83184    │ 0.702147    │
# │ 2   │ 937              │ 0.674416   │ 0.0         │
# │ 3   │ 995              │ 0.136027   │ 0.0         │
# │ 4   │ 1370             │ -2.02745   │ 0.0         │
# │ 5   │ 1400             │ 0.490228   │ 0.0         │
# │ 6   │ 2296             │ -0.135477  │ 0.0         │
# │ 7   │ 3115             │ 1.25382    │ 1.23361     │
# │ 8   │ 3378             │ 0.547869   │ 0.0         │
# │ 9   │ 4305             │ -0.0585686 │ 0.0         │
# │ 10  │ 5300             │ 2.76163    │ 2.27682     │
# n = 596, and p = 5364
# Total iteration number was 564
# Total time was 9.91289496421814
# running the 55 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β     │ estimated_β │
# │     │ Int64            │ Float64    │ Float64     │
# ├─────┼──────────────────┼────────────┼─────────────┤
# │ 1   │ 37               │ -0.0338267 │ 0.0         │
# │ 2   │ 480              │ 0.695248   │ 0.670003    │
# │ 3   │ 571              │ 0.867375   │ 0.856805    │
# │ 4   │ 991              │ -0.338475  │ -0.3768     │
# │ 5   │ 1011             │ 1.4642     │ 1.48927     │
# │ 6   │ 1282             │ 0.789543   │ 0.779332    │
# │ 7   │ 1609             │ -0.416764  │ 0.0         │
# │ 8   │ 2001             │ -0.357811  │ 0.0         │
# │ 9   │ 2025             │ 1.65083    │ 1.66378     │
# │ 10  │ 2482             │ -0.0232803 │ 0.0         │
# n = 317, and p = 2536
# Total iteration number was 278
# Total time was 1.3112318515777588
# running the 56 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β     │ estimated_β │
# │     │ Int64            │ Float64    │ Float64     │
# ├─────┼──────────────────┼────────────┼─────────────┤
# │ 1   │ 4                │ 0.513682   │ 0.448914    │
# │ 2   │ 54               │ -1.33103   │ 0.0         │
# │ 3   │ 136              │ -0.11301   │ 0.0         │
# │ 4   │ 159              │ -0.0368255 │ 0.0         │
# │ 5   │ 279              │ -2.60842   │ -2.53591    │
# │ 6   │ 315              │ -0.298101  │ -0.259437   │
# │ 7   │ 565              │ -0.950212  │ -0.914938   │
# │ 8   │ 618              │ -0.90703   │ -0.900395   │
# │ 9   │ 833              │ -1.78114   │ -1.64282    │
# │ 10  │ 1118             │ 0.403883   │ 0.462698    │
# n = 392, and p = 1176
# Total iteration number was 486
# Total time was 1.3574190139770508
# ...
# │ 5   │ 1449             │ 1.67268   │ 1.5029      │
# │ 6   │ 1509             │ -0.458372 │ 0.0         │
# │ 7   │ 1548             │ -0.597315 │ -0.639278   │
# │ 8   │ 1611             │ 0.272302  │ 0.0         │
# │ 9   │ 1621             │ 0.298858  │ 0.0         │
# │ 10  │ 1894             │ 0.809706  │ 0.979867    │
# n = 985, and p = 1970
# Total iteration number was 344
# Total time was 3.5903520584106445
# running the 83 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 135              │ -0.583617 │ 0.0         │
# │ 2   │ 246              │ 0.0559589 │ 0.0         │
# │ 3   │ 528              │ -0.674415 │ -0.729501   │
# │ 4   │ 706              │ -0.58651  │ -0.626327   │
# │ 5   │ 969              │ -0.248088 │ -0.142239   │
# │ 6   │ 1189             │ 0.323854  │ 0.263108    │
# │ 7   │ 1471             │ -0.589441 │ -0.603218   │
# │ 8   │ 1687             │ 1.23791   │ 1.2905      │
# │ 9   │ 2073             │ -0.258575 │ 0.0         │
# │ 10  │ 2203             │ -0.293928 │ -0.219388   │
# n = 516, and p = 2580
# Total iteration number was 53
# Total time was 0.41544294357299805
# running the 84 th model
# Did not converge!!!!! The run time for IHT was 4.728385925292969seconds and model size was10compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β     │ estimated_β │
# │     │ Int64            │ Float64    │ Float64     │
# ├─────┼──────────────────┼────────────┼─────────────┤
# │ 1   │ 1                │ -1.39602   │ -0.721334   │
# │ 2   │ 9                │ 0.865832   │ 0.927556    │
# │ 3   │ 36               │ 0.554006   │ 0.0         │
# │ 4   │ 276              │ -0.824963  │ 0.0         │
# │ 5   │ 279              │ -1.51615   │ -1.70933    │
# │ 6   │ 383              │ 0.173161   │ 0.0         │
# │ 7   │ 455              │ -0.0993538 │ 0.0         │
# │ 8   │ 1213             │ 0.316962   │ 0.0         │
# │ 9   │ 1451             │ 1.69256    │ 1.89007     │
# │ 10  │ 1794             │ -1.00332   │ 0.0         │
# n = 395, and p = 1975
# Total iteration number was 1000
# Total time was 4.728385925292969
# running the 85 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 149              │ 0.10597   │ 0.0         │
# │ 2   │ 197              │ 0.975227  │ 0.852891    │
# │ 3   │ 347              │ -0.822166 │ 0.0         │
# │ 4   │ 456              │ 0.576814  │ 0.652892    │
# │ 5   │ 863              │ -0.099226 │ 0.0         │
# │ 6   │ 912              │ 0.101605  │ 0.0         │
# │ 7   │ 1148             │ 0.127927  │ 0.0         │
# │ 8   │ 1248             │ 0.154355  │ 0.0         │
# │ 9   │ 1461             │ -0.582886 │ 0.0         │
# │ 10  │ 1555             │ 2.43496   │ 2.25794     │
# n = 788, and p = 1576
# Total iteration number was 367
# Total time was 2.5774199962615967
# running the 86 th model
# Did not converge!!!!! The run time for IHT was 3.2627251148223877seconds and model size was10compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 80               │ -0.415882 │ 0.0         │
# │ 2   │ 345              │ -0.961484 │ 0.0         │
# │ 3   │ 399              │ 0.911782  │ 0.845686    │
# │ 4   │ 810              │ -0.351533 │ 0.0         │
# │ 5   │ 928              │ -0.519614 │ 0.0         │
# │ 6   │ 951              │ -0.19262  │ 0.0         │
# │ 7   │ 1265             │ -0.681069 │ 0.0         │
# │ 8   │ 1403             │ -0.217831 │ 0.0         │
# │ 9   │ 1523             │ 0.504268  │ 0.578378    │
# │ 10  │ 1794             │ -0.938519 │ 0.0         │
# n = 228, and p = 2052
# Total iteration number was 1000
# Total time was 3.2627251148223877
# running the 87 th model
# Did not converge!!!!! The run time for IHT was 5.94677996635437seconds and model size was10compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β     │ estimated_β │
# │     │ Int64            │ Float64    │ Float64     │
# ├─────┼──────────────────┼────────────┼─────────────┤
# │ 1   │ 188              │ -0.102033  │ 0.0         │
# │ 2   │ 192              │ -0.239866  │ 0.0         │
# │ 3   │ 373              │ -0.769313  │ 0.0         │
# │ 4   │ 619              │ 1.06213    │ 0.0         │
# │ 5   │ 1299             │ 2.21167    │ 2.46008     │
# │ 6   │ 1341             │ -0.0887121 │ 0.0         │
# │ 7   │ 1907             │ 0.0512322  │ 0.0         │
# │ 8   │ 1934             │ 1.59196    │ 1.50889     │
# │ 9   │ 1995             │ -1.27859   │ -1.06688    │
# │ 10  │ 2418             │ -2.30854   │ -2.20498    │
# n = 373, and p = 2611
# Total iteration number was 1000
# Total time was 5.94677996635437
# running the 88 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β     │ estimated_β │
# │     │ Int64            │ Float64    │ Float64     │
# ├─────┼──────────────────┼────────────┼─────────────┤
# │ 1   │ 22               │ 0.83184    │ 0.702147    │
# │ 2   │ 937              │ 0.674416   │ 0.0         │
# │ 3   │ 995              │ 0.136027   │ 0.0         │
# │ 4   │ 1370             │ -2.02745   │ 0.0         │
# │ 5   │ 1400             │ 0.490228   │ 0.0         │
# │ 6   │ 2296             │ -0.135477  │ 0.0         │
# │ 7   │ 3115             │ 1.25382    │ 1.23361     │
# │ 8   │ 3378             │ 0.547869   │ 0.0         │
# │ 9   │ 4305             │ -0.0585686 │ 0.0         │
# │ 10  │ 5300             │ 2.76163    │ 2.27682     │
# n = 596, and p = 5364
# Total iteration number was 564
# Total time was 9.995223045349121
# running the 89 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β     │ estimated_β │
# │     │ Int64            │ Float64    │ Float64     │
# ├─────┼──────────────────┼────────────┼─────────────┤
# │ 1   │ 37               │ -0.0338267 │ 0.0         │
# │ 2   │ 480              │ 0.695248   │ 0.670003    │
# │ 3   │ 571              │ 0.867375   │ 0.856805    │
# │ 4   │ 991              │ -0.338475  │ -0.3768     │
# │ 5   │ 1011             │ 1.4642     │ 1.48927     │
# │ 6   │ 1282             │ 0.789543   │ 0.779332    │
# │ 7   │ 1609             │ -0.416764  │ 0.0         │
# │ 8   │ 2001             │ -0.357811  │ 0.0         │
# │ 9   │ 2025             │ 1.65083    │ 1.66378     │
# │ 10  │ 2482             │ -0.0232803 │ 0.0         │
# n = 317, and p = 2536
# Total iteration number was 278
# Total time was 1.3360679149627686
# running the 90 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β     │ estimated_β │
# │     │ Int64            │ Float64    │ Float64     │
# ├─────┼──────────────────┼────────────┼─────────────┤
# │ 1   │ 4                │ 0.513682   │ 0.448914    │
# │ 2   │ 54               │ -1.33103   │ 0.0         │
# │ 3   │ 136              │ -0.11301   │ 0.0         │
# │ 4   │ 159              │ -0.0368255 │ 0.0         │
# │ 5   │ 279              │ -2.60842   │ -2.53591    │
# │ 6   │ 315              │ -0.298101  │ -0.259437   │
# │ 7   │ 565              │ -0.950212  │ -0.914938   │
# │ 8   │ 618              │ -0.90703   │ -0.900395   │
# │ 9   │ 833              │ -1.78114   │ -1.64282    │
# │ 10  │ 1118             │ 0.403883   │ 0.462698    │
# n = 392, and p = 1176
# Total iteration number was 486
# Total time was 1.346923828125
# running the 91 th model
# Did not converge!!!!! The run time for IHT was 13.149163007736206seconds and model size was10compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 571              │ 0.773024  │ 0.662251    │
# │ 2   │ 736              │ 0.939701  │ 1.12644     │
# │ 3   │ 762              │ -0.11961  │ 0.0         │
# │ 4   │ 777              │ -0.127817 │ 0.0         │
# │ 5   │ 807              │ -1.05345  │ -1.1992     │
# │ 6   │ 1031             │ -0.22231  │ 0.0         │
# │ 7   │ 2636             │ -0.314104 │ 0.0         │
# │ 8   │ 3551             │ -0.781767 │ -1.02227    │
# │ 9   │ 3596             │ -1.23592  │ 0.0         │
# │ 10  │ 3878             │ -0.405063 │ 0.0         │
# n = 526, and p = 4208
# Total iteration number was 1000
# Total time was 13.149163007736206
# running the 92 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 48               │ 0.295283  │ 0.33845     │
# │ 2   │ 267              │ 0.397846  │ 0.424723    │
# │ 3   │ 911              │ -0.407813 │ -0.444839   │
# │ 4   │ 1069             │ 0.0230365 │ 0.0         │
# │ 5   │ 1210             │ -0.653161 │ -0.693002   │
# │ 6   │ 1491             │ -0.307373 │ -0.305068   │
# │ 7   │ 2153             │ -1.54703  │ -1.91583    │
# │ 8   │ 2719             │ -0.357009 │ 0.0         │
# │ 9   │ 3042             │ -2.70177  │ 0.0         │
# │ 10  │ 3316             │ 0.142427  │ 0.183285    │
# n = 458, and p = 4122
# Total iteration number was 41
# Total time was 0.49143314361572266
# running the 93 th model
# Did not converge!!!!! The run time for IHT was 2.516638994216919seconds and model size was10compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 151              │ 2.96597   │ 2.40907     │
# │ 2   │ 186              │ 1.16522   │ 0.0         │
# │ 3   │ 271              │ -0.84365  │ 0.0         │
# │ 4   │ 397              │ 0.982157  │ 0.0         │
# │ 5   │ 439              │ 0.0988462 │ 0.0         │
# │ 6   │ 581              │ -0.156941 │ 0.0         │
# │ 7   │ 851              │ -0.175329 │ 0.0         │
# │ 8   │ 916              │ -0.826267 │ 0.0         │
# │ 9   │ 1183             │ 1.10249   │ 0.0         │
# │ 10  │ 1298             │ -0.715442 │ 0.0         │
# n = 274, and p = 1370
# Total iteration number was 1000
# Total time was 2.516638994216919
# running the 94 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 1                │ 0.774686  │ 0.618953    │
# │ 2   │ 11               │ -0.426882 │ 0.0         │
# │ 3   │ 18               │ -0.396178 │ 0.0         │
# │ 4   │ 33               │ -0.360743 │ -0.359415   │
# │ 5   │ 56               │ 0.512995  │ 0.57555     │
# │ 6   │ 72               │ 1.89463   │ 1.93268     │
# │ 7   │ 134              │ -1.15297  │ -1.16711    │
# │ 8   │ 150              │ -1.30028  │ -1.39228    │
# │ 9   │ 208              │ -1.06833  │ 0.0         │
# │ 10  │ 209              │ 0.664143  │ 0.506428    │
# n = 277, and p = 277
# Total iteration number was 392
# Total time was 0.2442171573638916
# running the 95 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β     │ estimated_β │
# │     │ Int64            │ Float64    │ Float64     │
# ├─────┼──────────────────┼────────────┼─────────────┤
# │ 1   │ 28               │ 0.155486   │ 0.146166    │
# │ 2   │ 102              │ 0.68947    │ 0.69127     │
# │ 3   │ 242              │ -0.0848197 │ 0.0         │
# │ 4   │ 333              │ -0.346356  │ -0.342161   │
# │ 5   │ 364              │ -0.0791232 │ 0.0         │
# │ 6   │ 413              │ 0.93595    │ 0.94153     │
# │ 7   │ 499              │ 0.376639   │ 0.359744    │
# │ 8   │ 501              │ -0.0904944 │ 0.0         │
# │ 9   │ 591              │ -0.717629  │ -0.718043   │
# │ 10  │ 592              │ -0.561986  │ -0.54871    │
# n = 716, and p = 716
# Total iteration number was 54
# Total time was 0.20593500137329102
# running the 96 th model
# Did not converge!!!!! The run time for IHT was 1.087447166442871seconds and model size was10compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β     │ estimated_β │
# │     │ Int64            │ Float64    │ Float64     │
# ├─────┼──────────────────┼────────────┼─────────────┤
# │ 1   │ 168              │ -0.314457  │ 0.0         │
# │ 2   │ 184              │ 0.450781   │ 0.0         │
# │ 3   │ 200              │ -0.0323266 │ 0.0         │
# │ 4   │ 238              │ -1.02502   │ 0.0         │
# │ 5   │ 293              │ -1.89178   │ 0.0         │
# │ 6   │ 505              │ -0.226567  │ 0.0         │
# │ 7   │ 540              │ 0.389614   │ 0.0         │
# │ 8   │ 569              │ 1.81411    │ 0.0         │
# │ 9   │ 659              │ -1.37365   │ 0.0         │
# │ 10  │ 737              │ -0.334603  │ 0.0         │
# n = 146, and p = 876
# Total iteration number was 1000
# Total time was 1.087447166442871
# running the 97 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 574              │ 0.297149  │ 0.0         │
# │ 2   │ 1507             │ 1.21162   │ 1.07832     │
# │ 3   │ 1808             │ 0.115537  │ 0.0         │
# │ 4   │ 2199             │ -1.44659  │ 0.0         │
# │ 5   │ 2444             │ -1.3039   │ 0.0         │
# │ 6   │ 3558             │ 1.10471   │ 1.0515      │
# │ 7   │ 3773             │ -1.2936   │ -1.4375     │
# │ 8   │ 4033             │ -0.355583 │ 0.0         │
# │ 9   │ 5039             │ 0.587618  │ 0.0         │
# │ 10  │ 5058             │ 0.136803  │ 0.0         │
# n = 742, and p = 5194
# Total iteration number was 315
# Total time was 6.743177890777588
# running the 98 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 467              │ 1.15051   │ 1.18321     │
# │ 2   │ 486              │ 0.198973  │ 0.217969    │
# │ 3   │ 1290             │ -0.879589 │ -0.899588   │
# │ 4   │ 2159             │ -0.745542 │ 0.0         │
# │ 5   │ 2247             │ -1.38915  │ -1.41179    │
# │ 6   │ 2721             │ 0.180043  │ 0.188345    │
# │ 7   │ 2812             │ 0.830594  │ 0.835319    │
# │ 8   │ 2997             │ 0.420223  │ 0.427934    │
# │ 9   │ 3235             │ 0.0272763 │ 0.0         │
# │ 10  │ 3338             │ 0.522658  │ 0.522885    │
# n = 889, and p = 3556
# Total iteration number was 442
# Total time was 7.6473000049591064
# running the 99 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 139              │ -1.3064   │ 0.0         │
# │ 2   │ 363              │ -0.616187 │ -0.516979   │
# │ 3   │ 622              │ 0.704905  │ 0.524009    │
# │ 4   │ 1127             │ 0.720575  │ 0.518236    │
# │ 5   │ 1449             │ 1.67268   │ 1.5029      │
# │ 6   │ 1509             │ -0.458372 │ 0.0         │
# │ 7   │ 1548             │ -0.597315 │ -0.639278   │
# │ 8   │ 1611             │ 0.272302  │ 0.0         │
# │ 9   │ 1621             │ 0.298858  │ 0.0         │
# │ 10  │ 1894             │ 0.809706  │ 0.979867    │
# n = 985, and p = 1970
# Total iteration number was 344
# Total time was 3.714339017868042
# running the 100 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 135              │ -0.583617 │ 0.0         │
# │ 2   │ 246              │ 0.0559589 │ 0.0         │
# │ 3   │ 528              │ -0.674415 │ -0.729501   │
# │ 4   │ 706              │ -0.58651  │ -0.626327   │
# │ 5   │ 969              │ -0.248088 │ -0.142239   │
# │ 6   │ 1189             │ 0.323854  │ 0.263108    │
# │ 7   │ 1471             │ -0.589441 │ -0.603218   │
# │ 8   │ 1687             │ 1.23791   │ 1.2905      │
# │ 9   │ 2073             │ -0.258575 │ 0.0         │
# │ 10  │ 2203             │ -0.293928 │ -0.219388   │
# n = 516, and p = 2580
# Total iteration number was 53
# Total time was 0.43788719177246094

# %% [markdown]
# # Poisson testing ad hoc scaling v.df (divide v.b by 10)

# %%
#scaling v.b down by 2, scaling v.df down by exp(1/2)
for i = 1:100
    println("running the $i th model")
    n = rand(100:1000) 
    p = rand(1:10)n
    run_poisson(n, p)
end
# Out:
# running the 1 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 61               │ -0.985009 │ -0.999038   │
# │ 2   │ 195              │ -0.134038 │ 0.0         │
# │ 3   │ 339              │ -0.541968 │ -0.547913   │
# │ 4   │ 353              │ -0.24548  │ -0.192981   │
# │ 5   │ 363              │ -1.75137  │ -1.7294     │
# │ 6   │ 403              │ -0.232117 │ -0.205514   │
# │ 7   │ 446              │ -1.22987  │ -1.20587    │
# │ 8   │ 463              │ -0.184661 │ -0.188596   │
# │ 9   │ 578              │ 0.752658  │ 0.760266    │
# │ 10  │ 587              │ -0.933025 │ -0.899582   │
# n = 288, and p = 864
# Total iteration number was 127
# Total time was 0.19269108772277832
# running the 2 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β     │ estimated_β │
# │     │ Int64            │ Float64    │ Float64     │
# ├─────┼──────────────────┼────────────┼─────────────┤
# │ 1   │ 4                │ -0.9262    │ -0.900802   │
# │ 2   │ 50               │ 0.541709   │ 0.269025    │
# │ 3   │ 499              │ 0.7642     │ 0.642582    │
# │ 4   │ 957              │ -0.324672  │ 0.0         │
# │ 5   │ 1183             │ -0.312027  │ 0.0         │
# │ 6   │ 1488             │ -0.636542  │ 0.0         │
# │ 7   │ 1767             │ 0.762048   │ 0.671997    │
# │ 8   │ 2508             │ 0.712022   │ 0.0         │
# │ 9   │ 3106             │ -0.0943736 │ 0.0         │
# │ 10  │ 3330             │ -2.21392   │ -2.13213    │
# n = 373, and p = 3357
# Total iteration number was 531
# Total time was 3.6958038806915283
# running the 3 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 60               │ 2.47994   │ 1.18006     │
# │ 2   │ 158              │ -1.33615  │ 0.0         │
# │ 3   │ 246              │ 1.57253   │ 0.0         │
# │ 4   │ 385              │ 0.863036  │ 0.0         │
# │ 5   │ 418              │ 0.126956  │ 0.0         │
# │ 6   │ 568              │ 1.15843   │ 0.0         │
# │ 7   │ 746              │ -1.14701  │ 0.0         │
# │ 8   │ 796              │ 1.25819   │ 1.56578     │
# │ 9   │ 979              │ 1.13552   │ 0.0         │
# │ 10  │ 1562             │ -0.157115 │ 0.0         │
# n = 261, and p = 1566
# Total iteration number was 403
# Total time was 0.953361988067627
# running the 4 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β     │ estimated_β │
# │     │ Int64            │ Float64    │ Float64     │
# ├─────┼──────────────────┼────────────┼─────────────┤
# │ 1   │ 36               │ 0.0291318  │ 0.0         │
# │ 2   │ 315              │ 0.737451   │ 0.0         │
# │ 3   │ 1662             │ 0.392857   │ 0.0         │
# │ 4   │ 1822             │ -0.537887  │ 0.0         │
# │ 5   │ 1881             │ 2.53924    │ 2.17145     │
# │ 6   │ 2344             │ -0.0428135 │ 0.0         │
# │ 7   │ 2557             │ 0.537986   │ 0.0         │
# │ 8   │ 2714             │ 0.446035   │ 0.0         │
# │ 9   │ 2890             │ -1.13907   │ 0.0         │
# │ 10  │ 3164             │ 1.00863    │ 0.556252    │
# n = 487, and p = 3409
# Total iteration number was 252
# Total time was 2.3109941482543945
# running the 5 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 164              │ 0.400348  │ 0.412904    │
# │ 2   │ 1282             │ -1.01169  │ -1.02587    │
# │ 3   │ 1484             │ -0.480944 │ 0.0         │
# │ 4   │ 3424             │ -0.72189  │ -0.700997   │
# │ 5   │ 4212             │ -0.484155 │ -0.486556   │
# │ 6   │ 5025             │ 0.705864  │ 0.691175    │
# │ 7   │ 5324             │ -0.374139 │ -0.357863   │
# │ 8   │ 5657             │ 1.94551   │ 1.94377     │
# │ 9   │ 6171             │ -0.500868 │ -0.495636   │
# │ 10  │ 7860             │ -0.111692 │ -0.089612   │
# n = 860, and p = 8600
# Total iteration number was 145
# Total time was 5.858180046081543
# running the 6 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 13               │ -0.266127 │ 0.0         │
# │ 2   │ 65               │ -0.384746 │ -0.396859   │
# │ 3   │ 132              │ -0.705902 │ -0.771156   │
# │ 4   │ 135              │ -0.450695 │ 0.0         │
# │ 5   │ 169              │ -1.38495  │ -1.3916     │
# │ 6   │ 195              │ -0.18172  │ 0.0         │
# │ 7   │ 243              │ -0.96746  │ -0.940629   │
# │ 8   │ 291              │ 0.213028  │ 0.0         │
# │ 9   │ 409              │ -1.39059  │ -1.39811    │
# │ 10  │ 423              │ 0.529908  │ 0.480263    │
# n = 437, and p = 437
# Total iteration number was 195
# Total time was 0.22843408584594727
# running the 7 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 13               │ 1.03219   │ 0.0         │
# │ 2   │ 746              │ -2.04395  │ 0.0         │
# │ 3   │ 747              │ -0.244587 │ 0.0         │
# │ 4   │ 748              │ 0.660595  │ 0.0         │
# │ 5   │ 1766             │ 1.36775   │ 0.0         │
# │ 6   │ 2202             │ -1.3243   │ 0.0         │
# │ 7   │ 2373             │ -1.71821  │ 0.0         │
# │ 8   │ 3401             │ 0.0203611 │ 0.0         │
# │ 9   │ 3635             │ -1.65835  │ 0.0         │
# │ 10  │ 4493             │ 1.40398   │ 1.02893     │
# n = 577, and p = 4616
# Total iteration number was 571
# Total time was 8.254271030426025
# running the 8 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 5                │ 0.496098  │ 0.0         │
# │ 2   │ 52               │ 0.537965  │ 0.777162    │
# │ 3   │ 76               │ -1.59677  │ -1.31138    │
# │ 4   │ 87               │ 1.91715   │ 1.6657      │
# │ 5   │ 97               │ 1.41566   │ 1.01946     │
# │ 6   │ 174              │ -1.63307  │ 0.0         │
# │ 7   │ 215              │ 0.246489  │ 0.0         │
# │ 8   │ 216              │ 0.506934  │ 0.0         │
# │ 9   │ 244              │ -0.547957 │ 0.0         │
# │ 10  │ 263              │ 0.757525  │ 0.64615     │
# n = 333, and p = 333
# Total iteration number was 264
# Total time was 0.1903839111328125
# running the 9 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β      │ estimated_β │
# │     │ Int64            │ Float64     │ Float64     │
# ├─────┼──────────────────┼─────────────┼─────────────┤
# │ 1   │ 71               │ -0.101725   │ -0.0958992  │
# │ 2   │ 805              │ 1.60419     │ 1.57697     │
# │ 3   │ 1461             │ 0.731018    │ 0.716832    │
# │ 4   │ 1624             │ -1.84051    │ -1.78247    │
# │ 5   │ 1791             │ 0.403342    │ 0.393124    │
# │ 6   │ 2475             │ 0.436055    │ 0.434679    │
# │ 7   │ 3418             │ -0.00329061 │ 0.0         │
# │ 8   │ 4885             │ 0.588905    │ 0.57128     │
# │ 9   │ 5016             │ 0.609411    │ 0.59858     │
# │ 10  │ 5593             │ 0.0255569   │ 0.0         │
# n = 607, and p = 6070
# Total iteration number was 276
# Total time was 5.518054962158203
# running the 10 th model
# Did not converge!!!!! The run time for IHT was 11.31088900566101seconds and model size was10compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 53               │ 0.0979618 │ 0.0         │
# │ 2   │ 1259             │ -0.748236 │ 0.0         │
# │ 3   │ 1934             │ -1.6156   │ 0.0         │
# │ 4   │ 2149             │ 1.01842   │ 0.0         │
# │ 5   │ 2180             │ -0.115766 │ 0.0         │
# │ 6   │ 2458             │ 1.46053   │ 0.0         │
# │ 7   │ 2537             │ 1.84789   │ 0.0         │
# │ 8   │ 2626             │ -0.585224 │ 0.0         │
# │ 9   │ 3240             │ 0.50107   │ 0.0         │
# │ 10  │ 3257             │ 0.50446   │ 0.0         │
# n = 593, and p = 3558
# Total iteration number was 1000
# Total time was 11.31088900566101
# running the 11 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 8                │ 0.427745  │ 0.0         │
# │ 2   │ 136              │ 1.04905   │ 1.1816      │
# │ 3   │ 259              │ 1.26343   │ 0.0         │
# │ 4   │ 280              │ -0.107693 │ 0.0         │
# │ 5   │ 294              │ -0.995036 │ 0.0         │
# │ 6   │ 475              │ -1.07936  │ 0.0         │
# │ 7   │ 701              │ -0.947605 │ -1.46903    │
# │ 8   │ 754              │ -1.89462  │ -2.01616    │
# │ 9   │ 878              │ 0.361312  │ 0.0         │
# │ 10  │ 888              │ -0.108662 │ 0.0         │
# n = 117, and p = 936
# Total iteration number was 437
# Total time was 0.31848692893981934
# running the 12 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β     │ estimated_β │
# │     │ Int64            │ Float64    │ Float64     │
# ├─────┼──────────────────┼────────────┼─────────────┤
# │ 1   │ 7                │ 0.851923   │ 0.880178    │
# │ 2   │ 186              │ 0.981656   │ 0.946334    │
# │ 3   │ 215              │ 0.197538   │ 0.177312    │
# │ 4   │ 729              │ 0.20467    │ 0.183831    │
# │ 5   │ 1115             │ 0.0488647  │ 0.0571625   │
# │ 6   │ 1187             │ -1.30638   │ -1.30557    │
# │ 7   │ 1232             │ 0.212265   │ 0.204778    │
# │ 8   │ 1368             │ -0.0625165 │ 0.0         │
# │ 9   │ 1629             │ 0.25107    │ 0.288789    │
# │ 10  │ 1650             │ 0.298972   │ 0.284087    │
# n = 578, and p = 1734
# Total iteration number was 211
# Total time was 1.21337890625
# running the 13 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β     │ estimated_β │
# │     │ Int64            │ Float64    │ Float64     │
# ├─────┼──────────────────┼────────────┼─────────────┤
# │ 1   │ 11               │ 0.0399939  │ 0.0         │
# │ 2   │ 114              │ 1.60059    │ 1.538       │
# │ 3   │ 151              │ 0.859161   │ 0.839141    │
# │ 4   │ 260              │ 0.477167   │ 0.480857    │
# │ 5   │ 294              │ 0.343758   │ 0.308173    │
# │ 6   │ 310              │ -0.301803  │ -0.296318   │
# │ 7   │ 333              │ -0.0750364 │ 0.0         │
# │ 8   │ 344              │ 0.0848825  │ 0.0625333   │
# │ 9   │ 417              │ -0.178727  │ -0.159212   │
# │ 10  │ 456              │ 0.235095   │ 0.254378    │
# n = 468, and p = 468
# Total iteration number was 108
# Total time was 0.1486501693725586
# running the 14 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 746              │ 1.06155   │ 1.05067     │
# │ 2   │ 778              │ -1.09427  │ -1.11498    │
# │ 3   │ 909              │ -2.14263  │ -2.1617     │
# │ 4   │ 1667             │ -0.181806 │ -0.17262    │
# │ 5   │ 2559             │ -0.648749 │ -0.636218   │
# │ 6   │ 2931             │ 0.115536  │ 0.129899    │
# │ 7   │ 3330             │ 1.92427   │ 1.93455     │
# │ 8   │ 4543             │ -1.04643  │ -1.03572    │
# │ 9   │ 4778             │ -0.272727 │ 0.0         │
# │ 10  │ 4944             │ -0.191222 │ -0.19927    │
# n = 631, and p = 5048
# Total iteration number was 329
# Total time was 5.672429084777832
# running the 15 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 49               │ 0.808103  │ 0.713658    │
# │ 2   │ 889              │ -0.229319 │ 0.0         │
# │ 3   │ 1128             │ -0.502496 │ -0.537057   │
# │ 4   │ 1160             │ -0.290687 │ 0.0         │
# │ 5   │ 1267             │ -0.195091 │ 0.0         │
# │ 6   │ 1448             │ -1.71884  │ -1.70107    │
# │ 7   │ 1608             │ -1.79253  │ -1.77528    │
# │ 8   │ 1629             │ 0.582721  │ 0.489369    │
# │ 9   │ 2095             │ -0.23636  │ 0.0         │
# │ 10  │ 2219             │ 1.51219   │ 1.41866     │
# n = 528, and p = 2640
# Total iteration number was 520
# Total time was 3.954496145248413
# running the 16 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 708              │ -0.296501 │ 0.0         │
# │ 2   │ 889              │ 0.411067  │ 0.0         │
# │ 3   │ 1058             │ 0.341766  │ 0.0         │
# │ 4   │ 1105             │ -0.248857 │ 0.0         │
# │ 5   │ 1994             │ 0.273221  │ 0.0         │
# │ 6   │ 2352             │ 1.45798   │ 1.37113     │
# │ 7   │ 4575             │ -0.130683 │ 0.0         │
# │ 8   │ 5377             │ 1.41368   │ 1.33283     │
# │ 9   │ 5579             │ -1.0485   │ -1.01838    │
# │ 10  │ 5749             │ -0.284948 │ 0.0         │
# n = 583, and p = 5830
# Total iteration number was 175
# Total time was 3.235507011413574
# running the 17 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 200              │ 0.0670938 │ 0.0         │
# │ 2   │ 223              │ 0.419471  │ 0.0         │
# │ 3   │ 240              │ 0.554151  │ 0.0         │
# │ 4   │ 310              │ 0.856718  │ 0.839897    │
# │ 5   │ 1197             │ -0.704821 │ -0.489903   │
# │ 6   │ 1430             │ 1.59766   │ 1.37013     │
# │ 7   │ 2452             │ 0.908967  │ 0.953301    │
# │ 8   │ 2691             │ 0.698282  │ 0.0         │
# │ 9   │ 2729             │ -0.228871 │ 0.0         │
# │ 10  │ 2938             │ 0.159342  │ 0.0         │
# n = 740, and p = 3700
# Total iteration number was 246
# Total time was 3.561730146408081
# running the 18 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β     │ estimated_β │
# │     │ Int64            │ Float64    │ Float64     │
# ├─────┼──────────────────┼────────────┼─────────────┤
# │ 1   │ 29               │ 1.14855    │ 1.06057     │
# │ 2   │ 216              │ 1.0536     │ 0.931102    │
# │ 3   │ 708              │ -1.00313   │ -0.750034   │
# │ 4   │ 741              │ 0.47091    │ 0.0         │
# │ 5   │ 814              │ -0.0592248 │ 0.0         │
# │ 6   │ 1012             │ -0.834     │ -0.67389    │
# │ 7   │ 1065             │ -1.00272   │ -1.00167    │
# │ 8   │ 1296             │ -0.982696  │ 0.0         │
# │ 9   │ 1352             │ -1.12826   │ 0.0         │
# │ 10  │ 1467             │ -0.982909  │ -0.585623   │
# n = 853, and p = 1706
# Total iteration number was 226
# Total time was 1.7596919536590576
# running the 19 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β     │ estimated_β │
# │     │ Int64            │ Float64    │ Float64     │
# ├─────┼──────────────────┼────────────┼─────────────┤
# │ 1   │ 101              │ 0.967102   │ 0.979152    │
# │ 2   │ 304              │ 0.198052   │ 0.194449    │
# │ 3   │ 361              │ -0.167148  │ -0.165947   │
# │ 4   │ 705              │ 0.406127   │ 0.408937    │
# │ 5   │ 985              │ -2.81551   │ -2.85905    │
# │ 6   │ 1091             │ -0.0547972 │ -0.0683919  │
# │ 7   │ 1247             │ 0.0577849  │ 0.0523454   │
# │ 8   │ 1390             │ 0.51253    │ 0.510954    │
# │ 9   │ 1431             │ 0.971827   │ 0.960179    │
# │ 10  │ 2199             │ -0.598143  │ -0.543078   │
# n = 723, and p = 2892
# Total iteration number was 659
# Total time was 7.281373023986816
# running the 20 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β     │ estimated_β │
# │     │ Int64            │ Float64    │ Float64     │
# ├─────┼──────────────────┼────────────┼─────────────┤
# │ 1   │ 151              │ 0.0201094  │ 0.0         │
# │ 2   │ 238              │ 1.39184    │ 0.967114    │
# │ 3   │ 502              │ 0.624735   │ 0.0         │
# │ 4   │ 760              │ -0.684997  │ 0.0         │
# │ 5   │ 1287             │ 0.699991   │ 0.0         │
# │ 6   │ 2294             │ -0.0234585 │ 0.0         │
# │ 7   │ 3992             │ -0.455679  │ 0.0         │
# │ 8   │ 4086             │ -0.385143  │ 0.0         │
# │ 9   │ 4149             │ 1.52025    │ 1.36478     │
# │ 10  │ 4210             │ 1.66275    │ 0.0         │
# n = 550, and p = 4950
# Total iteration number was 525
# Total time was 7.670261859893799
# running the 21 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 945              │ 0.102871  │ 0.0         │
# │ 2   │ 1153             │ 0.580661  │ 0.616523    │
# │ 3   │ 1169             │ 0.313046  │ 0.347542    │
# │ 4   │ 1763             │ -0.141353 │ 0.0         │
# │ 5   │ 1777             │ -0.652556 │ -0.647032   │
# │ 6   │ 2333             │ 0.269112  │ 0.0         │
# │ 7   │ 2585             │ 0.116723  │ 0.0         │
# │ 8   │ 2603             │ 0.443439  │ 0.46384     │
# │ 9   │ 2788             │ 0.825486  │ 0.79818     │
# │ 10  │ 3413             │ 0.285003  │ 0.295175    │
# n = 446, and p = 4460
# Total iteration number was 42
# Total time was 0.4737129211425781
# running the 22 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 3                │ 1.3753    │ 1.37214     │
# │ 2   │ 365              │ 0.0338046 │ 0.0         │
# │ 3   │ 899              │ 2.07204   │ 2.06769     │
# │ 4   │ 1064             │ 0.780237  │ 0.787903    │
# │ 5   │ 2127             │ 0.911439  │ 0.916502    │
# │ 6   │ 2167             │ -0.157079 │ 0.0         │
# │ 7   │ 2217             │ 0.292772  │ 0.29094     │
# │ 8   │ 2597             │ -0.614568 │ -0.626895   │
# │ 9   │ 3084             │ 0.0922361 │ 0.0986202   │
# │ 10  │ 3291             │ 0.589744  │ 0.59243     │
# n = 906, and p = 3624
# Total iteration number was 390
# Total time was 6.680309057235718
# running the 23 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 193              │ 0.50423   │ 0.0         │
# │ 2   │ 329              │ -0.881648 │ 0.0         │
# │ 3   │ 526              │ 0.779442  │ 0.0         │
# │ 4   │ 881              │ -2.22087  │ 0.0         │
# │ 5   │ 947              │ -0.794274 │ 0.0         │
# │ 6   │ 959              │ 1.70794   │ 2.0834      │
# │ 7   │ 1005             │ 0.335995  │ 0.0         │
# │ 8   │ 1203             │ -0.49681  │ 0.0         │
# │ 9   │ 1413             │ -1.85204  │ 0.0         │
# │ 10  │ 2422             │ 0.788197  │ 0.0         │
# n = 863, and p = 2589
# Total iteration number was 709
# Total time was 8.227589845657349
# running the 24 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β     │ estimated_β │
# │     │ Int64            │ Float64    │ Float64     │
# ├─────┼──────────────────┼────────────┼─────────────┤
# │ 1   │ 48               │ 0.100814   │ 0.0998338   │
# │ 2   │ 358              │ 0.0105777  │ 0.0191779   │
# │ 3   │ 562              │ -0.51106   │ -0.508116   │
# │ 4   │ 569              │ -0.0565827 │ 0.0         │
# │ 5   │ 577              │ 2.21399    │ 2.20752     │
# │ 6   │ 772              │ -0.0751124 │ -0.0675736  │
# │ 7   │ 1081             │ -1.79407   │ -1.79042    │
# │ 8   │ 1500             │ 0.164773   │ 0.0         │
# │ 9   │ 1795             │ -1.75323   │ -1.74775    │
# │ 10  │ 2274             │ 0.298242   │ 0.0         │
# n = 494, and p = 2470
# Total iteration number was 671
# Total time was 4.479320049285889
# running the 25 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 104              │ 0.328088  │ 0.0         │
# │ 2   │ 165              │ -0.460698 │ 0.0         │
# │ 3   │ 226              │ 1.52406   │ 1.15393     │
# │ 4   │ 741              │ 0.926414  │ 0.0         │
# │ 5   │ 1241             │ -0.637886 │ 0.0         │
# │ 6   │ 1318             │ -0.900829 │ 0.0         │
# │ 7   │ 1861             │ 0.0718752 │ 0.0         │
# │ 8   │ 2140             │ 1.18543   │ 0.0         │
# │ 9   │ 2595             │ -2.6611   │ 0.0         │
# │ 10  │ 2653             │ 0.812042  │ 0.513356    │
# n = 329, and p = 2961
# Total iteration number was 158
# Total time was 0.8734300136566162
# running the 26 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 271              │ -0.908172 │ -0.90097    │
# │ 2   │ 422              │ -1.53985  │ -1.54691    │
# │ 3   │ 905              │ 0.396946  │ 0.391743    │
# │ 4   │ 1721             │ 0.607188  │ 0.58176     │
# │ 5   │ 1941             │ 0.234488  │ 0.229833    │
# │ 6   │ 2000             │ 0.345074  │ 0.371779    │
# │ 7   │ 2077             │ -0.317019 │ -0.292673   │
# │ 8   │ 2527             │ -1.30676  │ 0.0         │
# │ 9   │ 3059             │ 0.0446506 │ 0.0         │
# │ 10  │ 3137             │ 1.40524   │ 1.38504     │
# n = 559, and p = 3354
# Total iteration number was 120
# Total time was 1.2370657920837402
# running the 27 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 262              │ -0.327832 │ -0.401776   │
# │ 2   │ 332              │ -0.119219 │ 0.0         │
# │ 3   │ 408              │ 0.656962  │ 0.638131    │
# │ 4   │ 928              │ -0.588453 │ -0.55684    │
# │ 5   │ 1325             │ 0.394166  │ 0.0         │
# │ 6   │ 1345             │ -2.12272  │ 0.0         │
# │ 7   │ 1386             │ -0.197391 │ -0.239397   │
# │ 8   │ 2267             │ -1.04196  │ -1.05507    │
# │ 9   │ 2565             │ 0.47152   │ 0.356777    │
# │ 10  │ 2754             │ -0.379605 │ 0.0         │
# n = 311, and p = 2799
# Total iteration number was 70
# Total time was 0.35277795791625977
# running the 28 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 31               │ 0.641461  │ 0.0         │
# │ 2   │ 149              │ 0.5529    │ 0.0         │
# │ 3   │ 153              │ 1.0857    │ 0.73314     │
# │ 4   │ 1238             │ 0.580168  │ 0.0         │
# │ 5   │ 1610             │ 0.435787  │ 0.679332    │
# │ 6   │ 2113             │ -1.3254   │ 0.0         │
# │ 7   │ 2780             │ -0.335501 │ 0.0         │
# │ 8   │ 3021             │ 0.146244  │ 0.0         │
# │ 9   │ 3053             │ 1.16056   │ 0.857378    │
# │ 10  │ 3135             │ 0.175199  │ 0.0         │
# n = 322, and p = 3220
# Total iteration number was 93
# Total time was 0.551826000213623
# running the 29 th model
# Did not converge!!!!! The run time for IHT was 15.158776998519897seconds and model size was10compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 998              │ -0.338142 │ 0.0         │
# │ 2   │ 1064             │ 0.615931  │ 0.0         │
# │ 3   │ 1178             │ -0.056845 │ 0.0         │
# │ 4   │ 1926             │ 0.223451  │ 0.0         │
# │ 5   │ 3443             │ 1.04179   │ 0.0         │
# │ 6   │ 3675             │ -0.770731 │ 0.0         │
# │ 7   │ 3996             │ -1.19295  │ 0.0         │
# │ 8   │ 4223             │ 0.0699161 │ 0.0         │
# │ 9   │ 4289             │ 2.27486   │ 0.0         │
# │ 10  │ 4762             │ 0.522672  │ 0.0         │
# n = 560, and p = 5040
# Total iteration number was 1000
# Total time was 15.158776998519897
# running the 30 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 42               │ 0.594738  │ 0.0         │
# │ 2   │ 107              │ -0.320463 │ 0.0         │
# │ 3   │ 111              │ -1.23118  │ -1.11439    │
# │ 4   │ 136              │ 2.19009   │ 1.97112     │
# │ 5   │ 140              │ -2.65637  │ -2.41478    │
# │ 6   │ 162              │ 0.454339  │ 0.477954    │
# │ 7   │ 172              │ 0.518203  │ 0.244247    │
# │ 8   │ 247              │ 0.480934  │ 0.0         │
# │ 9   │ 286              │ 0.375618  │ 0.422153    │
# │ 10  │ 321              │ -0.670118 │ -0.550829   │
# n = 323, and p = 323
# Total iteration number was 532
# Total time was 0.35256505012512207
# running the 31 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β     │ estimated_β │
# │     │ Int64            │ Float64    │ Float64     │
# ├─────┼──────────────────┼────────────┼─────────────┤
# │ 1   │ 1442             │ -0.949688  │ -0.831629   │
# │ 2   │ 1464             │ -0.404527  │ 0.0         │
# │ 3   │ 1534             │ -0.0855779 │ 0.0         │
# │ 4   │ 1633             │ -0.457522  │ 0.0         │
# │ 5   │ 1646             │ -0.0443792 │ 0.0         │
# │ 6   │ 1783             │ 1.96274    │ 1.7682      │
# │ 7   │ 2087             │ -0.407423  │ -0.405605   │
# │ 8   │ 2388             │ 0.645731   │ 0.666297    │
# │ 9   │ 2462             │ 0.202232   │ 0.0         │
# │ 10  │ 3121             │ -1.02098   │ -1.08762    │
# n = 405, and p = 3240
# Total iteration number was 176
# Total time was 1.2976458072662354
# running the 32 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 574              │ 0.297149  │ 0.0         │
# │ 2   │ 1507             │ 1.21162   │ 1.13308     │
# │ 3   │ 1808             │ 0.115537  │ 0.0         │
# │ 4   │ 2199             │ -1.44659  │ 0.0         │
# │ 5   │ 2444             │ -1.3039   │ 0.0         │
# │ 6   │ 3558             │ 1.10471   │ 1.06492     │
# │ 7   │ 3773             │ -1.2936   │ -1.57839    │
# │ 8   │ 4033             │ -0.355583 │ 0.0         │
# │ 9   │ 5039             │ 0.587618  │ 0.0         │
# │ 10  │ 5058             │ 0.136803  │ 0.0         │
# n = 742, and p = 5194
# Total iteration number was 735
# Total time was 15.133135795593262
# running the 33 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 467              │ 1.15051   │ 1.15839     │
# │ 2   │ 486              │ 0.198973  │ 0.219673    │
# │ 3   │ 1290             │ -0.879589 │ -0.878353   │
# │ 4   │ 2159             │ -0.745542 │ 0.0         │
# │ 5   │ 2247             │ -1.38915  │ -1.39122    │
# │ 6   │ 2721             │ 0.180043  │ 0.183414    │
# │ 7   │ 2812             │ 0.830594  │ 0.818116    │
# │ 8   │ 2997             │ 0.420223  │ 0.415412    │
# │ 9   │ 3235             │ 0.0272763 │ 0.0         │
# │ 10  │ 3338             │ 0.522658  │ 0.513043    │
# n = 889, and p = 3556
# Total iteration number was 173
# Total time was 2.8808209896087646
# running the 34 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 139              │ -1.3064   │ 0.0         │
# │ 2   │ 363              │ -0.616187 │ -0.540005   │
# │ 3   │ 622              │ 0.704905  │ 0.546374    │
# │ 4   │ 1127             │ 0.720575  │ 0.441586    │
# │ 5   │ 1449             │ 1.67268   │ 1.48449     │
# │ 6   │ 1509             │ -0.458372 │ 0.0         │
# │ 7   │ 1548             │ -0.597315 │ -0.644422   │
# │ 8   │ 1611             │ 0.272302  │ 0.0         │
# │ 9   │ 1621             │ 0.298858  │ 0.0         │
# │ 10  │ 1894             │ 0.809706  │ 0.986202    │
# n = 985, and p = 1970
# Total iteration number was 260
# Total time was 2.7414309978485107
# running the 35 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 135              │ -0.583617 │ 0.0         │
# │ 2   │ 246              │ 0.0559589 │ 0.0         │
# │ 3   │ 528              │ -0.674415 │ -0.715644   │
# │ 4   │ 706              │ -0.58651  │ -0.621267   │
# │ 5   │ 969              │ -0.248088 │ -0.215776   │
# │ 6   │ 1189             │ 0.323854  │ 0.263548    │
# │ 7   │ 1471             │ -0.589441 │ -0.597217   │
# │ 8   │ 1687             │ 1.23791   │ 1.20851     │
# │ 9   │ 2073             │ -0.258575 │ -0.249053   │
# │ 10  │ 2203             │ -0.293928 │ -0.279802   │
# n = 516, and p = 2580
# Total iteration number was 58
# Total time was 0.43736815452575684
# running the 36 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β     │ estimated_β │
# │     │ Int64            │ Float64    │ Float64     │
# ├─────┼──────────────────┼────────────┼─────────────┤
# │ 1   │ 1                │ -1.39602   │ 0.0         │
# │ 2   │ 9                │ 0.865832   │ 0.475442    │
# │ 3   │ 36               │ 0.554006   │ 0.0         │
# │ 4   │ 276              │ -0.824963  │ 0.0         │
# │ 5   │ 279              │ -1.51615   │ 0.0         │
# │ 6   │ 383              │ 0.173161   │ 0.0         │
# │ 7   │ 455              │ -0.0993538 │ 0.0         │
# │ 8   │ 1213             │ 0.316962   │ 0.0         │
# │ 9   │ 1451             │ 1.69256    │ 1.19351     │
# │ 10  │ 1794             │ -1.00332   │ 0.0         │
# n = 395, and p = 1975
# Total iteration number was 458
# Total time was 1.977112054824829
# running the 37 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 149              │ 0.10597   │ 0.0         │
# │ 2   │ 197              │ 0.975227  │ 0.901102    │
# │ 3   │ 347              │ -0.822166 │ 0.0         │
# │ 4   │ 456              │ 0.576814  │ 0.747247    │
# │ 5   │ 863              │ -0.099226 │ 0.0         │
# │ 6   │ 912              │ 0.101605  │ 0.0         │
# │ 7   │ 1148             │ 0.127927  │ 0.0         │
# │ 8   │ 1248             │ 0.154355  │ 0.0         │
# │ 9   │ 1461             │ -0.582886 │ 0.0         │
# │ 10  │ 1555             │ 2.43496   │ 2.20788     │
# n = 788, and p = 1576
# Total iteration number was 358
# Total time was 2.3709449768066406
# running the 38 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 80               │ -0.415882 │ -0.265219   │
# │ 2   │ 345              │ -0.961484 │ -0.983024   │
# │ 3   │ 399              │ 0.911782  │ 0.899106    │
# │ 4   │ 810              │ -0.351533 │ -0.363181   │
# │ 5   │ 928              │ -0.519614 │ -0.450314   │
# │ 6   │ 951              │ -0.19262  │ 0.0         │
# │ 7   │ 1265             │ -0.681069 │ 0.0         │
# │ 8   │ 1403             │ -0.217831 │ 0.0         │
# │ 9   │ 1523             │ 0.504268  │ 0.547071    │
# │ 10  │ 1794             │ -0.938519 │ 0.0         │
# n = 228, and p = 2052
# Total iteration number was 108
# Total time was 0.3201460838317871
# running the 39 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β     │ estimated_β │
# │     │ Int64            │ Float64    │ Float64     │
# ├─────┼──────────────────┼────────────┼─────────────┤
# │ 1   │ 188              │ -0.102033  │ 0.0         │
# │ 2   │ 192              │ -0.239866  │ 0.0         │
# │ 3   │ 373              │ -0.769313  │ 0.0         │
# │ 4   │ 619              │ 1.06213    │ 0.0         │
# │ 5   │ 1299             │ 2.21167    │ 1.96452     │
# │ 6   │ 1341             │ -0.0887121 │ 0.0         │
# │ 7   │ 1907             │ 0.0512322  │ 0.0         │
# │ 8   │ 1934             │ 1.59196    │ 1.70531     │
# │ 9   │ 1995             │ -1.27859   │ 0.0         │
# │ 10  │ 2418             │ -2.30854   │ 0.0         │
# n = 373, and p = 2611
# Total iteration number was 669
# Total time was 3.57773494720459
# running the 40 th model
# Did not converge!!!!! The run time for IHT was 17.184314012527466seconds and model size was10compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β     │ estimated_β │
# │     │ Int64            │ Float64    │ Float64     │
# ├─────┼──────────────────┼────────────┼─────────────┤
# │ 1   │ 22               │ 0.83184    │ 0.70539     │
# │ 2   │ 937              │ 0.674416   │ 0.666831    │
# │ 3   │ 995              │ 0.136027   │ 0.0         │
# │ 4   │ 1370             │ -2.02745   │ -1.19712    │
# │ 5   │ 1400             │ 0.490228   │ 0.0         │
# │ 6   │ 2296             │ -0.135477  │ 0.0         │
# │ 7   │ 3115             │ 1.25382    │ 1.18185     │
# │ 8   │ 3378             │ 0.547869   │ 0.0         │
# │ 9   │ 4305             │ -0.0585686 │ 0.0         │
# │ 10  │ 5300             │ 2.76163    │ 2.19918     │
# n = 596, and p = 5364
# Total iteration number was 1000
# Total time was 17.184314012527466
# running the 41 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β     │ estimated_β │
# │     │ Int64            │ Float64    │ Float64     │
# ├─────┼──────────────────┼────────────┼─────────────┤
# │ 1   │ 37               │ -0.0338267 │ 0.0         │
# │ 2   │ 480              │ 0.695248   │ 0.638102    │
# │ 3   │ 571              │ 0.867375   │ 0.933789    │
# │ 4   │ 991              │ -0.338475  │ -0.372875   │
# │ 5   │ 1011             │ 1.4642     │ 1.509       │
# │ 6   │ 1282             │ 0.789543   │ 0.813335    │
# │ 7   │ 1609             │ -0.416764  │ 0.0         │
# │ 8   │ 2001             │ -0.357811  │ 0.0         │
# │ 9   │ 2025             │ 1.65083    │ 1.65614     │
# │ 10  │ 2482             │ -0.0232803 │ 0.0         │
# n = 317, and p = 2536
# Total iteration number was 308
# Total time was 1.4145989418029785
# running the 42 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β     │ estimated_β │
# │     │ Int64            │ Float64    │ Float64     │
# ├─────┼──────────────────┼────────────┼─────────────┤
# │ 1   │ 4                │ 0.513682   │ 0.394325    │
# │ 2   │ 54               │ -1.33103   │ 0.0         │
# │ 3   │ 136              │ -0.11301   │ 0.0         │
# │ 4   │ 159              │ -0.0368255 │ 0.0         │
# │ 5   │ 279              │ -2.60842   │ -2.49815    │
# │ 6   │ 315              │ -0.298101  │ 0.0         │
# │ 7   │ 565              │ -0.950212  │ -0.922887   │
# │ 8   │ 618              │ -0.90703   │ -0.824188   │
# │ 9   │ 833              │ -1.78114   │ -1.57649    │
# │ 10  │ 1118             │ 0.403883   │ 0.472674    │
# n = 392, and p = 1176
# Total iteration number was 440
# Total time was 1.1522541046142578
# running the 43 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 571              │ 0.773024  │ 0.7422      │
# │ 2   │ 736              │ 0.939701  │ 0.950725    │
# │ 3   │ 762              │ -0.11961  │ 0.0         │
# │ 4   │ 777              │ -0.127817 │ 0.0         │
# │ 5   │ 807              │ -1.05345  │ -1.04869    │
# │ 6   │ 1031             │ -0.22231  │ 0.0         │
# │ 7   │ 2636             │ -0.314104 │ -0.300328   │
# │ 8   │ 3551             │ -0.781767 │ -0.752804   │
# │ 9   │ 3596             │ -1.23592  │ -1.18682    │
# │ 10  │ 3878             │ -0.405063 │ -0.446751   │
# n = 526, and p = 4208
# Total iteration number was 156
# Total time was 1.9130499362945557
# running the 44 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 48               │ 0.295283  │ 0.311939    │
# │ 2   │ 267              │ 0.397846  │ 0.385634    │
# │ 3   │ 911              │ -0.407813 │ -0.419813   │
# │ 4   │ 1069             │ 0.0230365 │ 0.0         │
# │ 5   │ 1210             │ -0.653161 │ -0.653822   │
# │ 6   │ 1491             │ -0.307373 │ -0.284547   │
# │ 7   │ 2153             │ -1.54703  │ -1.49851    │
# │ 8   │ 2719             │ -0.357009 │ 0.0         │
# │ 9   │ 3042             │ -2.70177  │ 0.0         │
# │ 10  │ 3316             │ 0.142427  │ 0.186247    │
# n = 458, and p = 4122
# Total iteration number was 137
# Total time was 1.4864778518676758
# running the 45 th model
# Did not converge!!!!! The run time for IHT was 2.135478973388672seconds and model size was10compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 151              │ 2.96597   │ 2.56836     │
# │ 2   │ 186              │ 1.16522   │ 0.0         │
# │ 3   │ 271              │ -0.84365  │ 0.0         │
# │ 4   │ 397              │ 0.982157  │ 0.0         │
# │ 5   │ 439              │ 0.0988462 │ 0.0         │
# │ 6   │ 581              │ -0.156941 │ 0.0         │
# │ 7   │ 851              │ -0.175329 │ 0.0         │
# │ 8   │ 916              │ -0.826267 │ 0.0         │
# │ 9   │ 1183             │ 1.10249   │ 0.0         │
# │ 10  │ 1298             │ -0.715442 │ 0.0         │
# n = 274, and p = 1370
# Total iteration number was 1000
# Total time was 2.135478973388672
# running the 46 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 1                │ 0.774686  │ 0.935732    │
# │ 2   │ 11               │ -0.426882 │ 0.0         │
# │ 3   │ 18               │ -0.396178 │ -0.730999   │
# │ 4   │ 33               │ -0.360743 │ -0.298647   │
# │ 5   │ 56               │ 0.512995  │ 0.81336     │
# │ 6   │ 72               │ 1.89463   │ 1.31682     │
# │ 7   │ 134              │ -1.15297  │ 0.0         │
# │ 8   │ 150              │ -1.30028  │ 0.0         │
# │ 9   │ 208              │ -1.06833  │ 0.0         │
# │ 10  │ 209              │ 0.664143  │ 1.06996     │
# n = 277, and p = 277
# Total iteration number was 232
# Total time was 0.11385393142700195
# running the 47 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β     │ estimated_β │
# │     │ Int64            │ Float64    │ Float64     │
# ├─────┼──────────────────┼────────────┼─────────────┤
# │ 1   │ 28               │ 0.155486   │ 0.157363    │
# │ 2   │ 102              │ 0.68947    │ 0.684619    │
# │ 3   │ 242              │ -0.0848197 │ 0.0         │
# │ 4   │ 333              │ -0.346356  │ -0.326744   │
# │ 5   │ 364              │ -0.0791232 │ 0.0         │
# │ 6   │ 413              │ 0.93595    │ 0.948152    │
# │ 7   │ 499              │ 0.376639   │ 0.359667    │
# │ 8   │ 501              │ -0.0904944 │ 0.0         │
# │ 9   │ 591              │ -0.717629  │ -0.715413   │
# │ 10  │ 592              │ -0.561986  │ -0.567225   │
# n = 716, and p = 716
# Total iteration number was 62
# Total time was 0.18071603775024414
# running the 48 th model
# Did not converge!!!!! The run time for IHT was 0.7900958061218262seconds and model size was10compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β     │ estimated_β │
# │     │ Int64            │ Float64    │ Float64     │
# ├─────┼──────────────────┼────────────┼─────────────┤
# │ 1   │ 168              │ -0.314457  │ 0.0         │
# │ 2   │ 184              │ 0.450781   │ 0.0         │
# │ 3   │ 200              │ -0.0323266 │ 0.0         │
# │ 4   │ 238              │ -1.02502   │ 0.0         │
# │ 5   │ 293              │ -1.89178   │ 0.0         │
# │ 6   │ 505              │ -0.226567  │ 0.0         │
# │ 7   │ 540              │ 0.389614   │ 0.0         │
# │ 8   │ 569              │ 1.81411    │ 0.0         │
# │ 9   │ 659              │ -1.37365   │ 0.0         │
# │ 10  │ 737              │ -0.334603  │ 0.0         │
# n = 146, and p = 876
# Total iteration number was 1000
# Total time was 0.7900958061218262
# running the 49 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 574              │ 0.297149  │ 0.0         │
# │ 2   │ 1507             │ 1.21162   │ 1.13308     │
# │ 3   │ 1808             │ 0.115537  │ 0.0         │
# │ 4   │ 2199             │ -1.44659  │ 0.0         │
# │ 5   │ 2444             │ -1.3039   │ 0.0         │
# │ 6   │ 3558             │ 1.10471   │ 1.06492     │
# │ 7   │ 3773             │ -1.2936   │ -1.57839    │
# │ 8   │ 4033             │ -0.355583 │ 0.0         │
# │ 9   │ 5039             │ 0.587618  │ 0.0         │
# │ 10  │ 5058             │ 0.136803  │ 0.0         │
# n = 742, and p = 5194
# Total iteration number was 735
# Total time was 15.05984902381897
# running the 50 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 467              │ 1.15051   │ 1.15839     │
# │ 2   │ 486              │ 0.198973  │ 0.219673    │
# │ 3   │ 1290             │ -0.879589 │ -0.878353   │
# │ 4   │ 2159             │ -0.745542 │ 0.0         │
# │ 5   │ 2247             │ -1.38915  │ -1.39122    │
# │ 6   │ 2721             │ 0.180043  │ 0.183414    │
# │ 7   │ 2812             │ 0.830594  │ 0.818116    │
# │ 8   │ 2997             │ 0.420223  │ 0.415412    │
# │ 9   │ 3235             │ 0.0272763 │ 0.0         │
# │ 10  │ 3338             │ 0.522658  │ 0.513043    │
# n = 889, and p = 3556
# Total iteration number was 173
# Total time was 2.8819758892059326
# running the 51 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 139              │ -1.3064   │ 0.0         │
# │ 2   │ 363              │ -0.616187 │ -0.540005   │
# │ 3   │ 622              │ 0.704905  │ 0.546374    │
# │ 4   │ 1127             │ 0.720575  │ 0.441586    │
# │ 5   │ 1449             │ 1.67268   │ 1.48449     │
# │ 6   │ 1509             │ -0.458372 │ 0.0         │
# │ 7   │ 1548             │ -0.597315 │ -0.644422   │
# │ 8   │ 1611             │ 0.272302  │ 0.0         │
# │ 9   │ 1621             │ 0.298858  │ 0.0         │
# │ 10  │ 1894             │ 0.809706  │ 0.986202    │
# n = 985, and p = 1970
# Total iteration number was 260
# Total time was 2.7611429691314697
# running the 52 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 135              │ -0.583617 │ 0.0         │
# │ 2   │ 246              │ 0.0559589 │ 0.0         │
# │ 3   │ 528              │ -0.674415 │ -0.715644   │
# │ 4   │ 706              │ -0.58651  │ -0.621267   │
# │ 5   │ 969              │ -0.248088 │ -0.215776   │
# │ 6   │ 1189             │ 0.323854  │ 0.263548    │
# │ 7   │ 1471             │ -0.589441 │ -0.597217   │
# │ 8   │ 1687             │ 1.23791   │ 1.20851     │
# │ 9   │ 2073             │ -0.258575 │ -0.249053   │
# │ 10  │ 2203             │ -0.293928 │ -0.279802   │
# n = 516, and p = 2580
# Total iteration number was 58
# Total time was 0.4322938919067383
# running the 53 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β     │ estimated_β │
# │     │ Int64            │ Float64    │ Float64     │
# ├─────┼──────────────────┼────────────┼─────────────┤
# │ 1   │ 1                │ -1.39602   │ 0.0         │
# │ 2   │ 9                │ 0.865832   │ 0.475442    │
# │ 3   │ 36               │ 0.554006   │ 0.0         │
# │ 4   │ 276              │ -0.824963  │ 0.0         │
# │ 5   │ 279              │ -1.51615   │ 0.0         │
# │ 6   │ 383              │ 0.173161   │ 0.0         │
# │ 7   │ 455              │ -0.0993538 │ 0.0         │
# │ 8   │ 1213             │ 0.316962   │ 0.0         │
# │ 9   │ 1451             │ 1.69256    │ 1.19351     │
# │ 10  │ 1794             │ -1.00332   │ 0.0         │
# n = 395, and p = 1975
# Total iteration number was 458
# Total time was 1.9619269371032715
# running the 54 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 149              │ 0.10597   │ 0.0         │
# │ 2   │ 197              │ 0.975227  │ 0.901102    │
# │ 3   │ 347              │ -0.822166 │ 0.0         │
# │ 4   │ 456              │ 0.576814  │ 0.747247    │
# │ 5   │ 863              │ -0.099226 │ 0.0         │
# │ 6   │ 912              │ 0.101605  │ 0.0         │
# │ 7   │ 1148             │ 0.127927  │ 0.0         │
# │ 8   │ 1248             │ 0.154355  │ 0.0         │
# │ 9   │ 1461             │ -0.582886 │ 0.0         │
# │ 10  │ 1555             │ 2.43496   │ 2.20788     │
# n = 788, and p = 1576
# Total iteration number was 358
# Total time was 2.359011173248291
# running the 55 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 80               │ -0.415882 │ -0.265219   │
# │ 2   │ 345              │ -0.961484 │ -0.983024   │
# │ 3   │ 399              │ 0.911782  │ 0.899106    │
# │ 4   │ 810              │ -0.351533 │ -0.363181   │
# │ 5   │ 928              │ -0.519614 │ -0.450314   │
# │ 6   │ 951              │ -0.19262  │ 0.0         │
# │ 7   │ 1265             │ -0.681069 │ 0.0         │
# │ 8   │ 1403             │ -0.217831 │ 0.0         │
# │ 9   │ 1523             │ 0.504268  │ 0.547071    │
# │ 10  │ 1794             │ -0.938519 │ 0.0         │
# n = 228, and p = 2052
# Total iteration number was 108
# Total time was 0.3246040344238281
# running the 56 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β     │ estimated_β │
# │     │ Int64            │ Float64    │ Float64     │
# ├─────┼──────────────────┼────────────┼─────────────┤
# │ 1   │ 188              │ -0.102033  │ 0.0         │
# │ 2   │ 192              │ -0.239866  │ 0.0         │
# │ 3   │ 373              │ -0.769313  │ 0.0         │
# │ 4   │ 619              │ 1.06213    │ 0.0         │
# │ 5   │ 1299             │ 2.21167    │ 1.96452     │
# │ 6   │ 1341             │ -0.0887121 │ 0.0         │
# │ 7   │ 1907             │ 0.0512322  │ 0.0         │
# │ 8   │ 1934             │ 1.59196    │ 1.70531     │
# │ 9   │ 1995             │ -1.27859   │ 0.0         │
# │ 10  │ 2418             │ -2.30854   │ 0.0         │
# n = 373, and p = 2611
# Total iteration number was 669
# Total time was 3.652117967605591
# running the 57 th model
# Did not converge!!!!! The run time for IHT was 17.121922969818115seconds and model size was10compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β     │ estimated_β │
# │     │ Int64            │ Float64    │ Float64     │
# ├─────┼──────────────────┼────────────┼─────────────┤
# │ 1   │ 22               │ 0.83184    │ 0.70539     │
# │ 2   │ 937              │ 0.674416   │ 0.666831    │
# │ 3   │ 995              │ 0.136027   │ 0.0         │
# │ 4   │ 1370             │ -2.02745   │ -1.19712    │
# │ 5   │ 1400             │ 0.490228   │ 0.0         │
# │ 6   │ 2296             │ -0.135477  │ 0.0         │
# │ 7   │ 3115             │ 1.25382    │ 1.18185     │
# │ 8   │ 3378             │ 0.547869   │ 0.0         │
# ...
# │ 1   │ 168              │ -0.314457  │ 0.0         │
# │ 2   │ 184              │ 0.450781   │ 0.0         │
# │ 3   │ 200              │ -0.0323266 │ 0.0         │
# │ 4   │ 238              │ -1.02502   │ 0.0         │
# │ 5   │ 293              │ -1.89178   │ 0.0         │
# │ 6   │ 505              │ -0.226567  │ 0.0         │
# │ 7   │ 540              │ 0.389614   │ 0.0         │
# │ 8   │ 569              │ 1.81411    │ 0.0         │
# │ 9   │ 659              │ -1.37365   │ 0.0         │
# │ 10  │ 737              │ -0.334603  │ 0.0         │
# n = 146, and p = 876
# Total iteration number was 1000
# Total time was 0.8037829399108887
# running the 83 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 574              │ 0.297149  │ 0.0         │
# │ 2   │ 1507             │ 1.21162   │ 1.13308     │
# │ 3   │ 1808             │ 0.115537  │ 0.0         │
# │ 4   │ 2199             │ -1.44659  │ 0.0         │
# │ 5   │ 2444             │ -1.3039   │ 0.0         │
# │ 6   │ 3558             │ 1.10471   │ 1.06492     │
# │ 7   │ 3773             │ -1.2936   │ -1.57839    │
# │ 8   │ 4033             │ -0.355583 │ 0.0         │
# │ 9   │ 5039             │ 0.587618  │ 0.0         │
# │ 10  │ 5058             │ 0.136803  │ 0.0         │
# n = 742, and p = 5194
# Total iteration number was 735
# Total time was 15.266984939575195
# running the 84 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 467              │ 1.15051   │ 1.15839     │
# │ 2   │ 486              │ 0.198973  │ 0.219673    │
# │ 3   │ 1290             │ -0.879589 │ -0.878353   │
# │ 4   │ 2159             │ -0.745542 │ 0.0         │
# │ 5   │ 2247             │ -1.38915  │ -1.39122    │
# │ 6   │ 2721             │ 0.180043  │ 0.183414    │
# │ 7   │ 2812             │ 0.830594  │ 0.818116    │
# │ 8   │ 2997             │ 0.420223  │ 0.415412    │
# │ 9   │ 3235             │ 0.0272763 │ 0.0         │
# │ 10  │ 3338             │ 0.522658  │ 0.513043    │
# n = 889, and p = 3556
# Total iteration number was 173
# Total time was 2.932366132736206
# running the 85 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 139              │ -1.3064   │ 0.0         │
# │ 2   │ 363              │ -0.616187 │ -0.540005   │
# │ 3   │ 622              │ 0.704905  │ 0.546374    │
# │ 4   │ 1127             │ 0.720575  │ 0.441586    │
# │ 5   │ 1449             │ 1.67268   │ 1.48449     │
# │ 6   │ 1509             │ -0.458372 │ 0.0         │
# │ 7   │ 1548             │ -0.597315 │ -0.644422   │
# │ 8   │ 1611             │ 0.272302  │ 0.0         │
# │ 9   │ 1621             │ 0.298858  │ 0.0         │
# │ 10  │ 1894             │ 0.809706  │ 0.986202    │
# n = 985, and p = 1970
# Total iteration number was 260
# Total time was 2.755751848220825
# running the 86 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 135              │ -0.583617 │ 0.0         │
# │ 2   │ 246              │ 0.0559589 │ 0.0         │
# │ 3   │ 528              │ -0.674415 │ -0.715644   │
# │ 4   │ 706              │ -0.58651  │ -0.621267   │
# │ 5   │ 969              │ -0.248088 │ -0.215776   │
# │ 6   │ 1189             │ 0.323854  │ 0.263548    │
# │ 7   │ 1471             │ -0.589441 │ -0.597217   │
# │ 8   │ 1687             │ 1.23791   │ 1.20851     │
# │ 9   │ 2073             │ -0.258575 │ -0.249053   │
# │ 10  │ 2203             │ -0.293928 │ -0.279802   │
# n = 516, and p = 2580
# Total iteration number was 58
# Total time was 0.4374220371246338
# running the 87 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β     │ estimated_β │
# │     │ Int64            │ Float64    │ Float64     │
# ├─────┼──────────────────┼────────────┼─────────────┤
# │ 1   │ 1                │ -1.39602   │ 0.0         │
# │ 2   │ 9                │ 0.865832   │ 0.475442    │
# │ 3   │ 36               │ 0.554006   │ 0.0         │
# │ 4   │ 276              │ -0.824963  │ 0.0         │
# │ 5   │ 279              │ -1.51615   │ 0.0         │
# │ 6   │ 383              │ 0.173161   │ 0.0         │
# │ 7   │ 455              │ -0.0993538 │ 0.0         │
# │ 8   │ 1213             │ 0.316962   │ 0.0         │
# │ 9   │ 1451             │ 1.69256    │ 1.19351     │
# │ 10  │ 1794             │ -1.00332   │ 0.0         │
# n = 395, and p = 1975
# Total iteration number was 458
# Total time was 1.9712529182434082
# running the 88 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 149              │ 0.10597   │ 0.0         │
# │ 2   │ 197              │ 0.975227  │ 0.901102    │
# │ 3   │ 347              │ -0.822166 │ 0.0         │
# │ 4   │ 456              │ 0.576814  │ 0.747247    │
# │ 5   │ 863              │ -0.099226 │ 0.0         │
# │ 6   │ 912              │ 0.101605  │ 0.0         │
# │ 7   │ 1148             │ 0.127927  │ 0.0         │
# │ 8   │ 1248             │ 0.154355  │ 0.0         │
# │ 9   │ 1461             │ -0.582886 │ 0.0         │
# │ 10  │ 1555             │ 2.43496   │ 2.20788     │
# n = 788, and p = 1576
# Total iteration number was 358
# Total time was 2.3544881343841553
# running the 89 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 80               │ -0.415882 │ -0.265219   │
# │ 2   │ 345              │ -0.961484 │ -0.983024   │
# │ 3   │ 399              │ 0.911782  │ 0.899106    │
# │ 4   │ 810              │ -0.351533 │ -0.363181   │
# │ 5   │ 928              │ -0.519614 │ -0.450314   │
# │ 6   │ 951              │ -0.19262  │ 0.0         │
# │ 7   │ 1265             │ -0.681069 │ 0.0         │
# │ 8   │ 1403             │ -0.217831 │ 0.0         │
# │ 9   │ 1523             │ 0.504268  │ 0.547071    │
# │ 10  │ 1794             │ -0.938519 │ 0.0         │
# n = 228, and p = 2052
# Total iteration number was 108
# Total time was 0.31751108169555664
# running the 90 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β     │ estimated_β │
# │     │ Int64            │ Float64    │ Float64     │
# ├─────┼──────────────────┼────────────┼─────────────┤
# │ 1   │ 188              │ -0.102033  │ 0.0         │
# │ 2   │ 192              │ -0.239866  │ 0.0         │
# │ 3   │ 373              │ -0.769313  │ 0.0         │
# │ 4   │ 619              │ 1.06213    │ 0.0         │
# │ 5   │ 1299             │ 2.21167    │ 1.96452     │
# │ 6   │ 1341             │ -0.0887121 │ 0.0         │
# │ 7   │ 1907             │ 0.0512322  │ 0.0         │
# │ 8   │ 1934             │ 1.59196    │ 1.70531     │
# │ 9   │ 1995             │ -1.27859   │ 0.0         │
# │ 10  │ 2418             │ -2.30854   │ 0.0         │
# n = 373, and p = 2611
# Total iteration number was 669
# Total time was 3.5679759979248047
# running the 91 th model
# Did not converge!!!!! The run time for IHT was 16.89743995666504seconds and model size was10compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β     │ estimated_β │
# │     │ Int64            │ Float64    │ Float64     │
# ├─────┼──────────────────┼────────────┼─────────────┤
# │ 1   │ 22               │ 0.83184    │ 0.70539     │
# │ 2   │ 937              │ 0.674416   │ 0.666831    │
# │ 3   │ 995              │ 0.136027   │ 0.0         │
# │ 4   │ 1370             │ -2.02745   │ -1.19712    │
# │ 5   │ 1400             │ 0.490228   │ 0.0         │
# │ 6   │ 2296             │ -0.135477  │ 0.0         │
# │ 7   │ 3115             │ 1.25382    │ 1.18185     │
# │ 8   │ 3378             │ 0.547869   │ 0.0         │
# │ 9   │ 4305             │ -0.0585686 │ 0.0         │
# │ 10  │ 5300             │ 2.76163    │ 2.19918     │
# n = 596, and p = 5364
# Total iteration number was 1000
# Total time was 16.89743995666504
# running the 92 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β     │ estimated_β │
# │     │ Int64            │ Float64    │ Float64     │
# ├─────┼──────────────────┼────────────┼─────────────┤
# │ 1   │ 37               │ -0.0338267 │ 0.0         │
# │ 2   │ 480              │ 0.695248   │ 0.638102    │
# │ 3   │ 571              │ 0.867375   │ 0.933789    │
# │ 4   │ 991              │ -0.338475  │ -0.372875   │
# │ 5   │ 1011             │ 1.4642     │ 1.509       │
# │ 6   │ 1282             │ 0.789543   │ 0.813335    │
# │ 7   │ 1609             │ -0.416764  │ 0.0         │
# │ 8   │ 2001             │ -0.357811  │ 0.0         │
# │ 9   │ 2025             │ 1.65083    │ 1.65614     │
# │ 10  │ 2482             │ -0.0232803 │ 0.0         │
# n = 317, and p = 2536
# Total iteration number was 308
# Total time was 1.396765947341919
# running the 93 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β     │ estimated_β │
# │     │ Int64            │ Float64    │ Float64     │
# ├─────┼──────────────────┼────────────┼─────────────┤
# │ 1   │ 4                │ 0.513682   │ 0.394325    │
# │ 2   │ 54               │ -1.33103   │ 0.0         │
# │ 3   │ 136              │ -0.11301   │ 0.0         │
# │ 4   │ 159              │ -0.0368255 │ 0.0         │
# │ 5   │ 279              │ -2.60842   │ -2.49815    │
# │ 6   │ 315              │ -0.298101  │ 0.0         │
# │ 7   │ 565              │ -0.950212  │ -0.922887   │
# │ 8   │ 618              │ -0.90703   │ -0.824188   │
# │ 9   │ 833              │ -1.78114   │ -1.57649    │
# │ 10  │ 1118             │ 0.403883   │ 0.472674    │
# n = 392, and p = 1176
# Total iteration number was 440
# Total time was 1.1537120342254639
# running the 94 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 571              │ 0.773024  │ 0.7422      │
# │ 2   │ 736              │ 0.939701  │ 0.950725    │
# │ 3   │ 762              │ -0.11961  │ 0.0         │
# │ 4   │ 777              │ -0.127817 │ 0.0         │
# │ 5   │ 807              │ -1.05345  │ -1.04869    │
# │ 6   │ 1031             │ -0.22231  │ 0.0         │
# │ 7   │ 2636             │ -0.314104 │ -0.300328   │
# │ 8   │ 3551             │ -0.781767 │ -0.752804   │
# │ 9   │ 3596             │ -1.23592  │ -1.18682    │
# │ 10  │ 3878             │ -0.405063 │ -0.446751   │
# n = 526, and p = 4208
# Total iteration number was 156
# Total time was 1.8814759254455566
# running the 95 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 48               │ 0.295283  │ 0.311939    │
# │ 2   │ 267              │ 0.397846  │ 0.385634    │
# │ 3   │ 911              │ -0.407813 │ -0.419813   │
# │ 4   │ 1069             │ 0.0230365 │ 0.0         │
# │ 5   │ 1210             │ -0.653161 │ -0.653822   │
# │ 6   │ 1491             │ -0.307373 │ -0.284547   │
# │ 7   │ 2153             │ -1.54703  │ -1.49851    │
# │ 8   │ 2719             │ -0.357009 │ 0.0         │
# │ 9   │ 3042             │ -2.70177  │ 0.0         │
# │ 10  │ 3316             │ 0.142427  │ 0.186247    │
# n = 458, and p = 4122
# Total iteration number was 137
# Total time was 1.445713996887207
# running the 96 th model
# Did not converge!!!!! The run time for IHT was 2.1042590141296387seconds and model size was10compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 151              │ 2.96597   │ 2.56836     │
# │ 2   │ 186              │ 1.16522   │ 0.0         │
# │ 3   │ 271              │ -0.84365  │ 0.0         │
# │ 4   │ 397              │ 0.982157  │ 0.0         │
# │ 5   │ 439              │ 0.0988462 │ 0.0         │
# │ 6   │ 581              │ -0.156941 │ 0.0         │
# │ 7   │ 851              │ -0.175329 │ 0.0         │
# │ 8   │ 916              │ -0.826267 │ 0.0         │
# │ 9   │ 1183             │ 1.10249   │ 0.0         │
# │ 10  │ 1298             │ -0.715442 │ 0.0         │
# n = 274, and p = 1370
# Total iteration number was 1000
# Total time was 2.1042590141296387
# running the 97 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 1                │ 0.774686  │ 0.935732    │
# │ 2   │ 11               │ -0.426882 │ 0.0         │
# │ 3   │ 18               │ -0.396178 │ -0.730999   │
# │ 4   │ 33               │ -0.360743 │ -0.298647   │
# │ 5   │ 56               │ 0.512995  │ 0.81336     │
# │ 6   │ 72               │ 1.89463   │ 1.31682     │
# │ 7   │ 134              │ -1.15297  │ 0.0         │
# │ 8   │ 150              │ -1.30028  │ 0.0         │
# │ 9   │ 208              │ -1.06833  │ 0.0         │
# │ 10  │ 209              │ 0.664143  │ 1.06996     │
# n = 277, and p = 277
# Total iteration number was 232
# Total time was 0.11367511749267578
# running the 98 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β     │ estimated_β │
# │     │ Int64            │ Float64    │ Float64     │
# ├─────┼──────────────────┼────────────┼─────────────┤
# │ 1   │ 28               │ 0.155486   │ 0.157363    │
# │ 2   │ 102              │ 0.68947    │ 0.684619    │
# │ 3   │ 242              │ -0.0848197 │ 0.0         │
# │ 4   │ 333              │ -0.346356  │ -0.326744   │
# │ 5   │ 364              │ -0.0791232 │ 0.0         │
# │ 6   │ 413              │ 0.93595    │ 0.948152    │
# │ 7   │ 499              │ 0.376639   │ 0.359667    │
# │ 8   │ 501              │ -0.0904944 │ 0.0         │
# │ 9   │ 591              │ -0.717629  │ -0.715413   │
# │ 10  │ 592              │ -0.561986  │ -0.567225   │
# n = 716, and p = 716
# Total iteration number was 62
# Total time was 0.1808171272277832
# running the 99 th model
# Did not converge!!!!! The run time for IHT was 0.7914400100708008seconds and model size was10compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β     │ estimated_β │
# │     │ Int64            │ Float64    │ Float64     │
# ├─────┼──────────────────┼────────────┼─────────────┤
# │ 1   │ 168              │ -0.314457  │ 0.0         │
# │ 2   │ 184              │ 0.450781   │ 0.0         │
# │ 3   │ 200              │ -0.0323266 │ 0.0         │
# │ 4   │ 238              │ -1.02502   │ 0.0         │
# │ 5   │ 293              │ -1.89178   │ 0.0         │
# │ 6   │ 505              │ -0.226567  │ 0.0         │
# │ 7   │ 540              │ 0.389614   │ 0.0         │
# │ 8   │ 569              │ 1.81411    │ 0.0         │
# │ 9   │ 659              │ -1.37365   │ 0.0         │
# │ 10  │ 737              │ -0.334603  │ 0.0         │
# n = 146, and p = 876
# Total iteration number was 1000
# Total time was 0.7914400100708008
# running the 100 th model
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 574              │ 0.297149  │ 0.0         │
# │ 2   │ 1507             │ 1.21162   │ 1.13308     │
# │ 3   │ 1808             │ 0.115537  │ 0.0         │
# │ 4   │ 2199             │ -1.44659  │ 0.0         │
# │ 5   │ 2444             │ -1.3039   │ 0.0         │
# │ 6   │ 3558             │ 1.10471   │ 1.06492     │
# │ 7   │ 3773             │ -1.2936   │ -1.57839    │
# │ 8   │ 4033             │ -0.355583 │ 0.0         │
# │ 9   │ 5039             │ 0.587618  │ 0.0         │
# │ 10  │ 5058             │ 0.136803  │ 0.0         │
# n = 742, and p = 5194
# Total iteration number was 735
# Total time was 14.986450910568237

# %% [markdown]
# # Logistic sample size = 100~1000 (with debias)

# %%
for i = 1:100
    println("running the $i th model")
    n = rand(100:1000) 
    p = rand(1:10)n
    debias = true
    run_logistic(n, p, debias)
end
# Out:
# running the 1 th model
# Total iteration number was 10
# Total time was 0.8166790008544922
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 142              │ -1.29408  │ -1.329      │
# │ 2   │ 1361             │ 1.3569    │ 1.51201     │
# │ 3   │ 2545             │ 1.59891   │ 1.70748     │
# │ 4   │ 3195             │ -0.639507 │ -0.776259   │
# │ 5   │ 3960             │ 0.569607  │ 0.721466    │
# │ 6   │ 4701             │ 1.12605   │ 1.15373     │
# │ 7   │ 4920             │ -0.67882  │ -0.628831   │
# │ 8   │ 5429             │ 0.0773713 │ 0.0         │
# │ 9   │ 6640             │ 1.08847   │ 1.02796     │
# │ 10  │ 6729             │ -0.383984 │ -0.573983   │
# n = 774, and p = 7740
# Total iteration number was 10
# Total time was 0.8166790008544922
# running the 2 th model
# Total iteration number was 11
# Total time was 0.07755780220031738
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 98               │ 1.90581   │ 1.72456     │
# │ 2   │ 237              │ 0.783589  │ 0.0         │
# │ 3   │ 366              │ -2.87283  │ -2.86711    │
# │ 4   │ 458              │ -0.310705 │ 0.0         │
# │ 5   │ 629              │ -0.62432  │ -0.899482   │
# │ 6   │ 737              │ 1.0882    │ 1.04646     │
# │ 7   │ 1108             │ -0.451197 │ 0.0         │
# │ 8   │ 1434             │ -1.3209   │ -1.32584    │
# │ 9   │ 1477             │ 0.517999  │ 0.0         │
# │ 10  │ 1637             │ 0.31399   │ 0.481965    │
# n = 561, and p = 1683
# Total iteration number was 11
# Total time was 0.07755780220031738
# running the 3 th model
# Total iteration number was 12
# Total time was 0.49375009536743164
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 4                │ -0.602492 │ 0.0         │
# │ 2   │ 160              │ -1.24054  │ -1.23122    │
# │ 3   │ 262              │ 0.520363  │ 0.554246    │
# │ 4   │ 1453             │ -0.634573 │ -0.618126   │
# │ 5   │ 1551             │ 0.248643  │ 0.0         │
# │ 6   │ 2448             │ 0.295499  │ 0.0         │
# │ 7   │ 3895             │ 0.892042  │ 0.859899    │
# │ 8   │ 4135             │ 2.01453   │ 2.29273     │
# │ 9   │ 4776             │ -1.23643  │ -1.26109    │
# │ 10  │ 4808             │ 0.345054  │ 0.572794    │
# n = 943, and p = 6601
# Total iteration number was 12
# Total time was 0.49375009536743164
# running the 4 th model
# Total iteration number was 13
# Total time was 0.0576629638671875
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β     │ estimated_β │
# │     │ Int64            │ Float64    │ Float64     │
# ├─────┼──────────────────┼────────────┼─────────────┤
# │ 1   │ 64               │ -0.175249  │ 0.0         │
# │ 2   │ 116              │ 0.39979    │ 0.0         │
# │ 3   │ 371              │ 1.79795    │ 2.71031     │
# │ 4   │ 612              │ -0.221871  │ 0.0         │
# │ 5   │ 642              │ -1.0194    │ -1.12877    │
# │ 6   │ 757              │ 0.42968    │ 0.0         │
# │ 7   │ 891              │ -0.858919  │ -1.02343    │
# │ 8   │ 893              │ -2.79241   │ -3.91196    │
# │ 9   │ 1517             │ -0.0487122 │ 0.0         │
# │ 10  │ 1762             │ -0.818409  │ 0.0         │
# n = 270, and p = 1890
# Total iteration number was 13
# Total time was 0.0576629638671875
# running the 5 th model
# Total iteration number was 21
# Total time was 0.0469210147857666
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 128              │ 0.973577  │ 1.55516     │
# │ 2   │ 195              │ 1.55356   │ 1.7912      │
# │ 3   │ 256              │ 0.205437  │ 0.0         │
# │ 4   │ 470              │ -1.04084  │ -1.5172     │
# │ 5   │ 614              │ 0.543394  │ 0.0         │
# │ 6   │ 628              │ -0.710814 │ 0.0         │
# │ 7   │ 688              │ 0.633187  │ 0.0         │
# │ 8   │ 855              │ 1.20561   │ 1.57103     │
# │ 9   │ 882              │ -0.733444 │ -0.853855   │
# │ 10  │ 1022             │ 0.0743751 │ 0.0         │
# n = 208, and p = 1040
# Total iteration number was 21
# Total time was 0.0469210147857666
# running the 6 th model
# Total iteration number was 10
# Total time was 0.061311960220336914
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β     │ estimated_β │
# │     │ Int64            │ Float64    │ Float64     │
# ├─────┼──────────────────┼────────────┼─────────────┤
# │ 1   │ 424              │ 0.0170091  │ 0.0         │
# │ 2   │ 565              │ 0.155622   │ 0.0         │
# │ 3   │ 596              │ -0.0645844 │ 0.0         │
# │ 4   │ 671              │ -0.571291  │ -0.776779   │
# │ 5   │ 1079             │ -1.6299    │ -1.63791    │
# │ 6   │ 1440             │ -0.976322  │ -1.06072    │
# │ 7   │ 1441             │ 0.644601   │ 0.747543    │
# │ 8   │ 1473             │ -0.768027  │ -0.594271   │
# │ 9   │ 1475             │ 1.35484    │ 1.30546     │
# │ 10  │ 1556             │ 1.38937    │ 1.3699      │
# n = 429, and p = 1716
# Total iteration number was 10
# Total time was 0.061311960220336914
# running the 7 th model
# Total iteration number was 16
# Total time was 0.022211074829101562
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 48               │ 0.786754  │ 0.0         │
# │ 2   │ 219              │ 0.931507  │ 1.63494     │
# │ 3   │ 231              │ -1.12516  │ 0.0         │
# │ 4   │ 324              │ 0.708625  │ 2.23748     │
# │ 5   │ 340              │ -1.1914   │ -2.38247    │
# │ 6   │ 341              │ -0.666745 │ 0.0         │
# │ 7   │ 358              │ -0.385888 │ 0.0         │
# │ 8   │ 780              │ 0.899087  │ 0.0         │
# │ 9   │ 808              │ 1.6247    │ 2.7151      │
# │ 10  │ 847              │ -0.789647 │ 0.0         │
# n = 120, and p = 960
# Total iteration number was 16
# Total time was 0.022211074829101562
# running the 8 th model
# Total iteration number was 10
# Total time was 0.23598384857177734
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β      │ estimated_β │
# │     │ Int64            │ Float64     │ Float64     │
# ├─────┼──────────────────┼─────────────┼─────────────┤
# │ 1   │ 834              │ -0.318558   │ 0.0         │
# │ 2   │ 938              │ 0.623545    │ 0.704621    │
# │ 3   │ 1478             │ 0.739123    │ 0.954627    │
# │ 4   │ 1573             │ 0.0238099   │ 0.0         │
# │ 5   │ 2075             │ 0.403546    │ 0.461964    │
# │ 6   │ 2649             │ -0.00933782 │ 0.0         │
# │ 7   │ 2803             │ 2.5706      │ 2.79136     │
# │ 8   │ 3999             │ 1.18592     │ 1.3199      │
# │ 9   │ 4697             │ -1.79065    │ -2.12797    │
# │ 10  │ 5012             │ 0.27617     │ 0.0         │
# n = 649, and p = 5192
# Total iteration number was 10
# Total time was 0.23598384857177734
# running the 9 th model
# Total iteration number was 14
# Total time was 0.07393193244934082
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 94               │ -0.166484 │ 0.0         │
# │ 2   │ 144              │ -0.256425 │ 0.0         │
# │ 3   │ 605              │ -0.666533 │ -1.12016    │
# │ 4   │ 697              │ 1.02706   │ 1.43778     │
# │ 5   │ 733              │ -2.17893  │ -2.80853    │
# │ 6   │ 1195             │ -0.816666 │ 0.0         │
# │ 7   │ 1473             │ 1.53496   │ 1.88923     │
# │ 8   │ 1539             │ 0.263845  │ 0.0         │
# │ 9   │ 1600             │ 0.616618  │ 0.0         │
# │ 10  │ 2097             │ -0.874559 │ -0.730086   │
# n = 264, and p = 2112
# Total iteration number was 14
# Total time was 0.07393193244934082
# running the 10 th model
# Total iteration number was 10
# Total time was 0.00541996955871582
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 4                │ -0.146382 │ 0.0         │
# │ 2   │ 18               │ 0.768614  │ 2.7514      │
# │ 3   │ 24               │ 0.138413  │ 0.0         │
# │ 4   │ 40               │ -0.499137 │ -1.38032    │
# │ 5   │ 43               │ 0.349067  │ 0.0         │
# │ 6   │ 51               │ -1.06218  │ -3.39497    │
# │ 7   │ 54               │ -0.155595 │ 0.0         │
# │ 8   │ 72               │ 0.357095  │ 0.0         │
# │ 9   │ 94               │ 0.0864549 │ 0.0         │
# │ 10  │ 103              │ -1.12217  │ -3.29743    │
# n = 127, and p = 127
# Total iteration number was 10
# Total time was 0.00541996955871582
# running the 11 th model
# Total iteration number was 9
# Total time was 0.027554988861083984
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β     │ estimated_β │
# │     │ Int64            │ Float64    │ Float64     │
# ├─────┼──────────────────┼────────────┼─────────────┤
# │ 1   │ 27               │ 0.00121149 │ 0.0         │
# │ 2   │ 194              │ 0.186429   │ 0.0         │
# │ 3   │ 313              │ -0.0693668 │ 0.0         │
# │ 4   │ 316              │ 1.67995    │ 2.14079     │
# │ 5   │ 329              │ -0.201573  │ 0.0         │
# │ 6   │ 422              │ -1.16478   │ -1.35173    │
# │ 7   │ 548              │ -0.164487  │ 0.0         │
# │ 8   │ 687              │ 0.373957   │ 0.0         │
# │ 9   │ 738              │ -0.576154  │ -1.26807    │
# │ 10  │ 804              │ 0.980584   │ 1.39301     │
# n = 297, and p = 891
# Total iteration number was 9
# Total time was 0.027554988861083984
# running the 12 th model
# Total iteration number was 12
# Total time was 0.14343690872192383
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 117              │ -1.17667  │ -1.12265    │
# │ 2   │ 354              │ -1.05742  │ -0.925581   │
# │ 3   │ 663              │ -2.09476  │ -2.43029    │
# │ 4   │ 751              │ -1.01354  │ -0.920721   │
# │ 5   │ 852              │ 0.573226  │ 0.585841    │
# │ 6   │ 1246             │ -0.731379 │ -0.649862   │
# │ 7   │ 1322             │ -0.838928 │ -0.757003   │
# │ 8   │ 1744             │ 0.528708  │ 0.0         │
# │ 9   │ 2170             │ 0.0124362 │ 0.0         │
# │ 10  │ 2505             │ 2.0894    │ 2.00885     │
# n = 562, and p = 2810
# Total iteration number was 12
# Total time was 0.14343690872192383
# running the 13 th model
# Total iteration number was 21
# Total time was 0.04671788215637207
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 176              │ 0.322513  │ 0.0         │
# │ 2   │ 185              │ 0.330166  │ 0.0         │
# │ 3   │ 362              │ -0.385194 │ 0.0         │
# │ 4   │ 484              │ 0.939689  │ 2.48059     │
# │ 5   │ 587              │ -2.30074  │ -4.94141    │
# │ 6   │ 709              │ -1.2608   │ -3.15352    │
# │ 7   │ 748              │ 0.219858  │ 0.0         │
# │ 8   │ 779              │ 0.502937  │ 0.0         │
# │ 9   │ 788              │ 0.0861077 │ 0.0         │
# │ 10  │ 907              │ 0.351307  │ 0.0         │
# n = 183, and p = 915
# Total iteration number was 21
# Total time was 0.04671788215637207
# running the 14 th model
# Total iteration number was 13
# Total time was 0.2891731262207031
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 411              │ 1.04646   │ 1.02434     │
# │ 2   │ 493              │ 0.385152  │ 0.509197    │
# │ 3   │ 1172             │ 0.112855  │ 0.0         │
# │ 4   │ 1856             │ -0.802337 │ -0.626605   │
# │ 5   │ 2483             │ 0.364207  │ 0.0         │
# │ 6   │ 2579             │ -1.87889  │ -2.11231    │
# │ 7   │ 3153             │ -1.01213  │ -1.30821    │
# │ 8   │ 3444             │ 1.03247   │ 1.14833     │
# │ 9   │ 3843             │ 0.57025   │ 0.717643    │
# │ 10  │ 4110             │ 0.173951  │ 0.0         │
# n = 684, and p = 4788
# Total iteration number was 13
# Total time was 0.2891731262207031
# running the 15 th model
# Total iteration number was 15
# Total time was 0.16784095764160156
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 227              │ -0.413559 │ -0.47085    │
# │ 2   │ 298              │ -0.823963 │ -0.715387   │
# │ 3   │ 403              │ -0.620391 │ -0.629942   │
# │ 4   │ 649              │ -1.35914  │ -1.43267    │
# │ 5   │ 1198             │ 0.164888  │ 0.0         │
# │ 6   │ 1601             │ -0.328827 │ 0.0         │
# │ 7   │ 1624             │ 0.727235  │ 0.76916     │
# │ 8   │ 2437             │ 1.02451   │ 0.887182    │
# │ 9   │ 2468             │ -0.50137  │ -0.656824   │
# │ 10  │ 2716             │ 1.44398   │ 1.30065     │
# n = 564, and p = 2820
# Total iteration number was 15
# Total time was 0.16784095764160156
# running the 16 th model
# Total iteration number was 11
# Total time was 0.07982587814331055
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 107              │ -0.46558  │ -0.583361   │
# │ 2   │ 381              │ -0.395482 │ 0.0         │
# │ 3   │ 481              │ 0.298264  │ 0.0         │
# │ 4   │ 550              │ -0.222686 │ 0.0         │
# │ 5   │ 593              │ 0.0584931 │ 0.0         │
# │ 6   │ 768              │ -0.536403 │ -0.545472   │
# │ 7   │ 991              │ -1.68484  │ -1.54955    │
# │ 8   │ 1226             │ -0.34417  │ 0.0         │
# │ 9   │ 1745             │ -0.535434 │ -0.639882   │
# │ 10  │ 1852             │ -0.664682 │ -0.609155   │
# n = 442, and p = 2210
# Total iteration number was 11
# Total time was 0.07982587814331055
# running the 17 th model
# Total iteration number was 13
# Total time was 0.1807699203491211
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 7                │ -0.943332 │ -1.08383    │
# │ 2   │ 147              │ -0.360388 │ 0.0         │
# │ 3   │ 219              │ 0.0673775 │ 0.0         │
# │ 4   │ 273              │ -0.746705 │ -1.02942    │
# │ 5   │ 334              │ -0.136748 │ 0.0         │
# │ 6   │ 855              │ 0.693507  │ 0.61271     │
# │ 7   │ 1066             │ -1.54995  │ -1.60093    │
# │ 8   │ 2291             │ -1.40535  │ -1.40857    │
# │ 9   │ 2458             │ -0.399644 │ -0.598335   │
# │ 10  │ 2625             │ -0.361536 │ -0.481661   │
# n = 705, and p = 2820
# Total iteration number was 13
# Total time was 0.1807699203491211
# running the 18 th model
# Total iteration number was 14
# Total time was 0.019253969192504883
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β       │ estimated_β │
# │     │ Int64            │ Float64      │ Float64     │
# ├─────┼──────────────────┼──────────────┼─────────────┤
# │ 1   │ 107              │ -0.000349129 │ 0.0         │
# │ 2   │ 156              │ -1.30031     │ -18.3567    │
# │ 3   │ 299              │ 1.04437      │ 0.0         │
# │ 4   │ 381              │ -2.31183     │ -26.1486    │
# │ 5   │ 397              │ 0.123263     │ 0.0         │
# │ 6   │ 629              │ -0.502485    │ 0.0         │
# │ 7   │ 762              │ 0.0750558    │ 0.0         │
# │ 8   │ 771              │ -0.350663    │ 0.0         │
# │ 9   │ 824              │ 1.93608      │ 29.1686     │
# │ 10  │ 891              │ 0.57324      │ 0.0         │
# n = 112, and p = 896
# Total iteration number was 14
# Total time was 0.019253969192504883
# running the 19 th model
# Total iteration number was 17
# Total time was 0.3786630630493164
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 126              │ -0.677636 │ -0.647598   │
# │ 2   │ 1029             │ 1.6899    │ 1.60148     │
# │ 3   │ 1138             │ 1.06018   │ 1.14508     │
# │ 4   │ 1264             │ -0.90024  │ -1.08834    │
# │ 5   │ 1423             │ 1.73004   │ 1.95469     │
# │ 6   │ 1650             │ -0.311792 │ -0.528922   │
# │ 7   │ 1740             │ -1.64709  │ -1.8417     │
# │ 8   │ 2290             │ 0.207679  │ 0.0         │
# │ 9   │ 3515             │ -0.616284 │ -0.505864   │
# │ 10  │ 3622             │ 0.940934  │ 0.864878    │
# n = 928, and p = 3712
# Total iteration number was 17
# Total time was 0.3786630630493164
# running the 20 th model
# Total iteration number was 12
# Total time was 0.2531299591064453
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 467              │ 1.15051   │ 1.29778     │
# │ 2   │ 486              │ 0.198973  │ 0.0         │
# │ 3   │ 1290             │ -0.879589 │ -0.895173   │
# │ 4   │ 2159             │ -0.745542 │ -1.14741    │
# │ 5   │ 2247             │ -1.38915  │ -1.6379     │
# │ 6   │ 2721             │ 0.180043  │ 0.0         │
# │ 7   │ 2812             │ 0.830594  │ 1.09382     │
# │ 8   │ 2997             │ 0.420223  │ 0.425301    │
# │ 9   │ 3235             │ 0.0272763 │ 0.0         │
# │ 10  │ 3338             │ 0.522658  │ 0.663352    │
# n = 889, and p = 3556
# Total iteration number was 12
# Total time was 0.2531299591064453
# running the 21 th model
# Total iteration number was 9
# Total time was 0.017535924911499023
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β     │ estimated_β │
# │     │ Int64            │ Float64    │ Float64     │
# ├─────┼──────────────────┼────────────┼─────────────┤
# │ 1   │ 292              │ 1.78209    │ 3.95316     │
# │ 2   │ 303              │ 0.0770025  │ 0.0         │
# │ 3   │ 361              │ 0.113964   │ 0.0         │
# │ 4   │ 564              │ 0.522053   │ 0.0         │
# │ 5   │ 579              │ -0.0351569 │ 0.0         │
# │ 6   │ 637              │ 0.844576   │ 1.34894     │
# │ 7   │ 934              │ 0.92329    │ 0.0         │
# │ 8   │ 993              │ -0.485067  │ 0.0         │
# │ 9   │ 997              │ -0.0777191 │ 0.0         │
# │ 10  │ 1026             │ 0.563983   │ 1.76501     │
# n = 143, and p = 1144
# Total iteration number was 9
# Total time was 0.017535924911499023
# running the 22 th model
# Total iteration number was 19
# Total time was 0.08059382438659668
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β     │ estimated_β │
# │     │ Int64            │ Float64    │ Float64     │
# ├─────┼──────────────────┼────────────┼─────────────┤
# │ 1   │ 112              │ 0.50965    │ 0.0         │
# │ 2   │ 416              │ -0.227982  │ 0.0         │
# │ 3   │ 607              │ -1.28132   │ -1.3462     │
# │ 4   │ 645              │ -1.93628   │ -2.48057    │
# │ 5   │ 646              │ 0.0381907  │ 0.0         │
# │ 6   │ 732              │ -1.0426    │ -1.7885     │
# │ 7   │ 1403             │ 1.15199    │ 1.20423     │
# │ 8   │ 1447             │ -0.0485572 │ 0.0         │
# │ 9   │ 1622             │ -1.31879   │ -1.92063    │
# │ 10  │ 1905             │ 1.12407    │ 1.17461     │
# n = 278, and p = 1946
# Total iteration number was 19
# Total time was 0.08059382438659668
# running the 23 th model
# Total iteration number was 10
# Total time was 0.1610400676727295
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β     │ estimated_β │
# │     │ Int64            │ Float64    │ Float64     │
# ├─────┼──────────────────┼────────────┼─────────────┤
# │ 1   │ 23               │ -0.826677  │ -1.04932    │
# │ 2   │ 591              │ -0.172781  │ 0.0         │
# │ 3   │ 849              │ 0.051109   │ 0.0         │
# │ 4   │ 2352             │ -0.608703  │ -0.758454   │
# │ 5   │ 2437             │ 1.78671    │ 1.92238     │
# │ 6   │ 2589             │ -1.37921   │ -1.58589    │
# │ 7   │ 2903             │ -0.936571  │ -1.05815    │
# │ 8   │ 2934             │ -0.829349  │ -0.766089   │
# │ 9   │ 3003             │ -0.360678  │ 0.0         │
# │ 10  │ 3448             │ -0.0232368 │ 0.0         │
# n = 540, and p = 3780
# Total iteration number was 10
# Total time was 0.1610400676727295
# running the 24 th model
# Total iteration number was 11
# Total time was 0.09321904182434082
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 392              │ -0.256138 │ 0.0         │
# │ 2   │ 476              │ 0.0279183 │ 0.0         │
# │ 3   │ 656              │ -0.252095 │ 0.0         │
# │ 4   │ 661              │ 0.746031  │ 0.922493    │
# │ 5   │ 809              │ 1.05843   │ 1.50508     │
# │ 6   │ 881              │ 1.29804   │ 1.94491     │
# │ 7   │ 1244             │ -0.225332 │ 0.0         │
# │ 8   │ 1248             │ -0.637006 │ -1.04563    │
# │ 9   │ 1649             │ 0.128666  │ 0.0         │
# │ 10  │ 1953             │ -1.22395  │ -1.43573    │
# n = 471, and p = 2355
# Total iteration number was 11
# Total time was 0.09321904182434082
# running the 25 th model
# Total iteration number was 13
# Total time was 0.12665510177612305
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 889              │ -1.05587  │ -1.37755    │
# │ 2   │ 981              │ 0.158013  │ 0.0         │
# │ 3   │ 1152             │ -0.133925 │ 0.0         │
# │ 4   │ 1300             │ -0.632277 │ -0.734374   │
# │ 5   │ 2049             │ 3.06055   │ 2.32265     │
# │ 6   │ 2171             │ -0.626382 │ 0.0         │
# │ 7   │ 2364             │ -0.344393 │ 0.0         │
# │ 8   │ 2377             │ -1.2434   │ -1.25752    │
# │ 9   │ 2571             │ -0.569349 │ 0.0         │
# │ 10  │ 3269             │ 0.970367  │ 1.23441     │
# n = 353, and p = 3530
# Total iteration number was 13
# Total time was 0.12665510177612305
# running the 26 th model
# Total iteration number was 15
# Total time was 0.19098615646362305
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 365              │ -0.126612 │ 0.0         │
# │ 2   │ 483              │ -0.773719 │ -1.15796    │
# │ 3   │ 518              │ 0.173117  │ 0.0         │
# │ 4   │ 865              │ -0.12989  │ 0.0         │
# │ 5   │ 1299             │ 1.07848   │ 1.71742     │
# │ 6   │ 1474             │ 2.15016   │ 2.81561     │
# │ 7   │ 2369             │ 0.0936938 │ 0.0         │
# │ 8   │ 2447             │ -0.629272 │ -0.839661   │
# │ 9   │ 2886             │ 0.530622  │ 0.0         │
# │ 10  │ 3061             │ -2.95527  │ -3.88332    │
# n = 556, and p = 3336
# Total iteration number was 15
# Total time was 0.19098615646362305
# running the 27 th model
# Total iteration number was 15
# Total time was 0.06043195724487305
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 14               │ 0.277039  │ 0.0         │
# │ 2   │ 170              │ 0.434472  │ 0.573645    │
# │ 3   │ 213              │ 0.633348  │ 0.589873    │
# │ 4   │ 439              │ -0.462966 │ -0.471354   │
# │ 5   │ 453              │ -0.179147 │ 0.0         │
# │ 6   │ 528              │ 1.35176   │ 1.27236     │
# │ 7   │ 628              │ 0.0723131 │ 0.0         │
# │ 8   │ 672              │ 2.47344   │ 0.0         │
# │ 9   │ 852              │ -1.39517  │ -1.25344    │
# │ 10  │ 937              │ -0.398438 │ -0.496099   │
# n = 476, and p = 952
# Total iteration number was 15
# Total time was 0.06043195724487305
# running the 28 th model
# Total iteration number was 9
# Total time was 0.017622947692871094
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 43               │ -0.29297  │ 0.0         │
# │ 2   │ 100              │ -2.00729  │ -2.56514    │
# │ 3   │ 157              │ 0.0870092 │ 0.0         │
# │ 4   │ 237              │ -0.431021 │ 0.0         │
# │ 5   │ 436              │ 1.34053   │ 1.20058     │
# │ 6   │ 470              │ 1.85349   │ 2.648       │
# │ 7   │ 495              │ 0.398536  │ 0.0         │
# │ 8   │ 618              │ 0.808023  │ 0.0         │
# │ 9   │ 755              │ 1.04897   │ 0.0         │
# │ 10  │ 794              │ -1.12313  │ -1.49787    │
# n = 201, and p = 804
# Total iteration number was 9
# Total time was 0.017622947692871094
# running the 29 th model
# Total iteration number was 15
# Total time was 0.07625198364257812
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β     │ estimated_β │
# │     │ Int64            │ Float64    │ Float64     │
# ├─────┼──────────────────┼────────────┼─────────────┤
# │ 1   │ 81               │ 0.404983   │ 0.0         │
# │ 2   │ 96               │ -0.0485167 │ 0.0         │
# │ 3   │ 624              │ 0.344806   │ 0.0         │
# │ 4   │ 638              │ 0.261179   │ 0.0         │
# │ 5   │ 778              │ -1.18059   │ -1.60037    │
# │ 6   │ 803              │ 0.663572   │ 1.19164     │
# │ 7   │ 1017             │ -1.02794   │ -0.869031   │
# │ 8   │ 1184             │ 0.961434   │ 1.1145      │
# │ 9   │ 1215             │ -1.61835   │ -1.87453    │
# │ 10  │ 1369             │ -0.65952   │ -0.682345   │
# n = 469, and p = 1407
# Total iteration number was 15
# Total time was 0.07625198364257812
# running the 30 th model
# Total iteration number was 12
# Total time was 0.44892096519470215
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 1187             │ 0.0993693 │ 0.0         │
# │ 2   │ 1720             │ 0.372477  │ 0.0         │
# │ 3   │ 2145             │ 0.169634  │ 0.0         │
# │ 4   │ 2294             │ 1.44472   │ 1.75692     │
# │ 5   │ 2406             │ 0.651111  │ 0.939997    │
# │ 6   │ 3330             │ 1.18636   │ 1.5348      │
# │ 7   │ 3424             │ -0.736776 │ -0.841271   │
# │ 8   │ 4467             │ 0.187163  │ 0.0         │
# │ 9   │ 4910             │ -0.271202 │ -0.348606   │
# │ 10  │ 5179             │ 1.91967   │ 2.30894     │
# n = 900, and p = 6300
# Total iteration number was 12
# Total time was 0.44892096519470215
# running the 31 th model
# Total iteration number was 13
# Total time was 0.4106779098510742
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β     │ estimated_β │
# │     │ Int64            │ Float64    │ Float64     │
# ├─────┼──────────────────┼────────────┼─────────────┤
# │ 1   │ 139              │ 0.802769   │ 0.866125    │
# │ 2   │ 722              │ 1.459      │ 1.58222     │
# │ 3   │ 1814             │ -0.0989416 │ 0.0         │
# │ 4   │ 1954             │ -0.593968  │ -0.72841    │
# │ 5   │ 2130             │ -0.438075  │ -0.479471   │
# │ 6   │ 3312             │ -1.00669   │ -1.16662    │
# │ 7   │ 3485             │ -0.705159  │ -0.915379   │
# │ 8   │ 3592             │ 0.0170873  │ 0.0         │
# │ 9   │ 3640             │ -0.700011  │ -0.577643   │
# │ 10  │ 4250             │ -0.688699  │ -0.847791   │
# n = 773, and p = 6184
# Total iteration number was 13
# Total time was 0.4106779098510742
# running the 32 th model
# Total iteration number was 16
# Total time was 0.05637001991271973
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 51               │ -2.73368  │ -2.38582    │
# │ 2   │ 231              │ -0.450992 │ 0.0         │
# │ 3   │ 412              │ 0.968552  │ 0.0         │
# │ 4   │ 516              │ 0.43947   │ 0.0         │
# │ 5   │ 540              │ -1.69666  │ -1.42827    │
# │ 6   │ 988              │ -0.935449 │ 0.0         │
# │ 7   │ 1610             │ 0.205775  │ 0.0         │
# │ 8   │ 1690             │ 1.6914    │ 0.893572    │
# │ 9   │ 1727             │ -1.22139  │ 0.0         │
# │ 10  │ 1818             │ -0.828538 │ 0.0         │
# n = 198, and p = 1980
# Total iteration number was 16
# Total time was 0.05637001991271973
# running the 33 th model
# Total iteration number was 13
# Total time was 0.26872897148132324
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β     │ estimated_β │
# │     │ Int64            │ Float64    │ Float64     │
# ├─────┼──────────────────┼────────────┼─────────────┤
# │ 1   │ 414              │ -0.143111  │ 0.0         │
# │ 2   │ 759              │ 1.1096     │ 1.12883     │
# │ 3   │ 1212             │ 1.20805    │ 1.43456     │
# │ 4   │ 2063             │ 0.633137   │ 0.839592    │
# │ 5   │ 2898             │ -1.57484   │ -1.81075    │
# │ 6   │ 2984             │ -1.42628   │ -1.77162    │
# │ 7   │ 3466             │ -0.0843611 │ 0.0         │
# │ 8   │ 4011             │ 0.602094   │ 0.574456    │
# │ 9   │ 4188             │ 0.70136    │ 1.0734      │
# │ 10  │ 4303             │ -2.82157   │ -2.8333     │
# n = 579, and p = 5211
# Total iteration number was 13
# Total time was 0.26872897148132324
# running the 34 th model
# Total iteration number was 15
# Total time was 0.3618178367614746
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 123              │ 0.823661  │ 1.09195     │
# │ 2   │ 237              │ 2.7836    │ 3.21827     │
# │ 3   │ 409              │ -1.12165  │ -1.19396    │
# │ 4   │ 1671             │ -1.5639   │ -1.6948     │
# │ 5   │ 1717             │ -1.15469  │ -1.3644     │
# │ 6   │ 2300             │ -0.150092 │ 0.0         │
# │ 7   │ 2326             │ 0.210976  │ 0.0         │
# │ 8   │ 2484             │ -0.175243 │ 0.0         │
# │ 9   │ 3845             │ -1.12609  │ -1.15718    │
# │ 10  │ 4098             │ -0.310236 │ 0.0         │
# n = 841, and p = 4205
# Total iteration number was 15
# Total time was 0.3618178367614746
# running the 35 th model
# Total iteration number was 15
# Total time was 0.03537106513977051
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 48               │ -1.06456  │ -1.58238    │
# │ 2   │ 51               │ 1.83391   │ 2.27184     │
# │ 3   │ 129              │ -1.03524  │ -1.23393    │
# │ 4   │ 149              │ -1.33325  │ -1.64059    │
# │ 5   │ 189              │ -0.99306  │ -1.52806    │
# │ 6   │ 208              │ 1.95911   │ 2.40736     │
# │ 7   │ 213              │ -0.949286 │ -1.15741    │
# │ 8   │ 262              │ -0.729394 │ -1.68369    │
# │ 9   │ 380              │ -0.146462 │ 0.0         │
# │ 10  │ 657              │ 3.32657   │ 4.40125     │
# n = 261, and p = 783
# Total iteration number was 15
# Total time was 0.03537106513977051
# running the 36 th model
# Total iteration number was 17
# Total time was 0.10085201263427734
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 319              │ 0.149577  │ 0.0         │
# │ 2   │ 346              │ -0.610173 │ -0.796967   │
# │ 3   │ 677              │ -0.625481 │ 0.0         │
# │ 4   │ 819              │ -1.47886  │ -1.92241    │
# │ 5   │ 1089             │ -0.79843  │ 0.0         │
# │ 6   │ 1371             │ 0.0389689 │ 0.0         │
# │ 7   │ 1472             │ 0.915286  │ 1.42649     │
# │ 8   │ 2137             │ -1.77311  │ -2.41951    │
# │ 9   │ 2315             │ -1.15258  │ -1.42975    │
# │ 10  │ 2347             │ 0.816026  │ 1.12679     │
# n = 264, and p = 2640
# Total iteration number was 17
# Total time was 0.10085201263427734
# running the 37 th model
# Total iteration number was 21
# Total time was 0.5835590362548828
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β     │ estimated_β │
# │     │ Int64            │ Float64    │ Float64     │
# ├─────┼──────────────────┼────────────┼─────────────┤
# │ 1   │ 132              │ 0.515994   │ 0.47364     │
# │ 2   │ 400              │ -0.0175956 │ 0.0         │
# │ 3   │ 457              │ 0.386324   │ 0.0         │
# │ 4   │ 1804             │ -1.02387   │ -0.917325   │
# │ 5   │ 3652             │ -1.14336   │ -1.34407    │
# │ 6   │ 3784             │ 0.535989   │ 0.59041     │
# │ 7   │ 4133             │ -0.954138  │ -0.980173   │
# │ 8   │ 4363             │ 0.328149   │ 0.0         │
# │ 9   │ 5436             │ 1.33509    │ 1.66301     │
# │ 10  │ 5841             │ -1.20995   │ -1.38153    │
# n = 646, and p = 6460
# Total iteration number was 21
# Total time was 0.5835590362548828
# running the 38 th model
# Total iteration number was 15
# Total time was 0.5083858966827393
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 1185             │ -0.839616 │ -0.727313   │
# │ 2   │ 2307             │ -1.49196  │ -1.3771     │
# │ 3   │ 2614             │ -0.150569 │ 0.0         │
# │ 4   │ 2757             │ -0.255896 │ 0.0         │
# │ 5   │ 2929             │ 0.0343185 │ 0.0         │
# │ 6   │ 4394             │ 1.06675   │ 1.04523     │
# │ 7   │ 4565             │ -0.817232 │ -0.755889   │
# │ 8   │ 4867             │ 0.367551  │ 0.0         │
# │ 9   │ 5653             │ 0.944364  │ 0.912839    │
# │ 10  │ 6544             │ 1.53867   │ 1.54211     │
# n = 725, and p = 7250
# Total iteration number was 15
# Total time was 0.5083858966827393
# running the 39 th model
# Total iteration number was 13
# Total time was 0.11541390419006348
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 79               │ -1.286    │ -1.54047    │
# │ 2   │ 475              │ -0.839889 │ -0.95395    │
# │ 3   │ 716              │ 0.570855  │ 0.755014    │
# │ 4   │ 735              │ -0.858802 │ -0.95662    │
# │ 5   │ 766              │ 0.870346  │ 0.929095    │
# │ 6   │ 916              │ 0.251638  │ 0.0         │
# │ 7   │ 1051             │ 0.150983  │ 0.0         │
# │ 8   │ 1191             │ -0.912442 │ -0.989589   │
# │ 9   │ 1361             │ -1.45829  │ -1.40761    │
# │ 10  │ 1409             │ -1.08486  │ -0.95576    │
# n = 775, and p = 1550
# Total iteration number was 13
# Total time was 0.11541390419006348
# running the 40 th model
# Total iteration number was 13
# Total time was 0.019264936447143555
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 5                │ 0.936774  │ 0.0         │
# │ 2   │ 9                │ 0.481225  │ 0.0         │
# │ 3   │ 66               │ -1.2269   │ 0.0         │
# │ 4   │ 165              │ 2.11609   │ 2.1438      │
# │ 5   │ 315              │ -1.2754   │ 0.0         │
# │ 6   │ 371              │ 2.30441   │ 2.53849     │
# │ 7   │ 478              │ -0.293555 │ 0.0         │
# │ 8   │ 499              │ -0.503824 │ -0.854174   │
# │ 9   │ 573              │ -0.937532 │ 0.0         │
# │ 10  │ 615              │ -0.412055 │ 0.0         │
# n = 147, and p = 735
# Total iteration number was 13
# Total time was 0.019264936447143555
# running the 41 th model
# Total iteration number was 11
# Total time was 0.18379807472229004
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 205              │ 1.1977    │ 1.33508     │
# │ 2   │ 626              │ 1.28837   │ 1.05614     │
# │ 3   │ 793              │ -0.241551 │ 0.0         │
# │ 4   │ 1328             │ -1.27427  │ -1.3115     │
# │ 5   │ 1486             │ 0.192908  │ 0.0         │
# │ 6   │ 1630             │ 0.502058  │ 0.500302    │
# │ 7   │ 1700             │ -1.70514  │ -1.76849    │
# │ 8   │ 2274             │ -0.859923 │ 0.0         │
# │ 9   │ 2315             │ -0.182524 │ 0.0         │
# │ 10  │ 2384             │ 0.937334  │ 1.05191     │
# n = 873, and p = 2619
# Total iteration number was 11
# Total time was 0.18379807472229004
# running the 42 th model
# Total iteration number was 16
# Total time was 0.16301798820495605
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 792              │ 0.975422  │ 1.16145     │
# │ 2   │ 846              │ 0.518859  │ 0.0         │
# │ 3   │ 1039             │ -0.460785 │ 0.0         │
# │ 4   │ 1132             │ -1.83632  │ -2.15107    │
# │ 5   │ 1239             │ -1.6541   │ -0.792253   │
# │ 6   │ 1864             │ 0.492881  │ 0.0         │
# │ 7   │ 2033             │ -1.71595  │ -2.14394    │
# │ 8   │ 2493             │ -0.137798 │ 0.0         │
# │ 9   │ 2931             │ 0.334873  │ 0.0         │
# │ 10  │ 3051             │ -3.4594   │ -3.91448    │
# n = 453, and p = 3171
# Total iteration number was 16
# Total time was 0.16301798820495605
# running the 43 th model
# Total iteration number was 13
# Total time was 0.1461029052734375
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 209              │ 0.139522  │ 0.0         │
# │ 2   │ 225              │ 0.270865  │ 0.0         │
# │ 3   │ 807              │ 0.0565133 │ 0.0         │
# │ 4   │ 1184             │ 0.206198  │ 0.0         │
# │ 5   │ 1552             │ -0.505127 │ 0.0         │
# │ 6   │ 1933             │ -0.426121 │ 0.0         │
# │ 7   │ 1993             │ -1.13778  │ -1.38718    │
# │ 8   │ 2595             │ -0.30131  │ -0.708799   │
# │ 9   │ 2601             │ -0.468335 │ -0.501007   │
# │ 10  │ 2801             │ -0.835262 │ -1.12828    │
# n = 496, and p = 2976
# Total iteration number was 13
# Total time was 0.1461029052734375
# running the 44 th model
# Total iteration number was 18
# Total time was 0.3343679904937744
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β   │ estimated_β │
# │     │ Int64            │ Float64  │ Float64     │
# ├─────┼──────────────────┼──────────┼─────────────┤
# │ 1   │ 249              │ 0.511019 │ 0.641481    │
# │ 2   │ 736              │ 0.105036 │ 0.0         │
# │ 3   │ 839              │ 0.83014  │ 0.901114    │
# │ 4   │ 1242             │ 0.182851 │ 0.0         │
# │ 5   │ 1663             │ 1.69633  │ 1.81193     │
# │ 6   │ 1820             │ -1.2829  │ -1.13887    │
# │ 7   │ 2445             │ -1.12275 │ -1.11193    │
# │ 8   │ 3141             │ 1.14999  │ 1.01891     │
# │ 9   │ 3256             │ 0.696472 │ 1.06005     │
# │ 10  │ 4044             │ 0.060625 │ 0.0         │
# n = 537, and p = 4833
# Total iteration number was 18
# Total time was 0.3343679904937744
# running the 45 th model
# Total iteration number was 18
# Total time was 0.7242250442504883
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 209              │ -0.094004 │ 0.0         │
# │ 2   │ 1195             │ -0.364395 │ 0.0         │
# │ 3   │ 1412             │ 0.436083  │ 0.529104    │
# │ 4   │ 2565             │ -0.581709 │ -0.552411   │
# │ 5   │ 3523             │ -1.90785  │ -1.9356     │
# │ 6   │ 4643             │ -0.796676 │ -0.934962   │
# │ 7   │ 5317             │ -1.47278  │ -1.56754    │
# │ 8   │ 5330             │ 0.208787  │ 0.393977    │
# │ 9   │ 7204             │ -0.16627  │ 0.0         │
# │ 10  │ 7461             │ 0.493038  │ 0.553173    │
# n = 794, and p = 7940
# Total iteration number was 18
# Total time was 0.7242250442504883
# running the 46 th model
# Total iteration number was 13
# Total time was 0.24634695053100586
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 211              │ -1.32948  │ -1.62932    │
# │ 2   │ 316              │ 1.27211   │ 1.50238     │
# │ 3   │ 795              │ -1.07187  │ -1.19304    │
# │ 4   │ 1070             │ -1.22083  │ -1.30837    │
# │ 5   │ 1162             │ 0.0564076 │ 0.0         │
# │ 6   │ 1423             │ -1.07618  │ -1.43734    │
# │ 7   │ 2010             │ -0.261154 │ 0.0         │
# │ 8   │ 2829             │ -0.435131 │ -0.443974   │
# │ 9   │ 2873             │ 1.77708   │ 1.88172     │
# │ 10  │ 3102             │ -0.36192  │ -0.473354   │
# n = 840, and p = 3360
# Total iteration number was 13
# Total time was 0.24634695053100586
# running the 47 th model
# Total iteration number was 12
# Total time was 0.009713172912597656
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 12               │ 1.58542   │ 1.9345      │
# │ 2   │ 52               │ -1.31843  │ -1.02012    │
# │ 3   │ 58               │ -0.988026 │ -1.63167    │
# │ 4   │ 74               │ 0.338766  │ 0.0         │
# │ 5   │ 83               │ -0.505333 │ -0.671272   │
# │ 6   │ 109              │ -1.14111  │ -1.84119    │
# │ 7   │ 117              │ 0.959529  │ 0.913782    │
# │ 8   │ 119              │ -1.63481  │ -2.63457    │
# │ 9   │ 183              │ 0.554078  │ 0.0         │
# │ 10  │ 217              │ 0.141387  │ 0.0         │
# n = 219, and p = 219
# Total iteration number was 12
# Total time was 0.009713172912597656
# running the 48 th model
# Total iteration number was 10
# Total time was 0.33484792709350586
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 55               │ -1.45965  │ -1.51927    │
# │ 2   │ 363              │ -1.13338  │ -1.49294    │
# │ 3   │ 526              │ -0.590927 │ -0.883798   │
# │ 4   │ 1565             │ -1.71041  │ -1.79826    │
# │ 5   │ 2561             │ -1.7901   │ -1.90194    │
# │ 6   │ 4057             │ -0.32993  │ 0.0         │
# │ 7   │ 4409             │ 0.67404   │ 0.901471    │
# │ 8   │ 5398             │ 0.626964  │ 0.0         │
# │ 9   │ 6237             │ 3.05983   │ 3.61838     │
# │ 10  │ 6385             │ 0.267149  │ 0.0         │
# n = 735, and p = 6615
# Total iteration number was 10
# Total time was 0.33484792709350586
# running the 49 th model
# Total iteration number was 15
# Total time was 0.01030421257019043
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 24               │ -0.575652 │ -0.751363   │
# │ 2   │ 28               │ 1.02284   │ 1.30736     │
# │ 3   │ 68               │ 0.0955714 │ 0.0         │
# │ 4   │ 75               │ 0.453693  │ 0.0         │
# │ 5   │ 137              │ -0.369108 │ 0.0         │
# │ 6   │ 164              │ 0.793612  │ 0.0         │
# │ 7   │ 191              │ 0.490758  │ 0.0         │
# │ 8   │ 212              │ -1.12921  │ -1.85048    │
# │ 9   │ 215              │ -0.689681 │ -1.46474    │
# │ 10  │ 270              │ -2.23747  │ -3.01438    │
# n = 153, and p = 306
# Total iteration number was 15
# Total time was 0.01030421257019043
# running the 50 th model
# Total iteration number was 15
# Total time was 0.05671501159667969
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β     │ estimated_β │
# │     │ Int64            │ Float64    │ Float64     │
# ├─────┼──────────────────┼────────────┼─────────────┤
# │ 1   │ 151              │ -0.121658  │ 0.0         │
# │ 2   │ 242              │ 0.335352   │ 0.0         │
# │ 3   │ 317              │ 1.97501    │ 2.66293     │
# │ 4   │ 322              │ -0.882252  │ -0.620336   │
# │ 5   │ 440              │ -0.46194   │ 0.0         │
# │ 6   │ 576              │ -0.0837395 │ 0.0         │
# │ 7   │ 698              │ 2.33709    │ 3.09199     │
# │ 8   │ 789              │ -0.199564  │ 0.0         │
# │ 9   │ 840              │ -0.193499  │ 0.0         │
# │ 10  │ 898              │ -0.726693  │ -1.35079    │
# n = 461, and p = 922
# Total iteration number was 15
# Total time was 0.05671501159667969
# running the 51 th model
# Total iteration number was 14
# Total time was 0.08335709571838379
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 41               │ 0.752212  │ 0.529627    │
# │ 2   │ 60               │ 0.0518991 │ 0.0         │
# │ 3   │ 120              │ 0.769081  │ 0.612412    │
# │ 4   │ 229              │ -1.52062  │ -1.26242    │
# │ 5   │ 416              │ -1.38235  │ -1.4424     │
# │ 6   │ 608              │ 1.24618   │ 1.02943     │
# │ 7   │ 661              │ 0.746928  │ 0.0         │
# │ 8   │ 1160             │ -0.484285 │ 0.0         │
# │ 9   │ 1170             │ -2.82876  │ -2.1898     │
# │ 10  │ 1495             │ 0.681672  │ 0.0         │
# n = 412, and p = 1648
# Total iteration number was 14
# Total time was 0.08335709571838379
# running the 52 th model
# Total iteration number was 9
# Total time was 0.05468583106994629
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 118              │ 0.25518   │ 0.0         │
# │ 2   │ 127              │ -0.323778 │ -0.363048   │
# │ 3   │ 425              │ 0.0489831 │ 0.0         │
# │ 4   │ 433              │ 0.0275028 │ 0.0         │
# │ 5   │ 518              │ -0.387982 │ -0.398097   │
# │ 6   │ 546              │ -0.116337 │ 0.0         │
# │ 7   │ 749              │ 0.153077  │ 0.0         │
# │ 8   │ 910              │ 0.641583  │ 0.809276    │
# │ 9   │ 944              │ 0.999471  │ 1.05425     │
# │ 10  │ 1104             │ 0.246645  │ 0.0         │
# n = 567, and p = 1134
# Total iteration number was 9
# Total time was 0.05468583106994629
# running the 53 th model
# Total iteration number was 14
# Total time was 0.31546998023986816
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 127              │ 0.509509  │ 0.661512    │
# │ 2   │ 219              │ -1.36228  │ -1.49221    │
# │ 3   │ 1109             │ 0.528088  │ 0.703807    │
# │ 4   │ 1255             │ -1.12791  │ -1.1604     │
# │ 5   │ 1542             │ -1.12135  │ -1.33105    │
# │ 6   │ 1742             │ 0.0148215 │ 0.0         │
# │ 7   │ 2526             │ -0.794    │ -0.976605   │
# │ 8   │ 2584             │ -0.195511 │ 0.0         │
# │ 9   │ 3129             │ -0.367273 │ 0.0         │
# │ 10  │ 3378             │ -2.01854  │ -2.38892    │
# n = 907, and p = 3628
# Total iteration number was 14
# Total time was 0.31546998023986816
# running the 54 th model
# Total iteration number was 13
# Total time was 0.03351593017578125
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 46               │ -1.69868  │ -1.8196     │
# ...
# │     │ Int64            │ Float64    │ Float64     │
# ├─────┼──────────────────┼────────────┼─────────────┤
# │ 1   │ 148              │ 1.2879     │ 1.3957      │
# │ 2   │ 1307             │ 0.702289   │ 0.7278      │
# │ 3   │ 1422             │ 0.686514   │ 0.681513    │
# │ 4   │ 1603             │ -0.420498  │ 0.0         │
# │ 5   │ 2019             │ 0.232635   │ 0.410908    │
# │ 6   │ 2568             │ 0.266134   │ 0.0         │
# │ 7   │ 2847             │ 0.493452   │ 0.448406    │
# │ 8   │ 3174             │ -0.948889  │ -0.959059   │
# │ 9   │ 3496             │ -0.0514497 │ 0.0         │
# │ 10  │ 3881             │ 0.228231   │ 0.0         │
# n = 472, and p = 4248
# Total iteration number was 13
# Total time was 0.1860969066619873
# running the 84 th model
# Total iteration number was 13
# Total time was 0.06299686431884766
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β     │ estimated_β │
# │     │ Int64            │ Float64    │ Float64     │
# ├─────┼──────────────────┼────────────┼─────────────┤
# │ 1   │ 97               │ -0.383654  │ -0.503258   │
# │ 2   │ 207              │ -0.234292  │ 0.0         │
# │ 3   │ 318              │ -1.27781   │ -1.51862    │
# │ 4   │ 695              │ -0.247587  │ 0.0         │
# │ 5   │ 742              │ 0.37097    │ 0.531578    │
# │ 6   │ 966              │ -0.702159  │ -0.810234   │
# │ 7   │ 1036             │ -0.0727798 │ 0.0         │
# │ 8   │ 1118             │ -1.16849   │ -1.1849     │
# │ 9   │ 1285             │ -0.153092  │ 0.0         │
# │ 10  │ 1307             │ -0.133453  │ 0.0         │
# n = 361, and p = 1444
# Total iteration number was 13
# Total time was 0.06299686431884766
# running the 85 th model
# Total iteration number was 17
# Total time was 0.34749698638916016
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β     │ estimated_β │
# │     │ Int64            │ Float64    │ Float64     │
# ├─────┼──────────────────┼────────────┼─────────────┤
# │ 1   │ 781              │ 0.685303   │ 0.603716    │
# │ 2   │ 841              │ 1.08121    │ 1.42903     │
# │ 3   │ 999              │ -0.671743  │ -0.833839   │
# │ 4   │ 1129             │ -1.36311   │ -1.42506    │
# │ 5   │ 1133             │ -0.0305087 │ 0.0         │
# │ 6   │ 1702             │ 1.82135    │ 1.88833     │
# │ 7   │ 1755             │ 0.254952   │ 0.0         │
# │ 8   │ 2102             │ 0.734744   │ 0.73171     │
# │ 9   │ 2853             │ 0.0319311  │ 0.0         │
# │ 10  │ 3089             │ 0.339854   │ 0.0         │
# n = 881, and p = 3524
# Total iteration number was 17
# Total time was 0.34749698638916016
# running the 86 th model
# Total iteration number was 11
# Total time was 0.36164402961730957
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 616              │ -0.673323 │ -0.782085   │
# │ 2   │ 839              │ -0.164282 │ 0.0         │
# │ 3   │ 860              │ -0.631618 │ -0.679348   │
# │ 4   │ 874              │ -0.344967 │ -0.468455   │
# │ 5   │ 1092             │ -2.11699  │ -2.07484    │
# │ 6   │ 1287             │ -0.292449 │ -0.386709   │
# │ 7   │ 3637             │ -0.477398 │ -0.4456     │
# │ 8   │ 3685             │ -0.662922 │ -0.655113   │
# │ 9   │ 3702             │ 0.0721731 │ 0.0         │
# │ 10  │ 4781             │ 1.50711   │ 1.64146     │
# n = 988, and p = 4940
# Total iteration number was 11
# Total time was 0.36164402961730957
# running the 87 th model
# Total iteration number was 12
# Total time was 0.34203600883483887
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 691              │ -1.01725  │ -1.10874    │
# │ 2   │ 1847             │ 0.65398   │ 1.12135     │
# │ 3   │ 2238             │ 0.914938  │ 1.00088     │
# │ 4   │ 2788             │ 1.25214   │ 1.44373     │
# │ 5   │ 3102             │ -0.92934  │ -0.991875   │
# │ 6   │ 3225             │ 0.819527  │ 1.0838      │
# │ 7   │ 3568             │ 2.35438   │ 2.52719     │
# │ 8   │ 4562             │ -0.161074 │ 0.0         │
# │ 9   │ 4771             │ -0.849005 │ -0.903674   │
# │ 10  │ 6032             │ -1.98749  │ -2.3378     │
# n = 689, and p = 6201
# Total iteration number was 12
# Total time was 0.34203600883483887
# running the 88 th model
# Total iteration number was 14
# Total time was 0.04096388816833496
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 82               │ -0.967517 │ -1.48879    │
# │ 2   │ 161              │ -0.858774 │ -1.17089    │
# │ 3   │ 522              │ 0.635622  │ 0.757245    │
# │ 4   │ 857              │ 0.814346  │ 0.806905    │
# │ 5   │ 916              │ 0.579376  │ 0.760333    │
# │ 6   │ 937              │ -0.210214 │ 0.0         │
# │ 7   │ 944              │ -1.42121  │ -1.86158    │
# │ 8   │ 1009             │ -0.304529 │ 0.0         │
# │ 9   │ 1089             │ 0.397811  │ 0.0         │
# │ 10  │ 1117             │ 0.242586  │ 0.0         │
# n = 291, and p = 1164
# Total iteration number was 14
# Total time was 0.04096388816833496
# running the 89 th model
# Total iteration number was 12
# Total time was 0.39615416526794434
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 813              │ -0.826666 │ -0.943021   │
# │ 2   │ 1435             │ -0.208922 │ 0.0         │
# │ 3   │ 1969             │ 0.252041  │ 0.0         │
# │ 4   │ 2711             │ -0.577294 │ -0.670789   │
# │ 5   │ 3169             │ 0.0051948 │ 0.0         │
# │ 6   │ 3459             │ 0.728367  │ 0.834782    │
# │ 7   │ 3877             │ 0.291612  │ 0.0         │
# │ 8   │ 3929             │ -1.58844  │ -1.78935    │
# │ 9   │ 4609             │ -1.31224  │ -1.56401    │
# │ 10  │ 4667             │ -2.02859  │ -2.36768    │
# n = 997, and p = 4985
# Total iteration number was 12
# Total time was 0.39615416526794434
# running the 90 th model
# Total iteration number was 15
# Total time was 0.2913980484008789
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 69               │ -0.714614 │ -0.983614   │
# │ 2   │ 317              │ 0.515423  │ 0.0         │
# │ 3   │ 744              │ -1.07143  │ -1.16117    │
# │ 4   │ 898              │ 1.495     │ 1.76216     │
# │ 5   │ 1514             │ 0.31036   │ 0.0         │
# │ 6   │ 1575             │ -1.80379  │ -2.06328    │
# │ 7   │ 3723             │ -1.84859  │ -1.79464    │
# │ 8   │ 4657             │ 0.614915  │ 0.0         │
# │ 9   │ 5109             │ 1.57424   │ 1.90261     │
# │ 10  │ 5125             │ 0.730448  │ 0.831003    │
# n = 546, and p = 5460
# Total iteration number was 15
# Total time was 0.2913980484008789
# running the 91 th model
# Total iteration number was 22
# Total time was 0.20981287956237793
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 272              │ -0.975884 │ -1.23777    │
# │ 2   │ 489              │ -0.25538  │ 0.0         │
# │ 3   │ 570              │ -1.10553  │ -1.03162    │
# │ 4   │ 942              │ -0.151166 │ 0.0         │
# │ 5   │ 1696             │ 0.923527  │ 0.774793    │
# │ 6   │ 2055             │ 0.582103  │ 0.0         │
# │ 7   │ 2226             │ 1.8522    │ 2.08407     │
# │ 8   │ 2439             │ 0.362467  │ 0.0         │
# │ 9   │ 2473             │ -0.104984 │ 0.0         │
# │ 10  │ 2603             │ 0.187983  │ 0.0         │
# n = 444, and p = 3108
# Total iteration number was 22
# Total time was 0.20981287956237793
# running the 92 th model
# Total iteration number was 8
# Total time was 0.20222091674804688
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 987              │ -1.58046  │ -1.66097    │
# │ 2   │ 1693             │ 0.965216  │ 1.01007     │
# │ 3   │ 2946             │ 0.0278454 │ 0.0         │
# │ 4   │ 3004             │ 0.941393  │ 1.0443      │
# │ 5   │ 3156             │ 0.2568    │ 0.0         │
# │ 6   │ 3606             │ 0.969966  │ 1.10696     │
# │ 7   │ 4139             │ 0.272025  │ 0.0         │
# │ 8   │ 4155             │ 0.207306  │ 0.0         │
# │ 9   │ 4760             │ -0.97183  │ -1.09037    │
# │ 10  │ 5177             │ 1.78163   │ 2.82967     │
# n = 658, and p = 5264
# Total iteration number was 8
# Total time was 0.20222091674804688
# running the 93 th model
# Total iteration number was 12
# Total time was 0.15249085426330566
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 916              │ 1.26576   │ 1.99776     │
# │ 2   │ 1073             │ 1.64543   │ 1.87067     │
# │ 3   │ 1088             │ -0.68029  │ -1.0548     │
# │ 4   │ 1376             │ -0.224919 │ 0.0         │
# │ 5   │ 1428             │ -1.2593   │ -1.37776    │
# │ 6   │ 1964             │ -1.35383  │ -1.51588    │
# │ 7   │ 2052             │ -0.928196 │ -1.10535    │
# │ 8   │ 2606             │ 1.97879   │ 2.41044     │
# │ 9   │ 3307             │ 0.47577   │ 0.0         │
# │ 10  │ 3599             │ 1.13185   │ 1.47709     │
# n = 426, and p = 3834
# Total iteration number was 12
# Total time was 0.15249085426330566
# running the 94 th model
# Total iteration number was 10
# Total time was 0.028404951095581055
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β     │ estimated_β │
# │     │ Int64            │ Float64    │ Float64     │
# ├─────┼──────────────────┼────────────┼─────────────┤
# │ 1   │ 627              │ 0.798976   │ 0.0         │
# │ 2   │ 771              │ 0.939127   │ 0.0         │
# │ 3   │ 798              │ 0.00256104 │ 0.0         │
# │ 4   │ 841              │ -1.18634   │ 0.0         │
# │ 5   │ 874              │ 0.419041   │ 0.0         │
# │ 6   │ 888              │ -1.12502   │ -2.62133    │
# │ 7   │ 981              │ -1.8161    │ -4.17741    │
# │ 8   │ 1103             │ -1.98095   │ -3.92295    │
# │ 9   │ 1197             │ -0.407801  │ 0.0         │
# │ 10  │ 1298             │ 2.24137    │ 3.87858     │
# n = 158, and p = 1580
# Total iteration number was 10
# Total time was 0.028404951095581055
# running the 95 th model
# Total iteration number was 14
# Total time was 0.14709687232971191
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 228              │ -0.145855 │ 0.0         │
# │ 2   │ 442              │ -0.36377  │ 0.0         │
# │ 3   │ 574              │ -0.368509 │ 0.0         │
# │ 4   │ 686              │ 0.397946  │ 0.0         │
# │ 5   │ 947              │ -0.88063  │ -1.11323    │
# │ 6   │ 1173             │ 0.056533  │ 0.0         │
# │ 7   │ 1694             │ -2.35359  │ -2.91946    │
# │ 8   │ 1749             │ 1.14608   │ 1.22679     │
# │ 9   │ 2556             │ -0.654146 │ -0.875567   │
# │ 10  │ 2872             │ 0.769746  │ 1.10586     │
# n = 491, and p = 2946
# Total iteration number was 14
# Total time was 0.14709687232971191
# running the 96 th model
# Total iteration number was 17
# Total time was 0.716076135635376
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 1231             │ -0.556993 │ -0.598736   │
# │ 2   │ 1911             │ 0.728343  │ 0.531084    │
# │ 3   │ 2796             │ 0.998487  │ 0.927166    │
# │ 4   │ 3736             │ -0.315556 │ -0.394123   │
# │ 5   │ 4623             │ -0.128251 │ 0.0         │
# │ 6   │ 4674             │ -1.9215   │ -1.81087    │
# │ 7   │ 5306             │ -1.05468  │ -1.01394    │
# │ 8   │ 5557             │ 1.12991   │ 1.41592     │
# │ 9   │ 5907             │ -0.451535 │ -0.389829   │
# │ 10  │ 7855             │ -1.26301  │ -1.13072    │
# n = 799, and p = 7990
# Total iteration number was 17
# Total time was 0.716076135635376
# running the 97 th model
# Total iteration number was 20
# Total time was 0.03868818283081055
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 32               │ 0.893494  │ 1.35715     │
# │ 2   │ 93               │ -0.26192  │ 0.0         │
# │ 3   │ 159              │ -0.575586 │ -0.606339   │
# │ 4   │ 168              │ -0.017881 │ 0.0         │
# │ 5   │ 191              │ 1.06282   │ 1.09598     │
# │ 6   │ 233              │ -1.98548  │ -2.20865    │
# │ 7   │ 326              │ 0.522781  │ 0.840347    │
# │ 8   │ 330              │ -0.578841 │ -0.756622   │
# │ 9   │ 370              │ -0.152143 │ 0.0         │
# │ 10  │ 413              │ -1.26785  │ -1.6751     │
# n = 426, and p = 426
# Total iteration number was 20
# Total time was 0.03868818283081055
# running the 98 th model
# Total iteration number was 13
# Total time was 0.12872004508972168
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 225              │ 0.589023  │ 0.392718    │
# │ 2   │ 227              │ 0.495744  │ 0.452908    │
# │ 3   │ 519              │ -0.382954 │ 0.0         │
# │ 4   │ 563              │ -1.00459  │ -1.22042    │
# │ 5   │ 644              │ 0.102003  │ 0.0         │
# │ 6   │ 795              │ -1.07083  │ -1.35807    │
# │ 7   │ 906              │ 1.41709   │ 1.54293     │
# │ 8   │ 1313             │ -0.245752 │ 0.0         │
# │ 9   │ 1466             │ -0.640695 │ -0.6713     │
# │ 10  │ 1556             │ 0.222074  │ 0.0         │
# n = 790, and p = 1580
# Total iteration number was 13
# Total time was 0.12872004508972168
# running the 99 th model
# Total iteration number was 11
# Total time was 0.07724308967590332
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 642              │ -0.886677 │ -1.02024    │
# │ 2   │ 675              │ 0.153008  │ 0.0         │
# │ 3   │ 700              │ -1.61041  │ -1.75221    │
# │ 4   │ 962              │ 0.488594  │ 0.0         │
# │ 5   │ 1554             │ -0.768127 │ -0.675102   │
# │ 6   │ 1589             │ 0.604087  │ 0.740638    │
# │ 7   │ 1818             │ 0.0109748 │ 0.0         │
# │ 8   │ 1913             │ -0.368721 │ 0.0         │
# │ 9   │ 1959             │ -0.781844 │ -1.01918    │
# │ 10  │ 2096             │ 1.33066   │ 1.24628     │
# n = 383, and p = 2298
# Total iteration number was 11
# Total time was 0.07724308967590332
# running the 100 th model
# Total iteration number was 20
# Total time was 0.8407289981842041
# compare_model = 10×3 DataFrame
# │ Row │ correct_position │ true_β    │ estimated_β │
# │     │ Int64            │ Float64   │ Float64     │
# ├─────┼──────────────────┼───────────┼─────────────┤
# │ 1   │ 211              │ 1.03073   │ 1.10417     │
# │ 2   │ 638              │ 0.670303  │ 0.0         │
# │ 3   │ 2730             │ 0.0357848 │ 0.0         │
# │ 4   │ 3407             │ -1.36532  │ -1.64146    │
# │ 5   │ 3626             │ 1.47119   │ 1.75197     │
# │ 6   │ 4678             │ 0.132214  │ 0.0         │
# │ 7   │ 4780             │ -1.29963  │ -1.38455    │
# │ 8   │ 5484             │ 0.538991  │ 0.656174    │
# │ 9   │ 5617             │ -1.32188  │ -1.49392    │
# │ 10  │ 6661             │ -1.31508  │ -1.37527    │
# n = 977, and p = 6839
# Total iteration number was 20
# Total time was 0.8407289981842041
