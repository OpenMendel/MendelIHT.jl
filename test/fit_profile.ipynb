# %% [markdown]
# # Lets profile `fit` function for univariate and multivariate

# %%
using Revise
using MendelIHT
using SnpArrays
using Random
using GLM
using DelimitedFiles
using Test
using Distributions
using LinearAlgebra
using CSV
using DataFrames
using StatsBase
using Profile
# using ProfileView
BLAS.set_num_threads(1) # remember to set BLAS threads to 1 !!!
# Out:
# ┌ Info: Precompiling MendelIHT [921c7187-1484-5754-b919-5d3ed9ac03c4]
# └ @ Base loading.jl:1317

# %% [markdown]
# ## Univariate response with SnpLinAlg

# %%
n = 1000  # number of samples
p = 10000 # number of SNPs
k = 10    # number of causal SNPs per trait
d = Normal
l = canonicallink(d())

# set random seed for reproducibility
Random.seed!(2021)

# simulate `.bed` file with no missing data
x = simulate_random_snparray(undef, n, p)
xla = SnpLinAlg{Float64}(x, model=ADDITIVE_MODEL, center=true, scale=true) 

# intercept is the only nongenetic covariate
z = ones(n)
intercept = 1.0

# simulate response y, true model b, and the correct non-0 positions of b
Y, true_b, correct_position = simulate_random_response(xla, k, d, l, Zu=z*intercept);

# %%
Random.seed!(2020)
@time result = fit_iht(Y, xla, z, init_beta=true);
speed_per_iter = result.time / result.iter
# Out:
# ****                   MendelIHT Version 1.4.1                  ****
# ****     Benjamin Chu, Kevin Keys, Chris German, Hua Zhou       ****
# ****   Jin Zhou, Eric Sobel, Janet Sinsheimer, Kenneth Lange    ****
# ****                                                            ****
# ****                 Please cite our paper!                     ****
# ****         https://doi.org/10.1093/gigascience/giaa044        ****
#
# Initializing β to univariate regression values...
# ...completed in 0.1 seconds.
#
# Running sparse linear regression
# Number of threads = 1
# Link functin = IdentityLink()
# Sparsity parameter (k) = 10
# Prior weight scaling = off
# Doubly sparse projection = off
# Debias = off
# Max IHT iterations = 200
# Converging when tol < 0.0001 and iteration ≥ 5:
#
# Iteration 1: loglikelihood = -2466.2371277080556, backtracks = 0, tol = 0.5295306543287241
# Iteration 2: loglikelihood = -1579.16025278937, backtracks = 0, tol = 0.34661836758541936
# Iteration 3: loglikelihood = -1489.9150515502452, backtracks = 0, tol = 0.13025779204902216
# Iteration 4: loglikelihood = -1480.2469110185323, backtracks = 0, tol = 0.05903857146173997
# Iteration 5: loglikelihood = -1479.857116473815, backtracks = 1, tol = 0.004134904185743004
# Iteration 6: loglikelihood = -1479.7539297610465, backtracks = 1, tol = 0.002383730962410059
# Iteration 7: loglikelihood = -1479.7271685083651, backtracks = 1, tol = 0.0012901289847717665
# Iteration 8: loglikelihood = -1479.7203412361453, backtracks = 1, tol = 0.0006688794761477208
# Iteration 9: loglikelihood = -1479.7186166254837, backtracks = 1, tol = 0.00033857681371341554
# Iteration 10: loglikelihood = -1479.7181832079027, backtracks = 1, tol = 0.00016943109885077327
# Iteration 11: loglikelihood = -1479.7180745603014, backtracks = 1, tol = 8.43905290446323e-5
#   0.265817 seconds (671.30 k allocations: 104.477 MiB, 11.80% gc time, 28.72% compilation time)
# 0.004685987125743519

# %% [markdown]
# Univariate IHT runs at 0.004 seconds per iteration. Let's profile our fit function.

# %%
fit_iht(Y, xla, z, init_beta=true, verbose=false)
Profile.clear()
@profile fit_iht(Y, xla, z, init_beta=true, verbose=false);
Profile.print()
# Out:
# Overhead ╎ [+additional indent] Count File:Line; Function
# =========================================================
#   ╎57  @Base/task.jl:406; (::IJulia.var"#15#18")()
#   ╎ 57  @IJulia/src/eventloop.jl:8; eventloop(socket::ZMQ.Socket)
#   ╎  57  @Base/essentials.jl:706; invokelatest
#   ╎   57  @Base/essentials.jl:708; #invokelatest#2
#   ╎    57  .../execute_request.jl:67; execute_request(socket::ZMQ.Soc...
#   ╎     57  .../SoftGlobalScope.jl:65; softscope_include_string(m::Mo...
#   ╎    ╎ 57  @Base/loading.jl:1094; include_string(mapexpr::type...
#  8╎    ╎  57  @Base/boot.jl:360; eval
#   ╎    ╎   6   ...iler/typeinfer.jl:921; typeinf_ext_toplevel(mi::Cor...
#   ╎    ╎    6   ...iler/typeinfer.jl:925; typeinf_ext_toplevel(interp...
#   ╎    ╎     6   ...iler/typeinfer.jl:892; typeinf_ext(interp::Core.Co...
#   ╎    ╎    ╎ 6   ...ler/typeinfer.jl:209; typeinf(interp::Core.Compi...
#   ╎    ╎    ╎  5   ...ler/typeinfer.jl:214; _typeinf(interp::Core.Com...
#   ╎    ╎    ╎   5   ...terpretation.jl:1520; typeinf_nocycle(interp::...
#   ╎    ╎    ╎    2   ...terpretation.jl:1447; typeinf_local(interp::Co...
#   ╎    ╎    ╎     2   ...erpretation.jl:1167; abstract_eval_statement...
#   ╎    ╎    ╎    ╎ 2   ...erpretation.jl:1040; abstract_call(interp::...
#   ╎    ╎    ╎    ╎  2   ...rpretation.jl:1056; abstract_call(interp::...
#   ╎    ╎    ╎    ╎   2   ...rpretation.jl:1033; abstract_call_known(i...
#   ╎    ╎    ╎    ╎    2   ...rpretation.jl:168; abstract_call_gf_by_t...
#   ╎    ╎    ╎    ╎     2   ...rpretation.jl:330; abstract_call_method_...
#   ╎    ╎    ╎    ╎    ╎ 2   ...typeinfer.jl:209; typeinf(interp::Core...
#   ╎    ╎    ╎    ╎    ╎  1   ...typeinfer.jl:214; _typeinf(interp::Co...
#   ╎    ╎    ╎    ╎    ╎   1   ...retation.jl:1520; typeinf_nocycle(in...
#   ╎    ╎    ╎    ╎    ╎    1   ...retation.jl:1462; typeinf_local(inte...
#   ╎    ╎    ╎    ╎    ╎     1   ...etation.jl:1167; abstract_eval_sta...
#   ╎    ╎    ╎    ╎    ╎    ╎ 1   ...etation.jl:1040; abstract_call(in...
#   ╎    ╎    ╎    ╎    ╎    ╎  1   ...tation.jl:1056; abstract_call(in...
#   ╎    ╎    ╎    ╎    ╎    ╎   1   ...tation.jl:1033; abstract_call_k...
#   ╎    ╎    ╎    ╎    ╎    ╎    1   ...tation.jl:168; abstract_call_g...
#   ╎    ╎    ╎    ╎    ╎    ╎     1   ...tation.jl:330; abstract_call_m...
#   ╎    ╎    ╎    ╎    ╎    ╎    ╎ 1   ...einfer.jl:209; typeinf(interp:...
#   ╎    ╎    ╎    ╎    ╎    ╎    ╎  1   ...einfer.jl:214; _typeinf(interp...
#   ╎    ╎    ╎    ╎    ╎    ╎    ╎   1   ...tation.jl:1520; typeinf_nocycle...
#   ╎    ╎    ╎    ╎    ╎    ╎    ╎    1   ...tation.jl:1462; typeinf_local(i...
#   ╎    ╎    ╎    ╎    ╎    ╎    ╎     1   ...tation.jl:1167; abstract_eval_s...
#   ╎    ╎    ╎    ╎    ╎    ╎    ╎    ╎ 1   ...tation.jl:1040; abstract_call(i...
#   ╎    ╎    ╎    ╎    ╎    ╎    ╎    ╎  1   ...tation.jl:1056; abstract_call(i...
#   ╎    ╎    ╎    ╎    ╎    ╎    ╎    ╎   1   ...tation.jl:1032; abstract_call_k...
#   ╎    ╎    ╎    ╎    ╎    ╎    ╎    ╎    1   ...eutils.jl:50; argtypes_to_type
#   ╎    ╎    ╎    ╎    ╎    ╎    ╎    ╎     1   ...lities.jl:39; anymap(f::typeo...
#  1╎    ╎    ╎    ╎    ╎    ╎    ╎    ╎  +1 1   ...attice.jl:234; widenconst(c::C...
#   ╎    ╎    ╎    ╎    ╎  1   ...typeinfer.jl:244; _typeinf(interp::Co...
#   ╎    ╎    ╎    ╎    ╎   1   ...optimize.jl:272; optimize
#   ╎    ╎    ╎    ╎    ╎    1   ...r/driver.jl:129; run_passes(ci::Cor...
#   ╎    ╎    ╎    ╎    ╎     1   ...inlining.jl:68; ssa_inlining_pass!...
#   ╎    ╎    ╎    ╎    ╎    ╎ 1   ...nlining.jl:1203; assemble_inline_...
#   ╎    ╎    ╎    ╎    ╎    ╎  1   ...lining.jl:1102; analyze_single_c...
#   ╎    ╎    ╎    ╎    ╎    ╎   1   ...lining.jl:758; analyze_method!(...
#   ╎    ╎    ╎    ╎    ╎    ╎    1   ...lining.jl:704; resolve_todo(to...
#   ╎    ╎    ╎    ╎    ╎    ╎     1   ...lining.jl:771; Core.Compiler.I...
#   ╎    ╎    ╎    ╎    ╎    ╎    ╎ 1   ...legacy.jl:6; inflate_ir(ci::...
#   ╎    ╎    ╎    ╎    ╎    ╎    ╎  1   ...result.jl:50; matching_cache_...
#   ╎    ╎    ╎    ╎    ╎    ╎    ╎   1   .../array.jl:397; getindex(::Type...
#  1╎    ╎    ╎    ╎    ╎    ╎    ╎    1   ...e/boot.jl:448; Array
#   ╎    ╎    ╎    3   ...terpretation.jl:1462; typeinf_local(interp::Co...
#   ╎    ╎    ╎     3   ...erpretation.jl:1167; abstract_eval_statement...
#   ╎    ╎    ╎    ╎ 3   ...erpretation.jl:1040; abstract_call(interp::...
#   ╎    ╎    ╎    ╎  3   ...rpretation.jl:1056; abstract_call(interp::...
#   ╎    ╎    ╎    ╎   1   ...rpretation.jl:1032; abstract_call_known(i...
#   ╎    ╎    ╎    ╎    1   .../typeutils.jl:50; argtypes_to_type
#  1╎    ╎    ╎    ╎     1   .../utilities.jl:39; anymap(f::typeof(Core...
#   ╎    ╎    ╎    ╎   2   ...rpretation.jl:1033; abstract_call_known(i...
#   ╎    ╎    ╎    ╎    1   ...rpretation.jl:84; abstract_call_gf_by_t...
#   ╎    ╎    ╎    ╎     1   ...ethodtable.jl:65; (::Core.Compiler.var"...
#   ╎    ╎    ╎    ╎    ╎ 1   ...ethodtable.jl:66; #findall#217
#   ╎    ╎    ╎    ╎    ╎  1   @Base/iddict.jl:163; get!
#   ╎    ╎    ╎    ╎    ╎   1   ...thodtable.jl:67; (::Core.Compiler.va...
#   ╎    ╎    ╎    ╎    ╎    1   ...hodtable.jl:54; (::Core.Compiler.va...
#   ╎    ╎    ╎    ╎    ╎     1   ...hodtable.jl:57; #findall#216
#   ╎    ╎    ╎    ╎    ╎    ╎ 1   ...lection.jl:867; _methods_by_ftype
#   ╎    ╎    ╎    ╎    1   ...rpretation.jl:168; abstract_call_gf_by_t...
#   ╎    ╎    ╎    ╎     1   ...rpretation.jl:330; abstract_call_method_...
#   ╎    ╎    ╎    ╎    ╎ 1   ...typeinfer.jl:209; typeinf(interp::Core...
#   ╎    ╎    ╎    ╎    ╎  1   ...typeinfer.jl:244; _typeinf(interp::Co...
#   ╎    ╎    ╎    ╎    ╎   1   ...optimize.jl:272; optimize
#   ╎    ╎    ╎    ╎    ╎    1   ...r/driver.jl:129; run_passes(ci::Cor...
#   ╎    ╎    ╎    ╎    ╎     1   ...inlining.jl:68; ssa_inlining_pass!...
#   ╎    ╎    ╎    ╎    ╎    ╎ 1   ...nlining.jl:1155; assemble_inline_...
#   ╎    ╎    ╎    ╎    ╎    ╎  1   ...lining.jl:1013; process_simple!(...
#   ╎    ╎    ╎    ╎    ╎    ╎   1   ...lining.jl:892; call_sig(ir::Cor...
#   ╎    ╎    ╎    ╎    ╎    ╎    1   ...lities.jl:220; argextype
#  1╎    ╎    ╎    ╎    ╎    ╎     1   ...lities.jl:0; argextype(x::Any...
#   ╎    ╎    ╎  1   ...ler/typeinfer.jl:272; _typeinf(interp::Core.Com...
#   ╎    ╎    ╎   1   ...er/typeinfer.jl:376; cache_result!(interp::Cor...
#   ╎    ╎    ╎    1   ...er/typeinfer.jl:351; transform_result_for_cache
#  1╎    ╎    ╎     1   ...er/typeinfer.jl:331; maybe_compress_codeinfo(...
#   ╎    ╎   43  ...delIHT/src/fit.jl:72; (::MendelIHT.var"#fit_iht##k...
#   ╎    ╎    4   ...delIHT/src/fit.jl:96; fit_iht(y::Vector{Float64},...
#   ╎    ╎     4   @Base/timing.jl:287; macro expansion
#   ╎    ╎    ╎ 4   ...ta_structures.jl:116; initialize
#   ╎    ╎    ╎  4   ...ta_structures.jl:123; #initialize#1
#   ╎    ╎    ╎   4   ...rc/utilities.jl:334; init_iht_indices!(v::IHTV...
#   ╎    ╎    ╎    4   ...rc/utilities.jl:116; score!(v::IHTVariable{Fl...
#   ╎    ╎    ╎     4   ...inalg_direct.jl:148; mul!(out::Vector{Float64...
#   ╎    ╎    ╎    ╎ 3   ...nalg_direct.jl:470; _snparray_atx_tile!(c::...
#   ╎    ╎    ╎    ╎  3   ...nalg_direct.jl:725; _snparray_atx_additive...
#   ╎    ╎    ╎    ╎   3   ...ct_loopset.jl:706; _turbo_!(::Val{(false,...
#   ╎    ╎    ╎    ╎    3   ...ct_loopset.jl:706; macro expansion
#   ╎    ╎    ╎    ╎     1   .../base_defs.jl:86; >>
#   ╎    ╎    ╎    ╎    ╎ 1   ...nroll/fmap.jl:93; vashr
#   ╎    ╎    ╎    ╎    ╎  1   ...nroll/fmap.jl:9; fmap
#   ╎    ╎    ╎    ╎    ╎   1   ...roll/fmap.jl:9; fmap
#   ╎    ╎    ╎    ╎    ╎    1   ...nary_ops.jl:83; vashr
#  1╎    ╎    ╎    ╎    ╎     1   ...nary_ops.jl:83; macro expansion
#   ╎    ╎    ╎    ╎     2   ...trin_funcs.jl:291; vfmadd_fast
#   ╎    ╎    ╎    ╎    ╎ 2   ...rin_funcs.jl:289; _vfmadd_fast
#   ╎    ╎    ╎    ╎    ╎  2   ...base_defs.jl:267; vfma_fast
#   ╎    ╎    ╎    ╎    ╎   2   ...base_defs.jl:89; add_fast
#   ╎    ╎    ╎    ╎    ╎    2   ...oll/fmap.jl:62; vadd_fast
#   ╎    ╎    ╎    ╎    ╎     2   ...oll/fmap.jl:9; fmap
#   ╎    ╎    ╎    ╎    ╎    ╎ 2   ...oll/fmap.jl:9; fmap
#   ╎    ╎    ╎    ╎    ╎    ╎  2   ...oll/fmap.jl:9; fmap
#   ╎    ╎    ╎    ╎    ╎    ╎   2   ...ary_ops.jl:94; vadd_fast
#  2╎    ╎    ╎    ╎    ╎    ╎    2   ...ry_ops.jl:94; macro expansion
#   ╎    ╎    ╎    ╎ 1   ...nalg_direct.jl:480; _snparray_atx_tile!(c::...
#   ╎    ╎    ╎    ╎  1   ...nalg_direct.jl:725; _snparray_atx_additive...
#   ╎    ╎    ╎    ╎   1   ...ct_loopset.jl:706; _turbo_!(::Val{(false,...
#   ╎    ╎    ╎    ╎    1   ...ct_loopset.jl:706; macro expansion
#   ╎    ╎    ╎    ╎     1   ...trin_funcs.jl:291; vfmadd_fast
#   ╎    ╎    ╎    ╎    ╎ 1   ...rin_funcs.jl:289; _vfmadd_fast
#   ╎    ╎    ╎    ╎    ╎  1   ...base_defs.jl:267; vfma_fast
#   ╎    ╎    ╎    ╎    ╎   1   ...base_defs.jl:89; add_fast
#   ╎    ╎    ╎    ╎    ╎    1   ...oll/fmap.jl:62; vadd_fast
#   ╎    ╎    ╎    ╎    ╎     1   ...oll/fmap.jl:9; fmap
#   ╎    ╎    ╎    ╎    ╎    ╎ 1   ...oll/fmap.jl:9; fmap
#   ╎    ╎    ╎    ╎    ╎    ╎  1   ...oll/fmap.jl:9; fmap
#   ╎    ╎    ╎    ╎    ╎    ╎   1   ...ll/fmap.jl:6; fmap
#   ╎    ╎    ╎    ╎    ╎    ╎    1   ...ry_ops.jl:94; vadd_fast
#  1╎    ╎    ╎    ╎    ╎    ╎     1   ...ry_ops.jl:94; macro expansion
#   ╎    ╎    39  ...delIHT/src/fit.jl:102; fit_iht(y::Vector{Float64},...
#   ╎    ╎     39  ...delIHT/src/fit.jl:148; fit_iht!##kw
#   ╎    ╎    ╎ 39  ...elIHT/src/fit.jl:176; fit_iht!(v::IHTVariable{Fl...
#   ╎    ╎    ╎  1   ...elIHT/src/fit.jl:211; iht_one_step!(v::IHTVaria...
#   ╎    ╎    ╎   1   ...rc/utilities.jl:664; iht_stepsize!(v::IHTVaria...
#   ╎    ╎    ╎    1   @Base/simdloop.jl:77; macro expansion
#   ╎    ╎    ╎     1   ...rc/utilities.jl:665; macro expansion
#  1╎    ╎    ╎    ╎ 1   @Base/array.jl:839; setindex!(A::Vector{Flo...
#   ╎    ╎    ╎  1   ...elIHT/src/fit.jl:214; iht_one_step!(v::IHTVaria...
#   ╎    ╎    ╎   1   ...rc/utilities.jl:250; _iht_gradstep!(v::IHTVari...
#   ╎    ╎    ╎    1   ...bstractarray.jl:950; copyto!
#   ╎    ╎    ╎     1   ...bstractarray.jl:970; copyto_unaliased!(destst...
#  1╎    ╎    ╎    ╎ 1   @Base/array.jl:801; getindex
#   ╎    ╎    ╎  1   ...elIHT/src/fit.jl:217; iht_one_step!(v::IHTVaria...
#   ╎    ╎    ╎   1   ...src/utilities.jl:94; update_xb!(v::IHTVariable...
#   ╎    ╎    ╎    1   ...inalg_direct.jl:867; copyto!(v::Matrix{Float6...
#   ╎    ╎    ╎     1   @Base/simdloop.jl:77; macro expansion
#   ╎    ╎    ╎    ╎ 1   ...nalg_direct.jl:868; macro expansion
#   ╎    ╎    ╎    ╎  1   @Base/subarray.jl:276; getindex
#   ╎    ╎    ╎    ╎   1   ...nalg_direct.jl:62; getindex
#   ╎    ╎    ╎    ╎    1   ...c/snparray.jl:291; convert
#   ╎    ╎    ╎    ╎     1   @Base/int.jl:923; -
#  1╎    ╎    ╎    ╎    ╎ 1   @Base/int.jl:86; -
#   ╎    ╎    ╎  2   ...elIHT/src/fit.jl:218; iht_one_step!(v::IHTVaria...
#  2╎    ╎    ╎   2   ...src/utilities.jl:80; update_μ!(v::IHTVariable{...
#   ╎    ╎    ╎  1   ...elIHT/src/fit.jl:240; iht_one_step!(v::IHTVaria...
#   ╎    ╎    ╎   1   ...rc/utilities.jl:860; backtrack!(v::IHTVariable...
#   ╎    ╎    ╎    1   ...rc/utilities.jl:94; update_xb!(v::IHTVariable...
#   ╎    ╎    ╎     1   ...inalg_direct.jl:867; copyto!(v::Matrix{Float6...
#   ╎    ╎    ╎    ╎ 1   @Base/simdloop.jl:77; macro expansion
#   ╎    ╎    ╎    ╎  1   ...nalg_direct.jl:868; macro expansion
#   ╎    ╎    ╎    ╎   1   ...e/subarray.jl:276; getindex
#   ╎    ╎    ╎    ╎    1   ...alg_direct.jl:65; getindex
#  1╎    ╎    ╎    ╎     1   @Base/float.jl:332; *
#   ╎    ╎    ╎  33  ...elIHT/src/fit.jl:247; iht_one_step!(v::IHTVaria...
#   ╎    ╎    ╎   1   ...rc/utilities.jl:114; score!(v::IHTVariable{Flo...
#  1╎    ╎    ╎    1   @Base/operators.jl:560; *
#   ╎    ╎    ╎   32  ...rc/utilities.jl:116; score!(v::IHTVariable{Flo...
#   ╎    ╎    ╎    32  ...inalg_direct.jl:148; mul!(out::Vector{Float64...
#   ╎    ╎    ╎     27  ...inalg_direct.jl:470; _snparray_atx_tile!(c::V...
#   ╎    ╎    ╎    ╎ 27  ...nalg_direct.jl:725; _snparray_atx_additive_...
#   ╎    ╎    ╎    ╎  27  ...uct_loopset.jl:706; _turbo_!(::Val{(false,...
#   ╎    ╎    ╎    ╎   26  ...ct_loopset.jl:706; macro expansion
#   ╎    ╎    ╎    ╎    3   ...er_compute.jl:207; partialmap
#   ╎    ╎    ╎    ╎     3   ...er_compute.jl:0; macro expansion
#   ╎    ╎    ╎    ╎    ╎ 3   ...rin_funcs.jl:291; vfmadd_fast
#   ╎    ╎    ╎    ╎    ╎  3   ...rin_funcs.jl:289; _vfmadd_fast
#   ╎    ╎    ╎    ╎    ╎   3   ...in_funcs.jl:255; vfma_fast
#  3╎    ╎    ╎    ╎    ╎    3   ...in_funcs.jl:255; macro expansion
#   ╎    ╎    ╎    ╎    1   .../base_defs.jl:90; &
#   ╎    ╎    ╎    ╎     1   ...nroll/fmap.jl:62; vand
#   ╎    ╎    ╎    ╎    ╎ 1   ...nroll/fmap.jl:9; fmap
#   ╎    ╎    ╎    ╎    ╎  1   ...inary_ops.jl:83; vand
#  1╎    ╎    ╎    ╎    ╎   1   ...inary_ops.jl:83; macro expansion
#   ╎    ╎    ╎    ╎    4   .../base_defs.jl:90; >=
#   ╎    ╎    ╎    ╎     4   ...nroll/fmap.jl:63; vge
#   ╎    ╎    ╎    ╎    ╎ 4   ...nroll/fmap.jl:10; fmap
#   ╎    ╎    ╎    ╎    ╎  3   ...rin/masks.jl:438; vge
#   ╎    ╎    ╎    ╎    ╎   3   ...in/masks.jl:427; vge
#   ╎    ╎    ╎    ╎    ╎    3   ...ase_defs.jl:86; >=
#   ╎    ╎    ╎    ╎    ╎     3   ...in/masks.jl:403; vge
#  3╎    ╎    ╎    ╎    ╎    ╎ 3   ...n/masks.jl:374; macro expansion
#   ╎    ╎    ╎    ╎    ╎  1   ...roll/fmap.jl:10; fmap
#   ╎    ╎    ╎    ╎    ╎   1   ...roll/fmap.jl:10; fmap
#   ╎    ╎    ╎    ╎    ╎    1   ...roll/fmap.jl:7; fmap
#   ╎    ╎    ╎    ╎    ╎     1   ...in/masks.jl:438; vge
#   ╎    ╎    ╎    ╎    ╎    ╎ 1   ...n/masks.jl:427; vge
#   ╎    ╎    ╎    ╎    ╎    ╎  1   ...se_defs.jl:86; >=
#   ╎    ╎    ╎    ╎    ╎    ╎   1   .../masks.jl:403; vge
#  1╎    ╎    ╎    ╎    ╎    ╎    1   .../masks.jl:374; macro expansion
#   ╎    ╎    ╎    ╎    1   .../base_defs.jl:98; mul_fast
#   ╎    ╎    ╎    ╎     1   .../base_defs.jl:197; ifelse
#   ╎    ╎    ╎    ╎    ╎ 1   ...roll/fmap.jl:134; vifelse
#   ╎    ╎    ╎    ╎    ╎  1   ...roll/fmap.jl:18; fmap
#   ╎    ╎    ╎    ╎    ╎   1   ...roll/fmap.jl:18; macro expansion
#   ╎    ╎    ╎    ╎    ╎    1   ...in/masks.jl:455; vifelse
#  1╎    ╎    ╎    ╎    ╎     1   ...in/masks.jl:468; macro expansion
#   ╎    ╎    ╎    ╎    1   .../base_defs.jl:209; muladd
#   ╎    ╎    ╎    ╎     1   ...nroll/fmap.jl:126; vmuladd
#   ╎    ╎    ╎    ╎    ╎ 1   ...nroll/fmap.jl:18; fmap
#   ╎    ╎    ╎    ╎    ╎  1   ...roll/fmap.jl:18; macro expansion
#   ╎    ╎    ╎    ╎    ╎   1   ...in_funcs.jl:276; vmuladd
#   ╎    ╎    ╎    ╎    ╎    1   ...nary_ops.jl:25; vadd
#   ╎    ╎    ╎    ╎    ╎     1   ...nary_ops.jl:27; vadd_fast
#  1╎    ╎    ╎    ╎    ╎    ╎ 1   ...nary_ops.jl:27; macro expansion
#   ╎    ╎    ╎    ╎    12  ...trin_funcs.jl:291; vfmadd_fast
#   ╎    ╎    ╎    ╎     12  ...trin_funcs.jl:289; _vfmadd_fast
#   ╎    ╎    ╎    ╎    ╎ 12  ...base_defs.jl:267; vfma_fast
#   ╎    ╎    ╎    ╎    ╎  2   ...base_defs.jl:89; add_fast
#   ╎    ╎    ╎    ╎    ╎   2   ...roll/fmap.jl:62; vadd_fast
#   ╎    ╎    ╎    ╎    ╎    2   ...roll/fmap.jl:9; fmap
#   ╎    ╎    ╎    ╎    ╎     2   ...oll/fmap.jl:9; fmap
#   ╎    ╎    ╎    ╎    ╎    ╎ 2   ...oll/fmap.jl:9; fmap
#   ╎    ╎    ╎    ╎    ╎    ╎  2   ...ary_ops.jl:94; vadd_fast
#  2╎    ╎    ╎    ╎    ╎    ╎   2   ...ary_ops.jl:94; macro expansion
#   ╎    ╎    ╎    ╎    ╎  10  ...roll/fmap.jl:152; vifelse
#   ╎    ╎    ╎    ╎    ╎   10  ...roll/fmap.jl:18; fmap
#   ╎    ╎    ╎    ╎    ╎    10  ...oll/fmap.jl:18; macro expansion
#   ╎    ╎    ╎    ╎    ╎     10  ...in/masks.jl:455; vifelse
# 10╎    ╎    ╎    ╎    ╎    ╎ 10  ...n/masks.jl:468; macro expansion
#   ╎    ╎    ╎    ╎    1   ...emory_addr.jl:326; increment_ptr
#   ╎    ╎    ╎    ╎     1   ...emory_addr.jl:318; increment_ptr
#   ╎    ╎    ╎    ╎    ╎ 1   ...mory_addr.jl:299; _gep
#  1╎    ╎    ╎    ╎    ╎  1   ...mory_addr.jl:299; macro expansion
#   ╎    ╎    ╎    ╎    1   ...edpointers.jl:162; _vload
#   ╎    ╎    ╎    ╎     1   ...emory_addr.jl:628; __vload
#  1╎    ╎    ╎    ╎    ╎ 1   ...mory_addr.jl:628; macro expansion
#   ╎    ╎    ╎    ╎    2   ...edpointers.jl:187; _vload
#   ╎    ╎    ╎    ╎     2   ...emory_addr.jl:628; __vload
#  2╎    ╎    ╎    ╎    ╎ 2   ...mory_addr.jl:628; macro expansion
#  1╎    ╎    ╎    ╎   1   ...emory_addr.jl:0; macro expansion
#   ╎    ╎    ╎     5   ...inalg_direct.jl:480; _snparray_atx_tile!(c::V...
#   ╎    ╎    ╎    ╎ 5   ...nalg_direct.jl:725; _snparray_atx_additive_...
#   ╎    ╎    ╎    ╎  5   ...uct_loopset.jl:706; _turbo_!(::Val{(false,...
#   ╎    ╎    ╎    ╎   5   ...ct_loopset.jl:706; macro expansion
#   ╎    ╎    ╎    ╎    1   ...er_compute.jl:207; partialmap
#   ╎    ╎    ╎    ╎     1   ...er_compute.jl:0; macro expansion
#   ╎    ╎    ╎    ╎    ╎ 1   ...rin_funcs.jl:291; vfmadd_fast
#   ╎    ╎    ╎    ╎    ╎  1   ...rin_funcs.jl:289; _vfmadd_fast
#   ╎    ╎    ╎    ╎    ╎   1   ...in_funcs.jl:255; vfma_fast
#  1╎    ╎    ╎    ╎    ╎    1   ...in_funcs.jl:255; macro expansion
#   ╎    ╎    ╎    ╎    2   .../base_defs.jl:90; ==
#   ╎    ╎    ╎    ╎     2   ...nroll/fmap.jl:63; veq
#   ╎    ╎    ╎    ╎    ╎ 2   ...nroll/fmap.jl:10; fmap
#   ╎    ╎    ╎    ╎    ╎  1   ...rin/masks.jl:450; veq
#   ╎    ╎    ╎    ╎    ╎   1   ...in/masks.jl:390; veq
#  1╎    ╎    ╎    ╎    ╎    1   ...in/masks.jl:374; macro expansion
#   ╎    ╎    ╎    ╎    ╎  1   ...roll/fmap.jl:10; fmap
#   ╎    ╎    ╎    ╎    ╎   1   ...roll/fmap.jl:10; fmap
#   ╎    ╎    ╎    ╎    ╎    1   ...roll/fmap.jl:7; fmap
#   ╎    ╎    ╎    ╎    ╎     1   ...in/masks.jl:450; veq
#   ╎    ╎    ╎    ╎    ╎    ╎ 1   ...n/masks.jl:390; veq
#  1╎    ╎    ╎    ╎    ╎    ╎  1   ...n/masks.jl:374; macro expansion
#   ╎    ╎    ╎    ╎    1   .../base_defs.jl:90; >=
#   ╎    ╎    ╎    ╎     1   ...nroll/fmap.jl:63; vge
#   ╎    ╎    ╎    ╎    ╎ 1   ...nroll/fmap.jl:10; fmap
#   ╎    ╎    ╎    ╎    ╎  1   ...roll/fmap.jl:10; fmap
#   ╎    ╎    ╎    ╎    ╎   1   ...in/masks.jl:438; vge
#   ╎    ╎    ╎    ╎    ╎    1   ...in/masks.jl:427; vge
#   ╎    ╎    ╎    ╎    ╎     1   ...ase_defs.jl:86; >=
#   ╎    ╎    ╎    ╎    ╎    ╎ 1   ...n/masks.jl:403; vge
#  1╎    ╎    ╎    ╎    ╎    ╎  1   ...n/masks.jl:374; macro expansion
#   ╎    ╎    ╎    ╎    1   ...trin_funcs.jl:291; vfmadd_fast
#   ╎    ╎    ╎    ╎     1   ...trin_funcs.jl:289; _vfmadd_fast
#   ╎    ╎    ╎    ╎    ╎ 1   ...base_defs.jl:267; vfma_fast
#   ╎    ╎    ╎    ╎    ╎  1   ...roll/fmap.jl:152; vifelse
#   ╎    ╎    ╎    ╎    ╎   1   ...roll/fmap.jl:18; fmap
#   ╎    ╎    ╎    ╎    ╎    1   ...oll/fmap.jl:18; macro expansion
#   ╎    ╎    ╎    ╎    ╎     1   ...in/masks.jl:455; vifelse
#  1╎    ╎    ╎    ╎    ╎    ╎ 1   ...n/masks.jl:468; macro expansion
#   ╎84  ...hreadingconstructs.jl:48; (::MendelIHT.var"#42#threadsfor_f...
#   ╎ 84  ...hreadingconstructs.jl:81; (::MendelIHT.var"#42#threadsfor_f...
#  1╎  73  ...IHT/src/utilities.jl:701; macro expansion
#   ╎   1   @Base/subarray.jl:176; view
#   ╎    1   @Base/tuple.jl:214; map
#   ╎     1   @Base/subarray.jl:176; #141
#   ╎    ╎ 1   ...e/abstractarray.jl:1349; unalias
#   ╎    ╎  1   .../abstractarray.jl:1384; mightalias
#   ╎    ╎   1   .../abstractarray.jl:1407; dataids
#  1╎    ╎    1   @Base/reflection.jl:291; objectid
#   ╎   19  @Base/subarray.jl:178; view
#   ╎    19  @Base/subarray.jl:209; unsafe_view
#   ╎     19  @Base/subarray.jl:28; SubArray
#   ╎    ╎ 19  ...ultidimensional.jl:790; ensure_indexable
#   ╎    ╎  19  ...ultidimensional.jl:733; collect
#  6╎    ╎   6   @Base/array.jl:0; collect(itr::Base.Generator{...
#   ╎    ╎   13  @Base/array.jl:683; collect(itr::Base.Generator{...
#   ╎    ╎    13  @Base/array.jl:702; collect_to_with_first!
#   ╎    ╎     2   @Base/array.jl:724; collect_to!(dest::Vector{In...
#   ╎    ╎    ╎ 2   @Base/generator.jl:44; iterate
#   ╎    ╎    ╎  1   ...tidimensional.jl:772; iterate
#   ╎    ╎    ╎   1   @Base/int.jl:446; ==
#  1╎    ╎    ╎    1   @Base/promotion.jl:410; ==
#   ╎    ╎    ╎  1   ...tidimensional.jl:778; iterate
#   ╎    ╎    ╎   1   @Base/bitarray.jl:121; _blsr
#  1╎    ╎    ╎    1   @Base/int.jl:309; &
#   ╎    ╎     8   @Base/array.jl:728; collect_to!(dest::Vector{In...
#  8╎    ╎    ╎ 8   @Base/array.jl:839; setindex!
#   ╎    ╎     3   @Base/array.jl:729; collect_to!(dest::Vector{In...
#  3╎    ╎    ╎ 3   @Base/int.jl:87; +
#   ╎   52  ...rc/linalg_direct.jl:867; copyto!(v::Vector{Float64}, s::...
#   ╎    50  @Base/simdloop.jl:77; macro expansion
#   ╎     50  ...rc/linalg_direct.jl:868; macro expansion
#   ╎    ╎ 50  ...e/abstractarray.jl:1170; getindex
#   ╎    ╎  50  .../abstractarray.jl:1209; _getindex
#   ╎    ╎   50  @Base/subarray.jl:276; getindex
# 12╎    ╎    12  .../linalg_direct.jl:0; getindex
#   ╎    ╎    19  .../linalg_direct.jl:62; getindex
#  4╎    ╎     4   ...s/src/snparray.jl:0; convert
#  4╎    ╎     5   ...s/src/snparray.jl:291; convert
#   ╎    ╎    ╎ 1   @Base/int.jl:923; -
#  1╎    ╎    ╎  1   @Base/int.jl:86; -
#   ╎    ╎     1   ...s/src/snparray.jl:116; getindex
#   ╎    ╎    ╎ 1   ...abstractarray.jl:616; checkbounds
#   ╎    ╎    ╎  1   ...abstractarray.jl:595; checkbounds
#   ╎    ╎    ╎   1   ...bstractarray.jl:642; checkbounds_indices
#   ╎    ╎    ╎    1   ...bstractarray.jl:673; checkindex
#  1╎    ╎    ╎     1   @Base/int.jl:442; <=
#   ╎    ╎     9   ...s/src/snparray.jl:118; getindex
#  7╎    ╎    ╎ 7   @Base/array.jl:802; getindex
#  1╎    ╎    ╎ 1   @Base/int.jl:309; &
#   ╎    ╎    ╎ 1   @Base/int.jl:462; >>
#  1╎    ╎    ╎  1   @Base/int.jl:456; >>
#  2╎    ╎    9   .../linalg_direct.jl:64; getindex
#  6╎    ╎     6   @Base/array.jl:801; getindex
#  1╎    ╎     1   @Base/float.jl:329; -
#   ╎    ╎    10  .../linalg_direct.jl:65; getindex
#  2╎    ╎     2   @Base/array.jl:801; getindex
#  8╎    ╎     8   @Base/float.jl:332; *
#   ╎    2   @Base/simdloop.jl:78; macro expansion
#  2╎     2   @Base/int.jl:87; +
#   ╎  11  ...IHT/src/utilities.jl:702; macro expansion
#  1╎   1   ...HT/src/utilities.jl:717; linreg!(x::Vector{Float64}, y::...
#   ╎   2   ...HT/src/utilities.jl:727; linreg!(x::Vector{Float64}, y::...
#   ╎    2   @Base/reducedim.jl:874; sum
#   ╎     2   @Base/reducedim.jl:874; #sum#680
#   ╎    ╎ 2   @Base/reducedim.jl:878; _sum
#   ╎    ╎  2   @Base/reducedim.jl:878; #_sum#682
#   ╎    ╎   2   @Base/reducedim.jl:310; mapreduce
#   ╎    ╎    2   @Base/reducedim.jl:310; #mapreduce#672
#   ╎    ╎     2   @Base/reducedim.jl:318; _mapreduce_dim
#   ╎    ╎    ╎ 2   @Base/reduce.jl:415; _mapreduce(f::typeof(abs2)...
#   ╎    ╎    ╎  2   @Base/reduce.jl:257; mapreduce_impl
#   ╎    ╎    ╎   2   @Base/reduce.jl:243; mapreduce_impl(f::typeof(...
#   ╎    ╎    ╎    1   @Base/simdloop.jl:77; macro expansion
#   ╎    ╎    ╎     1   @Base/reduce.jl:244; macro expansion
#  1╎    ╎    ╎    ╎ 1   @Base/array.jl:801; getindex
#   ╎    ╎    ╎    1   @Base/simdloop.jl:78; macro expansion
#  1╎    ╎    ╎     1   @Base/int.jl:87; +
#   ╎   8   ...HT/src/utilities.jl:731; linreg!(x::Vector{Float64}, y::...
#   ╎    8   ...bra/src/cholesky.jl:252; cholesky!
#  1╎     8   ...bra/src/cholesky.jl:252; cholesky!
#  7╎    ╎ 7   ...ra/src/cholesky.jl:252; cholesky!(A::Symmetric{Float6...
# Total snapshots: 162

# %% [markdown]
# **Conclusion:**
# + `init_beta` took 4/43 samples (line 96 of `fit.jl`).
# + `score!` took 33/43 samples (line 247 of `fit.jl` which is the `score!` function, specifically on the line `mul!(v.df, Transpose(x), v.r)` (i.e. computing the gradient which requires full genotype matrix times dense vector). This is expected.

# %% [markdown]
# ## Multivariate response with SnpLinAlg (2 traits)

# %%
n = 1000  # number of samples
p = 10000 # number of SNPs
k = 10    # number of causal SNPs per trait
r = 2     # number of traits

# set random seed for reproducibility
Random.seed!(2021)

# simulate `.bed` file with no missing data
x = simulate_random_snparray(undef, n, p)
xla = SnpLinAlg{Float64}(x, model=ADDITIVE_MODEL, center=true, scale=true) 

# intercept is the only nongenetic covariate
z = ones(n, 1)
intercepts = randn(r)' # each trait have different intercept

# simulate response y, true model b, and the correct non-0 positions of b
Y, true_Σ, true_b, correct_position = simulate_random_response(xla, k, r, Zu=z*intercepts, overlap=2);

# %%
Random.seed!(2020)
Yt = Matrix(Y')
Zt = Matrix(z')
@time result = fit_iht(Yt, Transpose(xla), Zt, init_beta=true);
speed_per_iter = result.time / result.iter
# Out:
# ****                   MendelIHT Version 1.4.1                  ****
# ****     Benjamin Chu, Kevin Keys, Chris German, Hua Zhou       ****
# ****   Jin Zhou, Eric Sobel, Janet Sinsheimer, Kenneth Lange    ****
# ****                                                            ****
# ****                 Please cite our paper!                     ****
# ****         https://doi.org/10.1093/gigascience/giaa044        ****
#
# Initializing β to univariate regression values...
# ...completed in 0.3 seconds.
#
# Running sparse Multivariate Gaussian regression
# Number of threads = 1
# Link functin = IdentityLink()
# Sparsity parameter (k) = 10
# Prior weight scaling = off
# Doubly sparse projection = off
# Debias = off
# Max IHT iterations = 200
# Converging when tol < 0.0001 and iteration ≥ 5:
#
# Iteration 1: loglikelihood = -201.6215159825589, backtracks = 0, tol = 0.0
# Iteration 2: loglikelihood = 333.5651708910011, backtracks = 0, tol = 0.11348309227050864
# Iteration 3: loglikelihood = 372.19186911431996, backtracks = 0, tol = 0.018816055534363305
# Iteration 4: loglikelihood = 373.8698763400464, backtracks = 0, tol = 0.005456081342282623
# Iteration 5: loglikelihood = 373.9989690138535, backtracks = 0, tol = 0.0015532140583266918
# Iteration 6: loglikelihood = 374.0076615926413, backtracks = 0, tol = 0.000374737041695183
# Iteration 7: loglikelihood = 374.0082450800875, backtracks = 0, tol = 8.767730811229542e-5
#   0.359678 seconds (61.51 k allocations: 158.448 MiB, 16.78% gc time)
# 0.010966845921107702

# %% [markdown]
# Multivariate IHT runs at 0.01 seconds per iteration with 2 traits. Let's profile our fit function.

# %%
fit_iht(Yt, Transpose(xla), Zt, init_beta=true, verbose=false)
Profile.clear()
@profile fit_iht(Yt, Transpose(xla), Zt, init_beta=true, verbose=false);
Profile.print()
# Out:
# Overhead ╎ [+additional indent] Count File:Line; Function
# =========================================================
#   ╎73  @Base/task.jl:406; (::IJulia.var"#15#18")()
#   ╎ 73  @IJulia/src/eventloop.jl:8; eventloop(socket::ZMQ.Socket)
#   ╎  73  @Base/essentials.jl:706; invokelatest
#   ╎   73  @Base/essentials.jl:708; #invokelatest#2
#   ╎    73  .../execute_request.jl:67; execute_request(socket::ZMQ.Soc...
#   ╎     73  .../SoftGlobalScope.jl:65; softscope_include_string(m::Mo...
#   ╎    ╎ 73  @Base/loading.jl:1094; include_string(mapexpr::type...
#   ╎    ╎  73  @Base/boot.jl:360; eval
#   ╎    ╎   73  @MendelIHT/src/fit.jl:72; (::MendelIHT.var"#fit_iht##k...
#   ╎    ╎    9   ...delIHT/src/fit.jl:96; fit_iht(y::Matrix{Float64},...
#   ╎    ╎     9   @Base/timing.jl:287; macro expansion
#   ╎    ╎    ╎ 9   ...ta_structures.jl:116; initialize
#   ╎    ╎    ╎  9   ...ta_structures.jl:123; #initialize#1
#   ╎    ╎    ╎   9   ...multivariate.jl:393; init_iht_indices!(v::Mend...
#   ╎    ╎    ╎    9   ...multivariate.jl:62; score!(v::MendelIHT.mIHTV...
#   ╎    ╎    ╎     9   ...multivariate.jl:84; update_df!(v::MendelIHT....
#   ╎    ╎    ╎    ╎ 9   ...nalg_direct.jl:177; mul!(out::Matrix{Float6...
#   ╎    ╎    ╎    ╎  7   ...nalg_direct.jl:615; _snparray_AtX_tile!(C:...
#   ╎    ╎    ╎    ╎   7   ...alg_direct.jl:831; _snparray_AtX_additive...
#   ╎    ╎    ╎    ╎    7   ...ct_loopset.jl:706; _turbo_!(::Val{(false...
#   ╎    ╎    ╎    ╎     7   ...ct_loopset.jl:706; macro expansion
#   ╎    ╎    ╎    ╎    ╎ 2   ...ng/graphs.jl:202; cmpend
#  2╎    ╎    ╎    ╎    ╎  2   @Base/int.jl:442; <=
#   ╎    ╎    ╎    ╎    ╎ 2   ...base_defs.jl:86; mul_fast
#   ╎    ╎    ╎    ╎    ╎  2   ...inary_ops.jl:94; vmul_fast
#  2╎    ╎    ╎    ╎    ╎   2   ...inary_ops.jl:94; macro expansion
#   ╎    ╎    ╎    ╎    ╎ 1   ...base_defs.jl:86; sub_fast
#   ╎    ╎    ╎    ╎    ╎  1   ...inary_ops.jl:94; vsub_fast
#  1╎    ╎    ╎    ╎    ╎   1   ...inary_ops.jl:94; macro expansion
#   ╎    ╎    ╎    ╎    ╎ 1   ...broadcast.jl:81; vbroadcast
#   ╎    ╎    ╎    ╎    ╎  1   ...broadcast.jl:44; _vbroadcast
#  1╎    ╎    ╎    ╎    ╎   1   ...broadcast.jl:76; macro expansion
#   ╎    ╎    ╎    ╎    ╎ 1   ...dpointers.jl:162; _vload
#   ╎    ╎    ╎    ╎    ╎  1   ...mory_addr.jl:628; __vload
#  1╎    ╎    ╎    ╎    ╎   1   ...ory_addr.jl:628; macro expansion
#   ╎    ╎    ╎    ╎  2   ...nalg_direct.jl:627; _snparray_AtX_tile!(C:...
#   ╎    ╎    ╎    ╎   2   ...alg_direct.jl:831; _snparray_AtX_additive...
#   ╎    ╎    ╎    ╎    2   ...ct_loopset.jl:706; _turbo_!(::Val{(false...
#   ╎    ╎    ╎    ╎     2   ...ct_loopset.jl:706; macro expansion
#   ╎    ╎    ╎    ╎    ╎ 1   .../base_defs.jl:86; mul_fast
#   ╎    ╎    ╎    ╎    ╎  1   ...inary_ops.jl:94; vmul_fast
#  1╎    ╎    ╎    ╎    ╎   1   ...inary_ops.jl:94; macro expansion
#   ╎    ╎    ╎    ╎    ╎ 1   ...vbroadcast.jl:81; vbroadcast
#   ╎    ╎    ╎    ╎    ╎  1   ...broadcast.jl:44; _vbroadcast
#  1╎    ╎    ╎    ╎    ╎   1   ...broadcast.jl:76; macro expansion
#   ╎    ╎    64  ...delIHT/src/fit.jl:102; fit_iht(y::Matrix{Float64},...
#   ╎    ╎     64  ...delIHT/src/fit.jl:148; fit_iht!##kw
#   ╎    ╎    ╎ 63  ...elIHT/src/fit.jl:176; fit_iht!(v::MendelIHT.mIHT...
#   ╎    ╎    ╎  2   ...elIHT/src/fit.jl:214; iht_one_step!(v::MendelIH...
#   ╎    ╎    ╎   2   ...multivariate.jl:104; _iht_gradstep!
#   ╎    ╎    ╎    2   ...multivariate.jl:112; project_k!(v::MendelIHT....
#   ╎    ╎    ╎     1   ...rc/utilities.jl:480; project_k!
#   ╎    ╎    ╎    ╎ 1   @Base/sort.jl:165; partialsort##kw
#   ╎    ╎    ╎    ╎  1   @Base/sort.jl:165; partialsort(v::Vector{...
#   ╎    ╎    ╎    ╎   1   @Base/sort.jl:156; partialsort!##kw
#   ╎    ╎    ╎    ╎    1   @Base/sort.jl:156; #partialsort!#2
#   ╎    ╎    ╎    ╎     1   @Base/sort.jl:97; partialsort!
#   ╎    ╎    ╎    ╎    ╎ 1   @Base/sort.jl:657; sort!(v::Vector{Floa...
#   ╎    ╎    ╎    ╎    ╎  1   @Base/sort.jl:585; partition!(v::Vecto...
#   ╎    ╎    ╎    ╎    ╎   1   ...ordering.jl:111; lt
#   ╎    ╎    ╎    ╎    ╎    1   ...ordering.jl:110; lt
#   ╎    ╎    ╎    ╎    ╎     1   ...ordering.jl:109; lt
#  1╎    ╎    ╎    ╎    ╎    ╎ 1   ...e/float.jl:381; isless
#   ╎    ╎    ╎     1   ...rc/utilities.jl:482; project_k!
#  1╎    ╎    ╎    ╎ 1   @Base/float.jl:371; <
#   ╎    ╎    ╎  61  ...elIHT/src/fit.jl:247; iht_one_step!(v::MendelIH...
#   ╎    ╎    ╎   61  .../multivariate.jl:62; score!(v::MendelIHT.mIHTV...
#   ╎    ╎    ╎    61  ...multivariate.jl:84; update_df!(v::MendelIHT.m...
#   ╎    ╎    ╎     61  ...inalg_direct.jl:177; mul!(out::Matrix{Float64...
#   ╎    ╎    ╎    ╎ 50  ...nalg_direct.jl:615; _snparray_AtX_tile!(C::...
#   ╎    ╎    ╎    ╎  50  ...nalg_direct.jl:831; _snparray_AtX_additive...
#   ╎    ╎    ╎    ╎   50  ...ct_loopset.jl:706; _turbo_!(::Val{(false,...
#   ╎    ╎    ╎    ╎    50  ...ct_loopset.jl:706; macro expansion
#   ╎    ╎    ╎    ╎     5   ...ing/graphs.jl:202; cmpend
#  5╎    ╎    ╎    ╎    ╎ 5   @Base/int.jl:442; <=
#   ╎    ╎    ╎    ╎     1   .../base_defs.jl:88; ==
#   ╎    ╎    ╎    ╎    ╎ 1   ...rin/masks.jl:450; veq
#   ╎    ╎    ╎    ╎    ╎  1   ...rin/masks.jl:390; veq
#  1╎    ╎    ╎    ╎    ╎   1   ...in/masks.jl:374; macro expansion
#   ╎    ╎    ╎    ╎     2   .../base_defs.jl:286; add_fast
#   ╎    ╎    ╎    ╎    ╎ 2   ...rin/masks.jl:145; vadd_fast
#  2╎    ╎    ╎    ╎    ╎  2   ...rin/masks.jl:145; macro expansion
#   ╎    ╎    ╎    ╎     7   .../base_defs.jl:86; mul_fast
#   ╎    ╎    ╎    ╎    ╎ 7   ...binary_ops.jl:94; vmul_fast
#  7╎    ╎    ╎    ╎    ╎  7   ...inary_ops.jl:94; macro expansion
#   ╎    ╎    ╎    ╎     8   .../base_defs.jl:86; sub_fast
#   ╎    ╎    ╎    ╎    ╎ 4   ...promotion.jl:292; promote
#   ╎    ╎    ╎    ╎    ╎  4   ...promotion.jl:269; _promote
#   ╎    ╎    ╎    ╎    ╎   4   ...ase_defs.jl:152; convert
#   ╎    ╎    ╎    ╎    ╎    4   ...nversion.jl:29; vconvert
#  4╎    ╎    ╎    ╎    ╎     4   ...nversion.jl:12; macro expansion
#   ╎    ╎    ╎    ╎    ╎ 4   ...inary_ops.jl:94; vsub_fast
#  4╎    ╎    ╎    ╎    ╎  4   ...inary_ops.jl:94; macro expansion
#   ╎    ╎    ╎    ╎     5   ...trin_funcs.jl:291; vfmadd_fast
#   ╎    ╎    ╎    ╎    ╎ 5   ...rin_funcs.jl:289; _vfmadd_fast
#   ╎    ╎    ╎    ╎    ╎  5   ...base_defs.jl:269; vfma_fast
#   ╎    ╎    ╎    ╎    ╎   2   ...ase_defs.jl:86; add_fast
#   ╎    ╎    ╎    ╎    ╎    2   ...nary_ops.jl:94; vadd_fast
#  2╎    ╎    ╎    ╎    ╎     2   ...nary_ops.jl:94; macro expansion
#   ╎    ╎    ╎    ╎    ╎   3   ...in/masks.jl:455; vifelse
#  3╎    ╎    ╎    ╎    ╎    3   ...in/masks.jl:468; macro expansion
#   ╎    ╎    ╎    ╎     7   ...vbroadcast.jl:81; vbroadcast
#   ╎    ╎    ╎    ╎    ╎ 7   ...vbroadcast.jl:44; _vbroadcast
#  7╎    ╎    ╎    ╎    ╎  7   ...broadcast.jl:76; macro expansion
#   ╎    ╎    ╎    ╎     1   ...edpointers.jl:161; _vload
#   ╎    ╎    ╎    ╎    ╎ 1   ...dpointers.jl:157; linear_index
#   ╎    ╎    ╎    ╎    ╎  1   ...multiples.jl:101; tdot
#   ╎    ╎    ╎    ╎    ╎   1   ..._indexing.jl:21; tdot
#   ╎    ╎    ╎    ╎    ╎    1   .../lazymul.jl:105; add_indices
#   ╎    ╎    ╎    ╎    ╎     1   ...nary_ops.jl:123; vadd_nsw
#   ╎    ╎    ╎    ╎    ╎    ╎ 1   ...omotion.jl:292; promote
#   ╎    ╎    ╎    ╎    ╎    ╎  1   ...omotion.jl:269; _promote
#   ╎    ╎    ╎    ╎    ╎    ╎   1   ...e_defs.jl:150; convert
#   ╎    ╎    ╎    ╎    ╎    ╎    1   ...ersion.jl:73; vconvert
#   ╎    ╎    ╎    ╎    ╎    ╎     1   ...adcast.jl:44; _vbroadcast
#  1╎    ╎    ╎    ╎    ╎    ╎    ╎ 1   ...adcast.jl:76; macro expansion
#   ╎    ╎    ╎    ╎     14  ...edpointers.jl:162; _vload
#   ╎    ╎    ╎    ╎    ╎ 14  ...mory_addr.jl:628; __vload
# 14╎    ╎    ╎    ╎    ╎  14  ...mory_addr.jl:628; macro expansion
#   ╎    ╎    ╎    ╎ 11  ...nalg_direct.jl:627; _snparray_AtX_tile!(C::...
#   ╎    ╎    ╎    ╎  11  ...nalg_direct.jl:831; _snparray_AtX_additive...
#   ╎    ╎    ╎    ╎   11  ...ct_loopset.jl:706; _turbo_!(::Val{(false,...
#   ╎    ╎    ╎    ╎    11  ...ct_loopset.jl:706; macro expansion
#   ╎    ╎    ╎    ╎     5   .../base_defs.jl:86; mul_fast
#   ╎    ╎    ╎    ╎    ╎ 5   ...binary_ops.jl:94; vmul_fast
#  5╎    ╎    ╎    ╎    ╎  5   ...inary_ops.jl:94; macro expansion
#   ╎    ╎    ╎    ╎     3   .../base_defs.jl:86; sub_fast
#   ╎    ╎    ╎    ╎    ╎ 3   ...promotion.jl:292; promote
#   ╎    ╎    ╎    ╎    ╎  3   ...promotion.jl:269; _promote
#   ╎    ╎    ╎    ╎    ╎   3   ...ase_defs.jl:152; convert
#   ╎    ╎    ╎    ╎    ╎    3   ...nversion.jl:29; vconvert
#  3╎    ╎    ╎    ╎    ╎     3   ...nversion.jl:12; macro expansion
#   ╎    ╎    ╎    ╎     1   ...trin_funcs.jl:291; vfmadd_fast
#   ╎    ╎    ╎    ╎    ╎ 1   ...rin_funcs.jl:289; _vfmadd_fast
#   ╎    ╎    ╎    ╎    ╎  1   ...base_defs.jl:269; vfma_fast
#   ╎    ╎    ╎    ╎    ╎   1   ...in/masks.jl:455; vifelse
#  1╎    ╎    ╎    ╎    ╎    1   ...in/masks.jl:468; macro expansion
#   ╎    ╎    ╎    ╎     1   ...vbroadcast.jl:81; vbroadcast
#   ╎    ╎    ╎    ╎    ╎ 1   ...vbroadcast.jl:44; _vbroadcast
#  1╎    ╎    ╎    ╎    ╎  1   ...broadcast.jl:76; macro expansion
#   ╎    ╎    ╎    ╎     1   ...edpointers.jl:162; _vload
#   ╎    ╎    ╎    ╎    ╎ 1   ...mory_addr.jl:628; __vload
#  1╎    ╎    ╎    ╎    ╎  1   ...mory_addr.jl:628; macro expansion
#   ╎    ╎    ╎ 1   ...elIHT/src/fit.jl:184; fit_iht!(v::MendelIHT.mIHT...
#   ╎    ╎    ╎  1   .../multivariate.jl:415; check_convergence(v::Mend...
#   ╎    ╎    ╎   1   .../src/generic.jl:631; norm(itr::Matrix{Float64}...
#   ╎    ╎    ╎    1   .../src/generic.jl:556; normInf
#  1╎    ╎    ╎     1   .../src/generic.jl:472; generic_normInf
#   ╎129 ...hreadingconstructs.jl:48; (::MendelIHT.var"#165#threadsfor_...
#   ╎ 129 ...hreadingconstructs.jl:81; (::MendelIHT.var"#165#threadsfor_...
#   ╎  122 .../src/multivariate.jl:490; macro expansion
#   ╎   3   @Base/abstractarray.jl:949; copyto!
#   ╎    3   @Base/abstractarray.jl:1349; unalias
#   ╎     3   ...e/abstractarray.jl:1384; mightalias(A::Vector{Float64}...
#   ╎    ╎ 3   @Base/subarray.jl:102; dataids
#   ╎    ╎  3   ...ra/src/adjtrans.jl:98; dataids
#   ╎    ╎   3   .../abstractarray.jl:1407; dataids
#  3╎    ╎    3   @Base/reflection.jl:291; objectid
#   ╎   85  @Base/abstractarray.jl:950; copyto!
#   ╎    85  @Base/abstractarray.jl:976; copyto_unaliased!(deststyle::I...
#  5╎     5   ...e/abstractarray.jl:0; iterate
#   ╎     77  ...e/abstractarray.jl:1096; iterate
#   ╎    ╎ 77  @Base/subarray.jl:276; getindex
#   ╎    ╎  77  ...ra/src/adjtrans.jl:203; getindex
#  1╎    ╎   1   ...e/abstractarray.jl:0; getindex
# 15╎    ╎   15  ...c/linalg_direct.jl:0; getindex
#   ╎    ╎   39  ...c/linalg_direct.jl:62; getindex
# 10╎    ╎    21  ...s/src/snparray.jl:291; convert
#  1╎    ╎     1   @Base/float.jl:94; Float64
#   ╎    ╎     10  @Base/int.jl:923; -
# 10╎    ╎    ╎ 10  @Base/int.jl:86; -
#   ╎    ╎    3   ...s/src/snparray.jl:116; getindex
#   ╎    ╎     3   .../abstractarray.jl:616; checkbounds
#   ╎    ╎    ╎ 3   ...abstractarray.jl:595; checkbounds
#   ╎    ╎    ╎  3   ...abstractarray.jl:642; checkbounds_indices
#   ╎    ╎    ╎   3   ...bstractarray.jl:673; checkindex
#  3╎    ╎    ╎    3   @Base/int.jl:442; <=
#   ╎    ╎    15  ...s/src/snparray.jl:118; getindex
#  4╎    ╎     4   @Base/array.jl:802; getindex
#   ╎    ╎     11  @Base/int.jl:462; >>
#  5╎    ╎    ╎ 5   @Base/int.jl:455; >>
#  5╎    ╎    ╎ 6   @Base/int.jl:456; >>
#  3╎    ╎   5   ...c/linalg_direct.jl:64; getindex
#  2╎    ╎    2   @Base/array.jl:801; getindex
#   ╎    ╎   17  ...c/linalg_direct.jl:65; getindex
#  5╎    ╎    5   @Base/array.jl:801; getindex
# 12╎    ╎    12  @Base/float.jl:332; *
#  3╎     3   @Base/int.jl:87; +
#   ╎   8   @Base/subarray.jl:176; view
#   ╎    2   @Base/indices.jl:324; to_indices
#   ╎     2   @Base/indices.jl:333; to_indices
#   ╎    ╎ 2   ...ultidimensional.jl:810; to_indices
#   ╎    ╎  2   ...ultidimensional.jl:812; _maybe_linear_logical_index
#   ╎    ╎   2   @Base/indices.jl:277; to_index
#   ╎    ╎    2   @Base/indices.jl:294; to_index
#   ╎    ╎     2   ...ltidimensional.jl:728; LogicalIndex
#   ╎    ╎    ╎ 2   ...tidimensional.jl:726; LogicalIndex
#   ╎    ╎    ╎  2   @Base/reducedim.jl:392; count
#   ╎    ╎    ╎   2   @Base/reducedim.jl:392; #count#675
#   ╎    ╎    ╎    2   @Base/reducedim.jl:393; count##kw
#   ╎    ╎    ╎     2   @Base/reducedim.jl:393; #count#676
#   ╎    ╎    ╎    ╎ 2   @Base/bitarray.jl:1397; _count
#   ╎    ╎    ╎    ╎  2   ...e/bitarray.jl:1390; bitcount##kw
#  2╎    ╎    ╎    ╎   2   ...e/bitarray.jl:1392; #bitcount#251
#   ╎    6   @Base/tuple.jl:214; map
#   ╎     6   @Base/subarray.jl:176; #141
#   ╎    ╎ 6   ...e/abstractarray.jl:1349; unalias
#   ╎    ╎  6   .../abstractarray.jl:1384; mightalias
#   ╎    ╎   6   ...ra/src/adjtrans.jl:98; dataids
#   ╎    ╎    6   .../abstractarray.jl:1407; dataids
#  6╎    ╎     6   @Base/reflection.jl:291; objectid
#   ╎   26  @Base/subarray.jl:178; view
#   ╎    26  @Base/subarray.jl:209; unsafe_view
#   ╎     26  @Base/subarray.jl:28; SubArray
#   ╎    ╎ 26  ...ultidimensional.jl:789; ensure_indexable
#   ╎    ╎  26  ...ultidimensional.jl:790; ensure_indexable
#   ╎    ╎   26  ...ltidimensional.jl:733; collect
# 11╎    ╎    11  @Base/array.jl:0; collect(itr::Base.Generator...
#  1╎    ╎    15  @Base/array.jl:683; collect(itr::Base.Generator...
#   ╎    ╎     14  @Base/array.jl:702; collect_to_with_first!
#   ╎    ╎    ╎ 8   @Base/array.jl:724; collect_to!(dest::Vector{I...
#   ╎    ╎    ╎  8   @Base/generator.jl:44; iterate
#   ╎    ╎    ╎   3   ...idimensional.jl:772; iterate
#   ╎    ╎    ╎    3   @Base/int.jl:446; ==
#  3╎    ╎    ╎     3   @Base/promotion.jl:410; ==
#   ╎    ╎    ╎   1   ...idimensional.jl:778; iterate
#   ╎    ╎    ╎    1   @Base/bitarray.jl:121; _blsr
#  1╎    ╎    ╎     1   @Base/int.jl:309; &
#   ╎    ╎    ╎   4   ...idimensional.jl:779; iterate
#  3╎    ╎    ╎    3   @Base/int.jl:87; +
#   ╎    ╎    ╎    1   @Base/int.jl:464; <<
#  1╎    ╎    ╎     1   @Base/int.jl:457; <<
#   ╎    ╎    ╎ 2   @Base/array.jl:728; collect_to!(dest::Vector{I...
#  2╎    ╎    ╎  2   @Base/array.jl:839; setindex!
#   ╎    ╎    ╎ 4   @Base/array.jl:729; collect_to!(dest::Vector{I...
#  4╎    ╎    ╎  4   @Base/int.jl:87; +
#   ╎  7   .../src/multivariate.jl:491; macro expansion
#   ╎   1   ...HT/src/utilities.jl:726; linreg!(x::Vector{Float64}, y::...
#   ╎    1   @Base/reducedim.jl:873; sum
#   ╎     1   @Base/reducedim.jl:873; #sum#679
#   ╎    ╎ 1   @Base/reducedim.jl:877; _sum
#   ╎    ╎  1   @Base/reducedim.jl:877; #_sum#681
#   ╎    ╎   1   @Base/reducedim.jl:878; _sum
#   ╎    ╎    1   @Base/reducedim.jl:878; #_sum#682
#   ╎    ╎     1   @Base/reducedim.jl:310; mapreduce
#   ╎    ╎    ╎ 1   @Base/reducedim.jl:310; #mapreduce#672
#   ╎    ╎    ╎  1   @Base/reducedim.jl:318; _mapreduce_dim
#   ╎    ╎    ╎   1   @Base/reduce.jl:415; _mapreduce
#   ╎    ╎    ╎    1   @Base/reduce.jl:257; mapreduce_impl
#   ╎    ╎    ╎     1   @Base/reduce.jl:243; mapreduce_impl(f::typeof...
#   ╎    ╎    ╎    ╎ 1   @Base/simdloop.jl:78; macro expansion
#  1╎    ╎    ╎    ╎  1   @Base/int.jl:87; +
#   ╎   2   ...HT/src/utilities.jl:727; linreg!(x::Vector{Float64}, y::...
#   ╎    2   @Base/reducedim.jl:874; sum
#   ╎     2   @Base/reducedim.jl:874; #sum#680
#   ╎    ╎ 2   @Base/reducedim.jl:878; _sum
#   ╎    ╎  2   @Base/reducedim.jl:878; #_sum#682
#   ╎    ╎   2   @Base/reducedim.jl:310; mapreduce
#   ╎    ╎    2   @Base/reducedim.jl:310; #mapreduce#672
#   ╎    ╎     2   @Base/reducedim.jl:318; _mapreduce_dim
#   ╎    ╎    ╎ 2   @Base/reduce.jl:415; _mapreduce(f::typeof(abs2)...
#   ╎    ╎    ╎  2   @Base/reduce.jl:257; mapreduce_impl
#   ╎    ╎    ╎   2   @Base/reduce.jl:243; mapreduce_impl(f::typeof(...
#   ╎    ╎    ╎    1   @Base/simdloop.jl:69; macro expansion
#   ╎    ╎    ╎     1   @Base/range.jl:5; Colon
#   ╎    ╎    ╎    ╎ 1   @Base/range.jl:287; UnitRange
#  1╎    ╎    ╎    ╎  1   @Base/range.jl:292; unitrange_last
#   ╎    ╎    ╎    1   @Base/simdloop.jl:78; macro expansion
#  1╎    ╎    ╎     1   @Base/int.jl:87; +
#   ╎   1   ...HT/src/utilities.jl:728; linreg!(x::Vector{Float64}, y::...
#   ╎    1   @Base/reducedim.jl:873; sum
#   ╎     1   @Base/reducedim.jl:873; #sum#679
#   ╎    ╎ 1   @Base/reducedim.jl:877; _sum
#   ╎    ╎  1   @Base/reducedim.jl:877; #_sum#681
#   ╎    ╎   1   @Base/reducedim.jl:878; _sum
#   ╎    ╎    1   @Base/reducedim.jl:878; #_sum#682
#   ╎    ╎     1   @Base/reducedim.jl:310; mapreduce
#   ╎    ╎    ╎ 1   @Base/reducedim.jl:310; #mapreduce#672
#   ╎    ╎    ╎  1   @Base/reducedim.jl:318; _mapreduce_dim
#   ╎    ╎    ╎   1   @Base/reduce.jl:415; _mapreduce
#   ╎    ╎    ╎    1   @Base/reduce.jl:257; mapreduce_impl
#   ╎    ╎    ╎     1   @Base/reduce.jl:243; mapreduce_impl(f::typeof...
#   ╎    ╎    ╎    ╎ 1   @Base/simdloop.jl:78; macro expansion
#  1╎    ╎    ╎    ╎  1   @Base/int.jl:87; +
#   ╎   3   ...HT/src/utilities.jl:731; linreg!(x::Vector{Float64}, y::...
#   ╎    3   ...bra/src/cholesky.jl:252; cholesky!
#   ╎     3   ...bra/src/cholesky.jl:252; cholesky!
#  3╎    ╎ 3   ...ra/src/cholesky.jl:252; cholesky!(A::Symmetric{Float6...
# Total snapshots: 209

# %% [markdown]
# **Conclusion**:
# + `score!` consumes 61/73 samples on `fit_iht!`, specifically, the line `SnpArrays.mul!(v.p_by_r, v.X, v.n_by_r)` which compute `SnpLinAlg`-matrix multiplication. This is expected.
# + `init_beta` consumes 9/73 samples from `fit_iht`, which is ok.
# + `iht_stepsize!` (which inverts the covariance matrix) is not even sampled at all.

# %% [markdown]
# ## Multivariate response with SnpLinAlg (2 traits)

# %%
n = 1000  # number of samples
p = 10000 # number of SNPs
k = 10    # number of causal SNPs per trait
r = 10    # number of traits

# set random seed for reproducibility
Random.seed!(2021)

# simulate `.bed` file with no missing data
x = simulate_random_snparray(undef, n, p)
xla = SnpLinAlg{Float64}(x, model=ADDITIVE_MODEL, center=true, scale=true) 

# intercept is the only nongenetic covariate
z = ones(n, 1)
intercepts = randn(r)' # each trait have different intercept

# simulate response y, true model b, and the correct non-0 positions of b
Y, true_Σ, true_b, correct_position = simulate_random_response(xla, k, r, Zu=z*intercepts, overlap=0);

# %%
Random.seed!(2020)
Yt = Matrix(Y')
Zt = Matrix(z')
@time result = fit_iht(Yt, Transpose(xla), Zt, init_beta=true);
speed_per_iter = result.time / result.iter
# Out:
# ****                   MendelIHT Version 1.4.1                  ****
# ****     Benjamin Chu, Kevin Keys, Chris German, Hua Zhou       ****
# ****   Jin Zhou, Eric Sobel, Janet Sinsheimer, Kenneth Lange    ****
# ****                                                            ****
# ****                 Please cite our paper!                     ****
# ****         https://doi.org/10.1093/gigascience/giaa044        ****
#
# Initializing β to univariate regression values...
# ...completed in 1.0 seconds.
#
# Running sparse Multivariate Gaussian regression
# Number of threads = 1
# Link functin = IdentityLink()
# Sparsity parameter (k) = 10
# Prior weight scaling = off
# Doubly sparse projection = off
# Debias = off
# Max IHT iterations = 200
# Converging when tol < 0.0001 and iteration ≥ 5:
#
# Iteration 1: loglikelihood = -6804.448066023764, backtracks = 0, tol = 0.0
# Iteration 2: loglikelihood = -6777.540091483411, backtracks = 0, tol = 0.058246770583647925
# Iteration 3: loglikelihood = -6772.864909530544, backtracks = 0, tol = 0.026095886747018154
# Iteration 4: loglikelihood = -6771.701387581366, backtracks = 0, tol = 0.008771618216051724
# Iteration 5: loglikelihood = -6771.366273964879, backtracks = 0, tol = 0.005784829579875812
# Iteration 6: loglikelihood = -6771.263918380275, backtracks = 0, tol = 0.003011026399830286
# Iteration 7: loglikelihood = -6771.231870309224, backtracks = 0, tol = 0.0017222174629542212
# Iteration 8: loglikelihood = -6771.221710601443, backtracks = 0, tol = 0.000963316832303552
# Iteration 9: loglikelihood = -6771.218468198234, backtracks = 0, tol = 0.0005449810504878471
# Iteration 10: loglikelihood = -6771.217429378941, backtracks = 0, tol = 0.0003080226518573195
# Iteration 11: loglikelihood = -6771.217095774227, backtracks = 0, tol = 0.00017443074605207173
# Iteration 12: loglikelihood = -6771.216988483229, backtracks = 0, tol = 9.882794666769017e-5
#   1.447963 seconds (302.39 k allocations: 795.149 MiB, 4.34% gc time)
# 0.03809549411137899

# %%
fit_iht(Yt, Transpose(xla), Zt, init_beta=true, verbose=false)
Profile.clear()
@profile fit_iht(Yt, Transpose(xla), Zt, init_beta=true, verbose=false);
Profile.print()
# Out:
# Overhead ╎ [+additional indent] Count File:Line; Function
# =========================================================
#   2╎2    @Base/reduce.jl:233; mapreduce_impl(f::typeof(abs2),...
#    ╎409  @Base/task.jl:406; (::IJulia.var"#15#18")()
#    ╎ 409  ...lia/src/eventloop.jl:8; eventloop(socket::ZMQ.Socket)
#    ╎  409  @Base/essentials.jl:706; invokelatest
#    ╎   409  @Base/essentials.jl:708; #invokelatest#2
#    ╎    409  .../execute_request.jl:67; execute_request(socket::ZMQ.So...
#    ╎     409  ...SoftGlobalScope.jl:65; softscope_include_string(m::M...
#    ╎    ╎ 409  @Base/loading.jl:1094; include_string(mapexpr::typ...
#    ╎    ╎  409  @Base/boot.jl:360; eval
#    ╎    ╎   409  ...delIHT/src/fit.jl:72; (::MendelIHT.var"#fit_iht##...
#    ╎    ╎    33   ...elIHT/src/fit.jl:96; fit_iht(y::Matrix{Float64}...
#    ╎    ╎     33   @Base/timing.jl:287; macro expansion
#    ╎    ╎    ╎ 33   ...a_structures.jl:116; initialize
#    ╎    ╎    ╎  33   ...a_structures.jl:123; #initialize#1
#    ╎    ╎    ╎   1    ...multivariate.jl:354; init_iht_indices!(v::Men...
#    ╎    ╎    ╎    1    @Base/array.jl:335; fill!
#    ╎    ╎    ╎     1    @Base/array.jl:839; setindex!
#    ╎    ╎    ╎   1    ...multivariate.jl:387; init_iht_indices!(v::Men...
#    ╎    ╎    ╎    1    ...ultivariate.jl:112; project_k!(v::MendelIHT...
#    ╎    ╎    ╎     1    ...c/utilities.jl:480; project_k!
#    ╎    ╎    ╎    ╎ 1    @Base/sort.jl:165; partialsort##kw
#    ╎    ╎    ╎    ╎  1    @Base/sort.jl:165; partialsort(v::Vector...
#    ╎    ╎    ╎    ╎   1    @Base/sort.jl:156; partialsort!##kw
#    ╎    ╎    ╎    ╎    1    @Base/sort.jl:156; #partialsort!#2
#    ╎    ╎    ╎    ╎     1    @Base/sort.jl:97; partialsort!
#    ╎    ╎    ╎    ╎    ╎ 1    @Base/sort.jl:657; sort!(v::Vector{Flo...
#    ╎    ╎    ╎    ╎    ╎  1    @Base/sort.jl:586; partition!(v::Vect...
#    ╎    ╎    ╎    ╎    ╎   1    ...perators.jl:352; >=
#   1╎    ╎    ╎    ╎    ╎    1    @Base/int.jl:442; <=
#    ╎    ╎    ╎   31   ...multivariate.jl:393; init_iht_indices!(v::Men...
#    ╎    ╎    ╎    31   ...multivariate.jl:62; score!(v::MendelIHT.mIHT...
#    ╎    ╎    ╎     30   ...ultivariate.jl:84; update_df!(v::MendelIHT...
#    ╎    ╎    ╎    ╎ 30   ...alg_direct.jl:177; mul!(out::Matrix{Float...
#    ╎    ╎    ╎    ╎  25   ...alg_direct.jl:615; _snparray_AtX_tile!(C...
#    ╎    ╎    ╎    ╎   25   ...alg_direct.jl:831; _snparray_AtX_additiv...
#    ╎    ╎    ╎    ╎    25   ...t_loopset.jl:706; _turbo_!(::Val{(fals...
#    ╎    ╎    ╎    ╎     25   ...t_loopset.jl:706; macro expansion
#    ╎    ╎    ╎    ╎    ╎ 1    ...ase_defs.jl:88; >>
#    ╎    ╎    ╎    ╎    ╎  1    ...romotion.jl:48; promote_div
#    ╎    ╎    ╎    ╎    ╎   1    ...romotion.jl:57; promote_div
#    ╎    ╎    ╎    ╎    ╎    1    ...se_defs.jl:161; rem
#    ╎    ╎    ╎    ╎    ╎     1    ...version.jl:228; vrem
#    ╎    ╎    ╎    ╎    ╎    ╎ 1    ...version.jl:36; vconvert
#   1╎    ╎    ╎    ╎    ╎    ╎  1    ...ersion.jl:12; macro expansion
#    ╎    ╎    ╎    ╎    ╎ 2    ...ase_defs.jl:286; add_fast
#    ╎    ╎    ╎    ╎    ╎  2    ...in/masks.jl:145; vadd_fast
#   2╎    ╎    ╎    ╎    ╎   2    ...in/masks.jl:145; macro expansion
#    ╎    ╎    ╎    ╎    ╎ 2    ...ase_defs.jl:86; mul_fast
#    ╎    ╎    ╎    ╎    ╎  2    ...nary_ops.jl:94; vmul_fast
#   2╎    ╎    ╎    ╎    ╎   2    ...nary_ops.jl:94; macro expansion
#    ╎    ╎    ╎    ╎    ╎ 6    ...ase_defs.jl:86; sub_fast
#    ╎    ╎    ╎    ╎    ╎  2    ...romotion.jl:292; promote
#    ╎    ╎    ╎    ╎    ╎   2    ...romotion.jl:269; _promote
#    ╎    ╎    ╎    ╎    ╎    2    ...se_defs.jl:152; convert
#    ╎    ╎    ╎    ╎    ╎     2    ...version.jl:29; vconvert
#   2╎    ╎    ╎    ╎    ╎    ╎ 2    ...version.jl:12; macro expansion
#    ╎    ╎    ╎    ╎    ╎  4    ...nary_ops.jl:94; vsub_fast
#   4╎    ╎    ╎    ╎    ╎   4    ...nary_ops.jl:94; macro expansion
#    ╎    ╎    ╎    ╎    ╎ 4    ...in_funcs.jl:291; vfmadd_fast
#    ╎    ╎    ╎    ╎    ╎  4    ...in_funcs.jl:289; _vfmadd_fast
#    ╎    ╎    ╎    ╎    ╎   2    ...ase_defs.jl:269; vfma_fast
#    ╎    ╎    ╎    ╎    ╎    2    ...ase_defs.jl:86; add_fast
#    ╎    ╎    ╎    ╎    ╎     2    ...ary_ops.jl:94; vadd_fast
#   2╎    ╎    ╎    ╎    ╎    ╎ 2    ...ary_ops.jl:94; macro expansion
#    ╎    ╎    ╎    ╎    ╎   2    ...in_funcs.jl:255; vfma_fast
#   2╎    ╎    ╎    ╎    ╎    2    ...n_funcs.jl:255; macro expansion
#    ╎    ╎    ╎    ╎    ╎ 5    ...roadcast.jl:81; vbroadcast
#    ╎    ╎    ╎    ╎    ╎  5    ...roadcast.jl:44; _vbroadcast
#   5╎    ╎    ╎    ╎    ╎   5    ...roadcast.jl:76; macro expansion
#    ╎    ╎    ╎    ╎    ╎ 5    ...pointers.jl:162; _vload
#    ╎    ╎    ╎    ╎    ╎  5    ...ory_addr.jl:628; __vload
#   5╎    ╎    ╎    ╎    ╎   5    ...ory_addr.jl:628; macro expansion
#    ╎    ╎    ╎    ╎  5    ...alg_direct.jl:627; _snparray_AtX_tile!(C...
#    ╎    ╎    ╎    ╎   5    ...alg_direct.jl:831; _snparray_AtX_additiv...
#    ╎    ╎    ╎    ╎    5    ...t_loopset.jl:706; _turbo_!(::Val{(fals...
#    ╎    ╎    ╎    ╎     5    ...t_loopset.jl:706; macro expansion
#    ╎    ╎    ╎    ╎    ╎ 2    ...ase_defs.jl:86; sub_fast
#    ╎    ╎    ╎    ╎    ╎  2    ...romotion.jl:292; promote
#    ╎    ╎    ╎    ╎    ╎   2    ...romotion.jl:269; _promote
#    ╎    ╎    ╎    ╎    ╎    2    ...se_defs.jl:152; convert
#    ╎    ╎    ╎    ╎    ╎     2    ...version.jl:29; vconvert
#   2╎    ╎    ╎    ╎    ╎    ╎ 2    ...version.jl:12; macro expansion
#    ╎    ╎    ╎    ╎    ╎ 2    ...in_funcs.jl:291; vfmadd_fast
#    ╎    ╎    ╎    ╎    ╎  2    ...in_funcs.jl:289; _vfmadd_fast
#    ╎    ╎    ╎    ╎    ╎   2    ...ase_defs.jl:269; vfma_fast
#    ╎    ╎    ╎    ╎    ╎    1    ...se_defs.jl:86; add_fast
#    ╎    ╎    ╎    ╎    ╎     1    ...ary_ops.jl:94; vadd_fast
#   1╎    ╎    ╎    ╎    ╎    ╎ 1    ...ary_ops.jl:94; macro expansion
#    ╎    ╎    ╎    ╎    ╎    1    ...n/masks.jl:455; vifelse
#   1╎    ╎    ╎    ╎    ╎     1    ...n/masks.jl:468; macro expansion
#    ╎    ╎    ╎    ╎    ╎ 1    ...pointers.jl:162; _vload
#    ╎    ╎    ╎    ╎    ╎  1    ...ory_addr.jl:628; __vload
#   1╎    ╎    ╎    ╎    ╎   1    ...ory_addr.jl:628; macro expansion
#    ╎    ╎    ╎     1    ...ultivariate.jl:85; update_df!(v::MendelIHT...
#    ╎    ╎    ╎    ╎ 1    .../broadcast.jl:891; materialize!
#    ╎    ╎    ╎    ╎  1    .../broadcast.jl:894; materialize!
#    ╎    ╎    ╎    ╎   1    .../broadcast.jl:936; copyto!
#    ╎    ╎    ╎    ╎    1    ...broadcast.jl:977; copyto!
#    ╎    ╎    ╎    ╎     1    ...ractarray.jl:950; copyto!
#   1╎    ╎    ╎    ╎    ╎ 1    ...actarray.jl:976; copyto_unaliased!(d...
#    ╎    ╎    376  ...elIHT/src/fit.jl:102; fit_iht(y::Matrix{Float64}...
#    ╎    ╎     376  ...elIHT/src/fit.jl:148; fit_iht!##kw
#    ╎    ╎    ╎ 368  ...lIHT/src/fit.jl:176; fit_iht!(v::MendelIHT.mIH...
#    ╎    ╎    ╎  10   ...lIHT/src/fit.jl:214; iht_one_step!(v::MendelI...
#    ╎    ╎    ╎   10   ...multivariate.jl:104; _iht_gradstep!
#    ╎    ╎    ╎    10   ...ultivariate.jl:112; project_k!(v::MendelIHT...
#    ╎    ╎    ╎     10   ...c/utilities.jl:480; project_k!
#    ╎    ╎    ╎    ╎ 10   @Base/sort.jl:165; partialsort##kw
#    ╎    ╎    ╎    ╎  10   @Base/sort.jl:165; partialsort(v::Vector...
#    ╎    ╎    ╎    ╎   10   @Base/sort.jl:156; partialsort!##kw
#    ╎    ╎    ╎    ╎    10   @Base/sort.jl:156; #partialsort!#2
#    ╎    ╎    ╎    ╎     10   @Base/sort.jl:97; partialsort!
#    ╎    ╎    ╎    ╎    ╎ 10   @Base/sort.jl:657; sort!(v::Vector{Flo...
#    ╎    ╎    ╎    ╎    ╎  4    @Base/sort.jl:584; partition!(v::Vect...
#    ╎    ╎    ╎    ╎    ╎   4    ...ordering.jl:111; lt
#   1╎    ╎    ╎    ╎    ╎    1    ...e/float.jl:441; abs
#    ╎    ╎    ╎    ╎    ╎    3    ...rdering.jl:110; lt
#    ╎    ╎    ╎    ╎    ╎     3    ...rdering.jl:109; lt
#   3╎    ╎    ╎    ╎    ╎    ╎ 3    .../float.jl:381; isless
#   1╎    ╎    ╎    ╎    ╎  4    @Base/sort.jl:585; partition!(v::Vect...
#    ╎    ╎    ╎    ╎    ╎   3    ...ordering.jl:111; lt
#    ╎    ╎    ╎    ╎    ╎    3    ...rdering.jl:110; lt
#    ╎    ╎    ╎    ╎    ╎     3    ...rdering.jl:109; lt
#   3╎    ╎    ╎    ╎    ╎    ╎ 3    .../float.jl:381; isless
#    ╎    ╎    ╎    ╎    ╎  1    @Base/sort.jl:586; partition!(v::Vect...
#    ╎    ╎    ╎    ╎    ╎   1    ...perators.jl:352; >=
#   1╎    ╎    ╎    ╎    ╎    1    @Base/int.jl:442; <=
#    ╎    ╎    ╎    ╎    ╎  1    @Base/sort.jl:587; partition!(v::Vect...
#   1╎    ╎    ╎    ╎    ╎   1    @Base/array.jl:839; setindex!
#    ╎    ╎    ╎  1    ...lIHT/src/fit.jl:217; iht_one_step!(v::MendelI...
#    ╎    ╎    ╎   1    ...multivariate.jl:23; update_xb!(v::MendelIHT....
#    ╎    ╎    ╎    1    .../src/matmul.jl:275; mul!
#    ╎    ╎    ╎     1    .../src/matmul.jl:302; mul!
#    ╎    ╎    ╎    ╎ 1    ...src/matmul.jl:802; generic_matmatmul!(C::...
#    ╎    ╎    ╎    ╎  1    ...src/matmul.jl:875; _generic_matmatmul!(C...
#    ╎    ╎    ╎    ╎   1    @Base/range.jl:674; iterate
#   1╎    ╎    ╎    ╎    1    ...promotion.jl:410; ==
#    ╎    ╎    ╎  1    ...lIHT/src/fit.jl:222; iht_one_step!(v::MendelI...
#    ╎    ╎    ╎   1    ...multivariate.jl:245; solve_Σ!(v::MendelIHT.mI...
#    ╎    ╎    ╎    1    ...multivariate.jl:50; update_resid!(v::MendelI...
#   1╎    ╎    ╎     1    @Base/float.jl:329; -
#    ╎    ╎    ╎  356  ...lIHT/src/fit.jl:247; iht_one_step!(v::MendelI...
#    ╎    ╎    ╎   356  ...multivariate.jl:62; score!(v::MendelIHT.mIHT...
#    ╎    ╎    ╎    356  ...multivariate.jl:84; update_df!(v::MendelIHT....
#    ╎    ╎    ╎     356  ...nalg_direct.jl:177; mul!(out::Matrix{Float...
#    ╎    ╎    ╎    ╎ 294  ...alg_direct.jl:615; _snparray_AtX_tile!(C:...
#    ╎    ╎    ╎    ╎  294  ...alg_direct.jl:831; _snparray_AtX_additiv...
#    ╎    ╎    ╎    ╎   294  ...ct_loopset.jl:706; _turbo_!(::Val{(false...
#    ╎    ╎    ╎    ╎    294  ...t_loopset.jl:706; macro expansion
#    ╎    ╎    ╎    ╎     8    ...ng/graphs.jl:202; cmpend
#   8╎    ╎    ╎    ╎    ╎ 8    @Base/int.jl:442; <=
#    ╎    ╎    ╎    ╎     7    ...base_defs.jl:88; &
#    ╎    ╎    ╎    ╎    ╎ 7    ...inary_ops.jl:83; vand
#   7╎    ╎    ╎    ╎    ╎  7    ...nary_ops.jl:83; macro expansion
#    ╎    ╎    ╎    ╎     3    ...base_defs.jl:88; ==
#    ╎    ╎    ╎    ╎    ╎ 3    ...in/masks.jl:450; veq
#    ╎    ╎    ╎    ╎    ╎  3    ...in/masks.jl:390; veq
#   3╎    ╎    ╎    ╎    ╎   3    ...in/masks.jl:374; macro expansion
#    ╎    ╎    ╎    ╎     11   ...base_defs.jl:88; >>
#    ╎    ╎    ╎    ╎    ╎ 11   ...promotion.jl:48; promote_div
#    ╎    ╎    ╎    ╎    ╎  11   ...romotion.jl:57; promote_div
#    ╎    ╎    ╎    ╎    ╎   11   ...ase_defs.jl:161; rem
#    ╎    ╎    ╎    ╎    ╎    11   ...version.jl:228; vrem
#    ╎    ╎    ╎    ╎    ╎     11   ...version.jl:36; vconvert
#  11╎    ╎    ╎    ╎    ╎    ╎ 11   ...version.jl:12; macro expansion
#    ╎    ╎    ╎    ╎     26   ...base_defs.jl:286; add_fast
#    ╎    ╎    ╎    ╎    ╎ 26   ...in/masks.jl:145; vadd_fast
#  26╎    ╎    ╎    ╎    ╎  26   ...in/masks.jl:145; macro expansion
#    ╎    ╎    ╎    ╎     15   ...base_defs.jl:86; mul_fast
#    ╎    ╎    ╎    ╎    ╎ 15   ...inary_ops.jl:94; vmul_fast
#  15╎    ╎    ╎    ╎    ╎  15   ...nary_ops.jl:94; macro expansion
#    ╎    ╎    ╎    ╎     26   ...base_defs.jl:86; sub_fast
#    ╎    ╎    ╎    ╎    ╎ 14   ...romotion.jl:292; promote
#    ╎    ╎    ╎    ╎    ╎  14   ...romotion.jl:269; _promote
#    ╎    ╎    ╎    ╎    ╎   14   ...ase_defs.jl:152; convert
#    ╎    ╎    ╎    ╎    ╎    14   ...nversion.jl:29; vconvert
#  14╎    ╎    ╎    ╎    ╎     14   ...version.jl:12; macro expansion
#    ╎    ╎    ╎    ╎    ╎ 12   ...nary_ops.jl:94; vsub_fast
#  12╎    ╎    ╎    ╎    ╎  12   ...nary_ops.jl:94; macro expansion
#    ╎    ╎    ╎    ╎     72   ...rin_funcs.jl:291; vfmadd_fast
#    ╎    ╎    ╎    ╎    ╎ 72   ...in_funcs.jl:289; _vfmadd_fast
#    ╎    ╎    ╎    ╎    ╎  42   ...ase_defs.jl:269; vfma_fast
#    ╎    ╎    ╎    ╎    ╎   29   ...ase_defs.jl:86; add_fast
#    ╎    ╎    ╎    ╎    ╎    29   ...nary_ops.jl:94; vadd_fast
#  29╎    ╎    ╎    ╎    ╎     29   ...ary_ops.jl:94; macro expansion
#    ╎    ╎    ╎    ╎    ╎   13   ...in/masks.jl:455; vifelse
#  13╎    ╎    ╎    ╎    ╎    13   ...n/masks.jl:468; macro expansion
#    ╎    ╎    ╎    ╎    ╎  30   ...in_funcs.jl:255; vfma_fast
#  30╎    ╎    ╎    ╎    ╎   30   ...in_funcs.jl:255; macro expansion
#    ╎    ╎    ╎    ╎     62   ...broadcast.jl:81; vbroadcast
#    ╎    ╎    ╎    ╎    ╎ 62   ...broadcast.jl:44; _vbroadcast
#  62╎    ╎    ╎    ╎    ╎  62   ...roadcast.jl:76; macro expansion
#    ╎    ╎    ╎    ╎     3    ...rc/static.jl:41; vadd_nsw
#    ╎    ╎    ╎    ╎    ╎ 3    ...inary_ops.jl:38; vadd_nsw
#   3╎    ╎    ╎    ╎    ╎  3    ...nary_ops.jl:38; macro expansion
#    ╎    ╎    ╎    ╎     5    ...dpointers.jl:161; _vload
#    ╎    ╎    ╎    ╎    ╎ 5    ...pointers.jl:157; linear_index
#    ╎    ╎    ╎    ╎    ╎  5    ...ultiples.jl:101; tdot
#    ╎    ╎    ╎    ╎    ╎   5    ...indexing.jl:21; tdot
#    ╎    ╎    ╎    ╎    ╎    5    ...lazymul.jl:105; add_indices
#    ╎    ╎    ╎    ╎    ╎     4    ...ary_ops.jl:123; vadd_nsw
#    ╎    ╎    ╎    ╎    ╎    ╎ 4    ...motion.jl:292; promote
#    ╎    ╎    ╎    ╎    ╎    ╎  4    ...motion.jl:269; _promote
#    ╎    ╎    ╎    ╎    ╎    ╎   4    ...e_defs.jl:150; convert
#    ╎    ╎    ╎    ╎    ╎    ╎    4    ...ersion.jl:73; vconvert
#    ╎    ╎    ╎    ╎    ╎    ╎     4    ...adcast.jl:44; _vbroadcast
#   4╎    ╎    ╎    ╎    ╎    ╎    ╎ 4    ...adcast.jl:76; macro expansion
#    ╎    ╎    ╎    ╎    ╎     1    ...ary_ops.jl:124; vadd_nsw
#    ╎    ╎    ╎    ╎    ╎    ╎ 1    ...ary_ops.jl:28; vadd_nsw
#   1╎    ╎    ╎    ╎    ╎    ╎  1    ...ry_ops.jl:28; macro expansion
#    ╎    ╎    ╎    ╎     56   ...dpointers.jl:162; _vload
#    ╎    ╎    ╎    ╎    ╎ 56   ...ory_addr.jl:628; __vload
#  56╎    ╎    ╎    ╎    ╎  56   ...ory_addr.jl:628; macro expansion
#    ╎    ╎    ╎    ╎ 62   ...alg_direct.jl:627; _snparray_AtX_tile!(C:...
#    ╎    ╎    ╎    ╎  62   ...alg_direct.jl:831; _snparray_AtX_additiv...
#    ╎    ╎    ╎    ╎   62   ...ct_loopset.jl:706; _turbo_!(::Val{(false...
#    ╎    ╎    ╎    ╎    62   ...t_loopset.jl:706; macro expansion
#    ╎    ╎    ╎    ╎     1    ...base_defs.jl:88; &
#    ╎    ╎    ╎    ╎    ╎ 1    ...inary_ops.jl:83; vand
#   1╎    ╎    ╎    ╎    ╎  1    ...nary_ops.jl:83; macro expansion
#    ╎    ╎    ╎    ╎     1    ...base_defs.jl:88; ==
#    ╎    ╎    ╎    ╎    ╎ 1    ...in/masks.jl:450; veq
#    ╎    ╎    ╎    ╎    ╎  1    ...in/masks.jl:390; veq
#   1╎    ╎    ╎    ╎    ╎   1    ...in/masks.jl:374; macro expansion
#    ╎    ╎    ╎    ╎     1    ...base_defs.jl:88; >>
#    ╎    ╎    ╎    ╎    ╎ 1    ...promotion.jl:48; promote_div
#    ╎    ╎    ╎    ╎    ╎  1    ...romotion.jl:57; promote_div
#    ╎    ╎    ╎    ╎    ╎   1    ...ase_defs.jl:161; rem
#    ╎    ╎    ╎    ╎    ╎    1    ...version.jl:228; vrem
#    ╎    ╎    ╎    ╎    ╎     1    ...version.jl:36; vconvert
#   1╎    ╎    ╎    ╎    ╎    ╎ 1    ...version.jl:12; macro expansion
#    ╎    ╎    ╎    ╎     8    ...base_defs.jl:286; add_fast
#    ╎    ╎    ╎    ╎    ╎ 8    ...in/masks.jl:145; vadd_fast
#   8╎    ╎    ╎    ╎    ╎  8    ...in/masks.jl:145; macro expansion
#    ╎    ╎    ╎    ╎     4    ...base_defs.jl:86; mul_fast
#    ╎    ╎    ╎    ╎    ╎ 4    ...inary_ops.jl:94; vmul_fast
#   4╎    ╎    ╎    ╎    ╎  4    ...nary_ops.jl:94; macro expansion
#    ╎    ╎    ╎    ╎     7    ...base_defs.jl:86; sub_fast
#    ╎    ╎    ╎    ╎    ╎ 2    ...romotion.jl:292; promote
#    ╎    ╎    ╎    ╎    ╎  2    ...romotion.jl:269; _promote
#    ╎    ╎    ╎    ╎    ╎   2    ...ase_defs.jl:152; convert
#    ╎    ╎    ╎    ╎    ╎    2    ...nversion.jl:29; vconvert
#   2╎    ╎    ╎    ╎    ╎     2    ...version.jl:12; macro expansion
#    ╎    ╎    ╎    ╎    ╎ 5    ...nary_ops.jl:94; vsub_fast
#   5╎    ╎    ╎    ╎    ╎  5    ...nary_ops.jl:94; macro expansion
#    ╎    ╎    ╎    ╎     16   ...rin_funcs.jl:291; vfmadd_fast
#    ╎    ╎    ╎    ╎    ╎ 16   ...in_funcs.jl:289; _vfmadd_fast
#    ╎    ╎    ╎    ╎    ╎  8    ...ase_defs.jl:269; vfma_fast
#    ╎    ╎    ╎    ╎    ╎   6    ...ase_defs.jl:86; add_fast
#    ╎    ╎    ╎    ╎    ╎    6    ...nary_ops.jl:94; vadd_fast
#   6╎    ╎    ╎    ╎    ╎     6    ...ary_ops.jl:94; macro expansion
#    ╎    ╎    ╎    ╎    ╎   2    ...in/masks.jl:455; vifelse
#   2╎    ╎    ╎    ╎    ╎    2    ...n/masks.jl:468; macro expansion
#    ╎    ╎    ╎    ╎    ╎  8    ...in_funcs.jl:255; vfma_fast
#   8╎    ╎    ╎    ╎    ╎   8    ...in_funcs.jl:255; macro expansion
#    ╎    ╎    ╎    ╎     13   ...broadcast.jl:81; vbroadcast
#    ╎    ╎    ╎    ╎    ╎ 13   ...broadcast.jl:44; _vbroadcast
#  13╎    ╎    ╎    ╎    ╎  13   ...roadcast.jl:76; macro expansion
#    ╎    ╎    ╎    ╎     1    ...dpointers.jl:161; _vload
#    ╎    ╎    ╎    ╎    ╎ 1    ...pointers.jl:157; linear_index
#    ╎    ╎    ╎    ╎    ╎  1    ...ultiples.jl:101; tdot
#    ╎    ╎    ╎    ╎    ╎   1    ...indexing.jl:21; tdot
#    ╎    ╎    ╎    ╎    ╎    1    ...lazymul.jl:105; add_indices
#    ╎    ╎    ╎    ╎    ╎     1    ...ary_ops.jl:123; vadd_nsw
#    ╎    ╎    ╎    ╎    ╎    ╎ 1    ...motion.jl:292; promote
#    ╎    ╎    ╎    ╎    ╎    ╎  1    ...motion.jl:269; _promote
#    ╎    ╎    ╎    ╎    ╎    ╎   1    ...e_defs.jl:150; convert
#    ╎    ╎    ╎    ╎    ╎    ╎    1    ...ersion.jl:73; vconvert
#    ╎    ╎    ╎    ╎    ╎    ╎     1    ...adcast.jl:44; _vbroadcast
#   1╎    ╎    ╎    ╎    ╎    ╎    ╎ 1    ...adcast.jl:76; macro expansion
#    ╎    ╎    ╎    ╎     9    ...dpointers.jl:162; _vload
#    ╎    ╎    ╎    ╎    ╎ 9    ...ory_addr.jl:628; __vload
#   9╎    ╎    ╎    ╎    ╎  9    ...ory_addr.jl:628; macro expansion
#    ╎    ╎    ╎    ╎     1    ...dpointers.jl:201; _vstore!
#    ╎    ╎    ╎    ╎    ╎ 1    ...ory_addr.jl:807; __vstore!
#   1╎    ╎    ╎    ╎    ╎  1    ...ory_addr.jl:807; macro expansion
#    ╎    ╎    ╎ 8    ...lIHT/src/fit.jl:184; fit_iht!(v::MendelIHT.mIH...
#    ╎    ╎    ╎  5    ...multivariate.jl:414; check_convergence(v::Men...
#    ╎    ╎    ╎   5    .../src/metrics.jl:377; chebyshev(a::Matrix{Floa...
#    ╎    ╎    ╎    5    ...src/metrics.jl:328; Chebyshev
#    ╎    ╎    ╎     5    ...src/metrics.jl:252; _evaluate
#   1╎    ╎    ╎    ╎ 2    @Base/simdloop.jl:75; macro expansion
#   1╎    ╎    ╎    ╎  1    @Base/int.jl:83; <
#    ╎    ╎    ╎    ╎ 3    @Base/simdloop.jl:77; macro expansion
#    ╎    ╎    ╎    ╎  3    ...rc/metrics.jl:255; macro expansion
#    ╎    ╎    ╎    ╎   3    ...rc/metrics.jl:374; eval_reduce
#   3╎    ╎    ╎    ╎    3    @Base/math.jl:722; max
#    ╎    ╎    ╎  3    ...multivariate.jl:415; check_convergence(v::Men...
#    ╎    ╎    ╎   3    .../src/generic.jl:631; norm(itr::Matrix{Float64...
#    ╎    ╎    ╎    3    ...src/generic.jl:556; normInf
#    ╎    ╎    ╎     1    ...src/generic.jl:468; generic_normInf
#    ╎    ╎    ╎    ╎ 1    @Base/array.jl:777; iterate
#    ╎    ╎    ╎    ╎  1    @Base/int.jl:448; <
#   1╎    ╎    ╎    ╎   1    @Base/int.jl:441; <
#    ╎    ╎    ╎     1    ...src/generic.jl:471; generic_normInf
#    ╎    ╎    ╎    ╎ 1    ...rc/generic.jl:668; norm
#    ╎    ╎    ╎    ╎  1    ...rc/generic.jl:668; norm
#   1╎    ╎    ╎    ╎   1    @Base/float.jl:441; abs
#   1╎    ╎    ╎     1    ...src/generic.jl:472; generic_normInf
#    ╎684  ...readingconstructs.jl:48; (::MendelIHT.var"#165#threadsfo...
#    ╎ 684  ...readingconstructs.jl:81; (::MendelIHT.var"#165#threadsfo...
#   1╎  1    @Base/abstractarray.jl:0; macro expansion
#    ╎  625  ...src/multivariate.jl:490; macro expansion
#    ╎   14   @Base/abstractarray.jl:949; copyto!
#    ╎    14   ...e/abstractarray.jl:1349; unalias
#    ╎     14   .../abstractarray.jl:1384; mightalias(A::Vector{Float64...
#    ╎    ╎ 14   @Base/subarray.jl:102; dataids
#    ╎    ╎  14   ...a/src/adjtrans.jl:98; dataids
#    ╎    ╎   14   ...abstractarray.jl:1407; dataids
#  14╎    ╎    14   @Base/reflection.jl:291; objectid
#    ╎   495  @Base/abstractarray.jl:950; copyto!
#   1╎    1    ...e/abstractarray.jl:959; copyto_unaliased!(deststyle::...
#    ╎    1    ...e/abstractarray.jl:975; copyto_unaliased!(deststyle::...
#    ╎     1    .../abstractarray.jl:1094; iterate
#    ╎    ╎ 1    .../abstractarray.jl:1096; iterate
#    ╎    ╎  1    @Base/subarray.jl:276; getindex
#    ╎    ╎   1    ...a/src/adjtrans.jl:203; getindex
#    ╎    ╎    1    .../linalg_direct.jl:64; getindex
#   1╎    ╎     1    @Base/array.jl:801; getindex
#    ╎    493  ...e/abstractarray.jl:976; copyto_unaliased!(deststyle::...
#  29╎     29   .../abstractarray.jl:0; iterate
#    ╎     441  .../abstractarray.jl:1096; iterate
#    ╎    ╎ 441  @Base/subarray.jl:276; getindex
#    ╎    ╎  2    @Base/subarray.jl:246; reindex
#    ╎    ╎   2    @Base/subarray.jl:254; reindex
#   2╎    ╎    2    @Base/array.jl:801; getindex
#    ╎    ╎  439  ...a/src/adjtrans.jl:203; getindex
#  14╎    ╎   14   .../abstractarray.jl:0; getindex
# 115╎    ╎   115  .../linalg_direct.jl:0; getindex
#    ╎    ╎   171  .../linalg_direct.jl:62; getindex
#  28╎    ╎    87   .../src/snparray.jl:291; convert
#   1╎    ╎     1    @Base/float.jl:94; Float64
#    ╎    ╎     58   @Base/int.jl:923; -
#  58╎    ╎    ╎ 58   @Base/int.jl:86; -
#    ╎    ╎    17   .../src/snparray.jl:116; getindex
#    ╎    ╎     17   ...abstractarray.jl:616; checkbounds
#    ╎    ╎    ╎ 17   ...bstractarray.jl:595; checkbounds
#    ╎    ╎    ╎  17   ...bstractarray.jl:642; checkbounds_indices
#    ╎    ╎    ╎   17   ...bstractarray.jl:673; checkindex
#  17╎    ╎    ╎    17   @Base/int.jl:442; <=
#    ╎    ╎    1    .../src/snparray.jl:117; getindex
#   1╎    ╎     1    @Base/int.jl:87; +
#    ╎    ╎    66   .../src/snparray.jl:118; getindex
#  23╎    ╎     23   @Base/array.jl:802; getindex
#   1╎    ╎     1    @Base/int.jl:309; &
#    ╎    ╎     42   @Base/int.jl:462; >>
#  18╎    ╎    ╎ 18   @Base/int.jl:455; >>
#  24╎    ╎    ╎ 24   @Base/int.jl:456; >>
#  27╎    ╎   60   .../linalg_direct.jl:64; getindex
#  32╎    ╎    32   @Base/array.jl:801; getindex
#   1╎    ╎    1    @Base/float.jl:329; -
#   1╎    ╎   79   .../linalg_direct.jl:65; getindex
#  22╎    ╎    22   @Base/array.jl:801; getindex
#  56╎    ╎    56   @Base/float.jl:332; *
#  23╎     23   @Base/int.jl:87; +
#    ╎   13   @Base/subarray.jl:176; view
#    ╎    3    @Base/indices.jl:324; to_indices
#    ╎     3    @Base/indices.jl:333; to_indices
#    ╎    ╎ 3    ...ltidimensional.jl:810; to_indices
#    ╎    ╎  3    ...ltidimensional.jl:812; _maybe_linear_logical_index
#    ╎    ╎   3    @Base/indices.jl:277; to_index
#    ╎    ╎    3    @Base/indices.jl:294; to_index
#    ╎    ╎     3    ...tidimensional.jl:728; LogicalIndex
#    ╎    ╎    ╎ 3    ...idimensional.jl:726; LogicalIndex
#    ╎    ╎    ╎  3    @Base/reducedim.jl:392; count
#    ╎    ╎    ╎   3    @Base/reducedim.jl:392; #count#675
#    ╎    ╎    ╎    3    ...e/reducedim.jl:393; count##kw
#    ╎    ╎    ╎     3    ...e/reducedim.jl:393; #count#676
#    ╎    ╎    ╎    ╎ 3    ...e/bitarray.jl:1397; _count
#    ╎    ╎    ╎    ╎  3    ...e/bitarray.jl:1390; bitcount##kw
#   1╎    ╎    ╎    ╎   3    .../bitarray.jl:1392; #bitcount#251
#   1╎    ╎    ╎    ╎    1    @Base/array.jl:0; getindex
#   1╎    ╎    ╎    ╎    1    @Base/int.jl:372; count_ones
#    ╎    10   @Base/tuple.jl:214; map
#    ╎     10   @Base/subarray.jl:176; #141
#    ╎    ╎ 10   .../abstractarray.jl:1349; unalias
#    ╎    ╎  10   .../abstractarray.jl:1384; mightalias
#    ╎    ╎   3    ...abstractarray.jl:1407; dataids
#   3╎    ╎    3    @Base/reflection.jl:291; objectid
#    ╎    ╎   7    .../src/adjtrans.jl:98; dataids
#    ╎    ╎    7    ...abstractarray.jl:1407; dataids
#   7╎    ╎     7    @Base/reflection.jl:291; objectid
#    ╎   103  @Base/subarray.jl:178; view
#    ╎    103  @Base/subarray.jl:209; unsafe_view
#    ╎     103  @Base/subarray.jl:28; SubArray
#    ╎    ╎ 103  ...ltidimensional.jl:789; ensure_indexable
#    ╎    ╎  103  ...ltidimensional.jl:790; ensure_indexable
#    ╎    ╎   103  ...ltidimensional.jl:733; collect
#  37╎    ╎    37   @Base/array.jl:0; collect(itr::Base.Generato...
#   1╎    ╎    1    @Base/array.jl:672; collect(itr::Base.Generato...
#    ╎    ╎    1    @Base/array.jl:678; collect(itr::Base.Generato...
#    ╎    ╎     1    @Base/generator.jl:44; iterate
#   1╎    ╎    ╎ 1    ...tidimensional.jl:0; iterate
#    ╎    ╎    64   @Base/array.jl:683; collect(itr::Base.Generato...
#    ╎    ╎     64   @Base/array.jl:702; collect_to_with_first!
#    ╎    ╎    ╎ 41   @Base/array.jl:724; collect_to!(dest::Vector{...
#    ╎    ╎    ╎  41   @Base/generator.jl:44; iterate
#   1╎    ╎    ╎   5    ...idimensional.jl:772; iterate
#    ╎    ╎    ╎    4    @Base/int.jl:446; ==
#   4╎    ╎    ╎     4    ...e/promotion.jl:410; ==
#    ╎    ╎    ╎   5    ...idimensional.jl:777; iterate
#   5╎    ╎    ╎    5    @Base/int.jl:398; trailing_zeros
#    ╎    ╎    ╎   8    ...idimensional.jl:778; iterate
#    ╎    ╎    ╎    8    @Base/bitarray.jl:121; _blsr
#   8╎    ╎    ╎     8    @Base/int.jl:309; &
#    ╎    ╎    ╎   23   ...idimensional.jl:779; iterate
#  10╎    ╎    ╎    10   @Base/int.jl:87; +
#    ╎    ╎    ╎    13   @Base/int.jl:464; <<
#  13╎    ╎    ╎     13   @Base/int.jl:457; <<
#    ╎    ╎    ╎ 4    @Base/array.jl:728; collect_to!(dest::Vector{...
#   4╎    ╎    ╎  4    @Base/array.jl:839; setindex!
#    ╎    ╎    ╎ 19   @Base/array.jl:729; collect_to!(dest::Vector{...
#  19╎    ╎    ╎  19   @Base/int.jl:87; +
#    ╎  58   ...src/multivariate.jl:491; macro expansion
#   2╎   2    @Base/array.jl:801; getindex
#   2╎   2    ...HT/src/utilities.jl:717; linreg!(x::Vector{Float64}, y:...
#    ╎   3    ...HT/src/utilities.jl:726; linreg!(x::Vector{Float64}, y:...
#    ╎    3    @Base/reducedim.jl:873; sum
#    ╎     3    @Base/reducedim.jl:873; #sum#679
#    ╎    ╎ 3    @Base/reducedim.jl:877; _sum
#    ╎    ╎  3    @Base/reducedim.jl:877; #_sum#681
#    ╎    ╎   3    @Base/reducedim.jl:878; _sum
#    ╎    ╎    3    @Base/reducedim.jl:878; #_sum#682
#    ╎    ╎     3    @Base/reducedim.jl:310; mapreduce
#    ╎    ╎    ╎ 3    @Base/reducedim.jl:310; #mapreduce#672
#    ╎    ╎    ╎  3    @Base/reducedim.jl:318; _mapreduce_dim
#    ╎    ╎    ╎   3    @Base/reduce.jl:415; _mapreduce
#    ╎    ╎    ╎    3    @Base/reduce.jl:257; mapreduce_impl
#    ╎    ╎    ╎     3    @Base/reduce.jl:243; mapreduce_impl(f::type...
#    ╎    ╎    ╎    ╎ 1    @Base/simdloop.jl:77; macro expansion
#    ╎    ╎    ╎    ╎  1    @Base/reduce.jl:245; macro expansion
#    ╎    ╎    ╎    ╎   1    @Base/reduce.jl:27; add_sum
#   1╎    ╎    ╎    ╎    1    @Base/float.jl:326; +
#    ╎    ╎    ╎    ╎ 2    @Base/simdloop.jl:78; macro expansion
#   2╎    ╎    ╎    ╎  2    @Base/int.jl:87; +
#    ╎   7    ...HT/src/utilities.jl:727; linreg!(x::Vector{Float64}, y:...
#    ╎    7    @Base/reducedim.jl:874; sum
#    ╎     7    @Base/reducedim.jl:874; #sum#680
#    ╎    ╎ 7    @Base/reducedim.jl:878; _sum
#    ╎    ╎  7    @Base/reducedim.jl:878; #_sum#682
#    ╎    ╎   7    @Base/reducedim.jl:310; mapreduce
#    ╎    ╎    7    @Base/reducedim.jl:310; #mapreduce#672
#    ╎    ╎     7    @Base/reducedim.jl:318; _mapreduce_dim
#    ╎    ╎    ╎ 7    @Base/reduce.jl:415; _mapreduce(f::typeof(abs2...
#    ╎    ╎    ╎  7    @Base/reduce.jl:257; mapreduce_impl
#    ╎    ╎    ╎   7    @Base/reduce.jl:243; mapreduce_impl(f::typeof...
#   1╎    ╎    ╎    1    @Base/simdloop.jl:75; macro expansion
#    ╎    ╎    ╎    3    @Base/simdloop.jl:77; macro expansion
#    ╎    ╎    ╎     1    @Base/reduce.jl:244; macro expansion
#   1╎    ╎    ╎    ╎ 1    @Base/array.jl:801; getindex
#    ╎    ╎    ╎     2    @Base/reduce.jl:245; macro expansion
#    ╎    ╎    ╎    ╎ 2    @Base/reduce.jl:27; add_sum
#   2╎    ╎    ╎    ╎  2    @Base/float.jl:326; +
#    ╎    ╎    ╎    3    @Base/simdloop.jl:78; macro expansion
#   3╎    ╎    ╎     3    @Base/int.jl:87; +
#    ╎   6    ...HT/src/utilities.jl:728; linreg!(x::Vector{Float64}, y:...
#    ╎    6    @Base/reducedim.jl:873; sum
#    ╎     6    @Base/reducedim.jl:873; #sum#679
#    ╎    ╎ 6    @Base/reducedim.jl:877; _sum
#    ╎    ╎  6    @Base/reducedim.jl:877; #_sum#681
#    ╎    ╎   6    @Base/reducedim.jl:878; _sum
#    ╎    ╎    6    @Base/reducedim.jl:878; #_sum#682
#    ╎    ╎     6    @Base/reducedim.jl:310; mapreduce
#    ╎    ╎    ╎ 6    @Base/reducedim.jl:310; #mapreduce#672
#    ╎    ╎    ╎  6    @Base/reducedim.jl:318; _mapreduce_dim
#    ╎    ╎    ╎   6    @Base/reduce.jl:415; _mapreduce
#    ╎    ╎    ╎    6    @Base/reduce.jl:257; mapreduce_impl
#    ╎    ╎    ╎     6    @Base/reduce.jl:243; mapreduce_impl(f::type...
#    ╎    ╎    ╎    ╎ 4    @Base/simdloop.jl:77; macro expansion
#    ╎    ╎    ╎    ╎  4    @Base/reduce.jl:245; macro expansion
#    ╎    ╎    ╎    ╎   4    @Base/reduce.jl:27; add_sum
#   4╎    ╎    ╎    ╎    4    @Base/float.jl:326; +
#    ╎    ╎    ╎    ╎ 2    @Base/simdloop.jl:78; macro expansion
#   2╎    ╎    ╎    ╎  2    @Base/int.jl:87; +
#   5╎   5    ...HT/src/utilities.jl:730; linreg!(x::Vector{Float64}, y:...
#    ╎   33   ...HT/src/utilities.jl:731; linreg!(x::Vector{Float64}, y:...
#    ╎    33   ...ra/src/cholesky.jl:252; cholesky!
#    ╎     33   ...ra/src/cholesky.jl:252; cholesky!
#  33╎    ╎ 33   ...a/src/cholesky.jl:252; cholesky!(A::Symmetric{Float...
# Total snapshots: 1165

# %% [markdown]
# **Conclusion**:
# + `init_beta` consumes 33/409 samples from `fit_iht`, which is ok.
# + `score!` consumes 356/409 samples on `fit_iht!`, specifically, the line `SnpArrays.mul!(v.p_by_r, v.X, v.n_by_r)` which compute `SnpLinAlg`-matrix multiplication. This is expected.
# + `iht_stepsize!` (which inverts the covariance matrix) is not even sampled at all.

# %% [markdown]
# # Profile numeric matrices
#
# ## Univariate case

# %%
n = 1000  # number of samples
p = 10000 # number of SNPs
k = 10    # number of causal SNPs per trait
d = Normal
l = canonicallink(d())

# set random seed for reproducibility
Random.seed!(2021)

# simulate `.bed` file with no missing data
x = randn(n, p)

# intercept is the only nongenetic covariate
z = ones(n)
intercept = 1.0

# simulate response y, true model b, and the correct non-0 positions of b
Y, true_b, correct_position = simulate_random_response(x, k, d, l, Zu=z*intercept);

# run IHT
Random.seed!(2020)
@time result = fit_iht(Y, x, z);
speed_per_iter = result.time / result.iter
# Out:
# ****                   MendelIHT Version 1.4.0                  ****
# ****     Benjamin Chu, Kevin Keys, Chris German, Hua Zhou       ****
# ****   Jin Zhou, Eric Sobel, Janet Sinsheimer, Kenneth Lange    ****
# ****                                                            ****
# ****                 Please cite our paper!                     ****
# ****         https://doi.org/10.1093/gigascience/giaa044        ****
#
# Running sparse linear regression
# Link functin = IdentityLink()
# Sparsity parameter (k) = 10
# Prior weight scaling = off
# Doubly sparse projection = off
# Debias = off
# Max IHT iterations = 200
# Converging when tol < 0.0001:
#
# Iteration 1: loglikelihood = -1496.713961529228, backtracks = 0, tol = 0.42407482809494373
# Iteration 2: loglikelihood = -1440.396428956392, backtracks = 0, tol = 0.11860044142480099
# Iteration 3: loglikelihood = -1437.2177092287425, backtracks = 0, tol = 0.02302770129518664
# Iteration 4: loglikelihood = -1437.1722070780304, backtracks = 0, tol = 0.0027889369108425118
# Iteration 5: loglikelihood = -1437.1713084822375, backtracks = 0, tol = 0.0003953028766158861
# Iteration 6: loglikelihood = -1437.1712880425089, backtracks = 0, tol = 5.5490141042099236e-5
#   0.062282 seconds (139.09 k allocations: 3.304 MiB)
# 0.008611162503560385

# %% [markdown]
# ## Multivariate case

# %%
n = 1000  # number of samples
p = 10000 # number of SNPs
k = 10    # number of causal SNPs per trait
r = 2     # number of traits

# set random seed for reproducibility
Random.seed!(2022)

# simulate `.bed` file with no missing data
x = rand(0.:2., n, p)

# intercept is the only nongenetic covariate
z = ones(n, 1)
intercepts = randn(r)' # each trait have different intercept

# simulate response y, true model b, and the correct non-0 positions of b
Y, true_Σ, true_b, correct_position = simulate_random_response(x, k, r, Zu=z*intercepts, overlap=2);

# run IHT
Random.seed!(2020)
Yt = Matrix(Y')
Zt = Matrix(z')
Xt = Matrix(x')
@time result = fit_iht(Yt, Transpose(x), Zt, k = 20, max_iter=500);
speed_per_iter = result.time / result.iter
# Out:
# ****                   MendelIHT Version 1.4.0                  ****
# ****     Benjamin Chu, Kevin Keys, Chris German, Hua Zhou       ****
# ****   Jin Zhou, Eric Sobel, Janet Sinsheimer, Kenneth Lange    ****
# ****                                                            ****
# ****                 Please cite our paper!                     ****
# ****         https://doi.org/10.1093/gigascience/giaa044        ****
#
# Running sparse Multivariate Gaussian regression
# Link functin = IdentityLink()
# Sparsity parameter (k) = 20
# Prior weight scaling = off
# Doubly sparse projection = off
# Debias = off
# Max IHT iterations = 500
# Converging when tol < 0.0001:
#
# Iteration 1: loglikelihood = 191.73602048640578, backtracks = 0, tol = 0.2292371125117518
# Iteration 2: loglikelihood = 762.9277376172406, backtracks = 0, tol = 0.021360037643612592
# Iteration 3: loglikelihood = 884.2331365763932, backtracks = 0, tol = 0.02091394090715768
# Iteration 4: loglikelihood = 971.5768695868555, backtracks = 0, tol = 0.025650042181432565
# Iteration 5: loglikelihood = 1070.3071508501139, backtracks = 0, tol = 0.017265640322160526
# Iteration 6: loglikelihood = 1115.481929140687, backtracks = 0, tol = 0.034365269850100875
# Iteration 7: loglikelihood = 1182.519004345467, backtracks = 0, tol = 0.010322960424356764
# Iteration 8: loglikelihood = 1232.880104981737, backtracks = 0, tol = 0.024675793028653657
# Iteration 9: loglikelihood = 1292.9532868378444, backtracks = 0, tol = 0.02770021845447624
# Iteration 10: loglikelihood = 1332.2440462794211, backtracks = 0, tol = 0.008130924344834358
# Iteration 11: loglikelihood = 1378.5093686335272, backtracks = 0, tol = 0.01807978113360939
# Iteration 12: loglikelihood = 1417.073907310952, backtracks = 0, tol = 0.0159892886848576
# Iteration 13: loglikelihood = 1431.6621502869227, backtracks = 0, tol = 0.006653281776513292
# Iteration 14: loglikelihood = 1463.8705530888474, backtracks = 0, tol = 0.030036001483323665
# Iteration 15: loglikelihood = 1517.5690770142046, backtracks = 0, tol = 0.006084933983576127
# Iteration 16: loglikelihood = 1542.9618443997697, backtracks = 0, tol = 0.02879433840714019
# Iteration 17: loglikelihood = 1568.594783925591, backtracks = 0, tol = 0.0054899095403739715
# Iteration 18: loglikelihood = 1617.5263474499575, backtracks = 0, tol = 0.013192417789506894
# Iteration 19: loglikelihood = 1649.9050129133302, backtracks = 0, tol = 0.005175512613934254
# Iteration 20: loglikelihood = 1669.7856176589721, backtracks = 0, tol = 0.023877206023890235
# Iteration 21: loglikelihood = 1680.0376797276613, backtracks = 0, tol = 0.004448958655672293
# Iteration 22: loglikelihood = 1723.0269255461153, backtracks = 0, tol = 0.01047866972994391
# Iteration 23: loglikelihood = 1745.1896969401535, backtracks = 0, tol = 0.004741808030372114
# Iteration 24: loglikelihood = 1760.8992523942973, backtracks = 0, tol = 0.026493514911765614
# Iteration 25: loglikelihood = 1781.2454485511753, backtracks = 0, tol = 0.004334759172250856
# Iteration 26: loglikelihood = 1828.951469970274, backtracks = 0, tol = 0.005156362766532849
# Iteration 27: loglikelihood = 1841.9468421138167, backtracks = 0, tol = 0.009635190893601564
# Iteration 28: loglikelihood = 1854.8139913033951, backtracks = 0, tol = 0.0032070310184202965
# Iteration 29: loglikelihood = 1867.4909323450606, backtracks = 0, tol = 0.03748654165991623
# Iteration 30: loglikelihood = 1959.215185018816, backtracks = 0, tol = 0.010131830261107762
# Iteration 31: loglikelihood = 1984.9051698817452, backtracks = 0, tol = 0.002623129122446284
# Iteration 32: loglikelihood = 1994.8203663558722, backtracks = 0, tol = 0.008589467428411933
# Iteration 33: loglikelihood = 2012.949071051916, backtracks = 0, tol = 0.002750539613554889
# Iteration 34: loglikelihood = 2020.064929781384, backtracks = 0, tol = 0.003516641931436722
# Iteration 35: loglikelihood = 2026.7931991658895, backtracks = 0, tol = 0.007883519188683819
# Iteration 36: loglikelihood = 2034.8252463894328, backtracks = 0, tol = 0.0019018513116467134
# Iteration 37: loglikelihood = 2044.1165532989487, backtracks = 0, tol = 0.0021357288619395253
# Iteration 38: loglikelihood = 2047.9322117277577, backtracks = 0, tol = 0.05716827467951192
# Iteration 39: loglikelihood = 1959.766755342041, backtracks = 5, tol = 0.00013804570392730807
# Iteration 40: loglikelihood = 1965.059928398493, backtracks = 0, tol = 0.0043991382944948655
# Iteration 41: loglikelihood = 2094.316316180813, backtracks = 0, tol = 0.0019072108322471053
# Iteration 42: loglikelihood = 2116.74948555587, backtracks = 0, tol = 0.0010906154269509304
# Iteration 43: loglikelihood = 2120.9811857146187, backtracks = 0, tol = 0.0014056600632688125
# Iteration 44: loglikelihood = 2123.215860656934, backtracks = 0, tol = 0.01294728061828285
# Iteration 45: loglikelihood = 2131.003582716505, backtracks = 0, tol = 0.0010140256096837726
# Iteration 46: loglikelihood = 2135.6802634006985, backtracks = 0, tol = 0.0008642847951040848
# Iteration 47: loglikelihood = 2137.009064367138, backtracks = 0, tol = 0.005421767157444431
# Iteration 48: loglikelihood = 2140.9140264808766, backtracks = 0, tol = 0.0019585354069305313
# Iteration 49: loglikelihood = 2142.3813694228884, backtracks = 0, tol = 0.013108227201694035
# Iteration 50: loglikelihood = 2145.776780825231, backtracks = 0, tol = 0.0008755344806121519
# Iteration 51: loglikelihood = 2150.1182335725625, backtracks = 0, tol = 0.0007590910401385192
# Iteration 52: loglikelihood = 2151.1582282027243, backtracks = 0, tol = 0.0037512223978843594
# Iteration 53: loglikelihood = 2153.266134745263, backtracks = 0, tol = 0.004235400575913196
# Iteration 54: loglikelihood = 2155.5602943156246, backtracks = 0, tol = 0.002911862334197721
# Iteration 55: loglikelihood = 2157.1543050831488, backtracks = 0, tol = 0.007015428175391661
# Iteration 56: loglikelihood = 2160.3462040773106, backtracks = 0, tol = 0.0007710467032522672
# Iteration 57: loglikelihood = 2161.2367792079967, backtracks = 0, tol = 0.003978033227722414
# Iteration 58: loglikelihood = 2163.2703734090055, backtracks = 0, tol = 0.003011568081256592
# Iteration 59: loglikelihood = 2164.8292994345015, backtracks = 0, tol = 0.005812264887972884
# Iteration 60: loglikelihood = 2167.529870096958, backtracks = 0, tol = 0.001074564412535582
# Iteration 61: loglikelihood = 2168.305572706488, backtracks = 0, tol = 0.006851961567209912
# Iteration 62: loglikelihood = 2171.2180727138516, backtracks = 0, tol = 0.0007172525924096997
# Iteration 63: loglikelihood = 2172.0626305985097, backtracks = 0, tol = 0.0035229713629176575
# Iteration 64: loglikelihood = 2173.8036622219283, backtracks = 0, tol = 0.0035225413773834896
# Iteration 65: loglikelihood = 2175.5354785327577, backtracks = 0, tol = 0.003440749368116072
# Iteration 66: loglikelihood = 2177.2227832276326, backtracks = 0, tol = 0.0035701572304213517
# Iteration 67: loglikelihood = 2178.960197314254, backtracks = 0, tol = 0.003171476582628105
# Iteration 68: loglikelihood = 2180.51294371471, backtracks = 0, tol = 0.004178871758460913
# Iteration 69: loglikelihood = 2182.492237292582, backtracks = 0, tol = 0.0019992441282857716
# Iteration 70: loglikelihood = 2183.5083812409116, backtracks = 0, tol = 0.008643506996105126
# Iteration 71: loglikelihood = 2186.2634597020246, backtracks = 0, tol = 0.0004684690108216199
# Iteration 72: loglikelihood = 2187.709883010208, backtracks = 0, tol = 0.001307711279291694
# Iteration 73: loglikelihood = 2188.4607063974972, backtracks = 0, tol = 0.008098196417728775
# Iteration 74: loglikelihood = 2191.171628025695, backtracks = 0, tol = 0.00043947109581644184
# Iteration 75: loglikelihood = 2192.416004405335, backtracks = 0, tol = 0.0014620835175175669
# Iteration 76: loglikelihood = 2193.2018500436434, backtracks = 0, tol = 0.008510680984770931
# Iteration 77: loglikelihood = 2195.7914885876917, backtracks = 0, tol = 0.0004640604069702958
# Iteration 78: loglikelihood = 2197.245440491953, backtracks = 0, tol = 0.001193734050069803
# Iteration 79: loglikelihood = 2197.940553900342, backtracks = 0, tol = 0.0074122736693138565
# Iteration 80: loglikelihood = 2200.5145610476097, backtracks = 0, tol = 0.0004270041940699196
# Iteration 81: loglikelihood = 2201.5549307159695, backtracks = 0, tol = 0.001640265104893576
# Iteration 82: loglikelihood = 2202.383405854669, backtracks = 0, tol = 0.008236858820010717
# Iteration 83: loglikelihood = 2204.8323234472414, backtracks = 0, tol = 0.00045210527596898715
# Iteration 84: loglikelihood = 2206.229997664165, backtracks = 0, tol = 0.0011419937653449452
# Iteration 85: loglikelihood = 2206.887853412398, backtracks = 0, tol = 0.007067459943489918
# Iteration 86: loglikelihood = 2209.3252802291095, backtracks = 0, tol = 0.00042294411992699555
# Iteration 87: loglikelihood = 2210.2894254517446, backtracks = 0, tol = 0.0016395236690709624
# Iteration 88: loglikelihood = 2211.0975357157736, backtracks = 0, tol = 0.007827969097993161
# Iteration 89: loglikelihood = 2213.429952639904, backtracks = 0, tol = 0.000432260730496686
# Iteration 90: loglikelihood = 2214.7086637224697, backtracks = 0, tol = 0.0011478089649042153
# Iteration 91: loglikelihood = 2215.34423979986, backtracks = 0, tol = 0.007048976400950177
# Iteration 92: loglikelihood = 2217.6531056147114, backtracks = 0, tol = 0.00039109020041916366
# Iteration 93: loglikelihood = 2218.6490252818226, backtracks = 0, tol = 0.0014357012066123355
# Iteration 94: loglikelihood = 2219.36245723159, backtracks = 0, tol = 0.007661397383941276
# Iteration 95: loglikelihood = 2221.554674654979, backtracks = 0, tol = 0.000426387166111995
# Iteration 96: loglikelihood = 2222.8222412747705, backtracks = 0, tol = 0.001070978257668248
# Iteration 97: loglikelihood = 2223.417305094514, backtracks = 0, tol = 0.006594524787985083
# Iteration 98: loglikelihood = 2225.5999260946373, backtracks = 0, tol = 0.00039116320619878345
# Iteration 99: loglikelihood = 2226.4821390229968, backtracks = 0, tol = 0.0015223772579225298
# Iteration 100: loglikelihood = 2227.2079862941105, backtracks = 0, tol = 0.007253558939869261
# Iteration 101: loglikelihood = 2229.2931875211943, backtracks = 0, tol = 0.0004067104876960936
# Iteration 102: loglikelihood = 2230.443192424333, backtracks = 0, tol = 0.0010896078304098499
# Iteration 103: loglikelihood = 2231.021168645971, backtracks = 0, tol = 0.006646594059996735
# Iteration 104: loglikelihood = 2233.0806758139897, backtracks = 0, tol = 0.0003746447947418581
# Iteration 105: loglikelihood = 2234.01744125913, backtracks = 0, tol = 0.0012988610354885495
# Iteration 106: loglikelihood = 2234.646685119003, backtracks = 0, tol = 0.007105150351280813
# Iteration 107: loglikelihood = 2236.6001350963597, backtracks = 0, tol = 0.00040193091637765805
# Iteration 108: loglikelihood = 2237.7439616531765, backtracks = 0, tol = 0.0010168335629244113
# Iteration 109: loglikelihood = 2238.2845596951674, backtracks = 0, tol = 0.006245292845864789
# Iteration 110: loglikelihood = 2240.230399876368, backtracks = 0, tol = 0.0003561190388576903
# Iteration 111: loglikelihood = 2241.0684476138763, backtracks = 0, tol = 0.0013617695692803343
# Iteration 112: loglikelihood = 2241.701011915218, backtracks = 0, tol = 0.00682972315961455
# Iteration 113: loglikelihood = 2243.542406081842, backtracks = 0, tol = 0.0003899009042083472
# Iteration 114: loglikelihood = 2244.6247566234856, backtracks = 0, tol = 0.0009969835303817328
# Iteration 115: loglikelihood = 2245.1412187384226, backtracks = 0, tol = 0.006115667487787861
# Iteration 116: loglikelihood = 2246.973405677969, backtracks = 0, tol = 0.00035162716515846923
# Iteration 117: loglikelihood = 2247.8037077802774, backtracks = 0, tol = 0.0012681470447894177
# Iteration 118: loglikelihood = 2248.387669896121, backtracks = 0, tol = 0.006635524169506532
# Iteration 119: loglikelihood = 2250.112320553166, backtracks = 0, tol = 0.000382560952250903
# Iteration 120: loglikelihood = 2251.1667778241767, backtracks = 0, tol = 0.0009522451377829394
# Iteration 121: loglikelihood = 2251.6546756599696, backtracks = 0, tol = 0.005866701460863546
# Iteration 122: loglikelihood = 2253.380144944204, backtracks = 0, tol = 0.00034098424202437576
# Iteration 123: loglikelihood = 2254.1623211267943, backtracks = 0, tol = 0.0012557228476616803
# Iteration 124: loglikelihood = 2254.725592409404, backtracks = 0, tol = 0.02280288660716147
# Iteration 125: loglikelihood = 2263.274454528664, backtracks = 0, tol = 0.0015906144565574004
# Iteration 126: loglikelihood = 2277.954391702665, backtracks = 0, tol = 0.0014291898167459142
# Iteration 127: loglikelihood = 2281.8720646774805, backtracks = 0, tol = 0.008330832623550733
# Iteration 128: loglikelihood = 2291.0325712897, backtracks = 0, tol = 0.002715473796943137
# Iteration 129: loglikelihood = 2294.37661824695, backtracks = 0, tol = 0.0015179830239006795
# Iteration 130: loglikelihood = 2296.480076963896, backtracks = 0, tol = 0.008262563486333679
# Iteration 131: loglikelihood = 2304.927864977002, backtracks = 0, tol = 0.00818525431534331
# Iteration 132: loglikelihood = 2309.0877677971484, backtracks = 0, tol = 0.0009958717336992875
# Iteration 133: loglikelihood = 2313.7000999986594, backtracks = 0, tol = 0.0007463173185861159
# Iteration 134: loglikelihood = 2314.7957517075624, backtracks = 0, tol = 0.001421940809984668
# Iteration 135: loglikelihood = 2316.1837951546795, backtracks = 0, tol = 0.013166247291580791
# Iteration 136: loglikelihood = 2318.5813887716986, backtracks = 0, tol = 0.0008756987013052577
# Iteration 137: loglikelihood = 2325.17862245096, backtracks = 0, tol = 0.0004676290194375211
# Iteration 138: loglikelihood = 2326.372332546825, backtracks = 0, tol = 0.0005771670573021817
# Iteration 139: loglikelihood = 2326.916102616751, backtracks = 0, tol = 0.0029642994865185283
# Iteration 140: loglikelihood = 2328.7850928983135, backtracks = 0, tol = 0.004403415245309148
# Iteration 141: loglikelihood = 2331.417079660678, backtracks = 0, tol = 0.0010706617847464112
# Iteration 142: loglikelihood = 2332.106135136738, backtracks = 0, tol = 0.011539880580588585
# Iteration 143: loglikelihood = 2337.2004147643315, backtracks = 0, tol = 0.0004018513512484433
# Iteration 144: loglikelihood = 2338.60789087339, backtracks = 0, tol = 0.00046420983754725544
# Iteration 145: loglikelihood = 2339.0791975377315, backtracks = 0, tol = 0.001581190343343192
# Iteration 146: loglikelihood = 2339.974283429989, backtracks = 0, tol = 0.010051166053987336
# Iteration 147: loglikelihood = 2344.222282612597, backtracks = 0, tol = 0.0003595648099121411
# Iteration 148: loglikelihood = 2345.34820759303, backtracks = 0, tol = 0.0005108510345834034
# Iteration 149: loglikelihood = 2345.784290172974, backtracks = 0, tol = 0.002052768715262233
# Iteration 150: loglikelihood = 2346.8830166524394, backtracks = 0, tol = 0.005473065244747508
# Iteration 151: loglikelihood = 2349.5603346523008, backtracks = 0, tol = 0.0004833535254682989
# Iteration 152: loglikelihood = 2349.990487802349, backtracks = 0, tol = 0.0018585425628550524
# Iteration 153: loglikelihood = 2350.969573498789, backtracks = 0, tol = 0.006308346389190026
# Iteration 154: loglikelihood = 2353.868762234494, backtracks = 0, tol = 0.00036960405746902747
# Iteration 155: loglikelihood = 2354.3633936534798, backtracks = 0, tol = 0.001086083674105453
# Iteration 156: loglikelihood = 2354.954671842679, backtracks = 0, tol = 0.008730114182650973
# Iteration 157: loglikelihood = 2358.2935245793765, backtracks = 0, tol = 0.00033146493418445956
# Iteration 158: loglikelihood = 2359.299751271287, backtracks = 0, tol = 0.0005183604006522008
# Iteration 159: loglikelihood = 2359.6999946492283, backtracks = 0, tol = 0.0023560675386299253
# Iteration 160: loglikelihood = 2360.8727329044555, backtracks = 0, tol = 0.0028940237869612374
# Iteration 161: loglikelihood = 2362.2888174147733, backtracks = 0, tol = 0.0015634499682502052
# Iteration 162: loglikelihood = 2363.075695749561, backtracks = 0, tol = 0.007092936289712774
# Iteration 163: loglikelihood = 2365.8914872361042, backtracks = 0, tol = 0.00027723128411531674
# Iteration 164: loglikelihood = 2366.572379258215, backtracks = 0, tol = 0.0006706910232876595
# Iteration 165: loglikelihood = 2366.9770288463505, backtracks = 0, tol = 0.004453615485984517
# Iteration 166: loglikelihood = 2368.9828956591987, backtracks = 0, tol = 0.0005185709683387684
# Iteration 167: loglikelihood = 2369.359156616394, backtracks = 0, tol = 0.0025769350471417235
# Iteration 168: loglikelihood = 2370.58087987163, backtracks = 0, tol = 0.0018657952911717824
# Iteration 169: loglikelihood = 2371.4761932730416, backtracks = 0, tol = 0.004461431297222066
# Iteration 170: loglikelihood = 2373.4318317140323, backtracks = 0, tol = 0.00048286749109729374
# Iteration 171: loglikelihood = 2373.798508477471, backtracks = 0, tol = 0.002281053198001036
# Iteration 172: loglikelihood = 2374.865853911638, backtracks = 0, tol = 0.0024465869491328298
# Iteration 173: loglikelihood = 2376.0004065606963, backtracks = 0, tol = 0.0019526802675885906
# Iteration 174: loglikelihood = 2376.9125055359136, backtracks = 0, tol = 0.0036272344818156664
# Iteration 175: loglikelihood = 2378.513649457915, backtracks = 0, tol = 0.0006681473589634691
# Iteration 176: loglikelihood = 2378.890852567548, backtracks = 0, tol = 0.004814572703669344
# Iteration 177: loglikelihood = 2380.8620782541366, backtracks = 0, tol = 0.0003775881235658921
# Iteration 178: loglikelihood = 2381.2411817022694, backtracks = 0, tol = 0.0014282384667072795
# Iteration 179: loglikelihood = 2381.9044419536876, backtracks = 0, tol = 0.0064097308624162875
# Iteration 180: loglikelihood = 2384.140481261687, backtracks = 0, tol = 0.0002617119439653363
# Iteration 181: loglikelihood = 2384.800040842495, backtracks = 0, tol = 0.0006068812343742975
# Iteration 182: loglikelihood = 2385.1484112278267, backtracks = 0, tol = 0.004163335152212258
# Iteration 183: loglikelihood = 2386.8490962534297, backtracks = 0, tol = 0.0004404871194459201
# Iteration 184: loglikelihood = 2387.182861387303, backtracks = 0, tol = 0.002130923474243261
# Iteration 185: loglikelihood = 2388.1215604333306, backtracks = 0, tol = 0.0022857048329954126
# Iteration 186: loglikelihood = 2389.1192465774534, backtracks = 0, tol = 0.0018218109175786087
# Iteration 187: loglikelihood = 2389.9209278925255, backtracks = 0, tol = 0.0034200030301086066
# Iteration 188: loglikelihood = 2391.3336583883247, backtracks = 0, tol = 0.0006017911073152025
# Iteration 189: loglikelihood = 2391.665037897953, backtracks = 0, tol = 0.004370398045776062
# Iteration 190: loglikelihood = 2393.3434360474016, backtracks = 0, tol = 0.00035946142354854736
# Iteration 191: loglikelihood = 2393.6834446496537, backtracks = 0, tol = 0.0014733618460218095
# Iteration 192: loglikelihood = 2394.32418126336, backtracks = 0, tol = 0.0051531409988799515
# Iteration 193: loglikelihood = 2396.124239965036, backtracks = 0, tol = 0.0002539839052693982
# Iteration 194: loglikelihood = 2396.574819531471, backtracks = 0, tol = 0.0008053699085912325
# Iteration 195: loglikelihood = 2396.951200390103, backtracks = 0, tol = 0.00672463168375739
# Iteration 196: loglikelihood = 2398.772669347814, backtracks = 0, tol = 0.0002891844203637974
# Iteration 197: loglikelihood = 2399.676745926087, backtracks = 0, tol = 0.0004179176626746138
# Iteration 198: loglikelihood = 2399.9734573683963, backtracks = 0, tol = 0.0021922192820200232
# Iteration 199: loglikelihood = 2400.8718366524395, backtracks = 0, tol = 0.0015738857554980859
# Iteration 200: loglikelihood = 2401.5264503986996, backtracks = 0, tol = 0.003938960185395666
# Iteration 201: loglikelihood = 2402.969371445583, backtracks = 0, tol = 0.0003586941528690383
# Iteration 202: loglikelihood = 2403.27024037535, backtracks = 0, tol = 0.0016527688493255348
# Iteration 203: loglikelihood = 2403.945960232637, backtracks = 0, tol = 0.0033045625733307228
# Iteration 204: loglikelihood = 2405.192094703379, backtracks = 0, tol = 0.00048546351190561577
# Iteration 205: loglikelihood = 2405.469869244129, backtracks = 0, tol = 0.003297152872145087
# Iteration 206: loglikelihood = 2406.698906007162, backtracks = 0, tol = 0.00047183748206198426
# Iteration 207: loglikelihood = 2406.971411849488, backtracks = 0, tol = 0.0031668558963782512
# Iteration 208: loglikelihood = 2408.1484017412376, backtracks = 0, tol = 0.0004977881400387432
# Iteration 209: loglikelihood = 2408.4189041004615, backtracks = 0, tol = 0.003604845662182439
# Iteration 210: loglikelihood = 2409.6963541079617, backtracks = 0, tol = 0.00036642035888012533
# Iteration 211: loglikelihood = 2409.967989263697, backtracks = 0, tol = 0.0019040873162027786
# Iteration 212: loglikelihood = 2410.7071180427006, backtracks = 0, tol = 0.0018547862211485838
# Iteration 213: loglikelihood = 2411.4247110271826, backtracks = 0, tol = 0.0019673992571990094
# Iteration 214: loglikelihood = 2412.17889363056, backtracks = 0, tol = 0.0016118586737509711
# Iteration 215: loglikelihood = 2412.801351734067, backtracks = 0, tol = 0.0028598137252843522
# Iteration 216: loglikelihood = 2413.8356178607537, backtracks = 0, tol = 0.0005445526833155647
# Iteration 217: loglikelihood = 2414.097352329711, backtracks = 0, tol = 0.0045666628285050805
# Iteration 218: loglikelihood = 2415.4457573055242, backtracks = 0, tol = 0.00020309939866419854
# Iteration 219: loglikelihood = 2415.8554733204423, backtracks = 0, tol = 0.0006758757314742126
# Iteration 220: loglikelihood = 2416.142796396166, backtracks = 0, tol = 0.00610697124484533
# Iteration 221: loglikelihood = 2417.3619175119593, backtracks = 0, tol = 0.0002835650378534218
# Iteration 222: loglikelihood = 2418.293806946504, backtracks = 0, tol = 0.00032681163364429284
# Iteration 223: loglikelihood = 2418.5437912639686, backtracks = 0, tol = 0.001690434731584228
# Iteration 224: loglikelihood = 2419.1643042318956, backtracks = 0, tol = 0.0020719326113657604
# Iteration 225: loglikelihood = 2419.9086305160367, backtracks = 0, tol = 0.0010869763055892678
# Iteration 226: loglikelihood = 2420.314647860084, backtracks = 0, tol = 0.005627242982986544
# Iteration 227: loglikelihood = 2421.4608857039198, backtracks = 0, tol = 0.00026296427965495693
# Iteration 228: loglikelihood = 2422.2533930465997, backtracks = 0, tol = 0.0003433260793543842
# Iteration 229: loglikelihood = 2422.482170265646, backtracks = 0, tol = 0.002021070265083102
# Iteration 230: loglikelihood = 2423.1890628533793, backtracks = 0, tol = 0.0010499276138114736
# Iteration 231: loglikelihood = 2423.57138242023, backtracks = 0, tol = 0.005593010715760281
# Iteration 232: loglikelihood = 2424.6018279492155, backtracks = 0, tol = 0.00026667204140522346
# Iteration 233: loglikelihood = 2425.4316260921505, backtracks = 0, tol = 0.0003161047549915597
# Iteration 234: loglikelihood = 2425.654432467926, backtracks = 0, tol = 0.0017980083356526019
# Iteration 235: loglikelihood = 2426.2718466075485, backtracks = 0, tol = 0.0013461828184851133
# Iteration 236: loglikelihood = 2426.74035475377, backtracks = 0, tol = 0.0031536672307655835
# Iteration 237: loglikelihood = 2427.6902285652777, backtracks = 0, tol = 0.00029119576173605217
# Iteration 238: loglikelihood = 2427.9114366404397, backtracks = 0, tol = 0.0015966130372800699
# Iteration 239: loglikelihood = 2428.4527889588694, backtracks = 0, tol = 0.0017998704274128968
# Iteration 240: loglikelihood = 2429.0538877777794, backtracks = 0, tol = 0.0012069375122393056
# Iteration 241: loglikelihood = 2429.465373217214, backtracks = 0, tol = 0.003824910023206804
# Iteration 242: loglikelihood = 2430.4470812154923, backtracks = 0, tol = 0.0001812894713141627
# Iteration 243: loglikelihood = 2430.770348053056, backtracks = 0, tol = 0.0006704121957441745
# Iteration 244: loglikelihood = 2431.0136932411756, backtracks = 0, tol = 0.006285617646182696
# Iteration 245: loglikelihood = 2431.4257384531597, backtracks = 0, tol = 0.00033067242556877315
# Iteration 246: loglikelihood = 2432.830334180449, backtracks = 0, tol = 0.00019495190534737661
# Iteration 247: loglikelihood = 2433.09996096331, backtracks = 0, tol = 0.0008182690943024738
# Iteration 248: loglikelihood = 2433.376850731761, backtracks = 0, tol = 0.006104081025365011
# Iteration 249: loglikelihood = 2433.726226092155, backtracks = 0, tol = 0.0003254322998985586
# Iteration 250: loglikelihood = 2435.0930359093154, backtracks = 0, tol = 0.0001887366855136265
# Iteration 251: loglikelihood = 2435.35307988741, backtracks = 0, tol = 0.0008104587003425972
# Iteration 252: loglikelihood = 2435.6201815791587, backtracks = 0, tol = 0.005984578465194541
# Iteration 253: loglikelihood = 2435.880938459323, backtracks = 0, tol = 0.0003244366099398242
# Iteration 254: loglikelihood = 2437.2500356005503, backtracks = 0, tol = 0.0001790222533032391
# Iteration 255: loglikelihood = 2437.505822884831, backtracks = 0, tol = 0.0007776403504700219
# Iteration 256: loglikelihood = 2437.756493068632, backtracks = 0, tol = 0.005974920321937194
# Iteration 257: loglikelihood = 2437.866099151055, backtracks = 0, tol = 0.0003318190193164707
# Iteration 258: loglikelihood = 2439.31852870725, backtracks = 0, tol = 0.00016640784230063542
# Iteration 259: loglikelihood = 2439.58083607597, backtracks = 0, tol = 0.0007010189670236309
# Iteration 260: loglikelihood = 2439.8042164726335, backtracks = 0, tol = 0.006087952239565235
# Iteration 261: loglikelihood = 2439.6667919663514, backtracks = 5, tol = 1.0925270331339517e-5
#   6.650031 seconds (61.45 k allocations: 46.840 MiB)
# 0.024981919833070017

# %%
# first beta
β1 = result.beta[1, :]
true_b1_idx = findall(!iszero, true_b[:, 1])
[β1[true_b1_idx] true_b[true_b1_idx, 1]]
# Out:
# 3×2 Array{Float64,2}:
#  -1.32085   -1.50987
#  -0.457323  -0.619427
#  -1.80573   -1.84578

# %%
# second beta
β2 = result.beta[2, :]
true_b2_idx = findall(!iszero, true_b[:, 2])
[β2[true_b2_idx] true_b[true_b2_idx, 2]]
# Out:
# 7×2 Array{Float64,2}:
#  -0.257583  -0.308054
#  -0.665576  -0.54334
#   0.629238   0.586241
#   0.0       -0.0183675
#  -1.49299   -1.51484
#  -0.329601  -0.360181
#   2.04007    2.0501

# %%
# non genetic covariates
[result.c intercepts']
# Out:
# 2×2 Array{Float64,2}:
#  -0.326767   0.900301
#   0.0       -0.151044

# %%
# covariance matrix
[vec(result.Σ) vec(true_Σ)]
# Out:
# 4×2 Array{Float64,2}:
#   1.73172   1.69161
#  -1.62934  -1.57315
#  -1.62934  -1.57315
#   1.77269   1.69077
