# %% [markdown]
# # Normal: compare false positive/negatives with LASSO
#
# LASSO is currently the de facto penalized least squares method for [feature selection](https://en.wikipedia.org/wiki/Feature_selection). Here we compare the performance (in terms of the number of false positives/negative) of LASSO with IHT for GWAS data, using the `glmnet` implementation of cyclic coordinate descent for LASSO. Since the focus here is not scalability, we test our sample problems on moderately sized genotype matrces of 1000 samples with 10,000 SNPs.

# %%
using Distributed
addprocs(4)
nprocs()
# Out:
# 5

# %%
using MendelIHT
using SnpArrays
using DataFrames
using Distributions
using Random
using LinearAlgebra
using DelimitedFiles
using GLM
using RCall
R"library(glmnet)"
# Out:
# ┌ Info: Recompiling stale cache file /u/home/b/biona001/.julia/compiled/v1.0/MendelIHT/eaqWB.ji for MendelIHT [921c7187-1484-5754-b919-5d3ed9ac03c4]
# └ @ Base loading.jl:1187
# ┌ Info: Recompiling stale cache file /u/home/b/biona001/.julia/compiled/v1.0/Plots/ld3vC.ji for Plots [91a5bcdd-55d7-5caf-9e0b-520d859cae80]
# └ @ Base loading.jl:1187
# ┌ Info: Recompiling stale cache file /u/home/b/biona001/.julia/compiled/v1.0/RCall/8GFyb.ji for RCall [6f49c342-dc21-5d91-9882-a32aef131414]
# └ @ Base loading.jl:1187
# ┌ Warning: RCall.jl: During startup - Warning message:
# │ Setting LC_CTYPE failed, using "C"
# └ @ RCall /u/home/b/biona001/.julia/packages/RCall/ffM0W/src/io.jl:113
# ┌ Warning: RCall.jl: During startup - Warning message:
# │ Setting LC_CTYPE failed, using "C"
# └ @ RCall ~/.julia/packages/RCall/ffM0W/src/io.jl:113
# ┌ Warning: RCall.jl: During startup - Warning message:
# │ Setting LC_CTYPE failed, using "C"
# └ @ RCall ~/.julia/packages/RCall/ffM0W/src/io.jl:113
# ┌ Warning: RCall.jl: During startup - Warning message:
# │ Setting LC_CTYPE failed, using "C"
# └ @ RCall ~/.julia/packages/RCall/ffM0W/src/io.jl:113
# ┌ Warning: RCall.jl: During startup - Warning message:
# │ Setting LC_CTYPE failed, using "C"
# └ @ RCall ~/.julia/packages/RCall/ffM0W/src/io.jl:113
# ┌ Warning: RCall.jl: Loading required package: Matrix
# │ Loading required package: foreach
# │ Loaded glmnet 2.0-16
# │
# └ @ RCall /u/home/b/biona001/.julia/packages/RCall/ffM0W/src/io.jl:113
# RObject{StrSxp}
#  [1] "glmnet"    "foreach"   "Matrix"    "stats"     "graphics"  "grDevices"
#  [7] "utils"     "datasets"  "methods"   "base"

# %% [markdown]
# # How we ran LASSO
#
# We use the R library `glmnet` (implemented in Fortran) to run LASSO. [Documentation of Rcall.jl](http://juliainterop.github.io/RCall.jl/stable/gettingstarted.html) teaches us to to transfer variables between R and Julia. Since glmnet does not operate on genotype file, we need to convert `x` to Float64, and then run `glmnet`. We chose to run IHT across 50 different model sizes $\{1,2,...,50\}$ because the best model selected by LASSO averages to about 25 non-zero predictors, so we doubled that number.

# %%
function iht_lasso(n::Int64, p::Int64, k::Int64, d::UnionAll, l::Link)
    #construct snpmatrix, covariate files, and true model b
    x, = simulate_random_snparray(n, p, undef)
    xbm = SnpBitMatrix{Float64}(x, model=ADDITIVE_MODEL, center=true, scale=true); 
    z = ones(n, 1) # the intercept
    x_float = [convert(Matrix{Float64}, x, center=true, scale=true) z] #Float64 version of x

    # simulate response, true model b, and the correct non-0 positions of b
    y, true_b, correct_position = simulate_random_response(x, xbm, k, d, l)
 
    #specify path and folds
    num_folds = 3
    folds = rand(1:num_folds, size(x, 1));

    #run glmnet via Rcall
    @rput x_float y folds num_folds #make variables visible to R
    R"lasso_cv_result = cv.glmnet(x_float, y, nfolds = num_folds, foldid = folds)"
    R"lasso_beta_tmp = glmnet(x_float, y, lambda=lasso_cv_result$lambda.min)$beta"
    R"lasso_beta = as.vector(lasso_beta_tmp)"
    @rget lasso_cv_result lasso_beta #pull result from R to Julia
    lasso_k_est = count(!iszero, lasso_beta)
    
    #find non-zero entries returned by best lasso model as largest k estimate
    path = collect(1:50);
    
    #run IHT's cross validation routine 
    mses = cv_iht_distributed(d(), l, x, z, y, 1, path, folds, num_folds, use_maf=false, debias=false, showinfo=false, parallel=true);
    iht_k_est = argmin(mses)
    iht_result = L0_reg(x, xbm, z, y, 1, iht_k_est, d(), l, debias=false, init=false, use_maf=false)
    iht_beta = iht_result.beta
        
    #show lasso and IHT's reconstruction result
    compare_model = DataFrame(
        true_β  = true_b[correct_position], 
        IHT_β   = iht_beta[correct_position],
        lasso_β = lasso_beta[correct_position])
    @show compare_model
    
    #compute true/false positives/negatives for IHT and lasso
    iht_tp = count(!iszero, iht_beta[correct_position])
    iht_fp = iht_k_est - iht_tp
    iht_fn = k - iht_tp
    lasso_tp = count(!iszero, lasso_beta[correct_position])
    lasso_fp = lasso_k_est - lasso_tp
    lasso_fn = k - lasso_tp
    
    println("IHT false positives = $iht_fp")
    println("IHT false negatives = $iht_fn")
    println("LASSO false positives = $lasso_fp")
    println("LASSO false positives = $lasso_fn" * "\n")
    
    return iht_fp, iht_fn, lasso_fp, lasso_fn
end
# Out:
# iht_lasso (generic function with 1 method)

# %% [markdown]
# # Normal response

# %%
#simulat data with k true predictors, from distribution d and with link l.
n = 1000
p = 10000
k = 10
d = Normal
l = canonicallink(d())

#set random seed
Random.seed!(2019)

#run function above, saving results in 4 vectors
total_runs = 50
iht_false_positives = zeros(total_runs)
iht_false_negatives = zeros(total_runs)
lasso_false_positives = zeros(total_runs)
lasso_false_negatives = zeros(total_runs)
for i in 1:total_runs
    println("current run = $i")
    iht_fp, iht_fn, lasso_fp, lasso_fn = iht_lasso(n, p, k, d, l)
    iht_false_positives[i] = iht_fp
    iht_false_negatives[i] = iht_fn
    lasso_false_positives[i] = lasso_fp
    lasso_false_negatives[i] = lasso_fn
end
# Out:
# current run = 1
# compare_model = 10×3 DataFrame
# │ Row │ true_β   │ IHT_β     │ lasso_β   │
# │     │ Float64  │ Float64   │ Float64   │
# ├─────┼──────────┼───────────┼───────────┤
# │ 1   │ -1.29964 │ -1.24117  │ -1.14111  │
# │ 2   │ -0.2177  │ -0.234676 │ -0.124249 │
# │ 3   │ 0.786217 │ 0.820139  │ 0.710232  │
# │ 4   │ 0.599233 │ 0.583405  │ 0.481213  │
# │ 5   │ 0.283711 │ 0.298299  │ 0.199136  │
# │ 6   │ -1.12537 │ -1.14459  │ -1.0404   │
# │ 7   │ 0.693374 │ 0.673006  │ 0.588039  │
# │ 8   │ -0.67709 │ -0.709737 │ -0.626146 │
# │ 9   │ 0.14727  │ 0.16866   │ 0.0654867 │
# │ 10  │ 1.03477  │ 1.08116   │ 0.967405  │
# IHT false positives = 0
# IHT false negatives = 0
# LASSO false positives = 23
# LASSO false positives = 0
#
# current run = 2
# compare_model = 10×3 DataFrame
# │ Row │ true_β    │ IHT_β     │ lasso_β    │
# │     │ Float64   │ Float64   │ Float64    │
# ├─────┼───────────┼───────────┼────────────┤
# │ 1   │ 0.402907  │ 0.435489  │ 0.328459   │
# │ 2   │ 1.0652    │ 1.114     │ 1.01424    │
# │ 3   │ 1.70025   │ 1.63508   │ 1.5333     │
# │ 4   │ 0.958396  │ 0.881836  │ 0.776924   │
# │ 5   │ -0.591667 │ -0.572008 │ -0.461048  │
# │ 6   │ -0.843279 │ -0.861092 │ -0.759079  │
# │ 7   │ 0.808416  │ 0.779573  │ 0.677163   │
# │ 8   │ -0.266225 │ -0.224195 │ -0.128166  │
# │ 9   │ -0.202052 │ -0.187928 │ -0.0603049 │
# │ 10  │ 0.947818  │ 0.94391   │ 0.858604   │
# IHT false positives = 1
# IHT false negatives = 0
# LASSO false positives = 20
# LASSO false positives = 0
#
# current run = 3
# compare_model = 10×3 DataFrame
# │ Row │ true_β     │ IHT_β     │ lasso_β   │
# │     │ Float64    │ Float64   │ Float64   │
# ├─────┼────────────┼───────────┼───────────┤
# │ 1   │ 0.82617    │ 0.816955  │ 0.716936  │
# │ 2   │ -0.239796  │ -0.285488 │ -0.186181 │
# │ 3   │ -0.619471  │ -0.553541 │ -0.459789 │
# │ 4   │ 0.104725   │ 0.0       │ 0.0       │
# │ 5   │ -0.348812  │ -0.362273 │ -0.270661 │
# │ 6   │ 0.569118   │ 0.510122  │ 0.420509  │
# │ 7   │ 0.945753   │ 0.930583  │ 0.821947  │
# │ 8   │ 0.290317   │ 0.249951  │ 0.152909  │
# │ 9   │ -0.238683  │ -0.235828 │ -0.151928 │
# │ 10  │ 0.00937404 │ 0.0       │ 0.0       │
# IHT false positives = 0
# IHT false negatives = 2
# LASSO false positives = 52
# LASSO false positives = 2
#
# current run = 4
# compare_model = 10×3 DataFrame
# │ Row │ true_β     │ IHT_β     │ lasso_β    │
# │     │ Float64    │ Float64   │ Float64    │
# ├─────┼────────────┼───────────┼────────────┤
# │ 1   │ 1.83546    │ 1.83471   │ 1.72623    │
# │ 2   │ -1.59048   │ -1.60236  │ -1.51228   │
# │ 3   │ -0.823109  │ -0.785709 │ -0.679186  │
# │ 4   │ -1.15728   │ -1.10213  │ -0.99224   │
# │ 5   │ 1.70942    │ 1.68685   │ 1.60246    │
# │ 6   │ -0.0239156 │ 0.0       │ 0.0        │
# │ 7   │ -0.106773  │ 0.0       │ -0.0279146 │
# │ 8   │ -0.547578  │ -0.545289 │ -0.453916  │
# │ 9   │ -0.349837  │ -0.402927 │ -0.311952  │
# │ 10  │ 0.972382   │ 0.983907  │ 0.882386   │
# IHT false positives = 0
# IHT false negatives = 2
# LASSO false positives = 45
# LASSO false positives = 1
#
# current run = 5
# compare_model = 10×3 DataFrame
# │ Row │ true_β    │ IHT_β     │ lasso_β   │
# │     │ Float64   │ Float64   │ Float64   │
# ├─────┼───────────┼───────────┼───────────┤
# │ 1   │ -0.806624 │ -0.804601 │ -0.682293 │
# │ 2   │ 0.346669  │ 0.320606  │ 0.194244  │
# │ 3   │ -0.702952 │ -0.700851 │ -0.585104 │
# │ 4   │ 1.86822   │ 1.90847   │ 1.79384   │
# │ 5   │ -0.608564 │ -0.561798 │ -0.450964 │
# │ 6   │ -0.675667 │ -0.600638 │ -0.483607 │
# │ 7   │ 0.360639  │ 0.326624  │ 0.214201  │
# │ 8   │ -0.466695 │ -0.451843 │ -0.35596  │
# │ 9   │ -0.684112 │ -0.610104 │ -0.486493 │
# │ 10  │ -0.716234 │ -0.733509 │ -0.615359 │
# IHT false positives = 0
# IHT false negatives = 0
# LASSO false positives = 15
# LASSO false positives = 0
#
# current run = 6
# compare_model = 10×3 DataFrame
# │ Row │ true_β      │ IHT_β     │ lasso_β   │
# │     │ Float64     │ Float64   │ Float64   │
# ├─────┼─────────────┼───────────┼───────────┤
# │ 1   │ -0.00283651 │ 0.0       │ 0.0       │
# │ 2   │ 0.632895    │ 0.641733  │ 0.534288  │
# │ 3   │ -0.417821   │ -0.471049 │ -0.362064 │
# │ 4   │ 0.58994     │ 0.654802  │ 0.55219   │
# │ 5   │ -0.333628   │ -0.346856 │ -0.24605  │
# │ 6   │ 0.786003    │ 0.761726  │ 0.685101  │
# │ 7   │ -1.16849    │ -1.18119  │ -1.09682  │
# │ 8   │ -2.09712    │ -2.10973  │ -2.0203   │
# │ 9   │ -0.232465   │ -0.257654 │ -0.160844 │
# │ 10  │ -0.372841   │ -0.352163 │ -0.245082 │
# IHT false positives = 0
# IHT false negatives = 1
# LASSO false positives = 32
# LASSO false positives = 1
#
# current run = 7
# compare_model = 10×3 DataFrame
# │ Row │ true_β     │ IHT_β     │ lasso_β   │
# │     │ Float64    │ Float64   │ Float64   │
# ├─────┼────────────┼───────────┼───────────┤
# │ 1   │ 1.16641    │ 1.16187   │ 1.07312   │
# │ 2   │ 1.77868    │ 1.74373   │ 1.64332   │
# │ 3   │ -0.688293  │ -0.677932 │ -0.585826 │
# │ 4   │ -0.0578661 │ 0.0       │ 0.0       │
# │ 5   │ 1.0115     │ 1.06722   │ 0.979056  │
# │ 6   │ 0.488626   │ 0.443875  │ 0.352122  │
# │ 7   │ -1.10633   │ -1.08241  │ -0.988284 │
# │ 8   │ -0.986752  │ -1.01129  │ -0.910542 │
# │ 9   │ 0.603707   │ 0.544479  │ 0.453555  │
# │ 10  │ -0.725386  │ -0.730827 │ -0.63321  │
# IHT false positives = 0
# IHT false negatives = 1
# LASSO false positives = 23
# LASSO false positives = 1
#
# current run = 8
# compare_model = 10×3 DataFrame
# │ Row │ true_β   │ IHT_β    │ lasso_β  │
# │     │ Float64  │ Float64  │ Float64  │
# ├─────┼──────────┼──────────┼──────────┤
# │ 1   │ 1.03566  │ 1.0358   │ 0.938401 │
# │ 2   │ 0.651499 │ 0.705162 │ 0.606364 │
# │ 3   │ 2.30418  │ 2.28975  │ 2.19062  │
# │ 4   │ 0.351846 │ 0.383999 │ 0.290708 │
# │ 5   │ 0.565761 │ 0.640477 │ 0.548878 │
# │ 6   │ 1.33387  │ 1.40438  │ 1.30225  │
# │ 7   │ 1.0617   │ 1.0088   │ 0.931227 │
# │ 8   │ 2.3738   │ 2.37164  │ 2.2737   │
# │ 9   │ 0.292412 │ 0.34344  │ 0.252767 │
# │ 10  │ 1.13804  │ 1.15882  │ 1.06602  │
# IHT false positives = 0
# IHT false negatives = 0
# LASSO false positives = 43
# LASSO false positives = 0
#
# current run = 9
# compare_model = 10×3 DataFrame
# │ Row │ true_β    │ IHT_β     │ lasso_β   │
# │     │ Float64   │ Float64   │ Float64   │
# ├─────┼───────────┼───────────┼───────────┤
# │ 1   │ -1.29956  │ -1.27408  │ -1.18794  │
# │ 2   │ 0.0378833 │ 0.0       │ 0.0       │
# │ 3   │ -1.87841  │ -1.86657  │ -1.75789  │
# │ 4   │ 1.22847   │ 1.24587   │ 1.15285   │
# │ 5   │ -1.06092  │ -1.05738  │ -0.95346  │
# │ 6   │ -0.628201 │ -0.649721 │ -0.55457  │
# │ 7   │ -0.215611 │ -0.206988 │ -0.124032 │
# │ 8   │ -0.565184 │ -0.572072 │ -0.471347 │
# │ 9   │ -0.923484 │ -0.959686 │ -0.864386 │
# │ 10  │ -0.60896  │ -0.637882 │ -0.519608 │
# IHT false positives = 0
# IHT false negatives = 1
# LASSO false positives = 19
# LASSO false positives = 1
#
# current run = 10
# compare_model = 10×3 DataFrame
# │ Row │ true_β     │ IHT_β     │ lasso_β   │
# │     │ Float64    │ Float64   │ Float64   │
# ├─────┼────────────┼───────────┼───────────┤
# │ 1   │ 0.240557   │ 0.206904  │ 0.1068    │
# │ 2   │ 1.3491     │ 1.30945   │ 1.20506   │
# │ 3   │ -1.12465   │ -1.13861  │ -1.02776  │
# │ 4   │ -0.0117735 │ 0.0       │ 0.0       │
# │ 5   │ -0.751604  │ -0.752918 │ -0.641537 │
# │ 6   │ 0.0684607  │ 0.0       │ 0.0       │
# │ 7   │ 0.492597   │ 0.49461   │ 0.399727  │
# │ 8   │ -0.0646674 │ 0.0       │ 0.0       │
# │ 9   │ 0.281111   │ 0.295117  │ 0.189253  │
# │ 10  │ -0.083208  │ 0.0       │ 0.0       │
# IHT false positives = 0
# IHT false negatives = 4
# LASSO false positives = 15
# LASSO false positives = 4
#
# current run = 11
# compare_model = 10×3 DataFrame
# │ Row │ true_β    │ IHT_β     │ lasso_β    │
# │     │ Float64   │ Float64   │ Float64    │
# ├─────┼───────────┼───────────┼────────────┤
# │ 1   │ -0.185883 │ 0.0       │ -0.0440979 │
# │ 2   │ 0.177059  │ 0.205389  │ 0.105256   │
# │ 3   │ -1.28722  │ -1.27868  │ -1.16491   │
# │ 4   │ -0.564181 │ -0.576018 │ -0.457873  │
# │ 5   │ -0.660923 │ -0.631576 │ -0.523875  │
# │ 6   │ -0.806239 │ -0.839011 │ -0.741959  │
# │ 7   │ 1.24115   │ 1.28603   │ 1.1967     │
# │ 8   │ 0.990623  │ 0.94862   │ 0.855225   │
# │ 9   │ -0.213355 │ -0.237755 │ -0.139957  │
# │ 10  │ 0.389716  │ 0.366782  │ 0.275746   │
# IHT false positives = 0
# IHT false negatives = 1
# LASSO false positives = 29
# LASSO false positives = 0
#
# current run = 12
# compare_model = 10×3 DataFrame
# │ Row │ true_β     │ IHT_β     │ lasso_β   │
# │     │ Float64    │ Float64   │ Float64   │
# ├─────┼────────────┼───────────┼───────────┤
# │ 1   │ -0.0284436 │ 0.0       │ 0.0       │
# │ 2   │ -1.39381   │ -1.32755  │ -1.22314  │
# │ 3   │ -0.849352  │ -0.865414 │ -0.756373 │
# │ 4   │ 0.899294   │ 0.862909  │ 0.770499  │
# │ 5   │ 0.3139     │ 0.33078   │ 0.221283  │
# │ 6   │ -1.3748    │ -1.40081  │ -1.28131  │
# │ 7   │ -0.294593  │ -0.347015 │ -0.249192 │
# │ 8   │ 0.349643   │ 0.330524  │ 0.234096  │
# │ 9   │ 1.21517    │ 1.20793   │ 1.11324   │
# │ 10  │ 0.496945   │ 0.466088  │ 0.367688  │
# IHT false positives = 0
# IHT false negatives = 1
# LASSO false positives = 19
# LASSO false positives = 1
#
# current run = 13
# compare_model = 10×3 DataFrame
# │ Row │ true_β     │ IHT_β     │ lasso_β   │
# │     │ Float64    │ Float64   │ Float64   │
# ├─────┼────────────┼───────────┼───────────┤
# │ 1   │ -0.667715  │ -0.647928 │ -0.529859 │
# │ 2   │ 0.43451    │ 0.457948  │ 0.362281  │
# │ 3   │ 1.41509    │ 1.42004   │ 1.32082   │
# │ 4   │ 0.00572666 │ 0.0       │ 0.0       │
# │ 5   │ -1.21435   │ -1.22205  │ -1.13644  │
# │ 6   │ -0.518006  │ -0.564174 │ -0.456496 │
# │ 7   │ 1.25059    │ 1.26162   │ 1.16234   │
# │ 8   │ -0.74944   │ -0.78296  │ -0.672418 │
# │ 9   │ 0.578398   │ 0.584672  │ 0.484756  │
# │ 10  │ -0.921634  │ -0.882623 │ -0.790801 │
# IHT false positives = 0
# IHT false negatives = 1
# LASSO false positives = 12
# LASSO false positives = 1
#
# current run = 14
# compare_model = 10×3 DataFrame
# │ Row │ true_β     │ IHT_β     │ lasso_β   │
# │     │ Float64    │ Float64   │ Float64   │
# ├─────┼────────────┼───────────┼───────────┤
# │ 1   │ 1.29344    │ 1.26298   │ 1.17059   │
# │ 2   │ 0.364539   │ 0.402154  │ 0.31451   │
# │ 3   │ -0.0537018 │ 0.0       │ 0.0       │
# │ 4   │ 0.238197   │ 0.285477  │ 0.210175  │
# │ 5   │ -0.653942  │ -0.649307 │ -0.574546 │
# │ 6   │ -0.297883  │ -0.306792 │ -0.221034 │
# │ 7   │ -0.315342  │ -0.291943 │ -0.201372 │
# │ 8   │ 1.91569    │ 1.92175   │ 1.83834   │
# │ 9   │ -0.322342  │ -0.287814 │ -0.207936 │
# │ 10  │ -0.234379  │ -0.259068 │ -0.17219  │
# IHT false positives = 0
# IHT false negatives = 1
# LASSO false positives = 68
# LASSO false positives = 1
#
# current run = 15
# compare_model = 10×3 DataFrame
# │ Row │ true_β    │ IHT_β     │ lasso_β   │
# │     │ Float64   │ Float64   │ Float64   │
# ├─────┼───────────┼───────────┼───────────┤
# │ 1   │ -0.46621  │ -0.509949 │ -0.410091 │
# │ 2   │ 0.0512316 │ 0.0       │ 0.0       │
# │ 3   │ 0.520905  │ 0.462113  │ 0.35151   │
# │ 4   │ -0.722001 │ -0.798442 │ -0.701147 │
# │ 5   │ 0.82599   │ 0.795885  │ 0.701069  │
# │ 6   │ -1.72107  │ -1.68518  │ -1.57576  │
# │ 7   │ 0.957422  │ 0.956488  │ 0.863378  │
# │ 8   │ -0.34021  │ -0.352016 │ -0.282449 │
# │ 9   │ -0.539599 │ -0.527012 │ -0.435373 │
# │ 10  │ 0.369219  │ 0.330933  │ 0.224794  │
# IHT false positives = 0
# IHT false negatives = 1
# LASSO false positives = 20
# LASSO false positives = 1
#
# current run = 16
# compare_model = 10×3 DataFrame
# │ Row │ true_β    │ IHT_β     │ lasso_β   │
# │     │ Float64   │ Float64   │ Float64   │
# ├─────┼───────────┼───────────┼───────────┤
# │ 1   │ 1.87421   │ 1.86925   │ 1.7709    │
# │ 2   │ 1.04504   │ 1.08896   │ 1.00264   │
# │ 3   │ 0.601684  │ 0.52358   │ 0.439139  │
# │ 4   │ -1.51453  │ -1.48126  │ -1.39774  │
# │ 5   │ -0.477873 │ -0.555031 │ -0.444887 │
# │ 6   │ 0.803591  │ 0.834913  │ 0.735466  │
# │ 7   │ 0.638465  │ 0.680787  │ 0.588022  │
# │ 8   │ 0.166718  │ 0.0       │ 0.0433095 │
# │ 9   │ -1.75157  │ -1.76141  │ -1.6801   │
# │ 10  │ 0.844618  │ 0.864196  │ 0.783086  │
# IHT false positives = 0
# IHT false negatives = 1
# LASSO false positives = 53
# LASSO false positives = 0
#
# current run = 17
# compare_model = 10×3 DataFrame
# │ Row │ true_β    │ IHT_β     │ lasso_β    │
# │     │ Float64   │ Float64   │ Float64    │
# ├─────┼───────────┼───────────┼────────────┤
# │ 1   │ -1.51059  │ -1.50798  │ -1.40436   │
# │ 2   │ -0.751457 │ -0.736638 │ -0.643782  │
# │ 3   │ 0.902621  │ 0.880091  │ 0.770505   │
# │ 4   │ 0.251796  │ 0.256664  │ 0.157621   │
# │ 5   │ 0.882886  │ 0.923884  │ 0.808744   │
# │ 6   │ -1.64476  │ -1.68539  │ -1.58029   │
# │ 7   │ 0.338999  │ 0.373905  │ 0.27281    │
# │ 8   │ 0.303397  │ 0.24498   │ 0.141991   │
# │ 9   │ 1.52732   │ 1.5966    │ 1.48435    │
# │ 10  │ -0.141194 │ 0.0       │ -0.0431922 │
# IHT false positives = 0
# IHT false negatives = 1
# LASSO false positives = 30
# LASSO false positives = 0
#
# current run = 18
# compare_model = 10×3 DataFrame
# │ Row │ true_β    │ IHT_β     │ lasso_β   │
# │     │ Float64   │ Float64   │ Float64   │
# ├─────┼───────────┼───────────┼───────────┤
# │ 1   │ 1.53205   │ 1.56279   │ 1.44935   │
# │ 2   │ 0.632948  │ 0.709759  │ 0.599945  │
# │ 3   │ -2.4862   │ -2.51831  │ -2.41285  │
# │ 4   │ 0.519321  │ 0.565501  │ 0.455268  │
# │ 5   │ -0.883758 │ -0.914048 │ -0.808648 │
# │ 6   │ 0.570358  │ 0.589639  │ 0.483448  │
# │ 7   │ 1.05824   │ 1.05121   │ 0.945539  │
# │ 8   │ 0.897267  │ 0.866399  │ 0.763978  │
# │ 9   │ -0.983793 │ -0.935347 │ -0.835141 │
# │ 10  │ -0.18541  │ 0.0       │ -0.042505 │
# IHT false positives = 0
# IHT false negatives = 1
# LASSO false positives = 22
# LASSO false positives = 0
#
# current run = 19
# compare_model = 10×3 DataFrame
# │ Row │ true_β    │ IHT_β     │ lasso_β   │
# │     │ Float64   │ Float64   │ Float64   │
# ├─────┼───────────┼───────────┼───────────┤
# │ 1   │ 0.79628   │ 0.768661  │ 0.677956  │
# │ 2   │ -0.484048 │ -0.501558 │ -0.409981 │
# │ 3   │ -0.330817 │ -0.316727 │ -0.223986 │
# │ 4   │ -1.26943  │ -1.23132  │ -1.13679  │
# │ 5   │ -1.62361  │ -1.62717  │ -1.54382  │
# │ 6   │ -1.28796  │ -1.28823  │ -1.20196  │
# │ 7   │ -0.227111 │ -0.249648 │ -0.161353 │
# │ 8   │ -0.67733  │ -0.6377   │ -0.544775 │
# │ 9   │ 0.972427  │ 0.992644  │ 0.902216  │
# │ 10  │ 0.701564  │ 0.712838  │ 0.617308  │
# IHT false positives = 0
# IHT false negatives = 0
# LASSO false positives = 29
# LASSO false positives = 0
#
# current run = 20
# compare_model = 10×3 DataFrame
# │ Row │ true_β     │ IHT_β     │ lasso_β   │
# │     │ Float64    │ Float64   │ Float64   │
# ├─────┼────────────┼───────────┼───────────┤
# │ 1   │ -0.44968   │ -0.422545 │ -0.320388 │
# │ 2   │ -1.80835   │ -1.78847  │ -1.67122  │
# │ 3   │ -1.19484   │ -1.19864  │ -1.10224  │
# │ 4   │ -0.255765  │ -0.265682 │ -0.161478 │
# │ 5   │ -0.272302  │ -0.280221 │ -0.170259 │
# │ 6   │ -0.397279  │ -0.439654 │ -0.332636 │
# │ 7   │ -0.0653773 │ 0.0       │ 0.0       │
# │ 8   │ -1.12739   │ -1.20212  │ -1.09341  │
# │ 9   │ 0.556692   │ 0.537972  │ 0.439243  │
# │ 10  │ 1.92785    │ 1.96382   │ 1.8831    │
# IHT false positives = 0
# IHT false negatives = 1
# LASSO false positives = 17
# LASSO false positives = 1
#
# current run = 21
# compare_model = 10×3 DataFrame
# │ Row │ true_β    │ IHT_β     │ lasso_β   │
# │     │ Float64   │ Float64   │ Float64   │
# ├─────┼───────────┼───────────┼───────────┤
# │ 1   │ 0.576778  │ 0.511854  │ 0.423664  │
# │ 2   │ 0.39306   │ 0.363964  │ 0.264781  │
# │ 3   │ -1.22149  │ -1.2455   │ -1.13952  │
# │ 4   │ -0.267442 │ -0.271228 │ -0.166749 │
# │ 5   │ 1.08831   │ 1.0519    │ 0.979663  │
# │ 6   │ -0.043256 │ 0.0       │ 0.0       │
# │ 7   │ -0.44311  │ -0.482071 │ -0.388021 │
# │ 8   │ -0.303806 │ -0.269859 │ -0.179456 │
# │ 9   │ 0.548731  │ 0.522619  │ 0.425785  │
# │ 10  │ 1.61471   │ 1.57822   │ 1.48559   │
# IHT false positives = 0
# IHT false negatives = 1
# LASSO false positives = 33
# LASSO false positives = 1
#
# current run = 22
# compare_model = 10×3 DataFrame
# │ Row │ true_β     │ IHT_β     │ lasso_β   │
# │     │ Float64    │ Float64   │ Float64   │
# ├─────┼────────────┼───────────┼───────────┤
# │ 1   │ -0.102533  │ 0.0       │ 0.0       │
# │ 2   │ -1.13055   │ -1.09729  │ -0.998832 │
# │ 3   │ 0.469898   │ 0.430762  │ 0.321642  │
# │ 4   │ 1.39514    │ 1.38303   │ 1.26983   │
# │ 5   │ -0.113164  │ 0.0       │ 0.0       │
# │ 6   │ 0.824756   │ 0.859959  │ 0.750706  │
# │ 7   │ -0.889457  │ -0.890798 │ -0.776159 │
# │ 8   │ 0.0560147  │ 0.0       │ 0.0       │
# │ 9   │ -2.13178   │ -2.1291   │ -2.03689  │
# │ 10  │ 0.00924091 │ 0.0       │ 0.0       │
# IHT false positives = 0
# IHT false negatives = 4
# LASSO false positives = 5
# LASSO false positives = 4
#
# current run = 23
# compare_model = 10×3 DataFrame
# │ Row │ true_β    │ IHT_β     │ lasso_β   │
# │     │ Float64   │ Float64   │ Float64   │
# ├─────┼───────────┼───────────┼───────────┤
# │ 1   │ 1.44919   │ 1.46972   │ 1.36106   │
# │ 2   │ 0.69194   │ 0.65854   │ 0.573154  │
# │ 3   │ 0.689613  │ 0.707507  │ 0.615659  │
# │ 4   │ -1.57917  │ -1.57983  │ -1.46859  │
# │ 5   │ -0.822662 │ -0.825906 │ -0.725507 │
# │ 6   │ 0.17929   │ 0.0       │ 0.0598882 │
# │ 7   │ -0.034126 │ 0.0       │ 0.0       │
# │ 8   │ -1.27529  │ -1.28979  │ -1.18512  │
# │ 9   │ 1.77769   │ 1.75396   │ 1.65214   │
# │ 10  │ -0.683389 │ -0.643434 │ -0.540641 │
# IHT false positives = 0
# IHT false negatives = 2
# LASSO false positives = 24
# LASSO false positives = 1
#
# current run = 24
# compare_model = 10×3 DataFrame
# │ Row │ true_β     │ IHT_β     │ lasso_β   │
# │     │ Float64    │ Float64   │ Float64   │
# ├─────┼────────────┼───────────┼───────────┤
# │ 1   │ 0.193183   │ 0.0       │ 0.0246708 │
# │ 2   │ 0.474194   │ 0.454008  │ 0.346463  │
# │ 3   │ -0.931355  │ -0.948986 │ -0.832047 │
# │ 4   │ 1.08864    │ 1.11944   │ 1.02159   │
# │ 5   │ 0.474459   │ 0.489009  │ 0.375234  │
# │ 6   │ -0.0945259 │ 0.0       │ 0.0       │
# │ 7   │ -0.54971   │ -0.527228 │ -0.420519 │
# │ 8   │ -0.338488  │ -0.334978 │ -0.224527 │
# │ 9   │ -0.415819  │ -0.467085 │ -0.35218  │
# │ 10  │ -0.440719  │ -0.446814 │ -0.324674 │
# IHT false positives = 0
# IHT false negatives = 2
# LASSO false positives = 29
# LASSO false positives = 1
#
# current run = 25
# compare_model = 10×3 DataFrame
# │ Row │ true_β    │ IHT_β     │ lasso_β    │
# │     │ Float64   │ Float64   │ Float64    │
# ├─────┼───────────┼───────────┼────────────┤
# │ 1   │ 0.64504   │ 0.673554  │ 0.571844   │
# │ 2   │ 0.0396318 │ 0.0       │ 0.0357744  │
# │ 3   │ -0.160108 │ 0.0       │ -0.0435133 │
# │ 4   │ -0.380402 │ -0.37925  │ -0.285334  │
# │ 5   │ 1.09094   │ 1.1202    │ 1.01953    │
# │ 6   │ 1.51637   │ 1.44734   │ 1.34286    │
# │ 7   │ 1.67161   │ 1.67911   │ 1.57477    │
# │ 8   │ -0.232241 │ -0.234361 │ -0.142087  │
# │ 9   │ -2.70131  │ -2.71787  │ -2.61186   │
# │ 10  │ -0.758417 │ -0.750988 │ -0.658869  │
# IHT false positives = 1
# IHT false negatives = 2
# LASSO false positives = 47
# LASSO false positives = 0
#
# current run = 26
# compare_model = 10×3 DataFrame
# │ Row │ true_β    │ IHT_β     │ lasso_β   │
# │     │ Float64   │ Float64   │ Float64   │
# ├─────┼───────────┼───────────┼───────────┤
# │ 1   │ -0.363957 │ -0.367508 │ -0.264144 │
# │ 2   │ 1.25164   │ 1.26209   │ 1.16005   │
# │ 3   │ 1.83677   │ 1.85125   │ 1.75013   │
# │ 4   │ 0.693903  │ 0.658961  │ 0.547422  │
# │ 5   │ 0.933384  │ 0.898691  │ 0.79247   │
# │ 6   │ 1.25143   │ 1.2341    │ 1.12777   │
# │ 7   │ 0.981419  │ 0.987471  │ 0.884649  │
# │ 8   │ -1.14647  │ -1.13829  │ -1.02278  │
# │ 9   │ -1.58716  │ -1.62894  │ -1.52086  │
# │ 10  │ -0.714266 │ -0.720897 │ -0.603084 │
# IHT false positives = 0
# IHT false negatives = 0
# LASSO false positives = 28
# LASSO false positives = 0
#
# current run = 27
# compare_model = 10×3 DataFrame
# │ Row │ true_β     │ IHT_β     │ lasso_β    │
# │     │ Float64    │ Float64   │ Float64    │
# ├─────┼────────────┼───────────┼────────────┤
# │ 1   │ 0.557965   │ 0.59452   │ 0.50115    │
# │ 2   │ -0.25417   │ -0.280899 │ -0.188784  │
# │ 3   │ -0.280999  │ -0.26042  │ -0.156766  │
# │ 4   │ -0.339437  │ -0.359998 │ -0.260277  │
# │ 5   │ 1.11464    │ 1.12364   │ 1.02847    │
# │ 6   │ 0.226863   │ 0.257472  │ 0.178171   │
# │ 7   │ 1.57042    │ 1.56866   │ 1.48322    │
# │ 8   │ -0.0979811 │ 0.0       │ -0.0287622 │
# │ 9   │ 0.229467   │ 0.189965  │ 0.0866203  │
# │ 10  │ 1.17481    │ 1.17923   │ 1.09569    │
# IHT false positives = 0
# IHT false negatives = 1
# LASSO false positives = 76
# LASSO false positives = 0
#
# current run = 28
# compare_model = 10×3 DataFrame
# │ Row │ true_β    │ IHT_β     │ lasso_β   │
# │     │ Float64   │ Float64   │ Float64   │
# ├─────┼───────────┼───────────┼───────────┤
# │ 1   │ 0.678637  │ 0.71314   │ 0.605054  │
# │ 2   │ 1.01407   │ 1.06559   │ 0.947147  │
# │ 3   │ -0.068002 │ 0.0       │ 0.0       │
# │ 4   │ 0.866864  │ 0.876784  │ 0.766188  │
# │ 5   │ -1.04658  │ -1.04064  │ -0.942447 │
# │ 6   │ -0.733464 │ -0.756134 │ -0.645889 │
# │ 7   │ -0.875958 │ -0.852101 │ -0.755598 │
# │ 8   │ 0.363956  │ 0.395074  │ 0.295367  │
# │ 9   │ -1.95236  │ -1.97542  │ -1.86761  │
# │ 10  │ -1.17576  │ -1.16355  │ -1.06707  │
# IHT false positives = 0
# IHT false negatives = 1
# LASSO false positives = 15
# LASSO false positives = 1
#
# current run = 29
# compare_model = 10×3 DataFrame
# │ Row │ true_β     │ IHT_β     │ lasso_β    │
# │     │ Float64    │ Float64   │ Float64    │
# ├─────┼────────────┼───────────┼────────────┤
# │ 1   │ -0.826979  │ -0.81654  │ -0.71326   │
# │ 2   │ -0.95025   │ -0.904288 │ -0.813233  │
# │ 3   │ 0.339354   │ 0.34404   │ 0.259305   │
# │ 4   │ 2.83506    │ 2.79694   │ 2.70753    │
# │ 5   │ -1.30856   │ -1.29896  │ -1.21636   │
# │ 6   │ -0.0844876 │ 0.0       │ -0.0511412 │
# │ 7   │ -2.1173    │ -2.15321  │ -2.05766   │
# │ 8   │ -0.631789  │ -0.625973 │ -0.533633  │
# │ 9   │ -1.96178   │ -1.95281  │ -1.83662   │
# │ 10  │ 0.258615   │ 0.216449  │ 0.121782   │
# IHT false positives = 0
# IHT false negatives = 1
# LASSO false positives = 31
# LASSO false positives = 0
#
# current run = 30
# compare_model = 10×3 DataFrame
# │ Row │ true_β    │ IHT_β     │ lasso_β   │
# │     │ Float64   │ Float64   │ Float64   │
# ├─────┼───────────┼───────────┼───────────┤
# │ 1   │ -0.484374 │ -0.460625 │ -0.352859 │
# │ 2   │ 0.0844317 │ 0.0       │ 0.0       │
# │ 3   │ -1.36538  │ -1.35312  │ -1.25911  │
# │ 4   │ 1.70254   │ 1.69216   │ 1.58627   │
# │ 5   │ 1.99872   │ 2.02134   │ 1.92018   │
# │ 6   │ 1.14559   │ 1.17129   │ 1.07151   │
# │ 7   │ 0.258164  │ 0.273196  │ 0.161652  │
# │ 8   │ 3.06389   │ 3.05458   │ 2.95773   │
# │ 9   │ 0.288465  │ 0.27666   │ 0.180008  │
# │ 10  │ -0.38354  │ -0.328139 │ -0.212904 │
# IHT false positives = 0
# IHT false negatives = 1
# LASSO false positives = 20
# LASSO false positives = 1
#
# current run = 31
# compare_model = 10×3 DataFrame
# │ Row │ true_β     │ IHT_β     │ lasso_β     │
# │     │ Float64    │ Float64   │ Float64     │
# ├─────┼────────────┼───────────┼─────────────┤
# │ 1   │ -0.714264  │ -0.741969 │ -0.657509   │
# │ 2   │ 1.707      │ 1.67694   │ 1.58149     │
# │ 3   │ -0.612758  │ -0.598667 │ -0.515833   │
# │ 4   │ -1.63034   │ -1.67591  │ -1.58887    │
# │ 5   │ -0.0486264 │ 0.0       │ -0.00199663 │
# │ 6   │ -2.00163   │ -1.93859  │ -1.84801    │
# │ 7   │ 0.353532   │ 0.293489  │ 0.202433    │
# │ 8   │ -0.745047  │ -0.8051   │ -0.710229   │
# │ 9   │ -0.127538  │ -0.188308 │ -0.0833785  │
# │ 10  │ 2.18127    │ 2.14727   │ 2.05098     │
# IHT false positives = 0
# IHT false negatives = 1
# LASSO false positives = 46
# LASSO false positives = 0
#
# current run = 32
# compare_model = 10×3 DataFrame
# │ Row │ true_β      │ IHT_β    │ lasso_β    │
# │     │ Float64     │ Float64  │ Float64    │
# ├─────┼─────────────┼──────────┼────────────┤
# │ 1   │ -2.44982    │ -2.45376 │ -2.34963   │
# │ 2   │ -1.13625    │ -1.16105 │ -1.05868   │
# │ 3   │ -0.271937   │ -0.27623 │ -0.184485  │
# │ 4   │ 0.000258799 │ 0.0      │ 0.0        │
# │ 5   │ -1.43694    │ -1.45534 │ -1.35559   │
# │ 6   │ 0.611258    │ 0.611594 │ 0.503574   │
# │ 7   │ -1.341      │ -1.38448 │ -1.27833   │
# │ 8   │ 1.06648     │ 1.10335  │ 0.991414   │
# │ 9   │ -0.118912   │ 0.0      │ -0.0158297 │
# │ 10  │ 0.842094    │ 0.911139 │ 0.808895   │
# IHT false positives = 0
# IHT false negatives = 2
# LASSO false positives = 17
# LASSO false positives = 1
#
# current run = 33
# compare_model = 10×3 DataFrame
# │ Row │ true_β    │ IHT_β     │ lasso_β    │
# │     │ Float64   │ Float64   │ Float64    │
# ├─────┼───────────┼───────────┼────────────┤
# │ 1   │ -0.484798 │ -0.481967 │ -0.390768  │
# │ 2   │ -0.361355 │ -0.370286 │ -0.267226  │
# │ 3   │ -0.521531 │ -0.571704 │ -0.479817  │
# │ 4   │ 0.617995  │ 0.616615  │ 0.534961   │
# │ 5   │ -0.820002 │ -0.7686   │ -0.659948  │
# │ 6   │ -2.39172  │ -2.34236  │ -2.23594   │
# │ 7   │ -0.848756 │ -0.84912  │ -0.740955  │
# │ 8   │ 1.03028   │ 1.01628   │ 0.929896   │
# │ 9   │ 0.0474633 │ 0.0       │ 0.0        │
# │ 10  │ -0.125097 │ 0.0       │ -0.0386338 │
# IHT false positives = 0
# IHT false negatives = 2
# LASSO false positives = 22
# LASSO false positives = 1
#
# current run = 34
# compare_model = 10×3 DataFrame
# │ Row │ true_β     │ IHT_β     │ lasso_β    │
# │     │ Float64    │ Float64   │ Float64    │
# ├─────┼────────────┼───────────┼────────────┤
# │ 1   │ -0.132758  │ 0.0       │ -0.0449303 │
# │ 2   │ 0.349441   │ 0.314975  │ 0.215215   │
# │ 3   │ -0.405722  │ -0.435707 │ -0.34494   │
# │ 4   │ -0.371738  │ -0.403598 │ -0.304375  │
# │ 5   │ 0.00468385 │ 0.0       │ 0.0        │
# │ 6   │ -0.336855  │ -0.373036 │ -0.269638  │
# │ 7   │ -0.587751  │ -0.567464 │ -0.483323  │
# │ 8   │ -0.30821   │ -0.339825 │ -0.234346  │
# │ 9   │ -0.479542  │ -0.516401 │ -0.418     │
# │ 10  │ 1.25676    │ 1.24005   │ 1.16015    │
# IHT false positives = 0
# IHT false negatives = 2
# LASSO false positives = 38
# LASSO false positives = 1
#
# current run = 35
# compare_model = 10×3 DataFrame
# │ Row │ true_β   │ IHT_β     │ lasso_β   │
# │     │ Float64  │ Float64   │ Float64   │
# ├─────┼──────────┼───────────┼───────────┤
# │ 1   │ 0.251986 │ 0.226144  │ 0.127808  │
# │ 2   │ 1.26956  │ 1.21366   │ 1.1222    │
# │ 3   │ 0.683158 │ 0.704468  │ 0.617186  │
# │ 4   │ 0.714376 │ 0.7268    │ 0.62084   │
# │ 5   │ 0.965966 │ 0.978487  │ 0.882149  │
# │ 6   │ 1.6017   │ 1.62918   │ 1.54006   │
# │ 7   │ 0.111922 │ 0.0       │ 0.0202226 │
# │ 8   │ 0.943131 │ 0.943301  │ 0.834799  │
# │ 9   │ -0.53697 │ -0.511782 │ -0.396016 │
# │ 10  │ 0.308253 │ 0.293915  │ 0.193593  │
# IHT false positives = 0
# IHT false negatives = 1
# LASSO false positives = 40
# LASSO false positives = 0
#
# current run = 36
# compare_model = 10×3 DataFrame
# │ Row │ true_β     │ IHT_β     │ lasso_β    │
# │     │ Float64    │ Float64   │ Float64    │
# ├─────┼────────────┼───────────┼────────────┤
# │ 1   │ 2.15089    │ 2.12455   │ 2.01217    │
# │ 2   │ 0.942143   │ 0.923994  │ 0.813198   │
# │ 3   │ 0.627567   │ 0.713407  │ 0.60329    │
# │ 4   │ -0.0501013 │ 0.0       │ 0.0        │
# │ 5   │ -1.02696   │ -0.967819 │ -0.844183  │
# │ 6   │ 1.61441    │ 1.63232   │ 1.52737    │
# │ 7   │ 0.534859   │ 0.560326  │ 0.461863   │
# │ 8   │ 0.526747   │ 0.537916  │ 0.420505   │
# │ 9   │ 1.47968    │ 1.48601   │ 1.37947    │
# │ 10  │ -0.133134  │ 0.0       │ -0.0299582 │
# IHT false positives = 0
# IHT false negatives = 2
# LASSO false positives = 9
# LASSO false positives = 1
#
# current run = 37
# compare_model = 10×3 DataFrame
# │ Row │ true_β     │ IHT_β     │ lasso_β   │
# │     │ Float64    │ Float64   │ Float64   │
# ├─────┼────────────┼───────────┼───────────┤
# │ 1   │ 0.45813    │ 0.445729  │ 0.344685  │
# │ 2   │ -0.0762618 │ 0.0       │ 0.0       │
# │ 3   │ -0.409063  │ -0.338927 │ -0.241292 │
# │ 4   │ 0.0459559  │ 0.0       │ 0.0       │
# │ 5   │ 1.05298    │ 1.05185   │ 0.954521  │
# │ 6   │ -0.90485   │ -0.937016 │ -0.842108 │
# │ 7   │ -0.483856  │ -0.48247  │ -0.388117 │
# │ 8   │ -0.651075  │ -0.662176 │ -0.563978 │
# │ 9   │ -1.51594   │ -1.53732  │ -1.42894  │
# │ 10  │ -0.0549804 │ 0.0       │ 0.0       │
# IHT false positives = 0
# IHT false negatives = 3
# LASSO false positives = 32
# LASSO false positives = 3
#
# current run = 38
# compare_model = 10×3 DataFrame
# │ Row │ true_β     │ IHT_β    │ lasso_β   │
# │     │ Float64    │ Float64  │ Float64   │
# ├─────┼────────────┼──────────┼───────────┤
# │ 1   │ 0.0893327  │ 0.0      │ 0.0       │
# │ 2   │ 0.263149   │ 0.27937  │ 0.177417  │
# │ 3   │ -0.474276  │ -0.46512 │ -0.359006 │
# │ 4   │ -1.22631   │ -1.18446 │ -1.07784  │
# │ 5   │ -1.52834   │ -1.55542 │ -1.45792  │
# │ 6   │ -0.0141267 │ 0.0      │ 0.0       │
# │ 7   │ 2.21114    │ 2.25455  │ 2.14592   │
# │ 8   │ -1.72067   │ -1.74075 │ -1.63864  │
# │ 9   │ -1.65361   │ -1.66641 │ -1.56867  │
# │ 10  │ 0.46829    │ 0.50932  │ 0.396497  │
# IHT false positives = 0
# IHT false negatives = 2
# LASSO false positives = 12
# LASSO false positives = 2
#
# current run = 39
# compare_model = 10×3 DataFrame
# │ Row │ true_β    │ IHT_β     │ lasso_β    │
# │     │ Float64   │ Float64   │ Float64    │
# ├─────┼───────────┼───────────┼────────────┤
# │ 1   │ 1.42576   │ 1.37731   │ 1.29814    │
# │ 2   │ -1.14588  │ -1.16498  │ -1.0695    │
# │ 3   │ -2.43584  │ -2.45491  │ -2.36314   │
# │ 4   │ 0.899711  │ 0.916901  │ 0.814934   │
# │ 5   │ -0.415244 │ -0.42971  │ -0.322812  │
# │ 6   │ 0.613711  │ 0.615096  │ 0.518119   │
# │ 7   │ 0.107916  │ 0.0       │ 0.00925485 │
# │ 8   │ 1.16184   │ 1.17408   │ 1.07905    │
# │ 9   │ -0.545302 │ -0.573751 │ -0.480566  │
# │ 10  │ -0.52644  │ -0.497031 │ -0.398025  │
# IHT false positives = 0
# IHT false negatives = 1
# LASSO false positives = 20
# LASSO false positives = 0
#
# current run = 40
# compare_model = 10×3 DataFrame
# │ Row │ true_β    │ IHT_β     │ lasso_β   │
# │     │ Float64   │ Float64   │ Float64   │
# ├─────┼───────────┼───────────┼───────────┤
# │ 1   │ -0.890438 │ -0.913343 │ -0.812406 │
# │ 2   │ 1.05324   │ 1.05713   │ 0.945738  │
# │ 3   │ 0.500604  │ 0.473165  │ 0.392633  │
# │ 4   │ -0.980076 │ -0.965334 │ -0.872049 │
# │ 5   │ -0.416463 │ -0.415769 │ -0.316075 │
# │ 6   │ 0.707636  │ 0.652876  │ 0.542694  │
# │ 7   │ -0.940757 │ -0.922515 │ -0.828821 │
# │ 8   │ -1.04045  │ -1.03366  │ -0.926819 │
# │ 9   │ 1.45067   │ 1.46728   │ 1.37026   │
# │ 10  │ 0.460904  │ 0.457813  │ 0.361444  │
# IHT false positives = 0
# IHT false negatives = 0
# LASSO false positives = 55
# LASSO false positives = 0
#
# current run = 41
# compare_model = 10×3 DataFrame
# │ Row │ true_β      │ IHT_β     │ lasso_β   │
# │     │ Float64     │ Float64   │ Float64   │
# ├─────┼─────────────┼───────────┼───────────┤
# │ 1   │ -1.51937    │ -1.51725  │ -1.40948  │
# │ 2   │ -0.42069    │ -0.413319 │ -0.326819 │
# │ 3   │ -0.261269   │ -0.220379 │ -0.128765 │
# │ 4   │ -0.657006   │ -0.672372 │ -0.578286 │
# │ 5   │ 0.474532    │ 0.466628  │ 0.359948  │
# │ 6   │ 0.547387    │ 0.6051    │ 0.508322  │
# │ 7   │ -1.08377    │ -1.06577  │ -0.979109 │
# │ 8   │ -0.00746143 │ 0.0       │ 0.0       │
# │ 9   │ -0.314163   │ -0.269862 │ -0.167193 │
# │ 10  │ -0.82629    │ -0.789762 │ -0.679983 │
# IHT false positives = 0
# IHT false negatives = 1
# LASSO false positives = 38
# LASSO false positives = 1
#
# current run = 42
# compare_model = 10×3 DataFrame
# │ Row │ true_β    │ IHT_β     │ lasso_β   │
# │     │ Float64   │ Float64   │ Float64   │
# ├─────┼───────────┼───────────┼───────────┤
# │ 1   │ -0.948453 │ -0.974337 │ -0.891389 │
# │ 2   │ -0.268442 │ -0.208987 │ -0.096189 │
# │ 3   │ 0.815187  │ 0.833659  │ 0.735833  │
# │ 4   │ -1.99975  │ -1.99002  │ -1.88874  │
# │ 5   │ -1.09675  │ -1.0952   │ -1.00492  │
# │ 6   │ -0.26913  │ -0.255119 │ -0.148513 │
# │ 7   │ 0.43029   │ 0.433718  │ 0.345904  │
# │ 8   │ -1.00858  │ -0.920875 │ -0.833402 │
# │ 9   │ 0.270387  │ 0.26099   │ 0.154444  │
# │ 10  │ -0.939434 │ -0.918668 │ -0.823881 │
# IHT false positives = 0
# IHT false negatives = 0
# LASSO false positives = 33
# LASSO false positives = 0
#
# current run = 43
# compare_model = 10×3 DataFrame
# │ Row │ true_β    │ IHT_β     │ lasso_β      │
# │     │ Float64   │ Float64   │ Float64      │
# ├─────┼───────────┼───────────┼──────────────┤
# │ 1   │ 1.12878   │ 1.06216   │ 0.96409      │
# │ 2   │ 0.505294  │ 0.544353  │ 0.434642     │
# │ 3   │ 0.265822  │ 0.190867  │ 0.0912009    │
# │ 4   │ -0.487806 │ -0.500474 │ -0.390236    │
# │ 5   │ 0.217111  │ 0.181517  │ 0.0621826    │
# │ 6   │ -0.156281 │ 0.0       │ -0.000745365 │
# │ 7   │ 0.923586  │ 0.83499   │ 0.71765      │
# │ 8   │ 1.14851   │ 1.21311   │ 1.10011      │
# │ 9   │ -0.356859 │ -0.363671 │ -0.262015    │
# │ 10  │ -1.51381  │ -1.52479  │ -1.42139     │
# IHT false positives = 0
# IHT false negatives = 1
# LASSO false positives = 3
# LASSO false positives = 0
#
# current run = 44
# compare_model = 10×3 DataFrame
# │ Row │ true_β    │ IHT_β     │ lasso_β   │
# │     │ Float64   │ Float64   │ Float64   │
# ├─────┼───────────┼───────────┼───────────┤
# │ 1   │ -0.493499 │ -0.44428  │ -0.363596 │
# │ 2   │ -1.35053  │ -1.30865  │ -1.21271  │
# │ 3   │ -0.416246 │ -0.396218 │ -0.285986 │
# │ 4   │ -0.337579 │ -0.298066 │ -0.216715 │
# │ 5   │ -0.367771 │ -0.307387 │ -0.201508 │
# │ 6   │ 1.44879   │ 1.46488   │ 1.3705    │
# │ 7   │ 1.83698   │ 1.81012   │ 1.71743   │
# │ 8   │ 0.145851  │ 0.0       │ 0.0494825 │
# │ 9   │ 0.762505  │ 0.727612  │ 0.614645  │
# │ 10  │ 0.655159  │ 0.680372  │ 0.58441   │
# IHT false positives = 0
# IHT false negatives = 1
# LASSO false positives = 40
# LASSO false positives = 0
#
# current run = 45
# compare_model = 10×3 DataFrame
# │ Row │ true_β    │ IHT_β     │ lasso_β   │
# │     │ Float64   │ Float64   │ Float64   │
# ├─────┼───────────┼───────────┼───────────┤
# │ 1   │ 0.527001  │ 0.550516  │ 0.450912  │
# │ 2   │ -0.727695 │ -0.729951 │ -0.61625  │
# │ 3   │ 0.616899  │ 0.631268  │ 0.53511   │
# │ 4   │ 1.81702   │ 1.802     │ 1.69914   │
# │ 5   │ 1.79793   │ 1.74052   │ 1.62702   │
# │ 6   │ -0.338855 │ -0.305046 │ -0.21494  │
# │ 7   │ 0.401379  │ 0.416073  │ 0.324747  │
# │ 8   │ -0.62296  │ -0.561356 │ -0.456763 │
# │ 9   │ 1.38521   │ 1.36382   │ 1.25318   │
# │ 10  │ -0.538635 │ -0.540922 │ -0.452974 │
# IHT false positives = 0
# IHT false negatives = 0
# LASSO false positives = 41
# LASSO false positives = 0
#
# current run = 46
# compare_model = 10×3 DataFrame
# │ Row │ true_β    │ IHT_β     │ lasso_β    │
# │     │ Float64   │ Float64   │ Float64    │
# ├─────┼───────────┼───────────┼────────────┤
# │ 1   │ 0.553596  │ 0.533759  │ 0.43186    │
# │ 2   │ 0.700625  │ 0.660178  │ 0.556526   │
# │ 3   │ -1.37319  │ -1.39349  │ -1.29009   │
# │ 4   │ -0.70754  │ -0.692789 │ -0.599796  │
# │ 5   │ -0.085892 │ 0.0       │ 0.0        │
# │ 6   │ 0.802029  │ 0.75706   │ 0.647879   │
# │ 7   │ -0.333618 │ -0.313753 │ -0.223653  │
# │ 8   │ -0.925495 │ -0.917833 │ -0.807397  │
# │ 9   │ -0.300831 │ -0.21941  │ -0.0992421 │
# │ 10  │ 1.97306   │ 2.03163   │ 1.92029    │
# IHT false positives = 0
# IHT false negatives = 1
# LASSO false positives = 11
# LASSO false positives = 1
#
# current run = 47
# compare_model = 10×3 DataFrame
# │ Row │ true_β    │ IHT_β     │ lasso_β   │
# │     │ Float64   │ Float64   │ Float64   │
# ├─────┼───────────┼───────────┼───────────┤
# │ 1   │ 0.0694645 │ 0.0       │ 0.0       │
# │ 2   │ -1.0202   │ -1.03616  │ -0.934326 │
# │ 3   │ -0.893415 │ -0.883212 │ -0.78683  │
# │ 4   │ 0.43666   │ 0.482244  │ 0.378987  │
# │ 5   │ -1.41336  │ -1.45044  │ -1.33724  │
# │ 6   │ -1.02767  │ -1.00352  │ -0.917426 │
# │ 7   │ -1.45048  │ -1.38703  │ -1.2899   │
# │ 8   │ 0.0597132 │ 0.0       │ 0.0       │
# │ 9   │ 0.861161  │ 0.830416  │ 0.712986  │
# │ 10  │ 1.07082   │ 1.09895   │ 0.988087  │
# IHT false positives = 0
# IHT false negatives = 2
# LASSO false positives = 10
# LASSO false positives = 2
#
# current run = 48
# compare_model = 10×3 DataFrame
# │ Row │ true_β    │ IHT_β     │ lasso_β   │
# │     │ Float64   │ Float64   │ Float64   │
# ├─────┼───────────┼───────────┼───────────┤
# │ 1   │ -0.794804 │ -0.7626   │ -0.66294  │
# │ 2   │ -1.12732  │ -1.1685   │ -1.06461  │
# │ 3   │ 0.141158  │ 0.0       │ 0.0117579 │
# │ 4   │ 0.189242  │ 0.185683  │ 0.0631731 │
# │ 5   │ -0.48758  │ -0.477784 │ -0.375824 │
# │ 6   │ 0.114626  │ 0.0       │ 0.041718  │
# │ 7   │ 0.0713225 │ 0.0       │ 0.0       │
# │ 8   │ 0.470995  │ 0.511588  │ 0.412317  │
# │ 9   │ 1.43197   │ 1.46867   │ 1.37286   │
# │ 10  │ -0.677987 │ -0.676503 │ -0.567318 │
# IHT false positives = 0
# IHT false negatives = 3
# LASSO false positives = 18
# LASSO false positives = 1
#
# current run = 49
# compare_model = 10×3 DataFrame
# │ Row │ true_β      │ IHT_β     │ lasso_β    │
# │     │ Float64     │ Float64   │ Float64    │
# ├─────┼─────────────┼───────────┼────────────┤
# │ 1   │ -0.193086   │ -0.197338 │ -0.0926947 │
# │ 2   │ 0.664232    │ 0.708493  │ 0.622653   │
# │ 3   │ -1.52211    │ -1.53831  │ -1.4441    │
# │ 4   │ -0.672351   │ -0.682255 │ -0.586686  │
# │ 5   │ -0.371193   │ -0.350078 │ -0.263847  │
# │ 6   │ -0.00900926 │ 0.0       │ 0.0        │
# │ 7   │ 0.214014    │ 0.235373  │ 0.143957   │
# │ 8   │ -0.111294   │ 0.0       │ -0.0519878 │
# │ 9   │ 0.547206    │ 0.560036  │ 0.444624   │
# │ 10  │ -0.91931    │ -0.990236 │ -0.899104  │
# IHT false positives = 0
# IHT false negatives = 2
# LASSO false positives = 40
# LASSO false positives = 1
#
# current run = 50
# compare_model = 10×3 DataFrame
# │ Row │ true_β    │ IHT_β    │ lasso_β    │
# │     │ Float64   │ Float64  │ Float64    │
# ├─────┼───────────┼──────────┼────────────┤
# │ 1   │ -1.29843  │ -1.27398 │ -1.17393   │
# │ 2   │ 0.0427014 │ 0.0      │ 0.0        │
# │ 3   │ 0.535512  │ 0.518884 │ 0.395264   │
# │ 4   │ 0.610256  │ 0.625401 │ 0.524298   │
# │ 5   │ 0.43605   │ 0.397292 │ 0.272682   │
# │ 6   │ 0.430278  │ 0.472032 │ 0.373325   │
# │ 7   │ 0.905637  │ 0.90079  │ 0.806714   │
# │ 8   │ -0.1134   │ 0.0      │ -0.0151628 │
# │ 9   │ 0.410483  │ 0.396401 │ 0.286989   │
# │ 10  │ -1.09042  │ -1.14115 │ -1.02759   │
# IHT false positives = 0
# IHT false negatives = 2
# LASSO false positives = 8
# LASSO false positives = 1

# %% [markdown]
# # Compute average number of false positives/negatives

# %%
normal_iht_false_positives = sum(iht_false_positives) / 50
normal_iht_false_negatives = sum(iht_false_negatives) / 50
normal_lasso_false_positives = sum(lasso_false_positives) / 50
normal_lasso_false_negatives = sum(lasso_false_negatives) / 50
result = [normal_iht_false_positives; normal_iht_false_negatives; normal_lasso_false_positives; normal_lasso_false_negatives]
# Out:
# 4-element Array{Float64,1}:
#   0.04
#   1.28
#  28.54
#   0.8

# %%
IHT_did_not_converge = 0
LASSO_did_not_converge = 0
# Out:
# 0
