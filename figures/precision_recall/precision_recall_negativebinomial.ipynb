# %% [markdown]
# # Negative Binomial: Compute false positive/negatives
#
# Currently `glmnet` does not support negative binomila regression. Therefore, we simply compute the number of false positive/negatives of negative binomial in the same cross validation setting as Normal/Bernoulli/Poisson.

# %%
using Distributed
addprocs(4)
nprocs()
# Out:
# 5

# %%
using MendelIHT
using SnpArrays
using DataFrames
using Distributions
using Random
using LinearAlgebra
using DelimitedFiles
using GLM

# %%
function iht_negativebinomial(n::Int64, p::Int64, k::Int64, d::UnionAll, l::Link)
    #construct snpmatrix, covariate files, and true model b
    x, = simulate_random_snparray(n, p, undef)
    xbm = SnpBitMatrix{Float64}(x, model=ADDITIVE_MODEL, center=true, scale=true); 
    z = ones(n, 1) # the intercept
    x_float = [convert(Matrix{Float64}, x, center=true, scale=true) z] #Float64 version of x

    # simulate response, true model b, and the correct non-0 positions of b
    y, true_b, correct_position = simulate_random_response(x, xbm, k, d, l)
 
    #specify path and folds
    num_folds = 3
    folds = rand(1:num_folds, size(x, 1));

    #find non-zero entries returned by best lasso model as largest k estimate
    path = collect(1:50);
    
    #run IHT's cross validation routine 
    mses = cv_iht_distributed(d(), l, x, z, y, 1, path, folds, num_folds, use_maf=false, debias=false, showinfo=false, parallel=true);
    iht_k_est = argmin(mses)
    iht_result = L0_reg(x, xbm, z, y, 1, iht_k_est, d(), l, debias=false, init=false, use_maf=false)
    iht_beta = iht_result.beta
        
    #show lasso and IHT's reconstruction result
    compare_model = DataFrame(
        true_β  = true_b[correct_position], 
        IHT_β   = iht_beta[correct_position])
    @show compare_model
    
    #compute true/false positives/negatives for IHT and lasso
    iht_tp = count(!iszero, iht_beta[correct_position])
    iht_fp = iht_k_est - iht_tp
    iht_fn = k - iht_tp
    
    println("IHT false positives = $iht_fp")
    println("IHT false negatives = $iht_fn" * "\n")
    
    return iht_fp, iht_fn
end
# Out:
# iht_negativebinomial (generic function with 1 method)

# %%
#simulat data with k true predictors, from distribution d and with link l.
n = 1000
p = 10000
k = 10
d = NegativeBinomial
l = LogLink()

#set random seed
Random.seed!(2019)

#run function above, saving results in 4 vectors
total_runs = 50
iht_false_positives = zeros(total_runs)
iht_false_negatives = zeros(total_runs)
for i in 1:total_runs
    println("current run = $i")
    iht_fp, iht_fn = iht_negativebinomial(n, p, k, d, l)
    iht_false_positives[i] = iht_fp
    iht_false_negatives[i] = iht_fn
end
# Out:
# current run = 1
# compare_model = 10×2 DataFrame
# │ Row │ true_β     │ IHT_β     │
# │     │ Float64    │ Float64   │
# ├─────┼────────────┼───────────┤
# │ 1   │ -0.389892  │ -0.386837 │
# │ 2   │ -0.0653099 │ 0.0       │
# │ 3   │ 0.235865   │ 0.204037  │
# │ 4   │ 0.17977    │ 0.162094  │
# │ 5   │ 0.0851134  │ 0.117708  │
# │ 6   │ -0.33761   │ -0.239656 │
# │ 7   │ 0.208012   │ 0.235604  │
# │ 8   │ -0.203127  │ -0.261774 │
# │ 9   │ 0.0441809  │ 0.0       │
# │ 10  │ 0.310431   │ 0.321899  │
# IHT false positives = 0
# IHT false negatives = 2
#
# current run = 2
# compare_model = 10×2 DataFrame
# │ Row │ true_β    │ IHT_β    │
# │     │ Float64   │ Float64  │
# ├─────┼───────────┼──────────┤
# │ 1   │ -0.308163 │ 0.0      │
# │ 2   │ 0.748746  │ 0.724344 │
# │ 3   │ -0.270412 │ 0.0      │
# │ 4   │ -0.261287 │ 0.0      │
# │ 5   │ -0.355036 │ 0.0      │
# │ 6   │ -0.284426 │ 0.0      │
# │ 7   │ -0.307554 │ 0.0      │
# │ 8   │ 0.754297  │ 0.724457 │
# │ 9   │ 0.162804  │ 0.0      │
# │ 10  │ 0.130718  │ 0.0      │
# IHT false positives = 1
# IHT false negatives = 8
#
# current run = 3
# compare_model = 10×2 DataFrame
# │ Row │ true_β     │ IHT_β     │
# │     │ Float64    │ Float64   │
# ├─────┼────────────┼───────────┤
# │ 1   │ 0.17137    │ 0.168773  │
# │ 2   │ 0.537057   │ 0.563641  │
# │ 3   │ 0.267901   │ 0.206344  │
# │ 4   │ -0.336298  │ -0.36589  │
# │ 5   │ -0.254109  │ -0.21514  │
# │ 6   │ -0.616286  │ -0.586324 │
# │ 7   │ 0.051022   │ 0.0       │
# │ 8   │ -0.0109876 │ 0.0       │
# │ 9   │ 0.315196   │ 0.364527  │
# │ 10  │ -0.0553636 │ 0.0       │
# IHT false positives = 1
# IHT false negatives = 3
#
# current run = 4
# compare_model = 10×2 DataFrame
# │ Row │ true_β      │ IHT_β     │
# │     │ Float64     │ Float64   │
# ├─────┼─────────────┼───────────┤
# │ 1   │ -0.16485    │ 0.0       │
# │ 2   │ -0.347932   │ 0.0       │
# │ 3   │ -0.690756   │ -0.576129 │
# │ 4   │ -0.196446   │ 0.0       │
# │ 5   │ 0.581154    │ 0.649416  │
# │ 6   │ 0.395072    │ 0.971569  │
# │ 7   │ -0.0520715  │ 0.0       │
# │ 8   │ 0.275344    │ 0.0       │
# │ 9   │ -0.139324   │ 0.0       │
# │ 10  │ -0.00326263 │ 0.0       │
# IHT false positives = 0
# IHT false negatives = 7
#
# current run = 5
# compare_model = 10×2 DataFrame
# │ Row │ true_β     │ IHT_β     │
# │     │ Float64    │ Float64   │
# ├─────┼────────────┼───────────┤
# │ 1   │ -0.148859  │ -0.193564 │
# │ 2   │ 0.251835   │ 0.262053  │
# │ 3   │ 0.355103   │ 0.3433    │
# │ 4   │ -0.203741  │ -0.161466 │
# │ 5   │ 0.0214489  │ 0.0       │
# │ 6   │ -0.545542  │ -0.57535  │
# │ 7   │ -0.0225566 │ 0.0       │
# │ 8   │ 0.0914211  │ 0.0       │
# │ 9   │ -0.47323   │ -0.451949 │
# │ 10  │ -0.611881  │ -0.613918 │
# IHT false positives = 1
# IHT false negatives = 3
#
# current run = 6
# compare_model = 10×2 DataFrame
# │ Row │ true_β      │ IHT_β     │
# │     │ Float64     │ Float64   │
# ├─────┼─────────────┼───────────┤
# │ 1   │ 0.343306    │ 0.35795   │
# │ 2   │ -0.127769   │ -0.128406 │
# │ 3   │ -0.606436   │ -0.674331 │
# │ 4   │ 0.620939    │ 0.626661  │
# │ 5   │ -0.198264   │ -0.214965 │
# │ 6   │ -0.130968   │ 0.0       │
# │ 7   │ -0.00261787 │ 0.0       │
# │ 8   │ 0.0619672   │ 0.0       │
# │ 9   │ -0.128121   │ 0.0       │
# │ 10  │ 0.28296     │ 0.295498  │
# IHT false positives = 0
# IHT false negatives = 4
#
# current run = 7
# compare_model = 10×2 DataFrame
# │ Row │ true_β    │ IHT_β     │
# │     │ Float64   │ Float64   │
# ├─────┼───────────┼───────────┤
# │ 1   │ 0.260955  │ 0.299481  │
# │ 2   │ 0.109838  │ 0.0       │
# │ 3   │ -0.267555 │ 0.0       │
# │ 4   │ -0.748304 │ -0.861767 │
# │ 5   │ -0.249901 │ 0.0       │
# │ 6   │ 0.561626  │ 0.502137  │
# │ 7   │ 0.213342  │ 0.249841  │
# │ 8   │ -0.217519 │ 0.0       │
# │ 9   │ -0.254169 │ 0.0       │
# │ 10  │ -0.239593 │ -0.300925 │
# IHT false positives = 0
# IHT false negatives = 5
#
# current run = 8
# compare_model = 10×2 DataFrame
# │ Row │ true_β     │ IHT_β     │
# │     │ Float64    │ Float64   │
# ├─────┼────────────┼───────────┤
# │ 1   │ -0.594327  │ -0.612462 │
# │ 2   │ -0.370005  │ -0.356374 │
# │ 3   │ -0.0741691 │ 0.0       │
# │ 4   │ 0.0128071  │ 0.0       │
# │ 5   │ 0.0707181  │ 0.0       │
# │ 6   │ 0.581991   │ 0.564735  │
# │ 7   │ -0.103392  │ 0.0       │
# │ 8   │ 0.192849   │ 0.208579  │
# │ 9   │ -0.0827345 │ 0.0       │
# │ 10  │ 0.489389   │ 0.452994  │
# IHT false positives = 0
# IHT false negatives = 5
#
# current run = 9
# compare_model = 10×2 DataFrame
# │ Row │ true_β     │ IHT_β     │
# │     │ Float64    │ Float64   │
# ├─────┼────────────┼───────────┤
# │ 1   │ -0.536759  │ 0.0       │
# │ 2   │ 0.103982   │ 0.0       │
# │ 3   │ -0.435011  │ -0.500672 │
# │ 4   │ 0.227142   │ 0.187032  │
# │ 5   │ 0.227786   │ 0.250466  │
# │ 6   │ 0.491404   │ 0.523196  │
# │ 7   │ 0.0326904  │ 0.0       │
# │ 8   │ -0.0914164 │ 0.0       │
# │ 9   │ 0.489567   │ 0.511077  │
# │ 10  │ -0.577367  │ -0.586241 │
# IHT false positives = 0
# IHT false negatives = 4
#
# current run = 10
# compare_model = 10×2 DataFrame
# │ Row │ true_β      │ IHT_β     │
# │     │ Float64     │ Float64   │
# ├─────┼─────────────┼───────────┤
# │ 1   │ -0.421237   │ -0.450195 │
# │ 2   │ 0.31012     │ 0.294769  │
# │ 3   │ 0.115111    │ 0.0       │
# │ 4   │ -0.00700671 │ 0.0       │
# │ 5   │ 0.0429208   │ 0.0       │
# │ 6   │ -0.0959159  │ 0.0       │
# │ 7   │ 0.14628     │ 0.0       │
# │ 8   │ 0.0786876   │ 0.0       │
# │ 9   │ -0.707049   │ -0.718094 │
# │ 10  │ 0.245751    │ 0.22731   │
# IHT false positives = 0
# IHT false negatives = 6
#
# current run = 11
# compare_model = 10×2 DataFrame
# │ Row │ true_β    │ IHT_β     │
# │     │ Float64   │ Float64   │
# ├─────┼───────────┼───────────┤
# │ 1   │ 0.268896  │ 0.281869  │
# │ 2   │ -0.139221 │ -0.181078 │
# │ 3   │ -0.235155 │ -0.238934 │
# │ 4   │ 0.213082  │ 0.208693  │
# │ 5   │ 0.141615  │ 0.0       │
# │ 6   │ 0.0254815 │ 0.0       │
# │ 7   │ -0.123175 │ -0.15478  │
# │ 8   │ 0.0649358 │ 0.0       │
# │ 9   │ 0.293495  │ 0.310039  │
# │ 10  │ -0.435823 │ -0.485372 │
# IHT false positives = 0
# IHT false negatives = 3
#
# current run = 12
# Did not converge!!!!! The run time for IHT was 13.204360008239746 seconds and model size was8
# compare_model = 10×2 DataFrame
# │ Row │ true_β    │ IHT_β     │
# │     │ Float64   │ Float64   │
# ├─────┼───────────┼───────────┤
# │ 1   │ -0.489527 │ -0.362392 │
# │ 2   │ 0.0265899 │ 0.0       │
# │ 3   │ -0.149202 │ 0.0       │
# │ 4   │ 0.227511  │ 0.29746   │
# │ 5   │ 0.199771  │ 0.0       │
# │ 6   │ 0.268773  │ 0.316029  │
# │ 7   │ 0.0186435 │ 0.0       │
# │ 8   │ 0.438408  │ 0.450356  │
# │ 9   │ 0.622268  │ 0.665458  │
# │ 10  │ 0.558298  │ 0.457232  │
# IHT false positives = 2
# IHT false negatives = 4
#
# current run = 13
# compare_model = 10×2 DataFrame
# │ Row │ true_β     │ IHT_β     │
# │     │ Float64    │ Float64   │
# ├─────┼────────────┼───────────┤
# │ 1   │ -0.125867  │ -0.148919 │
# │ 2   │ -0.0866494 │ 0.0       │
# │ 3   │ 0.567022   │ 0.554588  │
# │ 4   │ 0.208978   │ 0.181528  │
# │ 5   │ 0.283564   │ 0.319553  │
# │ 6   │ 0.253967   │ 0.255828  │
# │ 7   │ -0.274781  │ -0.268232 │
# │ 8   │ -0.217733  │ -0.221312 │
# │ 9   │ 0.196186   │ 0.192513  │
# │ 10  │ -0.144314  │ 0.0       │
# IHT false positives = 3
# IHT false negatives = 2
#
# current run = 14
# compare_model = 10×2 DataFrame
# │ Row │ true_β    │ IHT_β     │
# │     │ Float64   │ Float64   │
# ├─────┼───────────┼───────────┤
# │ 1   │ 0.0121624 │ 0.0       │
# │ 2   │ 0.497701  │ 0.500222  │
# │ 3   │ 0.114783  │ 0.110419  │
# │ 4   │ 0.106273  │ 0.0       │
# │ 5   │ 0.498245  │ 0.49123   │
# │ 6   │ -0.429477 │ -0.386764 │
# │ 7   │ 0.572176  │ 0.550626  │
# │ 8   │ -0.125056 │ 0.0       │
# │ 9   │ 0.273983  │ 0.237169  │
# │ 10  │ 0.186875  │ 0.188383  │
# IHT false positives = 0
# IHT false negatives = 3
#
# current run = 15
# compare_model = 10×2 DataFrame
# │ Row │ true_β     │ IHT_β     │
# │     │ Float64    │ Float64   │
# ├─────┼────────────┼───────────┤
# │ 1   │ -0.0345146 │ 0.0       │
# │ 2   │ 0.322089   │ 0.361243  │
# │ 3   │ -0.108079  │ 0.0       │
# │ 4   │ 0.272567   │ 0.236393  │
# │ 5   │ 0.248692   │ 0.242462  │
# │ 6   │ 0.104753   │ 0.0       │
# │ 7   │ -0.0643638 │ 0.0       │
# │ 8   │ -0.229821  │ -0.265227 │
# │ 9   │ 0.339275   │ 0.318309  │
# │ 10  │ 0.58889    │ 0.569872  │
# IHT false positives = 0
# IHT false negatives = 4
#
# current run = 16
# compare_model = 10×2 DataFrame
# │ Row │ true_β     │ IHT_β     │
# │     │ Float64    │ Float64   │
# ├─────┼────────────┼───────────┤
# │ 1   │ -0.122748  │ 0.0       │
# │ 2   │ -0.181849  │ -0.163422 │
# │ 3   │ -0.168873  │ -0.134822 │
# │ 4   │ 0.0575911  │ 0.0       │
# │ 5   │ -0.250087  │ -0.294458 │
# │ 6   │ -0.10282   │ 0.0       │
# │ 7   │ -0.0662685 │ 0.0       │
# │ 8   │ 0.684153   │ 0.694116  │
# │ 9   │ -0.626521  │ -0.634055 │
# │ 10  │ 0.0019257  │ 0.0       │
# IHT false positives = 1
# IHT false negatives = 5
#
# current run = 17
# compare_model = 10×2 DataFrame
# │ Row │ true_β     │ IHT_β     │
# │     │ Float64    │ Float64   │
# ├─────┼────────────┼───────────┤
# │ 1   │ 0.432851   │ 0.407928  │
# │ 2   │ -0.071855  │ 0.0       │
# │ 3   │ -0.585717  │ -0.585217 │
# │ 4   │ -0.0844272 │ 0.0       │
# │ 5   │ -0.392859  │ -0.336501 │
# │ 6   │ -0.1588    │ 0.0       │
# │ 7   │ 0.333327   │ 0.364447  │
# │ 8   │ -0.0874288 │ 0.0       │
# │ 9   │ 0.200148   │ 0.21478   │
# │ 10  │ 0.192231   │ 0.201869  │
# IHT false positives = 0
# IHT false negatives = 4
#
# current run = 18
# compare_model = 10×2 DataFrame
# │ Row │ true_β    │ IHT_β     │
# │     │ Float64   │ Float64   │
# ├─────┼───────────┼───────────┤
# │ 1   │ -0.128197 │ -0.155483 │
# │ 2   │ -0.03069  │ 0.0       │
# │ 3   │ -0.273577 │ -0.256496 │
# │ 4   │ 0.227684  │ 0.220065  │
# │ 5   │ 0.194934  │ 0.148736  │
# │ 6   │ 0.0523842 │ 0.0       │
# │ 7   │ -0.160645 │ 0.0       │
# │ 8   │ 0.0222993 │ 0.0       │
# │ 9   │ 0.35066   │ 0.381311  │
# │ 10  │ 0.511653  │ 0.518027  │
# IHT false positives = 0
# IHT false negatives = 4
#
# current run = 19
# compare_model = 10×2 DataFrame
# │ Row │ true_β    │ IHT_β     │
# │     │ Float64   │ Float64   │
# ├─────┼───────────┼───────────┤
# │ 1   │ 0.660527  │ 1.27735   │
# │ 2   │ 0.209622  │ 0.0       │
# │ 3   │ -0.212113 │ 0.0       │
# │ 4   │ -0.595741 │ 0.0       │
# │ 5   │ -0.741473 │ -0.90187  │
# │ 6   │ 0.487111  │ 0.99309   │
# │ 7   │ -0.106167 │ 0.0       │
# │ 8   │ -0.668473 │ -0.721333 │
# │ 9   │ 0.0853967 │ 0.0       │
# │ 10  │ 0.163667  │ 0.0       │
# IHT false positives = 4
# IHT false negatives = 6
#
# current run = 20
# compare_model = 10×2 DataFrame
# │ Row │ true_β     │ IHT_β     │
# │     │ Float64    │ Float64   │
# ├─────┼────────────┼───────────┤
# │ 1   │ -0.292207  │ -0.318606 │
# │ 2   │ -0.0932363 │ 0.0       │
# │ 3   │ -0.42168   │ -0.406994 │
# │ 4   │ 0.309355   │ 0.317991  │
# │ 5   │ -0.63038   │ -0.685436 │
# │ 6   │ 0.333789   │ 0.342866  │
# │ 7   │ -0.0533629 │ 0.0       │
# │ 8   │ 0.483205   │ 0.503847  │
# │ 9   │ -0.111959  │ -0.117038 │
# │ 10  │ 0.264025   │ 0.254826  │
# IHT false positives = 0
# IHT false negatives = 2
#
# current run = 21
# compare_model = 10×2 DataFrame
# │ Row │ true_β     │ IHT_β     │
# │     │ Float64    │ Float64   │
# ├─────┼────────────┼───────────┤
# │ 1   │ 0.150938   │ 0.0       │
# │ 2   │ 0.158247   │ 0.198078  │
# │ 3   │ -0.0277652 │ 0.0       │
# │ 4   │ 0.0570686  │ 0.0       │
# │ 5   │ -0.0717762 │ 0.0       │
# │ 6   │ -0.274349  │ -0.235727 │
# │ 7   │ 0.0149027  │ 0.0       │
# │ 8   │ 0.418502   │ 0.416634  │
# │ 9   │ -0.0140353 │ 0.0       │
# │ 10  │ -0.265186  │ -0.261383 │
# IHT false positives = 1
# IHT false negatives = 6
#
# current run = 22
# compare_model = 10×2 DataFrame
# │ Row │ true_β     │ IHT_β     │
# │     │ Float64    │ Float64   │
# ├─────┼────────────┼───────────┤
# │ 1   │ -0.698596  │ -0.738516 │
# │ 2   │ -0.771141  │ -0.867362 │
# │ 3   │ 0.232156   │ 0.0       │
# │ 4   │ -0.404156  │ -0.418131 │
# │ 5   │ 0.221818   │ 0.0       │
# │ 6   │ 0.525399   │ 0.541622  │
# │ 7   │ 0.303149   │ 0.272654  │
# │ 8   │ -0.0143816 │ 0.0       │
# │ 9   │ -0.083935  │ 0.0       │
# │ 10  │ -0.222816  │ 0.0       │
# IHT false positives = 0
# IHT false negatives = 5
#
# current run = 23
# compare_model = 10×2 DataFrame
# │ Row │ true_β     │ IHT_β   │
# │     │ Float64    │ Float64 │
# ├─────┼────────────┼─────────┤
# │ 1   │ -0.115664  │ 0.0     │
# │ 2   │ 0.258066   │ 0.0     │
# │ 3   │ 0.881836   │ 1242.13 │
# │ 4   │ -0.454005  │ 0.0     │
# │ 5   │ -0.157648  │ 0.0     │
# │ 6   │ -0.0278308 │ 0.0     │
# │ 7   │ -0.160551  │ 0.0     │
# │ 8   │ -0.0904443 │ 0.0     │
# │ 9   │ 0.61617    │ 0.0     │
# │ 10  │ -0.187744  │ 0.0     │
# IHT false positives = 0
# IHT false negatives = 9
#
# current run = 24
# compare_model = 10×2 DataFrame
# │ Row │ true_β     │ IHT_β     │
# │     │ Float64    │ Float64   │
# ├─────┼────────────┼───────────┤
# │ 1   │ -0.0201913 │ 0.0       │
# │ 2   │ -0.12641   │ 0.0       │
# │ 3   │ -0.3601    │ -0.21949  │
# │ 4   │ 0.350951   │ 0.456797  │
# │ 5   │ -0.0823088 │ 0.0       │
# │ 6   │ -0.381043  │ -0.254649 │
# │ 7   │ -0.248145  │ 0.0       │
# │ 8   │ -0.0205182 │ 0.0       │
# │ 9   │ -0.489564  │ -0.347428 │
# │ 10  │ 0.414741   │ 0.563127  │
# IHT false positives = 3
# IHT false negatives = 5
#
# current run = 25
# compare_model = 10×2 DataFrame
# │ Row │ true_β    │ IHT_β     │
# │     │ Float64   │ Float64   │
# ├─────┼───────────┼───────────┤
# │ 1   │ -0.158556 │ 0.0       │
# │ 2   │ 0.124538  │ 0.0       │
# │ 3   │ 0.024693  │ 0.0       │
# │ 4   │ -0.436401 │ -0.473891 │
# │ 5   │ -0.416104 │ -0.448768 │
# │ 6   │ 0.391408  │ 0.384286  │
# │ 7   │ -0.044119 │ 0.0       │
# │ 8   │ -0.197311 │ 0.0       │
# │ 9   │ -0.385135 │ 0.0       │
# │ 10  │ 0.282463  │ 0.319523  │
# IHT false positives = 0
# IHT false negatives = 6
#
# current run = 26
# compare_model = 10×2 DataFrame
# │ Row │ true_β     │ IHT_β     │
# │     │ Float64    │ Float64   │
# ├─────┼────────────┼───────────┤
# │ 1   │ 0.134235   │ 0.166104  │
# │ 2   │ 0.35166    │ 0.361349  │
# │ 3   │ 0.115536   │ 0.0969604 │
# │ 4   │ -0.107707  │ 0.0       │
# │ 5   │ -0.171336  │ -0.210232 │
# │ 6   │ -0.295722  │ -0.317079 │
# │ 7   │ 0.270327   │ 0.225344  │
# │ 8   │ -0.572037  │ -0.617756 │
# │ 9   │ -0.0611966 │ 0.0       │
# │ 10  │ 0.452709   │ 0.431483  │
# IHT false positives = 1
# IHT false negatives = 2
#
# current run = 27
# compare_model = 10×2 DataFrame
# │ Row │ true_β     │ IHT_β    │
# │     │ Float64    │ Float64  │
# ├─────┼────────────┼──────────┤
# │ 1   │ -0.221742  │ 0.0      │
# │ 2   │ -0.108625  │ 0.0      │
# │ 3   │ 0.158847   │ 0.0      │
# │ 4   │ -0.0781192 │ 0.0      │
# │ 5   │ 0.388178   │ 0.413534 │
# │ 6   │ 0.262354   │ 0.288934 │
# │ 7   │ -0.23118   │ 0.0      │
# │ 8   │ 0.319824   │ 0.346491 │
# │ 9   │ 0.609538   │ 0.58554  │
# │ 10  │ 0.125691   │ 0.0      │
# IHT false positives = 0
# IHT false negatives = 6
#
# current run = 28
# compare_model = 10×2 DataFrame
# │ Row │ true_β    │ IHT_β     │
# │     │ Float64   │ Float64   │
# ├─────┼───────────┼───────────┤
# │ 1   │ 0.451054  │ 0.491566  │
# │ 2   │ 0.332974  │ 0.350387  │
# │ 3   │ 0.0137727 │ 0.0       │
# │ 4   │ -0.176852 │ 0.0       │
# │ 5   │ 0.176085  │ 0.0       │
# │ 6   │ -0.480829 │ -0.553494 │
# │ 7   │ 0.0279864 │ 0.0       │
# │ 8   │ -0.178223 │ 0.0       │
# │ 9   │ -0.1125   │ 0.0       │
# │ 10  │ -0.178892 │ 0.0       │
# IHT false positives = 0
# IHT false negatives = 7
#
# current run = 29
# compare_model = 10×2 DataFrame
# │ Row │ true_β       │ IHT_β     │
# │     │ Float64      │ Float64   │
# ├─────┼──────────────┼───────────┤
# │ 1   │ 0.0691145    │ 0.0       │
# │ 2   │ 0.429556     │ 0.454557  │
# │ 3   │ -0.308913    │ 0.0       │
# │ 4   │ -0.0559368   │ 0.0       │
# │ 5   │ 0.0575325    │ 0.0       │
# │ 6   │ -0.0386168   │ 0.0       │
# │ 7   │ -0.16983     │ 0.0       │
# │ 8   │ -0.287865    │ -0.344214 │
# │ 9   │ -0.000116206 │ 0.0       │
# │ 10  │ -0.212912    │ -0.234817 │
# IHT false positives = 0
# IHT false negatives = 7
#
# current run = 30
# compare_model = 10×2 DataFrame
# │ Row │ true_β     │ IHT_β     │
# │     │ Float64    │ Float64   │
# ├─────┼────────────┼───────────┤
# │ 1   │ -0.329041  │ -0.285961 │
# │ 2   │ 0.544084   │ 0.518963  │
# │ 3   │ -0.112741  │ 0.0       │
# │ 4   │ 0.00285518 │ 0.0       │
# │ 5   │ 0.0536938  │ 0.0       │
# │ 6   │ -0.540733  │ -0.545397 │
# │ 7   │ 0.156971   │ 0.0       │
# │ 8   │ -0.391332  │ -0.406491 │
# │ 9   │ -0.118877  │ 0.0       │
# │ 10  │ -0.041818  │ 0.0       │
# IHT false positives = 0
# IHT false negatives = 6
#
# current run = 31
# compare_model = 10×2 DataFrame
# │ Row │ true_β     │ IHT_β    │
# │     │ Float64    │ Float64  │
# ├─────┼────────────┼──────────┤
# │ 1   │ 0.634103   │ 0.937439 │
# │ 2   │ 0.620604   │ 2.15748  │
# │ 3   │ 0.369908   │ 0.0      │
# │ 4   │ 0.101534   │ 0.0      │
# │ 5   │ 0.637163   │ 0.872826 │
# │ 6   │ -0.30768   │ 0.0      │
# │ 7   │ -0.110514  │ 0.0      │
# │ 8   │ 0.0863606  │ 0.0      │
# │ 9   │ -0.262905  │ 0.0      │
# │ 10  │ -0.0183103 │ 0.0      │
# IHT false positives = 4
# IHT false negatives = 7
#
# current run = 32
# compare_model = 10×2 DataFrame
# │ Row │ true_β     │ IHT_β     │
# │     │ Float64    │ Float64   │
# ├─────┼────────────┼───────────┤
# │ 1   │ -0.277118  │ -0.343295 │
# │ 2   │ -0.466372  │ -0.438088 │
# │ 3   │ -0.0398897 │ 0.0       │
# │ 4   │ -0.527344  │ -0.516553 │
# │ 5   │ -0.293301  │ -0.358532 │
# │ 6   │ 0.0641007  │ 0.0       │
# │ 7   │ -0.049051  │ 0.0       │
# │ 8   │ 0.258366   │ 0.296696  │
# │ 9   │ 0.00486149 │ 0.0       │
# │ 10  │ 0.378508   │ 0.374706  │
# IHT false positives = 0
# IHT false negatives = 4
#
# current run = 33
# compare_model = 10×2 DataFrame
# │ Row │ true_β     │ IHT_β     │
# │     │ Float64    │ Float64   │
# ├─────┼────────────┼───────────┤
# │ 1   │ 0.391182   │ 0.399868  │
# │ 2   │ -0.52302   │ -0.555868 │
# │ 3   │ 0.705105   │ 0.759352  │
# │ 4   │ -0.045684  │ 0.0       │
# │ 5   │ 0.347724   │ 0.0       │
# │ 6   │ -0.0946838 │ 0.0       │
# │ 7   │ 0.143748   │ 0.0       │
# │ 8   │ -0.416015  │ 0.0       │
# │ 9   │ 0.323824   │ 0.326023  │
# │ 10  │ 0.465993   │ 0.492007  │
# IHT false positives = 0
# IHT false negatives = 5
#
# current run = 34
# Did not converge!!!!! The run time for IHT was 14.352911949157715 seconds and model size was7
# compare_model = 10×2 DataFrame
# │ Row │ true_β    │ IHT_β     │
# │     │ Float64   │ Float64   │
# ├─────┼───────────┼───────────┤
# │ 1   │ -0.325854 │ -0.20093  │
# │ 2   │ 0.532156  │ 0.622216  │
# │ 3   │ -0.542394 │ -0.238835 │
# │ 4   │ 0.0773538 │ 0.0       │
# │ 5   │ -0.216993 │ 0.0       │
# │ 6   │ -0.248882 │ 0.0       │
# │ 7   │ 0.281002  │ 0.208855  │
# │ 8   │ -0.119334 │ 0.0       │
# │ 9   │ -0.275365 │ -0.227116 │
# │ 10  │ -0.391504 │ 0.0       │
# IHT false positives = 2
# IHT false negatives = 5
#
# current run = 35
# compare_model = 10×2 DataFrame
# │ Row │ true_β     │ IHT_β    │
# │     │ Float64    │ Float64  │
# ├─────┼────────────┼──────────┤
# │ 1   │ 0.0515274  │ 0.0      │
# │ 2   │ 0.512032   │ 0.460939 │
# │ 3   │ 0.357751   │ 0.56478  │
# │ 4   │ 0.448846   │ 0.435003 │
# │ 5   │ -0.0285977 │ 0.0      │
# │ 6   │ 0.389615   │ 0.558249 │
# │ 7   │ 0.171642   │ 0.0      │
# │ 8   │ 0.602603   │ 1.11653  │
# │ 9   │ -0.0658592 │ 0.0      │
# │ 10  │ 0.134793   │ 0.0      │
# IHT false positives = 6
# IHT false negatives = 5
#
# current run = 36
# compare_model = 10×2 DataFrame
# │ Row │ true_β     │ IHT_β    │
# │     │ Float64    │ Float64  │
# ├─────┼────────────┼──────────┤
# │ 1   │ -0.500887  │ 0.0      │
# │ 2   │ 0.461366   │ 0.917736 │
# │ 3   │ -0.3281    │ 0.0      │
# │ 4   │ -0.0320337 │ 0.0      │
# │ 5   │ -0.29552   │ 0.0      │
# │ 6   │ 0.135655   │ 0.0      │
# │ 7   │ 0.0153543  │ 0.0      │
# │ 8   │ 0.517486   │ 1.0272   │
# │ 9   │ -0.276711  │ 0.0      │
# │ 10  │ 0.0750093  │ 0.0      │
# IHT false positives = 1
# IHT false negatives = 8
#
# current run = 37
# compare_model = 10×2 DataFrame
# │ Row │ true_β     │ IHT_β     │
# │     │ Float64    │ Float64   │
# ├─────┼────────────┼───────────┤
# │ 1   │ 0.192576   │ 0.0       │
# │ 2   │ -0.391531  │ -0.3426   │
# │ 3   │ 0.0780456  │ 0.0       │
# │ 4   │ -0.654065  │ -0.401591 │
# │ 5   │ 0.275352   │ 0.909045  │
# │ 6   │ -0.571058  │ -0.384238 │
# │ 7   │ 0.431278   │ 0.808296  │
# │ 8   │ -0.104421  │ 0.0       │
# │ 9   │ -0.0019163 │ 0.0       │
# │ 10  │ 0.205562   │ 0.307414  │
# IHT false positives = 4
# IHT false negatives = 4
#
# current run = 38
# compare_model = 10×2 DataFrame
# │ Row │ true_β     │ IHT_β   │
# │     │ Float64    │ Float64 │
# ├─────┼────────────┼─────────┤
# │ 1   │ -0.0830212 │ 0.0     │
# │ 2   │ -0.176432  │ 0.0     │
# │ 3   │ 0.227377   │ 0.0     │
# │ 4   │ -0.226449  │ 0.0     │
# │ 5   │ -0.0503127 │ 0.0     │
# │ 6   │ 0.387734   │ 0.39808 │
# │ 7   │ 0.176321   │ 0.0     │
# │ 8   │ 0.177879   │ 0.0     │
# │ 9   │ -0.606555  │ 0.0     │
# │ 10  │ 0.411759   │ 0.47801 │
# IHT false positives = 0
# IHT false negatives = 8
#
# current run = 39
# compare_model = 10×2 DataFrame
# │ Row │ true_β     │ IHT_β     │
# │     │ Float64    │ Float64   │
# ├─────┼────────────┼───────────┤
# │ 1   │ -0.1896    │ -0.188019 │
# │ 2   │ -0.232063  │ -0.219962 │
# │ 3   │ -0.247769  │ -0.240974 │
# │ 4   │ -0.0626826 │ 0.0       │
# │ 5   │ -0.201835  │ -0.19709  │
# │ 6   │ -0.098421  │ 0.0       │
# │ 7   │ -0.465508  │ -0.47191  │
# │ 8   │ 0.420086   │ 0.399074  │
# │ 9   │ -0.306633  │ -0.266936 │
# │ 10  │ 0.261557   │ 0.237493  │
# IHT false positives = 2
# IHT false negatives = 2
#
# current run = 40
# compare_model = 10×2 DataFrame
# │ Row │ true_β     │ IHT_β     │
# │     │ Float64    │ Float64   │
# ├─────┼────────────┼───────────┤
# │ 1   │ -0.305113  │ -0.278988 │
# │ 2   │ 0.240939   │ 0.258071  │
# │ 3   │ -0.0127947 │ 0.0       │
# │ 4   │ -0.221986  │ -0.239296 │
# │ 5   │ -0.177064  │ 0.0       │
# │ 6   │ 0.225016   │ 0.243483  │
# │ 7   │ -0.0469581 │ 0.0       │
# │ 8   │ 0.27213    │ 0.246771  │
# │ 9   │ 0.282786   │ 0.314731  │
# │ 10  │ -0.417658  │ -0.379154 │
# IHT false positives = 0
# IHT false negatives = 3
#
# current run = 41
# compare_model = 10×2 DataFrame
# │ Row │ true_β    │ IHT_β   │
# │     │ Float64   │ Float64 │
# ├─────┼───────────┼─────────┤
# │ 1   │ -0.312235 │ 0.0     │
# │ 2   │ -0.22746  │ 0.0     │
# │ 3   │ 0.156331  │ 0.0     │
# │ 4   │ 0.206298  │ 0.0     │
# │ 5   │ 0.849896  │ 2.03501 │
# │ 6   │ -0.333805 │ 0.0     │
# │ 7   │ 0.189317  │ 0.0     │
# │ 8   │ -0.320116 │ 0.0     │
# │ 9   │ 0.0700254 │ 0.0     │
# │ 10  │ 0.12404   │ 0.0     │
# IHT false positives = 0
# IHT false negatives = 9
#
# current run = 42
# compare_model = 10×2 DataFrame
# │ Row │ true_β    │ IHT_β   │
# │     │ Float64   │ Float64 │
# ├─────┼───────────┼─────────┤
# │ 1   │ 0.414793  │ 0.0     │
# │ 2   │ -0.156114 │ 0.0     │
# │ 3   │ -0.386753 │ 0.0     │
# │ 4   │ 0.49999   │ 0.0     │
# │ 5   │ 0.706397  │ 3.75958 │
# │ 6   │ -0.169213 │ 0.0     │
# │ 7   │ 0.245957  │ 0.0     │
# │ 8   │ 0.524386  │ 0.0     │
# │ 9   │ -0.332476 │ 0.0     │
# │ 10  │ 0.0587315 │ 0.0     │
# IHT false positives = 0
# IHT false negatives = 9
#
# current run = 43
# compare_model = 10×2 DataFrame
# │ Row │ true_β      │ IHT_β     │
# │     │ Float64     │ Float64   │
# ├─────┼─────────────┼───────────┤
# │ 1   │ 0.0123848   │ 0.0       │
# │ 2   │ 0.0447108   │ 0.0       │
# │ 3   │ -0.0564623  │ 0.0       │
# │ 4   │ -0.00738185 │ 0.0       │
# │ 5   │ 0.653413    │ 0.625329  │
# │ 6   │ -0.209229   │ -0.1867   │
# │ 7   │ -0.474121   │ -0.417629 │
# │ 8   │ -0.00778169 │ 0.0       │
# │ 9   │ -0.191398   │ -0.209008 │
# │ 10  │ -0.405206   │ -0.43531  │
# IHT false positives = 0
# IHT false negatives = 5
#
# current run = 44
# compare_model = 10×2 DataFrame
# │ Row │ true_β     │ IHT_β     │
# │     │ Float64    │ Float64   │
# ├─────┼────────────┼───────────┤
# │ 1   │ -0.407477  │ -0.46714  │
# │ 2   │ -0.0707954 │ 0.0       │
# │ 3   │ -0.248652  │ -0.267115 │
# │ 4   │ -0.046565  │ 0.0       │
# │ 5   │ 0.0322649  │ 0.0       │
# │ 6   │ -0.205621  │ -0.260051 │
# │ 7   │ -0.146244  │ 0.0       │
# │ 8   │ 0.391846   │ 0.395142  │
# │ 9   │ 0.482746   │ 0.482299  │
# │ 10  │ 0.0495608  │ 0.0       │
# IHT false positives = 0
# IHT false negatives = 5
#
# current run = 45
# compare_model = 10×2 DataFrame
# │ Row │ true_β     │ IHT_β    │
# │     │ Float64    │ Float64  │
# ├─────┼────────────┼──────────┤
# │ 1   │ 0.314162   │ 0.522904 │
# │ 2   │ -0.0129241 │ 0.0      │
# │ 3   │ 0.361082   │ 0.584157 │
# │ 4   │ 0.498318   │ 0.628396 │
# │ 5   │ 0.464378   │ 0.528175 │
# │ 6   │ -0.445019  │ -0.43675 │
# │ 7   │ -0.353314  │ 0.0      │
# │ 8   │ 0.166615   │ 0.0      │
# │ 9   │ -0.22309   │ 0.0      │
# │ 10  │ 0.434632   │ 0.0      │
# IHT false positives = 2
# IHT false negatives = 5
#
# current run = 46
# compare_model = 10×2 DataFrame
# │ Row │ true_β      │ IHT_β     │
# │     │ Float64     │ Float64   │
# ├─────┼─────────────┼───────────┤
# │ 1   │ 0.0442418   │ 0.0       │
# │ 2   │ -0.00383096 │ 0.0       │
# │ 3   │ -0.446122   │ -0.442178 │
# │ 4   │ 0.129079    │ 0.0       │
# │ 5   │ -0.142683   │ 0.0       │
# │ 6   │ -0.0464614  │ 0.0       │
# │ 7   │ -0.0801994  │ 0.0       │
# │ 8   │ -0.0789072  │ 0.0       │
# │ 9   │ -0.195067   │ 0.0       │
# │ 10  │ 0.302384    │ 0.32267   │
# IHT false positives = 0
# IHT false negatives = 8
#
# current run = 47
# compare_model = 10×2 DataFrame
# │ Row │ true_β    │ IHT_β     │
# │     │ Float64   │ Float64   │
# ├─────┼───────────┼───────────┤
# │ 1   │ -0.222623 │ -0.206525 │
# │ 2   │ 0.233403  │ 0.264985  │
# │ 3   │ 0.283149  │ 0.280666  │
# │ 4   │ 0.0176794 │ 0.0       │
# │ 5   │ 0.224283  │ 0.188262  │
# │ 6   │ -0.496739 │ -0.536446 │
# │ 7   │ -0.252564 │ -0.232662 │
# │ 8   │ 0.202071  │ 0.186276  │
# │ 9   │ -0.376555 │ -0.402398 │
# │ 10  │ -0.102183 │ 0.0       │
# IHT false positives = 0
# IHT false negatives = 2
#
# current run = 48
# compare_model = 10×2 DataFrame
# │ Row │ true_β     │ IHT_β     │
# │     │ Float64    │ Float64   │
# ├─────┼────────────┼───────────┤
# │ 1   │ -0.136858  │ 0.0       │
# │ 2   │ -0.254687  │ -0.242808 │
# │ 3   │ 0.0735064  │ 0.0       │
# │ 4   │ 0.259293   │ 0.257307  │
# │ 5   │ -0.271155  │ -0.200515 │
# │ 6   │ -0.0813769 │ 0.0       │
# │ 7   │ -0.174058  │ -0.224652 │
# │ 8   │ -0.297767  │ -0.265544 │
# │ 9   │ -0.102294  │ 0.0       │
# │ 10  │ -0.292038  │ -0.319107 │
# IHT false positives = 0
# IHT false negatives = 4
#
# current run = 49
# compare_model = 10×2 DataFrame
# │ Row │ true_β     │ IHT_β     │
# │     │ Float64    │ Float64   │
# ├─────┼────────────┼───────────┤
# │ 1   │ 0.00890582 │ 0.0       │
# │ 2   │ -0.0495758 │ 0.0       │
# │ 3   │ -0.0701617 │ 0.0       │
# │ 4   │ 0.14716    │ 0.176569  │
# │ 5   │ 0.373493   │ 0.368347  │
# │ 6   │ -0.344589  │ -0.259838 │
# │ 7   │ 0.367565   │ 0.393388  │
# │ 8   │ -0.130516  │ 0.0       │
# │ 9   │ -0.214019  │ -0.239775 │
# │ 10  │ -0.216821  │ -0.242901 │
# IHT false positives = 2
# IHT false negatives = 4
#
# current run = 50
# compare_model = 10×2 DataFrame
# │ Row │ true_β     │ IHT_β   │
# │     │ Float64    │ Float64 │
# ├─────┼────────────┼─────────┤
# │ 1   │ -0.142318  │ 0.0     │
# │ 2   │ 0.0532411  │ 0.0     │
# │ 3   │ 0.795347   │ 4.63164 │
# │ 4   │ -0.0491065 │ 0.0     │
# │ 5   │ -0.0581266 │ 0.0     │
# │ 6   │ 0.478048   │ 0.0     │
# │ 7   │ 0.0538702  │ 0.0     │
# │ 8   │ -0.564814  │ 0.0     │
# │ 9   │ 0.24502    │ 0.0     │
# │ 10  │ -0.411475  │ 0.0     │
# IHT false positives = 0
# IHT false negatives = 9

# %%
negativebinomial_iht_false_positives = (0+1+1+0+1+0+0+0+0+0+0+2+3+0+0+1+0+0+4+0+1+0+0+3+0+
                                       1+0+0+0+0+4+0+0+2+6+1+4+0+2+0+0+0+0+0+2+0+0+0+2+0)/ 50
bernoulli_iht_false_negatives = (2+8+3+7+3+4+5+5+4+6+3+4+2+3+4+5+4+4+6+2+6+5+9+5+6+
                                2+6+7+7+6+7+4+5+5+5+8+4+8+2+3+9+9+5+5+5+8+2+4+4+9)/50
IHT_did_not_converge = 2
result = [negativebinomial_iht_false_positives; bernoulli_iht_false_negatives]
# Out:
# 2-element Array{Float64,1}:
#  0.82
#  5.08
