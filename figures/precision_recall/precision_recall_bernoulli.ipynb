# %% [markdown]
# # Bernoulli: Compare false positive/negatives with LASSO
#
# LASSO is currently the de facto penalized least squares method for [feature selection](https://en.wikipedia.org/wiki/Feature_selection). Here we compare the performance (in terms of the number of false positives/negative) of LASSO with IHT for GWAS data, using the `glmnet` implementation of cyclic coordinate descent for LASSO. Since the focus here is not scalability, we test our sample problems on moderately sized genotype matrces of 1000 samples with 10,000 SNPs.

# %%
using Distributed
addprocs(4)
nprocs()
# Out:
# 5

# %%
using MendelIHT
using SnpArrays
using DataFrames
using Distributions
using Random
using LinearAlgebra
using DelimitedFiles
using GLM
using RCall
R"library(glmnet)"
# Out:
# ┌ Warning: RCall.jl: During startup - Warning message:
# │ Setting LC_CTYPE failed, using "C"
# └ @ RCall /u/home/b/biona001/.julia/packages/RCall/ffM0W/src/io.jl:113
# ┌ Warning: RCall.jl: During startup - Warning message:
# │ Setting LC_CTYPE failed, using "C"
# └ @ RCall ~/.julia/packages/RCall/ffM0W/src/io.jl:113
# ┌ Warning: RCall.jl: During startup - Warning message:
# │ Setting LC_CTYPE failed, using "C"
# └ @ RCall ~/.julia/packages/RCall/ffM0W/src/io.jl:113
# ┌ Warning: RCall.jl: During startup - Warning message:
# │ Setting LC_CTYPE failed, using "C"
# └ @ RCall ~/.julia/packages/RCall/ffM0W/src/io.jl:113
# ┌ Warning: RCall.jl: During startup - Warning message:
# │ Setting LC_CTYPE failed, using "C"
# └ @ RCall ~/.julia/packages/RCall/ffM0W/src/io.jl:113
# ┌ Warning: RCall.jl: Loading required package: Matrix
# │ Loading required package: foreach
# │ Loaded glmnet 2.0-16
# │
# └ @ RCall /u/home/b/biona001/.julia/packages/RCall/ffM0W/src/io.jl:113
# RObject{StrSxp}
#  [1] "glmnet"    "foreach"   "Matrix"    "stats"     "graphics"  "grDevices"
#  [7] "utils"     "datasets"  "methods"   "base"

# %% [markdown]
# # Bernoulli response (i.e. logistic regression)

# %%
function iht_lasso_bernoulli(n::Int64, p::Int64, k::Int64, d::UnionAll, l::Link)
    #construct snpmatrix, covariate files, and true model b
    x, = simulate_random_snparray(n, p, undef)
    xbm = SnpBitMatrix{Float64}(x, model=ADDITIVE_MODEL, center=true, scale=true); 
    z = ones(n, 1) # the intercept
    x_float = [convert(Matrix{Float64}, x, center=true, scale=true) z] #Float64 version of x

    # simulate response, true model b, and the correct non-0 positions of b
    y, true_b, correct_position = simulate_random_response(x, xbm, k, d, l)
 
    #specify path and folds
    num_folds = 3
    folds = rand(1:num_folds, size(x, 1));

    #run glmnet via Rcall
    @rput x_float y folds num_folds #make variables visible to R
    R"lasso_cv_result = cv.glmnet(x_float, y, nfolds = num_folds, foldid = folds, family='binomial')"
    R"lasso_beta_tmp = glmnet(x_float, y, lambda=lasso_cv_result$lambda.min, family='binomial')$beta"
    R"lasso_beta = as.vector(lasso_beta_tmp)"
    @rget lasso_cv_result lasso_beta #pull result from R to Julia
    lasso_k_est = count(!iszero, lasso_beta)
    
    #find non-zero entries returned by best lasso model as largest k estimate
    path = collect(1:50);
    
    #run IHT's cross validation routine 
    mses = cv_iht_distributed(d(), l, x, z, y, 1, path, folds, num_folds, use_maf=false, debias=false, showinfo=false, parallel=true);
    iht_k_est = argmin(mses)
    iht_result = L0_reg(x, xbm, z, y, 1, iht_k_est, d(), l, debias=false, init=false, use_maf=false)
    iht_beta = iht_result.beta
        
    #show lasso and IHT's reconstruction result
    compare_model = DataFrame(
        true_β  = true_b[correct_position], 
        IHT_β   = iht_beta[correct_position],
        lasso_β = lasso_beta[correct_position])
    @show compare_model
    
    #compute true/false positives/negatives for IHT and lasso
    iht_tp = count(!iszero, iht_beta[correct_position])
    iht_fp = iht_k_est - iht_tp
    iht_fn = k - iht_tp
    lasso_tp = count(!iszero, lasso_beta[correct_position])
    lasso_fp = lasso_k_est - lasso_tp
    lasso_fn = k - lasso_tp
    
    println("IHT false positives = $iht_fp")
    println("IHT false negatives = $iht_fn")
    println("LASSO false positives = $lasso_fp")
    println("LASSO false positives = $lasso_fn" * "\n")
    
    return iht_fp, iht_fn, lasso_fp, lasso_fn
end
# Out:
# iht_lasso_bernoulli (generic function with 1 method)

# %%
#simulat data with k true predictors, from distribution d and with link l.
n = 1000
p = 10000
k = 10
d = Bernoulli
l = canonicallink(d())

#set random seed
Random.seed!(2019)

#run function above, saving results in 4 vectors
total_runs = 50
iht_false_positives = zeros(total_runs)
iht_false_negatives = zeros(total_runs)
lasso_false_positives = zeros(total_runs)
lasso_false_negatives = zeros(total_runs)
for i in 1:total_runs
    println("current run = $i")
    iht_fp, iht_fn, lasso_fp, lasso_fn = iht_lasso_bernoulli(n, p, k, d, l)
    iht_false_positives[i] = iht_fp
    iht_false_negatives[i] = iht_fn
    lasso_false_positives[i] = lasso_fp
    lasso_false_negatives[i] = lasso_fn
end
# Out:
# current run = 1
# compare_model = 10×3 DataFrame
# │ Row │ true_β   │ IHT_β     │ lasso_β   │
# │     │ Float64  │ Float64   │ Float64   │
# ├─────┼──────────┼───────────┼───────────┤
# │ 1   │ -1.29964 │ -1.20594  │ -0.696055 │
# │ 2   │ -0.2177  │ 0.0       │ -0.032045 │
# │ 3   │ 0.786217 │ 0.74778   │ 0.35188   │
# │ 4   │ 0.599233 │ 0.500377  │ 0.144367  │
# │ 5   │ 0.283711 │ 0.0       │ 0.101466  │
# │ 6   │ -1.12537 │ -1.09734  │ -0.63629  │
# │ 7   │ 0.693374 │ 0.58001   │ 0.261347  │
# │ 8   │ -0.67709 │ -0.718464 │ -0.337016 │
# │ 9   │ 0.14727  │ 0.0       │ 0.0       │
# │ 10  │ 1.03477  │ 1.02787   │ 0.591364  │
# IHT false positives = 0
# IHT false negatives = 3
# LASSO false positives = 61
# LASSO false positives = 1
#
# current run = 2
# compare_model = 10×3 DataFrame
# │ Row │ true_β    │ IHT_β     │ lasso_β   │
# │     │ Float64   │ Float64   │ Float64   │
# ├─────┼───────────┼───────────┼───────────┤
# │ 1   │ -0.872089 │ -0.771944 │ -0.30663  │
# │ 2   │ -0.511788 │ -0.586261 │ -0.239912 │
# │ 3   │ 0.639028  │ 0.668167  │ 0.302832  │
# │ 4   │ -1.23082  │ -1.17154  │ -0.568799 │
# │ 5   │ 0.683517  │ 0.782097  │ 0.371164  │
# │ 6   │ -0.162982 │ 0.0       │ 0.0       │
# │ 7   │ -2.05519  │ -1.91028  │ -1.08467  │
# │ 8   │ 1.19014   │ 1.15791   │ 0.623925  │
# │ 9   │ 0.920725  │ 0.749588  │ 0.267722  │
# │ 10  │ 1.29556   │ 1.11188   │ 0.537087  │
# IHT false positives = 1
# IHT false negatives = 1
# LASSO false positives = 144
# LASSO false positives = 1
#
# current run = 3
# compare_model = 10×3 DataFrame
# │ Row │ true_β     │ IHT_β     │ lasso_β   │
# │     │ Float64    │ Float64   │ Float64   │
# ├─────┼────────────┼───────────┼───────────┤
# │ 1   │ 1.18012    │ 1.19663   │ 0.638251  │
# │ 2   │ 0.801966   │ 0.717363  │ 0.300946  │
# │ 3   │ -0.808403  │ -0.972686 │ -0.468475 │
# │ 4   │ -1.21664   │ -1.07194  │ -0.599294 │
# │ 5   │ -0.823003  │ -0.718623 │ -0.325052 │
# │ 6   │ -0.0322271 │ 0.0       │ 0.0       │
# │ 7   │ -1.29589   │ -1.23547  │ -0.650294 │
# │ 8   │ 0.923503   │ 0.856865  │ 0.393116  │
# │ 9   │ 0.773771   │ 0.750134  │ 0.337112  │
# │ 10  │ -0.528605  │ -0.581693 │ -0.229439 │
# IHT false positives = 0
# IHT false negatives = 1
# LASSO false positives = 89
# LASSO false positives = 1
#
# current run = 4
# compare_model = 10×3 DataFrame
# │ Row │ true_β    │ IHT_β     │ lasso_β    │
# │     │ Float64   │ Float64   │ Float64    │
# ├─────┼───────────┼───────────┼────────────┤
# │ 1   │ -0.846312 │ -0.879795 │ -0.435551  │
# │ 2   │ -0.665467 │ -0.699481 │ -0.301614  │
# │ 3   │ -0.76197  │ -0.792474 │ -0.317236  │
# │ 4   │ -0.758229 │ -0.749652 │ -0.369477  │
# │ 5   │ -0.138244 │ 0.0       │ 0.0        │
# │ 6   │ -0.889865 │ -0.751443 │ -0.409008  │
# │ 7   │ -0.451658 │ 0.0       │ -0.0972556 │
# │ 8   │ -0.618249 │ -0.564232 │ -0.230062  │
# │ 9   │ -1.54379  │ -1.46229  │ -0.958359  │
# │ 10  │ 1.36425   │ 1.40776   │ 0.841381   │
# IHT false positives = 0
# IHT false negatives = 2
# LASSO false positives = 129
# LASSO false positives = 1
#
# current run = 5
# compare_model = 10×3 DataFrame
# │ Row │ true_β    │ IHT_β     │ lasso_β    │
# │     │ Float64   │ Float64   │ Float64    │
# ├─────┼───────────┼───────────┼────────────┤
# │ 1   │ 1.43572   │ 1.44862   │ 0.840789   │
# │ 2   │ -0.368505 │ 0.0       │ -0.0190764 │
# │ 3   │ -0.134826 │ 0.0       │ 0.0        │
# │ 4   │ 0.974709  │ 0.82906   │ 0.426936   │
# │ 5   │ 1.4275    │ 1.40675   │ 0.851839   │
# │ 6   │ -2.00126  │ -2.11522  │ -1.38057   │
# │ 7   │ -1.88835  │ -1.90478  │ -1.21338   │
# │ 8   │ -0.142363 │ 0.0       │ 0.0        │
# │ 9   │ -0.135667 │ 0.0       │ 0.0        │
# │ 10  │ -0.698182 │ -0.676564 │ -0.307342  │
# IHT false positives = 0
# IHT false negatives = 4
# LASSO false positives = 185
# LASSO false positives = 3
#
# current run = 6
# compare_model = 10×3 DataFrame
# │ Row │ true_β    │ IHT_β     │ lasso_β  │
# │     │ Float64   │ Float64   │ Float64  │
# ├─────┼───────────┼───────────┼──────────┤
# │ 1   │ 0.687122  │ 0.683507  │ 0.283885 │
# │ 2   │ 0.973813  │ 0.838007  │ 0.392683 │
# │ 3   │ -0.468456 │ -0.576865 │ -0.16354 │
# │ 4   │ 0.870921  │ 0.889572  │ 0.465983 │
# │ 5   │ 2.03482   │ 1.96491   │ 1.23121  │
# │ 6   │ 0.656674  │ 0.728906  │ 0.282431 │
# │ 7   │ 0.666523  │ 0.659823  │ 0.27243  │
# │ 8   │ 0.304438  │ 0.0       │ 0.124003 │
# │ 9   │ -2.22819  │ -2.13921  │ -1.28105 │
# │ 10  │ -1.83075  │ -1.68843  │ -1.04578 │
# IHT false positives = 0
# IHT false negatives = 1
# LASSO false positives = 158
# LASSO false positives = 0
#
# current run = 7
# compare_model = 10×3 DataFrame
# │ Row │ true_β    │ IHT_β     │ lasso_β   │
# │     │ Float64   │ Float64   │ Float64   │
# ├─────┼───────────┼───────────┼───────────┤
# │ 1   │ -0.191599 │ 0.0       │ 0.0       │
# │ 2   │ -1.46422  │ -1.41435  │ -0.866795 │
# │ 3   │ 0.962084  │ 0.876101  │ 0.44819   │
# │ 4   │ -1.81266  │ -1.73811  │ -1.0268   │
# │ 5   │ -0.105312 │ 0.0       │ 0.0       │
# │ 6   │ -0.972855 │ -0.991739 │ -0.552469 │
# │ 7   │ -0.63823  │ -0.728211 │ -0.331831 │
# │ 8   │ 0.269525  │ 0.0       │ 0.0306814 │
# │ 9   │ 1.03719   │ 1.04233   │ 0.563066  │
# │ 10  │ -0.425078 │ 0.0       │ -0.132674 │
# IHT false positives = 0
# IHT false negatives = 4
# LASSO false positives = 111
# LASSO false positives = 2
#
# current run = 8
# compare_model = 10×3 DataFrame
# │ Row │ true_β    │ IHT_β     │ lasso_β    │
# │     │ Float64   │ Float64   │ Float64    │
# ├─────┼───────────┼───────────┼────────────┤
# │ 1   │ -0.801789 │ -0.883628 │ -0.407925  │
# │ 2   │ 0.674548  │ 0.671894  │ 0.237034   │
# │ 3   │ -1.28364  │ -1.27887  │ -0.677492  │
# │ 4   │ 1.3316    │ 1.47215   │ 0.800758   │
# │ 5   │ -0.514755 │ -0.564871 │ -0.215287  │
# │ 6   │ 0.91111   │ 0.867312  │ 0.426687   │
# │ 7   │ -1.69021  │ -1.69027  │ -0.97589   │
# │ 8   │ 0.278522  │ 0.0       │ 0.0        │
# │ 9   │ 0.0178461 │ 0.0       │ 0.0        │
# │ 10  │ -0.273926 │ 0.0       │ -0.0295454 │
# IHT false positives = 0
# IHT false negatives = 3
# LASSO false positives = 65
# LASSO false positives = 2
#
# current run = 9
# compare_model = 10×3 DataFrame
# │ Row │ true_β   │ IHT_β    │ lasso_β   │
# │     │ Float64  │ Float64  │ Float64   │
# ├─────┼──────────┼──────────┼───────────┤
# │ 1   │ 0.20097  │ 0.0      │ 0.0       │
# │ 2   │ 0.432351 │ 0.347703 │ 0.0662888 │
# │ 3   │ 0.385727 │ 0.39691  │ 0.116857  │
# │ 4   │ 0.899481 │ 0.7794   │ 0.366034  │
# │ 5   │ 0.562328 │ 0.402551 │ 0.131947  │
# │ 6   │ -1.6765  │ -1.33948 │ -0.871445 │
# │ 7   │ 0.579937 │ 0.54385  │ 0.203909  │
# │ 8   │ 0.422576 │ 0.0      │ 0.0611625 │
# │ 9   │ 0.502793 │ 0.0      │ 0.0276671 │
# │ 10  │ 0.723445 │ 0.572498 │ 0.245103  │
# IHT false positives = 0
# IHT false negatives = 3
# LASSO false positives = 25
# LASSO false positives = 1
#
# current run = 10
# compare_model = 10×3 DataFrame
# │ Row │ true_β      │ IHT_β     │ lasso_β    │
# │     │ Float64     │ Float64   │ Float64    │
# ├─────┼─────────────┼───────────┼────────────┤
# │ 1   │ 2.33302     │ 2.1459    │ 1.18817    │
# │ 2   │ 0.246926    │ 0.0       │ 0.00315262 │
# │ 3   │ -1.2795     │ -1.21648  │ -0.680503  │
# │ 4   │ -0.00696882 │ 0.0       │ 0.0        │
# │ 5   │ 1.17385     │ 1.19735   │ 0.652395   │
# │ 6   │ -0.0820692  │ 0.0       │ 0.0        │
# │ 7   │ -0.901971   │ -0.89453  │ -0.42524   │
# │ 8   │ 1.3595      │ 1.33188   │ 0.712226   │
# │ 9   │ -0.286463   │ 0.0       │ 0.0        │
# │ 10  │ -0.433872   │ -0.602163 │ -0.201043  │
# IHT false positives = 0
# IHT false negatives = 4
# LASSO false positives = 94
# LASSO false positives = 3
#
# current run = 11
# compare_model = 10×3 DataFrame
# │ Row │ true_β    │ IHT_β     │ lasso_β    │
# │     │ Float64   │ Float64   │ Float64    │
# ├─────┼───────────┼───────────┼────────────┤
# │ 1   │ -0.371688 │ 0.0       │ -0.0952994 │
# │ 2   │ -1.3385   │ -1.30799  │ -0.78093   │
# │ 3   │ 1.56377   │ 1.56291   │ 0.973851   │
# │ 4   │ -1.41519  │ -1.42925  │ -0.904569  │
# │ 5   │ -0.439244 │ -0.577359 │ -0.217037  │
# │ 6   │ 0.0795251 │ 0.0       │ 0.0        │
# │ 7   │ -0.539145 │ 0.0       │ -0.141285  │
# │ 8   │ 0.376679  │ 0.0       │ 0.0634085  │
# │ 9   │ -1.68979  │ -1.53348  │ -0.957773  │
# │ 10  │ 1.26637   │ 1.30133   │ 0.764344   │
# IHT false positives = 0
# IHT false negatives = 4
# LASSO false positives = 129
# LASSO false positives = 1
#
# current run = 12
# compare_model = 10×3 DataFrame
# │ Row │ true_β     │ IHT_β     │ lasso_β   │
# │     │ Float64    │ Float64   │ Float64   │
# ├─────┼────────────┼───────────┼───────────┤
# │ 1   │ 0.379041   │ 0.0       │ 0.0       │
# │ 2   │ 1.10996    │ 1.05511   │ 0.593084  │
# │ 3   │ 1.3245     │ 1.20205   │ 0.692375  │
# │ 4   │ -0.232987  │ 0.0       │ 0.0       │
# │ 5   │ -1.30509   │ -1.18586  │ -0.668554 │
# │ 6   │ -0.0185486 │ 0.0       │ 0.0       │
# │ 7   │ -0.647897  │ -0.706357 │ -0.344263 │
# │ 8   │ -0.160069  │ 0.0       │ 0.0       │
# │ 9   │ -1.36721   │ -1.20354  │ -0.677978 │
# │ 10  │ 0.607559   │ 0.556394  │ 0.235793  │
# IHT false positives = 0
# IHT false negatives = 4
# LASSO false positives = 66
# LASSO false positives = 4
#
# current run = 13
# compare_model = 10×3 DataFrame
# │ Row │ true_β    │ IHT_β     │ lasso_β    │
# │     │ Float64   │ Float64   │ Float64    │
# ├─────┼───────────┼───────────┼────────────┤
# │ 1   │ -1.32172  │ -1.1967   │ -0.66125   │
# │ 2   │ -2.42241  │ -2.39941  │ -1.54063   │
# │ 3   │ -0.962085 │ -0.896322 │ -0.418608  │
# │ 4   │ 0.928722  │ 0.873212  │ 0.431524   │
# │ 5   │ 0.87185   │ 0.801726  │ 0.33278    │
# │ 6   │ -0.882336 │ 0.0       │ -0.0979507 │
# │ 7   │ -0.325702 │ 0.0       │ -0.056286  │
# │ 8   │ -0.30372  │ 0.0       │ 0.0        │
# │ 9   │ -1.88809  │ -1.7284   │ -0.85221   │
# │ 10  │ 0.506851  │ 0.0       │ 0.138668   │
# IHT false positives = 0
# IHT false negatives = 4
# LASSO false positives = 109
# LASSO false positives = 1
#
# current run = 14
# compare_model = 10×3 DataFrame
# │ Row │ true_β    │ IHT_β     │ lasso_β    │
# │     │ Float64   │ Float64   │ Float64    │
# ├─────┼───────────┼───────────┼────────────┤
# │ 1   │ -0.440371 │ 0.0       │ -0.0102673 │
# │ 2   │ -0.273471 │ 0.0       │ 0.0        │
# │ 3   │ -0.461902 │ 0.0       │ -0.012371  │
# │ 4   │ 0.193672  │ 0.0       │ 0.0        │
# │ 5   │ -0.33359  │ 0.0       │ 0.0        │
# │ 6   │ -0.484993 │ 0.0       │ -0.196074  │
# │ 7   │ -2.28793  │ -1.96275  │ -1.3549    │
# │ 8   │ -0.664791 │ -0.675452 │ -0.309276  │
# │ 9   │ -1.19371  │ -1.14231  │ -0.672004  │
# │ 10  │ -1.10844  │ -0.877258 │ -0.466477  │
# IHT false positives = 0
# IHT false negatives = 6
# LASSO false positives = 52
# LASSO false positives = 3
#
# current run = 15
# compare_model = 10×3 DataFrame
# │ Row │ true_β   │ IHT_β     │ lasso_β   │
# │     │ Float64  │ Float64   │ Float64   │
# ├─────┼──────────┼───────────┼───────────┤
# │ 1   │ 2.04923  │ 1.84258   │ 1.12948   │
# │ 2   │ -1.60562 │ -1.50287  │ -0.737198 │
# │ 3   │ 0.302916 │ 0.0       │ 0.0       │
# │ 4   │ 0.453491 │ 0.0       │ 0.086117  │
# │ 5   │ 1.39488  │ 1.39003   │ 0.798775  │
# │ 6   │ 0.869995 │ 0.776417  │ 0.389032  │
# │ 7   │ -0.78997 │ -0.532408 │ -0.194915 │
# │ 8   │ 1.76702  │ 1.35121   │ 0.535847  │
# │ 9   │ 0.121948 │ 0.0       │ 0.0139707 │
# │ 10  │ 0.212302 │ 0.0       │ 0.0       │
# IHT false positives = 0
# IHT false negatives = 4
# LASSO false positives = 87
# LASSO false positives = 2
#
# current run = 16
# compare_model = 10×3 DataFrame
# │ Row │ true_β    │ IHT_β     │ lasso_β    │
# │     │ Float64   │ Float64   │ Float64    │
# ├─────┼───────────┼───────────┼────────────┤
# │ 1   │ -1.04354  │ -1.03214  │ -0.587662  │
# │ 2   │ -0.185709 │ 0.0       │ -0.0289403 │
# │ 3   │ -0.138808 │ 0.0       │ 0.0        │
# │ 4   │ -0.713629 │ -0.737418 │ -0.286467  │
# │ 5   │ 0.34244   │ 0.0       │ 0.0764318  │
# │ 6   │ 1.3142    │ 1.16902   │ 0.718206   │
# │ 7   │ 0.315155  │ 0.0       │ 0.0        │
# │ 8   │ -0.352167 │ 0.0       │ 0.0        │
# │ 9   │ 1.62014   │ 1.55602   │ 0.957778   │
# │ 10  │ 0.229358  │ 0.0       │ 0.0        │
# IHT false positives = 0
# IHT false negatives = 6
# LASSO false positives = 42
# LASSO false positives = 4
#
# current run = 17
# compare_model = 10×3 DataFrame
# │ Row │ true_β    │ IHT_β   │ lasso_β    │
# │     │ Float64   │ Float64 │ Float64    │
# ├─────┼───────────┼─────────┼────────────┤
# │ 1   │ 0.594891  │ 0.0     │ 0.144304   │
# │ 2   │ 2.1752    │ 1.76509 │ 1.11504    │
# │ 3   │ 0.342455  │ 0.0     │ 0.0804386  │
# │ 4   │ 0.426647  │ 0.0     │ 0.0744653  │
# │ 5   │ 0.16622   │ 0.0     │ 0.0        │
# │ 6   │ 1.67671   │ 1.41625 │ 0.886852   │
# │ 7   │ -0.257034 │ 0.0     │ -0.0847907 │
# │ 8   │ 0.502633  │ 0.0     │ 0.01757    │
# │ 9   │ 1.80147   │ 1.58198 │ 0.986828   │
# │ 10  │ 1.96243   │ 1.56686 │ 0.910082   │
# IHT false positives = 0
# IHT false negatives = 6
# LASSO false positives = 95
# LASSO false positives = 1
#
# current run = 18
# compare_model = 10×3 DataFrame
# │ Row │ true_β    │ IHT_β    │ lasso_β   │
# │     │ Float64   │ Float64  │ Float64   │
# ├─────┼───────────┼──────────┼───────────┤
# │ 1   │ 0.197683  │ 0.0      │ 0.0590009 │
# │ 2   │ -2.12723  │ -1.96951 │ -1.3984   │
# │ 3   │ -1.17618  │ -0.99949 │ -0.598604 │
# │ 4   │ 0.474057  │ 0.469324 │ 0.162076  │
# │ 5   │ 0.186395  │ 0.0      │ 0.0       │
# │ 6   │ 0.248025  │ 0.0      │ 0.0741417 │
# │ 7   │ 0.317626  │ 0.0      │ 0.0       │
# │ 8   │ -0.229409 │ 0.0      │ 0.0       │
# │ 9   │ -0.598456 │ 0.0      │ -0.10311  │
# │ 10  │ 0.0072679 │ 0.0      │ 0.0       │
# IHT false positives = 0
# IHT false negatives = 7
# LASSO false positives = 19
# LASSO false positives = 4
#
# current run = 19
# compare_model = 10×3 DataFrame
# │ Row │ true_β    │ IHT_β     │ lasso_β     │
# │     │ Float64   │ Float64   │ Float64     │
# ├─────┼───────────┼───────────┼─────────────┤
# │ 1   │ -0.321629 │ 0.0       │ -0.00235147 │
# │ 2   │ 1.67575   │ 2.21197   │ 0.264841    │
# │ 3   │ -1.76754  │ -1.87857  │ -1.19128    │
# │ 4   │ 0.465558  │ 0.709591  │ 0.176496    │
# │ 5   │ 0.311168  │ 0.0       │ 0.00858334  │
# │ 6   │ -0.23416  │ 0.0       │ 0.0         │
# │ 7   │ -0.019976 │ 0.0       │ 0.0         │
# │ 8   │ -0.809264 │ -0.663949 │ -0.360866   │
# │ 9   │ 0.221879  │ 0.0       │ 0.0         │
# │ 10  │ 0.0212675 │ 0.0       │ 0.0         │
# IHT false positives = 0
# IHT false negatives = 6
# LASSO false positives = 27
# LASSO false positives = 4
#
# current run = 20
# compare_model = 10×3 DataFrame
# │ Row │ true_β    │ IHT_β     │ lasso_β    │
# │     │ Float64   │ Float64   │ Float64    │
# ├─────┼───────────┼───────────┼────────────┤
# │ 1   │ 1.06327   │ 1.03558   │ 0.642909   │
# │ 2   │ -2.38301  │ -2.30537  │ -1.57279   │
# │ 3   │ 0.861439  │ 0.874814  │ 0.469945   │
# │ 4   │ -2.0459   │ -1.84974  │ -1.11955   │
# │ 5   │ 0.580892  │ 0.0       │ 0.259451   │
# │ 6   │ -1.09249  │ -1.01352  │ -0.603975  │
# │ 7   │ -1.65197  │ -1.47098  │ -0.881523  │
# │ 8   │ 0.958041  │ 0.978523  │ 0.560272   │
# │ 9   │ -0.541055 │ -0.590765 │ -0.251405  │
# │ 10  │ -0.300238 │ 0.0       │ -0.0706012 │
# IHT false positives = 0
# IHT false negatives = 2
# LASSO false positives = 220
# LASSO false positives = 0
#
# current run = 21
# compare_model = 10×3 DataFrame
# │ Row │ true_β    │ IHT_β     │ lasso_β   │
# │     │ Float64   │ Float64   │ Float64   │
# ├─────┼───────────┼───────────┼───────────┤
# │ 1   │ 1.18868   │ 1.13514   │ 0.586755  │
# │ 2   │ 0.48417   │ 0.461069  │ 0.131404  │
# │ 3   │ -1.807    │ -1.6857   │ -1.00618  │
# │ 4   │ 0.458255  │ 0.541073  │ 0.145927  │
# │ 5   │ -0.472271 │ -0.636635 │ -0.277064 │
# │ 6   │ 0.0919479 │ 0.0       │ 0.0       │
# │ 7   │ 1.44877   │ 1.35213   │ 0.757049  │
# │ 8   │ 1.0393    │ 0.880162  │ 0.397432  │
# │ 9   │ 0.527234  │ 0.523026  │ 0.182419  │
# │ 10  │ -0.187198 │ 0.0       │ 0.0       │
# IHT false positives = 0
# IHT false negatives = 2
# LASSO false positives = 37
# LASSO false positives = 2
#
# current run = 22
# Did not converge!!!!! The run time for IHT was 15.205319881439209 seconds and model size was7
# compare_model = 10×3 DataFrame
# │ Row │ true_β      │ IHT_β     │ lasso_β     │
# │     │ Float64     │ Float64   │ Float64     │
# ├─────┼─────────────┼───────────┼─────────────┤
# │ 1   │ -0.121228   │ 0.0       │ -0.00338189 │
# │ 2   │ 1.62025     │ 1.61304   │ 0.896622    │
# │ 3   │ -0.275292   │ -0.450365 │ -0.16006    │
# │ 4   │ -0.927595   │ -1.34034  │ -0.294046   │
# │ 5   │ -2.24533    │ -2.22515  │ -1.26174    │
# │ 6   │ -1.11235    │ -1.13686  │ -0.721756   │
# │ 7   │ 1.35144     │ 1.22054   │ 0.746576    │
# │ 8   │ -0.00374991 │ 0.0       │ 0.0         │
# │ 9   │ 1.3027      │ 1.20333   │ 0.754905    │
# │ 10  │ 0.0782733   │ 0.0       │ 0.0         │
# IHT false positives = 0
# IHT false negatives = 3
# LASSO false positives = 229
# LASSO false positives = 2
#
# current run = 23
# compare_model = 10×3 DataFrame
# │ Row │ true_β    │ IHT_β     │ lasso_β   │
# │     │ Float64   │ Float64   │ Float64   │
# ├─────┼───────────┼───────────┼───────────┤
# │ 1   │ 0.830835  │ 1.05843   │ 0.547604  │
# │ 2   │ -0.486412 │ -0.589012 │ -0.224149 │
# │ 3   │ 1.16033   │ 1.3231    │ 0.719644  │
# │ 4   │ -0.5822   │ -0.641712 │ -0.246477 │
# │ 5   │ 1.58548   │ 1.7191    │ 1.04796   │
# │ 6   │ -0.329297 │ 0.0       │ 0.0       │
# │ 7   │ 1.17781   │ 1.15965   │ 0.605632  │
# │ 8   │ 0.746877  │ 0.94313   │ 0.422188  │
# │ 9   │ -0.920548 │ -0.971507 │ -0.391876 │
# │ 10  │ -1.06971  │ -1.12141  │ -0.569085 │
# IHT false positives = 0
# IHT false negatives = 1
# LASSO false positives = 162
# LASSO false positives = 1
#
# current run = 24
# compare_model = 10×3 DataFrame
# │ Row │ true_β      │ IHT_β     │ lasso_β   │
# │     │ Float64     │ Float64   │ Float64   │
# ├─────┼─────────────┼───────────┼───────────┤
# │ 1   │ 0.644465    │ 0.513681  │ 0.212462  │
# │ 2   │ -0.499617   │ 0.0       │ -0.114636 │
# │ 3   │ -0.00401379 │ 0.0       │ 0.0       │
# │ 4   │ 0.168815    │ 0.0       │ 0.0       │
# │ 5   │ -1.25875    │ -1.1793   │ -0.718326 │
# │ 6   │ -0.626624   │ -0.562159 │ -0.259659 │
# │ 7   │ -0.0715476  │ 0.0       │ 0.0       │
# │ 8   │ 0.928845    │ 0.915136  │ 0.547847  │
# │ 9   │ -0.0567743  │ 0.0       │ 0.0       │
# │ 10  │ 0.967651    │ 0.974327  │ 0.560864  │
# IHT false positives = 0
# IHT false negatives = 5
# LASSO false positives = 45
# LASSO false positives = 4
#
# current run = 25
# compare_model = 10×3 DataFrame
# │ Row │ true_β    │ IHT_β     │ lasso_β    │
# │     │ Float64   │ Float64   │ Float64    │
# ├─────┼───────────┼───────────┼────────────┤
# │ 1   │ 0.748585  │ 0.668751  │ 0.343105   │
# │ 2   │ -2.38649  │ -2.21442  │ -1.65219   │
# │ 3   │ 0.267114  │ 0.0       │ 0.200769   │
# │ 4   │ 0.260112  │ 0.0       │ 0.0        │
# │ 5   │ -0.611901 │ -0.670711 │ -0.371704  │
# │ 6   │ 0.174811  │ 0.0       │ 0.0        │
# │ 7   │ -0.11666  │ 0.0       │ -0.0199607 │
# │ 8   │ -1.52254  │ -1.50888  │ -1.04233   │
# │ 9   │ 0.449192  │ 0.0       │ 0.163091   │
# │ 10  │ 0.0559064 │ 0.0       │ 0.0        │
# IHT false positives = 0
# IHT false negatives = 6
# LASSO false positives = 84
# LASSO false positives = 3
#
# current run = 26
# compare_model = 10×3 DataFrame
# │ Row │ true_β    │ IHT_β    │ lasso_β    │
# │     │ Float64   │ Float64  │ Float64    │
# ├─────┼───────────┼──────────┼────────────┤
# │ 1   │ 1.41583   │ 1.45352  │ 0.852084   │
# │ 2   │ -0.260895 │ 0.0      │ 0.0        │
# │ 3   │ -0.166977 │ 0.0      │ 0.0        │
# │ 4   │ -1.26476  │ -1.39206 │ -0.765992  │
# │ 5   │ 0.291436  │ 0.0      │ 0.0551057  │
# │ 6   │ -0.371521 │ 0.0      │ -0.0123402 │
# │ 7   │ 0.558468  │ 0.744272 │ 0.348689   │
# │ 8   │ 1.51326   │ 1.41957  │ 0.829876   │
# │ 9   │ 0.0775582 │ 0.0      │ 0.0        │
# │ 10  │ 1.14017   │ 0.978192 │ 0.468013   │
# IHT false positives = 0
# IHT false negatives = 5
# LASSO false positives = 36
# LASSO false positives = 3
#
# current run = 27
# compare_model = 10×3 DataFrame
# │ Row │ true_β    │ IHT_β     │ lasso_β   │
# │     │ Float64   │ Float64   │ Float64   │
# ├─────┼───────────┼───────────┼───────────┤
# │ 1   │ 0.132771  │ 0.0       │ 0.0       │
# │ 2   │ -0.145071 │ 0.0       │ -0.035843 │
# │ 3   │ -0.781848 │ -0.751744 │ -0.377707 │
# │ 4   │ 0.946355  │ 0.733114  │ 0.391082  │
# │ 5   │ 0.022901  │ 0.0       │ 0.0       │
# │ 6   │ -0.977321 │ -0.965955 │ -0.557043 │
# │ 7   │ 0.269074  │ 0.0       │ 0.0659629 │
# │ 8   │ 2.37936   │ 1.92746   │ 0.476209  │
# │ 9   │ -0.376621 │ -0.410534 │ -0.139282 │
# │ 10  │ 0.525521  │ 0.469372  │ 0.189788  │
# IHT false positives = 0
# IHT false negatives = 4
# LASSO false positives = 42
# LASSO false positives = 2
#
# current run = 28
# compare_model = 10×3 DataFrame
# │ Row │ true_β    │ IHT_β     │ lasso_β   │
# │     │ Float64   │ Float64   │ Float64   │
# ├─────┼───────────┼───────────┼───────────┤
# │ 1   │ -1.66714  │ -1.49436  │ -0.884565 │
# │ 2   │ 0.296512  │ 0.456008  │ 0.124308  │
# │ 3   │ -1.0199   │ -0.989578 │ -0.52275  │
# │ 4   │ 1.81054   │ 1.64266   │ 0.954625  │
# │ 5   │ -0.666186 │ -0.59868  │ -0.255529 │
# │ 6   │ 0.134437  │ 0.0       │ 0.0       │
# │ 7   │ -1.90361  │ -1.75     │ -1.07661  │
# │ 8   │ 0.22463   │ 0.0       │ 0.0       │
# │ 9   │ 0.550686  │ 0.0       │ 0.0372984 │
# │ 10  │ 0.506344  │ 0.0       │ 0.0738144 │
# IHT false positives = 0
# IHT false negatives = 4
# LASSO false positives = 78
# LASSO false positives = 2
#
# current run = 29
# compare_model = 10×3 DataFrame
# │ Row │ true_β     │ IHT_β     │ lasso_β   │
# │     │ Float64    │ Float64   │ Float64   │
# ├─────┼────────────┼───────────┼───────────┤
# │ 1   │ -1.66094   │ -1.65998  │ -0.728504 │
# │ 2   │ -0.0960436 │ 0.0       │ 0.0       │
# │ 3   │ -0.922529  │ -0.967508 │ -0.366092 │
# │ 4   │ -0.670602  │ -0.630305 │ -0.184413 │
# │ 5   │ -0.938701  │ -0.793243 │ -0.298894 │
# │ 6   │ 1.35941    │ 1.27559   │ 0.593115  │
# │ 7   │ 0.375191   │ 0.0       │ 0.0281645 │
# │ 8   │ 1.48513    │ 1.51799   │ 0.706399  │
# │ 9   │ 2.37889    │ 2.51222   │ 1.25408   │
# │ 10  │ 0.18817    │ 0.0       │ 0.0       │
# IHT false positives = 1
# IHT false negatives = 3
# LASSO false positives = 32
# LASSO false positives = 2
#
# current run = 30
# compare_model = 10×3 DataFrame
# │ Row │ true_β     │ IHT_β     │ lasso_β   │
# │     │ Float64    │ Float64   │ Float64   │
# ├─────┼────────────┼───────────┼───────────┤
# │ 1   │ 0.439631   │ 0.0       │ 0.123584  │
# │ 2   │ -1.20632   │ -1.06632  │ -0.668993 │
# │ 3   │ 0.0834879  │ 0.0       │ 0.0       │
# │ 4   │ 0.623301   │ 0.674219  │ 0.339506  │
# │ 5   │ -0.0840575 │ 0.0       │ 0.0       │
# │ 6   │ 1.8951     │ 1.80641   │ 1.32304   │
# │ 7   │ 0.149619   │ 0.0       │ 0.0       │
# │ 8   │ -0.0695977 │ 0.0       │ 0.0       │
# │ 9   │ -0.858231  │ -0.776711 │ -0.476136 │
# │ 10  │ -1.09822   │ -1.16876  │ -0.75903  │
# IHT false positives = 0
# IHT false negatives = 5
# LASSO false positives = 179
# LASSO false positives = 4
#
# current run = 31
# compare_model = 10×3 DataFrame
# │ Row │ true_β    │ IHT_β     │ lasso_β    │
# │     │ Float64   │ Float64   │ Float64    │
# ├─────┼───────────┼───────────┼────────────┤
# │ 1   │ -0.366982 │ 0.0       │ -0.101361  │
# │ 2   │ 1.02388   │ 0.938806  │ 0.477519   │
# │ 3   │ -1.28667  │ -1.31076  │ -0.723605  │
# │ 4   │ 0.362194  │ 0.0       │ 0.148165   │
# │ 5   │ -0.456316 │ 0.0       │ -0.0709866 │
# │ 6   │ 0.79798   │ 0.743403  │ 0.319359   │
# │ 7   │ -2.09573  │ -1.89313  │ -1.13905   │
# │ 8   │ -0.643185 │ -0.703082 │ -0.279516  │
# │ 9   │ -1.59822  │ -1.61039  │ -0.826635  │
# │ 10  │ 2.26642   │ 2.10118   │ 1.14711    │
# IHT false positives = 0
# IHT false negatives = 3
# LASSO false positives = 153
# LASSO false positives = 0
#
# current run = 32
# compare_model = 10×3 DataFrame
# │ Row │ true_β    │ IHT_β     │ lasso_β   │
# │     │ Float64   │ Float64   │ Float64   │
# ├─────┼───────────┼───────────┼───────────┤
# │ 1   │ -0.10447  │ 0.0       │ 0.0       │
# │ 2   │ 0.338831  │ 0.0       │ 0.101015  │
# │ 3   │ 0.203211  │ 0.0       │ 0.0       │
# │ 4   │ 1.04781   │ 0.919534  │ 0.485126  │
# │ 5   │ -0.917413 │ -0.857049 │ -0.426579 │
# │ 6   │ 1.2311    │ 1.13768   │ 0.605182  │
# │ 7   │ -1.95343  │ -1.70063  │ -1.05521  │
# │ 8   │ 0.854767  │ 0.897419  │ 0.425745  │
# │ 9   │ -0.755296 │ -0.817605 │ -0.390602 │
# │ 10  │ -0.427844 │ 0.0       │ -0.129748 │
# IHT false positives = 0
# IHT false negatives = 4
# LASSO false positives = 79
# LASSO false positives = 2
#
# current run = 33
# compare_model = 10×3 DataFrame
# │ Row │ true_β    │ IHT_β     │ lasso_β   │
# │     │ Float64   │ Float64   │ Float64   │
# ├─────┼───────────┼───────────┼───────────┤
# │ 1   │ -1.64548  │ -1.46102  │ -0.760786 │
# │ 2   │ 0.305992  │ 0.0       │ 0.0630218 │
# │ 3   │ 0.073027  │ 0.0       │ 0.0       │
# │ 4   │ 0.679443  │ 0.0       │ 0.109302  │
# │ 5   │ -0.602695 │ -0.606158 │ -0.217778 │
# │ 6   │ 0.201448  │ 0.0       │ 0.0       │
# │ 7   │ 1.36393   │ 1.27029   │ 0.698502  │
# │ 8   │ -1.5615   │ -1.51714  │ -0.844926 │
# │ 9   │ -0.252786 │ 0.0       │ 0.0       │
# │ 10  │ -1.65758  │ -1.5829   │ -0.870561 │
# IHT false positives = 0
# IHT false negatives = 5
# LASSO false positives = 41
# LASSO false positives = 3
#
# current run = 34
# compare_model = 10×3 DataFrame
# │ Row │ true_β    │ IHT_β     │ lasso_β   │
# │     │ Float64   │ Float64   │ Float64   │
# ├─────┼───────────┼───────────┼───────────┤
# │ 1   │ -0.968028 │ -0.792748 │ -0.307333 │
# │ 2   │ -0.058406 │ 0.0       │ 0.0       │
# │ 3   │ 1.40221   │ 1.13496   │ 0.54624   │
# │ 4   │ -1.52833  │ -1.33373  │ -0.721807 │
# │ 5   │ -0.604144 │ -0.706167 │ -0.315548 │
# │ 6   │ 1.12868   │ 1.07636   │ 0.501336  │
# │ 7   │ 2.06721   │ 1.93623   │ 1.09734   │
# │ 8   │ 0.0412734 │ 0.0       │ 0.0       │
# │ 9   │ 1.29079   │ 1.18999   │ 0.60284   │
# │ 10  │ 0.494771  │ 0.0       │ 0.112277  │
# IHT false positives = 0
# IHT false negatives = 3
# LASSO false positives = 65
# LASSO false positives = 2
#
# current run = 35
# compare_model = 10×3 DataFrame
# │ Row │ true_β    │ IHT_β    │ lasso_β   │
# │     │ Float64   │ Float64  │ Float64   │
# ├─────┼───────────┼──────────┼───────────┤
# │ 1   │ -0.903326 │ -0.79898 │ -0.378137 │
# │ 2   │ -1.62702  │ -1.51996 │ -0.892301 │
# │ 3   │ -0.209187 │ 0.0      │ -0.121238 │
# │ 4   │ 0.487385  │ 0.0      │ 0.149662  │
# │ 5   │ -1.50515  │ -1.48034 │ -0.834287 │
# │ 6   │ 1.48023   │ 1.41344  │ 0.814746  │
# │ 7   │ 0.891984  │ 0.929306 │ 0.462898  │
# │ 8   │ -1.65691  │ -1.67397 │ -0.602024 │
# │ 9   │ 0.956169  │ 1.08193  │ 0.477415  │
# │ 10  │ 0.707741  │ 0.0      │ 0.0873698 │
# IHT false positives = 0
# IHT false negatives = 3
# LASSO false positives = 126
# LASSO false positives = 0
#
# current run = 36
# compare_model = 10×3 DataFrame
# │ Row │ true_β    │ IHT_β     │ lasso_β    │
# │     │ Float64   │ Float64   │ Float64    │
# ├─────┼───────────┼───────────┼────────────┤
# │ 1   │ 0.331783  │ 0.0       │ 0.0722384  │
# │ 2   │ -1.30822  │ -1.16377  │ -0.70237   │
# │ 3   │ -0.651033 │ -0.537626 │ -0.260054  │
# │ 4   │ 0.261437  │ 0.0       │ 0.0928736  │
# │ 5   │ -0.412683 │ 0.0       │ -0.102691  │
# │ 6   │ -0.318389 │ 0.0       │ -0.0476904 │
# │ 7   │ -0.52751  │ -0.458798 │ -0.219776  │
# │ 8   │ 1.37783   │ 1.29225   │ 0.776345   │
# │ 9   │ -2.19743  │ -1.99927  │ -1.34208   │
# │ 10  │ -0.694061 │ -0.663709 │ -0.346245  │
# IHT false positives = 0
# IHT false negatives = 4
# LASSO false positives = 113
# LASSO false positives = 0
#
# current run = 37
# compare_model = 10×3 DataFrame
# │ Row │ true_β    │ IHT_β     │ lasso_β    │
# │     │ Float64   │ Float64   │ Float64    │
# ├─────┼───────────┼───────────┼────────────┤
# │ 1   │ 0.264718  │ 0.0       │ 0.0        │
# │ 2   │ -0.190443 │ 0.0       │ -0.0995492 │
# │ 3   │ 1.64348   │ 1.76462   │ 1.06155    │
# │ 4   │ -0.994088 │ -1.1501   │ -0.642696  │
# │ 5   │ 0.173064  │ 0.0       │ 0.0        │
# │ 6   │ -0.145006 │ 0.0       │ 0.0        │
# │ 7   │ -0.939043 │ -0.921028 │ -0.454661  │
# │ 8   │ -1.22621  │ -1.31269  │ -0.749299  │
# │ 9   │ -0.153334 │ 0.0       │ 0.0        │
# │ 10  │ 0.522483  │ 0.577187  │ 0.209582   │
# IHT false positives = 0
# IHT false negatives = 5
# LASSO false positives = 24
# LASSO false positives = 4
#
# current run = 38
# compare_model = 10×3 DataFrame
# │ Row │ true_β    │ IHT_β     │ lasso_β     │
# │     │ Float64   │ Float64   │ Float64     │
# ├─────┼───────────┼───────────┼─────────────┤
# │ 1   │ 0.103811  │ 0.0       │ 0.0         │
# │ 2   │ 0.212237  │ 0.0       │ 0.000901262 │
# │ 3   │ -1.15016  │ -1.10065  │ -0.638535   │
# │ 4   │ -0.634812 │ 0.0       │ -0.151274   │
# │ 5   │ 0.751658  │ 0.624964  │ 0.279414    │
# │ 6   │ -0.874038 │ -0.773407 │ -0.337493   │
# │ 7   │ 1.31668   │ 1.16575   │ 0.661663    │
# │ 8   │ 1.1581    │ 1.04531   │ 0.572656    │
# │ 9   │ -0.415636 │ 0.0       │ -0.110173   │
# │ 10  │ -0.784319 │ -0.662631 │ -0.187282   │
# IHT false positives = 0
# IHT false negatives = 4
# LASSO false positives = 41
# LASSO false positives = 1
#
# current run = 39
# compare_model = 10×3 DataFrame
# │ Row │ true_β    │ IHT_β     │ lasso_β    │
# │     │ Float64   │ Float64   │ Float64    │
# ├─────┼───────────┼───────────┼────────────┤
# │ 1   │ -0.944508 │ -1.01982  │ -0.517596  │
# │ 2   │ -1.36122  │ -1.40094  │ -0.779636  │
# │ 3   │ 0.432275  │ 0.568651  │ 0.194615   │
# │ 4   │ 0.034109  │ 0.0       │ 0.0        │
# │ 5   │ 0.491255  │ 0.544237  │ 0.185111   │
# │ 6   │ 1.17636   │ 1.30816   │ 0.690011   │
# │ 7   │ -0.410249 │ 0.0       │ -0.0488515 │
# │ 8   │ -0.478234 │ -0.513675 │ -0.138791  │
# │ 9   │ 1.81764   │ 1.58755   │ 0.882752   │
# │ 10  │ 0.60502   │ 0.714011  │ 0.286837   │
# IHT false positives = 1
# IHT false negatives = 2
# LASSO false positives = 66
# LASSO false positives = 1
#
# current run = 40
# compare_model = 10×3 DataFrame
# │ Row │ true_β    │ IHT_β     │ lasso_β    │
# │     │ Float64   │ Float64   │ Float64    │
# ├─────┼───────────┼───────────┼────────────┤
# │ 1   │ 0.935235  │ 0.87397   │ 0.387879   │
# │ 2   │ 0.875307  │ 0.804363  │ 0.419504   │
# │ 3   │ -1.31382  │ -0.776122 │ -0.204159  │
# │ 4   │ 0.515587  │ 0.579493  │ 0.2237     │
# │ 5   │ -1.82621  │ -1.72029  │ -0.955565  │
# │ 6   │ 0.949667  │ 0.88698   │ 0.460394   │
# │ 7   │ -0.655149 │ -0.630173 │ -0.30534   │
# │ 8   │ 1.93347   │ 1.98125   │ 1.0006     │
# │ 9   │ -0.328186 │ 0.0       │ -0.0378774 │
# │ 10  │ -0.206838 │ 0.0       │ 0.0        │
# IHT false positives = 0
# IHT false negatives = 2
# LASSO false positives = 150
# LASSO false positives = 1
#
# current run = 41
# compare_model = 10×3 DataFrame
# │ Row │ true_β    │ IHT_β     │ lasso_β   │
# │     │ Float64   │ Float64   │ Float64   │
# ├─────┼───────────┼───────────┼───────────┤
# │ 1   │ -0.452691 │ -0.487356 │ -0.227631 │
# │ 2   │ 0.356726  │ 0.0       │ 0.11666   │
# │ 3   │ 0.845248  │ 0.910127  │ 0.623674  │
# │ 4   │ 0.194707  │ 0.0       │ 0.0970107 │
# │ 5   │ 0.31124   │ 0.0       │ 0.0978602 │
# │ 6   │ 1.79477   │ 1.84542   │ 1.38347   │
# │ 7   │ 0.294013  │ 0.0       │ 0.0       │
# │ 8   │ -0.332875 │ 0.0       │ -0.129305 │
# │ 9   │ -0.66431  │ -0.72118  │ -0.391289 │
# │ 10  │ -0.564411 │ 0.0       │ -0.21376  │
# IHT false positives = 0
# IHT false negatives = 6
# LASSO false positives = 147
# LASSO false positives = 1
#
# current run = 42
# compare_model = 10×3 DataFrame
# │ Row │ true_β    │ IHT_β     │ lasso_β   │
# │     │ Float64   │ Float64   │ Float64   │
# ├─────┼───────────┼───────────┼───────────┤
# │ 1   │ -0.792254 │ -0.735874 │ -0.354188 │
# │ 2   │ 0.243656  │ 0.0       │ 0.0       │
# │ 3   │ 0.134008  │ 0.0       │ 0.0       │
# │ 4   │ -2.0823   │ -1.81401  │ -1.21105  │
# │ 5   │ -1.0111   │ -0.994746 │ -0.476462 │
# │ 6   │ -0.190096 │ 0.0       │ 0.0       │
# │ 7   │ 0.853722  │ 0.804331  │ 0.377998  │
# │ 8   │ 0.238424  │ 0.0       │ 0.03698   │
# │ 9   │ -0.743257 │ -0.699941 │ -0.335821 │
# │ 10  │ -1.52847  │ -1.48852  │ -0.959844 │
# IHT false positives = 0
# IHT false negatives = 4
# LASSO false positives = 131
# LASSO false positives = 3
#
# current run = 43
# compare_model = 10×3 DataFrame
# │ Row │ true_β    │ IHT_β     │ lasso_β    │
# │     │ Float64   │ Float64   │ Float64    │
# ├─────┼───────────┼───────────┼────────────┤
# │ 1   │ 0.0818385 │ 0.0       │ 0.0        │
# │ 2   │ 0.0142046 │ 0.0       │ 0.0        │
# │ 3   │ -0.420465 │ 0.0       │ -0.0421841 │
# │ 4   │ -0.671813 │ -0.56038  │ -0.219117  │
# │ 5   │ -2.01088  │ -2.00413  │ -1.30727   │
# │ 6   │ 1.21255   │ 1.31614   │ 0.778112   │
# │ 7   │ -0.684723 │ -0.694171 │ -0.311955  │
# │ 8   │ 0.398345  │ 0.0       │ 0.107577   │
# │ 9   │ 0.695893  │ 0.579787  │ 0.244876   │
# │ 10  │ -0.852096 │ -0.823891 │ -0.419449  │
# IHT false positives = 0
# IHT false negatives = 4
# LASSO false positives = 93
# LASSO false positives = 2
#
# current run = 44
# compare_model = 10×3 DataFrame
# │ Row │ true_β    │ IHT_β    │ lasso_β    │
# │     │ Float64   │ Float64  │ Float64    │
# ├─────┼───────────┼──────────┼────────────┤
# │ 1   │ 1.2057    │ 1.18466  │ 0.660184   │
# │ 2   │ 0.221834  │ 0.0      │ 0.0        │
# │ 3   │ -1.46666  │ -1.29997 │ -0.742823  │
# │ 4   │ -0.621031 │ -0.61786 │ -0.22279   │
# │ 5   │ -1.68527  │ -1.78153 │ -1.09398   │
# │ 6   │ -1.26995  │ -1.41377 │ -0.838877  │
# │ 7   │ -0.359156 │ 0.0      │ -0.0534202 │
# │ 8   │ 0.758991  │ 0.718353 │ 0.3296     │
# │ 9   │ 0.237315  │ 0.0      │ 0.0        │
# │ 10  │ 0.0830602 │ 0.0      │ 0.0        │
# IHT false positives = 0
# IHT false negatives = 4
# LASSO false positives = 75
# LASSO false positives = 3
#
# current run = 45
# compare_model = 10×3 DataFrame
# │ Row │ true_β     │ IHT_β     │ lasso_β    │
# │     │ Float64    │ Float64   │ Float64    │
# ├─────┼────────────┼───────────┼────────────┤
# │ 1   │ -0.523045  │ -0.380812 │ -0.0863474 │
# │ 2   │ 1.43982    │ 1.37717   │ 0.683267   │
# │ 3   │ -1.31612   │ -1.36203  │ -0.733007  │
# │ 4   │ 0.00772404 │ 0.0       │ 0.0        │
# │ 5   │ 1.12101    │ 1.20461   │ 0.55053    │
# │ 6   │ 0.584017   │ 0.496039  │ 0.144773   │
# │ 7   │ -1.30509   │ -1.27912  │ -0.654942  │
# │ 8   │ 0.0656554  │ 0.0       │ 0.0        │
# │ 9   │ 0.538553   │ 0.452358  │ 0.0833936  │
# │ 10  │ 1.00593    │ 1.02898   │ 0.493794   │
# IHT false positives = 0
# IHT false negatives = 2
# LASSO false positives = 49
# LASSO false positives = 2
#
# current run = 46
# compare_model = 10×3 DataFrame
# │ Row │ true_β    │ IHT_β    │ lasso_β    │
# │     │ Float64   │ Float64  │ Float64    │
# ├─────┼───────────┼──────────┼────────────┤
# │ 1   │ -1.22853  │ -1.14277 │ -0.679548  │
# │ 2   │ -0.345903 │ 0.0      │ -0.180345  │
# │ 3   │ 0.463433  │ 0.0      │ 0.141089   │
# │ 4   │ 0.795184  │ 0.538231 │ 0.2584     │
# │ 5   │ 1.43185   │ 1.39108  │ 0.877029   │
# │ 6   │ 0.823073  │ 0.837806 │ 0.404887   │
# │ 7   │ -0.152198 │ 0.0      │ -0.0361069 │
# │ 8   │ -1.49302  │ -1.57308 │ -1.04311   │
# │ 9   │ 1.0999    │ 1.09941  │ 0.635577   │
# │ 10  │ 0.253466  │ 0.0      │ 0.0        │
# IHT false positives = 0
# IHT false negatives = 4
# LASSO false positives = 132
# LASSO false positives = 1
#
# current run = 47
# compare_model = 10×3 DataFrame
# │ Row │ true_β    │ IHT_β     │ lasso_β   │
# │     │ Float64   │ Float64   │ Float64   │
# ├─────┼───────────┼───────────┼───────────┤
# │ 1   │ 0.159145  │ 0.0       │ 0.0       │
# │ 2   │ 0.521217  │ 0.0       │ 0.107944  │
# │ 3   │ 0.694336  │ 0.696965  │ 0.379439  │
# │ 4   │ 1.37779   │ 1.18417   │ 0.679136  │
# │ 5   │ -0.580732 │ -0.675942 │ -0.344943 │
# │ 6   │ 0.540998  │ 0.555727  │ 0.245337  │
# │ 7   │ 0.141576  │ 0.0       │ 0.0       │
# │ 8   │ 0.658366  │ 0.569694  │ 0.269691  │
# │ 9   │ -1.49048  │ -1.30089  │ -0.724554 │
# │ 10  │ -0.458753 │ -0.473481 │ -0.178114 │
# IHT false positives = 0
# IHT false negatives = 3
# LASSO false positives = 79
# LASSO false positives = 2
#
# current run = 48
# compare_model = 10×3 DataFrame
# │ Row │ true_β      │ IHT_β     │ lasso_β   │
# │     │ Float64     │ Float64   │ Float64   │
# ├─────┼─────────────┼───────────┼───────────┤
# │ 1   │ -0.00696938 │ 0.0       │ 0.0       │
# │ 2   │ -1.17547    │ -1.42073  │ -0.827664 │
# │ 3   │ -0.759381   │ -0.795777 │ -0.372596 │
# │ 4   │ -1.20903    │ -1.35746  │ -0.750989 │
# │ 5   │ -1.53337    │ -1.67393  │ -0.983005 │
# │ 6   │ 0.560507    │ 0.681583  │ 0.242321  │
# │ 7   │ 0.0767795   │ 0.0       │ 0.0       │
# │ 8   │ -0.0798947  │ 0.0       │ 0.0       │
# │ 9   │ 0.864681    │ 0.977054  │ 0.521574  │
# │ 10  │ -1.6341     │ -1.90639  │ -0.401196 │
# IHT false positives = 0
# IHT false negatives = 3
# LASSO false positives = 88
# LASSO false positives = 3
#
# current run = 49
# compare_model = 10×3 DataFrame
# │ Row │ true_β    │ IHT_β     │ lasso_β   │
# │     │ Float64   │ Float64   │ Float64   │
# ├─────┼───────────┼───────────┼───────────┤
# │ 1   │ -0.81133  │ -0.846124 │ -0.379314 │
# │ 2   │ 0.0794845 │ 0.0       │ 0.0       │
# │ 3   │ 2.53752   │ 2.39841   │ 1.33563   │
# │ 4   │ 0.762648  │ 0.766329  │ 0.341182  │
# │ 5   │ -0.167256 │ 0.0       │ 0.0       │
# │ 6   │ 0.0375286 │ 0.0       │ 0.0       │
# │ 7   │ -1.97567  │ -1.93162  │ -1.13174  │
# │ 8   │ -1.18638  │ -1.18205  │ -0.545816 │
# │ 9   │ -0.180231 │ 0.0       │ 0.0       │
# │ 10  │ -0.994936 │ -1.02784  │ -0.481252 │
# IHT false positives = 0
# IHT false negatives = 4
# LASSO false positives = 81
# LASSO false positives = 4
#
# current run = 50
# compare_model = 10×3 DataFrame
# │ Row │ true_β    │ IHT_β     │ lasso_β  │
# │     │ Float64   │ Float64   │ Float64  │
# ├─────┼───────────┼───────────┼──────────┤
# │ 1   │ 1.63231   │ 1.59635   │ 0.832932 │
# │ 2   │ 0.275971  │ 0.0       │ 0.0      │
# │ 3   │ -0.748727 │ -0.665605 │ -0.25523 │
# │ 4   │ 1.4197    │ 1.55959   │ 0.813688 │
# │ 5   │ 1.48411   │ 1.56594   │ 0.759243 │
# │ 6   │ 2.1012    │ 2.16976   │ 1.22119  │
# │ 7   │ 0.42606   │ 0.551435  │ 0.193855 │
# │ 8   │ 0.873189  │ 1.0565    │ 0.454859 │
# │ 9   │ 0.564919  │ 0.59901   │ 0.210592 │
# │ 10  │ 0.522636  │ 0.0       │ 0.112794 │
# IHT false positives = 0
# IHT false negatives = 2
# LASSO false positives = 119
# LASSO false positives = 1

# %%
bernoulli_iht_false_positives = sum(iht_false_positives) / 50
bernoulli_iht_false_negatives = sum(iht_false_negatives) / 50
bernoulli_lasso_false_positives = sum(lasso_false_positives) / 50
bernoulli_lasso_false_negatives = sum(lasso_false_negatives) / 50
result = [bernoulli_iht_false_positives; bernoulli_iht_false_negatives; 
         bernoulli_lasso_false_positives; bernoulli_lasso_false_negatives]
# Out:
# 4-element Array{Float64,1}:
#   0.06
#   3.68
#  93.66
#   2.0

# %%
IHT_did_not_converge = 1
LASSO_did_not_converge = 0
# Out:
# 0
