# %% [markdown]
# # Doubly sparse projection on simulated data
#
# Data simulated here have strong within-group correlation but 0 between-group correlation. We simulate $p = 10000$ SNPs all divided into groups of length 20. For how simulation was carried out, see our [paper](https://www.biorxiv.org/content/10.1101/697755v1.article-metrics).

# %%
using MendelIHT
using SnpArrays
using DataFrames
using Distributions
using BenchmarkTools
using Random
using LinearAlgebra
using GLM
using Statistics

# %%
function compare(d, l)
    
    # define problem size
    n = 1000
    p = 10000
    block_size = 20
    num_blocks = Int(p / block_size)

    # assign group membership
    membership = collect(1:num_blocks)
    g = zeros(Int64, p + 1)
    for i in 1:length(membership)
        for j in 1:block_size
            cur_row = block_size * (i - 1) + j
            g[block_size*(i - 1) + j] = membership[i]
        end
    end
    g[end] = membership[end]
    
    #simulate correlated snparray
    x = simulate_correlated_snparray(n, p, "tmp.bed")
    z = ones(n, 1) # the intercept
    x_float = convert(Matrix{Float64}, x, model=ADDITIVE_MODEL, center=true, scale=true)
    
    #simulate true model, where 5 groups each with 1~5 snps contribute
    true_b = zeros(p)
    true_groups = randperm(num_blocks)[1:5]
    sort!(true_groups)
    within_group = [randperm(block_size)[1:1], randperm(block_size)[1:2], 
                    randperm(block_size)[1:3], randperm(block_size)[1:4], 
                    randperm(block_size)[1:5]]
    correct_position = zeros(Int64, 15)
    for i in 1:5
        cur_group = block_size * (true_groups[i] - 1)
        cur_group_snps = cur_group .+ within_group[i]
        start, last = Int(i*(i-1)/2 + 1), Int(i*(i+1)/2)
        correct_position[start:last] .= cur_group_snps
    end
    for i in 1:15
        true_b[correct_position[i]] = rand(-1:2:1) * 0.2
    end
    sort!(correct_position)
        
    # simulate phenotype
    if d == Normal || d == Bernoulli || d == Poisson
        prob = linkinv.(l, x_float * true_b)
        clamp!(prob, -20, 20)
        y = [rand(d(i)) for i in prob]
    elseif d == NegativeBinomial
        r = 10
        μ = linkinv.(l, x_float * true_b)
        clamp!(μ, -20, 20)
        prob = 1 ./ (1 .+ μ ./ r)
        y = [rand(d(r, i)) for i in prob] #number of failtures before r success occurs
    end
    y = Float64.(y)
    
    #run IHT without groups
    k = 15
    ungrouped = L0_reg(x_float, z, y, 1, k, d(), l, verbose=false)

    # constant group IHT
#     J = 5
#     k = 5
#     constant_group = L0_reg(x_float, z, y, J, k, d(), l, group=g, verbose=false)

    #variable group IHT
    J = 5
    max_group_snps = ones(Int, num_blocks)
    max_group_snps[true_groups] .= collect(1:5)
    variable_group = L0_reg(x_float, z, y, J, max_group_snps, d(), l, verbose=false, group=g)

    #check result
    correct_position = findall(!iszero, true_b)
    compare_model = DataFrame(
        position   = correct_position,
        correct    = true_b[correct_position],
        ungrouped  = ungrouped.beta[correct_position], 
#         constant_group = constant_group.beta[correct_position],
        variable_group = variable_group.beta[correct_position])
    @show compare_model
    println("\n")

    #clean up
    rm("tmp.bed", force=true)

    #compute true positives and false positives
    ungroup_tp = count(!iszero, ungrouped.beta[correct_position])
#     constant_group_tp = count(!iszero, constant_group.beta[correct_position])
    variable_group_tp = count(!iszero, variable_group.beta[correct_position])
    ungroup_fp = 15 - ungroup_tp
#     constant_group_fp = 25 - constant_group_tp
    variable_group_fp = 15 - variable_group_tp

    return ungroup_tp, ungroup_fp, variable_group_tp, variable_group_fp
end
# Out:
# compare (generic function with 1 method)

# %% [markdown]
# ## Normal

# %%
Random.seed!(2019)

d = Normal
l = canonicallink(d())

num_runs = 100
ungroup_true_positives = zeros(num_runs)
ungroup_false_positives = zeros(num_runs)
variable_true_positives = zeros(num_runs)
variable_false_positives = zeros(num_runs)

@time for i in 1:num_runs
    println("running $i th model")
    utp, ufp, vtp, vfp = compare(d, l)
    ungroup_true_positives[i] = utp
    ungroup_false_positives[i] = ufp
    variable_true_positives[i] = vtp
    variable_false_positives[i] = vfp
end
# Out:
# running 1 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 3464     │ -0.2    │ -0.154814 │ -0.143728      │
# │ 2   │ 4927     │ 0.2     │ 0.157603  │ 0.159271       │
# │ 3   │ 4938     │ -0.2    │ -0.243461 │ -0.241363      │
# │ 4   │ 5001     │ -0.2    │ -0.194176 │ -0.194224      │
# │ 5   │ 5011     │ -0.2    │ -0.196923 │ -0.196444      │
# │ 6   │ 5018     │ -0.2    │ -0.19521  │ -0.190188      │
# │ 7   │ 5084     │ -0.2    │ 0.0       │ -0.158618      │
# │ 8   │ 5090     │ 0.2     │ 0.219459  │ 0.214238       │
# │ 9   │ 5098     │ -0.2    │ -0.118704 │ -0.236296      │
# │ 10  │ 5100     │ -0.2    │ -0.22058  │ -0.197157      │
# │ 11  │ 7004     │ 0.2     │ 0.303529  │ 0.28044        │
# │ 12  │ 7011     │ 0.2     │ 0.0       │ 0.0            │
# │ 13  │ 7015     │ -0.2    │ 0.0       │ -0.102599      │
# │ 14  │ 7016     │ 0.2     │ 0.0       │ 0.0694743      │
# │ 15  │ 7020     │ 0.2     │ 0.33711   │ 0.31375        │
#
#
# running 2 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 149      │ 0.2     │ 0.210418  │ 0.207119       │
# │ 2   │ 4292     │ 0.2     │ 0.26719   │ 0.264892       │
# │ 3   │ 4293     │ -0.2    │ -0.259249 │ -0.259531      │
# │ 4   │ 4985     │ -0.2    │ -0.219115 │ 0.0            │
# │ 5   │ 4995     │ 0.2     │ 0.163971  │ 0.0            │
# │ 6   │ 4999     │ 0.2     │ 0.0       │ 0.0            │
# │ 7   │ 8462     │ 0.2     │ 0.194181  │ 0.207175       │
# │ 8   │ 8463     │ -0.2    │ -0.197359 │ -0.194048      │
# │ 9   │ 8477     │ -0.2    │ -0.217324 │ -0.221809      │
# │ 10  │ 8479     │ -0.2    │ -0.232064 │ -0.228068      │
# │ 11  │ 9448     │ -0.2    │ -0.345045 │ -0.15619       │
# │ 12  │ 9450     │ 0.2     │ 0.0       │ 0.246484       │
# │ 13  │ 9452     │ 0.2     │ 0.204963  │ 0.162294       │
# │ 14  │ 9453     │ 0.2     │ 0.0       │ 0.228754       │
# │ 15  │ 9454     │ -0.2    │ 0.0       │ -0.161229      │
#
#
# running 3 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 677      │ 0.2     │ 0.239164  │ 0.238543       │
# │ 2   │ 1265     │ 0.2     │ 0.227287  │ 0.220113       │
# │ 3   │ 1279     │ -0.2    │ -0.24254  │ -0.239089      │
# │ 4   │ 4171     │ 0.2     │ 0.0       │ 0.0            │
# │ 5   │ 4173     │ -0.2    │ 0.0       │ 0.0            │
# │ 6   │ 4176     │ 0.2     │ 0.0       │ 0.0            │
# │ 7   │ 5408     │ -0.2    │ -0.168024 │ -0.222783      │
# │ 8   │ 5413     │ 0.2     │ 0.15971   │ 0.100565       │
# │ 9   │ 5416     │ -0.2    │ -0.165676 │ 0.0            │
# │ 10  │ 5419     │ 0.2     │ 0.243395  │ 0.131845       │
# │ 11  │ 5481     │ 0.2     │ 0.255055  │ 0.222099       │
# │ 12  │ 5484     │ 0.2     │ 0.0       │ 0.0            │
# │ 13  │ 5488     │ 0.2     │ 0.0       │ 0.108125       │
# │ 14  │ 5493     │ 0.2     │ 0.0       │ 0.0            │
# │ 15  │ 5499     │ 0.2     │ 0.334488  │ 0.351357       │
#
#
# running 4 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 43       │ 0.2     │ 0.2294    │ 0.237714       │
# │ 2   │ 174      │ -0.2    │ -0.153605 │ -0.170356      │
# │ 3   │ 176      │ 0.2     │ 0.191144  │ 0.194844       │
# │ 4   │ 782      │ -0.2    │ -0.168223 │ -0.172498      │
# │ 5   │ 790      │ -0.2    │ -0.255691 │ -0.252613      │
# │ 6   │ 796      │ -0.2    │ -0.210167 │ -0.218489      │
# │ 7   │ 4326     │ -0.2    │ 0.0       │ -0.160883      │
# │ 8   │ 4328     │ -0.2    │ -0.17009  │ -0.158488      │
# │ 9   │ 4334     │ 0.2     │ 0.0       │ 0.0            │
# │ 10  │ 4335     │ -0.2    │ 0.0       │ -0.0752514     │
# │ 11  │ 7366     │ -0.2    │ -0.162941 │ -0.17475       │
# │ 12  │ 7367     │ -0.2    │ -0.203634 │ -0.195273      │
# │ 13  │ 7372     │ -0.2    │ -0.296573 │ -0.293536      │
# │ 14  │ 7376     │ 0.2     │ 0.167054  │ 0.165788       │
# │ 15  │ 7378     │ -0.2    │ -0.222208 │ -0.212056      │
#
#
# running 5 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 2545     │ -0.2    │ -0.177418 │ -0.148732      │
# │ 2   │ 2850     │ -0.2    │ -0.203519 │ -0.153838      │
# │ 3   │ 2852     │ -0.2    │ -0.171217 │ 0.0            │
# │ 4   │ 3884     │ 0.2     │ 0.0       │ 0.0            │
# │ 5   │ 3885     │ 0.2     │ 0.153253  │ 0.101063       │
# │ 6   │ 3895     │ -0.2    │ 0.0       │ 0.0            │
# │ 7   │ 3983     │ 0.2     │ 0.158004  │ 0.0            │
# │ 8   │ 3986     │ 0.2     │ 0.198818  │ 0.0716458      │
# │ 9   │ 3990     │ -0.2    │ -0.215124 │ -0.232729      │
# │ 10  │ 3991     │ 0.2     │ 0.273645  │ 0.380695       │
# │ 11  │ 5182     │ 0.2     │ 0.194355  │ 0.15595        │
# │ 12  │ 5185     │ 0.2     │ 0.0       │ 0.0            │
# │ 13  │ 5187     │ 0.2     │ 0.164895  │ 0.0750745      │
# │ 14  │ 5188     │ 0.2     │ 0.0       │ 0.0            │
# │ 15  │ 5198     │ -0.2    │ 0.0       │ 0.0            │
#
#
# running 6 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 4633     │ -0.2    │ -0.218401 │ -0.206367      │
# │ 2   │ 6729     │ 0.2     │ 0.232347  │ 0.0            │
# │ 3   │ 6731     │ 0.2     │ 0.196861  │ 0.138497       │
# │ 4   │ 7884     │ 0.2     │ 0.141988  │ 0.0            │
# │ 5   │ 7889     │ 0.2     │ 0.18936   │ 0.232022       │
# │ 6   │ 7890     │ 0.2     │ 0.18936   │ 0.232022       │
# │ 7   │ 8410     │ 0.2     │ 0.173189  │ 0.166674       │
# │ 8   │ 8418     │ -0.2    │ -0.146028 │ -0.147644      │
# │ 9   │ 8419     │ -0.2    │ -0.170236 │ -0.183015      │
# │ 10  │ 8420     │ -0.2    │ -0.242714 │ -0.215433      │
# │ 11  │ 9527     │ -0.2    │ 0.0       │ 0.0            │
# │ 12  │ 9531     │ -0.2    │ 0.0       │ -0.112473      │
# │ 13  │ 9536     │ -0.2    │ -0.201689 │ -0.173309      │
# │ 14  │ 9538     │ 0.2     │ 0.0       │ 0.0            │
# │ 15  │ 9540     │ -0.2    │ -0.182904 │ -0.19792       │
#
#
# running 7 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 2246     │ 0.2     │ 0.218916  │ 0.221746       │
# │ 2   │ 3345     │ -0.2    │ -0.194389 │ -0.196065      │
# │ 3   │ 3346     │ -0.2    │ -0.262947 │ -0.254776      │
# │ 4   │ 5381     │ 0.2     │ 0.230511  │ 0.245535       │
# │ 5   │ 5397     │ -0.2    │ 0.0       │ -0.160552      │
# │ 6   │ 5398     │ 0.2     │ 0.0       │ 0.142356       │
# │ 7   │ 8085     │ 0.2     │ 0.178138  │ 0.261824       │
# │ 8   │ 8086     │ 0.2     │ 0.185933  │ 0.169238       │
# │ 9   │ 8088     │ -0.2    │ -0.224601 │ -0.146681      │
# │ 10  │ 8097     │ -0.2    │ -0.194547 │ 0.0            │
# │ 11  │ 9001     │ -0.2    │ -0.214248 │ -0.21918       │
# │ 12  │ 9006     │ -0.2    │ -0.229815 │ -0.221648      │
# │ 13  │ 9008     │ -0.2    │ -0.23104  │ -0.227998      │
# │ 14  │ 9012     │ -0.2    │ -0.177156 │ -0.16966       │
# │ 15  │ 9013     │ -0.2    │ -0.220027 │ -0.230682      │
#
#
# running 8 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 2898     │ -0.2    │ -0.139026 │ -0.143023      │
# │ 2   │ 3741     │ 0.2     │ 0.0       │ 0.122384       │
# │ 3   │ 3760     │ -0.2    │ -0.11925  │ -0.187201      │
# │ 4   │ 3949     │ 0.2     │ 0.157646  │ 0.154308       │
# │ 5   │ 3955     │ 0.2     │ 0.144214  │ 0.151328       │
# │ 6   │ 3959     │ -0.2    │ -0.226083 │ -0.225941      │
# │ 7   │ 5305     │ -0.2    │ -0.234053 │ -0.231316      │
# │ 8   │ 5308     │ -0.2    │ -0.122618 │ 0.0            │
# │ 9   │ 5311     │ -0.2    │ -0.216221 │ 0.0            │
# │ 10  │ 5317     │ 0.2     │ 0.185274  │ 0.171126       │
# │ 11  │ 6610     │ 0.2     │ 0.0       │ 0.0            │
# │ 12  │ 6611     │ 0.2     │ 0.337704  │ 0.285193       │
# │ 13  │ 6616     │ 0.2     │ 0.224796  │ 0.234861       │
# │ 14  │ 6617     │ 0.2     │ 0.0       │ 0.0981458      │
# │ 15  │ 6618     │ -0.2    │ 0.0       │ 0.0            │
#
#
# running 9 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 898      │ 0.2     │ 0.215172  │ 0.196112       │
# │ 2   │ 1174     │ 0.2     │ 0.0       │ 0.0775032      │
# │ 3   │ 1176     │ -0.2    │ 0.0       │ 0.0            │
# │ 4   │ 3664     │ 0.2     │ 0.178178  │ 0.166637       │
# │ 5   │ 3668     │ -0.2    │ -0.131162 │ -0.133741      │
# │ 6   │ 3670     │ 0.2     │ 0.168597  │ 0.172372       │
# │ 7   │ 5988     │ -0.2    │ -0.213135 │ -0.198543      │
# │ 8   │ 5993     │ 0.2     │ 0.188557  │ 0.181936       │
# │ 9   │ 5997     │ -0.2    │ -0.308549 │ -0.283866      │
# │ 10  │ 6000     │ -0.2    │ 0.0       │ 0.0            │
# │ 11  │ 9103     │ -0.2    │ -0.148096 │ -0.137671      │
# │ 12  │ 9106     │ 0.2     │ 0.0       │ 0.100882       │
# │ 13  │ 9109     │ 0.2     │ 0.0       │ 0.0            │
# │ 14  │ 9114     │ 0.2     │ 0.207417  │ 0.21915        │
# │ 15  │ 9116     │ -0.2    │ -0.230698 │ -0.214417      │
#
#
# running 10 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 3507     │ -0.2    │ -0.238084 │ -0.233517      │
# │ 2   │ 3754     │ 0.2     │ 0.138167  │ 0.14185        │
# │ 3   │ 3760     │ -0.2    │ -0.258661 │ -0.253841      │
# │ 4   │ 5242     │ -0.2    │ 0.0       │ 0.0            │
# │ 5   │ 5243     │ 0.2     │ 0.0       │ 0.0537834      │
# │ 6   │ 5252     │ 0.2     │ 0.150212  │ 0.162799       │
# │ 7   │ 7261     │ 0.2     │ 0.23145   │ 0.222644       │
# │ 8   │ 7262     │ -0.2    │ -0.223065 │ -0.215667      │
# │ 9   │ 7267     │ 0.2     │ 0.201716  │ 0.199332       │
# │ 10  │ 7270     │ -0.2    │ -0.175923 │ -0.177209      │
# │ 11  │ 7522     │ 0.2     │ 0.0       │ 0.155484       │
# │ 12  │ 7528     │ 0.2     │ 0.0       │ 0.0            │
# │ 13  │ 7536     │ 0.2     │ 0.229956  │ 0.221552       │
# │ 14  │ 7537     │ -0.2    │ -0.197216 │ -0.15477       │
# │ 15  │ 7538     │ -0.2    │ -0.172947 │ -0.289454      │
#
#
# running 11 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 991      │ 0.2     │ 0.193206  │ 0.198144       │
# │ 2   │ 1045     │ -0.2    │ -0.167678 │ -0.204195      │
# │ 3   │ 1055     │ 0.2     │ 0.146784  │ 0.152744       │
# │ 4   │ 2123     │ -0.2    │ -0.177046 │ -0.192264      │
# │ 5   │ 2135     │ 0.2     │ 0.216682  │ 0.217486       │
# │ 6   │ 2138     │ 0.2     │ 0.190978  │ 0.19642        │
# │ 7   │ 6043     │ -0.2    │ -0.142411 │ -0.165086      │
# │ 8   │ 6048     │ 0.2     │ 0.0       │ 0.214509       │
# │ 9   │ 6050     │ -0.2    │ 0.0       │ -0.219022      │
# │ 10  │ 6059     │ -0.2    │ -0.212577 │ -0.170809      │
# │ 11  │ 9344     │ 0.2     │ 0.0       │ 0.155976       │
# │ 12  │ 9345     │ -0.2    │ 0.0       │ 0.0            │
# │ 13  │ 9350     │ 0.2     │ 0.0       │ 0.0            │
# │ 14  │ 9353     │ 0.2     │ 0.162615  │ 0.224336       │
# │ 15  │ 9357     │ 0.2     │ 0.0       │ 0.0940189      │
#
#
# running 12 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 1992     │ 0.2     │ 0.142889  │ 0.162879       │
# │ 2   │ 2602     │ 0.2     │ 0.154273  │ 0.145664       │
# │ 3   │ 2617     │ -0.2    │ -0.237781 │ -0.234484      │
# │ 4   │ 3461     │ 0.2     │ 0.262852  │ 0.289818       │
# │ 5   │ 3462     │ -0.2    │ 0.0       │ -0.156481      │
# │ 6   │ 3470     │ -0.2    │ 0.0       │ 0.0            │
# │ 7   │ 3884     │ -0.2    │ -0.160915 │ -0.166223      │
# │ 8   │ 3891     │ 0.2     │ 0.247681  │ 0.248643       │
# │ 9   │ 3897     │ -0.2    │ -0.230448 │ -0.222849      │
# │ 10  │ 3898     │ -0.2    │ -0.227544 │ -0.235374      │
# │ 11  │ 4103     │ 0.2     │ 0.257246  │ 0.198129       │
# │ 12  │ 4104     │ 0.2     │ 0.223063  │ 0.212316       │
# │ 13  │ 4110     │ 0.2     │ 0.137441  │ 0.157444       │
# │ 14  │ 4115     │ -0.2    │ -0.130271 │ -0.143345      │
# │ 15  │ 4119     │ 0.2     │ 0.0       │ 0.0            │
#
#
# running 13 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 4669     │ -0.2    │ -0.200927 │ -0.19701       │
# │ 2   │ 5364     │ -0.2    │ -0.229915 │ -0.23219       │
# │ 3   │ 5374     │ -0.2    │ -0.159116 │ 0.0            │
# │ 4   │ 8082     │ 0.2     │ 0.281305  │ 0.276687       │
# │ 5   │ 8083     │ 0.2     │ 0.162013  │ 0.164843       │
# │ 6   │ 8089     │ -0.2    │ -0.210704 │ -0.210593      │
# │ 7   │ 8163     │ 0.2     │ 0.155286  │ 0.164978       │
# │ 8   │ 8166     │ 0.2     │ 0.217668  │ 0.21453        │
# │ 9   │ 8172     │ -0.2    │ -0.252471 │ -0.241715      │
# │ 10  │ 8177     │ 0.2     │ 0.140458  │ 0.143169       │
# │ 11  │ 9025     │ 0.2     │ 0.267746  │ 0.260738       │
# │ 12  │ 9026     │ 0.2     │ 0.0       │ 0.0            │
# │ 13  │ 9029     │ -0.2    │ 0.0       │ 0.0            │
# │ 14  │ 9037     │ 0.2     │ 0.146313  │ 0.133249       │
# │ 15  │ 9039     │ 0.2     │ 0.0       │ 0.0            │
#
#
# running 14 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 1859     │ 0.2     │ 0.166633  │ 0.175548       │
# │ 2   │ 4910     │ -0.2    │ -0.218199 │ -0.221645      │
# │ 3   │ 4912     │ 0.2     │ 0.181325  │ 0.177072       │
# │ 4   │ 5342     │ -0.2    │ -0.184243 │ -0.197042      │
# │ 5   │ 5350     │ 0.2     │ 0.233349  │ 0.238183       │
# │ 6   │ 5358     │ 0.2     │ 0.194978  │ 0.19717        │
# │ 7   │ 5544     │ 0.2     │ 0.250074  │ 0.187296       │
# │ 8   │ 5547     │ 0.2     │ 0.12315   │ 0.169299       │
# │ 9   │ 5550     │ -0.2    │ 0.0       │ -0.162354      │
# │ 10  │ 5560     │ 0.2     │ 0.0       │ 0.170419       │
# │ 11  │ 9801     │ -0.2    │ -0.235397 │ -0.236528      │
# │ 12  │ 9804     │ -0.2    │ -0.207635 │ -0.219851      │
# │ 13  │ 9807     │ -0.2    │ -0.24006  │ -0.214699      │
# │ 14  │ 9813     │ 0.2     │ 0.124534  │ 0.159421       │
# │ 15  │ 9814     │ -0.2    │ 0.0       │ -0.120347      │
#
#
# running 15 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 4056     │ 0.2     │ 0.122189  │ 0.118918       │
# │ 2   │ 4531     │ -0.2    │ -0.201276 │ -0.207002      │
# │ 3   │ 4534     │ 0.2     │ 0.1901    │ 0.212398       │
# │ 4   │ 5561     │ 0.2     │ 0.0       │ 0.0968837      │
# │ 5   │ 5567     │ -0.2    │ 0.0       │ 0.0            │
# │ 6   │ 5573     │ 0.2     │ 0.0       │ 0.0            │
# │ 7   │ 6021     │ 0.2     │ 0.236298  │ 0.236994       │
# │ 8   │ 6027     │ -0.2    │ -0.168455 │ -0.177737      │
# │ 9   │ 6028     │ 0.2     │ 0.135812  │ 0.163075       │
# │ 10  │ 6037     │ 0.2     │ 0.0       │ 0.0            │
# │ 11  │ 9542     │ -0.2    │ -0.188516 │ -0.177966      │
# │ 12  │ 9545     │ -0.2    │ -0.221658 │ -0.240823      │
# │ 13  │ 9550     │ 0.2     │ 0.159497  │ 0.142137       │
# │ 14  │ 9556     │ 0.2     │ 0.157862  │ 0.0            │
# │ 15  │ 9560     │ 0.2     │ 0.144288  │ 0.202228       │
#
#
# running 16 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 5760     │ -0.2    │ -0.17984  │ -0.178447      │
# │ 2   │ 6441     │ -0.2    │ -0.187226 │ -0.189001      │
# │ 3   │ 6447     │ 0.2     │ 0.234471  │ 0.236143       │
# │ 4   │ 8004     │ 0.2     │ 0.200232  │ 0.202366       │
# │ 5   │ 8011     │ 0.2     │ 0.194658  │ 0.1853         │
# │ 6   │ 8015     │ -0.2    │ -0.235915 │ -0.236865      │
# │ 7   │ 9543     │ -0.2    │ -0.162842 │ -0.167886      │
# │ 8   │ 9545     │ -0.2    │ -0.2273   │ -0.229296      │
# │ 9   │ 9549     │ -0.2    │ -0.151611 │ -0.152025      │
# │ 10  │ 9555     │ 0.2     │ 0.191013  │ 0.186848       │
# │ 11  │ 9786     │ -0.2    │ -0.156534 │ -0.126417      │
# │ 12  │ 9787     │ -0.2    │ -0.14916  │ -0.147125      │
# │ 13  │ 9789     │ -0.2    │ 0.0       │ 0.0            │
# │ 14  │ 9795     │ -0.2    │ -0.258685 │ -0.231326      │
# │ 15  │ 9797     │ -0.2    │ 0.0       │ 0.0            │
#
#
# running 17 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 1634     │ 0.2     │ 0.231723  │ 0.219142       │
# │ 2   │ 2851     │ -0.2    │ -0.191131 │ -0.122919      │
# │ 3   │ 2856     │ -0.2    │ -0.148092 │ 0.0            │
# │ 4   │ 5909     │ 0.2     │ 0.0       │ 0.0812633      │
# │ 5   │ 5913     │ 0.2     │ 0.113871  │ 0.0991409      │
# │ 6   │ 5914     │ -0.2    │ 0.0       │ 0.0            │
# │ 7   │ 7126     │ 0.2     │ 0.177479  │ 0.185324       │
# │ 8   │ 7133     │ -0.2    │ -0.186622 │ -0.203511      │
# │ 9   │ 7138     │ 0.2     │ 0.173003  │ 0.162141       │
# │ 10  │ 7139     │ 0.2     │ 0.251129  │ 0.243743       │
# │ 11  │ 8092     │ 0.2     │ 0.166125  │ 0.0            │
# │ 12  │ 8096     │ 0.2     │ 0.0       │ 0.0            │
# │ 13  │ 8097     │ -0.2    │ 0.0       │ -0.208765      │
# │ 14  │ 8098     │ 0.2     │ 0.0       │ 0.122642       │
# │ 15  │ 8099     │ 0.2     │ 0.217897  │ 0.144725       │
#
#
# running 18 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 3667     │ 0.2     │ 0.0       │ 0.0            │
# │ 2   │ 3773     │ -0.2    │ 0.0       │ 0.0            │
# │ 3   │ 3774     │ 0.2     │ 0.0       │ 0.0            │
# │ 4   │ 4487     │ 0.2     │ 0.119763  │ 0.174342       │
# │ 5   │ 4494     │ -0.2    │ 0.0       │ 0.0            │
# │ 6   │ 4496     │ 0.2     │ 0.0       │ 0.179115       │
# │ 7   │ 4882     │ -0.2    │ -0.184638 │ -0.18659       │
# │ 8   │ 4888     │ -0.2    │ -0.226611 │ -0.250494      │
# │ 9   │ 4889     │ 0.2     │ 0.18577   │ 0.190507       │
# │ 10  │ 4893     │ 0.2     │ 0.206079  │ 0.208441       │
# │ 11  │ 8501     │ 0.2     │ 0.152057  │ 0.0            │
# │ 12  │ 8504     │ 0.2     │ 0.298447  │ 0.334373       │
# │ 13  │ 8505     │ 0.2     │ 0.16598   │ 0.218249       │
# │ 14  │ 8508     │ -0.2    │ -0.112104 │ 0.0            │
# │ 15  │ 8519     │ -0.2    │ -0.163109 │ -0.0939474     │
#
#
# running 19 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 551      │ 0.2     │ 0.215666  │ 0.221404       │
# │ 2   │ 3143     │ 0.2     │ 0.0       │ 0.0            │
# │ 3   │ 3153     │ 0.2     │ 0.0       │ 0.0            │
# │ 4   │ 3662     │ -0.2    │ -0.196811 │ -0.257329      │
# │ 5   │ 3668     │ -0.2    │ 0.0       │ -0.195066      │
# │ 6   │ 3673     │ -0.2    │ 0.0       │ -0.168363      │
# │ 7   │ 7608     │ -0.2    │ -0.197075 │ -0.219934      │
# │ 8   │ 7609     │ 0.2     │ 0.199296  │ 0.205574       │
# │ 9   │ 7615     │ 0.2     │ 0.18217   │ 0.200655       │
# │ 10  │ 7617     │ 0.2     │ 0.192858  │ 0.198035       │
# │ 11  │ 9645     │ 0.2     │ 0.0       │ 0.165283       │
# │ 12  │ 9652     │ -0.2    │ -0.129262 │ -0.140582      │
# │ 13  │ 9656     │ -0.2    │ -0.229233 │ -0.2303        │
# │ 14  │ 9659     │ -0.2    │ -0.113463 │ -0.174403      │
# │ 15  │ 9660     │ -0.2    │ -0.238393 │ -0.260503      │
#
#
# running 20 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 1651     │ -0.2    │ -0.16377  │ -0.16615       │
# │ 2   │ 1948     │ 0.2     │ 0.179084  │ 0.187742       │
# │ 3   │ 1954     │ 0.2     │ 0.25302   │ 0.24365        │
# │ 4   │ 2665     │ 0.2     │ 0.213086  │ 0.213652       │
# │ 5   │ 2667     │ 0.2     │ 0.213709  │ 0.212071       │
# │ 6   │ 2669     │ 0.2     │ 0.19578   │ 0.197318       │
# │ 7   │ 3281     │ 0.2     │ 0.23079   │ 0.229604       │
# │ 8   │ 3293     │ -0.2    │ -0.178566 │ -0.191558      │
# │ 9   │ 3296     │ -0.2    │ -0.186407 │ -0.198028      │
# │ 10  │ 3300     │ 0.2     │ 0.149449  │ 0.146502       │
# │ 11  │ 5703     │ 0.2     │ 0.0       │ 0.171361       │
# │ 12  │ 5705     │ 0.2     │ 0.0       │ 0.202631       │
# │ 13  │ 5708     │ -0.2    │ -0.208127 │ -0.21211       │
# │ 14  │ 5709     │ -0.2    │ -0.178337 │ -0.177312      │
# │ 15  │ 5710     │ -0.2    │ -0.149435 │ -0.229603      │
#
#
# running 21 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 303      │ 0.2     │ 0.176621  │ 0.179101       │
# │ 2   │ 7622     │ -0.2    │ -0.251375 │ -0.253372      │
# │ 3   │ 7627     │ -0.2    │ -0.220672 │ -0.232706      │
# │ 4   │ 8372     │ 0.2     │ 0.215406  │ 0.219157       │
# │ 5   │ 8374     │ -0.2    │ -0.203066 │ -0.202027      │
# │ 6   │ 8376     │ -0.2    │ -0.218024 │ -0.220342      │
# │ 7   │ 9184     │ 0.2     │ 0.133604  │ 0.0790608      │
# │ 8   │ 9194     │ 0.2     │ 0.0       │ 0.0            │
# │ 9   │ 9196     │ -0.2    │ 0.0       │ 0.0            │
# │ 10  │ 9199     │ -0.2    │ 0.0       │ 0.0            │
# │ 11  │ 9967     │ -0.2    │ -0.287718 │ -0.249106      │
# │ 12  │ 9969     │ 0.2     │ 0.0       │ 0.0            │
# │ 13  │ 9971     │ 0.2     │ 0.0       │ 0.0            │
# │ 14  │ 9972     │ -0.2    │ 0.0       │ 0.0            │
# │ 15  │ 9979     │ 0.2     │ 0.171642  │ 0.0819628      │
#
#
# running 22 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 2088     │ -0.2    │ -0.210394 │ -0.212947      │
# │ 2   │ 2604     │ 0.2     │ 0.19103   │ 0.199129       │
# │ 3   │ 2616     │ 0.2     │ 0.173556  │ 0.166116       │
# │ 4   │ 3747     │ -0.2    │ -0.234713 │ -0.232777      │
# │ 5   │ 3753     │ -0.2    │ -0.189425 │ -0.187779      │
# │ 6   │ 3754     │ -0.2    │ -0.243016 │ -0.246513      │
# │ 7   │ 4864     │ -0.2    │ -0.207652 │ -0.200293      │
# │ 8   │ 4866     │ 0.2     │ 0.199972  │ 0.200943       │
# │ 9   │ 4869     │ 0.2     │ 0.223866  │ 0.232003       │
# │ 10  │ 4878     │ -0.2    │ -0.142004 │ -0.145155      │
# │ 11  │ 8383     │ 0.2     │ 0.190551  │ 0.223082       │
# │ 12  │ 8389     │ 0.2     │ 0.346838  │ 0.366893       │
# │ 13  │ 8394     │ -0.2    │ -0.126489 │ -0.135207      │
# │ 14  │ 8396     │ -0.2    │ 0.0       │ 0.0            │
# │ 15  │ 8398     │ -0.2    │ 0.0       │ 0.0            │
#
#
# running 23 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 3242     │ 0.2     │ 0.175398  │ 0.168332       │
# │ 2   │ 3956     │ 0.2     │ 0.304365  │ 0.284864       │
# │ 3   │ 3960     │ -0.2    │ -0.242843 │ -0.230001      │
# │ 4   │ 4041     │ 0.2     │ 0.252098  │ 0.245613       │
# │ 5   │ 4049     │ 0.2     │ 0.220766  │ 0.216811       │
# │ 6   │ 4059     │ -0.2    │ -0.146137 │ -0.147322      │
# │ 7   │ 4583     │ 0.2     │ 0.238457  │ 0.232972       │
# │ 8   │ 4594     │ -0.2    │ -0.122899 │ -0.129495      │
# │ 9   │ 4597     │ 0.2     │ 0.246288  │ 0.242651       │
# │ 10  │ 4598     │ 0.2     │ 0.182553  │ 0.196391       │
# │ 11  │ 9905     │ 0.2     │ 0.0       │ 0.137352       │
# │ 12  │ 9908     │ 0.2     │ 0.0       │ 0.0            │
# │ 13  │ 9914     │ -0.2    │ 0.0       │ 0.0            │
# │ 14  │ 9918     │ -0.2    │ -0.210796 │ -0.195301      │
# │ 15  │ 9919     │ -0.2    │ 0.0       │ 0.0            │
#
#
# running 24 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 4831     │ 0.2     │ 0.201342  │ 0.198656       │
# │ 2   │ 5402     │ 0.2     │ 0.162659  │ 0.173183       │
# │ 3   │ 5413     │ -0.2    │ -0.209534 │ -0.215925      │
# │ 4   │ 6784     │ -0.2    │ -0.191759 │ -0.188754      │
# │ 5   │ 6790     │ 0.2     │ 0.110402  │ 0.113553       │
# │ 6   │ 6791     │ 0.2     │ 0.263896  │ 0.262258       │
# │ 7   │ 7988     │ -0.2    │ -0.164283 │ -0.167985      │
# │ 8   │ 7991     │ -0.2    │ -0.211915 │ -0.210312      │
# │ 9   │ 7996     │ 0.2     │ 0.164367  │ 0.166886       │
# │ 10  │ 7998     │ 0.2     │ 0.232294  │ 0.22902        │
# │ 11  │ 9003     │ 0.2     │ 0.0       │ 0.0            │
# │ 12  │ 9005     │ -0.2    │ 0.0       │ -0.0927528     │
# │ 13  │ 9013     │ -0.2    │ 0.0       │ 0.0            │
# │ 14  │ 9015     │ 0.2     │ 0.206664  │ 0.177064       │
# │ 15  │ 9018     │ 0.2     │ 0.0       │ 0.0            │
#
#
# running 25 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 1473     │ -0.2    │ -0.207397 │ -0.209582      │
# │ 2   │ 2641     │ 0.2     │ 0.145589  │ 0.143715       │
# │ 3   │ 2643     │ 0.2     │ 0.18185   │ 0.17968        │
# │ 4   │ 3447     │ 0.2     │ 0.237264  │ 0.239055       │
# │ 5   │ 3454     │ -0.2    │ -0.241458 │ -0.244233      │
# │ 6   │ 3460     │ 0.2     │ 0.170387  │ 0.172273       │
# │ 7   │ 4223     │ 0.2     │ 0.117421  │ 0.230392       │
# │ 8   │ 4234     │ -0.2    │ -0.204371 │ -0.212808      │
# │ 9   │ 4237     │ -0.2    │ -0.163267 │ -0.158308      │
# │ 10  │ 4238     │ -0.2    │ -0.235413 │ -0.231562      │
# │ 11  │ 5562     │ -0.2    │ -0.281695 │ -0.309573      │
# │ 12  │ 5563     │ -0.2    │ 0.0       │ 0.0            │
# │ 13  │ 5577     │ 0.2     │ 0.193844  │ 0.213733       │
# │ 14  │ 5578     │ 0.2     │ 0.24785   │ 0.198257       │
# │ 15  │ 5580     │ 0.2     │ 0.0       │ 0.123192       │
#
#
# running 26 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 3597     │ 0.2     │ 0.216516  │ 0.211398       │
# │ 2   │ 5150     │ 0.2     │ 0.17887   │ 0.12148        │
# │ 3   │ 5157     │ -0.2    │ -0.195053 │ 0.0            │
# │ 4   │ 5542     │ 0.2     │ 0.0       │ 0.0            │
# │ 5   │ 5549     │ 0.2     │ 0.0       │ 0.0            │
# │ 6   │ 5550     │ -0.2    │ 0.0       │ -0.166899      │
# │ 7   │ 6801     │ 0.2     │ 0.25833   │ 0.260113       │
# │ 8   │ 6802     │ 0.2     │ 0.13699   │ 0.116471       │
# │ 9   │ 6806     │ -0.2    │ 0.0       │ -0.107823      │
# │ 10  │ 6810     │ -0.2    │ 0.0       │ 0.0            │
# │ 11  │ 8582     │ 0.2     │ 0.177076  │ 0.186008       │
# │ 12  │ 8586     │ 0.2     │ 0.254184  │ 0.212614       │
# │ 13  │ 8590     │ 0.2     │ 0.0       │ 0.21034        │
# │ 14  │ 8599     │ -0.2    │ -0.141674 │ -0.206689      │
# │ 15  │ 8600     │ 0.2     │ 0.132407  │ 0.199369       │
#
#
# running 27 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 1774     │ -0.2    │ 0.0       │ 0.0            │
# │ 2   │ 4050     │ 0.2     │ 0.0       │ 0.108529       │
# │ 3   │ 4055     │ -0.2    │ 0.0       │ 0.0            │
# │ 4   │ 7851     │ -0.2    │ -0.133145 │ -0.255027      │
# │ 5   │ 7853     │ 0.2     │ 0.0       │ 0.210218       │
# │ 6   │ 7856     │ 0.2     │ 0.186183  │ 0.178988       │
# │ 7   │ 7873     │ 0.2     │ 0.0       │ 0.0            │
# │ 8   │ 7874     │ -0.2    │ 0.0       │ 0.0            │
# │ 9   │ 7875     │ 0.2     │ 0.183739  │ 0.201445       │
# │ 10  │ 7878     │ 0.2     │ 0.164003  │ 0.195944       │
# │ 11  │ 8463     │ 0.2     │ 0.0       │ 0.0            │
# │ 12  │ 8469     │ -0.2    │ -0.238741 │ -0.242421      │
# │ 13  │ 8471     │ 0.2     │ 0.179116  │ 0.241043       │
# │ 14  │ 8477     │ 0.2     │ 0.148567  │ 0.0            │
# │ 15  │ 8479     │ 0.2     │ 0.221094  │ 0.148193       │
#
#
# running 28 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 866      │ 0.2     │ 0.164223  │ 0.183427       │
# │ 2   │ 2462     │ 0.2     │ 0.153923  │ 0.146433       │
# │ 3   │ 2467     │ 0.2     │ 0.168854  │ 0.188567       │
# │ 4   │ 3943     │ 0.2     │ 0.231672  │ 0.17123        │
# │ 5   │ 3945     │ 0.2     │ 0.0       │ 0.152965       │
# │ 6   │ 3947     │ -0.2    │ 0.0       │ 0.0            │
# │ 7   │ 4325     │ -0.2    │ -0.154025 │ -0.151146      │
# │ 8   │ 4330     │ 0.2     │ 0.248786  │ 0.206838       │
# │ 9   │ 4331     │ 0.2     │ 0.196554  │ 0.255967       │
# │ 10  │ 4333     │ -0.2    │ -0.285708 │ -0.300159      │
# │ 11  │ 4942     │ 0.2     │ 0.0       │ 0.0            │
# │ 12  │ 4944     │ 0.2     │ 0.0       │ 0.0            │
# │ 13  │ 4946     │ -0.2    │ 0.0       │ -0.144482      │
# │ 14  │ 4947     │ 0.2     │ 0.0       │ 0.0619762      │
# │ 15  │ 4948     │ 0.2     │ 0.334435  │ 0.372977       │
#
#
# running 29 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 1844     │ 0.2     │ 0.237262  │ 0.242332       │
# │ 2   │ 3621     │ 0.2     │ 0.196725  │ 0.126306       │
# │ 3   │ 3636     │ 0.2     │ 0.0       │ 0.0            │
# │ 4   │ 7843     │ -0.2    │ -0.228036 │ -0.215358      │
# │ 5   │ 7847     │ 0.2     │ 0.232712  │ 0.21243        │
# │ 6   │ 7849     │ -0.2    │ -0.10751  │ 0.0            │
# │ 7   │ 8387     │ 0.2     │ 0.0       │ 0.14723        │
# │ 8   │ 8388     │ -0.2    │ 0.0       │ -0.183378      │
# │ 9   │ 8392     │ -0.2    │ -0.24738  │ -0.288462      │
# │ 10  │ 8399     │ -0.2    │ 0.0       │ 0.0            │
# │ 11  │ 8823     │ -0.2    │ 0.0       │ -0.126784      │
# │ 12  │ 8824     │ 0.2     │ 0.0       │ 0.102184       │
# │ 13  │ 8828     │ 0.2     │ 0.198662  │ 0.183211       │
# │ 14  │ 8838     │ -0.2    │ 0.0       │ 0.0            │
# │ 15  │ 8839     │ 0.2     │ 0.156619  │ 0.122407       │
#
#
# running 30 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 1219     │ 0.2     │ 0.172837  │ 0.179218       │
# │ 2   │ 1627     │ -0.2    │ -0.179145 │ -0.17346       │
# │ 3   │ 1629     │ 0.2     │ 0.224482  │ 0.219834       │
# │ 4   │ 4150     │ 0.2     │ 0.195986  │ 0.104821       │
# │ 5   │ 4157     │ 0.2     │ 0.173418  │ 0.0            │
# │ 6   │ 4159     │ -0.2    │ -0.17378  │ -0.191901      │
# │ 7   │ 4201     │ 0.2     │ 0.206634  │ 0.210286       │
# │ 8   │ 4204     │ 0.2     │ 0.168138  │ 0.166377       │
# │ 9   │ 4208     │ -0.2    │ -0.179704 │ -0.180685      │
# │ 10  │ 4213     │ -0.2    │ -0.216141 │ -0.227027      │
# │ 11  │ 7885     │ 0.2     │ 0.207664  │ 0.213549       │
# │ 12  │ 7888     │ 0.2     │ 0.20578   │ 0.207874       │
# │ 13  │ 7891     │ 0.2     │ 0.206789  │ 0.204232       │
# │ 14  │ 7894     │ 0.2     │ 0.25856   │ 0.258227       │
# │ 15  │ 7895     │ 0.2     │ 0.163263  │ 0.165524       │
#
#
# running 31 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 933      │ -0.2    │ -0.189177 │ -0.190578      │
# │ 2   │ 2471     │ 0.2     │ 0.17521   │ 0.130159       │
# │ 3   │ 2480     │ -0.2    │ -0.162785 │ 0.0            │
# │ 4   │ 2522     │ -0.2    │ 0.0       │ -0.147586      │
# │ 5   │ 2523     │ 0.2     │ 0.0       │ 0.144717       │
# │ 6   │ 2531     │ 0.2     │ 0.269871  │ 0.262977       │
# │ 7   │ 4266     │ 0.2     │ 0.18002   │ 0.198237       │
# │ 8   │ 4267     │ 0.2     │ 0.220995  │ 0.211633       │
# │ 9   │ 4269     │ 0.2     │ 0.17691   │ 0.185805       │
# │ 10  │ 4272     │ -0.2    │ -0.179393 │ -0.196195      │
# │ 11  │ 7947     │ -0.2    │ 0.0       │ 0.0            │
# │ 12  │ 7948     │ 0.2     │ 0.0       │ 0.0            │
# │ 13  │ 7951     │ -0.2    │ -0.278845 │ -0.289613      │
# │ 14  │ 7955     │ -0.2    │ -0.270202 │ -0.192738      │
# │ 15  │ 7957     │ -0.2    │ -0.105706 │ -0.0970591     │
#
#
# running 32 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 5618     │ -0.2    │ -0.202793 │ -0.1889        │
# │ 2   │ 6733     │ 0.2     │ 0.191917  │ 0.0            │
# │ 3   │ 6736     │ 0.2     │ 0.263225  │ 0.165492       │
# │ 4   │ 7542     │ -0.2    │ -0.199339 │ -0.121723      │
# │ 5   │ 7543     │ -0.2    │ -0.168606 │ -0.155411      │
# │ 6   │ 7544     │ 0.2     │ 0.188252  │ 0.0            │
# │ 7   │ 8783     │ -0.2    │ -0.166677 │ -0.14329       │
# │ 8   │ 8790     │ -0.2    │ -0.221562 │ -0.245911      │
# │ 9   │ 8794     │ 0.2     │ 0.0       │ 0.116423       │
# │ 10  │ 8795     │ -0.2    │ 0.0       │ 0.0            │
# │ 11  │ 9783     │ -0.2    │ -0.168388 │ -0.185594      │
# │ 12  │ 9786     │ -0.2    │ 0.0       │ 0.0            │
# │ 13  │ 9787     │ 0.2     │ 0.0       │ 0.0            │
# │ 14  │ 9789     │ 0.2     │ 0.188016  │ 0.211786       │
# │ 15  │ 9797     │ 0.2     │ 0.195576  │ 0.17196        │
#
#
# running 33 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 3494     │ 0.2     │ 0.159927  │ 0.186118       │
# │ 2   │ 4205     │ -0.2    │ -0.193021 │ -0.210604      │
# │ 3   │ 4211     │ -0.2    │ -0.175956 │ -0.162507      │
# │ 4   │ 5185     │ -0.2    │ -0.205492 │ -0.211767      │
# │ 5   │ 5191     │ 0.2     │ 0.0       │ 0.114573       │
# │ 6   │ 5198     │ 0.2     │ 0.0       │ 0.0            │
# │ 7   │ 9649     │ -0.2    │ -0.131771 │ 0.0            │
# │ 8   │ 9651     │ -0.2    │ -0.175874 │ -0.170939      │
# │ 9   │ 9653     │ 0.2     │ 0.0       │ 0.0            │
# │ 10  │ 9654     │ 0.2     │ 0.235301  │ 0.200966       │
# │ 11  │ 9722     │ 0.2     │ 0.178104  │ 0.0            │
# │ 12  │ 9724     │ 0.2     │ 0.147174  │ 0.226594       │
# │ 13  │ 9734     │ 0.2     │ 0.0       │ 0.211128       │
# │ 14  │ 9735     │ -0.2    │ 0.0       │ -0.190705      │
# │ 15  │ 9736     │ -0.2    │ -0.27745  │ -0.246155      │
#
#
# running 34 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 1480     │ -0.2    │ -0.192149 │ -0.200367      │
# │ 2   │ 1647     │ 0.2     │ 0.196493  │ 0.196795       │
# │ 3   │ 1652     │ -0.2    │ -0.145006 │ -0.139019      │
# │ 4   │ 6401     │ 0.2     │ 0.0       │ 0.104357       │
# │ 5   │ 6405     │ -0.2    │ 0.0       │ -0.151519      │
# │ 6   │ 6419     │ 0.2     │ 0.0       │ 0.0            │
# │ 7   │ 6642     │ 0.2     │ 0.271963  │ 0.275628       │
# │ 8   │ 6651     │ -0.2    │ -0.204531 │ -0.221798      │
# │ 9   │ 6655     │ 0.2     │ 0.134024  │ 0.15437        │
# │ 10  │ 6660     │ -0.2    │ -0.156731 │ -0.137526      │
# │ 11  │ 8504     │ -0.2    │ 0.0       │ 0.0            │
# │ 12  │ 8505     │ -0.2    │ -0.319502 │ -0.271843      │
# │ 13  │ 8514     │ -0.2    │ -0.214506 │ -0.135433      │
# │ 14  │ 8516     │ 0.2     │ 0.0       │ 0.141658       │
# │ 15  │ 8518     │ -0.2    │ 0.0       │ 0.0            │
#
#
# running 35 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 146      │ 0.2     │ 0.136001  │ 0.136054       │
# │ 2   │ 3682     │ -0.2    │ -0.173299 │ -0.168052      │
# │ 3   │ 3697     │ 0.2     │ 0.184714  │ 0.18088        │
# │ 4   │ 7007     │ -0.2    │ 0.0       │ 0.0            │
# │ 5   │ 7011     │ -0.2    │ -0.187577 │ -0.213693      │
# │ 6   │ 7014     │ 0.2     │ 0.0       │ 0.125157       │
# │ 7   │ 7827     │ -0.2    │ 0.0       │ 0.0            │
# │ 8   │ 7830     │ -0.2    │ 0.0       │ -0.130225      │
# │ 9   │ 7834     │ -0.2    │ -0.177275 │ -0.243765      │
# │ 10  │ 7840     │ 0.2     │ 0.298511  │ 0.242285       │
# │ 11  │ 9047     │ -0.2    │ -0.328516 │ -0.217681      │
# │ 12  │ 9049     │ -0.2    │ 0.0       │ -0.182391      │
# │ 13  │ 9050     │ 0.2     │ 0.0       │ 0.165047       │
# │ 14  │ 9056     │ -0.2    │ -0.132546 │ -0.143849      │
# │ 15  │ 9060     │ 0.2     │ 0.164269  │ 0.206112       │
#
#
# running 36 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 731      │ -0.2    │ -0.212094 │ -0.205615      │
# │ 2   │ 4221     │ 0.2     │ 0.247954  │ 0.24747        │
# │ 3   │ 4234     │ 0.2     │ 0.163579  │ 0.165009       │
# │ 4   │ 4272     │ 0.2     │ 0.276735  │ 0.284052       │
# │ 5   │ 4276     │ -0.2    │ -0.179143 │ -0.174971      │
# │ 6   │ 4277     │ -0.2    │ -0.164146 │ -0.169588      │
# │ 7   │ 4885     │ -0.2    │ -0.276291 │ -0.273585      │
# │ 8   │ 4893     │ 0.2     │ 0.202039  │ 0.205996       │
# │ 9   │ 4895     │ 0.2     │ 0.176476  │ 0.190185       │
# │ 10  │ 4896     │ 0.2     │ 0.16434   │ 0.166709       │
# │ 11  │ 6821     │ 0.2     │ 0.280066  │ 0.177682       │
# │ 12  │ 6822     │ 0.2     │ 0.166327  │ 0.192564       │
# │ 13  │ 6824     │ -0.2    │ -0.185415 │ -0.220579      │
# │ 14  │ 6829     │ 0.2     │ 0.0       │ 0.188793       │
# │ 15  │ 6830     │ -0.2    │ 0.0       │ -0.171466      │
#
#
# running 37 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 971      │ 0.2     │ 0.183818  │ 0.191412       │
# │ 2   │ 2147     │ -0.2    │ 0.0       │ -0.14993       │
# │ 3   │ 2151     │ -0.2    │ -0.154904 │ -0.189766      │
# │ 4   │ 3022     │ -0.2    │ -0.228863 │ -0.227228      │
# │ 5   │ 3029     │ -0.2    │ -0.242673 │ -0.236972      │
# │ 6   │ 3031     │ 0.2     │ 0.238059  │ 0.233295       │
# │ 7   │ 8587     │ -0.2    │ -0.170958 │ -0.179678      │
# │ 8   │ 8588     │ -0.2    │ -0.229756 │ -0.219434      │
# │ 9   │ 8593     │ 0.2     │ 0.226164  │ 0.220047       │
# │ 10  │ 8594     │ 0.2     │ 0.179671  │ 0.176845       │
# │ 11  │ 9582     │ -0.2    │ -0.223555 │ -0.2189        │
# │ 12  │ 9585     │ -0.2    │ -0.221704 │ -0.222485      │
# │ 13  │ 9588     │ -0.2    │ -0.176172 │ -0.178408      │
# │ 14  │ 9594     │ 0.2     │ 0.220659  │ 0.221309       │
# │ 15  │ 9598     │ -0.2    │ -0.162468 │ -0.159578      │
#
#
# running 38 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 6349     │ 0.2     │ 0.216832  │ 0.214336       │
# │ 2   │ 8212     │ 0.2     │ 0.215969  │ 0.224341       │
# │ 3   │ 8215     │ 0.2     │ 0.194768  │ 0.203064       │
# │ 4   │ 9283     │ 0.2     │ 0.225531  │ 0.223234       │
# │ 5   │ 9293     │ -0.2    │ -0.240961 │ 0.0            │
# │ 6   │ 9298     │ -0.2    │ -0.190582 │ -0.165705      │
# │ 7   │ 9353     │ -0.2    │ -0.127002 │ -0.125497      │
# │ 8   │ 9355     │ -0.2    │ -0.239326 │ -0.229563      │
# │ 9   │ 9356     │ -0.2    │ -0.14007  │ -0.143786      │
# │ 10  │ 9359     │ -0.2    │ 0.0       │ 0.0            │
# │ 11  │ 9785     │ 0.2     │ 0.270176  │ 0.282839       │
# │ 12  │ 9786     │ -0.2    │ -0.283924 │ -0.291344      │
# │ 13  │ 9788     │ -0.2    │ -0.225721 │ -0.213866      │
# │ 14  │ 9793     │ -0.2    │ -0.188704 │ -0.181511      │
# │ 15  │ 9798     │ -0.2    │ -0.255891 │ -0.259797      │
#
#
# running 39 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 750      │ -0.2    │ -0.218887 │ -0.218155      │
# │ 2   │ 3591     │ 0.2     │ 0.197327  │ 0.0            │
# │ 3   │ 3594     │ 0.2     │ 0.137558  │ 0.0            │
# │ 4   │ 5314     │ -0.2    │ -0.152501 │ 0.0            │
# │ 5   │ 5316     │ -0.2    │ -0.192191 │ -0.172059      │
# │ 6   │ 5318     │ 0.2     │ 0.274832  │ 0.228342       │
# │ 7   │ 5901     │ -0.2    │ -0.225148 │ -0.23892       │
# │ 8   │ 5905     │ -0.2    │ 0.0       │ 0.0            │
# │ 9   │ 5916     │ -0.2    │ -0.182908 │ -0.174275      │
# │ 10  │ 5919     │ 0.2     │ 0.192994  │ 0.20646        │
# │ 11  │ 6788     │ -0.2    │ -0.248818 │ -0.247566      │
# │ 12  │ 6791     │ 0.2     │ 0.20454   │ 0.219169       │
# │ 13  │ 6795     │ -0.2    │ -0.177956 │ -0.162136      │
# │ 14  │ 6796     │ -0.2    │ -0.194709 │ -0.191781      │
# │ 15  │ 6799     │ -0.2    │ -0.161484 │ -0.161145      │
#
#
# running 40 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 2106     │ 0.2     │ 0.182144  │ 0.189062       │
# │ 2   │ 5202     │ -0.2    │ -0.213469 │ -0.22313       │
# │ 3   │ 5210     │ 0.2     │ 0.218902  │ 0.22739        │
# │ 4   │ 7150     │ -0.2    │ 0.0       │ 0.0            │
# │ 5   │ 7154     │ 0.2     │ 0.0       │ 0.0            │
# │ 6   │ 7159     │ -0.2    │ -0.202828 │ -0.167058      │
# │ 7   │ 8288     │ 0.2     │ 0.0       │ 0.0            │
# │ 8   │ 8290     │ 0.2     │ 0.0       │ 0.0            │
# │ 9   │ 8296     │ -0.2    │ -0.126353 │ -0.11635       │
# │ 10  │ 8300     │ -0.2    │ 0.0       │ -0.109751      │
# │ 11  │ 9842     │ 0.2     │ 0.0       │ 0.048632       │
# │ 12  │ 9846     │ -0.2    │ -0.123629 │ -0.144073      │
# │ 13  │ 9856     │ 0.2     │ 0.330859  │ 0.315875       │
# │ 14  │ 9858     │ -0.2    │ 0.0       │ 0.0            │
# │ 15  │ 9859     │ 0.2     │ 0.0       │ 0.0            │
#
#
# running 41 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 1067     │ -0.2    │ -0.139215 │ -0.144284      │
# │ 2   │ 1262     │ -0.2    │ -0.203798 │ -0.20687       │
# │ 3   │ 1280     │ 0.2     │ 0.213483  │ 0.224219       │
# │ 4   │ 1947     │ 0.2     │ 0.243895  │ 0.244994       │
# │ 5   │ 1951     │ 0.2     │ 0.203675  │ 0.201366       │
# │ 6   │ 1953     │ 0.2     │ 0.240081  │ 0.236319       │
# │ 7   │ 2388     │ 0.2     │ 0.192022  │ 0.186956       │
# │ 8   │ 2392     │ 0.2     │ 0.16807   │ 0.175836       │
# │ 9   │ 2397     │ -0.2    │ -0.225831 │ -0.233268      │
# │ 10  │ 2399     │ -0.2    │ -0.203605 │ -0.200408      │
# │ 11  │ 7185     │ 0.2     │ 0.0       │ 0.0            │
# │ 12  │ 7196     │ -0.2    │ -0.211546 │ -0.156782      │
# │ 13  │ 7197     │ 0.2     │ 0.211345  │ 0.137636       │
# │ 14  │ 7198     │ -0.2    │ 0.0       │ 0.0            │
# │ 15  │ 7199     │ -0.2    │ 0.0       │ 0.0            │
#
#
# running 42 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 3655     │ -0.2    │ -0.14453  │ -0.148611      │
# │ 2   │ 6229     │ 0.2     │ 0.17799   │ 0.176619       │
# │ 3   │ 6236     │ -0.2    │ -0.270142 │ -0.264234      │
# │ 4   │ 6971     │ 0.2     │ 0.0       │ 0.0            │
# │ 5   │ 6979     │ 0.2     │ 0.0       │ 0.0            │
# │ 6   │ 6980     │ -0.2    │ 0.0       │ 0.0            │
# │ 7   │ 7046     │ -0.2    │ -0.146608 │ -0.263769      │
# │ 8   │ 7049     │ -0.2    │ -0.1861   │ -0.174835      │
# │ 9   │ 7054     │ 0.2     │ 0.0       │ 0.209491       │
# │ 10  │ 7059     │ -0.2    │ 0.0       │ -0.228445      │
# │ 11  │ 9562     │ 0.2     │ 0.0       │ 0.152356       │
# │ 12  │ 9563     │ -0.2    │ 0.0       │ 0.0            │
# │ 13  │ 9567     │ -0.2    │ 0.0       │ -0.0983667     │
# │ 14  │ 9569     │ -0.2    │ -0.240164 │ -0.254565      │
# │ 15  │ 9574     │ 0.2     │ 0.0       │ 0.0            │
#
#
# running 43 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 2917     │ 0.2     │ 0.199608  │ 0.194058       │
# │ 2   │ 6522     │ 0.2     │ 0.182931  │ 0.185139       │
# │ 3   │ 6534     │ 0.2     │ 0.2563    │ 0.253546       │
# │ 4   │ 6681     │ -0.2    │ -0.166943 │ -0.169207      │
# │ 5   │ 6694     │ -0.2    │ -0.224239 │ -0.229345      │
# │ 6   │ 6696     │ 0.2     │ 0.235601  │ 0.236351       │
# │ 7   │ 8365     │ -0.2    │ 0.0       │ -0.169377      │
# │ 8   │ 8368     │ -0.2    │ 0.0       │ 0.0            │
# │ 9   │ 8374     │ 0.2     │ 0.0       │ 0.0            │
# │ 10  │ 8375     │ -0.2    │ 0.0       │ 0.0            │
# │ 11  │ 9147     │ 0.2     │ 0.166058  │ 0.156367       │
# │ 12  │ 9152     │ 0.2     │ 0.312608  │ 0.313549       │
# │ 13  │ 9154     │ -0.2    │ -0.152474 │ -0.139494      │
# │ 14  │ 9159     │ -0.2    │ -0.18006  │ -0.165016      │
# │ 15  │ 9160     │ 0.2     │ 0.192152  │ 0.189876       │
#
#
# running 44 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 414      │ -0.2    │ -0.252443 │ -0.245599      │
# │ 2   │ 2709     │ 0.2     │ 0.177284  │ 0.164211       │
# │ 3   │ 2720     │ 0.2     │ 0.212109  │ 0.219502       │
# │ 4   │ 3492     │ 0.2     │ 0.180906  │ 0.189315       │
# │ 5   │ 3494     │ -0.2    │ -0.214375 │ -0.229534      │
# │ 6   │ 3497     │ -0.2    │ -0.220617 │ -0.212292      │
# │ 7   │ 4007     │ -0.2    │ -0.218338 │ -0.215266      │
# │ 8   │ 4009     │ 0.2     │ 0.0       │ 0.194773       │
# │ 9   │ 4011     │ -0.2    │ 0.0       │ -0.174359      │
# │ 10  │ 4018     │ -0.2    │ -0.156107 │ -0.201172      │
# ...
# │ 7   │ 5341     │ 0.2     │ 0.226319  │ 0.191652       │
# │ 8   │ 5342     │ 0.2     │ 0.128173  │ 0.157675       │
# │ 9   │ 5347     │ -0.2    │ -0.19504  │ -0.200733      │
# │ 10  │ 5360     │ 0.2     │ 0.230945  │ 0.231019       │
# │ 11  │ 7601     │ 0.2     │ 0.21037   │ 0.0            │
# │ 12  │ 7607     │ -0.2    │ -0.180019 │ -0.213346      │
# │ 13  │ 7610     │ 0.2     │ 0.0       │ 0.0            │
# │ 14  │ 7612     │ 0.2     │ 0.265132  │ 0.192461       │
# │ 15  │ 7613     │ 0.2     │ 0.186694  │ 0.200827       │
#
#
# running 87 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 862      │ 0.2     │ 0.240382  │ 0.253902       │
# │ 2   │ 2769     │ 0.2     │ 0.185889  │ 0.173048       │
# │ 3   │ 2778     │ 0.2     │ 0.149008  │ 0.149507       │
# │ 4   │ 2787     │ -0.2    │ -0.20417  │ -0.202056      │
# │ 5   │ 2788     │ -0.2    │ -0.219674 │ -0.222639      │
# │ 6   │ 2794     │ 0.2     │ 0.193405  │ 0.197769       │
# │ 7   │ 5564     │ 0.2     │ 0.150331  │ 0.147077       │
# │ 8   │ 5566     │ 0.2     │ 0.198025  │ 0.195576       │
# │ 9   │ 5567     │ 0.2     │ 0.166589  │ 0.165449       │
# │ 10  │ 5573     │ 0.2     │ 0.219522  │ 0.231163       │
# │ 11  │ 7622     │ 0.2     │ 0.284194  │ 0.300594       │
# │ 12  │ 7628     │ -0.2    │ 0.0       │ -0.120828      │
# │ 13  │ 7632     │ -0.2    │ 0.0       │ 0.0            │
# │ 14  │ 7637     │ -0.2    │ -0.233516 │ -0.218948      │
# │ 15  │ 7639     │ 0.2     │ 0.147141  │ 0.161713       │
#
#
# running 88 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 1165     │ -0.2    │ -0.173371 │ -0.167249      │
# │ 2   │ 2943     │ 0.2     │ 0.194441  │ 0.199371       │
# │ 3   │ 2952     │ -0.2    │ -0.202582 │ -0.190099      │
# │ 4   │ 3405     │ 0.2     │ 0.206132  │ 0.187076       │
# │ 5   │ 3407     │ 0.2     │ 0.167094  │ 0.0            │
# │ 6   │ 3418     │ 0.2     │ 0.226462  │ 0.183147       │
# │ 7   │ 4343     │ -0.2    │ -0.253166 │ -0.245219      │
# │ 8   │ 4347     │ 0.2     │ 0.218981  │ 0.212711       │
# │ 9   │ 4348     │ 0.2     │ 0.203237  │ 0.191399       │
# │ 10  │ 4356     │ 0.2     │ 0.237431  │ 0.248323       │
# │ 11  │ 4923     │ -0.2    │ -0.253235 │ -0.157572      │
# │ 12  │ 4924     │ -0.2    │ 0.0       │ -0.251504      │
# │ 13  │ 4932     │ 0.2     │ 0.275437  │ 0.199933       │
# │ 14  │ 4937     │ 0.2     │ 0.0       │ 0.263374       │
# │ 15  │ 4938     │ -0.2    │ 0.0       │ -0.217879      │
#
#
# running 89 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped  │ variable_group │
# │     │ Int64    │ Float64 │ Float64    │ Float64        │
# ├─────┼──────────┼─────────┼────────────┼────────────────┤
# │ 1   │ 563      │ 0.2     │ 0.184366   │ 0.182698       │
# │ 2   │ 1863     │ -0.2    │ -0.194605  │ 0.0            │
# │ 3   │ 1867     │ 0.2     │ 0.212575   │ 0.157763       │
# │ 4   │ 4082     │ -0.2    │ -0.222187  │ -0.166005      │
# │ 5   │ 4087     │ 0.2     │ 0.198833   │ 0.164466       │
# │ 6   │ 4095     │ 0.2     │ 0.170293   │ 0.0            │
# │ 7   │ 7706     │ 0.2     │ 0.201337   │ 0.196385       │
# │ 8   │ 7708     │ -0.2    │ -0.204296  │ -0.195613      │
# │ 9   │ 7716     │ -0.2    │ -0.158633  │ -0.161         │
# │ 10  │ 7718     │ -0.2    │ -0.224619  │ -0.209367      │
# │ 11  │ 7964     │ -0.2    │ 0.0        │ 0.0            │
# │ 12  │ 7965     │ 0.2     │ 0.0        │ 0.111138       │
# │ 13  │ 7974     │ -0.2    │ -0.259123  │ -0.352716      │
# │ 14  │ 7975     │ -0.2    │ -0.0969648 │ -0.0262187     │
# │ 15  │ 7976     │ -0.2    │ -0.118086  │ -0.141208      │
#
#
# running 90 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 2308     │ 0.2     │ 0.170674  │ 0.17434        │
# │ 2   │ 3091     │ -0.2    │ -0.247671 │ -0.226357      │
# │ 3   │ 3095     │ -0.2    │ 0.0       │ -0.151801      │
# │ 4   │ 4841     │ 0.2     │ 0.206206  │ 0.199231       │
# │ 5   │ 4849     │ -0.2    │ -0.187945 │ -0.185937      │
# │ 6   │ 4852     │ 0.2     │ 0.203725  │ 0.20361        │
# │ 7   │ 6268     │ -0.2    │ -0.162908 │ -0.176144      │
# │ 8   │ 6272     │ 0.2     │ 0.103644  │ 0.122252       │
# │ 9   │ 6273     │ 0.2     │ 0.31601   │ 0.303555       │
# │ 10  │ 6274     │ -0.2    │ -0.226961 │ -0.216392      │
# │ 11  │ 7285     │ 0.2     │ 0.0       │ 0.152064       │
# │ 12  │ 7287     │ 0.2     │ 0.255624  │ 0.153064       │
# │ 13  │ 7288     │ 0.2     │ 0.0       │ 0.11772        │
# │ 14  │ 7293     │ -0.2    │ -0.252811 │ -0.223857      │
# │ 15  │ 7297     │ 0.2     │ 0.0       │ 0.0            │
#
#
# running 91 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 795      │ -0.2    │ -0.141711 │ -0.141006      │
# │ 2   │ 1026     │ 0.2     │ 0.197678  │ 0.195268       │
# │ 3   │ 1038     │ -0.2    │ -0.19824  │ -0.203653      │
# │ 4   │ 4187     │ 0.2     │ 0.164613  │ 0.165472       │
# │ 5   │ 4188     │ 0.2     │ 0.236201  │ 0.24151        │
# │ 6   │ 4195     │ 0.2     │ 0.199097  │ 0.205887       │
# │ 7   │ 4863     │ -0.2    │ -0.214881 │ -0.21736       │
# │ 8   │ 4871     │ -0.2    │ -0.199857 │ -0.204986      │
# │ 9   │ 4872     │ -0.2    │ -0.204108 │ -0.191688      │
# │ 10  │ 4874     │ 0.2     │ 0.238762  │ 0.234931       │
# │ 11  │ 6048     │ 0.2     │ 0.288694  │ 0.18634        │
# │ 12  │ 6049     │ -0.2    │ -0.190523 │ 0.0            │
# │ 13  │ 6051     │ -0.2    │ -0.181603 │ -0.180553      │
# │ 14  │ 6053     │ -0.2    │ -0.223204 │ -0.207832      │
# │ 15  │ 6058     │ 0.2     │ 0.264255  │ 0.207226       │
#
#
# running 92 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 1562     │ 0.2     │ 0.251338  │ 0.250985       │
# │ 2   │ 4409     │ -0.2    │ -0.220593 │ -0.21175       │
# │ 3   │ 4410     │ -0.2    │ -0.133679 │ -0.148085      │
# │ 4   │ 6961     │ -0.2    │ -0.196602 │ -0.185148      │
# │ 5   │ 6974     │ -0.2    │ -0.225955 │ -0.220767      │
# │ 6   │ 6978     │ 0.2     │ 0.231027  │ 0.22316        │
# │ 7   │ 7201     │ -0.2    │ 0.0       │ 0.0            │
# │ 8   │ 7205     │ 0.2     │ 0.0       │ 0.0            │
# │ 9   │ 7211     │ -0.2    │ 0.0       │ 0.0            │
# │ 10  │ 7213     │ -0.2    │ -0.192747 │ -0.155611      │
# │ 11  │ 7672     │ -0.2    │ -0.244657 │ -0.282963      │
# │ 12  │ 7674     │ 0.2     │ 0.185379  │ 0.0836002      │
# │ 13  │ 7676     │ 0.2     │ 0.218554  │ 0.211041       │
# │ 14  │ 7679     │ 0.2     │ 0.0       │ 0.0            │
# │ 15  │ 7680     │ -0.2    │ 0.0       │ 0.0            │
#
#
# running 93 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 1058     │ -0.2    │ -0.222185 │ -0.217487      │
# │ 2   │ 4789     │ -0.2    │ -0.228142 │ -0.228788      │
# │ 3   │ 4797     │ -0.2    │ -0.205777 │ -0.199265      │
# │ 4   │ 4822     │ -0.2    │ 0.0       │ -0.113375      │
# │ 5   │ 4828     │ 0.2     │ 0.1486    │ 0.176284       │
# │ 6   │ 4835     │ 0.2     │ 0.212812  │ 0.19598        │
# │ 7   │ 6021     │ -0.2    │ -0.245936 │ -0.25234       │
# │ 8   │ 6022     │ -0.2    │ -0.180437 │ -0.187605      │
# │ 9   │ 6032     │ 0.2     │ 0.272397  │ 0.272523       │
# │ 10  │ 6038     │ 0.2     │ 0.169208  │ 0.172439       │
# │ 11  │ 6501     │ -0.2    │ -0.165609 │ -0.172418      │
# │ 12  │ 6503     │ 0.2     │ 0.211196  │ 0.20515        │
# │ 13  │ 6506     │ 0.2     │ 0.20477   │ 0.2031         │
# │ 14  │ 6511     │ 0.2     │ 0.238573  │ 0.242887       │
# │ 15  │ 6516     │ -0.2    │ -0.205529 │ -0.201125      │
#
#
# running 94 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 2371     │ 0.2     │ 0.171748  │ 0.179374       │
# │ 2   │ 3945     │ -0.2    │ 0.0       │ 0.0            │
# │ 3   │ 3958     │ 0.2     │ 0.0       │ 0.0            │
# │ 4   │ 5443     │ -0.2    │ -0.150407 │ 0.0            │
# │ 5   │ 5451     │ 0.2     │ 0.198343  │ 0.17187        │
# │ 6   │ 5456     │ 0.2     │ 0.212728  │ 0.175944       │
# │ 7   │ 9582     │ 0.2     │ 0.0       │ 0.0            │
# │ 8   │ 9583     │ -0.2    │ -0.202043 │ -0.171448      │
# │ 9   │ 9587     │ -0.2    │ 0.0       │ -0.112652      │
# │ 10  │ 9598     │ 0.2     │ 0.0       │ 0.122047       │
# │ 11  │ 9802     │ -0.2    │ -0.16183  │ -0.20317       │
# │ 12  │ 9805     │ -0.2    │ -0.190402 │ -0.140901      │
# │ 13  │ 9807     │ 0.2     │ 0.240027  │ 0.163221       │
# │ 14  │ 9817     │ 0.2     │ 0.184983  │ 0.0            │
# │ 15  │ 9819     │ 0.2     │ 0.224439  │ 0.263343       │
#
#
# running 95 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 3064     │ -0.2    │ -0.20325  │ -0.199744      │
# │ 2   │ 4890     │ -0.2    │ 0.0       │ 0.0            │
# │ 3   │ 4896     │ 0.2     │ 0.148314  │ 0.146367       │
# │ 4   │ 7623     │ 0.2     │ 0.210427  │ 0.198536       │
# │ 5   │ 7632     │ 0.2     │ 0.157179  │ 0.0            │
# │ 6   │ 7638     │ 0.2     │ 0.0       │ 0.136071       │
# │ 7   │ 7942     │ -0.2    │ -0.179078 │ -0.165135      │
# │ 8   │ 7943     │ -0.2    │ -0.226158 │ -0.229124      │
# │ 9   │ 7957     │ -0.2    │ -0.159502 │ -0.168864      │
# │ 10  │ 7960     │ 0.2     │ 0.163521  │ 0.162663       │
# │ 11  │ 8225     │ 0.2     │ 0.227405  │ 0.233406       │
# │ 12  │ 8226     │ 0.2     │ 0.255928  │ 0.253036       │
# │ 13  │ 8231     │ -0.2    │ -0.223149 │ -0.21988       │
# │ 14  │ 8236     │ 0.2     │ 0.163095  │ 0.162213       │
# │ 15  │ 8238     │ 0.2     │ 0.23391   │ 0.232789       │
#
#
# running 96 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 2109     │ 0.2     │ 0.172223  │ 0.184012       │
# │ 2   │ 2210     │ -0.2    │ 0.0       │ 0.0            │
# │ 3   │ 2214     │ 0.2     │ 0.0       │ 0.131139       │
# │ 4   │ 8991     │ 0.2     │ 0.207836  │ 0.205755       │
# │ 5   │ 8992     │ 0.2     │ 0.173939  │ 0.180449       │
# │ 6   │ 8994     │ 0.2     │ 0.17994   │ 0.166124       │
# │ 7   │ 9284     │ 0.2     │ 0.151873  │ 0.153995       │
# │ 8   │ 9290     │ -0.2    │ -0.228408 │ -0.228334      │
# │ 9   │ 9292     │ 0.2     │ 0.209124  │ 0.2002         │
# │ 10  │ 9295     │ 0.2     │ 0.202943  │ 0.211235       │
# │ 11  │ 9709     │ 0.2     │ 0.144959  │ 0.14373        │
# │ 12  │ 9711     │ 0.2     │ 0.189641  │ 0.189256       │
# │ 13  │ 9716     │ 0.2     │ 0.186099  │ 0.195782       │
# │ 14  │ 9718     │ -0.2    │ -0.177587 │ -0.184619      │
# │ 15  │ 9720     │ -0.2    │ -0.218734 │ -0.217883      │
#
#
# running 97 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 4987     │ 0.2     │ 0.212971  │ 0.218952       │
# │ 2   │ 6421     │ -0.2    │ -0.200372 │ -0.201993      │
# │ 3   │ 6440     │ 0.2     │ 0.214484  │ 0.213438       │
# │ 4   │ 7822     │ -0.2    │ -0.123694 │ -0.129541      │
# │ 5   │ 7829     │ 0.2     │ 0.0       │ 0.0            │
# │ 6   │ 7840     │ -0.2    │ 0.0       │ -0.134701      │
# │ 7   │ 9741     │ 0.2     │ 0.132316  │ 0.0            │
# │ 8   │ 9749     │ 0.2     │ 0.172906  │ 0.166497       │
# │ 9   │ 9756     │ 0.2     │ 0.252227  │ 0.185546       │
# │ 10  │ 9758     │ -0.2    │ -0.241129 │ -0.223388      │
# │ 11  │ 9982     │ -0.2    │ 0.0       │ -0.160522      │
# │ 12  │ 9984     │ -0.2    │ 0.0       │ -0.165092      │
# │ 13  │ 9988     │ -0.2    │ 0.0       │ -0.1747        │
# │ 14  │ 9996     │ 0.2     │ 0.266797  │ 0.222153       │
# │ 15  │ 10000    │ -0.2    │ 0.0       │ -0.144375      │
#
#
# running 98 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 985      │ -0.2    │ -0.166704 │ -0.186738      │
# │ 2   │ 3863     │ -0.2    │ -0.184619 │ -0.188535      │
# │ 3   │ 3875     │ 0.2     │ 0.136581  │ 0.120101       │
# │ 4   │ 5421     │ 0.2     │ 0.131786  │ 0.0            │
# │ 5   │ 5424     │ 0.2     │ 0.112264  │ 0.142306       │
# │ 6   │ 5425     │ 0.2     │ 0.17247   │ 0.18833        │
# │ 7   │ 5607     │ -0.2    │ -0.138189 │ -0.17178       │
# │ 8   │ 5609     │ 0.2     │ 0.181516  │ 0.190334       │
# │ 9   │ 5614     │ -0.2    │ 0.0       │ 0.0            │
# │ 10  │ 5617     │ 0.2     │ 0.0       │ 0.0            │
# │ 11  │ 9045     │ 0.2     │ 0.183872  │ 0.181843       │
# │ 12  │ 9048     │ -0.2    │ 0.0       │ -0.0622715     │
# │ 13  │ 9051     │ 0.2     │ 0.0       │ 0.0            │
# │ 14  │ 9058     │ -0.2    │ 0.0       │ 0.0            │
# │ 15  │ 9060     │ 0.2     │ 0.0       │ 0.12259        │
#
#
# running 99 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 906      │ 0.2     │ 0.221945  │ 0.222302       │
# │ 2   │ 2122     │ 0.2     │ 0.182802  │ 0.18379        │
# │ 3   │ 2125     │ 0.2     │ 0.171831  │ 0.165874       │
# │ 4   │ 4364     │ -0.2    │ -0.182732 │ -0.168331      │
# │ 5   │ 4365     │ -0.2    │ -0.140353 │ -0.152639      │
# │ 6   │ 4366     │ -0.2    │ -0.239182 │ -0.228328      │
# │ 7   │ 5701     │ -0.2    │ -0.230939 │ -0.201738      │
# │ 8   │ 5703     │ -0.2    │ -0.284867 │ -0.281455      │
# │ 9   │ 5712     │ -0.2    │ 0.0       │ -0.14535       │
# │ 10  │ 5719     │ -0.2    │ -0.124531 │ -0.186784      │
# │ 11  │ 9683     │ -0.2    │ -0.221039 │ -0.233601      │
# │ 12  │ 9690     │ 0.2     │ 0.0       │ 0.0            │
# │ 13  │ 9691     │ -0.2    │ 0.0       │ -0.15798       │
# │ 14  │ 9695     │ -0.2    │ -0.32253  │ -0.313183      │
# │ 15  │ 9698     │ 0.2     │ 0.0       │ 0.0            │
#
#
# running 100 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 2612     │ 0.2     │ 0.13851   │ 0.160209       │
# │ 2   │ 6885     │ -0.2    │ -0.264988 │ -0.258252      │
# │ 3   │ 6900     │ -0.2    │ -0.246894 │ -0.254653      │
# │ 4   │ 8121     │ 0.2     │ 0.140129  │ 0.127946       │
# │ 5   │ 8135     │ -0.2    │ -0.144087 │ -0.142079      │
# │ 6   │ 8136     │ -0.2    │ -0.245802 │ -0.261505      │
# │ 7   │ 8511     │ 0.2     │ 0.200939  │ 0.269649       │
# │ 8   │ 8513     │ -0.2    │ 0.0       │ -0.203076      │
# │ 9   │ 8515     │ 0.2     │ 0.0       │ 0.126797       │
# │ 10  │ 8520     │ 0.2     │ 0.202334  │ 0.160271       │
# │ 11  │ 9422     │ 0.2     │ 0.25896   │ 0.248545       │
# │ 12  │ 9425     │ -0.2    │ -0.221812 │ -0.216768      │
# │ 13  │ 9429     │ -0.2    │ -0.166747 │ -0.180033      │
# │ 14  │ 9436     │ -0.2    │ -0.254762 │ -0.254598      │
# │ 15  │ 9437     │ -0.2    │ -0.13477  │ -0.143259      │
#
#
# 141.545961 seconds (6.97 M allocations: 11.068 GiB, 16.53% gc time)

# %%
@show mean(ungroup_true_positives)
@show mean(ungroup_false_positives)
@show mean(variable_true_positives)
@show mean(variable_false_positives)

@show std(ungroup_true_positives)
@show std(ungroup_false_positives)
@show std(variable_true_positives)
@show std(variable_false_positives)
# Out:
# mean(ungroup_true_positives) = 11.12
# mean(ungroup_false_positives) = 3.88
# mean(variable_true_positives) = 12.21
# mean(variable_false_positives) = 2.79
# std(ungroup_true_positives) = 1.9346912681433965
# std(ungroup_false_positives) = 1.9346912681433965
# std(variable_true_positives) = 1.9709762745267823
# std(variable_false_positives) = 1.9709762745267825
# 1.9709762745267825

# %% [markdown]
# ## Logistic

# %%
Random.seed!(2019)

d = Bernoulli
l = canonicallink(d())

num_runs = 100
ungroup_true_positives = zeros(num_runs)
ungroup_false_positives = zeros(num_runs)
variable_true_positives = zeros(num_runs)
variable_false_positives = zeros(num_runs)

@time for i in 1:num_runs
    println("running $i th model")
    utp, ufp, vtp, vfp = compare(d, l)
    ungroup_true_positives[i] = utp
    ungroup_false_positives[i] = ufp
    variable_true_positives[i] = vtp
    variable_false_positives[i] = vfp
end
# Out:
# running 1 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 3464     │ -0.2    │ 0.0       │ 0.0            │
# │ 2   │ 4927     │ 0.2     │ 0.284375  │ 0.214257       │
# │ 3   │ 4938     │ -0.2    │ 0.0       │ 0.0            │
# │ 4   │ 5001     │ -0.2    │ 0.0       │ -0.242449      │
# │ 5   │ 5011     │ -0.2    │ 0.0       │ -0.221208      │
# │ 6   │ 5018     │ -0.2    │ 0.0       │ 0.0            │
# │ 7   │ 5084     │ -0.2    │ 0.0       │ 0.0            │
# │ 8   │ 5090     │ 0.2     │ 0.249169  │ 0.215036       │
# │ 9   │ 5098     │ -0.2    │ 0.0       │ 0.0            │
# │ 10  │ 5100     │ -0.2    │ 0.0       │ -0.187706      │
# │ 11  │ 7004     │ 0.2     │ 0.0       │ 0.0            │
# │ 12  │ 7011     │ 0.2     │ 0.0       │ 0.0            │
# │ 13  │ 7015     │ -0.2    │ 0.0       │ 0.0            │
# │ 14  │ 7016     │ 0.2     │ 0.0       │ 0.0            │
# │ 15  │ 7020     │ 0.2     │ 0.512723  │ 0.398438       │
#
#
# running 2 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 149      │ 0.2     │ 0.0       │ 0.0            │
# │ 2   │ 4292     │ 0.2     │ 0.452738  │ 0.443885       │
# │ 3   │ 4293     │ -0.2    │ 0.0       │ -0.172176      │
# │ 4   │ 4985     │ -0.2    │ -0.287669 │ -0.188129      │
# │ 5   │ 4995     │ 0.2     │ 0.0       │ 0.0            │
# │ 6   │ 4999     │ 0.2     │ 0.0       │ 0.0            │
# │ 7   │ 8462     │ 0.2     │ 0.0       │ 0.0            │
# │ 8   │ 8463     │ -0.2    │ 0.0       │ 0.0            │
# │ 9   │ 8477     │ -0.2    │ 0.0       │ 0.0            │
# │ 10  │ 8479     │ -0.2    │ 0.0       │ 0.0            │
# │ 11  │ 9448     │ -0.2    │ 0.0       │ 0.0            │
# │ 12  │ 9450     │ 0.2     │ 0.0       │ 0.0            │
# │ 13  │ 9452     │ 0.2     │ 0.27902   │ 0.356357       │
# │ 14  │ 9453     │ 0.2     │ 0.0       │ 0.0            │
# │ 15  │ 9454     │ -0.2    │ 0.0       │ -0.272049      │
#
#
# running 3 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 677      │ 0.2     │ 0.337243  │ 0.309204       │
# │ 2   │ 1265     │ 0.2     │ 0.331259  │ 0.281982       │
# │ 3   │ 1279     │ -0.2    │ 0.0       │ -0.169719      │
# │ 4   │ 4171     │ 0.2     │ 0.0       │ 0.156973       │
# │ 5   │ 4173     │ -0.2    │ -0.297111 │ -0.283452      │
# │ 6   │ 4176     │ 0.2     │ 0.0       │ 0.261164       │
# │ 7   │ 5408     │ -0.2    │ 0.0       │ -0.163018      │
# │ 8   │ 5413     │ 0.2     │ 0.315919  │ 0.34582        │
# │ 9   │ 5416     │ -0.2    │ 0.0       │ -0.233261      │
# │ 10  │ 5419     │ 0.2     │ 0.0       │ 0.191907       │
# │ 11  │ 5481     │ 0.2     │ 0.0       │ 0.0870643      │
# │ 12  │ 5484     │ 0.2     │ 0.0       │ 0.169178       │
# │ 13  │ 5488     │ 0.2     │ 0.391234  │ 0.213139       │
# │ 14  │ 5493     │ 0.2     │ 0.0       │ 0.0            │
# │ 15  │ 5499     │ 0.2     │ 0.0       │ 0.0            │
#
#
# running 4 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 43       │ 0.2     │ 0.0       │ 0.0            │
# │ 2   │ 174      │ -0.2    │ 0.0       │ -0.35518       │
# │ 3   │ 176      │ 0.2     │ 0.0       │ 0.2162         │
# │ 4   │ 782      │ -0.2    │ 0.0       │ -0.147661      │
# │ 5   │ 790      │ -0.2    │ 0.0       │ -0.125643      │
# │ 6   │ 796      │ -0.2    │ 0.0       │ 0.0            │
# │ 7   │ 4326     │ -0.2    │ 0.0       │ 0.0            │
# │ 8   │ 4328     │ -0.2    │ 0.0       │ 0.0            │
# │ 9   │ 4334     │ 0.2     │ 0.0       │ 0.0            │
# │ 10  │ 4335     │ -0.2    │ 0.0       │ 0.0            │
# │ 11  │ 7366     │ -0.2    │ -0.353376 │ -0.167998      │
# │ 12  │ 7367     │ -0.2    │ 0.0       │ -0.150929      │
# │ 13  │ 7372     │ -0.2    │ 0.0       │ -0.104518      │
# │ 14  │ 7376     │ 0.2     │ 0.0       │ 0.0            │
# │ 15  │ 7378     │ -0.2    │ 0.0       │ -0.169772      │
#
#
# running 5 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 2545     │ -0.2    │ 0.0       │ 0.0            │
# │ 2   │ 2850     │ -0.2    │ 0.0       │ -0.171834      │
# │ 3   │ 2852     │ -0.2    │ -0.359581 │ 0.0            │
# │ 4   │ 3884     │ 0.2     │ 0.0       │ 0.0            │
# │ 5   │ 3885     │ 0.2     │ 0.0       │ 0.0            │
# │ 6   │ 3895     │ -0.2    │ 0.0       │ 0.0            │
# │ 7   │ 3983     │ 0.2     │ 0.0       │ 0.0            │
# │ 8   │ 3986     │ 0.2     │ 0.0       │ 0.0            │
# │ 9   │ 3990     │ -0.2    │ 0.0       │ -0.230547      │
# │ 10  │ 3991     │ 0.2     │ 0.210446  │ 0.300148       │
# │ 11  │ 5182     │ 0.2     │ 0.365713  │ 0.329092       │
# │ 12  │ 5185     │ 0.2     │ 0.0       │ 0.0            │
# │ 13  │ 5187     │ 0.2     │ 0.0       │ -0.1724        │
# │ 14  │ 5188     │ 0.2     │ 0.0       │ 0.0            │
# │ 15  │ 5198     │ -0.2    │ 0.0       │ 0.0            │
#
#
# running 6 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 4633     │ -0.2    │ 0.0       │ 0.0            │
# │ 2   │ 6729     │ 0.2     │ 0.0       │ 0.0            │
# │ 3   │ 6731     │ 0.2     │ 0.0       │ 0.0            │
# │ 4   │ 7884     │ 0.2     │ 0.0       │ 0.277062       │
# │ 5   │ 7889     │ 0.2     │ 0.280093  │ 0.255713       │
# │ 6   │ 7890     │ 0.2     │ 0.280093  │ 0.255713       │
# │ 7   │ 8410     │ 0.2     │ 0.0       │ 0.267358       │
# │ 8   │ 8418     │ -0.2    │ -0.36898  │ -0.178904      │
# │ 9   │ 8419     │ -0.2    │ -0.450222 │ -0.450877      │
# │ 10  │ 8420     │ -0.2    │ 0.0       │ -0.251891      │
# │ 11  │ 9527     │ -0.2    │ 0.0       │ 0.0            │
# │ 12  │ 9531     │ -0.2    │ 0.0       │ 0.0            │
# │ 13  │ 9536     │ -0.2    │ -0.40694  │ -0.245308      │
# │ 14  │ 9538     │ 0.2     │ 0.0       │ 0.327482       │
# │ 15  │ 9540     │ -0.2    │ 0.0       │ -0.242581      │
#
#
# running 7 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 3843     │ 0.2     │ 0.276723  │ 0.0            │
# │ 2   │ 5264     │ -0.2    │ 0.0       │ 0.0            │
# │ 3   │ 5271     │ 0.2     │ 0.0       │ 0.0            │
# │ 4   │ 5821     │ -0.2    │ 0.0       │ 0.0            │
# │ 5   │ 5823     │ 0.2     │ 0.0       │ 0.0            │
# │ 6   │ 5832     │ -0.2    │ 0.0       │ 0.0            │
# │ 7   │ 7947     │ 0.2     │ 0.0       │ 0.109612       │
# │ 8   │ 7958     │ 0.2     │ 0.0       │ 0.0            │
# │ 9   │ 7959     │ -0.2    │ -0.349228 │ -0.236084      │
# │ 10  │ 7960     │ -0.2    │ 0.0       │ -0.148374      │
# │ 11  │ 9526     │ 0.2     │ 0.0       │ 0.0            │
# │ 12  │ 9531     │ -0.2    │ 0.0       │ 0.0            │
# │ 13  │ 9536     │ -0.2    │ -0.49524  │ -0.122498      │
# │ 14  │ 9538     │ -0.2    │ 0.0       │ 0.0            │
# │ 15  │ 9540     │ -0.2    │ 0.0       │ 0.0            │
#
#
# running 8 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 2898     │ -0.2    │ 0.0       │ 0.0            │
# │ 2   │ 3741     │ 0.2     │ 0.0       │ 0.0            │
# │ 3   │ 3760     │ -0.2    │ 0.0       │ 0.0            │
# │ 4   │ 3949     │ 0.2     │ 0.0       │ 0.204483       │
# │ 5   │ 3955     │ 0.2     │ 0.0       │ 0.0            │
# │ 6   │ 3959     │ -0.2    │ -0.311637 │ -0.243838      │
# │ 7   │ 5305     │ -0.2    │ 0.0       │ 0.0            │
# │ 8   │ 5308     │ -0.2    │ 0.0       │ 0.0            │
# │ 9   │ 5311     │ -0.2    │ 0.0       │ -0.303642      │
# │ 10  │ 5317     │ 0.2     │ 0.0       │ 0.0            │
# │ 11  │ 6610     │ 0.2     │ 0.0       │ 0.0            │
# │ 12  │ 6611     │ 0.2     │ 0.0       │ 0.0888038      │
# │ 13  │ 6616     │ 0.2     │ 0.350542  │ 0.326235       │
# │ 14  │ 6617     │ 0.2     │ 0.0       │ 0.0            │
# │ 15  │ 6618     │ -0.2    │ 0.0       │ -0.121114      │
#
#
# running 9 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 1123     │ 0.2     │ 0.0       │ 0.0            │
# │ 2   │ 3306     │ 0.2     │ 0.0       │ 0.0            │
# │ 3   │ 3319     │ 0.2     │ 0.0       │ 0.0            │
# │ 4   │ 4282     │ -0.2    │ 0.0       │ -0.282535      │
# │ 5   │ 4283     │ 0.2     │ 0.0       │ 0.0            │
# │ 6   │ 4291     │ -0.2    │ 0.0       │ 0.0            │
# │ 7   │ 5442     │ 0.2     │ 0.0       │ 0.0997672      │
# │ 8   │ 5444     │ 0.2     │ 0.510188  │ 0.266613       │
# │ 9   │ 5456     │ -0.2    │ 0.0       │ -0.201483      │
# │ 10  │ 5460     │ 0.2     │ 0.0       │ 0.0            │
# │ 11  │ 8203     │ -0.2    │ 0.0       │ 0.0            │
# │ 12  │ 8204     │ -0.2    │ -0.581546 │ -0.431661      │
# │ 13  │ 8209     │ -0.2    │ 0.0       │ 0.0            │
# │ 14  │ 8212     │ 0.2     │ 0.0       │ 0.0            │
# │ 15  │ 8218     │ 0.2     │ 0.0       │ 0.0            │
#
#
# running 10 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 239      │ -0.2    │ -0.223992 │ 0.0            │
# │ 2   │ 2530     │ 0.2     │ 0.0       │ 0.0            │
# │ 3   │ 2537     │ -0.2    │ 0.0       │ 0.0            │
# │ 4   │ 5026     │ -0.2    │ -0.242384 │ -0.225443      │
# │ 5   │ 5030     │ 0.2     │ 0.0       │ 0.0            │
# │ 6   │ 5031     │ -0.2    │ 0.0       │ 0.0            │
# │ 7   │ 8962     │ 0.2     │ 0.0       │ 0.0            │
# │ 8   │ 8972     │ -0.2    │ 0.0       │ 0.0            │
# │ 9   │ 8975     │ -0.2    │ 0.0       │ -0.191453      │
# │ 10  │ 8979     │ -0.2    │ -0.269074 │ -0.265572      │
# │ 11  │ 9683     │ 0.2     │ 0.253879  │ 0.377868       │
# │ 12  │ 9691     │ -0.2    │ 0.0       │ -0.175235      │
# │ 13  │ 9694     │ 0.2     │ 0.0       │ 0.0            │
# │ 14  │ 9696     │ -0.2    │ 0.0       │ -0.335293      │
# │ 15  │ 9700     │ -0.2    │ 0.0       │ 0.0            │
#
#
# running 11 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 991      │ 0.2     │ 0.331075  │ 0.326064       │
# │ 2   │ 1045     │ -0.2    │ 0.0       │ 0.0            │
# │ 3   │ 1055     │ 0.2     │ 0.0       │ 0.0            │
# │ 4   │ 2123     │ -0.2    │ 0.0       │ -0.367997      │
# │ 5   │ 2135     │ 0.2     │ 0.27316   │ 0.166808       │
# │ 6   │ 2138     │ 0.2     │ 0.0       │ 0.399272       │
# │ 7   │ 6043     │ -0.2    │ 0.0       │ 0.0            │
# │ 8   │ 6048     │ 0.2     │ 0.0       │ 0.0            │
# │ 9   │ 6050     │ -0.2    │ 0.0       │ 0.0            │
# │ 10  │ 6059     │ -0.2    │ -0.239213 │ -0.235755      │
# │ 11  │ 9344     │ 0.2     │ 0.0       │ 0.363377       │
# │ 12  │ 9345     │ -0.2    │ 0.0       │ 0.0            │
# │ 13  │ 9350     │ 0.2     │ 0.0       │ 0.0            │
# │ 14  │ 9353     │ 0.2     │ 0.0       │ 0.167204       │
# │ 15  │ 9357     │ 0.2     │ 0.0       │ 0.254751       │
#
#
# running 12 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 1992     │ 0.2     │ 0.0       │ 0.0            │
# │ 2   │ 2602     │ 0.2     │ 0.0       │ 0.0            │
# │ 3   │ 2617     │ -0.2    │ 0.0       │ 0.0            │
# │ 4   │ 3461     │ 0.2     │ 0.0       │ 0.0            │
# │ 5   │ 3462     │ -0.2    │ 0.0       │ 0.0            │
# │ 6   │ 3470     │ -0.2    │ -0.345038 │ -0.227396      │
# │ 7   │ 3884     │ -0.2    │ 0.0       │ 0.0            │
# │ 8   │ 3891     │ 0.2     │ 0.435199  │ 0.327546       │
# │ 9   │ 3897     │ -0.2    │ 0.0       │ 0.0            │
# │ 10  │ 3898     │ -0.2    │ 0.0       │ -0.188756      │
# │ 11  │ 4103     │ 0.2     │ 0.280236  │ 0.170465       │
# │ 12  │ 4104     │ 0.2     │ 0.266294  │ 0.3675         │
# │ 13  │ 4110     │ 0.2     │ 0.0       │ 0.0            │
# │ 14  │ 4115     │ -0.2    │ -0.235771 │ -0.319289      │
# │ 15  │ 4119     │ 0.2     │ 0.0       │ 0.225959       │
#
#
# running 13 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 4669     │ -0.2    │ -0.414545 │ -0.351354      │
# │ 2   │ 5364     │ -0.2    │ 0.0       │ -0.226208      │
# │ 3   │ 5374     │ -0.2    │ -0.332067 │ -0.286376      │
# │ 4   │ 8082     │ 0.2     │ 0.0       │ 0.204228       │
# │ 5   │ 8083     │ 0.2     │ 0.368408  │ 0.242076       │
# │ 6   │ 8089     │ -0.2    │ -0.309071 │ -0.296563      │
# │ 7   │ 8163     │ 0.2     │ 0.0       │ 0.0            │
# │ 8   │ 8166     │ 0.2     │ 0.0       │ 0.0            │
# │ 9   │ 8172     │ -0.2    │ -0.335237 │ -0.227744      │
# │ 10  │ 8177     │ 0.2     │ 0.0       │ 0.181749       │
# │ 11  │ 9025     │ 0.2     │ 0.0       │ 0.136106       │
# │ 12  │ 9026     │ 0.2     │ 0.0       │ 0.24937        │
# │ 13  │ 9029     │ -0.2    │ 0.0       │ -0.233515      │
# │ 14  │ 9037     │ 0.2     │ 0.0       │ 0.0            │
# │ 15  │ 9039     │ 0.2     │ 0.0       │ 0.14247        │
#
#
# running 14 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 3337     │ 0.2     │ 0.274291  │ 0.289136       │
# │ 2   │ 3704     │ -0.2    │ -0.284059 │ -0.255996      │
# │ 3   │ 3714     │ 0.2     │ 0.237779  │ 0.21297        │
# │ 4   │ 4124     │ -0.2    │ 0.0       │ -0.184524      │
# │ 5   │ 4127     │ 0.2     │ 0.0       │ 0.0            │
# │ 6   │ 4130     │ 0.2     │ 0.0       │ 0.0            │
# │ 7   │ 8861     │ -0.2    │ 0.0       │ 0.0            │
# │ 8   │ 8866     │ -0.2    │ 0.0       │ -0.160472      │
# │ 9   │ 8877     │ 0.2     │ 0.0       │ 0.160107       │
# │ 10  │ 8879     │ 0.2     │ 0.0       │ 0.0            │
# │ 11  │ 9562     │ 0.2     │ 0.247577  │ 0.273817       │
# │ 12  │ 9564     │ 0.2     │ 0.0       │ 0.0            │
# │ 13  │ 9566     │ -0.2    │ -0.280049 │ -0.303969      │
# │ 14  │ 9568     │ 0.2     │ 0.0       │ 0.185954       │
# │ 15  │ 9570     │ 0.2     │ 0.0       │ 0.153881       │
#
#
# running 15 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 2508     │ 0.2     │ 0.0       │ 0.0            │
# │ 2   │ 5091     │ 0.2     │ 0.0       │ 0.177249       │
# │ 3   │ 5095     │ 0.2     │ 0.296964  │ 0.185129       │
# │ 4   │ 7083     │ -0.2    │ 0.0       │ -0.114777      │
# │ 5   │ 7092     │ -0.2    │ 0.0       │ 0.0            │
# │ 6   │ 7093     │ -0.2    │ -0.425438 │ -0.289817      │
# │ 7   │ 9023     │ 0.2     │ 0.0       │ 0.100095       │
# │ 8   │ 9027     │ -0.2    │ 0.0       │ 0.0            │
# │ 9   │ 9035     │ -0.2    │ 0.0       │ -0.119414      │
# │ 10  │ 9039     │ 0.2     │ 0.257887  │ 0.282196       │
# │ 11  │ 9862     │ -0.2    │ 0.0       │ 0.0            │
# │ 12  │ 9863     │ 0.2     │ 0.0       │ 0.0            │
# │ 13  │ 9868     │ 0.2     │ 0.25633   │ 0.192623       │
# │ 14  │ 9875     │ 0.2     │ 0.0       │ 0.132016       │
# │ 15  │ 9877     │ 0.2     │ 0.0       │ 0.22166        │
#
#
# running 16 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 584      │ 0.2     │ 0.0       │ 0.0            │
# │ 2   │ 2343     │ 0.2     │ 0.0       │ 0.0            │
# │ 3   │ 2348     │ -0.2    │ 0.0       │ 0.0            │
# │ 4   │ 6224     │ 0.2     │ 0.0       │ 0.0            │
# │ 5   │ 6235     │ 0.2     │ 0.0       │ 0.148303       │
# │ 6   │ 6237     │ 0.2     │ 0.0       │ 0.175407       │
# │ 7   │ 8321     │ 0.2     │ 0.0       │ 0.0            │
# │ 8   │ 8323     │ -0.2    │ 0.0       │ 0.0            │
# │ 9   │ 8328     │ -0.2    │ 0.0       │ 0.0            │
# │ 10  │ 8339     │ -0.2    │ 0.0       │ 0.0            │
# │ 11  │ 9161     │ -0.2    │ 0.0       │ 0.0            │
# │ 12  │ 9166     │ 0.2     │ 0.318817  │ 0.295738       │
# │ 13  │ 9171     │ 0.2     │ 0.0       │ 0.0            │
# │ 14  │ 9174     │ -0.2    │ 0.0       │ -0.245707      │
# │ 15  │ 9176     │ 0.2     │ 0.0       │ 0.0            │
#
#
# running 17 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 3072     │ -0.2    │ -0.297073 │ -0.314489      │
# │ 2   │ 6031     │ 0.2     │ 0.0       │ 0.336009       │
# │ 3   │ 6032     │ 0.2     │ 0.320806  │ 0.0            │
# │ 4   │ 7115     │ 0.2     │ 0.0       │ 0.144578       │
# │ 5   │ 7116     │ -0.2    │ 0.0       │ 0.0            │
# │ 6   │ 7119     │ -0.2    │ 0.0       │ 0.0            │
# │ 7   │ 7241     │ 0.2     │ 0.0       │ 0.0            │
# │ 8   │ 7243     │ -0.2    │ -0.247552 │ -0.219173      │
# │ 9   │ 7246     │ -0.2    │ 0.0       │ -0.264662      │
# │ 10  │ 7257     │ -0.2    │ 0.0       │ -0.261575      │
# │ 11  │ 8321     │ -0.2    │ 0.0       │ 0.0            │
# │ 12  │ 8326     │ -0.2    │ 0.0       │ 0.0            │
# │ 13  │ 8328     │ 0.2     │ 0.0       │ 0.0            │
# │ 14  │ 8335     │ -0.2    │ 0.0       │ 0.0            │
# │ 15  │ 8336     │ 0.2     │ 0.0       │ 0.0            │
#
#
# running 18 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 288      │ 0.2     │ 0.258249  │ 0.0            │
# │ 2   │ 2627     │ -0.2    │ -0.335284 │ -0.216129      │
# │ 3   │ 2640     │ 0.2     │ 0.0       │ 0.0            │
# │ 4   │ 2782     │ 0.2     │ 0.378772  │ 0.315119       │
# │ 5   │ 2790     │ 0.2     │ 0.0       │ 0.0            │
# │ 6   │ 2792     │ 0.2     │ 0.40348   │ 0.328944       │
# │ 7   │ 5321     │ -0.2    │ -0.413289 │ -0.244208      │
# │ 8   │ 5327     │ -0.2    │ 0.0       │ -0.274218      │
# │ 9   │ 5335     │ -0.2    │ 0.0       │ 0.0            │
# │ 10  │ 5336     │ 0.2     │ 0.0       │ 0.0            │
# │ 11  │ 8601     │ -0.2    │ 0.0       │ -0.203875      │
# │ 12  │ 8607     │ 0.2     │ 0.0       │ 0.0            │
# │ 13  │ 8609     │ 0.2     │ 0.333027  │ 0.235237       │
# │ 14  │ 8615     │ -0.2    │ 0.0       │ 0.0            │
# │ 15  │ 8619     │ -0.2    │ -0.366953 │ -0.41361       │
#
#
# running 19 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 1385     │ -0.2    │ 0.0       │ 0.0            │
# │ 2   │ 1744     │ -0.2    │ 0.0       │ 0.0            │
# │ 3   │ 1747     │ 0.2     │ 0.0       │ 0.0            │
# │ 4   │ 1825     │ -0.2    │ 0.0       │ 0.0            │
# │ 5   │ 1827     │ -0.2    │ 0.0       │ 0.0            │
# │ 6   │ 1829     │ 0.2     │ 0.0       │ 0.18516        │
# │ 7   │ 4721     │ 0.2     │ 0.327977  │ 0.232453       │
# │ 8   │ 4725     │ 0.2     │ 0.0       │ 0.152823       │
# │ 9   │ 4727     │ -0.2    │ 0.0       │ -0.189005      │
# │ 10  │ 4736     │ -0.2    │ 0.0       │ -0.234425      │
# │ 11  │ 6621     │ -0.2    │ 0.0       │ -0.162856      │
# │ 12  │ 6627     │ 0.2     │ 0.360106  │ 0.310084       │
# │ 13  │ 6634     │ -0.2    │ 0.0       │ -0.17116       │
# │ 14  │ 6635     │ -0.2    │ -0.450933 │ -0.24941       │
# │ 15  │ 6638     │ 0.2     │ 0.453295  │ 0.318613       │
#
#
# running 20 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 448      │ -0.2    │ 0.0       │ 0.0            │
# │ 2   │ 564      │ -0.2    │ 0.0       │ 0.0            │
# │ 3   │ 573      │ 0.2     │ 0.0       │ 0.0            │
# │ 4   │ 1562     │ 0.2     │ 0.358482  │ 0.287122       │
# │ 5   │ 1569     │ 0.2     │ 0.0       │ 0.182631       │
# │ 6   │ 1576     │ -0.2    │ 0.0       │ -0.25807       │
# │ 7   │ 2124     │ 0.2     │ 0.36839   │ 0.436419       │
# │ 8   │ 2127     │ -0.2    │ 0.0       │ -0.240141      │
# │ 9   │ 2133     │ -0.2    │ 0.0       │ 0.0            │
# │ 10  │ 2134     │ 0.2     │ 0.0       │ 0.159262       │
# │ 11  │ 8546     │ 0.2     │ 0.238374  │ 0.170851       │
# │ 12  │ 8547     │ 0.2     │ 0.0       │ 0.27906        │
# │ 13  │ 8549     │ -0.2    │ 0.0       │ -0.255382      │
# │ 14  │ 8551     │ 0.2     │ 0.0       │ 0.18501        │
# │ 15  │ 8552     │ -0.2    │ -0.288348 │ -0.291057      │
#
#
# running 21 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 116      │ -0.2    │ 0.0       │ 0.0            │
# │ 2   │ 6647     │ 0.2     │ 0.0       │ 0.0            │
# │ 3   │ 6652     │ -0.2    │ 0.0       │ 0.0            │
# │ 4   │ 7281     │ 0.2     │ 0.0       │ 0.172245       │
# │ 5   │ 7284     │ -0.2    │ 0.0       │ -0.237315      │
# │ 6   │ 7290     │ 0.2     │ 0.0       │ 0.0            │
# │ 7   │ 7942     │ 0.2     │ 0.0       │ 0.168007       │
# │ 8   │ 7948     │ -0.2    │ 0.0       │ -0.224304      │
# │ 9   │ 7951     │ 0.2     │ 0.0       │ 0.0            │
# │ 10  │ 7952     │ 0.2     │ 0.443939  │ 0.427058       │
# │ 11  │ 8684     │ 0.2     │ 0.333269  │ 0.206062       │
# │ 12  │ 8685     │ 0.2     │ 0.20617   │ 0.176944       │
# │ 13  │ 8691     │ 0.2     │ 0.0       │ 0.211802       │
# │ 14  │ 8694     │ -0.2    │ 0.0       │ -0.229381      │
# │ 15  │ 8698     │ 0.2     │ 0.0       │ 0.201812       │
#
#
# running 22 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 2088     │ -0.2    │ -0.250499 │ -0.310247      │
# │ 2   │ 2604     │ 0.2     │ 0.331821  │ 0.322472       │
# │ 3   │ 2616     │ 0.2     │ 0.0       │ 0.0            │
# │ 4   │ 3747     │ -0.2    │ 0.0       │ -0.209591      │
# │ 5   │ 3753     │ -0.2    │ 0.0       │ -0.114301      │
# │ 6   │ 3754     │ -0.2    │ -0.344997 │ -0.24901       │
# │ 7   │ 4864     │ -0.2    │ -0.212351 │ -0.221087      │
# │ 8   │ 4866     │ 0.2     │ 0.0       │ 0.273411       │
# │ 9   │ 4869     │ 0.2     │ 0.246042  │ 0.283764       │
# │ 10  │ 4878     │ -0.2    │ -0.307943 │ -0.293422      │
# │ 11  │ 8383     │ 0.2     │ 0.0       │ 0.322527       │
# │ 12  │ 8389     │ 0.2     │ 0.367345  │ 0.39828        │
# │ 13  │ 8394     │ -0.2    │ 0.0       │ -0.23629       │
# │ 14  │ 8396     │ -0.2    │ 0.0       │ -0.107661      │
# │ 15  │ 8398     │ -0.2    │ 0.0       │ 0.0            │
#
#
# running 23 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 3242     │ 0.2     │ 0.0       │ 0.0            │
# │ 2   │ 3956     │ 0.2     │ 0.0       │ 0.0            │
# │ 3   │ 3960     │ -0.2    │ 0.0       │ 0.0            │
# │ 4   │ 4041     │ 0.2     │ 0.279545  │ 0.224276       │
# │ 5   │ 4049     │ 0.2     │ 0.369272  │ 0.367354       │
# │ 6   │ 4059     │ -0.2    │ -0.274966 │ -0.274615      │
# │ 7   │ 4583     │ 0.2     │ 0.0       │ 0.0            │
# │ 8   │ 4594     │ -0.2    │ -0.352745 │ -0.348621      │
# │ 9   │ 4597     │ 0.2     │ 0.0       │ 0.0            │
# │ 10  │ 4598     │ 0.2     │ 0.388396  │ 0.327001       │
# │ 11  │ 9905     │ 0.2     │ 0.0       │ 0.229073       │
# │ 12  │ 9908     │ 0.2     │ 0.0       │ 0.0            │
# │ 13  │ 9914     │ -0.2    │ 0.0       │ -0.310181      │
# │ 14  │ 9918     │ -0.2    │ -0.274382 │ -0.312376      │
# │ 15  │ 9919     │ -0.2    │ 0.0       │ 0.0            │
#
#
# running 24 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 4831     │ 0.2     │ 0.378332  │ 0.0            │
# │ 2   │ 5402     │ 0.2     │ 0.0       │ 0.0            │
# │ 3   │ 5413     │ -0.2    │ 0.0       │ 0.0            │
# │ 4   │ 6784     │ -0.2    │ 0.0       │ 0.0            │
# │ 5   │ 6790     │ 0.2     │ 0.468223  │ 0.28014        │
# │ 6   │ 6791     │ 0.2     │ 0.0       │ 0.222274       │
# │ 7   │ 7988     │ -0.2    │ 0.0       │ -0.117217      │
# │ 8   │ 7991     │ -0.2    │ -0.345868 │ -0.265405      │
# │ 9   │ 7996     │ 0.2     │ 0.0       │ 0.0            │
# │ 10  │ 7998     │ 0.2     │ 0.449858  │ 0.368659       │
# │ 11  │ 9003     │ 0.2     │ 0.0       │ 0.0            │
# │ 12  │ 9005     │ -0.2    │ 0.0       │ 0.0            │
# │ 13  │ 9013     │ -0.2    │ 0.0       │ 0.0            │
# │ 14  │ 9015     │ 0.2     │ 0.322761  │ 0.327194       │
# │ 15  │ 9018     │ 0.2     │ 0.0       │ 0.0            │
#
#
# running 25 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 1473     │ -0.2    │ -0.241485 │ -0.288336      │
# │ 2   │ 2641     │ 0.2     │ 0.0       │ 0.0            │
# │ 3   │ 2643     │ 0.2     │ 0.248946  │ 0.213378       │
# │ 4   │ 3447     │ 0.2     │ 0.0       │ 0.0            │
# │ 5   │ 3454     │ -0.2    │ 0.0       │ 0.0            │
# │ 6   │ 3460     │ 0.2     │ 0.267902  │ 0.189409       │
# │ 7   │ 4223     │ 0.2     │ 0.0       │ 0.0            │
# │ 8   │ 4234     │ -0.2    │ 0.0       │ -0.199896      │
# │ 9   │ 4237     │ -0.2    │ 0.0       │ 0.0            │
# │ 10  │ 4238     │ -0.2    │ -0.497149 │ -0.394345      │
# │ 11  │ 5562     │ -0.2    │ 0.0       │ -0.257761      │
# │ 12  │ 5563     │ -0.2    │ -0.303957 │ -0.215942      │
# │ 13  │ 5577     │ 0.2     │ 0.357627  │ 0.0            │
# │ 14  │ 5578     │ 0.2     │ 0.350198  │ 0.184308       │
# │ 15  │ 5580     │ 0.2     │ 0.0       │ 0.0            │
#
#
# running 26 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 3597     │ 0.2     │ 0.0       │ 0.0            │
# │ 2   │ 5150     │ 0.2     │ 0.0       │ 0.0            │
# │ 3   │ 5157     │ -0.2    │ 0.0       │ 0.0            │
# │ 4   │ 5542     │ 0.2     │ 0.0       │ 0.194179       │
# │ 5   │ 5549     │ 0.2     │ 0.0       │ 0.0            │
# │ 6   │ 5550     │ -0.2    │ -0.28653  │ -0.238139      │
# │ 7   │ 6801     │ 0.2     │ 0.0       │ 0.164787       │
# │ 8   │ 6802     │ 0.2     │ 0.544566  │ 0.373213       │
# │ 9   │ 6806     │ -0.2    │ 0.0       │ -0.147762      │
# │ 10  │ 6810     │ -0.2    │ -0.318618 │ -0.273959      │
# │ 11  │ 8582     │ 0.2     │ 0.0       │ 0.0            │
# │ 12  │ 8586     │ 0.2     │ 0.404959  │ 0.449527       │
# │ 13  │ 8590     │ 0.2     │ 0.0       │ 0.0            │
# │ 14  │ 8599     │ -0.2    │ -0.301306 │ -0.233779      │
# │ 15  │ 8600     │ 0.2     │ 0.0       │ 0.0            │
#
#
# running 27 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 1774     │ -0.2    │ 0.0       │ 0.0            │
# │ 2   │ 4050     │ 0.2     │ 0.0       │ 0.0            │
# │ 3   │ 4055     │ -0.2    │ 0.0       │ -0.188385      │
# │ 4   │ 7851     │ -0.2    │ 0.0       │ -0.271562      │
# │ 5   │ 7853     │ 0.2     │ 0.0       │ 0.0            │
# │ 6   │ 7856     │ 0.2     │ 0.0       │ 0.124208       │
# │ 7   │ 7873     │ 0.2     │ 0.0       │ 0.148739       │
# │ 8   │ 7874     │ -0.2    │ 0.0       │ 0.0            │
# │ 9   │ 7875     │ 0.2     │ 0.0       │ 0.0            │
# │ 10  │ 7878     │ 0.2     │ 0.0       │ 0.0            │
# │ 11  │ 8463     │ 0.2     │ 0.0       │ 0.0            │
# │ 12  │ 8469     │ -0.2    │ 0.0       │ 0.0            │
# │ 13  │ 8471     │ 0.2     │ 0.0       │ 0.23427        │
# │ 14  │ 8477     │ 0.2     │ 0.0       │ 0.0            │
# │ 15  │ 8479     │ 0.2     │ 0.0       │ 0.275805       │
#
#
# running 28 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 866      │ 0.2     │ 0.0       │ 0.0            │
# │ 2   │ 2462     │ 0.2     │ 0.0       │ 0.0            │
# │ 3   │ 2467     │ 0.2     │ 0.238317  │ 0.23123        │
# │ 4   │ 3943     │ 0.2     │ 0.0       │ 0.345734       │
# │ 5   │ 3945     │ 0.2     │ 0.0       │ 0.0            │
# │ 6   │ 3947     │ -0.2    │ 0.0       │ 0.0            │
# │ 7   │ 4325     │ -0.2    │ 0.0       │ -0.227065      │
# │ 8   │ 4330     │ 0.2     │ 0.283518  │ 0.0            │
# │ 9   │ 4331     │ 0.2     │ 0.0       │ 0.372439       │
# │ 10  │ 4333     │ -0.2    │ 0.0       │ -0.263515      │
# │ 11  │ 4942     │ 0.2     │ 0.0       │ 0.0            │
# │ 12  │ 4944     │ 0.2     │ 0.0       │ 0.0            │
# │ 13  │ 4946     │ -0.2    │ 0.0       │ -0.194853      │
# │ 14  │ 4947     │ 0.2     │ 0.0       │ 0.0            │
# │ 15  │ 4948     │ 0.2     │ 0.33936   │ 0.317734       │
#
#
# running 29 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 1844     │ 0.2     │ 0.253856  │ 0.0            │
# │ 2   │ 3621     │ 0.2     │ 0.223652  │ 0.207568       │
# │ 3   │ 3636     │ 0.2     │ 0.0       │ 0.190694       │
# │ 4   │ 7843     │ -0.2    │ 0.0       │ 0.0            │
# │ 5   │ 7847     │ 0.2     │ 0.0       │ 0.0            │
# │ 6   │ 7849     │ -0.2    │ 0.0       │ 0.0            │
# │ 7   │ 8387     │ 0.2     │ 0.0       │ 0.144333       │
# │ 8   │ 8388     │ -0.2    │ 0.0       │ 0.0            │
# │ 9   │ 8392     │ -0.2    │ -0.304571 │ -0.305156      │
# │ 10  │ 8399     │ -0.2    │ 0.0       │ -0.112354      │
# │ 11  │ 8823     │ -0.2    │ 0.0       │ 0.0            │
# │ 12  │ 8824     │ 0.2     │ 0.0       │ 0.119616       │
# │ 13  │ 8828     │ 0.2     │ 0.0       │ 0.176335       │
# │ 14  │ 8838     │ -0.2    │ 0.0       │ 0.0            │
# │ 15  │ 8839     │ 0.2     │ 0.236059  │ 0.194415       │
#
#
# running 30 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 1219     │ 0.2     │ 0.28977   │ 0.314646       │
# │ 2   │ 1627     │ -0.2    │ 0.0       │ 0.0            │
# │ 3   │ 1629     │ 0.2     │ 0.0       │ 0.0            │
# │ 4   │ 4150     │ 0.2     │ 0.236962  │ 0.234131       │
# │ 5   │ 4157     │ 0.2     │ 0.224628  │ 0.298085       │
# │ 6   │ 4159     │ -0.2    │ 0.0       │ 0.0            │
# │ 7   │ 4201     │ 0.2     │ 0.0       │ 0.212642       │
# │ 8   │ 4204     │ 0.2     │ 0.0       │ 0.249016       │
# │ 9   │ 4208     │ -0.2    │ -0.334482 │ -0.308534      │
# │ 10  │ 4213     │ -0.2    │ 0.0       │ -0.170999      │
# │ 11  │ 7885     │ 0.2     │ 0.0       │ 0.0            │
# │ 12  │ 7888     │ 0.2     │ 0.0       │ 0.30658        │
# │ 13  │ 7891     │ 0.2     │ 0.0       │ 0.285214       │
# │ 14  │ 7894     │ 0.2     │ 0.514643  │ 0.23492        │
# │ 15  │ 7895     │ 0.2     │ 0.0       │ 0.105198       │
#
#
# running 31 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 933      │ -0.2    │ 0.0       │ 0.0            │
# │ 2   │ 2471     │ 0.2     │ 0.252948  │ 0.312392       │
# │ 3   │ 2480     │ -0.2    │ 0.0       │ 0.0            │
# │ 4   │ 2522     │ -0.2    │ 0.0       │ 0.0            │
# │ 5   │ 2523     │ 0.2     │ 0.0       │ 0.0            │
# │ 6   │ 2531     │ 0.2     │ 0.406433  │ 0.279515       │
# │ 7   │ 4266     │ 0.2     │ 0.0       │ 0.0            │
# │ 8   │ 4267     │ 0.2     │ 0.646653  │ 0.581578       │
# │ 9   │ 4269     │ 0.2     │ 0.0       │ 0.0907069      │
# │ 10  │ 4272     │ -0.2    │ 0.0       │ -0.22707       │
# │ 11  │ 7947     │ -0.2    │ 0.0       │ 0.0            │
# │ 12  │ 7948     │ 0.2     │ 0.0       │ 0.0            │
# │ 13  │ 7951     │ -0.2    │ 0.0       │ -0.312681      │
# │ 14  │ 7955     │ -0.2    │ 0.0       │ -0.0940534     │
# │ 15  │ 7957     │ -0.2    │ 0.0       │ 0.0            │
#
#
# running 32 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 5618     │ -0.2    │ -0.326388 │ 0.0            │
# │ 2   │ 6733     │ 0.2     │ 0.0       │ 0.0            │
# │ 3   │ 6736     │ 0.2     │ 0.0       │ 0.0            │
# │ 4   │ 7542     │ -0.2    │ 0.0       │ -0.101372      │
# │ 5   │ 7543     │ -0.2    │ 0.0       │ -0.260586      │
# │ 6   │ 7544     │ 0.2     │ 0.0       │ 0.19301        │
# │ 7   │ 8783     │ -0.2    │ 0.0       │ -0.214211      │
# │ 8   │ 8790     │ -0.2    │ -0.370061 │ -0.313994      │
# │ 9   │ 8794     │ 0.2     │ 0.0       │ 0.179764       │
# │ 10  │ 8795     │ -0.2    │ 0.0       │ 0.0            │
# │ 11  │ 9783     │ -0.2    │ 0.0       │ 0.0            │
# │ 12  │ 9786     │ -0.2    │ 0.0       │ 0.0            │
# │ 13  │ 9787     │ 0.2     │ 0.0       │ 0.0            │
# │ 14  │ 9789     │ 0.2     │ 0.0       │ 0.108235       │
# │ 15  │ 9797     │ 0.2     │ 0.0       │ 0.212968       │
#
#
# running 33 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 3494     │ 0.2     │ 0.0       │ 0.0            │
# │ 2   │ 4205     │ -0.2    │ -0.264788 │ -0.197466      │
# │ 3   │ 4211     │ -0.2    │ 0.0       │ 0.0            │
# │ 4   │ 5185     │ -0.2    │ -0.260641 │ -0.214381      │
# │ 5   │ 5191     │ 0.2     │ 0.0       │ 0.214848       │
# │ 6   │ 5198     │ 0.2     │ 0.0       │ 0.19244        │
# │ 7   │ 9649     │ -0.2    │ -0.257802 │ -0.153987      │
# │ 8   │ 9651     │ -0.2    │ 0.0       │ 0.0            │
# │ 9   │ 9653     │ 0.2     │ 0.0       │ 0.0            │
# │ 10  │ 9654     │ 0.2     │ 0.287272  │ 0.239378       │
# │ 11  │ 9722     │ 0.2     │ 0.0       │ 0.324067       │
# │ 12  │ 9724     │ 0.2     │ 0.0       │ 0.0            │
# │ 13  │ 9734     │ 0.2     │ 0.0       │ 0.0            │
# │ 14  │ 9735     │ -0.2    │ 0.0       │ -0.232775      │
# │ 15  │ 9736     │ -0.2    │ -0.380125 │ -0.261463      │
#
#
# running 34 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 1480     │ -0.2    │ 0.0       │ 0.0            │
# │ 2   │ 1647     │ 0.2     │ 0.0       │ 0.0            │
# │ 3   │ 1652     │ -0.2    │ 0.0       │ 0.0            │
# │ 4   │ 6401     │ 0.2     │ 0.0       │ 0.111404       │
# │ 5   │ 6405     │ -0.2    │ 0.0       │ 0.0            │
# │ 6   │ 6419     │ 0.2     │ 0.0       │ 0.0            │
# │ 7   │ 6642     │ 0.2     │ 0.272894  │ 0.328234       │
# │ 8   │ 6651     │ -0.2    │ -0.412074 │ -0.412966      │
# │ 9   │ 6655     │ 0.2     │ 0.0       │ 0.281332       │
# │ 10  │ 6660     │ -0.2    │ 0.0       │ 0.0            │
# │ 11  │ 8504     │ -0.2    │ 0.0       │ 0.0            │
# │ 12  │ 8505     │ -0.2    │ 0.0       │ -0.15364       │
# │ 13  │ 8514     │ -0.2    │ -0.354087 │ -0.24374       │
# │ 14  │ 8516     │ 0.2     │ 0.0       │ 0.0            │
# │ 15  │ 8518     │ -0.2    │ 0.0       │ 0.0            │
#
#
# running 35 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 146      │ 0.2     │ 0.0       │ 0.0            │
# │ 2   │ 3682     │ -0.2    │ 0.0       │ -0.221332      │
# │ 3   │ 3697     │ 0.2     │ 0.280126  │ 0.22515        │
# │ 4   │ 7007     │ -0.2    │ -0.395721 │ -0.324749      │
# │ 5   │ 7011     │ -0.2    │ 0.0       │ 0.0            │
# │ 6   │ 7014     │ 0.2     │ 0.0       │ 0.0            │
# │ 7   │ 7827     │ -0.2    │ -0.324576 │ -0.343646      │
# │ 8   │ 7830     │ -0.2    │ 0.0       │ -0.21567       │
# │ 9   │ 7834     │ -0.2    │ 0.0       │ 0.0            │
# │ 10  │ 7840     │ 0.2     │ 0.275     │ 0.401721       │
# │ 11  │ 9047     │ -0.2    │ 0.0       │ -0.167172      │
# │ 12  │ 9049     │ -0.2    │ -0.301754 │ -0.373972      │
# │ 13  │ 9050     │ 0.2     │ 0.0       │ 0.237188       │
# │ 14  │ 9056     │ -0.2    │ 0.0       │ -0.254447      │
# │ 15  │ 9060     │ 0.2     │ 0.0       │ 0.0            │
#
#
# running 36 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 731      │ -0.2    │ 0.0       │ 0.0            │
# │ 2   │ 4221     │ 0.2     │ 0.0       │ 0.0            │
# │ 3   │ 4234     │ 0.2     │ 0.0       │ 0.0            │
# │ 4   │ 4272     │ 0.2     │ 0.324805  │ 0.320466       │
# │ 5   │ 4276     │ -0.2    │ 0.0       │ 0.0            │
# │ 6   │ 4277     │ -0.2    │ 0.0       │ -0.258243      │
# │ 7   │ 4885     │ -0.2    │ -0.276369 │ -0.205608      │
# │ 8   │ 4893     │ 0.2     │ 0.0       │ 0.180203       │
# │ 9   │ 4895     │ 0.2     │ 0.0       │ 0.246933       │
# │ 10  │ 4896     │ 0.2     │ 0.245147  │ 0.220118       │
# │ 11  │ 6821     │ 0.2     │ 0.291732  │ 0.285222       │
# │ 12  │ 6822     │ 0.2     │ 0.0       │ 0.0            │
# │ 13  │ 6824     │ -0.2    │ 0.0       │ -0.0955381     │
# │ 14  │ 6829     │ 0.2     │ 0.0       │ 0.236389       │
# │ 15  │ 6830     │ -0.2    │ 0.0       │ -0.204444      │
#
#
# running 37 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 971      │ 0.2     │ 0.0       │ 0.0            │
# │ 2   │ 2147     │ -0.2    │ 0.0       │ 0.0            │
# │ 3   │ 2151     │ -0.2    │ 0.0       │ -0.213879      │
# │ 4   │ 3022     │ -0.2    │ 0.0       │ 0.0            │
# │ 5   │ 3029     │ -0.2    │ 0.0       │ 0.0            │
# │ 6   │ 3031     │ 0.2     │ 0.0       │ 0.110101       │
# │ 7   │ 8587     │ -0.2    │ -0.512112 │ -0.303553      │
# │ 8   │ 8588     │ -0.2    │ 0.0       │ -0.23204       │
# │ 9   │ 8593     │ 0.2     │ 0.0       │ 0.0            │
# │ 10  │ 8594     │ 0.2     │ 0.403423  │ 0.397792       │
# │ 11  │ 9582     │ -0.2    │ -0.240783 │ -0.16933       │
# │ 12  │ 9585     │ -0.2    │ 0.0       │ 0.0            │
# │ 13  │ 9588     │ -0.2    │ 0.0       │ 0.0            │
# │ 14  │ 9594     │ 0.2     │ 0.0       │ 0.0            │
# │ 15  │ 9598     │ -0.2    │ 0.0       │ -0.224239      │
#
#
# running 38 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 6349     │ 0.2     │ 0.264516  │ 0.278644       │
# │ 2   │ 8212     │ 0.2     │ 0.0       │ 0.0            │
# │ 3   │ 8215     │ 0.2     │ 0.282164  │ 0.217887       │
# │ 4   │ 9283     │ 0.2     │ 0.226122  │ 0.264092       │
# │ 5   │ 9293     │ -0.2    │ 0.0       │ -0.195846      │
# │ 6   │ 9298     │ -0.2    │ -0.295341 │ 0.0            │
# │ 7   │ 9353     │ -0.2    │ 0.0       │ 0.0            │
# │ 8   │ 9355     │ -0.2    │ -0.327437 │ -0.222012      │
# │ 9   │ 9356     │ -0.2    │ 0.0       │ 0.0            │
# │ 10  │ 9359     │ -0.2    │ 0.0       │ 0.0            │
# │ 11  │ 9785     │ 0.2     │ 0.0       │ 0.0            │
# │ 12  │ 9786     │ -0.2    │ 0.0       │ 0.0            │
# │ 13  │ 9788     │ -0.2    │ -0.253063 │ -0.227006      │
# │ 14  │ 9793     │ -0.2    │ 0.0       │ -0.152935      │
# │ 15  │ 9798     │ -0.2    │ 0.0       │ 0.0            │
#
#
# running 39 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 750      │ -0.2    │ 0.0       │ 0.0            │
# │ 2   │ 3591     │ 0.2     │ 0.0       │ 0.0            │
# │ 3   │ 3594     │ 0.2     │ 0.261387  │ 0.171233       │
# │ 4   │ 5314     │ -0.2    │ 0.0       │ 0.0            │
# │ 5   │ 5316     │ -0.2    │ 0.0       │ 0.0            │
# │ 6   │ 5318     │ 0.2     │ 0.0       │ 0.0            │
# │ 7   │ 5901     │ -0.2    │ -0.360391 │ -0.230487      │
# │ 8   │ 5905     │ -0.2    │ 0.0       │ -0.175422      │
# │ 9   │ 5916     │ -0.2    │ 0.0       │ 0.0            │
# │ 10  │ 5919     │ 0.2     │ 0.359677  │ 0.283455       │
# │ 11  │ 6788     │ -0.2    │ -0.268746 │ -0.268441      │
# │ 12  │ 6791     │ 0.2     │ 0.333196  │ 0.303338       │
# │ 13  │ 6795     │ -0.2    │ -0.379249 │ -0.268772      │
# │ 14  │ 6796     │ -0.2    │ 0.0       │ 0.0            │
# │ 15  │ 6799     │ -0.2    │ 0.0       │ -0.218163      │
#
#
# running 40 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 2106     │ 0.2     │ 0.0       │ 0.0            │
# │ 2   │ 5202     │ -0.2    │ 0.0       │ -0.248132      │
# │ 3   │ 5210     │ 0.2     │ 0.0       │ 0.0            │
# │ 4   │ 7150     │ -0.2    │ 0.0       │ 0.0            │
# │ 5   │ 7154     │ 0.2     │ 0.0       │ 0.0            │
# │ 6   │ 7159     │ -0.2    │ 0.0       │ 0.0            │
# │ 7   │ 8288     │ 0.2     │ 0.0       │ 0.0            │
# │ 8   │ 8290     │ 0.2     │ 0.424047  │ 0.437557       │
# │ 9   │ 8296     │ -0.2    │ 0.0       │ 0.0            │
# │ 10  │ 8300     │ -0.2    │ 0.0       │ 0.0            │
# │ 11  │ 9842     │ 0.2     │ 0.0       │ 0.0            │
# │ 12  │ 9846     │ -0.2    │ 0.0       │ 0.0            │
# │ 13  │ 9856     │ 0.2     │ 0.0       │ 0.0            │
# │ 14  │ 9858     │ -0.2    │ 0.0       │ -0.136694      │
# │ 15  │ 9859     │ 0.2     │ 0.216294  │ 0.321115       │
#
#
# running 41 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 1067     │ -0.2    │ 0.0       │ 0.0            │
# │ 2   │ 1262     │ -0.2    │ -0.258959 │ -0.297441      │
# │ 3   │ 1280     │ 0.2     │ 0.0       │ 0.203167       │
# │ 4   │ 1947     │ 0.2     │ 0.312615  │ 0.286762       │
# │ 5   │ 1951     │ 0.2     │ 0.0       │ 0.172347       │
# │ 6   │ 1953     │ 0.2     │ 0.401822  │ 0.337096       │
# │ 7   │ 2388     │ 0.2     │ 0.261303  │ 0.14095        │
# │ 8   │ 2392     │ 0.2     │ 0.0       │ 0.0            │
# │ 9   │ 2397     │ -0.2    │ 0.0       │ -0.167468      │
# │ 10  │ 2399     │ -0.2    │ -0.284994 │ -0.274163      │
# │ 11  │ 7185     │ 0.2     │ 0.0       │ 0.132231       │
# │ 12  │ 7196     │ -0.2    │ -0.370439 │ -0.156255      │
# │ 13  │ 7197     │ 0.2     │ 0.0       │ 0.0            │
# │ 14  │ 7198     │ -0.2    │ 0.0       │ 0.0            │
# │ 15  │ 7199     │ -0.2    │ 0.0       │ 0.0            │
#
#
# running 42 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 3655     │ -0.2    │ 0.0       │ 0.0            │
# │ 2   │ 6229     │ 0.2     │ 0.0       │ 0.0            │
# │ 3   │ 6236     │ -0.2    │ -0.283031 │ -0.299057      │
# │ 4   │ 6971     │ 0.2     │ 0.0       │ 0.0            │
# │ 5   │ 6979     │ 0.2     │ 0.0       │ 0.0            │
# │ 6   │ 6980     │ -0.2    │ 0.0       │ 0.0            │
# │ 7   │ 7046     │ -0.2    │ 0.0       │ 0.0            │
# │ 8   │ 7049     │ -0.2    │ 0.0       │ 0.0            │
# │ 9   │ 7054     │ 0.2     │ 0.0       │ 0.0            │
# │ 10  │ 7059     │ -0.2    │ 0.0       │ 0.0            │
# │ 11  │ 9562     │ 0.2     │ 0.0       │ 0.385298       │
# │ 12  │ 9563     │ -0.2    │ 0.0       │ 0.0            │
# │ 13  │ 9567     │ -0.2    │ 0.0       │ 0.0            │
# │ 14  │ 9569     │ -0.2    │ 0.0       │ -0.288044      │
# │ 15  │ 9574     │ 0.2     │ 0.0       │ 0.0            │
#
#
# running 43 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 2917     │ 0.2     │ 0.0       │ 0.0            │
# │ 2   │ 6522     │ 0.2     │ 0.0       │ 0.0            │
# │ 3   │ 6534     │ 0.2     │ 0.0       │ 0.157665       │
# │ 4   │ 6681     │ -0.2    │ -0.268612 │ -0.216828      │
# │ 5   │ 6694     │ -0.2    │ 0.0       │ -0.256947      │
# │ 6   │ 6696     │ 0.2     │ 0.0       │ 0.0            │
# │ 7   │ 8365     │ -0.2    │ 0.0       │ -0.235428      │
# │ 8   │ 8368     │ -0.2    │ 0.0       │ -0.283061      │
# │ 9   │ 8374     │ 0.2     │ 0.0       │ 0.0            │
# │ 10  │ 8375     │ -0.2    │ 0.0       │ 0.0            │
# │ 11  │ 9147     │ 0.2     │ 0.365982  │ 0.266044       │
# │ 12  │ 9152     │ 0.2     │ 0.0       │ 0.196142       │
# │ 13  │ 9154     │ -0.2    │ 0.0       │ -0.195745      │
# │ 14  │ 9159     │ -0.2    │ 0.0       │ -0.351274      │
# │ 15  │ 9160     │ 0.2     │ 0.0       │ 0.186191       │
#
#
# running 44 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 414      │ -0.2    │ -0.293805 │ -0.289486      │
# │ 2   │ 2709     │ 0.2     │ 0.0       │ 0.0            │
# │ 3   │ 2720     │ 0.2     │ 0.261395  │ 0.238116       │
# │ 4   │ 3492     │ 0.2     │ 0.0       │ 0.0            │
# │ 5   │ 3494     │ -0.2    │ 0.0       │ 0.0            │
# │ 6   │ 3497     │ -0.2    │ 0.0       │ 0.0            │
# │ 7   │ 4007     │ -0.2    │ 0.0       │ -0.264078      │
# │ 8   │ 4009     │ 0.2     │ 0.0       │ 0.252377       │
# │ 9   │ 4011     │ -0.2    │ -0.26696  │ -0.26468       │
# │ 10  │ 4018     │ -0.2    │ 0.0       │ -0.123708      │
# ...
# │ 7   │ 8281     │ 0.2     │ 0.0       │ 0.188564       │
# │ 8   │ 8285     │ -0.2    │ -0.343693 │ -0.196797      │
# │ 9   │ 8286     │ -0.2    │ 0.0       │ -0.122666      │
# │ 10  │ 8299     │ 0.2     │ 0.0       │ 0.0            │
# │ 11  │ 8465     │ 0.2     │ 0.0       │ 0.106819       │
# │ 12  │ 8470     │ 0.2     │ 0.401244  │ 0.411045       │
# │ 13  │ 8475     │ -0.2    │ 0.0       │ 0.0            │
# │ 14  │ 8478     │ -0.2    │ 0.0       │ 0.0            │
# │ 15  │ 8479     │ 0.2     │ 0.0       │ 0.0            │
#
#
# running 87 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 492      │ 0.2     │ 0.209431  │ 0.0            │
# │ 2   │ 4113     │ 0.2     │ 0.0       │ 0.0            │
# │ 3   │ 4114     │ -0.2    │ 0.0       │ 0.0            │
# │ 4   │ 6729     │ -0.2    │ 0.0       │ 0.0            │
# │ 5   │ 6730     │ -0.2    │ 0.0       │ -0.167752      │
# │ 6   │ 6737     │ -0.2    │ 0.0       │ -0.235482      │
# │ 7   │ 7362     │ -0.2    │ 0.0       │ 0.0            │
# │ 8   │ 7372     │ 0.2     │ 0.0       │ 0.0            │
# │ 9   │ 7373     │ 0.2     │ 0.0       │ 0.0            │
# │ 10  │ 7374     │ -0.2    │ 0.0       │ 0.0            │
# │ 11  │ 9941     │ -0.2    │ 0.0       │ -0.176735      │
# │ 12  │ 9944     │ -0.2    │ -0.472228 │ -0.194903      │
# │ 13  │ 9947     │ -0.2    │ 0.0       │ 0.0            │
# │ 14  │ 9954     │ 0.2     │ 0.0       │ 0.0            │
# │ 15  │ 9956     │ -0.2    │ 0.0       │ 0.0            │
#
#
# running 88 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 1979     │ -0.2    │ 0.0       │ 0.0            │
# │ 2   │ 3564     │ 0.2     │ 0.0       │ 0.0            │
# │ 3   │ 3575     │ -0.2    │ -0.257295 │ -0.210729      │
# │ 4   │ 4708     │ 0.2     │ 0.0       │ 0.0            │
# │ 5   │ 4712     │ -0.2    │ -0.329555 │ -0.283571      │
# │ 6   │ 4720     │ -0.2    │ 0.0       │ -0.110134      │
# │ 7   │ 4782     │ -0.2    │ -0.326843 │ -0.221105      │
# │ 8   │ 4788     │ -0.2    │ 0.0       │ 0.0            │
# │ 9   │ 4792     │ -0.2    │ 0.0       │ 0.0            │
# │ 10  │ 4794     │ 0.2     │ 0.0       │ 0.207361       │
# │ 11  │ 8847     │ -0.2    │ 0.0       │ -0.140455      │
# │ 12  │ 8848     │ -0.2    │ -0.49343  │ -0.352275      │
# │ 13  │ 8849     │ -0.2    │ 0.0       │ 0.0            │
# │ 14  │ 8850     │ -0.2    │ 0.0       │ -0.208129      │
# │ 15  │ 8860     │ 0.2     │ 0.0       │ 0.0            │
#
#
# running 89 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 658      │ -0.2    │ 0.0       │ 0.0            │
# │ 2   │ 1585     │ -0.2    │ -0.36495  │ -0.366917      │
# │ 3   │ 1597     │ 0.2     │ 0.0       │ 0.0            │
# │ 4   │ 2682     │ -0.2    │ 0.0       │ 0.0            │
# │ 5   │ 2693     │ 0.2     │ 0.283496  │ 0.0            │
# │ 6   │ 2696     │ -0.2    │ 0.0       │ 0.0            │
# │ 7   │ 4403     │ -0.2    │ 0.0       │ 0.0            │
# │ 8   │ 4405     │ -0.2    │ -0.497567 │ -0.262198      │
# │ 9   │ 4406     │ -0.2    │ 0.0       │ -0.144321      │
# │ 10  │ 4412     │ -0.2    │ 0.0       │ -0.173141      │
# │ 11  │ 7565     │ 0.2     │ 0.0       │ 0.101887       │
# │ 12  │ 7566     │ 0.2     │ 0.307034  │ 0.234029       │
# │ 13  │ 7569     │ -0.2    │ 0.0       │ -0.273123      │
# │ 14  │ 7570     │ -0.2    │ -0.265606 │ -0.0601032     │
# │ 15  │ 7580     │ 0.2     │ 0.0       │ 0.168744       │
#
#
# running 90 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 804      │ 0.2     │ 0.0       │ 0.0            │
# │ 2   │ 3164     │ -0.2    │ -0.36831  │ -0.23107       │
# │ 3   │ 3165     │ -0.2    │ 0.0       │ -0.205509      │
# │ 4   │ 3684     │ 0.2     │ 0.258388  │ 0.251817       │
# │ 5   │ 3686     │ 0.2     │ 0.0       │ 0.0            │
# │ 6   │ 3699     │ -0.2    │ -0.311409 │ -0.305422      │
# │ 7   │ 4746     │ -0.2    │ 0.0       │ -0.251529      │
# │ 8   │ 4751     │ 0.2     │ 0.0       │ 0.0            │
# │ 9   │ 4754     │ 0.2     │ 0.0       │ 0.185553       │
# │ 10  │ 4760     │ -0.2    │ -0.466833 │ -0.374784      │
# │ 11  │ 8541     │ 0.2     │ 0.0       │ 0.0            │
# │ 12  │ 8549     │ 0.2     │ 0.0       │ 0.157986       │
# │ 13  │ 8550     │ -0.2    │ 0.0       │ 0.0            │
# │ 14  │ 8557     │ 0.2     │ 0.0       │ 0.0            │
# │ 15  │ 8559     │ -0.2    │ 0.0       │ -0.0958349     │
#
#
# running 91 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 620      │ 0.2     │ 0.0       │ 0.0            │
# │ 2   │ 771      │ -0.2    │ 0.0       │ -0.220322      │
# │ 3   │ 773      │ 0.2     │ 0.0       │ 0.203317       │
# │ 4   │ 6669     │ 0.2     │ 0.0       │ 0.0            │
# │ 5   │ 6675     │ -0.2    │ -0.309701 │ -0.316778      │
# │ 6   │ 6680     │ -0.2    │ 0.0       │ 0.0            │
# │ 7   │ 8782     │ 0.2     │ 0.0       │ 0.0            │
# │ 8   │ 8784     │ 0.2     │ 0.25578   │ 0.240348       │
# │ 9   │ 8792     │ -0.2    │ 0.0       │ 0.0            │
# │ 10  │ 8799     │ 0.2     │ 0.0       │ 0.0            │
# │ 11  │ 9383     │ -0.2    │ 0.0       │ -0.214271      │
# │ 12  │ 9384     │ 0.2     │ 0.0       │ 0.15411        │
# │ 13  │ 9392     │ -0.2    │ 0.0       │ 0.0            │
# │ 14  │ 9395     │ 0.2     │ 0.0       │ 0.266876       │
# │ 15  │ 9396     │ 0.2     │ 0.0       │ 0.0753015      │
#
#
# running 92 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 397      │ 0.2     │ 0.0       │ 0.0            │
# │ 2   │ 1844     │ 0.2     │ 0.325954  │ 0.412839       │
# │ 3   │ 1847     │ -0.2    │ 0.0       │ -0.287153      │
# │ 4   │ 2143     │ -0.2    │ -0.249361 │ -0.33366       │
# │ 5   │ 2155     │ -0.2    │ 0.0       │ -0.225363      │
# │ 6   │ 2157     │ 0.2     │ 0.0       │ 0.0            │
# │ 7   │ 3024     │ -0.2    │ 0.0       │ -0.187308      │
# │ 8   │ 3025     │ -0.2    │ -0.381386 │ -0.297721      │
# │ 9   │ 3027     │ 0.2     │ 0.0       │ 0.225187       │
# │ 10  │ 3040     │ -0.2    │ 0.0       │ 0.0            │
# │ 11  │ 6765     │ -0.2    │ 0.0       │ 0.0            │
# │ 12  │ 6769     │ -0.2    │ -0.223952 │ -0.540263      │
# │ 13  │ 6773     │ -0.2    │ -0.268894 │ -0.290143      │
# │ 14  │ 6777     │ -0.2    │ 0.0       │ 0.0            │
# │ 15  │ 6779     │ -0.2    │ 0.0       │ 0.0            │
#
#
# running 93 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 1754     │ -0.2    │ -0.272735 │ 0.0            │
# │ 2   │ 6725     │ -0.2    │ -0.373033 │ -0.343065      │
# │ 3   │ 6731     │ -0.2    │ 0.0       │ -0.176711      │
# │ 4   │ 8164     │ -0.2    │ 0.0       │ -0.255278      │
# │ 5   │ 8168     │ 0.2     │ 0.0       │ 0.194541       │
# │ 6   │ 8177     │ 0.2     │ 0.269619  │ 0.248525       │
# │ 7   │ 8606     │ -0.2    │ 0.0       │ 0.0            │
# │ 8   │ 8607     │ 0.2     │ 0.0       │ 0.0            │
# │ 9   │ 8611     │ -0.2    │ 0.0       │ 0.0            │
# │ 10  │ 8620     │ -0.2    │ 0.0       │ 0.0            │
# │ 11  │ 9921     │ 0.2     │ 0.0       │ 0.0            │
# │ 12  │ 9922     │ -0.2    │ 0.0       │ -0.0757275     │
# │ 13  │ 9923     │ -0.2    │ -0.41985  │ -0.212935      │
# │ 14  │ 9928     │ 0.2     │ 0.0       │ 0.275807       │
# │ 15  │ 9939     │ 0.2     │ 0.0       │ 0.0            │
#
#
# running 94 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 676      │ -0.2    │ 0.0       │ 0.0            │
# │ 2   │ 727      │ -0.2    │ 0.0       │ 0.0            │
# │ 3   │ 738      │ -0.2    │ 0.0       │ 0.0            │
# │ 4   │ 1024     │ 0.2     │ 0.0       │ 0.0            │
# │ 5   │ 1034     │ 0.2     │ 0.0       │ 0.0            │
# │ 6   │ 1038     │ 0.2     │ 0.0       │ 0.0            │
# │ 7   │ 4809     │ -0.2    │ 0.0       │ 0.0            │
# │ 8   │ 4817     │ 0.2     │ 0.38373   │ 0.247681       │
# │ 9   │ 4818     │ 0.2     │ 0.0       │ 0.089608       │
# │ 10  │ 4820     │ -0.2    │ 0.0       │ 0.0            │
# │ 11  │ 5801     │ -0.2    │ -0.39919  │ -0.431594      │
# │ 12  │ 5803     │ -0.2    │ 0.0       │ -0.0808936     │
# │ 13  │ 5808     │ 0.2     │ 0.0       │ 0.109393       │
# │ 14  │ 5811     │ 0.2     │ 0.0       │ 0.0            │
# │ 15  │ 5817     │ 0.2     │ 0.0       │ 0.207712       │
#
#
# running 95 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 4039     │ 0.2     │ 0.0       │ 0.0            │
# │ 2   │ 6883     │ 0.2     │ 0.0       │ 0.0            │
# │ 3   │ 6890     │ -0.2    │ 0.0       │ 0.0            │
# │ 4   │ 7167     │ -0.2    │ 0.0       │ -0.163235      │
# │ 5   │ 7169     │ -0.2    │ 0.0       │ 0.0            │
# │ 6   │ 7175     │ 0.2     │ 0.0       │ 0.0            │
# │ 7   │ 7570     │ -0.2    │ 0.0       │ -0.200495      │
# │ 8   │ 7571     │ -0.2    │ 0.0       │ 0.0            │
# │ 9   │ 7572     │ -0.2    │ -0.354472 │ -0.366366      │
# │ 10  │ 7579     │ -0.2    │ 0.0       │ 0.0            │
# │ 11  │ 8445     │ -0.2    │ 0.0       │ 0.0            │
# │ 12  │ 8450     │ 0.2     │ 0.0       │ 0.309349       │
# │ 13  │ 8454     │ -0.2    │ -0.469319 │ -0.104503      │
# │ 14  │ 8458     │ 0.2     │ 0.0       │ 0.0            │
# │ 15  │ 8460     │ -0.2    │ 0.0       │ 0.0            │
#
#
# running 96 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 569      │ 0.2     │ 0.315792  │ 0.0            │
# │ 2   │ 1502     │ -0.2    │ 0.0       │ -0.309417      │
# │ 3   │ 1512     │ 0.2     │ 0.314821  │ 0.262403       │
# │ 4   │ 8486     │ 0.2     │ 0.414324  │ 0.230886       │
# │ 5   │ 8488     │ 0.2     │ 0.0       │ 0.31843        │
# │ 6   │ 8495     │ -0.2    │ 0.0       │ -0.36928       │
# │ 7   │ 9341     │ -0.2    │ -0.291259 │ -0.245107      │
# │ 8   │ 9345     │ 0.2     │ 0.0       │ 0.120855       │
# │ 9   │ 9356     │ 0.2     │ 0.414822  │ 0.248624       │
# │ 10  │ 9357     │ 0.2     │ 0.0       │ 0.0            │
# │ 11  │ 9688     │ -0.2    │ 0.0       │ -0.13265       │
# │ 12  │ 9690     │ -0.2    │ 0.0       │ 0.0            │
# │ 13  │ 9691     │ -0.2    │ 0.0       │ 0.0            │
# │ 14  │ 9696     │ 0.2     │ 0.0       │ 0.0            │
# │ 15  │ 9700     │ 0.2     │ 0.343238  │ 0.308384       │
#
#
# running 97 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 4029     │ -0.2    │ -0.294292 │ -0.298162      │
# │ 2   │ 4463     │ 0.2     │ 0.30867   │ 0.314932       │
# │ 3   │ 4468     │ 0.2     │ 0.255208  │ 0.289692       │
# │ 4   │ 7125     │ 0.2     │ 0.310438  │ 0.260402       │
# │ 5   │ 7138     │ -0.2    │ -0.472907 │ -0.368123      │
# │ 6   │ 7139     │ -0.2    │ 0.0       │ -0.137291      │
# │ 7   │ 7468     │ 0.2     │ 0.0       │ 0.0            │
# │ 8   │ 7469     │ 0.2     │ 0.0       │ 0.229404       │
# │ 9   │ 7475     │ 0.2     │ 0.0       │ 0.21128        │
# │ 10  │ 7478     │ 0.2     │ 0.0       │ 0.159271       │
# │ 11  │ 8231     │ -0.2    │ 0.0       │ 0.0            │
# │ 12  │ 8232     │ 0.2     │ 0.0       │ 0.0            │
# │ 13  │ 8234     │ 0.2     │ 0.0       │ 0.0            │
# │ 14  │ 8238     │ 0.2     │ 0.0       │ 0.0            │
# │ 15  │ 8239     │ -0.2    │ 0.0       │ 0.0            │
#
#
# running 98 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 522      │ 0.2     │ 0.259354  │ 0.0            │
# │ 2   │ 5411     │ 0.2     │ 0.327832  │ 0.277147       │
# │ 3   │ 5414     │ 0.2     │ 0.0       │ 0.165557       │
# │ 4   │ 6141     │ -0.2    │ -0.357905 │ -0.397703      │
# │ 5   │ 6151     │ -0.2    │ 0.0       │ 0.0            │
# │ 6   │ 6158     │ 0.2     │ 0.0       │ 0.0            │
# │ 7   │ 7321     │ 0.2     │ 0.0       │ 0.0            │
# │ 8   │ 7323     │ -0.2    │ 0.0       │ 0.0            │
# │ 9   │ 7324     │ 0.2     │ 0.0       │ 0.0            │
# │ 10  │ 7340     │ 0.2     │ 0.0       │ 0.307666       │
# │ 11  │ 9907     │ -0.2    │ 0.0       │ -0.141351      │
# │ 12  │ 9909     │ -0.2    │ 0.0       │ 0.0            │
# │ 13  │ 9912     │ 0.2     │ 0.0       │ 0.0            │
# │ 14  │ 9916     │ -0.2    │ 0.0       │ 0.0            │
# │ 15  │ 9917     │ -0.2    │ 0.0       │ -0.19237       │
#
#
# running 99 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 5614     │ 0.2     │ 0.0       │ 0.0            │
# │ 2   │ 6905     │ 0.2     │ 0.232678  │ 0.0            │
# │ 3   │ 6907     │ 0.2     │ 0.0       │ 0.0            │
# │ 4   │ 7547     │ 0.2     │ 0.0       │ 0.0            │
# │ 5   │ 7550     │ -0.2    │ 0.0       │ 0.0            │
# │ 6   │ 7560     │ -0.2    │ 0.0       │ 0.0            │
# │ 7   │ 8086     │ 0.2     │ 0.0       │ 0.0            │
# │ 8   │ 8087     │ -0.2    │ 0.0       │ 0.0            │
# │ 9   │ 8088     │ -0.2    │ -0.203587 │ -0.167214      │
# │ 10  │ 8090     │ -0.2    │ 0.0       │ -0.101919      │
# │ 11  │ 8784     │ 0.2     │ 0.0       │ 0.180947       │
# │ 12  │ 8791     │ 0.2     │ 0.202551  │ 0.266429       │
# │ 13  │ 8792     │ 0.2     │ 0.0       │ 0.0            │
# │ 14  │ 8793     │ -0.2    │ 0.0       │ 0.0            │
# │ 15  │ 8795     │ 0.2     │ 0.0       │ 0.178725       │
#
#
# running 100 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 1076     │ 0.2     │ 0.0       │ 0.0            │
# │ 2   │ 2227     │ -0.2    │ -0.336323 │ -0.250868      │
# │ 3   │ 2236     │ -0.2    │ 0.0       │ 0.0            │
# │ 4   │ 3361     │ -0.2    │ 0.0       │ -0.171317      │
# │ 5   │ 3365     │ 0.2     │ 0.0       │ 0.266144       │
# │ 6   │ 3380     │ 0.2     │ 0.0       │ 0.15873        │
# │ 7   │ 5442     │ 0.2     │ 0.0       │ 0.0            │
# │ 8   │ 5443     │ -0.2    │ 0.0       │ 0.0            │
# │ 9   │ 5450     │ -0.2    │ -0.338085 │ -0.150767      │
# │ 10  │ 5452     │ -0.2    │ -0.249028 │ -0.368679      │
# │ 11  │ 5822     │ 0.2     │ 0.327159  │ 0.25627        │
# │ 12  │ 5827     │ 0.2     │ 0.0       │ 0.0            │
# │ 13  │ 5834     │ -0.2    │ 0.0       │ -0.142205      │
# │ 14  │ 5838     │ -0.2    │ 0.0       │ 0.0            │
# │ 15  │ 5840     │ 0.2     │ 0.0       │ 0.178656       │
#
#
# 145.277412 seconds (3.85 M allocations: 11.564 GiB, 16.63% gc time)

# %%
@show mean(ungroup_true_positives)
@show mean(ungroup_false_positives)
@show mean(variable_true_positives)
@show mean(variable_false_positives)

@show std(ungroup_true_positives)
@show std(ungroup_false_positives)
@show std(variable_true_positives)
@show std(variable_false_positives)
# Out:
# mean(ungroup_true_positives) = 3.82
# mean(ungroup_false_positives) = 11.18
# mean(variable_true_positives) = 7.7
# mean(variable_false_positives) = 7.3
# std(ungroup_true_positives) = 1.6041612554021287
# std(ungroup_false_positives) = 1.604161255402129
# std(variable_true_positives) = 2.222474733128352
# std(variable_false_positives) = 2.222474733128352
# 2.222474733128352

# %% [markdown]
# ## Poisson

# %%
Random.seed!(2019)

d = Poisson
l = canonicallink(d())

num_runs = 100
ungroup_true_positives = zeros(num_runs)
ungroup_false_positives = zeros(num_runs)
variable_true_positives = zeros(num_runs)
variable_false_positives = zeros(num_runs)

@time for i in 1:num_runs
    println("running $i th model")
    utp, ufp, vtp, vfp = compare(d, l)
    ungroup_true_positives[i] = utp
    ungroup_false_positives[i] = ufp
    variable_true_positives[i] = vtp
    variable_false_positives[i] = vfp
end
# Out:
# running 1 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 3464     │ -0.2    │ -0.173963 │ -0.177852      │
# │ 2   │ 4927     │ 0.2     │ 0.0       │ 0.194465       │
# │ 3   │ 4938     │ -0.2    │ -0.256207 │ -0.243026      │
# │ 4   │ 5001     │ -0.2    │ -0.223954 │ -0.226218      │
# │ 5   │ 5011     │ -0.2    │ -0.197047 │ -0.194907      │
# │ 6   │ 5018     │ -0.2    │ -0.212477 │ -0.206918      │
# │ 7   │ 5084     │ -0.2    │ 0.0       │ -0.117447      │
# │ 8   │ 5090     │ 0.2     │ 0.218054  │ 0.215562       │
# │ 9   │ 5098     │ -0.2    │ 0.0       │ 0.0            │
# │ 10  │ 5100     │ -0.2    │ -0.246471 │ -0.213671      │
# │ 11  │ 7004     │ 0.2     │ 0.217706  │ 0.224078       │
# │ 12  │ 7011     │ 0.2     │ 0.189572  │ 0.182618       │
# │ 13  │ 7015     │ -0.2    │ -0.222002 │ -0.231538      │
# │ 14  │ 7016     │ 0.2     │ 0.214866  │ 0.222009       │
# │ 15  │ 7020     │ 0.2     │ 0.219321  │ 0.220227       │
#
#
# running 2 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 149      │ 0.2     │ 0.0       │ 0.199215       │
# │ 2   │ 4292     │ 0.2     │ 0.149985  │ 0.0            │
# │ 3   │ 4293     │ -0.2    │ -0.227085 │ -0.176924      │
# │ 4   │ 4985     │ -0.2    │ -0.249692 │ -0.229305      │
# │ 5   │ 4995     │ 0.2     │ 0.0       │ 0.0            │
# │ 6   │ 4999     │ 0.2     │ 0.100954  │ 0.0            │
# │ 7   │ 8462     │ 0.2     │ 0.0       │ 0.0            │
# │ 8   │ 8463     │ -0.2    │ 0.0       │ 0.0            │
# │ 9   │ 8477     │ -0.2    │ -0.188354 │ -0.161947      │
# │ 10  │ 8479     │ -0.2    │ -0.104148 │ -0.137333      │
# │ 11  │ 9448     │ -0.2    │ -0.211527 │ -0.13753       │
# │ 12  │ 9450     │ 0.2     │ 0.21142   │ 0.0            │
# │ 13  │ 9452     │ 0.2     │ 0.197525  │ 0.262921       │
# │ 14  │ 9453     │ 0.2     │ 0.200705  │ 0.139687       │
# │ 15  │ 9454     │ -0.2    │ -0.147309 │ -0.243881      │
#
#
# running 3 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 677      │ 0.2     │ 0.184812  │ 0.182563       │
# │ 2   │ 1265     │ 0.2     │ 0.205093  │ 0.201664       │
# │ 3   │ 1279     │ -0.2    │ -0.25363  │ -0.252184      │
# │ 4   │ 4171     │ 0.2     │ 0.239887  │ 0.234788       │
# │ 5   │ 4173     │ -0.2    │ -0.117527 │ -0.117916      │
# │ 6   │ 4176     │ 0.2     │ 0.203431  │ 0.20644        │
# │ 7   │ 5408     │ -0.2    │ -0.23093  │ -0.190688      │
# │ 8   │ 5413     │ 0.2     │ 0.107903  │ 0.159269       │
# │ 9   │ 5416     │ -0.2    │ -0.232815 │ 0.0            │
# │ 10  │ 5419     │ 0.2     │ 0.0       │ 0.0            │
# │ 11  │ 5481     │ 0.2     │ 0.0       │ 0.0            │
# │ 12  │ 5484     │ 0.2     │ 0.229183  │ 0.223641       │
# │ 13  │ 5488     │ 0.2     │ 0.130579  │ 0.124871       │
# │ 14  │ 5493     │ 0.2     │ 0.0       │ 0.0            │
# │ 15  │ 5499     │ 0.2     │ 0.191512  │ 0.194495       │
#
#
# running 4 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 43       │ 0.2     │ 0.206483  │ 0.215718       │
# │ 2   │ 174      │ -0.2    │ -0.181025 │ -0.171992      │
# │ 3   │ 176      │ 0.2     │ 0.200933  │ 0.197985       │
# │ 4   │ 782      │ -0.2    │ -0.138968 │ -0.141834      │
# │ 5   │ 790      │ -0.2    │ -0.163469 │ -0.169929      │
# │ 6   │ 796      │ -0.2    │ -0.249892 │ -0.24901       │
# │ 7   │ 4326     │ -0.2    │ 0.0       │ -0.0821446     │
# │ 8   │ 4328     │ -0.2    │ -0.238284 │ -0.216425      │
# │ 9   │ 4334     │ 0.2     │ 0.0       │ 0.0            │
# │ 10  │ 4335     │ -0.2    │ 0.0       │ 0.0            │
# │ 11  │ 7366     │ -0.2    │ -0.210962 │ -0.203201      │
# │ 12  │ 7367     │ -0.2    │ -0.194073 │ -0.20229       │
# │ 13  │ 7372     │ -0.2    │ -0.230292 │ -0.232552      │
# │ 14  │ 7376     │ 0.2     │ 0.198561  │ 0.196828       │
# │ 15  │ 7378     │ -0.2    │ -0.181441 │ -0.180784      │
#
#
# running 5 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 2545     │ -0.2    │ -0.198629 │ -0.22612       │
# │ 2   │ 2850     │ -0.2    │ -0.184102 │ -0.188327      │
# │ 3   │ 2852     │ -0.2    │ -0.157841 │ -0.158236      │
# │ 4   │ 3884     │ 0.2     │ 0.0       │ 0.282282       │
# │ 5   │ 3885     │ 0.2     │ 0.111326  │ 0.171257       │
# │ 6   │ 3895     │ -0.2    │ 0.0       │ -0.254797      │
# │ 7   │ 3983     │ 0.2     │ 0.226719  │ 0.250169       │
# │ 8   │ 3986     │ 0.2     │ 0.192622  │ 0.224255       │
# │ 9   │ 3990     │ -0.2    │ -0.19345  │ -0.206865      │
# │ 10  │ 3991     │ 0.2     │ 0.150683  │ 0.146825       │
# │ 11  │ 5182     │ 0.2     │ 0.0       │ 0.134333       │
# │ 12  │ 5185     │ 0.2     │ 0.0       │ 0.207007       │
# │ 13  │ 5187     │ 0.2     │ 0.206685  │ 0.296096       │
# │ 14  │ 5188     │ 0.2     │ 0.0       │ 0.0            │
# │ 15  │ 5198     │ -0.2    │ 0.0       │ -0.193257      │
#
#
# running 6 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 4633     │ -0.2    │ -0.221954 │ -0.220188      │
# │ 2   │ 6729     │ 0.2     │ 0.0       │ 0.0            │
# │ 3   │ 6731     │ 0.2     │ 0.173054  │ 0.189855       │
# │ 4   │ 7884     │ 0.2     │ 0.212195  │ 0.209259       │
# │ 5   │ 7889     │ 0.2     │ 0.204102  │ 0.20375        │
# │ 6   │ 7890     │ 0.2     │ 0.204102  │ 0.20375        │
# │ 7   │ 8410     │ 0.2     │ 0.227873  │ 0.222609       │
# │ 8   │ 8418     │ -0.2    │ -0.215272 │ -0.224083      │
# │ 9   │ 8419     │ -0.2    │ -0.162541 │ -0.158573      │
# │ 10  │ 8420     │ -0.2    │ -0.199882 │ -0.188269      │
# │ 11  │ 9527     │ -0.2    │ -0.20192  │ -0.157389      │
# │ 12  │ 9531     │ -0.2    │ -0.185812 │ -0.198792      │
# │ 13  │ 9536     │ -0.2    │ -0.270299 │ -0.245883      │
# │ 14  │ 9538     │ 0.2     │ 0.0       │ 0.185049       │
# │ 15  │ 9540     │ -0.2    │ -0.129706 │ -0.191748      │
#
#
# running 7 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 3843     │ 0.2     │ 0.145666  │ 0.150977       │
# │ 2   │ 5264     │ -0.2    │ -0.197584 │ -0.204789      │
# │ 3   │ 5271     │ 0.2     │ 0.262804  │ 0.24483        │
# │ 4   │ 5821     │ -0.2    │ 0.0       │ -0.146648      │
# │ 5   │ 5823     │ 0.2     │ 0.0       │ 0.152521       │
# │ 6   │ 5832     │ -0.2    │ -0.117315 │ 0.0            │
# │ 7   │ 7947     │ 0.2     │ 0.0       │ 0.147095       │
# │ 8   │ 7958     │ 0.2     │ 0.0       │ 0.184837       │
# │ 9   │ 7959     │ -0.2    │ -0.151237 │ -0.188909      │
# │ 10  │ 7960     │ -0.2    │ -0.238238 │ -0.248386      │
# │ 11  │ 9526     │ 0.2     │ 0.158809  │ 0.176187       │
# │ 12  │ 9531     │ -0.2    │ 0.0       │ 0.0            │
# │ 13  │ 9536     │ -0.2    │ -0.174083 │ -0.146757      │
# │ 14  │ 9538     │ -0.2    │ -0.180563 │ -0.212595      │
# │ 15  │ 9540     │ -0.2    │ -0.152566 │ -0.149816      │
#
#
# running 8 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 2898     │ -0.2    │ -0.264497 │ -0.2729        │
# │ 2   │ 3741     │ 0.2     │ 0.251851  │ 0.253486       │
# │ 3   │ 3760     │ -0.2    │ -0.202916 │ -0.187578      │
# │ 4   │ 3949     │ 0.2     │ 0.177854  │ 0.162775       │
# │ 5   │ 3955     │ 0.2     │ 0.233987  │ 0.221409       │
# │ 6   │ 3959     │ -0.2    │ -0.169666 │ -0.181788      │
# │ 7   │ 5305     │ -0.2    │ -0.302999 │ -0.306599      │
# │ 8   │ 5308     │ -0.2    │ -0.285187 │ -0.248066      │
# │ 9   │ 5311     │ -0.2    │ 0.0       │ 0.0            │
# │ 10  │ 5317     │ 0.2     │ 0.0       │ 0.0829398      │
# │ 11  │ 6610     │ 0.2     │ 0.0       │ 0.138685       │
# │ 12  │ 6611     │ 0.2     │ 0.291681  │ 0.226884       │
# │ 13  │ 6616     │ 0.2     │ 0.386381  │ 0.312518       │
# │ 14  │ 6617     │ 0.2     │ 0.0       │ 0.105408       │
# │ 15  │ 6618     │ -0.2    │ -0.177182 │ -0.200563      │
#
#
# running 9 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 1123     │ 0.2     │ 0.213356  │ 0.213359       │
# │ 2   │ 3306     │ 0.2     │ 0.237401  │ 0.23741        │
# │ 3   │ 3319     │ 0.2     │ 0.204626  │ 0.204616       │
# │ 4   │ 4282     │ -0.2    │ -0.20373  │ -0.203718      │
# │ 5   │ 4283     │ 0.2     │ 0.200997  │ 0.200989       │
# │ 6   │ 4291     │ -0.2    │ -0.154415 │ -0.154404      │
# │ 7   │ 5442     │ 0.2     │ 0.204769  │ 0.204797       │
# │ 8   │ 5444     │ 0.2     │ 0.191538  │ 0.191478       │
# │ 9   │ 5456     │ -0.2    │ -0.240574 │ -0.240604      │
# │ 10  │ 5460     │ 0.2     │ 0.215363  │ 0.2154         │
# │ 11  │ 8203     │ -0.2    │ -0.18954  │ -0.189443      │
# │ 12  │ 8204     │ -0.2    │ -0.236043 │ -0.23615       │
# │ 13  │ 8209     │ -0.2    │ -0.164991 │ -0.16507       │
# │ 14  │ 8212     │ 0.2     │ 0.218448  │ 0.218493       │
# │ 15  │ 8218     │ 0.2     │ 0.139633  │ 0.139551       │
#
#
# running 10 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 239      │ -0.2    │ -0.203171 │ -0.197993      │
# │ 2   │ 2530     │ 0.2     │ 0.23892   │ 0.233427       │
# │ 3   │ 2537     │ -0.2    │ -0.16909  │ -0.157117      │
# │ 4   │ 5026     │ -0.2    │ -0.194716 │ -0.223349      │
# │ 5   │ 5030     │ 0.2     │ 0.0       │ 0.0            │
# │ 6   │ 5031     │ -0.2    │ 0.0       │ -0.064108      │
# │ 7   │ 8962     │ 0.2     │ 0.201464  │ 0.207619       │
# │ 8   │ 8972     │ -0.2    │ -0.258659 │ -0.264748      │
# │ 9   │ 8975     │ -0.2    │ -0.191728 │ -0.199138      │
# │ 10  │ 8979     │ -0.2    │ -0.177816 │ -0.174175      │
# │ 11  │ 9683     │ 0.2     │ 0.0       │ 0.145934       │
# │ 12  │ 9691     │ -0.2    │ 0.0       │ 0.0            │
# │ 13  │ 9694     │ 0.2     │ 0.195633  │ 0.151721       │
# │ 14  │ 9696     │ -0.2    │ 0.0       │ -0.117947      │
# │ 15  │ 9700     │ -0.2    │ -0.256615 │ -0.220433      │
#
#
# running 11 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 991      │ 0.2     │ 0.178916  │ 0.164583       │
# │ 2   │ 1045     │ -0.2    │ -0.247596 │ -0.265639      │
# │ 3   │ 1055     │ 0.2     │ 0.170738  │ 0.184988       │
# │ 4   │ 2123     │ -0.2    │ 0.0       │ -0.187411      │
# │ 5   │ 2135     │ 0.2     │ 0.263278  │ 0.190502       │
# │ 6   │ 2138     │ 0.2     │ 0.0       │ 0.150226       │
# │ 7   │ 6043     │ -0.2    │ 0.0       │ 0.0            │
# │ 8   │ 6048     │ 0.2     │ 0.0       │ 0.0            │
# │ 9   │ 6050     │ -0.2    │ 0.0       │ -0.0983646     │
# │ 10  │ 6059     │ -0.2    │ -0.163422 │ -0.156228      │
# │ 11  │ 9344     │ 0.2     │ 0.0       │ 0.0            │
# │ 12  │ 9345     │ -0.2    │ 0.0       │ 0.0            │
# │ 13  │ 9350     │ 0.2     │ 0.0       │ 0.0            │
# │ 14  │ 9353     │ 0.2     │ 0.0       │ 0.167017       │
# │ 15  │ 9357     │ 0.2     │ 0.0       │ 0.0            │
#
#
# running 12 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 1992     │ 0.2     │ 0.197028  │ 0.207429       │
# │ 2   │ 2602     │ 0.2     │ 0.19807   │ 0.198104       │
# │ 3   │ 2617     │ -0.2    │ -0.210088 │ -0.205873      │
# │ 4   │ 3461     │ 0.2     │ 0.236232  │ 0.230884       │
# │ 5   │ 3462     │ -0.2    │ -0.236941 │ -0.225448      │
# │ 6   │ 3470     │ -0.2    │ -0.174094 │ -0.182012      │
# │ 7   │ 3884     │ -0.2    │ 0.0       │ -0.0949595     │
# │ 8   │ 3891     │ 0.2     │ 0.283724  │ 0.266827       │
# │ 9   │ 3897     │ -0.2    │ -0.134336 │ 0.0            │
# │ 10  │ 3898     │ -0.2    │ -0.249332 │ -0.221476      │
# │ 11  │ 4103     │ 0.2     │ 0.271693  │ 0.284743       │
# │ 12  │ 4104     │ 0.2     │ 0.191044  │ 0.182758       │
# │ 13  │ 4110     │ 0.2     │ 0.221664  │ 0.203696       │
# │ 14  │ 4115     │ -0.2    │ -0.160511 │ -0.163816      │
# │ 15  │ 4119     │ 0.2     │ 0.186323  │ 0.180462       │
#
#
# running 13 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 4669     │ -0.2    │ -0.233183 │ -0.241668      │
# │ 2   │ 5364     │ -0.2    │ -0.218796 │ -0.220318      │
# │ 3   │ 5374     │ -0.2    │ -0.154006 │ -0.150519      │
# │ 4   │ 8082     │ 0.2     │ 0.188223  │ 0.188248       │
# │ 5   │ 8083     │ 0.2     │ 0.204139  │ 0.206039       │
# │ 6   │ 8089     │ -0.2    │ -0.234971 │ -0.241014      │
# │ 7   │ 8163     │ 0.2     │ 0.206375  │ 0.207658       │
# │ 8   │ 8166     │ 0.2     │ 0.235948  │ 0.22984        │
# │ 9   │ 8172     │ -0.2    │ -0.168457 │ -0.164583      │
# │ 10  │ 8177     │ 0.2     │ 0.228729  │ 0.224704       │
# │ 11  │ 9025     │ 0.2     │ 0.0       │ 0.0            │
# │ 12  │ 9026     │ 0.2     │ 0.348105  │ 0.372441       │
# │ 13  │ 9029     │ -0.2    │ -0.171963 │ -0.143861      │
# │ 14  │ 9037     │ 0.2     │ 0.231897  │ 0.218501       │
# │ 15  │ 9039     │ 0.2     │ 0.0       │ 0.0            │
#
#
# running 14 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 3337     │ 0.2     │ 0.201296  │ 0.205792       │
# │ 2   │ 3704     │ -0.2    │ -0.167314 │ -0.170675      │
# │ 3   │ 3714     │ 0.2     │ 0.223073  │ 0.236628       │
# │ 4   │ 4124     │ -0.2    │ 0.0       │ 0.0            │
# │ 5   │ 4127     │ 0.2     │ 0.22209   │ 0.257759       │
# │ 6   │ 4130     │ 0.2     │ 0.0       │ 0.150627       │
# │ 7   │ 8861     │ -0.2    │ -0.255582 │ -0.212471      │
# │ 8   │ 8866     │ -0.2    │ -0.18103  │ -0.171336      │
# │ 9   │ 8877     │ 0.2     │ 0.190717  │ 0.0            │
# │ 10  │ 8879     │ 0.2     │ 0.255914  │ 0.271471       │
# │ 11  │ 9562     │ 0.2     │ 0.0976778 │ 0.108849       │
# │ 12  │ 9564     │ 0.2     │ 0.0       │ 0.0            │
# │ 13  │ 9566     │ -0.2    │ -0.118187 │ -0.123678      │
# │ 14  │ 9568     │ 0.2     │ 0.0       │ 0.113535       │
# │ 15  │ 9570     │ 0.2     │ 0.181602  │ 0.181421       │
#
#
# running 15 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 2508     │ 0.2     │ 0.241709  │ 0.240122       │
# │ 2   │ 5091     │ 0.2     │ 0.192024  │ 0.181287       │
# │ 3   │ 5095     │ 0.2     │ 0.184605  │ 0.18616        │
# │ 4   │ 7083     │ -0.2    │ -0.119111 │ -0.125438      │
# │ 5   │ 7092     │ -0.2    │ 0.0       │ 0.0            │
# │ 6   │ 7093     │ -0.2    │ -0.211012 │ -0.203859      │
# │ 7   │ 9023     │ 0.2     │ 0.205941  │ 0.202047       │
# │ 8   │ 9027     │ -0.2    │ -0.212026 │ -0.222091      │
# │ 9   │ 9035     │ -0.2    │ -0.178846 │ -0.176293      │
# │ 10  │ 9039     │ 0.2     │ 0.158768  │ 0.175774       │
# │ 11  │ 9862     │ -0.2    │ 0.0       │ 0.0            │
# │ 12  │ 9863     │ 0.2     │ 0.0       │ 0.0            │
# │ 13  │ 9868     │ 0.2     │ 0.245984  │ 0.225082       │
# │ 14  │ 9875     │ 0.2     │ 0.20052   │ 0.181652       │
# │ 15  │ 9877     │ 0.2     │ 0.225687  │ 0.198462       │
#
#
# running 16 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 584      │ 0.2     │ 0.185079  │ 0.18018        │
# │ 2   │ 2343     │ 0.2     │ 0.191487  │ 0.216638       │
# │ 3   │ 2348     │ -0.2    │ -0.199426 │ -0.212726      │
# │ 4   │ 6224     │ 0.2     │ 0.0       │ 0.0            │
# │ 5   │ 6235     │ 0.2     │ 0.0       │ 0.0            │
# │ 6   │ 6237     │ 0.2     │ 0.0       │ 0.0            │
# │ 7   │ 8321     │ 0.2     │ 0.0       │ 0.118186       │
# │ 8   │ 8323     │ -0.2    │ 0.0       │ 0.0            │
# │ 9   │ 8328     │ -0.2    │ -0.235517 │ -0.251316      │
# │ 10  │ 8339     │ -0.2    │ -0.142536 │ -0.175953      │
# │ 11  │ 9161     │ -0.2    │ 0.0       │ 0.0            │
# │ 12  │ 9166     │ 0.2     │ 0.196853  │ 0.188456       │
# │ 13  │ 9171     │ 0.2     │ 0.0       │ 0.11027        │
# │ 14  │ 9174     │ -0.2    │ 0.0       │ 0.0            │
# │ 15  │ 9176     │ 0.2     │ 0.0       │ 0.0            │
#
#
# running 17 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 3072     │ -0.2    │ -0.161245 │ -0.149709      │
# │ 2   │ 6031     │ 0.2     │ 0.110494  │ 0.129028       │
# │ 3   │ 6032     │ 0.2     │ 0.287335  │ 0.297627       │
# │ 4   │ 7115     │ 0.2     │ 0.181408  │ 0.178465       │
# │ 5   │ 7116     │ -0.2    │ -0.254389 │ -0.265949      │
# │ 6   │ 7119     │ -0.2    │ -0.235872 │ -0.235005      │
# │ 7   │ 7241     │ 0.2     │ 0.199263  │ 0.205202       │
# │ 8   │ 7243     │ -0.2    │ -0.207761 │ -0.219498      │
# │ 9   │ 7246     │ -0.2    │ -0.192903 │ -0.188762      │
# │ 10  │ 7257     │ -0.2    │ -0.188028 │ -0.184274      │
# │ 11  │ 8321     │ -0.2    │ 0.0       │ -0.0502484     │
# │ 12  │ 8326     │ -0.2    │ 0.0       │ 0.0            │
# │ 13  │ 8328     │ 0.2     │ 0.0       │ 0.061152       │
# │ 14  │ 8335     │ -0.2    │ 0.0       │ -0.133742      │
# │ 15  │ 8336     │ 0.2     │ 0.0       │ 0.0            │
#
#
# running 18 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 288      │ 0.2     │ 0.214648  │ 0.219064       │
# │ 2   │ 2627     │ -0.2    │ -0.171207 │ -0.167863      │
# │ 3   │ 2640     │ 0.2     │ 0.20176   │ 0.216339       │
# │ 4   │ 2782     │ 0.2     │ 0.0       │ 0.185693       │
# │ 5   │ 2790     │ 0.2     │ 0.204749  │ 0.212482       │
# │ 6   │ 2792     │ 0.2     │ 0.161033  │ 0.217508       │
# │ 7   │ 5321     │ -0.2    │ -0.322197 │ -0.245102      │
# │ 8   │ 5327     │ -0.2    │ -0.2942   │ -0.224039      │
# │ 9   │ 5335     │ -0.2    │ 0.0       │ -0.15065       │
# │ 10  │ 5336     │ 0.2     │ 0.0       │ 0.118211       │
# │ 11  │ 8601     │ -0.2    │ -0.195066 │ -0.198233      │
# │ 12  │ 8607     │ 0.2     │ 0.177702  │ 0.166862       │
# │ 13  │ 8609     │ 0.2     │ 0.21652   │ 0.223498       │
# │ 14  │ 8615     │ -0.2    │ -0.206259 │ -0.210849      │
# │ 15  │ 8619     │ -0.2    │ -0.175724 │ -0.18334       │
#
#
# running 19 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 1385     │ -0.2    │ -0.198696 │ -0.198685      │
# │ 2   │ 1744     │ -0.2    │ -0.211209 │ -0.211208      │
# │ 3   │ 1747     │ 0.2     │ 0.200571  │ 0.20057        │
# │ 4   │ 1825     │ -0.2    │ -0.205355 │ -0.205343      │
# │ 5   │ 1827     │ -0.2    │ -0.195234 │ -0.195223      │
# │ 6   │ 1829     │ 0.2     │ 0.193194  │ 0.193187       │
# │ 7   │ 4721     │ 0.2     │ 0.192131  │ 0.192173       │
# │ 8   │ 4725     │ 0.2     │ 0.199722  │ 0.199686       │
# │ 9   │ 4727     │ -0.2    │ -0.166262 │ -0.166221      │
# │ 10  │ 4736     │ -0.2    │ -0.192482 │ -0.192462      │
# │ 11  │ 6621     │ -0.2    │ -0.205128 │ -0.205147      │
# │ 12  │ 6627     │ 0.2     │ 0.195078  │ 0.195044       │
# │ 13  │ 6634     │ -0.2    │ -0.211265 │ -0.211268      │
# │ 14  │ 6635     │ -0.2    │ -0.197627 │ -0.197594      │
# │ 15  │ 6638     │ 0.2     │ 0.219793  │ 0.21975        │
#
#
# running 20 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 448      │ -0.2    │ -0.196199 │ -0.212257      │
# │ 2   │ 564      │ -0.2    │ -0.191305 │ -0.184229      │
# │ 3   │ 573      │ 0.2     │ 0.257884  │ 0.257762       │
# │ 4   │ 1562     │ 0.2     │ 0.128771  │ 0.167671       │
# │ 5   │ 1569     │ 0.2     │ 0.253539  │ 0.199084       │
# │ 6   │ 1576     │ -0.2    │ -0.190431 │ 0.0            │
# │ 7   │ 2124     │ 0.2     │ 0.113916  │ 0.151006       │
# │ 8   │ 2127     │ -0.2    │ 0.0       │ -0.163736      │
# │ 9   │ 2133     │ -0.2    │ 0.0       │ -0.251125      │
# │ 10  │ 2134     │ 0.2     │ 0.0       │ 0.199781       │
# │ 11  │ 8546     │ 0.2     │ 0.224331  │ 0.212288       │
# │ 12  │ 8547     │ 0.2     │ 0.202094  │ 0.194086       │
# │ 13  │ 8549     │ -0.2    │ -0.159135 │ -0.155067      │
# │ 14  │ 8551     │ 0.2     │ 0.189756  │ 0.192323       │
# │ 15  │ 8552     │ -0.2    │ -0.191489 │ -0.190446      │
#
#
# running 21 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 116      │ -0.2    │ -0.203209 │ -0.190778      │
# │ 2   │ 6647     │ 0.2     │ 0.209817  │ 0.21854        │
# │ 3   │ 6652     │ -0.2    │ -0.173297 │ -0.18789       │
# │ 4   │ 7281     │ 0.2     │ 0.0       │ 0.145941       │
# │ 5   │ 7284     │ -0.2    │ 0.0       │ -0.200024      │
# │ 6   │ 7290     │ 0.2     │ 0.270926  │ 0.240704       │
# │ 7   │ 7942     │ 0.2     │ 0.15494   │ 0.15824        │
# │ 8   │ 7948     │ -0.2    │ 0.0       │ 0.0            │
# │ 9   │ 7951     │ 0.2     │ 0.180423  │ 0.166801       │
# │ 10  │ 7952     │ 0.2     │ 0.264268  │ 0.269937       │
# │ 11  │ 8684     │ 0.2     │ 0.323268  │ 0.183681       │
# │ 12  │ 8685     │ 0.2     │ 0.175995  │ 0.222712       │
# │ 13  │ 8691     │ 0.2     │ 0.121833  │ 0.200841       │
# │ 14  │ 8694     │ -0.2    │ 0.0       │ -0.202173      │
# │ 15  │ 8698     │ 0.2     │ 0.0       │ 0.185216       │
#
#
# running 22 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 2088     │ -0.2    │ -0.160397 │ -0.145914      │
# │ 2   │ 2604     │ 0.2     │ 0.165369  │ 0.172674       │
# │ 3   │ 2616     │ 0.2     │ 0.259743  │ 0.264232       │
# │ 4   │ 3747     │ -0.2    │ -0.191361 │ -0.192156      │
# │ 5   │ 3753     │ -0.2    │ -0.227993 │ -0.238549      │
# │ 6   │ 3754     │ -0.2    │ -0.196783 │ -0.187806      │
# │ 7   │ 4864     │ -0.2    │ -0.22961  │ -0.236478      │
# │ 8   │ 4866     │ 0.2     │ 0.164581  │ 0.172278       │
# │ 9   │ 4869     │ 0.2     │ 0.162769  │ 0.16089        │
# │ 10  │ 4878     │ -0.2    │ -0.193072 │ -0.193146      │
# │ 11  │ 8383     │ 0.2     │ 0.129875  │ 0.167134       │
# │ 12  │ 8389     │ 0.2     │ 0.360729  │ 0.319704       │
# │ 13  │ 8394     │ -0.2    │ 0.0       │ -0.124191      │
# │ 14  │ 8396     │ -0.2    │ 0.0       │ 0.0            │
# │ 15  │ 8398     │ -0.2    │ 0.0       │ 0.0            │
#
#
# running 23 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 3242     │ 0.2     │ 0.177718  │ 0.17957        │
# │ 2   │ 3956     │ 0.2     │ 0.10157   │ 0.0802299      │
# │ 3   │ 3960     │ -0.2    │ 0.0       │ 0.0            │
# │ 4   │ 4041     │ 0.2     │ 0.211971  │ 0.221878       │
# │ 5   │ 4049     │ 0.2     │ 0.168382  │ 0.167141       │
# │ 6   │ 4059     │ -0.2    │ -0.196312 │ -0.19557       │
# │ 7   │ 4583     │ 0.2     │ 0.217979  │ 0.214601       │
# │ 8   │ 4594     │ -0.2    │ -0.20896  │ -0.216652      │
# │ 9   │ 4597     │ 0.2     │ 0.19985   │ 0.177686       │
# │ 10  │ 4598     │ 0.2     │ 0.199753  │ 0.20955        │
# │ 11  │ 9905     │ 0.2     │ 0.139426  │ 0.183935       │
# │ 12  │ 9908     │ 0.2     │ 0.0       │ 0.0            │
# │ 13  │ 9914     │ -0.2    │ 0.0       │ -0.125311      │
# │ 14  │ 9918     │ -0.2    │ -0.21733  │ -0.214891      │
# │ 15  │ 9919     │ -0.2    │ -0.172309 │ -0.172097      │
#
#
# running 24 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 4831     │ 0.2     │ 0.169749  │ 0.159442       │
# │ 2   │ 5402     │ 0.2     │ 0.229293  │ 0.237761       │
# │ 3   │ 5413     │ -0.2    │ -0.185199 │ -0.199555      │
# │ 4   │ 6784     │ -0.2    │ -0.216263 │ -0.222339      │
# │ 5   │ 6790     │ 0.2     │ 0.0       │ 0.15198        │
# │ 6   │ 6791     │ 0.2     │ 0.274772  │ 0.21503        │
# │ 7   │ 7988     │ -0.2    │ -0.24279  │ -0.23003       │
# │ 8   │ 7991     │ -0.2    │ -0.236292 │ -0.22278       │
# │ 9   │ 7996     │ 0.2     │ 0.240697  │ 0.240104       │
# │ 10  │ 7998     │ 0.2     │ 0.149009  │ 0.158465       │
# │ 11  │ 9003     │ 0.2     │ 0.0       │ 0.110994       │
# │ 12  │ 9005     │ -0.2    │ 0.0       │ 0.0            │
# │ 13  │ 9013     │ -0.2    │ 0.0       │ 0.0            │
# │ 14  │ 9015     │ 0.2     │ 0.15884   │ 0.121701       │
# │ 15  │ 9018     │ 0.2     │ 0.0       │ 0.0            │
#
#
# running 25 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 1473     │ -0.2    │ -0.189189 │ -0.196653      │
# │ 2   │ 2641     │ 0.2     │ 0.204214  │ 0.0            │
# │ 3   │ 2643     │ 0.2     │ 0.281207  │ 0.137279       │
# │ 4   │ 3447     │ 0.2     │ 0.16837   │ 0.177101       │
# │ 5   │ 3454     │ -0.2    │ -0.215827 │ -0.220031      │
# │ 6   │ 3460     │ 0.2     │ 0.190093  │ 0.196324       │
# │ 7   │ 4223     │ 0.2     │ 0.073439  │ 0.0            │
# │ 8   │ 4234     │ -0.2    │ -0.269726 │ -0.248957      │
# │ 9   │ 4237     │ -0.2    │ -0.205757 │ -0.135268      │
# │ 10  │ 4238     │ -0.2    │ -0.158684 │ -0.168838      │
# │ 11  │ 5562     │ -0.2    │ -0.242524 │ -0.275929      │
# │ 12  │ 5563     │ -0.2    │ -0.150014 │ -0.170429      │
# │ 13  │ 5577     │ 0.2     │ 0.223317  │ 0.0            │
# │ 14  │ 5578     │ 0.2     │ 0.211866  │ 0.19928        │
# │ 15  │ 5580     │ 0.2     │ 0.203253  │ 0.192876       │
#
#
# running 26 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 3597     │ 0.2     │ 0.205971  │ 0.219832       │
# │ 2   │ 5150     │ 0.2     │ 0.216177  │ 0.217947       │
# │ 3   │ 5157     │ -0.2    │ -0.210494 │ -0.210575      │
# │ 4   │ 5542     │ 0.2     │ 0.0       │ 0.0952661      │
# │ 5   │ 5549     │ 0.2     │ 0.0       │ 0.0            │
# │ 6   │ 5550     │ -0.2    │ 0.0       │ 0.0            │
# │ 7   │ 6801     │ 0.2     │ 0.197976  │ 0.208419       │
# │ 8   │ 6802     │ 0.2     │ 0.223966  │ 0.207626       │
# │ 9   │ 6806     │ -0.2    │ -0.183146 │ -0.197444      │
# │ 10  │ 6810     │ -0.2    │ -0.175306 │ -0.181306      │
# │ 11  │ 8582     │ 0.2     │ 0.165604  │ 0.142441       │
# │ 12  │ 8586     │ 0.2     │ 0.285644  │ 0.254863       │
# │ 13  │ 8590     │ 0.2     │ 0.0       │ 0.0            │
# │ 14  │ 8599     │ -0.2    │ 0.0       │ -0.119586      │
# │ 15  │ 8600     │ 0.2     │ 0.0       │ 0.126828       │
#
#
# running 27 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 1774     │ -0.2    │ -0.143975 │ -0.220639      │
# │ 2   │ 4050     │ 0.2     │ 0.170262  │ 0.0            │
# │ 3   │ 4055     │ -0.2    │ -0.181072 │ -0.152122      │
# │ 4   │ 7851     │ -0.2    │ 0.0       │ -0.172998      │
# │ 5   │ 7853     │ 0.2     │ 0.114859  │ 0.233919       │
# │ 6   │ 7856     │ 0.2     │ 0.217863  │ 0.221745       │
# │ 7   │ 7873     │ 0.2     │ 0.0       │ 0.143295       │
# │ 8   │ 7874     │ -0.2    │ 0.0       │ -0.161852      │
# │ 9   │ 7875     │ 0.2     │ 0.153012  │ 0.197592       │
# │ 10  │ 7878     │ 0.2     │ 0.18967   │ 0.227651       │
# │ 11  │ 8463     │ 0.2     │ 0.0       │ 0.0            │
# │ 12  │ 8469     │ -0.2    │ -0.234944 │ -0.228392      │
# │ 13  │ 8471     │ 0.2     │ 0.0       │ 0.0            │
# │ 14  │ 8477     │ 0.2     │ 0.240152  │ 0.251073       │
# │ 15  │ 8479     │ 0.2     │ 0.144088  │ 0.172671       │
#
#
# running 28 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 866      │ 0.2     │ 0.191804  │ 0.196554       │
# │ 2   │ 2462     │ 0.2     │ 0.214432  │ 0.213149       │
# │ 3   │ 2467     │ 0.2     │ 0.155966  │ 0.144564       │
# │ 4   │ 3943     │ 0.2     │ 0.0       │ 0.175071       │
# │ 5   │ 3945     │ 0.2     │ 0.254917  │ 0.27379        │
# │ 6   │ 3947     │ -0.2    │ -0.214918 │ -0.236288      │
# │ 7   │ 4325     │ -0.2    │ -0.223724 │ -0.219792      │
# │ 8   │ 4330     │ 0.2     │ 0.31538   │ 0.313237       │
# │ 9   │ 4331     │ 0.2     │ 0.0810707 │ 0.0902864      │
# │ 10  │ 4333     │ -0.2    │ -0.220879 │ -0.213883      │
# │ 11  │ 4942     │ 0.2     │ 0.142356  │ 0.118514       │
# │ 12  │ 4944     │ 0.2     │ 0.0       │ 0.0            │
# │ 13  │ 4946     │ -0.2    │ 0.0       │ -0.116949      │
# │ 14  │ 4947     │ 0.2     │ 0.16585   │ 0.0810069      │
# │ 15  │ 4948     │ 0.2     │ 0.148778  │ 0.290835       │
#
#
# running 29 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 1844     │ 0.2     │ 0.160592  │ 0.16706        │
# │ 2   │ 3621     │ 0.2     │ 0.132054  │ 0.139823       │
# │ 3   │ 3636     │ 0.2     │ 0.219836  │ 0.200098       │
# │ 4   │ 7843     │ -0.2    │ -0.226896 │ 0.0            │
# │ 5   │ 7847     │ 0.2     │ 0.249959  │ 0.242553       │
# │ 6   │ 7849     │ -0.2    │ -0.116497 │ 0.0            │
# │ 7   │ 8387     │ 0.2     │ 0.162684  │ 0.221412       │
# │ 8   │ 8388     │ -0.2    │ -0.209595 │ -0.231207      │
# │ 9   │ 8392     │ -0.2    │ -0.211809 │ -0.199987      │
# │ 10  │ 8399     │ -0.2    │ 0.0       │ -0.153812      │
# │ 11  │ 8823     │ -0.2    │ 0.0       │ -0.0579871     │
# │ 12  │ 8824     │ 0.2     │ 0.0       │ 0.0            │
# │ 13  │ 8828     │ 0.2     │ 0.203345  │ 0.216373       │
# │ 14  │ 8838     │ -0.2    │ 0.0       │ 0.0            │
# │ 15  │ 8839     │ 0.2     │ 0.195629  │ 0.168616       │
#
#
# running 30 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 1219     │ 0.2     │ 0.165214  │ 0.181819       │
# │ 2   │ 1627     │ -0.2    │ -0.194465 │ -0.18642       │
# │ 3   │ 1629     │ 0.2     │ 0.167579  │ 0.173365       │
# │ 4   │ 4150     │ 0.2     │ 0.200002  │ 0.189214       │
# │ 5   │ 4157     │ 0.2     │ 0.142778  │ 0.152294       │
# │ 6   │ 4159     │ -0.2    │ -0.217236 │ -0.214441      │
# │ 7   │ 4201     │ 0.2     │ 0.143985  │ 0.168017       │
# │ 8   │ 4204     │ 0.2     │ 0.191653  │ 0.220599       │
# │ 9   │ 4208     │ -0.2    │ 0.0       │ 0.0            │
# │ 10  │ 4213     │ -0.2    │ 0.0       │ -0.149706      │
# │ 11  │ 7885     │ 0.2     │ 0.190949  │ 0.196801       │
# │ 12  │ 7888     │ 0.2     │ 0.182104  │ 0.186231       │
# │ 13  │ 7891     │ 0.2     │ 0.150812  │ 0.160019       │
# │ 14  │ 7894     │ 0.2     │ 0.14835   │ 0.147623       │
# │ 15  │ 7895     │ 0.2     │ 0.270191  │ 0.268386       │
#
#
# running 31 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped  │ variable_group │
# │     │ Int64    │ Float64 │ Float64    │ Float64        │
# ├─────┼──────────┼─────────┼────────────┼────────────────┤
# │ 1   │ 933      │ -0.2    │ -0.253912  │ -0.254233      │
# │ 2   │ 2471     │ 0.2     │ 0.192029   │ 0.191044       │
# │ 3   │ 2480     │ -0.2    │ -0.216686  │ -0.213489      │
# │ 4   │ 2522     │ -0.2    │ 0.0        │ 0.0            │
# │ 5   │ 2523     │ 0.2     │ 0.0        │ 0.0            │
# │ 6   │ 2531     │ 0.2     │ 0.172114   │ 0.175375       │
# │ 7   │ 4266     │ 0.2     │ 0.184829   │ 0.185492       │
# │ 8   │ 4267     │ 0.2     │ 0.184511   │ 0.19099        │
# │ 9   │ 4269     │ 0.2     │ 0.204105   │ 0.200023       │
# │ 10  │ 4272     │ -0.2    │ -0.201579  │ -0.189701      │
# │ 11  │ 7947     │ -0.2    │ -0.0997509 │ -0.130413      │
# │ 12  │ 7948     │ 0.2     │ 0.0        │ 0.0            │
# │ 13  │ 7951     │ -0.2    │ -0.166726  │ -0.161809      │
# │ 14  │ 7955     │ -0.2    │ -0.212261  │ -0.192082      │
# │ 15  │ 7957     │ -0.2    │ -0.162391  │ -0.177824      │
#
#
# running 32 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 5618     │ -0.2    │ -0.149957 │ -0.163315      │
# │ 2   │ 6733     │ 0.2     │ 0.0       │ 0.0            │
# │ 3   │ 6736     │ 0.2     │ 0.187514  │ 0.149267       │
# │ 4   │ 7542     │ -0.2    │ -0.245875 │ -0.249952      │
# │ 5   │ 7543     │ -0.2    │ -0.213429 │ -0.223923      │
# │ 6   │ 7544     │ 0.2     │ 0.251748  │ 0.244867       │
# │ 7   │ 8783     │ -0.2    │ -0.138367 │ -0.194007      │
# │ 8   │ 8790     │ -0.2    │ -0.233046 │ -0.188459      │
# │ 9   │ 8794     │ 0.2     │ 0.0       │ 0.158504       │
# │ 10  │ 8795     │ -0.2    │ 0.0       │ -0.18128       │
# │ 11  │ 9783     │ -0.2    │ -0.195659 │ -0.182171      │
# │ 12  │ 9786     │ -0.2    │ 0.0       │ 0.0            │
# │ 13  │ 9787     │ 0.2     │ 0.0       │ 0.0            │
# │ 14  │ 9789     │ 0.2     │ 0.215876  │ 0.217772       │
# │ 15  │ 9797     │ 0.2     │ 0.14786   │ 0.130668       │
#
#
# running 33 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 3494     │ 0.2     │ 0.213598  │ 0.223055       │
# │ 2   │ 4205     │ -0.2    │ -0.219496 │ -0.221603      │
# │ 3   │ 4211     │ -0.2    │ -0.16832  │ -0.171601      │
# │ 4   │ 5185     │ -0.2    │ -0.222123 │ -0.207006      │
# │ 5   │ 5191     │ 0.2     │ 0.191597  │ 0.184509       │
# │ 6   │ 5198     │ 0.2     │ 0.0       │ 0.0            │
# │ 7   │ 9649     │ -0.2    │ 0.0       │ 0.0            │
# │ 8   │ 9651     │ -0.2    │ 0.0       │ 0.0            │
# │ 9   │ 9653     │ 0.2     │ 0.116896  │ 0.107758       │
# │ 10  │ 9654     │ 0.2     │ 0.242624  │ 0.241898       │
# │ 11  │ 9722     │ 0.2     │ 0.172691  │ 0.177582       │
# │ 12  │ 9724     │ 0.2     │ 0.170706  │ 0.177461       │
# │ 13  │ 9734     │ 0.2     │ 0.0       │ 0.0            │
# │ 14  │ 9735     │ -0.2    │ 0.0       │ 0.0            │
# │ 15  │ 9736     │ -0.2    │ -0.24808  │ -0.262752      │
#
#
# running 34 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 1480     │ -0.2    │ -0.179203 │ -0.185028      │
# │ 2   │ 1647     │ 0.2     │ 0.236442  │ 0.23645        │
# │ 3   │ 1652     │ -0.2    │ -0.229387 │ -0.226955      │
# │ 4   │ 6401     │ 0.2     │ 0.0       │ 0.0964505      │
# │ 5   │ 6405     │ -0.2    │ 0.0       │ 0.0            │
# │ 6   │ 6419     │ 0.2     │ 0.0       │ 0.0            │
# │ 7   │ 6642     │ 0.2     │ 0.126304  │ 0.139261       │
# │ 8   │ 6651     │ -0.2    │ -0.190834 │ -0.178488      │
# │ 9   │ 6655     │ 0.2     │ 0.153193  │ 0.165184       │
# │ 10  │ 6660     │ -0.2    │ -0.224901 │ -0.233875      │
# │ 11  │ 8504     │ -0.2    │ -0.091779 │ -0.150302      │
# │ 12  │ 8505     │ -0.2    │ -0.298374 │ -0.230144      │
# │ 13  │ 8514     │ -0.2    │ -0.246431 │ -0.217602      │
# │ 14  │ 8516     │ 0.2     │ 0.0       │ 0.173103       │
# │ 15  │ 8518     │ -0.2    │ 0.0       │ 0.0            │
#
#
# running 35 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 146      │ 0.2     │ 0.179507  │ 0.182304       │
# │ 2   │ 3682     │ -0.2    │ -0.194598 │ -0.187874      │
# │ 3   │ 3697     │ 0.2     │ 0.137373  │ 0.150037       │
# │ 4   │ 7007     │ -0.2    │ -0.152308 │ -0.15585       │
# │ 5   │ 7011     │ -0.2    │ -0.231048 │ -0.222854      │
# │ 6   │ 7014     │ 0.2     │ 0.205064  │ 0.20132        │
# │ 7   │ 7827     │ -0.2    │ -0.165347 │ -0.178143      │
# │ 8   │ 7830     │ -0.2    │ 0.0       │ -0.187935      │
# │ 9   │ 7834     │ -0.2    │ -0.203735 │ -0.227288      │
# │ 10  │ 7840     │ 0.2     │ 0.16717   │ 0.173838       │
# │ 11  │ 9047     │ -0.2    │ -0.335275 │ -0.2871        │
# │ 12  │ 9049     │ -0.2    │ 0.0       │ 0.0            │
# │ 13  │ 9050     │ 0.2     │ 0.0       │ 0.0            │
# │ 14  │ 9056     │ -0.2    │ -0.157203 │ -0.159811      │
# │ 15  │ 9060     │ 0.2     │ 0.275993  │ 0.270184       │
#
#
# running 36 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 731      │ -0.2    │ -0.162401 │ -0.161041      │
# │ 2   │ 4221     │ 0.2     │ 0.179383  │ 0.175608       │
# │ 3   │ 4234     │ 0.2     │ 0.177741  │ 0.171919       │
# │ 4   │ 4272     │ 0.2     │ 0.249373  │ 0.254876       │
# │ 5   │ 4276     │ -0.2    │ -0.213845 │ -0.214921      │
# │ 6   │ 4277     │ -0.2    │ -0.178169 │ -0.175264      │
# │ 7   │ 4885     │ -0.2    │ -0.205718 │ -0.205146      │
# │ 8   │ 4893     │ 0.2     │ 0.181654  │ 0.203474       │
# │ 9   │ 4895     │ 0.2     │ 0.267003  │ 0.21408        │
# │ 10  │ 4896     │ 0.2     │ 0.0       │ 0.166179       │
# │ 11  │ 6821     │ 0.2     │ 0.223193  │ 0.177699       │
# │ 12  │ 6822     │ 0.2     │ 0.188152  │ 0.181979       │
# │ 13  │ 6824     │ -0.2    │ -0.286484 │ -0.347013      │
# │ 14  │ 6829     │ 0.2     │ 0.163912  │ 0.0            │
# │ 15  │ 6830     │ -0.2    │ -0.212541 │ -0.147386      │
#
#
# running 37 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 971      │ 0.2     │ 0.238965  │ 0.233628       │
# │ 2   │ 2147     │ -0.2    │ -0.226186 │ -0.222796      │
# │ 3   │ 2151     │ -0.2    │ -0.190263 │ -0.187595      │
# │ 4   │ 3022     │ -0.2    │ -0.114087 │ -0.165432      │
# │ 5   │ 3029     │ -0.2    │ -0.167866 │ -0.175551      │
# │ 6   │ 3031     │ 0.2     │ 0.0       │ 0.108733       │
# │ 7   │ 8587     │ -0.2    │ -0.136167 │ -0.153976      │
# │ 8   │ 8588     │ -0.2    │ -0.262474 │ -0.242617      │
# │ 9   │ 8593     │ 0.2     │ 0.193802  │ 0.193429       │
# │ 10  │ 8594     │ 0.2     │ 0.130536  │ 0.12886        │
# │ 11  │ 9582     │ -0.2    │ 0.0       │ -0.108019      │
# │ 12  │ 9585     │ -0.2    │ 0.0       │ 0.0            │
# │ 13  │ 9588     │ -0.2    │ -0.244749 │ -0.222874      │
# │ 14  │ 9594     │ 0.2     │ 0.116049  │ 0.131792       │
# │ 15  │ 9598     │ -0.2    │ 0.0       │ 0.0            │
#
#
# running 38 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 6349     │ 0.2     │ 0.183269  │ 0.183266       │
# │ 2   │ 8212     │ 0.2     │ 0.235432  │ 0.235419       │
# │ 3   │ 8215     │ 0.2     │ 0.161704  │ 0.161681       │
# │ 4   │ 9283     │ 0.2     │ 0.191388  │ 0.191354       │
# │ 5   │ 9293     │ -0.2    │ 0.0       │ 0.0            │
# │ 6   │ 9298     │ -0.2    │ -0.165565 │ -0.165576      │
# │ 7   │ 9353     │ -0.2    │ 0.0       │ 0.0            │
# │ 8   │ 9355     │ -0.2    │ -0.212244 │ -0.212294      │
# │ 9   │ 9356     │ -0.2    │ 0.0       │ 0.0            │
# │ 10  │ 9359     │ -0.2    │ -0.173549 │ -0.173593      │
# │ 11  │ 9785     │ 0.2     │ 0.183866  │ 0.183738       │
# │ 12  │ 9786     │ -0.2    │ -0.212435 │ -0.21237       │
# │ 13  │ 9788     │ -0.2    │ -0.185304 │ -0.185189      │
# │ 14  │ 9793     │ -0.2    │ -0.260976 │ -0.261101      │
# │ 15  │ 9798     │ -0.2    │ -0.217652 │ -0.217664      │
#
#
# running 39 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 750      │ -0.2    │ -0.205054 │ -0.201719      │
# │ 2   │ 3591     │ 0.2     │ 0.182739  │ 0.0            │
# │ 3   │ 3594     │ 0.2     │ 0.23635   │ 0.189006       │
# │ 4   │ 5314     │ -0.2    │ 0.0       │ 0.0            │
# │ 5   │ 5316     │ -0.2    │ 0.0       │ 0.0            │
# │ 6   │ 5318     │ 0.2     │ 0.163266  │ 0.162513       │
# │ 7   │ 5901     │ -0.2    │ -0.156158 │ -0.146987      │
# │ 8   │ 5905     │ -0.2    │ -0.28757  │ -0.279668      │
# │ 9   │ 5916     │ -0.2    │ -0.180776 │ -0.19283       │
# │ 10  │ 5919     │ 0.2     │ 0.175725  │ 0.185596       │
# │ 11  │ 6788     │ -0.2    │ -0.169955 │ 0.0            │
# │ 12  │ 6791     │ 0.2     │ 0.145403  │ 0.105609       │
# │ 13  │ 6795     │ -0.2    │ -0.266911 │ -0.165133      │
# │ 14  │ 6796     │ -0.2    │ -0.11033  │ -0.212617      │
# │ 15  │ 6799     │ -0.2    │ 0.0       │ -0.165335      │
#
#
# running 40 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 2106     │ 0.2     │ 0.234331  │ 0.227249       │
# │ 2   │ 5202     │ -0.2    │ -0.230198 │ -0.213836      │
# │ 3   │ 5210     │ 0.2     │ 0.179415  │ 0.177806       │
# │ 4   │ 7150     │ -0.2    │ 0.0       │ 0.0            │
# │ 5   │ 7154     │ 0.2     │ 0.0       │ 0.0            │
# │ 6   │ 7159     │ -0.2    │ -0.210702 │ -0.20513       │
# │ 7   │ 8288     │ 0.2     │ 0.11837   │ 0.0            │
# │ 8   │ 8290     │ 0.2     │ 0.0       │ 0.0            │
# │ 9   │ 8296     │ -0.2    │ 0.0       │ -0.159278      │
# │ 10  │ 8300     │ -0.2    │ 0.0       │ 0.0            │
# │ 11  │ 9842     │ 0.2     │ 0.0       │ 0.106014       │
# │ 12  │ 9846     │ -0.2    │ 0.0       │ -0.149478      │
# │ 13  │ 9856     │ 0.2     │ 0.384981  │ 0.298769       │
# │ 14  │ 9858     │ -0.2    │ 0.0       │ -0.0604624     │
# │ 15  │ 9859     │ 0.2     │ 0.0       │ 0.0            │
#
#
# running 41 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 1067     │ -0.2    │ -0.183398 │ -0.173233      │
# │ 2   │ 1262     │ -0.2    │ -0.151341 │ -0.1502        │
# │ 3   │ 1280     │ 0.2     │ 0.196922  │ 0.191376       │
# │ 4   │ 1947     │ 0.2     │ 0.141614  │ 0.155707       │
# │ 5   │ 1951     │ 0.2     │ 0.176372  │ 0.195834       │
# │ 6   │ 1953     │ 0.2     │ 0.156321  │ 0.146659       │
# │ 7   │ 2388     │ 0.2     │ 0.276398  │ 0.247165       │
# │ 8   │ 2392     │ 0.2     │ 0.0       │ 0.201355       │
# │ 9   │ 2397     │ -0.2    │ -0.228535 │ -0.200197      │
# │ 10  │ 2399     │ -0.2    │ -0.137194 │ -0.196299      │
# │ 11  │ 7185     │ 0.2     │ 0.209446  │ 0.0            │
# │ 12  │ 7196     │ -0.2    │ -0.185872 │ -0.151714      │
# │ 13  │ 7197     │ 0.2     │ 0.222108  │ 0.0            │
# │ 14  │ 7198     │ -0.2    │ -0.20288  │ 0.0            │
# │ 15  │ 7199     │ -0.2    │ -0.206536 │ -0.129837      │
#
#
# running 42 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 3655     │ -0.2    │ -0.20072  │ -0.200843      │
# │ 2   │ 6229     │ 0.2     │ 0.22454   │ 0.229828       │
# │ 3   │ 6236     │ -0.2    │ -0.162147 │ -0.158677      │
# │ 4   │ 6971     │ 0.2     │ 0.0       │ 0.0            │
# │ 5   │ 6979     │ 0.2     │ 0.0       │ 0.0            │
# │ 6   │ 6980     │ -0.2    │ 0.0       │ 0.0            │
# │ 7   │ 7046     │ -0.2    │ -0.271636 │ -0.273631      │
# │ 8   │ 7049     │ -0.2    │ -0.246442 │ -0.239463      │
# │ 9   │ 7054     │ 0.2     │ 0.247987  │ 0.253252       │
# │ 10  │ 7059     │ -0.2    │ -0.240434 │ -0.240716      │
# │ 11  │ 9562     │ 0.2     │ 0.0       │ 0.150474       │
# │ 12  │ 9563     │ -0.2    │ -0.17447  │ -0.217688      │
# │ 13  │ 9567     │ -0.2    │ -0.195402 │ -0.208607      │
# │ 14  │ 9569     │ -0.2    │ -0.125933 │ -0.170043      │
# │ 15  │ 9574     │ 0.2     │ 0.162856  │ 0.201847       │
#
#
# running 43 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 2917     │ 0.2     │ 0.237376  │ 0.241942       │
# │ 2   │ 6522     │ 0.2     │ 0.20085   │ 0.197432       │
# │ 3   │ 6534     │ 0.2     │ 0.253904  │ 0.233975       │
# │ 4   │ 6681     │ -0.2    │ -0.211836 │ -0.204033      │
# │ 5   │ 6694     │ -0.2    │ -0.216575 │ 0.0            │
# │ 6   │ 6696     │ 0.2     │ 0.205694  │ 0.0            │
# │ 7   │ 8365     │ -0.2    │ -0.168564 │ -0.141625      │
# │ 8   │ 8368     │ -0.2    │ -0.162634 │ -0.136296      │
# │ 9   │ 8374     │ 0.2     │ 0.0       │ 0.0            │
# │ 10  │ 8375     │ -0.2    │ 0.0       │ 0.0            │
# │ 11  │ 9147     │ 0.2     │ 0.223542  │ 0.196447       │
# │ 12  │ 9152     │ 0.2     │ 0.168618  │ 0.215207       │
# │ 13  │ 9154     │ -0.2    │ 0.0       │ -0.108183      │
# │ 14  │ 9159     │ -0.2    │ 0.0       │ 0.0            │
# │ 15  │ 9160     │ 0.2     │ 0.135057  │ 0.155868       │
#
#
# running 44 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 414      │ -0.2    │ -0.19446  │ -0.193174      │
# │ 2   │ 2709     │ 0.2     │ 0.219103  │ 0.218182       │
# │ 3   │ 2720     │ 0.2     │ 0.167678  │ 0.162595       │
# │ 4   │ 3492     │ 0.2     │ 0.205243  │ 0.219332       │
# │ 5   │ 3494     │ -0.2    │ -0.263514 │ -0.274912      │
# │ 6   │ 3497     │ -0.2    │ -0.239888 │ -0.247102      │
# │ 7   │ 4007     │ -0.2    │ -0.228225 │ -0.191484      │
# │ 8   │ 4009     │ 0.2     │ 0.197614  │ 0.130363       │
# │ 9   │ 4011     │ -0.2    │ -0.177505 │ -0.242807      │
# │ 10  │ 4018     │ -0.2    │ -0.232363 │ 0.0            │
# ...
# │ 7   │ 5928     │ -0.2    │ -0.179332 │ -0.181957      │
# │ 8   │ 5929     │ -0.2    │ 0.0       │ 0.0            │
# │ 9   │ 5932     │ 0.2     │ 0.186673  │ 0.194111       │
# │ 10  │ 5935     │ 0.2     │ 0.205705  │ 0.213246       │
# │ 11  │ 7844     │ 0.2     │ 0.182101  │ 0.0            │
# │ 12  │ 7847     │ 0.2     │ 0.202183  │ 0.104298       │
# │ 13  │ 7851     │ -0.2    │ 0.0       │ -0.143297      │
# │ 14  │ 7854     │ 0.2     │ 0.0988843 │ 0.326381       │
# │ 15  │ 7857     │ -0.2    │ -0.278765 │ 0.0            │
#
#
# running 87 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 962      │ -0.2    │ -0.226171 │ -0.226172      │
# │ 2   │ 1182     │ -0.2    │ -0.188423 │ -0.188422      │
# │ 3   │ 1189     │ 0.2     │ 0.235505  │ 0.235513       │
# │ 4   │ 2283     │ 0.2     │ 0.196567  │ 0.196573       │
# │ 5   │ 2289     │ 0.2     │ 0.185562  │ 0.185575       │
# │ 6   │ 2294     │ -0.2    │ -0.155688 │ -0.155706      │
# │ 7   │ 6486     │ -0.2    │ -0.202538 │ -0.20254       │
# │ 8   │ 6492     │ -0.2    │ -0.161283 │ -0.161287      │
# │ 9   │ 6495     │ -0.2    │ -0.193403 │ -0.193397      │
# │ 10  │ 6499     │ -0.2    │ -0.192375 │ -0.192371      │
# │ 11  │ 9003     │ 0.2     │ 0.207851  │ 0.207913       │
# │ 12  │ 9006     │ -0.2    │ -0.244076 │ -0.244091      │
# │ 13  │ 9007     │ -0.2    │ -0.176945 │ -0.176893      │
# │ 14  │ 9013     │ -0.2    │ -0.251413 │ -0.251399      │
# │ 15  │ 9018     │ 0.2     │ 0.221486  │ 0.221519       │
#
#
# running 88 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 416      │ 0.2     │ 0.161844  │ 0.151532       │
# │ 2   │ 521      │ -0.2    │ -0.207544 │ -0.198852      │
# │ 3   │ 523      │ -0.2    │ -0.165678 │ -0.169135      │
# │ 4   │ 604      │ -0.2    │ 0.0       │ 0.0            │
# │ 5   │ 616      │ -0.2    │ 0.0       │ 0.0            │
# │ 6   │ 620      │ 0.2     │ 0.0       │ 0.0            │
# │ 7   │ 622      │ -0.2    │ -0.199145 │ -0.196814      │
# │ 8   │ 625      │ 0.2     │ 0.247607  │ 0.241605       │
# │ 9   │ 630      │ -0.2    │ -0.150311 │ -0.149454      │
# │ 10  │ 633      │ 0.2     │ 0.132354  │ 0.120589       │
# │ 11  │ 929      │ -0.2    │ 0.0       │ -0.260202      │
# │ 12  │ 933      │ -0.2    │ -0.183636 │ -0.188325      │
# │ 13  │ 937      │ -0.2    │ -0.201589 │ -0.249909      │
# │ 14  │ 939      │ 0.2     │ 0.097903  │ 0.2291         │
# │ 15  │ 940      │ -0.2    │ -0.211855 │ -0.214676      │
#
#
# running 89 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 3371     │ 0.2     │ 0.212089  │ 0.223038       │
# │ 2   │ 3971     │ -0.2    │ -0.200257 │ -0.201955      │
# │ 3   │ 3980     │ -0.2    │ -0.215787 │ -0.221275      │
# │ 4   │ 7081     │ 0.2     │ 0.202756  │ 0.204232       │
# │ 5   │ 7084     │ -0.2    │ -0.147281 │ -0.155344      │
# │ 6   │ 7085     │ -0.2    │ -0.279041 │ -0.277966      │
# │ 7   │ 9430     │ -0.2    │ -0.208825 │ -0.20314       │
# │ 8   │ 9432     │ 0.2     │ 0.196996  │ 0.201095       │
# │ 9   │ 9433     │ -0.2    │ -0.179172 │ -0.175948      │
# │ 10  │ 9439     │ 0.2     │ 0.21295   │ 0.203671       │
# │ 11  │ 9982     │ 0.2     │ 0.11791   │ 0.0            │
# │ 12  │ 9986     │ -0.2    │ 0.0       │ -0.13075       │
# │ 13  │ 9987     │ -0.2    │ -0.24902  │ -0.164688      │
# │ 14  │ 9994     │ 0.2     │ 0.213696  │ 0.23922        │
# │ 15  │ 9997     │ -0.2    │ -0.223054 │ -0.247101      │
#
#
# running 90 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 832      │ -0.2    │ -0.172726 │ -0.176079      │
# │ 2   │ 1235     │ 0.2     │ 0.229633  │ 0.222553       │
# │ 3   │ 1236     │ 0.2     │ 0.178801  │ 0.172566       │
# │ 4   │ 2881     │ -0.2    │ -0.174907 │ -0.18482       │
# │ 5   │ 2895     │ 0.2     │ 0.0960138 │ 0.21859        │
# │ 6   │ 2896     │ -0.2    │ 0.0       │ -0.191622      │
# │ 7   │ 4841     │ 0.2     │ 0.0       │ 0.104708       │
# │ 8   │ 4846     │ 0.2     │ 0.149297  │ 0.0            │
# │ 9   │ 4851     │ 0.2     │ 0.0       │ 0.0            │
# │ 10  │ 4855     │ -0.2    │ -0.200844 │ -0.203104      │
# │ 11  │ 5163     │ 0.2     │ 0.0       │ 0.0            │
# │ 12  │ 5165     │ 0.2     │ 0.0       │ 0.0951797      │
# │ 13  │ 5175     │ 0.2     │ 0.0       │ 0.0            │
# │ 14  │ 5177     │ -0.2    │ 0.0       │ 0.0            │
# │ 15  │ 5180     │ 0.2     │ 0.268791  │ 0.256533       │
#
#
# running 91 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 823      │ 0.2     │ 0.154913  │ 0.154915       │
# │ 2   │ 4173     │ -0.2    │ -0.196845 │ -0.196841      │
# │ 3   │ 4178     │ -0.2    │ -0.180131 │ -0.180137      │
# │ 4   │ 6404     │ 0.2     │ 0.184208  │ 0.184211       │
# │ 5   │ 6411     │ 0.2     │ 0.227352  │ 0.227352       │
# │ 6   │ 6413     │ 0.2     │ 0.196555  │ 0.196558       │
# │ 7   │ 9641     │ -0.2    │ -0.198887 │ -0.198887      │
# │ 8   │ 9649     │ -0.2    │ -0.205223 │ -0.205223      │
# │ 9   │ 9655     │ 0.2     │ 0.227953  │ 0.22796        │
# │ 10  │ 9659     │ 0.2     │ 0.212432  │ 0.212434       │
# │ 11  │ 9725     │ -0.2    │ -0.154167 │ -0.154136      │
# │ 12  │ 9726     │ -0.2    │ -0.159025 │ -0.159081      │
# │ 13  │ 9728     │ 0.2     │ 0.143919  │ 0.143946       │
# │ 14  │ 9730     │ 0.2     │ 0.208606  │ 0.208616       │
# │ 15  │ 9734     │ -0.2    │ 0.0       │ 0.0            │
#
#
# running 92 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 3691     │ -0.2    │ -0.152625 │ -0.159432      │
# │ 2   │ 4167     │ -0.2    │ -0.216633 │ -0.20129       │
# │ 3   │ 4177     │ -0.2    │ -0.153463 │ 0.0            │
# │ 4   │ 4422     │ 0.2     │ 0.238644  │ 0.236167       │
# │ 5   │ 4430     │ 0.2     │ 0.189816  │ 0.205445       │
# │ 6   │ 4431     │ 0.2     │ 0.219963  │ 0.197521       │
# │ 7   │ 9361     │ -0.2    │ -0.18694  │ -0.194972      │
# │ 8   │ 9368     │ 0.2     │ 0.20372   │ 0.21043        │
# │ 9   │ 9374     │ 0.2     │ 0.234939  │ 0.233344       │
# │ 10  │ 9378     │ -0.2    │ -0.195401 │ -0.200484      │
# │ 11  │ 9428     │ 0.2     │ 0.133772  │ 0.169993       │
# │ 12  │ 9431     │ -0.2    │ 0.0       │ -0.118585      │
# │ 13  │ 9433     │ -0.2    │ -0.29377  │ -0.263623      │
# │ 14  │ 9435     │ -0.2    │ -0.227381 │ -0.213904      │
# │ 15  │ 9439     │ -0.2    │ -0.222493 │ -0.220454      │
#
#
# running 93 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 2383     │ 0.2     │ 0.191678  │ 0.193293       │
# │ 2   │ 6376     │ 0.2     │ 0.224012  │ 0.207303       │
# │ 3   │ 6380     │ -0.2    │ -0.132029 │ -0.194139      │
# │ 4   │ 6442     │ -0.2    │ -0.234093 │ -0.250787      │
# │ 5   │ 6445     │ 0.2     │ 0.206762  │ 0.215145       │
# │ 6   │ 6459     │ 0.2     │ 0.178948  │ 0.165767       │
# │ 7   │ 7145     │ -0.2    │ -0.215158 │ -0.215985      │
# │ 8   │ 7147     │ -0.2    │ -0.205839 │ -0.202681      │
# │ 9   │ 7154     │ 0.2     │ 0.174672  │ 0.192011       │
# │ 10  │ 7160     │ -0.2    │ -0.220976 │ -0.231313      │
# │ 11  │ 8524     │ 0.2     │ 0.14568   │ 0.097827       │
# │ 12  │ 8527     │ -0.2    │ 0.0       │ 0.0            │
# │ 13  │ 8534     │ -0.2    │ 0.0       │ 0.0            │
# │ 14  │ 8535     │ -0.2    │ -0.168197 │ -0.152845      │
# │ 15  │ 8536     │ 0.2     │ 0.0       │ 0.0            │
#
#
# running 94 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 6434     │ 0.2     │ 0.274789  │ 0.27827        │
# │ 2   │ 6554     │ 0.2     │ 0.171259  │ 0.191182       │
# │ 3   │ 6559     │ -0.2    │ -0.201478 │ -0.217811      │
# │ 4   │ 7221     │ 0.2     │ 0.193468  │ 0.209743       │
# │ 5   │ 7227     │ -0.2    │ -0.203517 │ -0.210134      │
# │ 6   │ 7237     │ 0.2     │ 0.243185  │ 0.249612       │
# │ 7   │ 7884     │ 0.2     │ 0.239529  │ 0.248042       │
# │ 8   │ 7890     │ -0.2    │ -0.186533 │ -0.179811      │
# │ 9   │ 7894     │ -0.2    │ -0.234337 │ -0.24146       │
# │ 10  │ 7899     │ -0.2    │ -0.167208 │ -0.159916      │
# │ 11  │ 9009     │ 0.2     │ 0.0       │ 0.159737       │
# │ 12  │ 9011     │ -0.2    │ 0.0       │ -0.117833      │
# │ 13  │ 9016     │ 0.2     │ 0.0       │ 0.0            │
# │ 14  │ 9017     │ -0.2    │ 0.0       │ 0.0            │
# │ 15  │ 9018     │ 0.2     │ 0.114457  │ 0.126891       │
#
#
# running 95 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 2204     │ 0.2     │ 0.207883  │ 0.201805       │
# │ 2   │ 4423     │ -0.2    │ -0.242836 │ -0.235436      │
# │ 3   │ 4426     │ -0.2    │ -0.21579  │ -0.215489      │
# │ 4   │ 6726     │ 0.2     │ 0.255991  │ 0.257406       │
# │ 5   │ 6727     │ 0.2     │ 0.245433  │ 0.248786       │
# │ 6   │ 6737     │ 0.2     │ 0.189681  │ 0.197378       │
# │ 7   │ 8283     │ 0.2     │ 0.168948  │ 0.0            │
# │ 8   │ 8291     │ -0.2    │ -0.225767 │ -0.22641       │
# │ 9   │ 8292     │ -0.2    │ -0.169495 │ -0.147295      │
# │ 10  │ 8295     │ 0.2     │ 0.224562  │ 0.192257       │
# │ 11  │ 9622     │ -0.2    │ -0.181249 │ -0.177         │
# │ 12  │ 9624     │ 0.2     │ 0.153556  │ 0.152628       │
# │ 13  │ 9626     │ -0.2    │ -0.182612 │ -0.181688      │
# │ 14  │ 9632     │ -0.2    │ -0.219934 │ -0.216804      │
# │ 15  │ 9635     │ -0.2    │ -0.177288 │ -0.174973      │
#
#
# running 96 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 2895     │ -0.2    │ -0.198067 │ -0.192405      │
# │ 2   │ 3714     │ 0.2     │ 0.171257  │ 0.125787       │
# │ 3   │ 3715     │ -0.2    │ -0.170163 │ 0.0            │
# │ 4   │ 4501     │ -0.2    │ -0.233159 │ -0.248194      │
# │ 5   │ 4504     │ -0.2    │ -0.201275 │ -0.197662      │
# │ 6   │ 4518     │ -0.2    │ -0.214901 │ -0.20709       │
# │ 7   │ 8588     │ -0.2    │ -0.207494 │ 0.0            │
# │ 8   │ 8592     │ -0.2    │ -0.188313 │ -0.112272      │
# │ 9   │ 8594     │ -0.2    │ -0.201312 │ -0.277757      │
# │ 10  │ 8600     │ 0.2     │ 0.239621  │ 0.244882       │
# │ 11  │ 9084     │ 0.2     │ 0.16943   │ 0.180114       │
# │ 12  │ 9086     │ -0.2    │ -0.142106 │ -0.14572       │
# │ 13  │ 9087     │ -0.2    │ -0.213757 │ -0.212882      │
# │ 14  │ 9088     │ -0.2    │ -0.20695  │ -0.207742      │
# │ 15  │ 9100     │ 0.2     │ 0.212503  │ 0.198942       │
#
#
# running 97 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 471      │ 0.2     │ 0.210716  │ 0.205414       │
# │ 2   │ 2790     │ 0.2     │ 0.203893  │ 0.201559       │
# │ 3   │ 2796     │ 0.2     │ 0.194347  │ 0.184168       │
# │ 4   │ 4782     │ 0.2     │ 0.250696  │ 0.248421       │
# │ 5   │ 4787     │ -0.2    │ -0.189185 │ -0.19946       │
# │ 6   │ 4800     │ -0.2    │ -0.205413 │ -0.202386      │
# │ 7   │ 8806     │ -0.2    │ -0.183611 │ -0.198989      │
# │ 8   │ 8807     │ -0.2    │ -0.235557 │ -0.224633      │
# │ 9   │ 8808     │ -0.2    │ -0.188966 │ -0.179026      │
# │ 10  │ 8810     │ 0.2     │ 0.178846  │ 0.172633       │
# │ 11  │ 9362     │ -0.2    │ -0.179167 │ -0.176053      │
# │ 12  │ 9369     │ -0.2    │ 0.0       │ -0.190567      │
# │ 13  │ 9370     │ -0.2    │ -0.21674  │ -0.166994      │
# │ 14  │ 9373     │ 0.2     │ 0.0666293 │ 0.216096       │
# │ 15  │ 9380     │ -0.2    │ 0.0       │ -0.18814       │
#
#
# running 98 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 3412     │ 0.2     │ 0.187144  │ 0.189264       │
# │ 2   │ 3423     │ 0.2     │ 0.183102  │ 0.18843        │
# │ 3   │ 3431     │ 0.2     │ 0.193287  │ 0.195518       │
# │ 4   │ 4664     │ 0.2     │ 0.231013  │ 0.222723       │
# │ 5   │ 4667     │ -0.2    │ -0.212975 │ -0.201926      │
# │ 6   │ 4668     │ -0.2    │ -0.202672 │ -0.209212      │
# │ 7   │ 6244     │ 0.2     │ 0.0       │ 0.179253       │
# │ 8   │ 6250     │ 0.2     │ 0.245142  │ 0.222393       │
# │ 9   │ 6254     │ 0.2     │ 0.174062  │ 0.160661       │
# │ 10  │ 6258     │ -0.2    │ -0.189033 │ 0.0            │
# │ 11  │ 8411     │ -0.2    │ -0.262129 │ -0.256105      │
# │ 12  │ 8412     │ -0.2    │ -0.20162  │ -0.204447      │
# │ 13  │ 8415     │ -0.2    │ -0.220321 │ -0.211598      │
# │ 14  │ 8417     │ 0.2     │ 0.204984  │ 0.215729       │
# │ 15  │ 8420     │ 0.2     │ 0.149752  │ 0.15118        │
#
#
# running 99 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 180      │ 0.2     │ 0.19628   │ 0.196212       │
# │ 2   │ 3767     │ -0.2    │ -0.122184 │ -0.14283       │
# │ 3   │ 3776     │ -0.2    │ -0.151053 │ -0.133198      │
# │ 4   │ 4022     │ 0.2     │ 0.230161  │ 0.231242       │
# │ 5   │ 4027     │ 0.2     │ 0.270585  │ 0.26028        │
# │ 6   │ 4037     │ 0.2     │ 0.225238  │ 0.226784       │
# │ 7   │ 6442     │ 0.2     │ 0.236292  │ 0.234367       │
# │ 8   │ 6448     │ -0.2    │ -0.210896 │ -0.215767      │
# │ 9   │ 6450     │ -0.2    │ -0.203827 │ -0.220409      │
# │ 10  │ 6459     │ 0.2     │ 0.202498  │ 0.190937       │
# │ 11  │ 9528     │ -0.2    │ 0.0       │ 0.0            │
# │ 12  │ 9529     │ -0.2    │ 0.0       │ 0.0            │
# │ 13  │ 9530     │ 0.2     │ 0.0       │ 0.0            │
# │ 14  │ 9532     │ 0.2     │ 0.0       │ 0.143761       │
# │ 15  │ 9535     │ -0.2    │ 0.0       │ 0.0            │
#
#
# running 100 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 3162     │ 0.2     │ 0.167714  │ 0.158726       │
# │ 2   │ 3275     │ 0.2     │ 0.217477  │ 0.215699       │
# │ 3   │ 3276     │ 0.2     │ 0.165621  │ 0.159514       │
# │ 4   │ 6065     │ -0.2    │ -0.191816 │ -0.178865      │
# │ 5   │ 6070     │ 0.2     │ 0.260451  │ 0.262688       │
# │ 6   │ 6079     │ 0.2     │ 0.207386  │ 0.195066       │
# │ 7   │ 6086     │ -0.2    │ -0.230154 │ 0.0            │
# │ 8   │ 6087     │ 0.2     │ 0.298441  │ 0.175802       │
# │ 9   │ 6088     │ 0.2     │ 0.119531  │ 0.122751       │
# │ 10  │ 6097     │ -0.2    │ -0.186849 │ -0.182089      │
# │ 11  │ 7306     │ -0.2    │ -0.205478 │ -0.191555      │
# │ 12  │ 7311     │ -0.2    │ -0.208284 │ -0.198976      │
# │ 13  │ 7312     │ 0.2     │ 0.21605   │ 0.20091        │
# │ 14  │ 7319     │ 0.2     │ 0.198333  │ 0.186648       │
# │ 15  │ 7320     │ -0.2    │ -0.213882 │ -0.212293      │
#
#
# 131.535010 seconds (1.51 M allocations: 10.751 GiB, 10.92% gc time)

# %%
@show mean(ungroup_true_positives)
@show mean(ungroup_false_positives)
@show mean(variable_true_positives)
@show mean(variable_false_positives)

@show std(ungroup_true_positives)
@show std(ungroup_false_positives)
@show std(variable_true_positives)
@show std(variable_false_positives)
# Out:
# mean(ungroup_true_positives) = 11.46
# mean(ungroup_false_positives) = 3.54
# mean(variable_true_positives) = 12.44
# mean(variable_false_positives) = 2.56
# std(ungroup_true_positives) = 2.2130010703507894
# std(ungroup_false_positives) = 2.213001070350789
# std(variable_true_positives) = 1.6956271745733242
# std(variable_false_positives) = 1.6956271745733242
# 1.6956271745733242

# %% [markdown]
# ## Negative Binomial

# %%
Random.seed!(2019)

d = NegativeBinomial
l = LogLink()

num_runs = 100
ungroup_true_positives = zeros(num_runs)
ungroup_false_positives = zeros(num_runs)
variable_true_positives = zeros(num_runs)
variable_false_positives = zeros(num_runs)

@time for i in 1:num_runs
    println("running $i th model")
    utp, ufp, vtp, vfp = compare(d, l)
    ungroup_true_positives[i] = utp
    ungroup_false_positives[i] = ufp
    variable_true_positives[i] = vtp
    variable_false_positives[i] = vfp
end
# Out:
# running 1 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 3464     │ -0.2    │ -0.234958 │ -0.245853      │
# │ 2   │ 4927     │ 0.2     │ 0.158171  │ 0.160904       │
# │ 3   │ 4938     │ -0.2    │ -0.222613 │ -0.213439      │
# │ 4   │ 5001     │ -0.2    │ -0.193739 │ -0.19624       │
# │ 5   │ 5011     │ -0.2    │ -0.162718 │ -0.149913      │
# │ 6   │ 5018     │ -0.2    │ -0.190532 │ -0.181966      │
# │ 7   │ 5084     │ -0.2    │ 0.0       │ 0.0            │
# │ 8   │ 5090     │ 0.2     │ 0.226509  │ 0.21164        │
# │ 9   │ 5098     │ -0.2    │ 0.0       │ 0.0            │
# │ 10  │ 5100     │ -0.2    │ -0.140337 │ -0.157655      │
# │ 11  │ 7004     │ 0.2     │ 0.151748  │ 0.190224       │
# │ 12  │ 7011     │ 0.2     │ 0.206449  │ 0.21294        │
# │ 13  │ 7015     │ -0.2    │ -0.284706 │ -0.256058      │
# │ 14  │ 7016     │ 0.2     │ 0.218126  │ 0.19746        │
# │ 15  │ 7020     │ 0.2     │ 0.0       │ 0.111755       │
#
#
# running 2 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 693      │ -0.2    │ 0.0       │ 0.0            │
# │ 2   │ 3901     │ -0.2    │ -0.2851   │ -0.279824      │
# │ 3   │ 3909     │ 0.2     │ 0.185783  │ 0.160041       │
# │ 4   │ 5602     │ 0.2     │ 0.0       │ 0.159944       │
# │ 5   │ 5610     │ -0.2    │ 0.0       │ -0.176461      │
# │ 6   │ 5618     │ 0.2     │ 0.185615  │ 0.18974        │
# │ 7   │ 7444     │ -0.2    │ -0.213599 │ -0.215291      │
# │ 8   │ 7446     │ 0.2     │ 0.212661  │ 0.195881       │
# │ 9   │ 7448     │ 0.2     │ 0.231665  │ 0.242195       │
# │ 10  │ 7455     │ 0.2     │ 0.208033  │ 0.206495       │
# │ 11  │ 8187     │ -0.2    │ -0.150268 │ -0.20547       │
# │ 12  │ 8188     │ 0.2     │ 0.0       │ 0.134158       │
# │ 13  │ 8189     │ 0.2     │ 0.150813  │ 0.18656        │
# │ 14  │ 8190     │ -0.2    │ 0.0       │ -0.152418      │
# │ 15  │ 8198     │ 0.2     │ 0.165501  │ 0.182095       │
#
#
# running 3 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped  │ variable_group │
# │     │ Int64    │ Float64 │ Float64    │ Float64        │
# ├─────┼──────────┼─────────┼────────────┼────────────────┤
# │ 1   │ 1222     │ -0.2    │ -0.206192  │ -0.213001      │
# │ 2   │ 1831     │ -0.2    │ -0.255747  │ -0.223873      │
# │ 3   │ 1832     │ -0.2    │ -0.19565   │ -0.181364      │
# │ 4   │ 3330     │ -0.2    │ -0.322752  │ -0.247509      │
# │ 5   │ 3333     │ 0.2     │ 0.0        │ 0.191228       │
# │ 6   │ 3338     │ -0.2    │ -0.215544  │ -0.228203      │
# │ 7   │ 6401     │ 0.2     │ 0.215702   │ 0.201059       │
# │ 8   │ 6409     │ -0.2    │ -0.248999  │ -0.251775      │
# │ 9   │ 6417     │ -0.2    │ 0.0        │ 0.0            │
# │ 10  │ 6419     │ -0.2    │ -0.0937576 │ -0.0957335     │
# │ 11  │ 8225     │ -0.2    │ 0.0        │ -0.122371      │
# │ 12  │ 8231     │ -0.2    │ 0.0        │ -0.0920044     │
# │ 13  │ 8235     │ 0.2     │ 0.172704   │ 0.178159       │
# │ 14  │ 8237     │ -0.2    │ 0.0        │ 0.0            │
# │ 15  │ 8238     │ -0.2    │ -0.187581  │ -0.239225      │
#
#
# running 4 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 1084     │ 0.2     │ 0.0881369 │ 0.0            │
# │ 2   │ 5151     │ 0.2     │ 0.179341  │ 0.176065       │
# │ 3   │ 5159     │ 0.2     │ 0.169714  │ 0.164808       │
# │ 4   │ 6543     │ -0.2    │ -0.237713 │ -0.236135      │
# │ 5   │ 6551     │ -0.2    │ -0.250133 │ -0.242936      │
# │ 6   │ 6553     │ -0.2    │ -0.196127 │ -0.206262      │
# │ 7   │ 7149     │ 0.2     │ 0.242471  │ 0.252849       │
# │ 8   │ 7154     │ -0.2    │ -0.210563 │ -0.212062      │
# │ 9   │ 7158     │ -0.2    │ -0.156456 │ -0.165092      │
# │ 10  │ 7160     │ -0.2    │ -0.250727 │ -0.238839      │
# │ 11  │ 8641     │ -0.2    │ -0.160999 │ -0.129907      │
# │ 12  │ 8643     │ -0.2    │ -0.160898 │ -0.227092      │
# │ 13  │ 8646     │ 0.2     │ 0.0       │ 0.157523       │
# │ 14  │ 8648     │ -0.2    │ -0.144777 │ -0.206563      │
# │ 15  │ 8650     │ -0.2    │ -0.220284 │ -0.217355      │
#
#
# running 5 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 2147     │ 0.2     │ 0.176025  │ 0.182633       │
# │ 2   │ 3759     │ 0.2     │ 0.199821  │ 0.225889       │
# │ 3   │ 3760     │ 0.2     │ 0.182048  │ 0.15958        │
# │ 4   │ 4492     │ -0.2    │ -0.199992 │ -0.174318      │
# │ 5   │ 4497     │ -0.2    │ 0.0       │ -0.195863      │
# │ 6   │ 4499     │ 0.2     │ 0.139946  │ 0.24053        │
# │ 7   │ 6706     │ -0.2    │ 0.0       │ -0.225816      │
# │ 8   │ 6717     │ -0.2    │ 0.0       │ -0.309732      │
# │ 9   │ 6718     │ -0.2    │ 0.0       │ 0.0            │
# │ 10  │ 6719     │ 0.2     │ 0.0       │ 0.172319       │
# │ 11  │ 9322     │ -0.2    │ -0.198028 │ -0.212958      │
# │ 12  │ 9328     │ -0.2    │ 0.0       │ -0.158923      │
# │ 13  │ 9329     │ 0.2     │ 0.0       │ 0.199292       │
# │ 14  │ 9330     │ -0.2    │ -0.165003 │ -0.244991      │
# │ 15  │ 9335     │ 0.2     │ 0.0       │ 0.161985       │
#
#
# running 6 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 151      │ 0.2     │ 0.239185  │ 0.238137       │
# │ 2   │ 782      │ -0.2    │ -0.152817 │ 0.0            │
# │ 3   │ 794      │ 0.2     │ 0.206443  │ 0.143457       │
# │ 4   │ 7113     │ 0.2     │ 0.0       │ 0.0            │
# │ 5   │ 7116     │ -0.2    │ -0.130716 │ -0.1285        │
# │ 6   │ 7120     │ 0.2     │ 0.175782  │ 0.179485       │
# │ 7   │ 7948     │ 0.2     │ 0.259326  │ 0.258801       │
# │ 8   │ 7949     │ 0.2     │ 0.161404  │ 0.160923       │
# │ 9   │ 7956     │ 0.2     │ 0.224381  │ 0.234307       │
# │ 10  │ 7959     │ 0.2     │ 0.194369  │ 0.19578        │
# │ 11  │ 9223     │ 0.2     │ 0.230546  │ 0.203191       │
# │ 12  │ 9226     │ -0.2    │ 0.0       │ 0.0            │
# │ 13  │ 9231     │ -0.2    │ -0.121537 │ -0.175875      │
# │ 14  │ 9234     │ -0.2    │ -0.185755 │ -0.18018       │
# │ 15  │ 9238     │ -0.2    │ 0.0       │ -0.100196      │
#
#
# running 7 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 4629     │ 0.2     │ 0.240349  │ 0.234047       │
# │ 2   │ 4883     │ -0.2    │ -0.230852 │ -0.226913      │
# │ 3   │ 4897     │ -0.2    │ -0.22632  │ -0.196276      │
# │ 4   │ 4902     │ -0.2    │ 0.0       │ 0.0            │
# │ 5   │ 4903     │ 0.2     │ 0.0       │ 0.107913       │
# │ 6   │ 4920     │ 0.2     │ 0.182379  │ 0.155805       │
# │ 7   │ 4921     │ 0.2     │ 0.267585  │ 0.292039       │
# │ 8   │ 4922     │ 0.2     │ 0.164527  │ 0.0            │
# │ 9   │ 4924     │ 0.2     │ 0.217926  │ 0.155466       │
# │ 10  │ 4935     │ -0.2    │ -0.208126 │ -0.262196      │
# │ 11  │ 8546     │ 0.2     │ 0.17438   │ 0.108931       │
# │ 12  │ 8554     │ 0.2     │ 0.0       │ 0.0            │
# │ 13  │ 8555     │ -0.2    │ 0.0       │ 0.0            │
# │ 14  │ 8556     │ -0.2    │ -0.26617  │ -0.247064      │
# │ 15  │ 8559     │ 0.2     │ 0.341695  │ 0.340908       │
#
#
# running 8 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 2258     │ 0.2     │ 0.191687  │ 0.196561       │
# │ 2   │ 6091     │ 0.2     │ 0.270908  │ 0.248836       │
# │ 3   │ 6092     │ 0.2     │ 0.128347  │ 0.141103       │
# │ 4   │ 6661     │ 0.2     │ 0.240114  │ 0.235104       │
# │ 5   │ 6668     │ 0.2     │ 0.178014  │ 0.171693       │
# │ 6   │ 6676     │ 0.2     │ 0.194598  │ 0.198657       │
# │ 7   │ 7141     │ -0.2    │ -0.189702 │ -0.19245       │
# │ 8   │ 7144     │ -0.2    │ -0.235046 │ -0.236016      │
# │ 9   │ 7146     │ -0.2    │ -0.149771 │ -0.131953      │
# │ 10  │ 7158     │ -0.2    │ -0.194086 │ -0.193603      │
# │ 11  │ 7549     │ 0.2     │ 0.0       │ 0.166681       │
# │ 12  │ 7553     │ 0.2     │ 0.0       │ 0.135118       │
# │ 13  │ 7554     │ -0.2    │ 0.0       │ -0.205605      │
# │ 14  │ 7556     │ 0.2     │ 0.232954  │ 0.252539       │
# │ 15  │ 7558     │ -0.2    │ -0.263524 │ -0.205312      │
#
#
# running 9 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 2096     │ 0.2     │ 0.195987  │ 0.20435        │
# │ 2   │ 2845     │ 0.2     │ 0.179565  │ 0.190624       │
# │ 3   │ 2853     │ 0.2     │ 0.164668  │ 0.163281       │
# │ 4   │ 4329     │ -0.2    │ -0.238081 │ -0.180091      │
# │ 5   │ 4335     │ 0.2     │ 0.194709  │ 0.0            │
# │ 6   │ 4336     │ 0.2     │ 0.146065  │ 0.146233       │
# │ 7   │ 4522     │ -0.2    │ 0.0       │ -0.165596      │
# │ 8   │ 4529     │ -0.2    │ -0.162513 │ -0.206902      │
# │ 9   │ 4535     │ 0.2     │ 0.307854  │ 0.257613       │
# │ 10  │ 4539     │ -0.2    │ -0.252085 │ -0.264706      │
# │ 11  │ 6101     │ -0.2    │ -0.231377 │ 0.0            │
# │ 12  │ 6107     │ 0.2     │ 0.236699  │ 0.184656       │
# │ 13  │ 6108     │ 0.2     │ 0.211441  │ 0.230295       │
# │ 14  │ 6110     │ 0.2     │ 0.21371   │ 0.166351       │
# │ 15  │ 6111     │ 0.2     │ 0.199632  │ 0.182702       │
#
#
# running 10 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 303      │ 0.2     │ 0.201476  │ 0.195633       │
# │ 2   │ 4701     │ -0.2    │ -0.210877 │ -0.209258      │
# │ 3   │ 4709     │ -0.2    │ -0.256835 │ -0.256495      │
# │ 4   │ 7222     │ -0.2    │ -0.135974 │ -0.138774      │
# │ 5   │ 7231     │ 0.2     │ 0.24905   │ 0.243728       │
# │ 6   │ 7236     │ 0.2     │ 0.251893  │ 0.256557       │
# │ 7   │ 7961     │ 0.2     │ 0.201336  │ 0.209477       │
# │ 8   │ 7970     │ -0.2    │ -0.211066 │ -0.202608      │
# │ 9   │ 7974     │ 0.2     │ 0.236827  │ 0.22985        │
# │ 10  │ 7976     │ -0.2    │ -0.199539 │ -0.197497      │
# │ 11  │ 9025     │ 0.2     │ 0.224626  │ 0.242623       │
# │ 12  │ 9027     │ -0.2    │ -0.148046 │ -0.232476      │
# │ 13  │ 9031     │ 0.2     │ 0.181312  │ 0.186979       │
# │ 14  │ 9036     │ 0.2     │ 0.0       │ 0.194375       │
# │ 15  │ 9038     │ -0.2    │ 0.0       │ -0.183553      │
#
#
# running 11 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 1063     │ 0.2     │ 0.203915  │ 0.214457       │
# │ 2   │ 1644     │ 0.2     │ 0.24663   │ 0.217119       │
# │ 3   │ 1647     │ 0.2     │ 0.143707  │ 0.160351       │
# │ 4   │ 4082     │ 0.2     │ 0.0       │ 0.0            │
# │ 5   │ 4083     │ -0.2    │ 0.0       │ -0.10529       │
# │ 6   │ 4093     │ 0.2     │ 0.0       │ 0.12635        │
# │ 7   │ 4226     │ 0.2     │ 0.0       │ 0.0            │
# │ 8   │ 4230     │ -0.2    │ -0.210115 │ -0.159852      │
# │ 9   │ 4237     │ 0.2     │ 0.183782  │ 0.197124       │
# │ 10  │ 4238     │ 0.2     │ 0.121741  │ 0.159418       │
# │ 11  │ 6743     │ -0.2    │ -0.168146 │ -0.16973       │
# │ 12  │ 6746     │ -0.2    │ 0.0       │ 0.0            │
# │ 13  │ 6752     │ -0.2    │ 0.0       │ 0.0            │
# │ 14  │ 6753     │ 0.2     │ 0.0       │ 0.0977972      │
# │ 15  │ 6757     │ -0.2    │ -0.167162 │ -0.205318      │
#
#
# running 12 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 1429     │ 0.2     │ 0.203036  │ 0.197561       │
# │ 2   │ 2639     │ 0.2     │ 0.0       │ 0.0            │
# │ 3   │ 2640     │ -0.2    │ 0.0       │ 0.0            │
# │ 4   │ 3750     │ -0.2    │ -0.171843 │ -0.167077      │
# │ 5   │ 3751     │ -0.2    │ -0.209241 │ -0.219942      │
# │ 6   │ 3756     │ -0.2    │ -0.204049 │ -0.198799      │
# │ 7   │ 7441     │ 0.2     │ 0.250258  │ 0.258766       │
# │ 8   │ 7444     │ -0.2    │ 0.0       │ 0.0            │
# │ 9   │ 7451     │ -0.2    │ -0.155617 │ -0.150407      │
# │ 10  │ 7456     │ -0.2    │ -0.177065 │ -0.171065      │
# │ 11  │ 8785     │ -0.2    │ -0.234997 │ -0.234227      │
# │ 12  │ 8788     │ 0.2     │ 0.197446  │ 0.206365       │
# │ 13  │ 8794     │ -0.2    │ -0.243409 │ -0.25092       │
# │ 14  │ 8799     │ 0.2     │ 0.191542  │ 0.19785        │
# │ 15  │ 8800     │ 0.2     │ 0.192694  │ 0.194787       │
#
#
# running 13 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 4544     │ -0.2    │ -0.219274 │ -0.210254      │
# │ 2   │ 4583     │ 0.2     │ 0.236036  │ 0.226526       │
# │ 3   │ 4592     │ 0.2     │ 0.155367  │ 0.160707       │
# │ 4   │ 6103     │ -0.2    │ -0.195505 │ -0.166562      │
# │ 5   │ 6104     │ 0.2     │ 0.218551  │ 0.0            │
# │ 6   │ 6113     │ 0.2     │ 0.206985  │ 0.183544       │
# │ 7   │ 9104     │ -0.2    │ 0.0       │ 0.0            │
# │ 8   │ 9111     │ 0.2     │ 0.0       │ 0.0            │
# │ 9   │ 9113     │ 0.2     │ 0.247046  │ 0.231917       │
# │ 10  │ 9117     │ 0.2     │ 0.0       │ 0.0            │
# │ 11  │ 9370     │ -0.2    │ -0.177097 │ -0.181569      │
# │ 12  │ 9372     │ -0.2    │ -0.212801 │ -0.214871      │
# │ 13  │ 9375     │ -0.2    │ -0.242562 │ -0.234959      │
# │ 14  │ 9379     │ 0.2     │ 0.169025  │ 0.158019       │
# │ 15  │ 9380     │ 0.2     │ 0.175112  │ 0.176521       │
#
#
# running 14 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 5340     │ 0.2     │ 0.206213  │ 0.203811       │
# │ 2   │ 6169     │ 0.2     │ 0.192588  │ 0.180123       │
# │ 3   │ 6180     │ 0.2     │ 0.185399  │ 0.178216       │
# │ 4   │ 6234     │ -0.2    │ -0.253821 │ -0.25357       │
# │ 5   │ 6238     │ -0.2    │ -0.18923  │ -0.179241      │
# │ 6   │ 6239     │ -0.2    │ -0.233597 │ -0.228949      │
# │ 7   │ 8681     │ 0.2     │ 0.0       │ 0.153583       │
# │ 8   │ 8682     │ -0.2    │ 0.0       │ 0.0            │
# │ 9   │ 8691     │ -0.2    │ -0.183426 │ -0.157329      │
# │ 10  │ 8700     │ 0.2     │ 0.0       │ 0.16235        │
# │ 11  │ 9141     │ 0.2     │ 0.223553  │ 0.179615       │
# │ 12  │ 9144     │ -0.2    │ -0.121162 │ -0.160051      │
# │ 13  │ 9150     │ -0.2    │ 0.0       │ -0.195722      │
# │ 14  │ 9151     │ 0.2     │ 0.125824  │ 0.219955       │
# │ 15  │ 9157     │ 0.2     │ 0.18044   │ 0.257633       │
#
#
# running 15 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 249      │ 0.2     │ 0.111471  │ 0.13667        │
# │ 2   │ 4002     │ -0.2    │ -0.236312 │ -0.21764       │
# │ 3   │ 4019     │ 0.2     │ 0.21664   │ 0.216518       │
# │ 4   │ 4945     │ 0.2     │ 0.173502  │ 0.168805       │
# │ 5   │ 4948     │ -0.2    │ -0.206496 │ -0.214298      │
# │ 6   │ 4957     │ 0.2     │ 0.15864   │ 0.148467       │
# │ 7   │ 6009     │ -0.2    │ 0.0       │ -0.134615      │
# │ 8   │ 6011     │ -0.2    │ 0.0       │ 0.0            │
# │ 9   │ 6014     │ 0.2     │ 0.0       │ 0.147814       │
# │ 10  │ 6020     │ 0.2     │ 0.199912  │ 0.186609       │
# │ 11  │ 8942     │ 0.2     │ 0.290855  │ 0.242664       │
# │ 12  │ 8944     │ 0.2     │ 0.0       │ 0.0829412      │
# │ 13  │ 8946     │ 0.2     │ 0.0       │ 0.125755       │
# │ 14  │ 8949     │ -0.2    │ 0.0       │ 0.0            │
# │ 15  │ 8954     │ 0.2     │ 0.211298  │ 0.196845       │
#
#
# running 16 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 1277     │ 0.2     │ 0.225432  │ 0.231295       │
# │ 2   │ 1607     │ -0.2    │ -0.202444 │ -0.198386      │
# │ 3   │ 1620     │ -0.2    │ -0.24515  │ -0.2445        │
# │ 4   │ 2704     │ 0.2     │ 0.0       │ 0.0            │
# │ 5   │ 2713     │ 0.2     │ 0.168678  │ 0.175193       │
# │ 6   │ 2719     │ 0.2     │ 0.156417  │ 0.144831       │
# │ 7   │ 6205     │ -0.2    │ -0.232053 │ -0.223265      │
# │ 8   │ 6210     │ -0.2    │ -0.187977 │ -0.204704      │
# │ 9   │ 6211     │ 0.2     │ 0.200945  │ 0.180684       │
# │ 10  │ 6218     │ -0.2    │ -0.188145 │ -0.191791      │
# │ 11  │ 9863     │ -0.2    │ -0.244263 │ -0.147101      │
# │ 12  │ 9866     │ -0.2    │ 0.0       │ 0.0            │
# │ 13  │ 9869     │ -0.2    │ 0.0       │ 0.0            │
# │ 14  │ 9873     │ -0.2    │ 0.0       │ -0.139864      │
# │ 15  │ 9876     │ 0.2     │ 0.0       │ 0.125875       │
#
#
# running 17 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 1515     │ 0.2     │ 0.218465  │ 0.218457       │
# │ 2   │ 1826     │ 0.2     │ 0.213052  │ 0.213068       │
# │ 3   │ 1834     │ -0.2    │ -0.257636 │ -0.25763       │
# │ 4   │ 5166     │ 0.2     │ 0.194684  │ 0.194719       │
# │ 5   │ 5175     │ 0.2     │ 0.230109  │ 0.230182       │
# │ 6   │ 5177     │ 0.2     │ 0.223223  │ 0.223161       │
# │ 7   │ 5523     │ -0.2    │ -0.166072 │ -0.165925      │
# │ 8   │ 5525     │ 0.2     │ 0.21374   │ 0.21367        │
# │ 9   │ 5532     │ -0.2    │ -0.218692 │ -0.218818      │
# │ 10  │ 5536     │ 0.2     │ 0.227029  │ 0.227149       │
# │ 11  │ 5622     │ 0.2     │ 0.251662  │ 0.251531       │
# │ 12  │ 5625     │ 0.2     │ 0.170274  │ 0.17038        │
# │ 13  │ 5628     │ -0.2    │ -0.188224 │ -0.188319      │
# │ 14  │ 5632     │ 0.2     │ 0.267386  │ 0.267288       │
# │ 15  │ 5635     │ -0.2    │ -0.202166 │ -0.202064      │
#
#
# running 18 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 1625     │ 0.2     │ 0.190909  │ 0.189787       │
# │ 2   │ 4925     │ 0.2     │ 0.219912  │ 0.215658       │
# │ 3   │ 4929     │ -0.2    │ -0.219079 │ -0.211484      │
# │ 4   │ 5127     │ -0.2    │ -0.209345 │ -0.184174      │
# │ 5   │ 5130     │ 0.2     │ 0.0       │ 0.0            │
# │ 6   │ 5132     │ -0.2    │ 0.0       │ -0.0867927     │
# │ 7   │ 9084     │ -0.2    │ -0.155421 │ -0.159238      │
# │ 8   │ 9090     │ -0.2    │ 0.0       │ 0.0            │
# │ 9   │ 9094     │ -0.2    │ 0.0       │ 0.0            │
# │ 10  │ 9099     │ -0.2    │ 0.0       │ 0.0            │
# │ 11  │ 9141     │ -0.2    │ -0.236816 │ -0.240793      │
# │ 12  │ 9148     │ 0.2     │ 0.209548  │ 0.195904       │
# │ 13  │ 9152     │ 0.2     │ 0.256198  │ 0.260186       │
# │ 14  │ 9153     │ 0.2     │ 0.151495  │ 0.152617       │
# │ 15  │ 9155     │ 0.2     │ 0.277134  │ 0.256144       │
#
#
# running 19 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 1194     │ -0.2    │ -0.214939 │ -0.219055      │
# │ 2   │ 3222     │ -0.2    │ -0.174415 │ -0.184001      │
# │ 3   │ 3239     │ -0.2    │ -0.14053  │ -0.13681       │
# │ 4   │ 3649     │ 0.2     │ 0.166443  │ 0.174209       │
# │ 5   │ 3651     │ 0.2     │ 0.228484  │ 0.212208       │
# │ 6   │ 3657     │ 0.2     │ 0.209633  │ 0.223768       │
# │ 7   │ 4702     │ -0.2    │ 0.0       │ 0.0            │
# │ 8   │ 4713     │ -0.2    │ 0.0       │ 0.0            │
# │ 9   │ 4714     │ 0.2     │ 0.256961  │ 0.24051        │
# │ 10  │ 4719     │ -0.2    │ -0.161143 │ -0.161648      │
# │ 11  │ 8442     │ -0.2    │ 0.0       │ 0.0            │
# │ 12  │ 8449     │ 0.2     │ 0.105261  │ 0.175757       │
# │ 13  │ 8452     │ 0.2     │ 0.0       │ 0.16951        │
# │ 14  │ 8456     │ 0.2     │ 0.0       │ 0.0            │
# │ 15  │ 8457     │ -0.2    │ 0.0       │ 0.0            │
#
#
# running 20 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 378      │ 0.2     │ 0.210968  │ 0.212271       │
# │ 2   │ 602      │ -0.2    │ -0.18433  │ -0.179274      │
# │ 3   │ 605      │ 0.2     │ 0.177714  │ 0.176348       │
# │ 4   │ 5311     │ -0.2    │ -0.25954  │ -0.252087      │
# │ 5   │ 5312     │ 0.2     │ 0.20256   │ 0.184419       │
# │ 6   │ 5319     │ 0.2     │ 0.147604  │ 0.147442       │
# │ 7   │ 6643     │ 0.2     │ 0.270515  │ 0.139334       │
# │ 8   │ 6646     │ 0.2     │ 0.0       │ 0.0            │
# │ 9   │ 6658     │ 0.2     │ 0.238     │ 0.207559       │
# │ 10  │ 6660     │ 0.2     │ 0.0       │ 0.0            │
# │ 11  │ 8381     │ -0.2    │ 0.0       │ -0.195564      │
# │ 12  │ 8383     │ 0.2     │ 0.217655  │ 0.18899        │
# │ 13  │ 8384     │ 0.2     │ 0.179323  │ 0.242261       │
# │ 14  │ 8386     │ -0.2    │ -0.218848 │ -0.2297        │
# │ 15  │ 8398     │ 0.2     │ 0.130825  │ 0.174207       │
#
#
# running 21 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 1820     │ 0.2     │ 0.169389  │ 0.161716       │
# │ 2   │ 2930     │ 0.2     │ 0.178546  │ 0.191486       │
# │ 3   │ 2938     │ -0.2    │ -0.200957 │ -0.220288      │
# │ 4   │ 3204     │ -0.2    │ -0.121608 │ -0.106285      │
# │ 5   │ 3208     │ 0.2     │ 0.168642  │ 0.165354       │
# │ 6   │ 3216     │ -0.2    │ 0.0       │ 0.0            │
# │ 7   │ 7468     │ 0.2     │ 0.171951  │ 0.0            │
# │ 8   │ 7475     │ 0.2     │ 0.217849  │ 0.179068       │
# │ 9   │ 7477     │ 0.2     │ 0.164321  │ 0.203014       │
# │ 10  │ 7478     │ 0.2     │ 0.256621  │ 0.176095       │
# │ 11  │ 7863     │ 0.2     │ 0.0       │ 0.0            │
# │ 12  │ 7864     │ -0.2    │ 0.0       │ 0.0            │
# │ 13  │ 7865     │ 0.2     │ 0.0       │ 0.0            │
# │ 14  │ 7866     │ -0.2    │ 0.0       │ 0.0            │
# │ 15  │ 7874     │ -0.2    │ 0.0       │ 0.0            │
#
#
# running 22 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 1342     │ -0.2    │ -0.220426 │ -0.236777      │
# │ 2   │ 3661     │ -0.2    │ -0.221947 │ -0.212108      │
# │ 3   │ 3679     │ 0.2     │ 0.181424  │ 0.170534       │
# │ 4   │ 4909     │ -0.2    │ -0.207209 │ -0.215263      │
# │ 5   │ 4915     │ -0.2    │ -0.242567 │ -0.230452      │
# │ 6   │ 4917     │ -0.2    │ -0.188126 │ -0.176787      │
# │ 7   │ 9122     │ -0.2    │ -0.285895 │ -0.252756      │
# │ 8   │ 9123     │ -0.2    │ -0.133986 │ -0.116674      │
# │ 9   │ 9130     │ 0.2     │ 0.259081  │ 0.255735       │
# │ 10  │ 9140     │ 0.2     │ 0.0       │ 0.0            │
# │ 11  │ 9242     │ -0.2    │ 0.0       │ 0.0            │
# │ 12  │ 9244     │ -0.2    │ 0.0       │ -0.157814      │
# │ 13  │ 9248     │ 0.2     │ 0.0       │ 0.0            │
# │ 14  │ 9250     │ -0.2    │ 0.0       │ -0.17723       │
# │ 15  │ 9260     │ 0.2     │ 0.287043  │ 0.101209       │
#
#
# running 23 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 6416     │ -0.2    │ 0.0       │ -0.207108      │
# │ 2   │ 6674     │ 0.2     │ 0.16303   │ 0.158715       │
# │ 3   │ 6675     │ 0.2     │ 0.293808  │ 0.28854        │
# │ 4   │ 6804     │ 0.2     │ 0.198098  │ 0.224311       │
# │ 5   │ 6817     │ 0.2     │ 0.216142  │ 0.22107        │
# │ 6   │ 6819     │ -0.2    │ -0.146459 │ -0.146741      │
# │ 7   │ 7081     │ 0.2     │ 0.235155  │ 0.23568        │
# │ 8   │ 7082     │ -0.2    │ -0.229739 │ -0.25011       │
# │ 9   │ 7087     │ -0.2    │ -0.167629 │ -0.178523      │
# │ 10  │ 7100     │ -0.2    │ -0.173097 │ -0.165201      │
# │ 11  │ 9821     │ 0.2     │ 0.0       │ 0.0            │
# │ 12  │ 9822     │ -0.2    │ 0.0       │ 0.0            │
# │ 13  │ 9830     │ 0.2     │ 0.0       │ 0.097758       │
# │ 14  │ 9832     │ -0.2    │ -0.149631 │ -0.164248      │
# │ 15  │ 9834     │ 0.2     │ 0.240687  │ 0.195552       │
#
#
# running 24 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 549      │ 0.2     │ 0.17461   │ 0.168608       │
# │ 2   │ 701      │ -0.2    │ -0.193066 │ -0.194493      │
# │ 3   │ 703      │ -0.2    │ -0.231459 │ -0.226919      │
# │ 4   │ 4207     │ -0.2    │ -0.274711 │ -0.264851      │
# │ 5   │ 4210     │ -0.2    │ -0.219591 │ -0.219269      │
# │ 6   │ 4215     │ 0.2     │ 0.194052  │ 0.198          │
# │ 7   │ 4921     │ 0.2     │ 0.0       │ 0.0            │
# │ 8   │ 4922     │ -0.2    │ 0.0       │ 0.0            │
# │ 9   │ 4929     │ 0.2     │ 0.210793  │ 0.223295       │
# │ 10  │ 4940     │ 0.2     │ 0.196282  │ 0.241008       │
# │ 11  │ 5875     │ -0.2    │ -0.162072 │ -0.15197       │
# │ 12  │ 5876     │ -0.2    │ -0.171668 │ -0.170529      │
# │ 13  │ 5877     │ -0.2    │ -0.171668 │ -0.170529      │
# │ 14  │ 5878     │ -0.2    │ -0.199173 │ -0.197884      │
# │ 15  │ 5880     │ 0.2     │ 0.187443  │ 0.179842       │
#
#
# running 25 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 319      │ -0.2    │ -0.215073 │ -0.211436      │
# │ 2   │ 1572     │ -0.2    │ -0.179166 │ -0.165883      │
# │ 3   │ 1578     │ -0.2    │ -0.145178 │ -0.155897      │
# │ 4   │ 1967     │ -0.2    │ -0.232109 │ -0.231598      │
# │ 5   │ 1973     │ 0.2     │ 0.216896  │ 0.210581       │
# │ 6   │ 1974     │ 0.2     │ 0.20136   │ 0.208111       │
# │ 7   │ 2157     │ -0.2    │ 0.0       │ -0.137213      │
# │ 8   │ 2158     │ 0.2     │ 0.174955  │ 0.198139       │
# │ 9   │ 2159     │ 0.2     │ 0.249306  │ 0.304475       │
# │ 10  │ 2160     │ 0.2     │ 0.205008  │ 0.181401       │
# │ 11  │ 3601     │ -0.2    │ -0.166234 │ -0.166482      │
# │ 12  │ 3604     │ -0.2    │ -0.205796 │ -0.200754      │
# │ 13  │ 3613     │ -0.2    │ -0.165157 │ -0.210726      │
# │ 14  │ 3614     │ 0.2     │ 0.0       │ 0.135573       │
# │ 15  │ 3615     │ -0.2    │ 0.0       │ -0.124389      │
#
#
# running 26 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 385      │ -0.2    │ -0.22138  │ -0.204831      │
# │ 2   │ 2961     │ -0.2    │ -0.164842 │ -0.17102       │
# │ 3   │ 2967     │ 0.2     │ 0.21969   │ 0.207701       │
# │ 4   │ 3661     │ -0.2    │ -0.191252 │ -0.19826       │
# │ 5   │ 3672     │ 0.2     │ 0.208095  │ 0.235738       │
# │ 6   │ 3676     │ -0.2    │ -0.211966 │ -0.219958      │
# │ 7   │ 6021     │ 0.2     │ 0.261511  │ 0.270263       │
# │ 8   │ 6028     │ -0.2    │ 0.0       │ 0.0            │
# │ 9   │ 6029     │ 0.2     │ 0.0       │ 0.119299       │
# │ 10  │ 6036     │ 0.2     │ 0.267155  │ 0.212281       │
# │ 11  │ 9681     │ -0.2    │ 0.0       │ -0.194337      │
# │ 12  │ 9686     │ -0.2    │ -0.244512 │ -0.218158      │
# │ 13  │ 9695     │ 0.2     │ 0.0       │ 0.192455       │
# │ 14  │ 9697     │ -0.2    │ 0.0       │ 0.0            │
# │ 15  │ 9700     │ 0.2     │ 0.0       │ 0.165355       │
#
#
# running 27 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 2747     │ 0.2     │ 0.14021   │ 0.147295       │
# │ 2   │ 4962     │ -0.2    │ -0.156258 │ 0.0            │
# │ 3   │ 4974     │ -0.2    │ -0.206798 │ -0.163296      │
# │ 4   │ 6623     │ 0.2     │ 0.223645  │ 0.224058       │
# │ 5   │ 6628     │ -0.2    │ -0.190267 │ -0.188085      │
# │ 6   │ 6634     │ 0.2     │ 0.238553  │ 0.236148       │
# │ 7   │ 7182     │ 0.2     │ 0.238536  │ 0.233805       │
# │ 8   │ 7192     │ 0.2     │ 0.169898  │ 0.172461       │
# │ 9   │ 7194     │ 0.2     │ 0.265775  │ 0.262585       │
# │ 10  │ 7198     │ -0.2    │ -0.248325 │ -0.250698      │
# │ 11  │ 8906     │ -0.2    │ -0.166026 │ -0.162187      │
# │ 12  │ 8912     │ 0.2     │ 0.187899  │ 0.1868         │
# │ 13  │ 8915     │ 0.2     │ 0.184425  │ 0.186931       │
# │ 14  │ 8917     │ 0.2     │ 0.175291  │ 0.176151       │
# │ 15  │ 8919     │ 0.2     │ 0.188777  │ 0.190034       │
#
#
# running 28 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 2329     │ 0.2     │ 0.254259  │ 0.251885       │
# │ 2   │ 3526     │ 0.2     │ 0.222573  │ 0.220398       │
# │ 3   │ 3528     │ -0.2    │ -0.23105  │ -0.234181      │
# │ 4   │ 6667     │ 0.2     │ 0.248714  │ 0.259724       │
# │ 5   │ 6668     │ 0.2     │ 0.181064  │ 0.16998        │
# │ 6   │ 6673     │ 0.2     │ 0.0       │ 0.0            │
# │ 7   │ 7823     │ -0.2    │ 0.0       │ 0.0            │
# │ 8   │ 7826     │ -0.2    │ -0.298488 │ -0.187157      │
# │ 9   │ 7827     │ -0.2    │ 0.0       │ -0.0935572     │
# │ 10  │ 7830     │ -0.2    │ -0.120539 │ -0.143482      │
# │ 11  │ 8724     │ -0.2    │ -0.248921 │ -0.247149      │
# │ 12  │ 8727     │ -0.2    │ -0.183383 │ -0.176612      │
# │ 13  │ 8737     │ -0.2    │ -0.266932 │ -0.272396      │
# │ 14  │ 8739     │ 0.2     │ 0.17669   │ 0.16631        │
# │ 15  │ 8740     │ 0.2     │ 0.197186  │ 0.194          │
#
#
# running 29 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 294      │ 0.2     │ 0.197585  │ 0.183363       │
# │ 2   │ 591      │ -0.2    │ 0.0       │ 0.0            │
# │ 3   │ 592      │ 0.2     │ 0.134092  │ 0.0            │
# │ 4   │ 3448     │ -0.2    │ -0.24528  │ -0.25446       │
# │ 5   │ 3450     │ 0.2     │ 0.242537  │ 0.216479       │
# │ 6   │ 3458     │ -0.2    │ -0.194585 │ -0.21375       │
# │ 7   │ 6273     │ 0.2     │ 0.100713  │ 0.0            │
# │ 8   │ 6274     │ 0.2     │ 0.280513  │ 0.340834       │
# │ 9   │ 6276     │ -0.2    │ 0.0       │ 0.0            │
# │ 10  │ 6278     │ 0.2     │ 0.0       │ 0.0            │
# │ 11  │ 9004     │ 0.2     │ 0.0       │ 0.0            │
# │ 12  │ 9006     │ -0.2    │ 0.0       │ 0.0            │
# │ 13  │ 9009     │ 0.2     │ 0.245485  │ 0.244845       │
# │ 14  │ 9016     │ -0.2    │ -0.13859  │ -0.314584      │
# │ 15  │ 9018     │ -0.2    │ -0.127007 │ -0.132549      │
#
#
# running 30 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 1486     │ 0.2     │ 0.214572  │ 0.215503       │
# │ 2   │ 3422     │ 0.2     │ 0.160967  │ 0.156413       │
# │ 3   │ 3424     │ -0.2    │ -0.26444  │ -0.258853      │
# │ 4   │ 4965     │ -0.2    │ -0.238454 │ -0.229453      │
# │ 5   │ 4974     │ -0.2    │ -0.18817  │ -0.178941      │
# │ 6   │ 4978     │ 0.2     │ 0.157767  │ 0.152925       │
# │ 7   │ 7863     │ -0.2    │ -0.214956 │ -0.221617      │
# │ 8   │ 7866     │ 0.2     │ 0.226402  │ 0.215528       │
# │ 9   │ 7867     │ -0.2    │ -0.2171   │ -0.193155      │
# │ 10  │ 7873     │ -0.2    │ -0.196295 │ -0.197774      │
# │ 11  │ 9042     │ -0.2    │ -0.149578 │ 0.0            │
# │ 12  │ 9043     │ 0.2     │ 0.0       │ 0.0            │
# │ 13  │ 9044     │ -0.2    │ 0.0       │ -0.094344      │
# │ 14  │ 9052     │ 0.2     │ 0.235647  │ 0.182072       │
# │ 15  │ 9059     │ 0.2     │ 0.206472  │ 0.179619       │
#
#
# running 31 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 3        │ 0.2     │ 0.23834   │ 0.234567       │
# │ 2   │ 87       │ -0.2    │ -0.153757 │ -0.155711      │
# │ 3   │ 98       │ 0.2     │ 0.166844  │ 0.162594       │
# │ 4   │ 2225     │ -0.2    │ -0.186712 │ -0.186782      │
# │ 5   │ 2235     │ 0.2     │ 0.0       │ 0.0            │
# │ 6   │ 2237     │ 0.2     │ 0.0       │ 0.17508        │
# │ 7   │ 3046     │ 0.2     │ 0.192925  │ 0.188222       │
# │ 8   │ 3047     │ 0.2     │ 0.199621  │ 0.207722       │
# │ 9   │ 3048     │ 0.2     │ 0.198282  │ 0.194252       │
# │ 10  │ 3051     │ -0.2    │ -0.213491 │ -0.21189       │
# │ 11  │ 5383     │ -0.2    │ -0.278947 │ -0.194232      │
# │ 12  │ 5386     │ -0.2    │ -0.241036 │ -0.212541      │
# │ 13  │ 5388     │ 0.2     │ 0.17452   │ 0.209162       │
# │ 14  │ 5390     │ -0.2    │ -0.142387 │ -0.175709      │
# │ 15  │ 5400     │ -0.2    │ -0.165109 │ -0.233167      │
#
#
# running 32 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 797      │ 0.2     │ 0.156958  │ 0.173087       │
# │ 2   │ 1725     │ 0.2     │ 0.177474  │ 0.187425       │
# │ 3   │ 1728     │ -0.2    │ 0.0       │ 0.0            │
# │ 4   │ 2704     │ 0.2     │ 0.173427  │ 0.178359       │
# │ 5   │ 2710     │ -0.2    │ -0.196059 │ 0.0            │
# │ 6   │ 2713     │ 0.2     │ 0.236836  │ 0.143361       │
# │ 7   │ 3965     │ 0.2     │ 0.0       │ 0.0            │
# │ 8   │ 3972     │ -0.2    │ -0.161577 │ -0.183745      │
# │ 9   │ 3976     │ 0.2     │ 0.17198   │ 0.153646       │
# │ 10  │ 3978     │ -0.2    │ 0.0       │ 0.0            │
# │ 11  │ 4229     │ 0.2     │ 0.0       │ 0.148716       │
# │ 12  │ 4233     │ -0.2    │ 0.0       │ -0.200297      │
# │ 13  │ 4234     │ 0.2     │ 0.0       │ 0.0            │
# │ 14  │ 4236     │ 0.2     │ 0.0       │ 0.189213       │
# │ 15  │ 4239     │ 0.2     │ 0.296659  │ 0.299811       │
#
#
# running 33 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 1272     │ 0.2     │ 0.235649  │ 0.234037       │
# │ 2   │ 1343     │ -0.2    │ -0.162194 │ -0.167782      │
# │ 3   │ 1353     │ 0.2     │ 0.0       │ 0.0            │
# │ 4   │ 3384     │ -0.2    │ -0.221151 │ -0.192363      │
# │ 5   │ 3392     │ 0.2     │ 0.177069  │ 0.0            │
# │ 6   │ 3396     │ -0.2    │ -0.226599 │ -0.247251      │
# │ 7   │ 5405     │ -0.2    │ 0.0       │ -0.0607433     │
# │ 8   │ 5407     │ -0.2    │ -0.183876 │ -0.173383      │
# │ 9   │ 5414     │ -0.2    │ 0.0       │ 0.0            │
# │ 10  │ 5417     │ -0.2    │ -0.244496 │ -0.210631      │
# │ 11  │ 7923     │ -0.2    │ -0.168724 │ -0.166811      │
# │ 12  │ 7927     │ 0.2     │ 0.209451  │ 0.203464       │
# │ 13  │ 7928     │ 0.2     │ 0.172658  │ 0.172988       │
# │ 14  │ 7932     │ -0.2    │ -0.142099 │ -0.15255       │
# │ 15  │ 7933     │ -0.2    │ -0.278125 │ -0.27754       │
#
#
# running 34 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 219      │ -0.2    │ -0.191309 │ -0.190472      │
# │ 2   │ 2065     │ -0.2    │ -0.210754 │ -0.199193      │
# │ 3   │ 2067     │ -0.2    │ -0.204432 │ -0.195145      │
# │ 4   │ 2883     │ 0.2     │ 0.197907  │ 0.186089       │
# │ 5   │ 2887     │ 0.2     │ 0.223404  │ 0.203466       │
# │ 6   │ 2890     │ 0.2     │ 0.0       │ 0.119933       │
# │ 7   │ 7483     │ -0.2    │ -0.248978 │ -0.225891      │
# │ 8   │ 7485     │ -0.2    │ -0.200666 │ -0.218528      │
# │ 9   │ 7488     │ 0.2     │ 0.0       │ 0.0            │
# │ 10  │ 7495     │ -0.2    │ -0.205236 │ -0.217329      │
# │ 11  │ 9202     │ 0.2     │ 0.0       │ 0.0            │
# │ 12  │ 9205     │ -0.2    │ -0.139174 │ -0.172734      │
# │ 13  │ 9210     │ -0.2    │ 0.0       │ 0.0            │
# │ 14  │ 9215     │ -0.2    │ 0.0       │ -0.149814      │
# │ 15  │ 9216     │ -0.2    │ -0.263189 │ -0.226946      │
#
#
# running 35 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 3778     │ 0.2     │ 0.160476  │ 0.165273       │
# │ 2   │ 4623     │ 0.2     │ 0.271452  │ 0.246629       │
# │ 3   │ 4629     │ -0.2    │ -0.205116 │ -0.214398      │
# │ 4   │ 5305     │ -0.2    │ -0.193986 │ -0.188942      │
# │ 5   │ 5309     │ -0.2    │ -0.2508   │ -0.255606      │
# │ 6   │ 5313     │ 0.2     │ 0.249539  │ 0.22016        │
# │ 7   │ 5321     │ 0.2     │ 0.0       │ 0.0            │
# │ 8   │ 5322     │ -0.2    │ 0.0       │ 0.0            │
# │ 9   │ 5330     │ 0.2     │ 0.309218  │ 0.28729        │
# │ 10  │ 5332     │ 0.2     │ 0.172652  │ 0.181704       │
# │ 11  │ 9661     │ 0.2     │ 0.0       │ 0.0            │
# │ 12  │ 9671     │ -0.2    │ 0.0       │ -0.070125      │
# │ 13  │ 9672     │ 0.2     │ 0.0       │ 0.0            │
# │ 14  │ 9675     │ -0.2    │ -0.209229 │ -0.212425      │
# │ 15  │ 9676     │ -0.2    │ -0.209384 │ -0.174813      │
#
#
# running 36 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 4864     │ 0.2     │ 0.210072  │ 0.210074       │
# │ 2   │ 7368     │ 0.2     │ 0.19342   │ 0.193431       │
# │ 3   │ 7373     │ -0.2    │ -0.161169 │ -0.161165      │
# │ 4   │ 7406     │ -0.2    │ -0.229383 │ -0.229403      │
# │ 5   │ 7408     │ 0.2     │ 0.160665  │ 0.16071        │
# │ 6   │ 7418     │ -0.2    │ -0.203032 │ -0.203056      │
# │ 7   │ 8901     │ 0.2     │ 0.184916  │ 0.184916       │
# │ 8   │ 8904     │ 0.2     │ 0.16123   │ 0.161221       │
# │ 9   │ 8918     │ 0.2     │ 0.139346  │ 0.139351       │
# │ 10  │ 8920     │ -0.2    │ -0.196438 │ -0.196431      │
# │ 11  │ 9322     │ -0.2    │ -0.213517 │ -0.213539      │
# │ 12  │ 9327     │ -0.2    │ -0.204234 │ -0.204267      │
# │ 13  │ 9330     │ 0.2     │ 0.186905  │ 0.186895       │
# │ 14  │ 9335     │ -0.2    │ -0.142603 │ -0.14261       │
# │ 15  │ 9340     │ 0.2     │ 0.229049  │ 0.229038       │
#
#
# running 37 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 1795     │ -0.2    │ -0.217336 │ -0.203243      │
# │ 2   │ 3944     │ 0.2     │ 0.206252  │ 0.218313       │
# │ 3   │ 3956     │ 0.2     │ 0.215314  │ 0.220054       │
# │ 4   │ 4328     │ -0.2    │ -0.208896 │ -0.21478       │
# │ 5   │ 4332     │ -0.2    │ -0.198215 │ -0.187961      │
# │ 6   │ 4334     │ -0.2    │ -0.157067 │ -0.156363      │
# │ 7   │ 8625     │ -0.2    │ -0.256269 │ -0.258545      │
# │ 8   │ 8633     │ 0.2     │ 0.227437  │ 0.233393       │
# │ 9   │ 8638     │ -0.2    │ -0.224818 │ -0.212275      │
# │ 10  │ 8640     │ -0.2    │ -0.256881 │ -0.244643      │
# │ 11  │ 8702     │ 0.2     │ 0.0       │ 0.127653       │
# │ 12  │ 8704     │ -0.2    │ -0.236027 │ -0.228124      │
# │ 13  │ 8708     │ -0.2    │ -0.326851 │ -0.300027      │
# │ 14  │ 8711     │ 0.2     │ 0.0       │ 0.0            │
# │ 15  │ 8720     │ -0.2    │ -0.339122 │ -0.250616      │
#
#
# running 38 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 70       │ -0.2    │ -0.2235   │ -0.223501      │
# │ 2   │ 642      │ 0.2     │ 0.206586  │ 0.206585       │
# │ 3   │ 648      │ 0.2     │ 0.169249  │ 0.169252       │
# │ 4   │ 2568     │ -0.2    │ -0.246788 │ -0.246791      │
# │ 5   │ 2570     │ -0.2    │ -0.151859 │ -0.151859      │
# │ 6   │ 2580     │ -0.2    │ -0.214973 │ -0.214974      │
# │ 7   │ 2702     │ 0.2     │ 0.199942  │ 0.199948       │
# │ 8   │ 2708     │ 0.2     │ 0.219131  │ 0.219131       │
# │ 9   │ 2711     │ -0.2    │ 0.0       │ 0.0            │
# │ 10  │ 2719     │ 0.2     │ 0.161499  │ 0.161499       │
# │ 11  │ 9523     │ -0.2    │ -0.136057 │ -0.136055      │
# │ 12  │ 9533     │ 0.2     │ 0.0       │ 0.0            │
# │ 13  │ 9536     │ -0.2    │ 0.0       │ 0.0            │
# │ 14  │ 9537     │ -0.2    │ -0.187982 │ -0.188002      │
# │ 15  │ 9539     │ 0.2     │ 0.160004  │ 0.160014       │
#
#
# running 39 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 1087     │ -0.2    │ -0.215544 │ -0.209745      │
# │ 2   │ 4928     │ -0.2    │ -0.162125 │ 0.0            │
# │ 3   │ 4937     │ 0.2     │ 0.248624  │ 0.236408       │
# │ 4   │ 5343     │ -0.2    │ -0.209601 │ -0.19068       │
# │ 5   │ 5346     │ 0.2     │ 0.219506  │ 0.20517        │
# │ 6   │ 5349     │ 0.2     │ 0.282534  │ 0.303129       │
# │ 7   │ 6143     │ -0.2    │ 0.0       │ -0.243312      │
# │ 8   │ 6144     │ 0.2     │ 0.0       │ 0.230312       │
# │ 9   │ 6153     │ 0.2     │ 0.211986  │ 0.184621       │
# │ 10  │ 6154     │ -0.2    │ -0.256985 │ -0.184985      │
# │ 11  │ 8926     │ 0.2     │ 0.23536   │ 0.400462       │
# │ 12  │ 8928     │ 0.2     │ 0.0       │ 0.0            │
# │ 13  │ 8932     │ 0.2     │ 0.225906  │ 0.0            │
# │ 14  │ 8934     │ -0.2    │ -0.174942 │ -0.0868862     │
# │ 15  │ 8935     │ -0.2    │ -0.144085 │ -0.219295      │
#
#
# running 40 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 989      │ 0.2     │ 0.214395  │ 0.211201       │
# │ 2   │ 1750     │ -0.2    │ -0.237817 │ -0.231476      │
# │ 3   │ 1753     │ 0.2     │ 0.174418  │ 0.186441       │
# │ 4   │ 6401     │ -0.2    │ -0.216938 │ -0.212872      │
# │ 5   │ 6412     │ -0.2    │ -0.280824 │ -0.284841      │
# │ 6   │ 6415     │ 0.2     │ 0.186815  │ 0.183613       │
# │ 7   │ 7763     │ -0.2    │ -0.163726 │ -0.15848       │
# │ 8   │ 7764     │ 0.2     │ 0.0       │ 0.142872       │
# │ 9   │ 7778     │ 0.2     │ 0.169002  │ 0.189019       │
# │ 10  │ 7780     │ 0.2     │ 0.194141  │ 0.201616       │
# │ 11  │ 9382     │ 0.2     │ 0.181244  │ 0.163006       │
# │ 12  │ 9387     │ 0.2     │ 0.0       │ 0.0777506      │
# │ 13  │ 9388     │ -0.2    │ 0.0       │ 0.0            │
# │ 14  │ 9394     │ 0.2     │ 0.0       │ 0.0            │
# │ 15  │ 9396     │ 0.2     │ 0.0       │ 0.0            │
#
#
# running 41 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 2860     │ -0.2    │ -0.171568 │ -0.184176      │
# │ 2   │ 4586     │ -0.2    │ 0.0       │ 0.0            │
# │ 3   │ 4597     │ 0.2     │ 0.168017  │ 0.17501        │
# │ 4   │ 6407     │ -0.2    │ -0.187961 │ -0.189898      │
# │ 5   │ 6411     │ -0.2    │ -0.228052 │ -0.219817      │
# │ 6   │ 6412     │ -0.2    │ -0.162825 │ -0.174525      │
# │ 7   │ 7031     │ -0.2    │ 0.0       │ 0.0            │
# │ 8   │ 7032     │ -0.2    │ -0.31143  │ -0.260027      │
# │ 9   │ 7033     │ 0.2     │ 0.177162  │ 0.183369       │
# │ 10  │ 7040     │ 0.2     │ 0.205222  │ 0.162459       │
# │ 11  │ 8922     │ 0.2     │ 0.191143  │ 0.208629       │
# │ 12  │ 8924     │ -0.2    │ -0.176147 │ -0.250364      │
# │ 13  │ 8930     │ 0.2     │ 0.198495  │ 0.0            │
# │ 14  │ 8939     │ 0.2     │ 0.210735  │ 0.169626       │
# │ 15  │ 8940     │ 0.2     │ 0.195897  │ 0.255378       │
#
#
# running 42 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 385      │ 0.2     │ 0.206345  │ 0.211836       │
# │ 2   │ 1381     │ -0.2    │ -0.199821 │ -0.206616      │
# │ 3   │ 1393     │ 0.2     │ 0.211594  │ 0.227183       │
# │ 4   │ 3602     │ 0.2     │ 0.222979  │ 0.195558       │
# │ 5   │ 3604     │ 0.2     │ 0.19492   │ 0.192926       │
# │ 6   │ 3620     │ 0.2     │ 0.20083   │ 0.199108       │
# │ 7   │ 3624     │ 0.2     │ 0.369156  │ 0.354423       │
# │ 8   │ 3628     │ -0.2    │ 0.0       │ 0.0            │
# │ 9   │ 3629     │ -0.2    │ -0.307522 │ -0.305882      │
# │ 10  │ 3632     │ 0.2     │ 0.0       │ 0.0            │
# │ 11  │ 8527     │ 0.2     │ 0.0       │ 0.15292        │
# │ 12  │ 8528     │ -0.2    │ -0.208667 │ -0.259837      │
# │ 13  │ 8530     │ -0.2    │ -0.34438  │ -0.258986      │
# │ 14  │ 8531     │ -0.2    │ 0.0       │ 0.0            │
# │ 15  │ 8535     │ 0.2     │ 0.133254  │ 0.0            │
#
#
# running 43 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 5586     │ -0.2    │ -0.176642 │ -0.178093      │
# │ 2   │ 7363     │ 0.2     │ 0.208268  │ 0.0            │
# │ 3   │ 7379     │ 0.2     │ 0.181884  │ 0.152121       │
# │ 4   │ 8264     │ -0.2    │ -0.243483 │ -0.254709      │
# │ 5   │ 8266     │ -0.2    │ -0.17498  │ -0.168403      │
# │ 6   │ 8278     │ 0.2     │ 0.20366   │ 0.202461       │
# │ 7   │ 8672     │ -0.2    │ -0.323811 │ -0.315316      │
# │ 8   │ 8673     │ 0.2     │ 0.150422  │ 0.19063        │
# │ 9   │ 8675     │ -0.2    │ -0.291986 │ -0.219699      │
# │ 10  │ 8677     │ -0.2    │ 0.0       │ -0.147362      │
# │ 11  │ 8761     │ 0.2     │ 0.166997  │ 0.229073       │
# │ 12  │ 8766     │ -0.2    │ -0.141429 │ -0.186105      │
# │ 13  │ 8769     │ 0.2     │ 0.0       │ 0.180378       │
# │ 14  │ 8771     │ -0.2    │ 0.0       │ -0.23577       │
# │ 15  │ 8772     │ 0.2     │ 0.0       │ 0.187557       │
#
#
# running 44 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 2900     │ 0.2     │ 0.18156   │ 0.185003       │
# │ 2   │ 4749     │ 0.2     │ 0.188559  │ 0.189982       │
# │ 3   │ 4754     │ 0.2     │ 0.208184  │ 0.200279       │
# │ 4   │ 5241     │ 0.2     │ 0.237918  │ 0.224202       │
# │ 5   │ 5250     │ 0.2     │ 0.0       │ 0.151033       │
# │ 6   │ 5256     │ -0.2    │ 0.0       │ -0.162402      │
# │ 7   │ 6641     │ 0.2     │ 0.1719    │ 0.168345       │
# │ 8   │ 6644     │ 0.2     │ 0.238259  │ 0.208183       │
# │ 9   │ 6651     │ 0.2     │ 0.169428  │ 0.178677       │
# │ 10  │ 6653     │ 0.2     │ 0.19425   │ 0.194576       │
# ...
# │ 7   │ 8742     │ -0.2    │ -0.192103 │ 0.0            │
# │ 8   │ 8747     │ -0.2    │ -0.192595 │ 0.0            │
# │ 9   │ 8750     │ -0.2    │ -0.221085 │ -0.153396      │
# │ 10  │ 8756     │ 0.2     │ 0.22958   │ 0.255884       │
# │ 11  │ 9541     │ -0.2    │ 0.0       │ -0.192826      │
# │ 12  │ 9543     │ 0.2     │ 0.0       │ 0.183171       │
# │ 13  │ 9554     │ -0.2    │ -0.164082 │ -0.155802      │
# │ 14  │ 9558     │ -0.2    │ -0.218144 │ -0.201285      │
# │ 15  │ 9560     │ -0.2    │ -0.297543 │ -0.244574      │
#
#
# running 87 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 1159     │ 0.2     │ 0.169553  │ 0.179309       │
# │ 2   │ 5107     │ -0.2    │ -0.246775 │ -0.257908      │
# │ 3   │ 5117     │ -0.2    │ -0.221053 │ -0.216495      │
# │ 4   │ 7906     │ 0.2     │ 0.0       │ 0.0            │
# │ 5   │ 7913     │ 0.2     │ 0.21818   │ 0.247475       │
# │ 6   │ 7918     │ 0.2     │ 0.172151  │ 0.167522       │
# │ 7   │ 9802     │ -0.2    │ 0.0       │ 0.0            │
# │ 8   │ 9805     │ 0.2     │ 0.0       │ 0.0981644      │
# │ 9   │ 9810     │ -0.2    │ 0.0       │ -0.0676722     │
# │ 10  │ 9813     │ -0.2    │ 0.0       │ 0.0            │
# │ 11  │ 9961     │ -0.2    │ -0.234455 │ -0.22215       │
# │ 12  │ 9966     │ 0.2     │ 0.195886  │ 0.188863       │
# │ 13  │ 9967     │ 0.2     │ 0.132703  │ 0.144108       │
# │ 14  │ 9972     │ -0.2    │ -0.203094 │ -0.222244      │
# │ 15  │ 9975     │ -0.2    │ -0.211788 │ -0.212985      │
#
#
# running 88 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 445      │ -0.2    │ -0.172466 │ -0.167645      │
# │ 2   │ 2977     │ -0.2    │ -0.21112  │ 0.0            │
# │ 3   │ 2980     │ -0.2    │ -0.232832 │ -0.231557      │
# │ 4   │ 5001     │ -0.2    │ 0.0       │ 0.0            │
# │ 5   │ 5004     │ 0.2     │ 0.0       │ 0.0            │
# │ 6   │ 5012     │ -0.2    │ 0.0       │ 0.0            │
# │ 7   │ 5589     │ -0.2    │ -0.209635 │ -0.186897      │
# │ 8   │ 5591     │ -0.2    │ -0.227276 │ -0.196355      │
# │ 9   │ 5599     │ 0.2     │ 0.0       │ 0.153164       │
# │ 10  │ 5600     │ -0.2    │ 0.0       │ -0.16875       │
# │ 11  │ 9562     │ -0.2    │ -0.172305 │ -0.164939      │
# │ 12  │ 9573     │ 0.2     │ 0.209801  │ 0.234993       │
# │ 13  │ 9575     │ -0.2    │ -0.229611 │ -0.279854      │
# │ 14  │ 9576     │ -0.2    │ -0.181366 │ -0.139206      │
# │ 15  │ 9578     │ 0.2     │ 0.19562   │ 0.194476       │
#
#
# running 89 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 63       │ -0.2    │ -0.256168 │ -0.264881      │
# │ 2   │ 2907     │ 0.2     │ 0.174019  │ 0.178289       │
# │ 3   │ 2915     │ -0.2    │ -0.191864 │ -0.199428      │
# │ 4   │ 4304     │ 0.2     │ 0.131703  │ 0.181556       │
# │ 5   │ 4305     │ 0.2     │ 0.171477  │ 0.186048       │
# │ 6   │ 4306     │ -0.2    │ 0.0       │ 0.0            │
# │ 7   │ 6261     │ 0.2     │ 0.0       │ 0.118956       │
# │ 8   │ 6265     │ 0.2     │ 0.0       │ 0.119208       │
# │ 9   │ 6268     │ -0.2    │ 0.0       │ 0.0            │
# │ 10  │ 6275     │ -0.2    │ 0.0       │ 0.0            │
# │ 11  │ 7784     │ -0.2    │ -0.208347 │ 0.0            │
# │ 12  │ 7789     │ 0.2     │ 0.209481  │ 0.0            │
# │ 13  │ 7790     │ 0.2     │ 0.256681  │ 0.17489        │
# │ 14  │ 7791     │ 0.2     │ 0.175866  │ 0.224647       │
# │ 15  │ 7793     │ 0.2     │ 0.195877  │ 0.25409        │
#
#
# running 90 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 1736     │ -0.2    │ -0.174848 │ -0.168858      │
# │ 2   │ 3182     │ -0.2    │ -0.19875  │ -0.209062      │
# │ 3   │ 3184     │ -0.2    │ -0.176133 │ -0.170253      │
# │ 4   │ 5926     │ 0.2     │ 0.184621  │ 0.205075       │
# │ 5   │ 5927     │ 0.2     │ 0.183893  │ 0.157116       │
# │ 6   │ 5930     │ 0.2     │ 0.239992  │ 0.0            │
# │ 7   │ 6650     │ 0.2     │ 0.157376  │ 0.231808       │
# │ 8   │ 6651     │ -0.2    │ 0.0       │ 0.0            │
# │ 9   │ 6652     │ 0.2     │ 0.0       │ 0.0            │
# │ 10  │ 6653     │ -0.2    │ 0.0       │ -0.101433      │
# │ 11  │ 8781     │ -0.2    │ 0.0       │ -0.0981702     │
# │ 12  │ 8783     │ 0.2     │ 0.122706  │ 0.177279       │
# │ 13  │ 8785     │ 0.2     │ 0.184554  │ 0.159483       │
# │ 14  │ 8791     │ -0.2    │ 0.0       │ 0.0            │
# │ 15  │ 8798     │ 0.2     │ 0.0       │ 0.116817       │
#
#
# running 91 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 2130     │ 0.2     │ 0.219009  │ 0.214071       │
# │ 2   │ 5806     │ -0.2    │ -0.224568 │ -0.229775      │
# │ 3   │ 5809     │ -0.2    │ -0.171196 │ -0.188288      │
# │ 4   │ 6422     │ 0.2     │ 0.224704  │ 0.149444       │
# │ 5   │ 6432     │ -0.2    │ -0.218922 │ -0.275254      │
# │ 6   │ 6439     │ 0.2     │ 0.196134  │ 0.0            │
# │ 7   │ 8165     │ -0.2    │ -0.216929 │ -0.212222      │
# │ 8   │ 8170     │ 0.2     │ 0.192673  │ 0.196482       │
# │ 9   │ 8172     │ 0.2     │ 0.234875  │ 0.23237        │
# │ 10  │ 8173     │ 0.2     │ 0.160446  │ 0.163719       │
# │ 11  │ 8883     │ 0.2     │ 0.202975  │ 0.175354       │
# │ 12  │ 8886     │ -0.2    │ -0.236651 │ -0.19147       │
# │ 13  │ 8893     │ 0.2     │ 0.217687  │ 0.204487       │
# │ 14  │ 8897     │ 0.2     │ 0.0       │ 0.0            │
# │ 15  │ 8900     │ 0.2     │ 0.145462  │ 0.145005       │
#
#
# running 92 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 654      │ 0.2     │ 0.206625  │ 0.211377       │
# │ 2   │ 5641     │ -0.2    │ -0.168722 │ -0.158911      │
# │ 3   │ 5658     │ -0.2    │ -0.208099 │ -0.207282      │
# │ 4   │ 6765     │ 0.2     │ 0.0       │ 0.197797       │
# │ 5   │ 6774     │ -0.2    │ -0.187738 │ -0.226488      │
# │ 6   │ 6779     │ -0.2    │ -0.185496 │ -0.189358      │
# │ 7   │ 7183     │ 0.2     │ 0.137079  │ 0.144916       │
# │ 8   │ 7190     │ 0.2     │ 0.0       │ 0.0            │
# │ 9   │ 7191     │ -0.2    │ 0.0       │ -0.116776      │
# │ 10  │ 7199     │ -0.2    │ -0.221494 │ -0.1918        │
# │ 11  │ 9166     │ 0.2     │ 0.0       │ 0.0            │
# │ 12  │ 9167     │ -0.2    │ -0.109952 │ 0.0            │
# │ 13  │ 9168     │ -0.2    │ -0.201207 │ -0.293931      │
# │ 14  │ 9175     │ 0.2     │ 0.313989  │ 0.306297       │
# │ 15  │ 9176     │ 0.2     │ 0.0       │ 0.0            │
#
#
# running 93 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 3266     │ 0.2     │ 0.212329  │ 0.203052       │
# │ 2   │ 3493     │ 0.2     │ 0.0       │ 0.0            │
# │ 3   │ 3500     │ -0.2    │ 0.0       │ 0.0            │
# │ 4   │ 5723     │ -0.2    │ -0.223943 │ -0.210852      │
# │ 5   │ 5728     │ 0.2     │ 0.217053  │ 0.235962       │
# │ 6   │ 5734     │ 0.2     │ 0.180656  │ 0.187844       │
# │ 7   │ 7261     │ 0.2     │ 0.0       │ 0.0            │
# │ 8   │ 7269     │ 0.2     │ 0.221433  │ 0.171061       │
# │ 9   │ 7272     │ 0.2     │ 0.0       │ 0.076793       │
# │ 10  │ 7276     │ -0.2    │ -0.200014 │ -0.204173      │
# │ 11  │ 9409     │ -0.2    │ -0.159538 │ -0.253262      │
# │ 12  │ 9410     │ -0.2    │ -0.23552  │ -0.111476      │
# │ 13  │ 9412     │ 0.2     │ 0.179701  │ 0.197147       │
# │ 14  │ 9413     │ -0.2    │ -0.193211 │ -0.158523      │
# │ 15  │ 9420     │ -0.2    │ -0.194103 │ 0.0            │
#
#
# running 94 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 904      │ 0.2     │ 0.16609   │ 0.171785       │
# │ 2   │ 4881     │ -0.2    │ -0.235927 │ -0.186514      │
# │ 3   │ 4890     │ 0.2     │ 0.195627  │ 0.0            │
# │ 4   │ 5585     │ 0.2     │ 0.212602  │ 0.161021       │
# │ 5   │ 5589     │ -0.2    │ 0.0       │ -0.126383      │
# │ 6   │ 5594     │ 0.2     │ 0.187435  │ 0.182603       │
# │ 7   │ 7766     │ -0.2    │ -0.227611 │ -0.232653      │
# │ 8   │ 7770     │ 0.2     │ 0.189867  │ 0.172153       │
# │ 9   │ 7773     │ -0.2    │ -0.173152 │ -0.155249      │
# │ 10  │ 7778     │ -0.2    │ -0.184162 │ -0.205819      │
# │ 11  │ 9181     │ 0.2     │ 0.0       │ 0.0            │
# │ 12  │ 9183     │ -0.2    │ 0.0       │ -0.111133      │
# │ 13  │ 9188     │ 0.2     │ 0.245278  │ 0.200427       │
# │ 14  │ 9197     │ -0.2    │ -0.235349 │ -0.261215      │
# │ 15  │ 9198     │ -0.2    │ -0.125897 │ -0.0566852     │
#
#
# running 95 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 1198     │ -0.2    │ -0.190274 │ -0.192004      │
# │ 2   │ 5353     │ 0.2     │ 0.0       │ 0.0            │
# │ 3   │ 5354     │ -0.2    │ 0.0       │ 0.0            │
# │ 4   │ 7044     │ 0.2     │ 0.0       │ 0.0            │
# │ 5   │ 7050     │ 0.2     │ 0.147936  │ 0.189135       │
# │ 6   │ 7060     │ -0.2    │ 0.0       │ 0.0            │
# │ 7   │ 7706     │ 0.2     │ 0.0       │ 0.180467       │
# │ 8   │ 7712     │ -0.2    │ 0.0       │ -0.192773      │
# │ 9   │ 7713     │ 0.2     │ 0.0       │ 0.203552       │
# │ 10  │ 7718     │ -0.2    │ -0.275105 │ -0.262079      │
# │ 11  │ 8166     │ -0.2    │ 0.0       │ -0.0802987     │
# │ 12  │ 8168     │ -0.2    │ 0.0       │ 0.0            │
# │ 13  │ 8169     │ 0.2     │ 0.0       │ 0.0            │
# │ 14  │ 8171     │ -0.2    │ -0.307341 │ -0.294736      │
# │ 15  │ 8174     │ -0.2    │ 0.0       │ 0.0            │
#
#
# running 96 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 1411     │ -0.2    │ -0.234384 │ -0.225143      │
# │ 2   │ 6485     │ 0.2     │ 0.181634  │ 0.18719        │
# │ 3   │ 6499     │ 0.2     │ 0.175171  │ 0.175059       │
# │ 4   │ 8067     │ -0.2    │ 0.0       │ 0.0            │
# │ 5   │ 8071     │ 0.2     │ 0.19027   │ 0.19593        │
# │ 6   │ 8080     │ -0.2    │ -0.195398 │ -0.195286      │
# │ 7   │ 8403     │ -0.2    │ -0.19645  │ -0.201563      │
# │ 8   │ 8407     │ -0.2    │ -0.173145 │ -0.175263      │
# │ 9   │ 8414     │ 0.2     │ 0.168594  │ 0.174436       │
# │ 10  │ 8417     │ 0.2     │ 0.243336  │ 0.229435       │
# │ 11  │ 8490     │ 0.2     │ 0.292804  │ 0.265961       │
# │ 12  │ 8494     │ 0.2     │ 0.242518  │ 0.198885       │
# │ 13  │ 8496     │ -0.2    │ -0.260851 │ -0.225502      │
# │ 14  │ 8499     │ -0.2    │ 0.0       │ -0.158811      │
# │ 15  │ 8500     │ 0.2     │ 0.0       │ 0.189989       │
#
#
# running 97 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 1222     │ 0.2     │ 0.230485  │ 0.243075       │
# │ 2   │ 6024     │ -0.2    │ -0.227986 │ -0.228191      │
# │ 3   │ 6032     │ 0.2     │ 0.224198  │ 0.197425       │
# │ 4   │ 8008     │ -0.2    │ -0.227399 │ -0.207358      │
# │ 5   │ 8009     │ -0.2    │ -0.174131 │ -0.198583      │
# │ 6   │ 8010     │ -0.2    │ -0.207748 │ -0.209989      │
# │ 7   │ 9153     │ -0.2    │ 0.0       │ -0.185441      │
# │ 8   │ 9154     │ 0.2     │ 0.0       │ 0.172031       │
# │ 9   │ 9157     │ -0.2    │ -0.186638 │ -0.164491      │
# │ 10  │ 9160     │ 0.2     │ 0.134772  │ 0.171911       │
# │ 11  │ 9501     │ 0.2     │ 0.165027  │ 0.172954       │
# │ 12  │ 9508     │ -0.2    │ 0.0       │ -0.209419      │
# │ 13  │ 9512     │ -0.2    │ 0.0       │ -0.164086      │
# │ 14  │ 9514     │ 0.2     │ 0.0       │ 0.0            │
# │ 15  │ 9515     │ -0.2    │ -0.168943 │ -0.132038      │
#
#
# running 98 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 367      │ 0.2     │ 0.0907637 │ 0.0            │
# │ 2   │ 1243     │ 0.2     │ 0.230051  │ 0.233577       │
# │ 3   │ 1252     │ 0.2     │ 0.179904  │ 0.174389       │
# │ 4   │ 7027     │ 0.2     │ 0.223159  │ 0.219996       │
# │ 5   │ 7029     │ 0.2     │ 0.0       │ 0.0            │
# │ 6   │ 7030     │ -0.2    │ 0.0       │ -0.100731      │
# │ 7   │ 7608     │ -0.2    │ -0.229387 │ -0.229917      │
# │ 8   │ 7613     │ -0.2    │ -0.217241 │ -0.221659      │
# │ 9   │ 7616     │ -0.2    │ -0.197287 │ -0.20911       │
# │ 10  │ 7620     │ 0.2     │ 0.163161  │ 0.164992       │
# │ 11  │ 9763     │ -0.2    │ -0.26371  │ -0.23014       │
# │ 12  │ 9769     │ -0.2    │ -0.225332 │ -0.194215      │
# │ 13  │ 9773     │ -0.2    │ -0.218223 │ 0.0            │
# │ 14  │ 9779     │ 0.2     │ 0.20559   │ 0.0981227      │
# │ 15  │ 9780     │ 0.2     │ 0.120493  │ 0.230839       │
#
#
# running 99 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 931      │ -0.2    │ -0.180573 │ -0.165966      │
# │ 2   │ 3842     │ 0.2     │ 0.230863  │ 0.238689       │
# │ 3   │ 3855     │ -0.2    │ -0.177023 │ -0.187967      │
# │ 4   │ 4005     │ 0.2     │ 0.22062   │ 0.221408       │
# │ 5   │ 4006     │ 0.2     │ 0.217401  │ 0.219326       │
# │ 6   │ 4019     │ 0.2     │ 0.193077  │ 0.216259       │
# │ 7   │ 4284     │ 0.2     │ 0.0       │ 0.15003        │
# │ 8   │ 4289     │ 0.2     │ 0.0       │ 0.269208       │
# │ 9   │ 4290     │ 0.2     │ 0.198303  │ 0.200801       │
# │ 10  │ 4298     │ -0.2    │ -0.189043 │ -0.24283       │
# │ 11  │ 6841     │ 0.2     │ 0.175975  │ 0.16661        │
# │ 12  │ 6842     │ 0.2     │ 0.179175  │ 0.170917       │
# │ 13  │ 6844     │ 0.2     │ 0.0       │ 0.190988       │
# │ 14  │ 6845     │ -0.2    │ 0.0       │ 0.0            │
# │ 15  │ 6846     │ -0.2    │ -0.239333 │ -0.316797      │
#
#
# running 100 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ variable_group │
# │     │ Int64    │ Float64 │ Float64   │ Float64        │
# ├─────┼──────────┼─────────┼───────────┼────────────────┤
# │ 1   │ 1730     │ 0.2     │ 0.26498   │ 0.250949       │
# │ 2   │ 3782     │ -0.2    │ -0.241086 │ -0.24281       │
# │ 3   │ 3796     │ 0.2     │ 0.284998  │ 0.276475       │
# │ 4   │ 3904     │ 0.2     │ 0.17776   │ 0.174119       │
# │ 5   │ 3915     │ -0.2    │ -0.15449  │ -0.16905       │
# │ 6   │ 3917     │ -0.2    │ -0.157908 │ -0.154638      │
# │ 7   │ 5044     │ 0.2     │ 0.0       │ 0.0            │
# │ 8   │ 5045     │ -0.2    │ 0.0       │ 0.0            │
# │ 9   │ 5048     │ 0.2     │ 0.0       │ 0.0            │
# │ 10  │ 5051     │ 0.2     │ 0.0       │ 0.14091        │
# │ 11  │ 8462     │ -0.2    │ 0.0       │ -0.141842      │
# │ 12  │ 8465     │ 0.2     │ 0.0       │ 0.0965675      │
# │ 13  │ 8475     │ -0.2    │ 0.0       │ 0.0            │
# │ 14  │ 8476     │ 0.2     │ 0.146986  │ 0.086832       │
# │ 15  │ 8479     │ 0.2     │ 0.133896  │ 0.174827       │
#
#
# 132.792140 seconds (1.04 M allocations: 11.022 GiB, 12.15% gc time)

# %%
@show mean(ungroup_true_positives)
@show mean(ungroup_false_positives)
@show mean(variable_true_positives)
@show mean(variable_false_positives)

@show std(ungroup_true_positives)
@show std(ungroup_false_positives)
@show std(variable_true_positives)
@show std(variable_false_positives)
# Out:
# mean(ungroup_true_positives) = 11.0
# mean(ungroup_false_positives) = 4.0
# mean(variable_true_positives) = 12.35
# mean(variable_false_positives) = 2.65
# std(ungroup_true_positives) = 2.098580568870398
# std(ungroup_false_positives) = 2.098580568870398
# std(variable_true_positives) = 1.5851265762160014
# std(variable_false_positives) = 1.5851265762160014
# 1.5851265762160014
