# %% [markdown]
# # Doubly sparse projection for rare variant discovery

# %%
using Revise
using MendelIHT
using SnpArrays
using DataFrames
using Distributions
using BenchmarkTools
using Random
using LinearAlgebra
using GLM

# %%
#simulate 5 genes, each with 5 rare variants and 1 non-rare variant
function compare(d::UnionAll, l::Link)
    
    # define problem size
    n = 1000
    p = 100000

    # assign group membership
    g = ones(Int64, p + 1)
    g[20001:40000] .= 2
    g[40001:60000] .= 3
    g[60001:80000] .= 4
    g[80001:end] .= 5
    
    # construct 2 rare variants and 1 non rare variant in each group (gene)
    true_b = zeros(p)
    rare = collect(4000:4000:100000)
    common = collect(10000:20000:100000)
    [true_b[i] = 0.5 for i in rare]
    [true_b[i] = 0.5 for i in common]
    
    # construct snpmatrix, covariate files, and true model b using specific minor allele freq
    mafs = 0.5rand(p)
    clamp!(mafs, 0.05, 0.5)
    mafs[rare] .= 0.005
    mafs[common] .= 0.4
    x = simulate_random_snparray(n, p, "tmp.bed", mafs)
    z = ones(n, 1) # the intercept
    xbm = SnpBitMatrix{Float64}(x, model=ADDITIVE_MODEL, center=true, scale=true); 

    # use the SnpBitMatrix to simulate data
    prob = linkinv.(l, xbm * true_b)
    y = [rand(d(i)) for i in prob]
    y = Float64.(y)
    println("number of cases = " * string(sum(y)))
        
    #run IHT without groups
    k = 30
    ungrouped = L0_reg(x, xbm, z, y, 1, k, d(), l, debias=true, init=false, use_maf=false)
        
    #run IHT with groups
    J = 5
    k = 6
    grouped = L0_reg(x, xbm, z, y, J, k, d(), l, debias=true, init=false, use_maf=false, group=g)

    #check result
    correct_position = [common; rare] # 10000, 30000, 50000, 70000, 90000 are common ones, other are rares
    compare_model = DataFrame(
        position   = correct_position,
        correct    = true_b[correct_position],
        ungrouped  = ungrouped.beta[correct_position], 
        grouped    = grouped.beta[correct_position])
    @show compare_model
    println("\n")

    #clean up
    rm("tmp.bed", force=true)
    
    group_rare = count(!iszero, grouped.beta[rare])
    group_common = count(!iszero, grouped.beta[common])
    ungroup_rare = count(!iszero, ungrouped.beta[rare])
    ungroup_common = count(!iszero, ungrouped.beta[common])
    return group_rare, group_common, ungroup_rare, ungroup_common
end
# Out:
# compare (generic function with 1 method)

# %%
Random.seed!(2019)
d = Bernoulli
l = canonicallink(d())

group_rare_found = 0
group_common_found = 0
ungroup_rare_found = 0
ungroup_common_found = 0

num_runs = 10
for i in 1:num_runs
    println("running $i th model")
    gr, gc, ur, uc = compare(d, l)
    group_rare_found += gr
    group_common_found += gc
    ungroup_rare_found += ur
    ungroup_common_found += uc
end

println("Group IHT found: $group_common_found / " * string(5*num_runs) * " common variants and $group_rare_found / " * string(25*num_runs) * "rare variants")
println("Ungrouped IHT found: $ungroup_common_found / " * string(5*num_runs) * " common variants and $ungroup_rare_found / " * string(25*num_runs) * "rare variants")
# Out:
# running 1 th model
# number of cases = 426.0
# compare_model = 30×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped  │
# │     │ Int64    │ Float64 │ Float64   │ Float64  │
# ├─────┼──────────┼─────────┼───────────┼──────────┤
# │ 1   │ 10000    │ 0.5     │ 0.583125  │ 0.624073 │
# │ 2   │ 30000    │ 0.5     │ 0.51649   │ 0.50558  │
# │ 3   │ 50000    │ 0.5     │ 0.0       │ 0.0      │
# │ 4   │ 70000    │ 0.5     │ 0.524118  │ 0.556743 │
# │ 5   │ 90000    │ 0.5     │ 0.0       │ 0.442866 │
# │ 6   │ 4000     │ 0.5     │ 0.0       │ 0.417332 │
# │ 7   │ 8000     │ 0.5     │ 0.840596  │ 1.02274  │
# │ 8   │ 12000    │ 0.5     │ 0.0       │ 0.0      │
# │ 9   │ 16000    │ 0.5     │ 0.956049  │ 0.883687 │
# │ 10  │ 20000    │ 0.5     │ 0.0       │ 0.0      │
# │ 11  │ 24000    │ 0.5     │ 0.697486  │ 0.702569 │
# │ 12  │ 28000    │ 0.5     │ 0.487665  │ 0.550583 │
# │ 13  │ 32000    │ 0.5     │ 0.0       │ 0.0      │
# │ 14  │ 36000    │ 0.5     │ 0.0       │ 0.0      │
# │ 15  │ 40000    │ 0.5     │ 0.0       │ 0.724664 │
# │ 16  │ 44000    │ 0.5     │ 0.0       │ 0.0      │
# │ 17  │ 48000    │ 0.5     │ 0.660873  │ 0.734772 │
# │ 18  │ 52000    │ 0.5     │ 0.0       │ 0.0      │
# │ 19  │ 56000    │ 0.5     │ 0.854329  │ 0.723111 │
# │ 20  │ 60000    │ 0.5     │ 0.492104  │ 0.491965 │
# │ 21  │ 64000    │ 0.5     │ 0.0       │ 0.671978 │
# │ 22  │ 68000    │ 0.5     │ 0.0       │ 0.0      │
# │ 23  │ 72000    │ 0.5     │ 0.818541  │ 0.796672 │
# │ 24  │ 76000    │ 0.5     │ 0.878175  │ 0.816169 │
# │ 25  │ 80000    │ 0.5     │ 0.292155  │ 0.405124 │
# │ 26  │ 84000    │ 0.5     │ 0.0       │ 0.0      │
# │ 27  │ 88000    │ 0.5     │ 0.708468  │ 0.643932 │
# │ 28  │ 92000    │ 0.5     │ 0.0       │ 0.0      │
# │ 29  │ 96000    │ 0.5     │ 0.809676  │ 0.82022  │
# │ 30  │ 100000   │ 0.5     │ 0.804368  │ 0.790619 │
#
#
# running 2 th model
# number of cases = 424.0
# compare_model = 30×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped  │
# │     │ Int64    │ Float64 │ Float64   │ Float64  │
# ├─────┼──────────┼─────────┼───────────┼──────────┤
# │ 1   │ 10000    │ 0.5     │ 0.732883  │ 0.730308 │
# │ 2   │ 30000    │ 0.5     │ 0.635294  │ 0.557589 │
# │ 3   │ 50000    │ 0.5     │ 0.525116  │ 0.456668 │
# │ 4   │ 70000    │ 0.5     │ 0.529605  │ 0.47355  │
# │ 5   │ 90000    │ 0.5     │ 0.0       │ 0.0      │
# │ 6   │ 4000     │ 0.5     │ 0.697548  │ 0.826346 │
# │ 7   │ 8000     │ 0.5     │ 0.790544  │ 0.845896 │
# │ 8   │ 12000    │ 0.5     │ 0.621585  │ 0.0      │
# │ 9   │ 16000    │ 0.5     │ 0.0       │ 0.0      │
# │ 10  │ 20000    │ 0.5     │ 0.0       │ 0.373538 │
# │ 11  │ 24000    │ 0.5     │ 0.0       │ 0.0      │
# │ 12  │ 28000    │ 0.5     │ 0.82491   │ 0.0      │
# │ 13  │ 32000    │ 0.5     │ 0.581522  │ 0.0      │
# │ 14  │ 36000    │ 0.5     │ 0.562496  │ 0.636103 │
# │ 15  │ 40000    │ 0.5     │ 0.688212  │ 0.0      │
# │ 16  │ 44000    │ 0.5     │ 0.61124   │ 0.622988 │
# │ 17  │ 48000    │ 0.5     │ 0.355411  │ 0.41726  │
# │ 18  │ 52000    │ 0.5     │ 0.795888  │ 0.864215 │
# │ 19  │ 56000    │ 0.5     │ 1.00173   │ 1.00491  │
# │ 20  │ 60000    │ 0.5     │ 0.0       │ 0.0      │
# │ 21  │ 64000    │ 0.5     │ 0.0       │ 0.0      │
# │ 22  │ 68000    │ 0.5     │ 0.866801  │ 0.807906 │
# │ 23  │ 72000    │ 0.5     │ 0.0       │ 0.0      │
# │ 24  │ 76000    │ 0.5     │ 0.0       │ 0.0      │
# │ 25  │ 80000    │ 0.5     │ 0.883855  │ 0.92521  │
# │ 26  │ 84000    │ 0.5     │ 0.0       │ 0.0      │
# │ 27  │ 88000    │ 0.5     │ 0.0       │ 0.0      │
# │ 28  │ 92000    │ 0.5     │ 0.783396  │ 0.920648 │
# │ 29  │ 96000    │ 0.5     │ 0.627994  │ 0.684706 │
# │ 30  │ 100000   │ 0.5     │ 0.0       │ 0.661652 │
#
#
# running 3 th model
# number of cases = 401.0
# compare_model = 30×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped  │
# │     │ Int64    │ Float64 │ Float64   │ Float64  │
# ├─────┼──────────┼─────────┼───────────┼──────────┤
# │ 1   │ 10000    │ 0.5     │ 0.48478   │ 0.475821 │
# │ 2   │ 30000    │ 0.5     │ 0.519015  │ 0.64676  │
# │ 3   │ 50000    │ 0.5     │ 0.0       │ 0.452328 │
# │ 4   │ 70000    │ 0.5     │ 0.411707  │ 0.471702 │
# │ 5   │ 90000    │ 0.5     │ 0.535835  │ 0.6065   │
# │ 6   │ 4000     │ 0.5     │ 0.0       │ 0.0      │
# │ 7   │ 8000     │ 0.5     │ 0.0       │ 0.0      │
# │ 8   │ 12000    │ 0.5     │ 0.0       │ 0.0      │
# │ 9   │ 16000    │ 0.5     │ 0.858884  │ 0.949049 │
# │ 10  │ 20000    │ 0.5     │ 0.0       │ 0.0      │
# │ 11  │ 24000    │ 0.5     │ 1.1747    │ 1.06489  │
# │ 12  │ 28000    │ 0.5     │ 0.0       │ 0.0      │
# │ 13  │ 32000    │ 0.5     │ 0.775325  │ 0.868514 │
# │ 14  │ 36000    │ 0.5     │ 0.477219  │ 0.508682 │
# │ 15  │ 40000    │ 0.5     │ 0.775804  │ 0.761237 │
# │ 16  │ 44000    │ 0.5     │ 0.0       │ 0.84979  │
# │ 17  │ 48000    │ 0.5     │ 0.951213  │ 0.96539  │
# │ 18  │ 52000    │ 0.5     │ 0.0       │ 0.0      │
# │ 19  │ 56000    │ 0.5     │ 0.0       │ 0.0      │
# │ 20  │ 60000    │ 0.5     │ 0.0       │ 0.0      │
# │ 21  │ 64000    │ 0.5     │ 0.800104  │ 0.764051 │
# │ 22  │ 68000    │ 0.5     │ 0.984724  │ 0.976564 │
# │ 23  │ 72000    │ 0.5     │ 1.01177   │ 1.07556  │
# │ 24  │ 76000    │ 0.5     │ 0.848372  │ 0.0      │
# │ 25  │ 80000    │ 0.5     │ 0.871373  │ 0.899422 │
# │ 26  │ 84000    │ 0.5     │ 0.0       │ 0.0      │
# │ 27  │ 88000    │ 0.5     │ 0.0       │ 0.778858 │
# │ 28  │ 92000    │ 0.5     │ 1.03112   │ 1.0116   │
# │ 29  │ 96000    │ 0.5     │ 0.629073  │ 0.659522 │
# │ 30  │ 100000   │ 0.5     │ 0.0       │ 0.0      │
#
#
# running 4 th model
# number of cases = 417.0
# compare_model = 30×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped  │
# │     │ Int64    │ Float64 │ Float64   │ Float64  │
# ├─────┼──────────┼─────────┼───────────┼──────────┤
# │ 1   │ 10000    │ 0.5     │ 0.0       │ 0.350636 │
# │ 2   │ 30000    │ 0.5     │ 0.535845  │ 0.496763 │
# │ 3   │ 50000    │ 0.5     │ 0.350873  │ 0.342126 │
# │ 4   │ 70000    │ 0.5     │ 0.481707  │ 0.487195 │
# │ 5   │ 90000    │ 0.5     │ 0.78852   │ 0.692244 │
# │ 6   │ 4000     │ 0.5     │ 0.0       │ 0.0      │
# │ 7   │ 8000     │ 0.5     │ 0.949995  │ 0.718977 │
# │ 8   │ 12000    │ 0.5     │ 0.0       │ 0.666262 │
# │ 9   │ 16000    │ 0.5     │ 0.559911  │ 0.607987 │
# │ 10  │ 20000    │ 0.5     │ 0.0       │ 0.0      │
# │ 11  │ 24000    │ 0.5     │ 1.09611   │ 0.91944  │
# │ 12  │ 28000    │ 0.5     │ 0.0       │ 0.0      │
# │ 13  │ 32000    │ 0.5     │ 0.0       │ 0.0      │
# │ 14  │ 36000    │ 0.5     │ 0.515899  │ 0.40217  │
# │ 15  │ 40000    │ 0.5     │ 0.0       │ 0.0      │
# │ 16  │ 44000    │ 0.5     │ 1.09256   │ 0.829061 │
# │ 17  │ 48000    │ 0.5     │ 0.0       │ 0.691799 │
# │ 18  │ 52000    │ 0.5     │ 0.398096  │ 0.371948 │
# │ 19  │ 56000    │ 0.5     │ 0.0       │ 0.0      │
# │ 20  │ 60000    │ 0.5     │ 0.587201  │ 0.466722 │
# │ 21  │ 64000    │ 0.5     │ 0.0       │ 0.711603 │
# │ 22  │ 68000    │ 0.5     │ 0.508674  │ 0.43497  │
# │ 23  │ 72000    │ 0.5     │ 1.07084   │ 0.990952 │
# │ 24  │ 76000    │ 0.5     │ 1.02963   │ 0.815173 │
# │ 25  │ 80000    │ 0.5     │ 0.950334  │ 0.813255 │
# │ 26  │ 84000    │ 0.5     │ 0.657533  │ 0.581247 │
# │ 27  │ 88000    │ 0.5     │ 0.864871  │ 0.801823 │
# │ 28  │ 92000    │ 0.5     │ 0.0       │ 0.0      │
# │ 29  │ 96000    │ 0.5     │ 0.0       │ 0.0      │
# │ 30  │ 100000   │ 0.5     │ 0.575153  │ 0.514849 │
#
#
# running 5 th model
# number of cases = 417.0
# compare_model = 30×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped  │
# │     │ Int64    │ Float64 │ Float64   │ Float64  │
# ├─────┼──────────┼─────────┼───────────┼──────────┤
# │ 1   │ 10000    │ 0.5     │ 0.0       │ 0.0      │
# │ 2   │ 30000    │ 0.5     │ 0.379607  │ 0.454663 │
# │ 3   │ 50000    │ 0.5     │ 0.597828  │ 0.717451 │
# │ 4   │ 70000    │ 0.5     │ 0.0       │ 0.0      │
# │ 5   │ 90000    │ 0.5     │ 0.577848  │ 0.525877 │
# │ 6   │ 4000     │ 0.5     │ 0.0       │ 0.660556 │
# │ 7   │ 8000     │ 0.5     │ 1.42182   │ 1.0619   │
# │ 8   │ 12000    │ 0.5     │ 0.530686  │ 0.546218 │
# │ 9   │ 16000    │ 0.5     │ 0.493749  │ 0.543583 │
# │ 10  │ 20000    │ 0.5     │ 0.0       │ 0.0      │
# │ 11  │ 24000    │ 0.5     │ 1.41545   │ 0.843813 │
# │ 12  │ 28000    │ 0.5     │ 1.72011   │ 0.98458  │
# │ 13  │ 32000    │ 0.5     │ 0.0       │ 0.0      │
# │ 14  │ 36000    │ 0.5     │ 0.0       │ 0.0      │
# │ 15  │ 40000    │ 0.5     │ 1.59063   │ 1.11953  │
# │ 16  │ 44000    │ 0.5     │ 0.0       │ 0.0      │
# │ 17  │ 48000    │ 0.5     │ 0.0       │ 0.751884 │
# │ 18  │ 52000    │ 0.5     │ 0.0       │ 0.0      │
# │ 19  │ 56000    │ 0.5     │ 0.0       │ 0.528377 │
# │ 20  │ 60000    │ 0.5     │ 0.309208  │ 0.39654  │
# │ 21  │ 64000    │ 0.5     │ 0.0       │ 0.0      │
# │ 22  │ 68000    │ 0.5     │ 0.0       │ 0.348108 │
# │ 23  │ 72000    │ 0.5     │ 1.33415   │ 0.749819 │
# │ 24  │ 76000    │ 0.5     │ 0.0       │ 0.763205 │
# │ 25  │ 80000    │ 0.5     │ 0.0       │ 0.788828 │
# │ 26  │ 84000    │ 0.5     │ 0.0       │ 0.0      │
# │ 27  │ 88000    │ 0.5     │ 0.0       │ 0.0      │
# │ 28  │ 92000    │ 0.5     │ 0.0       │ 0.787542 │
# │ 29  │ 96000    │ 0.5     │ 0.0       │ 0.683664 │
# │ 30  │ 100000   │ 0.5     │ 0.0       │ 0.0      │
#
#
# running 6 th model
# number of cases = 424.0
# compare_model = 30×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped  │
# │     │ Int64    │ Float64 │ Float64   │ Float64  │
# ├─────┼──────────┼─────────┼───────────┼──────────┤
# │ 1   │ 10000    │ 0.5     │ 0.702002  │ 0.568959 │
# │ 2   │ 30000    │ 0.5     │ 0.0       │ 0.468806 │
# │ 3   │ 50000    │ 0.5     │ 0.834535  │ 0.839443 │
# │ 4   │ 70000    │ 0.5     │ 0.0       │ 0.0      │
# │ 5   │ 90000    │ 0.5     │ 0.58071   │ 0.603697 │
# │ 6   │ 4000     │ 0.5     │ 0.0       │ 0.0      │
# │ 7   │ 8000     │ 0.5     │ 0.0       │ 0.0      │
# │ 8   │ 12000    │ 0.5     │ 0.0       │ 0.0      │
# │ 9   │ 16000    │ 0.5     │ 0.0       │ 0.0      │
# │ 10  │ 20000    │ 0.5     │ 1.58656   │ 1.13133  │
# │ 11  │ 24000    │ 0.5     │ 0.0       │ 0.0      │
# │ 12  │ 28000    │ 0.5     │ 0.0       │ 0.0      │
# │ 13  │ 32000    │ 0.5     │ 0.560703  │ 0.622345 │
# │ 14  │ 36000    │ 0.5     │ 0.482326  │ 0.461532 │
# │ 15  │ 40000    │ 0.5     │ 0.0       │ 0.0      │
# │ 16  │ 44000    │ 0.5     │ 0.0       │ 0.0      │
# │ 17  │ 48000    │ 0.5     │ 0.0       │ 0.0      │
# │ 18  │ 52000    │ 0.5     │ 0.0       │ 0.0      │
# │ 19  │ 56000    │ 0.5     │ 0.0       │ 0.0      │
# │ 20  │ 60000    │ 0.5     │ 0.521951  │ 0.418584 │
# │ 21  │ 64000    │ 0.5     │ 0.512321  │ 0.645917 │
# │ 22  │ 68000    │ 0.5     │ 0.0       │ 1.34874  │
# │ 23  │ 72000    │ 0.5     │ 0.593788  │ 0.594766 │
# │ 24  │ 76000    │ 0.5     │ 0.697536  │ 0.742931 │
# │ 25  │ 80000    │ 0.5     │ 0.0       │ 0.0      │
# │ 26  │ 84000    │ 0.5     │ 0.56054   │ 0.493033 │
# │ 27  │ 88000    │ 0.5     │ 1.56889   │ 1.50037  │
# │ 28  │ 92000    │ 0.5     │ 0.0       │ 0.0      │
# │ 29  │ 96000    │ 0.5     │ 0.0       │ 0.0      │
# │ 30  │ 100000   │ 0.5     │ 1.94385   │ 1.40324  │
#
#
# running 7 th model
# number of cases = 418.0
# compare_model = 30×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped  │
# │     │ Int64    │ Float64 │ Float64   │ Float64  │
# ├─────┼──────────┼─────────┼───────────┼──────────┤
# │ 1   │ 10000    │ 0.5     │ 0.568929  │ 0.54007  │
# │ 2   │ 30000    │ 0.5     │ 0.674312  │ 0.653242 │
# │ 3   │ 50000    │ 0.5     │ 0.609831  │ 0.613156 │
# │ 4   │ 70000    │ 0.5     │ 0.0       │ 0.36946  │
# │ 5   │ 90000    │ 0.5     │ 0.554006  │ 0.48397  │
# │ 6   │ 4000     │ 0.5     │ 0.0       │ 0.0      │
# │ 7   │ 8000     │ 0.5     │ 0.792966  │ 0.829694 │
# │ 8   │ 12000    │ 0.5     │ 0.0       │ 0.0      │
# │ 9   │ 16000    │ 0.5     │ 0.858336  │ 0.875382 │
# │ 10  │ 20000    │ 0.5     │ 0.500696  │ 0.502536 │
# │ 11  │ 24000    │ 0.5     │ 0.0       │ 0.0      │
# │ 12  │ 28000    │ 0.5     │ 0.634564  │ 0.622238 │
# │ 13  │ 32000    │ 0.5     │ 0.692756  │ 0.0      │
# │ 14  │ 36000    │ 0.5     │ 0.703657  │ 0.853638 │
# │ 15  │ 40000    │ 0.5     │ 0.703795  │ 0.728343 │
# │ 16  │ 44000    │ 0.5     │ 0.0       │ 0.0      │
# │ 17  │ 48000    │ 0.5     │ 0.0       │ 0.0      │
# │ 18  │ 52000    │ 0.5     │ 0.76004   │ 0.913883 │
# │ 19  │ 56000    │ 0.5     │ 0.916012  │ 0.802808 │
# │ 20  │ 60000    │ 0.5     │ 0.761427  │ 0.748705 │
# │ 21  │ 64000    │ 0.5     │ 0.0       │ 0.0      │
# │ 22  │ 68000    │ 0.5     │ 0.761007  │ 0.646008 │
# │ 23  │ 72000    │ 0.5     │ 0.0       │ 0.0      │
# │ 24  │ 76000    │ 0.5     │ 0.56621   │ 0.605413 │
# │ 25  │ 80000    │ 0.5     │ 0.740678  │ 0.675029 │
# │ 26  │ 84000    │ 0.5     │ 0.0       │ 0.669723 │
# │ 27  │ 88000    │ 0.5     │ 0.890153  │ 0.86287  │
# │ 28  │ 92000    │ 0.5     │ 0.578378  │ 0.638316 │
# │ 29  │ 96000    │ 0.5     │ 0.539709  │ 0.515088 │
# │ 30  │ 100000   │ 0.5     │ 0.774436  │ 0.752305 │
#
#
# running 8 th model
# number of cases = 430.0
# compare_model = 30×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped  │
# │     │ Int64    │ Float64 │ Float64   │ Float64  │
# ├─────┼──────────┼─────────┼───────────┼──────────┤
# │ 1   │ 10000    │ 0.5     │ 0.395098  │ 0.466457 │
# │ 2   │ 30000    │ 0.5     │ 0.0       │ 0.0      │
# │ 3   │ 50000    │ 0.5     │ 0.534422  │ 0.536403 │
# │ 4   │ 70000    │ 0.5     │ 0.410933  │ 0.476372 │
# │ 5   │ 90000    │ 0.5     │ 0.4738    │ 0.556136 │
# │ 6   │ 4000     │ 0.5     │ 0.0       │ 0.0      │
# │ 7   │ 8000     │ 0.5     │ 0.0       │ 0.0      │
# │ 8   │ 12000    │ 0.5     │ 0.903248  │ 0.742147 │
# │ 9   │ 16000    │ 0.5     │ 0.0       │ 0.875109 │
# │ 10  │ 20000    │ 0.5     │ 1.21559   │ 0.995298 │
# │ 11  │ 24000    │ 0.5     │ 0.52985   │ 0.629034 │
# │ 12  │ 28000    │ 0.5     │ 1.28468   │ 1.04806  │
# │ 13  │ 32000    │ 0.5     │ 0.461456  │ 0.581821 │
# │ 14  │ 36000    │ 0.5     │ 0.0       │ 0.938826 │
# │ 15  │ 40000    │ 0.5     │ 0.0       │ 0.0      │
# │ 16  │ 44000    │ 0.5     │ 0.0       │ 0.0      │
# │ 17  │ 48000    │ 0.5     │ 0.0       │ 0.372333 │
# │ 18  │ 52000    │ 0.5     │ 0.0       │ 0.785803 │
# │ 19  │ 56000    │ 0.5     │ 0.0       │ 0.0      │
# │ 20  │ 60000    │ 0.5     │ 0.0       │ 0.0      │
# │ 21  │ 64000    │ 0.5     │ 0.0       │ 0.0      │
# │ 22  │ 68000    │ 0.5     │ 0.905128  │ 0.895814 │
# │ 23  │ 72000    │ 0.5     │ 0.0       │ 0.0      │
# │ 24  │ 76000    │ 0.5     │ 0.0       │ 0.0      │
# │ 25  │ 80000    │ 0.5     │ 0.0       │ 0.0      │
# │ 26  │ 84000    │ 0.5     │ 0.477227  │ 0.0      │
# │ 27  │ 88000    │ 0.5     │ 0.0       │ 0.0      │
# │ 28  │ 92000    │ 0.5     │ 1.19834   │ 0.929508 │
# │ 29  │ 96000    │ 0.5     │ 0.0       │ 0.0      │
# │ 30  │ 100000   │ 0.5     │ 0.0       │ 0.0      │
#
#
# running 9 th model
# number of cases = 430.0
# compare_model = 30×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped  │
# │     │ Int64    │ Float64 │ Float64   │ Float64  │
# ├─────┼──────────┼─────────┼───────────┼──────────┤
# │ 1   │ 10000    │ 0.5     │ 0.500299  │ 0.489351 │
# │ 2   │ 30000    │ 0.5     │ 0.39682   │ 0.460442 │
# │ 3   │ 50000    │ 0.5     │ 0.600036  │ 0.549488 │
# │ 4   │ 70000    │ 0.5     │ 0.433448  │ 0.468217 │
# │ 5   │ 90000    │ 0.5     │ 0.435127  │ 0.48306  │
# │ 6   │ 4000     │ 0.5     │ 0.0       │ 0.652687 │
# │ 7   │ 8000     │ 0.5     │ 0.82482   │ 0.785632 │
# │ 8   │ 12000    │ 0.5     │ 0.513729  │ 0.0      │
# │ 9   │ 16000    │ 0.5     │ 0.725817  │ 0.615827 │
# │ 10  │ 20000    │ 0.5     │ 0.0       │ 0.0      │
# │ 11  │ 24000    │ 0.5     │ 0.0       │ 0.0      │
# │ 12  │ 28000    │ 0.5     │ 0.43958   │ 0.0      │
# │ 13  │ 32000    │ 0.5     │ 0.0       │ 0.0      │
# │ 14  │ 36000    │ 0.5     │ 0.0       │ 0.0      │
# │ 15  │ 40000    │ 0.5     │ 0.0       │ 0.0      │
# │ 16  │ 44000    │ 0.5     │ 0.754567  │ 0.774505 │
# │ 17  │ 48000    │ 0.5     │ 0.0       │ 0.0      │
# │ 18  │ 52000    │ 0.5     │ 0.740235  │ 0.709576 │
# │ 19  │ 56000    │ 0.5     │ 0.881515  │ 0.881846 │
# │ 20  │ 60000    │ 0.5     │ 0.819824  │ 0.904086 │
# │ 21  │ 64000    │ 0.5     │ 0.0       │ 0.0      │
# │ 22  │ 68000    │ 0.5     │ 0.0       │ 0.0      │
# │ 23  │ 72000    │ 0.5     │ 0.713475  │ 0.834688 │
# │ 24  │ 76000    │ 0.5     │ 0.0       │ 0.0      │
# │ 25  │ 80000    │ 0.5     │ 0.0       │ 0.636405 │
# │ 26  │ 84000    │ 0.5     │ 0.754605  │ 0.837955 │
# │ 27  │ 88000    │ 0.5     │ 0.687407  │ 0.0      │
# │ 28  │ 92000    │ 0.5     │ 0.568899  │ 0.702899 │
# │ 29  │ 96000    │ 0.5     │ 0.497674  │ 0.437308 │
# │ 30  │ 100000   │ 0.5     │ 0.0       │ 0.0      │
#
#
# running 10 th model
# number of cases = 424.0
# compare_model = 30×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped  │
# │     │ Int64    │ Float64 │ Float64   │ Float64  │
# ├─────┼──────────┼─────────┼───────────┼──────────┤
# │ 1   │ 10000    │ 0.5     │ 0.464231  │ 0.508929 │
# │ 2   │ 30000    │ 0.5     │ 0.459453  │ 0.44119  │
# │ 3   │ 50000    │ 0.5     │ 0.772677  │ 0.791007 │
# │ 4   │ 70000    │ 0.5     │ 0.0       │ 0.0      │
# │ 5   │ 90000    │ 0.5     │ 0.516251  │ 0.475126 │
# │ 6   │ 4000     │ 0.5     │ 0.688985  │ 0.696761 │
# │ 7   │ 8000     │ 0.5     │ 0.64206   │ 0.605832 │
# │ 8   │ 12000    │ 0.5     │ 0.835587  │ 0.870662 │
# │ 9   │ 16000    │ 0.5     │ 0.0       │ 0.0      │
# │ 10  │ 20000    │ 0.5     │ 0.871023  │ 0.829968 │
# │ 11  │ 24000    │ 0.5     │ 0.0       │ 0.0      │
# │ 12  │ 28000    │ 0.5     │ 0.599614  │ 0.652338 │
# │ 13  │ 32000    │ 0.5     │ 0.694949  │ 0.697142 │
# │ 14  │ 36000    │ 0.5     │ 0.513736  │ 0.0      │
# │ 15  │ 40000    │ 0.5     │ 0.0       │ 0.589008 │
# │ 16  │ 44000    │ 0.5     │ 0.827984  │ 0.775897 │
# │ 17  │ 48000    │ 0.5     │ 0.0       │ 0.0      │
# │ 18  │ 52000    │ 0.5     │ 0.52657   │ 0.532191 │
# │ 19  │ 56000    │ 0.5     │ 0.0       │ 0.0      │
# │ 20  │ 60000    │ 0.5     │ 0.630059  │ 0.588424 │
# │ 21  │ 64000    │ 0.5     │ 0.510217  │ 0.502412 │
# │ 22  │ 68000    │ 0.5     │ 0.378479  │ 0.361533 │
# │ 23  │ 72000    │ 0.5     │ 0.70062   │ 0.825311 │
# │ 24  │ 76000    │ 0.5     │ 0.0       │ 0.0      │
# │ 25  │ 80000    │ 0.5     │ 0.582144  │ 0.505827 │
# │ 26  │ 84000    │ 0.5     │ 0.717904  │ 0.772843 │
# │ 27  │ 88000    │ 0.5     │ 0.674503  │ 0.720396 │
# │ 28  │ 92000    │ 0.5     │ 0.0       │ 0.0      │
# │ 29  │ 96000    │ 0.5     │ 0.575774  │ 0.662687 │
# │ 30  │ 100000   │ 0.5     │ 0.0       │ 0.0      │
#
#
# Group IHT found: 43 / 50 common variants and 144 / 250rare variants
# Ungrouped IHT found: 38 / 50 common variants and 128 / 250rare variants

# %% [markdown]
# # Note: The final table in the paper is ran in terminal and not reproduced here, although the code is the same.
