# %% [markdown]
# # Doubly sparse projection for rare variant discovery

# %%
using Revise
using MendelIHT
using SnpArrays
using DataFrames
using Distributions
using BenchmarkTools
using Random
using LinearAlgebra
using GLM

# %%
#simulate 5 genes, each with 5 rare variants and 1 non-rare variant
function compare(d::UnionAll, l::Link)
    
    # define problem size
    n = 1000
    p = 10000
    block_size = 20
    num_blocks = Int(p / block_size)

    # assign group membership
    membership = collect(1:num_blocks)
    g = zeros(Int64, p + 1)
    for i in 1:length(membership)
        for j in 1:block_size
            cur_row = block_size * (i - 1) + j
            g[block_size*(i - 1) + j] = membership[i]
        end
    end
    g[end] = membership[end]
    
    #simulate correlated snparray
    x = simulate_correlated_snparray(n, p, "tmp.bed")
    z = ones(n, 1) # the intercept
    x_float = convert(Matrix{Float64}, x, model=ADDITIVE_MODEL, center=true, scale=true)
    
    #simulate true model, where 5 groups each with 3 snps contribute
    true_b = zeros(p)
    true_groups = randperm(num_blocks)[1:5]
    within_group = [randperm(block_size)[1:3] randperm(block_size)[1:3] randperm(block_size)[1:3] randperm(block_size)[1:3] randperm(block_size)[1:3]]
    correct_position = zeros(Int64, 15)
    for i in 1:5
        cur_group = block_size * (true_groups[i] - 1)
        cur_group_snps = cur_group .+ within_group[:, i]
        correct_position[3*(i-1)+1:3i] .= cur_group_snps
    end
    for i in 1:15
        true_b[correct_position[i]] = rand(-1:2:1) * 0.2
    end
    sort!(correct_position)
        
    # simulate phenotype
    if d == Normal || d == Bernoulli || d == Poisson
        prob = linkinv.(l, x_float * true_b)
        clamp!(prob, -20, 20)
        y = [rand(d(i)) for i in prob]
    elseif d == NegativeBinomial
        nn = 10
        μ = linkinv.(l, x_float * true_b)
        clamp!(μ, -20, 20)
        prob = 1 ./ (1 .+ μ ./ nn)
        y = [rand(d(nn, i)) for i in prob] #number of failtures before nn success occurs
    end
    y = Float64.(y)
    
    #run IHT without groups
    k = 15
    ungrouped = L0_reg(x_float, z, y, 1, k, d(), l, debias=false)
        
    #run IHT with groups
    J = 5
    k = 3
    grouped = L0_reg(x_float, z, y, J, k, d(), l, debias=false, group=g)

    #check result
    compare_model = DataFrame(
        position   = correct_position,
        correct    = true_b[correct_position],
        ungrouped  = ungrouped.beta[correct_position], 
        grouped    = grouped.beta[correct_position])
    @show compare_model
    println("Grouped ran: ", grouped.iter, " iters and Ungrouped ran: ", ungrouped.iter, " iters")
    println("\n")

    #clean up
    rm("tmp.bed", force=true)
    
    group = count(!iszero, grouped.beta[correct_position])
    ungroup = count(!iszero, ungrouped.beta[correct_position])
    return group, ungroup
end
# Out:
# compare (generic function with 1 method)

# %% [markdown]
# # Normal

# %%
Random.seed!(2019)
d = Normal
l = canonicallink(d())

num_runs = 100
group_found = zeros(num_runs)
ungroup_found = zeros(num_runs)

for i in 1:num_runs
    println("running $i th model")
    gf, uf = compare(d, l)
    group_found[i] = gf
    ungroup_found[i] = uf
end

println("Group IHT found: ", sum(group_found), "/", 15num_runs, " variants", ", percentage = ", sum(group_found)/15num_runs)
println("Ungrouped IHT found: ", sum(ungroup_found), "/", 15num_runs, " variants" , ", percentage = ", sum(ungroup_found)/15num_runs)
println("Grouped common variant standard errors = ", std(group_found), ", percentage = ", std(group_found)/15)
println("Ungrouped common variant standard errors = ", std(ungroup_found), ", percentage = ", std(ungroup_found)/15)
# Out:
# running 1 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 3464     │ -0.2    │ -0.148166 │ -0.159439 │
# │ 2   │ 3466     │ -0.2    │ -0.183184 │ -0.173504 │
# │ 3   │ 3468     │ 0.2     │ 0.196883  │ 0.189621  │
# │ 4   │ 4924     │ -0.2    │ -0.221287 │ -0.26612  │
# │ 5   │ 4930     │ 0.2     │ 0.210063  │ 0.211576  │
# │ 6   │ 4938     │ 0.2     │ 0.0       │ 0.168352  │
# │ 7   │ 5004     │ 0.2     │ 0.21265   │ 0.21483   │
# │ 8   │ 5016     │ -0.2    │ -0.177054 │ -0.179432 │
# │ 9   │ 5020     │ 0.2     │ 0.198026  │ 0.196929  │
# │ 10  │ 5081     │ -0.2    │ -0.177789 │ -0.177659 │
# │ 11  │ 5091     │ -0.2    │ 0.0       │ -0.102868 │
# │ 12  │ 5098     │ 0.2     │ 0.0       │ 0.0       │
# │ 13  │ 7003     │ -0.2    │ 0.0       │ -0.202866 │
# │ 14  │ 7007     │ -0.2    │ 0.0       │ -0.188353 │
# │ 15  │ 7018     │ -0.2    │ -0.228586 │ -0.235657 │
# Grouped ran: 15 iters and Ungrouped ran: 16 iters
#
#
# running 2 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped    │
# │     │ Int64    │ Float64 │ Float64   │ Float64    │
# ├─────┼──────────┼─────────┼───────────┼────────────┤
# │ 1   │ 148      │ 0.2     │ 0.227538  │ 0.176615   │
# │ 2   │ 150      │ 0.2     │ 0.136113  │ 0.115631   │
# │ 3   │ 153      │ -0.2    │ -0.219945 │ 0.0        │
# │ 4   │ 4292     │ 0.2     │ 0.0       │ 0.0        │
# │ 5   │ 4293     │ -0.2    │ 0.0       │ -0.107013  │
# │ 6   │ 4294     │ 0.2     │ 0.0       │ 0.0        │
# │ 7   │ 4989     │ 0.2     │ 0.213247  │ 0.244946   │
# │ 8   │ 4992     │ -0.2    │ 0.0       │ -0.0764452 │
# │ 9   │ 4993     │ 0.2     │ 0.0       │ 0.0        │
# │ 10  │ 8465     │ -0.2    │ 0.0       │ 0.0        │
# │ 11  │ 8475     │ 0.2     │ 0.138265  │ 0.147511   │
# │ 12  │ 8479     │ -0.2    │ -0.180361 │ -0.189634  │
# │ 13  │ 9442     │ -0.2    │ 0.0       │ 0.0        │
# │ 14  │ 9443     │ 0.2     │ 0.160584  │ 0.16472    │
# │ 15  │ 9457     │ -0.2    │ 0.0       │ 0.0        │
# Grouped ran: 27 iters and Ungrouped ran: 18 iters
#
#
# running 3 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 668      │ -0.2    │ -0.205834 │ -0.210343 │
# │ 2   │ 673      │ 0.2     │ 0.189662  │ 0.202644  │
# │ 3   │ 679      │ 0.2     │ 0.225393  │ 0.226384  │
# │ 4   │ 1270     │ -0.2    │ -0.235419 │ -0.239535 │
# │ 5   │ 1277     │ 0.2     │ 0.217535  │ 0.226994  │
# │ 6   │ 1278     │ 0.2     │ 0.179431  │ 0.16394   │
# │ 7   │ 4161     │ 0.2     │ 0.0       │ 0.0837716 │
# │ 8   │ 4168     │ 0.2     │ 0.0       │ 0.0       │
# │ 9   │ 4173     │ 0.2     │ 0.0       │ 0.0       │
# │ 10  │ 5411     │ 0.2     │ 0.169718  │ 0.187273  │
# │ 11  │ 5413     │ 0.2     │ 0.0       │ 0.149809  │
# │ 12  │ 5416     │ -0.2    │ 0.0       │ -0.157299 │
# │ 13  │ 5485     │ 0.2     │ 0.244407  │ 0.196479  │
# │ 14  │ 5496     │ -0.2    │ 0.0       │ -0.118118 │
# │ 15  │ 5499     │ 0.2     │ 0.212497  │ 0.260948  │
# Grouped ran: 25 iters and Ungrouped ran: 28 iters
#
#
# running 4 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 48       │ -0.2    │ -0.195218 │ -0.240019 │
# │ 2   │ 54       │ -0.2    │ -0.18854  │ 0.0       │
# │ 3   │ 56       │ -0.2    │ -0.232954 │ -0.179097 │
# │ 4   │ 166      │ -0.2    │ 0.0       │ -0.136861 │
# │ 5   │ 168      │ -0.2    │ -0.192776 │ -0.139111 │
# │ 6   │ 175      │ 0.2     │ 0.189627  │ 0.0       │
# │ 7   │ 782      │ -0.2    │ -0.186288 │ -0.17398  │
# │ 8   │ 790      │ -0.2    │ -0.253883 │ -0.259258 │
# │ 9   │ 796      │ -0.2    │ -0.194945 │ -0.212008 │
# │ 10  │ 4327     │ -0.2    │ -0.182428 │ -0.19373  │
# │ 11  │ 4332     │ -0.2    │ -0.180084 │ -0.174251 │
# │ 12  │ 4338     │ 0.2     │ 0.225271  │ 0.209317  │
# │ 13  │ 7362     │ -0.2    │ 0.0       │ 0.0       │
# │ 14  │ 7363     │ 0.2     │ 0.0       │ 0.0       │
# │ 15  │ 7377     │ 0.2     │ 0.162529  │ 0.158069  │
# Grouped ran: 20 iters and Ungrouped ran: 18 iters
#
#
# running 5 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 2542     │ 0.2     │ 0.194309  │ 0.235496  │
# │ 2   │ 2547     │ -0.2    │ 0.0       │ -0.259555 │
# │ 3   │ 2548     │ 0.2     │ 0.0       │ 0.1956    │
# │ 4   │ 2844     │ -0.2    │ -0.174945 │ -0.191968 │
# │ 5   │ 2845     │ 0.2     │ 0.228074  │ 0.24533   │
# │ 6   │ 2855     │ 0.2     │ 0.145216  │ 0.143306  │
# │ 7   │ 3885     │ -0.2    │ -0.268677 │ -0.228728 │
# │ 8   │ 3895     │ -0.2    │ 0.0       │ -0.125639 │
# │ 9   │ 3897     │ -0.2    │ -0.2775   │ -0.207069 │
# │ 10  │ 3983     │ -0.2    │ 0.0       │ -0.219134 │
# │ 11  │ 3990     │ 0.2     │ 0.249423  │ 0.224157  │
# │ 12  │ 3992     │ 0.2     │ 0.0       │ 0.229528  │
# │ 13  │ 5183     │ 0.2     │ 0.106053  │ 0.1142    │
# │ 14  │ 5186     │ 0.2     │ 0.327901  │ 0.295739  │
# │ 15  │ 5190     │ 0.2     │ 0.201123  │ 0.20116   │
# Grouped ran: 39 iters and Ungrouped ran: 45 iters
#
#
# running 6 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 4631     │ 0.2     │ 0.214358  │ 0.220126  │
# │ 2   │ 4636     │ -0.2    │ -0.210856 │ -0.178829 │
# │ 3   │ 4638     │ -0.2    │ -0.198032 │ 0.0       │
# │ 4   │ 6730     │ -0.2    │ -0.159026 │ -0.161939 │
# │ 5   │ 6739     │ -0.2    │ -0.154763 │ -0.166611 │
# │ 6   │ 6740     │ -0.2    │ -0.215216 │ -0.222636 │
# │ 7   │ 7889     │ 0.2     │ 0.0       │ 0.173139  │
# │ 8   │ 7893     │ -0.2    │ -0.130661 │ -0.190164 │
# │ 9   │ 7898     │ 0.2     │ 0.0       │ 0.176424  │
# │ 10  │ 8409     │ 0.2     │ 0.178945  │ 0.174807  │
# │ 11  │ 8411     │ 0.2     │ 0.126124  │ 0.140324  │
# │ 12  │ 8413     │ 0.2     │ 0.219363  │ 0.231228  │
# │ 13  │ 9524     │ -0.2    │ -0.180435 │ -0.19575  │
# │ 14  │ 9529     │ 0.2     │ 0.0       │ 0.208668  │
# │ 15  │ 9530     │ -0.2    │ 0.0       │ -0.236518 │
# Grouped ran: 27 iters and Ungrouped ran: 21 iters
#
#
# running 7 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 2241     │ -0.2    │ -0.204956 │ -0.205328 │
# │ 2   │ 2246     │ -0.2    │ -0.176996 │ -0.177061 │
# │ 3   │ 2252     │ -0.2    │ -0.22579  │ -0.223204 │
# │ 4   │ 3345     │ -0.2    │ -0.207769 │ -0.212311 │
# │ 5   │ 3346     │ -0.2    │ -0.252863 │ -0.243966 │
# │ 6   │ 3357     │ -0.2    │ -0.176362 │ -0.16818  │
# │ 7   │ 5381     │ -0.2    │ 0.0       │ -0.153362 │
# │ 8   │ 5397     │ 0.2     │ 0.16382   │ 0.236524  │
# │ 9   │ 5398     │ 0.2     │ 0.0       │ 0.145362  │
# │ 10  │ 8086     │ 0.2     │ 0.180276  │ 0.195842  │
# │ 11  │ 8088     │ -0.2    │ -0.236191 │ -0.229389 │
# │ 12  │ 8100     │ -0.2    │ -0.204894 │ -0.19487  │
# │ 13  │ 9005     │ 0.2     │ 0.120182  │ 0.106976  │
# │ 14  │ 9006     │ 0.2     │ 0.227769  │ 0.207546  │
# │ 15  │ 9011     │ -0.2    │ -0.205104 │ 0.0       │
# Grouped ran: 20 iters and Ungrouped ran: 33 iters
#
#
# running 8 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 2883     │ 0.2     │ 0.135079  │ 0.137071  │
# │ 2   │ 2892     │ -0.2    │ -0.216623 │ -0.221249 │
# │ 3   │ 2898     │ -0.2    │ -0.155812 │ -0.152899 │
# │ 4   │ 3751     │ 0.2     │ 0.0       │ 0.0       │
# │ 5   │ 3757     │ 0.2     │ 0.255453  │ 0.240083  │
# │ 6   │ 3758     │ 0.2     │ 0.0       │ 0.144134  │
# │ 7   │ 3941     │ 0.2     │ 0.138432  │ 0.125553  │
# │ 8   │ 3953     │ 0.2     │ 0.186375  │ 0.181034  │
# │ 9   │ 3960     │ -0.2    │ -0.207036 │ -0.214901 │
# │ 10  │ 5305     │ -0.2    │ -0.253009 │ -0.246829 │
# │ 11  │ 5308     │ -0.2    │ -0.119733 │ -0.124258 │
# │ 12  │ 5317     │ 0.2     │ 0.182217  │ 0.182817  │
# │ 13  │ 6609     │ -0.2    │ -0.211018 │ -0.21095  │
# │ 14  │ 6615     │ -0.2    │ -0.137152 │ -0.150682 │
# │ 15  │ 6619     │ 0.2     │ 0.156139  │ 0.144552  │
# Grouped ran: 15 iters and Ungrouped ran: 20 iters
#
#
# running 9 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 882      │ -0.2    │ -0.193537 │ -0.195853 │
# │ 2   │ 894      │ 0.2     │ 0.21004   │ 0.215283  │
# │ 3   │ 896      │ 0.2     │ 0.205968  │ 0.204073  │
# │ 4   │ 1166     │ 0.2     │ 0.0       │ 0.228781  │
# │ 5   │ 1169     │ -0.2    │ -0.220795 │ -0.211682 │
# │ 6   │ 1174     │ -0.2    │ 0.0       │ -0.175683 │
# │ 7   │ 3663     │ 0.2     │ 0.231108  │ 0.151272  │
# │ 8   │ 3678     │ 0.2     │ 0.0       │ 0.0887421 │
# │ 9   │ 3679     │ -0.2    │ 0.0       │ 0.0       │
# │ 10  │ 5984     │ -0.2    │ 0.0       │ 0.0       │
# │ 11  │ 5988     │ 0.2     │ 0.187096  │ 0.147064  │
# │ 12  │ 5990     │ -0.2    │ -0.186556 │ 0.0       │
# │ 13  │ 9108     │ -0.2    │ -0.156517 │ -0.165357 │
# │ 14  │ 9113     │ 0.2     │ 0.211531  │ 0.202649  │
# │ 15  │ 9120     │ 0.2     │ 0.226408  │ 0.212584  │
# Grouped ran: 24 iters and Ungrouped ran: 29 iters
#
#
# running 10 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 3501     │ 0.2     │ 0.252344  │ 0.238592  │
# │ 2   │ 3514     │ -0.2    │ -0.190493 │ -0.191578 │
# │ 3   │ 3520     │ 0.2     │ 0.178108  │ 0.189619  │
# │ 4   │ 3747     │ -0.2    │ -0.276754 │ -0.297901 │
# │ 5   │ 3750     │ -0.2    │ 0.0       │ 0.0       │
# │ 6   │ 3756     │ 0.2     │ 0.166794  │ 0.153143  │
# │ 7   │ 5242     │ -0.2    │ 0.0       │ 0.0       │
# │ 8   │ 5247     │ 0.2     │ 0.221536  │ 0.225329  │
# │ 9   │ 5250     │ 0.2     │ 0.0       │ 0.13988   │
# │ 10  │ 7262     │ 0.2     │ 0.201084  │ 0.127006  │
# │ 11  │ 7277     │ -0.2    │ -0.221977 │ 0.0       │
# │ 12  │ 7278     │ 0.2     │ 0.229261  │ 0.171893  │
# │ 13  │ 7522     │ -0.2    │ -0.235597 │ -0.171195 │
# │ 14  │ 7523     │ -0.2    │ -0.202248 │ -0.14908  │
# │ 15  │ 7532     │ 0.2     │ 0.252107  │ 0.0       │
# Grouped ran: 20 iters and Ungrouped ran: 18 iters
#
#
# running 11 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 984      │ -0.2    │ 0.0       │ 0.0       │
# │ 2   │ 985      │ 0.2     │ 0.0       │ 0.0       │
# │ 3   │ 997      │ 0.2     │ 0.0       │ 0.0940634 │
# │ 4   │ 1043     │ 0.2     │ 0.225187  │ 0.238169  │
# │ 5   │ 1050     │ 0.2     │ 0.232627  │ 0.25698   │
# │ 6   │ 1059     │ 0.2     │ 0.171312  │ 0.189644  │
# │ 7   │ 2125     │ 0.2     │ 0.233561  │ 0.241205  │
# │ 8   │ 2130     │ 0.2     │ 0.170487  │ 0.19337   │
# │ 9   │ 2135     │ -0.2    │ -0.191301 │ -0.192981 │
# │ 10  │ 6043     │ -0.2    │ 0.0       │ 0.0       │
# │ 11  │ 6051     │ 0.2     │ 0.0       │ 0.146093  │
# │ 12  │ 6055     │ 0.2     │ 0.0       │ 0.129505  │
# │ 13  │ 9343     │ -0.2    │ 0.0       │ -0.107236 │
# │ 14  │ 9355     │ -0.2    │ -0.253126 │ -0.255534 │
# │ 15  │ 9358     │ -0.2    │ -0.308715 │ -0.246656 │
# Grouped ran: 19 iters and Ungrouped ran: 15 iters
#
#
# running 12 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 1982     │ -0.2    │ -0.137077 │ -0.147639 │
# │ 2   │ 1992     │ 0.2     │ 0.140003  │ 0.148809  │
# │ 3   │ 2000     │ 0.2     │ 0.250573  │ 0.257741  │
# │ 4   │ 2601     │ -0.2    │ -0.188545 │ -0.165805 │
# │ 5   │ 2602     │ -0.2    │ -0.263125 │ -0.278    │
# │ 6   │ 2610     │ -0.2    │ -0.18935  │ -0.181388 │
# │ 7   │ 3464     │ -0.2    │ -0.12912  │ -0.21606  │
# │ 8   │ 3477     │ 0.2     │ 0.222067  │ 0.197892  │
# │ 9   │ 3478     │ 0.2     │ 0.0       │ 0.169831  │
# │ 10  │ 3882     │ 0.2     │ 0.0       │ 0.198124  │
# │ 11  │ 3891     │ -0.2    │ 0.0       │ -0.152321 │
# │ 12  │ 3897     │ -0.2    │ -0.225002 │ -0.247753 │
# │ 13  │ 4110     │ 0.2     │ 0.118217  │ 0.175457  │
# │ 14  │ 4115     │ 0.2     │ 0.270964  │ 0.250385  │
# │ 15  │ 4119     │ 0.2     │ 0.0       │ 0.152513  │
# Grouped ran: 18 iters and Ungrouped ran: 12 iters
#
#
# running 13 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 4662     │ 0.2     │ 0.182837  │ 0.206801  │
# │ 2   │ 4663     │ -0.2    │ 0.0       │ 0.0       │
# │ 3   │ 4669     │ 0.2     │ 0.265197  │ 0.244118  │
# │ 4   │ 5365     │ 0.2     │ 0.224035  │ 0.232009  │
# │ 5   │ 5369     │ 0.2     │ 0.186251  │ 0.189357  │
# │ 6   │ 5377     │ -0.2    │ -0.173058 │ -0.168562 │
# │ 7   │ 8086     │ 0.2     │ 0.192001  │ 0.197688  │
# │ 8   │ 8092     │ 0.2     │ 0.238017  │ 0.219859  │
# │ 9   │ 8097     │ 0.2     │ 0.214959  │ 0.0       │
# │ 10  │ 8162     │ -0.2    │ -0.258102 │ -0.262695 │
# │ 11  │ 8169     │ -0.2    │ -0.23502  │ -0.224258 │
# │ 12  │ 8178     │ -0.2    │ -0.147761 │ -0.146357 │
# │ 13  │ 9023     │ 0.2     │ 0.225681  │ 0.223084  │
# │ 14  │ 9024     │ -0.2    │ -0.25211  │ -0.254476 │
# │ 15  │ 9034     │ 0.2     │ 0.235605  │ 0.238327  │
# Grouped ran: 23 iters and Ungrouped ran: 19 iters
#
#
# running 14 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped    │
# │     │ Int64    │ Float64 │ Float64   │ Float64    │
# ├─────┼──────────┼─────────┼───────────┼────────────┤
# │ 1   │ 1850     │ -0.2    │ 0.0       │ 0.0        │
# │ 2   │ 1852     │ 0.2     │ 0.212713  │ 0.149844   │
# │ 3   │ 1855     │ 0.2     │ 0.153355  │ 0.116335   │
# │ 4   │ 4904     │ 0.2     │ 0.0       │ 0.152457   │
# │ 5   │ 4913     │ -0.2    │ 0.0       │ -0.147373  │
# │ 6   │ 4914     │ -0.2    │ -0.158658 │ -0.170377  │
# │ 7   │ 5348     │ -0.2    │ -0.192994 │ 0.0        │
# │ 8   │ 5354     │ 0.2     │ 0.174768  │ 0.16097    │
# │ 9   │ 5359     │ 0.2     │ 0.197642  │ 0.169434   │
# │ 10  │ 5547     │ -0.2    │ -0.272233 │ -0.216874  │
# │ 11  │ 5550     │ -0.2    │ 0.0       │ -0.0840468 │
# │ 12  │ 5560     │ 0.2     │ 0.0       │ 0.0        │
# │ 13  │ 9802     │ 0.2     │ 0.0       │ 0.0        │
# │ 14  │ 9810     │ 0.2     │ 0.152826  │ 0.127633   │
# │ 15  │ 9818     │ -0.2    │ -0.186087 │ -0.180232  │
# Grouped ran: 22 iters and Ungrouped ran: 18 iters
#
#
# running 15 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 4043     │ -0.2    │ 0.0       │ 0.0       │
# │ 2   │ 4056     │ 0.2     │ 0.0       │ 0.0       │
# │ 3   │ 4058     │ 0.2     │ 0.0       │ 0.0       │
# │ 4   │ 4531     │ -0.2    │ -0.205954 │ -0.204539 │
# │ 5   │ 4534     │ 0.2     │ 0.234005  │ 0.230041  │
# │ 6   │ 4536     │ 0.2     │ 0.118146  │ 0.141204  │
# │ 7   │ 5570     │ 0.2     │ 0.0       │ 0.173836  │
# │ 8   │ 5576     │ -0.2    │ -0.146147 │ -0.184964 │
# │ 9   │ 5580     │ -0.2    │ -0.165195 │ -0.189002 │
# │ 10  │ 6021     │ 0.2     │ 0.0       │ 0.251526  │
# │ 11  │ 6027     │ 0.2     │ 0.0       │ 0.17289   │
# │ 12  │ 6028     │ 0.2     │ 0.20818   │ 0.250991  │
# │ 13  │ 9541     │ -0.2    │ -0.186955 │ -0.197766 │
# │ 14  │ 9547     │ 0.2     │ 0.162624  │ 0.163512  │
# │ 15  │ 9553     │ 0.2     │ 0.208636  │ 0.217111  │
# Grouped ran: 28 iters and Ungrouped ran: 15 iters
#
#
# running 16 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 5745     │ -0.2    │ -0.170373 │ -0.207668 │
# │ 2   │ 5749     │ -0.2    │ -0.224892 │ -0.151348 │
# │ 3   │ 5755     │ -0.2    │ -0.220356 │ 0.0       │
# │ 4   │ 6446     │ -0.2    │ -0.261581 │ -0.252732 │
# │ 5   │ 6447     │ -0.2    │ -0.128117 │ -0.138058 │
# │ 6   │ 6457     │ -0.2    │ -0.187414 │ -0.182863 │
# │ 7   │ 8004     │ 0.2     │ 0.216416  │ 0.22524   │
# │ 8   │ 8011     │ -0.2    │ -0.220638 │ -0.231483 │
# │ 9   │ 8015     │ -0.2    │ -0.237501 │ -0.243326 │
# │ 10  │ 9541     │ 0.2     │ 0.0       │ 0.0       │
# │ 11  │ 9547     │ -0.2    │ -0.144395 │ -0.122879 │
# │ 12  │ 9555     │ 0.2     │ 0.0       │ 0.0       │
# │ 13  │ 9791     │ 0.2     │ 0.203019  │ 0.211296  │
# │ 14  │ 9797     │ -0.2    │ -0.209373 │ -0.121977 │
# │ 15  │ 9800     │ -0.2    │ -0.201174 │ 0.0       │
# Grouped ran: 22 iters and Ungrouped ran: 23 iters
#
#
# running 17 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 1629     │ 0.2     │ 0.185683  │ 0.201509  │
# │ 2   │ 1633     │ 0.2     │ 0.0       │ 0.160756  │
# │ 3   │ 1634     │ -0.2    │ 0.0       │ -0.134816 │
# │ 4   │ 2842     │ -0.2    │ -0.213672 │ -0.179965 │
# │ 5   │ 2844     │ -0.2    │ -0.170275 │ 0.0       │
# │ 6   │ 2854     │ 0.2     │ 0.0       │ 0.0       │
# │ 7   │ 5906     │ 0.2     │ 0.251946  │ 0.25669   │
# │ 8   │ 5913     │ 0.2     │ 0.0       │ 0.0       │
# │ 9   │ 5918     │ 0.2     │ 0.118681  │ 0.130754  │
# │ 10  │ 7137     │ 0.2     │ 0.306446  │ 0.22121   │
# │ 11  │ 7138     │ 0.2     │ 0.0       │ 0.154371  │
# │ 12  │ 7139     │ -0.2    │ -0.12327  │ -0.180514 │
# │ 13  │ 8089     │ -0.2    │ 0.0       │ -0.17245  │
# │ 14  │ 8091     │ 0.2     │ 0.153905  │ 0.212147  │
# │ 15  │ 8096     │ 0.2     │ 0.0       │ 0.0       │
# Grouped ran: 30 iters and Ungrouped ran: 17 iters
#
#
# running 18 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 3661     │ -0.2    │ -0.230058 │ -0.22894  │
# │ 2   │ 3664     │ -0.2    │ -0.22938  │ -0.218539 │
# │ 3   │ 3668     │ 0.2     │ 0.0       │ 0.102387  │
# │ 4   │ 3762     │ 0.2     │ 0.17464   │ 0.181064  │
# │ 5   │ 3769     │ 0.2     │ 0.258922  │ 0.245655  │
# │ 6   │ 3773     │ -0.2    │ -0.2433   │ -0.239343 │
# │ 7   │ 4487     │ 0.2     │ 0.195454  │ 0.193261  │
# │ 8   │ 4494     │ 0.2     │ 0.0       │ 0.0714651 │
# │ 9   │ 4496     │ -0.2    │ 0.0       │ 0.0       │
# │ 10  │ 4887     │ 0.2     │ 0.185806  │ 0.16906   │
# │ 11  │ 4891     │ -0.2    │ -0.242753 │ -0.242444 │
# │ 12  │ 4900     │ 0.2     │ 0.216515  │ 0.220961  │
# │ 13  │ 8513     │ -0.2    │ 0.0       │ 0.0       │
# │ 14  │ 8514     │ 0.2     │ 0.0       │ 0.0702699 │
# │ 15  │ 8515     │ 0.2     │ 0.258252  │ 0.2173    │
# Grouped ran: 20 iters and Ungrouped ran: 23 iters
#
#
# running 19 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 548      │ 0.2     │ 0.218896  │ 0.154186  │
# │ 2   │ 555      │ 0.2     │ 0.0       │ 0.0       │
# │ 3   │ 557      │ -0.2    │ -0.144126 │ -0.168797 │
# │ 4   │ 3143     │ -0.2    │ -0.226774 │ -0.234367 │
# │ 5   │ 3148     │ -0.2    │ -0.198086 │ -0.198005 │
# │ 6   │ 3153     │ -0.2    │ -0.290755 │ -0.297831 │
# │ 7   │ 3662     │ 0.2     │ 0.0       │ 0.0       │
# │ 8   │ 3664     │ 0.2     │ 0.0       │ 0.0       │
# │ 9   │ 3671     │ 0.2     │ 0.0       │ 0.0672974 │
# │ 10  │ 7602     │ 0.2     │ 0.184053  │ 0.188351  │
# │ 11  │ 7608     │ 0.2     │ 0.198314  │ 0.192981  │
# │ 12  │ 7613     │ -0.2    │ -0.234268 │ -0.233012 │
# │ 13  │ 9645     │ -0.2    │ -0.245943 │ -0.237909 │
# │ 14  │ 9652     │ -0.2    │ -0.12569  │ -0.129686 │
# │ 15  │ 9656     │ -0.2    │ -0.236469 │ -0.24222  │
# Grouped ran: 18 iters and Ungrouped ran: 20 iters
#
#
# running 20 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 1646     │ 0.2     │ 0.229006  │ 0.221623  │
# │ 2   │ 1649     │ 0.2     │ 0.19204   │ 0.221157  │
# │ 3   │ 1651     │ -0.2    │ -0.167401 │ -0.170013 │
# │ 4   │ 1943     │ 0.2     │ 0.253599  │ 0.0       │
# │ 5   │ 1948     │ -0.2    │ -0.220896 │ -0.155354 │
# │ 6   │ 1949     │ -0.2    │ -0.189943 │ -0.235365 │
# │ 7   │ 2668     │ 0.2     │ 0.173966  │ 0.0       │
# │ 8   │ 2674     │ 0.2     │ 0.194219  │ 0.220658  │
# │ 9   │ 2676     │ 0.2     │ 0.203956  │ 0.14102   │
# │ 10  │ 3281     │ -0.2    │ 0.0       │ 0.0       │
# │ 11  │ 3293     │ 0.2     │ 0.155555  │ 0.144252  │
# │ 12  │ 3296     │ 0.2     │ 0.207649  │ 0.201381  │
# │ 13  │ 5705     │ -0.2    │ -0.210353 │ 0.0       │
# │ 14  │ 5707     │ 0.2     │ 0.181106  │ 0.130551  │
# │ 15  │ 5709     │ -0.2    │ -0.196625 │ -0.225514 │
# Grouped ran: 34 iters and Ungrouped ran: 26 iters
#
#
# running 21 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 307      │ 0.2     │ 0.176431  │ 0.178699  │
# │ 2   │ 312      │ 0.2     │ 0.214636  │ 0.218495  │
# │ 3   │ 319      │ 0.2     │ 0.0       │ 0.0       │
# │ 4   │ 7622     │ -0.2    │ -0.204838 │ -0.208717 │
# │ 5   │ 7627     │ -0.2    │ -0.271779 │ -0.277503 │
# │ 6   │ 7639     │ 0.2     │ 0.29341   │ 0.300406  │
# │ 7   │ 8372     │ 0.2     │ 0.212056  │ 0.212949  │
# │ 8   │ 8374     │ -0.2    │ -0.1945   │ -0.202732 │
# │ 9   │ 8376     │ -0.2    │ -0.222458 │ -0.211061 │
# │ 10  │ 9184     │ -0.2    │ -0.18637  │ -0.191055 │
# │ 11  │ 9196     │ 0.2     │ 0.2058    │ 0.21443   │
# │ 12  │ 9199     │ -0.2    │ -0.172642 │ -0.16476  │
# │ 13  │ 9963     │ 0.2     │ 0.0       │ 0.0       │
# │ 14  │ 9968     │ -0.2    │ -0.254243 │ -0.217842 │
# │ 15  │ 9976     │ -0.2    │ 0.0       │ -0.11799  │
# Grouped ran: 21 iters and Ungrouped ran: 20 iters
#
#
# running 22 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 2084     │ -0.2    │ -0.212542 │ -0.157697 │
# │ 2   │ 2093     │ -0.2    │ -0.214285 │ 0.0       │
# │ 3   │ 2096     │ -0.2    │ -0.163474 │ -0.154963 │
# │ 4   │ 2604     │ 0.2     │ 0.215855  │ 0.191244  │
# │ 5   │ 2609     │ 0.2     │ 0.0       │ 0.138897  │
# │ 6   │ 2618     │ 0.2     │ 0.153483  │ 0.228244  │
# │ 7   │ 3743     │ -0.2    │ -0.215233 │ 0.0       │
# │ 8   │ 3749     │ -0.2    │ -0.210431 │ 0.0       │
# │ 9   │ 3754     │ -0.2    │ -0.239935 │ -0.1525   │
# │ 10  │ 4867     │ 0.2     │ 0.186123  │ 0.192677  │
# │ 11  │ 4873     │ -0.2    │ -0.151198 │ -0.144305 │
# │ 12  │ 4874     │ -0.2    │ -0.202159 │ -0.220998 │
# │ 13  │ 8388     │ -0.2    │ -0.218317 │ -0.200457 │
# │ 14  │ 8391     │ 0.2     │ 0.0       │ 0.0       │
# │ 15  │ 8400     │ 0.2     │ 0.0       │ 0.0874601 │
# Grouped ran: 20 iters and Ungrouped ran: 14 iters
#
#
# running 23 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 3245     │ 0.2     │ 0.0       │ 0.0       │
# │ 2   │ 3254     │ -0.2    │ 0.0       │ 0.0       │
# │ 3   │ 3259     │ -0.2    │ -0.179827 │ -0.142727 │
# │ 4   │ 3943     │ 0.2     │ 0.239834  │ 0.162279  │
# │ 5   │ 3956     │ -0.2    │ 0.0       │ 0.0       │
# │ 6   │ 3960     │ 0.2     │ 0.0       │ 0.129979  │
# │ 7   │ 4041     │ -0.2    │ 0.0       │ 0.0       │
# │ 8   │ 4042     │ 0.2     │ 0.0       │ 0.118012  │
# │ 9   │ 4052     │ 0.2     │ 0.227107  │ 0.235016  │
# │ 10  │ 4594     │ 0.2     │ 0.167664  │ 0.166236  │
# │ 11  │ 4597     │ 0.2     │ 0.0       │ 0.0       │
# │ 12  │ 4598     │ -0.2    │ 0.0       │ 0.0       │
# │ 13  │ 9901     │ 0.2     │ 0.149458  │ 0.153544  │
# │ 14  │ 9909     │ 0.2     │ 0.209212  │ 0.206147  │
# │ 15  │ 9919     │ -0.2    │ -0.183368 │ -0.185298 │
# Grouped ran: 16 iters and Ungrouped ran: 12 iters
#
#
# running 24 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped    │
# │     │ Int64    │ Float64 │ Float64   │ Float64    │
# ├─────┼──────────┼─────────┼───────────┼────────────┤
# │ 1   │ 4826     │ 0.2     │ 0.15724   │ 0.15245    │
# │ 2   │ 4831     │ 0.2     │ 0.181547  │ 0.183174   │
# │ 3   │ 4835     │ -0.2    │ -0.163973 │ -0.182133  │
# │ 4   │ 5411     │ -0.2    │ -0.200808 │ -0.197476  │
# │ 5   │ 5416     │ 0.2     │ 0.248576  │ 0.249222   │
# │ 6   │ 5418     │ 0.2     │ 0.172663  │ 0.175478   │
# │ 7   │ 6784     │ 0.2     │ 0.210921  │ 0.190289   │
# │ 8   │ 6790     │ -0.2    │ 0.0       │ -0.0952216 │
# │ 9   │ 6791     │ 0.2     │ 0.0       │ 0.0        │
# │ 10  │ 7982     │ -0.2    │ -0.232728 │ -0.223528  │
# │ 11  │ 7983     │ 0.2     │ 0.167126  │ 0.175869   │
# │ 12  │ 7993     │ 0.2     │ 0.179208  │ 0.185603   │
# │ 13  │ 9013     │ 0.2     │ 0.0       │ 0.0        │
# │ 14  │ 9015     │ -0.2    │ 0.0       │ 0.0        │
# │ 15  │ 9018     │ -0.2    │ 0.0       │ 0.0        │
# Grouped ran: 22 iters and Ungrouped ran: 21 iters
#
#
# running 25 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 1322     │ 0.2     │ 0.0       │ 0.121612  │
# │ 2   │ 1324     │ -0.2    │ -0.206676 │ -0.135703 │
# │ 3   │ 1325     │ 0.2     │ 0.142415  │ 0.0       │
# │ 4   │ 2041     │ 0.2     │ 0.195729  │ 0.19341   │
# │ 5   │ 2042     │ 0.2     │ 0.236704  │ 0.232633  │
# │ 6   │ 2050     │ 0.2     │ 0.176305  │ 0.18853   │
# │ 7   │ 2866     │ 0.2     │ 0.177509  │ 0.165874  │
# │ 8   │ 2869     │ -0.2    │ -0.203316 │ -0.196708 │
# │ 9   │ 2872     │ 0.2     │ 0.203991  │ 0.207429  │
# │ 10  │ 4151     │ 0.2     │ 0.0       │ 0.152249  │
# │ 11  │ 4153     │ -0.2    │ 0.0       │ -0.203065 │
# │ 12  │ 4154     │ 0.2     │ 0.213471  │ 0.212827  │
# │ 13  │ 9923     │ -0.2    │ 0.0       │ 0.0       │
# │ 14  │ 9934     │ -0.2    │ -0.128807 │ -0.120408 │
# │ 15  │ 9940     │ 0.2     │ 0.233096  │ 0.227813  │
# Grouped ran: 26 iters and Ungrouped ran: 26 iters
#
#
# running 26 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 3581     │ -0.2    │ 0.0       │ 0.0       │
# │ 2   │ 3582     │ 0.2     │ 0.0       │ 0.11308   │
# │ 3   │ 3590     │ 0.2     │ 0.24071   │ 0.268168  │
# │ 4   │ 5142     │ 0.2     │ 0.197909  │ 0.164847  │
# │ 5   │ 5149     │ -0.2    │ 0.0       │ -0.117847 │
# │ 6   │ 5150     │ 0.2     │ 0.0       │ 0.0       │
# │ 7   │ 5550     │ -0.2    │ -0.2089   │ -0.203779 │
# │ 8   │ 5551     │ 0.2     │ 0.0       │ 0.0       │
# │ 9   │ 5557     │ 0.2     │ 0.200687  │ 0.199909  │
# │ 10  │ 6810     │ 0.2     │ 0.267361  │ 0.235872  │
# │ 11  │ 6819     │ 0.2     │ 0.0       │ 0.167071  │
# │ 12  │ 6820     │ -0.2    │ 0.0       │ -0.181744 │
# │ 13  │ 8592     │ -0.2    │ -0.227526 │ -0.207993 │
# │ 14  │ 8597     │ 0.2     │ 0.204187  │ 0.219947  │
# │ 15  │ 8599     │ 0.2     │ 0.1769    │ 0.201297  │
# Grouped ran: 40 iters and Ungrouped ran: 18 iters
#
#
# running 27 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 1763     │ -0.2    │ 0.0       │ 0.0       │
# │ 2   │ 1769     │ 0.2     │ 0.0       │ 0.0       │
# │ 3   │ 1779     │ 0.2     │ 0.203231  │ 0.180379  │
# │ 4   │ 4051     │ 0.2     │ 0.14187   │ 0.0       │
# │ 5   │ 4053     │ 0.2     │ 0.257948  │ 0.239195  │
# │ 6   │ 4056     │ 0.2     │ 0.220843  │ 0.235543  │
# │ 7   │ 7853     │ 0.2     │ 0.157856  │ 0.175481  │
# │ 8   │ 7855     │ -0.2    │ -0.256881 │ -0.266422 │
# │ 9   │ 7858     │ 0.2     │ 0.0       │ 0.0       │
# │ 10  │ 7874     │ -0.2    │ 0.0       │ -0.16782  │
# │ 11  │ 7875     │ 0.2     │ 0.140762  │ 0.219128  │
# │ 12  │ 7877     │ -0.2    │ -0.265563 │ -0.222591 │
# │ 13  │ 8462     │ 0.2     │ 0.0       │ 0.0975878 │
# │ 14  │ 8470     │ -0.2    │ -0.203506 │ -0.230859 │
# │ 15  │ 8475     │ 0.2     │ 0.258687  │ 0.193114  │
# Grouped ran: 25 iters and Ungrouped ran: 17 iters
#
#
# running 28 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 866      │ 0.2     │ 0.0       │ 0.0       │
# │ 2   │ 867      │ 0.2     │ 0.281878  │ 0.307029  │
# │ 3   │ 877      │ 0.2     │ 0.0       │ 0.0920981 │
# │ 4   │ 2463     │ -0.2    │ -0.184439 │ -0.172181 │
# │ 5   │ 2465     │ 0.2     │ 0.331614  │ 0.294849  │
# │ 6   │ 2467     │ 0.2     │ 0.0       │ 0.0       │
# │ 7   │ 3942     │ 0.2     │ 0.210224  │ 0.203679  │
# │ 8   │ 3944     │ 0.2     │ 0.217191  │ 0.214107  │
# │ 9   │ 3946     │ 0.2     │ 0.214818  │ 0.207612  │
# │ 10  │ 4322     │ -0.2    │ -0.228578 │ -0.233894 │
# │ 11  │ 4327     │ 0.2     │ 0.190042  │ 0.166974  │
# │ 12  │ 4337     │ 0.2     │ 0.203136  │ 0.206004  │
# │ 13  │ 4945     │ -0.2    │ -0.276226 │ -0.188792 │
# │ 14  │ 4950     │ -0.2    │ 0.0       │ 0.0       │
# │ 15  │ 4951     │ 0.2     │ 0.0       │ 0.0       │
# Grouped ran: 26 iters and Ungrouped ran: 18 iters
#
#
# running 29 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 1841     │ 0.2     │ 0.240057  │ 0.229798  │
# │ 2   │ 1853     │ -0.2    │ -0.214835 │ -0.225479 │
# │ 3   │ 1856     │ -0.2    │ -0.200531 │ -0.190113 │
# │ 4   │ 3623     │ -0.2    │ -0.17239  │ -0.113307 │
# │ 5   │ 3627     │ -0.2    │ 0.0       │ 0.0       │
# │ 6   │ 3629     │ 0.2     │ 0.0       │ 0.0       │
# │ 7   │ 7847     │ -0.2    │ -0.224001 │ -0.218267 │
# │ 8   │ 7852     │ 0.2     │ 0.212071  │ 0.207671  │
# │ 9   │ 7859     │ -0.2    │ -0.226252 │ -0.229505 │
# │ 10  │ 8384     │ 0.2     │ 0.284314  │ 0.273489  │
# │ 11  │ 8385     │ 0.2     │ 0.208968  │ 0.168343  │
# │ 12  │ 8391     │ 0.2     │ 0.182422  │ 0.0       │
# │ 13  │ 8828     │ 0.2     │ 0.246089  │ 0.247347  │
# │ 14  │ 8838     │ 0.2     │ 0.203756  │ 0.193881  │
# │ 15  │ 8839     │ -0.2    │ -0.258493 │ -0.262623 │
# Grouped ran: 24 iters and Ungrouped ran: 21 iters
#
#
# running 30 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 1202     │ 0.2     │ 0.15876   │ 0.154674  │
# │ 2   │ 1209     │ -0.2    │ -0.257795 │ -0.260843 │
# │ 3   │ 1219     │ 0.2     │ 0.149308  │ 0.152782  │
# │ 4   │ 1627     │ 0.2     │ 0.18108   │ 0.204591  │
# │ 5   │ 1629     │ 0.2     │ 0.17711   │ 0.211751  │
# │ 6   │ 1635     │ -0.2    │ 0.0       │ -0.14288  │
# │ 7   │ 4141     │ -0.2    │ -0.231309 │ -0.230125 │
# │ 8   │ 4144     │ 0.2     │ 0.177215  │ 0.174679  │
# │ 9   │ 4148     │ 0.2     │ 0.20215   │ 0.20463   │
# │ 10  │ 4205     │ 0.2     │ 0.206393  │ 0.213076  │
# │ 11  │ 4208     │ 0.2     │ 0.220497  │ 0.218205  │
# │ 12  │ 4214     │ 0.2     │ 0.210501  │ 0.217512  │
# │ 13  │ 7890     │ 0.2     │ 0.0       │ 0.0       │
# │ 14  │ 7897     │ 0.2     │ 0.188791  │ 0.18532   │
# │ 15  │ 7899     │ -0.2    │ -0.143102 │ -0.146357 │
# Grouped ran: 16 iters and Ungrouped ran: 16 iters
#
#
# running 31 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 921      │ 0.2     │ 0.17032   │ 0.160529  │
# │ 2   │ 929      │ -0.2    │ -0.228714 │ -0.217727 │
# │ 3   │ 933      │ -0.2    │ -0.180398 │ 0.0       │
# │ 4   │ 2466     │ 0.2     │ 0.247363  │ 0.143715  │
# │ 5   │ 2467     │ -0.2    │ -0.174639 │ 0.0       │
# │ 6   │ 2469     │ -0.2    │ -0.230471 │ -0.272102 │
# │ 7   │ 2527     │ -0.2    │ -0.186989 │ -0.170816 │
# │ 8   │ 2528     │ -0.2    │ -0.262617 │ -0.261759 │
# │ 9   │ 2531     │ -0.2    │ -0.129402 │ -0.141387 │
# │ 10  │ 4270     │ 0.2     │ 0.0       │ 0.0       │
# │ 11  │ 4271     │ -0.2    │ 0.0       │ 0.0       │
# │ 12  │ 4280     │ 0.2     │ 0.225058  │ 0.132797  │
# │ 13  │ 7942     │ 0.2     │ 0.187386  │ 0.193102  │
# │ 14  │ 7943     │ 0.2     │ 0.19348   │ 0.190773  │
# │ 15  │ 7951     │ 0.2     │ 0.139059  │ 0.142751  │
# Grouped ran: 31 iters and Ungrouped ran: 25 iters
#
#
# running 32 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped    │
# │     │ Int64    │ Float64 │ Float64   │ Float64    │
# ├─────┼──────────┼─────────┼───────────┼────────────┤
# │ 1   │ 5602     │ 0.2     │ 0.0       │ 0.0        │
# │ 2   │ 5603     │ -0.2    │ 0.0       │ -0.0514104 │
# │ 3   │ 5604     │ -0.2    │ -0.134379 │ -0.10842   │
# │ 4   │ 6725     │ 0.2     │ 0.215905  │ 0.260339   │
# │ 5   │ 6727     │ 0.2     │ 0.0       │ 0.0        │
# │ 6   │ 6738     │ -0.2    │ -0.177829 │ -0.154088  │
# │ 7   │ 7543     │ 0.2     │ 0.230506  │ 0.214064   │
# │ 8   │ 7546     │ 0.2     │ 0.159936  │ 0.163372   │
# │ 9   │ 7549     │ -0.2    │ -0.234334 │ -0.241145  │
# │ 10  │ 8783     │ 0.2     │ 0.234376  │ 0.252993   │
# │ 11  │ 8794     │ -0.2    │ -0.20634  │ -0.195934  │
# │ 12  │ 8795     │ -0.2    │ -0.222862 │ -0.211426  │
# │ 13  │ 9790     │ -0.2    │ 0.0       │ 0.0        │
# │ 14  │ 9793     │ 0.2     │ 0.140712  │ 0.152284   │
# │ 15  │ 9796     │ -0.2    │ 0.0       │ -0.0960905 │
# Grouped ran: 21 iters and Ungrouped ran: 14 iters
#
#
# running 33 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 3485     │ 0.2     │ 0.165464  │ 0.164826  │
# │ 2   │ 3491     │ 0.2     │ 0.182283  │ 0.174478  │
# │ 3   │ 3498     │ -0.2    │ -0.195307 │ -0.173056 │
# │ 4   │ 4205     │ 0.2     │ 0.208017  │ 0.199622  │
# │ 5   │ 4209     │ 0.2     │ 0.157448  │ 0.16337   │
# │ 6   │ 4211     │ -0.2    │ -0.177354 │ -0.161144 │
# │ 7   │ 5191     │ -0.2    │ -0.24704  │ -0.268935 │
# │ 8   │ 5193     │ -0.2    │ 0.0       │ 0.0       │
# │ 9   │ 5194     │ 0.2     │ 0.0       │ 0.0       │
# │ 10  │ 9652     │ -0.2    │ -0.180088 │ 0.0       │
# │ 11  │ 9654     │ 0.2     │ 0.207805  │ 0.28049   │
# │ 12  │ 9657     │ -0.2    │ -0.249563 │ -0.150849 │
# │ 13  │ 9722     │ 0.2     │ 0.0       │ 0.0       │
# │ 14  │ 9735     │ -0.2    │ 0.0       │ -0.17298  │
# │ 15  │ 9736     │ 0.2     │ 0.0       │ 0.144957  │
# Grouped ran: 25 iters and Ungrouped ran: 18 iters
#
#
# running 34 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 1474     │ -0.2    │ -0.170269 │ 0.0       │
# │ 2   │ 1476     │ -0.2    │ -0.222797 │ -0.120121 │
# │ 3   │ 1478     │ -0.2    │ -0.188645 │ -0.158816 │
# │ 4   │ 1652     │ -0.2    │ -0.156493 │ -0.137819 │
# │ 5   │ 1658     │ 0.2     │ 0.0       │ 0.183129  │
# │ 6   │ 1660     │ -0.2    │ 0.0       │ -0.169802 │
# │ 7   │ 6411     │ 0.2     │ 0.239364  │ 0.282038  │
# │ 8   │ 6415     │ 0.2     │ 0.183232  │ 0.190307  │
# │ 9   │ 6420     │ -0.2    │ -0.167159 │ 0.0       │
# │ 10  │ 6647     │ 0.2     │ 0.0       │ 0.0       │
# │ 11  │ 6652     │ 0.2     │ 0.0       │ 0.0       │
# │ 12  │ 6660     │ -0.2    │ 0.0       │ 0.0       │
# │ 13  │ 8501     │ 0.2     │ 0.149101  │ 0.0       │
# │ 14  │ 8505     │ -0.2    │ -0.210574 │ -0.131335 │
# │ 15  │ 8519     │ -0.2    │ -0.223266 │ -0.240892 │
# Grouped ran: 29 iters and Ungrouped ran: 22 iters
#
#
# running 35 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 147      │ 0.2     │ 0.0       │ 0.0       │
# │ 2   │ 150      │ -0.2    │ 0.0       │ 0.0       │
# │ 3   │ 154      │ 0.2     │ 0.112211  │ 0.0       │
# │ 4   │ 3690     │ 0.2     │ 0.150775  │ 0.0       │
# │ 5   │ 3696     │ -0.2    │ -0.161802 │ -0.178464 │
# │ 6   │ 3700     │ -0.2    │ -0.240903 │ -0.248914 │
# │ 7   │ 7002     │ -0.2    │ -0.191203 │ -0.195783 │
# │ 8   │ 7012     │ 0.2     │ 0.164039  │ 0.16496   │
# │ 9   │ 7017     │ -0.2    │ 0.0       │ 0.0       │
# │ 10  │ 7827     │ -0.2    │ -0.147426 │ -0.152148 │
# │ 11  │ 7831     │ -0.2    │ -0.275804 │ -0.281496 │
# │ 12  │ 7834     │ -0.2    │ -0.234201 │ -0.238102 │
# │ 13  │ 9041     │ -0.2    │ -0.270791 │ -0.275094 │
# │ 14  │ 9046     │ 0.2     │ 0.207307  │ 0.206779  │
# │ 15  │ 9050     │ 0.2     │ 0.186253  │ 0.184632  │
# Grouped ran: 39 iters and Ungrouped ran: 22 iters
#
#
# running 36 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 727      │ 0.2     │ 0.197663  │ 0.203534  │
# │ 2   │ 731      │ -0.2    │ -0.193617 │ -0.201247 │
# │ 3   │ 733      │ 0.2     │ 0.173779  │ 0.184613  │
# │ 4   │ 4221     │ 0.2     │ 0.140182  │ 0.159706  │
# │ 5   │ 4223     │ -0.2    │ 0.0       │ 0.0       │
# │ 6   │ 4234     │ -0.2    │ -0.202155 │ -0.186911 │
# │ 7   │ 4265     │ 0.2     │ 0.255998  │ 0.2476    │
# │ 8   │ 4273     │ 0.2     │ 0.241862  │ 0.248394  │
# │ 9   │ 4275     │ 0.2     │ 0.163046  │ 0.166     │
# │ 10  │ 4881     │ 0.2     │ 0.228692  │ 0.231107  │
# │ 11  │ 4882     │ -0.2    │ -0.258087 │ -0.261242 │
# │ 12  │ 4884     │ -0.2    │ -0.232132 │ -0.233201 │
# │ 13  │ 6832     │ 0.2     │ 0.194131  │ 0.17039   │
# │ 14  │ 6836     │ -0.2    │ 0.0       │ -0.165571 │
# │ 15  │ 6837     │ 0.2     │ 0.0       │ 0.0       │
# Grouped ran: 17 iters and Ungrouped ran: 32 iters
#
#
# running 37 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 967      │ -0.2    │ -0.19556  │ 0.0       │
# │ 2   │ 973      │ -0.2    │ -0.192122 │ -0.131359 │
# │ 3   │ 974      │ -0.2    │ -0.223076 │ -0.245666 │
# │ 4   │ 2142     │ 0.2     │ 0.0       │ 0.0       │
# │ 5   │ 2149     │ 0.2     │ 0.0       │ 0.0       │
# │ 6   │ 2151     │ -0.2    │ 0.0       │ 0.0       │
# │ 7   │ 3022     │ -0.2    │ -0.156181 │ -0.14853  │
# │ 8   │ 3028     │ 0.2     │ 0.189869  │ 0.187361  │
# │ 9   │ 3038     │ -0.2    │ -0.197413 │ -0.200919 │
# │ 10  │ 8584     │ -0.2    │ -0.119743 │ -0.129486 │
# │ 11  │ 8585     │ -0.2    │ -0.272986 │ -0.271014 │
# │ 12  │ 8591     │ 0.2     │ 0.232407  │ 0.2296    │
# │ 13  │ 9585     │ -0.2    │ -0.197055 │ 0.0       │
# │ 14  │ 9587     │ 0.2     │ 0.20305   │ 0.157594  │
# │ 15  │ 9591     │ -0.2    │ -0.143088 │ 0.0       │
# Grouped ran: 31 iters and Ungrouped ran: 28 iters
#
#
# running 38 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped    │
# │     │ Int64    │ Float64 │ Float64   │ Float64    │
# ├─────┼──────────┼─────────┼───────────┼────────────┤
# │ 1   │ 6345     │ -0.2    │ -0.174652 │ -0.149077  │
# │ 2   │ 6353     │ 0.2     │ 0.0       │ 0.0        │
# │ 3   │ 6358     │ -0.2    │ 0.0       │ -0.0754632 │
# │ 4   │ 8206     │ 0.2     │ 0.167086  │ 0.108686   │
# │ 5   │ 8209     │ 0.2     │ 0.181714  │ 0.0        │
# │ 6   │ 8218     │ 0.2     │ 0.179209  │ 0.193369   │
# │ 7   │ 9295     │ -0.2    │ -0.269885 │ -0.266004  │
# │ 8   │ 9296     │ -0.2    │ -0.121161 │ -0.128825  │
# │ 9   │ 9299     │ -0.2    │ -0.202962 │ -0.20309   │
# │ 10  │ 9343     │ -0.2    │ -0.207151 │ -0.205528  │
# │ 11  │ 9353     │ -0.2    │ -0.165213 │ -0.158534  │
# │ 12  │ 9358     │ -0.2    │ -0.266627 │ -0.277866  │
# │ 13  │ 9787     │ -0.2    │ -0.164187 │ -0.158735  │
# │ 14  │ 9792     │ 0.2     │ 0.195952  │ 0.20588    │
# │ 15  │ 9795     │ -0.2    │ -0.226201 │ -0.226353  │
# Grouped ran: 28 iters and Ungrouped ran: 34 iters
#
#
# running 39 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 741      │ -0.2    │ -0.179068 │ -0.187774 │
# │ 2   │ 745      │ 0.2     │ 0.174339  │ 0.0       │
# │ 3   │ 756      │ 0.2     │ 0.243832  │ 0.241328  │
# │ 4   │ 3591     │ -0.2    │ -0.176667 │ -0.191602 │
# │ 5   │ 3595     │ -0.2    │ -0.270041 │ -0.265138 │
# │ 6   │ 3596     │ -0.2    │ -0.15912  │ -0.146795 │
# │ 7   │ 5308     │ 0.2     │ 0.177941  │ 0.173434  │
# │ 8   │ 5310     │ -0.2    │ -0.201972 │ -0.196573 │
# │ 9   │ 5314     │ 0.2     │ 0.27475   │ 0.271616  │
# │ 10  │ 5914     │ -0.2    │ 0.0       │ 0.0       │
# │ 11  │ 5916     │ -0.2    │ 0.0       │ 0.0       │
# │ 12  │ 5918     │ -0.2    │ 0.0       │ 0.0       │
# │ 13  │ 6791     │ -0.2    │ -0.212278 │ -0.220447 │
# │ 14  │ 6794     │ -0.2    │ -0.203605 │ -0.211819 │
# │ 15  │ 6799     │ 0.2     │ 0.230444  │ 0.231719  │
# Grouped ran: 12 iters and Ungrouped ran: 11 iters
#
#
# running 40 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped    │
# │     │ Int64    │ Float64 │ Float64   │ Float64    │
# ├─────┼──────────┼─────────┼───────────┼────────────┤
# │ 1   │ 2106     │ 0.2     │ 0.169386  │ 0.189471   │
# │ 2   │ 2115     │ -0.2    │ -0.175254 │ -0.189762  │
# │ 3   │ 2118     │ 0.2     │ 0.156148  │ 0.152501   │
# │ 4   │ 5208     │ 0.2     │ 0.211265  │ 0.0        │
# │ 5   │ 5216     │ -0.2    │ -0.165612 │ -0.142907  │
# │ 6   │ 5220     │ 0.2     │ 0.244474  │ 0.188012   │
# │ 7   │ 7141     │ -0.2    │ 0.0       │ 0.0        │
# │ 8   │ 7142     │ 0.2     │ 0.0       │ 0.0        │
# │ 9   │ 7150     │ -0.2    │ 0.0       │ -0.185352  │
# │ 10  │ 8286     │ 0.2     │ 0.234248  │ 0.253618   │
# │ 11  │ 8298     │ 0.2     │ 0.0       │ 0.2481     │
# │ 12  │ 8299     │ -0.2    │ 0.0       │ -0.270646  │
# │ 13  │ 9850     │ -0.2    │ -0.242665 │ -0.0844169 │
# │ 14  │ 9854     │ 0.2     │ 0.253566  │ 0.0        │
# │ 15  │ 9859     │ -0.2    │ -0.229251 │ 0.0        │
# Grouped ran: 23 iters and Ungrouped ran: 21 iters
#
#
# running 41 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 1063     │ 0.2     │ 0.0       │ 0.126344  │
# │ 2   │ 1067     │ -0.2    │ 0.0       │ -0.113783 │
# │ 3   │ 1068     │ -0.2    │ -0.355548 │ -0.265006 │
# │ 4   │ 1262     │ 0.2     │ 0.206005  │ 0.198128  │
# │ 5   │ 1267     │ 0.2     │ 0.207379  │ 0.200422  │
# │ 6   │ 1280     │ 0.2     │ 0.206592  │ 0.202136  │
# │ 7   │ 1948     │ -0.2    │ -0.15594  │ 0.0       │
# │ 8   │ 1957     │ 0.2     │ 0.22335   │ 0.244106  │
# │ 9   │ 1959     │ 0.2     │ 0.121573  │ 0.0670808 │
# │ 10  │ 2385     │ 0.2     │ 0.175225  │ 0.197149  │
# │ 11  │ 2396     │ -0.2    │ -0.206376 │ 0.0       │
# │ 12  │ 2398     │ -0.2    │ -0.22147  │ -0.177071 │
# │ 13  │ 7187     │ 0.2     │ 0.225139  │ 0.230654  │
# │ 14  │ 7191     │ -0.2    │ -0.209336 │ -0.213335 │
# │ 15  │ 7193     │ -0.2    │ -0.171318 │ -0.175498 │
# Grouped ran: 21 iters and Ungrouped ran: 20 iters
#
#
# running 42 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 3646     │ 0.2     │ 0.178029  │ 0.170405  │
# │ 2   │ 3649     │ -0.2    │ -0.297269 │ -0.259428 │
# │ 3   │ 3659     │ -0.2    │ -0.232107 │ -0.216718 │
# │ 4   │ 6235     │ -0.2    │ -0.228375 │ -0.208983 │
# │ 5   │ 6237     │ -0.2    │ -0.232839 │ -0.25245  │
# │ 6   │ 6239     │ 0.2     │ 0.141185  │ 0.180634  │
# │ 7   │ 6962     │ 0.2     │ 0.0       │ 0.0       │
# │ 8   │ 6963     │ -0.2    │ 0.0       │ -0.168367 │
# │ 9   │ 6967     │ 0.2     │ 0.0       │ 0.19788   │
# │ 10  │ 7051     │ -0.2    │ 0.0       │ -0.134254 │
# │ 11  │ 7059     │ -0.2    │ -0.267082 │ -0.231713 │
# │ 12  │ 7060     │ -0.2    │ -0.202853 │ -0.192487 │
# │ 13  │ 9569     │ 0.2     │ 0.0       │ 0.158041  │
# │ 14  │ 9573     │ 0.2     │ 0.0       │ 0.208501  │
# │ 15  │ 9576     │ -0.2    │ -0.241762 │ -0.242898 │
# Grouped ran: 28 iters and Ungrouped ran: 26 iters
#
#
# running 43 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 2901     │ -0.2    │ -0.142173 │ -0.146863 │
# │ 2   │ 2914     │ -0.2    │ -0.166782 │ -0.184858 │
# │ 3   │ 2916     │ -0.2    │ -0.215802 │ -0.211772 │
# │ 4   │ 6532     │ -0.2    │ 0.0       │ 0.0       │
# │ 5   │ 6534     │ 0.2     │ 0.0       │ 0.046949  │
# │ 6   │ 6539     │ 0.2     │ 0.265642  │ 0.232934  │
# │ 7   │ 6682     │ -0.2    │ -0.173291 │ -0.174689 │
# │ 8   │ 6694     │ -0.2    │ -0.215651 │ -0.218086 │
# │ 9   │ 6697     │ 0.2     │ 0.208622  │ 0.212103  │
# │ 10  │ 8370     │ 0.2     │ 0.0       │ 0.0       │
# │ 11  │ 8377     │ 0.2     │ 0.0       │ 0.0       │
# │ 12  │ 8380     │ 0.2     │ 0.143164  │ 0.141855  │
# │ 13  │ 9145     │ 0.2     │ 0.209685  │ 0.23058   │
# │ 14  │ 9148     │ -0.2    │ -0.148567 │ -0.113574 │
# │ 15  │ 9155     │ 0.2     │ 0.142888  │ 0.0       │
# Grouped ran: 19 iters and Ungrouped ran: 30 iters
#
#
# running 44 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 404      │ 0.2     │ 0.244944  │ 0.240296  │
# │ 2   │ 406      │ 0.2     │ 0.183811  │ 0.189289  │
# │ 3   │ 415      │ 0.2     │ 0.168817  │ 0.158835  │
# │ 4   │ 2708     │ 0.2     │ 0.203071  │ 0.19674   │
# │ 5   │ 2711     │ 0.2     │ 0.217935  │ 0.215472  │
# │ 6   │ 2714     │ -0.2    │ -0.212805 │ -0.20837  │
# │ 7   │ 3487     │ -0.2    │ 0.0       │ -0.133039 │
# │ 8   │ 3489     │ -0.2    │ 0.0       │ 0.0       │
# │ 9   │ 3498     │ -0.2    │ 0.0       │ -0.127725 │
# │ 10  │ 4007     │ -0.2    │ -0.208582 │ -0.210784 │
# │ 11  │ 4009     │ -0.2    │ -0.200956 │ -0.160242 │
# │ 12  │ 4020     │ 0.2     │ 0.171159  │ 0.0       │
# │ 13  │ 6252     │ -0.2    │ -0.215736 │ -0.213391 │
# │ 14  │ 6254     │ -0.2    │ -0.219631 │ -0.207467 │
# │ 15  │ 6257     │ 0.2     │ 0.156239  │ 0.156892  │
# Grouped ran: 13 iters and Ungrouped ran: 21 iters
#
#
# running 45 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 265      │ -0.2    │ -0.218132 │ -0.218784 │
# │ 2   │ 266      │ -0.2    │ -0.205554 │ -0.193732 │
# │ 3   │ 280      │ 0.2     │ 0.234149  │ 0.236201  │
# │ 4   │ 982      │ -0.2    │ -0.19015  │ -0.193146 │
# │ 5   │ 987      │ 0.2     │ 0.189957  │ 0.201174  │
# │ 6   │ 995      │ -0.2    │ -0.193265 │ -0.204513 │
# │ 7   │ 7169     │ 0.2     │ 0.159021  │ 0.202795  │
# │ 8   │ 7170     │ -0.2    │ 0.0       │ -0.144192 │
# │ 9   │ 7178     │ -0.2    │ -0.211305 │ -0.211379 │
# │ 10  │ 7487     │ 0.2     │ 0.244855  │ 0.222158  │
# │ 11  │ 7489     │ -0.2    │ -0.134671 │ -0.139841 │
# │ 12  │ 7493     │ -0.2    │ -0.237358 │ -0.227443 │
# │ 13  │ 9045     │ -0.2    │ -0.22856  │ -0.148488 │
# │ 14  │ 9055     │ 0.2     │ 0.214755  │ 0.0       │
# │ 15  │ 9059     │ 0.2     │ 0.226089  │ 0.215408  │
# Grouped ran: 14 iters and Ungrouped ran: 14 iters
#
#
# running 46 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 1787     │ -0.2    │ -0.239582 │ -0.243987 │
# │ 2   │ 1792     │ 0.2     │ 0.202405  │ 0.218177  │
# ...
# │ 1   │ 2501     │ 0.2     │ 0.222133  │ 0.201216  │
# │ 2   │ 2505     │ 0.2     │ 0.243276  │ 0.246903  │
# │ 3   │ 2512     │ -0.2    │ -0.246115 │ -0.249202 │
# │ 4   │ 2842     │ 0.2     │ 0.222693  │ 0.216386  │
# │ 5   │ 2847     │ 0.2     │ 0.174823  │ 0.184058  │
# │ 6   │ 2860     │ 0.2     │ 0.237778  │ 0.237533  │
# │ 7   │ 3862     │ -0.2    │ -0.180534 │ -0.240968 │
# │ 8   │ 3870     │ -0.2    │ -0.13522  │ 0.0       │
# │ 9   │ 3880     │ 0.2     │ 0.0       │ 0.183466  │
# │ 10  │ 5348     │ 0.2     │ 0.0       │ 0.0       │
# │ 11  │ 5357     │ -0.2    │ 0.0       │ -0.110634 │
# │ 12  │ 5359     │ 0.2     │ 0.232717  │ 0.244951  │
# │ 13  │ 7610     │ -0.2    │ -0.216377 │ -0.212544 │
# │ 14  │ 7612     │ 0.2     │ 0.280249  │ 0.278751  │
# │ 15  │ 7613     │ 0.2     │ 0.212346  │ 0.197807  │
# Grouped ran: 21 iters and Ungrouped ran: 17 iters
#
#
# running 87 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 868      │ 0.2     │ 0.21026   │ 0.209405  │
# │ 2   │ 872      │ -0.2    │ -0.186411 │ -0.193274 │
# │ 3   │ 877      │ 0.2     │ 0.231081  │ 0.230428  │
# │ 4   │ 2763     │ -0.2    │ -0.23194  │ -0.234814 │
# │ 5   │ 2769     │ 0.2     │ 0.178717  │ 0.177929  │
# │ 6   │ 2778     │ -0.2    │ -0.268831 │ -0.268256 │
# │ 7   │ 2787     │ 0.2     │ 0.166887  │ 0.163099  │
# │ 8   │ 2788     │ 0.2     │ 0.177221  │ 0.17734   │
# │ 9   │ 2794     │ 0.2     │ 0.0       │ 0.0       │
# │ 10  │ 5562     │ 0.2     │ 0.156529  │ 0.161826  │
# │ 11  │ 5576     │ 0.2     │ 0.294806  │ 0.296084  │
# │ 12  │ 5578     │ 0.2     │ 0.200559  │ 0.195267  │
# │ 13  │ 7624     │ -0.2    │ -0.152845 │ -0.16629  │
# │ 14  │ 7626     │ -0.2    │ -0.146757 │ -0.217664 │
# │ 15  │ 7627     │ 0.2     │ 0.0       │ 0.257721  │
# Grouped ran: 22 iters and Ungrouped ran: 25 iters
#
#
# running 88 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 1163     │ 0.2     │ 0.211785  │ 0.215356  │
# │ 2   │ 1169     │ 0.2     │ 0.20705   │ 0.217549  │
# │ 3   │ 1172     │ 0.2     │ 0.153488  │ 0.170343  │
# │ 4   │ 2943     │ -0.2    │ -0.223241 │ -0.205379 │
# │ 5   │ 2947     │ 0.2     │ 0.160519  │ 0.16668   │
# │ 6   │ 2948     │ 0.2     │ 0.23877   │ 0.219805  │
# │ 7   │ 3403     │ 0.2     │ 0.170741  │ 0.204034  │
# │ 8   │ 3412     │ -0.2    │ 0.0       │ 0.0       │
# │ 9   │ 3417     │ -0.2    │ 0.0       │ 0.0       │
# │ 10  │ 4345     │ 0.2     │ 0.0       │ 0.0       │
# │ 11  │ 4347     │ -0.2    │ 0.0       │ 0.0       │
# │ 12  │ 4358     │ 0.2     │ 0.198165  │ 0.217396  │
# │ 13  │ 4925     │ -0.2    │ -0.186646 │ -0.174503 │
# │ 14  │ 4934     │ 0.2     │ 0.194998  │ 0.210298  │
# │ 15  │ 4939     │ -0.2    │ -0.175348 │ -0.189002 │
# Grouped ran: 23 iters and Ungrouped ran: 26 iters
#
#
# running 89 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 562      │ -0.2    │ -0.222148 │ -0.221309 │
# │ 2   │ 567      │ -0.2    │ -0.181379 │ -0.182477 │
# │ 3   │ 575      │ -0.2    │ -0.211136 │ -0.208595 │
# │ 4   │ 1868     │ 0.2     │ 0.198138  │ 0.175738  │
# │ 5   │ 1876     │ -0.2    │ -0.188548 │ -0.182266 │
# │ 6   │ 1878     │ -0.2    │ -0.215615 │ -0.232889 │
# │ 7   │ 4083     │ -0.2    │ -0.110258 │ -0.163925 │
# │ 8   │ 4087     │ 0.2     │ 0.212766  │ 0.201827  │
# │ 9   │ 4098     │ 0.2     │ 0.0       │ 0.163233  │
# │ 10  │ 7702     │ 0.2     │ 0.170007  │ 0.153666  │
# │ 11  │ 7703     │ 0.2     │ 0.240885  │ 0.243974  │
# │ 12  │ 7706     │ -0.2    │ -0.198142 │ -0.20886  │
# │ 13  │ 7964     │ 0.2     │ 0.0       │ 0.0       │
# │ 14  │ 7965     │ -0.2    │ 0.0       │ 0.0       │
# │ 15  │ 7975     │ -0.2    │ -0.229448 │ -0.18943  │
# Grouped ran: 32 iters and Ungrouped ran: 23 iters
#
#
# running 90 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 2308     │ 0.2     │ 0.172619  │ 0.175557  │
# │ 2   │ 2319     │ -0.2    │ -0.126411 │ -0.13813  │
# │ 3   │ 2320     │ -0.2    │ -0.180458 │ -0.178423 │
# │ 4   │ 3088     │ 0.2     │ 0.0       │ 0.13141   │
# │ 5   │ 3092     │ 0.2     │ 0.198855  │ 0.190076  │
# │ 6   │ 3094     │ 0.2     │ 0.0       │ 0.0       │
# │ 7   │ 4851     │ 0.2     │ 0.153155  │ 0.231767  │
# │ 8   │ 4853     │ -0.2    │ 0.0       │ -0.196621 │
# │ 9   │ 4855     │ 0.2     │ 0.0       │ 0.175795  │
# │ 10  │ 6261     │ 0.2     │ 0.214317  │ 0.204509  │
# │ 11  │ 6269     │ -0.2    │ -0.192954 │ -0.193249 │
# │ 12  │ 6272     │ -0.2    │ -0.198157 │ -0.193308 │
# │ 13  │ 7285     │ 0.2     │ 0.134035  │ 0.0       │
# │ 14  │ 7288     │ -0.2    │ -0.2345   │ -0.266863 │
# │ 15  │ 7297     │ 0.2     │ 0.271088  │ 0.138505  │
# Grouped ran: 51 iters and Ungrouped ran: 17 iters
#
#
# running 91 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 787      │ 0.2     │ 0.0       │ 0.0711199 │
# │ 2   │ 788      │ -0.2    │ 0.0       │ 0.0       │
# │ 3   │ 795      │ -0.2    │ 0.0       │ 0.0       │
# │ 4   │ 1023     │ 0.2     │ 0.241259  │ 0.0       │
# │ 5   │ 1028     │ -0.2    │ -0.222837 │ -0.115377 │
# │ 6   │ 1035     │ -0.2    │ -0.140946 │ -0.204073 │
# │ 7   │ 4189     │ -0.2    │ 0.0       │ 0.0       │
# │ 8   │ 4191     │ -0.2    │ 0.0       │ 0.0       │
# │ 9   │ 4198     │ 0.2     │ 0.0       │ 0.0618922 │
# │ 10  │ 4865     │ 0.2     │ 0.114634  │ 0.122017  │
# │ 11  │ 4866     │ 0.2     │ 0.289325  │ 0.270235  │
# │ 12  │ 4878     │ 0.2     │ 0.216394  │ 0.216953  │
# │ 13  │ 6043     │ -0.2    │ -0.184875 │ -0.182758 │
# │ 14  │ 6051     │ -0.2    │ -0.218918 │ -0.216372 │
# │ 15  │ 6054     │ 0.2     │ 0.248557  │ 0.244225  │
# Grouped ran: 23 iters and Ungrouped ran: 32 iters
#
#
# running 92 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 1572     │ -0.2    │ -0.249498 │ -0.238388 │
# │ 2   │ 1574     │ 0.2     │ 0.19155   │ 0.195766  │
# │ 3   │ 1579     │ 0.2     │ 0.187878  │ 0.184274  │
# │ 4   │ 4401     │ 0.2     │ 0.174614  │ 0.172192  │
# │ 5   │ 4411     │ 0.2     │ 0.0       │ 0.0       │
# │ 6   │ 4413     │ -0.2    │ -0.227226 │ -0.225147 │
# │ 7   │ 6969     │ 0.2     │ 0.0       │ 0.10575   │
# │ 8   │ 6970     │ -0.2    │ 0.0       │ 0.0       │
# │ 9   │ 6976     │ -0.2    │ -0.17886  │ -0.213531 │
# │ 10  │ 7201     │ -0.2    │ 0.0       │ 0.0       │
# │ 11  │ 7214     │ -0.2    │ 0.0       │ 0.0       │
# │ 12  │ 7218     │ -0.2    │ -0.243616 │ -0.165449 │
# │ 13  │ 7662     │ 0.2     │ 0.227389  │ 0.193079  │
# │ 14  │ 7668     │ -0.2    │ -0.187933 │ 0.0       │
# │ 15  │ 7679     │ -0.2    │ -0.228736 │ -0.263193 │
# Grouped ran: 16 iters and Ungrouped ran: 17 iters
#
#
# running 93 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 1043     │ 0.2     │ 0.1952    │ 0.170724  │
# │ 2   │ 1046     │ -0.2    │ 0.0       │ 0.0       │
# │ 3   │ 1056     │ -0.2    │ 0.0       │ 0.0       │
# │ 4   │ 4782     │ -0.2    │ -0.2055   │ -0.20305  │
# │ 5   │ 4790     │ -0.2    │ -0.243192 │ -0.243426 │
# │ 6   │ 4798     │ -0.2    │ -0.190006 │ -0.190612 │
# │ 7   │ 4822     │ 0.2     │ 0.311903  │ 0.303838  │
# │ 8   │ 4832     │ -0.2    │ -0.235322 │ -0.230968 │
# │ 9   │ 4838     │ 0.2     │ 0.157542  │ 0.152408  │
# │ 10  │ 6022     │ 0.2     │ 0.15298   │ 0.156437  │
# │ 11  │ 6028     │ -0.2    │ -0.189872 │ -0.18722  │
# │ 12  │ 6035     │ 0.2     │ 0.232361  │ 0.233585  │
# │ 13  │ 6503     │ -0.2    │ -0.213992 │ -0.218123 │
# │ 14  │ 6509     │ 0.2     │ 0.179369  │ 0.185782  │
# │ 15  │ 6517     │ 0.2     │ 0.214686  │ 0.209606  │
# Grouped ran: 13 iters and Ungrouped ran: 22 iters
#
#
# running 94 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 2365     │ 0.2     │ 0.121587  │ 0.213773  │
# │ 2   │ 2371     │ 0.2     │ 0.189855  │ 0.171788  │
# │ 3   │ 2380     │ -0.2    │ 0.0       │ -0.190847 │
# │ 4   │ 3943     │ 0.2     │ 0.159691  │ 0.160607  │
# │ 5   │ 3947     │ 0.2     │ 0.218606  │ 0.204871  │
# │ 6   │ 3958     │ 0.2     │ 0.211887  │ 0.207979  │
# │ 7   │ 5445     │ -0.2    │ -0.166964 │ 0.0       │
# │ 8   │ 5454     │ 0.2     │ 0.178364  │ 0.0       │
# │ 9   │ 5458     │ 0.2     │ 0.197597  │ 0.162351  │
# │ 10  │ 9587     │ -0.2    │ -0.199813 │ -0.193209 │
# │ 11  │ 9597     │ 0.2     │ 0.198343  │ 0.198931  │
# │ 12  │ 9599     │ -0.2    │ -0.187976 │ -0.187809 │
# │ 13  │ 9803     │ 0.2     │ 0.204915  │ 0.221742  │
# │ 14  │ 9811     │ -0.2    │ -0.142875 │ -0.14905  │
# │ 15  │ 9816     │ -0.2    │ -0.227519 │ -0.231077 │
# Grouped ran: 26 iters and Ungrouped ran: 15 iters
#
#
# running 95 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 3069     │ 0.2     │ 0.239115  │ 0.239713  │
# │ 2   │ 3070     │ 0.2     │ 0.126328  │ 0.126228  │
# │ 3   │ 3076     │ 0.2     │ 0.0       │ 0.0       │
# │ 4   │ 4885     │ 0.2     │ 0.0       │ 0.0       │
# │ 5   │ 4891     │ 0.2     │ 0.0       │ 0.0       │
# │ 6   │ 4896     │ -0.2    │ 0.0       │ 0.0       │
# │ 7   │ 7623     │ 0.2     │ 0.212559  │ 0.210666  │
# │ 8   │ 7632     │ -0.2    │ -0.197878 │ -0.197705 │
# │ 9   │ 7638     │ -0.2    │ -0.210883 │ -0.221123 │
# │ 10  │ 7942     │ -0.2    │ -0.165948 │ -0.159806 │
# │ 11  │ 7944     │ -0.2    │ 0.0       │ 0.0       │
# │ 12  │ 7960     │ 0.2     │ 0.130241  │ 0.135661  │
# │ 13  │ 8223     │ 0.2     │ 0.1774    │ 0.184003  │
# │ 14  │ 8237     │ -0.2    │ -0.213082 │ -0.206556 │
# │ 15  │ 8240     │ 0.2     │ 0.196977  │ 0.195177  │
# Grouped ran: 31 iters and Ungrouped ran: 23 iters
#
#
# running 96 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 2104     │ -0.2    │ 0.0       │ 0.0       │
# │ 2   │ 2112     │ 0.2     │ 0.0       │ 0.0       │
# │ 3   │ 2115     │ 0.2     │ 0.129029  │ 0.201358  │
# │ 4   │ 2209     │ -0.2    │ -0.174368 │ -0.160287 │
# │ 5   │ 2211     │ 0.2     │ 0.219476  │ 0.219323  │
# │ 6   │ 2216     │ -0.2    │ -0.205427 │ -0.205446 │
# │ 7   │ 8985     │ -0.2    │ -0.187074 │ -0.190658 │
# │ 8   │ 8989     │ 0.2     │ 0.187689  │ 0.183671  │
# │ 9   │ 8995     │ 0.2     │ 0.179139  │ 0.186288  │
# │ 10  │ 9290     │ 0.2     │ 0.118181  │ 0.11584   │
# │ 11  │ 9294     │ 0.2     │ 0.0       │ 0.0       │
# │ 12  │ 9299     │ 0.2     │ 0.0       │ 0.0948    │
# │ 13  │ 9711     │ 0.2     │ 0.18302   │ 0.184897  │
# │ 14  │ 9712     │ 0.2     │ 0.143965  │ 0.142987  │
# │ 15  │ 9714     │ 0.2     │ 0.19133   │ 0.197129  │
# Grouped ran: 14 iters and Ungrouped ran: 23 iters
#
#
# running 97 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped    │
# │     │ Int64    │ Float64 │ Float64   │ Float64    │
# ├─────┼──────────┼─────────┼───────────┼────────────┤
# │ 1   │ 4987     │ 0.2     │ 0.0       │ 0.0        │
# │ 2   │ 4988     │ -0.2    │ 0.0       │ -0.0889646 │
# │ 3   │ 4998     │ 0.2     │ 0.327098  │ 0.265582   │
# │ 4   │ 6421     │ 0.2     │ 0.180783  │ 0.178294   │
# │ 5   │ 6435     │ -0.2    │ -0.192713 │ -0.205012  │
# │ 6   │ 6440     │ -0.2    │ -0.213147 │ -0.213333  │
# │ 7   │ 7822     │ 0.2     │ 0.211524  │ 0.21233    │
# │ 8   │ 7829     │ 0.2     │ 0.135099  │ 0.138402   │
# │ 9   │ 7840     │ 0.2     │ 0.219192  │ 0.22324    │
# │ 10  │ 9741     │ -0.2    │ -0.151471 │ -0.14669   │
# │ 11  │ 9749     │ -0.2    │ -0.169415 │ -0.156918  │
# │ 12  │ 9756     │ -0.2    │ 0.0       │ 0.0        │
# │ 13  │ 9988     │ -0.2    │ 0.0       │ 0.0        │
# │ 14  │ 9996     │ -0.2    │ -0.194027 │ -0.179636  │
# │ 15  │ 10000    │ 0.2     │ 0.203888  │ 0.207192   │
# Grouped ran: 18 iters and Ungrouped ran: 15 iters
#
#
# running 98 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 985      │ -0.2    │ -0.186605 │ -0.17909  │
# │ 2   │ 991      │ 0.2     │ 0.174918  │ 0.185444  │
# │ 3   │ 1000     │ -0.2    │ -0.206451 │ -0.174928 │
# │ 4   │ 3867     │ 0.2     │ 0.0       │ 0.179697  │
# │ 5   │ 3874     │ 0.2     │ 0.0       │ 0.159639  │
# │ 6   │ 3877     │ 0.2     │ 0.155342  │ 0.21209   │
# │ 7   │ 5425     │ -0.2    │ -0.318759 │ -0.188455 │
# │ 8   │ 5426     │ -0.2    │ 0.0       │ -0.118472 │
# │ 9   │ 5433     │ 0.2     │ 0.202226  │ 0.0       │
# │ 10  │ 5601     │ -0.2    │ -0.188897 │ -0.125298 │
# │ 11  │ 5604     │ -0.2    │ 0.0       │ 0.0       │
# │ 12  │ 5605     │ 0.2     │ 0.0       │ 0.0       │
# │ 13  │ 9043     │ 0.2     │ 0.191509  │ 0.197968  │
# │ 14  │ 9055     │ 0.2     │ 0.204177  │ 0.127598  │
# │ 15  │ 9057     │ 0.2     │ 0.198243  │ 0.0       │
# Grouped ran: 18 iters and Ungrouped ran: 18 iters
#
#
# running 99 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 902      │ -0.2    │ 0.0       │ -0.107792 │
# │ 2   │ 905      │ -0.2    │ -0.23646  │ -0.203844 │
# │ 3   │ 907      │ -0.2    │ -0.238401 │ -0.219578 │
# │ 4   │ 2123     │ 0.2     │ 0.167581  │ 0.172424  │
# │ 5   │ 2126     │ 0.2     │ 0.133541  │ 0.127988  │
# │ 6   │ 2132     │ 0.2     │ 0.211286  │ 0.224706  │
# │ 7   │ 4363     │ -0.2    │ 0.0       │ 0.0       │
# │ 8   │ 4370     │ -0.2    │ -0.182371 │ -0.197478 │
# │ 9   │ 4378     │ 0.2     │ 0.0       │ 0.128135  │
# │ 10  │ 5704     │ -0.2    │ -0.220468 │ -0.2106   │
# │ 11  │ 5705     │ -0.2    │ -0.144745 │ -0.148716 │
# │ 12  │ 5706     │ -0.2    │ -0.271288 │ -0.264255 │
# │ 13  │ 9681     │ -0.2    │ -0.213899 │ -0.217434 │
# │ 14  │ 9692     │ 0.2     │ 0.165221  │ 0.16657   │
# │ 15  │ 9699     │ -0.2    │ -0.217113 │ -0.223638 │
# Grouped ran: 13 iters and Ungrouped ran: 17 iters
#
#
# running 100 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 2605     │ 0.2     │ 0.0       │ 0.165334  │
# │ 2   │ 2607     │ -0.2    │ 0.0       │ 0.0       │
# │ 3   │ 2620     │ -0.2    │ -0.205131 │ -0.228676 │
# │ 4   │ 6881     │ 0.2     │ 0.259977  │ 0.253349  │
# │ 5   │ 6895     │ 0.2     │ 0.23893   │ 0.241568  │
# │ 6   │ 6896     │ -0.2    │ -0.224993 │ -0.223062 │
# │ 7   │ 8121     │ -0.2    │ -0.248264 │ -0.249404 │
# │ 8   │ 8131     │ -0.2    │ -0.239805 │ -0.244995 │
# │ 9   │ 8132     │ 0.2     │ 0.20145   │ 0.221915  │
# │ 10  │ 8511     │ -0.2    │ 0.0       │ -0.148781 │
# │ 11  │ 8513     │ -0.2    │ -0.236245 │ -0.184239 │
# │ 12  │ 8515     │ 0.2     │ 0.0       │ 0.132768  │
# │ 13  │ 9425     │ -0.2    │ -0.266611 │ -0.242058 │
# │ 14  │ 9436     │ -0.2    │ 0.0       │ 0.0       │
# │ 15  │ 9437     │ 0.2     │ 0.0       │ 0.0       │
# Grouped ran: 27 iters and Ungrouped ran: 17 iters
#
#
# Group IHT found: 1214.0/1500 variants, percentage = 0.8093333333333333
# Ungrouped IHT found: 1130.0/1500 variants, percentage = 0.7533333333333333
# Grouped common variant standard errors = 1.5892314386698263, percentage = 0.10594876257798842
# Ungrouped common variant standard errors = 1.992409839791244, percentage = 0.1328273226527496

# %% [markdown]
# # Logistic

# %%
Random.seed!(2019)
d = Bernoulli
l = canonicallink(d())

num_runs = 100
group_found = zeros(num_runs)
ungroup_found = zeros(num_runs)

for i in 1:num_runs
    println("running $i th model")
    gf, uf = compare(d, l)
    group_found[i] = gf
    ungroup_found[i] = uf
end

println("Group IHT found: ", sum(group_found), "/", 15num_runs, " variants", "percentage = ", sum(group_found)/15num_runs)
println("Ungrouped IHT found: ", sum(ungroup_found), "/", 15num_runs, " variants" , "percentage = ", sum(ungroup_found)/15num_runs)
println("Grouped common variant standard errors = ", std(group_found), "percentage = ", std(group_found)/15)
println("Ungrouped common variant standard errors = ", std(ungroup_found), "percentage = ", std(ungroup_found)/15)
# Out:
# running 1 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped    │
# │     │ Int64    │ Float64 │ Float64   │ Float64    │
# ├─────┼──────────┼─────────┼───────────┼────────────┤
# │ 1   │ 3464     │ -0.2    │ 0.0       │ 0.0        │
# │ 2   │ 3466     │ -0.2    │ -0.269934 │ 0.0        │
# │ 3   │ 3468     │ 0.2     │ 0.0       │ 0.0        │
# │ 4   │ 4924     │ -0.2    │ 0.0       │ -0.0855497 │
# │ 5   │ 4930     │ 0.2     │ 0.286553  │ 0.354747   │
# │ 6   │ 4938     │ 0.2     │ 0.405353  │ 0.402313   │
# │ 7   │ 5004     │ 0.2     │ 0.28868   │ 0.266985   │
# │ 8   │ 5016     │ -0.2    │ 0.0       │ 0.0        │
# │ 9   │ 5020     │ 0.2     │ 0.237608  │ 0.155275   │
# │ 10  │ 5081     │ -0.2    │ 0.0       │ 0.0        │
# │ 11  │ 5091     │ -0.2    │ 0.0       │ 0.0        │
# │ 12  │ 5098     │ 0.2     │ 0.0       │ 0.0        │
# │ 13  │ 7003     │ -0.2    │ 0.0       │ 0.0        │
# │ 14  │ 7007     │ -0.2    │ 0.0       │ 0.0        │
# │ 15  │ 7018     │ -0.2    │ -0.315956 │ -0.240724  │
# Grouped ran: 49 iters and Ungrouped ran: 13 iters
#
#
# running 2 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 148      │ 0.2     │ 0.477482  │ 0.230764  │
# │ 2   │ 150      │ 0.2     │ 0.0       │ 0.0       │
# │ 3   │ 153      │ -0.2    │ -0.235244 │ -0.30952  │
# │ 4   │ 4292     │ 0.2     │ 0.324951  │ 0.237452  │
# │ 5   │ 4293     │ -0.2    │ 0.0       │ 0.0       │
# │ 6   │ 4294     │ 0.2     │ 0.0       │ 0.0       │
# │ 7   │ 4989     │ 0.2     │ 0.0       │ 0.0       │
# │ 8   │ 4992     │ -0.2    │ 0.0       │ -0.371792 │
# │ 9   │ 4993     │ 0.2     │ 0.0       │ 0.315046  │
# │ 10  │ 8465     │ -0.2    │ 0.0       │ 0.0       │
# │ 11  │ 8475     │ 0.2     │ 0.0       │ 0.0       │
# │ 12  │ 8479     │ -0.2    │ 0.0       │ 0.0       │
# │ 13  │ 9442     │ -0.2    │ 0.0       │ 0.0       │
# │ 14  │ 9443     │ 0.2     │ 0.0       │ 0.0       │
# │ 15  │ 9457     │ -0.2    │ 0.0       │ 0.0       │
# Grouped ran: 35 iters and Ungrouped ran: 16 iters
#
#
# running 3 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 668      │ -0.2    │ 0.0       │ 0.0       │
# │ 2   │ 673      │ 0.2     │ 0.0       │ 0.0       │
# │ 3   │ 679      │ 0.2     │ 0.0       │ 0.0       │
# │ 4   │ 1270     │ -0.2    │ 0.0       │ -0.110908 │
# │ 5   │ 1277     │ 0.2     │ 0.24668   │ 0.282149  │
# │ 6   │ 1278     │ 0.2     │ 0.0       │ 0.0       │
# │ 7   │ 4161     │ 0.2     │ 0.357044  │ 0.220709  │
# │ 8   │ 4168     │ 0.2     │ 0.0       │ 0.0       │
# │ 9   │ 4173     │ 0.2     │ 0.0       │ 0.0938194 │
# │ 10  │ 5411     │ 0.2     │ 0.321169  │ 0.231322  │
# │ 11  │ 5413     │ 0.2     │ 0.27247   │ 0.179948  │
# │ 12  │ 5416     │ -0.2    │ -0.260423 │ 0.0       │
# │ 13  │ 5485     │ 0.2     │ 0.0       │ 0.0       │
# │ 14  │ 5496     │ -0.2    │ 0.0       │ 0.0       │
# │ 15  │ 5499     │ 0.2     │ 0.0       │ 0.0       │
# Grouped ran: 31 iters and Ungrouped ran: 25 iters
#
#
# running 4 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped    │
# │     │ Int64    │ Float64 │ Float64   │ Float64    │
# ├─────┼──────────┼─────────┼───────────┼────────────┤
# │ 1   │ 48       │ -0.2    │ -0.310489 │ -0.244743  │
# │ 2   │ 54       │ -0.2    │ 0.0       │ 0.0        │
# │ 3   │ 56       │ -0.2    │ 0.0       │ -0.234086  │
# │ 4   │ 166      │ -0.2    │ -0.228067 │ -0.168328  │
# │ 5   │ 168      │ -0.2    │ 0.0       │ 0.0        │
# │ 6   │ 175      │ 0.2     │ 0.0       │ 0.102316   │
# │ 7   │ 782      │ -0.2    │ -0.223257 │ -0.229069  │
# │ 8   │ 790      │ -0.2    │ 0.0       │ 0.0        │
# │ 9   │ 796      │ -0.2    │ 0.0       │ -0.0897526 │
# │ 10  │ 4327     │ -0.2    │ 0.0       │ 0.0        │
# │ 11  │ 4332     │ -0.2    │ 0.0       │ 0.0        │
# │ 12  │ 4338     │ 0.2     │ 0.0       │ 0.0        │
# │ 13  │ 7362     │ -0.2    │ 0.0       │ 0.0        │
# │ 14  │ 7363     │ 0.2     │ 0.0       │ 0.0        │
# │ 15  │ 7377     │ 0.2     │ 0.0       │ 0.0        │
# Grouped ran: 36 iters and Ungrouped ran: 13 iters
#
#
# running 5 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped    │
# │     │ Int64    │ Float64 │ Float64   │ Float64    │
# ├─────┼──────────┼─────────┼───────────┼────────────┤
# │ 1   │ 2542     │ 0.2     │ 0.0       │ 0.215189   │
# │ 2   │ 2547     │ -0.2    │ 0.0       │ 0.0        │
# │ 3   │ 2548     │ 0.2     │ 0.266619  │ 0.268355   │
# │ 4   │ 2844     │ -0.2    │ 0.0       │ 0.0        │
# │ 5   │ 2845     │ 0.2     │ 0.285883  │ 0.0        │
# │ 6   │ 2855     │ 0.2     │ 0.0       │ 0.0        │
# │ 7   │ 3885     │ -0.2    │ 0.0       │ -0.166928  │
# │ 8   │ 3895     │ -0.2    │ 0.0       │ -0.0590432 │
# │ 9   │ 3897     │ -0.2    │ -0.479423 │ -0.363919  │
# │ 10  │ 3983     │ -0.2    │ 0.0       │ 0.0        │
# │ 11  │ 3990     │ 0.2     │ 0.373473  │ 0.298244   │
# │ 12  │ 3992     │ 0.2     │ 0.0       │ 0.0        │
# │ 13  │ 5183     │ 0.2     │ 0.533657  │ 0.213122   │
# │ 14  │ 5186     │ 0.2     │ 0.0       │ 0.234813   │
# │ 15  │ 5190     │ 0.2     │ 0.0       │ 0.148247   │
# Grouped ran: 57 iters and Ungrouped ran: 31 iters
#
#
# running 6 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 4631     │ 0.2     │ 0.0       │ 0.176254  │
# │ 2   │ 4636     │ -0.2    │ 0.0       │ -0.189747 │
# │ 3   │ 4638     │ -0.2    │ 0.0       │ 0.0       │
# │ 4   │ 6730     │ -0.2    │ 0.0       │ -0.210039 │
# │ 5   │ 6739     │ -0.2    │ -0.394059 │ -0.360554 │
# │ 6   │ 6740     │ -0.2    │ 0.0       │ -0.134194 │
# │ 7   │ 7889     │ 0.2     │ 0.0       │ 0.232791  │
# │ 8   │ 7893     │ -0.2    │ -0.542006 │ -0.276893 │
# │ 9   │ 7898     │ 0.2     │ 0.258104  │ 0.0       │
# │ 10  │ 8409     │ 0.2     │ 0.0       │ 0.0       │
# │ 11  │ 8411     │ 0.2     │ 0.0       │ 0.0       │
# │ 12  │ 8413     │ 0.2     │ 0.0       │ 0.157807  │
# │ 13  │ 9524     │ -0.2    │ 0.0       │ 0.0       │
# │ 14  │ 9529     │ 0.2     │ 0.0       │ 0.0       │
# │ 15  │ 9530     │ -0.2    │ 0.0       │ 0.0       │
# Grouped ran: 29 iters and Ungrouped ran: 61 iters
#
#
# running 7 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 2241     │ -0.2    │ 0.0       │ -0.18904  │
# │ 2   │ 2246     │ -0.2    │ -0.292934 │ -0.229449 │
# │ 3   │ 2252     │ -0.2    │ 0.0       │ 0.0       │
# │ 4   │ 3345     │ -0.2    │ -0.4104   │ -0.297317 │
# │ 5   │ 3346     │ -0.2    │ 0.0       │ 0.0       │
# │ 6   │ 3357     │ -0.2    │ 0.0       │ -0.234491 │
# │ 7   │ 5381     │ -0.2    │ 0.0       │ 0.0       │
# │ 8   │ 5397     │ 0.2     │ 0.0       │ 0.284614  │
# │ 9   │ 5398     │ 0.2     │ 0.352281  │ 0.312944  │
# │ 10  │ 8086     │ 0.2     │ 0.0       │ 0.0       │
# │ 11  │ 8088     │ -0.2    │ 0.0       │ 0.0       │
# │ 12  │ 8100     │ -0.2    │ 0.0       │ 0.0       │
# │ 13  │ 9005     │ 0.2     │ 0.0       │ 0.104335  │
# │ 14  │ 9006     │ 0.2     │ 0.408276  │ 0.347908  │
# │ 15  │ 9011     │ -0.2    │ 0.0       │ 0.0       │
# Grouped ran: 38 iters and Ungrouped ran: 15 iters
#
#
# running 8 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 1642     │ -0.2    │ 0.0       │ -0.104778 │
# │ 2   │ 1649     │ -0.2    │ 0.0       │ 0.0       │
# │ 3   │ 1656     │ 0.2     │ 0.336423  │ 0.197596  │
# │ 4   │ 1762     │ 0.2     │ 0.0       │ 0.0       │
# │ 5   │ 1767     │ -0.2    │ 0.0       │ 0.0       │
# │ 6   │ 1774     │ 0.2     │ 0.276216  │ 0.0       │
# │ 7   │ 2001     │ 0.2     │ 0.0       │ 0.0       │
# │ 8   │ 2005     │ 0.2     │ 0.0       │ 0.0       │
# │ 9   │ 2019     │ 0.2     │ 0.0       │ 0.0       │
# │ 10  │ 8422     │ 0.2     │ 0.0       │ 0.0       │
# │ 11  │ 8437     │ -0.2    │ 0.0       │ 0.0       │
# │ 12  │ 8438     │ 0.2     │ 0.0       │ 0.0       │
# │ 13  │ 8941     │ 0.2     │ 0.0       │ 0.0       │
# │ 14  │ 8956     │ -0.2    │ 0.0       │ 0.0       │
# │ 15  │ 8958     │ 0.2     │ 0.0       │ 0.0       │
# Grouped ran: 35 iters and Ungrouped ran: 13 iters
#
#
# running 9 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 882      │ -0.2    │ 0.0       │ 0.0       │
# │ 2   │ 894      │ 0.2     │ 0.0       │ 0.0694786 │
# │ 3   │ 896      │ 0.2     │ 0.348651  │ 0.294796  │
# │ 4   │ 1166     │ 0.2     │ 0.0       │ 0.0       │
# │ 5   │ 1169     │ -0.2    │ 0.0       │ -0.135918 │
# │ 6   │ 1174     │ -0.2    │ -0.424959 │ -0.236302 │
# │ 7   │ 3663     │ 0.2     │ 0.0       │ 0.118414  │
# │ 8   │ 3678     │ 0.2     │ 0.0       │ 0.153027  │
# │ 9   │ 3679     │ -0.2    │ 0.0       │ 0.0       │
# │ 10  │ 5984     │ -0.2    │ 0.0       │ 0.0       │
# │ 11  │ 5988     │ 0.2     │ 0.0       │ 0.0       │
# │ 12  │ 5990     │ -0.2    │ 0.0       │ 0.0       │
# │ 13  │ 9108     │ -0.2    │ 0.0       │ 0.0       │
# │ 14  │ 9113     │ 0.2     │ 0.0       │ 0.0       │
# │ 15  │ 9120     │ 0.2     │ 0.330125  │ 0.214778  │
# Grouped ran: 61 iters and Ungrouped ran: 23 iters
#
#
# running 10 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 3501     │ 0.2     │ 0.0       │ 0.152837  │
# │ 2   │ 3514     │ -0.2    │ -0.272321 │ -0.239963 │
# │ 3   │ 3520     │ 0.2     │ 0.0       │ 0.0       │
# │ 4   │ 3747     │ -0.2    │ -0.297992 │ -0.163968 │
# │ 5   │ 3750     │ -0.2    │ -0.229215 │ -0.223369 │
# │ 6   │ 3756     │ 0.2     │ 0.0       │ 0.173623  │
# │ 7   │ 5242     │ -0.2    │ 0.0       │ 0.0       │
# │ 8   │ 5247     │ 0.2     │ 0.0       │ 0.0       │
# │ 9   │ 5250     │ 0.2     │ 0.0       │ 0.0       │
# │ 10  │ 7262     │ 0.2     │ 0.0       │ 0.124221  │
# │ 11  │ 7277     │ -0.2    │ 0.0       │ 0.0       │
# │ 12  │ 7278     │ 0.2     │ 0.0       │ 0.0       │
# │ 13  │ 7522     │ -0.2    │ -0.26991  │ -0.241947 │
# │ 14  │ 7523     │ -0.2    │ -0.266177 │ -0.173243 │
# │ 15  │ 7532     │ 0.2     │ 0.0       │ 0.0       │
# Grouped ran: 20 iters and Ungrouped ran: 16 iters
#
#
# running 11 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 984      │ -0.2    │ 0.0       │ 0.0       │
# │ 2   │ 985      │ 0.2     │ 0.0       │ 0.0       │
# │ 3   │ 997      │ 0.2     │ 0.350285  │ 0.505246  │
# │ 4   │ 1043     │ 0.2     │ 0.0       │ 0.0       │
# │ 5   │ 1050     │ 0.2     │ 0.0       │ 0.0       │
# │ 6   │ 1059     │ 0.2     │ 0.0       │ 0.0       │
# │ 7   │ 2125     │ 0.2     │ 0.0       │ 0.348769  │
# │ 8   │ 2130     │ 0.2     │ 0.0       │ 0.0       │
# │ 9   │ 2135     │ -0.2    │ -0.243127 │ -0.351272 │
# │ 10  │ 6043     │ -0.2    │ 0.0       │ 0.0       │
# │ 11  │ 6051     │ 0.2     │ 0.0       │ 0.0       │
# │ 12  │ 6055     │ 0.2     │ 0.0       │ 0.0       │
# │ 13  │ 9343     │ -0.2    │ 0.0       │ 0.0       │
# │ 14  │ 9355     │ -0.2    │ 0.0       │ 0.0       │
# │ 15  │ 9358     │ -0.2    │ 0.0       │ 0.0       │
# Grouped ran: 60 iters and Ungrouped ran: 18 iters
#
#
# running 12 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 1982     │ -0.2    │ -0.270664 │ -0.144802 │
# │ 2   │ 1992     │ 0.2     │ 0.0       │ 0.0919326 │
# │ 3   │ 2000     │ 0.2     │ 0.0       │ 0.0       │
# │ 4   │ 2601     │ -0.2    │ 0.0       │ 0.0       │
# │ 5   │ 2602     │ -0.2    │ -0.285567 │ -0.189454 │
# │ 6   │ 2610     │ -0.2    │ 0.0       │ 0.0       │
# │ 7   │ 3464     │ -0.2    │ 0.0       │ 0.0       │
# │ 8   │ 3477     │ 0.2     │ 0.0       │ 0.0       │
# │ 9   │ 3478     │ 0.2     │ 0.0       │ 0.0       │
# │ 10  │ 3882     │ 0.2     │ 0.0       │ 0.18836   │
# │ 11  │ 3891     │ -0.2    │ 0.0       │ 0.0       │
# │ 12  │ 3897     │ -0.2    │ -0.290101 │ -0.310009 │
# │ 13  │ 4110     │ 0.2     │ 0.0       │ 0.0       │
# │ 14  │ 4115     │ 0.2     │ 0.0       │ 0.0       │
# │ 15  │ 4119     │ 0.2     │ 0.0       │ 0.0       │
# Grouped ran: 32 iters and Ungrouped ran: 19 iters
#
#
# running 13 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 4662     │ 0.2     │ 0.0       │ 0.0       │
# │ 2   │ 4663     │ -0.2    │ 0.0       │ 0.0       │
# │ 3   │ 4669     │ 0.2     │ 0.0       │ 0.0       │
# │ 4   │ 5365     │ 0.2     │ 0.254711  │ 0.23134   │
# │ 5   │ 5369     │ 0.2     │ 0.0       │ 0.175134  │
# │ 6   │ 5377     │ -0.2    │ -0.334251 │ -0.296024 │
# │ 7   │ 8086     │ 0.2     │ 0.276461  │ 0.322087  │
# │ 8   │ 8092     │ 0.2     │ 0.260468  │ 0.203689  │
# │ 9   │ 8097     │ 0.2     │ 0.0       │ 0.0       │
# │ 10  │ 8162     │ -0.2    │ 0.0       │ -0.206545 │
# │ 11  │ 8169     │ -0.2    │ 0.0       │ 0.0       │
# │ 12  │ 8178     │ -0.2    │ -0.592169 │ -0.436545 │
# │ 13  │ 9023     │ 0.2     │ 0.364344  │ 0.289747  │
# │ 14  │ 9024     │ -0.2    │ -0.440373 │ -0.358648 │
# │ 15  │ 9034     │ 0.2     │ 0.0       │ 0.144151  │
# Grouped ran: 39 iters and Ungrouped ran: 24 iters
#
#
# running 14 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 3324     │ 0.2     │ 0.0       │ 0.189001  │
# │ 2   │ 3326     │ 0.2     │ 0.0       │ 0.0       │
# │ 3   │ 3330     │ 0.2     │ 0.0       │ 0.226054  │
# │ 4   │ 3708     │ -0.2    │ 0.0       │ 0.0       │
# │ 5   │ 3717     │ 0.2     │ 0.0       │ 0.0       │
# │ 6   │ 3720     │ 0.2     │ 0.0       │ 0.0       │
# │ 7   │ 4126     │ -0.2    │ 0.0       │ 0.0       │
# │ 8   │ 4137     │ 0.2     │ 0.0       │ 0.0       │
# │ 9   │ 4139     │ -0.2    │ 0.0       │ 0.0       │
# │ 10  │ 8864     │ 0.2     │ 0.35684   │ 0.374019  │
# │ 11  │ 8873     │ -0.2    │ 0.0       │ 0.0       │
# │ 12  │ 8874     │ 0.2     │ 0.0       │ 0.0       │
# │ 13  │ 9564     │ -0.2    │ -0.247052 │ -0.239913 │
# │ 14  │ 9567     │ 0.2     │ 0.0       │ 0.172627  │
# │ 15  │ 9570     │ 0.2     │ 0.358535  │ 0.316514  │
# Grouped ran: 29 iters and Ungrouped ran: 13 iters
#
#
# running 15 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 2502     │ -0.2    │ 0.0       │ -0.283742 │
# │ 2   │ 2511     │ -0.2    │ 0.0       │ 0.0       │
# │ 3   │ 2515     │ -0.2    │ -0.252148 │ -0.260321 │
# │ 4   │ 5083     │ 0.2     │ 0.0       │ 0.0       │
# │ 5   │ 5095     │ 0.2     │ 0.0       │ 0.0       │
# │ 6   │ 5099     │ -0.2    │ 0.0       │ 0.0       │
# │ 7   │ 7083     │ 0.2     │ 0.365306  │ 0.233636  │
# │ 8   │ 7092     │ -0.2    │ 0.0       │ -0.104696 │
# │ 9   │ 7093     │ 0.2     │ 0.0       │ 0.0       │
# │ 10  │ 9025     │ 0.2     │ 0.237216  │ 0.0       │
# │ 11  │ 9028     │ 0.2     │ 0.0       │ 0.176664  │
# │ 12  │ 9040     │ 0.2     │ 0.30376   │ 0.230365  │
# │ 13  │ 9863     │ 0.2     │ 0.0       │ 0.0       │
# │ 14  │ 9875     │ -0.2    │ 0.0       │ 0.0       │
# │ 15  │ 9877     │ 0.2     │ 0.0       │ 0.0       │
# Grouped ran: 40 iters and Ungrouped ran: 19 iters
#
#
# running 16 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 591      │ -0.2    │ 0.0       │ 0.0       │
# │ 2   │ 594      │ 0.2     │ 0.0       │ 0.263641  │
# │ 3   │ 596      │ -0.2    │ -0.216766 │ -0.204949 │
# │ 4   │ 2344     │ 0.2     │ 0.0       │ 0.0       │
# │ 5   │ 2355     │ -0.2    │ 0.0       │ 0.0       │
# │ 6   │ 2357     │ -0.2    │ 0.0       │ 0.0       │
# │ 7   │ 6221     │ -0.2    │ 0.0       │ 0.0       │
# │ 8   │ 6223     │ 0.2     │ 0.0       │ 0.0       │
# │ 9   │ 6228     │ 0.2     │ 0.0       │ 0.0       │
# │ 10  │ 8324     │ 0.2     │ 0.0       │ 0.0       │
# │ 11  │ 8333     │ -0.2    │ 0.0       │ 0.0       │
# │ 12  │ 8335     │ 0.2     │ 0.0       │ 0.0       │
# │ 13  │ 9163     │ 0.2     │ 0.0       │ 0.0       │
# │ 14  │ 9168     │ 0.2     │ 0.0       │ 0.0       │
# │ 15  │ 9174     │ 0.2     │ 0.0       │ 0.0       │
# Grouped ran: 38 iters and Ungrouped ran: 14 iters
#
#
# running 17 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 3062     │ 0.2     │ 0.0       │ 0.219413  │
# │ 2   │ 3072     │ -0.2    │ -0.349836 │ -0.252048 │
# │ 3   │ 3078     │ 0.2     │ 0.0       │ 0.0       │
# │ 4   │ 6021     │ -0.2    │ 0.0       │ 0.0       │
# │ 5   │ 6023     │ 0.2     │ 0.0       │ 0.0       │
# │ 6   │ 6037     │ -0.2    │ 0.0       │ 0.0       │
# │ 7   │ 7111     │ -0.2    │ 0.0       │ 0.0       │
# │ 8   │ 7112     │ 0.2     │ 0.0       │ 0.0       │
# │ 9   │ 7117     │ -0.2    │ 0.0       │ 0.0       │
# │ 10  │ 7241     │ -0.2    │ 0.0       │ 0.0       │
# │ 11  │ 7246     │ 0.2     │ 0.0       │ 0.0       │
# │ 12  │ 7256     │ -0.2    │ 0.0       │ 0.0       │
# │ 13  │ 8335     │ -0.2    │ 0.0       │ 0.0       │
# │ 14  │ 8336     │ -0.2    │ 0.0       │ 0.0       │
# │ 15  │ 8339     │ 0.2     │ 0.0       │ 0.0       │
# Grouped ran: 50 iters and Ungrouped ran: 15 iters
#
#
# running 18 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 281      │ 0.2     │ 0.0       │ 0.0       │
# │ 2   │ 287      │ 0.2     │ 0.0       │ 0.0       │
# │ 3   │ 296      │ -0.2    │ 0.0       │ 0.0       │
# │ 4   │ 2627     │ -0.2    │ 0.0       │ 0.0       │
# │ 5   │ 2629     │ -0.2    │ -0.298974 │ -0.165915 │
# │ 6   │ 2635     │ -0.2    │ 0.0       │ 0.0       │
# │ 7   │ 2787     │ 0.2     │ 0.0       │ 0.219872  │
# │ 8   │ 2798     │ 0.2     │ 0.452652  │ 0.260883  │
# │ 9   │ 2800     │ 0.2     │ 0.0       │ 0.222927  │
# │ 10  │ 5322     │ -0.2    │ 0.0       │ 0.0       │
# │ 11  │ 5324     │ 0.2     │ 0.0       │ 0.0       │
# │ 12  │ 5328     │ 0.2     │ 0.256886  │ 0.220074  │
# │ 13  │ 8602     │ -0.2    │ -0.273368 │ -0.242168 │
# │ 14  │ 8610     │ 0.2     │ 0.0       │ 0.0       │
# │ 15  │ 8612     │ -0.2    │ 0.0       │ 0.0       │
# Grouped ran: 42 iters and Ungrouped ran: 16 iters
#
#
# running 19 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 1385     │ -0.2    │ -0.336136 │ -0.215754 │
# │ 2   │ 1387     │ -0.2    │ 0.0       │ 0.0       │
# │ 3   │ 1389     │ 0.2     │ 0.0       │ 0.175641  │
# │ 4   │ 1745     │ -0.2    │ 0.0       │ 0.0       │
# │ 5   │ 1751     │ 0.2     │ 0.0       │ 0.0       │
# │ 6   │ 1752     │ -0.2    │ 0.0       │ 0.0       │
# │ 7   │ 1824     │ 0.2     │ 0.0       │ 0.0       │
# │ 8   │ 1827     │ -0.2    │ 0.0       │ 0.0       │
# │ 9   │ 1829     │ -0.2    │ 0.0       │ 0.0       │
# │ 10  │ 4721     │ -0.2    │ 0.0       │ -0.201863 │
# │ 11  │ 4727     │ 0.2     │ 0.0       │ 0.187065  │
# │ 12  │ 4736     │ 0.2     │ 0.320064  │ 0.254434  │
# │ 13  │ 6621     │ 0.2     │ 0.0       │ 0.137337  │
# │ 14  │ 6627     │ -0.2    │ 0.0       │ 0.0       │
# │ 15  │ 6634     │ -0.2    │ 0.0       │ -0.198648 │
# Grouped ran: 25 iters and Ungrouped ran: 17 iters
#
#
# running 20 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 444      │ 0.2     │ 0.0       │ 0.0       │
# │ 2   │ 453      │ -0.2    │ -0.27819  │ -0.21844  │
# │ 3   │ 456      │ 0.2     │ 0.0       │ 0.0       │
# │ 4   │ 562      │ 0.2     │ 0.0       │ 0.0       │
# │ 5   │ 569      │ 0.2     │ 0.0       │ 0.0       │
# │ 6   │ 576      │ -0.2    │ 0.0       │ 0.0       │
# │ 7   │ 1564     │ -0.2    │ 0.0       │ 0.0       │
# │ 8   │ 1567     │ 0.2     │ 0.0       │ 0.0       │
# │ 9   │ 1574     │ 0.2     │ 0.0       │ 0.0       │
# │ 10  │ 2126     │ -0.2    │ 0.0       │ 0.0       │
# │ 11  │ 2127     │ -0.2    │ -0.402807 │ -0.363432 │
# │ 12  │ 2129     │ 0.2     │ 0.0       │ 0.191024  │
# │ 13  │ 8547     │ 0.2     │ 0.0       │ 0.171447  │
# │ 14  │ 8548     │ -0.2    │ 0.0       │ -0.246856 │
# │ 15  │ 8559     │ -0.2    │ -0.336137 │ -0.281828 │
# Grouped ran: 50 iters and Ungrouped ran: 15 iters
#
#
# running 21 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 105      │ 0.2     │ 0.263508  │ 0.202777  │
# │ 2   │ 111      │ 0.2     │ 0.0       │ 0.0       │
# │ 3   │ 114      │ 0.2     │ 0.0       │ 0.0783813 │
# │ 4   │ 6647     │ 0.2     │ 0.0       │ 0.0       │
# │ 5   │ 6652     │ -0.2    │ -0.303444 │ 0.0       │
# │ 6   │ 6659     │ 0.2     │ 0.0       │ 0.0       │
# │ 7   │ 7281     │ 0.2     │ 0.269987  │ 0.250067  │
# │ 8   │ 7284     │ 0.2     │ 0.0       │ 0.191713  │
# │ 9   │ 7290     │ 0.2     │ 0.0       │ 0.165567  │
# │ 10  │ 7942     │ -0.2    │ 0.0       │ 0.0       │
# │ 11  │ 7951     │ 0.2     │ 0.0       │ 0.0       │
# │ 12  │ 7952     │ -0.2    │ 0.0       │ 0.0       │
# │ 13  │ 8682     │ 0.2     │ 0.0       │ 0.0       │
# │ 14  │ 8696     │ -0.2    │ 0.0       │ 0.0       │
# │ 15  │ 8699     │ -0.2    │ 0.0       │ 0.0       │
# Grouped ran: 52 iters and Ungrouped ran: 16 iters
#
#
# running 22 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 2084     │ -0.2    │ 0.0       │ -0.283056 │
# │ 2   │ 2093     │ -0.2    │ 0.0       │ 0.0       │
# │ 3   │ 2096     │ -0.2    │ -0.505012 │ -0.435802 │
# │ 4   │ 2604     │ 0.2     │ 0.467298  │ 0.376626  │
# │ 5   │ 2609     │ 0.2     │ 0.0       │ 0.191929  │
# │ 6   │ 2618     │ 0.2     │ 0.0       │ 0.0       │
# │ 7   │ 3743     │ -0.2    │ -0.449756 │ 0.0       │
# │ 8   │ 3749     │ -0.2    │ -0.395023 │ 0.0       │
# │ 9   │ 3754     │ -0.2    │ 0.0       │ 0.0       │
# │ 10  │ 4867     │ 0.2     │ 0.0       │ 0.196445  │
# │ 11  │ 4873     │ -0.2    │ -0.2873   │ -0.345791 │
# │ 12  │ 4874     │ -0.2    │ 0.0       │ 0.0       │
# │ 13  │ 8388     │ -0.2    │ -0.331138 │ -0.272756 │
# │ 14  │ 8391     │ 0.2     │ 0.0       │ 0.0       │
# │ 15  │ 8400     │ 0.2     │ 0.0       │ 0.231531  │
# Grouped ran: 21 iters and Ungrouped ran: 16 iters
#
#
# running 23 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 3245     │ 0.2     │ 0.0       │ 0.183387  │
# │ 2   │ 3254     │ -0.2    │ 0.0       │ -0.140075 │
# │ 3   │ 3259     │ -0.2    │ -0.268318 │ -0.254259 │
# │ 4   │ 3943     │ 0.2     │ 0.327131  │ 0.211568  │
# │ 5   │ 3956     │ -0.2    │ 0.0       │ -0.154464 │
# │ 6   │ 3960     │ 0.2     │ 0.0       │ 0.0       │
# │ 7   │ 4041     │ -0.2    │ 0.0       │ 0.0       │
# │ 8   │ 4042     │ 0.2     │ 0.0       │ 0.162902  │
# │ 9   │ 4052     │ 0.2     │ 0.310742  │ 0.290703  │
# │ 10  │ 4594     │ 0.2     │ 0.0       │ 0.0       │
# │ 11  │ 4597     │ 0.2     │ 0.0       │ 0.0       │
# │ 12  │ 4598     │ -0.2    │ 0.0       │ 0.0       │
# │ 13  │ 9901     │ 0.2     │ 0.0       │ 0.159613  │
# │ 14  │ 9909     │ 0.2     │ 0.349816  │ 0.267516  │
# │ 15  │ 9919     │ -0.2    │ 0.0       │ -0.148316 │
# Grouped ran: 35 iters and Ungrouped ran: 14 iters
#
#
# running 24 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 4826     │ 0.2     │ 0.0       │ 0.0       │
# │ 2   │ 4831     │ 0.2     │ 0.287979  │ 0.268856  │
# │ 3   │ 4835     │ -0.2    │ -0.23854  │ -0.22459  │
# │ 4   │ 5411     │ -0.2    │ -0.3102   │ -0.248601 │
# │ 5   │ 5416     │ 0.2     │ 0.0       │ 0.0       │
# │ 6   │ 5418     │ 0.2     │ 0.34818   │ 0.312307  │
# │ 7   │ 6784     │ 0.2     │ 0.292798  │ 0.326499  │
# │ 8   │ 6790     │ -0.2    │ 0.0       │ 0.0       │
# │ 9   │ 6791     │ 0.2     │ 0.0       │ 0.216201  │
# │ 10  │ 7982     │ -0.2    │ -0.298777 │ 0.0       │
# │ 11  │ 7983     │ 0.2     │ 0.0       │ 0.0       │
# │ 12  │ 7993     │ 0.2     │ 0.0       │ 0.0       │
# │ 13  │ 9013     │ 0.2     │ 0.0       │ 0.0       │
# │ 14  │ 9015     │ -0.2    │ 0.0       │ 0.0       │
# │ 15  │ 9018     │ -0.2    │ 0.0       │ 0.0       │
# Grouped ran: 36 iters and Ungrouped ran: 16 iters
#
#
# running 25 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 1462     │ 0.2     │ 0.349843  │ 0.277732  │
# │ 2   │ 1463     │ 0.2     │ 0.0       │ 0.0       │
# │ 3   │ 1478     │ -0.2    │ 0.0       │ -0.164626 │
# │ 4   │ 2647     │ 0.2     │ 0.346083  │ 0.213741  │
# │ 5   │ 2654     │ -0.2    │ 0.0       │ -0.105481 │
# │ 6   │ 2660     │ -0.2    │ 0.0       │ -0.244516 │
# │ 7   │ 3449     │ 0.2     │ 0.363358  │ 0.141145  │
# │ 8   │ 3450     │ 0.2     │ 0.0       │ 0.182605  │
# │ 9   │ 3453     │ -0.2    │ 0.0       │ 0.0       │
# │ 10  │ 4223     │ -0.2    │ 0.0       │ -0.233461 │
# │ 11  │ 4234     │ 0.2     │ 0.391946  │ 0.183988  │
# │ 12  │ 4238     │ -0.2    │ 0.0       │ 0.0       │
# │ 13  │ 5561     │ -0.2    │ 0.0       │ 0.0       │
# │ 14  │ 5563     │ 0.2     │ 0.0       │ 0.0       │
# │ 15  │ 5576     │ 0.2     │ 0.0       │ 0.0       │
# Grouped ran: 75 iters and Ungrouped ran: 23 iters
#
#
# running 26 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 3581     │ -0.2    │ 0.0       │ 0.0       │
# │ 2   │ 3582     │ 0.2     │ 0.244801  │ 0.202035  │
# │ 3   │ 3590     │ 0.2     │ 0.0       │ 0.0862625 │
# │ 4   │ 5142     │ 0.2     │ 0.271468  │ 0.183654  │
# │ 5   │ 5149     │ -0.2    │ 0.0       │ 0.0       │
# │ 6   │ 5150     │ 0.2     │ 0.0       │ 0.0       │
# │ 7   │ 5550     │ -0.2    │ -0.253778 │ -0.241115 │
# │ 8   │ 5551     │ 0.2     │ 0.0       │ 0.0       │
# │ 9   │ 5557     │ 0.2     │ 0.234186  │ 0.24731   │
# │ 10  │ 6810     │ 0.2     │ 0.0       │ 0.0       │
# │ 11  │ 6819     │ 0.2     │ 0.0       │ 0.0       │
# │ 12  │ 6820     │ -0.2    │ 0.0       │ 0.0       │
# │ 13  │ 8592     │ -0.2    │ -0.291704 │ -0.296333 │
# │ 14  │ 8597     │ 0.2     │ 0.357818  │ 0.286276  │
# │ 15  │ 8599     │ 0.2     │ 0.0       │ 0.0       │
# Grouped ran: 22 iters and Ungrouped ran: 13 iters
#
#
# running 27 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 1763     │ -0.2    │ 0.0       │ 0.0       │
# │ 2   │ 1769     │ 0.2     │ 0.0       │ 0.0       │
# │ 3   │ 1779     │ 0.2     │ 0.0       │ 0.0       │
# │ 4   │ 4051     │ 0.2     │ 0.0       │ 0.0       │
# │ 5   │ 4053     │ 0.2     │ 0.0       │ 0.0       │
# │ 6   │ 4056     │ 0.2     │ 0.435761  │ 0.317058  │
# │ 7   │ 7853     │ 0.2     │ 0.0       │ 0.0       │
# │ 8   │ 7855     │ -0.2    │ 0.0       │ -0.123343 │
# │ 9   │ 7858     │ 0.2     │ 0.0       │ 0.0       │
# │ 10  │ 7874     │ -0.2    │ 0.0       │ 0.0       │
# │ 11  │ 7875     │ 0.2     │ 0.0       │ 0.0       │
# │ 12  │ 7877     │ -0.2    │ -0.24057  │ 0.0       │
# │ 13  │ 8462     │ 0.2     │ 0.29235   │ 0.290049  │
# │ 14  │ 8470     │ -0.2    │ 0.0       │ -0.193076 │
# │ 15  │ 8475     │ 0.2     │ 0.0       │ 0.0869366 │
# Grouped ran: 33 iters and Ungrouped ran: 15 iters
#
#
# running 28 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped    │
# │     │ Int64    │ Float64 │ Float64   │ Float64    │
# ├─────┼──────────┼─────────┼───────────┼────────────┤
# │ 1   │ 866      │ 0.2     │ 0.0       │ 0.112191   │
# │ 2   │ 867      │ 0.2     │ 0.403228  │ 0.272276   │
# │ 3   │ 877      │ 0.2     │ 0.0       │ 0.0        │
# │ 4   │ 2463     │ -0.2    │ -0.320527 │ -0.289776  │
# │ 5   │ 2465     │ 0.2     │ 0.225076  │ 0.205824   │
# │ 6   │ 2467     │ 0.2     │ 0.245742  │ 0.255513   │
# │ 7   │ 3942     │ 0.2     │ 0.0       │ 0.0618193  │
# │ 8   │ 3944     │ 0.2     │ 0.0       │ 0.0        │
# │ 9   │ 3946     │ 0.2     │ 0.278333  │ 0.271304   │
# │ 10  │ 4322     │ -0.2    │ -0.234017 │ -0.191064  │
# │ 11  │ 4327     │ 0.2     │ 0.0       │ 0.123087   │
# │ 12  │ 4337     │ 0.2     │ 0.291815  │ 0.25976    │
# │ 13  │ 4945     │ -0.2    │ 0.0       │ -0.0847635 │
# │ 14  │ 4950     │ -0.2    │ 0.0       │ 0.0        │
# │ 15  │ 4951     │ 0.2     │ 0.0       │ 0.0        │
# Grouped ran: 39 iters and Ungrouped ran: 15 iters
#
#
# running 29 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped  │
# │     │ Int64    │ Float64 │ Float64   │ Float64  │
# ├─────┼──────────┼─────────┼───────────┼──────────┤
# │ 1   │ 1841     │ 0.2     │ 0.0       │ 0.0      │
# │ 2   │ 1853     │ -0.2    │ 0.0       │ 0.0      │
# │ 3   │ 1856     │ -0.2    │ 0.0       │ 0.0      │
# │ 4   │ 3623     │ -0.2    │ 0.0       │ 0.0      │
# │ 5   │ 3627     │ -0.2    │ 0.0       │ 0.0      │
# │ 6   │ 3629     │ 0.2     │ 0.0       │ 0.0      │
# │ 7   │ 7847     │ -0.2    │ 0.0       │ 0.0      │
# │ 8   │ 7852     │ 0.2     │ 0.479561  │ 0.394901 │
# │ 9   │ 7859     │ -0.2    │ 0.0       │ 0.0      │
# │ 10  │ 8384     │ 0.2     │ 0.407458  │ 0.307295 │
# │ 11  │ 8385     │ 0.2     │ 0.0       │ 0.0      │
# │ 12  │ 8391     │ 0.2     │ 0.0       │ 0.0      │
# │ 13  │ 8828     │ 0.2     │ 0.0       │ 0.0      │
# │ 14  │ 8838     │ 0.2     │ 0.0       │ 0.0      │
# │ 15  │ 8839     │ -0.2    │ 0.0       │ 0.0      │
# Grouped ran: 39 iters and Ungrouped ran: 14 iters
#
#
# running 30 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped  │
# │     │ Int64    │ Float64 │ Float64   │ Float64  │
# ├─────┼──────────┼─────────┼───────────┼──────────┤
# │ 1   │ 1202     │ 0.2     │ 0.322093  │ 0.242541 │
# │ 2   │ 1209     │ -0.2    │ 0.0       │ 0.0      │
# │ 3   │ 1219     │ 0.2     │ 0.0       │ 0.190811 │
# │ 4   │ 1627     │ 0.2     │ 0.0       │ 0.110438 │
# │ 5   │ 1629     │ 0.2     │ 0.0       │ 0.173443 │
# │ 6   │ 1635     │ -0.2    │ 0.0       │ 0.0      │
# │ 7   │ 4141     │ -0.2    │ 0.0       │ 0.0      │
# │ 8   │ 4144     │ 0.2     │ 0.0       │ 0.0      │
# │ 9   │ 4148     │ 0.2     │ 0.0       │ 0.12483  │
# │ 10  │ 4205     │ 0.2     │ 0.0       │ 0.118778 │
# │ 11  │ 4208     │ 0.2     │ 0.0       │ 0.0      │
# │ 12  │ 4214     │ 0.2     │ 0.30278   │ 0.288142 │
# │ 13  │ 7890     │ 0.2     │ 0.0       │ 0.0      │
# │ 14  │ 7897     │ 0.2     │ 0.0       │ 0.0      │
# │ 15  │ 7899     │ -0.2    │ 0.0       │ 0.0      │
# Grouped ran: 29 iters and Ungrouped ran: 23 iters
#
#
# running 31 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped  │
# │     │ Int64    │ Float64 │ Float64   │ Float64  │
# ├─────┼──────────┼─────────┼───────────┼──────────┤
# │ 1   │ 921      │ 0.2     │ 0.0       │ 0.0      │
# │ 2   │ 929      │ -0.2    │ 0.0       │ 0.0      │
# │ 3   │ 933      │ -0.2    │ 0.0       │ 0.0      │
# │ 4   │ 2466     │ 0.2     │ 0.0       │ 0.0      │
# │ 5   │ 2467     │ -0.2    │ 0.0       │ 0.0      │
# │ 6   │ 2469     │ -0.2    │ 0.0       │ 0.0      │
# │ 7   │ 2527     │ -0.2    │ 0.0       │ -0.23391 │
# │ 8   │ 2528     │ -0.2    │ 0.0       │ 0.0      │
# │ 9   │ 2531     │ -0.2    │ 0.0       │ 0.0      │
# │ 10  │ 4270     │ 0.2     │ 0.0       │ 0.0      │
# │ 11  │ 4271     │ -0.2    │ 0.0       │ 0.0      │
# │ 12  │ 4280     │ 0.2     │ 0.0       │ 0.130928 │
# │ 13  │ 7942     │ 0.2     │ 0.0       │ 0.145007 │
# │ 14  │ 7943     │ 0.2     │ 0.388818  │ 0.421272 │
# │ 15  │ 7951     │ 0.2     │ 0.0       │ 0.0      │
# Grouped ran: 50 iters and Ungrouped ran: 32 iters
#
#
# running 32 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 5602     │ 0.2     │ 0.0       │ 0.0       │
# │ 2   │ 5603     │ -0.2    │ 0.0       │ -0.124082 │
# │ 3   │ 5604     │ -0.2    │ -0.426846 │ -0.337748 │
# │ 4   │ 6725     │ 0.2     │ 0.0       │ 0.0       │
# │ 5   │ 6727     │ 0.2     │ 0.0       │ 0.148935  │
# │ 6   │ 6738     │ -0.2    │ 0.0       │ 0.0       │
# │ 7   │ 7543     │ 0.2     │ 0.387506  │ 0.27446   │
# │ 8   │ 7546     │ 0.2     │ 0.0       │ 0.216034  │
# │ 9   │ 7549     │ -0.2    │ 0.0       │ 0.0       │
# │ 10  │ 8783     │ 0.2     │ 0.0       │ 0.251453  │
# │ 11  │ 8794     │ -0.2    │ 0.0       │ 0.0       │
# │ 12  │ 8795     │ -0.2    │ -0.411887 │ -0.247875 │
# │ 13  │ 9790     │ -0.2    │ 0.0       │ 0.0       │
# │ 14  │ 9793     │ 0.2     │ 0.0       │ 0.0       │
# │ 15  │ 9796     │ -0.2    │ 0.0       │ 0.0       │
# Grouped ran: 55 iters and Ungrouped ran: 25 iters
#
#
# running 33 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 3485     │ 0.2     │ 0.0       │ 0.0       │
# │ 2   │ 3491     │ 0.2     │ 0.0       │ 0.0       │
# │ 3   │ 3498     │ -0.2    │ 0.0       │ 0.0       │
# │ 4   │ 4205     │ 0.2     │ 0.0       │ 0.0       │
# │ 5   │ 4209     │ 0.2     │ 0.398783  │ 0.38108   │
# │ 6   │ 4211     │ -0.2    │ -0.402732 │ -0.39034  │
# │ 7   │ 5191     │ -0.2    │ -0.298022 │ -0.237583 │
# │ 8   │ 5193     │ -0.2    │ 0.0       │ 0.0       │
# │ 9   │ 5194     │ 0.2     │ 0.0       │ 0.0       │
# │ 10  │ 9652     │ -0.2    │ 0.0       │ 0.0       │
# │ 11  │ 9654     │ 0.2     │ 0.217125  │ 0.209674  │
# │ 12  │ 9657     │ -0.2    │ 0.0       │ 0.0       │
# │ 13  │ 9722     │ 0.2     │ 0.0       │ 0.0       │
# │ 14  │ 9735     │ -0.2    │ 0.0       │ 0.0       │
# │ 15  │ 9736     │ 0.2     │ 0.0       │ 0.0       │
# Grouped ran: 20 iters and Ungrouped ran: 14 iters
#
#
# running 34 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 1474     │ -0.2    │ 0.0       │ 0.0       │
# │ 2   │ 1476     │ -0.2    │ 0.0       │ -0.284044 │
# │ 3   │ 1478     │ -0.2    │ 0.0       │ 0.0       │
# │ 4   │ 1652     │ -0.2    │ 0.0       │ -0.118583 │
# │ 5   │ 1658     │ 0.2     │ 0.0       │ 0.0       │
# │ 6   │ 1660     │ -0.2    │ 0.0       │ -0.173274 │
# │ 7   │ 6411     │ 0.2     │ 0.0       │ 0.0       │
# │ 8   │ 6415     │ 0.2     │ 0.0       │ 0.0       │
# │ 9   │ 6420     │ -0.2    │ 0.0       │ 0.0       │
# │ 10  │ 6647     │ 0.2     │ 0.0       │ 0.0       │
# │ 11  │ 6652     │ 0.2     │ 0.0       │ 0.0       │
# │ 12  │ 6660     │ -0.2    │ 0.0       │ 0.0       │
# │ 13  │ 8501     │ 0.2     │ 0.0       │ 0.0       │
# │ 14  │ 8505     │ -0.2    │ 0.0       │ 0.0       │
# │ 15  │ 8519     │ -0.2    │ -0.366368 │ -0.252363 │
# Grouped ran: 65 iters and Ungrouped ran: 17 iters
#
#
# running 35 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 147      │ 0.2     │ 0.0       │ 0.0       │
# │ 2   │ 150      │ -0.2    │ 0.0       │ 0.0       │
# │ 3   │ 154      │ 0.2     │ 0.0       │ 0.0       │
# │ 4   │ 3690     │ 0.2     │ 0.232114  │ 0.223415  │
# │ 5   │ 3696     │ -0.2    │ -0.291477 │ -0.252952 │
# │ 6   │ 3700     │ -0.2    │ 0.0       │ -0.14709  │
# │ 7   │ 7002     │ -0.2    │ 0.0       │ 0.0       │
# │ 8   │ 7012     │ 0.2     │ 0.0       │ 0.0       │
# │ 9   │ 7017     │ -0.2    │ -0.309708 │ -0.369104 │
# │ 10  │ 7827     │ -0.2    │ 0.0       │ -0.223807 │
# │ 11  │ 7831     │ -0.2    │ 0.0       │ 0.0       │
# │ 12  │ 7834     │ -0.2    │ 0.0       │ 0.0       │
# │ 13  │ 9041     │ -0.2    │ 0.0       │ 0.0       │
# │ 14  │ 9046     │ 0.2     │ 0.0       │ 0.0       │
# │ 15  │ 9050     │ 0.2     │ 0.0       │ 0.0       │
# Grouped ran: 44 iters and Ungrouped ran: 11 iters
#
#
# running 36 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped  │
# │     │ Int64    │ Float64 │ Float64   │ Float64  │
# ├─────┼──────────┼─────────┼───────────┼──────────┤
# │ 1   │ 727      │ 0.2     │ 0.0       │ 0.0      │
# │ 2   │ 731      │ -0.2    │ 0.0       │ 0.0      │
# │ 3   │ 733      │ 0.2     │ 0.0       │ 0.0      │
# │ 4   │ 4221     │ 0.2     │ 0.0       │ 0.0      │
# │ 5   │ 4223     │ -0.2    │ 0.0       │ 0.0      │
# │ 6   │ 4234     │ -0.2    │ 0.0       │ 0.0      │
# │ 7   │ 4265     │ 0.2     │ 0.521326  │ 0.268362 │
# │ 8   │ 4273     │ 0.2     │ 0.0       │ 0.0      │
# │ 9   │ 4275     │ 0.2     │ 0.0       │ 0.178262 │
# │ 10  │ 4881     │ 0.2     │ 0.0       │ 0.0      │
# │ 11  │ 4882     │ -0.2    │ 0.0       │ 0.0      │
# │ 12  │ 4884     │ -0.2    │ 0.0       │ 0.0      │
# │ 13  │ 6832     │ 0.2     │ 0.28659   │ 0.249483 │
# │ 14  │ 6836     │ -0.2    │ 0.0       │ 0.0      │
# │ 15  │ 6837     │ 0.2     │ 0.0       │ 0.0      │
# Grouped ran: 52 iters and Ungrouped ran: 22 iters
#
#
# running 37 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 967      │ -0.2    │ -0.363514 │ -0.349706 │
# │ 2   │ 973      │ -0.2    │ 0.0       │ 0.0       │
# │ 3   │ 974      │ -0.2    │ -0.532534 │ -0.497    │
# │ 4   │ 2142     │ 0.2     │ 0.0       │ 0.210486  │
# │ 5   │ 2149     │ 0.2     │ 0.0       │ 0.407697  │
# │ 6   │ 2151     │ -0.2    │ 0.0       │ -0.346038 │
# │ 7   │ 3022     │ -0.2    │ -0.36024  │ -0.359278 │
# │ 8   │ 3028     │ 0.2     │ 0.0       │ 0.0       │
# │ 9   │ 3038     │ -0.2    │ 0.0       │ -0.226523 │
# │ 10  │ 8584     │ -0.2    │ 0.0       │ -0.171617 │
# │ 11  │ 8585     │ -0.2    │ -0.466645 │ -0.270114 │
# │ 12  │ 8591     │ 0.2     │ 0.0       │ 0.0       │
# │ 13  │ 9585     │ -0.2    │ 0.0       │ 0.0       │
# │ 14  │ 9587     │ 0.2     │ 0.33633   │ 0.303676  │
# │ 15  │ 9591     │ -0.2    │ 0.0       │ -0.167875 │
# Grouped ran: 32 iters and Ungrouped ran: 23 iters
#
#
# running 38 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 6345     │ -0.2    │ 0.0       │ 0.0       │
# │ 2   │ 6353     │ 0.2     │ 0.0       │ 0.0       │
# │ 3   │ 6358     │ -0.2    │ 0.0       │ 0.0       │
# │ 4   │ 8206     │ 0.2     │ 0.0       │ 0.0       │
# │ 5   │ 8209     │ 0.2     │ 0.418021  │ 0.303525  │
# │ 6   │ 8218     │ 0.2     │ 0.0       │ 0.170327  │
# │ 7   │ 9295     │ -0.2    │ 0.0       │ -0.350182 │
# │ 8   │ 9296     │ -0.2    │ -0.446359 │ 0.0       │
# │ 9   │ 9299     │ -0.2    │ -0.31613  │ -0.164588 │
# │ 10  │ 9343     │ -0.2    │ 0.0       │ -0.152025 │
# │ 11  │ 9353     │ -0.2    │ -0.267464 │ -0.250831 │
# │ 12  │ 9358     │ -0.2    │ 0.0       │ -0.124572 │
# │ 13  │ 9787     │ -0.2    │ 0.0       │ 0.0       │
# │ 14  │ 9792     │ 0.2     │ 0.575942  │ 0.26013   │
# │ 15  │ 9795     │ -0.2    │ 0.0       │ 0.0       │
# Grouped ran: 64 iters and Ungrouped ran: 18 iters
#
#
# running 39 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 741      │ -0.2    │ -0.254088 │ -0.207385 │
# │ 2   │ 745      │ 0.2     │ 0.0       │ 0.0970534 │
# │ 3   │ 756      │ 0.2     │ 0.0       │ 0.0       │
# │ 4   │ 3591     │ -0.2    │ 0.0       │ 0.0       │
# │ 5   │ 3595     │ -0.2    │ -0.355787 │ -0.160744 │
# │ 6   │ 3596     │ -0.2    │ 0.0       │ 0.0       │
# │ 7   │ 5308     │ 0.2     │ 0.0       │ 0.273482  │
# │ 8   │ 5310     │ -0.2    │ -0.268517 │ -0.273719 │
# │ 9   │ 5314     │ 0.2     │ 0.0       │ 0.206907  │
# │ 10  │ 5914     │ -0.2    │ 0.0       │ 0.0       │
# │ 11  │ 5916     │ -0.2    │ 0.0       │ 0.0       │
# │ 12  │ 5918     │ -0.2    │ 0.0       │ 0.0       │
# │ 13  │ 6791     │ -0.2    │ 0.0       │ 0.0       │
# │ 14  │ 6794     │ -0.2    │ 0.0       │ 0.0       │
# │ 15  │ 6799     │ 0.2     │ 0.0       │ 0.0       │
# Grouped ran: 32 iters and Ungrouped ran: 13 iters
#
#
# running 40 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 2106     │ 0.2     │ 0.0       │ 0.0       │
# │ 2   │ 2115     │ -0.2    │ 0.0       │ 0.0       │
# │ 3   │ 2118     │ 0.2     │ 0.0       │ 0.0       │
# │ 4   │ 5208     │ 0.2     │ 0.0       │ 0.0       │
# │ 5   │ 5216     │ -0.2    │ 0.0       │ -0.136343 │
# │ 6   │ 5220     │ 0.2     │ 0.0       │ 0.0       │
# │ 7   │ 7141     │ -0.2    │ 0.0       │ 0.0       │
# │ 8   │ 7142     │ 0.2     │ 0.0       │ 0.0       │
# │ 9   │ 7150     │ -0.2    │ 0.0       │ -0.104925 │
# │ 10  │ 8286     │ 0.2     │ 0.0       │ 0.0       │
# │ 11  │ 8298     │ 0.2     │ 0.0       │ 0.0       │
# │ 12  │ 8299     │ -0.2    │ 0.0       │ 0.0       │
# │ 13  │ 9850     │ -0.2    │ 0.0       │ 0.0       │
# │ 14  │ 9854     │ 0.2     │ 0.0       │ 0.0       │
# │ 15  │ 9859     │ -0.2    │ 0.0       │ 0.0       │
# Grouped ran: 35 iters and Ungrouped ran: 20 iters
#
#
# running 41 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 1063     │ 0.2     │ 0.0       │ 0.0       │
# │ 2   │ 1067     │ -0.2    │ 0.0       │ -0.186378 │
# │ 3   │ 1068     │ -0.2    │ -0.381575 │ -0.265056 │
# │ 4   │ 1262     │ 0.2     │ 0.0       │ 0.0       │
# │ 5   │ 1267     │ 0.2     │ 0.0       │ 0.162498  │
# │ 6   │ 1280     │ 0.2     │ 0.0       │ 0.175803  │
# │ 7   │ 1948     │ -0.2    │ 0.0       │ -0.168494 │
# │ 8   │ 1957     │ 0.2     │ 0.0       │ 0.216963  │
# │ 9   │ 1959     │ 0.2     │ 0.0       │ 0.0       │
# │ 10  │ 2385     │ 0.2     │ 0.0       │ 0.0       │
# │ 11  │ 2396     │ -0.2    │ 0.0       │ -0.291137 │
# │ 12  │ 2398     │ -0.2    │ -0.35349  │ -0.240712 │
# │ 13  │ 7187     │ 0.2     │ 0.0       │ 0.173638  │
# │ 14  │ 7191     │ -0.2    │ 0.0       │ -0.236096 │
# │ 15  │ 7193     │ -0.2    │ -0.412299 │ -0.383625 │
# Grouped ran: 25 iters and Ungrouped ran: 19 iters
#
#
# running 42 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 3646     │ 0.2     │ 0.0       │ 0.0       │
# │ 2   │ 3649     │ -0.2    │ 0.0       │ 0.0       │
# │ 3   │ 3659     │ -0.2    │ 0.0       │ 0.0       │
# │ 4   │ 6235     │ -0.2    │ -0.401641 │ -0.235067 │
# │ 5   │ 6237     │ -0.2    │ 0.0       │ -0.344439 │
# │ 6   │ 6239     │ 0.2     │ 0.0       │ 0.21621   │
# │ 7   │ 6962     │ 0.2     │ 0.0       │ 0.0       │
# │ 8   │ 6963     │ -0.2    │ 0.0       │ 0.0       │
# │ 9   │ 6967     │ 0.2     │ 0.0       │ 0.0       │
# │ 10  │ 7051     │ -0.2    │ -0.44565  │ -0.269607 │
# │ 11  │ 7059     │ -0.2    │ 0.0       │ 0.0       │
# │ 12  │ 7060     │ -0.2    │ 0.0       │ -0.169944 │
# │ 13  │ 9569     │ 0.2     │ 0.0       │ 0.0       │
# │ 14  │ 9573     │ 0.2     │ 0.0       │ 0.212844  │
# │ 15  │ 9576     │ -0.2    │ -0.314267 │ -0.247208 │
# Grouped ran: 36 iters and Ungrouped ran: 20 iters
#
#
# running 43 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 2901     │ -0.2    │ -0.373973 │ 0.0       │
# │ 2   │ 2914     │ -0.2    │ -0.541363 │ -0.402077 │
# │ 3   │ 2916     │ -0.2    │ 0.0       │ 0.0       │
# │ 4   │ 6532     │ -0.2    │ 0.0       │ 0.0       │
# │ 5   │ 6534     │ 0.2     │ 0.0       │ 0.0       │
# │ 6   │ 6539     │ 0.2     │ 0.330024  │ 0.331046  │
# │ 7   │ 6682     │ -0.2    │ 0.0       │ -0.234738 │
# │ 8   │ 6694     │ -0.2    │ 0.0       │ -0.235991 │
# │ 9   │ 6697     │ 0.2     │ 0.307509  │ 0.320814  │
# │ 10  │ 8370     │ 0.2     │ 0.0       │ 0.0       │
# │ 11  │ 8377     │ 0.2     │ 0.0       │ 0.0       │
# │ 12  │ 8380     │ 0.2     │ 0.0       │ 0.0       │
# │ 13  │ 9145     │ 0.2     │ 0.0       │ 0.160137  │
# │ 14  │ 9148     │ -0.2    │ 0.0       │ 0.0       │
# │ 15  │ 9155     │ 0.2     │ 0.31278   │ 0.247716  │
# Grouped ran: 29 iters and Ungrouped ran: 19 iters
#
#
# running 44 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 404      │ 0.2     │ 0.0       │ 0.0       │
# │ 2   │ 406      │ 0.2     │ 0.0       │ 0.158006  │
# │ 3   │ 415      │ 0.2     │ 0.0       │ 0.181523  │
# │ 4   │ 2708     │ 0.2     │ 0.0       │ 0.0       │
# │ 5   │ 2711     │ 0.2     │ 0.0       │ 0.0       │
# │ 6   │ 2714     │ -0.2    │ -0.238328 │ 0.0       │
# │ 7   │ 3487     │ -0.2    │ 0.0       │ 0.0       │
# │ 8   │ 3489     │ -0.2    │ 0.0       │ -0.163879 │
# │ 9   │ 3498     │ -0.2    │ -0.383316 │ -0.248958 │
# │ 10  │ 4007     │ -0.2    │ 0.0       │ -0.212983 │
# │ 11  │ 4009     │ -0.2    │ 0.0       │ 0.0       │
# │ 12  │ 4020     │ 0.2     │ 0.0       │ 0.0       │
# │ 13  │ 6252     │ -0.2    │ -0.354298 │ 0.0       │
# │ 14  │ 6254     │ -0.2    │ 0.0       │ 0.0       │
# │ 15  │ 6257     │ 0.2     │ 0.0       │ 0.0       │
# Grouped ran: 28 iters and Ungrouped ran: 25 iters
#
#
# running 45 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 265      │ -0.2    │ 0.0       │ 0.0       │
# │ 2   │ 266      │ -0.2    │ 0.0       │ 0.0       │
# │ 3   │ 280      │ 0.2     │ 0.0       │ 0.0       │
# │ 4   │ 982      │ -0.2    │ -0.411017 │ -0.327355 │
# │ 5   │ 987      │ 0.2     │ 0.0       │ 0.243566  │
# │ 6   │ 995      │ -0.2    │ 0.0       │ -0.249441 │
# │ 7   │ 7169     │ 0.2     │ 0.0       │ 0.232507  │
# │ 8   │ 7170     │ -0.2    │ 0.0       │ -0.33804  │
# │ 9   │ 7178     │ -0.2    │ -0.206678 │ -0.322376 │
# │ 10  │ 7487     │ 0.2     │ 0.0       │ 0.0       │
# │ 11  │ 7489     │ -0.2    │ 0.0       │ -0.217047 │
# │ 12  │ 7493     │ -0.2    │ -0.399592 │ -0.258303 │
# │ 13  │ 9045     │ -0.2    │ 0.0       │ 0.0       │
# │ 14  │ 9055     │ 0.2     │ 0.0       │ 0.0       │
# │ 15  │ 9059     │ 0.2     │ 0.0       │ 0.0       │
# Grouped ran: 22 iters and Ungrouped ran: 15 iters
#
#
# running 46 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 1787     │ -0.2    │ -0.238852 │ 0.0       │
# │ 2   │ 1792     │ 0.2     │ 0.0       │ 0.0       │
# │ 3   │ 1796     │ 0.2     │ 0.0       │ 0.0       │
# │ 4   │ 2952     │ -0.2    │ 0.0       │ 0.0       │
# ...
# │ 1   │ 2262     │ 0.2     │ 0.0       │ 0.0       │
# │ 2   │ 2271     │ 0.2     │ 0.2829    │ 0.0       │
# │ 3   │ 2273     │ 0.2     │ 0.0       │ 0.0       │
# │ 4   │ 4081     │ -0.2    │ 0.0       │ 0.0       │
# │ 5   │ 4085     │ -0.2    │ 0.0       │ 0.0       │
# │ 6   │ 4099     │ 0.2     │ 0.254447  │ 0.220941  │
# │ 7   │ 7923     │ -0.2    │ 0.0       │ 0.0       │
# │ 8   │ 7924     │ 0.2     │ 0.0       │ 0.0       │
# │ 9   │ 7933     │ -0.2    │ 0.0       │ 0.0       │
# │ 10  │ 8284     │ 0.2     │ 0.199058  │ 0.222778  │
# │ 11  │ 8287     │ -0.2    │ -0.304863 │ -0.282996 │
# │ 12  │ 8295     │ 0.2     │ 0.0       │ 0.137835  │
# │ 13  │ 8465     │ -0.2    │ -0.310793 │ -0.162985 │
# │ 14  │ 8470     │ 0.2     │ 0.313984  │ 0.0       │
# │ 15  │ 8475     │ 0.2     │ 0.0       │ 0.0       │
# Grouped ran: 19 iters and Ungrouped ran: 21 iters
#
#
# running 87 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 489      │ -0.2    │ 0.0       │ 0.0       │
# │ 2   │ 490      │ 0.2     │ 0.0       │ 0.0       │
# │ 3   │ 497      │ 0.2     │ 0.0       │ 0.0       │
# │ 4   │ 4102     │ -0.2    │ 0.0       │ 0.0       │
# │ 5   │ 4112     │ -0.2    │ -0.409925 │ -0.18614  │
# │ 6   │ 4113     │ -0.2    │ 0.0       │ -0.199244 │
# │ 7   │ 6721     │ -0.2    │ -0.288938 │ -0.236662 │
# │ 8   │ 6724     │ 0.2     │ 0.0       │ 0.165306  │
# │ 9   │ 6727     │ -0.2    │ 0.0       │ 0.0       │
# │ 10  │ 7372     │ -0.2    │ -0.366299 │ -0.210319 │
# │ 11  │ 7373     │ -0.2    │ 0.0       │ -0.152706 │
# │ 12  │ 7374     │ -0.2    │ 0.0       │ -0.171847 │
# │ 13  │ 9952     │ 0.2     │ 0.0       │ 0.0       │
# │ 14  │ 9953     │ -0.2    │ 0.0       │ 0.0       │
# │ 15  │ 9956     │ 0.2     │ 0.30925   │ 0.0       │
# Grouped ran: 38 iters and Ungrouped ran: 27 iters
#
#
# running 88 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 1962     │ 0.2     │ 0.0       │ 0.0       │
# │ 2   │ 1965     │ -0.2    │ 0.0       │ -0.192913 │
# │ 3   │ 1979     │ -0.2    │ 0.0       │ -0.141861 │
# │ 4   │ 3562     │ -0.2    │ 0.0       │ -0.268959 │
# │ 5   │ 3568     │ -0.2    │ 0.0       │ 0.0       │
# │ 6   │ 3574     │ -0.2    │ 0.0       │ 0.0       │
# │ 7   │ 4707     │ 0.2     │ 0.0       │ 0.0       │
# │ 8   │ 4708     │ -0.2    │ 0.0       │ -0.18877  │
# │ 9   │ 4710     │ -0.2    │ 0.0       │ -0.230861 │
# │ 10  │ 4782     │ -0.2    │ 0.0       │ 0.0       │
# │ 11  │ 4784     │ 0.2     │ 0.0       │ 0.0       │
# │ 12  │ 4795     │ -0.2    │ 0.0       │ 0.0       │
# │ 13  │ 8848     │ -0.2    │ -0.290089 │ -0.248156 │
# │ 14  │ 8852     │ 0.2     │ 0.285862  │ 0.254413  │
# │ 15  │ 8860     │ -0.2    │ 0.0       │ 0.0       │
# Grouped ran: 42 iters and Ungrouped ran: 22 iters
#
#
# running 89 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped    │
# │     │ Int64    │ Float64 │ Float64   │ Float64    │
# ├─────┼──────────┼─────────┼───────────┼────────────┤
# │ 1   │ 645      │ -0.2    │ 0.0       │ 0.0        │
# │ 2   │ 657      │ 0.2     │ 0.0       │ 0.0        │
# │ 3   │ 659      │ -0.2    │ 0.0       │ 0.0        │
# │ 4   │ 1585     │ 0.2     │ 0.0       │ 0.0        │
# │ 5   │ 1589     │ 0.2     │ 0.334974  │ 0.357028   │
# │ 6   │ 1590     │ 0.2     │ 0.284879  │ 0.229915   │
# │ 7   │ 2682     │ -0.2    │ 0.0       │ 0.0        │
# │ 8   │ 2693     │ -0.2    │ 0.0       │ 0.0        │
# │ 9   │ 2696     │ -0.2    │ 0.0       │ 0.0        │
# │ 10  │ 4407     │ 0.2     │ 0.0       │ 0.0        │
# │ 11  │ 4417     │ -0.2    │ 0.0       │ 0.0        │
# │ 12  │ 4418     │ -0.2    │ 0.0       │ 0.0        │
# │ 13  │ 7563     │ -0.2    │ -0.379701 │ -0.254703  │
# │ 14  │ 7565     │ -0.2    │ 0.0       │ -0.0896435 │
# │ 15  │ 7572     │ -0.2    │ 0.0       │ 0.0        │
# Grouped ran: 49 iters and Ungrouped ran: 14 iters
#
#
# running 90 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 811      │ 0.2     │ 0.0       │ 0.0       │
# │ 2   │ 814      │ -0.2    │ -0.383952 │ -0.3777   │
# │ 3   │ 820      │ -0.2    │ 0.0       │ 0.0       │
# │ 4   │ 3164     │ 0.2     │ 0.0       │ 0.0       │
# │ 5   │ 3171     │ -0.2    │ -0.24575  │ -0.237976 │
# │ 6   │ 3174     │ -0.2    │ 0.0       │ -0.121179 │
# │ 7   │ 3684     │ -0.2    │ 0.0       │ -0.105957 │
# │ 8   │ 3686     │ 0.2     │ 0.0       │ 0.0       │
# │ 9   │ 3699     │ 0.2     │ 0.0       │ 0.0898667 │
# │ 10  │ 4744     │ -0.2    │ 0.0       │ 0.0       │
# │ 11  │ 4745     │ 0.2     │ 0.0       │ 0.0       │
# │ 12  │ 4756     │ 0.2     │ 0.0       │ 0.0       │
# │ 13  │ 8541     │ 0.2     │ 0.22207   │ 0.0       │
# │ 14  │ 8549     │ -0.2    │ 0.0       │ 0.0       │
# │ 15  │ 8550     │ 0.2     │ 0.0       │ 0.0       │
# Grouped ran: 44 iters and Ungrouped ran: 15 iters
#
#
# running 91 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 609      │ -0.2    │ 0.0       │ 0.0       │
# │ 2   │ 610      │ 0.2     │ 0.0       │ 0.0       │
# │ 3   │ 620      │ 0.2     │ 0.0       │ 0.0       │
# │ 4   │ 764      │ 0.2     │ 0.0       │ 0.0       │
# │ 5   │ 772      │ -0.2    │ 0.0       │ -0.145984 │
# │ 6   │ 775      │ -0.2    │ 0.0       │ 0.0       │
# │ 7   │ 6669     │ 0.2     │ 0.0       │ 0.0       │
# │ 8   │ 6675     │ -0.2    │ -0.270641 │ 0.0       │
# │ 9   │ 6680     │ 0.2     │ 0.0       │ 0.0       │
# │ 10  │ 8784     │ 0.2     │ 0.0       │ 0.0       │
# │ 11  │ 8792     │ 0.2     │ 0.0       │ 0.0       │
# │ 12  │ 8799     │ 0.2     │ 0.0       │ 0.0       │
# │ 13  │ 9385     │ 0.2     │ 0.0       │ 0.187513  │
# │ 14  │ 9391     │ -0.2    │ 0.0       │ 0.0       │
# │ 15  │ 9393     │ -0.2    │ -0.409203 │ -0.18684  │
# Grouped ran: 36 iters and Ungrouped ran: 14 iters
#
#
# running 92 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 387      │ -0.2    │ 0.0       │ 0.0       │
# │ 2   │ 392      │ 0.2     │ 0.0       │ 0.191393  │
# │ 3   │ 397      │ 0.2     │ 0.342813  │ 0.216907  │
# │ 4   │ 1844     │ -0.2    │ 0.0       │ -0.115674 │
# │ 5   │ 1847     │ -0.2    │ -0.308467 │ -0.238726 │
# │ 6   │ 1858     │ 0.2     │ 0.0       │ 0.132169  │
# │ 7   │ 2143     │ -0.2    │ 0.0       │ 0.0       │
# │ 8   │ 2155     │ 0.2     │ 0.0       │ 0.0       │
# │ 9   │ 2157     │ -0.2    │ 0.0       │ 0.0       │
# │ 10  │ 3024     │ -0.2    │ -0.40797  │ -0.310025 │
# │ 11  │ 3025     │ -0.2    │ 0.0       │ -0.150654 │
# │ 12  │ 3027     │ -0.2    │ 0.0       │ -0.205113 │
# │ 13  │ 6765     │ -0.2    │ 0.0       │ 0.0       │
# │ 14  │ 6769     │ -0.2    │ 0.0       │ -0.160104 │
# │ 15  │ 6779     │ -0.2    │ 0.0       │ 0.0       │
# Grouped ran: 77 iters and Ungrouped ran: 20 iters
#
#
# running 93 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 1741     │ -0.2    │ -0.294196 │ -0.274123 │
# │ 2   │ 1742     │ 0.2     │ 0.0       │ 0.0       │
# │ 3   │ 1748     │ 0.2     │ 0.218544  │ 0.182252  │
# │ 4   │ 6730     │ -0.2    │ 0.0       │ -0.156062 │
# │ 5   │ 6733     │ -0.2    │ 0.0       │ 0.0       │
# │ 6   │ 6734     │ -0.2    │ -0.326522 │ -0.185089 │
# │ 7   │ 8165     │ 0.2     │ 0.0       │ 0.0       │
# │ 8   │ 8171     │ -0.2    │ -0.229162 │ 0.0       │
# │ 9   │ 8174     │ 0.2     │ 0.0       │ 0.0       │
# │ 10  │ 8604     │ -0.2    │ 0.0       │ 0.0       │
# │ 11  │ 8608     │ -0.2    │ -0.36559  │ -0.379054 │
# │ 12  │ 8617     │ -0.2    │ 0.0       │ -0.146545 │
# │ 13  │ 9926     │ 0.2     │ 0.0       │ 0.0       │
# │ 14  │ 9931     │ 0.2     │ 0.0       │ 0.0       │
# │ 15  │ 9940     │ -0.2    │ 0.0       │ 0.0       │
# Grouped ran: 35 iters and Ungrouped ran: 20 iters
#
#
# running 94 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 2043     │ 0.2     │ 0.274996  │ 0.251259  │
# │ 2   │ 2052     │ -0.2    │ 0.0       │ 0.0       │
# │ 3   │ 2055     │ 0.2     │ 0.322913  │ 0.278056  │
# │ 4   │ 2267     │ 0.2     │ 0.0       │ 0.0       │
# │ 5   │ 2273     │ 0.2     │ 0.0       │ 0.179543  │
# │ 6   │ 2280     │ 0.2     │ 0.318097  │ 0.251305  │
# │ 7   │ 4128     │ 0.2     │ 0.348455  │ 0.276254  │
# │ 8   │ 4134     │ 0.2     │ 0.0       │ 0.0       │
# │ 9   │ 4136     │ 0.2     │ 0.311351  │ 0.321616  │
# │ 10  │ 7921     │ 0.2     │ 0.324153  │ 0.232887  │
# │ 11  │ 7928     │ -0.2    │ -0.372456 │ -0.258684 │
# │ 12  │ 7929     │ -0.2    │ 0.0       │ -0.197594 │
# │ 13  │ 9389     │ -0.2    │ 0.0       │ 0.0       │
# │ 14  │ 9394     │ -0.2    │ -0.253131 │ -0.323142 │
# │ 15  │ 9398     │ -0.2    │ -0.314217 │ -0.225066 │
# Grouped ran: 39 iters and Ungrouped ran: 19 iters
#
#
# running 95 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 2565     │ 0.2     │ 0.0       │ 0.0       │
# │ 2   │ 2569     │ -0.2    │ 0.0       │ -0.187439 │
# │ 3   │ 2573     │ 0.2     │ 0.383076  │ 0.277821  │
# │ 4   │ 4405     │ -0.2    │ 0.0       │ 0.0       │
# │ 5   │ 4407     │ 0.2     │ 0.0       │ 0.0       │
# │ 6   │ 4410     │ -0.2    │ 0.0       │ 0.0       │
# │ 7   │ 5330     │ 0.2     │ 0.0       │ 0.253507  │
# │ 8   │ 5332     │ 0.2     │ 0.456904  │ 0.18573   │
# │ 9   │ 5340     │ 0.2     │ 0.0       │ 0.224077  │
# │ 10  │ 7706     │ 0.2     │ 0.0       │ 0.0       │
# │ 11  │ 7713     │ 0.2     │ 0.0       │ 0.0       │
# │ 12  │ 7717     │ 0.2     │ 0.0       │ 0.0       │
# │ 13  │ 8385     │ 0.2     │ 0.0       │ 0.0       │
# │ 14  │ 8392     │ 0.2     │ 0.0       │ 0.16795   │
# │ 15  │ 8399     │ -0.2    │ 0.0       │ 0.0       │
# Grouped ran: 52 iters and Ungrouped ran: 16 iters
#
#
# running 96 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 768      │ 0.2     │ 0.0       │ 0.0       │
# │ 2   │ 769      │ -0.2    │ 0.0       │ 0.0       │
# │ 3   │ 777      │ -0.2    │ 0.0       │ 0.0       │
# │ 4   │ 2426     │ -0.2    │ 0.0       │ -0.150697 │
# │ 5   │ 2429     │ -0.2    │ 0.0       │ 0.0       │
# │ 6   │ 2438     │ -0.2    │ 0.0       │ 0.0       │
# │ 7   │ 4514     │ 0.2     │ 0.0       │ 0.145748  │
# │ 8   │ 4515     │ -0.2    │ 0.0       │ 0.0       │
# │ 9   │ 4519     │ 0.2     │ 0.391862  │ 0.405019  │
# │ 10  │ 6648     │ 0.2     │ 0.0       │ 0.0       │
# │ 11  │ 6653     │ 0.2     │ 0.253044  │ 0.301079  │
# │ 12  │ 6658     │ -0.2    │ 0.0       │ 0.0       │
# │ 13  │ 8406     │ 0.2     │ 0.0       │ 0.0       │
# │ 14  │ 8412     │ 0.2     │ 0.338802  │ 0.372364  │
# │ 15  │ 8413     │ 0.2     │ 0.0       │ 0.0       │
# Grouped ran: 46 iters and Ungrouped ran: 17 iters
#
#
# running 97 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 3922     │ 0.2     │ 0.303991  │ 0.0       │
# │ 2   │ 3927     │ 0.2     │ 0.0       │ 0.0       │
# │ 3   │ 3940     │ 0.2     │ 0.0       │ 0.0       │
# │ 4   │ 7066     │ 0.2     │ 0.0       │ 0.201402  │
# │ 5   │ 7069     │ -0.2    │ 0.0       │ -0.22582  │
# │ 6   │ 7075     │ -0.2    │ -0.282382 │ -0.281292 │
# │ 7   │ 8784     │ 0.2     │ 0.0       │ 0.0       │
# │ 8   │ 8788     │ -0.2    │ 0.0       │ 0.0       │
# │ 9   │ 8800     │ -0.2    │ -0.287396 │ 0.0       │
# │ 10  │ 9709     │ 0.2     │ 0.0       │ 0.0       │
# │ 11  │ 9710     │ -0.2    │ 0.0       │ 0.0       │
# │ 12  │ 9713     │ -0.2    │ 0.0       │ 0.0       │
# │ 13  │ 9767     │ 0.2     │ 0.0       │ 0.0       │
# │ 14  │ 9774     │ -0.2    │ 0.0       │ -0.14878  │
# │ 15  │ 9776     │ -0.2    │ 0.0       │ 0.0       │
# Grouped ran: 27 iters and Ungrouped ran: 24 iters
#
#
# running 98 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 2166     │ 0.2     │ 0.0       │ 0.0       │
# │ 2   │ 2168     │ 0.2     │ 0.0       │ 0.0       │
# │ 3   │ 2170     │ -0.2    │ 0.0       │ 0.0       │
# │ 4   │ 4783     │ 0.2     │ 0.286461  │ 0.0       │
# │ 5   │ 4792     │ 0.2     │ 0.486469  │ 0.223108  │
# │ 6   │ 4800     │ -0.2    │ 0.0       │ 0.0       │
# │ 7   │ 5782     │ 0.2     │ 0.0       │ 0.0       │
# │ 8   │ 5783     │ -0.2    │ 0.0       │ 0.0       │
# │ 9   │ 5790     │ -0.2    │ 0.0       │ 0.0       │
# │ 10  │ 6886     │ 0.2     │ 0.2494    │ 0.266926  │
# │ 11  │ 6893     │ -0.2    │ -0.365746 │ -0.399543 │
# │ 12  │ 6899     │ -0.2    │ 0.0       │ 0.0       │
# │ 13  │ 9161     │ -0.2    │ 0.0       │ -0.157051 │
# │ 14  │ 9163     │ 0.2     │ 0.0       │ 0.198808  │
# │ 15  │ 9174     │ -0.2    │ -0.332283 │ -0.289934 │
# Grouped ran: 31 iters and Ungrouped ran: 15 iters
#
#
# running 99 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped    │
# │     │ Int64    │ Float64 │ Float64   │ Float64    │
# ├─────┼──────────┼─────────┼───────────┼────────────┤
# │ 1   │ 3161     │ 0.2     │ 0.0       │ 0.249543   │
# │ 2   │ 3168     │ -0.2    │ 0.0       │ 0.0        │
# │ 3   │ 3176     │ 0.2     │ 0.0       │ 0.167492   │
# │ 4   │ 4022     │ 0.2     │ 0.0       │ 0.0        │
# │ 5   │ 4023     │ -0.2    │ 0.0       │ 0.0        │
# │ 6   │ 4029     │ -0.2    │ 0.0       │ -0.0720428 │
# │ 7   │ 6123     │ 0.2     │ 0.0       │ 0.0        │
# │ 8   │ 6129     │ -0.2    │ 0.0       │ -0.104401  │
# │ 9   │ 6130     │ -0.2    │ -0.384465 │ -0.269276  │
# │ 10  │ 6228     │ 0.2     │ 0.0       │ 0.0        │
# │ 11  │ 6229     │ 0.2     │ 0.323018  │ 0.31528    │
# │ 12  │ 6237     │ 0.2     │ 0.331832  │ 0.304487   │
# │ 13  │ 9205     │ -0.2    │ -0.344688 │ -0.416343  │
# │ 14  │ 9214     │ -0.2    │ 0.0       │ 0.0        │
# │ 15  │ 9216     │ 0.2     │ 0.0       │ 0.0804098  │
# Grouped ran: 46 iters and Ungrouped ran: 16 iters
#
#
# running 100 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 2605     │ 0.2     │ 0.218577  │ 0.227288  │
# │ 2   │ 2607     │ -0.2    │ 0.0       │ 0.0       │
# │ 3   │ 2620     │ -0.2    │ 0.0       │ -0.145608 │
# │ 4   │ 6881     │ 0.2     │ 0.0       │ 0.0       │
# │ 5   │ 6895     │ 0.2     │ 0.0       │ 0.0       │
# │ 6   │ 6896     │ -0.2    │ 0.0       │ 0.0       │
# │ 7   │ 8121     │ -0.2    │ 0.0       │ -0.157993 │
# │ 8   │ 8131     │ -0.2    │ 0.0       │ 0.0       │
# │ 9   │ 8132     │ 0.2     │ 0.0       │ 0.0       │
# │ 10  │ 8511     │ -0.2    │ 0.0       │ 0.0       │
# │ 11  │ 8513     │ -0.2    │ -0.316713 │ -0.248305 │
# │ 12  │ 8515     │ 0.2     │ 0.0       │ 0.0       │
# │ 13  │ 9425     │ -0.2    │ -0.291302 │ 0.0       │
# │ 14  │ 9436     │ -0.2    │ 0.0       │ 0.0       │
# │ 15  │ 9437     │ 0.2     │ 0.0       │ 0.0       │
# Grouped ran: 40 iters and Ungrouped ran: 16 iters
#
#
# Group IHT found: 621.0/1500 variantspercentage = 0.414
# Ungrouped IHT found: 380.0/1500 variantspercentage = 0.25333333333333335
# Grouped common variant standard errors = 2.221542825437431percentage = 0.14810285502916207
# Ungrouped common variant standard errors = 1.5439683882250905percentage = 0.10293122588167271

# %% [markdown]
# # Poisson

# %%
Random.seed!(2019)
d = Poisson
l = canonicallink(d())

num_runs = 100
group_found = zeros(num_runs)
ungroup_found = zeros(num_runs)

for i in 1:num_runs
    println("running $i th model")
    gf, uf = compare(d, l)
    group_found[i] = gf
    ungroup_found[i] = uf
end

println("Group IHT found: ", sum(group_found), "/", 15num_runs, " variants", "percentage = ", sum(group_found)/15num_runs)
println("Ungrouped IHT found: ", sum(ungroup_found), "/", 15num_runs, " variants" , "percentage = ", sum(ungroup_found)/15num_runs)
println("Grouped common variant standard errors = ", std(group_found), "percentage = ", std(group_found)/15)
println("Ungrouped common variant standard errors = ", std(ungroup_found), "percentage = ", std(ungroup_found)/15)
# Out:
# running 1 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 3464     │ -0.2    │ -0.180238 │ -0.196032 │
# │ 2   │ 3466     │ -0.2    │ -0.211899 │ -0.203317 │
# │ 3   │ 3468     │ 0.2     │ 0.196402  │ 0.187232  │
# │ 4   │ 4924     │ -0.2    │ -0.235714 │ -0.24824  │
# │ 5   │ 4930     │ 0.2     │ 0.0       │ 0.143477  │
# │ 6   │ 4938     │ 0.2     │ 0.0       │ 0.0       │
# │ 7   │ 5004     │ 0.2     │ 0.200452  │ 0.197379  │
# │ 8   │ 5016     │ -0.2    │ -0.186234 │ -0.195465 │
# │ 9   │ 5020     │ 0.2     │ 0.188199  │ 0.185596  │
# │ 10  │ 5081     │ -0.2    │ -0.234073 │ -0.149247 │
# │ 11  │ 5091     │ -0.2    │ -0.230353 │ -0.156976 │
# │ 12  │ 5098     │ 0.2     │ 0.221201  │ 0.0       │
# │ 13  │ 7003     │ -0.2    │ -0.161933 │ -0.167107 │
# │ 14  │ 7007     │ -0.2    │ -0.193825 │ -0.196326 │
# │ 15  │ 7018     │ -0.2    │ -0.121225 │ -0.127475 │
# Grouped ran: 17 iters and Ungrouped ran: 25 iters
#
#
# running 2 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 148      │ 0.2     │ 0.188485  │ 0.207434  │
# │ 2   │ 150      │ 0.2     │ 0.206138  │ 0.0       │
# │ 3   │ 153      │ -0.2    │ -0.163113 │ -0.10989  │
# │ 4   │ 4292     │ 0.2     │ 0.0       │ 0.0       │
# │ 5   │ 4293     │ -0.2    │ -0.159959 │ -0.112687 │
# │ 6   │ 4294     │ 0.2     │ 0.0       │ 0.0       │
# │ 7   │ 4989     │ 0.2     │ 0.195142  │ 0.194709  │
# │ 8   │ 4992     │ -0.2    │ -0.212615 │ 0.0       │
# │ 9   │ 4993     │ 0.2     │ 0.178244  │ 0.0797293 │
# │ 10  │ 8465     │ -0.2    │ 0.0       │ 0.0       │
# │ 11  │ 8475     │ 0.2     │ 0.0       │ 0.0       │
# │ 12  │ 8479     │ -0.2    │ -0.239684 │ -0.235451 │
# │ 13  │ 9442     │ -0.2    │ -0.179765 │ -0.180357 │
# │ 14  │ 9443     │ 0.2     │ 0.219704  │ 0.193909  │
# │ 15  │ 9457     │ -0.2    │ -0.175283 │ -0.181477 │
# Grouped ran: 39 iters and Ungrouped ran: 32 iters
#
#
# running 3 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 668      │ -0.2    │ 0.0       │ 0.0       │
# │ 2   │ 673      │ 0.2     │ 0.189519  │ 0.199021  │
# │ 3   │ 679      │ 0.2     │ 0.0       │ 0.114763  │
# │ 4   │ 1270     │ -0.2    │ -0.201355 │ -0.205747 │
# │ 5   │ 1277     │ 0.2     │ 0.206647  │ 0.202892  │
# │ 6   │ 1278     │ 0.2     │ 0.201836  │ 0.197144  │
# │ 7   │ 4161     │ 0.2     │ 0.186599  │ 0.174113  │
# │ 8   │ 4168     │ 0.2     │ 0.222774  │ 0.221982  │
# │ 9   │ 4173     │ 0.2     │ 0.214064  │ 0.229256  │
# │ 10  │ 5411     │ 0.2     │ 0.157572  │ 0.0       │
# │ 11  │ 5413     │ 0.2     │ 0.175235  │ 0.226087  │
# │ 12  │ 5416     │ -0.2    │ -0.215595 │ -0.20207  │
# │ 13  │ 5485     │ 0.2     │ 0.136057  │ 0.139715  │
# │ 14  │ 5496     │ -0.2    │ 0.0       │ 0.0       │
# │ 15  │ 5499     │ 0.2     │ 0.116728  │ 0.113529  │
# Grouped ran: 40 iters and Ungrouped ran: 55 iters
#
#
# running 4 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 48       │ -0.2    │ -0.244343 │ -0.252521 │
# │ 2   │ 54       │ -0.2    │ -0.18345  │ -0.173752 │
# │ 3   │ 56       │ -0.2    │ -0.182512 │ -0.197853 │
# │ 4   │ 166      │ -0.2    │ -0.119924 │ -0.109116 │
# │ 5   │ 168      │ -0.2    │ -0.186189 │ -0.186734 │
# │ 6   │ 175      │ 0.2     │ 0.0       │ 0.0       │
# │ 7   │ 782      │ -0.2    │ -0.156513 │ -0.148631 │
# │ 8   │ 790      │ -0.2    │ 0.0       │ -0.113357 │
# │ 9   │ 796      │ -0.2    │ -0.183096 │ -0.206343 │
# │ 10  │ 4327     │ -0.2    │ -0.177416 │ -0.177083 │
# │ 11  │ 4332     │ -0.2    │ -0.215568 │ -0.2112   │
# │ 12  │ 4338     │ 0.2     │ 0.231186  │ 0.237901  │
# │ 13  │ 7362     │ -0.2    │ 0.0       │ 0.0       │
# │ 14  │ 7363     │ 0.2     │ 0.0       │ 0.0916112 │
# │ 15  │ 7377     │ 0.2     │ 0.125321  │ 0.124588  │
# Grouped ran: 26 iters and Ungrouped ran: 25 iters
#
#
# running 5 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 2542     │ 0.2     │ 0.175395  │ 0.202155  │
# │ 2   │ 2547     │ -0.2    │ 0.0       │ -0.170099 │
# │ 3   │ 2548     │ 0.2     │ 0.0       │ 0.16385   │
# │ 4   │ 2844     │ -0.2    │ -0.188789 │ -0.212635 │
# │ 5   │ 2845     │ 0.2     │ 0.206064  │ 0.203947  │
# │ 6   │ 2855     │ 0.2     │ 0.215899  │ 0.206278  │
# │ 7   │ 3885     │ -0.2    │ -0.216952 │ -0.220238 │
# │ 8   │ 3895     │ -0.2    │ -0.211813 │ -0.213096 │
# │ 9   │ 3897     │ -0.2    │ -0.142581 │ -0.145292 │
# │ 10  │ 3983     │ -0.2    │ 0.0       │ -0.164334 │
# │ 11  │ 3990     │ 0.2     │ 0.154788  │ 0.158822  │
# │ 12  │ 3992     │ 0.2     │ 0.0       │ 0.207508  │
# │ 13  │ 5183     │ 0.2     │ 0.324792  │ 0.330016  │
# │ 14  │ 5186     │ 0.2     │ 0.0       │ 0.0       │
# │ 15  │ 5190     │ 0.2     │ 0.162559  │ 0.159911  │
# Grouped ran: 32 iters and Ungrouped ran: 38 iters
#
#
# running 6 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 4631     │ 0.2     │ 0.225088  │ 0.21355   │
# │ 2   │ 4636     │ -0.2    │ -0.181876 │ -0.168695 │
# │ 3   │ 4638     │ -0.2    │ -0.198464 │ 0.0       │
# │ 4   │ 6730     │ -0.2    │ -0.156082 │ -0.156511 │
# │ 5   │ 6739     │ -0.2    │ -0.209689 │ -0.22546  │
# │ 6   │ 6740     │ -0.2    │ -0.167172 │ -0.1643   │
# │ 7   │ 7889     │ 0.2     │ 0.0944845 │ 0.188084  │
# │ 8   │ 7893     │ -0.2    │ -0.17343  │ -0.167428 │
# │ 9   │ 7898     │ 0.2     │ 0.226967  │ 0.217458  │
# │ 10  │ 8409     │ 0.2     │ 0.216028  │ 0.218177  │
# │ 11  │ 8411     │ 0.2     │ 0.188043  │ 0.18217   │
# │ 12  │ 8413     │ 0.2     │ 0.219212  │ 0.229449  │
# │ 13  │ 9524     │ -0.2    │ -0.128284 │ -0.15222  │
# │ 14  │ 9529     │ 0.2     │ 0.0       │ 0.190445  │
# │ 15  │ 9530     │ -0.2    │ 0.0       │ -0.209265 │
# Grouped ran: 29 iters and Ungrouped ran: 17 iters
#
#
# running 7 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 3844     │ -0.2    │ -0.191702 │ -0.178567 │
# │ 2   │ 3851     │ -0.2    │ -0.204501 │ -0.22683  │
# │ 3   │ 3857     │ 0.2     │ 0.210263  │ 0.19298   │
# │ 4   │ 5278     │ 0.2     │ 0.0       │ 0.170836  │
# │ 5   │ 5279     │ -0.2    │ 0.0       │ -0.185029 │
# │ 6   │ 5280     │ -0.2    │ -0.212882 │ -0.186663 │
# │ 7   │ 5836     │ 0.2     │ 0.0       │ 0.151553  │
# │ 8   │ 5838     │ -0.2    │ -0.182915 │ -0.198655 │
# │ 9   │ 5840     │ -0.2    │ 0.0       │ 0.0       │
# │ 10  │ 7941     │ -0.2    │ 0.0       │ -0.115726 │
# │ 11  │ 7943     │ -0.2    │ -0.196297 │ -0.137883 │
# │ 12  │ 7952     │ 0.2     │ 0.0       │ 0.0       │
# │ 13  │ 9522     │ 0.2     │ 0.21686   │ 0.164159  │
# │ 14  │ 9523     │ 0.2     │ 0.201591  │ 0.185722  │
# │ 15  │ 9536     │ -0.2    │ -0.181494 │ 0.0       │
# Grouped ran: 40 iters and Ungrouped ran: 18 iters
#
#
# running 8 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 2883     │ 0.2     │ 0.215325  │ 0.209516  │
# │ 2   │ 2892     │ -0.2    │ -0.178986 │ -0.188458 │
# │ 3   │ 2898     │ -0.2    │ 0.0       │ 0.0       │
# │ 4   │ 3751     │ 0.2     │ 0.136574  │ 0.143066  │
# │ 5   │ 3757     │ 0.2     │ 0.211995  │ 0.214016  │
# │ 6   │ 3758     │ 0.2     │ 0.0       │ 0.0       │
# │ 7   │ 3941     │ 0.2     │ 0.0       │ 0.211686  │
# │ 8   │ 3953     │ 0.2     │ 0.0       │ 0.193142  │
# │ 9   │ 3960     │ -0.2    │ -0.149757 │ -0.148366 │
# │ 10  │ 5305     │ -0.2    │ -0.133927 │ -0.126429 │
# │ 11  │ 5308     │ -0.2    │ 0.0       │ 0.0       │
# │ 12  │ 5317     │ 0.2     │ 0.200377  │ 0.206264  │
# │ 13  │ 6609     │ -0.2    │ -0.186328 │ -0.190281 │
# │ 14  │ 6615     │ -0.2    │ -0.145768 │ -0.161207 │
# │ 15  │ 6619     │ 0.2     │ 0.21241   │ 0.214373  │
# Grouped ran: 22 iters and Ungrouped ran: 18 iters
#
#
# running 9 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 1122     │ 0.2     │ 0.180433  │ 0.180434  │
# │ 2   │ 1123     │ -0.2    │ -0.167826 │ -0.167827 │
# │ 3   │ 1131     │ 0.2     │ 0.0       │ 0.0       │
# │ 4   │ 3305     │ -0.2    │ -0.192866 │ -0.192867 │
# │ 5   │ 3306     │ -0.2    │ -0.221457 │ -0.221459 │
# │ 6   │ 3319     │ 0.2     │ 0.183758  │ 0.183757  │
# │ 7   │ 4284     │ -0.2    │ -0.212427 │ -0.212429 │
# │ 8   │ 4289     │ 0.2     │ 0.204326  │ 0.204327  │
# │ 9   │ 4298     │ -0.2    │ -0.231543 │ -0.231543 │
# │ 10  │ 5443     │ 0.2     │ 0.121827  │ 0.121773  │
# │ 11  │ 5444     │ 0.2     │ 0.242777  │ 0.242839  │
# │ 12  │ 5450     │ 0.2     │ 0.254402  │ 0.254419  │
# │ 13  │ 8204     │ -0.2    │ -0.141271 │ -0.141272 │
# │ 14  │ 8216     │ 0.2     │ 0.217686  │ 0.217688  │
# │ 15  │ 8220     │ 0.2     │ 0.232131  │ 0.232132  │
# Grouped ran: 66 iters and Ungrouped ran: 81 iters
#
#
# running 10 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 222      │ -0.2    │ -0.120984 │ -0.185887 │
# │ 2   │ 232      │ -0.2    │ 0.0       │ -0.14127  │
# │ 3   │ 235      │ -0.2    │ 0.0       │ -0.196796 │
# │ 4   │ 2525     │ 0.2     │ 0.277935  │ 0.230472  │
# │ 5   │ 2530     │ -0.2    │ 0.0       │ -0.155161 │
# │ 6   │ 2537     │ -0.2    │ -0.140722 │ -0.153448 │
# │ 7   │ 5026     │ -0.2    │ -0.155596 │ -0.17487  │
# │ 8   │ 5030     │ -0.2    │ 0.0       │ 0.0       │
# │ 9   │ 5031     │ 0.2     │ 0.0       │ 0.0983702 │
# │ 10  │ 8971     │ 0.2     │ 0.168355  │ 0.172566  │
# │ 11  │ 8974     │ -0.2    │ -0.187922 │ -0.185132 │
# │ 12  │ 8976     │ 0.2     │ 0.215636  │ 0.227912  │
# │ 13  │ 9692     │ -0.2    │ -0.223813 │ -0.207462 │
# │ 14  │ 9695     │ 0.2     │ 0.303376  │ 0.299159  │
# │ 15  │ 9699     │ -0.2    │ -0.227989 │ -0.217943 │
# Grouped ran: 15 iters and Ungrouped ran: 21 iters
#
#
# running 11 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 984      │ -0.2    │ -0.206029 │ -0.201698 │
# │ 2   │ 985      │ 0.2     │ 0.172535  │ 0.163729  │
# │ 3   │ 997      │ 0.2     │ 0.198506  │ 0.210562  │
# │ 4   │ 1043     │ 0.2     │ 0.186282  │ 0.196665  │
# │ 5   │ 1050     │ 0.2     │ 0.240739  │ 0.256479  │
# │ 6   │ 1059     │ 0.2     │ 0.219898  │ 0.220887  │
# │ 7   │ 2125     │ 0.2     │ 0.187049  │ 0.184871  │
# │ 8   │ 2130     │ 0.2     │ 0.189786  │ 0.189092  │
# │ 9   │ 2135     │ -0.2    │ -0.223294 │ -0.221356 │
# │ 10  │ 6043     │ -0.2    │ -0.191288 │ 0.0       │
# │ 11  │ 6051     │ 0.2     │ 0.220324  │ 0.146816  │
# │ 12  │ 6055     │ 0.2     │ 0.215522  │ 0.121589  │
# │ 13  │ 9343     │ -0.2    │ -0.207729 │ -0.183342 │
# │ 14  │ 9355     │ -0.2    │ -0.191462 │ 0.0       │
# │ 15  │ 9358     │ -0.2    │ -0.209526 │ -0.170979 │
# Grouped ran: 19 iters and Ungrouped ran: 22 iters
#
#
# running 12 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 1982     │ -0.2    │ -0.219486 │ -0.202359 │
# │ 2   │ 1992     │ 0.2     │ 0.181425  │ 0.194532  │
# │ 3   │ 2000     │ 0.2     │ 0.207359  │ 0.218764  │
# │ 4   │ 2601     │ -0.2    │ -0.288747 │ -0.259295 │
# │ 5   │ 2602     │ -0.2    │ 0.0       │ -0.088831 │
# │ 6   │ 2610     │ -0.2    │ 0.0       │ 0.0       │
# │ 7   │ 3464     │ -0.2    │ -0.197631 │ -0.204086 │
# │ 8   │ 3477     │ 0.2     │ 0.164389  │ 0.154781  │
# │ 9   │ 3478     │ 0.2     │ 0.219761  │ 0.206414  │
# │ 10  │ 3882     │ 0.2     │ 0.187855  │ 0.186007  │
# │ 11  │ 3891     │ -0.2    │ -0.235306 │ -0.242611 │
# │ 12  │ 3897     │ -0.2    │ -0.191248 │ -0.194811 │
# │ 13  │ 4110     │ 0.2     │ 0.240119  │ 0.196188  │
# │ 14  │ 4115     │ 0.2     │ 0.213428  │ 0.188389  │
# │ 15  │ 4119     │ 0.2     │ 0.204948  │ 0.0       │
# Grouped ran: 19 iters and Ungrouped ran: 20 iters
#
#
# running 13 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 4662     │ 0.2     │ 0.0       │ 0.0       │
# │ 2   │ 4663     │ -0.2    │ -0.136264 │ -0.139066 │
# │ 3   │ 4669     │ 0.2     │ 0.228233  │ 0.224383  │
# │ 4   │ 5365     │ 0.2     │ 0.210979  │ 0.216821  │
# │ 5   │ 5369     │ 0.2     │ 0.198753  │ 0.199822  │
# │ 6   │ 5377     │ -0.2    │ -0.220784 │ -0.215991 │
# │ 7   │ 8086     │ 0.2     │ 0.192065  │ 0.21159   │
# │ 8   │ 8092     │ 0.2     │ 0.186371  │ 0.182781  │
# │ 9   │ 8097     │ 0.2     │ 0.196407  │ 0.200903  │
# │ 10  │ 8162     │ -0.2    │ -0.196073 │ -0.230318 │
# │ 11  │ 8169     │ -0.2    │ -0.215649 │ 0.0       │
# │ 12  │ 8178     │ -0.2    │ -0.197474 │ -0.23468  │
# │ 13  │ 9023     │ 0.2     │ 0.0       │ 0.0       │
# │ 14  │ 9024     │ -0.2    │ 0.0       │ 0.0       │
# │ 15  │ 9034     │ 0.2     │ 0.302577  │ 0.25278   │
# Grouped ran: 15 iters and Ungrouped ran: 33 iters
#
#
# running 14 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 3324     │ 0.2     │ 0.209251  │ 0.210238  │
# │ 2   │ 3326     │ 0.2     │ 0.216927  │ 0.215066  │
# │ 3   │ 3330     │ 0.2     │ 0.175243  │ 0.180445  │
# │ 4   │ 3708     │ -0.2    │ 0.0       │ -0.227271 │
# │ 5   │ 3717     │ 0.2     │ 0.229114  │ 0.2485    │
# │ 6   │ 3720     │ 0.2     │ 0.236188  │ 0.217467  │
# │ 7   │ 4126     │ -0.2    │ -0.228836 │ -0.223198 │
# │ 8   │ 4137     │ 0.2     │ 0.200873  │ 0.202131  │
# │ 9   │ 4139     │ -0.2    │ -0.157529 │ -0.158781 │
# │ 10  │ 8864     │ 0.2     │ 0.19487   │ 0.197826  │
# │ 11  │ 8873     │ -0.2    │ 0.0       │ 0.0       │
# │ 12  │ 8874     │ 0.2     │ 0.0       │ 0.0       │
# │ 13  │ 9564     │ -0.2    │ -0.146026 │ -0.152723 │
# │ 14  │ 9567     │ 0.2     │ 0.211573  │ 0.212006  │
# │ 15  │ 9570     │ 0.2     │ 0.227947  │ 0.2205    │
# Grouped ran: 22 iters and Ungrouped ran: 29 iters
#
#
# running 15 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 2502     │ -0.2    │ -0.192475 │ -0.190977 │
# │ 2   │ 2511     │ -0.2    │ -0.190336 │ 0.0       │
# │ 3   │ 2515     │ -0.2    │ -0.178784 │ -0.161467 │
# │ 4   │ 5083     │ 0.2     │ 0.0       │ 0.201996  │
# │ 5   │ 5095     │ 0.2     │ 0.141915  │ 0.152429  │
# │ 6   │ 5099     │ -0.2    │ 0.0       │ 0.0       │
# │ 7   │ 7083     │ 0.2     │ 0.285889  │ 0.246269  │
# │ 8   │ 7092     │ -0.2    │ 0.0       │ 0.0       │
# │ 9   │ 7093     │ 0.2     │ 0.0       │ 0.194669  │
# │ 10  │ 9025     │ 0.2     │ 0.186297  │ 0.189028  │
# │ 11  │ 9028     │ 0.2     │ 0.201194  │ 0.201004  │
# │ 12  │ 9040     │ 0.2     │ 0.148918  │ 0.157919  │
# │ 13  │ 9863     │ 0.2     │ 0.199114  │ 0.192932  │
# │ 14  │ 9875     │ -0.2    │ -0.212595 │ -0.212053 │
# │ 15  │ 9877     │ 0.2     │ 0.201487  │ 0.22271   │
# Grouped ran: 23 iters and Ungrouped ran: 18 iters
#
#
# running 16 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 591      │ -0.2    │ -0.234046 │ -0.235438 │
# │ 2   │ 594      │ 0.2     │ 0.222934  │ 0.213768  │
# │ 3   │ 596      │ -0.2    │ -0.208759 │ -0.201591 │
# │ 4   │ 2344     │ 0.2     │ 0.2467    │ 0.248548  │
# │ 5   │ 2355     │ -0.2    │ -0.233089 │ -0.228233 │
# │ 6   │ 2357     │ -0.2    │ -0.22119  │ -0.217807 │
# │ 7   │ 6221     │ -0.2    │ -0.145949 │ -0.141288 │
# │ 8   │ 6223     │ 0.2     │ 0.203253  │ 0.198869  │
# │ 9   │ 6228     │ 0.2     │ 0.16537   │ 0.169989  │
# │ 10  │ 8324     │ 0.2     │ 0.207215  │ 0.0       │
# │ 11  │ 8333     │ -0.2    │ -0.186862 │ -0.122672 │
# │ 12  │ 8335     │ 0.2     │ 0.198293  │ 0.163303  │
# │ 13  │ 9163     │ 0.2     │ 0.211134  │ 0.201948  │
# │ 14  │ 9168     │ 0.2     │ 0.213982  │ 0.216189  │
# │ 15  │ 9174     │ 0.2     │ 0.230475  │ 0.229192  │
# Grouped ran: 15 iters and Ungrouped ran: 25 iters
#
#
# running 17 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 3062     │ 0.2     │ 0.179822  │ 0.201331  │
# │ 2   │ 3072     │ -0.2    │ -0.159236 │ -0.147264 │
# │ 3   │ 3078     │ 0.2     │ 0.197978  │ 0.205118  │
# │ 4   │ 6021     │ -0.2    │ -0.150118 │ -0.147187 │
# │ 5   │ 6023     │ 0.2     │ 0.165804  │ 0.0       │
# │ 6   │ 6037     │ -0.2    │ 0.0       │ 0.0       │
# │ 7   │ 7111     │ -0.2    │ 0.0       │ -0.275706 │
# │ 8   │ 7112     │ 0.2     │ 0.0       │ 0.276338  │
# │ 9   │ 7117     │ -0.2    │ -0.327897 │ -0.276922 │
# │ 10  │ 7241     │ -0.2    │ 0.0       │ 0.0       │
# │ 11  │ 7246     │ 0.2     │ 0.163348  │ 0.159072  │
# │ 12  │ 7256     │ -0.2    │ -0.170529 │ -0.160905 │
# │ 13  │ 8335     │ -0.2    │ -0.251793 │ -0.265657 │
# │ 14  │ 8336     │ -0.2    │ -0.244544 │ -0.236623 │
# │ 15  │ 8339     │ 0.2     │ 0.263194  │ 0.269703  │
# Grouped ran: 22 iters and Ungrouped ran: 17 iters
#
#
# running 18 th model
# Did not converge after 100 iterations! The run time for IHT was 0.5312070846557617 seconds and model size was15
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped    │
# │     │ Int64    │ Float64 │ Float64   │ Float64    │
# ├─────┼──────────┼─────────┼───────────┼────────────┤
# │ 1   │ 281      │ 0.2     │ 0.203887  │ 0.207666   │
# │ 2   │ 287      │ 0.2     │ 0.250147  │ 0.253234   │
# │ 3   │ 296      │ -0.2    │ -0.189377 │ -0.195781  │
# │ 4   │ 2627     │ -0.2    │ -0.226816 │ -0.193122  │
# │ 5   │ 2629     │ -0.2    │ -0.200612 │ -0.227837  │
# │ 6   │ 2635     │ -0.2    │ -0.187675 │ -0.193734  │
# │ 7   │ 2787     │ 0.2     │ 0.196771  │ 0.199463   │
# │ 8   │ 2798     │ 0.2     │ 0.186573  │ 0.197102   │
# │ 9   │ 2800     │ 0.2     │ 0.20396   │ 0.206954   │
# │ 10  │ 5322     │ -0.2    │ -0.299165 │ -0.187279  │
# │ 11  │ 5324     │ 0.2     │ 0.244617  │ 0.0        │
# │ 12  │ 5328     │ 0.2     │ 0.242789  │ 0.164646   │
# │ 13  │ 8602     │ -0.2    │ -0.221846 │ -0.324358  │
# │ 14  │ 8610     │ 0.2     │ 0.261134  │ 0.0        │
# │ 15  │ 8612     │ -0.2    │ -0.144805 │ -0.0688306 │
# Grouped ran: 32 iters and Ungrouped ran: 100 iters
#
#
# running 19 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 1423     │ 0.2     │ 0.195162  │ 0.201716  │
# │ 2   │ 1430     │ -0.2    │ -0.232682 │ -0.23925  │
# │ 3   │ 1431     │ 0.2     │ 0.203606  │ 0.208656  │
# │ 4   │ 1881     │ -0.2    │ -0.212257 │ -0.20758  │
# │ 5   │ 1884     │ 0.2     │ 0.149206  │ 0.147745  │
# │ 6   │ 1892     │ -0.2    │ -0.24563  │ -0.235523 │
# │ 7   │ 4801     │ 0.2     │ 0.252961  │ 0.248876  │
# │ 8   │ 4808     │ -0.2    │ -0.239742 │ -0.229445 │
# │ 9   │ 4810     │ 0.2     │ 0.210867  │ 0.218914  │
# │ 10  │ 7170     │ -0.2    │ -0.208972 │ 0.0       │
# │ 11  │ 7176     │ -0.2    │ -0.142418 │ -0.137549 │
# │ 12  │ 7180     │ -0.2    │ -0.214855 │ -0.2017   │
# │ 13  │ 9921     │ 0.2     │ 0.0       │ 0.124904  │
# │ 14  │ 9929     │ 0.2     │ 0.129745  │ 0.17743   │
# │ 15  │ 9937     │ 0.2     │ 0.127687  │ 0.177     │
# Grouped ran: 19 iters and Ungrouped ran: 16 iters
#
#
# running 20 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 444      │ 0.2     │ 0.204949  │ 0.204911  │
# │ 2   │ 453      │ -0.2    │ -0.215387 │ -0.215382 │
# │ 3   │ 456      │ 0.2     │ 0.204669  │ 0.204657  │
# │ 4   │ 562      │ 0.2     │ 0.191642  │ 0.191666  │
# │ 5   │ 569      │ 0.2     │ 0.210646  │ 0.210632  │
# │ 6   │ 576      │ -0.2    │ -0.138228 │ -0.138242 │
# │ 7   │ 1564     │ -0.2    │ -0.205085 │ -0.205069 │
# │ 8   │ 1567     │ 0.2     │ 0.216763  │ 0.216762  │
# │ 9   │ 1574     │ 0.2     │ 0.214485  │ 0.214457  │
# │ 10  │ 2126     │ -0.2    │ -0.262119 │ -0.262118 │
# │ 11  │ 2127     │ -0.2    │ -0.188739 │ -0.188661 │
# │ 12  │ 2129     │ 0.2     │ 0.208457  │ 0.208408  │
# │ 13  │ 8547     │ 0.2     │ 0.19914   │ 0.199145  │
# │ 14  │ 8548     │ -0.2    │ -0.181678 │ -0.181688 │
# │ 15  │ 8559     │ -0.2    │ -0.16994  │ -0.169931 │
# Grouped ran: 13 iters and Ungrouped ran: 13 iters
#
#
# running 21 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 105      │ 0.2     │ 0.186158  │ 0.184306  │
# │ 2   │ 111      │ 0.2     │ 0.191309  │ 0.209753  │
# │ 3   │ 114      │ 0.2     │ 0.235169  │ 0.236166  │
# │ 4   │ 6647     │ 0.2     │ 0.216169  │ 0.214268  │
# │ 5   │ 6652     │ -0.2    │ -0.196251 │ -0.209726 │
# │ 6   │ 6659     │ 0.2     │ 0.207196  │ 0.216165  │
# │ 7   │ 7281     │ 0.2     │ 0.150078  │ 0.181652  │
# │ 8   │ 7284     │ 0.2     │ 0.19928   │ 0.0       │
# │ 9   │ 7290     │ 0.2     │ 0.22667   │ 0.189969  │
# │ 10  │ 7942     │ -0.2    │ -0.186906 │ -0.229099 │
# │ 11  │ 7951     │ 0.2     │ 0.0       │ 0.0580802 │
# │ 12  │ 7952     │ -0.2    │ 0.0       │ 0.0       │
# │ 13  │ 8682     │ 0.2     │ 0.208673  │ 0.209791  │
# │ 14  │ 8696     │ -0.2    │ -0.209748 │ -0.202811 │
# │ 15  │ 8699     │ -0.2    │ -0.201075 │ -0.194167 │
# Grouped ran: 20 iters and Ungrouped ran: 13 iters
#
#
# running 22 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 2084     │ -0.2    │ 0.0       │ -0.144418 │
# │ 2   │ 2093     │ -0.2    │ -0.111982 │ -0.190723 │
# │ 3   │ 2096     │ -0.2    │ 0.0       │ -0.137498 │
# │ 4   │ 2604     │ 0.2     │ 0.157315  │ 0.152874  │
# │ 5   │ 2609     │ 0.2     │ 0.183859  │ 0.177599  │
# │ 6   │ 2618     │ 0.2     │ 0.221322  │ 0.215922  │
# │ 7   │ 3743     │ -0.2    │ -0.15342  │ -0.167221 │
# │ 8   │ 3749     │ -0.2    │ -0.232112 │ -0.227352 │
# │ 9   │ 3754     │ -0.2    │ -0.226702 │ -0.217316 │
# │ 10  │ 4867     │ 0.2     │ 0.217941  │ 0.217074  │
# │ 11  │ 4873     │ -0.2    │ -0.139943 │ -0.160269 │
# │ 12  │ 4874     │ -0.2    │ -0.278939 │ -0.260923 │
# │ 13  │ 8388     │ -0.2    │ -0.213537 │ -0.219709 │
# │ 14  │ 8391     │ 0.2     │ 0.0       │ 0.099558  │
# │ 15  │ 8400     │ 0.2     │ 0.0       │ 0.0       │
# Grouped ran: 20 iters and Ungrouped ran: 25 iters
#
#
# running 23 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped    │
# │     │ Int64    │ Float64 │ Float64   │ Float64    │
# ├─────┼──────────┼─────────┼───────────┼────────────┤
# │ 1   │ 3245     │ 0.2     │ 0.0       │ 0.0        │
# │ 2   │ 3254     │ -0.2    │ 0.0       │ 0.0        │
# │ 3   │ 3259     │ -0.2    │ -0.129379 │ -0.157037  │
# │ 4   │ 3943     │ 0.2     │ 0.195811  │ 0.219176   │
# │ 5   │ 3956     │ -0.2    │ 0.0       │ 0.0        │
# │ 6   │ 3960     │ 0.2     │ 0.0       │ 0.0        │
# │ 7   │ 4041     │ -0.2    │ 0.0       │ -0.0979918 │
# │ 8   │ 4042     │ 0.2     │ 0.0       │ 0.0        │
# │ 9   │ 4052     │ 0.2     │ 0.129196  │ 0.134825   │
# │ 10  │ 4594     │ 0.2     │ 0.157023  │ 0.138627   │
# │ 11  │ 4597     │ 0.2     │ 0.0       │ 0.0        │
# │ 12  │ 4598     │ -0.2    │ 0.0       │ 0.0        │
# │ 13  │ 9901     │ 0.2     │ 0.21147   │ 0.199595   │
# │ 14  │ 9909     │ 0.2     │ 0.191594  │ 0.167887   │
# │ 15  │ 9919     │ -0.2    │ -0.225713 │ -0.235452  │
# Grouped ran: 30 iters and Ungrouped ran: 26 iters
#
#
# running 24 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped    │
# │     │ Int64    │ Float64 │ Float64   │ Float64    │
# ├─────┼──────────┼─────────┼───────────┼────────────┤
# │ 1   │ 4826     │ 0.2     │ 0.233698  │ 0.240765   │
# │ 2   │ 4831     │ 0.2     │ 0.162176  │ 0.164366   │
# │ 3   │ 4835     │ -0.2    │ -0.20615  │ -0.211664  │
# │ 4   │ 5411     │ -0.2    │ -0.215704 │ -0.219524  │
# │ 5   │ 5416     │ 0.2     │ 0.2217    │ 0.216902   │
# │ 6   │ 5418     │ 0.2     │ 0.21032   │ 0.212174   │
# │ 7   │ 6784     │ 0.2     │ 0.20248   │ 0.169545   │
# │ 8   │ 6790     │ -0.2    │ 0.0       │ -0.0980385 │
# │ 9   │ 6791     │ 0.2     │ 0.0       │ 0.0        │
# │ 10  │ 7982     │ -0.2    │ -0.204019 │ -0.199181  │
# │ 11  │ 7983     │ 0.2     │ 0.189286  │ 0.187389   │
# │ 12  │ 7993     │ 0.2     │ 0.202698  │ 0.194239   │
# │ 13  │ 9013     │ 0.2     │ 0.0       │ 0.0        │
# │ 14  │ 9015     │ -0.2    │ -0.120256 │ -0.125333  │
# │ 15  │ 9018     │ -0.2    │ -0.184918 │ -0.173677  │
# Grouped ran: 23 iters and Ungrouped ran: 21 iters
#
#
# running 25 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped  │ grouped   │
# │     │ Int64    │ Float64 │ Float64    │ Float64   │
# ├─────┼──────────┼─────────┼────────────┼───────────┤
# │ 1   │ 1462     │ 0.2     │ 0.273887   │ 0.216048  │
# │ 2   │ 1463     │ 0.2     │ 0.0        │ 0.158855  │
# │ 3   │ 1478     │ -0.2    │ -0.18021   │ -0.217499 │
# │ 4   │ 2647     │ 0.2     │ 0.21321    │ 0.195572  │
# │ 5   │ 2654     │ -0.2    │ -0.181228  │ -0.185334 │
# │ 6   │ 2660     │ -0.2    │ -0.158973  │ -0.158675 │
# │ 7   │ 3449     │ 0.2     │ 0.0        │ 0.181615  │
# │ 8   │ 3450     │ 0.2     │ 0.193235   │ 0.263958  │
# │ 9   │ 3453     │ -0.2    │ 0.0        │ -0.223719 │
# │ 10  │ 4223     │ -0.2    │ -0.0954923 │ -0.187241 │
# │ 11  │ 4234     │ 0.2     │ 0.226319   │ 0.217034  │
# │ 12  │ 4238     │ -0.2    │ -0.194631  │ -0.202779 │
# │ 13  │ 5561     │ -0.2    │ -0.198302  │ -0.191086 │
# │ 14  │ 5563     │ 0.2     │ 0.220495   │ 0.215094  │
# │ 15  │ 5576     │ 0.2     │ 0.259006   │ 0.259868  │
# Grouped ran: 47 iters and Ungrouped ran: 27 iters
#
#
# running 26 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 3581     │ -0.2    │ -0.20277  │ -0.199983 │
# │ 2   │ 3582     │ 0.2     │ 0.187005  │ 0.185688  │
# │ 3   │ 3590     │ 0.2     │ 0.21459   │ 0.211913  │
# │ 4   │ 5142     │ 0.2     │ 0.141167  │ 0.142831  │
# │ 5   │ 5149     │ -0.2    │ 0.0       │ 0.0       │
# │ 6   │ 5150     │ 0.2     │ 0.0       │ 0.0       │
# │ 7   │ 5550     │ -0.2    │ -0.149418 │ -0.139129 │
# │ 8   │ 5551     │ 0.2     │ 0.211472  │ 0.212556  │
# │ 9   │ 5557     │ 0.2     │ 0.204141  │ 0.207443  │
# │ 10  │ 6810     │ 0.2     │ 0.30299   │ 0.27935   │
# │ 11  │ 6819     │ 0.2     │ 0.0       │ 0.0       │
# │ 12  │ 6820     │ -0.2    │ -0.126261 │ -0.126545 │
# │ 13  │ 8592     │ -0.2    │ -0.185733 │ -0.189021 │
# │ 14  │ 8597     │ 0.2     │ 0.17341   │ 0.178334  │
# │ 15  │ 8599     │ 0.2     │ 0.1758    │ 0.175787  │
# Grouped ran: 17 iters and Ungrouped ran: 17 iters
#
#
# running 27 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 1763     │ -0.2    │ 0.0       │ 0.0       │
# │ 2   │ 1769     │ 0.2     │ 0.1776    │ 0.180706  │
# │ 3   │ 1779     │ 0.2     │ 0.160807  │ 0.147812  │
# │ 4   │ 4051     │ 0.2     │ 0.198907  │ 0.0       │
# │ 5   │ 4053     │ 0.2     │ 0.227077  │ 0.191574  │
# │ 6   │ 4056     │ 0.2     │ 0.238423  │ 0.223716  │
# │ 7   │ 7853     │ 0.2     │ 0.192748  │ 0.205387  │
# │ 8   │ 7855     │ -0.2    │ -0.212717 │ -0.221626 │
# │ 9   │ 7858     │ 0.2     │ 0.182596  │ 0.181319  │
# │ 10  │ 7874     │ -0.2    │ -0.208685 │ -0.197735 │
# │ 11  │ 7875     │ 0.2     │ 0.191147  │ 0.186841  │
# │ 12  │ 7877     │ -0.2    │ -0.19801  │ -0.198085 │
# │ 13  │ 8462     │ 0.2     │ 0.190044  │ 0.184566  │
# │ 14  │ 8470     │ -0.2    │ -0.208705 │ -0.215447 │
# │ 15  │ 8475     │ 0.2     │ 0.183885  │ 0.177997  │
# Grouped ran: 19 iters and Ungrouped ran: 19 iters
#
#
# running 28 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 866      │ 0.2     │ 0.0       │ 0.18571   │
# │ 2   │ 867      │ 0.2     │ 0.274378  │ 0.17858   │
# │ 3   │ 877      │ 0.2     │ 0.0       │ 0.184134  │
# │ 4   │ 2463     │ -0.2    │ -0.24603  │ -0.243741 │
# │ 5   │ 2465     │ 0.2     │ 0.177642  │ 0.180328  │
# │ 6   │ 2467     │ 0.2     │ 0.190009  │ 0.200214  │
# │ 7   │ 3942     │ 0.2     │ 0.268328  │ 0.237613  │
# │ 8   │ 3944     │ 0.2     │ 0.0       │ 0.143982  │
# │ 9   │ 3946     │ 0.2     │ 0.14041   │ 0.0       │
# │ 10  │ 4322     │ -0.2    │ -0.167998 │ -0.167483 │
# │ 11  │ 4327     │ 0.2     │ 0.213506  │ 0.191292  │
# │ 12  │ 4337     │ 0.2     │ 0.176862  │ 0.203418  │
# │ 13  │ 4945     │ -0.2    │ -0.23902  │ -0.177993 │
# │ 14  │ 4950     │ -0.2    │ 0.0       │ 0.0       │
# │ 15  │ 4951     │ 0.2     │ 0.0       │ 0.0       │
# Grouped ran: 26 iters and Ungrouped ran: 24 iters
#
#
# running 29 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 1841     │ 0.2     │ 0.219625  │ 0.220151  │
# │ 2   │ 1853     │ -0.2    │ -0.209032 │ -0.216196 │
# │ 3   │ 1856     │ -0.2    │ -0.218888 │ -0.21651  │
# │ 4   │ 3623     │ -0.2    │ -0.235565 │ -0.172261 │
# │ 5   │ 3627     │ -0.2    │ -0.215738 │ 0.0       │
# │ 6   │ 3629     │ 0.2     │ 0.169197  │ 0.163373  │
# │ 7   │ 7847     │ -0.2    │ -0.165625 │ -0.151918 │
# │ 8   │ 7852     │ 0.2     │ 0.180738  │ 0.183781  │
# │ 9   │ 7859     │ -0.2    │ -0.21471  │ -0.224921 │
# │ 10  │ 8384     │ 0.2     │ 0.183903  │ 0.171137  │
# │ 11  │ 8385     │ 0.2     │ 0.156672  │ 0.108891  │
# │ 12  │ 8391     │ 0.2     │ 0.220977  │ 0.0       │
# │ 13  │ 8828     │ 0.2     │ 0.203146  │ 0.213162  │
# │ 14  │ 8838     │ 0.2     │ 0.205899  │ 0.202997  │
# │ 15  │ 8839     │ -0.2    │ -0.216019 │ -0.21935  │
# Grouped ran: 23 iters and Ungrouped ran: 20 iters
#
#
# running 30 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 1202     │ 0.2     │ 0.182646  │ 0.170722  │
# │ 2   │ 1209     │ -0.2    │ 0.0       │ 0.0       │
# │ 3   │ 1219     │ 0.2     │ 0.144389  │ 0.147733  │
# │ 4   │ 1627     │ 0.2     │ 0.171171  │ 0.196186  │
# │ 5   │ 1629     │ 0.2     │ 0.136716  │ 0.154466  │
# │ 6   │ 1635     │ -0.2    │ 0.0       │ -0.198199 │
# │ 7   │ 4141     │ -0.2    │ 0.0       │ 0.0       │
# │ 8   │ 4144     │ 0.2     │ 0.0       │ 0.0       │
# │ 9   │ 4148     │ 0.2     │ 0.0       │ 0.0       │
# │ 10  │ 4205     │ 0.2     │ 0.193224  │ 0.19437   │
# │ 11  │ 4208     │ 0.2     │ 0.239814  │ 0.231159  │
# │ 12  │ 4214     │ 0.2     │ 0.138638  │ 0.144445  │
# │ 13  │ 7890     │ 0.2     │ 0.195414  │ 0.206757  │
# │ 14  │ 7897     │ 0.2     │ 0.215325  │ 0.215457  │
# │ 15  │ 7899     │ -0.2    │ -0.206377 │ -0.201625 │
# Grouped ran: 21 iters and Ungrouped ran: 22 iters
#
#
# running 31 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped    │
# │     │ Int64    │ Float64 │ Float64   │ Float64    │
# ├─────┼──────────┼─────────┼───────────┼────────────┤
# │ 1   │ 921      │ 0.2     │ 0.200442  │ 0.185231   │
# │ 2   │ 929      │ -0.2    │ -0.209086 │ -0.219338  │
# │ 3   │ 933      │ -0.2    │ -0.200295 │ -0.19738   │
# │ 4   │ 2466     │ 0.2     │ 0.185887  │ 0.17779    │
# │ 5   │ 2467     │ -0.2    │ -0.281707 │ -0.274849  │
# │ 6   │ 2469     │ -0.2    │ 0.0       │ 0.0        │
# │ 7   │ 2527     │ -0.2    │ -0.274349 │ -0.299588  │
# │ 8   │ 2528     │ -0.2    │ -0.12722  │ 0.0        │
# │ 9   │ 2531     │ -0.2    │ -0.164307 │ -0.158665  │
# │ 10  │ 4270     │ 0.2     │ 0.0       │ 0.0        │
# │ 11  │ 4271     │ -0.2    │ 0.0       │ -0.0994396 │
# │ 12  │ 4280     │ 0.2     │ 0.0       │ 0.0842161  │
# │ 13  │ 7942     │ 0.2     │ 0.209909  │ 0.200911   │
# │ 14  │ 7943     │ 0.2     │ 0.19846   │ 0.200135   │
# │ 15  │ 7951     │ 0.2     │ 0.181574  │ 0.186929   │
# Grouped ran: 36 iters and Ungrouped ran: 30 iters
#
#
# running 32 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 5602     │ 0.2     │ 0.0       │ 0.0       │
# │ 2   │ 5603     │ -0.2    │ -0.176344 │ -0.121228 │
# │ 3   │ 5604     │ -0.2    │ 0.0       │ -0.117863 │
# │ 4   │ 6725     │ 0.2     │ 0.184385  │ 0.169557  │
# │ 5   │ 6727     │ 0.2     │ 0.0       │ 0.0       │
# │ 6   │ 6738     │ -0.2    │ -0.193366 │ -0.193973 │
# │ 7   │ 7543     │ 0.2     │ 0.166572  │ 0.173562  │
# │ 8   │ 7546     │ 0.2     │ 0.205759  │ 0.193916  │
# │ 9   │ 7549     │ -0.2    │ -0.224843 │ -0.220507 │
# │ 10  │ 8783     │ 0.2     │ 0.197517  │ 0.200252  │
# │ 11  │ 8794     │ -0.2    │ -0.228777 │ -0.236312 │
# │ 12  │ 8795     │ -0.2    │ -0.140769 │ -0.156963 │
# │ 13  │ 9790     │ -0.2    │ -0.152907 │ -0.15298  │
# │ 14  │ 9793     │ 0.2     │ 0.179987  │ 0.183593  │
# │ 15  │ 9796     │ -0.2    │ -0.216467 │ -0.209301 │
# Grouped ran: 17 iters and Ungrouped ran: 18 iters
#
#
# running 33 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 3485     │ 0.2     │ 0.20682   │ 0.209322  │
# │ 2   │ 3491     │ 0.2     │ 0.158141  │ 0.158936  │
# │ 3   │ 3498     │ -0.2    │ -0.22475  │ -0.210685 │
# │ 4   │ 4205     │ 0.2     │ 0.243584  │ 0.256097  │
# │ 5   │ 4209     │ 0.2     │ 0.181506  │ 0.180617  │
# │ 6   │ 4211     │ -0.2    │ -0.195784 │ -0.181547 │
# │ 7   │ 5191     │ -0.2    │ -0.182735 │ -0.175959 │
# │ 8   │ 5193     │ -0.2    │ 0.0       │ -0.192849 │
# │ 9   │ 5194     │ 0.2     │ 0.104536  │ 0.245401  │
# │ 10  │ 9652     │ -0.2    │ -0.256142 │ -0.237779 │
# │ 11  │ 9654     │ 0.2     │ 0.215022  │ 0.217372  │
# │ 12  │ 9657     │ -0.2    │ -0.14919  │ -0.159937 │
# │ 13  │ 9722     │ 0.2     │ 0.0       │ 0.0       │
# │ 14  │ 9735     │ -0.2    │ 0.0       │ 0.0       │
# │ 15  │ 9736     │ 0.2     │ 0.18404   │ 0.150534  │
# Grouped ran: 29 iters and Ungrouped ran: 17 iters
#
#
# running 34 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 1474     │ -0.2    │ -0.200534 │ -0.189587 │
# │ 2   │ 1476     │ -0.2    │ -0.173773 │ -0.177222 │
# │ 3   │ 1478     │ -0.2    │ -0.165739 │ -0.165041 │
# │ 4   │ 1652     │ -0.2    │ -0.226262 │ -0.23577  │
# │ 5   │ 1658     │ 0.2     │ 0.0       │ 0.0       │
# │ 6   │ 1660     │ -0.2    │ 0.0       │ -0.212187 │
# │ 7   │ 6411     │ 0.2     │ 0.230199  │ 0.229748  │
# │ 8   │ 6415     │ 0.2     │ 0.188484  │ 0.184975  │
# │ 9   │ 6420     │ -0.2    │ -0.187881 │ -0.182334 │
# │ 10  │ 6647     │ 0.2     │ 0.0       │ 0.0       │
# │ 11  │ 6652     │ 0.2     │ 0.0       │ 0.0       │
# │ 12  │ 6660     │ -0.2    │ 0.0       │ 0.0       │
# │ 13  │ 8501     │ 0.2     │ 0.203415  │ 0.197326  │
# │ 14  │ 8505     │ -0.2    │ -0.187009 │ -0.173456 │
# │ 15  │ 8519     │ -0.2    │ -0.181809 │ -0.178592 │
# Grouped ran: 29 iters and Ungrouped ran: 15 iters
#
#
# running 35 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 147      │ 0.2     │ 0.192099  │ 0.248691  │
# │ 2   │ 150      │ -0.2    │ -0.200054 │ -0.217644 │
# │ 3   │ 154      │ 0.2     │ 0.0       │ 0.0       │
# │ 4   │ 3690     │ 0.2     │ 0.180754  │ 0.189997  │
# │ 5   │ 3696     │ -0.2    │ -0.183107 │ -0.178763 │
# │ 6   │ 3700     │ -0.2    │ -0.178821 │ -0.175349 │
# │ 7   │ 7002     │ -0.2    │ -0.196966 │ -0.192597 │
# │ 8   │ 7012     │ 0.2     │ 0.200987  │ 0.197235  │
# │ 9   │ 7017     │ -0.2    │ -0.183011 │ -0.191055 │
# │ 10  │ 7827     │ -0.2    │ -0.156593 │ -0.157603 │
# │ 11  │ 7831     │ -0.2    │ 0.0       │ 0.0       │
# │ 12  │ 7834     │ -0.2    │ -0.215017 │ -0.215996 │
# │ 13  │ 9041     │ -0.2    │ -0.182963 │ -0.182303 │
# │ 14  │ 9046     │ 0.2     │ 0.211481  │ 0.205809  │
# │ 15  │ 9050     │ 0.2     │ 0.0       │ 0.0       │
# Grouped ran: 17 iters and Ungrouped ran: 15 iters
#
#
# running 36 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 727      │ 0.2     │ 0.21932   │ 0.205198  │
# │ 2   │ 731      │ -0.2    │ -0.188633 │ -0.20549  │
# │ 3   │ 733      │ 0.2     │ 0.211394  │ 0.20755   │
# │ 4   │ 4221     │ 0.2     │ 0.0       │ 0.105325  │
# │ 5   │ 4223     │ -0.2    │ 0.0       │ 0.0       │
# │ 6   │ 4234     │ -0.2    │ -0.110839 │ -0.123223 │
# │ 7   │ 4265     │ 0.2     │ 0.219323  │ 0.218347  │
# │ 8   │ 4273     │ 0.2     │ 0.146297  │ 0.153559  │
# │ 9   │ 4275     │ 0.2     │ 0.200694  │ 0.203842  │
# │ 10  │ 4881     │ 0.2     │ 0.248183  │ 0.246166  │
# │ 11  │ 4882     │ -0.2    │ 0.0       │ 0.0       │
# │ 12  │ 4884     │ -0.2    │ 0.0       │ -0.104336 │
# │ 13  │ 6832     │ 0.2     │ 0.196281  │ 0.184186  │
# │ 14  │ 6836     │ -0.2    │ 0.0       │ -0.177082 │
# │ 15  │ 6837     │ 0.2     │ 0.153065  │ 0.228564  │
# Grouped ran: 15 iters and Ungrouped ran: 24 iters
#
#
# running 37 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 967      │ -0.2    │ -0.196192 │ 0.0       │
# │ 2   │ 973      │ -0.2    │ -0.216607 │ -0.217662 │
# │ 3   │ 974      │ -0.2    │ -0.168973 │ -0.110856 │
# │ 4   │ 2142     │ 0.2     │ 0.0       │ 0.099     │
# │ 5   │ 2149     │ 0.2     │ 0.0       │ 0.0       │
# │ 6   │ 2151     │ -0.2    │ -0.15073  │ -0.157219 │
# │ 7   │ 3022     │ -0.2    │ 0.0       │ 0.0       │
# │ 8   │ 3028     │ 0.2     │ 0.231461  │ 0.231773  │
# │ 9   │ 3038     │ -0.2    │ 0.0       │ 0.0       │
# │ 10  │ 8584     │ -0.2    │ -0.199501 │ -0.178552 │
# │ 11  │ 8585     │ -0.2    │ -0.209003 │ -0.23157  │
# │ 12  │ 8591     │ 0.2     │ 0.230505  │ 0.227926  │
# │ 13  │ 9585     │ -0.2    │ -0.201293 │ -0.156206 │
# │ 14  │ 9587     │ 0.2     │ 0.145849  │ 0.0       │
# │ 15  │ 9591     │ -0.2    │ -0.173386 │ -0.264342 │
# Grouped ran: 45 iters and Ungrouped ran: 33 iters
#
#
# running 38 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 6345     │ -0.2    │ -0.260785 │ -0.221457 │
# │ 2   │ 6353     │ 0.2     │ 0.121348  │ 0.20133   │
# │ 3   │ 6358     │ -0.2    │ 0.0       │ -0.175144 │
# │ 4   │ 8206     │ 0.2     │ 0.0       │ 0.0       │
# │ 5   │ 8209     │ 0.2     │ 0.16767   │ 0.268441  │
# │ 6   │ 8218     │ 0.2     │ 0.0       │ 0.0       │
# │ 7   │ 9295     │ -0.2    │ -0.255598 │ -0.259138 │
# │ 8   │ 9296     │ -0.2    │ -0.128824 │ -0.142393 │
# │ 9   │ 9299     │ -0.2    │ -0.188364 │ -0.195104 │
# │ 10  │ 9343     │ -0.2    │ -0.253909 │ -0.253623 │
# │ 11  │ 9353     │ -0.2    │ -0.152437 │ -0.160072 │
# │ 12  │ 9358     │ -0.2    │ -0.184112 │ -0.18027  │
# │ 13  │ 9787     │ -0.2    │ -0.200286 │ -0.211492 │
# │ 14  │ 9792     │ 0.2     │ 0.159198  │ 0.171837  │
# │ 15  │ 9795     │ -0.2    │ -0.217248 │ -0.222304 │
# Grouped ran: 26 iters and Ungrouped ran: 18 iters
#
#
# running 39 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 741      │ -0.2    │ -0.200379 │ -0.195624 │
# │ 2   │ 745      │ 0.2     │ 0.16451   │ 0.168617  │
# │ 3   │ 756      │ 0.2     │ 0.174264  │ 0.182254  │
# │ 4   │ 3591     │ -0.2    │ -0.193137 │ -0.197661 │
# │ 5   │ 3595     │ -0.2    │ -0.15754  │ -0.173309 │
# │ 6   │ 3596     │ -0.2    │ -0.170688 │ -0.165287 │
# │ 7   │ 5308     │ 0.2     │ 0.216196  │ 0.219245  │
# │ 8   │ 5310     │ -0.2    │ -0.18167  │ -0.175781 │
# │ 9   │ 5314     │ 0.2     │ 0.214763  │ 0.218596  │
# │ 10  │ 5914     │ -0.2    │ -0.154533 │ -0.157043 │
# │ 11  │ 5916     │ -0.2    │ -0.237297 │ -0.232912 │
# │ 12  │ 5918     │ -0.2    │ -0.203443 │ -0.21003  │
# │ 13  │ 6791     │ -0.2    │ 0.0       │ -0.182702 │
# │ 14  │ 6794     │ -0.2    │ -0.200498 │ -0.233141 │
# │ 15  │ 6799     │ 0.2     │ 0.192264  │ 0.205075  │
# Grouped ran: 19 iters and Ungrouped ran: 16 iters
#
#
# running 40 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped  │ grouped   │
# │     │ Int64    │ Float64 │ Float64    │ Float64   │
# ├─────┼──────────┼─────────┼────────────┼───────────┤
# │ 1   │ 2106     │ 0.2     │ 0.218256   │ 0.258049  │
# │ 2   │ 2115     │ -0.2    │ 0.0        │ 0.0       │
# │ 3   │ 2118     │ 0.2     │ 0.0        │ 0.0       │
# │ 4   │ 5208     │ 0.2     │ 0.198806   │ 0.194386  │
# │ 5   │ 5216     │ -0.2    │ -0.217271  │ -0.207706 │
# │ 6   │ 5220     │ 0.2     │ 0.172019   │ 0.1737    │
# │ 7   │ 7141     │ -0.2    │ -0.114383  │ 0.0       │
# │ 8   │ 7142     │ 0.2     │ 0.0        │ 0.0       │
# │ 9   │ 7150     │ -0.2    │ -0.0783932 │ -0.195403 │
# │ 10  │ 8286     │ 0.2     │ 0.172515   │ 0.190665  │
# │ 11  │ 8298     │ 0.2     │ 0.0        │ 0.112311  │
# │ 12  │ 8299     │ -0.2    │ 0.0        │ -0.141351 │
# │ 13  │ 9850     │ -0.2    │ -0.204696  │ -0.20829  │
# │ 14  │ 9854     │ 0.2     │ 0.188431   │ 0.166481  │
# │ 15  │ 9859     │ -0.2    │ -0.289446  │ -0.28754  │
# Grouped ran: 22 iters and Ungrouped ran: 31 iters
#
#
# running 41 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 1063     │ 0.2     │ 0.205891  │ 0.206393  │
# │ 2   │ 1067     │ -0.2    │ -0.217943 │ -0.216719 │
# │ 3   │ 1068     │ -0.2    │ -0.171761 │ -0.175703 │
# │ 4   │ 1262     │ 0.2     │ 0.267475  │ 0.251998  │
# │ 5   │ 1267     │ 0.2     │ 0.211357  │ 0.208937  │
# │ 6   │ 1280     │ 0.2     │ 0.168953  │ 0.16547   │
# │ 7   │ 1948     │ -0.2    │ 0.0       │ -0.230609 │
# │ 8   │ 1957     │ 0.2     │ 0.257051  │ 0.184397  │
# │ 9   │ 1959     │ 0.2     │ 0.114501  │ 0.217954  │
# │ 10  │ 2385     │ 0.2     │ 0.251758  │ 0.281651  │
# │ 11  │ 2396     │ -0.2    │ -0.205089 │ 0.0       │
# │ 12  │ 2398     │ -0.2    │ -0.163275 │ -0.121839 │
# │ 13  │ 7187     │ 0.2     │ 0.207577  │ 0.205256  │
# │ 14  │ 7191     │ -0.2    │ -0.192243 │ -0.189075 │
# │ 15  │ 7193     │ -0.2    │ -0.170072 │ -0.174115 │
# Grouped ran: 26 iters and Ungrouped ran: 27 iters
#
#
# running 42 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 3646     │ 0.2     │ 0.231878  │ 0.231876  │
# │ 2   │ 3649     │ -0.2    │ -0.239124 │ -0.239124 │
# │ 3   │ 3659     │ -0.2    │ -0.209763 │ -0.209761 │
# │ 4   │ 6235     │ -0.2    │ -0.188415 │ -0.188378 │
# │ 5   │ 6237     │ -0.2    │ -0.191883 │ -0.191918 │
# │ 6   │ 6239     │ 0.2     │ 0.22017   │ 0.22018   │
# │ 7   │ 6962     │ 0.2     │ 0.213056  │ 0.213054  │
# │ 8   │ 6963     │ -0.2    │ -0.204252 │ -0.204253 │
# │ 9   │ 6967     │ 0.2     │ 0.213965  │ 0.213964  │
# │ 10  │ 7051     │ -0.2    │ -0.152832 │ -0.152831 │
# │ 11  │ 7059     │ -0.2    │ -0.25517  │ -0.255166 │
# │ 12  │ 7060     │ -0.2    │ -0.213641 │ -0.213637 │
# │ 13  │ 9569     │ 0.2     │ 0.230255  │ 0.230254  │
# │ 14  │ 9573     │ 0.2     │ 0.17434   │ 0.174341  │
# │ 15  │ 9576     │ -0.2    │ -0.165991 │ -0.16599  │
# Grouped ran: 24 iters and Ungrouped ran: 25 iters
#
#
# running 43 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped    │
# │     │ Int64    │ Float64 │ Float64   │ Float64    │
# ├─────┼──────────┼─────────┼───────────┼────────────┤
# │ 1   │ 2901     │ -0.2    │ -0.142601 │ -0.151484  │
# │ 2   │ 2914     │ -0.2    │ -0.178164 │ -0.179316  │
# │ 3   │ 2916     │ -0.2    │ -0.219575 │ -0.220398  │
# │ 4   │ 6532     │ -0.2    │ 0.0       │ -0.0555001 │
# │ 5   │ 6534     │ 0.2     │ 0.0       │ 0.0        │
# │ 6   │ 6539     │ 0.2     │ 0.227455  │ 0.235752   │
# │ 7   │ 6682     │ -0.2    │ -0.20661  │ -0.208783  │
# │ 8   │ 6694     │ -0.2    │ -0.209747 │ -0.200149  │
# │ 9   │ 6697     │ 0.2     │ 0.171265  │ 0.162437   │
# │ 10  │ 8370     │ 0.2     │ 0.0       │ 0.0        │
# │ 11  │ 8377     │ 0.2     │ 0.0       │ 0.0        │
# │ 12  │ 8380     │ 0.2     │ 0.150314  │ 0.147243   │
# │ 13  │ 9145     │ 0.2     │ 0.166771  │ 0.151409   │
# │ 14  │ 9148     │ -0.2    │ -0.264872 │ -0.256684  │
# │ 15  │ 9155     │ 0.2     │ 0.256827  │ 0.256179   │
# Grouped ran: 21 iters and Ungrouped ran: 25 iters
#
#
# running 44 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 404      │ 0.2     │ 0.220984  │ 0.19668   │
# │ 2   │ 406      │ 0.2     │ 0.200708  │ 0.0       │
# │ 3   │ 415      │ 0.2     │ 0.201742  │ 0.22694   │
# │ 4   │ 2708     │ 0.2     │ 0.203821  │ 0.129065  │
# │ 5   │ 2711     │ 0.2     │ 0.207693  │ 0.0       │
# │ 6   │ 2714     │ -0.2    │ -0.215172 │ -0.169013 │
# │ 7   │ 3487     │ -0.2    │ -0.220481 │ -0.24543  │
# │ 8   │ 3489     │ -0.2    │ -0.215732 │ -0.211773 │
# │ 9   │ 3498     │ -0.2    │ -0.192731 │ -0.214546 │
# │ 10  │ 4007     │ -0.2    │ -0.145167 │ -0.189613 │
# │ 11  │ 4009     │ -0.2    │ 0.0       │ 0.0       │
# │ 12  │ 4020     │ 0.2     │ 0.0       │ 0.145004  │
# │ 13  │ 6252     │ -0.2    │ 0.0       │ 0.0       │
# │ 14  │ 6254     │ -0.2    │ -0.122852 │ 0.0       │
# │ 15  │ 6257     │ 0.2     │ 0.0       │ 0.102298  │
# Grouped ran: 22 iters and Ungrouped ran: 18 iters
#
#
# running 45 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 265      │ -0.2    │ 0.0       │ -0.226963 │
# │ 2   │ 266      │ -0.2    │ -0.266914 │ -0.21675  │
# │ 3   │ 280      │ 0.2     │ 0.199542  │ 0.214442  │
# │ 4   │ 982      │ -0.2    │ 0.0       │ 0.0       │
# │ 5   │ 987      │ 0.2     │ 0.197986  │ 0.198597  │
# │ 6   │ 995      │ -0.2    │ -0.183607 │ -0.173181 │
# │ 7   │ 7169     │ 0.2     │ 0.195277  │ 0.181835  │
# │ 8   │ 7170     │ -0.2    │ -0.178088 │ 0.0       │
# │ 9   │ 7178     │ -0.2    │ -0.181039 │ -0.152378 │
# │ 10  │ 7487     │ 0.2     │ 0.195506  │ 0.202788  │
# │ 11  │ 7489     │ -0.2    │ -0.211009 │ -0.200905 │
# │ 12  │ 7493     │ -0.2    │ -0.201876 │ -0.206404 │
# │ 13  │ 9045     │ -0.2    │ -0.138139 │ -0.131277 │
# │ 14  │ 9055     │ 0.2     │ 0.249844  │ 0.245533  │
# │ 15  │ 9059     │ 0.2     │ 0.0       │ 0.0       │
# Grouped ran: 16 iters and Ungrouped ran: 21 iters
#
#
# running 46 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ...
# │ 1   │ 2501     │ 0.2     │ 0.161709  │ 0.166018  │
# │ 2   │ 2505     │ 0.2     │ 0.248525  │ 0.242761  │
# │ 3   │ 2512     │ -0.2    │ -0.169765 │ -0.168375 │
# │ 4   │ 2842     │ 0.2     │ 0.273557  │ 0.274726  │
# │ 5   │ 2847     │ 0.2     │ 0.190144  │ 0.187435  │
# │ 6   │ 2860     │ 0.2     │ 0.152276  │ 0.16162   │
# │ 7   │ 3862     │ -0.2    │ -0.184896 │ -0.126283 │
# │ 8   │ 3870     │ -0.2    │ -0.200106 │ -0.173018 │
# │ 9   │ 3880     │ 0.2     │ 0.174426  │ 0.0       │
# │ 10  │ 5348     │ 0.2     │ 0.0       │ 0.174465  │
# │ 11  │ 5357     │ -0.2    │ 0.0       │ 0.0       │
# │ 12  │ 5359     │ 0.2     │ 0.171691  │ 0.177337  │
# │ 13  │ 7610     │ -0.2    │ -0.213709 │ -0.217882 │
# │ 14  │ 7612     │ 0.2     │ 0.238527  │ 0.238029  │
# │ 15  │ 7613     │ 0.2     │ 0.181941  │ 0.172125  │
# Grouped ran: 20 iters and Ungrouped ran: 20 iters
#
#
# running 87 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 868      │ 0.2     │ 0.171486  │ 0.162245  │
# │ 2   │ 872      │ -0.2    │ -0.221096 │ -0.211272 │
# │ 3   │ 877      │ 0.2     │ 0.170054  │ 0.159664  │
# │ 4   │ 2763     │ -0.2    │ 0.0       │ 0.0       │
# │ 5   │ 2769     │ 0.2     │ 0.157475  │ 0.15078   │
# │ 6   │ 2778     │ -0.2    │ -0.196545 │ -0.226326 │
# │ 7   │ 2787     │ 0.2     │ 0.242107  │ 0.244246  │
# │ 8   │ 2788     │ 0.2     │ 0.159658  │ 0.167405  │
# │ 9   │ 2794     │ 0.2     │ 0.201167  │ 0.196753  │
# │ 10  │ 5562     │ 0.2     │ 0.181704  │ 0.180772  │
# │ 11  │ 5576     │ 0.2     │ 0.213228  │ 0.214984  │
# │ 12  │ 5578     │ 0.2     │ 0.182161  │ 0.179077  │
# │ 13  │ 7624     │ -0.2    │ -0.19248  │ -0.185624 │
# │ 14  │ 7626     │ -0.2    │ -0.17461  │ -0.169    │
# │ 15  │ 7627     │ 0.2     │ 0.173678  │ 0.163761  │
# Grouped ran: 22 iters and Ungrouped ran: 22 iters
#
#
# running 88 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped    │
# │     │ Int64    │ Float64 │ Float64   │ Float64    │
# ├─────┼──────────┼─────────┼───────────┼────────────┤
# │ 1   │ 1163     │ 0.2     │ 0.179757  │ 0.170979   │
# │ 2   │ 1169     │ 0.2     │ 0.176871  │ 0.170919   │
# │ 3   │ 1172     │ 0.2     │ 0.201193  │ 0.204171   │
# │ 4   │ 2943     │ -0.2    │ -0.249099 │ -0.0735837 │
# │ 5   │ 2947     │ 0.2     │ 0.203034  │ 0.0        │
# │ 6   │ 2948     │ 0.2     │ 0.175304  │ 0.278223   │
# │ 7   │ 3403     │ 0.2     │ 0.216561  │ 0.23603    │
# │ 8   │ 3412     │ -0.2    │ -0.225471 │ -0.21527   │
# │ 9   │ 3417     │ -0.2    │ -0.233453 │ -0.241913  │
# │ 10  │ 4345     │ 0.2     │ 0.181197  │ 0.222933   │
# │ 11  │ 4347     │ -0.2    │ -0.181976 │ -0.230867  │
# │ 12  │ 4358     │ 0.2     │ 0.0       │ 0.210458   │
# │ 13  │ 4925     │ -0.2    │ -0.194826 │ 0.0        │
# │ 14  │ 4934     │ 0.2     │ 0.179485  │ 0.244034   │
# │ 15  │ 4939     │ -0.2    │ -0.244761 │ -0.150003  │
# Grouped ran: 33 iters and Ungrouped ran: 19 iters
#
#
# running 89 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 562      │ -0.2    │ -0.244936 │ -0.229249 │
# │ 2   │ 567      │ -0.2    │ -0.230812 │ -0.216886 │
# │ 3   │ 575      │ -0.2    │ 0.0       │ 0.0       │
# │ 4   │ 1868     │ 0.2     │ 0.189178  │ 0.19605   │
# │ 5   │ 1876     │ -0.2    │ -0.187691 │ -0.175196 │
# │ 6   │ 1878     │ -0.2    │ -0.208113 │ -0.217305 │
# │ 7   │ 4083     │ -0.2    │ -0.201822 │ -0.21317  │
# │ 8   │ 4087     │ 0.2     │ 0.171444  │ 0.200273  │
# │ 9   │ 4098     │ 0.2     │ 0.209279  │ 0.195646  │
# │ 10  │ 7702     │ 0.2     │ 0.245621  │ 0.229589  │
# │ 11  │ 7703     │ 0.2     │ 0.195579  │ 0.205351  │
# │ 12  │ 7706     │ -0.2    │ -0.182799 │ -0.19097  │
# │ 13  │ 7964     │ 0.2     │ 0.0       │ 0.0930799 │
# │ 14  │ 7965     │ -0.2    │ 0.0       │ 0.0       │
# │ 15  │ 7975     │ -0.2    │ -0.231515 │ -0.142651 │
# Grouped ran: 35 iters and Ungrouped ran: 23 iters
#
#
# running 90 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 2308     │ 0.2     │ 0.167894  │ 0.157821  │
# │ 2   │ 2319     │ -0.2    │ -0.213833 │ -0.20939  │
# │ 3   │ 2320     │ -0.2    │ -0.161216 │ 0.0       │
# │ 4   │ 3088     │ 0.2     │ 0.0       │ 0.0       │
# │ 5   │ 3092     │ 0.2     │ 0.201371  │ 0.204076  │
# │ 6   │ 3094     │ 0.2     │ 0.167559  │ 0.173535  │
# │ 7   │ 4851     │ 0.2     │ 0.193161  │ 0.201785  │
# │ 8   │ 4853     │ -0.2    │ -0.212568 │ -0.213213 │
# │ 9   │ 4855     │ 0.2     │ 0.230999  │ 0.22946   │
# │ 10  │ 6261     │ 0.2     │ 0.177977  │ 0.178093  │
# │ 11  │ 6269     │ -0.2    │ -0.186816 │ -0.188811 │
# │ 12  │ 6272     │ -0.2    │ -0.19864  │ -0.200957 │
# │ 13  │ 7285     │ 0.2     │ 0.236366  │ 0.234688  │
# │ 14  │ 7288     │ -0.2    │ -0.209111 │ -0.207532 │
# │ 15  │ 7297     │ 0.2     │ 0.186392  │ 0.181452  │
# Grouped ran: 24 iters and Ungrouped ran: 21 iters
#
#
# running 91 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 787      │ 0.2     │ 0.0       │ 0.0738684 │
# │ 2   │ 788      │ -0.2    │ 0.0       │ 0.0       │
# │ 3   │ 795      │ -0.2    │ 0.0       │ 0.0       │
# │ 4   │ 1023     │ 0.2     │ 0.187793  │ 0.0       │
# │ 5   │ 1028     │ -0.2    │ -0.212252 │ -0.160172 │
# │ 6   │ 1035     │ -0.2    │ -0.229728 │ -0.296568 │
# │ 7   │ 4189     │ -0.2    │ 0.0       │ 0.0       │
# │ 8   │ 4191     │ -0.2    │ 0.0       │ 0.0       │
# │ 9   │ 4198     │ 0.2     │ 0.0       │ 0.0       │
# │ 10  │ 4865     │ 0.2     │ 0.098794  │ 0.166123  │
# │ 11  │ 4866     │ 0.2     │ 0.329888  │ 0.321144  │
# │ 12  │ 4878     │ 0.2     │ 0.122623  │ 0.0       │
# │ 13  │ 6043     │ -0.2    │ -0.202904 │ -0.208791 │
# │ 14  │ 6051     │ -0.2    │ -0.176813 │ -0.178784 │
# │ 15  │ 6054     │ 0.2     │ 0.0       │ 0.0       │
# Grouped ran: 35 iters and Ungrouped ran: 29 iters
#
#
# running 92 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 1572     │ -0.2    │ 0.0       │ -0.222175 │
# │ 2   │ 1574     │ 0.2     │ 0.0       │ 0.199031  │
# │ 3   │ 1579     │ 0.2     │ 0.176624  │ 0.192857  │
# │ 4   │ 4401     │ 0.2     │ 0.160443  │ 0.152345  │
# │ 5   │ 4411     │ 0.2     │ 0.228714  │ 0.21989   │
# │ 6   │ 4413     │ -0.2    │ -0.203242 │ -0.1876   │
# │ 7   │ 6969     │ 0.2     │ 0.0       │ 0.0       │
# │ 8   │ 6970     │ -0.2    │ 0.0       │ 0.0       │
# │ 9   │ 6976     │ -0.2    │ -0.164133 │ -0.153573 │
# │ 10  │ 7201     │ -0.2    │ 0.0       │ 0.0       │
# │ 11  │ 7214     │ -0.2    │ 0.0       │ 0.0       │
# │ 12  │ 7218     │ -0.2    │ -0.190687 │ -0.201504 │
# │ 13  │ 7662     │ 0.2     │ 0.206394  │ 0.216992  │
# │ 14  │ 7668     │ -0.2    │ -0.118641 │ 0.0       │
# │ 15  │ 7679     │ -0.2    │ 0.0       │ 0.0       │
# Grouped ran: 25 iters and Ungrouped ran: 41 iters
#
#
# running 93 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 1043     │ 0.2     │ 0.197621  │ 0.181625  │
# │ 2   │ 1046     │ -0.2    │ -0.212328 │ -0.132368 │
# │ 3   │ 1056     │ -0.2    │ -0.265755 │ 0.0       │
# │ 4   │ 4782     │ -0.2    │ 0.0       │ -0.178812 │
# │ 5   │ 4790     │ -0.2    │ 0.0       │ -0.213427 │
# │ 6   │ 4798     │ -0.2    │ -0.144922 │ -0.246665 │
# │ 7   │ 4822     │ 0.2     │ 0.206983  │ 0.212283  │
# │ 8   │ 4832     │ -0.2    │ -0.182758 │ -0.181451 │
# │ 9   │ 4838     │ 0.2     │ 0.204182  │ 0.187845  │
# │ 10  │ 6022     │ 0.2     │ 0.265137  │ 0.281295  │
# │ 11  │ 6028     │ -0.2    │ -0.172138 │ -0.186296 │
# │ 12  │ 6035     │ 0.2     │ 0.189148  │ 0.173469  │
# │ 13  │ 6503     │ -0.2    │ -0.196963 │ -0.216231 │
# │ 14  │ 6509     │ 0.2     │ 0.168303  │ 0.175597  │
# │ 15  │ 6517     │ 0.2     │ 0.169369  │ 0.165547  │
# Grouped ran: 22 iters and Ungrouped ran: 20 iters
#
#
# running 94 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 2365     │ 0.2     │ 0.0       │ 0.167887  │
# │ 2   │ 2371     │ 0.2     │ 0.140978  │ 0.173053  │
# │ 3   │ 2380     │ -0.2    │ -0.111398 │ -0.192388 │
# │ 4   │ 3943     │ 0.2     │ 0.166904  │ 0.171799  │
# │ 5   │ 3947     │ 0.2     │ 0.247595  │ 0.248108  │
# │ 6   │ 3958     │ 0.2     │ 0.15302   │ 0.165323  │
# │ 7   │ 5445     │ -0.2    │ -0.149102 │ 0.0       │
# │ 8   │ 5454     │ 0.2     │ 0.0       │ 0.0       │
# │ 9   │ 5458     │ 0.2     │ 0.23367   │ 0.168305  │
# │ 10  │ 9587     │ -0.2    │ -0.195958 │ -0.138895 │
# │ 11  │ 9597     │ 0.2     │ 0.175046  │ 0.0       │
# │ 12  │ 9599     │ -0.2    │ -0.216971 │ -0.221061 │
# │ 13  │ 9803     │ 0.2     │ 0.240823  │ 0.2398    │
# │ 14  │ 9811     │ -0.2    │ -0.185305 │ -0.17111  │
# │ 15  │ 9816     │ -0.2    │ -0.218726 │ -0.221016 │
# Grouped ran: 20 iters and Ungrouped ran: 14 iters
#
#
# running 95 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 3069     │ 0.2     │ 0.197486  │ 0.140053  │
# │ 2   │ 3070     │ 0.2     │ 0.252037  │ 0.217648  │
# │ 3   │ 3076     │ 0.2     │ 0.221659  │ 0.0       │
# │ 4   │ 4885     │ 0.2     │ 0.264299  │ 0.264054  │
# │ 5   │ 4891     │ 0.2     │ 0.25156   │ 0.238591  │
# │ 6   │ 4896     │ -0.2    │ -0.274252 │ -0.245566 │
# │ 7   │ 7623     │ 0.2     │ 0.174873  │ 0.187265  │
# │ 8   │ 7632     │ -0.2    │ -0.160742 │ -0.186166 │
# │ 9   │ 7638     │ -0.2    │ 0.0       │ -0.148869 │
# │ 10  │ 7942     │ -0.2    │ -0.236803 │ -0.241775 │
# │ 11  │ 7944     │ -0.2    │ -0.188394 │ 0.0       │
# │ 12  │ 7960     │ 0.2     │ 0.24819   │ 0.186606  │
# │ 13  │ 8223     │ 0.2     │ 0.177668  │ 0.184045  │
# │ 14  │ 8237     │ -0.2    │ -0.152536 │ -0.14801  │
# │ 15  │ 8240     │ 0.2     │ 0.19012   │ 0.201768  │
# Grouped ran: 24 iters and Ungrouped ran: 31 iters
#
#
# running 96 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 2104     │ -0.2    │ 0.0       │ 0.0       │
# │ 2   │ 2112     │ 0.2     │ 0.160841  │ 0.160937  │
# │ 3   │ 2115     │ 0.2     │ 0.159002  │ 0.158987  │
# │ 4   │ 2209     │ -0.2    │ -0.211156 │ -0.211182 │
# │ 5   │ 2211     │ 0.2     │ 0.195134  │ 0.195144  │
# │ 6   │ 2216     │ -0.2    │ -0.20363  │ -0.2037   │
# │ 7   │ 8985     │ -0.2    │ -0.183989 │ -0.183983 │
# │ 8   │ 8989     │ 0.2     │ 0.195183  │ 0.195227  │
# │ 9   │ 8995     │ 0.2     │ 0.240126  │ 0.240171  │
# │ 10  │ 9290     │ 0.2     │ 0.142894  │ 0.143327  │
# │ 11  │ 9294     │ 0.2     │ 0.0       │ 0.0       │
# │ 12  │ 9299     │ 0.2     │ 0.121635  │ 0.121775  │
# │ 13  │ 9711     │ 0.2     │ 0.174496  │ 0.174612  │
# │ 14  │ 9712     │ 0.2     │ 0.192255  │ 0.192171  │
# │ 15  │ 9714     │ 0.2     │ 0.212167  │ 0.212193  │
# Grouped ran: 18 iters and Ungrouped ran: 23 iters
#
#
# running 97 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 4987     │ 0.2     │ 0.0       │ 0.261497  │
# │ 2   │ 4988     │ -0.2    │ 0.0       │ -0.276357 │
# │ 3   │ 4998     │ 0.2     │ 0.257406  │ 0.182364  │
# │ 4   │ 6421     │ 0.2     │ 0.248632  │ 0.243943  │
# │ 5   │ 6435     │ -0.2    │ -0.191759 │ -0.197441 │
# │ 6   │ 6440     │ -0.2    │ -0.243484 │ -0.219693 │
# │ 7   │ 7822     │ 0.2     │ 0.201989  │ 0.20172   │
# │ 8   │ 7829     │ 0.2     │ 0.200085  │ 0.197985  │
# │ 9   │ 7840     │ 0.2     │ 0.217212  │ 0.205748  │
# │ 10  │ 9741     │ -0.2    │ -0.211548 │ -0.240178 │
# │ 11  │ 9749     │ -0.2    │ -0.153382 │ -0.184514 │
# │ 12  │ 9756     │ -0.2    │ 0.0       │ -0.19793  │
# │ 13  │ 9988     │ -0.2    │ 0.0       │ 0.0       │
# │ 14  │ 9996     │ -0.2    │ -0.124998 │ -0.139526 │
# │ 15  │ 10000    │ 0.2     │ 0.27083   │ 0.259617  │
# Grouped ran: 27 iters and Ungrouped ran: 19 iters
#
#
# running 98 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 985      │ -0.2    │ -0.241705 │ -0.244449 │
# │ 2   │ 991      │ 0.2     │ 0.153045  │ 0.133455  │
# │ 3   │ 1000     │ -0.2    │ -0.20045  │ -0.193323 │
# │ 4   │ 3867     │ 0.2     │ 0.24793   │ 0.216491  │
# │ 5   │ 3874     │ 0.2     │ 0.196397  │ 0.0       │
# │ 6   │ 3877     │ 0.2     │ 0.241847  │ 0.224079  │
# │ 7   │ 5425     │ -0.2    │ -0.180681 │ -0.135609 │
# │ 8   │ 5426     │ -0.2    │ -0.188437 │ -0.201629 │
# │ 9   │ 5433     │ 0.2     │ 0.209231  │ 0.0       │
# │ 10  │ 5601     │ -0.2    │ -0.232617 │ -0.189348 │
# │ 11  │ 5604     │ -0.2    │ 0.0       │ 0.0       │
# │ 12  │ 5605     │ 0.2     │ 0.0       │ 0.0       │
# │ 13  │ 9043     │ 0.2     │ 0.158719  │ 0.144109  │
# │ 14  │ 9055     │ 0.2     │ 0.16594   │ 0.181669  │
# │ 15  │ 9057     │ 0.2     │ 0.270604  │ 0.275583  │
# Grouped ran: 26 iters and Ungrouped ran: 23 iters
#
#
# running 99 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 902      │ -0.2    │ -0.208871 │ -0.209796 │
# │ 2   │ 905      │ -0.2    │ -0.210046 │ -0.198695 │
# │ 3   │ 907      │ -0.2    │ -0.188345 │ -0.189185 │
# │ 4   │ 2123     │ 0.2     │ 0.164583  │ 0.166214  │
# │ 5   │ 2126     │ 0.2     │ 0.215878  │ 0.218113  │
# │ 6   │ 2132     │ 0.2     │ 0.20897   │ 0.200754  │
# │ 7   │ 4363     │ -0.2    │ -0.204211 │ 0.0       │
# │ 8   │ 4370     │ -0.2    │ -0.178774 │ -0.182499 │
# │ 9   │ 4378     │ 0.2     │ 0.204601  │ 0.144593  │
# │ 10  │ 5704     │ -0.2    │ -0.200416 │ -0.197332 │
# │ 11  │ 5705     │ -0.2    │ -0.189591 │ -0.191793 │
# │ 12  │ 5706     │ -0.2    │ -0.180375 │ -0.185395 │
# │ 13  │ 9681     │ -0.2    │ -0.175848 │ -0.177644 │
# │ 14  │ 9692     │ 0.2     │ 0.16701   │ 0.164098  │
# │ 15  │ 9699     │ -0.2    │ -0.238622 │ -0.250949 │
# Grouped ran: 26 iters and Ungrouped ran: 21 iters
#
#
# running 100 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped    │
# │     │ Int64    │ Float64 │ Float64   │ Float64    │
# ├─────┼──────────┼─────────┼───────────┼────────────┤
# │ 1   │ 2605     │ 0.2     │ 0.0       │ 0.0        │
# │ 2   │ 2607     │ -0.2    │ 0.0       │ -0.0875498 │
# │ 3   │ 2620     │ -0.2    │ -0.200751 │ -0.172895  │
# │ 4   │ 6881     │ 0.2     │ 0.212203  │ 0.186894   │
# │ 5   │ 6895     │ 0.2     │ 0.233517  │ 0.214736   │
# │ 6   │ 6896     │ -0.2    │ -0.200471 │ -0.187683  │
# │ 7   │ 8121     │ -0.2    │ -0.289764 │ -0.175808  │
# │ 8   │ 8131     │ -0.2    │ 0.0       │ -0.0848566 │
# │ 9   │ 8132     │ 0.2     │ 0.0       │ 0.0        │
# │ 10  │ 8511     │ -0.2    │ -0.236531 │ -0.124644  │
# │ 11  │ 8513     │ -0.2    │ -0.175556 │ -0.149531  │
# │ 12  │ 8515     │ 0.2     │ 0.177173  │ 0.0        │
# │ 13  │ 9425     │ -0.2    │ -0.174728 │ -0.221678  │
# │ 14  │ 9436     │ -0.2    │ 0.0       │ 0.0        │
# │ 15  │ 9437     │ 0.2     │ 0.0       │ 0.109573   │
# Grouped ran: 23 iters and Ungrouped ran: 19 iters
#
#
# Group IHT found: 1239.0/1500 variantspercentage = 0.826
# Ungrouped IHT found: 1197.0/1500 variantspercentage = 0.798
# Grouped common variant standard errors = 1.7574947734738442percentage = 0.11716631823158961
# Ungrouped common variant standard errors = 1.956367485257751percentage = 0.1304244990171834

# %% [markdown]
# # Negative Binomial

# %%
Random.seed!(2019)
d = NegativeBinomial
l = LogLink()

num_runs = 100
group_found = zeros(num_runs)
ungroup_found = zeros(num_runs)

for i in 1:num_runs
    println("running $i th model")
    gf, uf = compare(d, l)
    group_found[i] = gf
    ungroup_found[i] = uf
end

println("Group IHT found: ", sum(group_found), "/", 15num_runs, " variants", "percentage = ", sum(group_found)/15num_runs)
println("Ungrouped IHT found: ", sum(ungroup_found), "/", 15num_runs, " variants" , "percentage = ", sum(ungroup_found)/15num_runs)
println("Grouped common variant standard errors = ", std(group_found), "percentage = ", std(group_found)/15)
println("Ungrouped common variant standard errors = ", std(ungroup_found), "percentage = ", std(ungroup_found)/15)
# Out:
# running 1 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 3464     │ -0.2    │ -0.214793 │ -0.229371 │
# │ 2   │ 3466     │ -0.2    │ -0.20044  │ -0.192839 │
# │ 3   │ 3468     │ 0.2     │ 0.205078  │ 0.1956    │
# │ 4   │ 4924     │ -0.2    │ -0.147362 │ -0.161833 │
# │ 5   │ 4930     │ 0.2     │ 0.231746  │ 0.229945  │
# │ 6   │ 4938     │ 0.2     │ 0.21064   │ 0.199346  │
# │ 7   │ 5004     │ 0.2     │ 0.19831   │ 0.201262  │
# │ 8   │ 5016     │ -0.2    │ -0.189168 │ -0.198957 │
# │ 9   │ 5020     │ 0.2     │ 0.192298  │ 0.202311  │
# │ 10  │ 5081     │ -0.2    │ -0.123427 │ -0.122367 │
# │ 11  │ 5091     │ -0.2    │ 0.0       │ -0.109817 │
# │ 12  │ 5098     │ 0.2     │ 0.0       │ 0.0       │
# │ 13  │ 7003     │ -0.2    │ -0.240588 │ -0.23592  │
# │ 14  │ 7007     │ -0.2    │ -0.219081 │ -0.219578 │
# │ 15  │ 7018     │ -0.2    │ -0.239348 │ -0.24982  │
# Grouped ran: 17 iters and Ungrouped ran: 18 iters
#
#
# running 2 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped    │
# │     │ Int64    │ Float64 │ Float64   │ Float64    │
# ├─────┼──────────┼─────────┼───────────┼────────────┤
# │ 1   │ 687      │ 0.2     │ 0.0       │ 0.0707893  │
# │ 2   │ 688      │ -0.2    │ 0.0       │ 0.0        │
# │ 3   │ 690      │ 0.2     │ 0.0       │ 0.0        │
# │ 4   │ 3906     │ -0.2    │ 0.0       │ -0.0911471 │
# │ 5   │ 3908     │ 0.2     │ 0.0       │ 0.0        │
# │ 6   │ 3915     │ -0.2    │ 0.0       │ 0.0        │
# │ 7   │ 5601     │ 0.2     │ 0.210404  │ 0.200699   │
# │ 8   │ 5607     │ -0.2    │ -0.15859  │ 0.0        │
# │ 9   │ 5609     │ 0.2     │ 0.0       │ 0.0        │
# │ 10  │ 7441     │ 0.2     │ 0.246897  │ 0.137159   │
# │ 11  │ 7449     │ -0.2    │ -0.198808 │ 0.0        │
# │ 12  │ 7453     │ -0.2    │ -0.238898 │ -0.310023  │
# │ 13  │ 8182     │ 0.2     │ 0.227243  │ 0.209822   │
# │ 14  │ 8190     │ 0.2     │ 0.243159  │ 0.208571   │
# │ 15  │ 8198     │ 0.2     │ 0.167485  │ 0.0        │
# Grouped ran: 27 iters and Ungrouped ran: 15 iters
#
#
# running 3 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped    │
# │     │ Int64    │ Float64 │ Float64   │ Float64    │
# ├─────┼──────────┼─────────┼───────────┼────────────┤
# │ 1   │ 1222     │ -0.2    │ -0.1923   │ -0.1904    │
# │ 2   │ 1232     │ -0.2    │ -0.223148 │ -0.216044  │
# │ 3   │ 1239     │ -0.2    │ -0.215963 │ -0.206797  │
# │ 4   │ 1830     │ 0.2     │ 0.133506  │ 0.0        │
# │ 5   │ 1833     │ -0.2    │ -0.195871 │ 0.0        │
# │ 6   │ 1838     │ -0.2    │ -0.239426 │ -0.195028  │
# │ 7   │ 3325     │ -0.2    │ -0.204722 │ -0.203448  │
# │ 8   │ 3335     │ -0.2    │ -0.207926 │ -0.195102  │
# │ 9   │ 3337     │ 0.2     │ 0.172666  │ 0.168709   │
# │ 10  │ 6409     │ -0.2    │ -0.312873 │ -0.273366  │
# │ 11  │ 6411     │ -0.2    │ 0.0       │ -0.0715887 │
# │ 12  │ 6412     │ 0.2     │ 0.0       │ 0.0        │
# │ 13  │ 8221     │ -0.2    │ 0.0       │ 0.0        │
# │ 14  │ 8229     │ -0.2    │ 0.0       │ 0.0        │
# │ 15  │ 8237     │ -0.2    │ 0.0       │ 0.0        │
# Grouped ran: 61 iters and Ungrouped ran: 16 iters
#
#
# running 4 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 1083     │ 0.2     │ 0.114491  │ 0.231495  │
# │ 2   │ 1091     │ -0.2    │ -0.193503 │ -0.188446 │
# │ 3   │ 1093     │ -0.2    │ -0.206609 │ -0.205055 │
# │ 4   │ 5143     │ 0.2     │ 0.208563  │ 0.218116  │
# │ 5   │ 5148     │ -0.2    │ -0.212756 │ -0.21294  │
# │ 6   │ 5150     │ -0.2    │ -0.169971 │ -0.175985 │
# │ 7   │ 6551     │ -0.2    │ -0.259398 │ -0.233061 │
# │ 8   │ 6558     │ -0.2    │ -0.162406 │ -0.193792 │
# │ 9   │ 6559     │ -0.2    │ -0.125661 │ -0.212075 │
# │ 10  │ 7149     │ -0.2    │ -0.139547 │ -0.133299 │
# │ 11  │ 7154     │ -0.2    │ -0.227167 │ -0.213047 │
# │ 12  │ 7158     │ -0.2    │ -0.160719 │ -0.156261 │
# │ 13  │ 8644     │ 0.2     │ 0.0       │ 0.144061  │
# │ 14  │ 8658     │ 0.2     │ 0.292132  │ 0.186449  │
# │ 15  │ 8659     │ 0.2     │ 0.0       │ 0.171881  │
# Grouped ran: 18 iters and Ungrouped ran: 29 iters
#
#
# running 5 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 2158     │ -0.2    │ 0.0       │ -0.107397 │
# │ 2   │ 2159     │ 0.2     │ 0.0       │ 0.0       │
# │ 3   │ 2160     │ -0.2    │ -0.286183 │ -0.245154 │
# │ 4   │ 3757     │ -0.2    │ -0.137821 │ -0.141564 │
# │ 5   │ 3758     │ -0.2    │ -0.283066 │ -0.254756 │
# │ 6   │ 3759     │ -0.2    │ -0.22559  │ -0.203591 │
# │ 7   │ 4487     │ 0.2     │ 0.212869  │ 0.187573  │
# │ 8   │ 4488     │ 0.2     │ 0.183876  │ 0.194882  │
# │ 9   │ 4491     │ 0.2     │ 0.200091  │ 0.195243  │
# │ 10  │ 6702     │ 0.2     │ 0.237391  │ 0.259703  │
# │ 11  │ 6709     │ -0.2    │ 0.0       │ 0.0       │
# │ 12  │ 6710     │ 0.2     │ 0.0       │ 0.0588304 │
# │ 13  │ 9332     │ -0.2    │ -0.22552  │ -0.220572 │
# │ 14  │ 9337     │ 0.2     │ 0.198159  │ 0.19706   │
# │ 15  │ 9339     │ -0.2    │ -0.166219 │ -0.178771 │
# Grouped ran: 24 iters and Ungrouped ran: 27 iters
#
#
# running 6 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 142      │ -0.2    │ -0.193652 │ -0.218247 │
# │ 2   │ 151      │ 0.2     │ 0.0       │ 0.259774  │
# │ 3   │ 160      │ 0.2     │ 0.0       │ 0.202946  │
# │ 4   │ 782      │ 0.2     │ 0.239842  │ 0.231703  │
# │ 5   │ 791      │ -0.2    │ -0.206541 │ -0.204503 │
# │ 6   │ 794      │ 0.2     │ 0.187709  │ 0.192318  │
# │ 7   │ 7113     │ 0.2     │ 0.145342  │ 0.128967  │
# │ 8   │ 7116     │ 0.2     │ 0.264284  │ 0.264084  │
# │ 9   │ 7120     │ 0.2     │ 0.181987  │ 0.173976  │
# │ 10  │ 7943     │ -0.2    │ -0.255923 │ -0.253766 │
# │ 11  │ 7951     │ 0.2     │ 0.179078  │ 0.170955  │
# │ 12  │ 7954     │ -0.2    │ -0.194127 │ -0.195278 │
# │ 13  │ 9228     │ 0.2     │ 0.0       │ 0.11069   │
# │ 14  │ 9236     │ -0.2    │ 0.0       │ 0.0       │
# │ 15  │ 9239     │ -0.2    │ -0.167315 │ -0.19856  │
# Grouped ran: 21 iters and Ungrouped ran: 15 iters
#
#
# running 7 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 4621     │ 0.2     │ 0.175306  │ 0.177671  │
# │ 2   │ 4623     │ 0.2     │ 0.1997    │ 0.200746  │
# │ 3   │ 4637     │ -0.2    │ -0.223095 │ -0.22355  │
# │ 4   │ 4887     │ -0.2    │ 0.0       │ -0.1885   │
# │ 5   │ 4889     │ 0.2     │ 0.151296  │ 0.168317  │
# │ 6   │ 4897     │ -0.2    │ -0.15304  │ -0.197453 │
# │ 7   │ 4901     │ -0.2    │ -0.231823 │ -0.205237 │
# │ 8   │ 4902     │ -0.2    │ -0.151319 │ -0.165241 │
# │ 9   │ 4904     │ 0.2     │ 0.149068  │ 0.175416  │
# │ 10  │ 4935     │ 0.2     │ 0.0       │ 0.192115  │
# │ 11  │ 4936     │ -0.2    │ 0.0       │ -0.17638  │
# │ 12  │ 4939     │ 0.2     │ 0.13966   │ 0.157601  │
# │ 13  │ 8542     │ 0.2     │ 0.241196  │ 0.210016  │
# │ 14  │ 8543     │ 0.2     │ 0.181     │ 0.175051  │
# │ 15  │ 8560     │ 0.2     │ 0.200414  │ 0.211727  │
# Grouped ran: 28 iters and Ungrouped ran: 24 iters
#
#
# running 8 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 2243     │ 0.2     │ 0.134185  │ 0.134173  │
# │ 2   │ 2251     │ 0.2     │ 0.1937    │ 0.193678  │
# │ 3   │ 2252     │ 0.2     │ 0.162378  │ 0.162369  │
# │ 4   │ 6091     │ 0.2     │ 0.21689   │ 0.216889  │
# │ 5   │ 6094     │ 0.2     │ 0.190978  │ 0.19098   │
# │ 6   │ 6098     │ 0.2     │ 0.184985  │ 0.184996  │
# │ 7   │ 6673     │ 0.2     │ 0.160127  │ 0.160131  │
# │ 8   │ 6676     │ -0.2    │ -0.183602 │ -0.183602 │
# │ 9   │ 6678     │ -0.2    │ -0.256211 │ -0.256204 │
# │ 10  │ 7141     │ -0.2    │ -0.192956 │ -0.192953 │
# │ 11  │ 7146     │ 0.2     │ 0.187991  │ 0.187944  │
# │ 12  │ 7158     │ 0.2     │ 0.208646  │ 0.208637  │
# │ 13  │ 7541     │ -0.2    │ -0.177165 │ -0.177165 │
# │ 14  │ 7548     │ -0.2    │ -0.245499 │ -0.245492 │
# │ 15  │ 7556     │ -0.2    │ -0.214598 │ -0.214594 │
# Grouped ran: 15 iters and Ungrouped ran: 17 iters
#
#
# running 9 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 2082     │ 0.2     │ 0.0       │ 0.0       │
# │ 2   │ 2095     │ -0.2    │ 0.0       │ 0.0       │
# │ 3   │ 2099     │ 0.2     │ 0.0       │ 0.0       │
# │ 4   │ 2845     │ -0.2    │ -0.213649 │ -0.226409 │
# │ 5   │ 2851     │ 0.2     │ 0.231738  │ 0.239029  │
# │ 6   │ 2853     │ 0.2     │ 0.253506  │ 0.245004  │
# │ 7   │ 4332     │ 0.2     │ 0.210543  │ 0.203837  │
# │ 8   │ 4334     │ 0.2     │ 0.206086  │ 0.226617  │
# │ 9   │ 4336     │ 0.2     │ 0.110345  │ 0.112176  │
# │ 10  │ 4529     │ 0.2     │ 0.212587  │ 0.0       │
# │ 11  │ 4535     │ -0.2    │ -0.187445 │ -0.170725 │
# │ 12  │ 4536     │ -0.2    │ -0.172269 │ -0.172256 │
# │ 13  │ 6107     │ 0.2     │ 0.226939  │ 0.222229  │
# │ 14  │ 6108     │ 0.2     │ 0.187457  │ 0.186704  │
# │ 15  │ 6111     │ -0.2    │ -0.192416 │ -0.187345 │
# Grouped ran: 19 iters and Ungrouped ran: 17 iters
#
#
# running 10 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 303      │ 0.2     │ 0.0       │ 0.171374  │
# │ 2   │ 311      │ -0.2    │ 0.0       │ -0.152494 │
# │ 3   │ 320      │ -0.2    │ -0.199992 │ -0.185001 │
# │ 4   │ 4701     │ 0.2     │ 0.218985  │ 0.198724  │
# │ 5   │ 4714     │ -0.2    │ 0.0       │ -0.215755 │
# │ 6   │ 4716     │ 0.2     │ 0.108253  │ 0.240507  │
# │ 7   │ 7225     │ -0.2    │ -0.183662 │ -0.196599 │
# │ 8   │ 7236     │ 0.2     │ 0.258908  │ 0.204325  │
# │ 9   │ 7238     │ -0.2    │ -0.211422 │ 0.0       │
# │ 10  │ 7962     │ 0.2     │ 0.197264  │ 0.191282  │
# │ 11  │ 7971     │ 0.2     │ 0.231397  │ 0.221893  │
# │ 12  │ 7976     │ -0.2    │ -0.209506 │ -0.212976 │
# │ 13  │ 9021     │ 0.2     │ 0.0       │ 0.0       │
# │ 14  │ 9029     │ -0.2    │ -0.164634 │ -0.164053 │
# │ 15  │ 9035     │ 0.2     │ 0.0       │ 0.0       │
# Grouped ran: 24 iters and Ungrouped ran: 22 iters
#
#
# running 11 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 1062     │ 0.2     │ 0.199079  │ 0.205842  │
# │ 2   │ 1063     │ 0.2     │ 0.221117  │ 0.233455  │
# │ 3   │ 1073     │ 0.2     │ 0.151163  │ 0.152156  │
# │ 4   │ 1646     │ -0.2    │ 0.0       │ -0.113566 │
# │ 5   │ 1652     │ 0.2     │ 0.190908  │ 0.208932  │
# │ 6   │ 1657     │ -0.2    │ 0.0       │ 0.0       │
# │ 7   │ 4086     │ -0.2    │ -0.201659 │ -0.211119 │
# │ 8   │ 4097     │ -0.2    │ -0.193688 │ -0.17685  │
# │ 9   │ 4098     │ -0.2    │ -0.182669 │ -0.188742 │
# │ 10  │ 4224     │ 0.2     │ 0.0       │ 0.0       │
# │ 11  │ 4225     │ -0.2    │ 0.0       │ 0.0       │
# │ 12  │ 4227     │ 0.2     │ 0.0       │ 0.0       │
# │ 13  │ 6741     │ 0.2     │ 0.168525  │ 0.190867  │
# │ 14  │ 6743     │ 0.2     │ 0.232491  │ 0.220998  │
# │ 15  │ 6760     │ 0.2     │ 0.153856  │ 0.149744  │
# Grouped ran: 27 iters and Ungrouped ran: 13 iters
#
#
# running 12 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 1430     │ -0.2    │ -0.210879 │ -0.213689 │
# │ 2   │ 1431     │ -0.2    │ -0.244684 │ -0.233348 │
# │ 3   │ 1436     │ -0.2    │ -0.254236 │ -0.236976 │
# │ 4   │ 2624     │ 0.2     │ 0.0       │ 0.155908  │
# │ 5   │ 2631     │ 0.2     │ 0.0       │ 0.138031  │
# │ 6   │ 2636     │ 0.2     │ 0.196363  │ 0.207394  │
# │ 7   │ 3754     │ 0.2     │ 0.168445  │ 0.176851  │
# │ 8   │ 3759     │ -0.2    │ -0.185876 │ -0.190186 │
# │ 9   │ 3760     │ -0.2    │ -0.25161  │ -0.257893 │
# │ 10  │ 7450     │ -0.2    │ -0.235886 │ -0.227415 │
# │ 11  │ 7459     │ -0.2    │ -0.161824 │ -0.16368  │
# │ 12  │ 7460     │ -0.2    │ -0.277037 │ -0.267349 │
# │ 13  │ 8782     │ 0.2     │ 0.0       │ 0.141374  │
# │ 14  │ 8789     │ 0.2     │ 0.0       │ 0.0       │
# │ 15  │ 8792     │ -0.2    │ -0.179813 │ -0.164938 │
# Grouped ran: 25 iters and Ungrouped ran: 33 iters
#
#
# running 13 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 4552     │ -0.2    │ 0.0       │ -0.109976 │
# │ 2   │ 4559     │ 0.2     │ 0.0       │ 0.0       │
# │ 3   │ 4560     │ -0.2    │ 0.0       │ 0.0       │
# │ 4   │ 4584     │ -0.2    │ -0.220952 │ -0.217506 │
# │ 5   │ 4597     │ 0.2     │ 0.174572  │ 0.162032  │
# │ 6   │ 4600     │ 0.2     │ 0.217454  │ 0.231097  │
# │ 7   │ 6104     │ 0.2     │ 0.143473  │ 0.151498  │
# │ 8   │ 6113     │ 0.2     │ 0.0       │ 0.106214  │
# │ 9   │ 6117     │ -0.2    │ 0.0       │ 0.0       │
# │ 10  │ 9103     │ 0.2     │ 0.187191  │ 0.164026  │
# │ 11  │ 9107     │ 0.2     │ 0.169437  │ 0.180723  │
# │ 12  │ 9112     │ -0.2    │ -0.175103 │ -0.170235 │
# │ 13  │ 9363     │ 0.2     │ 0.13236   │ 0.14833   │
# │ 14  │ 9364     │ 0.2     │ 0.237243  │ 0.21892   │
# │ 15  │ 9373     │ -0.2    │ -0.233832 │ -0.237486 │
# Grouped ran: 24 iters and Ungrouped ran: 22 iters
#
#
# running 14 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 5334     │ 0.2     │ 0.224181  │ 0.253553  │
# │ 2   │ 5338     │ -0.2    │ 0.0       │ -0.231896 │
# │ 3   │ 5339     │ 0.2     │ 0.0       │ 0.216075  │
# │ 4   │ 6164     │ 0.2     │ 0.280218  │ 0.241859  │
# │ 5   │ 6170     │ 0.2     │ 0.257793  │ 0.266708  │
# │ 6   │ 6171     │ 0.2     │ 0.183274  │ 0.0       │
# │ 7   │ 6229     │ -0.2    │ 0.0       │ 0.0       │
# │ 8   │ 6238     │ -0.2    │ -0.162415 │ -0.155979 │
# │ 9   │ 6240     │ -0.2    │ -0.177992 │ -0.196032 │
# │ 10  │ 8681     │ -0.2    │ -0.128743 │ -0.127729 │
# │ 11  │ 8682     │ -0.2    │ -0.248789 │ -0.250041 │
# │ 12  │ 8700     │ -0.2    │ -0.169299 │ -0.170537 │
# │ 13  │ 9144     │ 0.2     │ 0.211829  │ 0.233594  │
# │ 14  │ 9150     │ 0.2     │ 0.2393    │ 0.254109  │
# │ 15  │ 9160     │ 0.2     │ 0.188365  │ 0.184641  │
# Grouped ran: 28 iters and Ungrouped ran: 24 iters
#
#
# running 15 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 246      │ -0.2    │ -0.203546 │ -0.148293 │
# │ 2   │ 249      │ 0.2     │ 0.15067   │ 0.0       │
# │ 3   │ 259      │ 0.2     │ 0.192856  │ 0.18891   │
# │ 4   │ 4002     │ 0.2     │ 0.0       │ 0.0       │
# │ 5   │ 4004     │ -0.2    │ 0.0       │ 0.0       │
# │ 6   │ 4006     │ 0.2     │ 0.0       │ 0.0       │
# │ 7   │ 4951     │ -0.2    │ -0.199483 │ -0.177798 │
# │ 8   │ 4954     │ 0.2     │ 0.151616  │ 0.151591  │
# │ 9   │ 4960     │ 0.2     │ 0.191405  │ 0.187974  │
# │ 10  │ 6005     │ 0.2     │ 0.0       │ 0.0       │
# │ 11  │ 6008     │ -0.2    │ -0.203308 │ -0.220794 │
# │ 12  │ 6017     │ 0.2     │ 0.172929  │ 0.166512  │
# │ 13  │ 8942     │ 0.2     │ 0.156003  │ 0.158431  │
# │ 14  │ 8945     │ 0.2     │ 0.0       │ 0.0       │
# │ 15  │ 8959     │ -0.2    │ 0.0       │ -0.111978 │
# Grouped ran: 16 iters and Ungrouped ran: 16 iters
#
#
# running 16 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 1267     │ -0.2    │ -0.254852 │ -0.239724 │
# │ 2   │ 1273     │ -0.2    │ -0.160913 │ -0.192309 │
# │ 3   │ 1277     │ 0.2     │ 0.24577   │ 0.236827  │
# │ 4   │ 1605     │ 0.2     │ 0.189314  │ 0.194736  │
# │ 5   │ 1610     │ -0.2    │ -0.201715 │ -0.215129 │
# │ 6   │ 1611     │ -0.2    │ -0.156595 │ -0.170375 │
# │ 7   │ 2704     │ -0.2    │ -0.227456 │ 0.0       │
# │ 8   │ 2713     │ 0.2     │ 0.0       │ 0.249466  │
# │ 9   │ 2719     │ -0.2    │ 0.0       │ -0.186617 │
# │ 10  │ 6203     │ 0.2     │ 0.232789  │ 0.106355  │
# │ 11  │ 6207     │ 0.2     │ 0.164429  │ 0.119307  │
# │ 12  │ 6220     │ 0.2     │ 0.165134  │ 0.0       │
# │ 13  │ 9863     │ -0.2    │ -0.265757 │ -0.250966 │
# │ 14  │ 9873     │ -0.2    │ -0.17788  │ -0.173155 │
# │ 15  │ 9876     │ -0.2    │ -0.222733 │ -0.234385 │
# Grouped ran: 29 iters and Ungrouped ran: 22 iters
#
#
# running 17 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped    │
# │     │ Int64    │ Float64 │ Float64   │ Float64    │
# ├─────┼──────────┼─────────┼───────────┼────────────┤
# │ 1   │ 1505     │ -0.2    │ 0.0       │ 0.0        │
# │ 2   │ 1512     │ -0.2    │ 0.0       │ -0.0874384 │
# │ 3   │ 1515     │ 0.2     │ 0.168057  │ 0.148632   │
# │ 4   │ 1824     │ 0.2     │ 0.0       │ 0.0        │
# │ 5   │ 1831     │ -0.2    │ 0.0       │ 0.0        │
# │ 6   │ 1835     │ 0.2     │ 0.0       │ 0.0        │
# │ 7   │ 5166     │ 0.2     │ 0.186356  │ 0.190478   │
# │ 8   │ 5171     │ 0.2     │ 0.21329   │ 0.198855   │
# │ 9   │ 5174     │ 0.2     │ 0.21532   │ 0.210454   │
# │ 10  │ 5523     │ 0.2     │ 0.180691  │ 0.187076   │
# │ 11  │ 5525     │ 0.2     │ 0.21834   │ 0.219559   │
# │ 12  │ 5532     │ 0.2     │ 0.22071   │ 0.206952   │
# │ 13  │ 5626     │ -0.2    │ -0.193613 │ -0.153413  │
# │ 14  │ 5635     │ -0.2    │ -0.212032 │ -0.178683  │
# │ 15  │ 5637     │ 0.2     │ 0.214737  │ 0.0        │
# Grouped ran: 43 iters and Ungrouped ran: 21 iters
#
#
# running 18 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 1627     │ -0.2    │ -0.213534 │ -0.181274 │
# │ 2   │ 1630     │ -0.2    │ -0.19184  │ -0.18203  │
# │ 3   │ 1632     │ -0.2    │ -0.171851 │ 0.0       │
# │ 4   │ 4921     │ -0.2    │ -0.214451 │ -0.234041 │
# │ 5   │ 4925     │ 0.2     │ 0.2076    │ 0.0       │
# │ 6   │ 4937     │ 0.2     │ 0.248344  │ 0.208817  │
# │ 7   │ 5124     │ 0.2     │ 0.0       │ 0.0671756 │
# │ 8   │ 5130     │ 0.2     │ 0.0       │ 0.0       │
# │ 9   │ 5139     │ -0.2    │ -0.13741  │ -0.159751 │
# │ 10  │ 9085     │ -0.2    │ -0.225478 │ -0.220285 │
# │ 11  │ 9086     │ -0.2    │ -0.22222  │ -0.216955 │
# │ 12  │ 9089     │ 0.2     │ 0.26381   │ 0.250333  │
# │ 13  │ 9141     │ 0.2     │ 0.195104  │ 0.170401  │
# │ 14  │ 9153     │ 0.2     │ 0.151337  │ 0.166519  │
# │ 15  │ 9155     │ -0.2    │ 0.0       │ -0.132059 │
# Grouped ran: 13 iters and Ungrouped ran: 17 iters
#
#
# running 19 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 1189     │ -0.2    │ -0.174581 │ -0.179644 │
# │ 2   │ 1191     │ -0.2    │ -0.196914 │ -0.197162 │
# │ 3   │ 1197     │ 0.2     │ 0.214315  │ 0.208278  │
# │ 4   │ 3223     │ -0.2    │ -0.200964 │ -0.187417 │
# │ 5   │ 3234     │ -0.2    │ -0.28218  │ -0.289907 │
# │ 6   │ 3240     │ -0.2    │ -0.19054  │ -0.184562 │
# │ 7   │ 3642     │ 0.2     │ 0.214439  │ 0.224694  │
# │ 8   │ 3649     │ -0.2    │ -0.190568 │ -0.186774 │
# │ 9   │ 3656     │ 0.2     │ 0.220046  │ 0.218717  │
# │ 10  │ 4702     │ -0.2    │ -0.174954 │ -0.185852 │
# │ 11  │ 4713     │ 0.2     │ 0.227227  │ 0.222207  │
# │ 12  │ 4714     │ -0.2    │ -0.19515  │ -0.192004 │
# │ 13  │ 8442     │ 0.2     │ 0.23174   │ 0.220927  │
# │ 14  │ 8449     │ 0.2     │ 0.193578  │ 0.0       │
# │ 15  │ 8459     │ 0.2     │ 0.210906  │ 0.182867  │
# Grouped ran: 13 iters and Ungrouped ran: 17 iters
#
#
# running 20 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 364      │ -0.2    │ -0.167201 │ 0.0       │
# │ 2   │ 378      │ 0.2     │ 0.0       │ 0.0       │
# │ 3   │ 380      │ 0.2     │ 0.231606  │ 0.201058  │
# │ 4   │ 602      │ 0.2     │ 0.179977  │ 0.173697  │
# │ 5   │ 605      │ -0.2    │ -0.197463 │ -0.206504 │
# │ 6   │ 620      │ 0.2     │ 0.203426  │ 0.184267  │
# │ 7   │ 5303     │ 0.2     │ 0.218302  │ 0.219583  │
# │ 8   │ 5306     │ 0.2     │ 0.179932  │ 0.18357   │
# │ 9   │ 5318     │ -0.2    │ 0.0       │ 0.0       │
# │ 10  │ 6651     │ 0.2     │ 0.251625  │ 0.25516   │
# │ 11  │ 6652     │ 0.2     │ 0.0       │ 0.0       │
# │ 12  │ 6659     │ 0.2     │ 0.233843  │ 0.239509  │
# │ 13  │ 8381     │ 0.2     │ 0.231844  │ 0.236498  │
# │ 14  │ 8384     │ -0.2    │ -0.246425 │ -0.257195 │
# │ 15  │ 8386     │ 0.2     │ 0.165951  │ 0.161488  │
# Grouped ran: 16 iters and Ungrouped ran: 18 iters
#
#
# running 21 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 1804     │ 0.2     │ 0.0       │ 0.0       │
# │ 2   │ 1808     │ 0.2     │ 0.214187  │ 0.0       │
# │ 3   │ 1816     │ 0.2     │ 0.148121  │ 0.105481  │
# │ 4   │ 2928     │ -0.2    │ 0.0       │ 0.0       │
# │ 5   │ 2935     │ 0.2     │ 0.0       │ 0.0       │
# │ 6   │ 2938     │ -0.2    │ -0.227949 │ -0.186199 │
# │ 7   │ 3203     │ -0.2    │ 0.0       │ 0.0       │
# │ 8   │ 3204     │ 0.2     │ 0.138395  │ 0.102717  │
# │ 9   │ 3214     │ 0.2     │ 0.179324  │ 0.196912  │
# │ 10  │ 7468     │ -0.2    │ -0.210116 │ -0.151706 │
# │ 11  │ 7472     │ 0.2     │ 0.201106  │ 0.0       │
# │ 12  │ 7480     │ 0.2     │ 0.231491  │ 0.149901  │
# │ 13  │ 7870     │ -0.2    │ -0.191679 │ -0.201404 │
# │ 14  │ 7877     │ 0.2     │ 0.0       │ 0.0       │
# │ 15  │ 7878     │ -0.2    │ 0.0       │ 0.0       │
# Grouped ran: 27 iters and Ungrouped ran: 23 iters
#
#
# running 22 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 1349     │ -0.2    │ -0.188795 │ -0.211562 │
# │ 2   │ 1355     │ 0.2     │ 0.0       │ 0.141983  │
# │ 3   │ 1357     │ -0.2    │ 0.0       │ -0.124794 │
# │ 4   │ 3662     │ 0.2     │ 0.0       │ 0.172683  │
# │ 5   │ 3663     │ 0.2     │ 0.326022  │ 0.214252  │
# │ 6   │ 3670     │ 0.2     │ 0.0       │ 0.141955  │
# │ 7   │ 4908     │ -0.2    │ -0.239418 │ -0.236835 │
# │ 8   │ 4910     │ -0.2    │ -0.193796 │ -0.194583 │
# │ 9   │ 4920     │ -0.2    │ -0.213278 │ -0.219537 │
# │ 10  │ 9122     │ -0.2    │ 0.0       │ -0.156201 │
# │ 11  │ 9131     │ -0.2    │ -0.19135  │ -0.218795 │
# │ 12  │ 9136     │ 0.2     │ 0.199204  │ 0.204332  │
# │ 13  │ 9241     │ -0.2    │ -0.217563 │ 0.0       │
# │ 14  │ 9246     │ -0.2    │ -0.223691 │ -0.170017 │
# │ 15  │ 9259     │ -0.2    │ -0.20548  │ -0.196979 │
# Grouped ran: 21 iters and Ungrouped ran: 20 iters
#
#
# running 23 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 6401     │ -0.2    │ -0.180559 │ -0.192477 │
# │ 2   │ 6410     │ 0.2     │ 0.169368  │ 0.161533  │
# │ 3   │ 6412     │ -0.2    │ -0.222349 │ -0.211461 │
# │ 4   │ 6663     │ 0.2     │ 0.0       │ 0.0       │
# │ 5   │ 6676     │ -0.2    │ 0.0       │ -0.141287 │
# │ 6   │ 6678     │ 0.2     │ 0.0       │ 0.1585    │
# │ 7   │ 6804     │ -0.2    │ -0.165424 │ -0.162498 │
# │ 8   │ 6814     │ 0.2     │ 0.170641  │ 0.188141  │
# │ 9   │ 6815     │ 0.2     │ 0.228907  │ 0.234324  │
# │ 10  │ 7084     │ -0.2    │ -0.198622 │ -0.123411 │
# │ 11  │ 7097     │ -0.2    │ -0.201865 │ -0.191138 │
# │ 12  │ 7099     │ 0.2     │ 0.246145  │ 0.0       │
# │ 13  │ 9821     │ 0.2     │ 0.236913  │ 0.2501    │
# │ 14  │ 9822     │ 0.2     │ 0.162858  │ 0.180725  │
# │ 15  │ 9840     │ -0.2    │ 0.0       │ -0.163243 │
# Grouped ran: 18 iters and Ungrouped ran: 21 iters
#
#
# running 24 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 541      │ -0.2    │ -0.196339 │ 0.0       │
# │ 2   │ 543      │ -0.2    │ -0.158034 │ -0.187531 │
# │ 3   │ 548      │ 0.2     │ 0.0       │ 0.139503  │
# │ 4   │ 701      │ -0.2    │ -0.224029 │ -0.135745 │
# │ 5   │ 709      │ -0.2    │ -0.246014 │ 0.0       │
# │ 6   │ 720      │ -0.2    │ -0.220508 │ -0.191858 │
# │ 7   │ 4207     │ 0.2     │ 0.13928   │ 0.145227  │
# │ 8   │ 4210     │ 0.2     │ 0.177027  │ 0.183558  │
# │ 9   │ 4215     │ 0.2     │ 0.197285  │ 0.199542  │
# │ 10  │ 4925     │ -0.2    │ 0.0       │ -0.177185 │
# │ 11  │ 4929     │ 0.2     │ 0.0       │ 0.145497  │
# │ 12  │ 4930     │ -0.2    │ -0.137805 │ -0.181569 │
# │ 13  │ 5875     │ 0.2     │ 0.153333  │ 0.217219  │
# │ 14  │ 5877     │ -0.2    │ 0.0       │ 0.0       │
# │ 15  │ 5878     │ -0.2    │ -0.238393 │ -0.219738 │
# Grouped ran: 20 iters and Ungrouped ran: 15 iters
#
#
# running 25 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 303      │ 0.2     │ 0.271816  │ 0.200746  │
# │ 2   │ 312      │ 0.2     │ 0.191353  │ 0.177322  │
# │ 3   │ 318      │ -0.2    │ -0.170356 │ 0.0       │
# │ 4   │ 1577     │ 0.2     │ 0.179579  │ 0.151114  │
# │ 5   │ 1578     │ 0.2     │ 0.0       │ 0.0       │
# │ 6   │ 1579     │ -0.2    │ 0.0       │ 0.0       │
# │ 7   │ 1964     │ -0.2    │ -0.172373 │ -0.174567 │
# │ 8   │ 1970     │ -0.2    │ -0.245721 │ -0.24607  │
# │ 9   │ 1979     │ -0.2    │ -0.145157 │ -0.1489   │
# │ 10  │ 2147     │ -0.2    │ -0.181937 │ 0.0       │
# │ 11  │ 2153     │ 0.2     │ 0.204124  │ 0.240666  │
# │ 12  │ 2154     │ 0.2     │ 0.206218  │ 0.17209   │
# │ 13  │ 3613     │ -0.2    │ -0.217735 │ 0.0       │
# │ 14  │ 3614     │ -0.2    │ -0.185291 │ -0.1869   │
# │ 15  │ 3615     │ -0.2    │ -0.186645 │ -0.143318 │
# Grouped ran: 15 iters and Ungrouped ran: 24 iters
#
#
# running 26 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 381      │ 0.2     │ 0.202244  │ 0.204903  │
# │ 2   │ 386      │ -0.2    │ -0.226962 │ -0.225616 │
# │ 3   │ 395      │ -0.2    │ 0.0       │ 0.0       │
# │ 4   │ 2961     │ -0.2    │ -0.24238  │ -0.203691 │
# │ 5   │ 2967     │ 0.2     │ 0.0       │ 0.0       │
# │ 6   │ 2968     │ -0.2    │ 0.0       │ 0.0       │
# │ 7   │ 3661     │ -0.2    │ -0.2059   │ -0.212293 │
# │ 8   │ 3669     │ 0.2     │ 0.188556  │ 0.193603  │
# │ 9   │ 3676     │ -0.2    │ -0.203963 │ -0.188655 │
# │ 10  │ 6022     │ -0.2    │ -0.198654 │ -0.187559 │
# │ 11  │ 6025     │ -0.2    │ -0.210099 │ -0.218693 │
# │ 12  │ 6029     │ 0.2     │ 0.209812  │ 0.199333  │
# │ 13  │ 9681     │ 0.2     │ 0.207704  │ 0.147222  │
# │ 14  │ 9692     │ 0.2     │ 0.228138  │ 0.0       │
# │ 15  │ 9696     │ 0.2     │ 0.0       │ 0.0       │
# Grouped ran: 21 iters and Ungrouped ran: 15 iters
#
#
# running 27 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 2752     │ 0.2     │ 0.105606  │ 0.0       │
# │ 2   │ 2757     │ -0.2    │ -0.226788 │ -0.223237 │
# │ 3   │ 2759     │ 0.2     │ 0.204569  │ 0.205805  │
# │ 4   │ 4972     │ 0.2     │ 0.209863  │ 0.211946  │
# │ 5   │ 4974     │ 0.2     │ 0.219291  │ 0.210426  │
# │ 6   │ 4978     │ 0.2     │ 0.152079  │ 0.158274  │
# │ 7   │ 6623     │ 0.2     │ 0.217442  │ 0.218383  │
# │ 8   │ 6628     │ -0.2    │ -0.222138 │ -0.222235 │
# │ 9   │ 6634     │ 0.2     │ 0.205007  │ 0.199373  │
# │ 10  │ 7182     │ 0.2     │ 0.0       │ 0.0650971 │
# │ 11  │ 7183     │ -0.2    │ 0.0       │ 0.0       │
# │ 12  │ 7194     │ 0.2     │ 0.217765  │ 0.217169  │
# │ 13  │ 8907     │ 0.2     │ 0.0       │ 0.0       │
# │ 14  │ 8916     │ -0.2    │ -0.209323 │ -0.208991 │
# │ 15  │ 8920     │ -0.2    │ 0.0       │ 0.0       │
# Grouped ran: 24 iters and Ungrouped ran: 27 iters
#
#
# running 28 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 2323     │ -0.2    │ -0.162628 │ -0.162765 │
# │ 2   │ 2326     │ -0.2    │ -0.266605 │ -0.274661 │
# │ 3   │ 2327     │ -0.2    │ -0.224784 │ -0.195205 │
# │ 4   │ 3526     │ -0.2    │ 0.0       │ -0.163978 │
# │ 5   │ 3529     │ 0.2     │ 0.150655  │ 0.192851  │
# │ 6   │ 3536     │ 0.2     │ 0.253077  │ 0.176004  │
# │ 7   │ 6666     │ 0.2     │ 0.218415  │ 0.198002  │
# │ 8   │ 6668     │ 0.2     │ 0.0       │ 0.126744  │
# │ 9   │ 6669     │ 0.2     │ 0.300291  │ 0.242165  │
# │ 10  │ 7824     │ 0.2     │ 0.233733  │ 0.234986  │
# │ 11  │ 7827     │ -0.2    │ -0.226429 │ -0.224261 │
# │ 12  │ 7837     │ 0.2     │ 0.146313  │ 0.155348  │
# │ 13  │ 8727     │ -0.2    │ -0.203979 │ -0.212892 │
# │ 14  │ 8728     │ -0.2    │ -0.219228 │ -0.216022 │
# │ 15  │ 8733     │ -0.2    │ -0.177599 │ -0.178067 │
# Grouped ran: 20 iters and Ungrouped ran: 21 iters
#
#
# running 29 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 293      │ -0.2    │ -0.191594 │ -0.195126 │
# │ 2   │ 294      │ -0.2    │ -0.248007 │ -0.245618 │
# │ 3   │ 296      │ 0.2     │ 0.225924  │ 0.220685  │
# │ 4   │ 584      │ -0.2    │ -0.218514 │ -0.145198 │
# │ 5   │ 586      │ 0.2     │ 0.214729  │ 0.0       │
# │ 6   │ 596      │ 0.2     │ 0.192294  │ 0.23117   │
# │ 7   │ 3443     │ -0.2    │ -0.2224   │ -0.224226 │
# │ 8   │ 3454     │ 0.2     │ 0.173959  │ 0.180578  │
# │ 9   │ 3459     │ 0.2     │ 0.0       │ 0.0       │
# │ 10  │ 6268     │ 0.2     │ 0.0       │ 0.0       │
# │ 11  │ 6270     │ 0.2     │ 0.218212  │ 0.194534  │
# │ 12  │ 6278     │ -0.2    │ -0.128108 │ -0.113477 │
# │ 13  │ 9011     │ -0.2    │ 0.0       │ 0.0       │
# │ 14  │ 9012     │ 0.2     │ 0.0       │ 0.0       │
# │ 15  │ 9016     │ -0.2    │ -0.173312 │ -0.132445 │
# Grouped ran: 21 iters and Ungrouped ran: 30 iters
#
#
# running 30 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 4317     │ -0.2    │ -0.196415 │ -0.203662 │
# │ 2   │ 4318     │ -0.2    │ -0.170425 │ -0.172361 │
# │ 3   │ 4320     │ 0.2     │ 0.270484  │ 0.262923  │
# │ 4   │ 6723     │ -0.2    │ -0.2336   │ -0.233794 │
# │ 5   │ 6724     │ -0.2    │ -0.149691 │ -0.158461 │
# │ 6   │ 6739     │ 0.2     │ 0.219222  │ 0.219525  │
# │ 7   │ 7706     │ -0.2    │ -0.245589 │ -0.225754 │
# │ 8   │ 7707     │ -0.2    │ 0.0       │ -0.147582 │
# │ 9   │ 7713     │ 0.2     │ 0.255575  │ 0.220091  │
# │ 10  │ 9321     │ 0.2     │ 0.321172  │ 0.230391  │
# │ 11  │ 9332     │ 0.2     │ 0.0       │ 0.0860025 │
# │ 12  │ 9334     │ -0.2    │ 0.0       │ 0.0       │
# │ 13  │ 9846     │ 0.2     │ 0.211802  │ 0.199452  │
# │ 14  │ 9853     │ -0.2    │ -0.194059 │ -0.206782 │
# │ 15  │ 9855     │ -0.2    │ -0.148653 │ -0.146044 │
# Grouped ran: 25 iters and Ungrouped ran: 14 iters
#
#
# running 31 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 6        │ -0.2    │ -0.312056 │ -0.270428 │
# │ 2   │ 8        │ 0.2     │ 0.256026  │ 0.235424  │
# │ 3   │ 11       │ 0.2     │ 0.0       │ 0.10871   │
# │ 4   │ 87       │ -0.2    │ -0.198192 │ -0.22227  │
# │ 5   │ 91       │ 0.2     │ 0.216676  │ 0.176874  │
# │ 6   │ 98       │ 0.2     │ 0.192019  │ 0.0       │
# │ 7   │ 2225     │ 0.2     │ 0.230223  │ 0.243805  │
# │ 8   │ 2235     │ 0.2     │ 0.0       │ 0.132756  │
# │ 9   │ 2237     │ -0.2    │ 0.0       │ -0.12311  │
# │ 10  │ 3043     │ 0.2     │ 0.19168   │ 0.19581   │
# │ 11  │ 3055     │ 0.2     │ 0.178521  │ 0.171388  │
# │ 12  │ 3060     │ -0.2    │ -0.247277 │ -0.242201 │
# │ 13  │ 5388     │ -0.2    │ -0.212682 │ -0.19645  │
# │ 14  │ 5390     │ -0.2    │ -0.159262 │ -0.17588  │
# │ 15  │ 5400     │ -0.2    │ -0.22298  │ -0.235965 │
# Grouped ran: 21 iters and Ungrouped ran: 17 iters
#
#
# running 32 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 784      │ 0.2     │ 0.251869  │ 0.269333  │
# │ 2   │ 790      │ -0.2    │ -0.23878  │ -0.23291  │
# │ 3   │ 793      │ -0.2    │ 0.0       │ 0.0       │
# │ 4   │ 1729     │ 0.2     │ 0.195929  │ 0.0       │
# │ 5   │ 1733     │ 0.2     │ 0.248016  │ 0.10887   │
# │ 6   │ 1739     │ 0.2     │ 0.217116  │ 0.0       │
# │ 7   │ 2712     │ 0.2     │ 0.0       │ 0.0       │
# │ 8   │ 2716     │ -0.2    │ 0.0       │ -0.162094 │
# │ 9   │ 2718     │ 0.2     │ 0.0       │ 0.161939  │
# │ 10  │ 3977     │ 0.2     │ 0.26375   │ 0.255597  │
# │ 11  │ 3978     │ 0.2     │ 0.212096  │ 0.213875  │
# │ 12  │ 3980     │ -0.2    │ -0.213968 │ -0.214664 │
# │ 13  │ 4224     │ 0.2     │ 0.0       │ 0.0       │
# │ 14  │ 4225     │ -0.2    │ 0.0       │ 0.0       │
# │ 15  │ 4228     │ 0.2     │ 0.21166   │ 0.153062  │
# Grouped ran: 21 iters and Ungrouped ran: 33 iters
#
#
# running 33 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 1263     │ -0.2    │ -0.206693 │ -0.228754 │
# │ 2   │ 1271     │ -0.2    │ -0.21091  │ -0.222556 │
# │ 3   │ 1273     │ 0.2     │ 0.238532  │ 0.238539  │
# │ 4   │ 1348     │ -0.2    │ -0.22798  │ -0.216895 │
# │ 5   │ 1352     │ 0.2     │ 0.0       │ 0.0       │
# │ 6   │ 1353     │ -0.2    │ 0.0       │ -0.129005 │
# │ 7   │ 3382     │ -0.2    │ -0.184039 │ -0.179849 │
# │ 8   │ 3392     │ 0.2     │ 0.222025  │ 0.229256  │
# │ 9   │ 3397     │ 0.2     │ 0.131547  │ 0.137248  │
# │ 10  │ 5404     │ -0.2    │ -0.160518 │ -0.109149 │
# │ 11  │ 5412     │ -0.2    │ -0.200894 │ 0.0       │
# │ 12  │ 5416     │ -0.2    │ -0.234093 │ -0.226556 │
# │ 13  │ 7925     │ 0.2     │ 0.0       │ 0.0       │
# │ 14  │ 7927     │ -0.2    │ 0.0       │ -0.119184 │
# │ 15  │ 7934     │ -0.2    │ 0.0       │ -0.152132 │
# Grouped ran: 23 iters and Ungrouped ran: 24 iters
#
#
# running 34 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 202      │ -0.2    │ -0.315671 │ -0.253499 │
# │ 2   │ 205      │ -0.2    │ 0.0       │ -0.161651 │
# │ 3   │ 210      │ 0.2     │ 0.162159  │ 0.231842  │
# │ 4   │ 2064     │ -0.2    │ 0.0       │ -0.180112 │
# │ 5   │ 2071     │ -0.2    │ -0.122178 │ -0.170978 │
# │ 6   │ 2079     │ -0.2    │ 0.0       │ -0.200167 │
# │ 7   │ 2885     │ 0.2     │ 0.143927  │ 0.156427  │
# │ 8   │ 2887     │ 0.2     │ 0.239315  │ 0.226058  │
# │ 9   │ 2889     │ 0.2     │ 0.215173  │ 0.202011  │
# │ 10  │ 7483     │ -0.2    │ -0.210347 │ -0.214786 │
# │ 11  │ 7487     │ -0.2    │ -0.266619 │ -0.253688 │
# │ 12  │ 7490     │ -0.2    │ -0.161778 │ -0.166441 │
# │ 13  │ 9203     │ -0.2    │ -0.193393 │ -0.194322 │
# │ 14  │ 9205     │ 0.2     │ 0.251514  │ 0.255187  │
# │ 15  │ 9215     │ -0.2    │ -0.180691 │ -0.172551 │
# Grouped ran: 18 iters and Ungrouped ran: 23 iters
#
#
# running 35 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped    │
# │     │ Int64    │ Float64 │ Float64   │ Float64    │
# ├─────┼──────────┼─────────┼───────────┼────────────┤
# │ 1   │ 3761     │ 0.2     │ 0.176439  │ 0.183055   │
# │ 2   │ 3762     │ -0.2    │ -0.232447 │ -0.243249  │
# │ 3   │ 3778     │ 0.2     │ 0.143816  │ 0.134285   │
# │ 4   │ 4625     │ 0.2     │ 0.182836  │ 0.171403   │
# │ 5   │ 4629     │ -0.2    │ -0.20178  │ -0.194901  │
# │ 6   │ 4633     │ 0.2     │ 0.222552  │ 0.209672   │
# │ 7   │ 5303     │ -0.2    │ -0.15929  │ -0.147616  │
# │ 8   │ 5309     │ 0.2     │ 0.142708  │ 0.148641   │
# │ 9   │ 5312     │ -0.2    │ -0.180421 │ -0.192384  │
# │ 10  │ 5321     │ 0.2     │ 0.0       │ 0.0        │
# │ 11  │ 5322     │ -0.2    │ 0.0       │ 0.0        │
# │ 12  │ 5332     │ -0.2    │ -0.190013 │ -0.181074  │
# │ 13  │ 9672     │ 0.2     │ 0.166666  │ 0.181361   │
# │ 14  │ 9675     │ 0.2     │ 0.0       │ 0.0        │
# │ 15  │ 9676     │ -0.2    │ 0.0       │ -0.0911587 │
# Grouped ran: 19 iters and Ungrouped ran: 18 iters
#
#
# running 36 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 4864     │ 0.2     │ 0.225134  │ 0.225121  │
# │ 2   │ 4878     │ -0.2    │ -0.204746 │ -0.204733 │
# │ 3   │ 4880     │ -0.2    │ -0.197911 │ -0.197908 │
# │ 4   │ 7362     │ 0.2     │ 0.161138  │ 0.161255  │
# │ 5   │ 7367     │ 0.2     │ 0.266686  │ 0.266489  │
# │ 6   │ 7375     │ -0.2    │ -0.186308 │ -0.186376 │
# │ 7   │ 7404     │ 0.2     │ 0.201071  │ 0.20104   │
# │ 8   │ 7408     │ 0.2     │ 0.146091  │ 0.146083  │
# │ 9   │ 7419     │ -0.2    │ -0.216976 │ -0.216959 │
# │ 10  │ 8906     │ -0.2    │ -0.211819 │ -0.211777 │
# │ 11  │ 8908     │ 0.2     │ 0.241209  │ 0.241271  │
# │ 12  │ 8913     │ -0.2    │ -0.179826 │ -0.179795 │
# │ 13  │ 9326     │ 0.2     │ 0.18473   │ 0.18474   │
# │ 14  │ 9328     │ -0.2    │ -0.163882 │ -0.163874 │
# │ 15  │ 9338     │ 0.2     │ 0.271573  │ 0.271576  │
# Grouped ran: 14 iters and Ungrouped ran: 22 iters
#
#
# running 37 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 1787     │ 0.2     │ 0.23328   │ 0.241518  │
# │ 2   │ 1788     │ 0.2     │ 0.216231  │ 0.208212  │
# │ 3   │ 1795     │ -0.2    │ -0.177296 │ -0.201928 │
# │ 4   │ 3948     │ -0.2    │ -0.234842 │ -0.193816 │
# │ 5   │ 3952     │ 0.2     │ 0.13953   │ 0.198192  │
# │ 6   │ 3954     │ -0.2    │ 0.0       │ -0.159217 │
# │ 7   │ 4324     │ -0.2    │ 0.0       │ 0.0       │
# │ 8   │ 4336     │ -0.2    │ -0.210788 │ 0.0       │
# │ 9   │ 4337     │ -0.2    │ -0.103469 │ 0.0       │
# │ 10  │ 8633     │ -0.2    │ -0.145063 │ -0.159602 │
# │ 11  │ 8638     │ 0.2     │ 0.149887  │ 0.161555  │
# │ 12  │ 8640     │ 0.2     │ 0.172125  │ 0.173534  │
# │ 13  │ 8702     │ -0.2    │ 0.0       │ -0.185074 │
# │ 14  │ 8711     │ -0.2    │ 0.0       │ -0.164726 │
# │ 15  │ 8720     │ -0.2    │ -0.15644  │ -0.236206 │
# Grouped ran: 28 iters and Ungrouped ran: 16 iters
#
#
# running 38 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped    │
# │     │ Int64    │ Float64 │ Float64   │ Float64    │
# ├─────┼──────────┼─────────┼───────────┼────────────┤
# │ 1   │ 68       │ -0.2    │ -0.259605 │ -0.246956  │
# │ 2   │ 71       │ -0.2    │ -0.186276 │ -0.179727  │
# │ 3   │ 79       │ 0.2     │ 0.0       │ 0.0        │
# │ 4   │ 643      │ -0.2    │ -0.213935 │ -0.223722  │
# │ 5   │ 656      │ 0.2     │ 0.246706  │ 0.244503   │
# │ 6   │ 657      │ 0.2     │ 0.2316    │ 0.23866    │
# │ 7   │ 2570     │ -0.2    │ 0.0       │ -0.0818676 │
# │ 8   │ 2574     │ 0.2     │ 0.0       │ 0.0        │
# │ 9   │ 2578     │ 0.2     │ 0.249191  │ 0.237558   │
# │ 10  │ 2702     │ -0.2    │ -0.213105 │ -0.212296  │
# │ 11  │ 2708     │ -0.2    │ -0.172737 │ -0.165341  │
# │ 12  │ 2719     │ -0.2    │ -0.183111 │ -0.18883   │
# │ 13  │ 9528     │ -0.2    │ -0.176547 │ -0.119656  │
# │ 14  │ 9530     │ 0.2     │ 0.179111  │ 0.0        │
# │ 15  │ 9540     │ 0.2     │ 0.243952  │ 0.32328    │
# Grouped ran: 20 iters and Ungrouped ran: 18 iters
#
#
# running 39 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 1083     │ 0.2     │ 0.180399  │ 0.175045  │
# │ 2   │ 1086     │ -0.2    │ -0.203519 │ -0.214432 │
# │ 3   │ 1089     │ 0.2     │ 0.193044  │ 0.188373  │
# │ 4   │ 4923     │ 0.2     │ 0.0       │ 0.0       │
# │ 5   │ 4924     │ -0.2    │ 0.0       │ -0.089148 │
# │ 6   │ 4933     │ -0.2    │ -0.278939 │ -0.24132  │
# │ 7   │ 5346     │ 0.2     │ 0.240892  │ 0.257223  │
# │ 8   │ 5352     │ 0.2     │ 0.0       │ 0.123682  │
# │ 9   │ 5355     │ -0.2    │ 0.0       │ 0.0       │
# │ 10  │ 6147     │ -0.2    │ -0.189512 │ -0.199911 │
# │ 11  │ 6156     │ -0.2    │ -0.233551 │ -0.23228  │
# │ 12  │ 6159     │ 0.2     │ 0.212067  │ 0.203185  │
# │ 13  │ 8924     │ 0.2     │ 0.275796  │ 0.296065  │
# │ 14  │ 8928     │ 0.2     │ 0.24871   │ 0.223888  │
# │ 15  │ 8937     │ -0.2    │ -0.203481 │ 0.0       │
# Grouped ran: 19 iters and Ungrouped ran: 27 iters
#
#
# running 40 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 983      │ 0.2     │ 0.222583  │ 0.226903  │
# │ 2   │ 984      │ 0.2     │ 0.195616  │ 0.199838  │
# │ 3   │ 1000     │ 0.2     │ 0.200305  │ 0.180472  │
# │ 4   │ 1743     │ 0.2     │ 0.280578  │ 0.230871  │
# │ 5   │ 1747     │ -0.2    │ 0.0       │ -0.168938 │
# │ 6   │ 1749     │ 0.2     │ 0.0       │ 0.151056  │
# │ 7   │ 6401     │ 0.2     │ 0.0       │ 0.0       │
# │ 8   │ 6412     │ -0.2    │ -0.247618 │ -0.273044 │
# │ 9   │ 6415     │ 0.2     │ 0.0       │ 0.0       │
# │ 10  │ 7767     │ 0.2     │ 0.161881  │ 0.0       │
# │ 11  │ 7768     │ 0.2     │ 0.203653  │ 0.213046  │
# │ 12  │ 7776     │ -0.2    │ -0.221564 │ -0.179043 │
# │ 13  │ 9381     │ -0.2    │ 0.0       │ -0.16946  │
# │ 14  │ 9390     │ 0.2     │ 0.0       │ 0.185173  │
# │ 15  │ 9393     │ -0.2    │ -0.257705 │ -0.170188 │
# Grouped ran: 27 iters and Ungrouped ran: 31 iters
#
#
# running 41 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 2845     │ -0.2    │ -0.126696 │ -0.120796 │
# │ 2   │ 2848     │ 0.2     │ 0.0       │ 0.0       │
# │ 3   │ 2860     │ -0.2    │ -0.197137 │ -0.174588 │
# │ 4   │ 4585     │ -0.2    │ -0.255217 │ 0.0       │
# │ 5   │ 4586     │ -0.2    │ -0.222988 │ -0.278    │
# │ 6   │ 4597     │ -0.2    │ -0.182919 │ 0.0       │
# │ 7   │ 6402     │ -0.2    │ 0.0       │ -0.109481 │
# │ 8   │ 6404     │ 0.2     │ 0.127105  │ 0.171166  │
# │ 9   │ 6410     │ 0.2     │ 0.0       │ 0.0       │
# │ 10  │ 7032     │ 0.2     │ 0.23532   │ 0.244386  │
# │ 11  │ 7033     │ -0.2    │ -0.187669 │ -0.185588 │
# │ 12  │ 7040     │ 0.2     │ 0.118161  │ 0.119609  │
# │ 13  │ 8927     │ -0.2    │ -0.157681 │ -0.130467 │
# │ 14  │ 8931     │ 0.2     │ 0.161222  │ 0.148614  │
# │ 15  │ 8932     │ 0.2     │ 0.245874  │ 0.236206  │
# Grouped ran: 20 iters and Ungrouped ran: 26 iters
#
#
# running 42 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped    │
# │     │ Int64    │ Float64 │ Float64   │ Float64    │
# ├─────┼──────────┼─────────┼───────────┼────────────┤
# │ 1   │ 381      │ 0.2     │ 0.24744   │ 0.259211   │
# │ 2   │ 393      │ 0.2     │ 0.229821  │ 0.235814   │
# │ 3   │ 400      │ 0.2     │ 0.180986  │ 0.169341   │
# │ 4   │ 1385     │ 0.2     │ 0.225835  │ 0.22525    │
# │ 5   │ 1391     │ -0.2    │ -0.176353 │ 0.0        │
# │ 6   │ 1398     │ 0.2     │ 0.179272  │ 0.155469   │
# │ 7   │ 3607     │ -0.2    │ -0.229127 │ -0.240788  │
# │ 8   │ 3608     │ 0.2     │ 0.220968  │ 0.242814   │
# │ 9   │ 3610     │ 0.2     │ 0.221125  │ 0.205781   │
# │ 10  │ 3622     │ -0.2    │ -0.181244 │ -0.218935  │
# │ 11  │ 3624     │ -0.2    │ -0.165131 │ 0.0        │
# │ 12  │ 3640     │ 0.2     │ 0.223752  │ 0.0        │
# │ 13  │ 8524     │ -0.2    │ -0.21954  │ -0.234435  │
# │ 14  │ 8528     │ 0.2     │ 0.0       │ 0.0        │
# │ 15  │ 8529     │ -0.2    │ 0.0       │ -0.0809311 │
# Grouped ran: 30 iters and Ungrouped ran: 20 iters
#
#
# running 43 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 5592     │ 0.2     │ 0.0       │ 0.0       │
# │ 2   │ 5595     │ 0.2     │ 0.267187  │ 0.267183  │
# │ 3   │ 5597     │ 0.2     │ 0.156625  │ 0.156625  │
# │ 4   │ 7363     │ -0.2    │ -0.179814 │ -0.179848 │
# │ 5   │ 7364     │ -0.2    │ -0.20882  │ -0.20872  │
# │ 6   │ 7379     │ 0.2     │ 0.173383  │ 0.173405  │
# │ 7   │ 8264     │ -0.2    │ -0.268106 │ -0.268032 │
# │ 8   │ 8266     │ -0.2    │ -0.164355 │ -0.164401 │
# │ 9   │ 8278     │ -0.2    │ -0.147711 │ -0.147784 │
# │ 10  │ 8664     │ 0.2     │ 0.0       │ 0.0       │
# │ 11  │ 8666     │ -0.2    │ -0.160085 │ -0.160091 │
# │ 12  │ 8671     │ 0.2     │ 0.16227   │ 0.162272  │
# │ 13  │ 8761     │ -0.2    │ -0.186106 │ -0.186114 │
# │ 14  │ 8769     │ -0.2    │ -0.206604 │ -0.206606 │
# │ 15  │ 8772     │ 0.2     │ 0.193906  │ 0.193909  │
# Grouped ran: 20 iters and Ungrouped ran: 16 iters
#
#
# running 44 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 2881     │ 0.2     │ 0.0       │ 0.0       │
# │ 2   │ 2883     │ 0.2     │ 0.0       │ 0.0       │
# │ 3   │ 2884     │ -0.2    │ 0.0       │ 0.0       │
# │ 4   │ 4749     │ -0.2    │ 0.0       │ 0.0       │
# │ 5   │ 4754     │ 0.2     │ 0.0       │ 0.0       │
# │ 6   │ 4760     │ 0.2     │ 0.15327   │ 0.135759  │
# │ 7   │ 5244     │ 0.2     │ 0.185329  │ 0.19295   │
# │ 8   │ 5251     │ -0.2    │ -0.26561  │ -0.255199 │
# │ 9   │ 5253     │ 0.2     │ 0.205634  │ 0.184922  │
# │ 10  │ 6657     │ 0.2     │ 0.181812  │ 0.153367  │
# │ 11  │ 6659     │ 0.2     │ 0.0       │ 0.0       │
# │ 12  │ 6660     │ 0.2     │ 0.137055  │ 0.19407   │
# │ 13  │ 7841     │ 0.2     │ 0.268934  │ 0.269569  │
# │ 14  │ 7850     │ 0.2     │ 0.209779  │ 0.206676  │
# │ 15  │ 7856     │ 0.2     │ 0.249235  │ 0.239051  │
# Grouped ran: 12 iters and Ungrouped ran: 18 iters
#
#
# running 45 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 703      │ -0.2    │ 0.0       │ 0.0       │
# │ 2   │ 705      │ 0.2     │ 0.0       │ 0.0       │
# │ 3   │ 716      │ -0.2    │ 0.0       │ -0.141676 │
# │ 4   │ 1822     │ 0.2     │ 0.240359  │ 0.231164  │
# │ 5   │ 1826     │ 0.2     │ 0.236266  │ 0.221256  │
# │ 6   │ 1830     │ 0.2     │ 0.169542  │ 0.182526  │
# │ 7   │ 2187     │ 0.2     │ 0.223563  │ 0.218512  │
# │ 8   │ 2190     │ -0.2    │ -0.218378 │ -0.226451 │
# │ 9   │ 2196     │ -0.2    │ -0.156161 │ -0.156834 │
# │ 10  │ 9123     │ -0.2    │ -0.221921 │ -0.226594 │
# │ 11  │ 9133     │ -0.2    │ -0.205502 │ -0.191736 │
# │ 12  │ 9137     │ 0.2     │ 0.239797  │ 0.221853  │
# │ 13  │ 9782     │ 0.2     │ 0.20625   │ 0.234739  │
# │ 14  │ 9790     │ -0.2    │ -0.19146  │ -0.20671  │
# │ 15  │ 9794     │ 0.2     │ 0.262892  │ 0.276884  │
# Grouped ran: 12 iters and Ungrouped ran: 16 iters
#
#
# running 46 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 201      │ -0.2    │ -0.206504 │ -0.206128 │
# │ 2   │ 209      │ 0.2     │ 0.158412  │ 0.171812  │
# ...
# │ 1   │ 91       │ 0.2     │ 0.176231  │ 0.156243  │
# │ 2   │ 95       │ 0.2     │ 0.0       │ 0.128857  │
# │ 3   │ 97       │ -0.2    │ -0.14207  │ -0.168199 │
# │ 4   │ 647      │ -0.2    │ 0.0       │ 0.0       │
# │ 5   │ 650      │ 0.2     │ 0.234965  │ 0.25331   │
# │ 6   │ 656      │ 0.2     │ 0.187299  │ 0.167776  │
# │ 7   │ 8721     │ -0.2    │ 0.0       │ 0.0       │
# │ 8   │ 8731     │ -0.2    │ -0.168458 │ -0.157489 │
# │ 9   │ 8740     │ -0.2    │ -0.279237 │ -0.245336 │
# │ 10  │ 9326     │ 0.2     │ 0.195839  │ 0.198314  │
# │ 11  │ 9331     │ 0.2     │ 0.175687  │ 0.16948   │
# │ 12  │ 9333     │ -0.2    │ -0.166994 │ -0.166657 │
# │ 13  │ 9348     │ 0.2     │ 0.260247  │ 0.247012  │
# │ 14  │ 9349     │ -0.2    │ -0.194404 │ -0.196127 │
# │ 15  │ 9355     │ -0.2    │ -0.221102 │ -0.234709 │
# Grouped ran: 25 iters and Ungrouped ran: 21 iters
#
#
# running 87 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 425      │ 0.2     │ 0.198089  │ 0.191892  │
# │ 2   │ 427      │ 0.2     │ 0.207813  │ 0.213138  │
# │ 3   │ 430      │ 0.2     │ 0.204223  │ 0.206387  │
# │ 4   │ 868      │ -0.2    │ -0.223976 │ -0.211159 │
# │ 5   │ 870      │ -0.2    │ -0.199339 │ -0.207483 │
# │ 6   │ 878      │ -0.2    │ -0.20984  │ -0.210741 │
# │ 7   │ 2804     │ -0.2    │ -0.196411 │ 0.0       │
# │ 8   │ 2806     │ 0.2     │ 0.19011   │ 0.145291  │
# │ 9   │ 2817     │ 0.2     │ 0.184487  │ 0.18741   │
# │ 10  │ 6581     │ -0.2    │ 0.0       │ 0.0       │
# │ 11  │ 6586     │ 0.2     │ 0.149176  │ 0.159949  │
# │ 12  │ 6589     │ -0.2    │ 0.0       │ -0.134973 │
# │ 13  │ 8666     │ -0.2    │ -0.220362 │ -0.199828 │
# │ 14  │ 8668     │ -0.2    │ 0.0       │ -0.190842 │
# │ 15  │ 8679     │ 0.2     │ 0.132851  │ 0.183484  │
# Grouped ran: 30 iters and Ungrouped ran: 16 iters
#
#
# running 88 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 2        │ -0.2    │ -0.188844 │ -0.195169 │
# │ 2   │ 9        │ -0.2    │ -0.240513 │ -0.223448 │
# │ 3   │ 13       │ -0.2    │ -0.178829 │ -0.181326 │
# │ 4   │ 395      │ 0.2     │ 0.272879  │ 0.204065  │
# │ 5   │ 399      │ 0.2     │ 0.0       │ 0.0       │
# │ 6   │ 400      │ -0.2    │ -0.140021 │ 0.0       │
# │ 7   │ 2869     │ 0.2     │ 0.149801  │ 0.0       │
# │ 8   │ 2877     │ -0.2    │ 0.0       │ -0.157536 │
# │ 9   │ 2879     │ 0.2     │ 0.0       │ 0.20948   │
# │ 10  │ 3943     │ 0.2     │ 0.185346  │ 0.173197  │
# │ 11  │ 3957     │ 0.2     │ 0.0       │ 0.0       │
# │ 12  │ 3958     │ -0.2    │ 0.0       │ -0.104128 │
# │ 13  │ 5846     │ -0.2    │ -0.207687 │ -0.211435 │
# │ 14  │ 5851     │ 0.2     │ 0.166025  │ 0.15972   │
# │ 15  │ 5855     │ 0.2     │ 0.152976  │ 0.176076  │
# Grouped ran: 44 iters and Ungrouped ran: 18 iters
#
#
# running 89 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped  │ grouped   │
# │     │ Int64    │ Float64 │ Float64    │ Float64   │
# ├─────┼──────────┼─────────┼────────────┼───────────┤
# │ 1   │ 2222     │ -0.2    │ 0.0        │ -0.20079  │
# │ 2   │ 2224     │ 0.2     │ 0.182008   │ 0.226211  │
# │ 3   │ 2229     │ 0.2     │ 0.0        │ 0.225877  │
# │ 4   │ 4584     │ -0.2    │ -0.246729  │ -0.247359 │
# │ 5   │ 4592     │ 0.2     │ 0.0        │ 0.151063  │
# │ 6   │ 4593     │ -0.2    │ 0.0        │ -0.184645 │
# │ 7   │ 5841     │ -0.2    │ -0.261552  │ -0.245279 │
# │ 8   │ 5844     │ -0.2    │ -0.234481  │ -0.256054 │
# │ 9   │ 5859     │ 0.2     │ 0.238945   │ 0.249467  │
# │ 10  │ 6002     │ 0.2     │ 0.0        │ 0.229276  │
# │ 11  │ 6010     │ -0.2    │ -0.0928926 │ -0.280696 │
# │ 12  │ 6011     │ -0.2    │ -0.301966  │ -0.145179 │
# │ 13  │ 6126     │ 0.2     │ 0.18559    │ 0.197221  │
# │ 14  │ 6136     │ -0.2    │ -0.265996  │ -0.24932  │
# │ 15  │ 6139     │ -0.2    │ -0.209782  │ -0.210012 │
# Grouped ran: 30 iters and Ungrouped ran: 43 iters
#
#
# running 90 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 65       │ 0.2     │ 0.220851  │ 0.216805  │
# │ 2   │ 76       │ -0.2    │ -0.210611 │ -0.210893 │
# │ 3   │ 77       │ -0.2    │ -0.15023  │ -0.143944 │
# │ 4   │ 1243     │ -0.2    │ -0.258728 │ -0.254464 │
# │ 5   │ 1247     │ -0.2    │ -0.167323 │ -0.166503 │
# │ 6   │ 1258     │ 0.2     │ 0.230089  │ 0.226173  │
# │ 7   │ 3148     │ -0.2    │ -0.205494 │ -0.206979 │
# │ 8   │ 3149     │ -0.2    │ -0.131659 │ -0.1235   │
# │ 9   │ 3158     │ -0.2    │ -0.174019 │ -0.1708   │
# │ 10  │ 6809     │ -0.2    │ -0.196769 │ -0.196057 │
# │ 11  │ 6812     │ -0.2    │ -0.202778 │ -0.19763  │
# │ 12  │ 6815     │ 0.2     │ 0.19272   │ 0.194407  │
# │ 13  │ 9285     │ -0.2    │ -0.127161 │ -0.222573 │
# │ 14  │ 9286     │ -0.2    │ -0.284966 │ -0.233816 │
# │ 15  │ 9289     │ 0.2     │ 0.0       │ 0.144681  │
# Grouped ran: 20 iters and Ungrouped ran: 26 iters
#
#
# running 91 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 1103     │ 0.2     │ 0.220635  │ 0.196437  │
# │ 2   │ 1114     │ 0.2     │ 0.216897  │ 0.21223   │
# │ 3   │ 1118     │ -0.2    │ -0.177447 │ -0.185377 │
# │ 4   │ 6646     │ 0.2     │ 0.186524  │ 0.179435  │
# │ 5   │ 6652     │ 0.2     │ 0.172175  │ 0.19606   │
# │ 6   │ 6655     │ 0.2     │ 0.202592  │ 0.253458  │
# │ 7   │ 7201     │ 0.2     │ 0.257839  │ 0.231443  │
# │ 8   │ 7207     │ 0.2     │ 0.0       │ 0.139356  │
# │ 9   │ 7209     │ -0.2    │ -0.147561 │ -0.179416 │
# │ 10  │ 7385     │ 0.2     │ 0.25676   │ 0.187563  │
# │ 11  │ 7389     │ 0.2     │ 0.245462  │ 0.231076  │
# │ 12  │ 7396     │ -0.2    │ -0.240445 │ 0.0       │
# │ 13  │ 8842     │ 0.2     │ 0.0       │ 0.126522  │
# │ 14  │ 8848     │ 0.2     │ 0.243972  │ 0.21085   │
# │ 15  │ 8855     │ 0.2     │ 0.0       │ 0.0       │
# Grouped ran: 14 iters and Ungrouped ran: 12 iters
#
#
# running 92 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 1648     │ -0.2    │ -0.141943 │ -0.141921 │
# │ 2   │ 1652     │ 0.2     │ 0.230762  │ 0.23078   │
# │ 3   │ 1657     │ 0.2     │ 0.170407  │ 0.17042   │
# │ 4   │ 6567     │ -0.2    │ -0.178949 │ -0.178963 │
# │ 5   │ 6575     │ 0.2     │ 0.215856  │ 0.215882  │
# │ 6   │ 6579     │ 0.2     │ 0.197257  │ 0.197255  │
# │ 7   │ 7025     │ 0.2     │ 0.198355  │ 0.198387  │
# │ 8   │ 7027     │ -0.2    │ 0.0       │ 0.0       │
# │ 9   │ 7033     │ -0.2    │ 0.0       │ 0.0       │
# │ 10  │ 7251     │ -0.2    │ -0.226845 │ -0.226726 │
# │ 11  │ 7252     │ -0.2    │ -0.230448 │ -0.230648 │
# │ 12  │ 7255     │ 0.2     │ 0.307209  │ 0.307364  │
# │ 13  │ 8586     │ 0.2     │ 0.143566  │ 0.143554  │
# │ 14  │ 8588     │ 0.2     │ 0.0       │ 0.0       │
# │ 15  │ 8590     │ 0.2     │ 0.201529  │ 0.201525  │
# Grouped ran: 18 iters and Ungrouped ran: 19 iters
#
#
# running 93 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped    │
# │     │ Int64    │ Float64 │ Float64   │ Float64    │
# ├─────┼──────────┼─────────┼───────────┼────────────┤
# │ 1   │ 1064     │ -0.2    │ -0.240245 │ -0.2438    │
# │ 2   │ 1065     │ -0.2    │ -0.221737 │ -0.211047  │
# │ 3   │ 1069     │ -0.2    │ -0.192767 │ -0.194594  │
# │ 4   │ 1521     │ -0.2    │ 0.0       │ -0.0948356 │
# │ 5   │ 1524     │ 0.2     │ 0.0       │ 0.0        │
# │ 6   │ 1535     │ -0.2    │ -0.242492 │ -0.210248  │
# │ 7   │ 2185     │ 0.2     │ 0.187966  │ 0.209632   │
# │ 8   │ 2187     │ -0.2    │ -0.133321 │ -0.146718  │
# │ 9   │ 2196     │ 0.2     │ 0.236259  │ 0.225636   │
# │ 10  │ 4838     │ -0.2    │ 0.0       │ 0.0        │
# │ 11  │ 4839     │ 0.2     │ 0.0       │ 0.0        │
# │ 12  │ 4840     │ -0.2    │ -0.23423  │ -0.234298  │
# │ 13  │ 5850     │ -0.2    │ -0.24726  │ -0.251329  │
# │ 14  │ 5852     │ 0.2     │ 0.145375  │ 0.151182   │
# │ 15  │ 5855     │ 0.2     │ 0.20785   │ 0.197883   │
# Grouped ran: 19 iters and Ungrouped ran: 14 iters
#
#
# running 94 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 2182     │ -0.2    │ -0.247259 │ -0.175629 │
# │ 2   │ 2184     │ -0.2    │ 0.0       │ -0.171338 │
# │ 3   │ 2198     │ 0.2     │ 0.17069   │ 0.218747  │
# │ 4   │ 4731     │ 0.2     │ 0.253762  │ 0.259847  │
# │ 5   │ 4738     │ 0.2     │ 0.22971   │ 0.206838  │
# │ 6   │ 4739     │ 0.2     │ 0.18429   │ 0.186954  │
# │ 7   │ 5869     │ -0.2    │ 0.0       │ -0.103961 │
# │ 8   │ 5871     │ 0.2     │ 0.177081  │ 0.194336  │
# │ 9   │ 5872     │ 0.2     │ 0.291062  │ 0.23407   │
# │ 10  │ 6525     │ -0.2    │ -0.189554 │ -0.183272 │
# │ 11  │ 6533     │ -0.2    │ 0.0       │ 0.0       │
# │ 12  │ 6539     │ -0.2    │ 0.0       │ 0.0       │
# │ 13  │ 9061     │ 0.2     │ 0.0       │ 0.0920841 │
# │ 14  │ 9070     │ 0.2     │ 0.233495  │ 0.219509  │
# │ 15  │ 9074     │ -0.2    │ 0.0       │ 0.0       │
# Grouped ran: 23 iters and Ungrouped ran: 23 iters
#
#
# running 95 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 1184     │ -0.2    │ -0.16308  │ -0.156305 │
# │ 2   │ 1190     │ -0.2    │ -0.20989  │ -0.219925 │
# │ 3   │ 1200     │ 0.2     │ 0.203022  │ 0.206971  │
# │ 4   │ 5341     │ -0.2    │ -0.172083 │ -0.189019 │
# │ 5   │ 5353     │ 0.2     │ 0.0       │ 0.130051  │
# │ 6   │ 5354     │ 0.2     │ 0.365636  │ 0.265125  │
# │ 7   │ 7041     │ -0.2    │ -0.209978 │ -0.206379 │
# │ 8   │ 7044     │ 0.2     │ 0.216718  │ 0.221316  │
# │ 9   │ 7058     │ -0.2    │ -0.19644  │ -0.196156 │
# │ 10  │ 7706     │ -0.2    │ -0.147127 │ -0.14389  │
# │ 11  │ 7711     │ 0.2     │ 0.0       │ 0.0       │
# │ 12  │ 7714     │ -0.2    │ -0.210747 │ -0.2069   │
# │ 13  │ 8166     │ -0.2    │ 0.0       │ -0.105939 │
# │ 14  │ 8172     │ 0.2     │ 0.0       │ 0.0       │
# │ 15  │ 8178     │ -0.2    │ 0.0       │ 0.0       │
# Grouped ran: 24 iters and Ungrouped ran: 16 iters
#
#
# running 96 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 1407     │ 0.2     │ 0.23896   │ 0.239942  │
# │ 2   │ 1411     │ -0.2    │ -0.24118  │ -0.241719 │
# │ 3   │ 1420     │ 0.2     │ 0.196881  │ 0.194759  │
# │ 4   │ 6494     │ -0.2    │ -0.190911 │ -0.18507  │
# │ 5   │ 6499     │ 0.2     │ 0.180391  │ 0.186796  │
# │ 6   │ 6500     │ 0.2     │ 0.212204  │ 0.204972  │
# │ 7   │ 8067     │ 0.2     │ 0.202897  │ 0.206056  │
# │ 8   │ 8074     │ -0.2    │ -0.206849 │ -0.198797 │
# │ 9   │ 8077     │ -0.2    │ -0.125215 │ -0.124683 │
# │ 10  │ 8402     │ 0.2     │ 0.209077  │ 0.173364  │
# │ 11  │ 8405     │ -0.2    │ -0.221686 │ 0.0       │
# │ 12  │ 8419     │ -0.2    │ -0.208579 │ -0.223473 │
# │ 13  │ 8481     │ 0.2     │ 0.0       │ 0.127337  │
# │ 14  │ 8488     │ 0.2     │ 0.227813  │ 0.240777  │
# │ 15  │ 8491     │ -0.2    │ 0.0       │ 0.0       │
# Grouped ran: 12 iters and Ungrouped ran: 17 iters
#
#
# running 97 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 1228     │ -0.2    │ -0.235961 │ -0.241911 │
# │ 2   │ 1229     │ 0.2     │ 0.269996  │ 0.273533  │
# │ 3   │ 1230     │ -0.2    │ -0.274179 │ -0.278909 │
# │ 4   │ 6024     │ -0.2    │ -0.211633 │ -0.201897 │
# │ 5   │ 6032     │ -0.2    │ -0.174293 │ -0.174709 │
# │ 6   │ 6038     │ -0.2    │ -0.197041 │ -0.19702  │
# │ 7   │ 8002     │ 0.2     │ 0.197829  │ 0.209364  │
# │ 8   │ 8004     │ 0.2     │ 0.248562  │ 0.249517  │
# │ 9   │ 8017     │ -0.2    │ -0.180733 │ -0.187178 │
# │ 10  │ 9153     │ 0.2     │ 0.0       │ 0.179741  │
# │ 11  │ 9154     │ -0.2    │ 0.0       │ -0.199542 │
# │ 12  │ 9157     │ -0.2    │ -0.192108 │ -0.185689 │
# │ 13  │ 9501     │ -0.2    │ -0.1952   │ -0.204649 │
# │ 14  │ 9512     │ 0.2     │ 0.22511   │ 0.227023  │
# │ 15  │ 9515     │ 0.2     │ 0.180592  │ 0.170195  │
# Grouped ran: 36 iters and Ungrouped ran: 23 iters
#
#
# running 98 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 363      │ -0.2    │ 0.0       │ 0.0       │
# │ 2   │ 373      │ 0.2     │ 0.130922  │ 0.131354  │
# │ 3   │ 380      │ -0.2    │ -0.136165 │ -0.133215 │
# │ 4   │ 1248     │ -0.2    │ -0.209434 │ -0.201297 │
# │ 5   │ 1256     │ 0.2     │ 0.182873  │ 0.180795  │
# │ 6   │ 1260     │ -0.2    │ -0.155899 │ -0.149603 │
# │ 7   │ 7027     │ -0.2    │ -0.234021 │ -0.234343 │
# │ 8   │ 7029     │ -0.2    │ -0.178312 │ -0.178682 │
# │ 9   │ 7030     │ 0.2     │ 0.180208  │ 0.173183  │
# │ 10  │ 7607     │ 0.2     │ 0.205997  │ 0.204461  │
# │ 11  │ 7614     │ 0.2     │ 0.236374  │ 0.227773  │
# │ 12  │ 7617     │ 0.2     │ 0.127052  │ 0.130454  │
# │ 13  │ 9763     │ 0.2     │ 0.0       │ 0.135059  │
# │ 14  │ 9765     │ -0.2    │ -0.114135 │ -0.141634 │
# │ 15  │ 9772     │ 0.2     │ 0.168979  │ 0.194977  │
# Grouped ran: 13 iters and Ungrouped ran: 18 iters
#
#
# running 99 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 924      │ 0.2     │ 0.173904  │ 0.0       │
# │ 2   │ 930      │ 0.2     │ 0.197637  │ 0.281442  │
# │ 3   │ 938      │ -0.2    │ 0.0       │ 0.0       │
# │ 4   │ 3841     │ 0.2     │ 0.0       │ 0.104513  │
# │ 5   │ 3844     │ 0.2     │ 0.0       │ 0.0       │
# │ 6   │ 3846     │ -0.2    │ -0.147201 │ -0.138106 │
# │ 7   │ 4009     │ 0.2     │ 0.205438  │ 0.214789  │
# │ 8   │ 4011     │ -0.2    │ -0.191206 │ -0.192271 │
# │ 9   │ 4013     │ -0.2    │ -0.223097 │ -0.235031 │
# │ 10  │ 4282     │ 0.2     │ 0.183221  │ 0.178042  │
# │ 11  │ 4295     │ 0.2     │ 0.146583  │ 0.109901  │
# │ 12  │ 4298     │ 0.2     │ 0.0       │ 0.0       │
# │ 13  │ 6845     │ 0.2     │ 0.0       │ 0.168411  │
# │ 14  │ 6846     │ -0.2    │ -0.166627 │ -0.256273 │
# │ 15  │ 6859     │ 0.2     │ 0.193686  │ 0.200068  │
# Grouped ran: 17 iters and Ungrouped ran: 16 iters
#
#
# running 100 th model
# compare_model = 15×4 DataFrame
# │ Row │ position │ correct │ ungrouped │ grouped   │
# │     │ Int64    │ Float64 │ Float64   │ Float64   │
# ├─────┼──────────┼─────────┼───────────┼───────────┤
# │ 1   │ 1726     │ 0.2     │ 0.22548   │ 0.243508  │
# │ 2   │ 1729     │ -0.2    │ 0.0       │ 0.0       │
# │ 3   │ 1730     │ 0.2     │ 0.0       │ 0.129585  │
# │ 4   │ 3782     │ -0.2    │ -0.263022 │ -0.255621 │
# │ 5   │ 3787     │ -0.2    │ -0.194473 │ -0.197132 │
# │ 6   │ 3796     │ 0.2     │ 0.280077  │ 0.272649  │
# │ 7   │ 3905     │ 0.2     │ 0.195482  │ 0.202634  │
# │ 8   │ 3908     │ 0.2     │ 0.153324  │ 0.160297  │
# │ 9   │ 3911     │ 0.2     │ 0.224178  │ 0.214334  │
# │ 10  │ 5044     │ -0.2    │ 0.0       │ 0.0       │
# │ 11  │ 5055     │ 0.2     │ 0.265328  │ 0.272928  │
# │ 12  │ 5057     │ 0.2     │ 0.0       │ 0.146845  │
# │ 13  │ 8462     │ 0.2     │ 0.120114  │ 0.227675  │
# │ 14  │ 8465     │ -0.2    │ -0.256597 │ -0.257596 │
# │ 15  │ 8476     │ -0.2    │ -0.156069 │ -0.15166  │
# Grouped ran: 17 iters and Ungrouped ran: 19 iters
#
#
# Group IHT found: 1212.0/1500 variantspercentage = 0.808
# Ungrouped IHT found: 1137.0/1500 variantspercentage = 0.758
# Grouped common variant standard errors = 2.0064542321863676percentage = 0.13376361547909119
# Ungrouped common variant standard errors = 1.8071407183054604percentage = 0.12047604788703069
